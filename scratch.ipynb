# %%
from functional import seq

# %%
timings_raw = """128085 compdump:107> _d_als=( _deno _asdf _aws _brew _brew_services _cockroach _deno...
101182 (eval):1> emulate -L zsh -o no_hist_expand -o extended_glob -o no_prompt_bang...
55804 compaudit:154> _i_wfiles=( )
34165 /Users/matt/.zshrc:322> PATH='/usr/local/anaconda3/condabin:/Users/matt/.asdf...
34083 /Users/matt/.zshrc:511> /usr/libexec/java_home -v 17
32074 handle_completion_insecurities:13> insecure_dirs=( )
27076 /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:17> compaudit
25117 /Users/matt/.zshrc:425> xcrun --show-sdk-path
21932 compaudit:60> _i_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/...
20789 compdump:26> _d_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/l...
20462 compaudit:60> _i_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/...
17807 /usr/local/share/antigen/antigen.zsh:21> ANTIGEN_CHECK_FILES=$'/Users/matt/.z...
17732 /usr/local/opt/asdf/libexec/asdf.sh:15> ASDF_DIR=/usr/local/opt/asdf/libexec
17267 /usr/local/share/antigen/antigen.zsh:27> zcompile /Users/matt/.zshrc
16280 /Users/matt/.zshrc:319> [ -n '' ']'
16113 /Users/matt/.zshrc:322> dirname /usr/local/anaconda3/bin/conda
16008 /Users/matt/.zshrc:423> export PYTHON_CONFIGURE_OPTS='--with-openssl=/usr/loc...
15809 /usr/local/opt/asdf/libexec/asdf.sh:10> current_script_path=/usr/local/opt/as...
15547 /usr/local/share/antigen/antigen.zsh:19> [[ '' != false && -f /Users/matt/.an...
15100 compinit:498> ((  0  ))
15003 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:100> SHORT_HOST='Mateo’s MacBook Pro'
12167 compaudit:154> _i_wfiles=( )
11705 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:111> zcompdump_revision='#omz revision: c...
11666 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:124> compinit -i -d '/Users/matt/.zcompdu...
11006 compinit:489> . /Users/matt/.zcompdump
9735 compdump:42> print 'n_comps=('
9364 compinit:485> . '/Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1'
9308 iterm2_print_state_data:3> _iterm2_hostname=ResNet-21-79.resnet.ucsb.edu
9135 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:2> [[ -f /Users/matt/.zsh-u...
9052 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:3> git_version=2.36.1
8941 detect-clipboard:3> ((  1  ))
8326 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:116> grep -q -Fx '#omz fpath: /Users/matt...
7756 iterm2_print_state_data:2> [ -z '' ']'
7633 /Users/matt/.iterm2_shell_integration.zsh:150> [ -z '' ']'
7003 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:24> ls -G .
7001 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:43> diff --color /dev/nul...
6339 WARN:2> echo '[WRN][1653210536.9144039154] /usr/local/share/antigen/antigen.z...
5963 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:51> [[ ! -w /Users/matt/.oh-my-zsh/cache ]]
5655 antigen-lock:13> touch /Users/matt/.antigen/.lock
5208 compinit:502> _i_test[$_i_name]=yes
5199 (anon):7> zmodload -F zsh/stat b:zstat
5068 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
4905 add-zsh-hook:92> autoload -- _fasd_preexec
4778 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:56> mkdir -p /Users/matt/.oh-my-zsh/cache...
4707 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:115> grep -q -Fx '#omz revision: c5bfe4b5...
4625 /Users/matt/.p10k.zsh:20> setopt no_aliases no_sh_glob brace_expand
4376 /usr/local/share/antigen/antigen.zsh:63> typeset -a __deferred_compdefs
4288 /Users/matt/.zcompdump:3> _comps=( - _precommand -array-value- _value -assign...
4181 _zsh_highlight_bind_widgets:7> zmodload zsh/zleparameter
4071 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
4070 compaudit:153> _i_wdirs=( )
3876 /Users/matt/.oh-my-zsh/lib/completion.zsh:2> zmodload -i zsh/complist
3676 compaudit:16> [[ -n '' ]]
3592 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
3575 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:41> autoload -Uz +X regexp-replace VC...
3506 compdump:136> mv -f /Users/matt/.antigen/.zcompdump.ResNet-21-79.resnet.ucsb....
3491 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:3> _comps=( - _precommand -a...
3463 compinit:187> comppostfuncs=( )
3417 antigen-remove-hook:14> sed s/-antigen-hook-//
3414 -antigen-cache-generate:25> cat
3385 regexp-replace:28> [[ $4 -regex-match $2 ]]
3263 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:98> [[ darwin21.0 = darwin* ]]
3187 compinit:498> ((  0  ))
3136 -antigen-cache-generate:25> date
3068 /Users/matt/.zshrc:147> source /usr/local/opt/git-extras/share/git-extras/git...
3039 (anon):8> mtime=''
3036 /Users/matt/.iterm2_shell_integration.zsh:151> uname
3022 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
2987 /Users/matt/.oh-my-zsh/lib/functions.zsh:128> zmodload zsh/langinfo
2856 /Users/matt/.zshrc:396> source /usr/local/opt/powerlevel10k/powerlevel10k.zsh...
2825 handle_completion_insecurities:13> compaudit
2303 antigen-remove-hook:14> sed s/-antigen-hook-//
2299 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/cli.zsh:108> compdef ...
2264 antigen-remove-hook:14> sed s/-antigen-hook-//
2203 antigen-apply-lock:3> rm -f /Users/matt/.antigen/.lock
2199 /usr/local/share/antigen/antigen.zsh:29> rm -f /Users/matt/.antigen/init.zsh
2115 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/zs...
2110 compaudit:16> [[ -n '' ]]
2107 /Users/matt/.zcompdump:1981> bindkey '^[~' _bash_complete-word
2103 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
2045 compdef:131> ((  0  ))
2022 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/gi...
1960 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> rm -rf /Users/matt/.oh...
1838 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:61> source /Users/matt/.oh-my-zsh/tools/c...
1803 /Users/matt/.zshrc:130> PATH='/Users/matt/bin:/usr/local/bin:/Users/matt/.pye...
1750 (eval):1> compaudit
1741 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1815> bindkey '^[~' _bash_co...
1714 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
1711 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/th...
1688 compdump:115> print -n ' _deno'
1652 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
1635 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
1609 is_plugin:3> test -f /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh
1592 /Users/matt/.antigen/init.zsh:60> source /Users/matt/.antigen/bundles/robbyru...
1575 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
1575 (anon):15> mkdir /Users/matt/.oh-my-zsh/log/update.lock
1519 /Users/matt/.zshrc:224> . /usr/local/opt/asdf/libexec/asdf.sh
1518 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
1510 is_theme:3> test -f /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme
1494 antigen-remove-hook:12> [[ 0 == 0 ]]
1480 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
1462 compaudit:153> _i_wdirs=( )
1457 compdef:169> shift
1439 compinit:503> read -rA _i_line
1407 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/diagnostics.zsh:56> a...
1406 _zsh_highlight__function_callable_p:13> autoload -U +X -- add-zle-hook-widget
1402 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:74> orig_comp=''
1400 (anon):42> ((  ( 19134 - 19130 ) < 13  ))
1380 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
1358 antigen-remove-hook:12> [[ 0 == 0 ]]
1328 antigen-remove-hook:12> [[ 0 == 0 ]]
1312 -antigen-cache-generate:25> print ''/Users/matt/.antigen/bundles/robbyrussell...
1304 compdump:101> print
1299 compdef:94> [[ -n yes ]]
1288 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1817> autoload -Uz _deno _as...
1285 -antigen-cache-generate:25> functions -- _antigen
1224 -antigen-cache-generate:25> print ''https://github.com/robbyrussell/oh-my-zsh...
1195 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/di...
1184 /Users/matt/.oh-my-zsh/lib/misc.zsh:7> is-at-least 5.1
1170 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:2008> autoload -Uz +X _call_...
1166 (anon):34> source /Users/matt/.oh-my-zsh/cache/.zsh-update
1156 compinit:525> compdump
1155 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
1152 compdef:94> [[ -n yes ]]
1136 /Users/matt/.oh-my-zsh/lib/diagnostics.zsh:56> autoload -Uz is-at-least
1132 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
1126 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
1108 compinit:503> read -rA _i_line
1105 /usr/local/share/antigen/antigen.zsh:25> [[ /Users/matt/.zshrc -nt /Users/mat...
1104 compdump:134> print '_comp_assocs=( '''' )'
1094 -antigen-hook-antigen-apply:4> compinit -i -d /Users/matt/.antigen/.zcompdump
1093 compdef:121> [[ -n yes ]]
1076 compdef:121> [[ -n yes ]]
1059 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
1054 compdef:94> [[ -n yes ]]
1043 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
1032 _zsh_highlight__is_function_p:2> ((  0  ))
1029 compinit:503> read -rA _i_line
1029 antigen-add-hook:23> ((  ! 0  ))
1028 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
1027 compdef:121> [[ -n yes ]]
1017 compdef:169> shift
1016 compdump:82> typeset _d_complist=''
1014 compinit:503> read -rA _i_line
1014 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:72> ((  1  ))
1008 compdef:94> [[ -n yes ]]
999 /Users/matt/.zshrc:18> source /Users/matt/.cache/p10k-instant-prompt-matt.zsh
998 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:183> source /Users/matt/.oh-my-zsh/themes...
997 (eval):1> functions[VCS_INFO_formats]=$'tsetopt localoptions noksharrays NO_s...
995 compdef:121> [[ -n yes ]]
993 compinit:535> zle -C menu-select .menu-select _main_complete
992 compdef:121> [[ -n yes ]]
986 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
978 compdef:94> [[ -n yes ]]
971 compdef:121> [[ -n yes ]]
961 compinit:503> read -rA _i_line
957 compdump:84> read -rA _d_line
956 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/vc...
955 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
951 compdef:121> [[ -n yes ]]
949 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:2> autoload -Uz is-at-least
938 compdef:121> [[ -n yes ]]
932 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
928 /Users/matt/.zshrc:523> source /usr/local/share/antigen/antigen.zsh
927 compinit:503> read -rA _i_line
923 /Users/matt/.antigen/init.zsh:53> source /Users/matt/.antigen/bundles/robbyru...
922 compinit:503> read -rA _i_line
920 /Users/matt/.zcompdump:1983> autoload -Uz _docker-compose _docker _deno _asdf...
919 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/te...
910 compinit:503> read -rA _i_line
906 /Users/matt/.antigen/init.zsh:59> source /Users/matt/.antigen/bundles/robbyru...
905 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
902 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:108> add-zsh-hook precmd omz_terms...
900 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
900 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
891 compdump:139> autoload -Uz compdump
891 /usr/local/share/antigen/antigen.zsh:1401> _ANTIGEN_EXTENSIONS=( )
891 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:22> [[ darwin21.0 == (dar...
889 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
888 compinit:535> zle -la menu-select
887 _zsh_highlight_bind_widgets:14> widgets_to_bind=( forward-word vi-add-next de...
885 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:2> colors
883 compinit:503> read -rA _i_line
880 compinit:503> read -rA _i_line
880 compdef:94> [[ -n yes ]]
877 compinit:502> _i_test[$_i_name]=yes
871 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
866 compinit:535> zle -C menu-select .menu-select _main_complete
866 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
864 compinit:502> _i_test[$_i_name]=yes
864 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
863 /Users/matt/.oh-my-zsh/lib/completion.zsh:78> autoload -U +X bashcompinit
858 /Users/matt/.zshrc:499> unalias o
845 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/sp...
844 _zsh_highlight_load_highlighters:11> local highlighter highlighter_dir
843 compinit:549> return 0
842 compinit:503> read -rA _i_line
841 /Users/matt/.zshrc:134> source /Users/matt/.iterm2_shell_integration.zsh
839 -antigen-hook-antigen-apply:5> local cdef
839 (anon):40> epoch_target=13
838 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
835 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:112> zcompdump_fpath='#omz fpath: /Users/...
830 antigen-apply-lock:2> unset _ANTIGEN_LOCK_PROCESS
800 antigen-add-hook:23> ((  ! 0  ))
798 compinit:503> read -rA _i_line
786 compinit:503> read -rA _i_line
784 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:28> [[ -n '' || -f /Users...
777 compdef:94> [[ -n yes ]]
772 compinit:503> read -rA _i_line
769 antigen-add-hook:23> ((  ! 0  ))
762 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlig...
761 -antigen-cache-generate:62> [[ true == true && -n '/Users/matt/.zshrc /Users/...
760 compinit:503> read -rA _i_line
758 compinit:503> read -rA _i_line
757 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:107> ZSH_COMPDUMP='/Users/matt/.zcompdump...
757 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
753 antigen-add-hook:23> ((  ! 0  ))
742 compinit:503> read -rA _i_line
741 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/fu...
732 compinit:503> read -rA _i_line
731 compinit:502> _i_test[$_i_name]=yes
729 compinit:502> _i_test[$_i_name]=yes
728 compinit:502> _i_test[$_i_name]=yes
720 compinit:503> read -rA _i_line
716 compinit:502> _i_test[$_i_name]=yes
716 -antigen-load:28> list=( /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/...
715 antigen-add-hook:23> ((  ! 0  ))
713 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
696 compinit:503> read -rA _i_line
695 compinit:503> read -rA _i_line
695 compinit:503> read -rA _i_line
694 compinit:503> read -rA _i_line
693 compinit:503> read -rA _i_line
682 compinit:503> read -rA _i_line
679 compinit:502> _i_test[$_i_name]=yes
676 /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:26> compinit -C
673 compinit:502> _i_test[$_i_name]=yes
669 compinit:503> read -rA _i_line
669 compinit:503> read -rA _i_line
663 compinit:503> read -rA _i_line
660 compinit:502> _i_test[$_i_name]=yes
659 compinit:502> _i_test[$_i_name]=yes
659 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/cl...
658 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
656 compdef:131> ((  21  ))
656 /Users/matt/.antigen/init.zsh:38> typeset -gaU fpath path
654 compinit:502> _i_test[$_i_name]=yes
653 /Users/matt/.zshrc:540> PATH='/usr/local/opt/make/libexec/gnubin:/usr/local/o...
652 compinit:503> read -rA _i_line
651 handle_completion_insecurities:12> local -aU insecure_dirs
650 compinit:503> read -rA _i_line
649 /Users/matt/.antigen/init.zsh:57> source /Users/matt/.antigen/bundles/robbyru...
648 compinit:503> read -rA _i_line
648 compinit:503> read -rA _i_line
648 compinit:502> _i_test[$_i_name]=yes
647 compinit:503> read -rA _i_line
644 compinit:502> _i_test[$_i_name]=yes
644 compinit:502> _i_test[$_i_name]=yes
643 compinit:502> _i_test[$_i_name]=yes
641 compinit:503> read -rA _i_line
639 compinit:503> read -rA _i_line
638 compinit:503> read -rA _i_line
637 compinit:503> read -rA _i_line
637 compinit:502> _i_test[$_i_name]=yes
637 compinit:502> _i_test[$_i_name]=yes
637 WARN:2> echo '[WRN][1653210536.8969058990] /usr/local/share/antigen/antigen.z...
637 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/cl...
636 compinit:503> read -rA _i_line
634 compinit:502> _i_test[$_i_name]=yes
633 compinit:503> read -rA _i_line
633 compinit:502> _i_test[$_i_name]=yes
632 compinit:502> _i_test[$_i_name]=yes
632 compinit:502> _i_test[$_i_name]=yes
631 /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy/pyenv-lazy.plugin.zsh:9> exp...
630 compinit:503> read -rA _i_line
629 compinit:503> read -rA _i_line
629 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> unset -f current_epoch...
629 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:36> compctl -U -K _fasd_zsh_cmd_...
628 compinit:502> _i_test[$_i_name]=yes
626 compinit:502> _i_test[$_i_name]=yes
626 compinit:502> _i_test[$_i_name]=yes
625 compinit:502> _i_test[$_i_name]=yes
623 compinit:503> read -rA _i_line
623 /Users/matt/.zshrc:101> source /Users/matt/.oh-my-zsh/oh-my-zsh.sh
622 /usr/local/share/antigen/antigen.zsh:1769> typeset -g _ZCACHE_CAPTURE_PREFIX
621 compinit:502> _i_test[$_i_name]=yes
620 compinit:503> read -rA _i_line
620 compinit:502> _i_test[$_i_name]=yes
620 /Users/matt/.zshrc:406> export PATH='/usr/local/opt/tcl-tk/bin:/Applications/...
619 compinit:503> read -rA _i_line
618 compinit:503> read -rA _i_line
618 compinit:502> _i_test[$_i_name]=yes
618 compinit:502> _i_test[$_i_name]=yes
616 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
614 compinit:502> _i_test[$_i_name]=yes
613 compinit:503> read -rA _i_line
612 compinit:502> _i_test[$_i_name]=yes
612 compinit:502> _i_test[$_i_name]=yes
612 compinit:502> _i_test[$_i_name]=yes
611 compinit:502> _i_test[$_i_name]=yes
609 compinit:502> _i_test[$_i_name]=yes
608 compinit:502> _i_test[$_i_name]=yes
608 compinit:502> _i_test[$_i_name]=yes
607 compinit:502> _i_test[$_i_name]=yes
606 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
605 compinit:502> _i_test[$_i_name]=yes
604 compinit:502> _i_test[$_i_name]=yes
603 compinit:503> read -rA _i_line
603 compinit:502> _i_test[$_i_name]=yes
603 antigen-remove-hook:14> functions -- -antigen-hook--antigen-load-env
602 compinit:502> _i_test[$_i_name]=yes
602 compinit:502> _i_test[$_i_name]=yes
602 antigen-remove-hook:14> functions -- -antigen-hook-antigen-bundle
600 compinit:502> _i_test[$_i_name]=yes
600 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/pr...
599 compinit:503> read -rA _i_line
598 compinit:502> _i_test[$_i_name]=yes
598 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:7> [[ /usr/local/bin/fasd...
597 compinit:502> _i_test[$_i_name]=yes
597 compinit:502> _i_test[$_i_name]=yes
597 compinit:502> _i_test[$_i_name]=yes
597 compinit:502> _i_test[$_i_name]=yes
596 compinit:503> read -rA _i_line
596 compinit:502> _i_test[$_i_name]=yes
596 compinit:502> _i_test[$_i_name]=yes
596 compinit:502> _i_test[$_i_name]=yes
595 compinit:503> read -rA _i_line
595 compinit:502> _i_test[$_i_name]=yes
594 compinit:502> _i_test[$_i_name]=yes
594 compinit:502> _i_test[$_i_name]=yes
593 compinit:502> _i_test[$_i_name]=yes
592 compinit:502> _i_test[$_i_name]=yes
592 compinit:502> _i_test[$_i_name]=yes
591 compinit:502> _i_test[$_i_name]=yes
591 compinit:502> _i_test[$_i_name]=yes
591 compinit:502> _i_test[$_i_name]=yes
590 compinit:503> read -rA _i_line
590 compinit:502> _i_test[$_i_name]=yes
590 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
588 compinit:503> read -rA _i_line
588 compinit:502> _i_test[$_i_name]=yes
587 compinit:503> read -rA _i_line
587 compinit:502> _i_test[$_i_name]=yes
587 compinit:502> _i_test[$_i_name]=yes
586 compinit:502> _i_test[$_i_name]=yes
586 compinit:502> _i_test[$_i_name]=yes
586 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
585 compinit:502> _i_test[$_i_name]=yes
585 compinit:502> _i_test[$_i_name]=yes
585 compinit:502> _i_test[$_i_name]=yes
585 compinit:502> _i_test[$_i_name]=yes
585 compinit:502> _i_test[$_i_name]=yes
584 compinit:502> _i_test[$_i_name]=yes
584 compinit:502> _i_test[$_i_name]=yes
584 compinit:502> _i_test[$_i_name]=yes
584 compinit:502> _i_test[$_i_name]=yes
582 compinit:502> _i_test[$_i_name]=yes
582 compinit:502> _i_test[$_i_name]=yes
581 compinit:502> _i_test[$_i_name]=yes
581 compinit:502> _i_test[$_i_name]=yes
581 compinit:502> _i_test[$_i_name]=yes
581 compinit:502> _i_test[$_i_name]=yes
581 compinit:502> _i_test[$_i_name]=yes
580 compinit:503> read -rA _i_line
580 compinit:502> _i_test[$_i_name]=yes
580 compinit:502> _i_test[$_i_name]=yes
580 compinit:502> _i_test[$_i_name]=yes
580 compinit:502> _i_test[$_i_name]=yes
580 compinit:502> _i_test[$_i_name]=yes
580 compinit:502> _i_test[$_i_name]=yes
579 compinit:502> _i_test[$_i_name]=yes
579 compinit:502> _i_test[$_i_name]=yes
579 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:159> source /Users/matt/.oh-my-zsh/plugin...
578 compinit:502> _i_test[$_i_name]=yes
578 compinit:502> _i_test[$_i_name]=yes
578 compinit:502> _i_test[$_i_name]=yes
577 compinit:502> _i_test[$_i_name]=yes
577 compinit:502> _i_test[$_i_name]=yes
577 compinit:502> _i_test[$_i_name]=yes
577 compdef:95> bindkey 'e/'
576 compinit:503> read -rA _i_line
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
576 compinit:502> _i_test[$_i_name]=yes
575 compinit:502> _i_test[$_i_name]=yes
575 compinit:502> _i_test[$_i_name]=yes
575 compinit:502> _i_test[$_i_name]=yes
575 compinit:502> _i_test[$_i_name]=yes
575 antigen-remove-hook:14> functions -- -antigen-hook--antigen-load-source
574 compinit:502> _i_test[$_i_name]=yes
574 compinit:502> _i_test[$_i_name]=yes
574 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compinit:502> _i_test[$_i_name]=yes
573 compdef:122> bindkey 'C-xC-r'
572 compinit:503> read -rA _i_line
572 compinit:502> _i_test[$_i_name]=yes
572 compinit:502> _i_test[$_i_name]=yes
572 compinit:502> _i_test[$_i_name]=yes
571 compinit:503> read -rA _i_line
571 compinit:502> _i_test[$_i_name]=yes
571 compinit:502> _i_test[$_i_name]=yes
571 compinit:502> _i_test[$_i_name]=yes
571 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:166> source /Users/matt/.oh-my-zsh/custom...
570 compinit:502> _i_test[$_i_name]=yes
570 compinit:502> _i_test[$_i_name]=yes
570 compinit:502> _i_test[$_i_name]=yes
569 compinit:502> _i_test[$_i_name]=yes
569 compinit:502> _i_test[$_i_name]=yes
569 compinit:502> _i_test[$_i_name]=yes
569 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/functions.zsh:128> zm...
568 compinit:502> _i_test[$_i_name]=yes
568 compinit:502> _i_test[$_i_name]=yes
567 compinit:503> read -rA _i_line
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
567 compinit:502> _i_test[$_i_name]=yes
566 compinit:503> read -rA _i_line
566 compinit:502> _i_test[$_i_name]=yes
566 compinit:502> _i_test[$_i_name]=yes
566 compinit:502> _i_test[$_i_name]=yes
566 compinit:502> _i_test[$_i_name]=yes
566 compinit:502> _i_test[$_i_name]=yes
566 compinit:502> _i_test[$_i_name]=yes
566 /Users/matt/.antigen/init.zsh:66> source /Users/matt/.antigen/bundles/robbyru...
565 compinit:502> _i_test[$_i_name]=yes
565 compinit:502> _i_test[$_i_name]=yes
565 compinit:502> _i_test[$_i_name]=yes
565 compinit:502> _i_test[$_i_name]=yes
565 compinit:502> _i_test[$_i_name]=yes
565 compinit:502> _i_test[$_i_name]=yes
565 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:122> source /Users/matt/.oh-my-zsh/lib/co...
564 compinit:502> _i_test[$_i_name]=yes
564 compinit:502> _i_test[$_i_name]=yes
564 compinit:502> _i_test[$_i_name]=yes
564 compinit:502> _i_test[$_i_name]=yes
563 compinit:502> _i_test[$_i_name]=yes
562 compinit:503> read -rA _i_line
562 compinit:502> _i_test[$_i_name]=yes
561 compinit:503> read -rA _i_line
561 compinit:503> read -rA _i_line
561 compinit:502> _i_test[$_i_name]=yes
561 compinit:502> _i_test[$_i_name]=yes
561 compinit:502> _i_test[$_i_name]=yes
561 compinit:502> _i_test[$_i_name]=yes
561 compinit:502> _i_test[$_i_name]=yes
560 compinit:502> _i_test[$_i_name]=yes
560 compinit:502> _i_test[$_i_name]=yes
560 compinit:502> _i_test[$_i_name]=yes
559 compinit:502> _i_test[$_i_name]=yes
559 compinit:502> _i_test[$_i_name]=yes
559 compinit:502> _i_test[$_i_name]=yes
559 compinit:502> _i_test[$_i_name]=yes
559 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
558 compinit:502> _i_test[$_i_name]=yes
557 compinit:503> read -rA _i_line
557 compinit:502> _i_test[$_i_name]=yes
557 compinit:502> _i_test[$_i_name]=yes
557 compinit:502> _i_test[$_i_name]=yes
557 compinit:502> _i_test[$_i_name]=yes
557 compinit:502> _i_test[$_i_name]=yes
556 compinit:503> read -rA _i_line
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
556 compinit:502> _i_test[$_i_name]=yes
555 compinit:502> _i_test[$_i_name]=yes
555 compinit:502> _i_test[$_i_name]=yes
555 compinit:502> _i_test[$_i_name]=yes
555 compinit:502> _i_test[$_i_name]=yes
555 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
554 compinit:502> _i_test[$_i_name]=yes
553 compinit:502> _i_test[$_i_name]=yes
553 compinit:502> _i_test[$_i_name]=yes
553 /Users/matt/.antigen/init.zsh:54> source /Users/matt/.antigen/bundles/robbyru...
552 compinit:503> read -rA _i_line
552 compinit:502> _i_test[$_i_name]=yes
552 compinit:502> _i_test[$_i_name]=yes
552 compinit:502> _i_test[$_i_name]=yes
552 compinit:502> _i_test[$_i_name]=yes
551 compinit:503> read -rA _i_line
551 compinit:502> _i_test[$_i_name]=yes
551 compinit:502> _i_test[$_i_name]=yes
551 compinit:502> _i_test[$_i_name]=yes
551 compinit:502> _i_test[$_i_name]=yes
551 compinit:502> _i_test[$_i_name]=yes
551 compinit:502> _i_test[$_i_name]=yes
550 compinit:502> _i_test[$_i_name]=yes
550 compinit:502> _i_test[$_i_name]=yes
550 compinit:502> _i_test[$_i_name]=yes
550 compinit:502> _i_test[$_i_name]=yes
550 compinit:502> _i_test[$_i_name]=yes
548 compinit:502> _i_test[$_i_name]=yes
548 compinit:502> _i_test[$_i_name]=yes
548 compinit:502> _i_test[$_i_name]=yes
547 compinit:502> _i_test[$_i_name]=yes
547 compinit:502> _i_test[$_i_name]=yes
547 compinit:502> _i_test[$_i_name]=yes
547 antigen-add-hook:25> functions -- -antigen-load-env
546 compinit:502> _i_test[$_i_name]=yes
546 compinit:502> _i_test[$_i_name]=yes
546 compinit:502> _i_test[$_i_name]=yes
545 compinit:539> read -A _i_line
545 compinit:502> _i_test[$_i_name]=yes
545 compinit:502> _i_test[$_i_name]=yes
545 compinit:502> _i_test[$_i_name]=yes
545 compinit:502> _i_test[$_i_name]=yes
545 /Users/matt/.antigen/init.zsh:56> source /Users/matt/.antigen/bundles/robbyru...
545 /Users/matt/.antigen/init.zsh:52> source /Users/matt/.antigen/bundles/robbyru...
544 compinit:502> _i_test[$_i_name]=yes
544 compinit:502> _i_test[$_i_name]=yes
544 compinit:502> _i_test[$_i_name]=yes
543 compinit:502> _i_test[$_i_name]=yes
542 compinit:503> read -rA _i_line
542 compinit:502> _i_test[$_i_name]=yes
542 compinit:502> _i_test[$_i_name]=yes
542 compinit:502> _i_test[$_i_name]=yes
542 compinit:502> _i_test[$_i_name]=yes
542 compinit:502> _i_test[$_i_name]=yes
541 compinit:503> read -rA _i_line
541 compinit:503> read -rA _i_line
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 compinit:502> _i_test[$_i_name]=yes
541 /Users/matt/.antigen/init.zsh:62> source /Users/matt/.antigen/bundles/robbyru...
540 compinit:503> read -rA _i_line
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
540 compinit:502> _i_test[$_i_name]=yes
539 compinit:502> _i_test[$_i_name]=yes
539 compinit:502> _i_test[$_i_name]=yes
539 compinit:502> _i_test[$_i_name]=yes
539 compinit:502> _i_test[$_i_name]=yes
539 compinit:502> _i_test[$_i_name]=yes
538 compinit:502> _i_test[$_i_name]=yes
538 compinit:502> _i_test[$_i_name]=yes
538 compinit:502> _i_test[$_i_name]=yes
537 compinit:502> _i_test[$_i_name]=yes
537 compinit:502> _i_test[$_i_name]=yes
537 compinit:502> _i_test[$_i_name]=yes
536 compinit:503> read -rA _i_line
536 compinit:502> _i_test[$_i_name]=yes
535 compinit:503> read -rA _i_line
535 compinit:503> read -rA _i_line
535 compinit:503> read -rA _i_line
535 compinit:502> _i_test[$_i_name]=yes
535 compinit:502> _i_test[$_i_name]=yes
535 compinit:502> _i_test[$_i_name]=yes
535 compinit:502> _i_test[$_i_name]=yes
534 compinit:502> _i_test[$_i_name]=yes
534 compinit:502> _i_test[$_i_name]=yes
534 compinit:502> _i_test[$_i_name]=yes
534 compinit:502> _i_test[$_i_name]=yes
534 compinit:502> _i_test[$_i_name]=yes
533 compinit:503> read -rA _i_line
533 compinit:502> _i_test[$_i_name]=yes
533 compinit:502> _i_test[$_i_name]=yes
532 compinit:502> _i_test[$_i_name]=yes
532 compinit:502> _i_test[$_i_name]=yes
532 compinit:502> _i_test[$_i_name]=yes
532 compinit:502> _i_test[$_i_name]=yes
531 compinit:502> _i_test[$_i_name]=yes
531 compinit:502> _i_test[$_i_name]=yes
531 compinit:502> _i_test[$_i_name]=yes
531 compinit:502> _i_test[$_i_name]=yes
531 compinit:502> _i_test[$_i_name]=yes
530 compinit:503> read -rA _i_line
530 compinit:502> _i_test[$_i_name]=yes
530 compinit:502> _i_test[$_i_name]=yes
529 compinit:503> read -rA _i_line
529 compinit:503> read -rA _i_line
529 compinit:502> _i_test[$_i_name]=yes
529 compinit:502> _i_test[$_i_name]=yes
529 compinit:502> _i_test[$_i_name]=yes
529 /Users/matt/.antigen/init.zsh:58> source /Users/matt/.antigen/bundles/robbyru...
528 compinit:503> read -rA _i_line
528 compinit:503> read -rA _i_line
528 compinit:502> _i_test[$_i_name]=yes
528 compinit:502> _i_test[$_i_name]=yes
528 compinit:502> _i_test[$_i_name]=yes
528 compinit:502> _i_test[$_i_name]=yes
528 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
527 compinit:503> read -rA _i_line
527 compinit:502> _i_test[$_i_name]=yes
527 compinit:502> _i_test[$_i_name]=yes
527 compinit:502> _i_test[$_i_name]=yes
527 compinit:502> _i_test[$_i_name]=yes
526 compinit:502> _i_test[$_i_name]=yes
526 compinit:502> _i_test[$_i_name]=yes
525 compinit:502> _i_test[$_i_name]=yes
524 compinit:502> _i_test[$_i_name]=yes
523 compinit:503> read -rA _i_line
523 compinit:503> read -rA _i_line
523 compinit:502> _i_test[$_i_name]=yes
523 compinit:502> _i_test[$_i_name]=yes
523 compinit:502> _i_test[$_i_name]=yes
522 compinit:502> _i_test[$_i_name]=yes
522 compinit:502> _i_test[$_i_name]=yes
522 compinit:502> _i_test[$_i_name]=yes
521 compinit:502> _i_test[$_i_name]=yes
521 compinit:502> _i_test[$_i_name]=yes
520 compinit:503> read -rA _i_line
520 compinit:503> read -rA _i_line
520 compinit:502> _i_test[$_i_name]=yes
520 compinit:502> _i_test[$_i_name]=yes
520 compinit:502> _i_test[$_i_name]=yes
520 compinit:502> _i_test[$_i_name]=yes
520 compinit:502> _i_test[$_i_name]=yes
520 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:11> source /Users/matt/.o...
520 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/nv...
519 compinit:503> read -rA _i_line
519 compinit:502> _i_test[$_i_name]=yes
518 compinit:503> read -rA _i_line
518 compinit:502> _i_test[$_i_name]=yes
518 compinit:502> _i_test[$_i_name]=yes
518 compinit:502> _i_test[$_i_name]=yes
518 compinit:502> _i_test[$_i_name]=yes
518 compinit:502> _i_test[$_i_name]=yes
517 compinit:502> _i_test[$_i_name]=yes
517 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:27> command -v git
516 compinit:503> read -rA _i_line
516 compinit:503> read -rA _i_line
516 compinit:502> _i_test[$_i_name]=yes
516 compinit:502> _i_test[$_i_name]=yes
516 compinit:502> _i_test[$_i_name]=yes
516 compinit:502> _i_test[$_i_name]=yes
516 compinit:502> _i_test[$_i_name]=yes
515 compinit:503> read -rA _i_line
515 compinit:502> _i_test[$_i_name]=yes
515 compinit:502> _i_test[$_i_name]=yes
515 compinit:502> _i_test[$_i_name]=yes
515 compinit:502> _i_test[$_i_name]=yes
515 compinit:502> _i_test[$_i_name]=yes
514 compinit:502> _i_test[$_i_name]=yes
514 compinit:502> _i_test[$_i_name]=yes
514 compinit:502> _i_test[$_i_name]=yes
513 compinit:503> read -rA _i_line
513 compinit:502> _i_test[$_i_name]=yes
513 compinit:502> _i_test[$_i_name]=yes
513 compinit:502> _i_test[$_i_name]=yes
513 compinit:502> _i_test[$_i_name]=yes
513 compinit:502> _i_test[$_i_name]=yes
513 compinit:502> _i_test[$_i_name]=yes
512 compinit:503> read -rA _i_line
511 compinit:503> read -rA _i_line
511 compinit:503> read -rA _i_line
511 compinit:502> _i_test[$_i_name]=yes
510 compinit:503> read -rA _i_line
510 compinit:503> read -rA _i_line
509 compinit:502> _i_test[$_i_name]=yes
508 compinit:502> _i_test[$_i_name]=yes
508 compinit:502> _i_test[$_i_name]=yes
507 compinit:503> read -rA _i_line
507 compinit:502> _i_test[$_i_name]=yes
507 compinit:502> _i_test[$_i_name]=yes
507 /usr/local/opt/asdf/libexec/asdf.sh:35> . /usr/local/opt/asdf/libexec/lib/asd...
506 compinit:503> read -rA _i_line
506 compinit:503> read -rA _i_line
506 compinit:502> _i_test[$_i_name]=yes
505 compinit:502> _i_test[$_i_name]=yes
505 compinit:502> _i_test[$_i_name]=yes
505 compinit:502> _i_test[$_i_name]=yes
504 compinit:503> read -rA _i_line
504 compinit:502> _i_test[$_i_name]=yes
503 compinit:502> _i_test[$_i_name]=yes
503 compinit:502> _i_test[$_i_name]=yes
503 compinit:502> _i_test[$_i_name]=yes
501 compinit:503> read -rA _i_line
501 compinit:503> read -rA _i_line
501 compinit:502> _i_test[$_i_name]=yes
500 compinit:503> read -rA _i_line
500 compinit:502> _i_test[$_i_name]=yes
500 compinit:502> _i_test[$_i_name]=yes
500 compinit:502> _i_test[$_i_name]=yes
499 compinit:503> read -rA _i_line
499 compinit:503> read -rA _i_line
499 compinit:502> _i_test[$_i_name]=yes
498 compinit:503> read -rA _i_line
497 compinit:503> read -rA _i_line
497 compinit:502> _i_test[$_i_name]=yes
497 compinit:502> _i_test[$_i_name]=yes
497 compinit:502> _i_test[$_i_name]=yes
497 compinit:502> _i_test[$_i_name]=yes
497 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:159> source /Users/matt/.oh-my-zsh/plugin...
496 compinit:502> _i_test[$_i_name]=yes
495 compinit:503> read -rA _i_line
495 compinit:502> _i_test[$_i_name]=yes
495 compinit:502> _i_test[$_i_name]=yes
494 compinit:503> read -rA _i_line
494 compinit:503> read -rA _i_line
494 compinit:502> _i_test[$_i_name]=yes
493 compinit:502> _i_test[$_i_name]=yes
493 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
492 compinit:503> read -rA _i_line
492 compinit:502> _i_test[$_i_name]=yes
491 compinit:502> _i_test[$_i_name]=yes
491 compinit:502> _i_test[$_i_name]=yes
491 /Users/matt/.antigen/init.zsh:63> source /Users/matt/.antigen/bundles/robbyru...
490 compinit:503> read -rA _i_line
490 compinit:503> read -rA _i_line
490 compinit:502> _i_test[$_i_name]=yes
490 compinit:502> _i_test[$_i_name]=yes
490 (eval):1> compaudit
489 compinit:503> read -rA _i_line
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compinit:502> _i_test[$_i_name]=yes
489 compdef:95> read -A opt
489 /Users/matt/.zshrc:543> source /usr/local/Caskroom/google-cloud-sdk/latest/go...
488 compinit:503> read -rA _i_line
488 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/hi...
488 /Users/matt/.antigen/init.zsh:72> source /Users/matt/.antigen/bundles/zsh-use...
488 /Users/matt/.antigen/init.zsh:71> source /Users/matt/.antigen/bundles/zsh-use...
487 compinit:503> read -rA _i_line
487 compinit:502> _i_test[$_i_name]=yes
487 compinit:502> _i_test[$_i_name]=yes
487 compinit:502> _i_test[$_i_name]=yes
486 compinit:503> read -rA _i_line
486 compinit:502> _i_test[$_i_name]=yes
485 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
484 compinit:503> read -rA _i_line
484 compinit:503> read -rA _i_line
484 compinit:503> read -rA _i_line
484 compinit:503> read -rA _i_line
484 compinit:502> _i_test[$_i_name]=yes
484 compinit:502> _i_test[$_i_name]=yes
484 compinit:502> _i_test[$_i_name]=yes
483 compinit:502> _i_test[$_i_name]=yes
483 compinit:502> _i_test[$_i_name]=yes
483 compinit:502> _i_test[$_i_name]=yes
482 compinit:503> read -rA _i_line
482 compinit:503> read -rA _i_line
482 compinit:502> _i_test[$_i_name]=yes
481 compinit:502> _i_test[$_i_name]=yes
481 compinit:502> _i_test[$_i_name]=yes
481 compinit:502> _i_test[$_i_name]=yes
481 compinit:502> _i_test[$_i_name]=yes
479 compinit:503> read -rA _i_line
479 compinit:503> read -rA _i_line
479 compinit:502> _i_test[$_i_name]=yes
479 compinit:502> _i_test[$_i_name]=yes
479 compinit:502> _i_test[$_i_name]=yes
479 compinit:502> _i_test[$_i_name]=yes
478 compinit:503> read -rA _i_line
478 compinit:503> read -rA _i_line
478 compinit:502> _i_test[$_i_name]=yes
478 compinit:502> _i_test[$_i_name]=yes
477 compinit:503> read -rA _i_line
477 compinit:502> _i_test[$_i_name]=yes
477 compinit:502> _i_test[$_i_name]=yes
477 compinit:502> _i_test[$_i_name]=yes
476 compinit:503> read -rA _i_line
476 compinit:502> _i_test[$_i_name]=yes
476 compinit:502> _i_test[$_i_name]=yes
475 compinit:503> read -rA _i_line
475 compinit:503> read -rA _i_line
475 compinit:503> read -rA _i_line
475 compinit:502> _i_test[$_i_name]=yes
474 compinit:503> read -rA _i_line
474 compinit:502> _i_test[$_i_name]=yes
474 compinit:502> _i_test[$_i_name]=yes
474 compinit:502> _i_test[$_i_name]=yes
473 compinit:503> read -rA _i_line
473 compinit:502> _i_test[$_i_name]=yes
473 /Users/matt/.antigen/init.zsh:61> source /Users/matt/.antigen/bundles/robbyru...
472 compinit:502> _i_test[$_i_name]=yes
472 antigen-add-hook:25> functions -- antigen-bundle
471 compinit:503> read -rA _i_line
470 compinit:503> read -rA _i_line
470 compinit:502> _i_test[$_i_name]=yes
470 compinit:502> _i_test[$_i_name]=yes
469 compinit:503> read -rA _i_line
469 compinit:503> read -rA _i_line
469 compinit:502> _i_test[$_i_name]=yes
469 compinit:502> _i_test[$_i_name]=yes
469 compinit:502> _i_test[$_i_name]=yes
469 compinit:502> _i_test[$_i_name]=yes
469 compinit:502> _i_test[$_i_name]=yes
468 compinit:503> read -rA _i_line
468 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:78> au...
466 compinit:502> _i_test[$_i_name]=yes
466 compinit:502> _i_test[$_i_name]=yes
466 antigen-add-hook:25> functions -- antigen-apply
466 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
465 compinit:502> _i_test[$_i_name]=yes
464 compinit:503> read -rA _i_line
463 compinit:503> read -rA _i_line
463 compinit:502> _i_test[$_i_name]=yes
462 compinit:502> _i_test[$_i_name]=yes
462 compinit:502> _i_test[$_i_name]=yes
462 compinit:502> _i_test[$_i_name]=yes
462 compinit:502> _i_test[$_i_name]=yes
462 compinit:502> _i_test[$_i_name]=yes
462 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
461 compinit:502> _i_test[$_i_name]=yes
460 compinit:502> _i_test[$_i_name]=yes
460 compinit:502> _i_test[$_i_name]=yes
459 compinit:503> read -rA _i_line
459 compinit:503> read -rA _i_line
459 compinit:502> _i_test[$_i_name]=yes
458 compinit:503> read -rA _i_line
458 /Users/matt/.antigen/init.zsh:68> source /Users/matt/.antigen/bundles/robbyru...
457 compinit:503> read -rA _i_line
457 compinit:502> _i_test[$_i_name]=yes
457 compinit:502> _i_test[$_i_name]=yes
457 compinit:502> _i_test[$_i_name]=yes
457 compinit:502> _i_test[$_i_name]=yes
456 compinit:503> read -rA _i_line
456 compinit:502> _i_test[$_i_name]=yes
456 compinit:502> _i_test[$_i_name]=yes
456 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/co...
455 compinit:502> _i_test[$_i_name]=yes
454 compinit:502> _i_test[$_i_name]=yes
454 compinit:502> _i_test[$_i_name]=yes
454 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/bz...
453 compinit:503> read -rA _i_line
453 compinit:503> read -rA _i_line
453 compinit:502> _i_test[$_i_name]=yes
453 compinit:502> _i_test[$_i_name]=yes
453 compinit:502> _i_test[$_i_name]=yes
453 compinit:502> _i_test[$_i_name]=yes
453 compinit:502> _i_test[$_i_name]=yes
453 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /usr/share/zsh/5.8.1/functions/u...
452 compinit:503> read -rA _i_line
452 compinit:503> read -rA _i_line
452 compinit:502> _i_test[$_i_name]=yes
452 compinit:502> _i_test[$_i_name]=yes
452 compinit:502> _i_test[$_i_name]=yes
452 antigen-add-hook:25> functions -- antigen
451 compinit:503> read -rA _i_line
451 compinit:502> _i_test[$_i_name]=yes
451 compinit:502> _i_test[$_i_name]=yes
451 compinit:502> _i_test[$_i_name]=yes
450 compinit:502> _i_test[$_i_name]=yes
449 compinit:502> _i_test[$_i_name]=yes
449 compinit:502> _i_test[$_i_name]=yes
449 compinit:502> _i_test[$_i_name]=yes
449 compinit:502> _i_test[$_i_name]=yes
448 compinit:502> _i_test[$_i_name]=yes
448 compinit:502> _i_test[$_i_name]=yes
448 compinit:502> _i_test[$_i_name]=yes
448 compinit:502> _i_test[$_i_name]=yes
448 compinit:502> _i_test[$_i_name]=yes
446 compinit:503> read -rA _i_line
446 compinit:503> read -rA _i_line
445 compinit:502> _i_test[$_i_name]=yes
444 compinit:502> _i_test[$_i_name]=yes
443 compinit:502> _i_test[$_i_name]=yes
443 compinit:502> _i_test[$_i_name]=yes
443 antigen-add-hook:25> functions -- -antigen-load-source
442 compinit:502> _i_test[$_i_name]=yes
442 compinit:502> _i_test[$_i_name]=yes
442 compinit:502> _i_test[$_i_name]=yes
441 compinit:502> _i_test[$_i_name]=yes
440 compinit:502> _i_test[$_i_name]=yes
439 compinit:503> read -rA _i_line
439 compinit:502> _i_test[$_i_name]=yes
439 compinit:502> _i_test[$_i_name]=yes
439 compinit:502> _i_test[$_i_name]=yes
439 /Users/matt/.zshrc:544> source /usr/local/Caskroom/google-cloud-sdk/latest/go...
438 compinit:503> read -rA _i_line
438 compinit:503> read -rA _i_line
438 compinit:502> _i_test[$_i_name]=yes
438 compinit:502> _i_test[$_i_name]=yes
438 -antigen-env-setup:1> typeset -gU fpath path
437 compinit:503> read -rA _i_line
437 compinit:502> _i_test[$_i_name]=yes
437 compinit:502> _i_test[$_i_name]=yes
437 compinit:502> _i_test[$_i_name]=yes
437 compinit:502> _i_test[$_i_name]=yes
436 compinit:502> _i_test[$_i_name]=yes
436 compinit:502> _i_test[$_i_name]=yes
436 compinit:502> _i_test[$_i_name]=yes
434 compinit:502> _i_test[$_i_name]=yes
434 compinit:502> _i_test[$_i_name]=yes
434 _zsh_highlight_load_highlighters:15> . /Users/matt/.oh-my-zsh/custom/plugins/...
433 compinit:503> read -rA _i_line
432 compinit:503> read -rA _i_line
432 compinit:502> _i_test[$_i_name]=yes
432 compinit:502> _i_test[$_i_name]=yes
432 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:157> source /Users/matt/.oh-my-zsh/custom...
431 compinit:502> _i_test[$_i_name]=yes
431 compinit:502> _i_test[$_i_name]=yes
431 compinit:502> _i_test[$_i_name]=yes
431 compinit:502> _i_test[$_i_name]=yes
431 compinit:502> _i_test[$_i_name]=yes
431 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
429 compinit:502> _i_test[$_i_name]=yes
429 compinit:502> _i_test[$_i_name]=yes
429 compinit:502> _i_test[$_i_name]=yes
429 compinit:502> _i_test[$_i_name]=yes
428 compinit:549> return 0
427 compinit:502> _i_test[$_i_name]=yes
427 /Users/matt/.antigen/init.zsh:70> source /Users/matt/.antigen/bundles/robbyru...
426 compinit:502> _i_test[$_i_name]=yes
425 compinit:503> read -rA _i_line
425 compinit:502> _i_test[$_i_name]=yes
425 compinit:502> _i_test[$_i_name]=yes
425 compinit:502> _i_test[$_i_name]=yes
424 compinit:503> read -rA _i_line
424 compinit:502> _i_test[$_i_name]=yes
424 compinit:502> _i_test[$_i_name]=yes
424 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 compinit:502> _i_test[$_i_name]=yes
423 _zsh_highlight_load_highlighters:11> local highlighter highlighter_dir
422 compinit:502> _i_test[$_i_name]=yes
422 compinit:502> _i_test[$_i_name]=yes
422 compinit:502> _i_test[$_i_name]=yes
422 compinit:502> _i_test[$_i_name]=yes
422 compinit:502> _i_test[$_i_name]=yes
422 compinit:481> read -rA _i_line
421 compinit:503> read -rA _i_line
421 compinit:503> read -rA _i_line
421 compinit:503> read -rA _i_line
421 compinit:502> _i_test[$_i_name]=yes
421 compinit:502> _i_test[$_i_name]=yes
421 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
420 compinit:539> read -A _i_line
420 compinit:502> _i_test[$_i_name]=yes
420 compinit:502> _i_test[$_i_name]=yes
420 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
419 compinit:502> _i_test[$_i_name]=yes
418 compinit:503> read -rA _i_line
418 compinit:502> _i_test[$_i_name]=yes
418 compinit:502> _i_test[$_i_name]=yes
418 compinit:502> _i_test[$_i_name]=yes
418 compinit:502> _i_test[$_i_name]=yes
418 compinit:502> _i_test[$_i_name]=yes
418 /Users/matt/.oh-my-zsh/lib/grep.zsh:6> source /Users/matt/.oh-my-zsh/cache/gr...
418 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
417 compinit:503> read -rA _i_line
417 compinit:502> _i_test[$_i_name]=yes
417 compinit:502> _i_test[$_i_name]=yes
417 compinit:502> _i_test[$_i_name]=yes
417 compinit:502> _i_test[$_i_name]=yes
417 compinit:502> _i_test[$_i_name]=yes
417 compdef:95> read -A opt
416 compinit:502> _i_test[$_i_name]=yes
416 compinit:502> _i_test[$_i_name]=yes
416 compinit:502> _i_test[$_i_name]=yes
416 compinit:502> _i_test[$_i_name]=yes
415 compinit:502> _i_test[$_i_name]=yes
415 compinit:502> _i_test[$_i_name]=yes
415 compinit:502> _i_test[$_i_name]=yes
415 compdef:122> read -A opt
414 compinit:503> read -rA _i_line
414 compinit:503> read -rA _i_line
414 /Users/matt/.zshrc:399> source /Users/matt/.p10k.zsh
413 compinit:502> _i_test[$_i_name]=yes
413 compinit:502> _i_test[$_i_name]=yes
413 compinit:502> _i_test[$_i_name]=yes
413 compinit:502> _i_test[$_i_name]=yes
412 compinit:503> read -rA _i_line
412 compinit:502> _i_test[$_i_name]=yes
412 compinit:502> _i_test[$_i_name]=yes
410 compinit:502> _i_test[$_i_name]=yes
410 compinit:502> _i_test[$_i_name]=yes
410 compinit:502> _i_test[$_i_name]=yes
410 compinit:502> _i_test[$_i_name]=yes
409 compinit:502> _i_test[$_i_name]=yes
409 compinit:502> _i_test[$_i_name]=yes
408 compinit:502> _i_test[$_i_name]=yes
408 compinit:502> _i_test[$_i_name]=yes
407 compinit:502> _i_test[$_i_name]=yes
407 compinit:502> _i_test[$_i_name]=yes
407 /Users/matt/.antigen/init.zsh:51> source /Users/matt/.antigen/bundles/robbyru...
406 compinit:502> _i_test[$_i_name]=yes
406 compinit:502> _i_test[$_i_name]=yes
406 compinit:502> _i_test[$_i_name]=yes
406 compinit:502> _i_test[$_i_name]=yes
406 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
405 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:275> alias 'gsi=git submodu...
405 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:159> source /Users/matt/.oh-my-zsh/plugin...
404 compinit:502> _i_test[$_i_name]=yes
404 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
403 _zsh_highlight_load_highlighters:15> . /Users/matt/.antigen/bundles/zsh-users...
402 compinit:503> read -rA _i_line
402 compinit:502> _i_test[$_i_name]=yes
402 compinit:502> _i_test[$_i_name]=yes
402 compinit:502> _i_test[$_i_name]=yes
402 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
401 compinit:502> _i_test[$_i_name]=yes
400 compinit:503> read -rA _i_line
400 compinit:502> _i_test[$_i_name]=yes
400 compinit:502> _i_test[$_i_name]=yes
399 compinit:502> _i_test[$_i_name]=yes
399 compinit:502> _i_test[$_i_name]=yes
399 compinit:502> _i_test[$_i_name]=yes
398 compinit:502> _i_test[$_i_name]=yes
398 compinit:502> _i_test[$_i_name]=yes
398 compdef:95> read -A opt
397 compinit:502> _i_test[$_i_name]=yes
397 compinit:502> _i_test[$_i_name]=yes
397 compinit:502> _i_test[$_i_name]=yes
397 compinit:502> _i_test[$_i_name]=yes
396 compinit:502> _i_test[$_i_name]=yes
396 compinit:502> _i_test[$_i_name]=yes
396 compinit:502> _i_test[$_i_name]=yes
396 compinit:502> _i_test[$_i_name]=yes
395 compinit:503> read -rA _i_line
395 compinit:502> _i_test[$_i_name]=yes
395 compinit:502> _i_test[$_i_name]=yes
395 compinit:502> _i_test[$_i_name]=yes
395 compinit:502> _i_test[$_i_name]=yes
395 compinit:502> _i_test[$_i_name]=yes
394 compinit:503> read -rA _i_line
394 compinit:502> _i_test[$_i_name]=yes
394 compinit:502> _i_test[$_i_name]=yes
394 compinit:502> _i_test[$_i_name]=yes
393 compinit:503> read -rA _i_line
393 compinit:502> _i_test[$_i_name]=yes
392 compinit:503> read -rA _i_line
392 compinit:502> _i_test[$_i_name]=yes
392 compinit:502> _i_test[$_i_name]=yes
392 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
391 compinit:502> _i_test[$_i_name]=yes
391 compinit:502> _i_test[$_i_name]=yes
391 compinit:502> _i_test[$_i_name]=yes
391 compinit:502> _i_test[$_i_name]=yes
390 compinit:539> read -A _i_line
390 compinit:503> read -rA _i_line
390 compinit:502> _i_test[$_i_name]=yes
389 compinit:502> _i_test[$_i_name]=yes
389 compinit:502> _i_test[$_i_name]=yes
389 compinit:502> _i_test[$_i_name]=yes
388 compinit:503> read -rA _i_line
388 compinit:502> _i_test[$_i_name]=yes
388 compinit:502> _i_test[$_i_name]=yes
387 compinit:502> _i_test[$_i_name]=yes
387 compinit:502> _i_test[$_i_name]=yes
387 compinit:502> _i_test[$_i_name]=yes
387 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:157> source /Users/matt/.oh-my-zsh/custom...
386 compinit:503> read -rA _i_line
386 compinit:502> _i_test[$_i_name]=yes
385 compinit:502> _i_test[$_i_name]=yes
385 compinit:502> _i_test[$_i_name]=yes
385 compinit:502> _i_test[$_i_name]=yes
384 compinit:502> _i_test[$_i_name]=yes
384 compinit:502> _i_test[$_i_name]=yes
383 compinit:502> _i_test[$_i_name]=yes
382 compinit:502> _i_test[$_i_name]=yes
382 compinit:502> _i_test[$_i_name]=yes
382 compinit:502> _i_test[$_i_name]=yes
382 compinit:502> _i_test[$_i_name]=yes
382 compinit:502> _i_test[$_i_name]=yes
381 compinit:503> read -rA _i_line
381 compinit:502> _i_test[$_i_name]=yes
381 compinit:502> _i_test[$_i_name]=yes
381 compinit:502> _i_test[$_i_name]=yes
381 compinit:502> _i_test[$_i_name]=yes
381 compinit:502> _i_test[$_i_name]=yes
380 compinit:502> _i_test[$_i_name]=yes
380 compinit:502> _i_test[$_i_name]=yes
378 compinit:503> read -rA _i_line
378 compinit:502> _i_test[$_i_name]=yes
378 compinit:502> _i_test[$_i_name]=yes
378 compinit:502> _i_test[$_i_name]=yes
378 compinit:502> _i_test[$_i_name]=yes
378 compinit:502> _i_test[$_i_name]=yes
377 compinit:503> read -rA _i_line
377 compinit:503> read -rA _i_line
377 compinit:503> read -rA _i_line
377 compinit:503> read -rA _i_line
377 compinit:502> _i_test[$_i_name]=yes
377 compinit:502> _i_test[$_i_name]=yes
377 compinit:502> _i_test[$_i_name]=yes
377 compinit:502> _i_test[$_i_name]=yes
377 compinit:502> _i_test[$_i_name]=yes
376 compinit:503> read -rA _i_line
376 compinit:503> read -rA _i_line
376 compinit:502> _i_test[$_i_name]=yes
376 compinit:502> _i_test[$_i_name]=yes
376 compdump:121> shift _d_als
375 compinit:503> read -rA _i_line
375 compinit:502> _i_test[$_i_name]=yes
375 compinit:502> _i_test[$_i_name]=yes
375 compinit:502> _i_test[$_i_name]=yes
374 compinit:503> read -rA _i_line
374 compinit:502> _i_test[$_i_name]=yes
374 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
374 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
372 compinit:502> _i_test[$_i_name]=yes
372 compinit:502> _i_test[$_i_name]=yes
372 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:157> source /Users/matt/.oh-my-zsh/custom...
371 compinit:502> _i_test[$_i_name]=yes
371 compinit:502> _i_test[$_i_name]=yes
371 compinit:502> _i_test[$_i_name]=yes
371 compinit:502> _i_test[$_i_name]=yes
371 /usr/local/opt/git-extras/share/git-extras/git-extras-completion.zsh:342> zst...
370 compinit:502> _i_test[$_i_name]=yes
370 compinit:502> _i_test[$_i_name]=yes
369 compinit:503> read -rA _i_line
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
369 compinit:502> _i_test[$_i_name]=yes
368 compinit:503> read -rA _i_line
368 compinit:502> _i_test[$_i_name]=yes
368 compinit:502> _i_test[$_i_name]=yes
367 compinit:503> read -rA _i_line
367 compinit:503> read -rA _i_line
367 compinit:503> read -rA _i_line
367 compinit:502> _i_test[$_i_name]=yes
367 compinit:502> _i_test[$_i_name]=yes
366 compinit:503> read -rA _i_line
366 compinit:503> read -rA _i_line
366 compinit:502> _i_test[$_i_name]=yes
366 compinit:502> _i_test[$_i_name]=yes
366 compinit:502> _i_test[$_i_name]=yes
366 compinit:502> _i_test[$_i_name]=yes
366 compinit:502> _i_test[$_i_name]=yes
366 compinit:502> _i_test[$_i_name]=yes
366 /Users/matt/.antigen/init.zsh:65> source /Users/matt/.antigen/bundles/robbyru...
365 compinit:503> read -rA _i_line
365 compinit:502> _i_test[$_i_name]=yes
364 compinit:503> read -rA _i_line
364 compinit:502> _i_test[$_i_name]=yes
364 compinit:502> _i_test[$_i_name]=yes
364 compinit:502> _i_test[$_i_name]=yes
364 compinit:502> _i_test[$_i_name]=yes
363 compinit:503> read -rA _i_line
363 compinit:502> _i_test[$_i_name]=yes
363 compinit:502> _i_test[$_i_name]=yes
362 compinit:503> read -rA _i_line
361 compinit:503> read -rA _i_line
361 compinit:502> _i_test[$_i_name]=yes
361 compinit:502> _i_test[$_i_name]=yes
361 compinit:502> _i_test[$_i_name]=yes
361 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/ke...
361 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/co...
360 compinit:502> _i_test[$_i_name]=yes
360 compinit:502> _i_test[$_i_name]=yes
360 compinit:502> _i_test[$_i_name]=yes
360 compinit:502> _i_test[$_i_name]=yes
359 compinit:503> read -rA _i_line
359 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
358 compinit:502> _i_test[$_i_name]=yes
358 compinit:502> _i_test[$_i_name]=yes
358 compinit:502> _i_test[$_i_name]=yes
357 compinit:503> read -rA _i_line
357 compinit:503> read -rA _i_line
357 compinit:503> read -rA _i_line
357 compinit:502> _i_test[$_i_name]=yes
356 compinit:503> read -rA _i_line
356 compinit:503> read -rA _i_line
356 compinit:503> read -rA _i_line
356 compinit:502> _i_test[$_i_name]=yes
355 compinit:503> read -rA _i_line
355 compinit:503> read -rA _i_line
355 compinit:503> read -rA _i_line
355 compinit:503> read -rA _i_line
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
355 compinit:502> _i_test[$_i_name]=yes
354 compinit:502> _i_test[$_i_name]=yes
354 compinit:502> _i_test[$_i_name]=yes
353 compinit:503> read -rA _i_line
353 compinit:503> read -rA _i_line
353 compinit:502> _i_test[$_i_name]=yes
353 compinit:502> _i_test[$_i_name]=yes
353 compinit:502> _i_test[$_i_name]=yes
353 /Users/matt/.antigen/init.zsh:69> source /Users/matt/.antigen/bundles/robbyru...
352 compinit:503> read -rA _i_line
352 compinit:503> read -rA _i_line
352 compinit:503> read -rA _i_line
352 compinit:503> read -rA _i_line
352 compinit:502> _i_test[$_i_name]=yes
351 compinit:503> read -rA _i_line
351 compinit:503> read -rA _i_line
351 compinit:502> _i_test[$_i_name]=yes
351 compinit:502> _i_test[$_i_name]=yes
351 compinit:502> _i_test[$_i_name]=yes
351 compinit:502> _i_test[$_i_name]=yes
350 compinit:503> read -rA _i_line
350 compinit:503> read -rA _i_line
350 compinit:502> _i_test[$_i_name]=yes
350 compinit:502> _i_test[$_i_name]=yes
350 compinit:502> _i_test[$_i_name]=yes
350 compinit:502> _i_test[$_i_name]=yes
350 compinit:502> _i_test[$_i_name]=yes
349 compinit:502> _i_test[$_i_name]=yes
349 compinit:502> _i_test[$_i_name]=yes
348 compinit:503> read -rA _i_line
348 compinit:502> _i_test[$_i_name]=yes
347 compinit:503> read -rA _i_line
347 compinit:502> _i_test[$_i_name]=yes
346 compinit:503> read -rA _i_line
346 compinit:502> _i_test[$_i_name]=yes
346 compinit:502> _i_test[$_i_name]=yes
346 compinit:502> _i_test[$_i_name]=yes
346 compinit:502> _i_test[$_i_name]=yes
346 compinit:502> _i_test[$_i_name]=yes
345 compinit:503> read -rA _i_line
345 compinit:503> read -rA _i_line
345 compinit:502> _i_test[$_i_name]=yes
345 compinit:502> _i_test[$_i_name]=yes
345 compinit:502> _i_test[$_i_name]=yes
345 compinit:502> _i_test[$_i_name]=yes
345 compinit:502> _i_test[$_i_name]=yes
345 compdef:95> read -A opt
345 /Users/matt/.antigen/init.zsh:67> source /Users/matt/.antigen/bundles/robbyru...
344 compinit:503> read -rA _i_line
344 compinit:503> read -rA _i_line
344 compinit:503> read -rA _i_line
344 compinit:502> _i_test[$_i_name]=yes
344 compinit:502> _i_test[$_i_name]=yes
344 compinit:502> _i_test[$_i_name]=yes
343 compinit:503> read -rA _i_line
343 compinit:502> _i_test[$_i_name]=yes
343 compinit:502> _i_test[$_i_name]=yes
343 compinit:502> _i_test[$_i_name]=yes
341 compinit:503> read -rA _i_line
341 compinit:502> _i_test[$_i_name]=yes
341 compinit:502> _i_test[$_i_name]=yes
340 compinit:503> read -rA _i_line
340 compinit:503> read -rA _i_line
340 compinit:502> _i_test[$_i_name]=yes
340 compinit:502> _i_test[$_i_name]=yes
340 compinit:502> _i_test[$_i_name]=yes
339 compinit:503> read -rA _i_line
339 compinit:502> _i_test[$_i_name]=yes
338 compinit:502> _i_test[$_i_name]=yes
337 compinit:503> read -rA _i_line
337 compinit:502> _i_test[$_i_name]=yes
337 compinit:502> _i_test[$_i_name]=yes
337 compinit:502> _i_test[$_i_name]=yes
337 /Users/matt/.antigen/init.zsh:55> source /Users/matt/.antigen/bundles/robbyru...
336 compinit:503> read -rA _i_line
336 compinit:502> _i_test[$_i_name]=yes
336 compinit:502> _i_test[$_i_name]=yes
336 compinit:502> _i_test[$_i_name]=yes
336 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
335 compinit:502> _i_test[$_i_name]=yes
334 regexp-replace:19> 4=$'tsetopt localoptions noksharrays NO_shwordsplitntlocal...
334 compinit:503> read -rA _i_line
334 compinit:502> _i_test[$_i_name]=yes
334 compinit:502> _i_test[$_i_name]=yes
333 compinit:502> _i_test[$_i_name]=yes
332 compinit:502> _i_test[$_i_name]=yes
331 compinit:502> _i_test[$_i_name]=yes
330 regexp-replace:41> eval 'functions[VCS_INFO_formats]=$'''t'''setopt localopti...
330 compinit:503> read -rA _i_line
330 compinit:502> _i_test[$_i_name]=yes
330 compinit:502> _i_test[$_i_name]=yes
330 compinit:502> _i_test[$_i_name]=yes
330 compinit:502> _i_test[$_i_name]=yes
330 compinit:502> _i_test[$_i_name]=yes
330 compinit:502> _i_test[$_i_name]=yes
330 -antigen-cache-generate:69> return true
329 compinit:502> _i_test[$_i_name]=yes
329 compinit:502> _i_test[$_i_name]=yes
329 compinit:502> _i_test[$_i_name]=yes
328 compinit:503> read -rA _i_line
328 compinit:503> read -rA _i_line
328 compinit:503> read -rA _i_line
328 compinit:502> _i_test[$_i_name]=yes
328 compinit:502> _i_test[$_i_name]=yes
327 compinit:503> read -rA _i_line
327 compinit:503> read -rA _i_line
327 compinit:503> read -rA _i_line
327 compinit:502> _i_test[$_i_name]=yes
327 compinit:502> _i_test[$_i_name]=yes
326 compinit:503> read -rA _i_line
326 compinit:502> _i_test[$_i_name]=yes
326 compinit:502> _i_test[$_i_name]=yes
326 compinit:502> _i_test[$_i_name]=yes
326 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/mi...
325 compinit:503> read -rA _i_line
325 compinit:503> read -rA _i_line
325 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:143> unset zcompdump_revision zcompdump_f...
323 compinit:502> _i_test[$_i_name]=yes
323 compinit:502> _i_test[$_i_name]=yes
322 compinit:502> _i_test[$_i_name]=yes
321 compinit:502> _i_test[$_i_name]=yes
319 compinit:503> read -rA _i_line
319 compinit:502> _i_test[$_i_name]=yes
319 compinit:502> _i_test[$_i_name]=yes
319 compinit:502> _i_test[$_i_name]=yes
318 compinit:503> read -rA _i_line
318 compinit:502> _i_test[$_i_name]=yes
317 compinit:503> read -rA _i_line
317 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
316 compinit:503> read -rA _i_line
316 compinit:503> read -rA _i_line
316 compinit:502> _i_test[$_i_name]=yes
316 compinit:502> _i_test[$_i_name]=yes
316 compdef:122> read -A opt
316 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:157> source /Users/matt/.oh-my-zsh/custom...
315 compinit:503> read -rA _i_line
315 compinit:503> read -rA _i_line
315 compinit:502> _i_test[$_i_name]=yes
315 compinit:502> _i_test[$_i_name]=yes
315 compinit:502> _i_test[$_i_name]=yes
314 compinit:503> read -rA _i_line
314 compinit:503> read -rA _i_line
314 compinit:502> _i_test[$_i_name]=yes
314 /usr/local/opt/git-extras/share/git-extras/git-extras-completion.zsh:344> zst...
312 compinit:503> read -rA _i_line
312 compinit:503> read -rA _i_line
312 compinit:503> read -rA _i_line
312 compinit:503> read -rA _i_line
312 compinit:503> read -rA _i_line
312 compinit:502> _i_test[$_i_name]=yes
312 compinit:502> _i_test[$_i_name]=yes
312 compinit:502> _i_test[$_i_name]=yes
312 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/di...
311 compinit:502> _i_test[$_i_name]=yes
310 compinit:502> _i_test[$_i_name]=yes
310 compinit:502> _i_test[$_i_name]=yes
310 compdef:95> read -A opt
309 compinit:503> read -rA _i_line
309 compinit:503> read -rA _i_line
309 compinit:502> _i_test[$_i_name]=yes
309 compinit:502> _i_test[$_i_name]=yes
309 compinit:502> _i_test[$_i_name]=yes
308 compinit:503> read -rA _i_line
308 compinit:503> read -rA _i_line
308 compinit:503> read -rA _i_line
308 compinit:502> _i_test[$_i_name]=yes
308 compinit:502> _i_test[$_i_name]=yes
307 compinit:502> _i_test[$_i_name]=yes
307 compdef:131> ((  0  ))
305 compinit:503> read -rA _i_line
305 compinit:503> read -rA _i_line
305 compinit:502> _i_test[$_i_name]=yes
305 compdef:122> read -A opt
305 /Users/matt/.antigen/init.zsh:64> source /Users/matt/.antigen/bundles/robbyru...
304 compinit:503> read -rA _i_line
304 compinit:503> read -rA _i_line
304 compinit:503> read -rA _i_line
304 compinit:502> _i_test[$_i_name]=yes
304 compdef:122> read -A opt
304 compdef:122> read -A opt
304 compdef:95> read -A opt
303 compinit:503> read -rA _i_line
303 compinit:503> read -rA _i_line
303 compinit:503> read -rA _i_line
303 compdef:122> read -A opt
302 compdef:122> read -A opt
301 compinit:503> read -rA _i_line
301 compinit:503> read -rA _i_line
299 compinit:503> read -rA _i_line
299 compinit:503> read -rA _i_line
298 compinit:503> read -rA _i_line
297 compinit:503> read -rA _i_line
296 compinit:503> read -rA _i_line
296 compinit:503> read -rA _i_line
296 compinit:503> read -rA _i_line
296 compinit:503> read -rA _i_line
295 compinit:502> _i_test[$_i_name]=yes
294 compinit:502> _i_test[$_i_name]=yes
294 compinit:502> _i_test[$_i_name]=yes
294 compinit:502> _i_test[$_i_name]=yes
294 compdump:113> ((  0  ))
294 compdump:84> read -rA _d_line
294 LOG:2> echo '[LOG][1653210536.9462730885] /usr/local/share/antigen/antigen.zs...
293 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/gr...
292 compinit:503> read -rA _i_line
292 compinit:503> read -rA _i_line
291 compinit:503> read -rA _i_line
291 compinit:502> _i_test[$_i_name]=yes
290 compinit:503> read -rA _i_line
290 compinit:503> read -rA _i_line
289 compinit:503> read -rA _i_line
289 compinit:502> _i_test[$_i_name]=yes
288 /Users/matt/.iterm2_shell_integration.zsh:33> whence -v iterm2_print_user_vars
287 compinit:503> read -rA _i_line
286 compinit:503> read -rA _i_line
284 compinit:503> read -rA _i_line
284 compinit:503> read -rA _i_line
284 compinit:502> _i_test[$_i_name]=yes
284 compinit:502> _i_test[$_i_name]=yes
283 compinit:503> read -rA _i_line
283 compinit:503> read -rA _i_line
282 compdump:48> print 'n_services=('
280 compinit:503> read -rA _i_line
279 compinit:503> read -rA _i_line
279 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
278 compinit:503> read -rA _i_line
277 compinit:503> read -rA _i_line
277 compinit:503> read -rA _i_line
276 compdump:52> print ')'
275 compdump:114> ((  ! 0  ))
274 compinit:503> read -rA _i_line
273 compinit:503> read -rA _i_line
273 compinit:503> read -rA _i_line
272 compinit:503> read -rA _i_line
272 compinit:502> _i_test[$_i_name]=yes
272 compinit:502> _i_test[$_i_name]=yes
270 compinit:503> read -rA _i_line
268 compinit:503> read -rA _i_line
268 compinit:503> read -rA _i_line
268 compinit:503> read -rA _i_line
268 compinit:503> read -rA _i_line
266 compinit:503> read -rA _i_line
266 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
264 compinit:503> read -rA _i_line
264 compinit:503> read -rA _i_line
263 compinit:503> read -rA _i_line
261 compinit:503> read -rA _i_line
261 compinit:503> read -rA _i_line
259 compinit:503> read -rA _i_line
259 compinit:502> _i_test[$_i_name]=yes
257 compdump:65> print ')'
255 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:48> [[ $'tsetopt localoptions nokshar...
253 compinit:498> ((  0  ))
252 compinit:503> read -rA _i_line
251 compinit:503> read -rA _i_line
250 LOG:2> echo '[LOG][1653210539.1364769936] /usr/local/share/antigen/antigen.zs...
248 compdump:46> print ')'
245 compinit:503> read -rA _i_line
245 compinit:503> read -rA _i_line
245 compinit:503> read -rA _i_line
243 regexp-replace:39> 5+=$'ntif [[ -n ${hook_com[action]} ]]ntthennttzstyle -a "...
243 compinit:502> _i_test[$_i_name]=yes
243 antigen-add-hook:25> eval $'function -antigen-hook-antigen-bundle () {ntTRACE...
242 compdef:14> getopts anpPkKde opt
241 compinit:503> read -rA _i_line
240 compinit:503> read -rA _i_line
238 compinit:503> read -rA _i_line
238 compinit:503> read -rA _i_line
236 compdump:121> shift _d_als
234 compinit:503> read -rA _i_line
232 compinit:502> _i_test[$_i_name]=yes
232 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
231 compinit:503> read -rA _i_line
230 compinit:503> read -rA _i_line
228 add-zle-hook-widget:105> ((  ! 1  ))
224 compinit:503> read -rA _i_line
222 compinit:503> read -rA _i_line
221 compinit:503> read -rA _i_line
221 compinit:503> read -rA _i_line
221 compinit:503> read -rA _i_line
220 compinit:503> read -rA _i_line
220 compdump:121> shift _d_als
220 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:89> fpath=( /Users/matt/.oh-my-zsh/custom...
218 compinit:503> read -rA _i_line
218 compinit:503> read -rA _i_line
218 compinit:503> read -rA _i_line
218 (eval):1> emulate -L zsh -o no_hist_expand -o extended_glob -o no_prompt_bang...
216 compinit:503> read -rA _i_line
216 compinit:503> read -rA _i_line
216 compinit:503> read -rA _i_line
215 compinit:503> read -rA _i_line
215 compdump:121> shift _d_als
214 compinit:503> read -rA _i_line
214 compinit:503> read -rA _i_line
214 /Users/matt/.zshrc:626> export PATH='/Users/matt/.rvm/gems/ruby-3.0.0/bin:/us...
213 compdump:96> [[ end-of-line = (_bash_complete-word|_bash_list-choices|_comple...
212 compinit:503> read -rA _i_line
212 compinit:503> read -rA _i_line
212 compdump:96> [[ yank-pop = (_bash_complete-word|_bash_list-choices|_complete_...
210 antigen-remove-hook:14> eval $'function antigen-bundle () {ntTRACE "Called an...
210 -antigen-hook-handler:50> -antigen-load-source-cached /Users/matt/.antigen/bu...
209 compinit:511> compdef -na _tcpsys tcp_open
208 compinit:506> case #autoload (#compdef)
206 compinit:503> read -rA _i_line
206 compinit:503> read -rA _i_line
205 compinit:503> read -rA _i_line
205 compinit:503> read -rA _i_line
205 compinit:503> read -rA _i_line
205 WARN:2> echo '[WRN][1653210536.9681220055] /usr/local/share/antigen/antigen.z...
204 compinit:503> read -rA _i_line
204 compinit:503> read -rA _i_line
204 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:111> cd -q /Users/matt/.oh-my-zsh
203 compinit:508> [[ cdbs-edit-patch = -[pPkK](n|) ]]
203 compinit:503> read -rA _i_line
202 regexp-replace:27> [[ -n $'tsetopt localoptions noksharrays NO_shwordsplitntl...
202 compinit:503> read -rA _i_line
202 compinit:503> read -rA _i_line
202 compdef:4> emulate -L zsh
201 compinit:503> read -rA _i_line
201 compinit:503> read -rA _i_line
200 compinit:503> read -rA _i_line
200 compdef:14> getopts anpPkKde opt
200 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/p...
199 compinit:503> read -rA _i_line
199 -antigen-cache-generate:63> echo '/Users/matt/.zshrcn/Users/matt/.zshrc'
198 compinit:503> read -rA _i_line
197 compinit:503> read -rA _i_line
197 compinit:503> read -rA _i_line
197 compinit:503> read -rA _i_line
196 compinit:503> read -rA _i_line
196 compinit:503> read -rA _i_line
196 compinit:503> read -rA _i_line
195 compinit:503> read -rA _i_line
195 compinit:503> read -rA _i_line
195 compinit:503> read -rA _i_line
195 compinit:503> read -rA _i_line
195 compinit:503> read -rA _i_line
194 compinit:503> read -rA _i_line
194 compinit:503> read -rA _i_line
194 compinit:503> read -rA _i_line
193 compdump:121> shift _d_als
192 compinit:503> read -rA _i_line
191 compinit:503> read -rA _i_line
191 compinit:503> read -rA _i_line
191 compinit:503> read -rA _i_line
191 -antigen-load-source-cached:1> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/...
190 compinit:503> read -rA _i_line
188 compinit:503> read -rA _i_line
188 compinit:503> read -rA _i_line
188 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
187 compinit:503> read -rA _i_line
186 compinit:503> read -rA _i_line
186 compinit:503> read -rA _i_line
186 compdef:16> autol=yes
185 compdump:84> read -rA _d_line
184 compinit:503> read -rA _i_line
184 compinit:503> read -rA _i_line
184 compinit:503> read -rA _i_line
182 compinit:503> read -rA _i_line
182 compinit:503> read -rA _i_line
182 TRACE:1> local PREFIX='[TRA][1653210536.9935579300]'
182 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/cu...
181 compinit:503> read -rA _i_line
181 compaudit:123> _i_wdirs=( )
180 compinit:503> read -rA _i_line
180 compinit:503> read -rA _i_line
180 compinit:503> read -rA _i_line
179 compinit:503> read -rA _i_line
179 compinit:503> read -rA _i_line
179 compdef:5> setopt extendedglob
179 LOG:2> echo '[LOG][1653210539.1313059330] /usr/local/share/antigen/antigen.zs...
178 compinit:503> read -rA _i_line
177 compinit:503> read -rA _i_line
177 compdump:112> print -n autoload -Uz
176 compinit:503> read -rA _i_line
176 compinit:503> read -rA _i_line
176 /Users/matt/.zcompdump:1857> _services=( '-redirect-,<,bunzip2' bunzip2 '-red...
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compinit:503> read -rA _i_line
175 compdump:94> bindkey
175 antigen-ext:9> _ANTIGEN_EXTENSIONS+=( cache )
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 compinit:503> read -rA _i_line
174 /Users/matt/.antigen/init.zsh:77> _ZCACHE_BUNDLE_SOURCE=( /Users/matt/.antige...
173 compinit:503> read -rA _i_line
173 compinit:503> read -rA _i_line
173 compinit:503> read -rA _i_line
173 compinit:503> read -rA _i_line
173 compdump:121> shift _d_als
172 compinit:503> read -rA _i_line
172 compdump:84> read -rA _d_line
172 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/c...
172 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
172 (anon):1558> trap - INT
171 compinit:503> read -rA _i_line
171 compinit:503> read -rA _i_line
171 compinit:503> read -rA _i_line
171 compinit:503> read -rA _i_line
170 compinit:503> read -rA _i_line
170 compinit:503> read -rA _i_line
170 compinit:503> read -rA _i_line
170 compinit:503> read -rA _i_line
170 compinit:503> read -rA _i_line
170 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
169 compinit:503> read -rA _i_line
169 compinit:503> read -rA _i_line
169 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:36> zmodload zsh/langinfo
168 compinit:503> read -rA _i_line
168 compinit:503> read -rA _i_line
168 compinit:503> read -rA _i_line
168 compinit:503> read -rA _i_line
168 antigen-remove-hook:14> eval $'function -antigen-load-source () {nttypeset -a...
168 /Users/matt/.zshrc:445> export PATH='/Users/matt/Library/Android/sdk/platform...
167 compinit:503> read -rA _i_line
167 compinit:503> read -rA _i_line
167 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=fasd
167 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:44> [...
166 compinit:503> read -rA _i_line
166 compinit:503> read -rA _i_line
166 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:150> source /Users/matt/.oh-my-zsh/lib/co...
166 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
166 -antigen-load:23> list=( /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-hi...
165 regexp-replace:32> 4=$'ntif [[ -n ${hook_com[action]} ]]ntthennttzstyle -a ":...
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compinit:503> read -rA _i_line
165 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
165 colors:91> colour=( 00 none 22 normal 44 bg-blue fg-red 31 01 bold 23 no-stan...
164 compinit:503> read -rA _i_line
164 compinit:503> read -rA _i_line
164 compinit:503> read -rA _i_line
164 compinit:503> read -rA _i_line
164 compinit:503> read -rA _i_line
164 compdump:121> shift _d_als
164 compdump:121> shift _d_als
164 compdef:2> local -a match mbegin mend
163 compinit:503> read -rA _i_line
163 compinit:503> read -rA _i_line
163 compinit:503> read -rA _i_line
163 compinit:503> read -rA _i_line
162 compinit:504> _i_tag='#compdef'
162 compinit:503> read -rA _i_line
162 compinit:503> read -rA _i_line
162 compinit:503> read -rA _i_line
162 antigen-remove-hook:14> eval $'function -antigen-load-env () {nttypeset -A bu...
161 compinit:503> read -rA _i_line
161 compinit:503> read -rA _i_line
161 compinit:503> read -rA _i_line
161 compinit:503> read -rA _i_line
161 compinit:502> _i_test[$_i_name]=yes
161 compdump:95> read -rA _d_line
161 compdef:5> setopt extendedglob
161 compaudit:170> return 0
161 TRACE:2> echo '[TRA][1653210536.9935579300] /usr/local/share/antigen/antigen....
161 /Users/matt/.zshrc:31> ZSH_THEME=robbyrussell
161 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
160 compinit:503> read -rA _i_line
160 compinit:503> read -rA _i_line
160 compinit:503> read -rA _i_line
160 compdump:121> shift _d_als
160 -antigen-cache-generate:4> LOG 'Gonna generate cache for /Users/matt/.antigen...
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compinit:503> read -rA _i_line
159 compaudit:123> _i_wdirs=( )
159 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/re...
159 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/li...
158 compinit:503> read -rA _i_line
158 compinit:503> read -rA _i_line
158 compinit:503> read -rA _i_line
158 compinit:503> read -rA _i_line
158 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/r...
157 compinit:503> read -rA _i_line
157 compinit:503> read -rA _i_line
157 compinit:503> read -rA _i_line
157 antigen-add-hook:25> eval $'function -antigen-hook--antigen-load-source () {n...
157 WARN:1> local PREFIX='[WRN][1653210536.9748868942]'
156 compinit:503> read -rA _i_line
156 compinit:503> read -rA _i_line
156 compinit:503> read -rA _i_line
156 compdef:17> new=yes
155 compinit:503> read -rA _i_line
155 compinit:503> read -rA _i_line
155 compinit:503> read -rA _i_line
155 compinit:503> read -rA _i_line
155 compinit:503> read -rA _i_line
155 compinit:503> read -rA _i_line
155 compdef:131> ((  0  ))
155 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/path.zsh.inc:1> ...
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compinit:503> read -rA _i_line
154 compdef:132> [[ concourse = -N ]]
154 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/pa...
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
153 compinit:503> read -rA _i_line
152 compinit:503> read -rA _i_line
152 compinit:503> read -rA _i_line
152 compinit:503> read -rA _i_line
152 compinit:503> read -rA _i_line
152 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compinit:503> read -rA _i_line
151 compdef:123> continue
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:503> read -rA _i_line
150 compinit:498> ((  0  ))
150 compdump:121> shift _d_als
150 compdump:121> shift _d_als
150 WARN:2> echo '[WRN][1653210536.9928040504] /usr/local/share/antigen/antigen.z...
150 /usr/local/share/antigen/antigen.zsh:10> autoload -U is-at-least
150 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:44> [[ iTerm.app == Apple_Terminal ]]
149 compinit:508> [[ seaf-cli = -[pPkK](n|) ]]
149 compinit:504> _i_tag='#compdef'
149 compinit:504> _i_tag='#compdef'
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compinit:503> read -rA _i_line
149 compdump:114> ((  ! 0  ))
149 WARN:2> echo '[WRN][1653210536.9426119328] /usr/local/share/antigen/antigen.z...
149 /Users/matt/.antigen/init.zsh:39> fpath+=( /Users/matt/.antigen/bundles/robby...
149 (anon):33> zle -N autosuggest-toggle _zsh_autosuggest_widget_toggle
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:503> read -rA _i_line
148 compinit:502> _i_test[$_i_name]=yes
148 compdump:121> shift _d_als
148 compdef:132> [[ swanctl = -N ]]
148 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
148 _zsh_highlight_bind_widgets:56> zle -N zle-isearch-update _zsh_highlight_widg...
148 /Users/matt/.zshrc:591> export PATH='/usr/local/opt/util-linux/sbin:/usr/loca...
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 compinit:503> read -rA _i_line
147 WARN:2> echo '[WRN][1653210536.9282801151] /usr/local/share/antigen/antigen.z...
147 LOG:2> echo '[LOG][1653210539.1359579563] /usr/local/share/antigen/antigen.zs...
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 compinit:503> read -rA _i_line
146 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/l...
146 -antigen-hook-antigen:11> return 0
145 compinit:503> read -rA _i_line
145 compinit:503> read -rA _i_line
145 compinit:503> read -rA _i_line
145 compinit:503> read -rA _i_line
145 compdump:121> shift _d_als
145 compdump:121> shift _d_als
145 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ro...
145 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-source-cached /U...
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compinit:503> read -rA _i_line
144 compdump:114> ((  ! 0  ))
144 colors:91> colour=( 00 none 22 normal 44 bg-blue fg-red 31 01 bold 23 no-stan...
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compinit:503> read -rA _i_line
143 compdef:123> continue
143 antigen-bundle-parallel-execute:41> antigen-bundle zsh-users/zsh-syntax-highl...
143 antigen-add-hook:25> eval $'function -antigen-hook-antigen-apply () {ntLOG "C...
143 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:7> FX=( reset $'%{C-[[00m%}' bold $'%...
143 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
142 compinit:503> read -rA _i_line
142 compinit:503> read -rA _i_line
142 compinit:503> read -rA _i_line
142 compinit:503> read -rA _i_line
141 compinit:503> read -rA _i_line
141 compinit:503> read -rA _i_line
141 compinit:503> read -rA _i_line
141 compdump:121> shift _d_als
141 compdef:14> getopts anpPkKde opt
141 WARN:2> echo '[WRN][1653210536.9748868942] /usr/local/share/antigen/antigen.z...
140 regexp-replace:27> [[ -n $'ntif [[ -n ${hook_com[action]} ]]ntthennttzstyle -...
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:503> read -rA _i_line
140 compinit:498> ((  0  ))
140 compdump:121> shift _d_als
140 compdef:169> shift
140 compdef:123> continue
140 compdef:9> ((  ! 4  ))
140 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
140 /Users/matt/.zshrc:620> export PATH='/Users/matt/Library/pnpm:/usr/local/opt/...
140 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/grep.zsh:4> __GREP_AL...
139 regexp-replace:43> [[ -n 1 ]]
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compinit:503> read -rA _i_line
139 compdump:115> print -n ' _dispatch'
139 compdef:159> cmd=rusage
139 compdef:123> [[ _complete_tag = undefined-key ]]
139 compdef:81> shift
138 compinit:508> [[ analyseplugin = -[pPkK](n|) ]]
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compinit:503> read -rA _i_line
138 compdef:131> ((  0  ))
138 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
138 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:134> grep -q -Fx '#omz revision: c5bfe4b5...
137 compinit:511> compdef -na _dd dd gdd
137 compinit:508> [[ wiggle = -[pPkK](n|) ]]
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 compinit:503> read -rA _i_line
137 LOG:2> echo '[LOG][1653210536.9932360649] /usr/local/share/antigen/antigen.zs...
137 /Users/matt/.zshrc:623> export PATH='/usr/local/opt/go@1.15/bin:/Users/matt/L...
137 /Users/matt/.zshrc:549> export PATH='/usr/local/opt/util-linux/bin:/usr/local...
137 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:5> export LSCOLORS=Gxfxcx...
137 /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy/pyenv-lazy.plugin.zsh:3> typ...
137 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
137 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:503> read -rA _i_line
136 compinit:502> _i_test[$_i_name]=yes
136 compdump:121> shift _d_als
136 compdef:80> [[ -n '' ]]
136 compdef:2> local -a match mbegin mend
136 (anon):26> zle -N autosuggest-toggle _zsh_autosuggest_widget_toggle
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:503> read -rA _i_line
135 compinit:502> _i_test[$_i_name]=yes
135 compdef:169> shift
135 compdef:85> [[ -n '' ]]
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compinit:503> read -rA _i_line
134 compdump:121> shift _d_als
134 compdump:84> read -rA _d_line
134 compdef:123> continue
134 compdef:123> continue
134 antigen-apply-cached:19> source /Users/matt/.antigen/init.zsh
134 -antigen-load:35> -antigen-load-source /Users/matt/.antigen/bundles/robbyruss...
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compinit:503> read -rA _i_line
133 compdump:121> shift _d_als
133 compdump:121> shift _d_als
133 compdef:123> continue
133 /Users/matt/.zshrc:336> export PATH='/usr/local/opt/icu4c/bin:/usr/local/anac...
132 compinit:504> _i_tag='#compdef'
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compinit:503> read -rA _i_line
132 compdump:121> shift _d_als
132 compdump:115> print -n ' _aws'
132 compdef:155> [[ delta = *=* ]]
132 compdef:131> ((  0  ))
132 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
132 -antigen-hook-antigen-apply:1> LOG 'Called antigen-apply'
132 (anon):5> unset -m '(POWERLEVEL9K_*|DEFAULT_USER)~POWERLEVEL9K_GITSTATUS_DIR'
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compinit:503> read -rA _i_line
131 compdump:121> shift _d_als
131 compdump:61> print 'n_postpatcomps=('
131 compdef:5> setopt extendedglob
131 -antigen-load:23> list=( /Users/matt/.antigen/bundles/zsh-users/zsh-autosugge...
130 complete:13> compdef '_bash_complete -o nospace -o default -F _python_argcomp...
130 compinit:508> [[ source = -[pPkK](n|) ]]
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compinit:503> read -rA _i_line
130 compdump:28> [[ -n '' ]]
130 /Users/matt/.zshrc:550> export PATH='/usr/local/opt/util-linux/sbin:/usr/loca...
130 /Users/matt/.oh-my-zsh/lib/grep.zsh:4> __GREP_ALIAS_CACHES=( /Users/matt/.oh-...
130 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:7> FX=( ...
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:503> read -rA _i_line
129 compinit:498> ((  0  ))
129 compdump:121> shift _d_als
129 compdef:123> continue
129 WARN:2> echo '[WRN][1653210536.9266879559] /usr/local/share/antigen/antigen.z...
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:503> read -rA _i_line
128 compinit:502> _i_test[$_i_name]=yes
128 compdump:121> shift _d_als
128 compdump:44> print -r - ''zypper'' ''_zypper''
128 compdef:96> [[ _history-complete-newer = undefined-key ]]
128 compdef:96> [[ _bash_complete-word = undefined-key ]]
128 /Users/matt/.zshrc:150> export PATH='/usr/local/opt/python/libexec/bin:/usr/l...
128 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:7> ZSH_THEME_GIT_PROMPT_...
127 compinit:503> read -rA _i_line
127 compinit:503> read -rA _i_line
127 compinit:503> read -rA _i_line
127 compinit:503> read -rA _i_line
127 compinit:503> read -rA _i_line
127 compinit:503> read -rA _i_line
127 compdef:131> ((  0  ))
127 compdef:131> ((  0  ))
127 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
127 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
126 compinit:503> read -rA _i_line
126 compinit:503> read -rA _i_line
126 compinit:503> read -rA _i_line
126 compinit:503> read -rA _i_line
126 compinit:503> read -rA _i_line
126 compinit:503> read -rA _i_line
126 -antigen-hook-handler:71> return 0
125 compinit:515> autoload -Uz _obsd_architectures
125 compinit:511> compdef -na _source source .
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compinit:503> read -rA _i_line
125 compdump:121> shift _d_als
125 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
125 TRACE:2> echo '[TRA][1653210536.9486889839] /Users/matt/.zshrc:1749n[TRA][165...
125 LOG:2> echo '[LOG][1653210539.2717499733] /usr/local/share/antigen/antigen.zs...
125 LOG:2> echo '[LOG][1653210536.9088621140] /usr/local/share/antigen/antigen.zs...
124 compinit:508> [[ printenv = -[pPkK](n|) ]]
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compinit:503> read -rA _i_line
124 compdef:123> continue
124 compdef:14> getopts anpPkKde opt
124 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1707> _services=( '-redirect...
124 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:168> unset config_file
124 -antigen-load:23> list=( )
123 compinit:503> read -rA _i_line
123 compinit:503> read -rA _i_line
123 compdump:121> shift _d_als
123 compdump:84> read -rA _d_line
123 compdef:96> [[ _history-complete-older = undefined-key ]]
123 compdef:96> [[ _expand_word = undefined-key ]]
123 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
123 WARN:2> echo '[WRN][1653210536.9480609894] /usr/local/share/antigen/antigen.z...
123 LOG:2> echo '[LOG][1653210536.9742040634] /usr/local/share/antigen/antigen.zs...
123 LOG:2> echo '[LOG][1653210536.9541649818] /usr/local/share/antigen/antigen.zs...
123 /Users/matt/.zshrc:511> export JAVA_HOME=/usr/local/Cellar/openjdk/18.0.1/lib...
123 /Users/matt/.zshrc:425> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
122 compinit:549> return 0
122 compinit:505> shift _i_line
122 compinit:503> read -rA _i_line
122 compinit:503> read -rA _i_line
122 compdump:121> shift _d_als
122 compdump:116> ((  ! --_i && 1077 > 1  ))
122 compdump:84> read -rA _d_line
122 compdump:84> read -rA _d_line
122 compdump:36> print '#files: 1094tversion: 5.8.1'
122 compdef:131> ((  0  ))
122 compdef:80> autoload -Uz _zdump
122 compdef:5> setopt extendedglob
122 antigen-add-hook:25> eval $'function -antigen-hook-antigen () {ntlocal cmd="$...
122 -antigen-hook-handler:71> return 0
121 compinit:540> [[ expand-or-complete = expand-or-complete ]]
121 compinit:503> read -rA _i_line
121 compinit:503> read -rA _i_line
121 compinit:503> read -rA _i_line
121 compinit:503> read -rA _i_line
121 compinit:503> read -rA _i_line
121 compinit:503> read -rA _i_line
121 compdump:96> [[ history-incremental-search-backward = (_bash_complete-word|_b...
120 compinit:503> read -rA _i_line
120 compinit:503> read -rA _i_line
120 compinit:502> _i_test[$_i_name]=yes
120 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
120 LOG:2> echo '[LOG][1653210536.9491870403] /usr/local/share/antigen/antigen.zs...
119 compinit:503> read -rA _i_line
119 compinit:503> read -rA _i_line
119 compinit:503> read -rA _i_line
119 compinit:503> read -rA _i_line
119 compinit:503> read -rA _i_line
119 compdef:151> _postpatcomps[$1]=_pbm
119 compdef:131> ((  0  ))
119 WARN:2> echo '[WRN][1653210536.9535129070] /usr/local/share/antigen/antigen.z...
119 LOG:2> echo '[LOG][1653210539.1528389454] /usr/local/share/antigen/antigen.zs...
119 /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy/pyenv-lazy.plugin.zsh:2> exp...
119 -antigen-cache-generate:58> zcompile /Users/matt/.antigen/init.zsh
118 regexp-replace:30> 5+=$'tsetopt localoptions noksharrays NO_shwordsplitntloca...
118 compinit:503> read -rA _i_line
118 compinit:503> read -rA _i_line
118 compinit:503> read -rA _i_line
118 compinit:503> read -rA _i_line
118 compinit:503> read -rA _i_line
118 compinit:502> _i_test[$_i_name]=yes
118 compdump:121> shift _d_als
118 compdump:121> shift _d_als
118 compdump:121> shift _d_als
118 compdump:121> shift _d_als
118 compdump:84> read -rA _d_line
118 compdump:83> zle -lL
118 compdef:131> ((  0  ))
118 compdef:131> ((  0  ))
118 /Users/matt/.zshrc:481> export PATH='/usr/local/opt/binutils/bin:/Users/matt/...
118 /Users/matt/.zshrc:351> export PATH='/usr/local/opt/libarchive/bin:/usr/local...
118 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:126> handle_completion_insecurities
117 compinit:503> read -rA _i_line
117 compinit:503> read -rA _i_line
117 compinit:503> read -rA _i_line
117 compinit:503> read -rA _i_line
117 compdump:128> print 'autoload -Uz +X _call_program'
117 compdump:121> shift _d_als
117 compdef:123> [[ _complete_debug = undefined-key ]]
117 compdef:80> autoload -Uz _time_zone
117 compdef:40> ((  ! 2  ))
117 compdef:5> setopt extendedglob
117 WARN:2> echo '[WRN][1653210536.9906630516] /usr/local/share/antigen/antigen.z...
117 WARN:2> echo '[WRN][1653210536.9433560371] /usr/local/share/antigen/antigen.z...
117 WARN:2> echo '[WRN][1653210536.9412178993] /usr/local/share/antigen/antigen.z...
117 WARN:2> echo '[WRN][1653210536.8987739086] /usr/local/share/antigen/antigen.z...
117 LOG:2> echo '[LOG][1653210536.9899580479] /usr/local/share/antigen/antigen.zs...
117 /usr/local/share/antigen/antigen.zsh:29> [[ -f /Users/matt/.antigen/init.zsh ]]
117 /Users/matt/.zshrc:449> export PATH='/Users/matt/.gem/ruby/3.0.0/bin:/Users/m...
117 -antigen-hook-handler:4> args=( /Users/matt/.antigen/bundles/robbyrussell/oh-...
117 -antigen-cache-generate:61> LOG 'CHECK_FILES /Users/matt/.zshrc /Users/matt/....
116 compinit:503> read -rA _i_line
116 compinit:503> read -rA _i_line
116 compinit:502> _i_test[$_i_name]=yes
116 (anon):25> trap $'n    ret=$?n    unset update_moden    unset -f current_epoc...
115 compinit:503> read -rA _i_line
115 compinit:503> read -rA _i_line
115 compinit:503> read -rA _i_line
115 compinit:503> read -rA _i_line
115 compinit:503> read -rA _i_line
115 compinit:502> _i_test[$_i_name]=yes
115 compinit:502> _i_test[$_i_name]=yes
115 compdump:121> shift _d_als
115 compdump:115> print -n ' _brew_services'
115 compdef:14> getopts anpPkKde opt
115 compaudit:170> return 0
115 antigen-add-hook:28> eval $'function antigen-bundle () {n      noglob -antige...
114 compinit:503> read -rA _i_line
114 compinit:503> read -rA _i_line
114 compinit:503> read -rA _i_line
114 compinit:503> read -rA _i_line
114 compinit:503> read -rA _i_line
114 compinit:503> read -rA _i_line
114 compinit:502> _i_test[$_i_name]=yes
114 compdump:121> shift _d_als
114 compdump:121> shift _d_als
114 compdump:84> read -rA _d_line
114 antigen-remove-hook:20> unfunction -- antigen-bundle-cached
114 add-zsh-hook:92> autoload -- omz_termsupport_preexec
114 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> return 0
114 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:162> unset plugin
113 compinit:511> compdef -na _print print printf
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:503> read -rA _i_line
113 compinit:498> ((  0  ))
113 compdump:121> shift _d_als
113 compdump:121> shift _d_als
113 compdump:121> shift _d_als
113 compdump:121> shift _d_als
113 compdump:84> read -rA _d_line
113 compdef:131> ((  0  ))
113 compdef:81> shift
113 compdef:38> shift OPTIND-1
113 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
113 /Users/matt/.zshrc:12> export skip_global_compinit=1
113 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:266> alias 'grst=git restor...
113 -antigen-hook-antigen-apply:13> unset __deferred_compdefs
112 compinit:505> shift _i_line
112 compinit:504> _i_tag='#compdef'
112 compinit:503> read -rA _i_line
112 compinit:503> read -rA _i_line
112 compinit:503> read -rA _i_line
112 compinit:503> read -rA _i_line
112 compinit:503> read -rA _i_line
112 compinit:502> _i_test[$_i_name]=yes
112 compinit:502> _i_test[$_i_name]=yes
112 compdump:121> shift _d_als
112 compdump:91> _d_bks+=( _next_tags )
112 compdef:131> ((  0  ))
112 antigen-add-hook:25> eval $'function -antigen-hook--antigen-load-env () {ntty...
112 WARN:2> echo '[WRN][1653210539.1356918812] /usr/local/share/antigen/antigen.z...
112 (eval):246> alias 'zz=fasd_cd -d -i'
111 compinit:503> read -rA _i_line
111 compinit:503> read -rA _i_line
111 compinit:502> _i_test[$_i_name]=yes
111 compdef:85> [[ -n '' ]]
111 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
111 add-zsh-hook:92> autoload -- omz_termsupport_preexec
111 WARN:2> echo '[WRN][1653210536.9318161011] /usr/local/share/antigen/antigen.z...
110 compinit:503> read -rA _i_line
110 compdump:121> shift _d_als
110 LOG:2> echo '[LOG][1653210536.9360189438] /usr/local/share/antigen/antigen.zs...
110 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:50> trap - INT
109 compinit:508> [[ readshortcut = -[pPkK](n|) ]]
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:503> read -rA _i_line
109 compinit:502> _i_test[$_i_name]=yes
109 compinit:502> _i_test[$_i_name]=yes
109 compinit:502> _i_test[$_i_name]=yes
109 WARN:2> echo '[WRN][1653210536.9824450016] /usr/local/share/antigen/antigen.z...
109 (anon):42> current_epoch
108 compinit:516> [[ '' !=  # ]]
108 compinit:511> compdef -na _svcprop svcprop
108 compinit:511> compdef -na _groups newgrp groupdel
108 compinit:504> _i_tag='#compdef'
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:503> read -rA _i_line
108 compinit:502> _i_test[$_i_name]=yes
108 compinit:502> _i_test[$_i_name]=yes
108 compinit:502> _i_test[$_i_name]=yes
108 compinit:502> _i_test[$_i_name]=yes
108 compdump:121> shift _d_als
108 compdef:131> ((  0  ))
108 compdef:123> [[ _next_tags = undefined-key ]]
108 compdef:123> [[ _correct_word = undefined-key ]]
108 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_brackets...
108 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
108 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
107 compinit:503> read -rA _i_line
107 compinit:503> read -rA _i_line
107 compinit:503> read -rA _i_line
107 compinit:503> read -rA _i_line
107 compinit:503> read -rA _i_line
107 compinit:503> read -rA _i_line
107 compinit:502> _i_test[$_i_name]=yes
107 compinit:502> _i_test[$_i_name]=yes
107 compinit:502> _i_test[$_i_name]=yes
107 compinit:502> _i_test[$_i_name]=yes
107 compdump:121> shift _d_als
107 compdump:121> shift _d_als
107 compdump:121> shift _d_als
107 compdump:121> shift _d_als
107 compdump:84> read -rA _d_line
107 compdef:131> ((  0  ))
107 compdef:85> [[ -n '' ]]
107 /Users/matt/.zshrc:491> export PATH='/usr/local/opt/binutils/bin:/Users/matt/...
107 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/r...
107 (eval):1> -antigen-lock-init
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:503> read -rA _i_line
106 compinit:502> _i_test[$_i_name]=yes
106 compinit:502> _i_test[$_i_name]=yes
106 compinit:502> _i_test[$_i_name]=yes
106 compdef:131> ((  0  ))
106 compdef:14> getopts anpPkKde opt
106 antigen-remove-hook:20> unfunction -- -antigen-load-source-cached
106 WARN:2> echo '[WRN][1653210536.9735939503] /usr/local/share/antigen/antigen.z...
106 /usr/local/share/antigen/antigen.zsh:22> ANTIGEN_CHECK_FILES=( /Users/matt/.z...
106 -antigen-load-source:1> -antigen-hook-handler -antigen-load-source /Users/mat...
106 -antigen-hook-antigen-apply:2> TRACE 'Gonna create compdump file @ apply' COM...
105 compinit:503> read -rA _i_line
105 compinit:503> read -rA _i_line
105 compinit:503> read -rA _i_line
105 compinit:503> read -rA _i_line
105 compinit:502> _i_test[$_i_name]=yes
105 compinit:502> _i_test[$_i_name]=yes
105 compinit:502> _i_test[$_i_name]=yes
105 compdump:121> shift _d_als
105 compdump:121> shift _d_als
105 compdef:131> ((  0  ))
105 compdef:14> getopts anpPkKde opt
105 WARN:2> echo '[WRN][1653210539.1321380138] /usr/local/share/antigen/antigen.z...
105 WARN:2> echo '[WRN][1653210536.9877779484] /usr/local/share/antigen/antigen.z...
105 WARN:2> echo '[WRN][1653210536.9809319973] /usr/local/share/antigen/antigen.z...
105 LOG:1> local PREFIX='[LOG][1653210536.9932360649]'
105 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
104 compinit:503> read -rA _i_line
104 compinit:503> read -rA _i_line
104 compinit:503> read -rA _i_line
104 compinit:503> read -rA _i_line
104 compinit:502> _i_test[$_i_name]=yes
104 compdump:121> shift _d_als
104 compdump:121> shift _d_als
104 compdef:80> autoload -Uz _xargs
104 compdef:14> getopts anpPkKde opt
104 WARN:2> echo '[WRN][1653210536.9925670624] /usr/local/share/antigen/antigen.z...
104 WARN:2> echo '[WRN][1653210536.9689109325] /usr/local/share/antigen/antigen.z...
104 -antigen-load:23> list=( /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/...
103 compinit:511> compdef -na _twisted twist twistd trial conch cftp ckeygen pyht...
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compinit:503> read -rA _i_line
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:121> shift _d_als
103 compdump:114> ((  ! 0  ))
103 compdump:84> read -rA _d_line
103 compdef:162> [[ -z yes || -z _samba ]]
103 compdef:162> [[ -z yes || -z _print ]]
103 compdef:131> ((  0  ))
103 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
103 _zsh_highlight_bind_widgets:27> case builtin (builtin)
103 _zsh_highlight__function_callable_p:14> return 0
103 WARN:2> echo '[WRN][1653210536.9595990181] /usr/local/share/antigen/antigen.z...
103 WARN:2> echo '[WRN][1653210536.9136290550] /usr/local/share/antigen/antigen.z...
103 LOG:2> echo '[LOG][1653210536.9760370255] /usr/local/share/antigen/antigen.zs...
103 /Users/matt/.zshrc:496> export PATH='/usr/local/opt/llvm/bin:/usr/local/opt/b...
103 /Users/matt/.oh-my-zsh/lib/cli.zsh:109> ((  1  ))
103 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
102 compinit:508> [[ tput = -[pPkK](n|) ]]
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:503> read -rA _i_line
102 compinit:502> _i_test[$_i_name]=yes
102 compinit:502> _i_test[$_i_name]=yes
102 compdump:121> shift _d_als
102 compdump:121> shift _d_als
102 compdump:121> shift _d_als
102 compdump:114> ((  ! 0  ))
102 compdef:123> [[ _complete_help = undefined-key ]]
102 compdef:2> local -a match mbegin mend
102 WARN:2> echo '[WRN][1653210536.9660480022] /usr/local/share/antigen/antigen.z...
102 WARN:2> echo '[WRN][1653210536.9277129173] /usr/local/share/antigen/antigen.z...
102 WARN:1> local PREFIX='[WRN][1653210536.8969058990]'
102 -antigen-cache-generate:65> zcompile /Users/matt/.zshrc
101 p10k:3> eval $'emulate -L zsh -o no_hist_expand -o extended_glob -o no_prompt...
101 compinit:511> compdef -na _man man apropos whatis
101 compinit:503> read -rA _i_line
101 compinit:503> read -rA _i_line
101 compinit:503> read -rA _i_line
101 compinit:503> read -rA _i_line
101 compinit:502> _i_test[$_i_name]=yes
101 compinit:502> _i_test[$_i_name]=yes
101 compinit:502> _i_test[$_i_name]=yes
101 compinit:502> _i_test[$_i_name]=yes
101 compdump:121> shift _d_als
101 compdump:121> shift _d_als
101 compdump:121> shift _d_als
101 compdump:121> shift _d_als
101 compdump:121> shift _d_als
101 compdump:121> shift _d_als
101 compdef:169> shift
101 compdef:131> ((  0  ))
101 compdef:14> getopts anpPkKde opt
101 TRACE:2> echo '[TRA][1653210536.9780349731] /usr/local/share/antigen/antigen....
101 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
101 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
100 env_default:1> [[ '' = *-export* ]]
100 compinit:539> bindkey '^i'
100 compinit:503> read -rA _i_line
100 compinit:503> read -rA _i_line
100 compinit:503> read -rA _i_line
100 compinit:502> _i_test[$_i_name]=yes
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:121> shift _d_als
100 compdump:84> read -rA _d_line
100 compdef:159> cmd=xdvi
100 compdef:131> ((  0  ))
100 compdef:131> ((  0  ))
100 compdef:14> getopts anpPkKde opt
100 WARN:2> echo '[WRN][1653210539.1319010258] /usr/local/share/antigen/antigen.z...
100 WARN:2> echo '[WRN][1653210536.9771480560] /usr/local/share/antigen/antigen.z...
100 WARN:2> echo '[WRN][1653210536.9285290241] /usr/local/share/antigen/antigen.z...
100 WARN:1> local PREFIX='[WRN][1653210536.9312219620]'
100 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
100 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/prompt_info_functions...
99 compinit:503> read -rA _i_line
99 compinit:503> read -rA _i_line
99 compinit:503> read -rA _i_line
99 compinit:503> read -rA _i_line
99 compinit:502> _i_test[$_i_name]=yes
99 compinit:502> _i_test[$_i_name]=yes
99 compinit:502> _i_test[$_i_name]=yes
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdump:121> shift _d_als
99 compdef:81> shift
99 WARN:2> echo '[WRN][1653210536.9030649662] /usr/local/share/antigen/antigen.z...
98 compinit:504> _i_tag='#compdef'
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:503> read -rA _i_line
98 compinit:502> _i_test[$_i_name]=yes
98 compinit:502> _i_test[$_i_name]=yes
98 compinit:502> _i_test[$_i_name]=yes
98 compinit:500> _i_name=_lsdev
98 compinit:498> ((  0  ))
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdump:121> shift _d_als
98 compdef:2> local -a match mbegin mend
98 WARN:2> echo '[WRN][1653210536.9813849926] /usr/local/share/antigen/antigen.z...
98 WARN:2> echo '[WRN][1653210536.9539918900] /usr/local/share/antigen/antigen.z...
98 WARN:2> echo '[WRN][1653210536.9435911179] /usr/local/share/antigen/antigen.z...
98 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:1> autoload ...
98 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
97 compinit:511> compdef -na _dirs dirs
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:503> read -rA _i_line
97 compinit:502> _i_test[$_i_name]=yes
97 compinit:502> _i_test[$_i_name]=yes
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:121> shift _d_als
97 compdump:84> read -rA _d_line
97 compdef:162> [[ -z yes || -z _top ]]
97 compdef:131> ((  0  ))
97 compdef:131> ((  0  ))
97 compdef:131> ((  0  ))
97 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
97 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
97 WARN:2> echo '[WRN][1653210536.9803979397] /usr/local/share/antigen/antigen.z...
97 WARN:2> echo '[WRN][1653210536.9555900097] /usr/local/share/antigen/antigen.z...
97 WARN:2> echo '[WRN][1653210536.9484770298] /usr/local/share/antigen/antigen.z...
97 WARN:2> echo '[WRN][1653210536.9347500801] /usr/local/share/antigen/antigen.z...
97 TRACE:2> echo '[TRA][1653210536.9850850105] /usr/local/share/antigen/antigen....
97 LOG:2> echo '[LOG][1653210539.2722671032] /usr/local/share/antigen/antigen.zs...
96 group_lazy_load:5> alias 'npm=lazy_load "nvm node npm" ". /Users/matt/.nvm/nv...
96 compinit:505> shift _i_line
96 compinit:504> _i_tag='#compdef'
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:503> read -rA _i_line
96 compinit:502> _i_test[$_i_name]=yes
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:121> shift _d_als
96 compdump:114> ((  ! 0  ))
96 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_pattern_...
96 WARN:2> echo '[WRN][1653210536.9827640057] /usr/local/share/antigen/antigen.z...
96 WARN:2> echo '[WRN][1653210536.9707241058] /usr/local/share/antigen/antigen.z...
96 WARN:2> echo '[WRN][1653210536.9657800198] /usr/local/share/antigen/antigen.z...
96 LOG:2> echo '[LOG][1653210536.9884018898] /usr/local/share/antigen/antigen.zs...
96 /usr/local/opt/asdf/libexec/asdf.sh:37> unset _under current_script_path ASDF...
96 (anon):1> eval $'emulate -L zsh -o no_hist_expand -o extended_glob -o no_prom...
95 detect-clipboard:3> ((  1  ))
95 compinit:511> compdef -na _tree tree
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:503> read -rA _i_line
95 compinit:502> _i_test[$_i_name]=yes
95 compinit:502> _i_test[$_i_name]=yes
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:121> shift _d_als
95 compdump:84> read -rA _d_line
95 compdef:162> [[ -z yes || -z _readshortcut ]]
95 antigen-remove-hook:20> unfunction -- -antigen-load-env-cached
95 /Users/matt/.zshrc:377> export PATH='/Applications/Firefox Developer Edition....
95 /Users/matt/.iterm2_shell_integration.zsh:151> [ Darwin '!=' Darwin ']'
94 compinit:511> compdef -na _wiggle wiggle
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:503> read -rA _i_line
94 compinit:502> _i_test[$_i_name]=yes
94 compinit:502> _i_test[$_i_name]=yes
94 compinit:498> ((  0  ))
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:121> shift _d_als
94 compdump:115> print -n ' _surfraw'
94 compdump:84> read -rA _d_line
94 compdef:38> shift OPTIND-1
94 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
94 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
94 WARN:2> echo '[WRN][1653210536.9529869556] /usr/local/share/antigen/antigen.z...
94 WARN:2> echo '[WRN][1653210536.9428710938] /usr/local/share/antigen/antigen.z...
94 WARN:2> echo '[WRN][1653210536.9280569553] /usr/local/share/antigen/antigen.z...
94 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:26> [[ ! -w /Users/matt/.oh...
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:503> read -rA _i_line
93 compinit:501> ((  0 + 0  ))
93 compdump:121> shift _d_als
93 compdump:121> shift _d_als
93 compdump:121> shift _d_als
93 compdump:121> shift _d_als
93 compdef:79> func=_git-pulls
93 compdef:17> new=yes
93 compdef:17> new=yes
93 compdef:14> getopts anpPkKde opt
93 compdef:5> setopt extendedglob
93 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_root_pre...
93 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_root_pre...
93 WARN:2> echo '[WRN][1653210536.9755730629] /usr/local/share/antigen/antigen.z...
93 WARN:2> echo '[WRN][1653210536.9752879143] /usr/local/share/antigen/antigen.z...
93 WARN:2> echo '[WRN][1653210536.9655408859] /usr/local/share/antigen/antigen.z...
93 WARN:1> local PREFIX='[WRN][1653210536.9824450016]'
93 TRACE:2> echo '[TRA][1653210536.9709599018] /usr/local/share/antigen/antigen....
93 LOG:2> echo '[LOG][1653210536.9468140602] /usr/local/share/antigen/antigen.zs...
93 /Users/matt/.zshrc:137> export PATH='/usr/local/bin:/usr/local/sbin:/Users/ma...
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:503> read -rA _i_line
92 compinit:502> _i_test[$_i_name]=yes
92 compinit:502> _i_test[$_i_name]=yes
92 compinit:502> _i_test[$_i_name]=yes
92 compinit:502> _i_test[$_i_name]=yes
92 compinit:502> _i_test[$_i_name]=yes
92 compinit:501> ((  0 + 0  ))
92 compinit:501> ((  0 + 0  ))
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:121> shift _d_als
92 compdump:115> print -n ' _all_matches'
92 compdef:40> ((  ! 2  ))
92 compdef:5> setopt extendedglob
92 compdef:2> local -a match mbegin mend
92 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
92 WARN:2> echo '[WRN][1653210536.9079029560] /usr/local/share/antigen/antigen.z...
92 WARN:2> echo '[WRN][1653210536.9039700031] /usr/local/share/antigen/antigen.z...
92 WARN:1> local PREFIX='[WRN][1653210536.9689109325]'
92 TRACE:2> echo '[TRA][1653210536.9625670910] /usr/local/share/antigen/antigen....
92 TRACE:2> echo '[TRA][1653210536.9458570480] /Users/matt/.zshrc:1749n[TRA][165...
92 LOG:2> echo '[LOG][1653210536.9393780231] /usr/local/share/antigen/antigen.zs...
92 LOG:1> local PREFIX='[LOG][1653210539.1313059330]'
92 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;255m%}'
92 -antigen-hook-handler:7> hooks=( -antigen-load-env-cached )
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:503> read -rA _i_line
91 compinit:502> _i_test[$_i_name]=yes
91 compinit:482> [[ _i_autodump -eq 1 && 1131 -eq 1094 ]]
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdump:121> shift _d_als
91 compdef:155> [[ man = *=* ]]
91 compdef:4> emulate -L zsh
91 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
91 antigen-add-hook:34> return 0
91 WARN:2> echo '[WRN][1653210539.1323750019] /usr/local/share/antigen/antigen.z...
91 WARN:2> echo '[WRN][1653210536.9895188808] /usr/local/share/antigen/antigen.z...
91 WARN:2> echo '[WRN][1653210536.9377849102] /usr/local/share/antigen/antigen.z...
91 TRACE:2> echo '[TRA][1653210536.9512660503] /Users/matt/.zshrc:1749n[TRA][165...
91 LOG:1> local PREFIX='[LOG][1653210536.9360189438]'
91 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
91 /Users/matt/.iterm2_shell_integration.zsh:167> printf '033]1337;ShellIntegrat...
91 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:119>...
90 compinit:504> _i_tag='#compdef'
90 compinit:503> read -rA _i_line
90 compinit:503> read -rA _i_line
90 compinit:503> read -rA _i_line
90 compinit:503> read -rA _i_line
90 compinit:503> read -rA _i_line
90 compinit:502> _i_test[$_i_name]=yes
90 compdump:124> print
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:121> shift _d_als
90 compdump:115> print -n ' _brew'
90 compdump:84> read -rA _d_line
90 compdef:169> shift
90 compdef:14> getopts anpPkKde opt
90 _zsh_highlight_bind_widgets:25> local cur_widget
90 LOG:2> echo '[LOG][1653210536.9903640747] /usr/local/share/antigen/antigen.zs...
90 /usr/local/opt/asdf/libexec/asdf.sh:27> [[ ':/usr/local/opt/curl/bin:/usr/loc...
90 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1757> _postpatcomps=( '(p[bg...
90 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:91> fpath=( /Users/matt/.oh-my-zsh/plugin...
89 compinit:505> shift _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:503> read -rA _i_line
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compinit:502> _i_test[$_i_name]=yes
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:121> shift _d_als
89 compdump:84> read -rA _d_line
89 compdef:139> case  (postpattern)
89 compdef:131> ((  0  ))
89 compdef:131> ((  0  ))
89 compdef:85> [[ -n '' ]]
89 compdef:81> shift
89 compdef:2> local -a match mbegin mend
89 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_pattern_...
89 WARN:2> echo '[WRN][1653210536.9848880768] /usr/local/share/antigen/antigen.z...
89 WARN:2> echo '[WRN][1653210536.9830529690] /usr/local/share/antigen/antigen.z...
89 WARN:2> echo '[WRN][1653210536.9731121063] /usr/local/share/antigen/antigen.z...
89 WARN:2> echo '[WRN][1653210536.9610900879] /usr/local/share/antigen/antigen.z...
89 WARN:2> echo '[WRN][1653210536.9581029415] /usr/local/share/antigen/antigen.z...
89 WARN:2> echo '[WRN][1653210536.9490199089] /usr/local/share/antigen/antigen.z...
89 /usr/local/share/antigen/antigen.zsh:49> _ANTIGEN_INSTALL_DIR=/usr/local/Cell...
89 /Users/matt/.zshrc:355> export PATH='/usr/local/opt/gnu-getopt/bin:/usr/local...
89 /Users/matt/.zcompdump:1920> _postpatcomps=( '(p[bgpn]m*|*top[bgpn]m)' _pbm '...
89 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:89> fpath=( /Users/matt/.oh-my-zsh/custom...
89 /Users/matt/.oh-my-zsh/lib/misc.zsh:1> autoload -Uz is-at-least
88 current_epoch:1> zmodload zsh/datetime
88 compinit:540> [[ expand-or-complete = expand-or-complete ]]
88 compinit:508> [[ choc = -[pPkK](n|) ]]
88 compinit:504> _i_tag='#compdef'
88 compinit:504> _i_tag='#compdef'
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:503> read -rA _i_line
88 compinit:502> _i_test[$_i_name]=yes
88 compinit:502> _i_test[$_i_name]=yes
88 compinit:502> _i_test[$_i_name]=yes
88 compinit:502> _i_test[$_i_name]=yes
88 compinit:502> _i_test[$_i_name]=yes
88 compinit:502> _i_test[$_i_name]=yes
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:121> shift _d_als
88 compdump:114> ((  ! 0  ))
88 compdump:96> [[ set-mark-command = (_bash_complete-word|_bash_list-choices|_c...
88 compdump:95> read -rA _d_line
88 compdef:139> case  (pattern)
88 compdef:132> [[ unrar = -N ]]
88 compdef:131> ((  0  ))
88 compdef:131> ((  0  ))
88 compdef:131> ((  0  ))
88 compdef:80> autoload -Uz _stgit
88 compdef:17> new=yes
88 compdef:5> setopt extendedglob
88 compdef:4> emulate -L zsh
88 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
88 WARN:2> echo '[WRN][1653210536.9872930050] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9778380394] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9740309715] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9461081028] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9423990250] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9388229847] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9385180473] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9381248951] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9048819542] /usr/local/share/antigen/antigen.z...
88 WARN:2> echo '[WRN][1653210536.9033310413] /usr/local/share/antigen/antigen.z...
88 TRACE:1> local PREFIX='[TRA][1653210536.9486889839]'
88 LOG:2> echo '[LOG][1653210536.8990159035] /usr/local/share/antigen/antigen.zs...
88 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:20> ((  0  ))
88 /usr/local/opt/asdf/libexec/asdf.sh:31> PATH='/Users/matt/.asdf/shims:/usr/lo...
88 /usr/local/opt/asdf/libexec/asdf.sh:30> PATH='/usr/local/opt/asdf/libexec/bin...
88 /Users/matt/.zshrc:363> PATH='/usr/local/opt/gnu-tar/libexec/gnubin:/usr/loca...
88 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:39> ((  1  ))
88 -antigen-hook-handler:40> [[ 0 == -1 ]]
87 compinit:511> compdef -na _setfacl setfacl setfacl.exe
87 compinit:511> compdef -na _mkzsh mkzsh mkzsh.exe
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:503> read -rA _i_line
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:502> _i_test[$_i_name]=yes
87 compinit:501> ((  0 + 0  ))
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdump:121> shift _d_als
87 compdef:131> ((  0  ))
87 compdef:131> ((  0  ))
87 compdef:45> [[ -z '' ]]
87 compdef:38> shift OPTIND-1
87 compdef:14> getopts anpPkKde opt
87 compdef:2> local -a match mbegin mend
87 WARN:2> echo '[WRN][1653210536.9915490150] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9890539646] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9845941067] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9822130203] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9806630611] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9510591030] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9415469170] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9354550838] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9344339371] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9312219620] /usr/local/share/antigen/antigen.z...
87 WARN:2> echo '[WRN][1653210536.9300360680] /usr/local/share/antigen/antigen.z...
87 WARN:1> local PREFIX='[WRN][1653210536.9707241058]'
87 TRACE:2> echo '[TRA][1653210536.9537529945] /Users/matt/.zshrc:1749n[TRA][165...
87 LOG:2> echo '[LOG][1653210536.9494960308] /usr/local/share/antigen/antigen.zs...
86 iterm2_print_user_vars:1> true
86 compinit:511> compdef -na _git-pulls git-pulls
86 compinit:506> case #compdef (#compdef)
86 compinit:505> shift _i_line
86 compinit:503> read -rA _i_line
86 compinit:503> read -rA _i_line
86 compinit:503> read -rA _i_line
86 compinit:503> read -rA _i_line
86 compinit:503> read -rA _i_line
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compinit:502> _i_test[$_i_name]=yes
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:121> shift _d_als
86 compdump:113> ((  876  ))
86 compdump:84> read -rA _d_line
86 compdump:54> print 'n_patcomps=('
86 compdef:136> [[ comb = -P ]]
86 compdef:131> ((  0  ))
86 compdef:123> [[ _correct_filename = undefined-key ]]
86 compdef:14> getopts anpPkKde opt
86 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
86 antigen-apply:2> return 0
86 WARN:2> echo '[WRN][1653210536.9897890091] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9882330894] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9842069149] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9775569439] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9733400345] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9507610798] /usr/local/share/antigen/antigen.z...
86 WARN:2> echo '[WRN][1653210536.9351499081] /usr/local/share/antigen/antigen.z...
86 LOG:2> echo '[LOG][1653210536.9441480637] /usr/local/share/antigen/antigen.zs...
86 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:33> typeset -gr __p9k_in...
86 /usr/local/opt/asdf/libexec/asdf.sh:5> _under=/usr/local/opt/asdf/libexec/asd...
86 /Users/matt/.oh-my-zsh/lib/prompt_info_functions.zsh:36> ZSH_THEME_RVM_PROMPT...
86 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:83> unset orig_comp
86 -antigen-load:32> -antigen-load-env dir /Users/matt/.antigen/bundles/robbyrus...
85 compinit:508> [[ lldb = -[pPkK](n|) ]]
85 compinit:504> _i_tag='#compdef'
85 compinit:504> _i_tag='#compdef'
85 compinit:503> read -rA _i_line
85 compinit:503> read -rA _i_line
85 compinit:503> read -rA _i_line
85 compinit:503> read -rA _i_line
85 compinit:503> read -rA _i_line
85 compinit:503> read -rA _i_line
85 compinit:502> _i_test[$_i_name]=yes
85 compinit:502> _i_test[$_i_name]=yes
85 compinit:502> _i_test[$_i_name]=yes
85 compinit:502> _i_test[$_i_name]=yes
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdump:121> shift _d_als
85 compdef:162> [[ -z yes || -z _zmodload ]]
85 compdef:16> autol=yes
85 compdef:9> ((  ! 4  ))
85 WARN:2> echo '[WRN][1653210536.9758670330] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9664640427] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9473578930] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9449770451] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9418590069] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9408938885] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9383349419] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9320480824] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9315900803] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9291119576] /usr/local/share/antigen/antigen.z...
85 WARN:2> echo '[WRN][1653210536.9140360355] /usr/local/share/antigen/antigen.z...
85 LOG:2> echo '[LOG][1653210536.9815690517] /usr/local/share/antigen/antigen.zs...
85 /Users/matt/.zshrc:337> export PATH='/usr/local/opt/icu4c/sbin:/usr/local/opt...
85 /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:14> setopt extendedglob
85 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
85 -antigen-hook-handler:57> -antigen-hook-antigen-apply
84 complete:13> compdef '_bash_complete -o nospace -F _python_argcomplete' gsutil
84 compinit:504> _i_tag='#compdef'
84 compinit:504> _i_tag='#compdef'
84 compinit:503> read -rA _i_line
84 compinit:503> read -rA _i_line
84 compinit:503> read -rA _i_line
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:502> _i_test[$_i_name]=yes
84 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dict
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:121> shift _d_als
84 compdump:117> _i=5
84 compdump:44> print -r - ''fgrep'' ''_grep''
84 compdef:139> case  (*)
84 compdef:81> shift
84 compdef:14> getopts anpPkKde opt
84 compdef:9> ((  ! 3  ))
84 compdef:4> emulate -L zsh
84 compdef:4> emulate -L zsh
84 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
84 WARN:2> echo '[WRN][1653210536.9923679829] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9892809391] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9875199795] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9675359726] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9531950951] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9515130520] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9476659298] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9456670284] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9446558952] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9399080276] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9390780926] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9371500015] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9367499352] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9323499203] /usr/local/share/antigen/antigen.z...
84 WARN:2> echo '[WRN][1653210536.9288530350] /usr/local/share/antigen/antigen.z...
84 LOG:2> echo '[LOG][1653210536.9764180183] /usr/local/share/antigen/antigen.zs...
84 LOG:2> echo '[LOG][1653210536.9037830830] /usr/local/share/antigen/antigen.zs...
84 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:20> typeset -gr __p9k_ro...
84 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
83 compinit:504> _i_tag='#compdef'
83 compinit:504> _i_tag='#compdef'
83 compinit:503> read -rA _i_line
83 compinit:503> read -rA _i_line
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:502> _i_test[$_i_name]=yes
83 compinit:498> ((  0  ))
83 compdump:138> unfunction compdump
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:121> shift _d_als
83 compdump:84> read -rA _d_line
83 compdump:84> read -rA _d_line
83 compdump:44> print -r - ''bpython3-gtk'' ''_bpython''
83 compdef:162> [[ -z yes || -z _sh ]]
83 compdef:131> ((  0  ))
83 compdef:81> shift
83 compdef:49> [[ _fmadm = *=* ]]
83 compdef:38> shift OPTIND-1
83 compdef:38> shift OPTIND-1
83 compdef:4> emulate -L zsh
83 add-zle-hook-widget:38> shift 0
83 WARN:2> echo '[WRN][1653210536.9621150494] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9617240429] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9527740479] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9503710270] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9500648975] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9478809834] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9453699589] /usr/local/share/antigen/antigen.z...
83 WARN:2> echo '[WRN][1653210536.9369399548] /usr/local/share/antigen/antigen.z...
83 LOG:2> echo '[LOG][1653210536.9832410812] /usr/local/share/antigen/antigen.zs...
83 LOG:2> echo '[LOG][1653210536.9053249359] /usr/local/share/antigen/antigen.zs...
82 compinit:504> _i_tag='#autoload'
82 compinit:503> read -rA _i_line
82 compinit:503> read -rA _i_line
82 compinit:503> read -rA _i_line
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compinit:502> _i_test[$_i_name]=yes
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:121> shift _d_als
82 compdump:84> read -rA _d_line
82 compdump:84> read -rA _d_line
82 compdef:162> [[ -z yes || -z _scutil ]]
82 compdef:155> [[ stg = *=* ]]
82 compdef:139> case  (pattern)
82 compdef:132> [[ portsnap = -N ]]
82 compdef:131> ((  0  ))
82 compdef:80> [[ -n yes ]]
82 compdef:40> ((  ! 2  ))
82 compdef:9> ((  ! 12  ))
82 compdef:5> setopt extendedglob
82 compdef:2> local -a match mbegin mend
82 compdef:2> local -a match mbegin mend
82 compdef:2> local -a match mbegin mend
82 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
82 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
82 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
82 WARN:2> echo '[WRN][1653210536.9704639912] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9700880051] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9677569866] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9623780251] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9567201138] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9552149773] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9545629025] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9524610043] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9421789646] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9357130527] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9338250160] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9336249828] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9334299564] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9302320480] /usr/local/share/antigen/antigen.z...
82 WARN:2> echo '[WRN][1653210536.9086840153] /usr/local/share/antigen/antigen.z...
82 WARN:1> local PREFIX='[WRN][1653210536.9266879559]'
82 LOG:2> echo '[LOG][1653210536.9835979939] /usr/local/share/antigen/antigen.zs...
82 LOG:2> echo '[LOG][1653210536.9695029259] /usr/local/share/antigen/antigen.zs...
82 LOG:2> echo '[LOG][1653210536.9691359997] /usr/local/share/antigen/antigen.zs...
82 LOG:2> echo '[LOG][1653210536.9519650936] /usr/local/share/antigen/antigen.zs...
82 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
82 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
82 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/correction.zsh:1> [[ ...
82 -antigen-env-setup:26> -antigen-set-default ANTIGEN_LOG /dev/null
81 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestion...
81 compinit:511> compdef -na _cheat cheat
81 compinit:508> [[ spamassassin = -[pPkK](n|) ]]
81 compinit:505> shift _i_line
81 compinit:503> read -rA _i_line
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compinit:502> _i_test[$_i_name]=yes
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:121> shift _d_als
81 compdump:84> read -rA _d_line
81 compdump:44> print -r - ''-redirect-,<,gunzip'' ''_gzip''
81 compdef:131> ((  0  ))
81 compdef:131> ((  0  ))
81 compdef:131> ((  0  ))
81 compdef:95> bindkey 'C-xe'
81 compdef:83> case  (*)
81 compdef:80> autoload -Uz _sccs
81 compdef:9> ((  ! 3  ))
81 antigen:2> return 0
81 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_cursor_p...
81 WARN:2> echo '[WRN][1653210536.9920940399] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9918479919] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9773759842] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9554290771] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9547460079] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9505848885] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9451949596] /usr/local/share/antigen/antigen.z...
81 WARN:2> echo '[WRN][1653210536.9400899410] /usr/local/share/antigen/antigen.z...
81 WARN:1> local PREFIX='[WRN][1653210536.9435911179]'
81 /Users/matt/.zcompdump:1916> _patcomps=( '*/(init|rc[0-9S]#).d/*' _init_d )
81 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:13> zstyle -s :omz:update m...
81 /Users/matt/.oh-my-zsh/cache/grep-alias:3> alias 'fgrep=fgrep --color=auto --...
81 /Users/matt/.oh-my-zsh/cache/.zsh-update:1> LAST_EPOCH=19130
81 -antigen-hook-handler:56> WARN '-antigen-hook-antigen use oh-my-zsh'
80 is_theme:3> test -f /Users/matt/.oh-my-zsh/custom/robbyrussell.zsh-theme
80 compinit:539> bindkey '^i'
80 compinit:509> compdef -Pna _zftp 'zf*'
80 compinit:505> shift _i_line
80 compinit:504> _i_tag='#autoload'
80 compinit:502> _i_test[$_i_name]=yes
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdump:121> shift _d_als
80 compdef:131> ((  0  ))
80 compdef:2> local -a match mbegin mend
80 WARN:2> echo '[WRN][1653210536.9402849674] /usr/local/share/antigen/antigen.z...
80 WARN:2> echo '[WRN][1653210536.9349720478] /usr/local/share/antigen/antigen.z...
80 WARN:2> echo '[WRN][1653210536.9326000214] /usr/local/share/antigen/antigen.z...
80 WARN:2> echo '[WRN][1653210536.9304440022] /usr/local/share/antigen/antigen.z...
80 WARN:2> echo '[WRN][1653210536.9035999775] /usr/local/share/antigen/antigen.z...
80 -antigen-set-default:1> local arg_name=ANTIGEN_LOCK
79 compinit:515> autoload -Uz _x_colormapid
79 compinit:504> _i_tag='#compdef'
79 compinit:504> _i_tag='#autoload'
79 compinit:503> read -rA _i_line
79 compinit:503> read -rA _i_line
79 compinit:502> _i_test[$_i_name]=yes
79 compinit:502> _i_test[$_i_name]=yes
79 compinit:502> _i_test[$_i_name]=yes
79 compinit:502> _i_test[$_i_name]=yes
79 compinit:502> _i_test[$_i_name]=yes
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:121> shift _d_als
79 compdump:84> read -rA _d_line
79 compdef:131> ((  0  ))
79 compdef:131> ((  0  ))
79 compdef:131> ((  0  ))
79 compdef:131> ((  0  ))
79 compdef:131> ((  0  ))
79 compdef:95> bindkey 'C-xa'
79 compdef:14> getopts anpPkKde opt
79 compdef:14> getopts anpPkKde opt
79 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
79 LOG:2> echo '[LOG][1653210536.9666299820] /usr/local/share/antigen/antigen.zs...
79 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
79 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:32> c...
78 compinit:508> [[ p4 = -[pPkK](n|) ]]
78 compinit:508> [[ lsdev = -[pPkK](n|) ]]
78 compinit:506> case #autoload (#autoload)
78 compinit:506> case #autoload (#autoload)
78 compinit:505> shift _i_line
78 compinit:503> read -rA _i_line
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:502> _i_test[$_i_name]=yes
78 compinit:480> [[ -n yes ]]
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:121> shift _d_als
78 compdump:116> ((  ! --_i && 1091 > 1  ))
78 compdump:95> read -rA _d_line
78 compdump:84> read -rA _d_line
78 compdump:69> print -r - ''_call_program'' ''+X''
78 compdef:162> [[ -z yes || -z _tar ]]
78 compdef:131> ((  0  ))
78 compdef:131> ((  0  ))
78 compdef:80> [[ -n yes ]]
78 compdef:15> case n (a)
78 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
78 WARN:2> echo '[WRN][1653210536.9844160080] /usr/local/share/antigen/antigen.z...
78 WARN:2> echo '[WRN][1653210536.9702908993] /usr/local/share/antigen/antigen.z...
78 WARN:2> echo '[WRN][1653210536.9619410038] /usr/local/share/antigen/antigen.z...
78 WARN:2> echo '[WRN][1653210536.9051480293] /usr/local/share/antigen/antigen.z...
78 LOG:2> echo '[LOG][1653210536.9517130852] /usr/local/share/antigen/antigen.zs...
78 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:31> typeset -gr __p9k_in...
78 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
77 compinit:511> compdef -na _lsdev lsdev
77 compinit:505> shift _i_line
77 compinit:504> _i_tag='#compdef'
77 compinit:503> read -rA _i_line
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compinit:502> _i_test[$_i_name]=yes
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:121> shift _d_als
77 compdump:95> read -rA _d_line
77 compdump:84> read -rA _d_line
77 compdump:84> read -rA _d_line
77 compdef:132> [[ stdbuf = -N ]]
77 compdef:131> ((  0  ))
77 compdef:131> ((  0  ))
77 compdef:100> shift 3
77 compdef:81> shift
77 compdef:49> [[ _zdump = *=* ]]
77 compdef:17> new=yes
77 compdef:15> case n (a)
77 compdef:14> getopts anpPkKde opt
77 compdef:4> emulate -L zsh
77 compdef:4> emulate -L zsh
77 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
77 antigen-add-hook:34> return 0
77 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_line_paint
77 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_brackets...
77 WARN:2> echo '[WRN][1653210536.9138619900] /usr/local/share/antigen/antigen.z...
77 WARN:1> local PREFIX='[WRN][1653210536.9681220055]'
77 LOG:2> echo '[LOG][1653210536.9328980446] /usr/local/share/antigen/antigen.zs...
77 /usr/local/share/antigen/antigen.zsh:2042> ANTIGEN_DEBUG_LOG=/Users/matt/.ant...
77 /Users/matt/.zshrc:215> export PATH='/usr/local/opt/curl/bin:/usr/local/bin:/...
77 /Users/matt/.oh-my-zsh/lib/completion.zsh:45> zstyle ':completion:*' cache-pa...
77 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:48> zs...
76 compinit:511> compdef -na _postfix postconf postqueue postsuper
76 compinit:508> [[ envdir = -[pPkK](n|) ]]
76 compinit:505> shift _i_line
76 compinit:504> _i_tag='#compdef'
76 compinit:504> _i_tag='#compdef'
76 compinit:502> _i_test[$_i_name]=yes
76 compinit:502> _i_test[$_i_name]=yes
76 compdump:121> shift _d_als
76 compdump:121> shift _d_als
76 compdump:121> shift _d_als
76 compdump:121> shift _d_als
76 compdump:121> shift _d_als
76 compdump:121> shift _d_als
76 compdump:116> ((  ! --_i && 129 > 1  ))
76 compdump:84> read -rA _d_line
76 compdump:84> read -rA _d_line
76 compdump:44> print -r - ''grepdiff'' ''_patchutils''
76 compdef:131> ((  0  ))
76 compdef:131> ((  0  ))
76 compdef:131> ((  0  ))
76 compdef:131> ((  0  ))
76 compdef:131> ((  0  ))
76 compdef:95> bindkey 'C-xd'
76 compdef:80> autoload -Uz _ip
76 compdef:49> [[ _units = *=* ]]
76 compdef:14> getopts anpPkKde opt
76 compdef:5> setopt extendedglob
76 compdef:4> emulate -L zsh
76 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
76 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
76 antigen-remove-hook:16> unfunction -- -antigen-hook--antigen-load-env
76 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_cursor_p...
76 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:57> ((  0  ))
76 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:5> typeset -AHg FX FG BG
75 compinit:504> _i_tag='#compdef'
75 compinit:503> read -rA _i_line
75 compinit:502> _i_test[$_i_name]=yes
75 compinit:502> _i_test[$_i_name]=yes
75 compinit:502> _i_test[$_i_name]=yes
75 compinit:501> ((  0 + 0  ))
75 compdump:131> print
75 compdump:121> shift _d_als
75 compdump:121> shift _d_als
75 compdump:121> shift _d_als
75 compdump:121> shift _d_als
75 compdump:121> shift _d_als
75 compdump:116> ((  ! --_i && 921 > 1  ))
75 compdump:116> ((  ! --_i && 2 > 1  ))
75 compdump:96> [[ _bash_complete-word = (_bash_complete-word|_bash_list-choices...
75 compdump:84> read -rA _d_line
75 compdef:162> [[ -z yes || -z _ldconfig ]]
75 compdef:131> ((  0  ))
75 compdef:131> ((  0  ))
75 compdef:131> ((  0  ))
75 compdef:131> ((  0  ))
75 compdef:81> shift
75 compdef:9> ((  ! 2  ))
75 compdef:5> setopt extendedglob
75 LOG:2> echo '[LOG][1653210536.9294450283] /usr/local/share/antigen/antigen.zs...
75 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:319> alias 'gamscp=git am -...
75 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:44> typeset PATCH='for tmp (base base...
75 (eval):198> alias 'which-command=whence'
74 compinit:511> compdef -na _bundle bundle
74 compinit:503> read -rA _i_line
74 compinit:502> _i_test[$_i_name]=yes
74 compinit:502> _i_test[$_i_name]=yes
74 compinit:502> _i_test[$_i_name]=yes
74 compdump:121> shift _d_als
74 compdump:121> shift _d_als
74 compdump:121> shift _d_als
74 compdump:121> shift _d_als
74 compdump:116> ((  ! --_i && 1052 > 1  ))
74 compdump:113> ((  356  ))
74 compdump:84> read -rA _d_line
74 compdump:67> print 'n_compautos=('
74 compdef:136> [[ readshortcut = -P ]]
74 compdef:132> [[ printf = -N ]]
74 compdef:131> ((  0  ))
74 compdef:131> ((  0  ))
74 compdef:131> ((  0  ))
74 compdef:131> ((  0  ))
74 compdef:131> ((  0  ))
74 compdef:81> shift
74 compdef:17> new=yes
74 compdef:14> getopts anpPkKde opt
74 compdef:9> ((  ! 3  ))
74 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
74 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
74 colors:8> color=( 00 none 01 bold 02 faint 22 normal 03 standout 23 no-stando...
74 WARN:1> local PREFIX='[WRN][1653210536.9803979397]'
74 LOG:1> local PREFIX='[LOG][1653210536.9468140602]'
74 /usr/local/opt/asdf/libexec/asdf.sh:28> [[ ':/usr/local/opt/curl/bin:/usr/loc...
74 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1753> _patcomps=( '*/(init|r...
74 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:75> ZSH_CUSTOM=/Users/matt/.oh-my-zsh/custom
74 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:45> zs...
74 (anon):322> typeset -g POWERLEVEL9K_VCS_UNTRACKED_ICON='?'
73 compinit:511> compdef -na _snap snap
73 compinit:511> compdef -na _ip ip
73 compinit:503> read -rA _i_line
73 compinit:503> read -rA _i_line
73 compinit:502> _i_test[$_i_name]=yes
73 compinit:502> _i_test[$_i_name]=yes
73 compinit:502> _i_test[$_i_name]=yes
73 compinit:502> _i_test[$_i_name]=yes
73 compinit:502> _i_test[$_i_name]=yes
73 compinit:502> _i_test[$_i_name]=yes
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:121> shift _d_als
73 compdump:116> ((  ! --_i && 351 > 1  ))
73 compdump:115> print -n ' _dak'
73 compdump:96> [[ '"' = (_bash_complete-word|_bash_list-choices|_complete_debug...
73 compdump:84> read -rA _d_line
73 compdump:84> read -rA _d_line
73 compdump:84> read -rA _d_line
73 compdump:84> read -rA _d_line
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:131> ((  0  ))
73 compdef:80> autoload -Uz _prstat
73 compdef:38> shift OPTIND-1
73 compdef:14> getopts anpPkKde opt
73 compdef:4> emulate -L zsh
73 compdef:2> local -a match mbegin mend
73 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
73 WARN:1> local PREFIX='[WRN][1653210539.1319010258]'
73 /Users/matt/.zshrc:162> export PATH='/usr/local/bin:/usr/local/sbin:/Users/ma...
73 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
73 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
73 /Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/zsh-completions.plugin....
73 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
73 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
73 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-high...
72 compinit:511> compdef -na _guilt guilt guilt-add guilt-applied guilt-delete g...
72 compinit:505> shift _i_line
72 compinit:504> _i_tag='#autoload'
72 compinit:502> _i_test[$_i_name]=yes
72 compinit:502> _i_test[$_i_name]=yes
72 compinit:502> _i_test[$_i_name]=yes
72 compinit:502> _i_test[$_i_name]=yes
72 compinit:502> _i_test[$_i_name]=yes
72 compinit:501> ((  0 + 0  ))
72 compdump:133> print 'typeset -gUa _comp_assocs'
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:121> shift _d_als
72 compdump:118> print -n ' 
           '
72 compdump:84> read -rA _d_line
72 compdump:84> read -rA _d_line
72 compdump:84> read -rA _d_line
72 compdump:84> read -rA _d_line
72 compdef:169> shift
72 compdef:162> [[ -z yes || -z _strip ]]
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:131> ((  0  ))
72 compdef:17> new=yes
72 compdef:15> case n (n)
72 compdef:14> getopts anpPkKde opt
72 compdef:2> local -a match mbegin mend
72 antigen:2> return 0
72 WARN:1> local PREFIX='[WRN][1653210536.9906630516]'
72 WARN:1> local PREFIX='[WRN][1653210536.8987739086]'
72 /usr/local/share/antigen/antigen.zsh:35> [[ -f /Users/matt/.antigen/init.zsh ]]
72 /Users/matt/.zshrc:17> [[ -r /Users/matt/.cache/p10k-instant-prompt-matt.zsh ]]
72 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:194> compdef _git 'ggu=git-...
72 /Users/matt/.oh-my-zsh/lib/completion.zsh:48> zstyle ':completion:*:*:*:users...
72 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2universion=/Users/ma...
72 /Users/matt/.cache/p10k-instant-prompt-matt.zsh:2> return 0
72 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
72 -antigen-hook-handler:1> local target=-antigen-load-env args hook called
71 regexp-replace:28> [[ $4 -regex-match $2 ]]
71 compinit:504> _i_tag='#compdef'
71 compinit:504> _i_tag='#compdef'
71 compinit:503> read -rA _i_line
71 compinit:503> read -rA _i_line
71 compinit:502> _i_test[$_i_name]=yes
71 compinit:502> _i_test[$_i_name]=yes
71 compinit:502> _i_test[$_i_name]=yes
71 compinit:502> _i_test[$_i_name]=yes
71 compinit:501> ((  0 + 0  ))
71 compdump:121> shift _d_als
71 compdump:121> shift _d_als
71 compdump:121> shift _d_als
71 compdump:121> shift _d_als
71 compdump:115> print -n ' _zpty'
71 compdump:96> [[ vi-goto-column = (_bash_complete-word|_bash_list-choices|_com...
71 compdump:84> read -rA _d_line
71 compdump:84> read -rA _d_line
71 compdump:84> read -rA _d_line
71 compdump:84> read -rA _d_line
71 compdump:84> read -rA _d_line
71 compdump:84> read -rA _d_line
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:131> ((  0  ))
71 compdef:95> bindkey 'e~'
71 compdef:40> ((  ! 3  ))
71 compdef:15> case n (a)
71 compdef:4> emulate -L zsh
71 compdef:4> emulate -L zsh
71 compaudit:46> fpath=( /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy /Users...
71 antigen-remove-hook:16> unfunction -- -antigen-hook--antigen-load-source
71 LOG:2> echo '[LOG][1653210536.9142179489] /usr/local/share/antigen/antigen.zs...
71 LOG:1> local PREFIX='[LOG][1653210539.1364769936]'
71 /usr/local/share/antigen/antigen.zsh:24> config=/Users/matt/.zshrc
71 /Users/matt/.zshrc:156> export PATH='/Users/matt/theos/bin:/usr/local/opt/pyt...
71 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:119> bindkey '^[m' copy-prev-shel...
71 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:25> bindkey -M vicmd $'C-[[5~' up...
71 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
71 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
70 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/fasd/fasd.plugin.zsh
70 compinit:539> bindkey '^i'
70 compinit:530> _i_line=menu-expand-or-complete
70 compinit:504> _i_tag='#compdef'
70 compinit:504> _i_tag='#compdef'
70 compinit:504> _i_tag='#compdef'
70 compinit:504> _i_tag='#compdef'
70 compinit:502> _i_test[$_i_name]=yes
70 compinit:502> _i_test[$_i_name]=yes
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:121> shift _d_als
70 compdump:115> print -n ' _nano'
70 compdump:111> integer _i=5
70 compdump:85> [[ bracketed-paste = _* ]]
70 compdump:84> read -rA _d_line
70 compdump:84> read -rA _d_line
70 compdump:84> read -rA _d_line
70 compdump:71> print ')'
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:131> ((  0  ))
70 compdef:45> [[ -z '' ]]
70 compdef:14> getopts anpPkKde opt
70 compdef:9> ((  ! 9  ))
70 compdef:4> emulate -L zsh
70 compdef:2> local -a match mbegin mend
70 compdef:2> local -a match mbegin mend
70 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_root_paint
70 _zsh_highlight_bind_widgets:4> local prefix=orig-s0.0000080000-r6249
70 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:318> alias 'gama=git am --a...
70 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:24> alias 'ls=ls -G'
70 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/clipboard.zsh:107> de...
69 compinit:540> [[ expand-or-complete = expand-or-complete ]]
69 compinit:511> compdef -na _rspec rspec
69 compinit:511> compdef -na _protoc protoc
69 compinit:506> case #compdef (#compdef)
69 compinit:505> shift _i_line
69 compinit:504> _i_tag='#compdef'
69 compinit:504> _i_tag='#compdef'
69 compinit:504> _i_tag='#compdef'
69 compinit:504> _i_tag='#autoload'
69 compinit:502> _i_test[$_i_name]=yes
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:121> shift _d_als
69 compdump:85> [[ _bash_complete-word = _* && _bash_completions = _* ]]
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdump:84> read -rA _d_line
69 compdef:136> [[ xargs = -P ]]
69 compdef:134> [[ zpty = -p ]]
69 compdef:134> [[ zcompile = -p ]]
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:131> ((  0  ))
69 compdef:122> bindkey 'C-x?'
69 compdef:95> bindkey 'e,'
69 compdef:80> autoload -Uz _sockstat
69 compdef:15> case n (n)
69 compdef:5> setopt extendedglob
69 compdef:4> emulate -L zsh
69 compdef:2> local -a match mbegin mend
69 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
69 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
69 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
69 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
69 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;49m'
69 antigen-add-hook:34> return 0
69 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
69 WARN:1> local PREFIX='[WRN][1653210539.1356918812]'
69 WARN:1> local PREFIX='[WRN][1653210536.9928040504]'
69 WARN:1> local PREFIX='[WRN][1653210536.9595990181]'
69 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:32> typeset -gr __p9k_in...
69 /Users/matt/.zshrc:139> export PATH='/usr/local/opt/python/libexec/bin:/usr/l...
69 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
69 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:69> zstyle ':completion:fasd-com...
69 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
69 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:5> types...
68 compinit:511> compdef -na _perforce p4 p4d -value-,P4CLIENT,-default- -value-...
68 compinit:511> compdef -na _a2utils a2ensite a2dissite a2enmod a2dismod
68 compinit:506> case #compdef (#compdef)
68 compinit:504> _i_tag='#compdef'
68 compinit:504> _i_tag='#autoload'
68 compinit:503> read -rA _i_line
68 compinit:502> _i_test[$_i_name]=yes
68 compinit:502> _i_test[$_i_name]=yes
68 compinit:501> ((  0 + 0  ))
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:121> shift _d_als
68 compdump:113> ((  368  ))
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:84> read -rA _d_line
68 compdump:56> print -r - ''*/(init|rc[0-9S]#).d/*'' ''_init_d''
68 compdef:155> [[ yast = *=* ]]
68 compdef:139> case  (postpattern)
68 compdef:134> [[ swanctl = -p ]]
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:131> ((  0  ))
68 compdef:122> bindkey 'C-xh'
68 compdef:92> [[ .complete-word = .menu-select ]]
68 compdef:81> shift
68 compdef:17> new=yes
68 compdef:2> local -a match mbegin mend
68 compaudit:46> fpath=( /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy /Users...
68 WARN:1> local PREFIX='[WRN][1653210539.1323750019]'
68 WARN:1> local PREFIX='[WRN][1653210536.9877779484]'
68 WARN:1> local PREFIX='[WRN][1653210536.9318161011]'
68 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:89> fpath=( /Users/matt/.oh-my-zsh/custom...
68 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
68 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/grep.zsh:6> source /U...
68 -antigen-load:2> bundle=( btype plugin dir /Users/matt/.antigen/bundles/robby...
67 complete:13> compdef '_bash_complete -o default -F _bq_completer' bq
67 compinit:511> compdef -na _seafile seaf-cli
67 compinit:511> compdef -na _debdiff debdiff
67 compinit:511> compdef -na _chflags chflags
67 compinit:508> [[ -value-,TZ,-default- = -[pPkK](n|) ]]
67 compinit:505> shift _i_line
67 compinit:505> shift _i_line
67 compinit:505> shift _i_line
67 compinit:505> shift _i_line
67 compinit:504> _i_tag='#compdef'
67 compinit:504> _i_tag='#compdef'
67 compinit:504> _i_tag='#compdef'
67 compinit:504> _i_tag='#compdef'
67 compinit:504> _i_tag='#autoload'
67 compinit:503> read -rA _i_line
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compinit:502> _i_test[$_i_name]=yes
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:121> shift _d_als
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdump:84> read -rA _d_line
67 compdef:162> [[ -z yes || -z _kitchen ]]
67 compdef:136> [[ mina = -P ]]
67 compdef:132> [[ mgv = -N ]]
67 compdef:131> ((  0  ))
67 compdef:131> ((  0  ))
67 compdef:131> ((  0  ))
67 compdef:131> ((  0  ))
67 compdef:79> func=_which
67 compdef:38> shift OPTIND-1
67 compdef:17> new=yes
67 compdef:14> getopts anpPkKde opt
67 compdef:14> getopts anpPkKde opt
67 compdef:14> getopts anpPkKde opt
67 compdef:9> ((  ! 3  ))
67 compdef:9> ((  ! 3  ))
67 compdef:5> setopt extendedglob
67 compdef:5> setopt extendedglob
67 bashcompinit:179> return 0
67 antigen-add-hook:34> return 0
67 add-zsh-hook:85> typeset -ga precmd_functions
67 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_line_paint
67 LOG:1> local PREFIX='[LOG][1653210539.1359579563]'
67 /Users/matt/.zshrc:495> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
67 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:70> autoload -U compaudit compinit
67 /Users/matt/.cache/p10k-instant-prompt-matt.zsh:1> [[ -t 0 && -t 1 && -t 2 ]]
67 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
67 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
67 (anon):1558> ((  ! 1  ))
67 (anon):10> zstyle zle-hook types isearch-exit isearch-update line-pre-redraw ...
66 compinit:511> compdef -na _xauth xauth
66 compinit:511> compdef -na _urls -value-,WWW_HOME,-default- -P '-value-,(ftp|h...
66 compinit:511> compdef -na _spamassassin spamassassin
66 compinit:511> compdef -na _gstat gstat
66 compinit:511> compdef -na _gcc gcc g++ cc c++ llvm-gcc llvm-g++ clang clang++...
66 compinit:505> shift _i_line
66 compinit:505> shift _i_line
66 compinit:504> _i_tag='#compdef'
66 compinit:504> _i_tag='#autoload'
66 compinit:503> read -rA _i_line
66 compinit:503> read -rA _i_line
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:502> _i_test[$_i_name]=yes
66 compinit:170> typeset -gH _comp_setup=$'local -A _comp_caller_options;n      ...
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:121> shift _d_als
66 compdump:96> [[ backward-word = (_bash_complete-word|_bash_list-choices|_comp...
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdump:84> read -rA _d_line
66 compdef:132> [[ postconf = -N ]]
66 compdef:131> ((  0  ))
66 compdef:131> ((  0  ))
66 compdef:131> ((  0  ))
66 compdef:131> ((  0  ))
66 compdef:131> ((  0  ))
66 compdef:131> ((  0  ))
66 compdef:122> bindkey 'C-xC'
66 compdef:81> shift
66 compdef:80> autoload -Uz _fmadm
66 compdef:14> getopts anpPkKde opt
66 compdef:2> local -a match mbegin mend
66 add-zsh-hook:92> autoload -- _zsh_autosuggest_start
66 _zsh_highlight_bind_widgets:23> widgets_to_bind+=( zle-isearch-update )
66 WARN:1> local PREFIX='[WRN][1653210536.9925670624]'
66 /Users/matt/.zshrc:138> export PATH='/usr/local/bin:/usr/local/sbin:/Users/ma...
66 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
66 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
66 -antigen-hook-handler:48> ((  1  ))
66 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
65 compinit:546> unfunction compinit compaudit
65 compinit:511> compdef -na _rkt rkt
65 compinit:511> compdef -na _perl_modules pmpath pmvers pmdesc pmload pmexp pme...
65 compinit:511> compdef -na _openstack openstack aodh barbican ceilometer cinde...
65 compinit:511> compdef -na _md5sum md5sum gmd5sum b2sum gb2sum sha1sum gsha1su...
65 compinit:511> compdef -na _cksum cksum gcksum sum gsum md2 md4 md5 rmd160 sha...
65 compinit:508> [[ tardy = -[pPkK](n|) ]]
65 compinit:506> case #compdef (#compdef)
65 compinit:505> shift _i_line
65 compinit:504> _i_tag='#compdef'
65 compinit:503> read -rA _i_line
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:502> _i_test[$_i_name]=yes
65 compinit:501> ((  0 + 0  ))
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:121> shift _d_als
65 compdump:116> ((  ! --_i && 838 > 1  ))
65 compdump:97> print -r 'bindkey '''^[~''' _bash_complete-word'
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdump:84> read -rA _d_line
65 compdef:169> shift
65 compdef:139> case  (postpattern)
65 compdef:132> [[ diana = -N ]]
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:131> ((  0  ))
65 compdef:122> bindkey 'C-xm'
65 compdef:80> autoload -Uz _a2utils
65 compdef:79> func=_sccs
65 compdef:49> [[ -z '' ]]
65 compdef:45> [[ -z '' ]]
65 compdef:38> shift OPTIND-1
65 compdef:17> new=yes
65 compdef:16> autol=yes
65 compdef:14> getopts anpPkKde opt
65 compdef:14> getopts anpPkKde opt
65 compdef:14> getopts anpPkKde opt
65 compdef:4> emulate -L zsh
65 compdef:2> local -a match mbegin mend
65 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
65 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
65 colors:8> color=( 00 none 01 bold 02 faint 22 normal 03 standout 23 no-stando...
65 antigen:2> return 0
65 antigen-bundle-parallel-execute:45> WARN 'Parallel install done' PARALLEL
65 antigen-add-hook:34> return 0
65 WARN:1> local PREFIX='[WRN][1653210536.9529869556]'
65 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> '(anon)'
65 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:1> PROMPT=$'%(?:%{C-[[01...
65 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:264> alias 'grset=git remot...
65 -antigen-parse-args:117> local name=https://github.com/robbyrussell/oh-my-zsh...
64 compinit:504> _i_tag='#compdef'
64 compinit:504> _i_tag='#compdef'
64 compinit:504> _i_tag='#compdef'
64 compinit:504> _i_tag='#autoload'
64 compinit:502> _i_test[$_i_name]=yes
64 compinit:502> _i_test[$_i_name]=yes
64 compinit:502> _i_test[$_i_name]=yes
64 compinit:502> _i_test[$_i_name]=yes
64 compinit:170> typeset -gH _comp_setup=$'local -A _comp_caller_options;n      ...
64 compdump:126> local _c
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:121> shift _d_als
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:84> read -rA _d_line
64 compdump:16> emulate -L zsh
64 compdef:162> [[ -z yes || -z _ifconfig ]]
64 compdef:160> svc=''
64 compdef:139> case  (*)
64 compdef:136> [[ rmid = -P ]]
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:131> ((  0  ))
64 compdef:122> bindkey 'C-xn'
64 compdef:115> zle -C _most_recent_file .complete-word _most_recent_file
64 compdef:80> autoload -Uz _setfacl
64 compdef:17> new=yes
64 compdef:15> case n (a)
64 compdef:14> getopts anpPkKde opt
64 compdef:4> emulate -L zsh
64 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
64 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
64 add-zsh-hook:92> autoload -- _antigen_compinit
64 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_regexp_p...
64 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_regexp_p...
64 WARN:1> local PREFIX='[WRN][1653210536.9617240429]'
64 /Users/matt/.oh-my-zsh/lib/completion.zsh:41> zstyle ':completion:*:cd:*' tag...
64 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
64 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/grep.zsh:1> __GREP_CA...
64 -antigen-hook-handler:71> return 0
63 is_plugin:4> test -f /Users/matt/.oh-my-zsh/custom/plugins/fasd/_fasd
63 compinit:511> compdef -na _make make gmake pmake dmake freebsd-make bmake
63 compinit:511> compdef -na _chown chown chgrp 'gchown=chown' 'gchgrp=chgrp' 'z...
63 compinit:504> _i_tag='#compdef'
63 compinit:504> _i_tag='#compdef'
63 compinit:504> _i_tag='#compdef'
63 compinit:504> _i_tag='#autoload'
63 compinit:503> read -rA _i_line
63 compinit:503> read -rA _i_line
63 compinit:503> read -rA _i_line
63 compinit:502> _i_test[$_i_name]=yes
63 compinit:502> _i_test[$_i_name]=yes
63 compinit:502> _i_test[$_i_name]=yes
63 compinit:502> _i_test[$_i_name]=yes
63 compinit:502> _i_test[$_i_name]=yes
63 compinit:501> ((  0 + 0  ))
63 compinit:480> [[ -n yes ]]
63 compinit:170> typeset -gH _comp_setup=$'local -A _comp_caller_options;n      ...
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:121> shift _d_als
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdump:84> read -rA _d_line
63 compdef:162> [[ -z yes || -z _at ]]
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:131> ((  0  ))
63 compdef:122> bindkey 'C-xt'
63 compdef:81> shift
63 compdef:81> shift
63 compdef:80> [[ -n yes ]]
63 compdef:40> ((  ! 3  ))
63 compdef:16> autol=yes
63 compdef:15> case a (a)
63 compdef:14> getopts anpPkKde opt
63 compdef:14> getopts anpPkKde opt
63 compdef:14> getopts anpPkKde opt
63 compdef:9> ((  ! 3  ))
63 compdef:4> emulate -L zsh
63 compdef:4> emulate -L zsh
63 compdef:2> local -a match mbegin mend
63 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
63 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
63 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
63 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
63 add-zle-hook-widget:50> local -aU extant_hooks
63 WARN:1> local PREFIX='[WRN][1653210536.9480609894]'
63 /Users/matt/.zshrc:236> export CONDA_PYTHON_EXE=/usr/local/anaconda3/bin/python
63 /Users/matt/.p10k.zsh:1584> typeset -g POWERLEVEL9K_CONFIG_FILE=/Users/matt/....
63 -antigen-hook-handler:71> return 0
63 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
63 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
63 (anon):43> return
62 compinit:511> compdef -na _yadm yadm
62 compinit:511> compdef -na _readshortcut readshortcut readshortcut.exe
62 compinit:511> compdef -na _postgresql clusterdb createdb createuser dropdb dr...
62 compinit:511> compdef -na _mullvad mullvad
62 compinit:511> compdef -na _evince evince
62 compinit:508> [[ ztodo = -[pPkK](n|) ]]
62 compinit:508> [[ sudo = -[pPkK](n|) ]]
62 compinit:508> [[ ping = -[pPkK](n|) ]]
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#compdef'
62 compinit:504> _i_tag='#autoload'
62 compinit:504> _i_tag='#autoload'
62 compinit:504> _i_tag='#autoload'
62 compinit:504> _i_tag='#autoload'
62 compinit:504> _i_tag='#autoload'
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:502> _i_test[$_i_name]=yes
62 compinit:501> ((  0 + 0  ))
62 compinit:501> ((  0 + 0  ))
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:121> shift _d_als
62 compdump:116> ((  ! --_i && 145 > 1  ))
62 compdump:115> print -n ' _sqlite'
62 compdump:113> ((  1053  ))
62 compdump:95> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:84> read -rA _d_line
62 compdump:44> print -r - ''vserver'' ''_vserver''
62 compdef:169> shift
62 compdef:132> [[ xargs = -N ]]
62 compdef:131> ((  2  ))
62 compdef:131> ((  1  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:131> ((  0  ))
62 compdef:81> shift
62 compdef:80> [[ -n yes ]]
62 compdef:38> shift OPTIND-1
62 compdef:14> getopts anpPkKde opt
62 compdef:5> setopt extendedglob
62 compdef:5> setopt extendedglob
62 compdef:2> local -a match mbegin mend
62 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
62 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
62 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
62 add-zle-hook-widget:105> ((  ! 1  ))
62 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_root_paint
62 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
62 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-delete-char-o...
62 WARN:1> local PREFIX='[WRN][1653210536.9535129070]'
62 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:2011> _comp_assocs=( '' )
62 /Users/matt/.p10k.zsh:22> '(anon)'
62 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:18> [[ '' != true ]]
62 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:290> alias 'gstp=git stash ...
62 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:276> alias 'gsps=git show -...
62 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:265> alias 'grss=git restor...
62 /Users/matt/.oh-my-zsh/lib/completion.zsh:59> zstyle '*' single-ignored show
62 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
62 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
62 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
61 group_lazy_load:5> alias 'mkvirtualenv=lazy_load "virtualenvwrapper wipeenv c...
61 compinit:515> autoload -Uz _watch-snoop
61 compinit:511> compdef -na _xargs xargs gxargs
61 compinit:511> compdef -na _tee tee gtee
61 compinit:511> compdef -na _growisofs mkisofs growisofs
61 compinit:511> compdef -na _cdr cdr
61 compinit:508> [[ print = -[pPkK](n|) ]]
61 compinit:508> [[ newgrp = -[pPkK](n|) ]]
61 compinit:505> shift _i_line
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#compdef'
61 compinit:504> _i_tag='#autoload'
61 compinit:504> _i_tag='#autoload'
61 compinit:504> _i_tag='#autoload'
61 compinit:503> read -rA _i_line
61 compinit:502> _i_test[$_i_name]=yes
61 compinit:502> _i_test[$_i_name]=yes
61 compinit:502> _i_test[$_i_name]=yes
61 compinit:502> _i_test[$_i_name]=yes
61 compinit:501> ((  0 + 0  ))
61 compinit:500> _i_name=_topgit
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:121> shift _d_als
61 compdump:115> print -n ' _gem'
61 compdump:115> print -n ' _ack'
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:84> read -rA _d_line
61 compdump:63> print -r - ''zf*'' ''_zftp''
61 compdump:50> print -r - ''zf_chown'' ''chown''
61 compdef:160> svc=''
61 compdef:155> [[ urxvt256c-mlc = *=* ]]
61 compdef:139> case  (postpattern)
61 compdef:132> [[ mkzsh = -N ]]
61 compdef:131> ((  25  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:131> ((  0  ))
61 compdef:122> bindkey 'C-xc'
61 compdef:115> zle -C _complete_debug .complete-word _complete_debug
61 compdef:95> bindkey '^X~'
61 compdef:16> autol=yes
61 compdef:9> ((  ! 8  ))
61 compdef:4> emulate -L zsh
61 compdef:2> local -a match mbegin mend
61 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
61 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
61 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_main_paint
61 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
61 WARN:1> local PREFIX='[WRN][1653210536.9752879143]'
61 WARN:1> local PREFIX='[WRN][1653210536.9655408859]'
61 WARN:1> local PREFIX='[WRN][1653210536.9484770298]'
61 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
61 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
61 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:57> fpath=( /Users/matt/.oh-my-zsh/cache/...
61 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:47> setopt auto_cd
61 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
61 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:59> zs...
61 -antigen-parse-args:164> return 0
61 -antigen-hook-handler:71> return 0
61 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-source-cached /U...
61 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
60 compinit:511> compdef -na _dvi dvips dvibook dviconcat dvicopy dvidvi dvipdf ...
60 compinit:511> compdef -na _devtodo devtodo todo tda tde tdd tdr
60 compinit:511> compdef -na _analyseplugin analyseplugin
60 compinit:509> compdef -Pna _pbm '(p[bgpn]m*|*top[bgpn]m)'
60 compinit:505> shift _i_line
60 compinit:504> _i_tag='#compdef'
60 compinit:504> _i_tag='#compdef'
60 compinit:504> _i_tag='#compdef'
60 compinit:504> _i_tag='#compdef'
60 compinit:504> _i_tag='#compdef'
60 compinit:504> _i_tag='#compdef'
60 compinit:503> read -rA _i_line
60 compinit:502> _i_test[$_i_name]=yes
60 compinit:502> _i_test[$_i_name]=yes
60 compinit:502> _i_test[$_i_name]=yes
60 compinit:502> _i_test[$_i_name]=yes
60 compinit:502> _i_test[$_i_name]=yes
60 compinit:502> _i_test[$_i_name]=yes
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:121> shift _d_als
60 compdump:114> ((  ! 0  ))
60 compdump:114> ((  ! 0  ))
60 compdump:95> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdump:84> read -rA _d_line
60 compdef:169> shift
60 compdef:169> shift
60 compdef:162> [[ -z yes || -z _setfacl ]]
60 compdef:160> svc=''
60 compdef:155> [[ zmodload = *=* ]]
60 compdef:155> [[ md5sum = *=* ]]
60 compdef:139> case  (pattern)
60 compdef:131> ((  1  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:131> ((  0  ))
60 compdef:83> case  (key)
60 compdef:80> autoload -Uz _kdeconnect
60 compdef:79> func=_rcctl
60 compdef:5> setopt extendedglob
60 compdef:4> emulate -L zsh
60 compdef:2> local -a match mbegin mend
60 compdef:2> local -a match mbegin mend
60 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
60 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
60 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
60 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
60 compaudit:33> set -- /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy /Users/...
60 antigen-add-hook:28> eval $'function antigen () {n      noglob -antigen-hook-...
60 add-zsh-hook:92> autoload -- _zsh_autosuggest_start
60 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
60 WARN:1> local PREFIX='[WRN][1653210536.9920940399]'
60 WARN:1> local PREFIX='[WRN][1653210536.9433560371]'
60 WARN:1> local PREFIX='[WRN][1653210536.9423990250]'
60 WARN:1> local PREFIX='[WRN][1653210536.9030649662]'
60 /usr/local/opt/asdf/libexec/asdf.sh:17> export ASDF_DIR
60 /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:15> [[ '' != true ]]
60 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:2> ((  ! 1  ))
60 /Users/matt/.oh-my-zsh/lib/completion.zsh:14> zstyle ':completion:*:*:*:*:*' ...
60 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
60 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:41> ...
60 -antigen-hook-antigen:7> shift
60 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
59 compinit:511> compdef -na _yt-dlp yt-dlp
59 compinit:511> compdef -na _ansible ansible ansible-config ansible-console ans...
59 compinit:503> read -rA _i_line
59 compinit:502> _i_test[$_i_name]=yes
59 compinit:502> _i_test[$_i_name]=yes
59 compinit:502> _i_test[$_i_name]=yes
59 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_users_on
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:121> shift _d_als
59 compdump:116> ((  ! --_i && 1094 > 1  ))
59 compdump:116> ((  ! --_i && 342 > 1  ))
59 compdump:115> print -n ' _dkms'
59 compdump:113> ((  1092  ))
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdump:84> read -rA _d_line
59 compdef:164> _services[$cmd]=svn
59 compdef:163> _comps[$cmd]=_subversion
59 compdef:162> [[ -z yes || -z _printenv ]]
59 compdef:160> svc=''
59 compdef:134> [[ pump = -p ]]
59 compdef:134> [[ jmeter-plugins = -p ]]
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:131> ((  0  ))
59 compdef:93> zle -C _expand_alias .complete-word _expand_alias
59 compdef:80> autoload -Uz _perf
59 compdef:15> case a (a)
59 compdef:14> getopts anpPkKde opt
59 compdef:5> setopt extendedglob
59 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
59 antigen-add-hook:34> return 0
59 antigen-add-hook:28> eval $'function -antigen-load-source () {n      noglob -...
59 _zsh_highlight_load_highlighters:16> type _zsh_highlight_highlighter_main_paint
59 _zsh_highlight_bind_widgets:50> zle -N auto-suffix-remove _zsh_highlight_widg...
59 WARN:1> local PREFIX='[WRN][1653210539.1321380138]'
59 WARN:1> local PREFIX='[WRN][1653210536.9418590069]'
59 /Users/matt/.zshrc:227> export ZSH_PYENV_LAZY_VIRTUALENV=true
59 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;116m%}'
59 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
59 -antigen-parse-args:13> args[make_local_clone]=true
59 -antigen-interactive-mode:7> [[ file:file:shfunc:shfunc == toplevel* || file:...
59 -antigen-hook-handler:58> ret=0
59 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
58 iterm2_print_state_data:5> printf '033]1337;RemoteHost=%s@%s007' matt ResNet-...
58 compinit:511> compdef -na _webbrowser amaya arena chimera dillo dwb express g...
58 compinit:511> compdef -na _restic _restic restic
58 compinit:511> compdef -na _printenv printenv gprintenv
58 compinit:508> [[ cheat = -[pPkK](n|) ]]
58 compinit:505> shift _i_line
58 compinit:505> shift _i_line
58 compinit:505> shift _i_line
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#compdef'
58 compinit:504> _i_tag='#autoload'
58 compinit:504> _i_tag='#autoload'
58 compinit:503> read -rA _i_line
58 compinit:503> read -rA _i_line
58 compinit:503> read -rA _i_line
58 compinit:502> _i_test[$_i_name]=yes
58 compinit:502> _i_test[$_i_name]=yes
58 compinit:502> _i_test[$_i_name]=yes
58 compinit:502> _i_test[$_i_name]=yes
58 compinit:500> _i_name=_ranlib
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:121> shift _d_als
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:84> read -rA _d_line
58 compdump:44> print -r - ''cu'' ''_cu''
58 compdef:139> case postpattern (postpattern)
58 compdef:139> case  (postpattern)
58 compdef:139> case  (pattern)
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:131> ((  0  ))
58 compdef:81> shift
58 compdef:80> [[ -n yes ]]
58 compdef:80> [[ -n yes ]]
58 compdef:40> ((  ! 2  ))
58 compdef:17> new=yes
58 compdef:16> autol=yes
58 compdef:9> ((  ! 6  ))
58 compdef:9> ((  ! 3  ))
58 compdef:4> emulate -L zsh
58 compdef:2> local -a match mbegin mend
58 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
58 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
58 compaudit:176> compaudit
58 WARN:1> local PREFIX='[WRN][1653210536.9923679829]'
58 WARN:1> local PREFIX='[WRN][1653210536.9827640057]'
58 WARN:1> local PREFIX='[WRN][1653210536.9822130203]'
58 WARN:1> local PREFIX='[WRN][1653210536.9755730629]'
58 WARN:1> local PREFIX='[WRN][1653210536.9136290550]'
58 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:14> local -a __p9k_src_opts
58 /Users/matt/.zshrc:429> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
58 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:6> alias 'f=fasd -f'
58 -antigen-load-env:1> -antigen-hook-handler -antigen-load-env dir /Users/matt/...
58 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
58 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
58 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
58 (eval):1> typeset -g ANTIGEN_DEFAULT_REPO_URL=https://github.com/robbyrussell...
57 is_theme:3> test -f /Users/matt/.oh-my-zsh/custom/themes/robbyrussell.zsh-theme
57 compinit:511> compdef -na _x_utils xdpyinfo xwininfo xkill xfontsel xfd xev x...
57 compinit:511> compdef -na _rubocop rubocop
57 compinit:511> compdef -na _gnupod gnupod_addsong 'gnupod_addsong.pl=gnupod_ad...
57 compinit:511> compdef -na _ethtool ethtool
57 compinit:511> compdef -na _dumper dumper dumper.exe
57 compinit:511> compdef -na _default -default-
57 compinit:511> compdef -na _debcheckout debcheckout
57 compinit:511> compdef -na _chmod chmod gchmod zf_chmod
57 compinit:511> compdef -na _cdrecord cdrecord wodim
57 compinit:511> compdef -na _cabal cabal
57 compinit:508> [[ -P = -[pPkK](n|) ]]
57 compinit:505> shift _i_line
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#compdef'
57 compinit:504> _i_tag='#autoload'
57 compinit:504> _i_tag='#autoload'
57 compinit:504> _i_tag='#autoload'
57 compinit:504> _i_tag='#autoload'
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:502> _i_test[$_i_name]=yes
57 compinit:494> typeset -A _i_test
57 compinit:70> emulate -L zsh
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:121> shift _d_als
57 compdump:114> ((  ! 0  ))
57 compdump:114> ((  ! 0  ))
57 compdump:113> ((  869  ))
57 compdump:96> [[ execute-last-named-cmd = (_bash_complete-word|_bash_list-choi...
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdump:84> read -rA _d_line
57 compdef:169> shift
57 compdef:162> [[ -z yes || -z _which ]]
57 compdef:139> case  (postpattern)
57 compdef:134> [[ gprintenv = -p ]]
57 compdef:132> [[ rcctl = -N ]]
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:131> ((  0  ))
57 compdef:115> zle -C _correct_filename .complete-word _correct_filename
57 compdef:83> case  (widgetkey)
57 compdef:81> shift
57 compdef:80> autoload -Uz _vserver
57 compdef:80> autoload -Uz _diana
57 compdef:80> [[ -n yes ]]
57 compdef:79> func=_dhcpcd
57 compdef:45> [[ -z '' ]]
57 compdef:38> shift OPTIND-1
57 compdef:17> new=yes
57 compdef:15> case n (n)
57 compdef:15> case n (a)
57 compdef:5> setopt extendedglob
57 compdef:4> emulate -L zsh
57 compdef:4> emulate -L zsh
57 compdef:2> local -a match mbegin mend
57 compdef:2> local -a match mbegin mend
57 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
57 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
57 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
57 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
57 compaudit:33> set -- /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy /Users/...
57 antigen-bundle:2> return 0
57 antigen-add-hook:28> eval $'function -antigen-load-env () {n      noglob -ant...
57 add-zsh-hook:15> emulate -L zsh
57 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
57 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:83> unset __p9k_src_opts
57 /Users/matt/.zshrc:497> LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/local/opt/...
57 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> unset update_mode
57 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
57 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
57 /Users/matt/.iterm2_shell_integration.zsh:18> ITERM2_SHOULD_DECORATE_PROMPT=1
57 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
57 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
57 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
57 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:14> zs...
57 -antigen-hook-handler:71> return 0
57 -antigen-hook-antigen-apply:11> zcompile /Users/matt/.antigen/.zcompdump
57 (anon):25> typeset -g POWERLEVEL9K_RIGHT_PROMPT_ELEMENTS=( status command_exe...
56 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy/pyenv-l...
56 is-at-least:53> return 0
56 compinit:511> compdef -na _xz xz unxz 'xzcat=unxz' 'lzma=xz' 'unlzma=unxz' 'l...
56 compinit:511> compdef -na _surfraw surfraw sr
56 compinit:511> compdef -na _openssl openssl
56 compinit:511> compdef -na _java javac java javadoc appletviewer jar jdb javah...
56 compinit:511> compdef -na _gsettings gsettings
56 compinit:511> compdef -na _grep grep egrep fgrep bsdgrep zgrep zegrep zfgrep ...
56 compinit:511> compdef -na _exec exec
56 compinit:511> compdef -na _entr entr
56 compinit:511> compdef -na _dumpadm dumpadm
56 compinit:511> compdef -na _debchange debchange 'dch=debchange'
56 compinit:511> compdef -na _chkconfig chkconfig
56 compinit:511> compdef -na _cdcd cdcd
56 compinit:511> compdef -na _cal cal ncal
56 compinit:511> compdef -na _caffeinate caffeinate
56 compinit:505> shift _i_line
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#compdef'
56 compinit:504> _i_tag='#autoload'
56 compinit:504> _i_tag='#autoload'
56 compinit:504> _i_tag='#autoload'
56 compinit:504> _i_tag='#autoload'
56 compinit:504> _i_tag='#autoload'
56 compinit:504> _i_tag='#autoload'
56 compinit:503> read -rA _i_line
56 compinit:502> _i_test[$_i_name]=yes
56 compinit:502> _i_test[$_i_name]=yes
56 compinit:502> _i_test[$_i_name]=yes
56 compinit:500> _i_name=_piuparts
56 compinit:131> _comp_options=( bareglobqual extendedglob glob multibyte multif...
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:121> shift _d_als
56 compdump:118> print -n ' 
           '
56 compdump:115> print -n ' _x_title'
56 compdump:115> print -n ' _stdbuf'
56 compdump:115> print -n ' _mullvad'
56 compdump:114> ((  ! 0  ))
56 compdump:96> [[ undo = (_bash_complete-word|_bash_list-choices|_complete_debu...
56 compdump:96> [[ accept-and-hold = (_bash_complete-word|_bash_list-choices|_co...
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:84> read -rA _d_line
56 compdump:44> print -r - ''bpython3-urwid'' ''_bpython''
56 compdef:169> shift
56 compdef:139> case  (postpattern)
56 compdef:134> [[ 'svnadmin-static=svnadmin' = -p ]]
56 compdef:132> [[ rspec = -N ]]
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:131> ((  0  ))
56 compdef:115> zle -C _next_tags .list-choices _next_tags
56 compdef:83> case  (*)
56 compdef:81> shift
56 compdef:81> shift
56 compdef:80> autoload -Uz _concourse
56 compdef:80> [[ -n yes ]]
56 compdef:38> shift OPTIND-1
56 compdef:16> autol=yes
56 compdef:15> case a (a)
56 compdef:15> case a (a)
56 compdef:14> getopts anpPkKde opt
56 compdef:14> getopts anpPkKde opt
56 compdef:14> getopts anpPkKde opt
56 compdef:9> ((  ! 3  ))
56 compdef:5> setopt extendedglob
56 compdef:4> emulate -L zsh
56 compdef:4> emulate -L zsh
56 compdef:4> emulate -L zsh
56 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
56 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
56 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
56 antigen-remove-hook:16> unfunction -- -antigen-hook-antigen-bundle
56 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( deno )
56 WARN:1> local PREFIX='[WRN][1653210536.9809319973]'
56 WARN:1> local PREFIX='[WRN][1653210536.9610900879]'
56 WARN:1> local PREFIX='[WRN][1653210536.9300360680]'
56 WARN:1> local PREFIX='[WRN][1653210536.9277129173]'
56 LOG:1> local PREFIX='[LOG][1653210536.9815690517]'
56 /Users/matt/.zshrc:490> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
56 /Users/matt/.zshrc:324> export PATH
56 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:67> fpath=( /Users/matt/.oh-my-zsh/functi...
56 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:76> bindkey -M vicmd '^?' backwar...
56 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:1> alias 'a=fasd -a'
56 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:2> se...
56 -antigen-lock-init:2> -antigen-set-default ANTIGEN_LOCK /Users/matt/.antigen/...
56 -antigen-interactive-mode:7> [[ file:file:shfunc:shfunc:shfunc:eval:shfunc:sh...
56 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
56 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
56 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
56 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
56 (eval):107> alias 'ggpush=git push origin "$(git_current_branch)"'
55 compinit:511> compdef -na _zypper zypper
55 compinit:511> compdef -na _xdvi xdvi
55 compinit:511> compdef -na _unace unace
55 compinit:511> compdef -na _pv pv
55 compinit:511> compdef -na _psutils epsffit extractres fixdlsrps fixfmps fixma...
55 compinit:511> compdef -na _ninja ninja
55 compinit:511> compdef -na _modutils lsmod modinfo modprobe rmmod insmod
55 compinit:511> compdef -na _meson meson
55 compinit:511> compdef -na _etags etags
55 compinit:511> compdef -na _drill drill
55 compinit:511> compdef -na _deborphan deborphan
55 compinit:511> compdef -na _dcut dcut
55 compinit:511> compdef -na _chsh chsh chpass
55 compinit:511> compdef -na _chrt chrt
55 compinit:511> compdef -na _chcon chcon
55 compinit:511> compdef -na _chattr chattr
55 compinit:511> compdef -na _cdrdao cdrdao
55 compinit:511> compdef -na _bzr bzr
55 compinit:508> [[ setfacl = -[pPkK](n|) ]]
55 compinit:508> [[ bundle = -[pPkK](n|) ]]
55 compinit:505> shift _i_line
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#compdef'
55 compinit:504> _i_tag='#autoload'
55 compinit:504> _i_tag='#autoload'
55 compinit:504> _i_tag='#autoload'
55 compinit:504> _i_tag='#autoload'
55 compinit:504> _i_tag='#autoload'
55 compinit:503> read -rA _i_line
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:121> shift _d_als
55 compdump:118> print -n ' 
           '
55 compdump:117> _i=5
55 compdump:116> ((  ! --_i && 868 > 1  ))
55 compdump:115> print -n ' _zsh'
55 compdump:115> print -n ' _file_descriptors'
55 compdump:114> ((  ! 0  ))
55 compdump:84> read -rA _d_line
55 compdump:84> read -rA _d_line
55 compdump:58> print ')'
55 compdef:169> shift
55 compdef:159> cmd=ltrace
55 compdef:155> [[ isag = *=* ]]
55 compdef:139> case  (pattern)
55 compdef:136> [[ top = -P ]]
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:131> ((  0  ))
55 compdef:83> case  (widgetkey)
55 compdef:83> case  (key)
55 compdef:83> case  (*)
55 compdef:80> autoload -Uz _mpv
55 compdef:80> [[ -n yes ]]
55 compdef:49> [[ -z '' ]]
55 compdef:40> ((  ! 2  ))
55 compdef:14> getopts anpPkKde opt
55 compdef:5> setopt extendedglob
55 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
55 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
55 add-zsh-hook:92> autoload -- omz_termsupport_precmd
55 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
55 WARN:1> local PREFIX='[WRN][1653210536.9315900803]'
55 TRACE:1> local PREFIX='[TRA][1653210536.9625670910]'
55 TRACE:1> local PREFIX='[TRA][1653210536.9512660503]'
55 LOG:1> local PREFIX='[LOG][1653210539.2717499733]'
55 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:25> typeset -gr __p9k_in...
55 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:152> unset custom_config_file
55 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2api=/Users/matt/.ite...
55 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
55 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
55 -antigen-hook-antigen:10> antigen-bundle deno
55 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
55 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
55 (eval):1> typeset -g ANTIGEN_LOCK=/Users/matt/.antigen/.lock
54 compinit:511> compdef -na _tarsnap tarsnap
54 compinit:511> compdef -na _pump pump
54 compinit:511> compdef -na _objdump objdump eu-objdump llvm-objdump
54 compinit:511> compdef -na _math -math- let
54 compinit:511> compdef -na _ispell ispell buildhash munchlist findaffix tryaff...
54 compinit:511> compdef -na _iftop iftop
54 compinit:511> compdef -na _envdir envdir
54 compinit:511> compdef -na _dir_list -value-,TERMINFO_DIRS,-default- -P '-valu...
54 compinit:511> compdef -na _defaults defaults
54 compinit:511> compdef -na _debuild debuild
54 compinit:511> compdef -na _brew brew
54 compinit:509> compdef -Kna _expand_alias _expand_alias complete-word 'C-xa'
54 compinit:508> [[ xdvi = -[pPkK](n|) ]]
54 compinit:508> [[ tree = -[pPkK](n|) ]]
54 compinit:508> [[ chflags = -[pPkK](n|) ]]
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compinit:504> _i_tag='#compdef'
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:121> shift _d_als
54 compdump:96> [[ backward-kill-word = (_bash_complete-word|_bash_list-choices|...
54 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
54 compdump:84> read -rA _d_line
54 compdump:84> read -rA _d_line
54 compdump:24> [[ -w /Users/matt/.antigen ]]
54 compdef:169> shift
54 compdef:169> shift
54 compdef:169> shift
54 compdef:162> [[ -z yes || -z _sh ]]
54 compdef:160> svc=''
54 compdef:160> svc=''
54 compdef:159> cmd=bpython2-gtk
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:131> ((  0  ))
54 compdef:115> zle -C _complete_tag .complete-word _complete_tag
54 compdef:81> shift
54 compdef:80> autoload -Uz _todo.sh
54 compdef:80> autoload -Uz _cpio
54 compdef:80> [[ -n yes ]]
54 compdef:14> getopts anpPkKde opt
54 compdef:9> ((  ! 6  ))
54 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
54 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
54 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
54 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
54 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;49m'
54 add-zsh-hook:92> autoload -- omz_termsupport_precmd
54 WARN:1> local PREFIX='[WRN][1653210536.9806630611]'
54 WARN:1> local PREFIX='[WRN][1653210536.9731121063]'
54 WARN:1> local PREFIX='[WRN][1653210536.9675359726]'
54 WARN:1> local PREFIX='[WRN][1653210536.9473578930]'
54 TRACE:1> local PREFIX='[TRA][1653210536.9850850105]'
54 LOG:1> local PREFIX='[LOG][1653210539.2722671032]'
54 LOG:1> local PREFIX='[LOG][1653210536.9903640747]'
54 LOG:1> local PREFIX='[LOG][1653210536.9832410812]'
54 /usr/local/share/antigen/antigen.zsh:9> zmodload zsh/parameter
54 /usr/local/opt/asdf/libexec/asdf.sh:19> [ -d /usr/local/opt/asdf/libexec ']'
54 /Users/matt/.zshrc:494> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
54 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:23> compdef _git '_git_log_...
54 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
54 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
54 -antigen-interactive-mode:7> [[ file:file:shfunc:shfunc:shfunc:eval:shfunc:sh...
54 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
54 -antigen-hook-antigen:8> ((  1  ))
53 compinit:516> [[ '' !=  # ]]
53 compinit:511> compdef -na _virtualbox 'VBoxManage=vboxmanage' 'VBoxHeadless=v...
53 compinit:511> compdef -na _thor thor
53 compinit:511> compdef -na _tardy tardy
53 compinit:511> compdef -na _perldoc perldoc -value-,PERLDOC,-default-
53 compinit:511> compdef -na _mere mere
53 compinit:511> compdef -na _lldb lldb
53 compinit:511> compdef -na _dsh dsh
53 compinit:511> compdef -na _debsign debsign
53 compinit:511> compdef -na _calendar calendar
53 compinit:511> compdef -na _a2ps a2ps
53 compinit:508> [[ pwgen = -[pPkK](n|) ]]
53 compinit:508> [[ concourse = -[pPkK](n|) ]]
53 compinit:505> shift _i_line
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#compdef'
53 compinit:504> _i_tag='#autoload'
53 compinit:501> ((  0 + 0  ))
53 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sort
53 compinit:481> read -rA _i_line
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:121> shift _d_als
53 compdump:115> print -n ' _pipenv'
53 compdump:114> ((  ! 0  ))
53 compdump:84> read -rA _d_line
53 compdump:84> read -rA _d_line
53 compdump:84> read -rA _d_line
53 compdump:43> _d_f=tcpdump
53 compdef:136> [[ pstoedit = -P ]]
53 compdef:136> [[ mutt = -P ]]
53 compdef:134> [[ afew = -p ]]
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:131> ((  0  ))
53 compdef:115> zle -C _complete_help .complete-word _complete_help
53 compdef:81> shift
53 compdef:80> autoload -Uz _pbm
53 compdef:38> shift OPTIND-1
53 compdef:38> shift OPTIND-1
53 compdef:17> new=yes
53 compdef:16> autol=yes
53 compdef:5> setopt extendedglob
53 compdef:4> emulate -L zsh
53 compdef:2> local -a match mbegin mend
53 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
53 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
53 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
53 _zsh_highlight_bind_widgets:26> cur_widget=get-line
53 WARN:1> local PREFIX='[WRN][1653210536.9872930050]'
53 WARN:1> local PREFIX='[WRN][1653210536.9830529690]'
53 WARN:1> local PREFIX='[WRN][1653210536.9771480560]'
53 WARN:1> local PREFIX='[WRN][1653210536.9735939503]'
53 WARN:1> local PREFIX='[WRN][1653210536.9660480022]'
53 WARN:1> local PREFIX='[WRN][1653210536.9428710938]'
53 TRACE:1> local PREFIX='[TRA][1653210536.9780349731]'
53 TRACE:1> local PREFIX='[TRA][1653210536.9537529945]'
53 LOG:1> local PREFIX='[LOG][1653210536.9494960308]'
53 /Users/matt/.zshrc:436> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
53 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:128> alias 'gdw=git diff --...
53 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:53> unset PATCH PATCH_ID
53 -antigen-parse-args:5> shift
53 -antigen-load-env:2> return 0
53 -antigen-hook-handler:71> return 0
53 -antigen-hook-handler:71> return 0
53 -antigen-hook-handler:71> return 0
53 -antigen-hook-handler:66> [[ 0 == -1 ]]
53 -antigen-hook-handler:51> return 0
53 -antigen-hook-handler:44> local replace_hook=0 ret=0
53 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-apply-lock antigen-...
53 -antigen-hook-handler:7> hooks=( antigen-lock )
53 -antigen-env-setup:52> antigen-ext-init
53 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
53 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
53 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-high...
52 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
52 compinit:541> zstyle -a :completion: completer _i_line
52 compinit:533> zle -C complete-word .complete-word _main_complete
52 compinit:511> compdef -na _tidy tidy
52 compinit:511> compdef -na _sdd sdd
52 compinit:511> compdef -na _mussh mussh
52 compinit:511> compdef -na _mtools mattrib mcopy mdel mdu mcd mdeltree mdir mf...
52 compinit:511> compdef -na _mondo mondoarchive
52 compinit:511> compdef -na _exportfs exportfs
52 compinit:511> compdef -na _dcop dcop dcopstart dcopfind dcopref dcopclient dc...
52 compinit:511> compdef -na _bittorrent btdownloadcurses btdownloadheadless btd...
52 compinit:511> compdef -na _awk awk gawk nawk
52 compinit:511> compdef -na _antiword antiword
52 compinit:508> [[ twist = -[pPkK](n|) ]]
52 compinit:506> case #autoload (#autoload)
52 compinit:505> shift _i_line
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#compdef'
52 compinit:504> _i_tag='#autoload'
52 compinit:501> ((  0 + 0  ))
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:121> shift _d_als
52 compdump:116> ((  ! --_i && 69 > 1  ))
52 compdump:115> print -n ' _strftime'
52 compdump:115> print -n ' _django'
52 compdump:114> ((  ! 0  ))
52 compdump:113> ((  303  ))
52 compdump:113> ((  1  ))
52 compdump:84> read -rA _d_line
52 compdump:50> print -r - ''VBoxHeadless'' ''vboxheadless''
52 compdump:44> print -r - ''rubber-pipe'' ''_rubber''
52 compdump:43> _d_f=rubber-pipe
52 compdump:43> _d_f=make
52 compdump:43> _d_f=grm
52 compdef:139> case  (pattern)
52 compdef:139> case  (pattern)
52 compdef:139> case  (*)
52 compdef:136> [[ uml_moo = -P ]]
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:131> ((  0  ))
52 compdef:100> shift 3
52 compdef:93> zle -C _expand_word .complete-word _expand_word
52 compdef:80> autoload -Uz _git-pulls
52 compdef:80> [[ -n yes ]]
52 compdef:79> func=_zpty
52 compdef:45> [[ -z '' ]]
52 compdef:40> ((  ! 5  ))
52 compdef:16> autol=yes
52 compdef:5> setopt extendedglob
52 compdef:2> local -a match mbegin mend
52 compdef:2> local -a match mbegin mend
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
52 bashcompinit:179> return 0
52 antigen-remove-hook:20> unfunction -- antigen-bundle-defer
52 antigen-remove-hook:20> unfunction -- antigen-apply-parallel-execute
52 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
52 WARN:1> local PREFIX='[WRN][1653210536.9890539646]'
52 WARN:1> local PREFIX='[WRN][1653210536.9882330894]'
52 WARN:1> local PREFIX='[WRN][1653210536.9813849926]'
52 WARN:1> local PREFIX='[WRN][1653210536.9758670330]'
52 WARN:1> local PREFIX='[WRN][1653210536.9740309715]'
52 WARN:1> local PREFIX='[WRN][1653210536.9500648975]'
52 WARN:1> local PREFIX='[WRN][1653210536.9449770451]'
52 WARN:1> local PREFIX='[WRN][1653210536.9079029560]'
52 WARN:1> local PREFIX='[WRN][1653210536.9048819542]'
52 WARN:1> local PREFIX='[WRN][1653210536.9033310413]'
52 TRACE:1> local PREFIX='[TRA][1653210536.9709599018]'
52 TRACE:1> local PREFIX='[TRA][1653210536.9458570480]'
52 LOG:1> local PREFIX='[LOG][1653210536.9742040634]'
52 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:30> typeset -gr __p9k_in...
52 /Users/matt/.zshrc:489> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
52 /Users/matt/.zshrc:482> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
52 /Users/matt/.zshrc:478> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
52 /Users/matt/.zshrc:344> export GUILE_LOAD_COMPILED_PATH=/usr/local/lib/guile/...
52 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1797> zle -C _list_expansion...
52 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:223> alias 'glola=git log -...
52 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:200> alias 'ggsup=git branc...
52 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:61> alias 'g=git'
52 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:59> ZSH_THEME_RUBY_PROMPT...
52 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
52 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:63> zle -C fasd-complete-f compl...
52 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
52 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
52 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
52 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:7> uns...
52 -antigen-set-default:3> eval 'test -z "$ANTIGEN_COMPINIT_OPTS" && typeset -g ...
52 -antigen-hook-handler:71> return 0
52 -antigen-hook-handler:71> return 0
52 -antigen-hook-handler:51> return 0
52 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
52 (anon):16> eval $'_zsh_autosuggest_widget_clear() {ntttlocal -i retvalnnttt_z...
51 compinit:511> compdef -na _zstyle zstyle
51 compinit:511> compdef -na _zcash-cli zcash-cli
51 compinit:511> compdef -na _yarn yarn
51 compinit:511> compdef -na _xmlsoft xsltproc xmllint -value-,XML_CATALOG_FILES...
51 compinit:511> compdef -na _vnstat vnstat
51 compinit:511> compdef -na _vagrant vagrant
51 compinit:511> compdef -na _ufw ufw
51 compinit:511> compdef -na _udisksctl udisksctl
51 compinit:511> compdef -na _swift swift swiftc
51 compinit:511> compdef -na _rpm rpm rpmbuild rpmkeys rpmsign rpmspec rpmquery ...
51 compinit:511> compdef -na _ps1234 -value-,PROMPT,-default- -value-,PROMPT2,-d...
51 compinit:511> compdef -na _networkmanager nmcli
51 compinit:511> compdef -na _mysql_utils mysql mysqlshow mysqldump mysqlimport ...
51 compinit:511> compdef -na _mpv mpv
51 compinit:511> compdef -na _middleman middleman
51 compinit:511> compdef -na _heroku heroku
51 compinit:511> compdef -na _django django-admin.py django-admin manage.py
51 compinit:511> compdef -na _cygcheck cygcheck cygcheck.exe
51 compinit:511> compdef -na _cpupower cpupower
51 compinit:508> [[ unhash = -[pPkK](n|) ]]
51 compinit:508> [[ fwupdmgr = -[pPkK](n|) ]]
51 compinit:506> case #compdef (#compdef)
51 compinit:506> case #compdef (#compdef)
51 compinit:504> _i_tag='#compdef'
51 compinit:504> _i_tag='#compdef'
51 compinit:504> _i_tag='#compdef'
51 compinit:504> _i_tag='#compdef'
51 compinit:504> _i_tag='#compdef'
51 compinit:504> _i_tag='#autoload'
51 compinit:501> ((  0 + 0  ))
51 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkginfo
51 compinit:131> _comp_options=( bareglobqual extendedglob glob multibyte multif...
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:121> shift _d_als
51 compdump:116> ((  ! --_i && 8 > 1  ))
51 compdump:114> ((  ! 0  ))
51 compdump:113> ((  350  ))
51 compdump:96> [[ _read_comp = (_bash_complete-word|_bash_list-choices|_complet...
51 compdump:95> read -rA _d_line
51 compdump:85> [[ argument-base = _* ]]
51 compdump:84> read -rA _d_line
51 compdump:84> read -rA _d_line
51 compdump:84> read -rA _d_line
51 compdump:84> read -rA _d_line
51 compdump:44> print -r - ''wodim'' ''_cdrecord''
51 compdump:44> print -r - ''gpasswd'' ''_gpasswd''
51 compdump:43> _d_f=-redirect-,<,uncompress
51 compdef:162> [[ -z yes || -z _xmlsoft ]]
51 compdef:162> [[ -z yes || -z _update-alternatives ]]
51 compdef:160> svc=''
51 compdef:160> svc=''
51 compdef:155> [[ txt = *=* ]]
51 compdef:132> [[ strip = -N ]]
51 compdef:132> [[ sockstat = -N ]]
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:131> ((  0  ))
51 compdef:115> zle -C _read_comp .complete-word _read_comp
51 compdef:115> zle -C _correct_word .complete-word _correct_word
51 compdef:49> [[ _genisoimage = *=* ]]
51 compdef:49> [[ -z '' ]]
51 compdef:17> new=yes
51 compdef:17> new=yes
51 compdef:16> autol=yes
51 compdef:15> case a (a)
51 compdef:14> getopts anpPkKde opt
51 compdef:14> getopts anpPkKde opt
51 compdef:14> getopts anpPkKde opt
51 compdef:5> setopt extendedglob
51 compdef:4> emulate -L zsh
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
51 add-zsh-hook:86> set -A precmd_functions _p9k_do_nothing _p9k_precmd_first om...
51 _zsh_highlight_bind_widgets:50> zle -N vi-add-next _zsh_highlight_widget_orig...
51 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
51 WARN:1> local PREFIX='[WRN][1653210536.9895188808]'
51 WARN:1> local PREFIX='[WRN][1653210536.9892809391]'
51 WARN:1> local PREFIX='[WRN][1653210536.9875199795]'
51 WARN:1> local PREFIX='[WRN][1653210536.9842069149]'
51 WARN:1> local PREFIX='[WRN][1653210536.9733400345]'
51 WARN:1> local PREFIX='[WRN][1653210536.9664640427]'
51 WARN:1> local PREFIX='[WRN][1653210536.9657800198]'
51 WARN:1> local PREFIX='[WRN][1653210536.9446558952]'
51 WARN:1> local PREFIX='[WRN][1653210536.9377849102]'
51 WARN:1> local PREFIX='[WRN][1653210536.9367499352]'
51 WARN:1> local PREFIX='[WRN][1653210536.9282801151]'
51 WARN:1> local PREFIX='[WRN][1653210536.9280569553]'
51 LOG:1> local PREFIX='[LOG][1653210536.9884018898]'
51 LOG:1> local PREFIX='[LOG][1653210536.9760370255]'
51 LOG:1> local PREFIX='[LOG][1653210536.9691359997]'
51 /usr/local/share/antigen/antigen.zsh:25> [[ /Users/matt/.zshrc -nt /Users/mat...
51 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
51 /Users/matt/.zshrc:529> antigen bundle deno
51 /Users/matt/.zshrc:476> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
51 /Users/matt/.zshrc:427> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
51 /Users/matt/.zshrc:25> export ZSH=/Users/matt/.oh-my-zsh
51 /Users/matt/.p10k.zsh:16> local -a p10k_config_opts
51 /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:22> [[ -n '' ]]
51 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:335> unset git_version
51 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:89> fpath=( /Users/matt/.oh-my-zsh/custom...
51 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:2> [ -n 5.8.1 ']'
51 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:76> ...
51 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:7> (...
51 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:4> WOR...
51 -antigen-load:39> return 0
51 -antigen-hook-handler:71> return 0
51 -antigen-hook-handler:71> return 0
51 -antigen-hook-handler:71> return 0
51 -antigen-hook-handler:51> return 0
51 -antigen-hook-handler:7> typeset -a hooks
51 (eval):1> typeset -g ANTIGEN_OMZ_REPO_URL=https://github.com/robbyrussell/oh-...
50 compinit:511> compdef -na _zmodload zmodload
50 compinit:511> compdef -na _yp ypcat ypmatch yppasswd ypwhich ypset ypserv ypb...
50 compinit:511> compdef -na _xloadimage xli xloadimage xsetbg xview
50 compinit:511> compdef -na _wg-quick wg-quick
50 compinit:511> compdef -na _scrub scrub
50 compinit:511> compdef -na _redis-cli redis-cli rec
50 compinit:511> compdef -na _rclone _rclone rclone
50 compinit:511> compdef -na _ralio ralio
50 compinit:511> compdef -na _rails rails
50 compinit:511> compdef -na _pdf pdf2dsc pdf2ps pdfimages pdfinfo pdftopbm pdft...
50 compinit:511> compdef -na _mina mina
50 compinit:511> compdef -na _mh ali anno burst comp dist flist flists fmttest f...
50 compinit:511> compdef -na _libvirt virsh virt-admin virt-host-validate virt-p...
50 compinit:511> compdef -na _kfmclient kfmclient kioclient
50 compinit:511> compdef -na _helm _helm helm
50 compinit:511> compdef -na _gh _gh gh
50 compinit:511> compdef -na _espeak espeak
50 compinit:511> compdef -na _dpkg-cross dpkg-cross
50 compinit:511> compdef -na _cygstart cygstart cygstart.exe
50 compinit:511> compdef -na _cplay cplay
50 compinit:511> compdef -na _alias alias
50 compinit:504> _i_tag='#compdef'
50 compinit:504> _i_tag='#compdef'
50 compinit:504> _i_tag='#compdef'
50 compinit:504> _i_tag='#compdef'
50 compinit:503> read -rA _i_line
50 compinit:503> read -rA _i_line
50 compinit:501> ((  0 + 0  ))
50 compinit:131> _comp_options=( bareglobqual extendedglob glob multibyte multif...
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:121> shift _d_als
50 compdump:118> print -n ' 
           '
50 compdump:116> ((  ! --_i && 911 > 1  ))
50 compdump:116> ((  ! --_i && 43 > 1  ))
50 compdump:114> ((  ! 0  ))
50 compdump:114> ((  ! 0  ))
50 compdump:114> ((  ! 0  ))
50 compdump:114> ((  ! 0  ))
50 compdump:84> read -rA _d_line
50 compdump:84> read -rA _d_line
50 compdump:84> read -rA _d_line
50 compdump:44> print -r - ''tracepath'' ''_tracepath''
50 compdump:44> print -r - ''ksh'' ''_sh''
50 compdef:169> shift
50 compdef:169> shift
50 compdef:162> [[ -z yes || -z _uniq ]]
50 compdef:162> [[ -z yes || -z _sbuild ]]
50 compdef:160> svc=''
50 compdef:159> cmd=zpty
50 compdef:132> [[ todo.sh = -N ]]
50 compdef:131> ((  10  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:131> ((  0  ))
50 compdef:80> autoload -Uz _kpartx
50 compdef:49> [[ -z '' ]]
50 compdef:45> [[ -z '' ]]
50 compdef:45> [[ -z '' ]]
50 compdef:40> ((  ! 4  ))
50 compdef:40> ((  ! 2  ))
50 compdef:38> shift OPTIND-1
50 compdef:14> getopts anpPkKde opt
50 compdef:14> getopts anpPkKde opt
50 compdef:14> getopts anpPkKde opt
50 compdef:9> ((  ! 5  ))
50 compdef:9> ((  ! 3  ))
50 compdef:5> setopt extendedglob
50 compdef:5> setopt extendedglob
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
50 antigen-remove-hook:15> ((  1  ))
50 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
50 WARN:1> local PREFIX='[WRN][1653210536.9700880051]'
50 WARN:1> local PREFIX='[WRN][1653210536.9581029415]'
50 WARN:1> local PREFIX='[WRN][1653210536.9503710270]'
50 WARN:1> local PREFIX='[WRN][1653210536.9476659298]'
50 WARN:1> local PREFIX='[WRN][1653210536.9408938885]'
50 WARN:1> local PREFIX='[WRN][1653210536.9369399548]'
50 WARN:1> local PREFIX='[WRN][1653210536.9347500801]'
50 WARN:1> local PREFIX='[WRN][1653210536.9035999775]'
50 LOG:1> local PREFIX='[LOG][1653210536.9899580479]'
50 /Users/matt/.zshrc:531> antigen bundle zsh-users/zsh-autosuggestions
50 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:121> [[ '' != true ]]
50 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
50 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
50 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:4> [[ '' != ...
50 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
50 -antigen-parse-args:4> local var=bundle
50 -antigen-hook-handler:71> return 0
50 -antigen-hook-handler:71> return 0
50 -antigen-hook-handler:58> ret=0
50 -antigen-hook-handler:51> return 0
50 -antigen-cache-execute:63> return 0
50 (anon):6> local -a hooktypes=( zle-isearch-exit zle-isearch-update zle-line-p...
50 (anon):3> eval $'_zsh_autosuggest_widget_toggle() {ntttlocal -i retvalnnttt_z...
49 compinit:511> compdef -na _zlogin zlogin
49 compinit:511> compdef -na _yum yum yumdb
49 compinit:511> compdef -na _xinput xinput
49 compinit:511> compdef -na _scala scala scalac
49 compinit:511> compdef -na _read read
49 compinit:511> compdef -na _pspdf gsbj gsdj gsdj500 gslj gslp gsnd ps2ascii gh...
49 compinit:511> compdef -na _hledger hledger
49 compinit:511> compdef -na _fwupdmgr fwupdmgr
49 compinit:511> compdef -na _fs_usage fs_usage
49 compinit:511> compdef -na _emulate emulate
49 compinit:511> compdef -na _dpkg_source dpkg-source
49 compinit:511> compdef -na _curl curl
49 compinit:511> compdef -na _cu cu
49 compinit:511> compdef -na _crontab crontab
49 compinit:511> compdef -na _compress compress uncompress '-redirect-,<,uncompr...
49 compinit:511> compdef -na _compadd compadd
49 compinit:511> compdef -na _cmp cmp gcmp
49 compinit:511> compdef -na _chroot chroot gchroot
49 compinit:511> compdef -na _cdbs-edit-patch cdbs-edit-patch
49 compinit:511> compdef -na _ccal ccal
49 compinit:511> compdef -na _bpython bpython bpython-gtk bpython-urwid bpython2...
49 compinit:511> compdef -na _adb adb -value-,ADB_TRACE,-default- -value-,ANDROI...
49 compinit:509> compdef -Kna _expand_word _expand_word complete-word 'C-xe' _li...
49 compinit:505> shift _i_line
49 compinit:505> shift _i_line
49 compinit:504> _i_tag='#compdef'
49 compinit:504> _i_tag='#compdef'
49 compinit:504> _i_tag='#compdef'
49 compinit:503> read -rA _i_line
49 compinit:501> ((  0 + 0  ))
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:121> shift _d_als
49 compdump:116> ((  ! --_i && 383 > 1  ))
49 compdump:115> print -n ' _run-help'
49 compdump:114> ((  ! 0  ))
49 compdump:96> [[ self-insert-unmeta = (_bash_complete-word|_bash_list-choices|...
49 compdump:84> read -rA _d_line
49 compdump:43> _d_f=last
49 compdef:131> ((  1  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:131> ((  0  ))
49 compdef:83> case  (widgetkey)
49 compdef:80> autoload -Uz _tr
49 compdef:49> [[ _yt-dlp = *=* ]]
49 compdef:45> [[ -z '' ]]
49 compdef:45> [[ -z '' ]]
49 compdef:17> new=yes
49 compdef:14> getopts anpPkKde opt
49 compdef:14> getopts anpPkKde opt
49 compdef:14> getopts anpPkKde opt
49 compdef:9> ((  ! 3  ))
49 compdef:5> setopt extendedglob
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
49 antigen-remove-hook:15> ((  1  ))
49 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
49 WARN:1> local PREFIX='[WRN][1653210536.9897890091]'
49 WARN:1> local PREFIX='[WRN][1653210536.9845941067]'
49 WARN:1> local PREFIX='[WRN][1653210536.9677569866]'
49 WARN:1> local PREFIX='[WRN][1653210536.9456670284]'
49 WARN:1> local PREFIX='[WRN][1653210536.9381248951]'
49 WARN:1> local PREFIX='[WRN][1653210536.9320480824]'
49 WARN:1> local PREFIX='[WRN][1653210536.9285290241]'
49 WARN:1> local PREFIX='[WRN][1653210536.9051480293]'
49 LOG:1> local PREFIX='[LOG][1653210536.9517130852]'
49 LOG:1> local PREFIX='[LOG][1653210536.8990159035]'
49 (anon):16> eval $'_zsh_autosuggest_widget_partial_accept() {ntttlocal -i retv...
48 compinit:511> compdef -na _zcat zcat
48 compinit:511> compdef -na _xcode-select xcode-select
48 compinit:511> compdef -na _xclip xclip
48 compinit:511> compdef -na _xautolock xautolock
48 compinit:511> compdef -na _urxvt rxvt urxvt urxvtc urxvt256c urxvt256cc urxvt...
48 compinit:511> compdef -na _tin tin rtin
48 compinit:511> compdef -na _texinfo info tkinfo pinfo install-info makeinfo te...
48 compinit:511> compdef -na _sudo sudo sudoedit
48 compinit:511> compdef -na _other_accounts talk ntalk ytalk
48 compinit:511> compdef -na _mdfind mdfind
48 compinit:511> compdef -na _lsattr lsattr
48 compinit:511> compdef -na _iwconfig iwconfig
48 compinit:511> compdef -na _gqview gqview
48 compinit:511> compdef -na _gnutls gnutls-cli gnutls-cli-debug gnutls-serv cer...
48 compinit:511> compdef -na _figlet figlet
48 compinit:511> compdef -na _dtruss dtruss
48 compinit:511> compdef -na _dpkg-repack dpkg-repack
48 compinit:511> compdef -na _dpkg-buildpackage dpkg-buildpackage
48 compinit:511> compdef -na _directory_stack popd
48 compinit:511> compdef -na _dhclient dhclient dhclient3
48 compinit:511> compdef -na _dconf dconf
48 compinit:511> compdef -na _cvs cvs
48 compinit:511> compdef -na _cut cut gcut
48 compinit:511> compdef -na _csup csup
48 compinit:511> compdef -na _cpio cpio
48 compinit:511> compdef -na _configure configure config.status
48 compinit:511> compdef -na _aptitude aptitude
48 compinit:505> shift _i_line
48 compinit:505> shift _i_line
48 compinit:504> _i_tag='#compdef'
48 compinit:504> _i_tag='#compdef'
48 compinit:504> _i_tag='#compdef'
48 compinit:504> _i_tag='#autoload'
48 compinit:504> _i_tag='#autoload'
48 compinit:504> _i_tag='#autoload'
48 compinit:503> read -rA _i_line
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:121> shift _d_als
48 compdump:117> _i=5
48 compdump:116> ((  ! --_i && 923 > 1  ))
48 compdump:116> ((  ! --_i && 112 > 1  ))
48 compdump:114> ((  ! 0  ))
48 compdump:114> ((  ! 0  ))
48 compdump:96> [[ beginning-of-line = (_bash_complete-word|_bash_list-choices|_...
48 compdump:84> read -rA _d_line
48 compdump:44> print -r - ''5l'' ''_go''
48 compdump:43> _d_f=attr
48 compdef:162> [[ -z yes || -z _unexpand ]]
48 compdef:139> case  (postpattern)
48 compdef:139> case  (*)
48 compdef:136> [[ ps2ps = -P ]]
48 compdef:134> [[ dcopstart = -p ]]
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:131> ((  0  ))
48 compdef:100> shift 3
48 compdef:83> case  (key)
48 compdef:38> shift OPTIND-1
48 compdef:17> new=yes
48 compdef:17> new=yes
48 compdef:14> getopts anpPkKde opt
48 compdef:14> getopts anpPkKde opt
48 compdef:14> getopts anpPkKde opt
48 compdef:9> ((  ! 3  ))
48 compdef:5> setopt extendedglob
48 compdef:5> setopt extendedglob
48 compdef:4> emulate -L zsh
48 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
48 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
48 compaudit:62> [[ 956 -lt 20 || /usr/share/zsh/5.8.1/functions = */Base || -d ...
48 colors:4> emulate -L zsh
48 antigen-remove-hook:20> unfunction -- antigen-bundle-parallel
48 antigen-bundle-parallel:2> _PARALLEL_BUNDLE+=( deno )
48 antigen-bundle-parallel-execute:11> -antigen-parse-args bundle zsh-users/zsh-...
48 antigen-bundle-parallel-execute:10> args=zsh-users/zsh-autosuggestions
48 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
48 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
48 WARN:1> local PREFIX='[WRN][1653210536.9848880768]'
48 WARN:1> local PREFIX='[WRN][1653210536.9844160080]'
48 WARN:1> local PREFIX='[WRN][1653210536.9775569439]'
48 WARN:1> local PREFIX='[WRN][1653210536.9773759842]'
48 WARN:1> local PREFIX='[WRN][1653210536.9567201138]'
48 WARN:1> local PREFIX='[WRN][1653210536.9527740479]'
48 WARN:1> local PREFIX='[WRN][1653210536.9524610043]'
48 WARN:1> local PREFIX='[WRN][1653210536.9490199089]'
48 WARN:1> local PREFIX='[WRN][1653210536.9478809834]'
48 WARN:1> local PREFIX='[WRN][1653210536.9385180473]'
48 WARN:1> local PREFIX='[WRN][1653210536.9383349419]'
48 WARN:1> local PREFIX='[WRN][1653210536.9344339371]'
48 WARN:1> local PREFIX='[WRN][1653210536.9291119576]'
48 WARN:1> local PREFIX='[WRN][1653210536.9288530350]'
48 WARN:1> local PREFIX='[WRN][1653210536.9138619900]'
48 LOG:1> local PREFIX='[LOG][1653210536.9835979939]'
48 LOG:1> local PREFIX='[LOG][1653210536.9666299820]'
48 LOG:1> local PREFIX='[LOG][1653210536.9037830830]'
48 /Users/matt/.zshrc:597> group_lazy_load 'pyenv virtualenvwrapper_lazy' virtua...
48 /Users/matt/.zshrc:477> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
48 /Users/matt/.zshrc:439> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
48 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:267> alias 'grt=cd "$(git r...
48 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
48 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
48 /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy/pyenv-lazy.plugin.zsh:8> typ...
48 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:75> [ '' ']'
48 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
48 -antigen-hook-handler:71> return 0
48 (anon):16> eval $'_zsh_autosuggest_widget_suggest() {ntttlocal -i retvalnnttt...
47 is-at-least:53> return 0
47 compinit:516> [[ '' !=  # ]]
47 compinit:511> compdef -na _zsocket zsocket
47 compinit:511> compdef -na _zparseopts zparseopts
47 compinit:511> compdef -na _zle zle
47 compinit:511> compdef -na _xfig xfig
47 compinit:511> compdef -na _tilde -tilde-
47 compinit:511> compdef -na _sbt sbt
47 compinit:511> compdef -na _samba smbcontrol smbclient nmblookup smbstatus
47 compinit:511> compdef -na _route route
47 compinit:511> compdef -na _ri ri
47 compinit:511> compdef -na _open open
47 compinit:511> compdef -na _mdadm mdadm
47 compinit:511> compdef -na _mc mc
47 compinit:511> compdef -na _ln ln gln zf_ln
47 compinit:511> compdef -na _jq jq
47 compinit:511> compdef -na _hosts ftp rwho rup xping traceroute aaaa zone mx n...
47 compinit:511> compdef -na _fortune fortune
47 compinit:511> compdef -na _ffmpeg ffmpeg
47 compinit:511> compdef -na _eog eog
47 compinit:511> compdef -na _elfdump elfdump
47 compinit:511> compdef -na _ed ed
47 compinit:511> compdef -na _ecasound ecasound
47 compinit:511> compdef -na _du du gdu
47 compinit:511> compdef -na _dig dig
47 compinit:511> compdef -na _diffstat diffstat
47 compinit:511> compdef -na _diff3 diff3
47 compinit:511> compdef -na _dchroot-dsa dchroot-dsa
47 compinit:511> compdef -na _dbus dbus-send dbus-monitor dbus-launch
47 compinit:511> compdef -na _cygpath cygpath cygpath.exe
47 compinit:511> compdef -na _cvsup cvsup
47 compinit:511> compdef -na _composer composer composer.phar
47 compinit:511> compdef -na _compdef compdef
47 compinit:511> compdef -na _comm comm gcomm
47 compinit:511> compdef -na _cd cd chdir pushd
47 compinit:511> compdef -na _avahi avahi-browse avahi-browse-domains avahi-reso...
47 compinit:511> compdef -na _arp arp
47 compinit:511> compdef -na _apt apt apt-get apt-cache apt-cdrom apt-config apt...
47 compinit:505> shift _i_line
47 compinit:505> shift _i_line
47 compinit:504> _i_tag='#compdef'
47 compinit:504> _i_tag='#compdef'
47 compinit:504> _i_tag='#compdef'
47 compinit:504> _i_tag='#compdef'
47 compinit:504> _i_tag='#autoload'
47 compinit:504> _i_tag='#autoload'
47 compinit:504> _i_tag='#autoload'
47 compinit:503> read -rA _i_line
47 compinit:501> ((  0 + 0  ))
47 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_cursor
47 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tune2fs
47 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_yadm
47 compinit:498> ((  0  ))
47 compdump:127> _c=_call_program
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:121> shift _d_als
47 compdump:115> print -n ' _swift'
47 compdump:91> _d_bks+=( _expand_alias )
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:84> read -rA _d_line
47 compdump:73> print
47 compdump:49> _d_f=VBoxHeadless
47 compdef:169> shift
47 compdef:169> shift
47 compdef:139> case  (pattern)
47 compdef:132> [[ pkginfo = -N ]]
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:131> ((  0  ))
47 compdef:100> shift 3
47 compdef:83> case  (widgetkey)
47 compdef:83> case  (*)
47 compdef:81> shift
47 compdef:80> autoload -Uz _doas
47 compdef:79> func=_units
47 compdef:17> new=yes
47 compdef:15> case n (a)
47 compdef:15> case n (a)
47 compdef:15> case a (a)
47 compdef:14> getopts anpPkKde opt
47 compdef:9> ((  ! 4  ))
47 compdef:5> setopt extendedglob
47 compdef:5> setopt extendedglob
47 compdef:4> emulate -L zsh
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
47 antigen-ext:9> _ANTIGEN_EXTENSIONS+=( lock )
47 antigen-bundle-parallel-execute:28> [[ 0 > 0 ]]
47 antigen-add-hook:28> eval $'function antigen-apply () {n      noglob -antigen...
47 _zsh_highlight_load_highlighters:5> [[ -d /Users/matt/.oh-my-zsh/custom/plugi...
47 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
47 _zsh_highlight_bind_widgets:27> case builtin (builtin)
47 _zsh_highlight_bind_widgets:27> case builtin (builtin)
47 _zsh_highlight_bind_widgets:13> local -U widgets_to_bind
47 WARN:1> local PREFIX='[WRN][1653210536.9915490150]'
47 WARN:1> local PREFIX='[WRN][1653210536.9778380394]'
47 WARN:1> local PREFIX='[WRN][1653210536.9619410038]'
47 WARN:1> local PREFIX='[WRN][1653210536.9451949596]'
47 WARN:1> local PREFIX='[WRN][1653210536.9415469170]'
47 WARN:1> local PREFIX='[WRN][1653210536.9412178993]'
47 WARN:1> local PREFIX='[WRN][1653210536.9354550838]'
47 WARN:1> local PREFIX='[WRN][1653210536.9086840153]'
47 WARN:1> local PREFIX='[WRN][1653210536.9039700031]'
47 LOG:1> local PREFIX='[LOG][1653210536.9764180183]'
47 LOG:1> local PREFIX='[LOG][1653210536.9695029259]'
47 LOG:1> local PREFIX='[LOG][1653210536.9491870403]'
47 LOG:1> local PREFIX='[LOG][1653210536.9441480637]'
47 LOG:1> local PREFIX='[LOG][1653210536.9142179489]'
47 LOG:1> local PREFIX='[LOG][1653210536.9053249359]'
47 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:2010> typeset -gUa _comp_assocs
47 /Users/matt/.p10k.zsh:1587> unset p10k_config_opts
47 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:148> alias 'gga=git gui cit...
47 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:6> fasd_cache=/Users/matt...
47 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
47 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=zsh-syntax-highlighting
47 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:31> bindkey -M vicmd $'C-[[6~' do...
47 /Users/matt/.antigen/init.zsh:44> add-zsh-hook precmd _antigen_compinit
47 -antigen-load:1> local bundle list
47 -antigen-hook-handler:71> return 0
47 -antigen-hook-handler:71> return 0
47 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
47 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-env-cached dir /...
46 is-at-least:53> return 0
46 is-at-least:50> break
46 is-at-least:23> emulate -L zsh
46 complete:3> args=( -o nospace -o default -F _python_argcomplete gcloud )
46 compinit:541> zstyle -a :completion: completer _i_line
46 compinit:533> zle -C menu-expand-or-complete .menu-expand-or-complete _main_c...
46 compinit:516> [[ '' !=  # ]]
46 compinit:516> [[ '' !=  # ]]
46 compinit:511> compdef -na _zip zip unzip zipinfo
46 compinit:511> compdef -na _zfs zfs
46 compinit:511> compdef -na _zattr zgetattr zsetattr zdelattr zlistattr
46 compinit:511> compdef -na _wipefs wipefs
46 compinit:511> compdef -na _wemux wemux
46 compinit:511> compdef -na _snoop snoop
46 compinit:511> compdef -na _sccs sccs admin cdc comb delta get help prs prt rm...
46 compinit:511> compdef -na _pkgtool installpkg upgradepkg removepkg pkgtool ex...
46 compinit:511> compdef -na _numfmt numfmt gnumfmt
46 compinit:511> compdef -na _nkf nkf
46 compinit:511> compdef -na _mplayer mplayer gmplayer
46 compinit:511> compdef -na _mpc mpc -value-,MPD_HOST,-default
46 compinit:511> compdef -na _mount mount umount
46 compinit:511> compdef -na _matlab matlab
46 compinit:511> compdef -na _mail mail 'mailx=mail' 'Mail=mail' mush zmail 'nai...
46 compinit:511> compdef -na _lsvg lsvg
46 compinit:511> compdef -na _lp lp lpr lpq lprm lpoptions lpstat lpinfo lpadmin
46 compinit:511> compdef -na _less less -value-,LESS,-default- -value-,LESSCHARS...
46 compinit:511> compdef -na _ld_debug -value-,LD_DEBUG,-default-
46 compinit:511> compdef -na _include-what-you-use include-what-you-use
46 compinit:511> compdef -na _gzip gzip gunzip 'gzcat=gunzip' pigz unpigz '-redi...
46 compinit:511> compdef -na _gpg gpg gpgv gpg-zip 'gpg2=gpg'
46 compinit:511> compdef -na _go gccgo gofmt 5l 6l 8l 5g 6g 8g
46 compinit:511> compdef -na _gem gem -P 'gem[0-9.]#'
46 compinit:511> compdef -na _elinks elinks
46 compinit:511> compdef -na _dmesg dmesg
46 compinit:511> compdef -na _dkms dkms
46 compinit:511> compdef -na _dhcpcd dhcpcd
46 compinit:511> compdef -na _dak dak
46 compinit:511> compdef -na _cssh cssh crsh
46 compinit:511> compdef -na _cscope cscope
46 compinit:511> compdef -na _concourse concourse fly
46 compinit:511> compdef -na _command command
46 compinit:511> compdef -na _column column
46 compinit:511> compdef -na _code code
46 compinit:511> compdef -na _cmake cmake -value-,CMAKE_GENERATOR,-default-
46 compinit:511> compdef -na _cat cat gcat
46 compinit:511> compdef -na _bsd_pkg pkg_add pkg_create pkg_delete pkg_info
46 compinit:511> compdef -na _artisan artisan
46 compinit:511> compdef -na _archlinux-java archlinux-java
46 compinit:509> compdef -kna _complete_tag complete-word 'C-xt'
46 compinit:509> compdef -kna _complete_debug complete-word 'C-x?'
46 compinit:508> [[ pkginfo = -[pPkK](n|) ]]
46 compinit:506> case #compdef (#compdef)
46 compinit:505> shift _i_line
46 compinit:505> shift _i_line
46 compinit:505> shift _i_line
46 compinit:505> shift _i_line
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#compdef'
46 compinit:504> _i_tag='#autoload'
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:121> shift _d_als
46 compdump:117> _i=5
46 compdump:115> print -n ' _subscript'
46 compdump:115> print -n ' _stow'
46 compdump:115> print -n ' _loadkeys'
46 compdump:115> print -n ' _dhcpcd'
46 compdump:114> ((  ! 0  ))
46 compdump:113> ((  912  ))
46 compdump:96> [[ backward-kill-word = (_bash_complete-word|_bash_list-choices|...
46 compdump:44> print -r - ''tcpdump'' ''_tcpdump''
46 compdump:43> _d_f=wodim
46 compdef:164> _services[$cmd]=uncompress
46 compdef:162> [[ -z yes || -z _sccs ]]
46 compdef:155> [[ jmeter-plugins = *=* ]]
46 compdef:155> [[ dmake = *=* ]]
46 compdef:155> [[ autoload = *=* ]]
46 compdef:139> case  (postpattern)
46 compdef:132> [[ zmail = -N ]]
46 compdef:132> [[ nmblookup = -N ]]
46 compdef:131> ((  3  ))
46 compdef:131> ((  1  ))
46 compdef:131> ((  1  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:131> ((  0  ))
46 compdef:100> shift 3
46 compdef:93> zle -C _history-complete-older .complete-word _history_complete_word
46 compdef:93> zle -C _bash_complete-word .complete-word _bash_completions
46 compdef:83> case  (widgetkey)
46 compdef:81> shift
46 compdef:80> autoload -Uz _tcpsys
46 compdef:79> func=_zdump
46 compdef:79> func=_top
46 compdef:79> func=_git
46 compdef:15> case a (a)
46 compdef:14> getopts anpPkKde opt
46 compdef:14> getopts anpPkKde opt
46 compdef:14> getopts anpPkKde opt
46 compdef:14> getopts anpPkKde opt
46 compdef:14> getopts anpPkKde opt
46 compdef:9> ((  ! 3  ))
46 compdef:9> ((  ! 3  ))
46 compdef:5> setopt extendedglob
46 compdef:4> emulate -L zsh
46 compdef:2> local -a match mbegin mend
46 compdef:2> local -a match mbegin mend
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
46 antigen-remove-hook:12> [[ 2 == 0 ]]
46 antigen-apply-parallel-execute:6> unset _PARALLEL_BUNDLE
46 antigen-apply-cached:5> LOG 'TRACE: /usr/local/share/antigen/antigen.zsh:1515...
46 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
46 WARN:1> local PREFIX='[WRN][1653210536.9918479919]'
46 WARN:1> local PREFIX='[WRN][1653210536.9702908993]'
46 WARN:1> local PREFIX='[WRN][1653210536.9623780251]'
46 WARN:1> local PREFIX='[WRN][1653210536.9621150494]'
46 WARN:1> local PREFIX='[WRN][1653210536.9554290771]'
46 WARN:1> local PREFIX='[WRN][1653210536.9545629025]'
46 WARN:1> local PREFIX='[WRN][1653210536.9539918900]'
46 WARN:1> local PREFIX='[WRN][1653210536.9531950951]'
46 WARN:1> local PREFIX='[WRN][1653210536.9510591030]'
46 WARN:1> local PREFIX='[WRN][1653210536.9507610798]'
46 WARN:1> local PREFIX='[WRN][1653210536.9505848885]'
46 WARN:1> local PREFIX='[WRN][1653210536.9461081028]'
46 WARN:1> local PREFIX='[WRN][1653210536.9453699589]'
46 WARN:1> local PREFIX='[WRN][1653210536.9421789646]'
46 WARN:1> local PREFIX='[WRN][1653210536.9400899410]'
46 WARN:1> local PREFIX='[WRN][1653210536.9371500015]'
46 WARN:1> local PREFIX='[WRN][1653210536.9351499081]'
46 WARN:1> local PREFIX='[WRN][1653210536.9349720478]'
46 WARN:1> local PREFIX='[WRN][1653210536.9334299564]'
46 WARN:1> local PREFIX='[WRN][1653210536.9326000214]'
46 WARN:1> local PREFIX='[WRN][1653210536.9323499203]'
46 LOG:1> local PREFIX='[LOG][1653210536.9541649818]'
46 LOG:1> local PREFIX='[LOG][1653210536.9519650936]'
46 LOG:1> local PREFIX='[LOG][1653210536.9462730885]'
46 LOG:1> local PREFIX='[LOG][1653210536.9328980446]'
46 LOG:1> local PREFIX='[LOG][1653210536.9294450283]'
46 /Users/matt/.zshrc:483> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
46 /Users/matt/.zshrc:143> bindkey '^Xx7f' backward-kill-line
46 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1782> _compautos=( _call_pro...
46 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:97> alias 'gcf=git config -...
46 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:91> fpath=( /Users/matt/.oh-my-zsh/plugin...
46 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:46> typeset PATCH_ID=vcs_info-patch-9...
46 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
46 -antigen-parse-args:164> return 0
46 -antigen-parse-args:164> return 0
46 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
46 -antigen-load:32> -antigen-load-env dir /Users/matt/.antigen/bundles/robbyrus...
46 -antigen-load-source:1> -antigen-hook-handler -antigen-load-source /Users/mat...
46 -antigen-load-env-cached:2> bundle=( dir /Users/matt/.antigen/bundles/zsh-use...
46 -antigen-interactive-mode:2> [[ '' !=  ]]
46 -antigen-hook-handler:71> return 0
46 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-source with 0'
46 -antigen-hook-handler:39> antigen-bundle-cached deno
46 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-source mo...
46 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-apply...
46 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-apply...
46 (anon):205> local anchor_files=( .bzr .citc .git .hg .node-version .python-ve...
46 (anon):3> eval $'_zsh_autosuggest_widget_clear() {ntttlocal -i retvalnnttt_zs...
45 iterm2_print_state_data:1> local _iterm2_hostname=''
45 is-at-least:53> return 0
45 compinit:515> autoload -Uz _x_extension
45 compinit:511> compdef -na _zsh zsh
45 compinit:511> compdef -na _zed zed fned
45 compinit:511> compdef -na _zcalc zcalc
45 compinit:511> compdef -na _xmms2 xmms2
45 compinit:511> compdef -na _x_display -value-,DISPLAY,-default-
45 compinit:511> compdef -na _stdbuf stdbuf gstdbuf
45 compinit:511> compdef -na _sed sed gsed psed s2p
45 compinit:511> compdef -na _php php -P 'php[0-9.-]'
45 compinit:511> compdef -na _object_classes odmget odmshow odme
45 compinit:511> compdef -na _netstat netstat
45 compinit:511> compdef -na _net_interfaces ifup ifdown
45 compinit:511> compdef -na _mozilla mozilla mozilla-firefox mozilla-xremote-cl...
45 compinit:511> compdef -na _lunchy lunchy
45 compinit:511> compdef -na _look look
45 compinit:511> compdef -na _kitchen kitchen
45 compinit:511> compdef -na _jobs_builtin jobs
45 compinit:511> compdef -na _host host
45 compinit:511> compdef -na _flac flac metaflac
45 compinit:511> compdef -na _fakeroot fakeroot
45 compinit:511> compdef -na _docker docker dockerd
45 compinit:511> compdef -na _dlocate dlocate
45 compinit:511> compdef -na _coffee coffee
45 compinit:511> compdef -na _add-zle-hook-widget add-zle-hook-widget
45 compinit:509> compdef -kna _most_recent_file complete-word 'C-xm'
45 compinit:508> [[ a2ensite = -[pPkK](n|) ]]
45 compinit:508> [[ -K = -[pPkK](n|) ]]
45 compinit:506> case #compdef (#compdef)
45 compinit:506> case #compdef (#compdef)
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#compdef'
45 compinit:504> _i_tag='#autoload'
45 compinit:504> _i_tag='#autoload'
45 compinit:504> _i_tag='#autoload'
45 compinit:500> _i_name=_setsid
45 compinit:498> ((  0  ))
45 compdump:121> shift _d_als
45 compdump:121> shift _d_als
45 compdump:121> shift _d_als
45 compdump:121> shift _d_als
45 compdump:121> shift _d_als
45 compdump:121> shift _d_als
45 compdump:116> ((  ! --_i && 482 > 1  ))
45 compdump:114> ((  ! 0  ))
45 compdump:114> ((  ! 0  ))
45 compdump:113> ((  868  ))
45 compdump:95> read -rA _d_line
45 compdump:84> read -rA _d_line
45 compdump:84> read -rA _d_line
45 compdump:84> read -rA _d_line
45 compdump:44> print -r - ''google'' ''_google''
45 compdump:44> print -r - ''atrm'' ''_at''
45 compdef:169> shift
45 compdef:162> [[ -z yes || -z _source ]]
45 compdef:162> [[ -z yes || -z _ps1234 ]]
45 compdef:162> [[ -z yes || -z _mdutil ]]
45 compdef:155> [[ scl = *=* ]]
45 compdef:139> case  (pattern)
45 compdef:136> [[ gnocchi = -P ]]
45 compdef:134> [[ ipsec = -p ]]
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:131> ((  0  ))
45 compdef:83> case  (widgetkey)
45 compdef:83> case  (*)
45 compdef:80> [[ -n yes ]]
45 compdef:80> [[ -n yes ]]
45 compdef:38> shift OPTIND-1
45 compdef:38> shift OPTIND-1
45 compdef:16> autol=yes
45 compdef:16> autol=yes
45 compdef:16> autol=yes
45 compdef:15> case n (a)
45 compdef:14> getopts anpPkKde opt
45 compdef:14> getopts anpPkKde opt
45 compdef:14> getopts anpPkKde opt
45 compdef:9> ((  ! 13  ))
45 compdef:4> emulate -L zsh
45 compdef:4> emulate -L zsh
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
45 antigen-bundle-parallel:1> TRACE 'antigen-bundle-parallel: zsh-users/zsh-synt...
45 add-zle-hook-widget:89> zle -N zle-line-pre-redraw azhw:zle-line-pre-redraw
45 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
45 _zsh_highlight_bind_widgets:27> case completion:.delete-char-or-list:_main_co...
45 WARN:1> local PREFIX='[WRN][1653210536.9552149773]'
45 WARN:1> local PREFIX='[WRN][1653210536.9515130520]'
45 WARN:1> local PREFIX='[WRN][1653210536.9390780926]'
45 WARN:1> local PREFIX='[WRN][1653210536.9388229847]'
45 WARN:1> local PREFIX='[WRN][1653210536.9357130527]'
45 WARN:1> local PREFIX='[WRN][1653210536.9336249828]'
45 WARN:1> local PREFIX='[WRN][1653210536.9304440022]'
45 WARN:1> local PREFIX='[WRN][1653210536.9302320480]'
45 LOG:1> local PREFIX='[LOG][1653210536.9393780231]'
45 LOG:1> local PREFIX='[LOG][1653210536.9088621140]'
45 /Users/matt/.zshrc:435> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
45 /Users/matt/.zshrc:431> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
45 /Users/matt/.zcompdump:1952> zle -C _bash_complete-word .complete-word _bash_...
45 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:302> alias 'gtl=gtl(){ git ...
45 /Users/matt/.oh-my-zsh/lib/misc.zsh:8> autoload -Uz bracketed-paste-magic
45 /Users/matt/.oh-my-zsh/lib/completion.zsh:37> zstyle ':completion:*:*:*:*:pro...
45 /Users/matt/.oh-my-zsh/lib/completion.zsh:32> zstyle ':completion:*:*:kill:*:...
45 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
45 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:25> add-zsh-hook preexec _fasd_p...
45 /Users/matt/.iterm2_shell_integration.zsh:15> [[ -o interactive ]]
45 /Users/matt/.antigen/init.zsh:75> _ANTIGEN_BUNDLE_RECORD=( 'https://github.co...
45 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
45 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
45 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
45 -antigen-parse-args:121> [[ "$name" -regex-match '.*/(.*/.*).*$' ]]
45 -antigen-load-env-cached:2> bundle=( dir /Users/matt/.antigen/bundles/robbyru...
45 -antigen-hook-handler:71> return 0
45 -antigen-hook-handler:64> WARN 'Post hook:' antigen-apply-cached
45 -antigen-hook-handler:50> -antigen-load-env-cached dir /Users/matt/.antigen/b...
45 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-env-cached dir /...
45 (anon):16> eval $'_zsh_autosuggest_widget_fetch() {ntttlocal -i retvalnnttt_z...
44 is_plugin:2> local name=pyenv-lazy
44 is-at-least:53> return 0
44 compinit:511> compdef -na _wget wget
44 compinit:511> compdef -na _trash-empty trash-empty
44 compinit:511> compdef -na _trash trash
44 compinit:511> compdef -na _tmuxinator tmuxinator mux
44 compinit:511> compdef -na _sw_vers sw_vers
44 compinit:511> compdef -na _service service
44 compinit:511> compdef -na _ruby ruby irb erb ruby-mri -P '(ruby|[ei]rb)[0-9.]...
44 compinit:511> compdef -na _pfctl pfctl
44 compinit:511> compdef -na _networksetup networksetup
44 compinit:511> compdef -na _mktemp mktemp gmktemp
44 compinit:511> compdef -na _mii-tool mii-tool
44 compinit:511> compdef -na _luarocks luarocks
44 compinit:511> compdef -na _ls ls gls
44 compinit:511> compdef -na _lighttpd lighty-enable-mod lighty-disable-mod
44 compinit:511> compdef -na _kld kldload kldunload
44 compinit:511> compdef -na _ibus ibus
44 compinit:511> compdef -na _grep-excuses grep-excuses
44 compinit:511> compdef -na _global global
44 compinit:511> compdef -na _ghostscript gs ghostscript
44 compinit:511> compdef -na _getopt getopt ggetopt
44 compinit:511> compdef -na _getent getent
44 compinit:511> compdef -na _env env genv
44 compinit:511> compdef -na _ecdsautil ecdsautil
44 compinit:511> compdef -na _drush drush
44 compinit:511> compdef -na _docpad docpad
44 compinit:511> compdef -na _docker_compose docker-compose
44 compinit:511> compdef -na _dladm dladm
44 compinit:511> compdef -na _darcs darcs
44 compinit:511> compdef -na _bug bug reportbug querybts
44 compinit:511> compdef -na _brew_services brew
44 compinit:511> compdef -na _apachectl apachectl apache2ctl
44 compinit:511> compdef -na _ant ant -value-,ANT_ARGS,-default-
44 compinit:511> compdef -na _alsa-utils aplay arecord
44 compinit:511> compdef -na _aliases unalias
44 compinit:508> [[ rspec = -[pPkK](n|) ]]
44 compinit:508> [[ -math- = -[pPkK](n|) ]]
44 compinit:505> shift _i_line
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#compdef'
44 compinit:504> _i_tag='#autoload'
44 compinit:504> _i_tag='#autoload'
44 compinit:504> _i_tag='#autoload'
44 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:121> shift _d_als
44 compdump:116> ((  ! --_i && 431 > 1  ))
44 compdump:115> print -n ' _tin'
44 compdump:115> print -n ' _showmount'
44 compdump:113> ((  797  ))
44 compdump:84> read -rA _d_line
44 compdump:44> print -r - ''dhcpcd'' ''_dhcpcd''
44 compdef:169> shift
44 compdef:164> [[ -n yes ]]
44 compdef:136> [[ printf = -P ]]
44 compdef:136> [[ dash = -P ]]
44 compdef:132> [[ ttyctl = -N ]]
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:131> ((  0  ))
44 compdef:93> zle -C _list_expansions .list-choices _expand_word
44 compdef:93> zle -C _history-complete-newer .complete-word _history_complete_word
44 compdef:49> [[ _seq = *=* ]]
44 compdef:38> shift OPTIND-1
44 compdef:38> shift OPTIND-1
44 compdef:17> new=yes
44 compdef:16> autol=yes
44 compdef:5> setopt extendedglob
44 compdef:5> setopt extendedglob
44 compdef:5> setopt extendedglob
44 compdef:4> emulate -L zsh
44 compdef:4> emulate -L zsh
44 compdef:2> local -a match mbegin mend
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
44 antigen-remove-hook:15> ((  1  ))
44 antigen-add-hook:34> return 0
44 add-zsh-hook:85> typeset -ga precmd_functions
44 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
44 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_history-comp...
44 WARN:1> local PREFIX='[WRN][1653210536.9704639912]'
44 WARN:1> local PREFIX='[WRN][1653210536.9555900097]'
44 WARN:1> local PREFIX='[WRN][1653210536.9547460079]'
44 WARN:1> local PREFIX='[WRN][1653210536.9399080276]'
44 WARN:1> local PREFIX='[WRN][1653210536.9338250160]'
44 WARN:1> local PREFIX='[WRN][1653210536.9140360355]'
44 /Users/matt/.zshrc:437> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
44 /Users/matt/.zshrc:428> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
44 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:188> compdef _git 'ggpnp=gi...
44 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:2> autoload -U colors
44 /Users/matt/.oh-my-zsh/lib/directories.zsh:35> alias 'lsa=ls -lah'
44 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
44 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
44 -antigen-load:32> -antigen-load-env dir /Users/matt/.antigen/bundles/zsh-user...
44 -antigen-load-env-cached:2> bundle=( dir /Users/matt/.antigen/bundles/zsh-use...
44 -antigen-hook-handler:71> return 0
44 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-source-cached /U...
44 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-lock'
44 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-defer antige...
44 -antigen-cache-generate:2> local record
44 (anon):722> typeset -g POWERLEVEL9K_VI_COMMAND_MODE_STRING=NORMAL
44 (anon):16> eval $'_zsh_autosuggest_widget_execute() {ntttlocal -i retvalnnttt...
43 detect-clipboard:3> ((  1  ))
43 compinit:511> compdef -na _ztodo ztodo
43 compinit:511> compdef -na _zcompile zcompile
43 compinit:511> compdef -na _xwit xwit
43 compinit:511> compdef -na _xpdf xpdf zxpdf
43 compinit:511> compdef -na _wc wc gwc
43 compinit:511> compdef -na _wanna-build wanna-build
43 compinit:511> compdef -na _uscan uscan
43 compinit:511> compdef -na _unhash unhash
43 compinit:511> compdef -na _tty tty gtty
43 compinit:511> compdef -na _totd totdconfig
43 compinit:511> compdef -na _timeout timeout gtimeout
43 compinit:511> compdef -na _tcpdump tcpdump
43 compinit:511> compdef -na _rsvm rsvm
43 compinit:511> compdef -na _portmaster portmaster
43 compinit:511> compdef -na _pgsql_utils psql pg_dump pg_dumpall pg_restore cre...
43 compinit:511> compdef -na _pgrep pgrep pkill
43 compinit:511> compdef -na _nm nm eu-nm
43 compinit:511> compdef -na _mosh mosh
43 compinit:511> compdef -na _mkshortcut mkshortcut mkshortcut.exe
43 compinit:511> compdef -na _mkfifo mkfifo gmkfifo
43 compinit:511> compdef -na _mixerctl mixerctl
43 compinit:511> compdef -na _mencal mencal
43 compinit:511> compdef -na _lynx lynx
43 compinit:511> compdef -na _losetup losetup -value-,LOOPDEV_DEBUG,-default-
43 compinit:511> compdef -na _lintian lintian lintian-info
43 compinit:511> compdef -na _ldconfig ldconfig ldconfig.real
43 compinit:511> compdef -na _last last lastb
43 compinit:511> compdef -na _graphicsmagick gm
43 compinit:511> compdef -na _getclip getclip getclip.exe
43 compinit:511> compdef -na _genisoimage genisoimage
43 compinit:511> compdef -na _fuser fuser
43 compinit:511> compdef -na _freebsd-update freebsd-update
43 compinit:511> compdef -na _dget dget
43 compinit:511> compdef -na _dad dad
43 compinit:511> compdef -na _cppcheck cppcheck
43 compinit:511> compdef -na _cowsay cowsay cowthink
43 compinit:511> compdef -na _chromium chromium
43 compinit:511> compdef -na _bzip2 bzip2 bunzip2 'bzcat=bunzip2' bzip2recover '...
43 compinit:511> compdef -na _builtin builtin
43 compinit:511> compdef -na _bsdinstall bsdinstall
43 compinit:511> compdef -na _brace_parameter -brace-parameter-
43 compinit:511> compdef -na _bitcoin-cli bitcoin-cli
43 compinit:511> compdef -na _beadm beadm
43 compinit:511> compdef -na _attr attr getfattr setfattr xattr
43 compinit:511> compdef -na _at atrm atq at batch
43 compinit:511> compdef -na _apt-show-versions apt-show-versions
43 compinit:511> compdef -na _apm apm
43 compinit:511> compdef -na _ack ack ack2 ack-grep ack-standalone
43 compinit:509> compdef -kna _complete_help complete-word 'C-xh'
43 compinit:505> shift _i_line
43 compinit:505> shift _i_line
43 compinit:505> shift _i_line
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#compdef'
43 compinit:504> _i_tag='#autoload'
43 compinit:504> _i_tag='#autoload'
43 compinit:501> ((  0 + 0  ))
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:121> shift _d_als
43 compdump:115> print -n ' _vnstat'
43 compdump:114> ((  ! 0  ))
43 compdump:114> ((  ! 0  ))
43 compdump:113> ((  724  ))
43 compdump:95> read -rA _d_line
43 compdump:84> read -rA _d_line
43 compdump:84> read -rA _d_line
43 compdump:44> print -r - ''lha'' ''_lha''
43 compdump:43> _d_f=psmerge
43 compdef:169> shift
43 compdef:169> shift
43 compdef:162> [[ -z yes || -z _xpdf ]]
43 compdef:162> [[ -z yes || -z _sccs ]]
43 compdef:162> [[ -z yes || -z _samba ]]
43 compdef:162> [[ -z yes || -z _math ]]
43 compdef:139> case  (*)
43 compdef:136> [[ lighty-disable-mod = -P ]]
43 compdef:136> [[ jmeter-plugins = -P ]]
43 compdef:132> [[ tla = -N ]]
43 compdef:131> ((  8  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:131> ((  0  ))
43 compdef:100> shift 3
43 compdef:96> [[ _list_expansions = undefined-key ]]
43 compdef:83> case  (key)
43 compdef:81> shift
43 compdef:81> shift
43 compdef:80> autoload -Uz _plutil
43 compdef:17> new=yes
43 compdef:17> new=yes
43 compdef:14> getopts anpPkKde opt
43 compdef:14> getopts anpPkKde opt
43 compdef:14> getopts anpPkKde opt
43 compdef:9> ((  ! 5  ))
43 compdef:9> ((  ! 3  ))
43 compdef:5> setopt extendedglob
43 compdef:4> emulate -L zsh
43 compdef:2> local -a match mbegin mend
43 compdef:2> local -a match mbegin mend
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
43 colors:77> color[${color[$k]}]=30
43 antigen:2> return 0
43 antigen-bundle:2> return 0
43 antigen-bundle-parallel-execute:39> local bundle
43 antigen-apply-cached:6> [[ true == true && 2 -eq 0 ]]
43 antigen-add-hook:34> return 0
43 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
43 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
43 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
43 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_list_expansi...
43 WARN:1> local PREFIX='[WRN][1653210536.9426119328]'
43 WARN:1> local PREFIX='[WRN][1653210536.9402849674]'
43 WARN:1> local PREFIX='[WRN][1653210536.9144039154]'
43 /usr/local/share/antigen/antigen.zsh:54> typeset -aU _ANTIGEN_BUNDLE_RECORD
43 /Users/matt/.zshrc:441> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
43 /Users/matt/.zshrc:440> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
43 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:279> alias 'gst=git status'
43 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
43 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:41> bindkey -M vicmd $'C-[OA' up-...
43 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
43 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
43 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
43 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:31> ...
43 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:23> a...
43 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:78> ba...
43 -antigen-parse-args:164> return 0
43 -antigen-load-env:2> return 0
43 -antigen-hook-handler:71> return 0
43 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-env-cached dir /...
43 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
43 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
43 -antigen-hook-antigen-bundle:26> -antigen-load btype plugin dir /Users/matt/....
43 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggest...
43 (anon):439> typeset -g 'POWERLEVEL9K_VCS_STAGED_MAX_NUM=-1' 'POWERLEVEL9K_VCS...
43 (anon):16> eval $'_zsh_autosuggest_widget_disable() {ntttlocal -i retvalnnttt...
42 is_theme:2> local name=robbyrussell
42 is_plugin:4> test -f /Users/matt/.oh-my-zsh/custom/plugins/zshfl/_zshfl
42 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/zshfl/zshfl.plugin...
42 is_plugin:2> local name=zsh-syntax-highlighting
42 is-at-least:30> ((  0 <= 2  ))
42 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
42 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
42 group_lazy_load:5> alias 'rake=lazy_load "rvm irb rake" ". /Users/matt/.rvm/s...
42 compinit:546> unfunction compinit compaudit
42 compinit:516> [[ '' !=  # ]]
42 compinit:511> compdef -na _yafc yafc
42 compinit:511> compdef -na _xsel xsel
42 compinit:511> compdef -na _xournal xournal
42 compinit:511> compdef -na _xmodmap xmodmap
42 compinit:511> compdef -na _w w
42 compinit:511> compdef -na _tox tox
42 compinit:511> compdef -na _top top
42 compinit:511> compdef -na _toilet toilet
42 compinit:511> compdef -na _tla tla
42 compinit:511> compdef -na _svcs svcs
42 compinit:511> compdef -na _svcadm svcadm
42 compinit:511> compdef -na _sqsh sqsh
42 compinit:511> compdef -na _sqlite sqlite sqlite3
42 compinit:511> compdef -na _softwareupdate softwareupdate
42 compinit:511> compdef -na _script script scriptreplay
42 compinit:511> compdef -na _schroot schroot
42 compinit:511> compdef -na _schedtool schedtool
42 compinit:511> compdef -na _sched sched
42 compinit:511> compdef -na _sc_usage sc_usage
42 compinit:511> compdef -na _say say
42 compinit:511> compdef -na _rrdtool rrdtool
42 compinit:511> compdef -na _rm rm grm zf_rm
42 compinit:511> compdef -na _rdesktop rdesktop xfreerdp
42 compinit:511> compdef -na _quilt quilt
42 compinit:511> compdef -na _qiv qiv
42 compinit:511> compdef -na _ptree ptree
42 compinit:511> compdef -na _portaudit portaudit
42 compinit:511> compdef -na _pon pon poff
42 compinit:511> compdef -na _pm2 pm2
42 compinit:511> compdef -na _pfexec pfexec
42 compinit:511> compdef -na _pbcopy pbcopy pbpaste
42 compinit:511> compdef -na _okular okular
42 compinit:511> compdef -na _nvram nvram
42 compinit:511> compdef -na _nftables nft
42 compinit:511> compdef -na _netcat nc netcat
42 compinit:511> compdef -na _ncftp ncftp lftp
42 compinit:511> compdef -na _nautilus nautilus
42 compinit:511> compdef -na _mysqldiff mysqldiff
42 compinit:511> compdef -na _madison madison rmadison
42 compinit:511> compdef -na _lsusb lsusb
42 compinit:511> compdef -na _lspv lspv
42 compinit:511> compdef -na _lsof lsof
42 compinit:511> compdef -na _lscfg lscfg
42 compinit:511> compdef -na _locale locale
42 compinit:511> compdef -na _limit limit
42 compinit:511> compdef -na _kvno kvno
42 compinit:511> compdef -na _kill kill
42 compinit:511> compdef -na _joe joe
42 compinit:511> compdef -na _jexec jexec
42 compinit:511> compdef -na _jail jail
42 compinit:511> compdef -na _inxi inxi
42 compinit:511> compdef -na _hostname hostname
42 compinit:511> compdef -na _hash hash rehash
42 compinit:511> compdef -na _gphoto2 gphoto2
42 compinit:511> compdef -na _getfacl getfacl getfacl.exe
42 compinit:511> compdef -na _geany geany
42 compinit:511> compdef -na _gcore gcore
42 compinit:511> compdef -na _fusermount fusermount
42 compinit:511> compdef -na _fstat fstat
42 compinit:511> compdef -na _finger finger
42 compinit:511> compdef -na _findmnt findmnt
42 compinit:511> compdef -na _find find gfind
42 compinit:511> compdef -na _files -redirect-,-default-,-default-
42 compinit:511> compdef -na _fc fc history r
42 compinit:511> compdef -na _emulator emulator
42 compinit:511> compdef -na _dtrace dtrace
42 compinit:511> compdef -na _dput dput
42 compinit:511> compdef -na _bibtex bibtex
42 compinit:511> compdef -na _bash bash
42 compinit:511> compdef -na _auto-apt auto-apt
42 compinit:511> compdef -na _asciinema asciinema
42 compinit:511> compdef -na _apt-file apt-file
42 compinit:511> compdef -na _android android
42 compinit:511> compdef -na _add-zsh-hook add-zsh-hook
42 compinit:509> compdef -kna _next_tags list-choices 'C-xn'
42 compinit:509> compdef -kna _correct_word complete-word 'C-xc'
42 compinit:509> compdef -kna _correct_filename complete-word 'C-xC'
42 compinit:509> compdef -Pna _yodl 'yodl(|2*)'
42 compinit:509> compdef -Pna _tiff '(tiff*|*2tiff|pal2rgb)'
42 compinit:509> compdef -Pna _qemu 'qemu(|-system-*)'
42 compinit:508> [[ snap = -[pPkK](n|) ]]
42 compinit:508> [[ protoc = -[pPkK](n|) ]]
42 compinit:508> [[ iftop = -[pPkK](n|) ]]
42 compinit:508> [[ hledger = -[pPkK](n|) ]]
42 compinit:508> [[ git-pulls = -[pPkK](n|) ]]
42 compinit:506> case #compdef (#compdef)
42 compinit:505> shift _i_line
42 compinit:505> shift _i_line
42 compinit:505> shift _i_line
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#compdef'
42 compinit:504> _i_tag='#autoload'
42 compinit:501> ((  0 + 0  ))
42 compinit:500> _i_name=_python
42 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_selinux_users
42 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jobs_fg
42 compdump:121> shift _d_als
42 compdump:121> shift _d_als
42 compdump:121> shift _d_als
42 compdump:116> ((  ! --_i && 1092 > 1  ))
42 compdump:116> ((  ! --_i && 1051 > 1  ))
42 compdump:116> ((  ! --_i && 171 > 1  ))
42 compdump:114> ((  ! 0  ))
42 compdump:113> ((  7  ))
42 compdump:90> print -r - zle -C _read_comp .complete-word _read_comp
42 compdump:84> read -rA _d_line
42 compdump:44> print -r - ''w'' ''_w''
42 compdump:43> _d_f=pidstat
42 compdump:43> _d_f=nocorrect
42 compdef:169> shift
42 compdef:169> shift
42 compdef:162> [[ -z yes || -z _sed ]]
42 compdef:162> [[ -z yes || -z _groups ]]
42 compdef:162> [[ -z yes || -z _add-zle-hook-widget ]]
42 compdef:139> case  (pattern)
42 compdef:131> ((  3  ))
42 compdef:131> ((  2  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:131> ((  0  ))
42 compdef:83> case  (*)
42 compdef:83> case  (*)
42 compdef:81> shift
42 compdef:80> autoload -Uz _locales
42 compdef:80> [[ -n yes ]]
42 compdef:79> func=_genisoimage
42 compdef:49> [[ _toilet = *=* ]]
42 compdef:45> [[ -z '' ]]
42 compdef:15> case n (n)
42 compdef:15> case a (a)
42 compdef:14> getopts anpPkKde opt
42 compdef:9> ((  ! 5  ))
42 compdef:9> ((  ! 3  ))
42 compdef:4> emulate -L zsh
42 compdef:4> emulate -L zsh
42 compdef:2> local -a match mbegin mend
42 compdef:2> local -a match mbegin mend
42 compdef:2> local -a match mbegin mend
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
42 antigen-remove-hook:12> [[ 4 == 0 ]]
42 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_cursor_p...
42 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
42 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
42 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
42 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
42 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
42 _zsh_highlight_bind_widgets:26> cur_widget=kill-buffer
42 /Users/matt/.zshrc:433> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
42 /Users/matt/.zshrc:329> [ -z x ']'
42 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:90> is_plugin /Users/matt/.oh-my-zsh fasd
42 /Users/matt/.oh-my-zsh/lib/history.zsh:32> SAVEHIST=10000
42 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
42 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'imgls=/Users/matt/.iter...
42 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
42 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:50> ...
42 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:40> setop...
42 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:21> case ...
42 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
42 -antigen-load-env-cached:2> bundle=( dir /Users/matt/.antigen/bundles/robbyru...
42 -antigen-hook-handler:69> LOG 'Return from hook antigen-apply with 0'
42 -antigen-hook-handler:37> hook=antigen-apply-defer
42 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-source-cached'
42 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
42 -antigen-hook-handler:11> meta=( target antigen-apply mode once type pre call...
42 -antigen-hook-handler:11> meta=( target antigen type pre mode once called 0 )
42 -antigen-hook-handler:1> local target=antigen-bundle args hook called
42 (anon):127> typeset -g POWERLEVEL9K_MULTILINE_NEWLINE_PROMPT_GAP_BACKGROUND=''
42 (anon):16> eval $'_zsh_autosuggest_widget_accept() {ntttlocal -i retvalnnttt_...
42 (anon):1> emulate -L zsh -o extended_glob
41 is-at-least:53> return 0
41 env_default:2> return 3
41 env_default:1> return 0
41 compinit:511> compdef -na _zeal zeal
41 compinit:511> compdef -na _xxd xxd
41 compinit:511> compdef -na _xv xv
41 compinit:511> compdef -na _xset xset
41 compinit:511> compdef -na _watch watch
41 compinit:511> compdef -na _wajig wajig
41 compinit:511> compdef -na _vpnc vpnc vpnc-connect
41 compinit:511> compdef -na _urpmi urpme urpmi urpmi.addmedia urpmi.removemedia...
41 compinit:511> compdef -na _update-rc.d update-rc.d
41 compinit:511> compdef -na _trash-list trash-list
41 compinit:511> compdef -na _tput tput
41 compinit:511> compdef -na _tpb tpb
41 compinit:511> compdef -na _tmuxp tmuxp
41 compinit:511> compdef -na _sshfs sshfs
41 compinit:511> compdef -na _seq seq gseq
41 compinit:511> compdef -na _scutil scutil
41 compinit:511> compdef -na _screen screen
41 compinit:511> compdef -na _redirect -redirect-
41 compinit:511> compdef -na _rake rake
41 compinit:511> compdef -na _netscape netscape
41 compinit:511> compdef -na _mupdf mupdf
41 compinit:511> compdef -na _mt mt
41 compinit:511> compdef -na _module module
41 compinit:511> compdef -na _mix mix
41 compinit:511> compdef -na _lz4 lz4 lz4c lz4c32 lz4cat unlz4
41 compinit:511> compdef -na _loadkeys loadkeys
41 compinit:511> compdef -na _links links links2
41 compinit:511> compdef -na _ldd ldd
41 compinit:511> compdef -na _ldap ldap
41 compinit:511> compdef -na _jot jot
41 compinit:511> compdef -na _jonas jonas
41 compinit:511> compdef -na _groff groff
41 compinit:511> compdef -na _functions unfunction
41 compinit:511> compdef -na _free free
41 compinit:511> compdef -na _flowadm flowadm
41 compinit:511> compdef -na _flex flex flex++
41 compinit:511> compdef -na _fetch fetch
41 compinit:511> compdef -na _enscript enscript
41 compinit:511> compdef -na _diff diff gdiff
41 compinit:511> compdef -na _debfoster debfoster
41 compinit:511> compdef -na _cryptsetup cryptsetup
41 compinit:511> compdef -na _condition -condition-
41 compinit:511> compdef -na _bts bts
41 compinit:511> compdef -na _basename basename gbasename
41 compinit:511> compdef -na _asciidoctor asciidoctor
41 compinit:511> compdef -na _arping arping
41 compinit:511> compdef -na _apt-move apt-move
41 compinit:511> compdef -na _abcde abcde
41 compinit:511> compdef -na _SUSEconfig SuSEconfig
41 compinit:508> [[ tee = -[pPkK](n|) ]]
41 compinit:508> [[ snoop = -[pPkK](n|) ]]
41 compinit:508> [[ gstat = -[pPkK](n|) ]]
41 compinit:508> [[ debdiff = -[pPkK](n|) ]]
41 compinit:508> [[ android = -[pPkK](n|) ]]
41 compinit:505> shift _i_line
41 compinit:505> shift _i_line
41 compinit:505> shift _i_line
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#compdef'
41 compinit:504> _i_tag='#autoload'
41 compinit:504> _i_tag='#autoload'
41 compinit:76> [[ 1 -gt 0 && -C = -[dDiuC] ]]
41 compdump:121> shift _d_als
41 compdump:121> shift _d_als
41 compdump:121> shift _d_als
41 compdump:121> shift _d_als
41 compdump:118> print -n ' 
           '
41 compdump:117> _i=5
41 compdump:116> ((  ! --_i && 913 > 1  ))
41 compdump:115> print -n ' _say'
41 compdump:113> ((  605  ))
41 compdump:96> [[ _correct_filename = (_bash_complete-word|_bash_list-choices|_...
41 compdump:43> _d_f=chrt
41 compdef:169> shift
41 compdef:169> shift
41 compdef:169> shift
41 compdef:169> shift
41 compdef:169> shift
41 compdef:162> [[ -z yes || -z _precommand ]]
41 compdef:162> [[ -z yes || -z _gtk-launch ]]
41 compdef:156> cmd=ggpnp
41 compdef:139> case  (*)
41 compdef:136> [[ twidge = -P ]]
41 compdef:136> [[ truss = -P ]]
41 compdef:134> [[ mina = -p ]]
41 compdef:132> [[ protoc = -N ]]
41 compdef:132> [[ cssh = -N ]]
41 compdef:131> ((  16  ))
41 compdef:131> ((  10  ))
41 compdef:131> ((  1  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:131> ((  0  ))
41 compdef:96> [[ _expand_alias = undefined-key ]]
41 compdef:83> case  (*)
41 compdef:81> shift
41 compdef:81> shift
41 compdef:49> [[ _todo.sh = *=* ]]
41 compdef:49> [[ _rspec = *=* ]]
41 compdef:45> [[ -z '' ]]
41 compdef:40> ((  ! 2  ))
41 compdef:38> shift OPTIND-1
41 compdef:17> new=yes
41 compdef:16> autol=yes
41 compdef:14> getopts anpPkKde opt
41 compdef:14> getopts anpPkKde opt
41 compdef:9> ((  ! 4  ))
41 compdef:5> setopt extendedglob
41 compdef:5> setopt extendedglob
41 compdef:5> setopt extendedglob
41 compdef:5> setopt extendedglob
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:4> emulate -L zsh
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:2> local -a match mbegin mend
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
41 antigen-remove-hook:12> [[ 1 == 0 ]]
41 antigen-ext:9> _ANTIGEN_EXTENSIONS+=( defer )
41 antigen-ext:3> ((  1 && 0 == 0  ))
41 antigen-ext:3> ((  1 && 0 == 0  ))
41 antigen-ext-init:5> antigen-ext lock
41 antigen-bundle-parallel-execute:24> repositories+=( https://github.com/zsh-us...
41 antigen-apply:2> return 0
41 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle type r...
41 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_pattern_...
41 _zsh_highlight_bind_widgets:50> zle -N forward-word _zsh_highlight_widget_ori...
41 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
41 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
41 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
41 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
41 /Users/matt/.zshrc:134> test -e /Users/matt/.iterm2_shell_integration.zsh
41 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:262> alias 'grrm=git remote...
41 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:178> is_theme /Users/matt/.oh-my-zsh/cust...
41 /Users/matt/.oh-my-zsh/lib/completion.zsh:78> bashcompinit
41 /Users/matt/.antigen/init.zsh:78> _ANTIGEN_CACHE_VERSION=v2.2.3
41 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
41 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
41 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
41 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:116> ...
41 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
41 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:19> ...
41 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:32> zs...
41 -antigen-parse-args:164> return 0
41 -antigen-parse-args:164> return 0
41 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/zs...
41 -antigen-load:32> -antigen-load-env dir /Users/matt/.antigen/bundles/zsh-user...
41 -antigen-load-env-cached:11> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/bu...
41 -antigen-hook-handler:51> [[ 0 == -1 ]]
41 -antigen-hook-handler:50> -antigen-load-env-cached dir /Users/matt/.antigen/b...
41 -antigen-hook-handler:50> -antigen-load-env-cached dir /Users/matt/.antigen/b...
41 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-env-cached dir /...
41 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-apply mode once...
41 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-apply...
41 -antigen-hook-antigen-bundle:32> _ANTIGEN_BUNDLE_RECORD+=( 'https://github.co...
41 -antigen-hook-antigen-bundle:26> -antigen-load btype plugin dir /Users/matt/....
41 -antigen-env-setup:52> ((  1  ))
41 (eval):1> typeset -g ANTIGEN_PREZTO_REPO_URL=https://github.com/sorin-ionescu...
41 (eval):1> typeset -g ANTIGEN_COMPINIT_OPTS=-i
41 (eval):1> typeset -g ANTIGEN_CLONE_OPTS='--single-branch --recursive --depth=1'
41 (anon):920> typeset -g POWERLEVEL9K_GOENV_PROMPT_ALWAYS_SHOW=false
41 (anon):16> eval $'_zsh_autosuggest_widget_enable() {ntttlocal -i retvalnnttt_...
41 (anon):3> eval $'_zsh_autosuggest_widget_fetch() {ntttlocal -i retvalnnttt_zs...
41 (anon):3> eval $'_zsh_autosuggest_widget_enable() {ntttlocal -i retvalnnttt_z...
40 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
40 is-at-least:23> emulate -L zsh
40 env_default:1> return 0
40 compinit:530> _i_line=complete-word
40 compinit:511> compdef -na _tail tail gtail
40 compinit:511> compdef -na _svccfg svccfg
40 compinit:511> compdef -na _set set
40 compinit:511> compdef -na _prstat prstat
40 compinit:511> compdef -na _portsnap portsnap
40 compinit:511> compdef -na _pmap pmap
40 compinit:511> compdef -na _pkginfo pkginfo
40 compinit:511> compdef -na _perl perl
40 compinit:511> compdef -na _pbuilder pbuilder
40 compinit:511> compdef -na _monotone mtn
40 compinit:511> compdef -na _ltrace ltrace
40 compinit:511> compdef -na _lslv lslv
40 compinit:511> compdef -na _imagemagick animate composite combine convert disp...
40 compinit:511> compdef -na _gnome-gv gnome-gv ggv
40 compinit:511> compdef -na _fsh fsh
40 compinit:511> compdef -na _choc choc
40 compinit:511> compdef -na _bogofilter bogoutil bogotune bogofilter
40 compinit:511> compdef -na _bindkey bindkey
40 compinit:511> compdef -na _beep beep
40 compinit:511> compdef -na _atach atach
40 compinit:511> compdef -na _acpi acpi
40 compinit:508> [[ tarsnap = -[pPkK](n|) ]]
40 compinit:508> [[ mullvad = -[pPkK](n|) ]]
40 compinit:508> [[ evince = -[pPkK](n|) ]]
40 compinit:506> case #autoload (#autoload)
40 compinit:505> shift _i_line
40 compinit:505> shift _i_line
40 compinit:505> shift _i_line
40 compinit:505> shift _i_line
40 compinit:505> shift _i_line
40 compinit:505> shift _i_line
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#compdef'
40 compinit:504> _i_tag='#autoload'
40 compinit:504> _i_tag='#autoload'
40 compinit:501> ((  0 + 0  ))
40 compinit:191> : compinit -antigen-hook-antigen-apply -antigen-hook-handler an...
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:121> shift _d_als
40 compdump:118> print -n ' 
           '
40 compdump:117> _i=5
40 compdump:116> ((  ! --_i && 263 > 1  ))
40 compdump:115> print -n ' _wg-quick'
40 compdump:115> print -n ' _rake'
40 compdump:114> ((  ! 0  ))
40 compdump:96> [[ transpose-chars = (_bash_complete-word|_bash_list-choices|_co...
40 compdump:96> [[ history-search-backward = (_bash_complete-word|_bash_list-cho...
40 compdump:96> [[ history-incremental-search-forward = (_bash_complete-word|_ba...
40 compdump:96> [[ backward-char = (_bash_complete-word|_bash_list-choices|_comp...
40 compdump:96> [[ _most_recent_file = (_bash_complete-word|_bash_list-choices|_...
40 compdump:96> [[ _list_expansions = (_bash_complete-word|_bash_list-choices|_c...
40 compdump:96> [[ _history-complete-newer = (_bash_complete-word|_bash_list-cho...
40 compdump:96> [[ _expand_word = (_bash_complete-word|_bash_list-choices|_compl...
40 compdump:96> [[ _complete_debug = (_bash_complete-word|_bash_list-choices|_co...
40 compdump:95> read -rA _d_line
40 compdump:95> read -rA _d_line
40 compdump:50> print -r - ''Mail'' ''mail''
40 compdef:169> shift
40 compdef:162> [[ -z yes || -z _tmuxp ]]
40 compdef:162> [[ -z yes || -z _perldoc ]]
40 compdef:162> [[ -z yes || -z _ispell ]]
40 compdef:162> [[ -z yes || -z _chattr ]]
40 compdef:155> [[ unexpand = *=* ]]
40 compdef:148> [[ 'gcc-*' = (#b)(*)=(*) ]]
40 compdef:139> case  (pattern)
40 compdef:139> case  (pattern)
40 compdef:136> [[ tcp_open = -P ]]
40 compdef:134> [[ cssh = -p ]]
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:131> ((  0  ))
40 compdef:96> [[ _bash_list-choices = undefined-key ]]
40 compdef:83> case  (*)
40 compdef:81> shift
40 compdef:80> autoload -Uz _force
40 compdef:80> [[ -n yes ]]
40 compdef:80> [[ -n yes ]]
40 compdef:38> shift OPTIND-1
40 compdef:16> autol=yes
40 compdef:15> case n (a)
40 compdef:14> getopts anpPkKde opt
40 compdef:9> ((  ! 5  ))
40 compdef:9> ((  ! 3  ))
40 compdef:5> setopt extendedglob
40 compdef:5> setopt extendedglob
40 compdef:4> emulate -L zsh
40 compdef:4> emulate -L zsh
40 compdef:2> local -a match mbegin mend
40 compdef:2> local -a match mbegin mend
40 compdef:2> local -a match mbegin mend
40 compdef:2> local -a match mbegin mend
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
40 compaudit:62> [[ 1094 -lt 20 || /usr/share/zsh/5.8.1/functions = */Base || -d...
40 antigen-remove-hook:2> meta=( target -antigen-load-source mode repeat type re...
40 antigen-add-hook:34> return 0
40 add-zsh-hook:66> local fn=omz_termsupport_precmd
40 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
40 add-zsh-hook:15> emulate -L zsh
40 add-zle-hook-widget:23> zmodload zsh/parameter
40 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_line_pre...
40 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_brackets...
40 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
40 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
40 _zsh_highlight_bind_widgets:50> zle -N capitalize-word _zsh_highlight_widget_...
40 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
40 _zsh_highlight_bind_widgets:19> widgets_to_bind+=( zle-line-finish )
40 /Users/matt/.zshrc:619> export PNPM_HOME=/Users/matt/Library/pnpm
40 /Users/matt/.zshrc:407> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
40 /Users/matt/.zshrc:91> plugins=( zshfl git zsh-syntax-highlighting zsh-autosu...
40 /Users/matt/.zcompdump:1963> zle -C _list_expansions .list-choices _expand_word
40 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:219> alias 'glol=git log --...
40 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:16> alias 'j=zz'
40 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
40 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
40 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:116> [[ iTerm.app == Apple_Termina...
40 /Users/matt/.oh-my-zsh/lib/grep.zsh:1> __GREP_CACHE_FILE=/Users/matt/.oh-my-z...
40 /Users/matt/.oh-my-zsh/lib/completion.zsh:34> [[ darwin21.0 = solaris* ]]
40 /Users/matt/.oh-my-zsh/lib/completion.zsh:4> WORDCHARS=''
40 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
40 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:59> zle -C fasd-complete complet...
40 /Users/matt/.iterm2_shell_integration.zsh:34> [ 1 -ne 0 ']'
40 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
40 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:13> bi...
40 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/zs...
40 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/zs...
40 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/ro...
40 -antigen-lock-execute:26> antigen-add-hook antigen-apply antigen-apply-lock p...
40 -antigen-load:4> typeset -Ua list
40 -antigen-load-env:2> return 0
40 -antigen-load-env:2> return 0
40 -antigen-hook-handler:50> -antigen-load-env-cached dir /Users/matt/.antigen/b...
40 -antigen-hook-handler:48> ((  1  ))
40 -antigen-hook-handler:12> [[ repeat == once ]]
40 -antigen-hook-antigen-bundle:32> _ANTIGEN_BUNDLE_RECORD+=( 'https://github.co...
40 -antigen-defer-execute:22> antigen-add-hook antigen-apply antigen-apply-defer...
40 -antigen-cache-execute:61> antigen-add-hook -antigen-load-source -antigen-loa...
40 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggest...
40 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh bt...
40 (anon):834> typeset -g 'POWERLEVEL9K_CONTEXT_DEFAULT_CONTENT_EXPANSION=' 'POW...
40 (anon):172> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_ERROR_VIINS_FOREGROUND=196' ...
40 (anon):170> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_OK_VIINS_FOREGROUND=76' 'POW...
40 (anon):16> eval $'_zsh_autosuggest_widget_modify() {ntttlocal -i retvalnnttt_...
40 (anon):3> eval $'_zsh_autosuggest_widget_partial_accept() {ntttlocal -i retva...
39 compinit:541> zstyle -a :completion: completer _i_line
39 compinit:511> compdef -na _zmv zmv zln zcp
39 compinit:511> compdef -na _topgit tg
39 compinit:511> compdef -na _time_zone -value-,TZ,-default-
39 compinit:511> compdef -na _teamocil teamocil
39 compinit:511> compdef -na _scons scons
39 compinit:511> compdef -na _runit sv
39 compinit:511> compdef -na _rslsync rslsync
39 compinit:511> compdef -na _rfkill rfkill
39 compinit:511> compdef -na _pwgen pwgen
39 compinit:511> compdef -na _locate locate mlocate slocate glocate
39 compinit:511> compdef -na _gv gv
39 compinit:511> compdef -na _feh feh
39 compinit:511> compdef -na _aap aap
39 compinit:508> [[ thor = -[pPkK](n|) ]]
39 compinit:508> [[ pump = -[pPkK](n|) ]]
39 compinit:508> [[ pmpath = -[pPkK](n|) ]]
39 compinit:508> [[ mussh = -[pPkK](n|) ]]
39 compinit:508> [[ -default- = -[pPkK](n|) ]]
39 compinit:508> [[ -P = -[pPkK](n|) ]]
39 compinit:505> shift _i_line
39 compinit:505> shift _i_line
39 compinit:505> shift _i_line
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#compdef'
39 compinit:504> _i_tag='#autoload'
39 compinit:504> _i_tag='#autoload'
39 compinit:504> _i_tag='#autoload'
39 compinit:504> _i_tag='#autoload'
39 compinit:501> ((  0 + 0  ))
39 compinit:500> _i_name=_pkginfo
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:121> shift _d_als
39 compdump:115> print -n ' _sysctl'
39 compdump:113> ((  416  ))
39 compdump:96> [[ history-search-forward = (_bash_complete-word|_bash_list-choi...
39 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
39 compdump:96> [[ _history-complete-older = (_bash_complete-word|_bash_list-cho...
39 compdump:96> [[ _correct_word = (_bash_complete-word|_bash_list-choices|_comp...
39 compdump:90> print -r - zle -C _expand_alias .complete-word _expand_alias
39 compdump:44> print -r - ''pidstat'' ''_sysstat''
39 compdump:44> print -r - ''figlet'' ''_figlet''
39 compdump:43> _d_f=rubocop
39 compdef:164> _services[$cmd]=git-checkout
39 compdef:162> [[ -z yes || -z _precommand ]]
39 compdef:162> [[ -z yes || -z _openstack ]]
39 compdef:159> cmd=gb2sum
39 compdef:132> [[ stg = -N ]]
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:131> ((  0  ))
39 compdef:100> shift 3
39 compdef:81> shift
39 compdef:81> shift
39 compdef:80> autoload -Uz _zpty
39 compdef:80> autoload -Uz _which
39 compdef:80> autoload -Uz _pm2
39 compdef:80> [[ -n yes ]]
39 compdef:40> ((  ! 2  ))
39 compdef:38> shift OPTIND-1
39 compdef:17> new=yes
39 compdef:17> new=yes
39 compdef:15> case n (a)
39 compdef:14> getopts anpPkKde opt
39 compdef:5> setopt extendedglob
39 compdef:4> emulate -L zsh
39 compdef:4> emulate -L zsh
39 compdef:4> emulate -L zsh
39 compdef:4> emulate -L zsh
39 compdef:2> local -a match mbegin mend
39 compdef:2> local -a match mbegin mend
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
39 bashcompinit:179> return 0
39 antigen-add-hook:34> return 0
39 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
39 _zsh_highlight_bind_widgets:50> zle -N quoted-insert _zsh_highlight_widget_or...
39 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
39 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
39 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
39 _zsh_highlight_bind_widgets:27> case builtin (builtin)
39 /usr/local/share/antigen/antigen.zsh:1398> typeset -Ag _ANTIGEN_HOOKS
39 /Users/matt/.zshrc:403> alias 'vv=f -e '''nvim''
39 /Users/matt/.zshrc:132> [ -z '' ']'
39 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1786> zle -C _bash_complete-...
39 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
39 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=113
39 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:63> bindkey -M vicmd $'C-[OF' end...
39 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:56> bindkey -M viins $'C-[OH' beg...
39 /Users/matt/.oh-my-zsh/lib/cli.zsh:110> compdef _omz omz
39 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
39 /Users/matt/.oh-my-zsh/cache/grep-alias:3> alias 'fgrep=fgrep --color=auto --...
39 /Users/matt/.oh-my-zsh/cache/grep-alias:1> alias 'grep=grep --color=auto --ex...
39 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:81> zstyle ':completion:*' compl...
39 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:18> alias 'zz=fasd_cd -d -i'
39 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
39 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
39 -antigen-parse-args:164> return 0
39 -antigen-parse-args:164> return 0
39 -antigen-lock-init:9> return 0
39 -antigen-load:39> return 0
39 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-parallel zsh-us...
39 -antigen-hook-antigen-bundle:26> -antigen-load btype plugin dir /Users/matt/....
39 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
39 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
39 (eval):162> alias 'gss=git status -s'
39 (eval):122> alias 'glod=git log --graph --pretty='''%Cred%h%Creset -%C(auto)%...
39 (anon):16> eval $'_zsh_autosuggest_widget_toggle() {ntttlocal -i retvalnnttt_...
39 (anon):3> eval $'_zsh_autosuggest_widget_modify() {ntttlocal -i retvalnnttt_z...
39 (anon):3> eval $'_zsh_autosuggest_widget_accept() {ntttlocal -i retvalnnttt_z...
38 is-at-least:53> return 0
38 compinit:515> autoload -Uz _baudrates
38 compinit:515> autoload -Uz +X _call_program
38 compinit:511> compdef -na _typeset autoload declare export functions integer ...
38 compinit:511> compdef -na _sublimetext subl
38 compinit:511> compdef -na _ssh ssh 'slogin=ssh' scp ssh-add ssh-agent ssh-cop...
38 compinit:511> compdef -na _pdftk pdftk
38 compinit:511> compdef -na _members members
38 compinit:511> compdef -na _lzop lzop
38 compinit:511> compdef -na _first -first-
38 compinit:511> compdef -na _dpkg dpkg dpkg-deb dpkg-query dpkg-reconfigure
38 compinit:511> compdef -na _dict dict
38 compinit:511> compdef -na _btrfs btrfs
38 compinit:508> [[ meson = -[pPkK](n|) ]]
38 compinit:508> [[ cksum = -[pPkK](n|) ]]
38 compinit:505> shift _i_line
38 compinit:505> shift _i_line
38 compinit:505> shift _i_line
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#compdef'
38 compinit:504> _i_tag='#autoload'
38 compinit:504> _i_tag='#autoload'
38 compinit:504> _i_tag='#autoload'
38 compinit:504> _i_tag='#autoload'
38 compinit:504> _i_tag='#autoload'
38 compinit:501> ((  0 + 0  ))
38 compinit:501> ((  0 + 0  ))
38 compinit:501> ((  0 + 0  ))
38 compinit:500> _i_name=_swift
38 compinit:500> _i_name=_console
38 compinit:493> [[ -z '' ]]
38 compinit:70> emulate -L zsh
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:121> shift _d_als
38 compdump:118> print -n ' 
           '
38 compdump:115> print -n ' _spamassassin'
38 compdump:115> print -n ' _beep'
38 compdump:114> ((  ! 0  ))
38 compdump:113> ((  572  ))
38 compdump:96> [[ up-line-or-beginning-search = (_bash_complete-word|_bash_list...
38 compdump:96> [[ send-break = (_bash_complete-word|_bash_list-choices|_complet...
38 compdump:96> [[ run-help = (_bash_complete-word|_bash_list-choices|_complete_...
38 compdump:96> [[ reverse-menu-complete = (_bash_complete-word|_bash_list-choic...
38 compdump:96> [[ neg-argument = (_bash_complete-word|_bash_list-choices|_compl...
38 compdump:96> [[ forward-char = (_bash_complete-word|_bash_list-choices|_compl...
38 compdump:96> [[ expand-or-complete = (_bash_complete-word|_bash_list-choices|...
38 compdump:96> [[ end-of-buffer-or-history = (_bash_complete-word|_bash_list-ch...
38 compdump:96> [[ down-line-or-history = (_bash_complete-word|_bash_list-choice...
38 compdump:96> [[ down-line-or-beginning-search = (_bash_complete-word|_bash_li...
38 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
38 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
38 compdump:96> [[ _next_tags = (_bash_complete-word|_bash_list-choices|_complet...
38 compdump:96> [[ _expand_alias = (_bash_complete-word|_bash_list-choices|_comp...
38 compdump:96> [[ _complete_tag = (_bash_complete-word|_bash_list-choices|_comp...
38 compdump:96> [[ _bash_list-choices = (_bash_complete-word|_bash_list-choices|...
38 compdump:95> read -rA _d_line
38 compdump:95> read -rA _d_line
38 compdump:85> [[ menu-expand-or-complete = _* ]]
38 compdump:44> print -r - ''mkzsh.exe'' ''_mkzsh''
38 compdump:43> _d_f=figlet
38 compdump:43> _d_f=-value-,PS3,-default-
38 compdef:169> shift
38 compdef:162> [[ -z yes || -z _rclone ]]
38 compdef:162> [[ -z yes || -z _printenv ]]
38 compdef:159> cmd=smbclient
38 compdef:155> [[ mina = *=* ]]
38 compdef:139> case  (pattern)
38 compdef:139> case  (*)
38 compdef:136> [[ strip = -P ]]
38 compdef:136> [[ lighty-enable-mod = -P ]]
38 compdef:132> [[ smbclient = -N ]]
38 compdef:131> ((  15  ))
38 compdef:131> ((  0  ))
38 compdef:131> ((  0  ))
38 compdef:131> ((  0  ))
38 compdef:131> ((  0  ))
38 compdef:83> case  (widgetkey)
38 compdef:81> shift
38 compdef:81> shift
38 compdef:17> new=yes
38 compdef:17> new=yes
38 compdef:16> autol=yes
38 compdef:16> autol=yes
38 compdef:14> getopts anpPkKde opt
38 compdef:14> getopts anpPkKde opt
38 compdef:14> getopts anpPkKde opt
38 compdef:9> ((  ! 3  ))
38 compdef:5> setopt extendedglob
38 compdef:5> setopt extendedglob
38 compdef:5> setopt extendedglob
38 compdef:5> setopt extendedglob
38 compdef:4> emulate -L zsh
38 compdef:2> local -a match mbegin mend
38 compdef:2> local -a match mbegin mend
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
38 antigen:2> return 0
38 antigen-remove-hook:2> meta=( target antigen-bundle mode repeat type pre call...
38 antigen-lock:3> [[ -f /Users/matt/.antigen/.lock ]]
38 antigen-bundle:1> -antigen-hook-handler antigen-bundle deno
38 antigen-bundle-parallel-execute:13> [[ ! -d /Users/matt/.antigen/bundles/robb...
38 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_cursor_p...
38 _zsh_highlight_bind_widgets:50> zle -N vi-caps-lock-panic _zsh_highlight_widg...
38 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
38 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-menu-select ....
38 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:50> '(anon)'
38 /Users/matt/.zshrc:548> export MACOSX_DEPLOYMENT_TARGET=12.3
38 /Users/matt/.zcompdump:2205> _comp_assocs=( '' )
38 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:138> alias 'gf=git fetch'
38 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
38 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
38 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:91> fpath=( /Users/matt/.oh-my-zsh/plugin...
38 /Users/matt/.oh-my-zsh/lib/vcs_info.zsh:49> regexp-replace 'functions[VCS_INF...
38 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:51> SCREEN_NO=''
38 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:109> add-zsh-hook preexec omz_term...
38 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:50> bindkey -M vicmd $'C-[OB' dow...
38 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:28> [[ -n $'C-[[6~' ]]
38 /Users/matt/.oh-my-zsh/lib/directories.zsh:23> alias 'rd=rmdir'
38 /Users/matt/.oh-my-zsh/lib/correction.zsh:1> [[ '' == true ]]
38 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
38 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
38 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
38 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2attention=/Users/mat...
38 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
38 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
38 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:13> break
38 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:35> a...
38 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:37> zs...
38 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:23> zs...
38 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:2> zmo...
38 -antigen-set-default:3> eval 'test -z "$ANTIGEN_LOCK" && typeset -g ANTIGEN_L...
38 -antigen-set-default:2> local arg_value=/Users/matt/.antigen/.lock
38 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/ro...
38 -antigen-load:39> return 0
38 -antigen-load-source:2> return 0
38 -antigen-load-source:2> return 0
38 -antigen-load-env:1> -antigen-hook-handler -antigen-load-env dir /Users/matt/...
38 -antigen-hook-handler:65> antigen-apply-lock
38 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-autosuggestions
38 -antigen-hook-handler:39> antigen-apply-parallel
38 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
38 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
38 -antigen-hook-handler:1> local target=antigen-apply args hook called
38 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
38 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
38 (eval):202> alias 'gtv=git tag | sort -V'
38 (eval):76> alias 'gcl=git clone --recurse-submodules'
38 (eval):1> typeset -g ANTIGEN_COMPDUMP=/Users/matt/.antigen/.zcompdump
38 (anon):229> typeset -g POWERLEVEL9K_SHORTEN_FOLDER_MARKER='(.bzr|.citc|.git|....
38 (anon):3> eval $'_zsh_autosuggest_widget_suggest() {ntttlocal -i retvalnnttt_...
38 (anon):3> eval $'_zsh_autosuggest_widget_disable() {ntttlocal -i retvalnnttt_...
37 is_plugin:4> test -f /Users/matt/.oh-my-zsh/custom/plugins/git/_git
37 is_plugin:3> test -f /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh
37 is_plugin:3> test -f /Users/matt/.oh-my-zsh/custom/plugins/git/git.plugin.zsh
37 is-at-least:49> ((  ++min_cnt > 2  ))
37 env_default:2> return 3
37 compinit:511> compdef -na _yaourt yaourt 'yaourt.static=yaourt'
37 compinit:511> compdef -na _xmlstarlet xmlstarlet xml
37 compinit:511> compdef -na _units units
37 compinit:511> compdef -na _trash-restore trash-restore
37 compinit:511> compdef -na _sort sort gsort
37 compinit:511> compdef -na _putclip putclip putclip.exe
37 compinit:511> compdef -na _locales -value-,LANG,-default- -value-,LANGUAGE,-d...
37 compinit:511> compdef -na _jrnl jrnl
37 compinit:511> compdef -na _golang go -P '-value-,GO*,-default-' -P '-value-,C...
37 compinit:511> compdef -na _dos2unix dos2unix unix2dos mac2unix unix2mac
37 compinit:511> compdef -na _dmidecode dmidecode
37 compinit:511> compdef -na _cygrunsrv cygrunsrv cygrunsrv.exe
37 compinit:509> compdef -Kna _bash_completions _bash_complete-word complete-wor...
37 compinit:508> [[ yadm = -[pPkK](n|) ]]
37 compinit:508> [[ swift = -[pPkK](n|) ]]
37 compinit:508> [[ add-zle-hook-widget = -[pPkK](n|) ]]
37 compinit:508> [[ -value-,WWW_HOME,-default- = -[pPkK](n|) ]]
37 compinit:508> [[ -k = -[pPkK](n|) ]]
37 compinit:508> [[ -k = -[pPkK](n|) ]]
37 compinit:505> shift _i_line
37 compinit:505> shift _i_line
37 compinit:505> shift _i_line
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#compdef'
37 compinit:504> _i_tag='#autoload'
37 compinit:504> _i_tag='#autoload'
37 compinit:504> _i_tag='#autoload'
37 compinit:504> _i_tag='#autoload'
37 compinit:504> _i_tag='#autoload'
37 compinit:504> _i_tag='#autoload'
37 compinit:501> ((  0 + 0  ))
37 compinit:501> ((  0 + 0  ))
37 compinit:501> ((  0 + 0  ))
37 compinit:500> _i_name=_signify
37 compinit:191> : compinit /Users/matt/.oh-my-zsh/oh-my-zsh.sh /Users/matt/.zshrc
37 compinit:91> _i_fail=ign
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:121> shift _d_als
37 compdump:118> print -n ' 
           '
37 compdump:118> print -n ' 
           '
37 compdump:118> print -n ' 
           '
37 compdump:118> print -n ' 
           '
37 compdump:117> _i=5
37 compdump:116> ((  ! --_i && 330 > 1  ))
37 compdump:115> print -n ' _zsocket'
37 compdump:115> print -n ' _swanctl'
37 compdump:115> print -n ' _slrn'
37 compdump:115> print -n ' _path_files'
37 compdump:115> print -n ' _nedit'
37 compdump:115> print -n ' _iconvconfig'
37 compdump:115> print -n ' _date_formats'
37 compdump:115> print -n ' _ccal'
37 compdump:114> ((  ! 0  ))
37 compdump:96> [[ which-command = (_bash_complete-word|_bash_list-choices|_comp...
37 compdump:96> [[ vi-match-bracket = (_bash_complete-word|_bash_list-choices|_c...
37 compdump:96> [[ vi-cmd-mode = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ up-line-or-history = (_bash_complete-word|_bash_list-choices|...
37 compdump:96> [[ undo = (_bash_complete-word|_bash_list-choices|_complete_debu...
37 compdump:96> [[ self-insert-unmeta = (_bash_complete-word|_bash_list-choices|...
37 compdump:96> [[ self-insert = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ quote-line = (_bash_complete-word|_bash_list-choices|_complet...
37 compdump:96> [[ overwrite-mode = (_bash_complete-word|_bash_list-choices|_com...
37 compdump:96> [[ list-expand = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ list-expand = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ kill-line = (_bash_complete-word|_bash_list-choices|_complete...
37 compdump:96> [[ kill-buffer = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ insert-last-word = (_bash_complete-word|_bash_list-choices|_c...
37 compdump:96> [[ infer-next-history = (_bash_complete-word|_bash_list-choices|...
37 compdump:96> [[ history-search-backward = (_bash_complete-word|_bash_list-cho...
37 compdump:96> [[ history-incremental-search-backward = (_bash_complete-word|_b...
37 compdump:96> [[ forward-word = (_bash_complete-word|_bash_list-choices|_compl...
37 compdump:96> [[ exchange-point-and-mark = (_bash_complete-word|_bash_list-cho...
37 compdump:96> [[ edit-command-line = (_bash_complete-word|_bash_list-choices|_...
37 compdump:96> [[ down-line-or-history = (_bash_complete-word|_bash_list-choice...
37 compdump:96> [[ down-line-or-history = (_bash_complete-word|_bash_list-choice...
37 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
37 compdump:96> [[ delete-char-or-list = (_bash_complete-word|_bash_list-choices...
37 compdump:96> [[ copy-prev-shell-word = (_bash_complete-word|_bash_list-choice...
37 compdump:96> [[ clear-screen = (_bash_complete-word|_bash_list-choices|_compl...
37 compdump:96> [[ capitalize-word = (_bash_complete-word|_bash_list-choices|_co...
37 compdump:96> [[ bracketed-paste = (_bash_complete-word|_bash_list-choices|_co...
37 compdump:96> [[ beginning-of-line = (_bash_complete-word|_bash_list-choices|_...
37 compdump:96> [[ beginning-of-buffer-or-history = (_bash_complete-word|_bash_l...
37 compdump:96> [[ backward-word = (_bash_complete-word|_bash_list-choices|_comp...
37 compdump:96> [[ backward-word = (_bash_complete-word|_bash_list-choices|_comp...
37 compdump:96> [[ backward-kill-line = (_bash_complete-word|_bash_list-choices|...
37 compdump:96> [[ backward-kill-line = (_bash_complete-word|_bash_list-choices|...
37 compdump:96> [[ backward-delete-char = (_bash_complete-word|_bash_list-choice...
37 compdump:96> [[ backward-delete-char = (_bash_complete-word|_bash_list-choice...
37 compdump:96> [[ backward-char = (_bash_complete-word|_bash_list-choices|_comp...
37 compdump:96> [[ accept-line-and-down-history = (_bash_complete-word|_bash_lis...
37 compdump:96> [[ accept-line = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ accept-line = (_bash_complete-word|_bash_list-choices|_comple...
37 compdump:96> [[ accept-and-hold = (_bash_complete-word|_bash_list-choices|_co...
37 compdump:96> [[ _complete_help = (_bash_complete-word|_bash_list-choices|_com...
37 compdump:85> [[ vi-backward-delete-char = _* ]]
37 compdump:44> print -r - ''w3m'' ''_w3m''
37 compdump:44> print -r - ''rubber-info'' ''_rubber''
37 compdump:44> print -r - ''-redirect-,<,gzip'' ''_gzip''
37 compdump:43> _d_f=bpython3-urwid
37 compdef:162> [[ -z yes || -z _xmlsoft ]]
37 compdef:162> [[ -z yes || -z _guilt ]]
37 compdef:160> svc=''
37 compdef:139> case  (postpattern)
37 compdef:139> case  (postpattern)
37 compdef:139> case  (pattern)
37 compdef:136> [[ scl = -P ]]
37 compdef:134> [[ eval = -p ]]
37 compdef:132> [[ unace = -N ]]
37 compdef:132> [[ top = -N ]]
37 compdef:132> [[ kitchen = -N ]]
37 compdef:132> [[ -math- = -N ]]
37 compdef:131> ((  1  ))
37 compdef:131> ((  0  ))
37 compdef:123> [[ _most_recent_file = undefined-key ]]
37 compdef:93> zle -C _bash_list-choices .list-choices _bash_completions
37 compdef:81> shift
37 compdef:80> autoload -Uz _envdir
37 compdef:80> [[ -n yes ]]
37 compdef:80> [[ -n yes ]]
37 compdef:80> [[ -n yes ]]
37 compdef:38> shift OPTIND-1
37 compdef:17> new=yes
37 compdef:15> case n (n)
37 compdef:14> getopts anpPkKde opt
37 compdef:14> getopts anpPkKde opt
37 compdef:14> getopts anpPkKde opt
37 compdef:14> getopts anpPkKde opt
37 compdef:9> ((  ! 17  ))
37 compdef:5> setopt extendedglob
37 compdef:5> setopt extendedglob
37 compdef:5> setopt extendedglob
37 compdef:5> setopt extendedglob
37 compdef:5> setopt extendedglob
37 compdef:5> setopt extendedglob
37 compdef:4> emulate -L zsh
37 compdef:2> local -a match mbegin mend
37 compdef:2> local -a match mbegin mend
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
37 antigen-bundle-parallel-execute:13> [[ ! -d /Users/matt/.antigen/bundles/zsh-...
37 antigen-bundle-parallel-execute:13> [[ ! -d /Users/matt/.antigen/bundles/robb...
37 antigen-apply-cached:19> [[ -f /Users/matt/.antigen/init.zsh ]]
37 antigen-add-hook:34> return 0
37 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_history-comp...
37 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
37 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
37 /Users/matt/.zshrc:432> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
37 /Users/matt/.zshrc:414> export PKG_CONFIG_PATH=':/usr/local/opt/curl/lib/pkgc...
37 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:220> alias 'glols=git log -...
37 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:180> is_theme /Users/matt/.oh-my-zsh/cust...
37 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
37 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
37 /Users/matt/.oh-my-zsh/lib/misc.zsh:25> alias '_=sudo '
37 /Users/matt/.oh-my-zsh/lib/misc.zsh:9> zle -N bracketed-paste bracketed-paste...
37 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:57> bindkey -M vicmd $'C-[OH' beg...
37 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:19> bindkey -e
37 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
37 /Users/matt/.oh-my-zsh/cache/grep-alias:1> alias 'grep=grep --color=auto --ex...
37 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
37 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
37 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
37 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:25> alias '_...
37 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:38> a...
37 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/ro...
37 -antigen-parse-args:69> [[ zsh-users/zsh-autosuggestions != */* ]]
37 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
37 -antigen-load:39> return 0
37 -antigen-load-source-cached:1> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/...
37 -antigen-load-env:1> -antigen-hook-handler -antigen-load-env dir /Users/matt/...
37 -antigen-load-env:1> -antigen-hook-handler -antigen-load-env dir /Users/matt/...
37 -antigen-load-env-cached:8> return
37 -antigen-hook-handler:65> antigen-apply-cached
37 -antigen-hook-handler:51> [[ 0 == -1 ]]
37 -antigen-hook-handler:49> WARN 'Replace hook:' -antigen-load-source-cached /U...
37 -antigen-hook-handler:12> [[ repeat == once ]]
37 -antigen-hook-handler:9> typeset -A meta
37 -antigen-hook-handler:2> local hooks meta
37 -antigen-hook-handler:2> local hooks meta
37 -antigen-hook-antigen-bundle:32> _ANTIGEN_BUNDLE_RECORD+=( 'https://github.co...
37 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
37 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
37 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
37 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
37 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/robbyrussell/o...
37 (eval):1> typeset -g _ANTIGEN_BUILTIN_EXTENSIONS='lock parallel defer cache'
37 (eval):1> test -z /Users/matt/.antigen/init.zsh
37 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh bt...
37 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh bt...
37 (anon):1377> typeset -g POWERLEVEL9K_GOOGLE_APP_CRED_DEFAULT_FOREGROUND=32
37 (anon):502> typeset -g POWERLEVEL9K_COMMAND_EXECUTION_TIME_FOREGROUND=248
37 (anon):11> typeset -g POWERLEVEL9K_LEFT_PROMPT_ELEMENTS=( dir vcs newline pro...
37 (anon):3> eval $'_zsh_autosuggest_widget_execute() {ntttlocal -i retvalnnttt_...
36 is_plugin:3> test -f /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh
36 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
36 is-at-least:53> return 0
36 is-at-least:53> return 0
36 group_lazy_load:5> alias 'rmvirtualenv=lazy_load "virtualenvwrapper wipeenv c...
36 env_default:2> export 'LESS=-R'
36 compinit:546> unfunction compinit compaudit
36 compinit:533> zle -C complete-word .complete-word _main_complete
36 compinit:511> compdef -na _zsh-mime-handler zsh-mime-handler
36 compinit:511> compdef -na _zpool zpool
36 compinit:511> compdef -na _yast yast yast2
36 compinit:511> compdef -na _wpa_cli wpa_cli
36 compinit:511> compdef -na _vim vim gvim gex gview nvim rvim rview rgvim rgvie...
36 compinit:511> compdef -na _trash-put trash-put trash
36 compinit:511> compdef -na _supervisorctl supervisorctl
36 compinit:511> compdef -na _subliminal subliminal
36 compinit:511> compdef -na _sh sh ash csh dash ksh ksh88 ksh93 mksh oksh pdksh...
36 compinit:511> compdef -na _setcap setcap
36 compinit:511> compdef -na _pygmentize pygmentize
36 compinit:511> compdef -na _port port
36 compinit:511> compdef -na _play play
36 compinit:511> compdef -na _pkcon pkcon
36 compinit:511> compdef -na _pixz pixz
36 compinit:511> compdef -na _picocom picocom
36 compinit:511> compdef -na _od od god
36 compinit:511> compdef -na _nl nl gnl
36 compinit:511> compdef -na _kubectl kubectl
36 compinit:511> compdef -na _kak kak
36 compinit:511> compdef -na _hub hub
36 compinit:511> compdef -na _hdiutil hdiutil
36 compinit:511> compdef -na _glances glances
36 compinit:511> compdef -na _directories dircmp -P '-value-,*path,-default-'
36 compinit:511> compdef -na _date date gdate
36 compinit:511> compdef -na _cygserver cygserver cygserver.exe
36 compinit:511> compdef -na _console console
36 compinit:511> compdef -na _clay clay
36 compinit:509> compdef -Pna _x_arguments '*/X11(|R<4->)/*'
36 compinit:509> compdef -Kna _history_complete_word _history-complete-older com...
36 compinit:508> [[ xargs = -[pPkK](n|) ]]
36 compinit:508> [[ tail = -[pPkK](n|) ]]
36 compinit:508> [[ svcprop = -[pPkK](n|) ]]
36 compinit:508> [[ rubocop = -[pPkK](n|) ]]
36 compinit:508> [[ mkisofs = -[pPkK](n|) ]]
36 compinit:508> [[ guilt = -[pPkK](n|) ]]
36 compinit:508> [[ exportfs = -[pPkK](n|) ]]
36 compinit:508> [[ etags = -[pPkK](n|) ]]
36 compinit:508> [[ dvips = -[pPkK](n|) ]]
36 compinit:508> [[ debchange = -[pPkK](n|) ]]
36 compinit:508> [[ dd = -[pPkK](n|) ]]
36 compinit:508> [[ SuSEconfig = -[pPkK](n|) ]]
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:505> shift _i_line
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#compdef'
36 compinit:504> _i_tag='#autoload'
36 compinit:504> _i_tag='#autoload'
36 compinit:504> _i_tag='#autoload'
36 compinit:504> _i_tag='#autoload'
36 compinit:501> ((  0 + 0  ))
36 compinit:501> ((  0 + 0  ))
36 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wc
36 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_setsid
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:121> shift _d_als
36 compdump:118> print -n ' 
           '
36 compdump:118> print -n ' 
           '
36 compdump:116> ((  ! --_i && 871 > 1  ))
36 compdump:116> ((  ! --_i && 807 > 1  ))
36 compdump:116> ((  ! --_i && 664 > 1  ))
36 compdump:116> ((  ! --_i && 416 > 1  ))
36 compdump:116> ((  ! --_i && 358 > 1  ))
36 compdump:116> ((  ! --_i && 7 > 1  ))
36 compdump:115> print -n ' _zcash-cli'
36 compdump:115> print -n ' _xinput'
36 compdump:115> print -n ' _sort'
36 compdump:115> print -n ' _attr'
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:114> ((  ! 0  ))
36 compdump:113> ((  15  ))
36 compdump:96> [[ yank = (_bash_complete-word|_bash_list-choices|_complete_debu...
36 compdump:96> [[ what-cursor-position = (_bash_complete-word|_bash_list-choice...
36 compdump:96> [[ vi-join = (_bash_complete-word|_bash_list-choices|_complete_d...
36 compdump:96> [[ vi-find-next-char = (_bash_complete-word|_bash_list-choices|_...
36 compdump:96> [[ up-line-or-history = (_bash_complete-word|_bash_list-choices|...
36 compdump:96> [[ up-line-or-history = (_bash_complete-word|_bash_list-choices|...
36 compdump:96> [[ up-case-word = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ up-case-word = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ undo = (_bash_complete-word|_bash_list-choices|_complete_debu...
36 compdump:96> [[ transpose-words = (_bash_complete-word|_bash_list-choices|_co...
36 compdump:96> [[ transpose-words = (_bash_complete-word|_bash_list-choices|_co...
36 compdump:96> [[ spell-word = (_bash_complete-word|_bash_list-choices|_complet...
36 compdump:96> [[ spell-word = (_bash_complete-word|_bash_list-choices|_complet...
36 compdump:96> [[ spell-word = (_bash_complete-word|_bash_list-choices|_complet...
36 compdump:96> [[ send-break = (_bash_complete-word|_bash_list-choices|_complet...
36 compdump:96> [[ self-insert-unmeta = (_bash_complete-word|_bash_list-choices|...
36 compdump:96> [[ self-insert = (_bash_complete-word|_bash_list-choices|_comple...
36 compdump:96> [[ run-help = (_bash_complete-word|_bash_list-choices|_complete_...
36 compdump:96> [[ redo = (_bash_complete-word|_bash_list-choices|_complete_debu...
36 compdump:96> [[ quoted-insert = (_bash_complete-word|_bash_list-choices|_comp...
36 compdump:96> [[ quote-region = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ push-line = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ push-line = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ push-line = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ list-choices = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ kill-word = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ kill-word = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ kill-word = (_bash_complete-word|_bash_list-choices|_complete...
36 compdump:96> [[ kill-region = (_bash_complete-word|_bash_list-choices|_comple...
36 compdump:96> [[ insert-last-word = (_bash_complete-word|_bash_list-choices|_c...
36 compdump:96> [[ history-search-forward = (_bash_complete-word|_bash_list-choi...
36 compdump:96> [[ history-incremental-search-forward = (_bash_complete-word|_ba...
36 compdump:96> [[ get-line = (_bash_complete-word|_bash_list-choices|_complete_...
36 compdump:96> [[ get-line = (_bash_complete-word|_bash_list-choices|_complete_...
36 compdump:96> [[ forward-word = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ forward-word = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ forward-char = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ forward-char = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ expand-word = (_bash_complete-word|_bash_list-choices|_comple...
36 compdump:96> [[ expand-history = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ execute-named-cmd = (_bash_complete-word|_bash_list-choices|_...
36 compdump:96> [[ end-of-line = (_bash_complete-word|_bash_list-choices|_comple...
36 compdump:96> [[ down-case-word = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ digit-argument = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ delete-char = (_bash_complete-word|_bash_list-choices|_comple...
36 compdump:96> [[ copy-region-as-kill = (_bash_complete-word|_bash_list-choices...
36 compdump:96> [[ copy-prev-word = (_bash_complete-word|_bash_list-choices|_com...
36 compdump:96> [[ clear-screen = (_bash_complete-word|_bash_list-choices|_compl...
36 compdump:96> [[ capitalize-word = (_bash_complete-word|_bash_list-choices|_co...
36 compdump:96> [[ backward-kill-word = (_bash_complete-word|_bash_list-choices|...
36 compdump:96> [[ backward-char = (_bash_complete-word|_bash_list-choices|_comp...
36 compdump:96> [[ '"ls^J"' = (_bash_complete-word|_bash_list-choices|_complete_...
36 compdump:96> [[ '"' = (_bash_complete-word|_bash_list-choices|_complete_debug...
36 compdump:95> read -rA _d_line
36 compdump:95> read -rA _d_line
36 compdump:95> read -rA _d_line
36 compdump:60> _d_tmp=_postpatcomps
36 compdump:44> print -r - ''wipefs'' ''_wipefs''
36 compdump:44> print -r - ''scp'' ''_ssh''
36 compdump:44> print -r - ''lftp'' ''_ncftp''
36 compdump:44> print -r - ''kvno'' ''_kvno''
36 compdump:44> print -r - ''kpdf'' ''_pdf''
36 compdump:44> print -r - ''irssi'' ''_irssi''
36 compdump:44> print -r - ''ironic'' ''_openstack''
36 compdump:44> print -r - ''install'' ''_install''
36 compdump:44> print -r - ''-value-,RPROMPT,-default-'' ''_ps1234''
36 compdef:169> shift
36 compdef:162> [[ -z yes || -z _vagrant ]]
36 compdef:162> [[ -z yes || -z _surfraw ]]
36 compdef:162> [[ -z yes || -z _pspdf ]]
36 compdef:162> [[ -z yes || -z _ping ]]
36 compdef:162> [[ -z yes || -z _pids ]]
36 compdef:162> [[ -z yes || -z _openstack ]]
36 compdef:159> cmd=ksh93
36 compdef:155> [[ tcp_open = *=* ]]
36 compdef:155> [[ poff = *=* ]]
36 compdef:155> [[ ltrace = *=* ]]
36 compdef:139> case  (postpattern)
36 compdef:134> [[ ksh93 = -p ]]
36 compdef:134> [[ bpython3-urwid = -p ]]
36 compdef:132> [[ softwareupdate = -N ]]
36 compdef:132> [[ route = -N ]]
36 compdef:132> [[ pstoedit = -N ]]
36 compdef:132> [[ lp = -N ]]
36 compdef:132> [[ a2ensite = -N ]]
36 compdef:131> ((  1  ))
36 compdef:123> [[ _read_comp = undefined-key ]]
36 compdef:83> case  (widgetkey)
36 compdef:83> case  (key)
36 compdef:83> case  (*)
36 compdef:81> shift
36 compdef:81> shift
36 compdef:81> shift
36 compdef:81> shift
36 compdef:80> autoload -Uz _tput
36 compdef:80> autoload -Uz _dmesg
36 compdef:49> [[ _xdvi = *=* ]]
36 compdef:49> [[ _strip = *=* ]]
36 compdef:40> ((  ! 2  ))
36 compdef:38> shift OPTIND-1
36 compdef:17> new=yes
36 compdef:17> new=yes
36 compdef:17> new=yes
36 compdef:16> autol=yes
36 compdef:16> autol=yes
36 compdef:15> case n (n)
36 compdef:15> case n (a)
36 compdef:15> case n (a)
36 compdef:15> case n (a)
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:14> getopts anpPkKde opt
36 compdef:9> ((  ! 4  ))
36 compdef:9> ((  ! 4  ))
36 compdef:9> ((  ! 3  ))
36 compdef:9> ((  ! 3  ))
36 compdef:5> setopt extendedglob
36 compdef:5> setopt extendedglob
36 compdef:5> setopt extendedglob
36 compdef:5> setopt extendedglob
36 compdef:4> emulate -L zsh
36 compdef:4> emulate -L zsh
36 compdef:4> emulate -L zsh
36 compdef:4> emulate -L zsh
36 compdef:4> emulate -L zsh
36 compdef:2> local -a match mbegin mend
36 compdef:2> local -a match mbegin mend
36 compdef:2> local -a match mbegin mend
36 compdef:2> local -a match mbegin mend
36 compdef:2> local -a match mbegin mend
36 compdef:2> local -a match mbegin mend
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
36 compaudit:51> ((  0  ))
36 antigen-bundle-parallel-execute:13> [[ ! -d /Users/matt/.antigen/bundles/zsh-...
36 antigen-bundle-parallel-execute:11> typeset -A bundle
36 add-zsh-hook:86> set -A preexec_functions omz_termsupport_preexec _zsh_highli...
36 add-zle-hook-widget:51> local hook=zle-line-pre-redraw
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_regexp_p...
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_regexp_p...
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_pattern_...
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_main_pre...
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_line_pre...
36 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_brackets...
36 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
36 _zsh_highlight_bind_widgets:50> zle -N history-beginning-search-backward _zsh...
36 _zsh_highlight_bind_widgets:50> zle -N beginning-of-buffer-or-history _zsh_hi...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:46> zle -N _complete_debug _zsh_highlight_widget_...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:45> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-menu-expand-o...
36 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
36 _zsh_highlight_bind_widgets:26> cur_widget=vi-add-next
36 /Users/matt/.zshrc:413> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
36 /Users/matt/.zshrc:412> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
36 /Users/matt/.zshrc:409> export PKG_CONFIG_PATH=:/usr/local/opt/curl/lib/pkgco...
36 /Users/matt/.zshrc:408> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
36 /Users/matt/.zshrc:366> export CLOUDSDK_PYTHON=python3.8
36 /Users/matt/.zshrc:233> export CONDA_EXE=/usr/local/anaconda3/bin/conda
36 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:2> PROMPT+=' %{$fg[cyan]...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:313> alias 'gwip=git add -A...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:312> alias 'gwch=git whatch...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:283> alias 'gsta=git stash ...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:282> is-at-least 2.13 2.36.1
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:222> alias 'glods=git log -...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:221> alias 'glod=git log --...
36 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:206> alias 'gignored=git ls...
36 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:12> unset fasd_cache
36 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:158> [[ -f /Users/matt/.oh-my-zsh/plugins...
36 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
36 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
36 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
36 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:105> autoload -Uz add-zsh-hook
36 /Users/matt/.oh-my-zsh/lib/clipboard.zsh:107> detect-clipboard
36 /Users/matt/.iterm2_shell_integration.zsh:166> iterm2_print_state_data
36 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
36 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
36 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
36 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:25> ...
36 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/grep.zsh:41> unset __...
36 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/ro...
36 -antigen-parse-args:69> [[ https://github.com/robbyrussell/oh-my-zsh.git != *...
36 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
36 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
36 -antigen-parse-args:38> case 0 (0)
36 -antigen-parse-args:5> shift
36 -antigen-load:5> local location=/Users/matt/.antigen/bundles/zsh-users/zsh-au...
36 -antigen-load:2> bundle=( btype plugin dir /Users/matt/.antigen/bundles/zsh-u...
36 -antigen-load:2> bundle=( btype plugin dir /Users/matt/.antigen/bundles/zsh-u...
36 -antigen-load-source:2> return 0
36 -antigen-load-source:2> return 0
36 -antigen-load-source-cached:1> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/...
36 -antigen-load-env-cached:11> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/bu...
36 -antigen-load-env-cached:8> return
36 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
36 -antigen-hook-handler:69> LOG 'Return from hook antigen-apply with 0'
36 -antigen-hook-handler:55> [[ 0 == 0 ]]
36 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
36 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
36 -antigen-hook-handler:11> meta=( target antigen-apply type post mode once cal...
36 -antigen-hook-handler:7> typeset -a hooks
36 -antigen-hook-handler:4> args=( dir /Users/matt/.antigen/bundles/zsh-users/zs...
36 -antigen-hook-handler:2> local hooks meta
36 -antigen-hook-antigen-bundle:32> _ANTIGEN_BUNDLE_RECORD+=( 'https://github.co...
36 -antigen-hook-antigen-bundle:26> -antigen-load btype plugin dir /Users/matt/....
36 -antigen-hook-antigen-bundle:19> [[ ! -d /Users/matt/.antigen/bundles/zsh-use...
36 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
36 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
36 (eval):175> alias 'gswc=git switch -c'
36 (eval):1> typeset -g ANTIGEN_SUBMODULE_OPTS='--recursive --depth=1'
36 (eval):1> typeset -g ANTIGEN_CLONE_ENV='GIT_TERMINAL_PROMPT=0'
36 (eval):1> typeset -g ANTIGEN_AUTO_CONFIG=true
36 (eval):1> bundle=( dir /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh bt...
36 (anon):1098> typeset -g POWERLEVEL9K_PHPENV_PROMPT_ALWAYS_SHOW=false
36 (anon):669> typeset -g 'POWERLEVEL9K_NORDVPN_DISCONNECTED_VISUAL_IDENTIFIER_E...
36 (anon):668> typeset -g 'POWERLEVEL9K_NORDVPN_DISCONNECTED_CONTENT_EXPANSION='...
36 (anon):242> typeset -g POWERLEVEL9K_SHORTEN_DIR_LENGTH=1
35 group_lazy_load:5> alias 'wipeenv=lazy_load "virtualenvwrapper wipeenv cdproj...
35 group_lazy_load:5> alias 'virtualenvwrapper=lazy_load "virtualenvwrapper wipe...
35 compinit:515> autoload -Uz _prefix
35 compinit:515> autoload -Uz _deb_architectures
35 compinit:511> compdef -na _zpty zpty
35 compinit:511> compdef -na _zoneadm zoneadm
35 compinit:511> compdef -na _valgrind valgrind -value-,VALGRIND_OPTS,-default-
35 compinit:511> compdef -na _users passwd groups userdel chage chfn
35 compinit:511> compdef -na _subl subl
35 compinit:511> compdef -na _stack stack
35 compinit:511> compdef -na _srm srm
35 compinit:511> compdef -na _showoff showoff
35 compinit:511> compdef -na _shasum shasum -P 'shasum(|5).*'
35 compinit:511> compdef -na _sfdx sfdx
35 compinit:511> compdef -na _setup.py setup.py
35 compinit:511> compdef -na _readelf readelf eu-readelf
35 compinit:511> compdef -na _printers -value-,PRINTER,-default- -value-,LPDEST,...
35 compinit:511> compdef -na _precommand - nohup eval time rusage noglob nocorre...
35 compinit:511> compdef -na _periscope periscope
35 compinit:511> compdef -na _perf perf
35 compinit:511> compdef -na _pdm pdm
35 compinit:511> compdef -na _patool patool
35 compinit:511> compdef -na _patchutils combinediff interdiff filterdiff flipdi...
35 compinit:511> compdef -na _optirun optirun
35 compinit:511> compdef -na _nvm nvm
35 compinit:511> compdef -na _nice nice
35 compinit:511> compdef -na _nanoc nanoc
35 compinit:511> compdef -na _nano nano
35 compinit:511> compdef -na _moosic moosic
35 compinit:511> compdef -na _jmeter-plugins jmeter-plugins
35 compinit:511> compdef -na _iptables iptables iptables-save iptables-restore i...
35 compinit:511> compdef -na _iconvconfig iconvconfig
35 compinit:511> compdef -na _git-flow git-flow
35 compinit:511> compdef -na _getmail getmail
35 compinit:511> compdef -na _enable enable
35 compinit:511> compdef -na _dupload dupload
35 compinit:511> compdef -na _dpatch-edit-patch dpatch-edit-patch
35 compinit:511> compdef -na _doas doas
35 compinit:511> compdef -na _dnf dnf dnf-2 dnf-3
35 compinit:511> compdef -na _dhcpinfo dhcpinfo
35 compinit:511> compdef -na _dchroot dchroot
35 compinit:511> compdef -na _baz baz
35 compinit:509> compdef -kna _read_comp complete-word 'C-xC-r'
35 compinit:508> [[ zypper = -[pPkK](n|) ]]
35 compinit:508> [[ sdd = -[pPkK](n|) ]]
35 compinit:508> [[ scl = -[pPkK](n|) ]]
35 compinit:508> [[ read = -[pPkK](n|) ]]
35 compinit:508> [[ make = -[pPkK](n|) ]]
35 compinit:508> [[ devtodo = -[pPkK](n|) ]]
35 compinit:508> [[ debsign = -[pPkK](n|) ]]
35 compinit:508> [[ deborphan = -[pPkK](n|) ]]
35 compinit:508> [[ chsh = -[pPkK](n|) ]]
35 compinit:508> [[ chroot = -[pPkK](n|) ]]
35 compinit:508> [[ chown = -[pPkK](n|) ]]
35 compinit:508> [[ chmod = -[pPkK](n|) ]]
35 compinit:508> [[ chcon = -[pPkK](n|) ]]
35 compinit:508> [[ caffeinate = -[pPkK](n|) ]]
35 compinit:508> [[ cabal = -[pPkK](n|) ]]
35 compinit:508> [[ aptitude = -[pPkK](n|) ]]
35 compinit:508> [[ -k = -[pPkK](n|) ]]
35 compinit:508> [[ -K = -[pPkK](n|) ]]
35 compinit:506> case #compdef (#compdef)
35 compinit:506> case #compdef (#compdef)
35 compinit:506> case #autoload (#compdef)
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:505> shift _i_line
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#compdef'
35 compinit:504> _i_tag='#autoload'
35 compinit:504> _i_tag='#autoload'
35 compinit:504> _i_tag='#autoload'
35 compinit:501> ((  1 + 0  ))
35 compinit:501> ((  0 + 0  ))
35 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_figlet
35 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_deb_codenames
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:121> shift _d_als
35 compdump:116> ((  ! --_i && 678 > 1  ))
35 compdump:115> print -n ' _alias'
35 compdump:113> ((  524  ))
35 compdump:113> ((  344  ))
35 compdump:113> ((  299  ))
35 compdump:95> read -rA _d_line
35 compdump:95> read -rA _d_line
35 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
35 compdump:68> _d_f=_call_program
35 compdump:44> print -r - ''-value-,PS3,-default-'' ''_ps1234''
35 compdump:43> _d_f=sha384
35 compdump:43> _d_f=diana
35 compdump:43> _d_f=-value-,RPROMPT,-default-
35 compdump:43> _d_f=-value-,PS4,-default-
35 compdef:169> shift
35 compdef:169> shift
35 compdef:162> [[ -z yes || -z _rdesktop ]]
35 compdef:162> [[ -z yes || -z _pspdf ]]
35 compdef:162> [[ -z yes || -z _play ]]
35 compdef:162> [[ -z yes || -z _jmeter-plugins ]]
35 compdef:162> [[ -z yes || -z _groups ]]
35 compdef:159> cmd=autoload
35 compdef:139> case  (postpattern)
35 compdef:139> case  (postpattern)
35 compdef:134> [[ smbcontrol = -p ]]
35 compdef:132> [[ play = -N ]]
35 compdef:132> [[ dmesg = -N ]]
35 compdef:131> ((  1  ))
35 compdef:114> [[ complete-word = menu-select ]]
35 compdef:81> shift
35 compdef:81> shift
35 compdef:81> shift
35 compdef:80> autoload -Uz _unison
35 compdef:80> autoload -Uz _thor
35 compdef:80> autoload -Uz _mina
35 compdef:80> autoload -Uz _jmeter-plugins
35 compdef:80> [[ -n yes ]]
35 compdef:80> [[ -n yes ]]
35 compdef:80> [[ -n yes ]]
35 compdef:80> [[ -n yes ]]
35 compdef:49> [[ _setfacl = *=* ]]
35 compdef:38> shift OPTIND-1
35 compdef:17> new=yes
35 compdef:17> new=yes
35 compdef:17> new=yes
35 compdef:17> new=yes
35 compdef:17> new=yes
35 compdef:16> autol=yes
35 compdef:15> case n (a)
35 compdef:15> case n (a)
35 compdef:15> case a (a)
35 compdef:14> getopts anpPkKde opt
35 compdef:14> getopts anpPkKde opt
35 compdef:14> getopts anpPkKde opt
35 compdef:14> getopts anpPkKde opt
35 compdef:14> getopts anpPkKde opt
35 compdef:14> getopts anpPkKde opt
35 compdef:9> ((  ! 3  ))
35 compdef:9> ((  ! 3  ))
35 compdef:9> ((  ! 3  ))
35 compdef:5> setopt extendedglob
35 compdef:4> emulate -L zsh
35 compdef:4> emulate -L zsh
35 compdef:4> emulate -L zsh
35 compdef:4> emulate -L zsh
35 compdef:4> emulate -L zsh
35 compdef:4> emulate -L zsh
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:2> local -a match mbegin mend
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
35 antigen-bundle:2> return 0
35 antigen-bundle:2> return 0
35 antigen-bundle-parallel:2> _PARALLEL_BUNDLE+=( zsh-users/zsh-syntax-highlight...
35 antigen-bundle-parallel:2> _PARALLEL_BUNDLE+=( zsh-users/zsh-autosuggestions )
35 antigen-bundle-parallel:2> _PARALLEL_BUNDLE+=( '--loc=lib' )
35 antigen-apply-parallel:8> antigen-add-hook antigen-bundle antigen-bundle-para...
35 antigen-apply-lock:1> WARN 'Freeing antigen-lock file at /Users/matt/.antigen...
35 antigen-apply-cached:27> antigen-remove-hook -antigen-load-source-cached
35 antigen-add-hook:23> ((  ! 1  ))
35 add-zsh-hook:90> set -A precmd_functions omz_termsupport_precmd
35 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
35 _zsh_highlight_load_highlighters:17> type _zsh_highlight_highlighter_main_pre...
35 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.oh-my-zsh/custom/plug...
35 _zsh_highlight_load_highlighters:13> highlighter=brackets
35 _zsh_highlight_bind_widgets:50> zle -N emacs-backward-word _zsh_highlight_wid...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
35 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-expand-or-com...
35 /usr/local/share/antigen/antigen.zsh:2062> -antigen-env-setup
35 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
35 /Users/matt/.zshrc:547> export SDKROOT=/Applications/Xcode.app/Contents/Devel...
35 /Users/matt/.zshrc:530> antigen bundle zsh-users/zsh-syntax-highlighting
35 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:207> alias 'git-svn-dcommit...
35 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:74> alias 'gbda=git branch ...
35 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
35 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
35 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
35 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
35 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
35 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
35 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
35 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:105> ...
35 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:57> ...
35 -antigen-use-oh-my-zsh:2> ANTIGEN_DEFAULT_REPO_URL=https://github.com/robbyru...
35 -antigen-set-default:1> local arg_name=ANTIGEN_SUBMODULE_OPTS
35 -antigen-parallel-execute:74> antigen-add-hook antigen-apply antigen-apply-pa...
35 -antigen-load:35> -antigen-load-source /Users/matt/.antigen/bundles/robbyruss...
35 -antigen-load:2> bundle=( btype plugin dir /Users/matt/.antigen/bundles/robby...
35 -antigen-load-source:1> -antigen-hook-handler -antigen-load-source /Users/mat...
35 -antigen-load-source-cached:1> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/...
35 -antigen-interactive-mode:7> [[ file:file:shfunc:shfunc:shfunc:eval:shfunc:sh...
35 -antigen-interactive-mode:1> WARN '-antigen-interactive-mode: file:file:shfun...
35 -antigen-hook-handler:69> LOG 'Return from hook antigen with 0'
35 -antigen-hook-handler:57> -antigen-hook-antigen use oh-my-zsh
35 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-defer '--loc=lib'
35 -antigen-hook-handler:48> ((  1  ))
35 -antigen-hook-handler:48> ((  1  ))
35 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-env-cached'
35 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-source-cached )
35 -antigen-hook-handler:7> typeset -a hooks
35 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
35 -antigen-hook-handler:4> args=( dir /Users/matt/.antigen/bundles/zsh-users/zs...
35 -antigen-hook-handler:4> args=( dir /Users/matt/.antigen/bundles/robbyrussell...
35 -antigen-hook-handler:4> args=( dir /Users/matt/.antigen/bundles/robbyrussell...
35 -antigen-hook-antigen-apply:3> autoload -Uz compinit
35 -antigen-env-setup:4> -antigen-set-default ANTIGEN_OMZ_REPO_URL https://githu...
35 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
35 (eval):175> alias 'grup=git remote update'
35 (eval):104> alias 'gga=git gui citool --amend'
35 (eval):1> typeset -g _ANTIGEN_WARN_DUPLICATES=true
35 (eval):1> typeset -g _ANTIGEN_THEME_COMPAT=true
35 (eval):1> typeset -g _ANTIGEN_GREP_COMMAND='GREP_OPTIONS= command grep '
35 (eval):1> typeset -g ANTIGEN_LOG=/dev/null
35 (anon):709> typeset -g POWERLEVEL9K_DISK_USAGE_NORMAL_FOREGROUND=35
35 (anon):417> functions -M my_git_formatter
35 (anon):34> [[ -z 19130 ]]
34 group_lazy_load:5> alias 'toggleglobalsitepackages=lazy_load "virtualenvwrapp...
34 group_lazy_load:5> alias 'setvirtualenvproject=lazy_load "virtualenvwrapper w...
34 group_lazy_load:5> alias 'lssitepackages=lazy_load "virtualenvwrapper wipeenv...
34 group_lazy_load:5> alias 'add2virtualenv=lazy_load "virtualenvwrapper wipeenv...
34 compinit:533> zle -C expand-or-complete-prefix .expand-or-complete-prefix _ma...
34 compinit:516> [[ '' !=  # ]]
34 compinit:511> compdef -na _zargs zargs -value-,-default-,-command-
34 compinit:511> compdef -na _xft_fonts fc-list fc-match
34 compinit:511> compdef -na _value -value- -array-value- -value-,-default-,-def...
34 compinit:511> compdef -na _touch touch gtouch
34 compinit:511> compdef -na _toolchain-source tpkg-install tpkg-make tpkg-debar...
34 compinit:511> compdef -na _systat systat
34 compinit:511> compdef -na _sysstat mpstat cifsiostat isag sadf sar pidstat
34 compinit:511> compdef -na _svm svm
34 compinit:511> compdef -na _subversion svn 'svnlite=svn' svnadmin 'svnadmin-st...
34 compinit:511> compdef -na _stow stow chkstow
34 compinit:511> compdef -na _rlogin rlogin rsh 'remsh=rsh' rcp
34 compinit:511> compdef -na _postscript ps2epsi ps2pdf psmulti pswrap ps2pdf12 ...
34 compinit:511> compdef -na _pipenv pipenv
34 compinit:511> compdef -na _pids pflags pcred pldd psig pstack pfiles pwdx pst...
34 compinit:511> compdef -na _phing phing
34 compinit:511> compdef -na _node node
34 compinit:511> compdef -na _mvn mvn mvnDebug
34 compinit:511> compdef -na _lua lua -P 'lua[0-9.-]##'
34 compinit:511> compdef -na _jobs_fg disown fg
34 compinit:511> compdef -na _jobs_bg bg
34 compinit:511> compdef -na _jmeter jmeter
34 compinit:511> compdef -na _irssi irssi
34 compinit:511> compdef -na _htop htop
34 compinit:511> compdef -na _git git gitk
34 compinit:511> compdef -na _echotc echotc
34 compinit:511> compdef -na _e2label e2label
34 compinit:511> compdef -na _disable disable
34 compinit:511> compdef -na _afew afew
34 compinit:508> [[ rkt = -[pPkK](n|) ]]
34 compinit:508> [[ rfkill = -[pPkK](n|) ]]
34 compinit:508> [[ pkgrm = -[pPkK](n|) ]]
34 compinit:508> [[ mount = -[pPkK](n|) ]]
34 compinit:508> [[ hash = -[pPkK](n|) ]]
34 compinit:508> [[ gsettings = -[pPkK](n|) ]]
34 compinit:508> [[ entr = -[pPkK](n|) ]]
34 compinit:508> [[ dumper = -[pPkK](n|) ]]
34 compinit:508> [[ dumpadm = -[pPkK](n|) ]]
34 compinit:508> [[ defaults = -[pPkK](n|) ]]
34 compinit:508> [[ debuild = -[pPkK](n|) ]]
34 compinit:508> [[ debcheckout = -[pPkK](n|) ]]
34 compinit:508> [[ chattr = -[pPkK](n|) ]]
34 compinit:508> [[ a2ps = -[pPkK](n|) ]]
34 compinit:508> [[ -k = -[pPkK](n|) ]]
34 compinit:506> case #compdef (#compdef)
34 compinit:506> case #compdef (#compdef)
34 compinit:506> case #autoload (#autoload)
34 compinit:506> case #autoload (#autoload)
34 compinit:506> case #autoload (#autoload)
34 compinit:505> shift _i_line
34 compinit:505> shift _i_line
34 compinit:505> shift _i_line
34 compinit:505> shift _i_line
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#compdef'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:504> _i_tag='#autoload'
34 compinit:501> ((  0 + 0  ))
34 compinit:501> ((  0 + 0  ))
34 compinit:501> ((  0 + 0  ))
34 compinit:501> ((  0 + 0  ))
34 compinit:501> ((  0 + 0  ))
34 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_scons
34 compinit:70> emulate -L zsh
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:121> shift _d_als
34 compdump:116> ((  ! --_i && 453 > 1  ))
34 compdump:116> ((  ! --_i && 202 > 1  ))
34 compdump:115> print -n ' _trash-list'
34 compdump:115> print -n ' _sys_calls'
34 compdump:95> read -rA _d_line
34 compdump:95> read -rA _d_line
34 compdump:44> print -r - ''-value-,PS4,-default-'' ''_ps1234''
34 compdump:43> _d_f=tcp_open
34 compdump:43> _d_f=script
34 compdump:43> _d_f=rubber-info
34 compdump:43> _d_f=mkzsh.exe
34 compdump:43> _d_f=lintian
34 compdump:43> _d_f=kubectl
34 compdump:43> _d_f=-
34 compdef:169> shift
34 compdef:169> shift
34 compdef:164> _services[$cmd]=debchange
34 compdef:162> [[ -z yes || -z _uniq ]]
34 compdef:162> [[ -z yes || -z _tarsnap ]]
34 compdef:162> [[ -z yes || -z _rclone ]]
34 compdef:162> [[ -z yes || -z _qdbus ]]
34 compdef:162> [[ -z yes || -z _md5sum ]]
34 compdef:162> [[ -z yes || -z _guilt ]]
34 compdef:162> [[ -z yes || -z _debdiff ]]
34 compdef:159> cmd=gmd5sum
34 compdef:151> _postpatcomps[$1]=_gcc
34 compdef:139> case  (*)
34 compdef:136> [[ sbuild = -P ]]
34 compdef:132> [[ dhcpinfo = -N ]]
34 compdef:131> ((  2  ))
34 compdef:131> ((  1  ))
34 compdef:83> case  (widgetkey)
34 compdef:83> case  (widgetkey)
34 compdef:83> case  (*)
34 compdef:81> shift
34 compdef:81> shift
34 compdef:81> shift
34 compdef:81> shift
34 compdef:81> shift
34 compdef:80> autoload -Uz _tarsnap
34 compdef:80> autoload -Uz _rclone
34 compdef:80> autoload -Uz _protoc
34 compdef:80> autoload -Uz _pon
34 compdef:80> autoload -Uz _groups
34 compdef:80> [[ -n yes ]]
34 compdef:80> [[ -n yes ]]
34 compdef:49> [[ _precommand = *=* ]]
34 compdef:49> [[ -z '' ]]
34 compdef:38> shift OPTIND-1
34 compdef:17> new=yes
34 compdef:17> new=yes
34 compdef:15> case n (a)
34 compdef:15> case a (a)
34 compdef:15> case a (a)
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:14> getopts anpPkKde opt
34 compdef:9> ((  ! 3  ))
34 compdef:9> ((  ! 3  ))
34 compdef:9> ((  ! 3  ))
34 compdef:5> setopt extendedglob
34 compdef:5> setopt extendedglob
34 compdef:5> setopt extendedglob
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:4> emulate -L zsh
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:2> local -a match mbegin mend
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
34 compaudit:146> [[ -f /etc/debian_version ]]
34 compaudit:29> ((  13 == 0  ))
34 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
34 antigen-remove-hook:2> meta=( target antigen-apply mode once type replace cal...
34 antigen-ext:9> -antigen-defer-execute
34 antigen-ext-init:2> local ext
34 antigen-bundle:2> return 0
34 antigen-bundle:2> return 0
34 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-syntax-h...
34 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-autosugg...
34 antigen-bundle-parallel-execute:7> WARN '--loc=lib deno zsh-users/zsh-syntax-...
34 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( '--loc=lib' )
34 antigen-apply-cached:23> unset _ZCACHE_CAPTURE_BUNDLE _ZCACHE_CAPTURE_FUNCTIONS
34 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-apply-lock:antigen-apply...
34 add-zsh-hook:60> ((  help || 2 != 2 || 3 == 0  ))
34 add-zle-hook-widget:5> local usage='Usage: add-zle-hook-widget hook widgetnam...
34 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
34 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
34 _zsh_highlight_bind_widgets:50> zle -N what-cursor-position _zsh_highlight_wi...
34 _zsh_highlight_bind_widgets:50> zle -N vi-find-next-char-skip _zsh_highlight_...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
34 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-list-choices ...
34 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-complete-word...
34 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_bash_complet...
34 _zsh_highlight_bind_widgets:40> eval '_zsh_highlight_widget_orig-s0.000008000...
34 /Users/matt/.zshrc:596> export WORKON_HOME=/Users/matt/.virtualenvs
34 /Users/matt/.zshrc:444> export ANDROID_SDK=/Users/matt/Library/Android/sdk
34 /Users/matt/.zshrc:399> [[ ! -f /Users/matt/.p10k.zsh ]]
34 /Users/matt/.zshrc:354> export PKG_CONFIG_PATH=:/usr/local/opt/curl/lib/pkgco...
34 /Users/matt/.zshrc:353> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
34 /Users/matt/.zshrc:338> export PKG_CONFIG_PATH=:/usr/local/opt/curl/lib/pkgco...
34 /Users/matt/.zshrc:142> bindkey '^U' backward-kill-line
34 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:177> [[ -n robbyrussell ]]
34 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:29> bindkey -M emacs $'C-[[6~' do...
34 /Users/matt/.oh-my-zsh/lib/completion.zsh:8> setopt auto_menu
34 /Users/matt/.antigen/init.zsh:44> autoload -Uz add-zsh-hook
34 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:108> ...
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:9> zle -N br...
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:63> ...
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:29> ...
34 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:6> al...
34 -antigen-parse-args:162> eval 'bundle=(dir '''/Users/matt/.antigen/bundles/zs...
34 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
34 -antigen-parse-args:18> argkey=zsh-users/zsh-syntax-highlighting
34 -antigen-parse-args:9> typeset -A args
34 -antigen-parse-args:1> local argkey key value index=0 args
34 -antigen-parallel-execute:62> antigen-add-hook antigen-apply antigen-apply-pa...
34 -antigen-hook-handler:66> [[ 0 == -1 ]]
34 -antigen-hook-handler:58> ret=0
34 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-parallel '--loc...
34 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-defer zsh-users...
34 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-env-cached )
34 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-source mo...
34 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-env mode ...
34 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-en...
34 -antigen-hook-handler:7> hooks=( antigen-apply-lock antigen-apply-parallel an...
34 -antigen-hook-handler:2> local hooks meta
34 -antigen-hook-antigen-bundle:19> [[ ! -d /Users/matt/.antigen/bundles/zsh-use...
34 -antigen-env-setup:12> [[ ! -d /Users/matt/.antigen ]]
34 -antigen-cache-init:18> return 0
34 -antigen-cache-init:14> [[ /Users/matt/.antigen/init.zsh == false ]]
34 -antigen-cache-init:6> _ZCACHE_CAPTURE_BUNDLE=( )
34 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
34 (eval):110> alias 'gignore=git update-index --assume-unchanged'
34 (eval):56> alias 'gbl=git blame -b -w'
34 (eval):45> alias 'gamscp=git am --show-current-patch'
34 (eval):1> typeset -g ANTIGEN_MUTEX=true
34 (anon):1420> typeset -g POWERLEVEL9K_IP_FOREGROUND=38
34 (anon):176> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_OK_VICMD_CONTENT_EXPANSION=❮...
33 group_lazy_load:5> alias 'showvirtualenv=lazy_load "virtualenvwrapper wipeenv...
33 detect-clipboard:1> emulate -L zsh
33 compinit:533> zle -C reverse-menu-complete .reverse-menu-complete _main_complete
33 compinit:516> [[ '' !=  # ]]
33 compinit:511> compdef -na _zdump zdump
33 compinit:511> compdef -na _whereis whereis
33 compinit:511> compdef -na _vorbis oggenc ogg123 ogginfo oggdec vorbiscomment
33 compinit:511> compdef -na _unison unison
33 compinit:511> compdef -na _tr tr gtr
33 compinit:511> compdef -na _opkg opkg ipkg
33 compinit:511> compdef -na _mtr mtr
33 compinit:511> compdef -na _module-assistant module-assistant m-a
33 compinit:511> compdef -na _make-kpkg make-kpkg
33 compinit:511> compdef -na _kpartx kpartx
33 compinit:511> compdef -na _knock knock
33 compinit:511> compdef -na _jls jls
33 compinit:511> compdef -na _initctl initctl start stop restart reload status
33 compinit:511> compdef -na _ifconfig ifconfig
33 compinit:511> compdef -na _gist gist
33 compinit:511> compdef -na _df df gdf
33 compinit:511> compdef -na _conan conan
33 compinit:511> compdef -na _bower bower
33 compinit:511> compdef -na _asdf asdf
33 compinit:508> [[ zed = -[pPkK](n|) ]]
33 compinit:508> [[ yt-dlp = -[pPkK](n|) ]]
33 compinit:508> [[ sed = -[pPkK](n|) ]]
33 compinit:508> [[ openstack = -[pPkK](n|) ]]
33 compinit:508> [[ exec = -[pPkK](n|) ]]
33 compinit:508> [[ dcut = -[pPkK](n|) ]]
33 compinit:508> [[ cowsay = -[pPkK](n|) ]]
33 compinit:508> [[ chrt = -[pPkK](n|) ]]
33 compinit:508> [[ chkconfig = -[pPkK](n|) ]]
33 compinit:508> [[ cdrecord = -[pPkK](n|) ]]
33 compinit:508> [[ cdrdao = -[pPkK](n|) ]]
33 compinit:508> [[ cdr = -[pPkK](n|) ]]
33 compinit:508> [[ cal = -[pPkK](n|) ]]
33 compinit:508> [[ bzr = -[pPkK](n|) ]]
33 compinit:508> [[ _restic = -[pPkK](n|) ]]
33 compinit:506> case #compdef (#compdef)
33 compinit:505> shift _i_line
33 compinit:505> shift _i_line
33 compinit:505> shift _i_line
33 compinit:505> shift _i_line
33 compinit:505> shift _i_line
33 compinit:505> shift _i_line
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#compdef'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:504> _i_tag='#autoload'
33 compinit:501> ((  0 + 0  ))
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:121> shift _d_als
33 compdump:118> print -n ' 
           '
33 compdump:118> print -n ' 
           '
33 compdump:116> ((  ! --_i && 915 > 1  ))
33 compdump:116> ((  ! --_i && 876 > 1  ))
33 compdump:115> print -n ' _which'
33 compdump:115> print -n ' _compress'
33 compdump:113> ((  921  ))
33 compdump:95> read -rA _d_line
33 compdump:95> read -rA _d_line
33 compdump:95> read -rA _d_line
33 compdump:95> read -rA _d_line
33 compdump:95> read -rA _d_line
33 compdump:44> print -r - ''pigz'' ''_gzip''
33 compdump:44> print -r - ''make'' ''_make''
33 compdump:44> print -r - ''appletviewer'' ''_java''
33 compdump:19> typeset _d_file _d_f _d_bks _d_line _d_als _d_files _d_name _d_tmp
33 compdef:169> shift
33 compdef:162> [[ -z yes || -z _thor ]]
33 compdef:162> [[ -z yes || -z _scl ]]
33 compdef:162> [[ -z yes || -z _pmap ]]
33 compdef:162> [[ -z yes || -z _ltrace ]]
33 compdef:160> svc=''
33 compdef:155> [[ native2ascii = *=* ]]
33 compdef:139> case  (pattern)
33 compdef:139> case  (pattern)
33 compdef:136> [[ zpty = -P ]]
33 compdef:136> [[ tar = -P ]]
33 compdef:136> [[ sadf = -P ]]
33 compdef:136> [[ freezer = -P ]]
33 compdef:132> [[ zstyle = -N ]]
33 compdef:132> [[ ksh88 = -N ]]
33 compdef:114> [[ complete-word = menu-select ]]
33 compdef:83> case  (widgetkey)
33 compdef:81> shift
33 compdef:81> shift
33 compdef:81> shift
33 compdef:80> autoload -Uz _play
33 compdef:80> autoload -Uz _mount
33 compdef:80> autoload -Uz _iwconfig
33 compdef:80> [[ -n yes ]]
33 compdef:79> func=_xdvi
33 compdef:40> ((  ! 3  ))
33 compdef:38> shift OPTIND-1
33 compdef:17> new=yes
33 compdef:17> new=yes
33 compdef:17> new=yes
33 compdef:17> new=yes
33 compdef:17> new=yes
33 compdef:17> new=yes
33 compdef:15> case n (n)
33 compdef:15> case a (a)
33 compdef:14> getopts anpPkKde opt
33 compdef:14> getopts anpPkKde opt
33 compdef:14> getopts anpPkKde opt
33 compdef:14> getopts anpPkKde opt
33 compdef:9> ((  ! 3  ))
33 compdef:5> setopt extendedglob
33 compdef:5> setopt extendedglob
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:4> emulate -L zsh
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:2> local -a match mbegin mend
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
33 compaudit:176> compaudit
33 antigen-ext:9> -antigen-lock-execute
33 antigen-apply-cached:28> antigen-remove-hook antigen-bundle-cached
33 add-zsh-hook:28> getopts dDhLUzk opt
33 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
33 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-expand-or-com...
33 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_expand_word ...
33 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_correct_file...
33 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_bash_completi...
33 /Users/matt/.zshrc:595> export PYENV_VIRTUALENVWRAPPER_PREFER_PYVENV=true
33 /Users/matt/.zshrc:534> antigen apply
33 /Users/matt/.zshrc:526> antigen use oh-my-zsh
33 /Users/matt/.zshrc:420> export READLINE_PREFIX=/usr/local/opt/readline
33 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
33 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:42> [[ -z /Users/matt/.oh-my-zsh ]]
33 /Users/matt/.oh-my-zsh/lib/misc.zsh:4> [[ '' != true ]]
33 /Users/matt/.oh-my-zsh/lib/grep.zsh:41> unset __GREP_CACHE_FILE __GREP_ALIAS_...
33 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
33 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
33 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:35> setopt i...
33 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:7> (...
33 -antigen-parse-args:87> [[ zsh-users/zsh-syntax-highlighting != git://* && zs...
33 -antigen-parse-args:4> local var=bundle
33 -antigen-load:35> -antigen-load-source /Users/matt/.antigen/bundles/zsh-users...
33 -antigen-load:27> [[ 1 == 0 ]]
33 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-source with 0'
33 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-parallel deno
33 -antigen-hook-handler:48> ((  1  ))
33 -antigen-hook-handler:48> ((  1  ))
33 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-defer antige...
33 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-defer )
33 -antigen-hook-antigen:11> return 0
33 -antigen-hook-antigen-bundle:19> [[ ! -d /Users/matt/.antigen/bundles/robbyru...
33 -antigen-hook-antigen-bundle:19> [[ ! -d /Users/matt/.antigen/bundles/robbyru...
33 (eval):165> alias 'gstaa=git stash apply'
33 (eval):123> alias 'glods=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
33 (eval):92> alias 'gdca=git diff --cached'
33 (eval):78> alias 'gcm=git checkout $(git_main_branch)'
33 (anon):1> emulate -L zsh
32 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
32 group_lazy_load:5> alias 'workon=lazy_load "virtualenvwrapper wipeenv cdproje...
32 group_lazy_load:5> alias 'mkproject=lazy_load "virtualenvwrapper wipeenv cdpr...
32 group_lazy_load:5> alias 'deactivate=lazy_load "virtualenvwrapper wipeenv cdp...
32 group_lazy_load:5> alias 'cpvirtualenv=lazy_load "virtualenvwrapper wipeenv c...
32 group_lazy_load:5> alias 'cdvirtualenv=lazy_load "virtualenvwrapper wipeenv c...
32 group_lazy_load:5> alias 'allvirtualenv=lazy_load "virtualenvwrapper wipeenv ...
32 detect-clipboard:1> emulate -L zsh
32 complete:4> zparseopts -D -a void o: A: G: W: C: F: P: S: X: a b c d e f g j ...
32 compinit:524> [[ 1 = 1 ]]
32 compinit:516> _compautos[${_i_name}]=+X
32 compinit:511> compdef -na _zcalc_line -zcalc-line-
32 compinit:511> compdef -na _xscreensaver xscreensaver-command
32 compinit:511> compdef -na _who who gwho
32 compinit:511> compdef -na _vnc vncserver vncviewer xvncviewer xtightvncviewer...
32 compinit:511> compdef -na _update-alternatives update-alternatives
32 compinit:511> compdef -na _uml linux uml_moo uml_mconsole uml_switch tunctl
32 compinit:511> compdef -na _tload tload
32 compinit:511> compdef -na _tex tex latex slitex pdftex pdflatex jadetex pdfja...
32 compinit:511> compdef -na _strftime strftime
32 compinit:511> compdef -na _stgit stg
32 compinit:511> compdef -na _signify signify
32 compinit:511> compdef -na _rubber rubber rubber-pipe rubber-info
32 compinit:511> compdef -na _renice renice
32 compinit:511> compdef -na _ranlib ranlib
32 compinit:511> compdef -na _nothing true false times clear logname whoami sync
32 compinit:511> compdef -na _mutt mutt
32 compinit:511> compdef -na _mkdir mkdir gmkdir zf_mkdir
32 compinit:511> compdef -na _knife knife
32 compinit:511> compdef -na _kdeconnect kdeconnect-cli
32 compinit:511> compdef -na _join join gjoin
32 compinit:511> compdef -na _httpie http
32 compinit:511> compdef -na _git-revise git-revise
32 compinit:511> compdef -na _fail2ban-client fail2ban-client
32 compinit:511> compdef -na _equal -equal-
32 compinit:511> compdef -na _diana diana
32 compinit:511> compdef -na _cockroach _cockroach cockroach
32 compinit:508> [[ tmuxp = -[pPkK](n|) ]]
32 compinit:508> [[ tmuxinator = -[pPkK](n|) ]]
32 compinit:508> [[ mpv = -[pPkK](n|) ]]
32 compinit:508> [[ man = -[pPkK](n|) ]]
32 compinit:508> [[ host = -[pPkK](n|) ]]
32 compinit:508> [[ ethtool = -[pPkK](n|) ]]
32 compinit:508> [[ env = -[pPkK](n|) ]]
32 compinit:508> [[ dsh = -[pPkK](n|) ]]
32 compinit:508> [[ drill = -[pPkK](n|) ]]
32 compinit:508> [[ composer = -[pPkK](n|) ]]
32 compinit:508> [[ cdcd = -[pPkK](n|) ]]
32 compinit:508> [[ -value-,TERMINFO_DIRS,-default- = -[pPkK](n|) ]]
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:505> shift _i_line
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#compdef'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:504> _i_tag='#autoload'
32 compinit:501> ((  0 + 0  ))
32 compinit:501> ((  0 + 0  ))
32 compinit:501> ((  0 + 0  ))
32 compinit:191> : compinit /Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zs...
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:121> shift _d_als
32 compdump:117> _i=5
32 compdump:116> ((  ! --_i && 142 > 1  ))
32 compdump:115> print -n ' _shutdown'
32 compdump:115> print -n ' _hwinfo'
32 compdump:115> print -n ' _cksum'
32 compdump:114> ((  ! 0  ))
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:95> read -rA _d_line
32 compdump:49> _d_f=VBoxManage
32 compdump:44> print -r - ''scselect'' ''_scselect''
32 compdump:44> print -r - ''free'' ''_free''
32 compdump:44> print -r - ''cygpath.exe'' ''_cygpath''
32 compdump:44> print -r - ''6g'' ''_go''
32 compdump:43> _d_f=sha512
32 compdump:43> _d_f=kpartx
32 compdump:43> _d_f=brctl
32 compdef:169> shift
32 compdef:169> shift
32 compdef:162> [[ -z yes || -z _zstyle ]]
32 compdef:162> [[ -z yes || -z _xargs ]]
32 compdef:162> [[ -z yes || -z _dcop ]]
32 compdef:159> cmd=-value-,RPROMPT2,-default-
32 compdef:155> [[ zpty = *=* ]]
32 compdef:155> [[ zargs = *=* ]]
32 compdef:155> [[ comb = *=* ]]
32 compdef:139> case  (pattern)
32 compdef:139> case  (pattern)
32 compdef:139> case  (pattern)
32 compdef:139> case  (pattern)
32 compdef:139> case  (pattern)
32 compdef:136> [[ patch = -P ]]
32 compdef:134> [[ tla = -p ]]
32 compdef:134> [[ rmiregistry = -p ]]
32 compdef:132> [[ zmodload = -N ]]
32 compdef:132> [[ pon = -N ]]
32 compdef:132> [[ git-pulls = -N ]]
32 compdef:132> [[ genisoimage = -N ]]
32 compdef:132> [[ debdiff = -N ]]
32 compdef:132> [[ -value-,TERMINFO_DIRS,-default- = -N ]]
32 compdef:81> shift
32 compdef:81> shift
32 compdef:81> shift
32 compdef:81> shift
32 compdef:81> shift
32 compdef:80> autoload -Uz _xdvi
32 compdef:80> autoload -Uz _tardy
32 compdef:80> autoload -Uz _seq
32 compdef:80> autoload -Uz _entr
32 compdef:80> autoload -Uz _debdiff
32 compdef:49> [[ _shutdown = *=* ]]
32 compdef:40> ((  ! 2  ))
32 compdef:38> shift OPTIND-1
32 compdef:17> new=yes
32 compdef:17> new=yes
32 compdef:17> new=yes
32 compdef:16> autol=yes
32 compdef:16> autol=yes
32 compdef:16> autol=yes
32 compdef:15> case n (a)
32 compdef:15> case a (a)
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:14> getopts anpPkKde opt
32 compdef:9> ((  ! 5  ))
32 compdef:9> ((  ! 3  ))
32 compdef:9> ((  ! 3  ))
32 compdef:9> ((  ! 3  ))
32 compdef:9> ((  ! 3  ))
32 compdef:9> ((  ! 3  ))
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:5> setopt extendedglob
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:4> emulate -L zsh
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:2> local -a match mbegin mend
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
32 colors:103> typeset -AHg fg fg_bold fg_no_bold
32 colors:4> emulate -L zsh
32 antigen:1> -antigen-hook-handler antigen bundle zsh-users/zsh-autosuggestions
32 antigen-remove-hook:2> meta=( target antigen-bundle mode repeat type replace ...
32 antigen-remove-hook:2> meta=( target -antigen-load-env mode repeat type repla...
32 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-syntax-highl...
32 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-syntax-highl...
32 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-autosuggesti...
32 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-bundle
32 add-zsh-hook:85> typeset -ga preexec_functions
32 add-zsh-hook:28> getopts dDhLUzk opt
32 add-zsh-hook:15> emulate -L zsh
32 add-zle-hook-widget:45> ((  help || 2 != 2 || 3 == 0  ))
32 add-zle-hook-widget:40> 1=line-pre-redraw
32 add-zle-hook-widget:5> local usage='Usage: add-zle-hook-widget hook widgetnam...
32 _zsh_highlight_load_highlighters:14> [[ -f /Users/matt/.antigen/bundles/zsh-u...
32 _zsh_highlight_bind_widgets:50> zle -N kill-line _zsh_highlight_widget_orig-s...
32 _zsh_highlight_bind_widgets:50> zle -N insert-last-word _zsh_highlight_widget...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
32 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-reverse-menu-...
32 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_bash_list-ch...
32 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-down-line-or-...
32 /usr/local/share/antigen/antigen.zsh:1768> typeset -ga _ZCACHE_BUNDLE_SOURCE ...
32 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
32 /usr/local/Caskroom/google-cloud-sdk/latest/google-cloud-sdk/completion.zsh.i...
32 /Users/matt/.zshrc:348> export GUILE_TLS_CERTIFICATE_DIRECTORY=/usr/local/etc...
32 /Users/matt/.p10k.zsh:17> p10k_config_opts+=( aliases )
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:301> alias 'gtv=git tag | s...
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:277> alias 'gsr=git svn reb...
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:268> alias 'gru=git reset --'
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:201> alias 'gpsup=git push ...
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:196> alias 'ggpur=ggu'
32 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:73> alias 'gbd=git branch -d'
32 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:182> is_theme /Users/matt/.oh-my-zsh/them...
32 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:158> [[ -f /Users/matt/.oh-my-zsh/plugins...
32 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=zsh-completions
32 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:49> setopt prompt_subst
32 /Users/matt/.oh-my-zsh/lib/misc.zsh:35> setopt interactivecomments
32 /Users/matt/.oh-my-zsh/lib/misc.zsh:13> break
32 /Users/matt/.oh-my-zsh/lib/directories.zsh:2> setopt auto_pushd
32 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
32 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
32 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:60> zstyle ':completion:fasd-com...
32 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'imgcat=/Users/matt/.ite...
32 /Users/matt/.iterm2_shell_integration.zsh:16> [ xterm-256color '!=' screen -a...
32 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
32 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
32 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:109> ...
32 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:31> alias 'a...
32 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:39> ...
32 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:25> alias...
32 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:8> set...
32 -antigen-parallel-init:1> WARN 'Init parallel extension' PARALLEL
32 -antigen-load:35> -antigen-load-source /Users/matt/.antigen/bundles/zsh-users...
32 -antigen-load-source:1> -antigen-hook-handler -antigen-load-source /Users/mat...
32 -antigen-interactive-mode:1> WARN '-antigen-interactive-mode: file:file:shfun...
32 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-source with 0'
32 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-env with 0'
32 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-env with 0'
32 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-env with 0'
32 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
32 -antigen-hook-handler:58> ret=0
32 -antigen-hook-handler:57> -antigen-hook-antigen-bundle zsh-users/zsh-syntax-h...
32 -antigen-hook-handler:57> -antigen-hook-antigen bundle zsh-users/zsh-syntax-h...
32 -antigen-hook-handler:55> [[ 0 == 0 ]]
32 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-parallel zsh-us...
32 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-defer zsh-users...
32 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-bundle-defer deno
32 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-defer antige...
32 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-source-cached )
32 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
32 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
32 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-so...
32 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-so...
32 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-so...
32 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-en...
32 -antigen-hook-handler:3> shift
32 -antigen-hook-antigen-bundle:1> TRACE 'Called antigen-bundle with --loc=lib' ...
32 -antigen-cache-generate:6> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
32 (eval):58> alias 'gbr=git branch --remote'
32 (eval):1> typeset -g ANTIGEN_BUNDLES=/Users/matt/.antigen/bundles
32 (eval):1> typeset -g ADOTDIR=/Users/matt/.antigen
32 (anon):437> typeset -g POWERLEVEL9K_VCS_LOADING_CONTENT_EXPANSION='${$((my_gi...
32 (anon):174> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_OK_VIINS_CONTENT_EXPANSION=❯...
31 is_plugin:2> local name=fasd
31 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
31 is-at-least:23> emulate -L zsh
31 is-at-least:23> emulate -L zsh
31 group_lazy_load:5> alias 'mktmpenv=lazy_load "virtualenvwrapper wipeenv cdpro...
31 group_lazy_load:5> alias 'lsvirtualenv=lazy_load "virtualenvwrapper wipeenv c...
31 group_lazy_load:5> alias 'cdsitepackages=lazy_load "virtualenvwrapper wipeenv...
31 group_lazy_load:5> alias 'cdproject=lazy_load "virtualenvwrapper wipeenv cdpr...
31 complete:8> [[ -n '' ]]
31 compinit:515> autoload -Uz _requested
31 compinit:515> autoload -Uz _expand
31 compinit:511> compdef -na _xterm xterm
31 compinit:511> compdef -na _xrandr xrandr
31 compinit:511> compdef -na _whois whois fwhois
31 compinit:511> compdef -na _which which whence where type
31 compinit:511> compdef -na _vim-addons vim-addons
31 compinit:511> compdef -na _vars getopts unset
31 compinit:511> compdef -na _vared vared
31 compinit:511> compdef -na _users_on write
31 compinit:511> compdef -na _user_admin useradd usermod groupadd groupmod
31 compinit:511> compdef -na _uptime uptime guptime
31 compinit:511> compdef -na _unexpand unexpand gunexpand expand gexpand
31 compinit:511> compdef -na _transmission transmission-remote
31 compinit:511> compdef -na _tmux tmux
31 compinit:511> compdef -na _system_profiler system_profiler
31 compinit:511> compdef -na _swanctl swanctl
31 compinit:511> compdef -na _svn-buildpackage svn-buildpackage
31 compinit:511> compdef -na _stty stty gstty
31 compinit:511> compdef -na _strings strings gstrings eu-strings
31 compinit:511> compdef -na _strace strace strace64
31 compinit:511> compdef -na _slabtop slabtop
31 compinit:511> compdef -na _setxkbmap setxkbmap
31 compinit:511> compdef -na _setopt setopt unsetopt
31 compinit:511> compdef -na _scl scl
31 compinit:511> compdef -na _qtplay qtplay
31 compinit:511> compdef -na _ps ps
31 compinit:511> compdef -na _powerd powerd
31 compinit:511> compdef -na _pkgrm pkgrm
31 compinit:511> compdef -na _pidof pidof
31 compinit:511> compdef -na _pax pax
31 compinit:511> compdef -na _pack pack unpack 'pcat=unpack'
31 compinit:511> compdef -na _nginx nginx
31 compinit:511> compdef -na _nedit nedit 'nedit-nc=nc' 'ncl=nc'
31 compinit:511> compdef -na _lsblk lsblk
31 compinit:511> compdef -na _killall killall killall5
31 compinit:511> compdef -na _ipadm ipadm
31 compinit:511> compdef -na _invoke-rc.d invoke-rc.d
31 compinit:511> compdef -na _install install ginstall
31 compinit:511> compdef -na _hwinfo hwinfo
31 compinit:511> compdef -na _homestead homestead
31 compinit:511> compdef -na _gprof gprof
31 compinit:511> compdef -na _git-journal git-journal
31 compinit:511> compdef -na _git-buildpackage git-buildpackage
31 compinit:511> compdef -na _fold fold gfold
31 compinit:511> compdef -na _fink fink
31 compinit:511> compdef -na _fetchmail fetchmail
31 compinit:511> compdef -na _echoti echoti
31 compinit:511> compdef -na _dvc dvc
31 compinit:511> compdef -na _ccache ccache -P '-value-,CCACHE_*,-default-'
31 compinit:511> compdef -na _bsdconfig bsdconfig
31 compinit:511> compdef -na _base64 base64 gbase64 base32 gbase32
31 compinit:511> compdef -na _autocd -command-
31 compinit:511> compdef -na _acroread acroread
31 compinit:511> compdef -na _acpitool acpitool
31 compinit:509> compdef -Pna _texi '(texi(2*|ndex))'
31 compinit:509> compdef -Pna _python 'python[0-9.]#'
31 compinit:508> [[ xdpyinfo = -[pPkK](n|) ]]
31 compinit:508> [[ wg-quick = -[pPkK](n|) ]]
31 compinit:508> [[ trash-empty = -[pPkK](n|) ]]
31 compinit:508> [[ tox = -[pPkK](n|) ]]
31 compinit:508> [[ ri = -[pPkK](n|) ]]
31 compinit:508> [[ putclip = -[pPkK](n|) ]]
31 compinit:508> [[ pm2 = -[pPkK](n|) ]]
31 compinit:508> [[ objdump = -[pPkK](n|) ]]
31 compinit:508> [[ mere = -[pPkK](n|) ]]
31 compinit:508> [[ fakeroot = -[pPkK](n|) ]]
31 compinit:508> [[ enscript = -[pPkK](n|) ]]
31 compinit:508> [[ elinks = -[pPkK](n|) ]]
31 compinit:508> [[ dput = -[pPkK](n|) ]]
31 compinit:508> [[ diff = -[pPkK](n|) ]]
31 compinit:508> [[ debfoster = -[pPkK](n|) ]]
31 compinit:508> [[ calendar = -[pPkK](n|) ]]
31 compinit:508> [[ ansible = -[pPkK](n|) ]]
31 compinit:508> [[ _helm = -[pPkK](n|) ]]
31 compinit:508> [[ -k = -[pPkK](n|) ]]
31 compinit:508> [[ -K = -[pPkK](n|) ]]
31 compinit:508> [[ 'VBoxManage=vboxmanage' = -[pPkK](n|) ]]
31 compinit:506> case #compdef (#compdef)
31 compinit:506> case #autoload (#autoload)
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:505> shift _i_line
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#compdef'
31 compinit:504> _i_tag='#autoload'
31 compinit:504> _i_tag='#autoload'
31 compinit:504> _i_tag='#autoload'
31 compinit:504> _i_tag='#autoload'
31 compinit:504> _i_tag='#autoload'
31 compinit:504> _i_tag='#autoload'
31 compinit:501> ((  0 + 0  ))
31 compinit:501> ((  0 + 0  ))
31 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zmv
31 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svcprop
31 compinit:482> [[ _i_autodump -eq 1 && 956 -eq 956 && 5.8.1 = 5.8.1 ]]
31 compinit:118> typeset -gHA _lastcomp
31 compinit:76> [[ 0 -gt 0 ]]
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:121> shift _d_als
31 compdump:118> print -n ' 
           '
31 compdump:116> ((  ! --_i && 1028 > 1  ))
31 compdump:116> ((  ! --_i && 572 > 1  ))
31 compdump:116> ((  ! --_i && 303 > 1  ))
31 compdump:115> print -n ' _yaourt'
31 compdump:115> print -n ' _wemux'
31 compdump:115> print -n ' _signify'
31 compdump:115> print -n ' _knock'
31 compdump:115> print -n ' _jmeter'
31 compdump:115> print -n ' _asdf'
31 compdump:115> print -n ' _all_labels'
31 compdump:114> ((  ! 0  ))
31 compdump:114> ((  ! 0  ))
31 compdump:114> ((  ! 0  ))
31 compdump:114> ((  ! 0  ))
31 compdump:114> ((  ! 0  ))
31 compdump:113> ((  1076  ))
31 compdump:97> print -r 'bindkey '''^X^R''' _read_comp'
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:95> read -rA _d_line
31 compdump:91> _d_bks+=( _read_comp )
31 compdump:90> print -r - zle -C _bash_complete-word .complete-word _bash_compl...
31 compdump:85> [[ orig-s0.0000080000-r6249-self-insert = _* ]]
31 compdump:44> print -r - ''tcp_open'' ''_tcpsys''
31 compdump:44> print -r - ''sha384'' ''_cksum''
31 compdump:44> print -r - ''screen'' ''_screen''
31 compdump:44> print -r - ''psmerge'' ''_psutils''
31 compdump:44> print -r - ''nocorrect'' ''_precommand''
31 compdump:44> print -r - ''module'' ''_module''
31 compdump:44> print -r - ''lintian'' ''_lintian''
31 compdump:44> print -r - ''ksh88'' ''_sh''
31 compdump:44> print -r - ''diana'' ''_diana''
31 compdump:44> print -r - ''dhcpinfo'' ''_dhcpinfo''
31 compdump:44> print -r - ''chrt'' ''_chrt''
31 compdump:17> setopt extendedglob noshglob
31 compdef:169> shift
31 compdef:169> shift
31 compdef:169> shift
31 compdef:169> shift
31 compdef:169> shift
31 compdef:162> [[ -z yes || -z _zpty ]]
31 compdef:162> [[ -z yes || -z _xinput ]]
31 compdef:162> [[ -z yes || -z _sh ]]
31 compdef:162> [[ -z yes || -z _pump ]]
31 compdef:162> [[ -z yes || -z _networksetup ]]
31 compdef:162> [[ -z yes || -z _mina ]]
31 compdef:162> [[ -z yes || -z _md5sum ]]
31 compdef:162> [[ -z yes || -z _gstat ]]
31 compdef:162> [[ -z yes || -z _dmesg ]]
31 compdef:162> [[ -z yes || -z _debuild ]]
31 compdef:162> [[ -z yes || -z _chmod ]]
31 compdef:159> cmd=twidge
31 compdef:155> [[ sbuild = *=* ]]
31 compdef:139> case  (postpattern)
31 compdef:139> case  (pattern)
31 compdef:139> case  (*)
31 compdef:139> case  (*)
31 compdef:136> [[ heat = -P ]]
31 compdef:136> [[ ack-grep = -P ]]
31 compdef:134> [[ lp = -p ]]
31 compdef:132> [[ yadm = -N ]]
31 compdef:132> [[ schedtool = -N ]]
31 compdef:132> [[ git-flow = -N ]]
31 compdef:132> [[ dash = -N ]]
31 compdef:132> [[ 'VBoxManage=vboxmanage' = -N ]]
31 compdef:131> ((  1  ))
31 compdef:83> case  (*)
31 compdef:81> shift
31 compdef:81> shift
31 compdef:81> shift
31 compdef:81> shift
31 compdef:81> shift
31 compdef:80> autoload -Uz _rubocop
31 compdef:80> autoload -Uz _rspec
31 compdef:80> autoload -Uz _route
31 compdef:80> autoload -Uz _meson
31 compdef:80> autoload -Uz _directory_stack
31 compdef:80> autoload -Uz _debsign
31 compdef:80> [[ -n yes ]]
31 compdef:80> [[ -n yes ]]
31 compdef:80> [[ -n yes ]]
31 compdef:49> [[ _fmt = *=* ]]
31 compdef:40> ((  ! 3  ))
31 compdef:38> shift OPTIND-1
31 compdef:38> shift OPTIND-1
31 compdef:38> shift OPTIND-1
31 compdef:17> new=yes
31 compdef:17> new=yes
31 compdef:17> new=yes
31 compdef:17> new=yes
31 compdef:17> new=yes
31 compdef:17> new=yes
31 compdef:16> autol=yes
31 compdef:16> autol=yes
31 compdef:16> autol=yes
31 compdef:15> case n (a)
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:14> getopts anpPkKde opt
31 compdef:9> ((  ! 3  ))
31 compdef:9> ((  ! 3  ))
31 compdef:9> ((  ! 3  ))
31 compdef:9> ((  ! 3  ))
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:5> setopt extendedglob
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:4> emulate -L zsh
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:2> local -a match mbegin mend
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
31 compaudit:156> case 0:0 (0:0)
31 colors:115> bg_bold[${k#bg-}]=$'C-[[01;42m'
31 antigen-use:2> -antigen-use-oh-my-zsh
31 antigen-remove-hook:2> meta=( target antigen-bundle mode repeat type replace ...
31 antigen-remove-hook:1> local hook=-antigen-load-source-cached
31 antigen-ext:9> _ANTIGEN_EXTENSIONS+=( parallel )
31 antigen-ext:6> WARN '-antigen-lock-init return code was 0'
31 antigen-ext-init:5> antigen-ext parallel
31 antigen-bundle:2> return 0
31 antigen-bundle:2> return 0
31 antigen-bundle:2> return 0
31 antigen-bundle:2> return 0
31 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-autosugg...
31 antigen-bundle:1> -antigen-hook-handler antigen-bundle '--loc=lib'
31 antigen-bundle-parallel:1> TRACE 'antigen-bundle-parallel: --loc=lib' PARALLEL
31 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-syntax-highl...
31 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-autosuggesti...
31 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( zsh-users/zsh-autosuggesti...
31 antigen-apply-parallel:1> WARN 'Parallel pre-apply' PARALLEL PRE-APPLY
31 antigen-apply-defer:11> unset _DEFERRED_BUNDLE
31 antigen-apply-defer:8> antigen-bundle zsh-users/zsh-syntax-highlighting
31 antigen-apply-defer:8> antigen-bundle zsh-users/zsh-autosuggestions
31 antigen-apply-defer:8> antigen-bundle deno
31 antigen-apply-defer:8> antigen-bundle '--loc=lib'
31 antigen-apply-cached:18> -antigen-cache-generate
31 antigen-add-hook:1> local target=antigen-apply hook=antigen-apply-lock type=p...
31 add-zsh-hook:86> set -A precmd_functions omz_termsupport_precmd _zsh_highligh...
31 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
31 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
31 add-zle-hook-widget:181> add-zle-hook-widget zle-line-pre-redraw _zsh_highlig...
31 add-zle-hook-widget:23> zmodload zsh/zleparameter
31 add-zle-hook-widget:22> zmodload -e zsh/zle
31 add-zle-hook-widget:2> zstyle -a zle-hook types hooktypes
31 _zsh_highlight_bind_widgets:50> zle -N vi-set-mark _zsh_highlight_widget_orig...
31 _zsh_highlight_bind_widgets:50> zle -N vi-put-after _zsh_highlight_widget_ori...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:49> eval '_zsh_highlight_widget_orig-s0.000008000...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_read_comp .c...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_next_tags .l...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_most_recent_...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_expand_alias...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_correct_word...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_complete_hel...
31 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_complete_deb...
31 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
31 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
31 /usr/local/share/antigen/antigen.zsh:2041> zmodload zsh/datetime
31 /usr/local/share/antigen/antigen.zsh:57> ((  ! 1  ))
31 /usr/local/share/antigen/antigen.zsh:24> config=/Users/matt/.zshrc
31 /Users/matt/.zshrc:402> export EDITOR=nvim
31 /Users/matt/.zshrc:359> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
31 /Users/matt/.zshrc:316> export CONDA_SHLVL=0
31 /Users/matt/.zshrc:218> export PKG_CONFIG_PATH=:/usr/local/opt/curl/lib/pkgco...
31 /Users/matt/.zshrc:165> alias 'gpu=git push -u'
31 /Users/matt/.zshrc:153> export THEOS=/Users/matt/theos
31 /Users/matt/.p10k.zsh:1586> setopt aliases
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:315> alias 'gam=git am'
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:310> alias 'glum=git pull u...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:305> alias 'gunwip=git log ...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:304> alias 'gunignore=git u...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:298> alias 'gswd=git switch...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:291> alias 'gsts=git stash ...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:270> alias 'grv=git remote -v'
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:245> alias 'gra=git remote ...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:224> alias 'glog=git log --...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:218> alias 'glo=git log --o...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:210> alias 'gke=gitk --all ...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:198> alias 'ggpush=git push...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:197> alias 'ggpull=git pull...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:179> compdef _git 'ggp=git-...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:169> compdef _git 'ggl=git-...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:141> alias 'gfa=git fetch -...
31 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:105> alias 'gcl=git clone -...
31 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:158> [[ -f /Users/matt/.oh-my-zsh/plugins...
31 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:47> ZSH_CACHE_DIR=/Users/matt/.oh-my-zsh/...
31 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:23> bindkey -M emacs $'C-[[5~' up...
31 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
31 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
31 /Users/matt/.iterm2_shell_integration.zsh:161> precmd_functions=( omz_termsup...
31 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
31 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
31 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:41> Z...
31 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
31 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:19> setopt l...
31 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:7> is-at-lea...
31 -antigen-set-default:3> eval 'test -z "$ANTIGEN_OMZ_REPO_URL" && typeset -g A...
31 -antigen-parse-args:118> local branch=''
31 -antigen-parse-args:87> [[ zsh-users/zsh-syntax-highlighting != git://* && zs...
31 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
31 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
31 -antigen-parallel-init:3> -antigen-interactive-mode
31 -antigen-lock-init:3> typeset -g _ANTIGEN_LOCK_PROCESS=false
31 -antigen-load:27> [[ 1 == 0 ]]
31 -antigen-load:4> list=( )
31 -antigen-interactive-mode:1> WARN '-antigen-interactive-mode: file:file:shfun...
31 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
31 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
31 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
31 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-env with 0'
31 -antigen-hook-handler:58> ret=0
31 -antigen-hook-handler:58> ret=0
31 -antigen-hook-handler:58> ret=0
31 -antigen-hook-handler:58> ret=0
31 -antigen-hook-handler:58> ret=0
31 -antigen-hook-handler:57> -antigen-hook-antigen-bundle zsh-users/zsh-autosugg...
31 -antigen-hook-handler:57> -antigen-hook-antigen bundle zsh-users/zsh-autosugg...
31 -antigen-hook-handler:56> WARN '-antigen-hook-antigen bundle zsh-users/zsh-au...
31 -antigen-hook-handler:50> -antigen-load-source-cached /Users/matt/.antigen/bu...
31 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-defer antige...
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached'
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached antig...
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached antig...
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached antig...
31 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached antig...
31 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-source-cached'
31 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-env-cached'
31 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-env-cached'
31 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-source-cached )
31 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-env-cached )
31 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-env-cached )
31 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-env-cached )
31 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
31 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen mode once type ...
31 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-env mode ...
31 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
31 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
31 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-en...
31 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
31 -antigen-hook-handler:11> meta=( target -antigen-load-env mode repeat type re...
31 -antigen-hook-handler:9> typeset -A meta
31 -antigen-hook-antigen:11> return 0
31 -antigen-hook-antigen:10> antigen-use oh-my-zsh
31 -antigen-env-setup:6> -antigen-set-default ANTIGEN_PREZTO_REPO_URL https://gi...
31 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
31 -antigen-cache-execute:55> antigen-add-hook -antigen-load-env -antigen-load-e...
31 (eval):224> alias 'it2universion=/Users/matt/.iterm2/it2universion'
31 (eval):94> alias 'gdcw=git diff --cached --word-diff'
31 (eval):47> alias 'gapa=git add --patch'
31 (eval):1> test -z /Users/matt/.antigen/.resources
31 (anon):203> typeset -g POWERLEVEL9K_DIR_ANCHOR_BOLD=true
31 (anon):178> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_OK_VIVIS_CONTENT_EXPANSION=V...
31 (anon):2> action=enable
30 regexp-replace:36> break
30 is-at-least:31> [[ '' != <-> ]]
30 compinit:542> ((  3 <= 2  ))
30 compinit:515> autoload -Uz _call_function
30 compinit:511> compdef -na _w3m w3m
30 compinit:511> compdef -na _uname uname guname
30 compinit:511> compdef -na _ttyctl ttyctl
30 compinit:511> compdef -na _truss truss
30 compinit:511> compdef -na _tracepath tracepath tracepath6
30 compinit:511> compdef -na _tcptraceroute tcptraceroute
30 compinit:511> compdef -na _tar tar gtar star bsdtar
30 compinit:511> compdef -na _sysctl sysctl
30 compinit:511> compdef -na _subscript -subscript-
30 compinit:511> compdef -na _sockstat sockstat
30 compinit:511> compdef -na _socket socket
30 compinit:511> compdef -na _smartmontools smartctl
30 compinit:511> compdef -na _shuf shuf gshuf
30 compinit:511> compdef -na _showmount showmount
30 compinit:511> compdef -na _savecore savecore
30 compinit:511> compdef -na _rmdir rmdir grmdir zf_rmdir
30 compinit:511> compdef -na _rebootin rebootin
30 compinit:511> compdef -na _readlink readlink greadlink
30 compinit:511> compdef -na _rcs co ci rcs rcsdiff merge
30 compinit:511> compdef -na _rar rar unrar
30 compinit:511> compdef -na _prompt prompt
30 compinit:511> compdef -na _procstat procstat
30 compinit:511> compdef -na _portlint portlint
30 compinit:511> compdef -na _plutil plutil
30 compinit:511> compdef -na _pkgin pkgin
30 compinit:511> compdef -na _piuparts piuparts
30 compinit:511> compdef -na _osascript osascript
30 compinit:511> compdef -na _nslookup nslookup
30 compinit:511> compdef -na _normal -command-line-
30 compinit:511> compdef -na _ngrep ngrep
30 compinit:511> compdef -na _myrepos mr
30 compinit:511> compdef -na _mv mv gmv zf_mv
30 compinit:511> compdef -na _mknod mknod gmknod
30 compinit:511> compdef -na _mdutil mdutil
30 compinit:511> compdef -na _ipsec ipsec strongswan
30 compinit:511> compdef -na _inetadm inetadm
30 compinit:511> compdef -na _in_vared -vared-
30 compinit:511> compdef -na _iconv iconv
30 compinit:511> compdef -na _hexdump hexdump hd
30 compinit:511> compdef -na _gpasswd gpasswd
30 compinit:511> compdef -na _google google
30 compinit:511> compdef -na _git-wtf git-wtf
30 compinit:511> compdef -na _ghc ghc ghci ghc-pkg
30 compinit:511> compdef -na _getconf getconf
30 compinit:511> compdef -na _force force
30 compinit:511> compdef -na _fmt fmt gfmt
30 compinit:511> compdef -na _fmadm fmadm
30 compinit:511> compdef -na _flutter flutter
30 compinit:511> compdef -na _floppy dosread dosdel
30 compinit:511> compdef -na _fleetctl fleetctl
30 compinit:511> compdef -na _fab fab
30 compinit:511> compdef -na _cf cf
30 compinit:511> compdef -na _cap cap
30 compinit:509> compdef -pna _init_d '*/(init|rc[0-9S]#).d/*'
30 compinit:509> compdef -Pna _pydoc 'pydoc[0-9.]#'
30 compinit:508> [[ zsocket = -[pPkK](n|) ]]
30 compinit:508> [[ zcash-cli = -[pPkK](n|) ]]
30 compinit:508> [[ xsltproc = -[pPkK](n|) ]]
30 compinit:508> [[ xli = -[pPkK](n|) ]]
30 compinit:508> [[ xautolock = -[pPkK](n|) ]]
30 compinit:508> [[ wemux = -[pPkK](n|) ]]
30 compinit:508> [[ vnstat = -[pPkK](n|) ]]
30 compinit:508> [[ trash-list = -[pPkK](n|) ]]
30 compinit:508> [[ tin = -[pPkK](n|) ]]
30 compinit:508> [[ route = -[pPkK](n|) ]]
30 compinit:508> [[ psql = -[pPkK](n|) ]]
30 compinit:508> [[ md5sum = -[pPkK](n|) ]]
30 compinit:508> [[ kpartx = -[pPkK](n|) ]]
30 compinit:508> [[ jq = -[pPkK](n|) ]]
30 compinit:508> [[ dtrace = -[pPkK](n|) ]]
30 compinit:508> [[ django-admin.py = -[pPkK](n|) ]]
30 compinit:508> [[ dhclient = -[pPkK](n|) ]]
30 compinit:508> [[ dcop = -[pPkK](n|) ]]
30 compinit:508> [[ cygrunsrv = -[pPkK](n|) ]]
30 compinit:508> [[ cygpath = -[pPkK](n|) ]]
30 compinit:508> [[ cygcheck = -[pPkK](n|) ]]
30 compinit:508> [[ cvs = -[pPkK](n|) ]]
30 compinit:508> [[ configure = -[pPkK](n|) ]]
30 compinit:508> [[ cd = -[pPkK](n|) ]]
30 compinit:508> [[ ali = -[pPkK](n|) ]]
30 compinit:508> [[ -value-,LD_DEBUG,-default- = -[pPkK](n|) ]]
30 compinit:508> [[ -value-,LANG,-default- = -[pPkK](n|) ]]
30 compinit:508> [[ -k = -[pPkK](n|) ]]
30 compinit:508> [[ -P = -[pPkK](n|) ]]
30 compinit:506> case #compdef (#compdef)
30 compinit:506> case #compdef (#compdef)
30 compinit:506> case #autoload (#autoload)
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:505> shift _i_line
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#compdef'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:504> _i_tag='#autoload'
30 compinit:501> ((  0 + 0  ))
30 compinit:501> ((  0 + 0  ))
30 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_column
30 compinit:76> [[ 3 -gt 0 && -i = -[dDiuC] ]]
30 compinit:73> typeset _i_dumpfile _i_files _i_line _i_done _i_dir _i_autodump=1
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:121> shift _d_als
30 compdump:116> ((  ! --_i && 658 > 1  ))
30 compdump:116> ((  ! --_i && 452 > 1  ))
30 compdump:116> ((  ! --_i && 369 > 1  ))
30 compdump:116> ((  ! --_i && 362 > 1  ))
30 compdump:116> ((  ! --_i && 341 > 1  ))
30 compdump:116> ((  ! --_i && 264 > 1  ))
30 compdump:116> ((  ! --_i && 9 > 1  ))
30 compdump:115> print -n ' _trash-put'
30 compdump:115> print -n ' _subversion'
30 compdump:114> ((  ! 0  ))
30 compdump:114> ((  ! 0  ))
30 compdump:114> ((  ! 0  ))
30 compdump:113> ((  481  ))
30 compdump:113> ((  382  ))
30 compdump:113> ((  357  ))
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:95> read -rA _d_line
30 compdump:85> [[ up-line = _* ]]
30 compdump:44> print -r - ''udisksctl'' ''_udisksctl''
30 compdump:44> print -r - ''script'' ''_script''
30 compdump:44> print -r - ''mlocate'' ''_locate''
30 compdump:44> print -r - ''install-info'' ''_texinfo''
30 compdump:44> print -r - ''gtimeout'' ''_timeout''
30 compdump:44> print -r - ''attr'' ''_attr''
30 compdump:44> print -r - ''-'' ''_precommand''
30 compdump:43> _d_f=wpa_cli
30 compdef:169> shift
30 compdef:164> _services[$cmd]=vboxmanage
30 compdef:164> _services[$cmd]=git-log
30 compdef:164> _services[$cmd]=chown
30 compdef:162> [[ -z yes || -z _yadm ]]
30 compdef:162> [[ -z yes || -z _units ]]
30 compdef:162> [[ -z yes || -z _tmuxinator ]]
30 compdef:162> [[ -z yes || -z _rspec ]]
30 compdef:162> [[ -z yes || -z _pspdf ]]
30 compdef:162> [[ -z yes || -z _openstack ]]
30 compdef:162> [[ -z yes || -z _openstack ]]
30 compdef:162> [[ -z yes || -z _mkzsh ]]
30 compdef:162> [[ -z yes || -z _md5sum ]]
30 compdef:162> [[ -z yes || -z _devtodo ]]
30 compdef:162> [[ -z yes || -z _compress ]]
30 compdef:162> [[ -z yes || -z _cksum ]]
30 compdef:162> [[ -z yes || -z _bogofilter ]]
30 compdef:162> [[ -z yes || -z _apt-move ]]
30 compdef:160> svc=''
30 compdef:159> cmd=scl
30 compdef:155> [[ kitchen = *=* ]]
30 compdef:139> case  (postpattern)
30 compdef:139> case  (*)
30 compdef:139> case  (*)
30 compdef:136> [[ git = -P ]]
30 compdef:134> [[ svnadmin = -p ]]
30 compdef:132> [[ xinput = -N ]]
30 compdef:132> [[ newgrp = -N ]]
30 compdef:132> [[ mush = -N ]]
30 compdef:132> [[ ifup = -N ]]
30 compdef:132> [[ cvsup = -N ]]
30 compdef:132> [[ compress = -N ]]
30 compdef:132> [[ _rclone = -N ]]
30 compdef:132> [[ -value-,WWW_HOME,-default- = -N ]]
30 compdef:132> [[ -value-,ANDROID_SERIAL,-default- = -N ]]
30 compdef:131> ((  8  ))
30 compdef:114> [[ complete-word = menu-select ]]
30 compdef:83> case  (*)
30 compdef:81> shift
30 compdef:81> shift
30 compdef:81> shift
30 compdef:81> shift
30 compdef:81> shift
30 compdef:81> shift
30 compdef:81> shift
30 compdef:80> autoload -Uz _users
30 compdef:80> autoload -Uz _unhash
30 compdef:80> autoload -Uz _tree
30 compdef:80> autoload -Uz _rsync
30 compdef:80> autoload -Uz _cvsup
30 compdef:80> autoload -Uz _a2ps
30 compdef:45> [[ -z '' ]]
30 compdef:38> shift OPTIND-1
30 compdef:38> shift OPTIND-1
30 compdef:38> shift OPTIND-1
30 compdef:38> shift OPTIND-1
30 compdef:38> shift OPTIND-1
30 compdef:38> shift OPTIND-1
30 compdef:17> new=yes
30 compdef:17> new=yes
30 compdef:17> new=yes
30 compdef:17> new=yes
30 compdef:17> new=yes
30 compdef:16> autol=yes
30 compdef:16> autol=yes
30 compdef:15> case n (n)
30 compdef:15> case n (a)
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:14> getopts anpPkKde opt
30 compdef:9> ((  ! 18  ))
30 compdef:9> ((  ! 10  ))
30 compdef:9> ((  ! 4  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:9> ((  ! 3  ))
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:5> setopt extendedglob
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:4> emulate -L zsh
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:2> local -a match mbegin mend
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
30 compaudit:13> emulate -L zsh
30 colors:77> color[${color[$k]}]=41
30 colors:77> color[${color[$k]}]=31
30 bashcompinit:177> unfunction bashcompinit
30 antigen:1> -antigen-hook-handler antigen use oh-my-zsh
30 antigen-remove-hook:1> local hook=antigen-bundle-cached
30 antigen-ext:9> -antigen-cache-execute
30 antigen-ext:3> ((  1 && 0 == 0  ))
30 antigen-bundle:2> return 0
30 antigen-bundle:1> -antigen-hook-handler antigen-bundle deno
30 antigen-bundle-parallel-execute:21> WARN 'Bundle zsh-users/zsh-syntax-highlig...
30 antigen-bundle-parallel-execute:21> WARN 'Bundle zsh-users/zsh-autosuggestion...
30 antigen-bundle-parallel-execute:21> WARN 'Bundle robbyrussell/oh-my-zsh alrea...
30 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( deno )
30 antigen-apply-parallel-execute:2> antigen-remove-hook antigen-bundle-parallel
30 antigen-apply-defer:7> LOG 'Processing deferred bundle: zsh-users/zsh-syntax-...
30 antigen-apply-defer:2> antigen-remove-hook antigen-bundle-defer
30 antigen-add-hook:23> ((  ! 1  ))
30 antigen-add-hook:1> local target=-antigen-load-source hook=-antigen-load-sour...
30 add-zsh-hook:26> integer del list help
30 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
30 add-zsh-hook:15> emulate -L zsh
30 add-zle-hook-widget:71> [[ _zsh_highlight__zle-line-pre-redraw = zle-line-pre...
30 add-zle-hook-widget:2> zstyle -a zle-hook types hooktypes
30 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-_complete_tag...
30 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-up-line-or-be...
30 _zsh_highlight_bind_widgets:27> case builtin (builtin)
30 _zsh_highlight_bind_widgets:2> setopt localoptions noksharrays
30 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:82> setopt aliases
30 /Users/matt/.zshrc:486> export MONO_GAC_PREFIX=/usr/local
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:309> alias 'gupav=git pull ...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:263> alias 'grs=git restore'
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:258> alias 'groh=git reset ...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:252> alias 'grbom=git rebas...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:242> alias 'gpv=git push -v'
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:232> alias 'gmum=git merge ...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:229> alias 'gmom=git merge ...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:226> alias 'glp=_git_log_pr...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:225> alias 'gloga=git log -...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:217> alias 'glgm=git log --...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:205> alias 'gignore=git upd...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:203> alias 'ghh=git help'
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:159> compdef _git 'ggfl=git...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:143> alias 'gfo=git fetch o...
30 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:108> alias 'gcm=git checkou...
30 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:14> alias 'v=f -e "$EDITOR"'
30 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
30 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:106> [[ -z '' ]]
30 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
30 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
30 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=pyenv-lazy
30 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:48> setopt multios
30 /Users/matt/.oh-my-zsh/lib/misc.zsh:31> alias 'afind=ack -il'
30 /Users/matt/.oh-my-zsh/lib/misc.zsh:19> setopt long_list_jobs
30 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/custom/pl...
30 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:70> bindkey -M vicmd $'C-[[Z' rev...
30 /Users/matt/.oh-my-zsh/lib/history.zsh:40> setopt share_history
30 /Users/matt/.oh-my-zsh/lib/history.zsh:25> alias 'history=omz_history'
30 /Users/matt/.oh-my-zsh/lib/completion.zsh:23> zstyle ':completion:*' matcher-...
30 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
30 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
30 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:42> Z...
30 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:41> zs...
30 -antigen-parse-args:160> args[name]=''zsh-users/zsh-syntax-highlighting''
30 -antigen-parse-args:87> [[ zsh-users/zsh-autosuggestions != git://* && zsh-us...
30 -antigen-parse-args:44> [[ "$value" -regex-match "://" || "$value" -regex-mat...
30 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
30 -antigen-lock-init:6> -antigen-set-default ANTIGEN_MUTEX true
30 -antigen-lock-execute:18> antigen-add-hook antigen antigen-lock pre once
30 -antigen-interactive-mode:1> WARN '-antigen-interactive-mode: file:file:shfun...
30 -antigen-hook-handler:69> LOG 'Return from hook -antigen-load-source with 0'
30 -antigen-hook-handler:64> WARN 'Post hook:' antigen-apply-lock
30 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
30 -antigen-hook-handler:58> ret=0
30 -antigen-hook-handler:57> -antigen-hook-antigen bundle deno
30 -antigen-hook-handler:50> antigen-bundle-parallel zsh-users/zsh-syntax-highli...
30 -antigen-hook-handler:50> antigen-bundle-parallel zsh-users/zsh-autosuggestions
30 -antigen-hook-handler:50> antigen-bundle-parallel '--loc=lib'
30 -antigen-hook-handler:50> -antigen-load-source-cached /Users/matt/.antigen/bu...
30 -antigen-hook-handler:39> antigen-apply-defer
30 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
30 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-lock'
30 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached'
30 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached'
30 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-apply-lock antigen-...
30 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-source-cached'
30 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-source-cached'
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-apply mode once...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-apply mode once...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-apply mode once...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-apply mode once...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-source mo...
30 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-source mo...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply mo...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen mode onc...
30 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-en...
30 -antigen-hook-handler:7> hooks=( antigen-lock )
30 -antigen-hook-handler:1> local target=antigen-bundle args hook called
30 -antigen-hook-antigen:11> return 0
30 -antigen-hook-antigen:11> return 0
30 -antigen-hook-antigen-bundle:1> TRACE 'Called antigen-bundle with zsh-users/z...
30 -antigen-env-setup:40> -antigen-set-default _ANTIGEN_GREP_COMMAND 'GREP_OPTIO...
30 -antigen-env-setup:18> [[ ! -d /Users/matt/.antigen/bundles ]]
30 -antigen-env-setup:8> -antigen-set-default ANTIGEN_DEFAULT_REPO_URL https://g...
30 -antigen-defer-execute:6> antigen-add-hook antigen-bundle antigen-bundle-defe...
30 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
30 -antigen-cache-execute:39> antigen-add-hook antigen-bundle antigen-bundle-cac...
30 (eval):111> alias 'gignored=git ls-files -v | grep "^[[:lower:]]"'
30 (anon):828> typeset -g 'POWERLEVEL9K_CONTEXT_REMOTE_TEMPLATE=%n@%m' 'POWERLEV...
30 (anon):431> typeset -g POWERLEVEL9K_VCS_DISABLED_WORKDIR_PATTERN='~'
30 (anon):180> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_OK_VIOWR_CONTENT_EXPANSION=▶...
30 (anon):119> typeset -g POWERLEVEL9K_MULTILINE_LAST_PROMPT_SUFFIX=''
30 (anon):40> zstyle -s :omz:update frequency epoch_target
30 (anon):8> is-at-least 5.1
29 iterm2_print_state_data:7> iterm2_print_user_vars
29 is_theme:1> local base_dir=/Users/matt/.oh-my-zsh/custom
29 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
29 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
29 compinit:515> autoload -Uz _description
29 compinit:511> compdef -na _wait wait
29 compinit:511> compdef -na _vserver vserver
29 compinit:511> compdef -na _vmstat vmstat
29 compinit:511> compdef -na _visudo visudo
29 compinit:511> compdef -na _vcsh vcsh
29 compinit:511> compdef -na _uniq uniq guniq
29 compinit:511> compdef -na _terminals infocmp -value-,TERM,-default-
29 compinit:511> compdef -na _sysrc sysrc
29 compinit:511> compdef -na _strip strip
29 compinit:511> compdef -na _ss ss
29 compinit:511> compdef -na _smit smit smitty
29 compinit:511> compdef -na _slrn slrn
29 compinit:511> compdef -na _shred shred gshred
29 compinit:511> compdef -na _sbuild sbuild
29 compinit:511> compdef -na _run-help run-help
29 compinit:511> compdef -na _rsync rsync
29 compinit:511> compdef -na _qdbus qdbus
29 compinit:511> compdef -na _pscp pscp pscp.exe
29 compinit:511> compdef -na _prove prove
29 compinit:511> compdef -na _pkg5 pkg
29 compinit:511> compdef -na _patch patch gpatch
29 compinit:511> compdef -na _nmap nmap
29 compinit:511> compdef -na _mergechanges mergechanges
29 compinit:511> compdef -na _mdls mdls
29 compinit:511> compdef -na _localedef localedef
29 compinit:511> compdef -na _lha lha
29 compinit:511> compdef -na _ipset ipset
29 compinit:511> compdef -na _iostat iostat
29 compinit:511> compdef -na _head head ghead
29 compinit:511> compdef -na _gtk-launch gtk-launch
29 compinit:511> compdef -na _gradle gradle gradlew
29 compinit:511> compdef -na _gas gas
29 compinit:511> compdef -na _ffind ffind
29 compinit:511> compdef -na _deno deno
29 compinit:511> compdef -na _cp cp gcp
29 compinit:511> compdef -na _brctl brctl
29 compinit:511> compdef -na _axi-cache axi-cache
29 compinit:511> compdef -na _augeas augtool
29 compinit:508> [[ zparseopts = -[pPkK](n|) ]]
29 compinit:508> [[ yast = -[pPkK](n|) ]]
29 compinit:508> [[ yarn = -[pPkK](n|) ]]
29 compinit:508> [[ xinput = -[pPkK](n|) ]]
29 compinit:508> [[ xfig = -[pPkK](n|) ]]
29 compinit:508> [[ xcode-select = -[pPkK](n|) ]]
29 compinit:508> [[ whereis = -[pPkK](n|) ]]
29 compinit:508> [[ sshfs = -[pPkK](n|) ]]
29 compinit:508> [[ sfdx = -[pPkK](n|) ]]
29 compinit:508> [[ scala = -[pPkK](n|) ]]
29 compinit:508> [[ sbt = -[pPkK](n|) ]]
29 compinit:508> [[ popd = -[pPkK](n|) ]]
29 compinit:508> [[ open = -[pPkK](n|) ]]
29 compinit:508> [[ nkf = -[pPkK](n|) ]]
29 compinit:508> [[ mina = -[pPkK](n|) ]]
29 compinit:508> [[ mc = -[pPkK](n|) ]]
29 compinit:508> [[ lunchy = -[pPkK](n|) ]]
29 compinit:508> [[ javac = -[pPkK](n|) ]]
29 compinit:508> [[ gzip = -[pPkK](n|) ]]
29 compinit:508> [[ grep = -[pPkK](n|) ]]
29 compinit:508> [[ fstat = -[pPkK](n|) ]]
29 compinit:508> [[ figlet = -[pPkK](n|) ]]
29 compinit:508> [[ ffmpeg = -[pPkK](n|) ]]
29 compinit:508> [[ elfdump = -[pPkK](n|) ]]
29 compinit:508> [[ ecasound = -[pPkK](n|) ]]
29 compinit:508> [[ dtruss = -[pPkK](n|) ]]
29 compinit:508> [[ dpkg-cross = -[pPkK](n|) ]]
29 compinit:508> [[ dpkg-buildpackage = -[pPkK](n|) ]]
29 compinit:508> [[ dkms = -[pPkK](n|) ]]
29 compinit:508> [[ df = -[pPkK](n|) ]]
29 compinit:508> [[ dchroot-dsa = -[pPkK](n|) ]]
29 compinit:508> [[ dbus-send = -[pPkK](n|) ]]
29 compinit:508> [[ cygstart = -[pPkK](n|) ]]
29 compinit:508> [[ cut = -[pPkK](n|) ]]
29 compinit:508> [[ cssh = -[pPkK](n|) ]]
29 compinit:508> [[ cscope = -[pPkK](n|) ]]
29 compinit:508> [[ apm = -[pPkK](n|) ]]
29 compinit:508> [[ amaya = -[pPkK](n|) ]]
29 compinit:508> [[ _rclone = -[pPkK](n|) ]]
29 compinit:508> [[ _gh = -[pPkK](n|) ]]
29 compinit:508> [[ -P = -[pPkK](n|) ]]
29 compinit:508> [[ -P = -[pPkK](n|) ]]
29 compinit:506> case #compdef (#compdef)
29 compinit:506> case #autoload (#autoload)
29 compinit:506> case #autoload (#autoload)
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:505> shift _i_line
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#compdef'
29 compinit:504> _i_tag='#autoload'
29 compinit:501> ((  1 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:501> ((  0 + 0  ))
29 compinit:500> _i_name=_print
29 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tar_archive
29 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hwinfo
29 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_baudrates
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:121> shift _d_als
29 compdump:118> print -n ' 
           '
29 compdump:118> print -n ' 
           '
29 compdump:115> print -n ' _smartmontools'
29 compdump:115> print -n ' _cvsup'
29 compdump:114> ((  ! 0  ))
29 compdump:114> ((  ! 0  ))
29 compdump:113> ((  664  ))
29 compdump:113> ((  302  ))
29 compdump:113> ((  169  ))
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:95> read -rA _d_line
29 compdump:55> _d_f=*/(init|rc[0-9S]#).d/*
29 compdump:44> print -r - ''zoneadm'' ''_zoneadm''
29 compdump:44> print -r - ''mdadm'' ''_mdadm''
29 compdump:44> print -r - ''guname'' ''_uname''
29 compdump:43> _d_f=wait
29 compdump:43> _d_f=sha512sum
29 compdump:43> _d_f=isag
29 compdef:169> shift
29 compdef:163> _comps[$cmd]=_mail
29 compdef:162> [[ -z yes || -z _zargs ]]
29 compdef:162> [[ -z yes || -z _postgresql ]]
29 compdef:162> [[ -z yes || -z _pon ]]
29 compdef:162> [[ -z yes || -z _hash ]]
29 compdef:162> [[ -z yes || -z _evince ]]
29 compdef:162> [[ -z yes || -z _drill ]]
29 compdef:162> [[ -z yes || -z _defaults ]]
29 compdef:162> [[ -z yes || -z _debchange ]]
29 compdef:162> [[ -z yes || -z _dd ]]
29 compdef:162> [[ -z yes || -z _cssh ]]
29 compdef:162> [[ -z yes || -z _compress ]]
29 compdef:162> [[ -z yes || -z _chrt ]]
29 compdef:162> [[ -z yes || -z _chmod ]]
29 compdef:162> [[ -z yes || -z _cabal ]]
29 compdef:162> [[ -z yes || -z _afew ]]
29 compdef:162> [[ -z yes || -z _a2utils ]]
29 compdef:162> [[ -z yes || -z _a2ps ]]
29 compdef:159> cmd=chage
29 compdef:155> [[ gnocchi = *=* ]]
29 compdef:155> [[ figlet = *=* ]]
29 compdef:155> [[ dig = *=* ]]
29 compdef:139> case  (postpattern)
29 compdef:139> case  (postpattern)
29 compdef:139> case  (*)
29 compdef:132> [[ pidstat = -N ]]
29 compdef:132> [[ mkdir = -N ]]
29 compdef:132> [[ heat = -N ]]
29 compdef:83> case  (widgetkey)
29 compdef:81> shift
29 compdef:81> shift
29 compdef:81> shift
29 compdef:81> shift
29 compdef:81> shift
29 compdef:80> autoload -Uz _yt-dlp
29 compdef:80> autoload -Uz _xxd
29 compdef:80> autoload -Uz _trash-list
29 compdef:80> autoload -Uz _tmuxinator
29 compdef:80> autoload -Uz _snap
29 compdef:80> autoload -Uz _lzop
29 compdef:80> autoload -Uz _ispell
29 compdef:80> autoload -Uz _dumper
29 compdef:80> autoload -Uz _dpkg_source
29 compdef:80> autoload -Uz _deborphan
29 compdef:80> autoload -Uz _complete_debug
29 compdef:80> autoload -Uz _chkconfig
29 compdef:80> autoload -Uz _cal
29 compdef:80> autoload -Uz _caffeinate
29 compdef:80> autoload -Uz _bash_completions
29 compdef:80> [[ -n yes ]]
29 compdef:80> [[ -n yes ]]
29 compdef:80> [[ -n yes ]]
29 compdef:80> [[ -n yes ]]
29 compdef:49> [[ -z '' ]]
29 compdef:40> ((  ! 2  ))
29 compdef:38> shift OPTIND-1
29 compdef:38> shift OPTIND-1
29 compdef:38> shift OPTIND-1
29 compdef:38> shift OPTIND-1
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:17> new=yes
29 compdef:16> autol=yes
29 compdef:16> autol=yes
29 compdef:16> autol=yes
29 compdef:16> autol=yes
29 compdef:15> case n (n)
29 compdef:15> case n (a)
29 compdef:15> case a (a)
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:14> getopts anpPkKde opt
29 compdef:9> ((  ! 8  ))
29 compdef:9> ((  ! 8  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 4  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:9> ((  ! 3  ))
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:5> setopt extendedglob
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:4> emulate -L zsh
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:2> local -a match mbegin mend
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
29 compaudit:92> _i_exes=( /proc/87947/exe /proc/87947/object/a.out )
29 compaudit:51> ((  0  ))
29 colors:112> typeset -AHg bg bg_bold bg_no_bold
29 colors:112> typeset -AHg bg bg_bold bg_no_bold
29 antigen-lock:12> WARN 'Creating antigen-lock file at /Users/matt/.antigen/.lock'
29 antigen-ext:6> WARN '-antigen-parallel-init return code was 0'
29 antigen-ext-init:5> ((  1  ))
29 antigen-bundle-parallel-execute:21> WARN 'Bundle robbyrussell/oh-my-zsh alrea...
29 antigen-bundle-defer:2> return -1
29 antigen-bundle-defer:2> return -1
29 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( '--loc=lib' )
29 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( '--loc=lib' )
29 antigen-apply-parallel-execute:8> antigen-apply
29 antigen-apply-defer:7> LOG 'Processing deferred bundle: deno' DEFER
29 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
29 add-zsh-hook:22> local usage='Usage: add-zsh-hook hook functionnValid hooks a...
29 _zsh_highlight_load_highlighters:5> [[ -d /Users/matt/.antigen/bundles/zsh-us...
29 _zsh_highlight_bind_widgets:44> zle -C orig-s0.0000080000-r6249-menu-complete...
29 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-zle-line-fini...
29 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-bracketed-pas...
29 _zsh_highlight_bind_widgets:26> cur_widget=history-beginning-search-forward
29 _zsh_highlight_bind_widgets:3> typeset -F SECONDS
29 /usr/local/share/antigen/antigen.zsh:14> [[ '' != false ]]
29 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:21> ((  0  ))
29 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:18> setopt no_aliases no...
29 /Users/matt/.zshrc:588> group_lazy_load '. /Users/matt/.nvm/nvm.sh' nvm node npm
29 /Users/matt/.zshrc:537> alias 'gmt=git mergetool'
29 /Users/matt/.zshrc:339> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
29 /Users/matt/.zcompdump:1948> _compautos=( _call_program +X )
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:307> alias 'gupv=git pull -...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:297> alias 'gswm=git switch...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:294> alias 'gsu=git submodu...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:292> alias 'gstu=gsta --inc...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:287> alias 'gstc=git stash ...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:278> alias 'gss=git status -s'
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:273> alias 'gsd=git svn dco...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:269> alias 'grup=git remote...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:250> alias 'grbi=git rebase...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:248> alias 'grbc=git rebase...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:239> alias 'gpoat=git push ...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:238> alias 'gpf!=git push -...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:231> alias 'gmtlvim=git mer...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:215> alias 'glgg=git log --...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:136> compdef _git 'gdv=git-...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:123> alias 'gdcw=git diff -...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:90> alias 'gcan!=git commit...
29 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:63> alias 'ga=git add'
29 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
29 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=zsh-autosuggestions
29 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:75> bindkey -M viins '^?' backwar...
29 /Users/matt/.oh-my-zsh/lib/history.zsh:31> HISTSIZE=50000
29 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
29 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:68> zstyle ':completion:fasd-com...
29 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2setkeylabel=/Users/m...
29 /Users/matt/.iterm2_shell_integration.zsh:160> [[ -z 'omz_termsupport_precmd ...
29 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:15> ...
29 -antigen-parse-args:160> args[name]=''zsh-users/zsh-syntax-highlighting''
29 -antigen-load:2> typeset -A bundle
29 -antigen-load-env-cached:6> [[ plugins/deno == / ]]
29 -antigen-hook-handler:69> LOG 'Return from hook antigen with 0'
29 -antigen-hook-handler:63> hook=antigen-apply-lock
29 -antigen-hook-handler:63> hook=antigen-apply-cached
29 -antigen-hook-handler:56> WARN '-antigen-hook-antigen-bundle zsh-users/zsh-sy...
29 -antigen-hook-handler:56> WARN '-antigen-hook-antigen bundle zsh-users/zsh-sy...
29 -antigen-hook-handler:56> WARN '-antigen-hook-antigen bundle deno'
29 -antigen-hook-handler:55> [[ 1 == 0 ]]
29 -antigen-hook-handler:50> antigen-bundle-parallel deno
29 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-lock use oh-my-zsh
29 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
29 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached deno
29 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-apply-defer
29 -antigen-hook-handler:35> WARN 'Processing hooks: -antigen-load-env-cached'
29 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
29 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
29 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
29 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
29 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
29 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
29 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
29 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-env mode ...
29 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
29 -antigen-hook-handler:14> continue
29 -antigen-hook-handler:11> meta=( target antigen-bundle type replace mode repe...
29 -antigen-hook-handler:11> meta=( target -antigen-load-env type replace mode r...
29 -antigen-hook-handler:11> meta=( target -antigen-load-env mode repeat type re...
29 -antigen-hook-handler:10> hook=antigen-lock
29 -antigen-hook-handler:7> hooks=( antigen-apply-lock antigen-apply-parallel an...
29 -antigen-hook-antigen:8> ((  1  ))
29 -antigen-hook-antigen-bundle:14> [[ true == true && ! 0 == 0 ]]
29 -antigen-hook-antigen-bundle:8> -antigen-parse-args bundle zsh-users/zsh-synt...
29 -antigen-hook-antigen-bundle:1> TRACE 'Called antigen-bundle with zsh-users/z...
29 -antigen-env-setup:31> -antigen-set-default ANTIGEN_CLONE_OPTS '--single-bran...
29 -antigen-env-setup:30> -antigen-set-default ANTIGEN_CLONE_ENV 'GIT_TERMINAL_P...
29 -antigen-env-setup:11> -antigen-set-default ADOTDIR /Users/matt/.antigen
29 -antigen-cache-init:12> -antigen-set-default ANTIGEN_CACHE /Users/matt/.antig...
29 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
29 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
29 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
29 -antigen-cache-execute:33> antigen-add-hook antigen-apply antigen-apply-cache...
29 (eval):203> alias 'gunignore=git update-index --no-assume-unchanged'
29 (eval):43> alias 'gamc=git am --continue'
29 (anon):1493> typeset -g POWERLEVEL9K_TIME_VISUAL_IDENTIFIER_EXPANSION=''
29 (anon):951> typeset -g 'POWERLEVEL9K_NODEENV_LEFT_DELIMITER=' 'POWERLEVEL9K_N...
29 (anon):908> typeset -g POWERLEVEL9K_PYENV_CONTENT_EXPANSION='${P9K_CONTENT}${...
29 (anon):693> typeset -g POWERLEVEL9K_MIDNIGHT_COMMANDER_FOREGROUND=178
29 (anon):473> typeset -g POWERLEVEL9K_STATUS_OK_PIPE=true
29 (anon):168> typeset -g POWERLEVEL9K_PROMPT_CHAR_BACKGROUND=''
28 iterm2_print_state_data:6> printf '033]1337;CurrentDir=%s007' /Users/matt
28 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
28 is-at-least:23> emulate -L zsh
28 complete:3> args=( -o nospace -F _python_argcomplete gsutil )
28 compinit:516> [[ '' !=  # ]]
28 compinit:515> autoload -Uz _deb_codenames
28 compinit:511> compdef -na _twidge twidge
28 compinit:511> compdef -na _tune2fs tune2fs
28 compinit:511> compdef -na _telnet telnet
28 compinit:511> compdef -na _swaks swaks
28 compinit:511> compdef -na _stat stat gstat zstat
28 compinit:511> compdef -na _sisu sisu
28 compinit:511> compdef -na _shutdown shutdown
28 compinit:511> compdef -na _reprepro reprepro
28 compinit:511> compdef -na _pkgadd pkgadd
28 compinit:511> compdef -na _pkg-config pkg-config
28 compinit:511> compdef -na _ping ping ping6
28 compinit:511> compdef -na _pine pine pinef
28 compinit:511> compdef -na _paste paste gpaste
28 compinit:511> compdef -na _pandoc pandoc
28 compinit:511> compdef -na _limits unlimit
28 compinit:511> compdef -na _ionice ionice
28 compinit:511> compdef -na _id id gid
28 compinit:511> compdef -na _gdb gdb
28 compinit:511> compdef -na _fw_update fw_update
28 compinit:511> compdef -na _coreadm coreadm
28 compinit:511> compdef -na _cask cask
28 compinit:511> compdef -na _aws aws
28 compinit:511> compdef -na _assign -assign-parameter-
28 compinit:508> [[ zstyle = -[pPkK](n|) ]]
28 compinit:508> [[ zmv = -[pPkK](n|) ]]
28 compinit:508> [[ zmodload = -[pPkK](n|) ]]
28 compinit:508> [[ zcat = -[pPkK](n|) ]]
28 compinit:508> [[ yaourt = -[pPkK](n|) ]]
28 compinit:508> [[ xmlstarlet = -[pPkK](n|) ]]
28 compinit:508> [[ xclip = -[pPkK](n|) ]]
28 compinit:508> [[ vagrant = -[pPkK](n|) ]]
28 compinit:508> [[ talk = -[pPkK](n|) ]]
28 compinit:508> [[ redis-cli = -[pPkK](n|) ]]
28 compinit:508> [[ qiv = -[pPkK](n|) ]]
28 compinit:508> [[ portmaster = -[pPkK](n|) ]]
28 compinit:508> [[ middleman = -[pPkK](n|) ]]
28 compinit:508> [[ ln = -[pPkK](n|) ]]
28 compinit:508> [[ jobs = -[pPkK](n|) ]]
28 compinit:508> [[ jexec = -[pPkK](n|) ]]
28 compinit:508> [[ gnutls-cli = -[pPkK](n|) ]]
28 compinit:508> [[ emulate = -[pPkK](n|) ]]
28 compinit:508> [[ dpkg-repack = -[pPkK](n|) ]]
28 compinit:508> [[ dlocate = -[pPkK](n|) ]]
28 compinit:508> [[ diffstat = -[pPkK](n|) ]]
28 compinit:508> [[ dak = -[pPkK](n|) ]]
28 compinit:508> [[ curl = -[pPkK](n|) ]]
28 compinit:508> [[ csup = -[pPkK](n|) ]]
28 compinit:508> [[ command = -[pPkK](n|) ]]
28 compinit:508> [[ column = -[pPkK](n|) ]]
28 compinit:508> [[ cmp = -[pPkK](n|) ]]
28 compinit:508> [[ cat = -[pPkK](n|) ]]
28 compinit:508> [[ -brace-parameter- = -[pPkK](n|) ]]
28 compinit:506> case #autoload (#autoload)
28 compinit:506> case #autoload (#autoload)
28 compinit:506> case #autoload (#autoload)
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:505> shift _i_line
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#compdef'
28 compinit:504> _i_tag='#autoload'
28 compinit:504> _i_tag='#autoload'
28 compinit:501> ((  0 + 0  ))
28 compinit:501> ((  0 + 0  ))
28 compinit:501> ((  0 + 0  ))
28 compinit:501> ((  0 + 0  ))
28 compinit:500> _i_name=_svcprop
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:121> shift _d_als
28 compdump:118> print -n ' 
           '
28 compdump:116> ((  ! --_i && 773 > 1  ))
28 compdump:114> ((  ! 0  ))
28 compdump:113> ((  980  ))
28 compdump:113> ((  611  ))
28 compdump:97> print -r 'bindkey '''^[/''' _history-complete-older'
28 compdump:97> print -r 'bindkey '''^Xc''' _correct_word'
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:95> read -rA _d_line
28 compdump:91> _d_bks+=( _history-complete-newer )
28 compdump:90> print -r - zle -C _bash_list-choices .list-choices _bash_complet...
28 compdump:44> print -r - ''-redirect-,<,compress'' ''_compress''
28 compdump:43> _d_f=reportbug
28 compdump:43> _d_f=mlocate
28 compdump:43> _d_f=lastb
28 compdump:43> _d_f=kvno
28 compdump:43> _d_f=irssi
28 compdump:43> _d_f=gpasswd
28 compdef:169> shift
28 compdef:169> shift
28 compdef:164> _services[$cmd]=svnadmin
28 compdef:164> _services[$cmd]=mail
28 compdef:162> [[ -z yes || -z _zypper ]]
28 compdef:162> [[ -z yes || -z _xscreensaver ]]
28 compdef:162> [[ -z yes || -z _xargs ]]
28 compdef:162> [[ -z yes || -z _webbrowser ]]
28 compdef:162> [[ -z yes || -z _swanctl ]]
28 compdef:162> [[ -z yes || -z _snap ]]
28 compdef:162> [[ -z yes || -z _slrn ]]
28 compdef:162> [[ -z yes || -z _sh ]]
28 compdef:162> [[ -z yes || -z _rar ]]
28 compdef:162> [[ -z yes || -z _numfmt ]]
28 compdef:162> [[ -z yes || -z _gsettings ]]
28 compdef:162> [[ -z yes || -z _growisofs ]]
28 compdef:162> [[ -z yes || -z _dvi ]]
28 compdef:162> [[ -z yes || -z _dumper ]]
28 compdef:162> [[ -z yes || -z _dumper ]]
28 compdef:162> [[ -z yes || -z _devtodo ]]
28 compdef:162> [[ -z yes || -z _debcheckout ]]
28 compdef:162> [[ -z yes || -z _chsh ]]
28 compdef:162> [[ -z yes || -z _chsh ]]
28 compdef:162> [[ -z yes || -z _cheat ]]
28 compdef:162> [[ -z yes || -z _chcon ]]
28 compdef:162> [[ -z yes || -z _cal ]]
28 compdef:162> [[ -z yes || -z _bittorrent ]]
28 compdef:162> [[ -z yes || -z '' ]]
28 compdef:160> svc=''
28 compdef:160> svc=''
28 compdef:159> cmd=sysrc
28 compdef:155> [[ update-alternatives = *=* ]]
28 compdef:155> [[ sysrc = *=* ]]
28 compdef:155> [[ cvsup = *=* ]]
28 compdef:139> case  (pattern)
28 compdef:139> case  (*)
28 compdef:139> case  (*)
28 compdef:136> [[ pump = -P ]]
28 compdef:136> [[ ipsec = -P ]]
28 compdef:136> [[ gsum = -P ]]
28 compdef:134> [[ zf_chmod = -p ]]
28 compdef:134> [[ prun = -p ]]
28 compdef:134> [[ kitchen = -p ]]
28 compdef:134> [[ . = -p ]]
28 compdef:132> [[ tree = -N ]]
28 compdef:132> [[ tarsnap = -N ]]
28 compdef:132> [[ snap = -N ]]
28 compdef:114> [[ complete-word = menu-select ]]
28 compdef:83> case  (*)
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:81> shift
28 compdef:80> autoload -Uz _xinput
28 compdef:80> autoload -Uz _wemux
28 compdef:80> autoload -Uz _vim
28 compdef:80> autoload -Uz _trash-empty
28 compdef:80> autoload -Uz _tox
28 compdef:80> autoload -Uz _math
28 compdef:80> autoload -Uz _gsettings
28 compdef:80> autoload -Uz _growisofs
28 compdef:80> autoload -Uz _genisoimage
28 compdef:80> autoload -Uz _fortune
28 compdef:80> autoload -Uz _ethtool
28 compdef:80> autoload -Uz _dtruss
28 compdef:80> autoload -Uz _debfoster
28 compdef:80> autoload -Uz _brew_services
28 compdef:80> [[ -n yes ]]
28 compdef:80> [[ -n yes ]]
28 compdef:49> [[ -z '' ]]
28 compdef:45> [[ -z '' ]]
28 compdef:40> ((  ! 3  ))
28 compdef:38> shift OPTIND-1
28 compdef:38> shift OPTIND-1
28 compdef:38> shift OPTIND-1
28 compdef:38> shift OPTIND-1
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:17> new=yes
28 compdef:16> autol=yes
28 compdef:16> autol=yes
28 compdef:15> case n (n)
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:14> getopts anpPkKde opt
28 compdef:9> ((  ! 10  ))
28 compdef:9> ((  ! 4  ))
28 compdef:9> ((  ! 4  ))
28 compdef:9> ((  ! 4  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:9> ((  ! 3  ))
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:5> setopt extendedglob
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:4> emulate -L zsh
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:2> local -a match mbegin mend
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
28 compaudit:88> local _i_owners=u0u501
28 colors:103> typeset -AHg fg fg_bold fg_no_bold
28 antigen-ext:1> local ext=lock
28 antigen-ext-init:5> ((  1  ))
28 antigen-bundle-defer:2> return -1
28 antigen-apply-parallel-execute:7> antigen-remove-hook antigen-apply-parallel-...
28 antigen-apply-parallel-execute:1> WARN 'Parallel replace-apply' PARALLEL REPL...
28 antigen-apply-cached:26> antigen-remove-hook -antigen-load-env-cached
28 antigen-add-hook:13> [[ antigen-apply-lock:antigen-apply-parallel:antigen-app...
28 add-zsh-hook:84> ((  0 == 0  ))
28 add-zsh-hook:65> local hook=preexec_functions
28 _zsh_highlight_bind_widgets:50> zle -N overwrite-mode _zsh_highlight_widget_o...
28 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-self-insert u...
28 _zsh_highlight_bind_widgets:27> case builtin (builtin)
28 _zsh_highlight_bind_widgets:27> case builtin (builtin)
28 /usr/local/share/antigen/antigen.zsh:54> [[ '' != true ]]
28 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:80> setopt prompt_cr pro...
28 /usr/local/opt/asdf/libexec/asdf.sh:6> [ -z '' ']'
28 /Users/matt/.zshrc:356> export XML_CATALOG_FILES=/usr/local/etc/xml/catalog
28 /Users/matt/.zshrc:352> export LDFLAGS=' -L/usr/local/opt/curl/lib -L/usr/loc...
28 /Users/matt/.zcompdump:1953> zle -C _bash_list-choices .list-choices _bash_co...
28 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1787> zle -C _bash_list-choi...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:317> alias 'gams=git am --s...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:286> alias 'gstaa=git stash...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:251> alias 'grbm=git rebase...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:237> alias 'gpf=git push --...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:235> alias 'gp=git push'
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:233> alias 'gma=git merge -...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:230> alias 'gmtl=git merget...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:216> alias 'glgga=git log -...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:213> alias 'glg=git log --s...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:212> alias 'gl=git pull'
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:209> alias 'gk=gitk --all -...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:154> compdef _git 'ggf=git-...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:140> is-at-least 2.8 2.36.1
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:126> alias 'gdt=git diff-tr...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:106> alias 'gclean=git clea...
28 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:79> alias 'gbs=git bisect'
28 /Users/matt/.oh-my-zsh/plugins/fasd/fasd.plugin.zsh:15> alias 'o=a -e xdg-open'
28 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
28 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:42> ZSH_THEME_TERM_TITLE_IDLE='%n@...
28 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:41> ZSH_THEME_TERM_TAB_TITLE_IDLE=...
28 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/cache/com...
28 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:74> bindkey -M emacs '^?' backwar...
28 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:7> ((  1  ))
28 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
28 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
28 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
28 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:67> zle -C fasd-complete-d compl...
28 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:64> zstyle ':completion:fasd-com...
28 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:61> zstyle ':completion:fasd-com...
28 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
28 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:70> ...
28 -antigen-set-default:3> eval 'test -z "$ANTIGEN_PREZTO_REPO_URL" && typeset -...
28 -antigen-set-default:3> eval 'test -z "$ANTIGEN_MUTEX" && typeset -g ANTIGEN_...
28 -antigen-set-default:3> eval 'test -z "$ANTIGEN_DEFAULT_REPO_URL" && typeset ...
28 -antigen-set-default:3> eval 'test -z "$ANTIGEN_AUTO_CONFIG" && typeset -g AN...
28 -antigen-parse-args:87> [[ zsh-users/zsh-autosuggestions != git://* && zsh-us...
28 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
28 -antigen-parallel-execute:1> WARN 'Exec parallel extension' PARALLEL
28 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
28 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
28 -antigen-hook-handler:69> LOG 'Return from hook antigen with 0'
28 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
28 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
28 -antigen-hook-handler:57> -antigen-hook-antigen-bundle deno
28 -antigen-hook-handler:57> -antigen-hook-antigen-bundle '--loc=lib'
28 -antigen-hook-handler:57> -antigen-hook-antigen apply
28 -antigen-hook-handler:56> WARN '-antigen-hook-antigen-bundle zsh-users/zsh-au...
28 -antigen-hook-handler:51> WARN 'antigen-bundle-defer shortcircuited'
28 -antigen-hook-handler:51> WARN 'antigen-bundle-defer shortcircuited'
28 -antigen-hook-handler:50> antigen-bundle-defer zsh-users/zsh-syntax-highlighting
28 -antigen-hook-handler:50> -antigen-load-source-cached /Users/matt/.antigen/bu...
28 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
28 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
28 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached deno
28 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached '--loc=lib'
28 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-bundle-cached'
28 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-parallel )
28 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
28 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
28 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
28 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
28 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
28 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
28 -antigen-hook-handler:20> WARN 'Updated meta: target' -antigen-load-env mode ...
28 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
28 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
28 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
28 -antigen-hook-handler:18> meta[called]=1
28 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
28 -antigen-hook-handler:11> meta=( target antigen-apply type post mode once cal...
28 -antigen-hook-handler:11> meta=( target -antigen-load-env mode repeat type re...
28 -antigen-hook-handler:7> hooks=( -antigen-load-env-cached )
28 -antigen-hook-handler:1> local target=-antigen-load-source args hook called
28 -antigen-env-setup:43> -antigen-set-default _ANTIGEN_BUILTIN_EXTENSIONS 'lock...
28 -antigen-env-setup:24> -antigen-set-default ANTIGEN_COMPDUMP /Users/matt/.ant...
28 -antigen-cache-init:13> -antigen-set-default ANTIGEN_RSRC /Users/matt/.antige...
28 -antigen-cache-init:9> -antigen-set-default ANTIGEN_AUTO_CONFIG true
28 (eval):187> alias 'gwch=git whatchanged -p --abbrev-commit --pretty=medium'
28 (eval):44> alias 'gams=git am --skip'
28 (anon):1449> typeset -g 'POWERLEVEL9K_BATTERY_CHARGING_FOREGROUND=70' 'POWERL...
28 (anon):1167> typeset -g POWERLEVEL9K_KUBECONTEXT_SHOW_ON_COMMAND='kubectl|hel...
28 (anon):882> typeset -g POWERLEVEL9K_ANACONDA_CONTENT_EXPANSION='${${${${CONDA...
28 (anon):506> typeset -g POWERLEVEL9K_COMMAND_EXECUTION_TIME_VISUAL_IDENTIFIER_...
28 (anon):318> typeset -g POWERLEVEL9K_VCS_BRANCH_ICON=''
28 (anon):6> zmodload zsh/datetime
27 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
27 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
27 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
27 is-at-least:25> local IFS=.- min_cnt=0 ver_cnt=0 part min_ver version order
27 complete:4> zparseopts -D -a void o: A: G: W: C: F: P: S: X: a b c d e f g j ...
27 complete:3> args=( -o default -F _bq_completer bq )
27 compinit:533> zle -C reverse-menu-complete .reverse-menu-complete _main_complete
27 compinit:533> zle -C complete-word .complete-word _main_complete
27 compinit:511> compdef -na _vmctl vmctl
27 compinit:511> compdef -na _ulimit ulimit
27 compinit:511> compdef -na _todo.sh todo.sh
27 compinit:511> compdef -na _su su
27 compinit:511> compdef -na _setsid setsid
27 compinit:511> compdef -na _scselect scselect
27 compinit:511> compdef -na _rcctl rcctl
27 compinit:511> compdef -na _otool otool llvm-otool
27 compinit:511> compdef -na _osc osc
27 compinit:511> compdef -na _bison bison
27 compinit:511> compdef -na _arrays shift
27 compinit:508> [[ zsh = -[pPkK](n|) ]]
27 compinit:508> [[ zpty = -[pPkK](n|) ]]
27 compinit:508> [[ zlogin = -[pPkK](n|) ]]
27 compinit:508> [[ zle = -[pPkK](n|) ]]
27 compinit:508> [[ zgetattr = -[pPkK](n|) ]]
27 compinit:508> [[ yum = -[pPkK](n|) ]]
27 compinit:508> [[ xz = -[pPkK](n|) ]]
27 compinit:508> [[ xpdf = -[pPkK](n|) ]]
27 compinit:508> [[ xauth = -[pPkK](n|) ]]
27 compinit:508> [[ ufw = -[pPkK](n|) ]]
27 compinit:508> [[ udisksctl = -[pPkK](n|) ]]
27 compinit:508> [[ trash-put = -[pPkK](n|) ]]
27 compinit:508> [[ stdbuf = -[pPkK](n|) ]]
27 compinit:508> [[ scrub = -[pPkK](n|) ]]
27 compinit:508> [[ rsvm = -[pPkK](n|) ]]
27 compinit:508> [[ ralio = -[pPkK](n|) ]]
27 compinit:508> [[ rails = -[pPkK](n|) ]]
27 compinit:508> [[ pdf2dsc = -[pPkK](n|) ]]
27 compinit:508> [[ node = -[pPkK](n|) ]]
27 compinit:508> [[ nmcli = -[pPkK](n|) ]]
27 compinit:508> [[ mysql = -[pPkK](n|) ]]
27 compinit:508> [[ mdfind = -[pPkK](n|) ]]
27 compinit:508> [[ mattrib = -[pPkK](n|) ]]
27 compinit:508> [[ matlab = -[pPkK](n|) ]]
27 compinit:508> [[ lsattr = -[pPkK](n|) ]]
27 compinit:508> [[ jonas = -[pPkK](n|) ]]
27 compinit:508> [[ jmeter-plugins = -[pPkK](n|) ]]
27 compinit:508> [[ gsbj = -[pPkK](n|) ]]
27 compinit:508> [[ gqview = -[pPkK](n|) ]]
27 compinit:508> [[ gnupod_addsong = -[pPkK](n|) ]]
27 compinit:508> [[ gcc = -[pPkK](n|) ]]
27 compinit:508> [[ fs_usage = -[pPkK](n|) ]]
27 compinit:508> [[ fortune = -[pPkK](n|) ]]
27 compinit:508> [[ espeak = -[pPkK](n|) ]]
27 compinit:508> [[ epsffit = -[pPkK](n|) ]]
27 compinit:508> [[ eog = -[pPkK](n|) ]]
27 compinit:508> [[ ed = -[pPkK](n|) ]]
27 compinit:508> [[ du = -[pPkK](n|) ]]
27 compinit:508> [[ dpkg-source = -[pPkK](n|) ]]
27 compinit:508> [[ dpkg = -[pPkK](n|) ]]
27 compinit:508> [[ dpatch-edit-patch = -[pPkK](n|) ]]
27 compinit:508> [[ docker-compose = -[pPkK](n|) ]]
27 compinit:508> [[ dmesg = -[pPkK](n|) ]]
27 compinit:508> [[ disown = -[pPkK](n|) ]]
27 compinit:508> [[ dirs = -[pPkK](n|) ]]
27 compinit:508> [[ dig = -[pPkK](n|) ]]
27 compinit:508> [[ diff3 = -[pPkK](n|) ]]
27 compinit:508> [[ dconf = -[pPkK](n|) ]]
27 compinit:508> [[ darcs = -[pPkK](n|) ]]
27 compinit:508> [[ cvsup = -[pPkK](n|) ]]
27 compinit:508> [[ cu = -[pPkK](n|) ]]
27 compinit:508> [[ crontab = -[pPkK](n|) ]]
27 compinit:508> [[ cpupower = -[pPkK](n|) ]]
27 compinit:508> [[ cplay = -[pPkK](n|) ]]
27 compinit:508> [[ cpio = -[pPkK](n|) ]]
27 compinit:508> [[ compress = -[pPkK](n|) ]]
27 compinit:508> [[ compdef = -[pPkK](n|) ]]
27 compinit:508> [[ compadd = -[pPkK](n|) ]]
27 compinit:508> [[ comm = -[pPkK](n|) ]]
27 compinit:508> [[ clusterdb = -[pPkK](n|) ]]
27 compinit:508> [[ ccal = -[pPkK](n|) ]]
27 compinit:508> [[ btdownloadcurses = -[pPkK](n|) ]]
27 compinit:508> [[ asdf = -[pPkK](n|) ]]
27 compinit:508> [[ alias = -[pPkK](n|) ]]
27 compinit:508> [[ -value-,DISPLAY,-default- = -[pPkK](n|) ]]
27 compinit:508> [[ -tilde- = -[pPkK](n|) ]]
27 compinit:508> [[ -p = -[pPkK](n|) ]]
27 compinit:508> [[ -k = -[pPkK](n|) ]]
27 compinit:508> [[ -P = -[pPkK](n|) ]]
27 compinit:508> [[ -P = -[pPkK](n|) ]]
27 compinit:506> case #compdef (#compdef)
27 compinit:506> case #compdef (#compdef)
27 compinit:506> case #compdef (#compdef)
27 compinit:506> case #autoload (#autoload)
27 compinit:506> case #autoload (#autoload)
27 compinit:506> case #autoload (#autoload)
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:505> shift _i_line
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#compdef'
27 compinit:504> _i_tag='#autoload'
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:501> ((  0 + 0  ))
27 compinit:500> _i_name=_selinux_users
27 compinit:500> _i_name=_requested
27 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xmlstarlet
27 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_requested
27 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_printers
27 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
27 compinit:473> autoload -Uz compdump compinstall
27 compinit:473> autoload -Uz compdump compinstall
27 compinit:73> typeset _i_dumpfile _i_files _i_line _i_done _i_dir _i_autodump=1
27 compinit:73> typeset _i_dumpfile _i_files _i_line _i_done _i_dir _i_autodump=1
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:121> shift _d_als
27 compdump:118> print -n ' 
           '
27 compdump:118> print -n ' 
           '
27 compdump:117> _i=5
27 compdump:114> ((  ! 0  ))
27 compdump:114> ((  ! 0  ))
27 compdump:114> ((  ! 0  ))
27 compdump:114> ((  ! 0  ))
27 compdump:114> ((  ! 0  ))
27 compdump:113> ((  1025  ))
27 compdump:113> ((  370  ))
27 compdump:113> ((  290  ))
27 compdump:97> print -r 'bindkey '''^X~''' _bash_list-choices'
27 compdump:97> print -r 'bindkey '''^Xt''' _complete_tag'
27 compdump:97> print -r 'bindkey '''^Xh''' _complete_help'
27 compdump:97> print -r 'bindkey '''^Xe''' _expand_word'
27 compdump:97> print -r 'bindkey '''^X?''' _complete_debug'
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:95> read -rA _d_line
27 compdump:81> _d_bks=( )
27 compdump:50> print -r - ''-redirect-,<,bunzip2'' ''bunzip2''
27 compdump:43> _d_f=makeinfo
27 compdump:43> _d_f=cygstart.exe
27 compdef:169> shift
27 compdef:164> _services[$cmd]=yaourt
27 compdef:162> [[ -z yes || -z _xloadimage ]]
27 compdef:162> [[ -z yes || -z _users ]]
27 compdef:162> [[ -z yes || -z _trash-list ]]
27 compdef:162> [[ -z yes || -z _trash-empty ]]
27 compdef:162> [[ -z yes || -z _texinfo ]]
27 compdef:162> [[ -z yes || -z _protoc ]]
27 compdef:162> [[ -z yes || -z _pon ]]
27 compdef:162> [[ -z yes || -z _mpv ]]
27 compdef:162> [[ -z yes || -z _md5sum ]]
27 compdef:162> [[ -z yes || -z _math ]]
27 compdef:162> [[ -z yes || -z _lp ]]
27 compdef:162> [[ -z yes || -z _ldconfig ]]
27 compdef:162> [[ -z yes || -z _helm ]]
27 compdef:162> [[ -z yes || -z _guilt ]]
27 compdef:162> [[ -z yes || -z _growisofs ]]
27 compdef:162> [[ -z yes || -z _exec ]]
27 compdef:162> [[ -z yes || -z _ethtool ]]
27 compdef:162> [[ -z yes || -z _entr ]]
27 compdef:162> [[ -z yes || -z _dumpadm ]]
27 compdef:162> [[ -z yes || -z _dsh ]]
27 compdef:162> [[ -z yes || -z _debsign ]]
27 compdef:162> [[ -z yes || -z _dd ]]
27 compdef:162> [[ -z yes || -z _dcut ]]
27 compdef:162> [[ -z yes || -z _concourse ]]
27 compdef:162> [[ -z yes || -z _cksum ]]
27 compdef:162> [[ -z yes || -z _chown ]]
27 compdef:162> [[ -z yes || -z _chown ]]
27 compdef:162> [[ -z yes || -z _chkconfig ]]
27 compdef:162> [[ -z yes || -z _chflags ]]
27 compdef:162> [[ -z yes || -z _cdrecord ]]
27 compdef:162> [[ -z yes || -z _cdrecord ]]
27 compdef:162> [[ -z yes || -z _cdrdao ]]
27 compdef:162> [[ -z yes || -z _cdcd ]]
27 compdef:162> [[ -z yes || -z _cal ]]
27 compdef:162> [[ -z yes || -z _caffeinate ]]
27 compdef:162> [[ -z yes || -z _bzr ]]
27 compdef:160> svc=''
27 compdef:159> cmd=zmodload
27 compdef:159> cmd=urxvt256c-mlc
27 compdef:159> cmd=native2ascii
27 compdef:159> cmd=cdc
27 compdef:155> [[ xautolock = *=* ]]
27 compdef:155> [[ printenv = *=* ]]
27 compdef:139> case  (*)
27 compdef:139> case  (*)
27 compdef:136> [[ kitchen = -P ]]
27 compdef:136> [[ arp = -P ]]
27 compdef:134> [[ smbclient = -p ]]
27 compdef:132> [[ zpty = -N ]]
27 compdef:132> [[ thor = -N ]]
27 compdef:132> [[ tcp_open = -N ]]
27 compdef:132> [[ rake = -N ]]
27 compdef:132> [[ ltrace = -N ]]
27 compdef:132> [[ gsettings = -N ]]
27 compdef:132> [[ gsbj = -N ]]
27 compdef:132> [[ debchange = -N ]]
27 compdef:132> [[ acpi = -N ]]
27 compdef:131> ((  17  ))
27 compdef:131> ((  1  ))
27 compdef:83> case  (widgetkey)
27 compdef:83> case  (widgetkey)
27 compdef:83> case  (key)
27 compdef:83> case  (*)
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:81> shift
27 compdef:80> autoload -Uz _zparseopts
27 compdef:80> autoload -Uz _tmuxp
27 compdef:80> autoload -Uz _ri
27 compdef:80> autoload -Uz _hledger
27 compdef:80> autoload -Uz _gstat
27 compdef:80> autoload -Uz _expand_alias
27 compdef:80> autoload -Uz _exec
27 compdef:80> autoload -Uz _evince
27 compdef:80> autoload -Uz _dvi
27 compdef:80> autoload -Uz _dumpadm
27 compdef:80> autoload -Uz _dsh
27 compdef:80> autoload -Uz _defaults
27 compdef:80> autoload -Uz _debuild
27 compdef:80> autoload -Uz _debcheckout
27 compdef:80> autoload -Uz _debchange
27 compdef:80> autoload -Uz _curl
27 compdef:80> autoload -Uz _chsh
27 compdef:80> autoload -Uz _chown
27 compdef:80> autoload -Uz _chcon
27 compdef:80> autoload -Uz _chattr
27 compdef:80> autoload -Uz _cdrdao
27 compdef:80> autoload -Uz _cdr
27 compdef:80> autoload -Uz _cdcd
27 compdef:80> autoload -Uz _cabal
27 compdef:80> autoload -Uz _bzr
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:80> [[ -n yes ]]
27 compdef:79> func=_setfacl
27 compdef:49> [[ _pkginfo = *=* ]]
27 compdef:49> [[ _last = *=* ]]
27 compdef:45> [[ -z '' ]]
27 compdef:45> [[ -z '' ]]
27 compdef:40> ((  ! 2  ))
27 compdef:40> ((  ! 2  ))
27 compdef:38> shift OPTIND-1
27 compdef:38> shift OPTIND-1
27 compdef:38> shift OPTIND-1
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:17> new=yes
27 compdef:16> autol=yes
27 compdef:16> autol=yes
27 compdef:16> autol=yes
27 compdef:15> case a (a)
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:14> getopts anpPkKde opt
27 compdef:9> ((  ! 11  ))
27 compdef:9> ((  ! 5  ))
27 compdef:9> ((  ! 5  ))
27 compdef:9> ((  ! 4  ))
27 compdef:9> ((  ! 4  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 3  ))
27 compdef:9> ((  ! 2  ))
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:5> setopt extendedglob
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:4> emulate -L zsh
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:2> local -a match mbegin mend
27 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
27 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
27 compdef:1> local opt autol type func delete eval new i ret=0 cmd svc
27 compaudit:88> local _i_owners=u0u501
27 compaudit:84> [[ ign == use ]]
27 colors:77> color[${color[$k]}]=43
27 antigen-ext:9> -antigen-parallel-execute
27 antigen-ext:8> LOG 'LOADED EXTENSION parallel' EXT
27 antigen-ext:8> LOG 'LOADED EXTENSION lock' EXT
27 antigen-ext:6> WARN '-antigen-defer-init return code was 0'
27 antigen-ext:5> local ret=0
27 antigen-ext:4> eval -antigen-lock-init
27 antigen-ext-init:5> antigen-ext cache
27 antigen-bundle:2> return 0
27 antigen-bundle-parallel:1> TRACE 'antigen-bundle-parallel: deno' PARALLEL
27 antigen-bundle-parallel-execute:41> antigen-bundle zsh-users/zsh-autosuggestions
27 antigen-bundle-parallel-execute:11> -antigen-parse-args bundle zsh-users/zsh-...
27 antigen-bundle-parallel-execute:5> WARN 'Gonna install in parallel 4 bundles....
27 antigen-bundle-defer:2> return -1
27 antigen-bundle-cached:1> _ZCACHE_CAPTURE_BUNDLE+=( deno )
27 antigen-apply-parallel-execute:4> antigen-bundle-parallel-execute
27 antigen-apply-defer:7> LOG 'Processing deferred bundle: zsh-users/zsh-autosug...
27 antigen-apply-defer:7> LOG 'Processing deferred bundle: --loc=lib' DEFER
27 antigen-apply-defer:1> WARN 'Defer pre-apply' DEFER PRE-APPLY
27 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-source ...
27 antigen-add-hook:3> ((  ! 1  ))
27 antigen-add-hook:3> ((  ! 1  ))
27 antigen-add-hook:3> ((  ! 1  ))
27 add-zsh-hook:66> local fn=_fasd_preexec
27 add-zle-hook-widget:99> extant_hooks+=( 1:_zsh_highlight__zle-line-pre-redraw )
27 add-zle-hook-widget:82> zstyle -g extant_hooks zle-line-pre-redraw widgets
27 add-zle-hook-widget:71> [[ _zsh_highlight__zle-line-finish = zle-line-finish ]]
27 add-zle-hook-widget:28> '(anon)' zle-line-pre-redraw _zsh_highlight__zle-line...
27 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-zle-line-init...
27 _zsh_highlight_bind_widgets:39> zle -N orig-s0.0000080000-r6249-edit-command-...
27 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_main_complete...
27 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:80> ((  0  ))
27 /Users/matt/.zshrc:587> export NVM_DIR=/Users/matt/.nvm
27 /Users/matt/.zshrc:234> export _CE_M=''
27 /Users/matt/.zshrc:159> export HOMEBREW_AUTO_UPDATE_SECS=86400
27 /Users/matt/.zshrc:155> export THEOS_DEVICE_PORT=2222
27 /Users/matt/.zcompdump:2202> autoload -Uz +X _call_program
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:316> alias 'gamc=git am --c...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:308> alias 'gupa=git pull -...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:306> alias 'gup=git pull --...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:296> alias 'gswc=git switch...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:295> alias 'gsw=git switch'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:293> alias 'gstall=git stas...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:289> alias 'gstl=git stash ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:288> alias 'gstd=git stash ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:274> alias 'gsh=git show'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:272> alias 'gsb=git status ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:261> alias 'grmv=git remote...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:257> alias 'grhh=git reset ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:256> alias 'grh=git reset'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:255> alias 'grev=git revert'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:254> alias 'grbs=git rebase...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:249> alias 'grbd=git rebase...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:247> alias 'grba=git rebase...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:246> alias 'grb=git rebase'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:240> alias 'gpr=git pull --...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:236> alias 'gpd=git push --...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:228> alias 'gm=git merge'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:145> alias 'gfg=git ls-file...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:133> compdef _git 'gdnolock...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:125> alias 'gds=git diff --...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:119> alias 'gcssm=git commi...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:107> alias 'gpristine=git r...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:103> compdef _git 'gccd=git...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:89> alias 'gca!=git commit ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:86> alias 'gc!=git commit -...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:85> alias 'gc=git commit -v'
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:83> alias 'gbss=git bisect ...
27 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:69> alias 'gapt=git apply -...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:165> config_file=/Users/matt/.oh-my-zsh/c...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:156> [[ -f /Users/matt/.oh-my-zsh/custom/...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
27 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:90> is_plugin /Users/matt/.oh-my-zsh zshfl
27 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/custom/pl...
27 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:108> bindkey -s 'el' 'lsn'
27 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:95> bindkey -M vicmd '^[[3;5~' ki...
27 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:81> bindkey -M vicmd $'C-[[3~' de...
27 /Users/matt/.oh-my-zsh/lib/completion.zsh:61> [[ false != false ]]
27 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
27 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:65> zstyle ':completion:fasd-com...
27 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2getvar=/Users/matt/....
27 /Users/matt/.antigen/init.zsh:75> typeset -gaU _ANTIGEN_BUNDLE_RECORD
27 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
27 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /us...
27 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
27 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:61> [[...
27 -antigen-use-oh-my-zsh:9> antigen-bundle '--loc=lib'
27 -antigen-set-default:3> eval 'test -z "$ANTIGEN_CACHE" && typeset -g ANTIGEN_...
27 -antigen-set-default:2> local arg_value=https://github.com/robbyrussell/oh-my...
27 -antigen-parse-args:160> args[name]=''zsh-users/zsh-autosuggestions''
27 -antigen-parse-args:69> [[ https://github.com/robbyrussell/oh-my-zsh.git != *...
27 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--url | --loc...
27 -antigen-parse-args:1> local argkey key value index=0 args
27 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
27 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
27 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
27 -antigen-hook-handler:51> WARN 'antigen-bundle-defer shortcircuited'
27 -antigen-hook-handler:50> antigen-apply-parallel-execute
27 -antigen-hook-handler:48> ((  1  ))
27 -antigen-hook-handler:44> local replace_hook=0 ret=0
27 -antigen-hook-handler:44> local replace_hook=0 ret=0
27 -antigen-hook-handler:39> antigen-lock use oh-my-zsh
27 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached zsh-users/zs...
27 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached deno
27 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached '--loc=lib'
27 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-bundle-cached '--loc=lib'
27 -antigen-hook-handler:38> WARN 'Pre hook:' antigen-apply-parallel
27 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-lock'
27 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-lock'
27 -antigen-hook-handler:35> WARN 'Processing hooks: antigen-lock'
27 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-parallel )
27 -antigen-hook-handler:24> pre_hooks+=( antigen-lock )
27 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
27 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
27 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
27 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
27 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
27 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-apply...
27 -antigen-hook-handler:11> meta=( target -antigen-load-source mode repeat type...
27 -antigen-hook-handler:11> meta=( target -antigen-load-source mode repeat type...
27 -antigen-hook-handler:7> hooks=( antigen-bundle-defer antigen-bundle-cached )
27 -antigen-hook-handler:7> hooks=( antigen-bundle-defer antigen-bundle-cached )
27 -antigen-hook-handler:7> hooks=( antigen-bundle-cached antigen-bundle-parallel )
27 -antigen-hook-antigen-bundle:8> -antigen-parse-args bundle deno
27 -antigen-hook-antigen-bundle:7> typeset -A bundle
27 -antigen-env-setup:32> -antigen-set-default ANTIGEN_SUBMODULE_OPTS '--recursi...
27 -antigen-env-setup:25> -antigen-set-default ANTIGEN_COMPINIT_OPTS -i
27 -antigen-env-setup:15> -antigen-set-default ANTIGEN_BUNDLES /Users/matt/.anti...
27 -antigen-cache-generate:64> rsrc=/Users/matt/.zshrc
27 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
27 -antigen-cache-generate:1> local -aU _fpath _PATH _sources
27 (eval):176> alias 'gswd=git switch $(git_develop_branch)'
27 (eval):106> alias 'ggpur=ggu'
27 (eval):83> alias 'gcount=git shortlog -sn'
27 (eval):77> alias 'gclean=git clean -id'
27 (anon):1453> typeset -g POWERLEVEL9K_BATTERY_STAGES=( '%K{232}▁' '%K{232}▂' '...
27 (anon):1431> typeset -g POWERLEVEL9K_IP_CONTENT_EXPANSION='${P9K_IP_RX_RATE:+...
27 (anon):1332> typeset -g POWERLEVEL9K_GCLOUD_COMPLETE_CONTENT_EXPANSION='${P9K...
27 (anon):1288> typeset -g POWERLEVEL9K_AWS_EB_ENV_FOREGROUND=70
27 (anon):1059> typeset -g POWERLEVEL9K_LUAENV_PROMPT_ALWAYS_SHOW=false
27 (anon):666> typeset -g POWERLEVEL9K_NORDVPN_FOREGROUND=39
27 (anon):488> typeset -g POWERLEVEL9K_STATUS_ERROR_SIGNAL_VISUAL_IDENTIFIER_EXP...
27 (anon):187> typeset -g 'POWERLEVEL9K_PROMPT_CHAR_LEFT_LEFT_WHITESPACE=' 'POWE...
27 (anon):185> typeset -g POWERLEVEL9K_PROMPT_CHAR_LEFT_PROMPT_FIRST_SEGMENT_STA...
27 (anon):183> typeset -g POWERLEVEL9K_PROMPT_CHAR_LEFT_PROMPT_LAST_SEGMENT_END_...
27 (anon):156> typeset -g POWERLEVEL9K_RIGHT_PROMPT_LAST_SEGMENT_END_SYMBOL=''
27 (anon):3> local epoch_target mtime option LAST_EPOCH
26 p10k:1> [[ 1 != 1 || reload != finalize ]]
26 is_plugin:2> local name=fasd
26 is-at-least:49> ((  ++min_cnt > 2  ))
26 is-at-least:23> emulate -L zsh
26 is-at-least:23> emulate -L zsh
26 is-at-least:23> emulate -L zsh
26 group_lazy_load:4> cmd=nvm
26 complete:8> [[ -n '' ]]
26 complete:4> zparseopts -D -a void o: A: G: W: C: F: P: S: X: a b c d e f g j ...
26 complete:1> emulate -L zsh
26 compinit:547> autoload -Uz compinit compaudit
26 compinit:516> [[ '' !=  # ]]
26 compinit:515> autoload -Uz _umountable
26 compinit:511> compdef -na _trap trap
26 compinit:511> compdef -na _tac tac gtac
26 compinit:511> compdef -na _split split gsplit
26 compinit:511> compdef -na _parameter -parameter-
26 compinit:511> compdef -na _npm npm
26 compinit:508> [[ zsh-mime-handler = -[pPkK](n|) ]]
26 compinit:508> [[ zpool = -[pPkK](n|) ]]
26 compinit:508> [[ zip = -[pPkK](n|) ]]
26 compinit:508> [[ ypcat = -[pPkK](n|) ]]
26 compinit:508> [[ xsel = -[pPkK](n|) ]]
26 compinit:508> [[ xrandr = -[pPkK](n|) ]]
26 compinit:508> [[ wipefs = -[pPkK](n|) ]]
26 compinit:508> [[ wanna-build = -[pPkK](n|) ]]
26 compinit:508> [[ wajig = -[pPkK](n|) ]]
26 compinit:508> [[ virsh = -[pPkK](n|) ]]
26 compinit:508> [[ unfunction = -[pPkK](n|) ]]
26 compinit:508> [[ trash-restore = -[pPkK](n|) ]]
26 compinit:508> [[ teamocil = -[pPkK](n|) ]]
26 compinit:508> [[ sw_vers = -[pPkK](n|) ]]
26 compinit:508> [[ surfraw = -[pPkK](n|) ]]
26 compinit:508> [[ subliminal = -[pPkK](n|) ]]
26 compinit:508> [[ subl = -[pPkK](n|) ]]
26 compinit:508> [[ showoff = -[pPkK](n|) ]]
26 compinit:508> [[ setup.py = -[pPkK](n|) ]]
26 compinit:508> [[ sccs = -[pPkK](n|) ]]
26 compinit:508> [[ rslsync = -[pPkK](n|) ]]
26 compinit:508> [[ rpm = -[pPkK](n|) ]]
26 compinit:508> [[ pygmentize = -[pPkK](n|) ]]
26 compinit:508> [[ port = -[pPkK](n|) ]]
26 compinit:508> [[ pon = -[pPkK](n|) ]]
26 compinit:508> [[ periscope = -[pPkK](n|) ]]
26 compinit:508> [[ perf = -[pPkK](n|) ]]
26 compinit:508> [[ patool = -[pPkK](n|) ]]
26 compinit:508> [[ odmget = -[pPkK](n|) ]]
26 compinit:508> [[ nl = -[pPkK](n|) ]]
26 compinit:508> [[ ninja = -[pPkK](n|) ]]
26 compinit:508> [[ nft = -[pPkK](n|) ]]
26 compinit:508> [[ networksetup = -[pPkK](n|) ]]
26 compinit:508> [[ nanoc = -[pPkK](n|) ]]
26 compinit:508> [[ nano = -[pPkK](n|) ]]
26 compinit:508> [[ mvn = -[pPkK](n|) ]]
26 compinit:508> [[ moosic = -[pPkK](n|) ]]
26 compinit:508> [[ mondoarchive = -[pPkK](n|) ]]
26 compinit:508> [[ mix = -[pPkK](n|) ]]
26 compinit:508> [[ mdadm = -[pPkK](n|) ]]
26 compinit:508> [[ ls = -[pPkK](n|) ]]
26 compinit:508> [[ losetup = -[pPkK](n|) ]]
26 compinit:508> [[ links = -[pPkK](n|) ]]
26 compinit:508> [[ lighty-enable-mod = -[pPkK](n|) ]]
26 compinit:508> [[ iwconfig = -[pPkK](n|) ]]
26 compinit:508> [[ info = -[pPkK](n|) ]]
26 compinit:508> [[ include-what-you-use = -[pPkK](n|) ]]
26 compinit:508> [[ iconvconfig = -[pPkK](n|) ]]
26 compinit:508> [[ ibus = -[pPkK](n|) ]]
26 compinit:508> [[ heroku = -[pPkK](n|) ]]
26 compinit:508> [[ gv = -[pPkK](n|) ]]
26 compinit:508> [[ gpg = -[pPkK](n|) ]]
26 compinit:508> [[ git-flow = -[pPkK](n|) ]]
26 compinit:508> [[ git = -[pPkK](n|) ]]
26 compinit:508> [[ gist = -[pPkK](n|) ]]
26 compinit:508> [[ getmail = -[pPkK](n|) ]]
26 compinit:508> [[ getclip = -[pPkK](n|) ]]
26 compinit:508> [[ geany = -[pPkK](n|) ]]
26 compinit:508> [[ fusermount = -[pPkK](n|) ]]
26 compinit:508> [[ ftp = -[pPkK](n|) ]]
26 compinit:508> [[ flex = -[pPkK](n|) ]]
26 compinit:508> [[ fc = -[pPkK](n|) ]]
26 compinit:508> [[ emulator = -[pPkK](n|) ]]
26 compinit:508> [[ dos2unix = -[pPkK](n|) ]]
26 compinit:508> [[ dnf = -[pPkK](n|) ]]
26 compinit:508> [[ dircmp = -[pPkK](n|) ]]
26 compinit:508> [[ dict = -[pPkK](n|) ]]
26 compinit:508> [[ dhcpinfo = -[pPkK](n|) ]]
26 compinit:508> [[ deno = -[pPkK](n|) ]]
26 compinit:508> [[ date = -[pPkK](n|) ]]
26 compinit:508> [[ cygserver = -[pPkK](n|) ]]
26 compinit:508> [[ code = -[pPkK](n|) ]]
26 compinit:508> [[ cmake = -[pPkK](n|) ]]
26 compinit:508> [[ chromium = -[pPkK](n|) ]]
26 compinit:508> [[ builtin = -[pPkK](n|) ]]
26 compinit:508> [[ bug = -[pPkK](n|) ]]
26 compinit:508> [[ bsdinstall = -[pPkK](n|) ]]
26 compinit:508> [[ bpython = -[pPkK](n|) ]]
26 compinit:508> [[ awk = -[pPkK](n|) ]]
26 compinit:508> [[ avahi-browse = -[pPkK](n|) ]]
26 compinit:508> [[ asciidoctor = -[pPkK](n|) ]]
26 compinit:508> [[ apt = -[pPkK](n|) ]]
26 compinit:508> [[ apachectl = -[pPkK](n|) ]]
26 compinit:508> [[ antiword = -[pPkK](n|) ]]
26 compinit:508> [[ afew = -[pPkK](n|) ]]
26 compinit:508> [[ add-zsh-hook = -[pPkK](n|) ]]
26 compinit:508> [[ adb = -[pPkK](n|) ]]
26 compinit:508> [[ aap = -[pPkK](n|) ]]
26 compinit:508> [[ -value-,PROMPT,-default- = -[pPkK](n|) ]]
26 compinit:508> [[ -redirect-,-default-,-default- = -[pPkK](n|) ]]
26 compinit:508> [[ -condition- = -[pPkK](n|) ]]
26 compinit:506> case #compdef (#compdef)
26 compinit:506> case #compdef (#compdef)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:506> case #autoload (#autoload)
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:505> shift _i_line
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#compdef'
26 compinit:504> _i_tag='#autoload'
26 compinit:504> _i_tag='#autoload'
26 compinit:504> _i_tag='#autoload'
26 compinit:504> _i_tag='#autoload'
26 compinit:504> _i_tag='#autoload'
26 compinit:501> ((  1 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:501> ((  0 + 0  ))
26 compinit:500> _i_name=_portsnap
26 compinit:500> _i_name=_jobs_fg
26 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zsh
26 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cdr
26 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_acroread
26 compinit:497> [[ /Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy = . ]]
26 compinit:479> [[ -f '/Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1' ]]
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:121> shift _d_als
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:118> print -n ' 
           '
26 compdump:117> _i=5
26 compdump:115> print -n ' _stgit'
26 compdump:115> print -n ' _procstat'
26 compdump:115> print -n ' _install'
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:114> ((  ! 0  ))
26 compdump:113> ((  1012  ))
26 compdump:113> ((  709  ))
26 compdump:113> ((  144  ))
26 compdump:97> print -r 'bindkey '''^[,''' _history-complete-newer'
26 compdump:97> print -r 'bindkey '''^Xn''' _next_tags'
26 compdump:97> print -r 'bindkey '''^Xm''' _most_recent_file'
26 compdump:97> print -r 'bindkey '''^Xd''' _list_expansions'
26 compdump:97> print -r 'bindkey '''^Xa''' _expand_alias'
26 compdump:97> print -r 'bindkey '''^XC''' _correct_filename'
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:95> read -rA _d_line
26 compdump:90> print -r - zle -C _history-complete-older .complete-word _histor...
26 compdump:85> [[ end-of-buffer-or-history = _* ]]
26 compdef:169> shift
26 compdef:169> shift
26 compdef:169> shift
26 compdef:164> _services[$cmd]=gunzip
26 compdef:162> [[ -z yes || -z _xdvi ]]
26 compdef:162> [[ -z yes || -z _xautolock ]]
26 compdef:162> [[ -z yes || -z _typeset ]]
26 compdef:162> [[ -z yes || -z _tpb ]]
26 compdef:162> [[ -z yes || -z _tox ]]
26 compdef:162> [[ -z yes || -z _tmuxinator ]]
26 compdef:162> [[ -z yes || -z _tla ]]
26 compdef:162> [[ -z yes || -z _sysstat ]]
26 compdef:162> [[ -z yes || -z _sysrc ]]
26 compdef:162> [[ -z yes || -z _scala ]]
26 compdef:162> [[ -z yes || -z _route ]]
26 compdef:162> [[ -z yes || -z _ri ]]
26 compdef:162> [[ -z yes || -z _readshortcut ]]
26 compdef:162> [[ -z yes || -z _pfexec ]]
26 compdef:162> [[ -z yes || -z _lighttpd ]]
26 compdef:162> [[ -z yes || -z _java ]]
26 compdef:162> [[ -z yes || -z _java ]]
26 compdef:162> [[ -z yes || -z _hosts ]]
26 compdef:162> [[ -z yes || -z _hosts ]]
26 compdef:162> [[ -z yes || -z _grep ]]
26 compdef:162> [[ -z yes || -z _gcc ]]
26 compdef:162> [[ -z yes || -z _figlet ]]
26 compdef:162> [[ -z yes || -z _enscript ]]
26 compdef:162> [[ -z yes || -z _dvi ]]
26 compdef:162> [[ -z yes || -z _dput ]]
26 compdef:162> [[ -z yes || -z _directory_stack ]]
26 compdef:162> [[ -z yes || -z _dir_list ]]
26 compdef:162> [[ -z yes || -z _default ]]
26 compdef:162> [[ -z yes || -z _deborphan ]]
26 compdef:162> [[ -z yes || -z _debfoster ]]
26 compdef:162> [[ -z yes || -z _cvsup ]]
26 compdef:162> [[ -z yes || -z _curl ]]
26 compdef:162> [[ -z yes || -z _cdr ]]
26 compdef:162> [[ -z yes || -z _cdbs-edit-patch ]]
26 compdef:160> svc=''
26 compdef:159> cmd=dmake
26 compdef:155> [[ sccs = *=* ]]
26 compdef:155> [[ git-pulls = *=* ]]
26 compdef:155> [[ dvicopy = *=* ]]
26 compdef:139> case  (postpattern)
26 compdef:139> case  (postpattern)
26 compdef:139> case  (*)
26 compdef:134> [[ rcctl = -p ]]
26 compdef:134> [[ concourse = -p ]]
26 compdef:132> [[ yt-dlp = -N ]]
26 compdef:132> [[ xdpyinfo = -N ]]
26 compdef:132> [[ sccs = -N ]]
26 compdef:132> [[ rubocop = -N ]]
26 compdef:132> [[ popd = -N ]]
26 compdef:132> [[ nl = -N ]]
26 compdef:132> [[ mina = -N ]]
26 compdef:132> [[ lsvg = -N ]]
26 compdef:132> [[ kvno = -N ]]
26 compdef:132> [[ jq = -N ]]
26 compdef:132> [[ gstat = -N ]]
26 compdef:132> [[ debsign = -N ]]
26 compdef:132> [[ chsh = -N ]]
26 compdef:132> [[ cabal = -N ]]
26 compdef:132> [[ atrm = -N ]]
26 compdef:132> [[ a2ps = -N ]]
26 compdef:131> ((  12  ))
26 compdef:131> ((  11  ))
26 compdef:131> ((  7  ))
26 compdef:131> ((  3  ))
26 compdef:131> ((  1  ))
26 compdef:114> [[ list-choices = menu-select ]]
26 compdef:114> [[ complete-word = menu-select ]]
26 compdef:114> [[ complete-word = menu-select ]]
26 compdef:92> [[ .complete-word = .menu-select ]]
26 compdef:91> [[ complete-word = .* ]]
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:81> shift
26 compdef:80> autoload -Uz _zypper
26 compdef:80> autoload -Uz _yast
26 compdef:80> autoload -Uz _yadm
26 compdef:80> autoload -Uz _wiggle
26 compdef:80> autoload -Uz _toilet
26 compdef:80> autoload -Uz _stow
26 compdef:80> autoload -Uz _restic
26 compdef:80> autoload -Uz _ralio
26 compdef:80> autoload -Uz _rake
26 compdef:80> autoload -Uz _open
26 compdef:80> autoload -Uz _mdadm
26 compdef:80> autoload -Uz _ltrace
26 compdef:80> autoload -Uz _jls
26 compdef:80> autoload -Uz _expand_word
26 compdef:80> autoload -Uz _enscript
26 compdef:80> autoload -Uz _drill
26 compdef:80> autoload -Uz _dput
26 compdef:80> autoload -Uz _dir_list
26 compdef:80> autoload -Uz _devtodo
26 compdef:80> autoload -Uz _default
26 compdef:80> autoload -Uz _dd
26 compdef:80> autoload -Uz _dcut
26 compdef:80> autoload -Uz _cygserver
26 compdef:80> autoload -Uz _compress
26 compdef:80> autoload -Uz _cksum
26 compdef:80> autoload -Uz _chrt
26 compdef:80> autoload -Uz _chmod
26 compdef:80> autoload -Uz _chflags
26 compdef:80> autoload -Uz _cdrecord
26 compdef:80> autoload -Uz _cat
26 compdef:80> [[ -n yes ]]
26 compdef:80> [[ -n yes ]]
26 compdef:80> [[ -n yes ]]
26 compdef:80> [[ -n yes ]]
26 compdef:80> [[ -n yes ]]
26 compdef:80> [[ -n '' ]]
26 compdef:79> func=_bug
26 compdef:49> [[ _value = *=* ]]
26 compdef:49> [[ _stgit = *=* ]]
26 compdef:49> [[ _rubocop = *=* ]]
26 compdef:49> [[ _protoc = *=* ]]
26 compdef:49> [[ _play = *=* ]]
26 compdef:49> [[ _iwconfig = *=* ]]
26 compdef:49> [[ _dmesg = *=* ]]
26 compdef:49> [[ _curl = *=* ]]
26 compdef:49> [[ _a2ps = *=* ]]
26 compdef:49> [[ -z '' ]]
26 compdef:40> ((  ! 3  ))
26 compdef:40> ((  ! 2  ))
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:38> shift OPTIND-1
26 compdef:27> type=postpattern
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:17> new=yes
26 compdef:16> autol=yes
26 compdef:16> autol=yes
26 compdef:16> autol=yes
26 compdef:16> autol=yes
26 compdef:16> autol=yes
26 compdef:15> case n (n)
26 compdef:15> case n (n)
26 compdef:15> case n (n)
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:14> getopts anpPkKde opt
26 compdef:9> ((  ! 6  ))
26 compdef:9> ((  ! 4  ))
26 compdef:9> ((  ! 4  ))
26 compdef:9> ((  ! 4  ))
26 compdef:9> ((  ! 4  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:9> ((  ! 3  ))
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:5> setopt extendedglob
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:4> emulate -L zsh
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compdef:2> local -a match mbegin mend
26 compaudit:29> ((  14 == 0  ))
26 compaudit:13> emulate -L zsh
26 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;44m'
26 colors:99> bold_color=$'C-[[01m'
26 colors:77> color[${color[$k]}]=35
26 antigen:1> -antigen-hook-handler antigen bundle zsh-users/zsh-syntax-highligh...
26 antigen:1> -antigen-hook-handler antigen bundle deno
26 antigen-use:1> [[ oh-my-zsh == oh-my-zsh ]]
26 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
26 antigen-remove-hook:4> hooks=( antigen-apply-lock antigen-apply-parallel anti...
26 antigen-lock:1> LOG 'antigen-lock called'
26 antigen-ext:8> LOG 'LOADED EXTENSION defer' EXT
26 antigen-ext:8> LOG 'LOADED EXTENSION cache' EXT
26 antigen-ext:7> ((  0 == 0  ))
26 antigen-ext:6> WARN '-antigen-cache-init return code was 0'
26 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-syntax-h...
26 antigen-bundle-parallel:1> TRACE 'antigen-bundle-parallel: zsh-users/zsh-auto...
26 antigen-bundle-parallel-execute:41> antigen-bundle '--loc=lib'
26 antigen-bundle-parallel-execute:8> typeset -Ua repositories
26 antigen-bundle-parallel-execute:1> WARN 'Parallel antigen-bundle-parallel-exe...
26 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply type pr...
26 antigen-add-hook:1> local target=antigen-apply hook=antigen-apply-defer type=...
26 antigen-add-hook:1> local target=antigen hook=antigen-lock type=pre mode=once
26 add-zsh-hook:28> getopts dDhLUzk opt
26 add-zsh-hook:28> getopts dDhLUzk opt
26 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
26 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
26 add-zsh-hook:15> emulate -L zsh
26 _zsh_highlight_bind_widgets:50> zle -N kill-buffer _zsh_highlight_widget_orig...
26 _zsh_highlight_bind_widgets:50> zle -N history-incremental-pattern-search-for...
26 _zsh_highlight_bind_widgets:50> zle -N accept-and-menu-complete _zsh_highligh...
26 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
26 _zsh_highlight_bind_widgets:27> case builtin (builtin)
26 _zsh_highlight_bind_widgets:27> case builtin (builtin)
26 _zsh_highlight_bind_widgets:27> case builtin (builtin)
26 _zsh_highlight_bind_widgets:26> cur_widget=vi-undo-change
26 _zsh_highlight__function_callable_p:1> _zsh_highlight__is_function_p add-zle-...
26 /Users/matt/.zshrc:599> unset -f group_lazy_load
26 /Users/matt/.zshrc:592> group_lazy_load '. /Users/matt/.rvm/scripts/rvm' rvm ...
26 /Users/matt/.zshrc:373> alias 'vi=nvim'
26 /Users/matt/.zshrc:345> export GUILE_SYSTEM_EXTENSIONS_PATH=/usr/local/lib/gu...
26 /Users/matt/.zshrc:340> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
26 /Users/matt/.zshrc:144> bindkey '^X^_' redo
26 /Users/matt/.zcompdump:1961> zle -C _history-complete-newer .complete-word _h...
26 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1796> zle -C _history-comple...
26 /Users/matt/.p10k.zsh:1586> ((  1  ))
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:300> alias 'gts=git tag -s'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:260> alias 'grmc=git rm --c...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:259> alias 'grm=git rm'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:253> alias 'grbo=git rebase...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:244> alias 'gr=git remote'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:241> alias 'gpu=git push up...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:214> alias 'glgp=git log --...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:147> alias 'gg=git gui citool'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:127> alias 'gdup=git diff @...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:124> alias 'gdct=git descri...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:122> alias 'gdca=git diff -...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:118> alias 'gcss=git commit...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:117> alias 'gcs=git commit -S'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:116> alias 'gcpc=git cherry...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:114> alias 'gcp=git cherry-...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:113> alias 'gcount=git shor...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:112> alias 'gcor=git checko...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:111> alias 'gco=git checkout'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:110> alias 'gcmsg=git commi...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:109> alias 'gcd=git checkou...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:95> alias 'gcasm=git commit...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:93> alias 'gcsm=git commit ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:92> alias 'gcam=git commit ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:91> alias 'gcans!=git commi...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:88> alias 'gca=git commit -...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:87> alias 'gcn!=git commit ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:81> alias 'gbsg=git bisect ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:80> alias 'gbsb=git bisect ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:77> alias 'gbnm=git branch ...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:76> alias 'gbl=git blame -b...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:75> alias 'gbD=git branch -D'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:68> alias 'gap=git apply'
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:66> alias 'gau=git add --up...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:65> alias 'gapa=git add --p...
26 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:64> alias 'gaa=git add --all'
26 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
26 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
26 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
26 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:90> is_plugin /Users/matt/.oh-my-zsh git
26 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;013m%}'
26 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/plugins/f...
26 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:14> zle -N zle-line-init
26 /Users/matt/.oh-my-zsh/lib/directories.zsh:38> alias 'la=ls -lAh'
26 /Users/matt/.oh-my-zsh/lib/directories.zsh:32> compdef _dirs d
26 /Users/matt/.oh-my-zsh/lib/directories.zsh:6> alias -g '...=../..'
26 /Users/matt/.oh-my-zsh/lib/completion.zsh:26> unset CASE_SENSITIVE HYPHEN_INS...
26 /Users/matt/.oh-my-zsh/lib/completion.zsh:20> [[ '' = true ]]
26 /Users/matt/.oh-my-zsh/lib/completion.zsh:10> setopt always_to_end
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
26 /Users/matt/.oh-my-zsh/cache/grep-alias:2> alias 'egrep=egrep --color=auto --...
26 /Users/matt/.iterm2_shell_integration.zsh:164> preexec_functions=( omz_termsu...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:110>...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:81> ...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:36> a...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:26> un...
26 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:10> se...
26 -antigen-set-default:3> eval 'test -z "$_ANTIGEN_GREP_COMMAND" && typeset -g ...
26 -antigen-set-default:3> eval 'test -z "$_ANTIGEN_BUILTIN_EXTENSIONS" && types...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_SUBMODULE_OPTS" && typeset -g...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_RSRC" && typeset -g ANTIGEN_R...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_COMPDUMP" && typeset -g ANTIG...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_CLONE_OPTS" && typeset -g ANT...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_CLONE_ENV" && typeset -g ANTI...
26 -antigen-set-default:3> eval 'test -z "$ANTIGEN_BUNDLES" && typeset -g ANTIGE...
26 -antigen-parse-args:160> args[name]=''zsh-users/zsh-autosuggestions''
26 -antigen-parse-args:112> [[ plugin == theme ]]
26 -antigen-parse-args:112> [[ plugin == theme ]]
26 -antigen-parse-args:22> case deno (--url | --loc | --branch | --btype)
26 -antigen-hook-handler:69> LOG 'Return from hook antigen-bundle with 0'
26 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
26 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
26 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
26 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
26 -antigen-hook-handler:56> WARN '-antigen-hook-antigen apply'
26 -antigen-hook-handler:51> [[ 0 == -1 ]]
26 -antigen-hook-handler:51> WARN 'antigen-bundle-defer shortcircuited'
26 -antigen-hook-handler:50> antigen-bundle-defer zsh-users/zsh-autosuggestions
26 -antigen-hook-handler:49> WARN 'Replace hook:' antigen-apply-parallel-execute
26 -antigen-hook-handler:44> local replace_hook=0 ret=0
26 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-syntax-highligh...
26 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-syntax-highligh...
26 -antigen-hook-handler:30> post_hooks+=( antigen-apply-cached )
26 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-parallel )
26 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-parallel )
26 -antigen-hook-handler:27> replace_hooks+=( -antigen-load-source-cached )
26 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
26 -antigen-hook-handler:20> WARN 'Updated meta: target' antigen-bundle mode rep...
26 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
26 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-so...
26 -antigen-hook-handler:14> continue
26 -antigen-hook-handler:14> continue
26 -antigen-hook-handler:14> continue
26 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-lock'
26 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-lock'
26 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-lock'
26 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
26 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
26 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
26 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
26 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
26 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
26 -antigen-hook-handler:11> meta=( target -antigen-load-source mode repeat type...
26 -antigen-hook-handler:7> hooks=( antigen-bundle-defer antigen-bundle-cached )
26 -antigen-hook-handler:7> hooks=( antigen-bundle-defer antigen-bundle-cached )
26 -antigen-hook-handler:7> hooks=( antigen-bundle-cached antigen-bundle-parallel )
26 -antigen-hook-handler:7> hooks=( antigen-bundle-cached antigen-bundle-parallel )
26 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
26 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
26 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
26 -antigen-hook-handler:1> local target=antigen args hook called
26 -antigen-hook-antigen:10> antigen-bundle zsh-users/zsh-autosuggestions
26 -antigen-hook-antigen:8> ((  1  ))
26 -antigen-hook-antigen:8> ((  1  ))
26 -antigen-hook-antigen-bundle:14> [[ true == true && ! 0 == 0 ]]
26 -antigen-hook-antigen-bundle:8> -antigen-parse-args bundle zsh-users/zsh-auto...
26 -antigen-hook-antigen-bundle:8> -antigen-parse-args bundle '--loc=lib'
26 -antigen-hook-antigen-bundle:7> typeset -A bundle
26 -antigen-hook-antigen-bundle:2> [[ -z zsh-users/zsh-syntax-highlighting ]]
26 -antigen-hook-antigen-bundle:2> [[ -z zsh-users/zsh-autosuggestions ]]
26 -antigen-hook-antigen-bundle:1> TRACE 'Called antigen-bundle with deno' BUNDLE
26 -antigen-env-setup:46> -antigen-interactive-mode
26 -antigen-env-setup:38> -antigen-set-default _ANTIGEN_THEME_COMPAT true
26 -antigen-env-setup:35> -antigen-set-default _ANTIGEN_WARN_DUPLICATES true
26 -antigen-defer-init:2> -antigen-interactive-mode
26 -antigen-cache-init:1> -antigen-interactive-mode
26 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
26 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
26 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
26 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
26 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
26 (eval):177> alias 'gsb=git status -sb'
26 (eval):167> alias 'gstc=git stash clear'
26 (eval):164> alias 'gsta=git stash push'
26 (eval):48> alias 'gapt=git apply --3way'
26 (eval):46> alias 'gap=git apply'
26 (anon):1394> typeset -g POWERLEVEL9K_GOOGLE_APP_CRED_DEFAULT_CONTENT_EXPANSIO...
26 (anon):1299> typeset -g POWERLEVEL9K_AZURE_VISUAL_IDENTIFIER_EXPANSION=az
26 (anon):1111> typeset -g POWERLEVEL9K_SCALAENV_PROMPT_ALWAYS_SHOW=false
26 (anon):1027> typeset -g POWERLEVEL9K_RBENV_SOURCES=( shell local global )
26 (anon):967> typeset -g POWERLEVEL9K_GO_VERSION_PROJECT_ONLY=true
26 (anon):821> typeset -g 'POWERLEVEL9K_CONTEXT_REMOTE_FOREGROUND=180' 'POWERLEV...
26 (anon):819> typeset -g POWERLEVEL9K_CONTEXT_ROOT_FOREGROUND=178
26 (anon):671> typeset -g POWERLEVEL9K_NORDVPN_VISUAL_IDENTIFIER_EXPANSION=nord
26 (anon):527> typeset -g POWERLEVEL9K_ASDF_FOREGROUND=66
26 (anon):498> typeset -g POWERLEVEL9K_COMMAND_EXECUTION_TIME_THRESHOLD=3
26 (anon):463> typeset -g POWERLEVEL9K_STATUS_EXTENDED_STATES=true
26 (anon):436> typeset -g POWERLEVEL9K_VCS_CONTENT_EXPANSION='${$((my_git_format...
26 (anon):240> typeset -g POWERLEVEL9K_DIR_TRUNCATE_BEFORE_MARKER=false
26 (anon):194> typeset -g POWERLEVEL9K_SHORTEN_STRATEGY=truncate_to_unique
26 (anon):150> typeset -g POWERLEVEL9K_LEFT_PROMPT_LAST_SEGMENT_END_SYMBOL='uE0B0'
26 (anon):146> typeset -g POWERLEVEL9K_LEFT_SEGMENT_SEPARATOR='uE0B0'
26 (anon):114> typeset -g POWERLEVEL9K_MULTILINE_NEWLINE_PROMPT_PREFIX=''
26 (anon):90> typeset -g POWERLEVEL9K_MODE=powerline
26 (anon):8> autoload -Uz is-at-least
26 (anon):2> emulate -L zsh
25 regexp-replace:24> local MATCH MBEGIN MEND
25 is_theme:2> local name=robbyrussell
25 is_theme:1> local base_dir=/Users/matt/.oh-my-zsh/custom/themes
25 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh
25 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh
25 is-at-least:53> ((  part > min_ver[min_cnt]  ))
25 is-at-least:23> emulate -L zsh
25 env_default:2> export 'PAGER=less'
25 compinit:533> zle -C delete-char-or-list .delete-char-or-list _main_complete
25 compinit:516> [[ '' !=  # ]]
25 compinit:515> autoload -Uz _x_geometry
25 compinit:515> autoload -Uz _tar_archive
25 compinit:515> autoload -Uz _pick_variant
25 compinit:515> autoload -Uz _debbugs_bugnumber
25 compinit:515> autoload -Uz _cache_invalid
25 compinit:508> [[ zoneadm = -[pPkK](n|) ]]
25 compinit:508> [[ zeal = -[pPkK](n|) ]]
25 compinit:508> [[ zcalc = -[pPkK](n|) ]]
25 compinit:508> [[ yafc = -[pPkK](n|) ]]
25 compinit:508> [[ xxd = -[pPkK](n|) ]]
25 compinit:508> [[ xv = -[pPkK](n|) ]]
25 compinit:508> [[ xset = -[pPkK](n|) ]]
25 compinit:508> [[ xournal = -[pPkK](n|) ]]
25 compinit:508> [[ xmodmap = -[pPkK](n|) ]]
25 compinit:508> [[ wpa_cli = -[pPkK](n|) ]]
25 compinit:508> [[ wget = -[pPkK](n|) ]]
25 compinit:508> [[ wc = -[pPkK](n|) ]]
25 compinit:508> [[ watch = -[pPkK](n|) ]]
25 compinit:508> [[ vpnc = -[pPkK](n|) ]]
25 compinit:508> [[ vim = -[pPkK](n|) ]]
25 compinit:508> [[ update-rc.d = -[pPkK](n|) ]]
25 compinit:508> [[ unalias = -[pPkK](n|) ]]
25 compinit:508> [[ top = -[pPkK](n|) ]]
25 compinit:508> [[ tmux = -[pPkK](n|) ]]
25 compinit:508> [[ tload = -[pPkK](n|) ]]
25 compinit:508> [[ timeout = -[pPkK](n|) ]]
25 compinit:508> [[ tcpdump = -[pPkK](n|) ]]
25 compinit:508> [[ svm = -[pPkK](n|) ]]
25 compinit:508> [[ supervisorctl = -[pPkK](n|) ]]
25 compinit:508> [[ stack = -[pPkK](n|) ]]
25 compinit:508> [[ srm = -[pPkK](n|) ]]
25 compinit:508> [[ scutil = -[pPkK](n|) ]]
25 compinit:508> [[ script = -[pPkK](n|) ]]
25 compinit:508> [[ schedtool = -[pPkK](n|) ]]
25 compinit:508> [[ rm = -[pPkK](n|) ]]
25 compinit:508> [[ readelf = -[pPkK](n|) ]]
25 compinit:508> [[ rdesktop = -[pPkK](n|) ]]
25 compinit:508> [[ rake = -[pPkK](n|) ]]
25 compinit:508> [[ quilt = -[pPkK](n|) ]]
25 compinit:508> [[ ptree = -[pPkK](n|) ]]
25 compinit:508> [[ portsnap = -[pPkK](n|) ]]
25 compinit:508> [[ play = -[pPkK](n|) ]]
25 compinit:508> [[ pkcon = -[pPkK](n|) ]]
25 compinit:508> [[ pixz = -[pPkK](n|) ]]
25 compinit:508> [[ pipenv = -[pPkK](n|) ]]
25 compinit:508> [[ php = -[pPkK](n|) ]]
25 compinit:508> [[ phing = -[pPkK](n|) ]]
25 compinit:508> [[ pgrep = -[pPkK](n|) ]]
25 compinit:508> [[ pfexec = -[pPkK](n|) ]]
25 compinit:508> [[ pfctl = -[pPkK](n|) ]]
25 compinit:508> [[ pdm = -[pPkK](n|) ]]
25 compinit:508> [[ optirun = -[pPkK](n|) ]]
25 compinit:508> [[ openssl = -[pPkK](n|) ]]
25 compinit:508> [[ okular = -[pPkK](n|) ]]
25 compinit:508> [[ od = -[pPkK](n|) ]]
25 compinit:508> [[ nvram = -[pPkK](n|) ]]
25 compinit:508> [[ nvm = -[pPkK](n|) ]]
25 compinit:508> [[ numfmt = -[pPkK](n|) ]]
25 compinit:508> [[ nm = -[pPkK](n|) ]]
25 compinit:508> [[ nginx = -[pPkK](n|) ]]
25 compinit:508> [[ netstat = -[pPkK](n|) ]]
25 compinit:508> [[ netscape = -[pPkK](n|) ]]
25 compinit:508> [[ ncftp = -[pPkK](n|) ]]
25 compinit:508> [[ mysqldiff = -[pPkK](n|) ]]
25 compinit:508> [[ mupdf = -[pPkK](n|) ]]
25 compinit:508> [[ mpc = -[pPkK](n|) ]]
25 compinit:508> [[ mozilla = -[pPkK](n|) ]]
25 compinit:508> [[ mosh = -[pPkK](n|) ]]
25 compinit:508> [[ mkzsh = -[pPkK](n|) ]]
25 compinit:508> [[ mkshortcut = -[pPkK](n|) ]]
25 compinit:508> [[ mkfifo = -[pPkK](n|) ]]
25 compinit:508> [[ make-kpkg = -[pPkK](n|) ]]
25 compinit:508> [[ mail = -[pPkK](n|) ]]
25 compinit:508> [[ madison = -[pPkK](n|) ]]
25 compinit:508> [[ lynx = -[pPkK](n|) ]]
25 compinit:508> [[ lsusb = -[pPkK](n|) ]]
25 compinit:508> [[ lspv = -[pPkK](n|) ]]
25 compinit:508> [[ lsmod = -[pPkK](n|) ]]
25 compinit:508> [[ lp = -[pPkK](n|) ]]
25 compinit:508> [[ look = -[pPkK](n|) ]]
25 compinit:508> [[ loadkeys = -[pPkK](n|) ]]
25 compinit:508> [[ lintian = -[pPkK](n|) ]]
25 compinit:508> [[ less = -[pPkK](n|) ]]
25 compinit:508> [[ ldconfig = -[pPkK](n|) ]]
25 compinit:508> [[ kubectl = -[pPkK](n|) ]]
25 compinit:508> [[ kitchen = -[pPkK](n|) ]]
25 compinit:508> [[ jot = -[pPkK](n|) ]]
25 compinit:508> [[ jls = -[pPkK](n|) ]]
25 compinit:508> [[ iptables = -[pPkK](n|) ]]
25 compinit:508> [[ inxi = -[pPkK](n|) ]]
25 compinit:508> [[ installpkg = -[pPkK](n|) ]]
25 compinit:508> [[ ifup = -[pPkK](n|) ]]
25 compinit:508> [[ hub = -[pPkK](n|) ]]
25 compinit:508> [[ hostname = -[pPkK](n|) ]]
25 compinit:508> [[ groff = -[pPkK](n|) ]]
25 compinit:508> [[ gphoto2 = -[pPkK](n|) ]]
25 compinit:508> [[ gm = -[pPkK](n|) ]]
25 compinit:508> [[ getopt = -[pPkK](n|) ]]
25 compinit:508> [[ getfacl = -[pPkK](n|) ]]
25 compinit:508> [[ gem = -[pPkK](n|) ]]
25 compinit:508> [[ gccgo = -[pPkK](n|) ]]
25 compinit:508> [[ fsh = -[pPkK](n|) ]]
25 compinit:508> [[ free = -[pPkK](n|) ]]
25 compinit:508> [[ flowadm = -[pPkK](n|) ]]
25 compinit:508> [[ flac = -[pPkK](n|) ]]
25 compinit:508> [[ findmnt = -[pPkK](n|) ]]
25 compinit:508> [[ find = -[pPkK](n|) ]]
25 compinit:508> [[ fetch = -[pPkK](n|) ]]
25 compinit:508> [[ ecdsautil = -[pPkK](n|) ]]
25 compinit:508> [[ e2label = -[pPkK](n|) ]]
25 compinit:508> [[ dupload = -[pPkK](n|) ]]
25 compinit:508> [[ drush = -[pPkK](n|) ]]
25 compinit:508> [[ docker = -[pPkK](n|) ]]
25 compinit:508> [[ dmidecode = -[pPkK](n|) ]]
25 compinit:508> [[ disable = -[pPkK](n|) ]]
25 compinit:508> [[ dhcpcd = -[pPkK](n|) ]]
25 compinit:508> [[ dchroot = -[pPkK](n|) ]]
25 compinit:508> [[ dad = -[pPkK](n|) ]]
25 compinit:508> [[ cryptsetup = -[pPkK](n|) ]]
25 compinit:508> [[ cppcheck = -[pPkK](n|) ]]
25 compinit:508> [[ clay = -[pPkK](n|) ]]
25 compinit:508> [[ bts = -[pPkK](n|) ]]
25 compinit:508> [[ brew = -[pPkK](n|) ]]
25 compinit:508> [[ bower = -[pPkK](n|) ]]
25 compinit:508> [[ bitcoin-cli = -[pPkK](n|) ]]
25 compinit:508> [[ basename = -[pPkK](n|) ]]
25 compinit:508> [[ auto-apt = -[pPkK](n|) ]]
25 compinit:508> [[ attr = -[pPkK](n|) ]]
25 compinit:508> [[ asciinema = -[pPkK](n|) ]]
25 compinit:508> [[ artisan = -[pPkK](n|) ]]
25 compinit:508> [[ arping = -[pPkK](n|) ]]
25 compinit:508> [[ arp = -[pPkK](n|) ]]
25 compinit:508> [[ archlinux-java = -[pPkK](n|) ]]
25 compinit:508> [[ apt-show-versions = -[pPkK](n|) ]]
25 compinit:508> [[ apt-file = -[pPkK](n|) ]]
25 compinit:508> [[ ack = -[pPkK](n|) ]]
25 compinit:508> [[ abcde = -[pPkK](n|) ]]
25 compinit:508> [[ -value-,PRINTER,-default- = -[pPkK](n|) ]]
25 compinit:508> [[ -redirect- = -[pPkK](n|) ]]
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #compdef (#compdef)
25 compinit:506> case #autoload (#compdef)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:506> case #autoload (#autoload)
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:505> shift _i_line
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#compdef'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:504> _i_tag='#autoload'
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:501> ((  0 + 0  ))
25 compinit:500> _i_name=_wc
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_uscan
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_picocom
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_oldlist
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gsettings
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_file_systems
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_domains
25 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debfoster
25 compinit:497> [[ /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlightin...
25 compinit:497> [[ /Users/matt/.oh-my-zsh/custom/plugins/zsh-completions = . ]]
25 compinit:497> [[ /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions = ...
25 compinit:479> [[ -f /Users/matt/.antigen/.zcompdump ]]
25 compinit:123> typeset -g _comp_dumpfile='/Users/matt/.zcompdump-Mateo’s MacBo...
25 compinit:74> typeset _i_tag _i_file _i_addfiles _i_fail=ask _i_check=yes _i_name
25 compinit:71> setopt extendedglob
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:121> shift _d_als
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:118> print -n ' 
           '
25 compdump:115> print -n ' _xterm'
25 compdump:115> print -n ' _sockstat'
25 compdump:115> print -n ' _mvn'
25 compdump:115> print -n ' _mkdir'
25 compdump:115> print -n ' _generic'
25 compdump:115> print -n ' _first'
25 compdump:115> print -n ' _extensions'
25 compdump:115> print -n ' _dmidecode'
25 compdump:115> print -n ' _dig'
25 compdump:115> print -n ' _be_name'
25 compdump:115> print -n ' _aliases'
25 compdump:114> ((  ! 0  ))
25 compdump:114> ((  ! 0  ))
25 compdump:114> ((  ! 0  ))
25 compdump:114> ((  ! 0  ))
25 compdump:114> ((  ! 0  ))
25 compdump:113> ((  917  ))
25 compdump:113> ((  870  ))
25 compdump:113> ((  864  ))
25 compdump:113> ((  785  ))
25 compdump:113> ((  721  ))
25 compdump:113> ((  369  ))
25 compdump:113> ((  361  ))
25 compdump:113> ((  174  ))
25 compdump:95> read -rA _d_line
25 compdump:95> read -rA _d_line
25 compdump:95> read -rA _d_line
25 compdump:95> read -rA _d_line
25 compdump:95> read -rA _d_line
25 compdump:95> read -rA _d_line
25 compdump:90> print -r - zle -C _complete_debug .complete-word _complete_debug
25 compdump:49> _d_f=-redirect-,<,bunzip2
25 compdump:44> print -r - ''analyseplugin'' ''_analyseplugin''
25 compdump:21> _d_file=/Users/matt/.antigen/.zcompdump.ResNet-21-79.resnet.ucsb...
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:169> shift
25 compdef:164> _services[$cmd]=vboxheadless
25 compdef:164> _services[$cmd]=gunzip
25 compdef:164> _services[$cmd]=gnupod_addsong
25 compdef:164> _services[$cmd]=git-checkout
25 compdef:164> _services[$cmd]=git-checkout
25 compdef:164> _services[$cmd]=firefox
25 compdef:164> [[ -n '' ]]
25 compdef:162> [[ -z yes || -z _zparseopts ]]
25 compdef:162> [[ -z yes || -z _zed ]]
25 compdef:162> [[ -z yes || -z _zcash-cli ]]
25 compdef:162> [[ -z yes || -z _yp ]]
25 compdef:162> [[ -z yes || -z _xloadimage ]]
25 compdef:162> [[ -z yes || -z _xft_fonts ]]
25 compdef:162> [[ -z yes || -z _webbrowser ]]
25 compdef:162> [[ -z yes || -z _urxvt ]]
25 compdef:162> [[ -z yes || -z _unexpand ]]
25 compdef:162> [[ -z yes || -z _typeset ]]
25 compdef:162> [[ -z yes || -z _twidge ]]
25 compdef:162> [[ -z yes || -z _tardy ]]
25 compdef:162> [[ -z yes || -z _sublimetext ]]
25 compdef:162> [[ -z yes || -z _softwareupdate ]]
25 compdef:162> [[ -z yes || -z _scala ]]
25 compdef:162> [[ -z yes || -z _postfix ]]
25 compdef:162> [[ -z yes || -z _perl_modules ]]
25 compdef:162> [[ -z yes || -z _openstack ]]
25 compdef:162> [[ -z yes || -z _openstack ]]
25 compdef:162> [[ -z yes || -z _numfmt ]]
25 compdef:162> [[ -z yes || -z _node ]]
25 compdef:162> [[ -z yes || -z _middleman ]]
25 compdef:162> [[ -z yes || -z _man ]]
25 compdef:162> [[ -z yes || -z _man ]]
25 compdef:162> [[ -z yes || -z _mail ]]
25 compdef:162> [[ -z yes || -z _mail ]]
25 compdef:162> [[ -z yes || -z _lighttpd ]]
25 compdef:162> [[ -z yes || -z _jobs_builtin ]]
25 compdef:162> [[ -z yes || -z _ipsec ]]
25 compdef:162> [[ -z yes || -z _ip ]]
25 compdef:162> [[ -z yes || -z _initctl ]]
25 compdef:162> [[ -z yes || -z _id ]]
25 compdef:162> [[ -z yes || -z _hash ]]
25 compdef:162> [[ -z yes || -z _guilt ]]
25 compdef:162> [[ -z yes || -z _guilt ]]
25 compdef:162> [[ -z yes || -z _ghostscript ]]
25 compdef:162> [[ -z yes || -z _dpkg-buildpackage ]]
25 compdef:162> [[ -z yes || -z _dnf ]]
25 compdef:162> [[ -z yes || -z _dbus ]]
25 compdef:162> [[ -z yes || -z _darcs ]]
25 compdef:162> [[ -z yes || -z _cygrunsrv ]]
25 compdef:162> [[ -z yes || -z _cpupower ]]
25 compdef:162> [[ -z yes || -z _cowsay ]]
25 compdef:162> [[ -z yes || -z _configure ]]
25 compdef:162> [[ -z yes || -z _comm ]]
25 compdef:162> [[ -z yes || -z _a2utils ]]
25 compdef:159> cmd=mgv
25 compdef:155> [[ tarsnap = *=* ]]
25 compdef:155> [[ socket = *=* ]]
25 compdef:155> [[ chpass = *=* ]]
25 compdef:155> [[ _rclone = *=* ]]
25 compdef:151> _postpatcomps[$1]=_x_arguments
25 compdef:151> _postpatcomps[$1]=_dir_list
25 compdef:139> case  (postpattern)
25 compdef:139> case  (*)
25 compdef:136> [[ todo.sh = -P ]]
25 compdef:134> [[ stg = -p ]]
25 compdef:134> [[ printf = -p ]]
25 compdef:134> [[ a2ps = -p ]]
25 compdef:132> [[ zeal = -N ]]
25 compdef:132> [[ xwit = -N ]]
25 compdef:132> [[ xdvi = -N ]]
25 compdef:132> [[ tardy = -N ]]
25 compdef:132> [[ rails = -N ]]
25 compdef:132> [[ numfmt = -N ]]
25 compdef:132> [[ netscape = -N ]]
25 compdef:132> [[ mkisofs = -N ]]
25 compdef:132> [[ man = -N ]]
25 compdef:132> [[ lighty-enable-mod = -N ]]
25 compdef:132> [[ guilt-files = -N ]]
25 compdef:132> [[ entr = -N ]]
25 compdef:132> [[ dumpadm = -N ]]
25 compdef:132> [[ defaults = -N ]]
25 compdef:132> [[ deborphan = -N ]]
25 compdef:132> [[ debcheckout = -N ]]
25 compdef:132> [[ dd = -N ]]
25 compdef:132> [[ cpupower = -N ]]
25 compdef:132> [[ chown = -N ]]
25 compdef:132> [[ chkconfig = -N ]]
25 compdef:132> [[ chattr = -N ]]
25 compdef:132> [[ caffeinate = -N ]]
25 compdef:132> [[ bzr = -N ]]
25 compdef:132> [[ _restic = -N ]]
25 compdef:131> ((  4  ))
25 compdef:131> ((  2  ))
25 compdef:131> ((  1  ))
25 compdef:114> [[ complete-word = menu-select ]]
25 compdef:83> case  (key)
25 compdef:83> case  (key)
25 compdef:83> case  (*)
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:81> shift
25 compdef:80> autoload -Uz _virtualbox
25 compdef:80> autoload -Uz _units
25 compdef:80> autoload -Uz _svccfg
25 compdef:80> autoload -Uz _setcap
25 compdef:80> autoload -Uz _nl
25 compdef:80> autoload -Uz _netscape
25 compdef:80> autoload -Uz _modutils
25 compdef:80> autoload -Uz _man
25 compdef:80> autoload -Uz _lynx
25 compdef:80> autoload -Uz _dos2unix
25 compdef:80> autoload -Uz _df
25 compdef:80> autoload -Uz _acpi
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:80> [[ -n yes ]]
25 compdef:79> func=_todo.sh
25 compdef:79> func=_shutdown
25 compdef:79> func=_rubocop
25 compdef:79> func=_fmadm
25 compdef:79> func=_dir_list
25 compdef:49> [[ _iftop = *=* ]]
25 compdef:49> [[ _groups = *=* ]]
25 compdef:49> [[ _dumper = *=* ]]
25 compdef:49> [[ _disable = *=* ]]
25 compdef:49> [[ _debdiff = *=* ]]
25 compdef:49> [[ _cowsay = *=* ]]
25 compdef:45> [[ -z '' ]]
25 compdef:40> ((  ! 2  ))
25 compdef:40> ((  ! 2  ))
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:38> shift OPTIND-1
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:17> new=yes
25 compdef:16> autol=yes
25 compdef:16> autol=yes
25 compdef:16> autol=yes
25 compdef:16> autol=yes
25 compdef:15> case n (a)
25 compdef:15> case a (a)
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:14> getopts anpPkKde opt
25 compdef:9> ((  ! 27  ))
25 compdef:9> ((  ! 8  ))
25 compdef:9> ((  ! 5  ))
25 compdef:9> ((  ! 5  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 4  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:9> ((  ! 3  ))
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:5> setopt extendedglob
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:4> emulate -L zsh
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compdef:2> local -a match mbegin mend
25 compaudit:61> [[ -n /usr/share/zsh/5.8.1/functions ]]
25 colors:95> local lc=$'C-[[' rc=m
25 colors:77> color[${color[$k]}]=32
25 bashcompinit:177> unfunction bashcompinit
25 antigen:1> -antigen-hook-handler antigen apply
25 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
25 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
25 antigen-remove-hook:3> local target=-antigen-load-env
25 antigen-remove-hook:1> local hook=antigen-apply-parallel-execute
25 antigen-ext:7> ((  0 == 0  ))
25 antigen-ext:7> ((  0 == 0  ))
25 antigen-ext:5> local ret=0
25 antigen-ext-init:5> antigen-ext defer
25 antigen-ext-init:5> ((  1  ))
25 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-syntax-h...
25 antigen-bundle:1> -antigen-hook-handler antigen-bundle zsh-users/zsh-autosugg...
25 antigen-bundle:1> -antigen-hook-handler antigen-bundle deno
25 antigen-bundle:1> -antigen-hook-handler antigen-bundle '--loc=lib'
25 antigen-bundle:1> -antigen-hook-handler antigen-bundle '--loc=lib'
25 antigen-bundle-parallel-execute:41> antigen-bundle deno
25 antigen-bundle-parallel-execute:24> repositories+=( https://github.com/zsh-us...
25 antigen-bundle-parallel-execute:11> -antigen-parse-args bundle '--loc=lib'
25 antigen-bundle-parallel-execute:3> local args pid
25 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-apply-lock:antigen-apply...
25 antigen-add-hook:1> local target=antigen-bundle hook=antigen-bundle-parallel ...
25 add-zsh-hook:90> set -A preexec_functions omz_termsupport_preexec
25 add-zsh-hook:84> ((  2 == 0  ))
25 add-zsh-hook:65> local hook=precmd_functions
25 add-zsh-hook:60> ((  help || 2 != 2 || 2 == 0  ))
25 add-zsh-hook:28> getopts dDhLUzk opt
25 add-zsh-hook:24> local opt
25 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
25 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
25 add-zsh-hook:15> emulate -L zsh
25 add-zle-hook-widget:102> autoload -- _zsh_highlight__zle-line-pre-redraw
25 add-zle-hook-widget:100> zstyle -- zle-line-finish widgets 0:user:zle-line-fi...
25 add-zle-hook-widget:81> integer i=3-2
25 add-zle-hook-widget:11> getopts dDhLUzk opt
25 _zsh_highlight_load_highlighters:2> setopt localoptions noksharrays bareglobqual
25 _zsh_highlight_bind_widgets:50> zle -N history-incremental-search-forward _zs...
25 _zsh_highlight_bind_widgets:50> zle -N history-incremental-pattern-search-bac...
25 _zsh_highlight_bind_widgets:27> case user:zle-line-finish (user:_zsh_highligh...
25 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_main_complete ...
25 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
25 /usr/local/share/antigen/antigen.zsh:1400> typeset -g _ANTIGEN_HOOK_PREFIX=-a...
25 /Users/matt/.zshrc:417> export OPENSSL_PREFIX=/usr/local/opt/openssl@3
25 /Users/matt/.zshrc:380> alias 'brew=env PATH="${PATH//:($(pyenv root)/shims|$...
25 /Users/matt/.zshrc:369> export DOTNET_CLI_TELEMETRY_OPTOUT=true
25 /Users/matt/.zshrc:343> export GUILE_LOAD_PATH=/usr/local/share/guile/site/3.0
25 /Users/matt/.zshrc:315> [ -z '' ']'
25 /Users/matt/.zshrc:221> export BREW_PREFIX=/usr/local
25 /Users/matt/.zshrc:177> alias 'gstst=git move-staged'
25 /Users/matt/.zcompdump:1962> zle -C _history-complete-older .complete-word _h...
25 /Users/matt/.zcompdump:1954> zle -C _complete_debug .complete-word _complete_...
25 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1798> zle -C _most_recent_fi...
25 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1795> zle -C _history-comple...
25 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1794> zle -C _expand_word .c...
25 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1788> zle -C _complete_debug...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:121> alias 'gd=git diff'
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:115> alias 'gcpa=git cherry...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:96> alias 'gcb=git checkout...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:94> alias 'gcas=git commit ...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:82> alias 'gbsr=git bisect ...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:78> alias 'gbr=git branch -...
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:72> alias 'gba=git branch -a'
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:71> alias 'gb=git branch'
25 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:67> alias 'gav=git add --ve...
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=zshfl
25 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:60> [[ '' != true ]]
25 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:9> [[ '' != true ]]
25 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;214m%}'
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:12> zle -N self-insert url-quote-magic
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:11> autoload -Uz url-quote-magic
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /usr/local/share/zsh/site-functi...
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/plugins/z...
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/custom/pl...
25 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/custom/pl...
25 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:110> bindkey ' ' magic-space
25 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:109> bindkey '^r' history-increme...
25 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:104> bindkey -M vicmd '^[[1;5D' b...
25 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:15> zle -N zle-line-finish
25 /Users/matt/.oh-my-zsh/lib/history.zsh:30> [ -z /Users/matt/.zsh_history ']'
25 /Users/matt/.oh-my-zsh/lib/directories.zsh:36> alias 'l=ls -lah'
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
25 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/br...
25 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:24> autoload -Uz add-zsh-hook
25 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:74> ...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:23> ...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:22> ...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:32> [ 100...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:31> [ 500...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:30> [ -z ...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:37> a...
25 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:4> se...
25 -antigen-set-default:3> eval 'test -z "$_ANTIGEN_WARN_DUPLICATES" && typeset ...
25 -antigen-set-default:3> eval 'test -z "$_ANTIGEN_THEME_COMPAT" && typeset -g ...
25 -antigen-set-default:3> eval 'test -z "$ANTIGEN_LOG" && typeset -g ANTIGEN_LO...
25 -antigen-set-default:2> local arg_value='--single-branch --recursive --depth=1'
25 -antigen-parse-args:117> local name=https://github.com/zsh-users/zsh-syntax-h...
25 -antigen-parse-args:117> local name=https://github.com/zsh-users/zsh-autosugg...
25 -antigen-parse-args:117> local name=https://github.com/robbyrussell/oh-my-zsh...
25 -antigen-parse-args:117> local name=https://github.com/robbyrussell/oh-my-zsh...
25 -antigen-parse-args:1> local argkey key value index=0 args
25 -antigen-parse-args:1> local argkey key value index=0 args
25 -antigen-lock-init:8> [[ true == true ]]
25 -antigen-load:27> [[ 1 == 0 ]]
25 -antigen-load:27> [[ 0 == 0 ]]
25 -antigen-hook-handler:60> WARN 'Replaced hooked function.'
25 -antigen-hook-handler:56> WARN '-antigen-hook-antigen-bundle deno'
25 -antigen-hook-handler:56> WARN '-antigen-hook-antigen-bundle --loc=lib'
25 -antigen-hook-handler:51> [[ -1 == -1 ]]
25 -antigen-hook-handler:50> antigen-bundle-defer '--loc=lib'
25 -antigen-hook-handler:48> ((  1  ))
25 -antigen-hook-handler:48> ((  1  ))
25 -antigen-hook-handler:44> local replace_hook=0 ret=0
25 -antigen-hook-handler:44> local replace_hook=0 ret=0
25 -antigen-hook-handler:44> local replace_hook=0 ret=0
25 -antigen-hook-handler:44> local replace_hook=0 ret=0
25 -antigen-hook-handler:44> local replace_hook=0 ret=0
25 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-syntax-highligh...
25 -antigen-hook-handler:39> antigen-bundle-cached '--loc=lib'
25 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
25 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
25 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply mo...
25 -antigen-hook-handler:13> WARN 'Ignoring hook due to mode once: antigen-lock'
25 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
25 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
25 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
25 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
25 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
25 -antigen-hook-handler:11> meta=( target antigen-apply type pre mode once call...
25 -antigen-hook-handler:11> meta=( target antigen mode once type pre called 1 )
25 -antigen-hook-handler:11> meta=( target antigen mode once type pre called 1 )
25 -antigen-hook-handler:7> hooks=( antigen-bundle-cached antigen-bundle-parallel )
25 -antigen-hook-handler:7> hooks=( antigen-bundle-cached )
25 -antigen-hook-handler:7> hooks=( -antigen-load-source-cached )
25 -antigen-hook-handler:7> hooks=( -antigen-load-source-cached )
25 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
25 -antigen-hook-handler:4> args=( /Users/matt/.antigen/bundles/zsh-users/zsh-sy...
25 -antigen-hook-handler:4> args=( /Users/matt/.antigen/bundles/robbyrussell/oh-...
25 -antigen-hook-handler:3> shift
25 -antigen-hook-handler:1> local target=antigen-bundle args hook called
25 -antigen-hook-handler:1> local target=antigen-bundle args hook called
25 -antigen-hook-handler:1> local target=antigen-bundle args hook called
25 -antigen-hook-handler:1> local target=antigen-bundle args hook called
25 -antigen-hook-handler:1> local target=antigen args hook called
25 -antigen-hook-handler:1> local target=-antigen-load-source args hook called
25 -antigen-hook-handler:1> local target=-antigen-load-source args hook called
25 -antigen-hook-handler:1> local target=-antigen-load-env args hook called
25 -antigen-hook-antigen:10> antigen-bundle zsh-users/zsh-syntax-highlighting
25 -antigen-hook-antigen-bundle:13> local record='https://github.com/zsh-users/z...
25 -antigen-hook-antigen-bundle:13> local record='https://github.com/zsh-users/z...
25 -antigen-hook-antigen-bundle:9> [[ -z plugin ]]
25 -antigen-hook-antigen-bundle:9> [[ -z plugin ]]
25 -antigen-hook-antigen-bundle:9> [[ -z plugin ]]
25 -antigen-hook-antigen-bundle:9> [[ -z plugin ]]
25 -antigen-hook-antigen-bundle:7> typeset -A bundle
25 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
25 (eval):1> -antigen-parallel-init
25 (anon):1434> typeset -g POWERLEVEL9K_IP_INTERFACE='e.*'
25 (anon):1407> typeset -g POWERLEVEL9K_VPN_IP_CONTENT_EXPANSION=''
25 (anon):1331> typeset -g POWERLEVEL9K_GCLOUD_PARTIAL_CONTENT_EXPANSION='${P9K_...
25 (anon):1195> typeset -g POWERLEVEL9K_KUBECONTEXT_CLASSES=( '*' DEFAULT )
25 (anon):1133> typeset -g POWERLEVEL9K_TERRAFORM_SHOW_DEFAULT=false
25 (anon):1005> typeset -g POWERLEVEL9K_JAVA_VERSION_PROJECT_ONLY=true
25 (anon):983> typeset -g POWERLEVEL9K_DOTNET_VERSION_PROJECT_ONLY=true
25 (anon):935> typeset -g POWERLEVEL9K_NODENV_SHOW_SYSTEM=true
25 (anon):845> typeset -g POWERLEVEL9K_VIRTUALENV_SHOW_PYTHON_VERSION=false
25 (anon):792> typeset -g POWERLEVEL9K_TIMEWARRIOR_CONTENT_EXPANSION='${P9K_CONT...
25 (anon):755> typeset -g POWERLEVEL9K_LOAD_WARNING_FOREGROUND=178
25 (anon):739> typeset -g POWERLEVEL9K_RAM_FOREGROUND=66
25 (anon):711> typeset -g POWERLEVEL9K_DISK_USAGE_CRITICAL_FOREGROUND=160
25 (anon):677> typeset -g POWERLEVEL9K_RANGER_VISUAL_IDENTIFIER_EXPANSION=▲
25 (anon):675> typeset -g POWERLEVEL9K_RANGER_FOREGROUND=178
25 (anon):655> typeset -g POWERLEVEL9K_ASDF_HASKELL_FOREGROUND=172
25 (anon):620> typeset -g POWERLEVEL9K_ASDF_LUA_FOREGROUND=32
25 (anon):600> typeset -g POWERLEVEL9K_ASDF_NODEJS_FOREGROUND=70
25 (anon):582> typeset -g POWERLEVEL9K_ASDF_SHOW_ON_UPGLOB=''
25 (anon):516> typeset -g POWERLEVEL9K_BACKGROUND_JOBS_VISUAL_IDENTIFIER_EXPANSI...
25 (anon):512> typeset -g POWERLEVEL9K_BACKGROUND_JOBS_VERBOSE=false
25 (anon):481> typeset -g POWERLEVEL9K_STATUS_ERROR_VISUAL_IDENTIFIER_EXPANSION=✘
25 (anon):480> typeset -g POWERLEVEL9K_STATUS_ERROR_FOREGROUND=160
25 (anon):475> typeset -g POWERLEVEL9K_STATUS_OK_PIPE_VISUAL_IDENTIFIER_EXPANSION=✔
25 (anon):445> typeset -g POWERLEVEL9K_VCS_VISUAL_IDENTIFIER_EXPANSION=''
25 (anon):259> typeset -g POWERLEVEL9K_DIR_HYPERLINK=false
25 (anon):152> typeset -g POWERLEVEL9K_RIGHT_PROMPT_FIRST_SEGMENT_START_SYMBOL='...
25 (anon):125> typeset -g POWERLEVEL9K_MULTILINE_FIRST_PROMPT_GAP_CHAR=' '
25 (anon):15> action=clear
25 (anon):1> typeset -ga _ZSH_AUTOSUGGEST_BUILTIN_ACTIONS
24 is_theme:1> local base_dir=/Users/matt/.oh-my-zsh/themes
24 is_plugin:2> local name=zshfl
24 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
24 is-at-least:45> part=5
24 complete:1> emulate -L zsh
24 complete:1> emulate -L zsh
24 compinit:547> autoload -Uz compinit compaudit
24 compinit:535> zle -la menu-select
24 compinit:533> zle -C reverse-menu-complete .reverse-menu-complete _main_complete
24 compinit:533> zle -C expand-or-complete-prefix .expand-or-complete-prefix _ma...
24 compinit:516> [[ +X !=  # ]]
24 compinit:516> [[ '' !=  # ]]
24 compinit:516> [[ '' !=  # ]]
24 compinit:516> [[ '' !=  # ]]
24 compinit:515> autoload -Uz _x_visual
24 compinit:515> autoload -Uz _widgets
24 compinit:515> autoload -Uz _match
24 compinit:515> autoload -Uz _main_complete
24 compinit:515> autoload -Uz _dates
24 compinit:515> autoload -Uz _all_labels
24 compinit:508> [[ zfs = -[pPkK](n|) ]]
24 compinit:508> [[ zcompile = -[pPkK](n|) ]]
24 compinit:508> [[ xwit = -[pPkK](n|) ]]
24 compinit:508> [[ uscan = -[pPkK](n|) ]]
24 compinit:508> [[ urpme = -[pPkK](n|) ]]
24 compinit:508> [[ units = -[pPkK](n|) ]]
24 compinit:508> [[ tr = -[pPkK](n|) ]]
24 compinit:508> [[ tg = -[pPkK](n|) ]]
24 compinit:508> [[ tcp_open = -[pPkK](n|) ]]
24 compinit:508> [[ svcs = -[pPkK](n|) ]]
24 compinit:508> [[ svccfg = -[pPkK](n|) ]]
24 compinit:508> [[ svcadm = -[pPkK](n|) ]]
24 compinit:508> [[ sv = -[pPkK](n|) ]]
24 compinit:508> [[ sqsh = -[pPkK](n|) ]]
24 compinit:508> [[ sqlite = -[pPkK](n|) ]]
24 compinit:508> [[ sort = -[pPkK](n|) ]]
24 compinit:508> [[ sh = -[pPkK](n|) ]]
24 compinit:508> [[ setcap = -[pPkK](n|) ]]
24 compinit:508> [[ seq = -[pPkK](n|) ]]
24 compinit:508> [[ rxvt = -[pPkK](n|) ]]
24 compinit:508> [[ rrdtool = -[pPkK](n|) ]]
24 compinit:508> [[ rmdir = -[pPkK](n|) ]]
24 compinit:508> [[ pkg_add = -[pPkK](n|) ]]
24 compinit:508> [[ picocom = -[pPkK](n|) ]]
24 compinit:508> [[ pflags = -[pPkK](n|) ]]
24 compinit:508> [[ perldoc = -[pPkK](n|) ]]
24 compinit:508> [[ nice = -[pPkK](n|) ]]
24 compinit:508> [[ nc = -[pPkK](n|) ]]
24 compinit:508> [[ nautilus = -[pPkK](n|) ]]
24 compinit:508> [[ mt = -[pPkK](n|) ]]
24 compinit:508> [[ module-assistant = -[pPkK](n|) ]]
24 compinit:508> [[ members = -[pPkK](n|) ]]
24 compinit:508> [[ luarocks = -[pPkK](n|) ]]
24 compinit:508> [[ lsvg = -[pPkK](n|) ]]
24 compinit:508> [[ lsof = -[pPkK](n|) ]]
24 compinit:508> [[ lscfg = -[pPkK](n|) ]]
24 compinit:508> [[ limit = -[pPkK](n|) ]]
24 compinit:508> [[ kvno = -[pPkK](n|) ]]
24 compinit:508> [[ kak = -[pPkK](n|) ]]
24 compinit:508> [[ jrnl = -[pPkK](n|) ]]
24 compinit:508> [[ joe = -[pPkK](n|) ]]
24 compinit:508> [[ jmeter = -[pPkK](n|) ]]
24 compinit:508> [[ ispell = -[pPkK](n|) ]]
24 compinit:508> [[ ipadm = -[pPkK](n|) ]]
24 compinit:508> [[ initctl = -[pPkK](n|) ]]
24 compinit:508> [[ http = -[pPkK](n|) ]]
24 compinit:508> [[ gs = -[pPkK](n|) ]]
24 compinit:508> [[ grep-excuses = -[pPkK](n|) ]]
24 compinit:508> [[ gradle = -[pPkK](n|) ]]
24 compinit:508> [[ go = -[pPkK](n|) ]]
24 compinit:508> [[ global = -[pPkK](n|) ]]
24 compinit:508> [[ ghc = -[pPkK](n|) ]]
24 compinit:508> [[ genisoimage = -[pPkK](n|) ]]
24 compinit:508> [[ gcore = -[pPkK](n|) ]]
24 compinit:508> [[ freebsd-update = -[pPkK](n|) ]]
24 compinit:508> [[ finger = -[pPkK](n|) ]]
24 compinit:508> [[ feh = -[pPkK](n|) ]]
24 compinit:508> [[ fc-list = -[pPkK](n|) ]]
24 compinit:508> [[ enable = -[pPkK](n|) ]]
24 compinit:508> [[ echoti = -[pPkK](n|) ]]
24 compinit:508> [[ docpad = -[pPkK](n|) ]]
24 compinit:508> [[ doas = -[pPkK](n|) ]]
24 compinit:508> [[ dladm = -[pPkK](n|) ]]
24 compinit:508> [[ diana = -[pPkK](n|) ]]
24 compinit:508> [[ dget = -[pPkK](n|) ]]
24 compinit:508> [[ console = -[pPkK](n|) ]]
24 compinit:508> [[ coffee = -[pPkK](n|) ]]
24 compinit:508> [[ bzip2 = -[pPkK](n|) ]]
24 compinit:508> [[ bogoutil = -[pPkK](n|) ]]
24 compinit:508> [[ beep = -[pPkK](n|) ]]
24 compinit:508> [[ beadm = -[pPkK](n|) ]]
24 compinit:508> [[ base64 = -[pPkK](n|) ]]
24 compinit:508> [[ autoload = -[pPkK](n|) ]]
24 compinit:508> [[ atrm = -[pPkK](n|) ]]
24 compinit:508> [[ -zcalc-line- = -[pPkK](n|) ]]
24 compinit:508> [[ -equal- = -[pPkK](n|) ]]
24 compinit:508> [[ -K = -[pPkK](n|) ]]
24 compinit:508> [[ - = -[pPkK](n|) ]]
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #compdef (#compdef)
24 compinit:506> case #autoload (#compdef)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:506> case #autoload (#autoload)
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:505> shift _i_line
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#compdef'
24 compinit:504> _i_tag='#autoload'
24 compinit:504> _i_tag='#autoload'
24 compinit:504> _i_tag='#autoload'
24 compinit:504> _i_tag='#autoload'
24 compinit:504> _i_tag='#autoload'
24 compinit:504> _i_tag='#autoload'
24 compinit:501> ((  1 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:501> ((  0 + 0  ))
24 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_python
24 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_printenv
24 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
24 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
24 compinit:497> [[ /Users/matt/.oh-my-zsh/plugins/fasd = . ]]
24 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/plugins/fasd
24 compinit:108> typeset -gHA _comps _services _patcomps _postpatcomps
24 compinit:74> typeset _i_tag _i_file _i_addfiles _i_fail=ask _i_check=yes _i_name
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:121> shift _d_als
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:118> print -n ' 
           '
24 compdump:117> _i=5
24 compdump:116> ((  ! --_i && 524 > 1  ))
24 compdump:116> ((  ! --_i && 4 > 1  ))
24 compdump:115> print -n ' _fsh'
24 compdump:115> print -n ' _dpkg_source'
24 compdump:114> ((  ! 0  ))
24 compdump:114> ((  ! 0  ))
24 compdump:114> ((  ! 0  ))
24 compdump:114> ((  ! 0  ))
24 compdump:114> ((  ! 0  ))
24 compdump:114> ((  ! 0  ))
24 compdump:113> ((  1037  ))
24 compdump:113> ((  867  ))
24 compdump:95> read -rA _d_line
24 compdump:95> read -rA _d_line
24 compdump:95> read -rA _d_line
24 compdump:90> print -r - zle -C _most_recent_file .complete-word _most_recent_...
24 compdump:90> print -r - zle -C _list_expansions .list-choices _expand_word
24 compdump:90> print -r - zle -C _correct_word .complete-word _correct_word
24 compdump:90> print -r - zle -C _correct_filename .complete-word _correct_file...
24 compdump:90> print -r - zle -C _complete_tag .complete-word _complete_tag
24 compdump:44> print -r - ''bpython3'' ''_bpython''
24 compdump:44> print -r - ''.'' ''_source''
24 compdump:44> print -r - ''-value-,XML_CATALOG_FILES,-default-'' ''_xmlsoft''
24 compdump:44> print -r - ''-value-,ANSIBLE_STDOUT_CALLBACK,-default-'' ''_ansi...
24 compdump:44> print -r - ''-brace-parameter-'' ''_brace_parameter''
24 compdump:44> print -r - ''-array-value-'' ''_value''
24 compdef:169> shift
24 compdef:169> shift
24 compdef:169> shift
24 compdef:169> shift
24 compdef:169> shift
24 compdef:169> shift
24 compdef:164> _services[$cmd]=unpack
24 compdef:164> _services[$cmd]=gunzip
24 compdef:164> _services[$cmd]=git-diff
24 compdef:164> _services[$cmd]=git-clone
24 compdef:164> _services[$cmd]=git-checkout
24 compdef:164> _services[$cmd]=git-checkout
24 compdef:164> _services[$cmd]=bunzip2
24 compdef:164> [[ -n '' ]]
24 compdef:163> _comps[$cmd]=_omz
24 compdef:163> _comps[$cmd]=_chown
24 compdef:162> [[ -z yes || -z _zcompile ]]
24 compdef:162> [[ -z yes || -z _zcat ]]
24 compdef:162> [[ -z yes || -z _yarn ]]
24 compdef:162> [[ -z yes || -z _xwit ]]
24 compdef:162> [[ -z yes || -z _xmlstarlet ]]
24 compdef:162> [[ -z yes || -z _xfig ]]
24 compdef:162> [[ -z yes || -z _xcode-select ]]
24 compdef:162> [[ -z yes || -z _x_utils ]]
24 compdef:162> [[ -z yes || -z _wipefs ]]
24 compdef:162> [[ -z yes || -z _wg-quick ]]
24 compdef:162> [[ -z yes || -z _vnstat ]]
24 compdef:162> [[ -z yes || -z _urls ]]
24 compdef:162> [[ -z yes || -z _udisksctl ]]
24 compdef:162> [[ -z yes || -z _ttyctl ]]
24 compdef:162> [[ -z yes || -z _tree ]]
24 compdef:162> [[ -z yes || -z _teamocil ]]
24 compdef:162> [[ -z yes || -z _sysstat ]]
24 compdef:162> [[ -z yes || -z _stgit ]]
24 compdef:162> [[ -z yes || -z _stdbuf ]]
24 compdef:162> [[ -z yes || -z _setup.py ]]
24 compdef:162> [[ -z yes || -z _sdd ]]
24 compdef:162> [[ -z yes || -z _sccs ]]
24 compdef:162> [[ -z yes || -z _runit ]]
24 compdef:162> [[ -z yes || -z _rubocop ]]
24 compdef:162> [[ -z yes || -z _pygmentize ]]
24 compdef:162> [[ -z yes || -z _precommand ]]
24 compdef:162> [[ -z yes || -z _portsnap ]]
24 compdef:162> [[ -z yes || -z _ping ]]
24 compdef:162> [[ -z yes || -z _openstack ]]
24 compdef:162> [[ -z yes || -z _open ]]
24 compdef:162> [[ -z yes || -z _object_classes ]]
24 compdef:162> [[ -z yes || -z _nl ]]
24 compdef:162> [[ -z yes || -z _networkmanager ]]
24 compdef:162> [[ -z yes || -z _nano ]]
24 compdef:162> [[ -z yes || -z _mplayer ]]
24 compdef:162> [[ -z yes || -z _mh ]]
24 compdef:162> [[ -z yes || -z _mdfind ]]
24 compdef:162> [[ -z yes || -z _lsattr ]]
24 compdef:162> [[ -z yes || -z _lp ]]
24 compdef:162> [[ -z yes || -z _jexec ]]
24 compdef:162> [[ -z yes || -z _java ]]
24 compdef:162> [[ -z yes || -z _initctl ]]
24 compdef:162> [[ -z yes || -z _heroku ]]
24 compdef:162> [[ -z yes || -z _guilt ]]
24 compdef:162> [[ -z yes || -z _git-pulls ]]
24 compdef:162> [[ -z yes || -z _git ]]
24 compdef:162> [[ -z yes || -z _ghc ]]
24 compdef:162> [[ -z yes || -z _getent ]]
24 compdef:162> [[ -z yes || -z _fortune ]]
24 compdef:162> [[ -z yes || -z _fc ]]
24 compdef:162> [[ -z yes || -z _eog ]]
24 compdef:162> [[ -z yes || -z _env ]]
24 compdef:162> [[ -z yes || -z _emulate ]]
24 compdef:162> [[ -z yes || -z _elinks ]]
24 compdef:162> [[ -z yes || -z _ed ]]
24 compdef:162> [[ -z yes || -z _dvi ]]
24 compdef:162> [[ -z yes || -z _dpkg-cross ]]
24 compdef:162> [[ -z yes || -z _dpkg ]]
24 compdef:162> [[ -z yes || -z _dlocate ]]
24 compdef:162> [[ -z yes || -z _django ]]
24 compdef:162> [[ -z yes || -z _diffstat ]]
24 compdef:162> [[ -z yes || -z _diff3 ]]
24 compdef:162> [[ -z yes || -z _diff ]]
24 compdef:162> [[ -z yes || -z _dhcpinfo ]]
24 compdef:162> [[ -z yes || -z _dhclient ]]
24 compdef:162> [[ -z yes || -z _dconf ]]
24 compdef:162> [[ -z yes || -z _dchroot-dsa ]]
24 compdef:162> [[ -z yes || -z _cygpath ]]
24 compdef:162> [[ -z yes || -z _cygpath ]]
24 compdef:162> [[ -z yes || -z _cygcheck ]]
24 compdef:162> [[ -z yes || -z _cygcheck ]]
24 compdef:162> [[ -z yes || -z _cut ]]
24 compdef:162> [[ -z yes || -z _cut ]]
24 compdef:162> [[ -z yes || -z _csup ]]
24 compdef:162> [[ -z yes || -z _cplay ]]
24 compdef:162> [[ -z yes || -z _configure ]]
24 compdef:162> [[ -z yes || -z _compdef ]]
24 compdef:162> [[ -z yes || -z _comm ]]
24 compdef:162> [[ -z yes || -z _clay ]]
24 compdef:162> [[ -z yes || -z _chmod ]]
24 compdef:162> [[ -z yes || -z _ccal ]]
24 compdef:162> [[ -z yes || -z _cat ]]
24 compdef:162> [[ -z yes || -z _cat ]]
24 compdef:162> [[ -z yes || -z _btrfs ]]
24 compdef:162> [[ -z yes || -z _bpython ]]
24 compdef:162> [[ -z yes || -z _autocd ]]
24 compdef:159> cmd=ping6
24 compdef:155> [[ thor = *=* ]]
24 compdef:155> [[ pump = *=* ]]
24 compdef:155> [[ pstoedit = *=* ]]
24 compdef:155> [[ play = *=* ]]
24 compdef:155> [[ ldconfig = *=* ]]
24 compdef:155> [[ ifconfig = *=* ]]
24 compdef:155> [[ gb2sum = *=* ]]
24 compdef:155> [[ 'ggpnp=git-checkout' = *=* ]]
24 compdef:151> _postpatcomps[$1]=_yodl
24 compdef:144> _patcomps[$1]=_init_d
24 compdef:139> case  (postpattern)
24 compdef:139> case  (postpattern)
24 compdef:139> case  (*)
24 compdef:139> case  (*)
24 compdef:136> [[ rmiregistry = -P ]]
24 compdef:136> [[ pkginfo = -P ]]
24 compdef:134> [[ unrar = -p ]]
24 compdef:134> [[ ghc = -p ]]
24 compdef:134> [[ debdiff = -p ]]
24 compdef:132> [[ zypper = -N ]]
24 compdef:132> [[ wiggle = -N ]]
24 compdef:132> [[ tmuxinator = -N ]]
24 compdef:132> [[ readshortcut.exe = -N ]]
24 compdef:132> [[ mplayer = -N ]]
24 compdef:132> [[ mkshortcut = -N ]]
24 compdef:132> [[ meson = -N ]]
24 compdef:132> [[ ldconfig = -N ]]
24 compdef:132> [[ info = -N ]]
24 compdef:132> [[ gtk-launch = -N ]]
24 compdef:132> [[ exec = -N ]]
24 compdef:132> [[ ethtool = -N ]]
24 compdef:132> [[ enscript = -N ]]
24 compdef:132> [[ ecdsautil = -N ]]
24 compdef:132> [[ drill = -N ]]
24 compdef:132> [[ dpkg-source = -N ]]
24 compdef:132> [[ dkms = -N ]]
24 compdef:132> [[ dcut = -N ]]
24 compdef:132> [[ curl = -N ]]
24 compdef:132> [[ cksum = -N ]]
24 compdef:132> [[ chflags = -N ]]
24 compdef:132> [[ cdrecord = -N ]]
24 compdef:132> [[ cdrdao = -N ]]
24 compdef:132> [[ cdcd = -N ]]
24 compdef:132> [[ cal = -N ]]
24 compdef:131> ((  10  ))
24 compdef:131> ((  1  ))
24 compdef:117> shift
24 compdef:83> case  (widgetkey)
24 compdef:83> case  (widgetkey)
24 compdef:83> case  (key)
24 compdef:83> case  (key)
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:81> shift
24 compdef:80> autoload -Uz _zsocket
24 compdef:80> autoload -Uz _zsh-mime-handler
24 compdef:80> autoload -Uz _zmodload
24 compdef:80> autoload -Uz _zle
24 compdef:80> autoload -Uz _zcash-cli
24 compdef:80> autoload -Uz _yarn
24 compdef:80> autoload -Uz _xwit
24 compdef:80> autoload -Uz _xloadimage
24 compdef:80> autoload -Uz _xcode-select
24 compdef:80> autoload -Uz _xclip
24 compdef:80> autoload -Uz _xautolock
24 compdef:80> autoload -Uz _xauth
24 compdef:80> autoload -Uz _x_display
24 compdef:80> autoload -Uz _teamocil
24 compdef:80> autoload -Uz _subliminal
24 compdef:80> autoload -Uz _shutdown
24 compdef:80> autoload -Uz _setup.py
24 compdef:80> autoload -Uz _sdd
24 compdef:80> autoload -Uz _precommand
24 compdef:80> autoload -Uz _mix
24 compdef:80> autoload -Uz _lsvg
24 compdef:80> autoload -Uz _lighttpd
24 compdef:80> autoload -Uz _jq
24 compdef:80> autoload -Uz _hash
24 compdef:80> autoload -Uz _gtk-launch
24 compdef:80> autoload -Uz _fmt
24 compdef:80> autoload -Uz _espeak
24 compdef:80> autoload -Uz _env
24 compdef:80> autoload -Uz _emulator
24 compdef:80> autoload -Uz _ecasound
24 compdef:80> autoload -Uz _dpkg-repack
24 compdef:80> autoload -Uz _dkms
24 compdef:80> autoload -Uz _directories
24 compdef:80> autoload -Uz _dhcpinfo
24 compdef:80> autoload -Uz _dhclient
24 compdef:80> autoload -Uz _dcop
24 compdef:80> autoload -Uz _dak
24 compdef:80> autoload -Uz _cygstart
24 compdef:80> autoload -Uz _cscope
24 compdef:80> autoload -Uz _cowsay
24 compdef:80> autoload -Uz _configure
24 compdef:80> autoload -Uz _compadd
24 compdef:80> autoload -Uz _code
24 compdef:80> autoload -Uz _cdbs-edit-patch
24 compdef:80> autoload -Uz _ccal
24 compdef:80> autoload -Uz _alias
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:80> [[ -n yes ]]
24 compdef:79> func=_strip
24 compdef:79> func=_emulate
24 compdef:49> [[ _xargs = *=* ]]
24 compdef:49> [[ _tarsnap = *=* ]]
24 compdef:49> [[ _rsync = *=* ]]
24 compdef:49> [[ _mina = *=* ]]
24 compdef:49> [[ _debsign = *=* ]]
24 compdef:49> [[ -z '' ]]
24 compdef:49> [[ -z '' ]]
24 compdef:40> ((  ! 3  ))
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:38> shift OPTIND-1
24 compdef:29> type=widgetkey
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:17> new=yes
24 compdef:16> autol=yes
24 compdef:16> autol=yes
24 compdef:16> autol=yes
24 compdef:16> autol=yes
24 compdef:15> case n (a)
24 compdef:15> case a (a)
24 compdef:15> case a (a)
24 compdef:15> case P ([pPkK])
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:14> getopts anpPkKde opt
24 compdef:9> ((  ! 29  ))
24 compdef:9> ((  ! 16  ))
24 compdef:9> ((  ! 10  ))
24 compdef:9> ((  ! 9  ))
24 compdef:9> ((  ! 5  ))
24 compdef:9> ((  ! 5  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 4  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 3  ))
24 compdef:9> ((  ! 2  ))
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:5> setopt extendedglob
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:4> emulate -L zsh
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compdef:2> local -a match mbegin mend
24 compaudit:61> [[ -n /usr/share/zsh/5.8.1/functions ]]
24 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;36m'
24 colors:105> fg[${k#fg-}]=$'C-[[31m'
24 colors:76> local k
24 bashcompinit:177> unfunction bashcompinit
24 antigen-remove-hook:1> local hook=-antigen-load-env-cached
24 antigen-ext:5> local ret=0
24 antigen-ext:1> local ext=parallel
24 antigen-add-hook:23> ((  ! 1  ))
24 antigen-add-hook:23> ((  ! 1  ))
24 antigen-add-hook:1> local target=antigen-apply hook=antigen-apply-parallel ty...
24 add-zsh-hook:84> ((  0 == 0  ))
24 add-zsh-hook:60> ((  help || 2 != 2 || 2 == 0  ))
24 add-zsh-hook:28> getopts dDhLUzk opt
24 add-zsh-hook:28> getopts dDhLUzk opt
24 add-zsh-hook:26> integer del list help
24 add-zsh-hook:26> integer del list help
24 add-zsh-hook:26> integer del list help
24 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
24 add-zsh-hook:17> local -a hooktypes
24 add-zsh-hook:15> emulate -L zsh
24 add-zle-hook-widget:100> zstyle -- zle-line-pre-redraw widgets 1:_zsh_highlig...
24 add-zle-hook-widget:84> [[ '' != user:azhw:zle-line-pre-redraw ]]
24 add-zle-hook-widget:11> getopts dDhLUzk opt
24 add-zle-hook-widget:1> local -a hooktypes
24 _zsh_highlight_bind_widgets:50> zle -N transpose-chars _zsh_highlight_widget_...
24 _zsh_highlight_bind_widgets:50> zle -N neg-argument _zsh_highlight_widget_ori...
24 _zsh_highlight_bind_widgets:46> zle -N _read_comp _zsh_highlight_widget_orig-...
24 _zsh_highlight_bind_widgets:41> zle -N edit-command-line _zsh_highlight_widge...
24 _zsh_highlight_bind_widgets:27> case completion:.menu-select:_main_complete (...
24 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_main_complete...
24 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
24 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_alias ...
24 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
24 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
24 _zsh_highlight_bind_widgets:27> case builtin (builtin)
24 _zsh_highlight_bind_widgets:26> cur_widget=expand-word
24 /usr/local/share/antigen/antigen.zsh:16> ANTIGEN_RSRC=/Users/matt/.antigen/.r...
24 /Users/matt/.zshrc:418> export ZLIB_PREFIX=/usr/local/opt/zlib
24 /Users/matt/.zshrc:374> alias 'vim=nvim'
24 /Users/matt/.zshrc:372> alias 'v=nvim'
24 /Users/matt/.zshrc:360> export CPPFLAGS=' -I/usr/local/opt/curl/include -I/us...
24 /Users/matt/.zshrc:235> export _CE_CONDA=''
24 /Users/matt/.zshrc:216> export LDFLAGS=' -L/usr/local/opt/curl/lib'
24 /Users/matt/.zshrc:154> export THEOS_DEVICE_IP=localhost
24 /Users/matt/.zcompdump:1959> zle -C _expand_alias .complete-word _expand_alias
24 /Users/matt/.zcompdump:1957> zle -C _correct_filename .complete-word _correct...
24 /Users/matt/.zcompdump:1956> zle -C _complete_tag .complete-word _complete_tag
24 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1800> zle -C _read_comp .com...
24 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1793> zle -C _expand_alias ....
24 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1791> zle -C _correct_filena...
24 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1790> zle -C _complete_tag ....
24 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1789> zle -C _complete_help ...
24 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:126> ret=0
24 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
24 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
24 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
24 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:88> is_plugin /Users/matt/.oh-my-zsh/cust...
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;189m%}'
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;042m%}'
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;204m%}'
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;160m%}'
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;114m%}'
24 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;028m%}'
24 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /usr/share/zsh/site-functions/ur...
24 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/plugins/g...
24 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:116> bindkey 'C-xC-e' edit-comman...
24 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:24> bindkey -M viins $'C-[[5~' up...
24 /Users/matt/.oh-my-zsh/lib/directories.zsh:4> setopt pushdminus
24 /Users/matt/.oh-my-zsh/lib/completion.zsh:29> zstyle ':completion:*' special-...
24 /Users/matt/.oh-my-zsh/lib/completion.zsh:13> bindkey -M menuselect '^o' acce...
24 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
24 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
24 /Users/matt/.antigen/init.zsh:48> ZSH_CACHE_DIR=/Users/matt/.oh-my-zsh/cache
24 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
24 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
24 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
24 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
24 /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggestions/zsh-autosuggestion...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:8> autoload ...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:115>...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:108>...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:104>...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:95> ...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:14> ...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:36> setop...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/grep.zsh:5> [[ -n /Us...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:44> zs...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:31> zs...
24 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:29> zs...
24 -antigen-set-default:3> eval 'test -z "$ADOTDIR" && typeset -g ADOTDIR='''/Us...
24 -antigen-set-default:2> local arg_value=https://github.com/sorin-ionescu/prez...
24 -antigen-set-default:2> local arg_value=https://github.com/robbyrussell/oh-my...
24 -antigen-set-default:1> local arg_name=ANTIGEN_PREZTO_REPO_URL
24 -antigen-set-default:1> local arg_name=ANTIGEN_OMZ_REPO_URL
24 -antigen-set-default:1> local arg_name=ANTIGEN_LOG
24 -antigen-parse-args:160> args[name]=''robbyrussell/oh-my-zsh''
24 -antigen-parse-args:117> local name=https://github.com/zsh-users/zsh-syntax-h...
24 -antigen-parse-args:117> local name=https://github.com/robbyrussell/oh-my-zsh...
24 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
24 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
24 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
24 -antigen-parse-args:1> local argkey key value index=0 args
24 -antigen-parse-args:1> local argkey key value index=0 args
24 -antigen-hook-handler:69> LOG 'Return from hook antigen with 0'
24 -antigen-hook-handler:69> LOG 'Return from hook antigen with 0'
24 -antigen-hook-handler:50> antigen-bundle-defer deno
24 -antigen-hook-handler:44> local replace_hook=0 ret=0
24 -antigen-hook-handler:44> local replace_hook=0 ret=0
24 -antigen-hook-handler:44> local replace_hook=0 ret=0
24 -antigen-hook-handler:44> local replace_hook=0 ret=0
24 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-autosuggestions
24 -antigen-hook-handler:39> antigen-bundle-cached zsh-users/zsh-autosuggestions
24 -antigen-hook-handler:39> antigen-bundle-cached deno
24 -antigen-hook-handler:39> antigen-bundle-cached deno
24 -antigen-hook-handler:39> antigen-bundle-cached '--loc=lib'
24 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
24 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
24 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
24 -antigen-hook-handler:14> continue
24 -antigen-hook-handler:12> [[ repeat == once ]]
24 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
24 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
24 -antigen-hook-handler:11> meta=( target antigen-bundle type replace mode repe...
24 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
24 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
24 -antigen-hook-handler:11> meta=( target antigen-apply type replace mode once ...
24 -antigen-hook-handler:11> meta=( target antigen-apply mode once type post cal...
24 -antigen-hook-handler:11> meta=( target antigen mode once type pre called 1 )
24 -antigen-hook-handler:11> meta=( target -antigen-load-source type replace mod...
24 -antigen-hook-handler:7> hooks=( antigen-lock )
24 -antigen-hook-handler:7> hooks=( antigen-bundle-cached )
24 -antigen-hook-handler:7> hooks=( antigen-bundle-cached )
24 -antigen-hook-handler:7> hooks=( antigen-bundle-cached )
24 -antigen-hook-handler:7> hooks=( -antigen-load-source-cached )
24 -antigen-hook-handler:4> args=( /Users/matt/.antigen/bundles/zsh-users/zsh-au...
24 -antigen-hook-handler:1> local target=antigen-bundle args hook called
24 -antigen-hook-handler:1> local target=antigen args hook called
24 -antigen-hook-handler:1> local target=-antigen-load-env args hook called
24 -antigen-hook-handler:1> local target=-antigen-load-env args hook called
24 -antigen-hook-antigen:8> ((  1  ))
24 -antigen-hook-antigen-bundle:14> [[ true == true && ! 0 == 0 ]]
24 -antigen-hook-antigen-bundle:2> [[ -z deno ]]
24 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
24 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
24 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
24 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/z...
24 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
24 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
24 (eval):129> alias 'gra=git remote add'
24 (eval):80> alias 'gf=git fetch'
24 (eval):21> alias 'gaa=git add --all'
24 (anon):1459> typeset -g POWERLEVEL9K_WIFI_FOREGROUND=68
24 (anon):1451> typeset -g POWERLEVEL9K_BATTERY_DISCONNECTED_FOREGROUND=178
24 (anon):1373> typeset -g POWERLEVEL9K_GOOGLE_APP_CRED_CLASSES=( '*' DEFAULT )
24 (anon):1306> typeset -g POWERLEVEL9K_GCLOUD_FOREGROUND=32
24 (anon):1290> typeset -g POWERLEVEL9K_AWS_EB_ENV_VISUAL_IDENTIFIER_EXPANSION=eb
24 (anon):1056> typeset -g POWERLEVEL9K_LUAENV_SOURCES=( shell local global )
24 (anon):1040> typeset -g POWERLEVEL9K_RVM_SHOW_GEMSET=false
24 (anon):989> typeset -g POWERLEVEL9K_PHP_VERSION_FOREGROUND=99
24 (anon):891> typeset -g POWERLEVEL9K_PYENV_SOURCES=( shell local global )
24 (anon):850> typeset -g 'POWERLEVEL9K_VIRTUALENV_LEFT_DELIMITER=' 'POWERLEVEL9...
24 (anon):848> typeset -g POWERLEVEL9K_VIRTUALENV_SHOW_WITH_PYENV=false
24 (anon):830> typeset -g POWERLEVEL9K_CONTEXT_TEMPLATE=%n@%m
24 (anon):826> typeset -g POWERLEVEL9K_CONTEXT_ROOT_TEMPLATE=%B%n@%m
24 (anon):767> typeset -g POWERLEVEL9K_TODO_HIDE_ZERO_FILTERED=false
24 (anon):728> typeset -g POWERLEVEL9K_VI_OVERWRITE_MODE_STRING=OVERTYPE
24 (anon):645> typeset -g POWERLEVEL9K_ASDF_POSTGRES_FOREGROUND=31
24 (anon):625> typeset -g POWERLEVEL9K_ASDF_JAVA_FOREGROUND=32
24 (anon):504> typeset -g POWERLEVEL9K_COMMAND_EXECUTION_TIME_FORMAT='d h m s'
24 (anon):500> typeset -g POWERLEVEL9K_COMMAND_EXECUTION_TIME_PRECISION=0
24 (anon):493> typeset -g POWERLEVEL9K_STATUS_ERROR_PIPE_FOREGROUND=160
24 (anon):442> typeset -g POWERLEVEL9K_VCS_VISUAL_IDENTIFIER_COLOR=76
24 (anon):434> typeset -g POWERLEVEL9K_VCS_DISABLE_GITSTATUS_FORMATTING=true
24 (anon):158> typeset -g POWERLEVEL9K_EMPTY_LINE_LEFT_PROMPT_LAST_SEGMENT_END_S...
24 (anon):154> typeset -g POWERLEVEL9K_LEFT_PROMPT_FIRST_SEGMENT_START_SYMBOL=''
24 (anon):142> typeset -g POWERLEVEL9K_LEFT_SUBSEGMENT_SEPARATOR='%242FuE0B1'
24 (anon):19> zle -N autosuggest-fetch _zsh_autosuggest_widget_fetch
24 (anon):1> local action
23 is_plugin:2> local name=zsh-autosuggestions
23 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh/custom
23 env_default:1> [[ scalar-export = *-export* ]]
23 complete:8> [[ -n '' ]]
23 compinit:533> zle -C expand-or-complete .expand-or-complete _main_complete
23 compinit:516> [[ '' !=  # ]]
23 compinit:515> autoload -Uz _describe
23 compinit:508> [[ xmms2 = -[pPkK](n|) ]]
23 compinit:508> [[ which = -[pPkK](n|) ]]
23 compinit:508> [[ w = -[pPkK](n|) ]]
23 compinit:508> [[ vserver = -[pPkK](n|) ]]
23 compinit:508> [[ update-alternatives = -[pPkK](n|) ]]
23 compinit:508> [[ tty = -[pPkK](n|) ]]
23 compinit:508> [[ truss = -[pPkK](n|) ]]
23 compinit:508> [[ transmission-remote = -[pPkK](n|) ]]
23 compinit:508> [[ tpkg-install = -[pPkK](n|) ]]
23 compinit:508> [[ totdconfig = -[pPkK](n|) ]]
23 compinit:508> [[ stow = -[pPkK](n|) ]]
23 compinit:508> [[ ssh = -[pPkK](n|) ]]
23 compinit:508> [[ smbcontrol = -[pPkK](n|) ]]
23 compinit:508> [[ showmount = -[pPkK](n|) ]]
23 compinit:508> [[ scselect = -[pPkK](n|) ]]
23 compinit:508> [[ screen = -[pPkK](n|) ]]
23 compinit:508> [[ sched = -[pPkK](n|) ]]
23 compinit:508> [[ rsync = -[pPkK](n|) ]]
23 compinit:508> [[ rlogin = -[pPkK](n|) ]]
23 compinit:508> [[ pv = -[pPkK](n|) ]]
23 compinit:508> [[ pscp = -[pPkK](n|) ]]
23 compinit:508> [[ ps2epsi = -[pPkK](n|) ]]
23 compinit:508> [[ powerd = -[pPkK](n|) ]]
23 compinit:508> [[ pidof = -[pPkK](n|) ]]
23 compinit:508> [[ perl = -[pPkK](n|) ]]
23 compinit:508> [[ pbuilder = -[pPkK](n|) ]]
23 compinit:508> [[ pbcopy = -[pPkK](n|) ]]
23 compinit:508> [[ nedit = -[pPkK](n|) ]]
23 compinit:508> [[ mtn = -[pPkK](n|) ]]
23 compinit:508> [[ mplayer = -[pPkK](n|) ]]
23 compinit:508> [[ module = -[pPkK](n|) ]]
23 compinit:508> [[ mktemp = -[pPkK](n|) ]]
23 compinit:508> [[ mii-tool = -[pPkK](n|) ]]
23 compinit:508> [[ mencal = -[pPkK](n|) ]]
23 compinit:508> [[ ltrace = -[pPkK](n|) ]]
23 compinit:508> [[ lslv = -[pPkK](n|) ]]
23 compinit:508> [[ locate = -[pPkK](n|) ]]
23 compinit:508> [[ locale = -[pPkK](n|) ]]
23 compinit:508> [[ ldd = -[pPkK](n|) ]]
23 compinit:508> [[ last = -[pPkK](n|) ]]
23 compinit:508> [[ kldload = -[pPkK](n|) ]]
23 compinit:508> [[ kdeconnect-cli = -[pPkK](n|) ]]
23 compinit:508> [[ ip = -[pPkK](n|) ]]
23 compinit:508> [[ ionice = -[pPkK](n|) ]]
23 compinit:508> [[ install = -[pPkK](n|) ]]
23 compinit:508> [[ id = -[pPkK](n|) ]]
23 compinit:508> [[ gtk-launch = -[pPkK](n|) ]]
23 compinit:508> [[ getent = -[pPkK](n|) ]]
23 compinit:508> [[ gdb = -[pPkK](n|) ]]
23 compinit:508> [[ gas = -[pPkK](n|) ]]
23 compinit:508> [[ fuser = -[pPkK](n|) ]]
23 compinit:508> [[ fmt = -[pPkK](n|) ]]
23 compinit:508> [[ cp = -[pPkK](n|) ]]
23 compinit:508> [[ btrfs = -[pPkK](n|) ]]
23 compinit:508> [[ bibtex = -[pPkK](n|) ]]
23 compinit:508> [[ baz = -[pPkK](n|) ]]
23 compinit:508> [[ bash = -[pPkK](n|) ]]
23 compinit:508> [[ aws = -[pPkK](n|) ]]
23 compinit:508> [[ apt-move = -[pPkK](n|) ]]
23 compinit:508> [[ aplay = -[pPkK](n|) ]]
23 compinit:508> [[ ant = -[pPkK](n|) ]]
23 compinit:508> [[ animate = -[pPkK](n|) ]]
23 compinit:508> [[ acpitool = -[pPkK](n|) ]]
23 compinit:508> [[ acpi = -[pPkK](n|) ]]
23 compinit:508> [[ _cockroach = -[pPkK](n|) ]]
23 compinit:508> [[ -k = -[pPkK](n|) ]]
23 compinit:508> [[ -P = -[pPkK](n|) ]]
23 compinit:506> case #compdef (#compdef)
23 compinit:506> case #compdef (#compdef)
23 compinit:506> case #compdef (#compdef)
23 compinit:506> case #compdef (#compdef)
23 compinit:506> case #autoload (#autoload)
23 compinit:506> case #autoload (#autoload)
23 compinit:506> case #autoload (#autoload)
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:505> shift _i_line
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#compdef'
23 compinit:504> _i_tag='#autoload'
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:501> ((  0 + 0  ))
23 compinit:500> _i_name=_zmv
23 compinit:500> _i_name=_prefix
23 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sc_usage
23 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_growisofs
23 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_complete_help
23 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
23 compinit:497> [[ /Users/matt/.oh-my-zsh/plugins/git = . ]]
23 compinit:74> typeset _i_tag _i_file _i_addfiles _i_fail=ask _i_check=yes _i_name
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:121> shift _d_als
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:118> print -n ' 
           '
23 compdump:116> ((  ! --_i && 329 > 1  ))
23 compdump:115> print -n ' _yp'
23 compdump:114> ((  ! 0  ))
23 compdump:114> ((  ! 0  ))
23 compdump:114> ((  ! 0  ))
23 compdump:114> ((  ! 0  ))
23 compdump:113> ((  378  ))
23 compdump:95> read -rA _d_line
23 compdump:90> print -r - zle -C _history-complete-newer .complete-word _histor...
23 compdump:63> print -r - ''(p[bgpn]m*|*top[bgpn]m)'' ''_pbm''
23 compdump:62> _d_f=(p[bgpn]m*|*top[bgpn]m)
23 compdump:50> print -r - ''-redirect-,<,uncompress'' ''uncompress''
23 compdump:44> print -r - ''ruby-mri'' ''_ruby''
23 compdump:44> print -r - ''inc'' ''_mh''
23 compdump:44> print -r - ''grm'' ''_rm''
23 compdump:44> print -r - ''ansible-galaxy'' ''_ansible''
23 compdump:44> print -r - ''-value-,VALGRIND_OPTS,-default-'' ''_valgrind''
23 compdump:44> print -r - ''-value-,RPS1,-default-'' ''_ps1234''
23 compdump:44> print -r - ''-value-,PS2,-default-'' ''_ps1234''
23 compdump:44> print -r - ''-value-,MPD_HOST,-default'' ''_mpc''
23 compdump:44> print -r - ''-value-,LESSCHARSET,-default-'' ''_less''
23 compdump:44> print -r - ''-value-,CXXFLAGS,-default-'' ''_gcc''
23 compdump:44> print -r - ''-value-,CFLAGS,-default-'' ''_gcc''
23 compdump:44> print -r - ''-value-,ANT_ARGS,-default-'' ''_ant''
23 compdump:44> print -r - ''-value-,ANDROID_LOG_TAGS,-default-'' ''_adb''
23 compdump:44> print -r - ''-value-,-default-,-default-'' ''_value''
23 compdump:44> print -r - ''-redirect-,-default-,-default-'' ''_files''
23 compdump:44> print -r - ''-equal-'' ''_equal''
23 compdump:44> print -r - ''-condition-'' ''_condition''
23 compdef:169> shift
23 compdef:169> shift
23 compdef:169> shift
23 compdef:169> shift
23 compdef:169> shift
23 compdef:164> _services[$cmd]=unxz
23 compdef:164> _services[$cmd]=mail
23 compdef:164> _services[$cmd]=chown
23 compdef:162> [[ -z yes || -z _zmv ]]
23 compdef:162> [[ -z yes || -z _x_utils ]]
23 compdef:162> [[ -z yes || -z _x_display ]]
23 compdef:162> [[ -z yes || -z _urpmi ]]
23 compdef:162> [[ -z yes || -z _trash-restore ]]
23 compdef:162> [[ -z yes || -z _trash ]]
23 compdef:162> [[ -z yes || -z _sysstat ]]
23 compdef:162> [[ -z yes || -z _stat ]]
23 compdef:162> [[ -z yes || -z _srm ]]
23 compdef:162> [[ -z yes || -z _showoff ]]
23 compdef:162> [[ -z yes || -z _sbt ]]
23 compdef:162> [[ -z yes || -z _rsvm ]]
23 compdef:162> [[ -z yes || -z _redis-cli ]]
23 compdef:162> [[ -z yes || -z _rdesktop ]]
23 compdef:162> [[ -z yes || -z _ralio ]]
23 compdef:162> [[ -z yes || -z _pspdf ]]
23 compdef:162> [[ -z yes || -z _postgresql ]]
23 compdef:162> [[ -z yes || -z _postgresql ]]
23 compdef:162> [[ -z yes || -z _perldoc ]]
23 compdef:162> [[ -z yes || -z _periscope ]]
23 compdef:162> [[ -z yes || -z _patool ]]
23 compdef:162> [[ -z yes || -z _openstack ]]
23 compdef:162> [[ -z yes || -z _ninja ]]
23 compdef:162> [[ -z yes || -z _mkdir ]]
23 compdef:162> [[ -z yes || -z _mkdir ]]
23 compdef:162> [[ -z yes || -z _mdadm ]]
23 compdef:162> [[ -z yes || -z _kubectl ]]
23 compdef:162> [[ -z yes || -z _ispell ]]
23 compdef:162> [[ -z yes || -z _guilt ]]
23 compdef:162> [[ -z yes || -z _ghc ]]
23 compdef:162> [[ -z yes || -z _fmadm ]]
23 compdef:162> [[ -z yes || -z _ffmpeg ]]
23 compdef:162> [[ -z yes || -z _etags ]]
23 compdef:162> [[ -z yes || -z _espeak ]]
23 compdef:162> [[ -z yes || -z _dupload ]]
23 compdef:162> [[ -z yes || -z _dpkg-repack ]]
23 compdef:162> [[ -z yes || -z _dpatch-edit-patch ]]
23 compdef:162> [[ -z yes || -z _dnf ]]
23 compdef:162> [[ -z yes || -z _django ]]
23 compdef:162> [[ -z yes || -z _diana ]]
23 compdef:162> [[ -z yes || -z _dhclient ]]
23 compdef:162> [[ -z yes || -z _dchroot ]]
23 compdef:162> [[ -z yes || -z _dbus ]]
23 compdef:162> [[ -z yes || -z _date ]]
23 compdef:162> [[ -z yes || -z _cygstart ]]
23 compdef:162> [[ -z yes || -z _cygstart ]]
23 compdef:162> [[ -z yes || -z _cygserver ]]
23 compdef:162> [[ -z yes || -z _cygserver ]]
23 compdef:162> [[ -z yes || -z _cvs ]]
23 compdef:162> [[ -z yes || -z _cssh ]]
23 compdef:162> [[ -z yes || -z _crontab ]]
23 compdef:162> [[ -z yes || -z _concourse ]]
23 compdef:162> [[ -z yes || -z _compadd ]]
23 compdef:162> [[ -z yes || -z _command ]]
23 compdef:162> [[ -z yes || -z _cmp ]]
23 compdef:162> [[ -z yes || -z _chroot ]]
23 compdef:162> [[ -z yes || -z _chroot ]]
23 compdef:162> [[ -z yes || -z _calendar ]]
23 compdef:162> [[ -z yes || -z _bzip2 ]]
23 compdef:162> [[ -z yes || -z _at ]]
23 compdef:162> [[ -z yes || -z _alias ]]
23 compdef:159> cmd=yt-dlp
23 compdef:159> cmd=txt
23 compdef:159> cmd=delta
23 compdef:155> [[ newgrp = *=* ]]
23 compdef:155> [[ ksh88 = *=* ]]
23 compdef:155> [[ debdiff = *=* ]]
23 compdef:155> [[ dash = *=* ]]
23 compdef:155> [[ aoss = *=* ]]
23 compdef:139> case  (postpattern)
23 compdef:139> case  (pattern)
23 compdef:139> case  (pattern)
23 compdef:139> case  (*)
23 compdef:136> [[ django-admin = -P ]]
23 compdef:134> [[ nmblookup = -p ]]
23 compdef:132> [[ zlogin = -N ]]
23 compdef:132> [[ tpkg-install = -N ]]
23 compdef:132> [[ redis-cli = -N ]]
23 compdef:132> [[ ralio = -N ]]
23 compdef:132> [[ networksetup = -N ]]
23 compdef:132> [[ mpv = -N ]]
23 compdef:132> [[ mdadm = -N ]]
23 compdef:132> [[ last = -N ]]
23 compdef:132> [[ kpartx = -N ]]
23 compdef:132> [[ hostname = -N ]]
23 compdef:132> [[ fortune = -N ]]
23 compdef:132> [[ evince = -N ]]
23 compdef:132> [[ dvips = -N ]]
23 compdef:132> [[ dpkg-repack = -N ]]
23 compdef:132> [[ dpkg-buildpackage = -N ]]
23 compdef:132> [[ devtodo = -N ]]
23 compdef:132> [[ dchroot-dsa = -N ]]
23 compdef:132> [[ cpio = -N ]]
23 compdef:132> [[ chrt = -N ]]
23 compdef:132> [[ chcon = -N ]]
23 compdef:132> [[ apt-move = -N ]]
23 compdef:132> [[ -default- = -N ]]
23 compdef:132> [[ '(p[bgpn]m*|*top[bgpn]m)' = -N ]]
23 compdef:131> ((  3  ))
23 compdef:117> shift
23 compdef:83> case  (widgetkey)
23 compdef:83> case  (widgetkey)
23 compdef:83> case  (widgetkey)
23 compdef:83> case  (widgetkey)
23 compdef:83> case  (*)
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:81> shift
23 compdef:80> autoload -Uz _zstyle
23 compdef:80> autoload -Uz _zmv
23 compdef:80> autoload -Uz _xmlsoft
23 compdef:80> autoload -Uz _xft_fonts
23 compdef:80> autoload -Uz _x_utils
23 compdef:80> autoload -Uz _x_arguments
23 compdef:80> autoload -Uz _vmstat
23 compdef:80> autoload -Uz _urxvt
23 compdef:80> autoload -Uz _urls
23 compdef:80> autoload -Uz _udisksctl
23 compdef:80> autoload -Uz _trash-put
23 compdef:80> autoload -Uz _top
23 compdef:80> autoload -Uz _tilde
23 compdef:80> autoload -Uz _strip
23 compdef:80> autoload -Uz _scala
23 compdef:80> autoload -Uz _rfkill
23 compdef:80> autoload -Uz _redis-cli
23 compdef:80> autoload -Uz _quilt
23 compdef:80> autoload -Uz _pygmentize
23 compdef:80> autoload -Uz _pscp
23 compdef:80> autoload -Uz _patool
23 compdef:80> autoload -Uz _nvm
23 compdef:80> autoload -Uz _nkf
23 compdef:80> autoload -Uz _lunchy
23 compdef:80> autoload -Uz _jobs_builtin
23 compdef:80> autoload -Uz _hostname
23 compdef:80> autoload -Uz _heroku
23 compdef:80> autoload -Uz _flutter
23 compdef:80> autoload -Uz _equal
23 compdef:80> autoload -Uz _emulate
23 compdef:80> autoload -Uz _e2label
23 compdef:80> autoload -Uz _dtrace
23 compdef:80> autoload -Uz _dpatch-edit-patch
23 compdef:80> autoload -Uz _dnf
23 compdef:80> autoload -Uz _cu
23 compdef:80> autoload -Uz _comm
23 compdef:80> autoload -Uz _ant
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:80> [[ -n yes ]]
23 compdef:49> [[ _thor = *=* ]]
23 compdef:49> [[ _snap = *=* ]]
23 compdef:49> [[ _mtr = *=* ]]
23 compdef:49> [[ _mount = *=* ]]
23 compdef:49> [[ _locales = *=* ]]
23 compdef:49> [[ -z '' ]]
23 compdef:45> [[ -z '' ]]
23 compdef:40> ((  ! 2  ))
23 compdef:40> ((  ! 2  ))
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:38> shift OPTIND-1
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:17> new=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:16> autol=yes
23 compdef:15> case a (a)
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:14> getopts anpPkKde opt
23 compdef:9> ((  ! 5  ))
23 compdef:9> ((  ! 5  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 4  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:9> ((  ! 3  ))
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:5> setopt extendedglob
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:4> emulate -L zsh
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compdef:2> local -a match mbegin mend
23 compaudit:163> [[ -n '' ]]
23 compaudit:163> [[ -n '' ]]
23 compaudit:102> [[ -e /proc/87947/object/a.out ]]
23 colors:115> bg_bold[${k#bg-}]=$'C-[[01;41m'
23 colors:77> color[${color[$k]}]=42
23 colors:6> typeset -Ag color colour
23 antigen-ext:5> local ret=0
23 antigen-ext:3> ((  1 && 0 == 0  ))
23 antigen-ext:2> local func=-antigen-lock-init
23 antigen-bundle-parallel-execute:11> typeset -A bundle
23 antigen-bundle-parallel-execute:11> -antigen-parse-args bundle deno
23 antigen-bundle-defer:1> _DEFERRED_BUNDLE+=( zsh-users/zsh-syntax-highlighting )
23 antigen-apply:1> -antigen-hook-handler antigen-apply
23 antigen-apply:1> -antigen-hook-handler antigen-apply
23 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply type re...
23 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply type pr...
23 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply type po...
23 antigen-add-hook:1> local target=antigen-bundle hook=antigen-bundle-defer typ...
23 antigen-add-hook:1> local target=antigen-apply hook=antigen-apply-parallel-ex...
23 add-zsh-hook:84> ((  3 == 0  ))
23 add-zsh-hook:28> getopts dDhLUzk opt
23 add-zsh-hook:26> integer del list help
23 add-zle-hook-widget:9> integer del list help
23 _zsh_highlight_bind_widgets:50> zle -N vi-repeat-change _zsh_highlight_widget...
23 _zsh_highlight_bind_widgets:50> zle -N vi-match-bracket _zsh_highlight_widget...
23 _zsh_highlight_bind_widgets:50> zle -N vi-history-search-forward _zsh_highlig...
23 _zsh_highlight_bind_widgets:50> zle -N vi-goto-mark _zsh_highlight_widget_ori...
23 _zsh_highlight_bind_widgets:50> zle -N vi-change-whole-line _zsh_highlight_wi...
23 _zsh_highlight_bind_widgets:50> zle -N vi-backward-delete-char _zsh_highlight...
23 _zsh_highlight_bind_widgets:50> zle -N vi-backward-blank-word-end _zsh_highli...
23 _zsh_highlight_bind_widgets:50> zle -N history-search-forward _zsh_highlight_...
23 _zsh_highlight_bind_widgets:50> zle -N history-incremental-search-backward _z...
23 _zsh_highlight_bind_widgets:50> zle -N execute-last-named-cmd _zsh_highlight_...
23 _zsh_highlight_bind_widgets:50> zle -N copy-prev-word _zsh_highlight_widget_o...
23 _zsh_highlight_bind_widgets:50> zle -N accept-and-infer-next-history _zsh_hig...
23 _zsh_highlight_bind_widgets:46> zle -N expand-or-complete-prefix _zsh_highlig...
23 _zsh_highlight_bind_widgets:46> zle -N delete-char-or-list _zsh_highlight_wid...
23 _zsh_highlight_bind_widgets:27> case user:down-line-or-beginning-search (user:*)
23 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_bash_completio...
23 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete:_main_com...
23 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
23 _zsh_highlight_bind_widgets:27> case builtin (user:*)
23 _zsh_highlight_bind_widgets:27> case builtin (builtin)
23 _zsh_highlight_bind_widgets:27> case builtin (builtin)
23 /usr/local/share/antigen/antigen.zsh:1398> _ANTIGEN_HOOKS=( )
23 /Users/matt/.zshrc:419> export SQLITE_PREFIX=/usr/local/opt/sqlite
23 /Users/matt/.zshrc:217> export CPPFLAGS=' -I/usr/local/opt/curl/include'
23 /Users/matt/.zcompdump:2204> typeset -gUa _comp_assocs
23 /Users/matt/.zcompdump:1966> zle -C _read_comp .complete-word _read_comp
23 /Users/matt/.zcompdump:1964> zle -C _most_recent_file .complete-word _most_re...
23 /Users/matt/.zcompdump:1955> zle -C _complete_help .complete-word _complete_help
23 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1801> bindkey '^X^R' _read_comp
23 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1792> zle -C _correct_word ....
23 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:5> ZSH_THEME_GIT_PROMPT_...
23 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:4> ZSH_THEME_GIT_PROMPT_...
23 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;101m%}'
23 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;057m%}'
23 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;072m%}'
23 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:100> bindkey -M vicmd '^[[1;5C' f...
23 /Users/matt/.oh-my-zsh/lib/history.zsh:35> setopt extended_history
23 /Users/matt/.oh-my-zsh/lib/grep.zsh:5> [[ -n /Users/matt/.oh-my-zsh/cache/gre...
23 /Users/matt/.oh-my-zsh/lib/directories.zsh:37> alias 'll=ls -lh'
23 /Users/matt/.oh-my-zsh/lib/completion.zsh:31> zstyle ':completion:*' list-col...
23 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
23 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
23 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/highlighters/ma...
23 /Users/matt/.oh-my-zsh/cache/grep-alias:2> alias 'egrep=egrep --color=auto --...
23 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:2> alias 's=fasd -si'
23 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2copy=/Users/matt/.it...
23 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
23 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:100>...
23 -antigen-set-default:2> local arg_value=true
23 -antigen-set-default:2> local arg_value='lock parallel defer cache'
23 -antigen-parse-args:160> args[name]=''robbyrussell/oh-my-zsh''
23 -antigen-parse-args:117> local name=https://github.com/zsh-users/zsh-autosugg...
23 -antigen-parse-args:69> [[ zsh-users/zsh-syntax-highlighting != */* ]]
23 -antigen-parse-args:55> value=zsh-users/zsh-syntax-highlighting
23 -antigen-parse-args:41> local domain=''
23 -antigen-parse-args:41> local domain=''
23 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
23 -antigen-parse-args:1> local argkey key value index=0 args
23 -antigen-load:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/pl...
23 -antigen-load:1> local bundle list
23 -antigen-hook-handler:56> WARN '-antigen-hook-antigen-apply '
23 -antigen-hook-handler:51> [[ 0 == -1 ]]
23 -antigen-hook-handler:44> local replace_hook=0 ret=0
23 -antigen-hook-handler:44> local replace_hook=0 ret=0
23 -antigen-hook-handler:44> local replace_hook=0 ret=0
23 -antigen-hook-handler:44> local replace_hook=0 ret=0
23 -antigen-hook-handler:39> antigen-bundle-cached '--loc=lib'
23 -antigen-hook-handler:37> hook=antigen-bundle-cached
23 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
23 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle m...
23 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply mo...
23 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply mo...
23 -antigen-hook-handler:12> [[ repeat == once ]]
23 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type repla...
23 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
23 -antigen-hook-handler:11> meta=( target antigen-apply mode once type post cal...
23 -antigen-hook-handler:10> hook=antigen-apply-cached
23 -antigen-hook-handler:7> hooks=( antigen-lock )
23 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
23 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
23 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
23 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
23 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
23 -antigen-hook-handler:2> local hooks meta
23 -antigen-hook-handler:1> local target=antigen-bundle args hook called
23 -antigen-hook-handler:1> local target=-antigen-load-source args hook called
23 -antigen-hook-antigen:2> [[ -z use ]]
23 -antigen-hook-antigen:1> local cmd=use
23 -antigen-hook-antigen-bundle:14> [[ true == true && ! 0 == 0 ]]
23 -antigen-hook-antigen-bundle:13> local record='https://github.com/robbyrussel...
23 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
23 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-a...
23 (eval):104> alias 'glods=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
23 (eval):103> alias 'glod=git log --graph --pretty='''%Cred%h%Creset -%C(auto)%...
23 (anon):1410> typeset -g POWERLEVEL9K_VPN_IP_INTERFACE='(gpd|wg|(.*tun))[0-9]*'
23 (anon):1345> typeset -g POWERLEVEL9K_GOOGLE_APP_CRED_SHOW_ON_COMMAND='terrafo...
23 (anon):1337> typeset -g POWERLEVEL9K_GCLOUD_REFRESH_PROJECT_NAME_SECONDS=60
23 (anon):1283> typeset -g POWERLEVEL9K_AWS_DEFAULT_FOREGROUND=208
23 (anon):1254> typeset -g POWERLEVEL9K_AWS_SHOW_ON_COMMAND='aws|awless|terrafor...
23 (anon):1200> typeset -g POWERLEVEL9K_KUBECONTEXT_DEFAULT_VISUAL_IDENTIFIER_EX...
23 (anon):1199> typeset -g POWERLEVEL9K_KUBECONTEXT_DEFAULT_FOREGROUND=134
23 (anon):1161> typeset -g POWERLEVEL9K_TERRAFORM_OTHER_FOREGROUND=38
23 (anon):1113> typeset -g POWERLEVEL9K_SCALAENV_SHOW_SYSTEM=true
23 (anon):1095> typeset -g POWERLEVEL9K_PHPENV_SOURCES=( shell local global )
23 (anon):1085> typeset -g POWERLEVEL9K_PLENV_PROMPT_ALWAYS_SHOW=false
23 (anon):1082> typeset -g POWERLEVEL9K_PLENV_SOURCES=( shell local global )
23 (anon):1072> typeset -g POWERLEVEL9K_JENV_PROMPT_ALWAYS_SHOW=false
23 (anon):1069> typeset -g POWERLEVEL9K_JENV_SOURCES=( shell local global )
23 (anon):928> typeset -g POWERLEVEL9K_NODENV_FOREGROUND=70
23 (anon):896> typeset -g POWERLEVEL9K_PYENV_SHOW_SYSTEM=true
23 (anon):735> typeset -g POWERLEVEL9K_RANGER_VISUAL_IDENTIFIER_EXPANSION=▲
23 (anon):650> typeset -g POWERLEVEL9K_ASDF_PHP_FOREGROUND=99
23 (anon):640> typeset -g POWERLEVEL9K_ASDF_ELIXIR_FOREGROUND=129
23 (anon):595> typeset -g POWERLEVEL9K_ASDF_GOLANG_FOREGROUND=37
23 (anon):563> typeset -g POWERLEVEL9K_ASDF_PROMPT_ALWAYS_SHOW=false
23 (anon):494> typeset -g POWERLEVEL9K_STATUS_ERROR_PIPE_VISUAL_IDENTIFIER_EXPAN...
23 (anon):487> typeset -g POWERLEVEL9K_STATUS_VERBOSE_SIGNAME=false
23 (anon):469> typeset -g POWERLEVEL9K_STATUS_OK_VISUAL_IDENTIFIER_EXPANSION=✔
23 (anon):468> typeset -g POWERLEVEL9K_STATUS_OK_FOREGROUND=70
23 (anon):452> typeset -g POWERLEVEL9K_VCS_BACKENDS=( git )
23 (anon):248> typeset -g POWERLEVEL9K_DIR_MAX_LENGTH=80
23 (anon):201> typeset -g POWERLEVEL9K_DIR_ANCHOR_FOREGROUND=39
23 (anon):128> [[ ' ' !=   ]]
23 (anon):117> typeset -g POWERLEVEL9K_MULTILINE_FIRST_PROMPT_SUFFIX=''
23 (anon):109> typeset -g POWERLEVEL9K_PROMPT_ADD_NEWLINE=true
23 (anon):25> zle -N autosuggest-disable _zsh_autosuggest_widget_disable
22 regexp-replace:34> 6=1
22 regexp-replace:11> integer pcre
22 is_plugin:2> local name=zsh-completions
22 is-at-least:32> ((  ++ver_cnt > 4  ))
22 handle_completion_insecurities:16> return
22 compinit:547> autoload -Uz compinit compaudit
22 compinit:530> _i_line=reverse-menu-complete
22 compinit:530> _i_line=delete-char-or-list
22 compinit:530> _i_line=complete-word
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:516> [[ '' !=  # ]]
22 compinit:515> autoload -Uz _zones
22 compinit:515> autoload -Uz _x_window
22 compinit:515> autoload -Uz _x_selection_timeout
22 compinit:515> autoload -Uz _physical_volumes
22 compinit:515> autoload -Uz _next_label
22 compinit:515> autoload -Uz _history_modifiers
22 compinit:515> autoload -Uz _guard
22 compinit:515> autoload -Uz _dict_words
22 compinit:515> autoload -Uz _delimiters
22 compinit:515> autoload -Uz _deb_files
22 compinit:508> [[ zargs = -[pPkK](n|) ]]
22 compinit:508> [[ xscreensaver-command = -[pPkK](n|) ]]
22 compinit:508> [[ write = -[pPkK](n|) ]]
22 compinit:508> [[ who = -[pPkK](n|) ]]
22 compinit:508> [[ vncserver = -[pPkK](n|) ]]
22 compinit:508> [[ vared = -[pPkK](n|) ]]
22 compinit:508> [[ valgrind = -[pPkK](n|) ]]
22 compinit:508> [[ unace = -[pPkK](n|) ]]
22 compinit:508> [[ trash = -[pPkK](n|) ]]
22 compinit:508> [[ tracepath = -[pPkK](n|) ]]
22 compinit:508> [[ tpb = -[pPkK](n|) ]]
22 compinit:508> [[ touch = -[pPkK](n|) ]]
22 compinit:508> [[ toilet = -[pPkK](n|) ]]
22 compinit:508> [[ tla = -[pPkK](n|) ]]
22 compinit:508> [[ tar = -[pPkK](n|) ]]
22 compinit:508> [[ systat = -[pPkK](n|) ]]
22 compinit:508> [[ swaks = -[pPkK](n|) ]]
22 compinit:508> [[ svn-buildpackage = -[pPkK](n|) ]]
22 compinit:508> [[ svn = -[pPkK](n|) ]]
22 compinit:508> [[ stg = -[pPkK](n|) ]]
22 compinit:508> [[ stat = -[pPkK](n|) ]]
22 compinit:508> [[ softwareupdate = -[pPkK](n|) ]]
22 compinit:508> [[ sisu = -[pPkK](n|) ]]
22 compinit:508> [[ set = -[pPkK](n|) ]]
22 compinit:508> [[ service = -[pPkK](n|) ]]
22 compinit:508> [[ scons = -[pPkK](n|) ]]
22 compinit:508> [[ sc_usage = -[pPkK](n|) ]]
22 compinit:508> [[ say = -[pPkK](n|) ]]
22 compinit:508> [[ rubber = -[pPkK](n|) ]]
22 compinit:508> [[ rebootin = -[pPkK](n|) ]]
22 compinit:508> [[ readlink = -[pPkK](n|) ]]
22 compinit:508> [[ postconf = -[pPkK](n|) ]]
22 compinit:508> [[ portaudit = -[pPkK](n|) ]]
22 compinit:508> [[ pmap = -[pPkK](n|) ]]
22 compinit:508> [[ pdftk = -[pPkK](n|) ]]
22 compinit:508> [[ passwd = -[pPkK](n|) ]]
22 compinit:508> [[ pack = -[pPkK](n|) ]]
22 compinit:508> [[ opkg = -[pPkK](n|) ]]
22 compinit:508> [[ oggenc = -[pPkK](n|) ]]
22 compinit:508> [[ mv = -[pPkK](n|) ]]
22 compinit:508> [[ mtr = -[pPkK](n|) ]]
22 compinit:508> [[ mpstat = -[pPkK](n|) ]]
22 compinit:508> [[ mknod = -[pPkK](n|) ]]
22 compinit:508> [[ mkdir = -[pPkK](n|) ]]
22 compinit:508> [[ mixerctl = -[pPkK](n|) ]]
22 compinit:508> [[ lzop = -[pPkK](n|) ]]
22 compinit:508> [[ lz4 = -[pPkK](n|) ]]
22 compinit:508> [[ lua = -[pPkK](n|) ]]
22 compinit:508> [[ linux = -[pPkK](n|) ]]
22 compinit:508> [[ ldap = -[pPkK](n|) ]]
22 compinit:508> [[ kill = -[pPkK](n|) ]]
22 compinit:508> [[ kfmclient = -[pPkK](n|) ]]
22 compinit:508> [[ jail = -[pPkK](n|) ]]
22 compinit:508> [[ irssi = -[pPkK](n|) ]]
22 compinit:508> [[ ipsec = -[pPkK](n|) ]]
22 compinit:508> [[ iostat = -[pPkK](n|) ]]
22 compinit:508> [[ ifconfig = -[pPkK](n|) ]]
22 compinit:508> [[ hwinfo = -[pPkK](n|) ]]
22 compinit:508> [[ homestead = -[pPkK](n|) ]]
22 compinit:508> [[ hexdump = -[pPkK](n|) ]]
22 compinit:508> [[ head = -[pPkK](n|) ]]
22 compinit:508> [[ hdiutil = -[pPkK](n|) ]]
22 compinit:508> [[ google = -[pPkK](n|) ]]
22 compinit:508> [[ gnome-gv = -[pPkK](n|) ]]
22 compinit:508> [[ glances = -[pPkK](n|) ]]
22 compinit:508> [[ git-buildpackage = -[pPkK](n|) ]]
22 compinit:508> [[ flutter = -[pPkK](n|) ]]
22 compinit:508> [[ fleetctl = -[pPkK](n|) ]]
22 compinit:508> [[ fink = -[pPkK](n|) ]]
22 compinit:508> [[ ffind = -[pPkK](n|) ]]
22 compinit:508> [[ fetchmail = -[pPkK](n|) ]]
22 compinit:508> [[ echotc = -[pPkK](n|) ]]
22 compinit:508> [[ conan = -[pPkK](n|) ]]
22 compinit:508> [[ combinediff = -[pPkK](n|) ]]
22 compinit:508> [[ co = -[pPkK](n|) ]]
22 compinit:508> [[ cf = -[pPkK](n|) ]]
22 compinit:508> [[ ccache = -[pPkK](n|) ]]
22 compinit:508> [[ cask = -[pPkK](n|) ]]
22 compinit:508> [[ bindkey = -[pPkK](n|) ]]
22 compinit:508> [[ bg = -[pPkK](n|) ]]
22 compinit:508> [[ axi-cache = -[pPkK](n|) ]]
22 compinit:508> [[ augtool = -[pPkK](n|) ]]
22 compinit:508> [[ atach = -[pPkK](n|) ]]
22 compinit:508> [[ -value- = -[pPkK](n|) ]]
22 compinit:508> [[ -subscript- = -[pPkK](n|) ]]
22 compinit:508> [[ -first- = -[pPkK](n|) ]]
22 compinit:508> [[ -P = -[pPkK](n|) ]]
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #compdef (#compdef)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:506> case #autoload (#autoload)
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:505> shift _i_line
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:504> _i_tag='#compdef'
22 compinit:501> ((  1 + 0  ))
22 compinit:501> ((  1 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:501> ((  0 + 0  ))
22 compinit:500> _i_name=_tar_archive
22 compinit:500> _i_name=_scons
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zattr
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xxd
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_unace
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_stty
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_smartmontools
22 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_print
22 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
22 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
22 compinit:498> ((  0  ))
22 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/plugins/git
22 compinit:123> typeset -g _comp_dumpfile=/Users/matt/.antigen/.zcompdump
22 compinit:108> typeset -gHA _comps _services _patcomps _postpatcomps
22 compinit:82> _i_dumpfile='/Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1'
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:121> shift _d_als
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n ' 
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:118> print -n '
           '
22 compdump:116> ((  ! --_i && 375 > 1  ))
22 compdump:116> ((  ! --_i && 331 > 1  ))
22 compdump:115> print -n ' _tr'
22 compdump:115> print -n ' _gpg'
22 compdump:115> print -n ' _ed'
22 compdump:115> print -n ' _docker_compose'
22 compdump:115> print -n ' _dladm'
22 compdump:115> print -n ' _add-zle-hook-widget'
22 compdump:115> print -n ' _absolute_command_paths'
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:114> ((  ! 0  ))
22 compdump:113> ((  143  ))
22 compdump:95> read -rA _d_line
22 compdump:95> read -rA _d_line
22 compdump:95> read -rA _d_line
22 compdump:91> _d_bks+=( _bash_complete-word )
22 compdump:90> print -r - zle -C _next_tags .list-choices _next_tags
22 compdump:90> print -r - zle -C _expand_word .complete-word _expand_word
22 compdump:90> print -r - zle -C _complete_help .complete-word _complete_help
22 compdump:63> print -r - ''-value-,(ftp|http(|s))_proxy,-default-'' ''_urls''
22 compdump:63> print -r - ''(ruby|[ei]rb)[0-9.]#'' ''_ruby''
22 compdump:50> print -r - ''-redirect-,<,gzip'' ''gzip''
22 compdump:50> print -r - ''-redirect-,<,compress'' ''compress''
22 compdump:50> print -r - ''-redirect-,<,bzip2'' ''bzip2''
22 compdump:44> print -r - ''tpkg-make'' ''_toolchain-source''
22 compdump:44> print -r - ''bitcoin-cli'' ''_bitcoin-cli''
22 compdump:44> print -r - ''ansible-inventory'' ''_ansible''
22 compdump:44> print -r - ''a2dismod'' ''_a2utils''
22 compdump:44> print -r - ''_restic'' ''_restic''
22 compdump:44> print -r - ''VBoxHeadless'' ''_virtualbox''
22 compdump:44> print -r - ''SuSEconfig'' ''_SUSEconfig''
22 compdump:44> print -r - ''-value-,XZ_DEFAULTS,-default-'' ''_xz''
22 compdump:44> print -r - ''-value-,WWW_HOME,-default-'' ''_urls''
22 compdump:44> print -r - ''-value-,TERMINFO_DIRS,-default-'' ''_dir_list''
22 compdump:44> print -r - ''-value-,TERM,-default-'' ''_terminals''
22 compdump:44> print -r - ''-value-,RPS2,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,RPROMPT2,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,PROMPT4,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,PROMPT3,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,PROMPT2,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,PROMPT,-default-'' ''_ps1234''
22 compdump:44> print -r - ''-value-,PRINTER,-default-'' ''_printers''
22 compdump:44> print -r - ''-value-,P4USER,-default-'' ''_perforce''
22 compdump:44> print -r - ''-value-,P4MERGE,-default-'' ''_perforce''
22 compdump:44> print -r - ''-value-,P4CLIENT,-default-'' ''_perforce''
22 compdump:44> print -r - ''-value-,LPDEST,-default-'' ''_printers''
22 compdump:44> print -r - ''-value-,LOOPDEV_DEBUG,-default-'' ''_losetup''
22 compdump:44> print -r - ''-value-,LD_DEBUG,-default-'' ''_ld_debug''
22 compdump:44> print -r - ''-value-,LANGUAGE,-default-'' ''_locales''
22 compdump:44> print -r - ''-value-,GREP_OPTIONS,-default-'' ''_grep''
22 compdump:44> print -r - ''-value-,ANDROID_SERIAL,-default-'' ''_adb''
22 compdump:44> print -r - ''-value-,-default-,-command-'' ''_zargs''
22 compdump:44> print -r - ''-redirect-,>,gzip'' ''_gzip''
22 compdump:44> print -r - ''-redirect-,>,compress'' ''_compress''
22 compdump:44> print -r - ''-redirect-,<,unxz'' ''_xz''
22 compdump:44> print -r - ''-redirect-'' ''_redirect''
22 compdump:44> print -r - ''-command-line-'' ''_normal''
22 compdump:44> print -r - ''-assign-parameter-'' ''_assign''
22 compdump:22> [[ /Users/matt/.antigen/.zcompdump.ResNet-21-79.resnet.ucsb.edu....
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:169> shift
22 compdef:164> _services[$cmd]=rsh
22 compdef:164> _services[$cmd]=gzip
22 compdef:164> _services[$cmd]=git-checkout
22 compdef:164> _services[$cmd]=compress
22 compdef:164> _services[$cmd]=chgrp
22 compdef:164> _services[$cmd]=bunzip2
22 compdef:164> [[ -n '' ]]
22 compdef:164> [[ -n '' ]]
22 compdef:163> _comps[$cmd]=_virtualbox
22 compdef:163> _comps[$cmd]=_debchange
22 compdef:163> _comps[$cmd]=_compress
22 compdef:162> [[ -z yes || -z _ztodo ]]
22 compdef:162> [[ -z yes || -z _zsocket ]]
22 compdef:162> [[ -z yes || -z _zsh-mime-handler ]]
22 compdef:162> [[ -z yes || -z _zsh ]]
22 compdef:162> [[ -z yes || -z _zpool ]]
22 compdef:162> [[ -z yes || -z _zoneadm ]]
22 compdef:162> [[ -z yes || -z _zmv ]]
22 compdef:162> [[ -z yes || -z _zlogin ]]
22 compdef:162> [[ -z yes || -z _zle ]]
22 compdef:162> [[ -z yes || -z _zargs ]]
22 compdef:162> [[ -z yes || -z _yast ]]
22 compdef:162> [[ -z yes || -z _yast ]]
22 compdef:162> [[ -z yes || -z _yaourt ]]
22 compdef:162> [[ -z yes || -z _xsel ]]
22 compdef:162> [[ -z yes || -z _xmlstarlet ]]
22 compdef:162> [[ -z yes || -z _xclip ]]
22 compdef:162> [[ -z yes || -z _xauth ]]
22 compdef:162> [[ -z yes || -z _wpa_cli ]]
22 compdef:162> [[ -z yes || -z _wiggle ]]
22 compdef:162> [[ -z yes || -z _wemux ]]
22 compdef:162> [[ -z yes || -z _webbrowser ]]
22 compdef:162> [[ -z yes || -z _wait ]]
22 compdef:162> [[ -z yes || -z _vpnc ]]
22 compdef:162> [[ -z yes || -z _valgrind ]]
22 compdef:162> [[ -z yes || -z _ufw ]]
22 compdef:162> [[ -z yes || -z _truss ]]
22 compdef:162> [[ -z yes || -z _trash-put ]]
22 compdef:162> [[ -z yes || -z _time_zone ]]
22 compdef:162> [[ -z yes || -z _tcpsys ]]
22 compdef:162> [[ -z yes || -z _tar ]]
22 compdef:162> [[ -z yes || -z _surfraw ]]
22 compdef:162> [[ -z yes || -z _supervisorctl ]]
22 compdef:162> [[ -z yes || -z _subversion ]]
22 compdef:162> [[ -z yes || -z _sqlite ]]
22 compdef:162> [[ -z yes || -z _shred ]]
22 compdef:162> [[ -z yes || -z _sed ]]
22 compdef:162> [[ -z yes || -z _scrub ]]
22 compdef:162> [[ -z yes || -z _rslsync ]]
22 compdef:162> [[ -z yes || -z _rkt ]]
22 compdef:162> [[ -z yes || -z _rfkill ]]
22 compdef:162> [[ -z yes || -z _redis-cli ]]
22 compdef:162> [[ -z yes || -z _rcctl ]]
22 compdef:162> [[ -z yes || -z _rails ]]
22 compdef:162> [[ -z yes || -z _psutils ]]
22 compdef:162> [[ -z yes || -z _port ]]
22 compdef:162> [[ -z yes || -z _pm2 ]]
22 compdef:162> [[ -z yes || -z _pkcon ]]
22 compdef:162> [[ -z yes || -z _pixz ]]
22 compdef:162> [[ -z yes || -z _pipenv ]]
22 compdef:162> [[ -z yes || -z _phing ]]
22 compdef:162> [[ -z yes || -z _pdm ]]
22 compdef:162> [[ -z yes || -z _patch ]]
22 compdef:162> [[ -z yes || -z _openssl ]]
22 compdef:162> [[ -z yes || -z _object_classes ]]
22 compdef:162> [[ -z yes || -z _nkf ]]
22 compdef:162> [[ -z yes || -z _nice ]]
22 compdef:162> [[ -z yes || -z _nanoc ]]
22 compdef:162> [[ -z yes || -z _mvn ]]
22 compdef:162> [[ -z yes || -z _mussh ]]
22 compdef:162> [[ -z yes || -z _mupdf ]]
22 compdef:162> [[ -z yes || -z _mullvad ]]
22 compdef:162> [[ -z yes || -z _module-assistant ]]
22 compdef:162> [[ -z yes || -z _module ]]
22 compdef:162> [[ -z yes || -z _mkshortcut ]]
22 compdef:162> [[ -z yes || -z _mix ]]
22 compdef:162> [[ -z yes || -z _mc ]]
22 compdef:162> [[ -z yes || -z _matlab ]]
22 compdef:162> [[ -z yes || -z _man ]]
22 compdef:162> [[ -z yes || -z _make-kpkg ]]
22 compdef:162> [[ -z yes || -z _madison ]]
22 compdef:162> [[ -z yes || -z _lsvg ]]
22 compdef:162> [[ -z yes || -z _ln ]]
22 compdef:162> [[ -z yes || -z _libvirt ]]
22 compdef:162> [[ -z yes || -z _last ]]
22 compdef:162> [[ -z yes || -z _kvno ]]
22 compdef:162> [[ -z yes || -z _jq ]]
22 compdef:162> [[ -z yes || -z _ipsec ]]
22 compdef:162> [[ -z yes || -z _install ]]
22 compdef:162> [[ -z yes || -z _id ]]
22 compdef:162> [[ -z yes || -z _hledger ]]
22 compdef:162> [[ -z yes || -z _gzip ]]
22 compdef:162> [[ -z yes || -z _gqview ]]
22 compdef:162> [[ -z yes || -z _gnutls ]]
22 compdef:162> [[ -z yes || -z _git ]]
22 compdef:162> [[ -z yes || -z _gh ]]
22 compdef:162> [[ -z yes || -z _gh ]]
22 compdef:162> [[ -z yes || -z _getmail ]]
22 compdef:162> [[ -z yes || -z _genisoimage ]]
22 compdef:162> [[ -z yes || -z _fs_usage ]]
22 compdef:162> [[ -z yes || -z _equal ]]
22 compdef:162> [[ -z yes || -z _env ]]
22 compdef:162> [[ -z yes || -z _enable ]]
22 compdef:162> [[ -z yes || -z _elfdump ]]
22 compdef:162> [[ -z yes || -z _echotc ]]
22 compdef:162> [[ -z yes || -z _ecasound ]]
22 compdef:162> [[ -z yes || -z _du ]]
22 compdef:162> [[ -z yes || -z _du ]]
22 compdef:162> [[ -z yes || -z _dtruss ]]
22 compdef:162> [[ -z yes || -z _dpkg_source ]]
22 compdef:162> [[ -z yes || -z _dpkg ]]
22 compdef:162> [[ -z yes || -z _dos2unix ]]
22 compdef:162> [[ -z yes || -z _dos2unix ]]
22 compdef:162> [[ -z yes || -z _doas ]]
22 compdef:162> [[ -z yes || -z _dmidecode ]]
22 compdef:162> [[ -z yes || -z _dladm ]]
22 compdef:162> [[ -z yes || -z _dkms ]]
22 compdef:162> [[ -z yes || -z _disable ]]
22 compdef:162> [[ -z yes || -z _dirs ]]
22 compdef:162> [[ -z yes || -z _dig ]]
22 compdef:162> [[ -z yes || -z _dict ]]
22 compdef:162> [[ -z yes || -z _df ]]
22 compdef:162> [[ -z yes || -z _devtodo ]]
22 compdef:162> [[ -z yes || -z _devtodo ]]
22 compdef:162> [[ -z yes || -z _devtodo ]]
22 compdef:162> [[ -z yes || -z _deno ]]
22 compdef:162> [[ -z yes || -z _dcop ]]
22 compdef:162> [[ -z yes || -z _date ]]
22 compdef:162> [[ -z yes || -z _dak ]]
22 compdef:162> [[ -z yes || -z _cygrunsrv ]]
22 compdef:162> [[ -z yes || -z _cu ]]
22 compdef:162> [[ -z yes || -z _cscope ]]
22 compdef:162> [[ -z yes || -z _cryptsetup ]]
22 compdef:162> [[ -z yes || -z _column ]]
22 compdef:162> [[ -z yes || -z _code ]]
22 compdef:162> [[ -z yes || -z _cksum ]]
22 compdef:162> [[ -z yes || -z _cd ]]
22 compdef:162> [[ -z yes || -z _brew ]]
22 compdef:162> [[ -z yes || -z _arp ]]
22 compdef:162> [[ -z yes || -z _apt-file ]]
22 compdef:162> [[ -z yes || -z _acpi ]]
22 compdef:162> [[ -z yes || -z '' ]]
22 compdef:160> svc=''
22 compdef:160> svc=''
22 compdef:160> svc=''
22 compdef:160> svc=''
22 compdef:159> cmd=printf
22 compdef:159> cmd=jmeter-plugins
22 compdef:159> cmd=chpass
22 compdef:155> [[ vagrant = *=* ]]
22 compdef:155> [[ tla = *=* ]]
22 compdef:155> [[ mix = *=* ]]
22 compdef:155> [[ eval = *=* ]]
22 compdef:155> [[ chage = *=* ]]
22 compdef:155> [[ -value-,LANG,-default- = *=* ]]
22 compdef:151> _postpatcomps[$1]=_zftp
22 compdef:151> _postpatcomps[$1]=_tiff
22 compdef:151> _postpatcomps[$1]=_texi
22 compdef:151> _postpatcomps[$1]=_qemu
22 compdef:148> [[ '-value-,*PATH,-default-' = (#b)(*)=(*) ]]
22 compdef:139> case  (postpattern)
22 compdef:139> case  (postpattern)
22 compdef:139> case  (pattern)
22 compdef:139> case  (*)
22 compdef:139> case  (*)
22 compdef:139> case  (*)
22 compdef:136> [[ sockstat = -P ]]
22 compdef:136> [[ devtodo = -P ]]
22 compdef:134> [[ xargs = -p ]]
22 compdef:134> [[ ttyctl = -p ]]
22 compdef:134> [[ source = -p ]]
22 compdef:134> [[ postconf = -p ]]
22 compdef:134> [[ ping6 = -p ]]
22 compdef:134> [[ mkzsh = -p ]]
22 compdef:132> [[ zcash-cli = -N ]]
22 compdef:132> [[ xfreerdp = -N ]]
22 compdef:132> [[ xauth = -N ]]
22 compdef:132> [[ wg-quick = -N ]]
22 compdef:132> [[ wait = -N ]]
22 compdef:132> [[ w = -N ]]
22 compdef:132> [[ udisksctl = -N ]]
22 compdef:132> [[ trash-list = -N ]]
22 compdef:132> [[ trash-empty = -N ]]
22 compdef:132> [[ tmuxp = -N ]]
22 compdef:132> [[ sqlite = -N ]]
22 compdef:132> [[ sdd = -N ]]
22 compdef:132> [[ rxvt = -N ]]
22 compdef:132> [[ ri = -N ]]
22 compdef:132> [[ prun = -N ]]
22 compdef:132> [[ printenv = -N ]]
22 compdef:132> [[ odmget = -N ]]
22 compdef:132> [[ middleman = -N ]]
22 compdef:132> [[ jmeter-plugins = -N ]]
22 compdef:132> [[ guilt = -N ]]
22 compdef:132> [[ freezer = -N ]]
22 compdef:132> [[ ecasound = -N ]]
22 compdef:132> [[ dumper = -N ]]
22 compdef:132> [[ dsh = -N ]]
22 compdef:132> [[ dpkg-cross = -N ]]
22 compdef:132> [[ dmidecode = -N ]]
22 compdef:132> [[ django-admin.py = -N ]]
22 compdef:132> [[ dirs = -N ]]
22 compdef:132> [[ diffstat = -N ]]
22 compdef:132> [[ diff3 = -N ]]
22 compdef:132> [[ dhclient = -N ]]
22 compdef:132> [[ debuild = -N ]]
22 compdef:132> [[ debfoster = -N ]]
22 compdef:132> [[ cygstart = -N ]]
22 compdef:132> [[ cygcheck = -N ]]
22 compdef:132> [[ cowsay = -N ]]
22 compdef:132> [[ chmod = -N ]]
22 compdef:132> [[ cdr = -N ]]
22 compdef:132> [[ brew = -N ]]
22 compdef:132> [[ aptitude = -N ]]
22 compdef:132> [[ _gh = -N ]]
22 compdef:132> [[ . = -N ]]
22 compdef:132> [[ -value-,TZ,-default- = -N ]]
22 compdef:131> ((  1  ))
22 compdef:117> shift
22 compdef:104> [[ 2 -lt 2 ]]
22 compdef:92> [[ .list-choices = .menu-select ]]
22 compdef:92> [[ .complete-word = .menu-select ]]
22 compdef:83> case  (widgetkey)
22 compdef:83> case  (widgetkey)
22 compdef:83> case  (widgetkey)
22 compdef:83> case  (key)
22 compdef:83> case  (key)
22 compdef:83> case  (key)
22 compdef:83> case  (*)
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:81> shift
22 compdef:80> autoload -Uz _zsh
22 compdef:80> autoload -Uz _zlogin
22 compdef:80> autoload -Uz _zcat
22 compdef:80> autoload -Uz _xsel
22 compdef:80> autoload -Uz _xmlstarlet
22 compdef:80> autoload -Uz _xfig
22 compdef:80> autoload -Uz _wpa_cli
22 compdef:80> autoload -Uz _wg-quick
22 compdef:80> autoload -Uz _vnstat
22 compdef:80> autoload -Uz _vagrant
22 compdef:80> autoload -Uz _ufw
22 compdef:80> autoload -Uz _trash-restore
22 compdef:80> autoload -Uz _texi
22 compdef:80> autoload -Uz _supervisorctl
22 compdef:80> autoload -Uz _stdbuf
22 compdef:80> autoload -Uz _stack
22 compdef:80> autoload -Uz _srm
22 compdef:80> autoload -Uz _seafile
22 compdef:80> autoload -Uz _scrub
22 compdef:80> autoload -Uz _sbt
22 compdef:80> autoload -Uz _rslsync
22 compdef:80> autoload -Uz _rails
22 compdef:80> autoload -Uz _port
22 compdef:80> autoload -Uz _pkcon
22 compdef:80> autoload -Uz _pixz
22 compdef:80> autoload -Uz _pipenv
22 compdef:80> autoload -Uz _phing
22 compdef:80> autoload -Uz _periscope
22 compdef:80> autoload -Uz _optirun
22 compdef:80> autoload -Uz _openstack
22 compdef:80> autoload -Uz _openssl
22 compdef:80> autoload -Uz _numfmt
22 compdef:80> autoload -Uz _node
22 compdef:80> autoload -Uz _ninja
22 compdef:80> autoload -Uz _nginx
22 compdef:80> autoload -Uz _networkmanager
22 compdef:80> autoload -Uz _mullvad
22 compdef:80> autoload -Uz _most_recent_file
22 compdef:80> autoload -Uz _middleman
22 compdef:80> autoload -Uz _mencal
22 compdef:80> autoload -Uz _mdfind
22 compdef:80> autoload -Uz _md5sum
22 compdef:80> autoload -Uz _matlab
22 compdef:80> autoload -Uz _lsattr
22 compdef:80> autoload -Uz _losetup
22 compdef:80> autoload -Uz _lldb
22 compdef:80> autoload -Uz _ldconfig
22 compdef:80> autoload -Uz _last
22 compdef:80> autoload -Uz _kubectl
22 compdef:80> autoload -Uz _jobs_bg
22 compdef:80> autoload -Uz _iconvconfig
22 compdef:80> autoload -Uz _hub
22 compdef:80> autoload -Uz _helm
22 compdef:80> autoload -Uz _gv
22 compdef:80> autoload -Uz _guilt
22 compdef:80> autoload -Uz _gnome-gv
22 compdef:80> autoload -Uz _git
22 compdef:80> autoload -Uz _gh
22 compdef:80> autoload -Uz _fs_usage
22 compdef:80> autoload -Uz _figlet
22 compdef:80> autoload -Uz _etags
22 compdef:80> autoload -Uz _enable
22 compdef:80> autoload -Uz _elinks
22 compdef:80> autoload -Uz _ecdsautil
22 compdef:80> autoload -Uz _dpkg-cross
22 compdef:80> autoload -Uz _dpkg-buildpackage
22 compdef:80> autoload -Uz _dpkg
22 compdef:80> autoload -Uz _dmidecode
22 compdef:80> autoload -Uz _dladm
22 compdef:80> autoload -Uz _django
22 compdef:80> autoload -Uz _disable
22 compdef:80> autoload -Uz _diffstat
22 compdef:80> autoload -Uz _diff3
22 compdef:80> autoload -Uz _dict
22 compdef:80> autoload -Uz _dconf
22 compdef:80> autoload -Uz _dchroot-dsa
22 compdef:80> autoload -Uz _date
22 compdef:80> autoload -Uz _darcs
22 compdef:80> autoload -Uz _cygpath
22 compdef:80> autoload -Uz _cygcheck
22 compdef:80> autoload -Uz _cvs
22 compdef:80> autoload -Uz _cut
22 compdef:80> autoload -Uz _csup
22 compdef:80> autoload -Uz _cssh
22 compdef:80> autoload -Uz _crontab
22 compdef:80> autoload -Uz _cpupower
22 compdef:80> autoload -Uz _compdef
22 compdef:80> autoload -Uz _column
22 compdef:80> autoload -Uz _cmp
22 compdef:80> autoload -Uz _chroot
22 compdef:80> autoload -Uz _cheat
22 compdef:80> autoload -Uz _cd
22 compdef:80> autoload -Uz _builtin
22 compdef:80> autoload -Uz _base64
22 compdef:80> autoload -Uz _afew
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:80> [[ -n yes ]]
22 compdef:79> func=_pdf
22 compdef:79> func=_mh
22 compdef:49> [[ _pon = *=* ]]
22 compdef:49> [[ _locate = *=* ]]
22 compdef:49> [[ _git-pulls = *=* ]]
22 compdef:49> [[ -z '' ]]
22 compdef:49> [[ -z '' ]]
22 compdef:45> [[ -z '' ]]
22 compdef:40> ((  ! 3  ))
22 compdef:40> ((  ! 2  ))
22 compdef:40> ((  ! 2  ))
22 compdef:40> ((  ! 2  ))
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:38> shift OPTIND-1
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:17> new=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:16> autol=yes
22 compdef:15> case n (n)
22 compdef:15> case n (n)
22 compdef:15> case n (a)
22 compdef:15> case n (a)
22 compdef:15> case n (a)
22 compdef:15> case a (a)
22 compdef:15> case a (a)
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:14> getopts anpPkKde opt
22 compdef:9> ((  ! 9  ))
22 compdef:9> ((  ! 8  ))
22 compdef:9> ((  ! 6  ))
22 compdef:9> ((  ! 5  ))
22 compdef:9> ((  ! 5  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 4  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:9> ((  ! 3  ))
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:5> setopt extendedglob
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:4> emulate -L zsh
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compdef:2> local -a match mbegin mend
22 compaudit:156> case 0:0 (0:0)
22 compaudit:84> [[ ign == use ]]
22 compaudit:52> local _compdir=/usr/share/zsh/5.8.1/functions
22 colors:115> bg_bold[${k#bg-}]=$'C-[[01;41m'
22 colors:95> local lc=$'C-[[' rc=m
22 bashcompinit:178> autoload -Uz bashcompinit
22 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
22 antigen-remove-hook:3> local target=antigen-bundle
22 antigen-remove-hook:3> local target=antigen-apply
22 antigen-remove-hook:3> local target=-antigen-load-source
22 antigen-remove-hook:1> local hook=antigen-bundle-parallel
22 antigen-remove-hook:1> local hook=antigen-bundle-defer
22 antigen-ext:7> ((  0 == 0  ))
22 antigen-ext-init:5> ((  1  ))
22 antigen-bundle-parallel-execute:11> typeset -A bundle
22 antigen-apply-defer:5> local bundle
22 antigen-add-hook:23> ((  ! 1  ))
22 antigen-add-hook:23> ((  ! 1  ))
22 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-apply
22 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-apply
22 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-apply
22 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle type r...
22 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply type po...
22 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen type pre mode...
22 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target -antigen-load-env typ...
22 antigen-add-hook:13> [[ '' ==  ]]
22 antigen-add-hook:8> ((  ! 1  ))
22 antigen-add-hook:3> ((  ! 1  ))
22 antigen-add-hook:1> local target=antigen-bundle hook=antigen-bundle-cached ty...
22 antigen-add-hook:1> local target=antigen-apply hook=antigen-apply-cached type...
22 add-zsh-hook:84> ((  5 == 0  ))
22 add-zsh-hook:83> ((  1  ))
22 add-zsh-hook:65> local hook=precmd_functions
22 add-zsh-hook:60> ((  help || 2 != 2 || 2 == 0  ))
22 add-zsh-hook:60> ((  help || 2 != 2 || 2 == 0  ))
22 add-zsh-hook:60> ((  help || 2 != 2 || 2 == 0  ))
22 add-zsh-hook:24> local opt
22 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
22 add-zsh-hook:15> emulate -L zsh
22 add-zle-hook-widget:99> extant_hooks+=( 1:_zsh_highlight__zle-line-finish )
22 add-zle-hook-widget:89> zle -N zle-line-finish azhw:zle-line-finish
22 add-zle-hook-widget:87> extant_hooks=( 0:user:zle-line-finish )
22 add-zle-hook-widget:85> [[ -n user:zle-line-finish ]]
22 add-zle-hook-widget:85> [[ -n '' ]]
22 add-zle-hook-widget:50> local -aU extant_hooks
22 add-zle-hook-widget:9> integer del list help
22 _zsh_highlight_load_highlighters:2> setopt localoptions noksharrays bareglobqual
22 _zsh_highlight_bind_widgets:50> zle -N where-is _zsh_highlight_widget_orig-s0...
22 _zsh_highlight_bind_widgets:50> zle -N vi-yank-whole-line _zsh_highlight_widg...
22 _zsh_highlight_bind_widgets:50> zle -N vi-repeat-search _zsh_highlight_widget...
22 _zsh_highlight_bind_widgets:50> zle -N vi-oper-swap-case _zsh_highlight_widge...
22 _zsh_highlight_bind_widgets:50> zle -N vi-kill-eol _zsh_highlight_widget_orig...
22 _zsh_highlight_bind_widgets:50> zle -N vi-forward-blank-word-end _zsh_highlig...
22 _zsh_highlight_bind_widgets:50> zle -N vi-down-line-or-history _zsh_highlight...
22 _zsh_highlight_bind_widgets:50> zle -N vi-digit-or-beginning-of-line _zsh_hig...
22 _zsh_highlight_bind_widgets:50> zle -N vi-backward-blank-word _zsh_highlight_...
22 _zsh_highlight_bind_widgets:50> zle -N select-in-blank-word _zsh_highlight_wi...
22 _zsh_highlight_bind_widgets:50> zle -N select-a-shell-word _zsh_highlight_wid...
22 _zsh_highlight_bind_widgets:50> zle -N select-a-blank-word _zsh_highlight_wid...
22 _zsh_highlight_bind_widgets:50> zle -N read-command _zsh_highlight_widget_ori...
22 _zsh_highlight_bind_widgets:50> zle -N push-line-or-edit _zsh_highlight_widge...
22 _zsh_highlight_bind_widgets:50> zle -N kill-word _zsh_highlight_widget_orig-s...
22 _zsh_highlight_bind_widgets:50> zle -N history-search-backward _zsh_highlight...
22 _zsh_highlight_bind_widgets:50> zle -N history-beginning-search-forward _zsh_...
22 _zsh_highlight_bind_widgets:50> zle -N gosmacs-transpose-chars _zsh_highlight...
22 _zsh_highlight_bind_widgets:50> zle -N exchange-point-and-mark _zsh_highlight...
22 _zsh_highlight_bind_widgets:50> zle -N end-of-line _zsh_highlight_widget_orig...
22 _zsh_highlight_bind_widgets:50> zle -N end-of-buffer-or-history _zsh_highligh...
22 _zsh_highlight_bind_widgets:50> zle -N down-line-or-history _zsh_highlight_wi...
22 _zsh_highlight_bind_widgets:50> zle -N describe-key-briefly _zsh_highlight_wi...
22 _zsh_highlight_bind_widgets:50> zle -N copy-prev-shell-word _zsh_highlight_wi...
22 _zsh_highlight_bind_widgets:50> zle -N beginning-of-line _zsh_highlight_widge...
22 _zsh_highlight_bind_widgets:50> zle -N beginning-of-history _zsh_highlight_wi...
22 _zsh_highlight_bind_widgets:50> zle -N backward-kill-word _zsh_highlight_widg...
22 _zsh_highlight_bind_widgets:50> zle -N accept-and-hold _zsh_highlight_widget_...
22 _zsh_highlight_bind_widgets:46> zle -N reverse-menu-complete _zsh_highlight_w...
22 _zsh_highlight_bind_widgets:46> zle -N menu-select _zsh_highlight_widget_orig...
22 _zsh_highlight_bind_widgets:46> zle -N _history-complete-older _zsh_highlight...
22 _zsh_highlight_bind_widgets:46> zle -N _correct_word _zsh_highlight_widget_or...
22 _zsh_highlight_bind_widgets:41> zle -N down-line-or-beginning-search _zsh_hig...
22 _zsh_highlight_bind_widgets:27> case user:bracketed-paste-magic (user:*)
22 _zsh_highlight_bind_widgets:27> case completion:.menu-expand-or-complete:_mai...
22 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_next_tags (com...
22 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_expand_word (c...
22 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete-prefix:_m...
22 _zsh_highlight_bind_widgets:27> case completion:.delete-char-or-list:_main_co...
22 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_read_comp (co...
22 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_most_recent_f...
22 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_word (...
22 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_filen...
22 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_tag ...
22 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
22 _zsh_highlight_bind_widgets:27> case builtin (user:*)
22 _zsh_highlight_bind_widgets:27> case builtin (user:*)
22 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
22 _zsh_highlight_bind_widgets:27> case builtin (builtin)
22 _zsh_highlight_bind_widgets:27> case builtin (builtin)
22 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:82> ((  1  ))
22 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:17> [[ ! -o no_brace_exp...
22 /usr/local/opt/asdf/libexec/asdf.sh:26> ASDF_USER_SHIMS=/Users/matt/.asdf/shims
22 /Users/matt/.zcompdump:1965> zle -C _next_tags .list-choices _next_tags
22 /Users/matt/.zcompdump:1960> zle -C _expand_word .complete-word _expand_word
22 /Users/matt/.zcompdump:1958> zle -C _correct_word .complete-word _correct_word
22 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1799> zle -C _next_tags .lis...
22 /Users/matt/.p10k.zsh:19> [[ ! -o no_brace_expand ]]
22 /Users/matt/.oh-my-zsh/themes/robbyrussell.zsh-theme:6> ZSH_THEME_GIT_PROMPT_...
22 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=git
22 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:149> [[ -f /Users/matt/.oh-my-zsh/custom/...
22 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;145m%}'
22 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;113m%}'
22 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;070m%}'
22 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;033m%}'
22 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=116
22 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:99> bindkey -M viins '^[[1;5C' fo...
22 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:39> bindkey -M emacs $'C-[OA' up-...
22 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:22> [[ -n $'C-[[5~' ]]
22 /Users/matt/.oh-my-zsh/lib/directories.zsh:20> alias '9=cd -9'
22 /Users/matt/.oh-my-zsh/lib/directories.zsh:13> alias '2=cd -2'
22 /Users/matt/.oh-my-zsh/lib/directories.zsh:7> alias -g '....=../../..'
22 /Users/matt/.oh-my-zsh/lib/completion.zsh:44> zstyle ':completion:*' use-cach...
22 /Users/matt/.oh-my-zsh/lib/completion.zsh:6> unsetopt menu_complete
22 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:17> alias 'z=fasd_cd -d'
22 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2setcolor=/Users/matt...
22 /Users/matt/.antigen/init.zsh:77> typeset -ga _ZCACHE_BUNDLE_SOURCE
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
22 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:12> zle -N s...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:116>...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:48> ...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:35> setop...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:17> a...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:9> al...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:7> al...
22 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:3> se...
22 -antigen-set-default:2> local arg_value=/Users/matt/.antigen/init.zsh
22 -antigen-set-default:2> local arg_value=/Users/matt/.antigen/bundles
22 -antigen-set-default:2> local arg_value=/Users/matt/.antigen/.zcompdump
22 -antigen-set-default:2> local arg_value=/Users/matt/.antigen/.resources
22 -antigen-set-default:2> local arg_value=/Users/matt/.antigen
22 -antigen-set-default:2> local arg_value='GREP_OPTIONS= command grep '
22 -antigen-set-default:2> local arg_value='--recursive --depth=1'
22 -antigen-set-default:1> local arg_name=_ANTIGEN_WARN_DUPLICATES
22 -antigen-set-default:1> local arg_name=_ANTIGEN_BUILTIN_EXTENSIONS
22 -antigen-set-default:1> local arg_name=ANTIGEN_DEFAULT_REPO_URL
22 -antigen-set-default:1> local arg_name=ANTIGEN_COMPINIT_OPTS
22 -antigen-set-default:1> local arg_name=ANTIGEN_CLONE_ENV
22 -antigen-parse-args:112> [[ plugin == theme ]]
22 -antigen-parse-args:112> [[ plugin == theme ]]
22 -antigen-parse-args:69> [[ zsh-users/zsh-syntax-highlighting != */* ]]
22 -antigen-parse-args:55> value=zsh-users/zsh-syntax-highlighting
22 -antigen-parse-args:55> value=zsh-users/zsh-autosuggestions
22 -antigen-parse-args:55> value=zsh-users/zsh-autosuggestions
22 -antigen-parse-args:41> local domain=''
22 -antigen-parse-args:41> local domain=''
22 -antigen-parse-args:41> local domain=''
22 -antigen-parse-args:5> shift
22 -antigen-parse-args:5> shift
22 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
22 -antigen-parse-args:1> local argkey key value index=0 args
22 -antigen-parallel-init:2> typeset -ga _PARALLEL_BUNDLE
22 -antigen-load:1> local bundle list
22 -antigen-load:1> local bundle list
22 -antigen-load-env-cached:3> local location=/Users/matt/.antigen/bundles/zsh-u...
22 -antigen-load-env-cached:3> local location=/Users/matt/.antigen/bundles/robby...
22 -antigen-load-env-cached:1> local bundle
22 -antigen-load-env-cached:1> local bundle
22 -antigen-hook-handler:51> [[ 0 == -1 ]]
22 -antigen-hook-handler:48> ((  1  ))
22 -antigen-hook-handler:44> local replace_hook=0 ret=0
22 -antigen-hook-handler:40> [[ 0 == -1 ]]
22 -antigen-hook-handler:37> hook=antigen-bundle-cached
22 -antigen-hook-handler:37> hook=antigen-bundle-cached
22 -antigen-hook-handler:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-apply mo...
22 -antigen-hook-handler:12> [[ repeat == once ]]
22 -antigen-hook-handler:12> [[ repeat == once ]]
22 -antigen-hook-handler:12> [[ repeat == once ]]
22 -antigen-hook-handler:12> [[ repeat == once ]]
22 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
22 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
22 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
22 -antigen-hook-handler:11> meta=( target antigen-bundle type pre mode repeat c...
22 -antigen-hook-handler:11> meta=( target antigen-bundle mode repeat type pre c...
22 -antigen-hook-handler:11> meta=( target antigen-apply type pre mode once call...
22 -antigen-hook-handler:11> meta=( target antigen-apply mode once type pre call...
22 -antigen-hook-handler:11> meta=( target antigen mode once type pre called 1 )
22 -antigen-hook-handler:7> hooks=( antigen-lock )
22 -antigen-hook-handler:7> hooks=( -antigen-load-env-cached )
22 -antigen-hook-handler:7> hooks=( -antigen-load-env-cached )
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
22 -antigen-hook-handler:3> shift
22 -antigen-hook-handler:1> local target=antigen-bundle args hook called
22 -antigen-hook-handler:1> local target=antigen-bundle args hook called
22 -antigen-hook-handler:1> local target=antigen-bundle args hook called
22 -antigen-hook-handler:1> local target=antigen-bundle args hook called
22 -antigen-hook-handler:1> local target=antigen-apply args hook called
22 -antigen-hook-handler:1> local target=antigen args hook called
22 -antigen-hook-antigen:10> antigen-apply
22 -antigen-hook-antigen-bundle:2> [[ -z '--loc=lib' ]]
22 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
22 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/z...
22 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
22 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
22 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-s...
22 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
22 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
22 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
22 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
22 (eval):112> alias 'git-svn-dcommit-push=git svn dcommit && git push github $(...
22 (anon):1536> typeset -g POWERLEVEL9K_TRANSIENT_PROMPT=always
22 (anon):1447> typeset -g POWERLEVEL9K_BATTERY_LOW_FOREGROUND=160
22 (anon):1304> typeset -g POWERLEVEL9K_GCLOUD_SHOW_ON_COMMAND='gcloud|gcs'
22 (anon):1295> typeset -g POWERLEVEL9K_AZURE_SHOW_ON_COMMAND='az|terraform|pulu...
22 (anon):1157> typeset -g POWERLEVEL9K_TERRAFORM_CLASSES=( '*' OTHER )
22 (anon):1119> typeset -g POWERLEVEL9K_HASKELL_STACK_FOREGROUND=172
22 (anon):1108> typeset -g POWERLEVEL9K_SCALAENV_SOURCES=( shell local global )
22 (anon):1054> typeset -g POWERLEVEL9K_LUAENV_FOREGROUND=32
22 (anon):975> typeset -g POWERLEVEL9K_RUST_VERSION_PROJECT_ONLY=true
22 (anon):957> typeset -g POWERLEVEL9K_NODE_VERSION_FOREGROUND=70
22 (anon):949> typeset -g POWERLEVEL9K_NODEENV_SHOW_NODE_VERSION=false
22 (anon):922> typeset -g POWERLEVEL9K_GOENV_SHOW_SYSTEM=true
22 (anon):856> typeset -g POWERLEVEL9K_ANACONDA_FOREGROUND=37
22 (anon):787> typeset -g POWERLEVEL9K_TIMEWARRIOR_FOREGROUND=110
22 (anon):732> typeset -g POWERLEVEL9K_VI_MODE_INSERT_FOREGROUND=66
22 (anon):729> typeset -g POWERLEVEL9K_VI_MODE_OVERWRITE_FOREGROUND=172
22 (anon):725> typeset -g POWERLEVEL9K_VI_VISUAL_MODE_STRING=VISUAL
22 (anon):714> typeset -g POWERLEVEL9K_DISK_USAGE_CRITICAL_LEVEL=95
22 (anon):710> typeset -g POWERLEVEL9K_DISK_USAGE_WARNING_FOREGROUND=220
22 (anon):699> typeset -g POWERLEVEL9K_NIX_SHELL_FOREGROUND=74
22 (anon):660> typeset -g POWERLEVEL9K_ASDF_JULIA_FOREGROUND=70
22 (anon):630> typeset -g POWERLEVEL9K_ASDF_PERL_FOREGROUND=67
22 (anon):615> typeset -g POWERLEVEL9K_ASDF_FLUTTER_FOREGROUND=38
22 (anon):605> typeset -g POWERLEVEL9K_ASDF_RUST_FOREGROUND=37
22 (anon):590> typeset -g POWERLEVEL9K_ASDF_PYTHON_FOREGROUND=37
22 (anon):585> typeset -g POWERLEVEL9K_ASDF_RUBY_FOREGROUND=168
22 (anon):556> typeset -g POWERLEVEL9K_ASDF_SOURCES=( shell local global )
22 (anon):485> typeset -g POWERLEVEL9K_STATUS_ERROR_SIGNAL_FOREGROUND=160
22 (anon):484> typeset -g POWERLEVEL9K_STATUS_ERROR_SIGNAL=true
22 (anon):458> typeset -g POWERLEVEL9K_VCS_MODIFIED_FOREGROUND=178
22 (anon):456> typeset -g POWERLEVEL9K_VCS_CLEAN_FOREGROUND=76
22 (anon):443> typeset -g POWERLEVEL9K_VCS_LOADING_VISUAL_IDENTIFIER_COLOR=244
22 (anon):426> typeset -g POWERLEVEL9K_VCS_MAX_INDEX_SIZE_DIRTY=-1
22 (anon):254> typeset -g POWERLEVEL9K_DIR_MIN_COMMAND_COLUMNS_PCT=50
22 (anon):251> typeset -g POWERLEVEL9K_DIR_MIN_COMMAND_COLUMNS=40
22 (anon):198> typeset -g POWERLEVEL9K_DIR_SHORTENED_FOREGROUND=103
22 (anon):181> typeset -g POWERLEVEL9K_PROMPT_CHAR_OVERWRITE_STATE=true
22 (anon):162> typeset -g POWERLEVEL9K_OS_ICON_FOREGROUND=255
22 (anon):148> typeset -g POWERLEVEL9K_RIGHT_SEGMENT_SEPARATOR='uE0B2'
22 (anon):144> typeset -g POWERLEVEL9K_RIGHT_SUBSEGMENT_SEPARATOR='%242FuE0B3'
22 (anon):139> typeset -g POWERLEVEL9K_BACKGROUND=234
22 (anon):126> typeset -g POWERLEVEL9K_MULTILINE_FIRST_PROMPT_GAP_BACKGROUND=''
22 (anon):118> typeset -g POWERLEVEL9K_MULTILINE_NEWLINE_PROMPT_SUFFIX=''
22 (anon):115> typeset -g POWERLEVEL9K_MULTILINE_LAST_PROMPT_PREFIX=''
22 (anon):113> typeset -g POWERLEVEL9K_MULTILINE_FIRST_PROMPT_PREFIX=''
22 (anon):106> typeset -g POWERLEVEL9K_ICON_BEFORE_CONTENT=''
22 (anon):20> zle -N autosuggest-suggest _zsh_autosuggest_widget_suggest
22 (anon):3> _ZSH_AUTOSUGGEST_BUILTIN_ACTIONS=( clear fetch suggest accept execu...
21 regexp-replace:25> local -a match mbegin mend
21 is_theme:2> local name=robbyrussell
21 is_plugin:2> local name=zshfl
21 is_plugin:1> local base_dir=/Users/matt/.oh-my-zsh
21 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
21 handle_completion_insecurities:16> [[ -z '' ]]
21 complete:2> local args void cmd print remove
21 compinit:533> zle -C menu-complete .menu-complete _main_complete
21 compinit:533> zle -C list-choices .list-choices _main_complete
21 compinit:533> zle -C list-choices .list-choices _main_complete
21 compinit:533> zle -C delete-char-or-list .delete-char-or-list _main_complete
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:516> [[ '' !=  # ]]
21 compinit:515> autoload -Uz _x_modifier
21 compinit:515> autoload -Uz _x_borderwidth
21 compinit:515> autoload -Uz _email_addresses
21 compinit:515> autoload -Uz _deb_packages
21 compinit:515> autoload -Uz _complete_help_generic
21 compinit:508> [[ zdump = -[pPkK](n|) ]]
21 compinit:508> [[ xterm = -[pPkK](n|) ]]
21 compinit:508> [[ whois = -[pPkK](n|) ]]
21 compinit:508> [[ w3m = -[pPkK](n|) ]]
21 compinit:508> [[ vmstat = -[pPkK](n|) ]]
21 compinit:508> [[ useradd = -[pPkK](n|) ]]
21 compinit:508> [[ uptime = -[pPkK](n|) ]]
21 compinit:508> [[ unison = -[pPkK](n|) ]]
21 compinit:508> [[ uniq = -[pPkK](n|) ]]
21 compinit:508> [[ unexpand = -[pPkK](n|) ]]
21 compinit:508> [[ uname = -[pPkK](n|) ]]
21 compinit:508> [[ ulimit = -[pPkK](n|) ]]
21 compinit:508> [[ ttyctl = -[pPkK](n|) ]]
21 compinit:508> [[ true = -[pPkK](n|) ]]
21 compinit:508> [[ tidy = -[pPkK](n|) ]]
21 compinit:508> [[ tex = -[pPkK](n|) ]]
21 compinit:508> [[ tcptraceroute = -[pPkK](n|) ]]
21 compinit:508> [[ tac = -[pPkK](n|) ]]
21 compinit:508> [[ system_profiler = -[pPkK](n|) ]]
21 compinit:508> [[ sysrc = -[pPkK](n|) ]]
21 compinit:508> [[ sysctl = -[pPkK](n|) ]]
21 compinit:508> [[ swanctl = -[pPkK](n|) ]]
21 compinit:508> [[ subl = -[pPkK](n|) ]]
21 compinit:508> [[ su = -[pPkK](n|) ]]
21 compinit:508> [[ stty = -[pPkK](n|) ]]
21 compinit:508> [[ strings = -[pPkK](n|) ]]
21 compinit:508> [[ strftime = -[pPkK](n|) ]]
21 compinit:508> [[ strace = -[pPkK](n|) ]]
21 compinit:508> [[ ss = -[pPkK](n|) ]]
21 compinit:508> [[ split = -[pPkK](n|) ]]
21 compinit:508> [[ smit = -[pPkK](n|) ]]
21 compinit:508> [[ slrn = -[pPkK](n|) ]]
21 compinit:508> [[ signify = -[pPkK](n|) ]]
21 compinit:508> [[ shutdown = -[pPkK](n|) ]]
21 compinit:508> [[ shuf = -[pPkK](n|) ]]
21 compinit:508> [[ shred = -[pPkK](n|) ]]
21 compinit:508> [[ shift = -[pPkK](n|) ]]
21 compinit:508> [[ shasum = -[pPkK](n|) ]]
21 compinit:508> [[ setopt = -[pPkK](n|) ]]
21 compinit:508> [[ schroot = -[pPkK](n|) ]]
21 compinit:508> [[ sbuild = -[pPkK](n|) ]]
21 compinit:508> [[ savecore = -[pPkK](n|) ]]
21 compinit:508> [[ run-help = -[pPkK](n|) ]]
21 compinit:508> [[ ruby = -[pPkK](n|) ]]
21 compinit:508> [[ reprepro = -[pPkK](n|) ]]
21 compinit:508> [[ renice = -[pPkK](n|) ]]
21 compinit:508> [[ rar = -[pPkK](n|) ]]
21 compinit:508> [[ ranlib = -[pPkK](n|) ]]
21 compinit:508> [[ qdbus = -[pPkK](n|) ]]
21 compinit:508> [[ ps = -[pPkK](n|) ]]
21 compinit:508> [[ prstat = -[pPkK](n|) ]]
21 compinit:508> [[ prompt = -[pPkK](n|) ]]
21 compinit:508> [[ portlint = -[pPkK](n|) ]]
21 compinit:508> [[ pine = -[pPkK](n|) ]]
21 compinit:508> [[ pax = -[pPkK](n|) ]]
21 compinit:508> [[ paste = -[pPkK](n|) ]]
21 compinit:508> [[ otool = -[pPkK](n|) ]]
21 compinit:508> [[ osascript = -[pPkK](n|) ]]
21 compinit:508> [[ nslookup = -[pPkK](n|) ]]
21 compinit:508> [[ nmap = -[pPkK](n|) ]]
21 compinit:508> [[ mutt = -[pPkK](n|) ]]
21 compinit:508> [[ mr = -[pPkK](n|) ]]
21 compinit:508> [[ mdutil = -[pPkK](n|) ]]
21 compinit:508> [[ mdls = -[pPkK](n|) ]]
21 compinit:508> [[ lsblk = -[pPkK](n|) ]]
21 compinit:508> [[ localedef = -[pPkK](n|) ]]
21 compinit:508> [[ lha = -[pPkK](n|) ]]
21 compinit:508> [[ knock = -[pPkK](n|) ]]
21 compinit:508> [[ knife = -[pPkK](n|) ]]
21 compinit:508> [[ killall = -[pPkK](n|) ]]
21 compinit:508> [[ join = -[pPkK](n|) ]]
21 compinit:508> [[ ipset = -[pPkK](n|) ]]
21 compinit:508> [[ invoke-rc.d = -[pPkK](n|) ]]
21 compinit:508> [[ inetadm = -[pPkK](n|) ]]
21 compinit:508> [[ iconv = -[pPkK](n|) ]]
21 compinit:508> [[ htop = -[pPkK](n|) ]]
21 compinit:508> [[ gprof = -[pPkK](n|) ]]
21 compinit:508> [[ gpasswd = -[pPkK](n|) ]]
21 compinit:508> [[ git-wtf = -[pPkK](n|) ]]
21 compinit:508> [[ git-revise = -[pPkK](n|) ]]
21 compinit:508> [[ git-journal = -[pPkK](n|) ]]
21 compinit:508> [[ getopts = -[pPkK](n|) ]]
21 compinit:508> [[ getconf = -[pPkK](n|) ]]
21 compinit:508> [[ fw_update = -[pPkK](n|) ]]
21 compinit:508> [[ force = -[pPkK](n|) ]]
21 compinit:508> [[ fold = -[pPkK](n|) ]]
21 compinit:508> [[ fmadm = -[pPkK](n|) ]]
21 compinit:508> [[ fail2ban-client = -[pPkK](n|) ]]
21 compinit:508> [[ fab = -[pPkK](n|) ]]
21 compinit:508> [[ dvc = -[pPkK](n|) ]]
21 compinit:508> [[ cap = -[pPkK](n|) ]]
21 compinit:508> [[ bsdconfig = -[pPkK](n|) ]]
21 compinit:508> [[ brew = -[pPkK](n|) ]]
21 compinit:508> [[ bison = -[pPkK](n|) ]]
21 compinit:508> [[ acroread = -[pPkK](n|) ]]
21 compinit:508> [[ -vared- = -[pPkK](n|) ]]
21 compinit:508> [[ -parameter- = -[pPkK](n|) ]]
21 compinit:508> [[ -command-line- = -[pPkK](n|) ]]
21 compinit:508> [[ -assign-parameter- = -[pPkK](n|) ]]
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #compdef (#compdef)
21 compinit:506> case #autoload (#compdef)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:506> case #autoload (#autoload)
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:505> shift _i_line
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#compdef'
21 compinit:504> _i_tag='#autoload'
21 compinit:504> _i_tag='#autoload'
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:501> ((  0 + 0  ))
21 compinit:500> _i_name=_x_cursor
21 compinit:500> _i_name=_unace
21 compinit:500> _i_name=_tox
21 compinit:500> _i_name=_teamocil
21 compinit:500> _i_name=_printenv
21 compinit:500> _i_name=_lua
21 compinit:500> _i_name=_htop
21 compinit:500> _i_name=_baudrates
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tput
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_stdbuf
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ps
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_portaudit
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_other_accounts
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lua
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_expand_word
21 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_SUSEconfig
21 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
21 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
21 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlig...
21 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions
21 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions
21 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/custom/plugins/pyenv-lazy
21 compinit:486> _i_done=yes
21 compinit:125> typeset -g _comp_dumpfile=/Users/matt/.zcompdump
21 compinit:108> typeset -gHA _comps _services _patcomps _postpatcomps
21 compinit:76> [[ 3 -gt 0 && -i = -[dDiuC] ]]
21 compinit:71> setopt extendedglob
21 compinit:71> setopt extendedglob
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:121> shift _d_als
21 compdump:117> _i=5
21 compdump:116> ((  ! --_i && 1076 > 1  ))
21 compdump:116> ((  ! --_i && 1012 > 1  ))
21 compdump:116> ((  ! --_i && 980 > 1  ))
21 compdump:116> ((  ! --_i && 853 > 1  ))
21 compdump:116> ((  ! --_i && 797 > 1  ))
21 compdump:116> ((  ! --_i && 785 > 1  ))
21 compdump:116> ((  ! --_i && 732 > 1  ))
21 compdump:116> ((  ! --_i && 370 > 1  ))
21 compdump:116> ((  ! --_i && 368 > 1  ))
21 compdump:116> ((  ! --_i && 356 > 1  ))
21 compdump:116> ((  ! --_i && 290 > 1  ))
21 compdump:115> print -n ' _yt-dlp'
21 compdump:115> print -n ' _yadm'
21 compdump:115> print -n ' _x_visual'
21 compdump:115> print -n ' _x_utils'
21 compdump:115> print -n ' _x_modifier'
21 compdump:115> print -n ' _wiggle'
21 compdump:115> print -n ' _unexpand'
21 compdump:115> print -n ' _twisted'
21 compdump:115> print -n ' _toolchain-source'
21 compdump:115> print -n ' _sub_commands'
21 compdump:115> print -n ' _strip'
21 compdump:115> print -n ' _snap'
21 compdump:115> print -n ' _restic'
21 compdump:115> print -n ' _pdm'
21 compdump:115> print -n ' _ninja'
21 compdump:115> print -n ' _mpv'
21 compdump:115> print -n ' _meson'
21 compdump:115> print -n ' _kubectl'
21 compdump:115> print -n ' _heroku'
21 compdump:115> print -n ' _helm'
21 compdump:115> print -n ' _git'
21 compdump:115> print -n ' _getclip'
21 compdump:115> print -n ' _file_flags'
21 compdump:115> print -n ' _dvc'
21 compdump:115> print -n ' _docker'
21 compdump:115> print -n ' _dmesg'
21 compdump:115> print -n ' _darcs'
21 compdump:115> print -n ' _cu'
21 compdump:115> print -n ' _correct'
21 compdump:115> print -n ' _cockroach'
21 compdump:115> print -n ' _augeas'
21 compdump:115> print -n ' _abcde'
21 compdump:115> print -n ' _aap'
21 compdump:115> print -n ' _a2utils'
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:114> ((  ! 0  ))
21 compdump:113> ((  1094  ))
21 compdump:113> ((  865  ))
21 compdump:85> [[ capitalize-word = _* ]]
21 compdump:85> [[ _history-complete-older = _* && _history_complete_word = _* ]]
21 compdump:85> [[ _expand_alias = _* && _expand_alias = _* ]]
21 compdump:63> print -r - ''pydoc[0-9.]#'' ''_pydoc''
21 compdump:63> print -r - ''-value-,RUBY(LIB|OPT|PATH),-default-'' ''_ruby''
21 compdump:63> print -r - ''-value-,LC_*,-default-'' ''_locales''
21 compdump:63> print -r - ''-value-,GO*,-default-'' ''_golang''
21 compdump:63> print -r - ''-value-,CGO*,-default-'' ''_golang''
21 compdump:63> print -r - ''-value-,*path,-default-'' ''_directories''
21 compdump:63> print -r - ''-value-,*PATH,-default-'' ''_dir_list''
21 compdump:63> print -r - ''*/X11(|R<4->)/*'' ''_x_arguments''
21 compdump:63> print -r - ''(tiff*|*2tiff|pal2rgb)'' ''_tiff''
21 compdump:63> print -r - ''(texi(2*|ndex))'' ''_texi''
21 compdump:50> print -r - ''xzcat'' ''unxz''
21 compdump:50> print -r - ''unlzma'' ''unxz''
21 compdump:50> print -r - ''tunes2pod.pl'' ''tunes2pod''
21 compdump:50> print -r - ''mailx'' ''mail''
21 compdump:50> print -r - ''iceweasel'' ''firefox''
21 compdump:50> print -r - ''gnupod_search.pl'' ''gnupod_search''
21 compdump:50> print -r - ''gnupod_check.pl'' ''gnupod_check''
21 compdump:50> print -r - ''gnupod_addsong.pl'' ''gnupod_addsong''
21 compdump:50> print -r - ''gnupod_INIT.pl'' ''gnupod_INIT''
21 compdump:50> print -r - ''ggl'' ''git-checkout''
21 compdump:50> print -r - ''gdnolock'' ''git-diff''
21 compdump:50> print -r - ''bzcat'' ''bunzip2''
21 compdump:50> print -r - ''-redirect-,>,gzip'' ''gunzip''
21 compdump:50> print -r - ''-redirect-,>,compress'' ''uncompress''
21 compdump:50> print -r - ''-redirect-,>,bzip2'' ''bunzip2''
21 compdump:50> print -r - ''-redirect-,<,gunzip'' ''gunzip''
21 compdump:44> print -r - ''zsh-mime-handler'' ''_zsh-mime-handler''
21 compdump:44> print -r - ''slabtop'' ''_slabtop''
21 compdump:44> print -r - ''sha256'' ''_cksum''
21 compdump:44> print -r - ''btdownloadheadless'' ''_bittorrent''
21 compdump:44> print -r - ''aptitude'' ''_aptitude''
21 compdump:44> print -r - ''apropos'' ''_man''
21 compdump:44> print -r - ''aplay'' ''_alsa-utils''
21 compdump:44> print -r - ''apachectl'' ''_apachectl''
21 compdump:44> print -r - ''apache2ctl'' ''_apachectl''
21 compdump:44> print -r - ''aoss'' ''_precommand''
21 compdump:44> print -r - ''aodh'' ''_openstack''
21 compdump:44> print -r - ''antiword'' ''_antiword''
21 compdump:44> print -r - ''ansible-vault'' ''_ansible''
21 compdump:44> print -r - ''ansible-pull'' ''_ansible''
21 compdump:44> print -r - ''ansible-doc'' ''_ansible''
21 compdump:44> print -r - ''ansible-console'' ''_ansible''
21 compdump:44> print -r - ''ansible-config'' ''_ansible''
21 compdump:44> print -r - ''animate'' ''_imagemagick''
21 compdump:44> print -r - ''android'' ''_android''
21 compdump:44> print -r - ''amaya'' ''_webbrowser''
21 compdump:44> print -r - ''afew'' ''_afew''
21 compdump:44> print -r - ''admin'' ''_sccs''
21 compdump:44> print -r - ''add-zsh-hook'' ''_add-zsh-hook''
21 compdump:44> print -r - ''add-zle-hook-widget'' ''_add-zle-hook-widget''
21 compdump:44> print -r - ''acroread'' ''_acroread''
21 compdump:44> print -r - ''ack-standalone'' ''_ack''
21 compdump:44> print -r - ''ack-grep'' ''_ack''
21 compdump:44> print -r - ''ack'' ''_ack''
21 compdump:44> print -r - ''a2ensite'' ''_a2utils''
21 compdump:44> print -r - ''a2enmod'' ''_a2utils''
21 compdump:44> print -r - ''a2dissite'' ''_a2utils''
21 compdump:44> print -r - ''_git_log_prettily'' ''_git''
21 compdump:44> print -r - ''_cockroach'' ''_cockroach''
21 compdump:44> print -r - ''VBoxManage'' ''_virtualbox''
21 compdump:44> print -r - ''-zcalc-line-'' ''_zcalc_line''
21 compdump:44> print -r - ''-vared-'' ''_in_vared''
21 compdump:44> print -r - ''-value-,XZ_OPT,-default-'' ''_xz''
21 compdump:44> print -r - ''-value-,TZ,-default-'' ''_time_zone''
21 compdump:44> print -r - ''-value-,PS1,-default-'' ''_ps1234''
21 compdump:44> print -r - ''-value-,P4PORT,-default-'' ''_perforce''
21 compdump:44> print -r - ''-value-,LESS,-default-'' ''_less''
21 compdump:44> print -r - ''-value-,LDFLAGS,-default-'' ''_gcc''
21 compdump:44> print -r - ''-value-,LANG,-default-'' ''_locales''
21 compdump:44> print -r - ''-value-,GZIP,-default-'' ''_gzip''
21 compdump:44> print -r - ''-value-,DISPLAY,-default-'' ''_x_display''
21 compdump:44> print -r - ''-value-,CPPFLAGS,-default-'' ''_gcc''
21 compdump:44> print -r - ''-value-,CMAKE_GENERATOR,-default-'' ''_cmake''
21 compdump:44> print -r - ''-value-,ADB_TRACE,-default-'' ''_adb''
21 compdump:44> print -r - ''-tilde-'' ''_tilde''
21 compdump:44> print -r - ''-subscript-'' ''_subscript''
21 compdump:44> print -r - ''-redirect-,>,xz'' ''_xz''
21 compdump:44> print -r - ''-redirect-,>,bzip2'' ''_bzip2''
21 compdump:44> print -r - ''-redirect-,<,xz'' ''_xz''
21 compdump:44> print -r - ''-redirect-,<,uncompress'' ''_compress''
21 compdump:44> print -r - ''-redirect-,<,bzip2'' ''_bzip2''
21 compdump:44> print -r - ''-redirect-,<,bunzip2'' ''_bzip2''
21 compdump:44> print -r - ''-parameter-'' ''_parameter''
21 compdump:44> print -r - ''-math-'' ''_math''
21 compdump:44> print -r - ''-first-'' ''_first''
21 compdump:44> print -r - ''-default-'' ''_default''
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:169> shift
21 compdef:164> _services[$cmd]=unxz
21 compdef:164> _services[$cmd]=unxz
21 compdef:164> _services[$cmd]=uncompress
21 compdef:164> _services[$cmd]=tunes2pod
21 compdef:164> _services[$cmd]=ssh
21 compdef:164> _services[$cmd]=nc
21 compdef:164> _services[$cmd]=mail
21 compdef:164> _services[$cmd]=gnupod_search
21 compdef:164> _services[$cmd]=gnupod_check
21 compdef:164> _services[$cmd]=gnupod_INIT
21 compdef:164> _services[$cmd]=git-diff
21 compdef:164> _services[$cmd]=chgrp
21 compdef:164> _services[$cmd]=bzip2
21 compdef:164> _services[$cmd]=bunzip2
21 compdef:162> [[ -z yes || -z _zip ]]
21 compdef:162> [[ -z yes || -z _zdump ]]
21 compdef:162> [[ -z yes || -z _zcalc ]]
21 compdef:162> [[ -z yes || -z _xz ]]
21 compdef:162> [[ -z yes || -z _xxd ]]
21 compdef:162> [[ -z yes || -z _xournal ]]
21 compdef:162> [[ -z yes || -z _xmlsoft ]]
21 compdef:162> [[ -z yes || -z _xft_fonts ]]
21 compdef:162> [[ -z yes || -z _x_utils ]]
21 compdef:162> [[ -z yes || -z _who ]]
21 compdef:162> [[ -z yes || -z _which ]]
21 compdef:162> [[ -z yes || -z _wanna-build ]]
21 compdef:162> [[ -z yes || -z _vserver ]]
21 compdef:162> [[ -z yes || -z _vim-addons ]]
21 compdef:162> [[ -z yes || -z _vars ]]
21 compdef:162> [[ -z yes || -z _urxvt ]]
21 compdef:162> [[ -z yes || -z _urpmi ]]
21 compdef:162> [[ -z yes || -z _tput ]]
21 compdef:162> [[ -z yes || -z _toilet ]]
21 compdef:162> [[ -z yes || -z _texinfo ]]
21 compdef:162> [[ -z yes || -z _tar ]]
21 compdef:162> [[ -z yes || -z _svn-buildpackage ]]
21 compdef:162> [[ -z yes || -z _svm ]]
21 compdef:162> [[ -z yes || -z _subliminal ]]
21 compdef:162> [[ -z yes || -z _stack ]]
21 compdef:162> [[ -z yes || -z _sort ]]
21 compdef:162> [[ -z yes || -z _sfdx ]]
21 compdef:162> [[ -z yes || -z _setcap ]]
21 compdef:162> [[ -z yes || -z _service ]]
21 compdef:162> [[ -z yes || -z _samba ]]
21 compdef:162> [[ -z yes || -z _rmdir ]]
21 compdef:162> [[ -z yes || -z _rm ]]
21 compdef:162> [[ -z yes || -z _rake ]]
21 compdef:162> [[ -z yes || -z _quilt ]]
21 compdef:162> [[ -z yes || -z _psutils ]]
21 compdef:162> [[ -z yes || -z _postscript ]]
21 compdef:162> [[ -z yes || -z _postgresql ]]
21 compdef:162> [[ -z yes || -z _postgresql ]]
21 compdef:162> [[ -z yes || -z _postgresql ]]
21 compdef:162> [[ -z yes || -z _postfix ]]
21 compdef:162> [[ -z yes || -z _pkginfo ]]
21 compdef:162> [[ -z yes || -z _pids ]]
21 compdef:162> [[ -z yes || -z _pfctl ]]
21 compdef:162> [[ -z yes || -z _perl_modules ]]
21 compdef:162> [[ -z yes || -z _perf ]]
21 compdef:162> [[ -z yes || -z _pdf ]]
21 compdef:162> [[ -z yes || -z _patch ]]
21 compdef:162> [[ -z yes || -z _otool ]]
21 compdef:162> [[ -z yes || -z _other_accounts ]]
21 compdef:162> [[ -z yes || -z _optirun ]]
21 compdef:162> [[ -z yes || -z _openstack ]]
21 compdef:162> [[ -z yes || -z _objdump ]]
21 compdef:162> [[ -z yes || -z _nvm ]]
21 compdef:162> [[ -z yes || -z _nm ]]
21 compdef:162> [[ -z yes || -z _nl ]]
21 compdef:162> [[ -z yes || -z _netcat ]]
21 compdef:162> [[ -z yes || -z _net_interfaces ]]
21 compdef:162> [[ -z yes || -z _net_interfaces ]]
21 compdef:162> [[ -z yes || -z _ncftp ]]
21 compdef:162> [[ -z yes || -z _ncftp ]]
21 compdef:162> [[ -z yes || -z _mysqldiff ]]
21 compdef:162> [[ -z yes || -z _mvn ]]
21 compdef:162> [[ -z yes || -z _mt ]]
21 compdef:162> [[ -z yes || -z _mpc ]]
21 compdef:162> [[ -z yes || -z _mpc ]]
21 compdef:162> [[ -z yes || -z _mount ]]
21 compdef:162> [[ -z yes || -z _mount ]]
21 compdef:162> [[ -z yes || -z _mosh ]]
21 compdef:162> [[ -z yes || -z _moosic ]]
21 compdef:162> [[ -z yes || -z _mondo ]]
21 compdef:162> [[ -z yes || -z _mkzsh ]]
21 compdef:162> [[ -z yes || -z _mktemp ]]
21 compdef:162> [[ -z yes || -z _mktemp ]]
21 compdef:162> [[ -z yes || -z _mkshortcut ]]
21 compdef:162> [[ -z yes || -z _mknod ]]
21 compdef:162> [[ -z yes || -z _mh ]]
21 compdef:162> [[ -z yes || -z _mere ]]
21 compdef:162> [[ -z yes || -z _md5sum ]]
21 compdef:162> [[ -z yes || -z _md5sum ]]
21 compdef:162> [[ -z yes || -z _make ]]
21 compdef:162> [[ -z yes || -z _lynx ]]
21 compdef:162> [[ -z yes || -z _lslv ]]
21 compdef:162> [[ -z yes || -z _lsdev ]]
21 compdef:162> [[ -z yes || -z _losetup ]]
21 compdef:162> [[ -z yes || -z _locate ]]
21 compdef:162> [[ -z yes || -z _locales ]]
21 compdef:162> [[ -z yes || -z _locales ]]
21 compdef:162> [[ -z yes || -z _ln ]]
21 compdef:162> [[ -z yes || -z _ld_debug ]]
21 compdef:162> [[ -z yes || -z _last ]]
21 compdef:162> [[ -z yes || -z _kfmclient ]]
21 compdef:162> [[ -z yes || -z _jobs_fg ]]
21 compdef:162> [[ -z yes || -z _jobs_bg ]]
21 compdef:162> [[ -z yes || -z _jls ]]
21 compdef:162> [[ -z yes || -z _irssi ]]
21 compdef:162> [[ -z yes || -z _install ]]
21 compdef:162> [[ -z yes || -z _include-what-you-use ]]
21 compdef:162> [[ -z yes || -z _imagemagick ]]
21 compdef:162> [[ -z yes || -z _iconvconfig ]]
21 compdef:162> [[ -z yes || -z _ibus ]]
21 compdef:162> [[ -z yes || -z _hub ]]
21 compdef:162> [[ -z yes || -z _hosts ]]
21 compdef:162> [[ -z yes || -z _hostname ]]
21 compdef:162> [[ -z yes || -z _hexdump ]]
21 compdef:162> [[ -z yes || -z _helm ]]
21 compdef:162> [[ -z yes || -z _head ]]
21 compdef:162> [[ -z yes || -z _hdiutil ]]
21 compdef:162> [[ -z yes || -z _gzip ]]
21 compdef:162> [[ -z yes || -z _gzip ]]
21 compdef:162> [[ -z yes || -z _gv ]]
21 compdef:162> [[ -z yes || -z _guilt ]]
21 compdef:162> [[ -z yes || -z _guilt ]]
21 compdef:162> [[ -z yes || -z _guilt ]]
21 compdef:162> [[ -z yes || -z _groff ]]
21 compdef:162> [[ -z yes || -z _graphicsmagick ]]
21 compdef:162> [[ -z yes || -z _gphoto2 ]]
21 compdef:162> [[ -z yes || -z _go ]]
21 compdef:162> [[ -z yes || -z _gist ]]
21 compdef:162> [[ -z yes || -z _ghostscript ]]
21 compdef:162> [[ -z yes || -z _getopt ]]
21 compdef:162> [[ -z yes || -z _getclip ]]
21 compdef:162> [[ -z yes || -z _gcore ]]
21 compdef:162> [[ -z yes || -z _fuser ]]
21 compdef:162> [[ -z yes || -z _functions ]]
21 compdef:162> [[ -z yes || -z _fstat ]]
21 compdef:162> [[ -z yes || -z _force ]]
21 compdef:162> [[ -z yes || -z _flowadm ]]
21 compdef:162> [[ -z yes || -z _flex ]]
21 compdef:162> [[ -z yes || -z _flac ]]
21 compdef:162> [[ -z yes || -z _findmnt ]]
21 compdef:162> [[ -z yes || -z _find ]]
21 compdef:162> [[ -z yes || -z _find ]]
21 compdef:162> [[ -z yes || -z _files ]]
21 compdef:162> [[ -z yes || -z _fc ]]
21 compdef:162> [[ -z yes || -z _fakeroot ]]
21 compdef:162> [[ -z yes || -z _fab ]]
21 compdef:162> [[ -z yes || -z _envdir ]]
21 compdef:162> [[ -z yes || -z _echoti ]]
21 compdef:162> [[ -z yes || -z _ecdsautil ]]
21 compdef:162> [[ -z yes || -z _e2label ]]
21 compdef:162> [[ -z yes || -z _dtrace ]]
21 compdef:162> [[ -z yes || -z _docpad ]]
21 compdef:162> [[ -z yes || -z _directories ]]
21 compdef:162> [[ -z yes || -z _diff ]]
21 compdef:162> [[ -z yes || -z _dhcpcd ]]
21 compdef:162> [[ -z yes || -z _df ]]
21 compdef:162> [[ -z yes || -z _devtodo ]]
21 compdef:162> [[ -z yes || -z _dcop ]]
21 compdef:162> [[ -z yes || -z _dcop ]]
21 compdef:162> [[ -z yes || -z _cpio ]]
21 compdef:162> [[ -z yes || -z _cowsay ]]
21 compdef:162> [[ -z yes || -z _composer ]]
21 compdef:162> [[ -z yes || -z _cmp ]]
21 compdef:162> [[ -z yes || -z _cmake ]]
21 compdef:162> [[ -z yes || -z _cd ]]
21 compdef:162> [[ -z yes || -z _bts ]]
21 compdef:162> [[ -z yes || -z _bsdinstall ]]
21 compdef:162> [[ -z yes || -z _brace_parameter ]]
21 compdef:162> [[ -z yes || -z _bittorrent ]]
21 compdef:162> [[ -z yes || -z _basename ]]
21 compdef:162> [[ -z yes || -z _basename ]]
21 compdef:162> [[ -z yes || -z _awk ]]
21 compdef:162> [[ -z yes || -z _asciinema ]]
21 compdef:162> [[ -z yes || -z _asciidoctor ]]
21 compdef:162> [[ -z yes || -z _artisan ]]
21 compdef:162> [[ -z yes || -z _arping ]]
21 compdef:162> [[ -z yes || -z _archlinux-java ]]
21 compdef:162> [[ -z yes || -z _aptitude ]]
21 compdef:162> [[ -z yes || -z _apt-show-versions ]]
21 compdef:162> [[ -z yes || -z _apm ]]
21 compdef:162> [[ -z yes || -z _apachectl ]]
21 compdef:162> [[ -z yes || -z _apachectl ]]
21 compdef:162> [[ -z yes || -z _antiword ]]
21 compdef:162> [[ -z yes || -z _ansible ]]
21 compdef:162> [[ -z yes || -z _analyseplugin ]]
21 compdef:162> [[ -z yes || -z _aliases ]]
21 compdef:162> [[ -z yes || -z _add-zsh-hook ]]
21 compdef:162> [[ -z yes || -z '' ]]
21 compdef:162> [[ -z yes || -z '' ]]
21 compdef:157> svc=yes
21 compdef:156> cmd='-redirect-,<,uncompress'
21 compdef:155> [[ yadm = *=* ]]
21 compdef:155> [[ twidge = *=* ]]
21 compdef:155> [[ traceroute = *=* ]]
21 compdef:155> [[ tmuxinator = *=* ]]
21 compdef:155> [[ tardy = *=* ]]
21 compdef:155> [[ rusage = *=* ]]
21 compdef:155> [[ initctl = *=* ]]
21 compdef:155> [[ cpupower = *=* ]]
21 compdef:155> [[ cheat = *=* ]]
21 compdef:155> [[ afew = *=* ]]
21 compdef:151> _postpatcomps[$1]=_python
21 compdef:139> case  (postpattern)
21 compdef:139> case  (pattern)
21 compdef:139> case  (pattern)
21 compdef:139> case  (pattern)
21 compdef:139> case  (pattern)
21 compdef:139> case  (pattern)
21 compdef:139> case  (*)
21 compdef:139> case  (*)
21 compdef:139> case  (*)
21 compdef:136> [[ dcopstart = -P ]]
21 compdef:134> [[ strip = -p ]]
21 compdef:134> [[ poff = -p ]]
21 compdef:134> [[ getopts = -p ]]
21 compdef:134> [[ diana = -p ]]
21 compdef:134> [[ ack-grep = -p ]]
21 compdef:132> [[ zsh-mime-handler = -N ]]
21 compdef:132> [[ zsh = -N ]]
21 compdef:132> [[ zparseopts = -N ]]
21 compdef:132> [[ zcat = -N ]]
21 compdef:132> [[ yarn = -N ]]
21 compdef:132> [[ xsltproc = -N ]]
21 compdef:132> [[ xcode-select = -N ]]
21 compdef:132> [[ xclip = -N ]]
21 compdef:132> [[ xautolock = -N ]]
21 compdef:132> [[ vagrant = -N ]]
21 compdef:132> [[ urpme = -N ]]
21 compdef:132> [[ units = -N ]]
21 compdef:132> [[ tpb = -N ]]
21 compdef:132> [[ tox = -N ]]
21 compdef:132> [[ surfraw = -N ]]
21 compdef:132> [[ sqsh = -N ]]
21 compdef:132> [[ sort = -N ]]
21 compdef:132> [[ smbcontrol = -N ]]
21 compdef:132> [[ scrub = -N ]]
21 compdef:132> [[ sbt = -N ]]
21 compdef:132> [[ rkt = -N ]]
21 compdef:132> [[ readshortcut = -N ]]
21 compdef:132> [[ ping = -N ]]
21 compdef:132> [[ pfexec = -N ]]
21 compdef:132> [[ nmcli = -N ]]
21 compdef:132> [[ mc = -N ]]
21 compdef:132> [[ matlab = -N ]]
21 compdef:132> [[ jobs = -N ]]
21 compdef:132> [[ iwconfig = -N ]]
21 compdef:132> [[ heroku = -N ]]
21 compdef:132> [[ hash = -N ]]
21 compdef:132> [[ gqview = -N ]]
21 compdef:132> [[ fs_usage = -N ]]
21 compdef:132> [[ flex = -N ]]
21 compdef:132> [[ envdir = -N ]]
21 compdef:132> [[ emulator = -N ]]
21 compdef:132> [[ elfdump = -N ]]
21 compdef:132> [[ dput = -N ]]
21 compdef:132> [[ dpatch-edit-patch = -N ]]
21 compdef:132> [[ doas = -N ]]
21 compdef:132> [[ dlocate = -N ]]
21 compdef:132> [[ dconf = -N ]]
21 compdef:132> [[ darcs = -N ]]
21 compdef:132> [[ cygpath = -N ]]
21 compdef:132> [[ configure = -N ]]
21 compdef:132> [[ compdef = -N ]]
21 compdef:132> [[ command = -N ]]
21 compdef:132> [[ coffee = -N ]]
21 compdef:132> [[ cdbs-edit-patch = -N ]]
21 compdef:132> [[ _helm = -N ]]
21 compdef:132> [[ -value-,LANG,-default- = -N ]]
21 compdef:132> [[ -redirect-,-default-,-default- = -N ]]
21 compdef:132> [[ -command- = -N ]]
21 compdef:132> [[ '*/X11(|R<4->)/*' = -N ]]
21 compdef:131> ((  14  ))
21 compdef:131> ((  4  ))
21 compdef:131> ((  4  ))
21 compdef:131> ((  1  ))
21 compdef:131> ((  1  ))
21 compdef:117> shift
21 compdef:91> [[ complete-word = .* ]]
21 compdef:83> case  (widgetkey)
21 compdef:83> case  (widgetkey)
21 compdef:83> case  (*)
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:81> shift
21 compdef:80> autoload -Uz _ztodo
21 compdef:80> autoload -Uz _zpool
21 compdef:80> autoload -Uz _zoneadm
21 compdef:80> autoload -Uz _zcompile
21 compdef:80> autoload -Uz _yaourt
21 compdef:80> autoload -Uz _xpdf
21 compdef:80> autoload -Uz _wipefs
21 compdef:80> autoload -Uz _whereis
21 compdef:80> autoload -Uz _twisted
21 compdef:80> autoload -Uz _transmission
21 compdef:80> autoload -Uz _tpb
21 compdef:80> autoload -Uz _svm
21 compdef:80> autoload -Uz _subscript
21 compdef:80> autoload -Uz _subl
21 compdef:80> autoload -Uz _socket
21 compdef:80> autoload -Uz _showoff
21 compdef:80> autoload -Uz _sfdx
21 compdef:80> autoload -Uz _rsvm
21 compdef:80> autoload -Uz _rkt
21 compdef:80> autoload -Uz _renice
21 compdef:80> autoload -Uz _readelf
21 compdef:80> autoload -Uz _qdbus
21 compdef:80> autoload -Uz _prove
21 compdef:80> autoload -Uz _printenv
21 compdef:80> autoload -Uz _pkg-config
21 compdef:80> autoload -Uz _pgsql_utils
21 compdef:80> autoload -Uz _pdm
21 compdef:80> autoload -Uz _pdf
21 compdef:80> autoload -Uz _pack
21 compdef:80> autoload -Uz _nice
21 compdef:80> autoload -Uz _nanoc
21 compdef:80> autoload -Uz _nano
21 compdef:80> autoload -Uz _mysqldiff
21 compdef:80> autoload -Uz _mvn
21 compdef:80> autoload -Uz _mussh
21 compdef:80> autoload -Uz _moosic
21 compdef:80> autoload -Uz _mkshortcut
21 compdef:80> autoload -Uz _mc
21 compdef:80> autoload -Uz _make-kpkg
21 compdef:80> autoload -Uz _lsof
21 compdef:80> autoload -Uz _ln
21 compdef:80> autoload -Uz _ld_debug
21 compdef:80> autoload -Uz _jexec
21 compdef:80> autoload -Uz _hdiutil
21 compdef:80> autoload -Uz _gzip
21 compdef:80> autoload -Uz _gqview
21 compdef:80> autoload -Uz _git-flow
21 compdef:80> autoload -Uz _gist
21 compdef:80> autoload -Uz _getmail
21 compdef:80> autoload -Uz _flex
21 compdef:80> autoload -Uz _ffmpeg
21 compdef:80> autoload -Uz _eog
21 compdef:80> autoload -Uz _elfdump
21 compdef:80> autoload -Uz _ed
21 compdef:80> autoload -Uz _echoti
21 compdef:80> autoload -Uz _echotc
21 compdef:80> autoload -Uz _dupload
21 compdef:80> autoload -Uz _du
21 compdef:80> autoload -Uz _docker_compose
21 compdef:80> autoload -Uz _dlocate
21 compdef:80> autoload -Uz _dirs
21 compdef:80> autoload -Uz _dig
21 compdef:80> autoload -Uz _diff
21 compdef:80> autoload -Uz _dhcpcd
21 compdef:80> autoload -Uz _deno
21 compdef:80> autoload -Uz _dchroot
21 compdef:80> autoload -Uz _dbus
21 compdef:80> autoload -Uz _cygrunsrv
21 compdef:80> autoload -Uz _cryptsetup
21 compdef:80> autoload -Uz _cplay
21 compdef:80> autoload -Uz _complete_help
21 compdef:80> autoload -Uz _command
21 compdef:80> autoload -Uz _clay
21 compdef:80> autoload -Uz _calendar
21 compdef:80> autoload -Uz _bug
21 compdef:80> autoload -Uz _apachectl
21 compdef:80> autoload -Uz _add-zle-hook-widget
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:80> [[ -n yes ]]
21 compdef:79> func=_yast
21 compdef:79> func=_rspec
21 compdef:79> func=_dmesg
21 compdef:49> [[ _xinput = *=* ]]
21 compdef:49> [[ _wait = *=* ]]
21 compdef:49> [[ _unhash = *=* ]]
21 compdef:49> [[ _route = *=* ]]
21 compdef:49> [[ _rake = *=* ]]
21 compdef:49> [[ _mh = *=* ]]
21 compdef:49> [[ _mdadm = *=* ]]
21 compdef:49> [[ _git = *=* ]]
21 compdef:49> [[ _ecdsautil = *=* ]]
21 compdef:49> [[ _directory_stack = *=* ]]
21 compdef:49> [[ _dhcpinfo = *=* ]]
21 compdef:49> [[ _default = *=* ]]
21 compdef:49> [[ _debchange = *=* ]]
21 compdef:49> [[ _chrt = *=* ]]
21 compdef:49> [[ _chkconfig = *=* ]]
21 compdef:49> [[ _chflags = *=* ]]
21 compdef:49> [[ _caffeinate = *=* ]]
21 compdef:49> [[ _cabal = *=* ]]
21 compdef:49> [[ _bzr = *=* ]]
21 compdef:49> [[ -z '' ]]
21 compdef:40> ((  ! 13  ))
21 compdef:40> ((  ! 12  ))
21 compdef:40> ((  ! 3  ))
21 compdef:40> ((  ! 3  ))
21 compdef:40> ((  ! 3  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:40> ((  ! 2  ))
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:38> shift OPTIND-1
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:17> new=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:16> autol=yes
21 compdef:15> case n (n)
21 compdef:15> case n (n)
21 compdef:15> case n (a)
21 compdef:15> case n (a)
21 compdef:15> case n (a)
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:14> getopts anpPkKde opt
21 compdef:9> ((  ! 19  ))
21 compdef:9> ((  ! 19  ))
21 compdef:9> ((  ! 15  ))
21 compdef:9> ((  ! 14  ))
21 compdef:9> ((  ! 13  ))
21 compdef:9> ((  ! 13  ))
21 compdef:9> ((  ! 13  ))
21 compdef:9> ((  ! 12  ))
21 compdef:9> ((  ! 12  ))
21 compdef:9> ((  ! 11  ))
21 compdef:9> ((  ! 10  ))
21 compdef:9> ((  ! 7  ))
21 compdef:9> ((  ! 7  ))
21 compdef:9> ((  ! 7  ))
21 compdef:9> ((  ! 7  ))
21 compdef:9> ((  ! 6  ))
21 compdef:9> ((  ! 6  ))
21 compdef:9> ((  ! 6  ))
21 compdef:9> ((  ! 6  ))
21 compdef:9> ((  ! 6  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 5  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 4  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:9> ((  ! 3  ))
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:5> setopt extendedglob
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:4> emulate -L zsh
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compdef:2> local -a match mbegin mend
21 compaudit:146> [[ -f /etc/debian_version ]]
21 colors:105> fg[${k#fg-}]=$'C-[[31m'
21 colors:77> color[${color[$k]}]=32
21 colors:6> typeset -Ag color colour
21 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=antigen-apply-lock:antigen-...
21 antigen-remove-hook:4> hooks=( antigen-bundle-defer antigen-bundle-cached ant...
21 antigen-remove-hook:3> local target=antigen-bundle
21 antigen-remove-hook:3> local target=antigen-bundle
21 antigen-ext:1> local ext=defer
21 antigen-ext:1> local ext=cache
21 antigen-bundle-parallel-execute:24> repositories+=( https://github.com/robbyr...
21 antigen-bundle-parallel-execute:24> repositories+=( https://github.com/robbyr...
21 antigen-bundle-parallel-execute:11> typeset -A bundle
21 antigen-bundle-defer:1> _DEFERRED_BUNDLE+=( zsh-users/zsh-autosuggestions )
21 antigen-bundle-defer:1> _DEFERRED_BUNDLE+=( deno )
21 antigen-bundle-defer:1> _DEFERRED_BUNDLE+=( '--loc=lib' )
21 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-bundle
21 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-apply
21 antigen-add-hook:22> local hook_function=-antigen-hook-antigen
21 antigen-add-hook:22> local hook_function=-antigen-hook--antigen-load-env
21 antigen-add-hook:19> _ANTIGEN_HOOKS_META[$hook]='target antigen-bundle type p...
21 antigen-add-hook:3> ((  ! 1  ))
21 antigen-add-hook:1> local target=-antigen-load-env hook=-antigen-load-env-cac...
21 add-zsh-hook:66> local fn=omz_termsupport_precmd
21 add-zsh-hook:66> local fn=_antigen_compinit
21 add-zsh-hook:65> local hook=preexec_functions
21 add-zsh-hook:65> local hook=precmd_functions
21 add-zsh-hook:65> local hook=precmd_functions
21 add-zsh-hook:60> ((  help || 2 != 2 || 3 == 0  ))
21 add-zsh-hook:60> ((  help || 2 != 2 || 3 == 0  ))
21 add-zsh-hook:26> integer del list help
21 add-zsh-hook:26> integer del list help
21 add-zsh-hook:25> local -a autoopts
21 add-zsh-hook:24> local opt
21 add-zsh-hook:24> local opt
21 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
21 add-zsh-hook:18> hooktypes=( chpwd precmd preexec periodic zshaddhistory zshe...
21 add-zsh-hook:17> local -a hooktypes
21 add-zle-hook-widget:101> ((  ! 0  ))
21 add-zle-hook-widget:95> i=0+1
21 add-zle-hook-widget:81> integer i=3-2
21 add-zle-hook-widget:51> local hook=zle-line-finish
21 add-zle-hook-widget:45> ((  help || 2 != 2 || 5 == 0  ))
21 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
21 _zsh_highlight_bind_widgets:54> ((  ! 0  ))
21 _zsh_highlight_bind_widgets:50> zle -N visual-line-mode _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N vi-yank-eol _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N vi-set-buffer _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N vi-rev-repeat-search _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N vi-rev-repeat-find _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N vi-replace-chars _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N vi-repeat-find _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N vi-quoted-insert _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N vi-pound-insert _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:50> zle -N vi-open-line-below _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N vi-open-line-above _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N vi-kill-line _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:50> zle -N vi-history-search-backward _zsh_highli...
21 _zsh_highlight_bind_widgets:50> zle -N vi-goto-mark-line _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N vi-forward-word-end _zsh_highlight_wid...
21 _zsh_highlight_bind_widgets:50> zle -N vi-forward-char _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:50> zle -N vi-forward-blank-word _zsh_highlight_w...
21 _zsh_highlight_bind_widgets:50> zle -N vi-first-non-blank _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N vi-find-prev-char-skip _zsh_highlight_...
21 _zsh_highlight_bind_widgets:50> zle -N vi-find-prev-char _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N vi-find-next-char _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N vi-fetch-history _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N vi-end-of-line _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N vi-down-case _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:50> zle -N vi-cmd-mode _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N vi-change _zsh_highlight_widget_orig-s...
21 _zsh_highlight_bind_widgets:50> zle -N vi-beginning-of-line _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N vi-backward-word-end _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N vi-backward-word _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N vi-backward-kill-word _zsh_highlight_w...
21 _zsh_highlight_bind_widgets:50> zle -N up-line-or-search _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N up-line-or-history _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N universal-argument _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N undefined-key _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N transpose-words _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:50> zle -N set-mark-command _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:50> zle -N send-break _zsh_highlight_widget_orig-...
21 _zsh_highlight_bind_widgets:50> zle -N self-insert-unmeta _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N select-in-word _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N select-in-shell-word _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N select-a-word _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N recursive-edit _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N quote-region _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:50> zle -N put-replace-selection _zsh_highlight_w...
21 _zsh_highlight_bind_widgets:50> zle -N magic-space _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N list-expand _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N kill-whole-line _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:50> zle -N kill-region _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N infer-next-history _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N get-line _zsh_highlight_widget_orig-s0...
21 _zsh_highlight_bind_widgets:50> zle -N expand-history _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N expand-cmd-path _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:50> zle -N execute-named-cmd _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N emacs-forward-word _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N down-line-or-search _zsh_highlight_wid...
21 _zsh_highlight_bind_widgets:50> zle -N down-line _zsh_highlight_widget_orig-s...
21 _zsh_highlight_bind_widgets:50> zle -N down-history _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:50> zle -N down-case-word _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N digit-argument _zsh_highlight_widget_o...
21 _zsh_highlight_bind_widgets:50> zle -N delete-word _zsh_highlight_widget_orig...
21 _zsh_highlight_bind_widgets:50> zle -N deactivate-region _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:50> zle -N copy-region-as-kill _zsh_highlight_wid...
21 _zsh_highlight_bind_widgets:50> zle -N beginning-of-line-hist _zsh_highlight_...
21 _zsh_highlight_bind_widgets:50> zle -N backward-kill-line _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N backward-delete-word _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N backward-delete-char _zsh_highlight_wi...
21 _zsh_highlight_bind_widgets:50> zle -N backward-char _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N auto-suffix-retain _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:50> zle -N argument-base _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N accept-search _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:50> zle -N accept-line-and-down-history _zsh_high...
21 _zsh_highlight_bind_widgets:46> zle -N list-choices _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:46> zle -N expand-or-complete _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:46> zle -N complete-word _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:46> zle -N _next_tags _zsh_highlight_widget_orig-...
21 _zsh_highlight_bind_widgets:46> zle -N _most_recent_file _zsh_highlight_widge...
21 _zsh_highlight_bind_widgets:46> zle -N _list_expansions _zsh_highlight_widget...
21 _zsh_highlight_bind_widgets:46> zle -N _history-complete-newer _zsh_highlight...
21 _zsh_highlight_bind_widgets:46> zle -N _expand_word _zsh_highlight_widget_ori...
21 _zsh_highlight_bind_widgets:46> zle -N _expand_alias _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:46> zle -N _bash_list-choices _zsh_highlight_widg...
21 _zsh_highlight_bind_widgets:46> zle -N _bash_complete-word _zsh_highlight_wid...
21 _zsh_highlight_bind_widgets:41> zle -N zle-line-init _zsh_highlight_widget_or...
21 _zsh_highlight_bind_widgets:41> zle -N zle-line-finish _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:41> zle -N up-line-or-beginning-search _zsh_highl...
21 _zsh_highlight_bind_widgets:41> zle -N bracketed-paste _zsh_highlight_widget_...
21 _zsh_highlight_bind_widgets:27> case user:zle-line-init (user:*)
21 _zsh_highlight_bind_widgets:27> case user:zle-line-finish (user:*)
21 _zsh_highlight_bind_widgets:27> case user:url-quote-magic (user:*)
21 _zsh_highlight_bind_widgets:27> case user:up-line-or-beginning-search (user:*)
21 _zsh_highlight_bind_widgets:27> case user:edit-command-line (user:*)
21 _zsh_highlight_bind_widgets:27> case completion:.reverse-menu-complete:_main_...
21 _zsh_highlight_bind_widgets:27> case completion:.menu-complete:_main_complete...
21 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_word ...
21 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_help...
21 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_debu...
21 _zsh_highlight_bind_widgets:27> case builtin (user:*)
21 _zsh_highlight_bind_widgets:27> case builtin (user:*)
21 _zsh_highlight_bind_widgets:27> case builtin (user:*)
21 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
21 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
21 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
21 _zsh_highlight_bind_widgets:27> case builtin (builtin)
21 _zsh_highlight_bind_widgets:27> case builtin (builtin)
21 _zsh_highlight_bind_widgets:27> case builtin (builtin)
21 _zsh_highlight_bind_widgets:27> case builtin (builtin)
21 _zsh_highlight_bind_widgets:26> cur_widget=quoted-insert
21 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:15> __p9k_src_opts+=( al...
21 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:15> [[ ! -o aliases ]]
21 /usr/local/opt/asdf/libexec/asdf.sh:25> ASDF_BIN=/usr/local/opt/asdf/libexec/bin
21 /usr/local/opt/asdf/libexec/asdf.sh:9> [[ /usr/local/opt/asdf/libexec/asdf.sh...
21 /Users/matt/.zshrc:390> alias 'et=empty-trash'
21 /Users/matt/.zshrc:386> alias 'e=exit'
21 /Users/matt/.zshrc:212> alias 'nrr=npm run release'
21 /Users/matt/.zshrc:209> alias 'nrc=npm run commit'
21 /Users/matt/.zshrc:171> export BROWSER=firefox
21 /Users/matt/.zcompdump:1967> bindkey '^X^R' _read_comp
21 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1802> bindkey '^X?' _complet...
21 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
21 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
21 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
21 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
21 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;233m%}'
21 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;114m%}'
21 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;248m%}'
21 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;115m%}'
21 /Users/matt/.oh-my-zsh/lib/misc.zsh:22> env_default LESS -R
21 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:107> bindkey 'ew' kill-region
21 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:103> bindkey -M viins '^[[1;5D' b...
21 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:98> bindkey -M emacs '^[[1;5C' fo...
21 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:93> bindkey -M emacs '^[[3;5~' ki...
21 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:7> ((  1  ))
21 /Users/matt/.oh-my-zsh/lib/history.zsh:21> case  (mm/dd/yyyy)
21 /Users/matt/.oh-my-zsh/lib/directories.zsh:9> alias -g '......=../../../../..'
21 /Users/matt/.oh-my-zsh/custom/plugins/zsh-syntax-highlighting/zsh-syntax-high...
21 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
21 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2ul=/Users/matt/.iter...
21 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2git=/Users/matt/.ite...
21 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2dl=/Users/matt/.iter...
21 /Users/matt/.iterm2_shell_integration.zsh:170> alias 'it2check=/Users/matt/.i...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/zsh-syntax-hig...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
21 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/b...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:22> env_defa...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:11> autoload...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:109>...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:107>...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:94> ...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:75> ...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:44> ...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:40> ...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:24> ...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:34> [[...
21 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:6> uns...
21 -antigen-use-oh-my-zsh:6> [[ -z /Users/matt/.oh-my-zsh/cache ]]
21 -antigen-set-default:2> local arg_value=true
21 -antigen-set-default:2> local arg_value=true
21 -antigen-set-default:2> local arg_value=true
21 -antigen-set-default:2> local arg_value=/dev/null
21 -antigen-set-default:2> local arg_value=-i
21 -antigen-set-default:2> local arg_value='GIT_TERMINAL_PROMPT=0'
21 -antigen-set-default:1> local arg_name=_ANTIGEN_THEME_COMPAT
21 -antigen-set-default:1> local arg_name=_ANTIGEN_GREP_COMMAND
21 -antigen-set-default:1> local arg_name=ANTIGEN_MUTEX
21 -antigen-set-default:1> local arg_name=ANTIGEN_COMPDUMP
21 -antigen-set-default:1> local arg_name=ANTIGEN_CLONE_OPTS
21 -antigen-set-default:1> local arg_name=ANTIGEN_BUNDLES
21 -antigen-set-default:1> local arg_name=ANTIGEN_AUTO_CONFIG
21 -antigen-set-default:1> local arg_name=ADOTDIR
21 -antigen-parse-args:160> args[name]=''robbyrussell/oh-my-zsh''
21 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/zsh-users/z...
21 -antigen-parse-args:134> [[ true == true ]]
21 -antigen-parse-args:112> [[ plugin == theme ]]
21 -antigen-parse-args:112> [[ plugin == theme ]]
21 -antigen-parse-args:112> [[ plugin == theme ]]
21 -antigen-parse-args:112> [[ plugin == theme ]]
21 -antigen-parse-args:69> [[ zsh-users/zsh-autosuggestions != */* ]]
21 -antigen-parse-args:61> args[$key]=zsh-users/zsh-syntax-highlighting
21 -antigen-parse-args:61> args[$key]=zsh-users/zsh-autosuggestions
21 -antigen-parse-args:55> value=deno
21 -antigen-parse-args:55> value=deno
21 -antigen-parse-args:41> local domain=''
21 -antigen-parse-args:20> value=zsh-users/zsh-syntax-highlighting
21 -antigen-parse-args:19> key=zsh-users/zsh-syntax-highlighting
21 -antigen-parse-args:5> shift
21 -antigen-parse-args:5> shift
21 -antigen-parse-args:4> local var=bundle
21 -antigen-parse-args:2> local match mbegin mend MATCH MBEGIN MEND
21 -antigen-load:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/li...
21 -antigen-load-env-cached:7> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/bun...
21 -antigen-load-env-cached:7> _ZCACHE_BUNDLE_SOURCE+=( /Users/matt/.antigen/bun...
21 -antigen-load-env-cached:3> local location=/Users/matt/.antigen/bundles/zsh-u...
21 -antigen-load-env-cached:3> local location=/Users/matt/.antigen/bundles/robby...
21 -antigen-load-env-cached:1> local bundle
21 -antigen-load-env-cached:1> local bundle
21 -antigen-hook-handler:55> [[ 1 == 0 ]]
21 -antigen-hook-handler:55> [[ 1 == 0 ]]
21 -antigen-hook-handler:51> [[ 0 == -1 ]]
21 -antigen-hook-handler:51> [[ 0 == -1 ]]
21 -antigen-hook-handler:51> [[ 0 == -1 ]]
21 -antigen-hook-handler:51> [[ 0 == -1 ]]
21 -antigen-hook-handler:51> [[ 0 == -1 ]]
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:48> ((  1  ))
21 -antigen-hook-handler:44> local replace_hook=0 ret=0
21 -antigen-hook-handler:44> local replace_hook=0 ret=0
21 -antigen-hook-handler:44> local replace_hook=0 ret=0
21 -antigen-hook-handler:44> local replace_hook=0 ret=0
21 -antigen-hook-handler:40> [[ 0 == -1 ]]
21 -antigen-hook-handler:40> [[ 0 == -1 ]]
21 -antigen-hook-handler:40> [[ 0 == -1 ]]
21 -antigen-hook-handler:40> [[ 0 == -1 ]]
21 -antigen-hook-handler:37> hook=antigen-bundle-cached
21 -antigen-hook-handler:37> hook=antigen-bundle-cached
21 -antigen-hook-handler:37> hook=antigen-bundle-cached
21 -antigen-hook-handler:37> hook=antigen-bundle-cached
21 -antigen-hook-handler:17> let 'called=3+1'
21 -antigen-hook-handler:17> let 'called=2+1'
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ repeat == once ]]
21 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
21 -antigen-hook-handler:12> [[ once == once && 1 == 1 ]]
21 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
21 -antigen-hook-handler:12> [[ once == once && 0 == 1 ]]
21 -antigen-hook-handler:7> hooks=( -antigen-load-source-cached )
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:6> typeset -a pre_hooks replace_hooks post_hooks
21 -antigen-hook-handler:4> args=( bundle zsh-users/zsh-syntax-highlighting )
21 -antigen-hook-handler:4> args=( bundle zsh-users/zsh-autosuggestions )
21 -antigen-hook-handler:2> local hooks meta
21 -antigen-hook-handler:2> local hooks meta
21 -antigen-hook-handler:2> local hooks meta
21 -antigen-hook-handler:1> local target=antigen args hook called
21 -antigen-hook-antigen-bundle:7> typeset -A bundle
21 -antigen-cache-generate:20> _PATH+=( /Users/matt/.antigen/bundles/zsh-users/z...
21 -antigen-cache-generate:18> _sources+=( $'source '/Users/matt/.antigen/bundle...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
21 (eval):210> alias 'gwip=git add -A; git rm $(git ls-files --deleted) 2> /dev/...
21 (eval):109> alias 'glols=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
21 (eval):57> alias 'gcl=git clone --recurse-submodules'
21 (eval):55> alias 'gbda=git branch --no-color --merged | command grep -vE "^([...
21 (eval):1> -antigen-defer-init
21 (eval):1> -antigen-cache-init
21 (anon):1491> typeset -g POWERLEVEL9K_TIME_UPDATE_ON_COMMAND=false
21 (anon):1487> typeset -g POWERLEVEL9K_TIME_FORMAT='%D{%I:%M:%S %p}'
21 (anon):1455> typeset -g POWERLEVEL9K_BATTERY_VERBOSE=false
21 (anon):1414> typeset -g POWERLEVEL9K_VPN_IP_SHOW_ALL=false
21 (anon):1297> typeset -g POWERLEVEL9K_AZURE_FOREGROUND=32
21 (anon):1279> typeset -g POWERLEVEL9K_AWS_CLASSES=( '*' DEFAULT )
21 (anon):1127> typeset -g POWERLEVEL9K_HASKELL_STACK_ALWAYS_SHOW=true
21 (anon):1125> typeset -g POWERLEVEL9K_HASKELL_STACK_SOURCES=( shell local )
21 (anon):1106> typeset -g POWERLEVEL9K_SCALAENV_FOREGROUND=160
21 (anon):1100> typeset -g POWERLEVEL9K_PHPENV_SHOW_SYSTEM=true
21 (anon):1093> typeset -g POWERLEVEL9K_PHPENV_FOREGROUND=99
21 (anon):1087> typeset -g POWERLEVEL9K_PLENV_SHOW_SYSTEM=true
21 (anon):1080> typeset -g POWERLEVEL9K_PLENV_FOREGROUND=67
21 (anon):1074> typeset -g POWERLEVEL9K_JENV_SHOW_SYSTEM=true
21 (anon):1067> typeset -g POWERLEVEL9K_JENV_FOREGROUND=32
21 (anon):1061> typeset -g POWERLEVEL9K_LUAENV_SHOW_SYSTEM=true
21 (anon):1048> typeset -g POWERLEVEL9K_FVM_FOREGROUND=38
21 (anon):1042> typeset -g POWERLEVEL9K_RVM_SHOW_PREFIX=false
21 (anon):1038> typeset -g POWERLEVEL9K_RVM_FOREGROUND=168
21 (anon):1030> typeset -g POWERLEVEL9K_RBENV_PROMPT_ALWAYS_SHOW=false
21 (anon):1013> typeset -g POWERLEVEL9K_PACKAGE_FOREGROUND=117
21 (anon):1007> typeset -g POWERLEVEL9K_JAVA_VERSION_FULL=false
21 (anon):1003> typeset -g POWERLEVEL9K_JAVA_VERSION_FOREGROUND=32
21 (anon):997> typeset -g POWERLEVEL9K_LARAVEL_VERSION_FOREGROUND=161
21 (anon):991> typeset -g POWERLEVEL9K_PHP_VERSION_PROJECT_ONLY=true
21 (anon):981> typeset -g POWERLEVEL9K_DOTNET_VERSION_FOREGROUND=134
21 (anon):959> typeset -g POWERLEVEL9K_NODE_VERSION_PROJECT_ONLY=true
21 (anon):941> typeset -g POWERLEVEL9K_NVM_FOREGROUND=70
21 (anon):933> typeset -g POWERLEVEL9K_NODENV_PROMPT_ALWAYS_SHOW=false
21 (anon):930> typeset -g POWERLEVEL9K_NODENV_SOURCES=( shell local global )
21 (anon):917> typeset -g POWERLEVEL9K_GOENV_SOURCES=( shell local global )
21 (anon):915> typeset -g POWERLEVEL9K_GOENV_FOREGROUND=37
21 (anon):894> typeset -g POWERLEVEL9K_PYENV_PROMPT_ALWAYS_SHOW=false
21 (anon):889> typeset -g POWERLEVEL9K_PYENV_FOREGROUND=37
21 (anon):843> typeset -g POWERLEVEL9K_VIRTUALENV_FOREGROUND=37
21 (anon):823> typeset -g POWERLEVEL9K_CONTEXT_FOREGROUND=180
21 (anon):799> typeset -g POWERLEVEL9K_TASKWARRIOR_FOREGROUND=74
21 (anon):765> typeset -g POWERLEVEL9K_TODO_HIDE_ZERO_TOTAL=true
21 (anon):763> typeset -g POWERLEVEL9K_TODO_FOREGROUND=110
21 (anon):757> typeset -g POWERLEVEL9K_LOAD_CRITICAL_FOREGROUND=166
21 (anon):751> typeset -g POWERLEVEL9K_LOAD_WHICH=5
21 (anon):745> typeset -g POWERLEVEL9K_SWAP_FOREGROUND=96
21 (anon):731> typeset -g POWERLEVEL9K_VI_INSERT_MODE_STRING=''
21 (anon):726> typeset -g POWERLEVEL9K_VI_MODE_VISUAL_FOREGROUND=68
21 (anon):723> typeset -g POWERLEVEL9K_VI_MODE_NORMAL_FOREGROUND=106
21 (anon):716> typeset -g POWERLEVEL9K_DISK_USAGE_ONLY_WARNING=false
21 (anon):713> typeset -g POWERLEVEL9K_DISK_USAGE_WARNING_LEVEL=90
21 (anon):687> typeset -g POWERLEVEL9K_VIM_SHELL_FOREGROUND=34
21 (anon):681> typeset -g POWERLEVEL9K_NNN_FOREGROUND=72
21 (anon):635> typeset -g POWERLEVEL9K_ASDF_ERLANG_FOREGROUND=125
21 (anon):610> typeset -g POWERLEVEL9K_ASDF_DOTNET_CORE_FOREGROUND=134
21 (anon):569> typeset -g POWERLEVEL9K_ASDF_SHOW_SYSTEM=true
21 (anon):520> typeset -g POWERLEVEL9K_DIRENV_FOREGROUND=178
21 (anon):514> typeset -g POWERLEVEL9K_BACKGROUND_JOBS_FOREGROUND=37
21 (anon):492> typeset -g POWERLEVEL9K_STATUS_ERROR_PIPE=true
21 (anon):479> typeset -g POWERLEVEL9K_STATUS_ERROR=false
21 (anon):474> typeset -g POWERLEVEL9K_STATUS_OK_PIPE_FOREGROUND=70
21 (anon):467> typeset -g POWERLEVEL9K_STATUS_OK=false
21 (anon):457> typeset -g POWERLEVEL9K_VCS_UNTRACKED_FOREGROUND=76
21 (anon):311> typeset -g POWERLEVEL9K_DIR_CLASSES=( )
21 (anon):267> typeset -g POWERLEVEL9K_LOCK_ICON=∅
21 (anon):263> typeset -g POWERLEVEL9K_DIR_SHOW_WRITABLE=v2
21 (anon):196> typeset -g POWERLEVEL9K_SHORTEN_DELIMITER=''
21 (anon):191> typeset -g POWERLEVEL9K_DIR_FOREGROUND=31
21 (anon):93> typeset -g POWERLEVEL9K_ICON_PADDING=none
21 (anon):23> zle -N autosuggest-execute _zsh_autosuggest_widget_execute
21 (anon):21> zle -N autosuggest-accept _zsh_autosuggest_widget_accept
21 (anon):2> action=clear
20 regexp-replace:15> emulate -L zsh
20 is_plugin:2> local name=git
20 is_plugin:2> local name=git
20 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
20 is-at-least:31> [[ 5 != <-> ]]
20 is-at-least:31> [[ 5 != <-> ]]
20 is-at-least:31> [[ 5 != <-> ]]
20 is-at-least:28> version=( 5 8 1 0 )
20 is-at-least:28> version=( 2 36 1 0 )
20 group_lazy_load:5> alias 'nvm=lazy_load "nvm node npm" ". /Users/matt/.nvm/nv...
20 group_lazy_load:4> cmd=virtualenvwrapper
20 group_lazy_load:4> cmd=rvm
20 group_lazy_load:3> shift 1
20 env_default:1> [[ '' = *-export* ]]
20 detect-clipboard:3> [[ darwin21.0 == darwin* ]]
20 complete:2> local args void cmd print remove
20 compinit:533> zle -C menu-expand-or-complete .menu-expand-or-complete _main_c...
20 compinit:533> zle -C expand-or-complete-prefix .expand-or-complete-prefix _ma...
20 compinit:533> zle -C expand-or-complete .expand-or-complete _main_complete
20 compinit:533> zle -C delete-char-or-list .delete-char-or-list _main_complete
20 compinit:530> _i_line=complete-word
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:516> [[ '' !=  # ]]
20 compinit:515> autoload -Uz _xt_session_id
20 compinit:515> autoload -Uz _x_title
20 compinit:515> autoload -Uz _x_resource
20 compinit:515> autoload -Uz _x_keysym
20 compinit:515> autoload -Uz _x_font
20 compinit:515> autoload -Uz _extensions
20 compinit:515> autoload -Uz _date_formats
20 compinit:515> autoload -Uz _ctags_tags
20 compinit:515> autoload -Uz _completers
20 compinit:515> autoload -Uz _combination
20 compinit:515> autoload -Uz _canonical_paths
20 compinit:508> [[ wait = -[pPkK](n|) ]]
20 compinit:508> [[ vmctl = -[pPkK](n|) ]]
20 compinit:508> [[ visudo = -[pPkK](n|) ]]
20 compinit:508> [[ vim-addons = -[pPkK](n|) ]]
20 compinit:508> [[ vcsh = -[pPkK](n|) ]]
20 compinit:508> [[ unlimit = -[pPkK](n|) ]]
20 compinit:508> [[ twidge = -[pPkK](n|) ]]
20 compinit:508> [[ tune2fs = -[pPkK](n|) ]]
20 compinit:508> [[ todo.sh = -[pPkK](n|) ]]
20 compinit:508> [[ telnet = -[pPkK](n|) ]]
20 compinit:508> [[ strip = -[pPkK](n|) ]]
20 compinit:508> [[ sockstat = -[pPkK](n|) ]]
20 compinit:508> [[ socket = -[pPkK](n|) ]]
20 compinit:508> [[ smartctl = -[pPkK](n|) ]]
20 compinit:508> [[ slabtop = -[pPkK](n|) ]]
20 compinit:508> [[ setxkbmap = -[pPkK](n|) ]]
20 compinit:508> [[ setsid = -[pPkK](n|) ]]
20 compinit:508> [[ rcctl = -[pPkK](n|) ]]
20 compinit:508> [[ qtplay = -[pPkK](n|) ]]
20 compinit:508> [[ prove = -[pPkK](n|) ]]
20 compinit:508> [[ procstat = -[pPkK](n|) ]]
20 compinit:508> [[ plutil = -[pPkK](n|) ]]
20 compinit:508> [[ pkgin = -[pPkK](n|) ]]
20 compinit:508> [[ pkgadd = -[pPkK](n|) ]]
20 compinit:508> [[ pkg-config = -[pPkK](n|) ]]
20 compinit:508> [[ pkg = -[pPkK](n|) ]]
20 compinit:508> [[ piuparts = -[pPkK](n|) ]]
20 compinit:508> [[ patch = -[pPkK](n|) ]]
20 compinit:508> [[ osc = -[pPkK](n|) ]]
20 compinit:508> [[ npm = -[pPkK](n|) ]]
20 compinit:508> [[ ngrep = -[pPkK](n|) ]]
20 compinit:508> [[ mergechanges = -[pPkK](n|) ]]
20 compinit:508> [[ infocmp = -[pPkK](n|) ]]
20 compinit:508> [[ dosread = -[pPkK](n|) ]]
20 compinit:508> [[ coreadm = -[pPkK](n|) ]]
20 compinit:508> [[ -command- = -[pPkK](n|) ]]
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #compdef (#compdef)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:506> case #autoload (#autoload)
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:505> shift _i_line
20 compinit:504> _i_tag='#compdef'
20 compinit:504> _i_tag='#compdef'
20 compinit:504> _i_tag='#autoload'
20 compinit:504> _i_tag='#autoload'
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:501> ((  0 + 0  ))
20 compinit:500> _i_name=_users_on
20 compinit:500> _i_name=_stty
20 compinit:500> _i_name=_hledger
20 compinit:500> _i_name=_dget
20 compinit:500> _i_name=_delimiters
20 compinit:500> _i_name=_debfoster
20 compinit:500> _i_name=_chflags
20 compinit:500> _i_name=_canonical_paths
20 compinit:500> _i_name=_arp
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xournal
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xloadimage
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkgrm
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nginx
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_newsgroups
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_htop
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cksum
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chkconfig
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arping
20 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_a2utils
20 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
20 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
20 compinit:498> ((  0  ))
20 compinit:497> [[ /Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/src = ...
20 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/src
20 compinit:490> _i_done=yes
20 compinit:445> autoload -Uz compaudit
20 compinit:440> typeset _i_wdirs _i_wfiles
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:121> shift _d_als
20 compdump:116> ((  ! --_i && 1093 > 1  ))
20 compdump:116> ((  ! --_i && 1038 > 1  ))
20 compdump:116> ((  ! --_i && 912 > 1  ))
20 compdump:116> ((  ! --_i && 869 > 1  ))
20 compdump:116> ((  ! --_i && 867 > 1  ))
20 compdump:116> ((  ! --_i && 865 > 1  ))
20 compdump:116> ((  ! --_i && 818 > 1  ))
20 compdump:116> ((  ! --_i && 772 > 1  ))
20 compdump:116> ((  ! --_i && 750 > 1  ))
20 compdump:116> ((  ! --_i && 605 > 1  ))
20 compdump:116> ((  ! --_i && 601 > 1  ))
20 compdump:116> ((  ! --_i && 573 > 1  ))
20 compdump:116> ((  ! --_i && 555 > 1  ))
20 compdump:116> ((  ! --_i && 496 > 1  ))
20 compdump:116> ((  ! --_i && 201 > 1  ))
20 compdump:116> ((  ! --_i && 1 > 1  ))
20 compdump:115> print -n ' _yum'
20 compdump:115> print -n ' _xfig'
20 compdump:115> print -n ' _x_window'
20 compdump:115> print -n ' _x_selection_timeout'
20 compdump:115> print -n ' _x_locale'
20 compdump:115> print -n ' _x_geometry'
20 compdump:115> print -n ' _x_borderwidth'
20 compdump:115> print -n ' _wajig'
20 compdump:115> print -n ' _vserver'
20 compdump:115> print -n ' _users_on'
20 compdump:115> print -n ' _update-rc.d'
20 compdump:115> print -n ' _update-alternatives'
20 compdump:115> print -n ' _uname'
20 compdump:115> print -n ' _tree'
20 compdump:115> print -n ' _transmission'
20 compdump:115> print -n ' _tracepath'
20 compdump:115> print -n ' _svcadm'
20 compdump:115> print -n ' _suffix_alias_files'
20 compdump:115> print -n ' _strings'
20 compdump:115> print -n ' _store_cache'
20 compdump:115> print -n ' _ssh'
20 compdump:115> print -n ' _softwareupdate'
20 compdump:115> print -n ' _socket'
20 compdump:115> print -n ' _sc_usage'
20 compdump:115> print -n ' _retrieve_mac_apps'
20 compdump:115> print -n ' _rclone'
20 compdump:115> print -n ' _portsnap'
20 compdump:115> print -n ' _object_classes'
20 compdump:115> print -n ' _main_complete'
20 compdump:115> print -n ' _jmeter-plugins'
20 compdump:115> print -n ' _initctl'
20 compdump:115> print -n ' _hub'
20 compdump:115> print -n ' _history'
20 compdump:115> print -n ' _graphicsmagick'
20 compdump:115> print -n ' _gphoto2'
20 compdump:115> print -n ' _gh'
20 compdump:115> print -n ' _fw_update'
20 compdump:115> print -n ' _fuse_arguments'
20 compdump:115> print -n ' _fs_usage'
20 compdump:115> print -n ' _find_net_interfaces'
20 compdump:115> print -n ' _file_modes'
20 compdump:115> print -n ' _fetchmail'
20 compdump:115> print -n ' _fetch'
20 compdump:115> print -n ' _fbsd_device_types'
20 compdump:115> print -n ' _external_pwds'
20 compdump:115> print -n ' _evince'
20 compdump:115> print -n ' _emulator'
20 compdump:115> print -n ' _email_addresses'
20 compdump:115> print -n ' _elfdump'
20 compdump:115> print -n ' _ecasound'
20 compdump:115> print -n ' _dynamic_directory_name'
20 compdump:115> print -n ' _du'
20 compdump:115> print -n ' _dpkg-buildpackage'
20 compdump:115> print -n ' _dpatch-edit-patch'
20 compdump:115> print -n ' _domains'
20 compdump:115> print -n ' _dns_types'
20 compdump:115> print -n ' _dlocate'
20 compdump:115> print -n ' _directory_stack'
20 compdump:115> print -n ' _deno'
20 compdump:115> print -n ' _debcheckout'
20 compdump:115> print -n ' _debbugs_bugnumber'
20 compdump:115> print -n ' _dates'
20 compdump:115> print -n ' _date'
20 compdump:115> print -n ' _cygstart'
20 compdump:115> print -n ' _cygpath'
20 compdump:115> print -n ' _cygcheck'
20 compdump:115> print -n ' _cvs'
20 compdump:115> print -n ' _cut'
20 compdump:115> print -n ' _cask'
20 compdump:115> print -n ' _canonical_paths'
20 compdump:115> print -n ' _bpf_filters'
20 compdump:115> print -n ' _bittorrent'
20 compdump:115> print -n ' _bind_addresses'
20 compdump:115> print -n ' _beadm'
20 compdump:115> print -n ' _avahi'
20 compdump:115> print -n ' _asciidoctor'
20 compdump:115> print -n ' _arrays'
20 compdump:115> print -n ' _arch_namespace'
20 compdump:115> print -n ' _arch_archives'
20 compdump:115> print -n ' _add-zsh-hook'
20 compdump:115> print -n ' _adb'
20 compdump:115> print -n ' _acroread'
20 compdump:115> print -n ' _acpitool'
20 compdump:115> print -n ' _acpi'
20 compdump:115> print -n ' _a2ps'
20 compdump:115> print -n ' _SUSEconfig'
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:114> ((  ! 0  ))
20 compdump:91> _d_bks+=( _history-complete-older )
20 compdump:91> _d_bks+=( _complete_debug )
20 compdump:91> _d_bks+=( _bash_list-choices )
20 compdump:86> [[ -z '' && .list-choices = .menu-select ]]
20 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
20 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
20 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
20 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
20 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
20 compdump:85> [[ up-line-or-beginning-search = _* ]]
20 compdump:85> [[ orig-s0.0000080000-r6249-zle-line-init = _* ]]
20 compdump:85> [[ orig-s0.0000080000-r6249-expand-or-complete-prefix = _* ]]
20 compdump:85> [[ orig-s0.0000080000-r6249-down-line-or-beginning-search = _* ]]
20 compdump:85> [[ orig-s0.0000080000-r6249-bracketed-paste = _* ]]
20 compdump:85> [[ orig-s0.0000080000-r6249-_bash_list-choices = _* ]]
20 compdump:85> [[ history-incremental-pattern-search-backward = _* ]]
20 compdump:85> [[ _read_comp = _* && _read_comp = _* ]]
20 compdump:63> print -r - ''shasum(|5).*'' ''_shasum''
20 compdump:63> print -r - ''qemu(|-system-*)'' ''_qemu''
20 compdump:63> print -r - ''python[0-9.]#'' ''_python''
20 compdump:63> print -r - ''php[0-9.-]'' ''_php''
20 compdump:63> print -r - ''lua[0-9.-]##'' ''_lua''
20 compdump:63> print -r - ''gem[0-9.]#'' ''_gem''
20 compdump:63> print -r - ''gcc-*'' ''_gcc''
20 compdump:63> print -r - ''c++-*'' ''_gcc''
20 compdump:63> print -r - ''-value-,CCACHE_*,-default-'' ''_ccache''
20 compdump:50> print -r - ''zf_chgrp'' ''chgrp''
20 compdump:50> print -r - ''yaourt.static'' ''yaourt''
20 compdump:50> print -r - ''xetex'' ''tex''
20 compdump:50> print -r - ''xelatex'' ''latex''
20 compdump:50> print -r - ''svnadmin-static'' ''svnadmin''
20 compdump:50> print -r - ''slogin'' ''ssh''
20 compdump:50> print -r - ''remsh'' ''rsh''
20 compdump:50> print -r - ''nedit-nc'' ''nc''
20 compdump:50> print -r - ''ncl'' ''nc''
20 compdump:50> print -r - ''mktunes.pl'' ''mktunes''
20 compdump:50> print -r - ''lzma'' ''xz''
20 compdump:50> print -r - ''gzcat'' ''gunzip''
20 compdump:50> print -r - ''gpg2'' ''gpg''
20 compdump:50> print -r - ''ggu'' ''git-checkout''
20 compdump:50> print -r - ''ggpnp'' ''git-checkout''
20 compdump:50> print -r - ''ggp'' ''git-checkout''
20 compdump:50> print -r - ''ggfl'' ''git-checkout''
20 compdump:50> print -r - ''ggf'' ''git-checkout''
20 compdump:50> print -r - ''gdv'' ''git-diff''
20 compdump:50> print -r - ''gchown'' ''chown''
20 compdump:50> print -r - ''gchgrp'' ''chgrp''
20 compdump:50> print -r - ''gccd'' ''git-clone''
20 compdump:50> print -r - ''dch'' ''debchange''
20 compdump:50> print -r - ''_git_log_prettily'' ''git-log''
20 compdump:50> print -r - ''VBoxManage'' ''vboxmanage''
20 compdump:50> print -r - ''-redirect-,>,xz'' ''unxz''
20 compdump:44> print -r - ''yaourt.static'' ''_yaourt''
20 compdump:44> print -r - ''vpnc-connect'' ''_vpnc''
20 compdump:44> print -r - ''twistd'' ''_twisted''
20 compdump:44> print -r - ''truss'' ''_truss''
20 compdump:44> print -r - ''tcsh'' ''_sh''
20 compdump:44> print -r - ''supervisorctl'' ''_supervisorctl''
20 compdump:44> print -r - ''scons'' ''_scons''
20 compdump:44> print -r - ''kubectl'' ''_kubectl''
20 compdump:44> print -r - ''iconvconfig'' ''_iconvconfig''
20 compdump:44> print -r - ''gfmt'' ''_fmt''
20 compdump:44> print -r - ''freebsd-update'' ''_freebsd-update''
20 compdump:44> print -r - ''filterdiff'' ''_patchutils''
20 compdump:44> print -r - ''feh'' ''_feh''
20 compdump:44> print -r - ''fail2ban-client'' ''_fail2ban-client''
20 compdump:44> print -r - ''dpkg-buildpackage'' ''_dpkg-buildpackage''
20 compdump:44> print -r - ''avahi-resolve-address'' ''_avahi''
20 compdump:44> print -r - ''archlinux-java'' ''_archlinux-java''
20 compdump:44> print -r - ''apt-show-versions'' ''_apt-show-versions''
20 compdump:44> print -r - ''apm'' ''_apm''
20 compdump:44> print -r - ''ant'' ''_ant''
20 compdump:44> print -r - ''ansible-playbook'' ''_ansible''
20 compdump:44> print -r - ''ansible'' ''_ansible''
20 compdump:44> print -r - ''anno'' ''_mh''
20 compdump:44> print -r - ''alias'' ''_alias''
20 compdump:44> print -r - ''ali'' ''_mh''
20 compdump:44> print -r - ''adb'' ''_adb''
20 compdump:44> print -r - ''acpitool'' ''_acpitool''
20 compdump:44> print -r - ''acpi'' ''_acpi''
20 compdump:44> print -r - ''ack2'' ''_ack''
20 compdump:44> print -r - ''abcde'' ''_abcde''
20 compdump:44> print -r - ''aap'' ''_aap''
20 compdump:44> print -r - ''aaaa'' ''_hosts''
20 compdump:44> print -r - ''a2ps'' ''_a2ps''
20 compdump:44> print -r - ''_rclone'' ''_rclone''
20 compdump:44> print -r - ''_helm'' ''_helm''
20 compdump:44> print -r - ''_gh'' ''_gh''
20 compdump:44> print -r - ''Mosaic'' ''_webbrowser''
20 compdump:44> print -r - ''Mail'' ''_mail''
20 compdump:44> print -r - ''8l'' ''_go''
20 compdump:44> print -r - ''8g'' ''_go''
20 compdump:44> print -r - ''6l'' ''_go''
20 compdump:44> print -r - ''5g'' ''_go''
20 compdump:44> print -r - ''-value-,SPROMPT,-default-'' ''_ps1234''
20 compdump:44> print -r - ''-value-,PERLDOC,-default-'' ''_perldoc''
20 compdump:44> print -r - ''-value-'' ''_value''
20 compdump:44> print -r - ''-command-'' ''_autocd''
20 compdump:43> _d_f=finger
20 compdump:43> _d_f=atq
20 compdump:43> _d_f=ansible-config
20 compdump:43> _d_f=-array-value-
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:169> shift
20 compdef:164> _services[$cmd]=xz
20 compdef:164> _services[$cmd]=tex
20 compdef:164> _services[$cmd]=gpg
20 compdef:163> _comps[$cmd]=_git
20 compdef:163> _comps[$cmd]=_dirs
20 compdef:162> [[ -z yes || -z _zip ]]
20 compdef:162> [[ -z yes || -z _zfs ]]
20 compdef:162> [[ -z yes || -z _zed ]]
20 compdef:162> [[ -z yes || -z _zeal ]]
20 compdef:162> [[ -z yes || -z _zcalc_line ]]
20 compdef:162> [[ -z yes || -z _zattr ]]
20 compdef:162> [[ -z yes || -z _zattr ]]
20 compdef:162> [[ -z yes || -z _yum ]]
20 compdef:162> [[ -z yes || -z _yp ]]
20 compdef:162> [[ -z yes || -z _yafc ]]
20 compdef:162> [[ -z yes || -z _xset ]]
20 compdef:162> [[ -z yes || -z _xpdf ]]
20 compdef:162> [[ -z yes || -z _xmodmap ]]
20 compdef:162> [[ -z yes || -z _xloadimage ]]
20 compdef:162> [[ -z yes || -z _x_utils ]]
20 compdef:162> [[ -z yes || -z _x_utils ]]
20 compdef:162> [[ -z yes || -z _x_utils ]]
20 compdef:162> [[ -z yes || -z _x_utils ]]
20 compdef:162> [[ -z yes || -z _whois ]]
20 compdef:162> [[ -z yes || -z _wc ]]
20 compdef:162> [[ -z yes || -z _watch ]]
20 compdef:162> [[ -z yes || -z _wajig ]]
20 compdef:162> [[ -z yes || -z _vpnc ]]
20 compdef:162> [[ -z yes || -z _vim ]]
20 compdef:162> [[ -z yes || -z _vim ]]
20 compdef:162> [[ -z yes || -z _vars ]]
20 compdef:162> [[ -z yes || -z _value ]]
20 compdef:162> [[ -z yes || -z _valgrind ]]
20 compdef:162> [[ -z yes || -z _users_on ]]
20 compdef:162> [[ -z yes || -z _users ]]
20 compdef:162> [[ -z yes || -z _user_admin ]]
20 compdef:162> [[ -z yes || -z _urxvt ]]
20 compdef:162> [[ -z yes || -z _uptime ]]
20 compdef:162> [[ -z yes || -z _unison ]]
20 compdef:162> [[ -z yes || -z _unexpand ]]
20 compdef:162> [[ -z yes || -z _uname ]]
20 compdef:162> [[ -z yes || -z _uml ]]
20 compdef:162> [[ -z yes || -z _ulimit ]]
20 compdef:162> [[ -z yes || -z _twisted ]]
20 compdef:162> [[ -z yes || -z _tty ]]
20 compdef:162> [[ -z yes || -z _tracepath ]]
20 compdef:162> [[ -z yes || -z _tr ]]
20 compdef:162> [[ -z yes || -z _touch ]]
20 compdef:162> [[ -z yes || -z _topgit ]]
20 compdef:162> [[ -z yes || -z _toolchain-source ]]
20 compdef:162> [[ -z yes || -z _tin ]]
20 compdef:162> [[ -z yes || -z _timeout ]]
20 compdef:162> [[ -z yes || -z _tilde ]]
20 compdef:162> [[ -z yes || -z _texinfo ]]
20 compdef:162> [[ -z yes || -z _terminals ]]
20 compdef:162> [[ -z yes || -z _tee ]]
20 compdef:162> [[ -z yes || -z _tee ]]
20 compdef:162> [[ -z yes || -z _tail ]]
20 compdef:162> [[ -z yes || -z _tac ]]
20 compdef:162> [[ -z yes || -z _system_profiler ]]
20 compdef:162> [[ -z yes || -z _systat ]]
20 compdef:162> [[ -z yes || -z _sysstat ]]
20 compdef:162> [[ -z yes || -z _svccfg ]]
20 compdef:162> [[ -z yes || -z _svcadm ]]
20 compdef:162> [[ -z yes || -z _sudo ]]
20 compdef:162> [[ -z yes || -z _subscript ]]
20 compdef:162> [[ -z yes || -z _sublimetext ]]
20 compdef:162> [[ -z yes || -z _stty ]]
20 compdef:162> [[ -z yes || -z _strings ]]
20 compdef:162> [[ -z yes || -z _strace ]]
20 compdef:162> [[ -z yes || -z _strace ]]
20 compdef:162> [[ -z yes || -z _stow ]]
20 compdef:162> [[ -z yes || -z _stow ]]
20 compdef:162> [[ -z yes || -z _stdbuf ]]
20 compdef:162> [[ -z yes || -z _sockstat ]]
20 compdef:162> [[ -z yes || -z _smit ]]
20 compdef:162> [[ -z yes || -z _shuf ]]
20 compdef:162> [[ -z yes || -z _sh ]]
20 compdef:162> [[ -z yes || -z _setfacl ]]
20 compdef:162> [[ -z yes || -z _set ]]
20 compdef:162> [[ -z yes || -z _seq ]]
20 compdef:162> [[ -z yes || -z _seq ]]
20 compdef:162> [[ -z yes || -z _sed ]]
20 compdef:162> [[ -z yes || -z _script ]]
20 compdef:162> [[ -z yes || -z _sched ]]
20 compdef:162> [[ -z yes || -z _sccs ]]
20 compdef:162> [[ -z yes || -z _rubber ]]
20 compdef:162> [[ -z yes || -z _rsync ]]
20 compdef:162> [[ -z yes || -z _rrdtool ]]
20 compdef:162> [[ -z yes || -z _rpm ]]
20 compdef:162> [[ -z yes || -z _rmdir ]]
20 compdef:162> [[ -z yes || -z _rlogin ]]
20 compdef:162> [[ -z yes || -z _readlink ]]
20 compdef:162> [[ -z yes || -z _readelf ]]
20 compdef:162> [[ -z yes || -z _putclip ]]
20 compdef:162> [[ -z yes || -z _putclip ]]
20 compdef:162> [[ -z yes || -z _pspdf ]]
20 compdef:162> [[ -z yes || -z _pscp ]]
20 compdef:162> [[ -z yes || -z _ps1234 ]]
20 compdef:162> [[ -z yes || -z _ps1234 ]]
20 compdef:162> [[ -z yes || -z _prstat ]]
20 compdef:162> [[ -z yes || -z _printers ]]
20 compdef:162> [[ -z yes || -z _printers ]]
20 compdef:162> [[ -z yes || -z _print ]]
20 compdef:162> [[ -z yes || -z _precommand ]]
20 compdef:162> [[ -z yes || -z _precommand ]]
20 compdef:162> [[ -z yes || -z _postgresql ]]
20 compdef:162> [[ -z yes || -z _postgresql ]]
20 compdef:162> [[ -z yes || -z _postgresql ]]
20 compdef:162> [[ -z yes || -z _postgresql ]]
20 compdef:162> [[ -z yes || -z _portmaster ]]
20 compdef:162> [[ -z yes || -z _portlint ]]
20 compdef:162> [[ -z yes || -z _pkgtool ]]
20 compdef:162> [[ -z yes || -z _pkgtool ]]
20 compdef:162> [[ -z yes || -z _pkgin ]]
20 compdef:162> [[ -z yes || -z _pine ]]
20 compdef:162> [[ -z yes || -z _picocom ]]
20 compdef:162> [[ -z yes || -z _pgrep ]]
20 compdef:162> [[ -z yes || -z _pgrep ]]
20 compdef:162> [[ -z yes || -z _perl ]]
20 compdef:162> [[ -z yes || -z _perforce ]]
20 compdef:162> [[ -z yes || -z _pdf ]]
20 compdef:162> [[ -z yes || -z _patchutils ]]
20 compdef:162> [[ -z yes || -z _paste ]]
20 compdef:162> [[ -z yes || -z _parameter ]]
20 compdef:162> [[ -z yes || -z _pack ]]
20 compdef:162> [[ -z yes || -z _other_accounts ]]
20 compdef:162> [[ -z yes || -z _opkg ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _openstack ]]
20 compdef:162> [[ -z yes || -z _okular ]]
20 compdef:162> [[ -z yes || -z _od ]]
20 compdef:162> [[ -z yes || -z _objdump ]]
20 compdef:162> [[ -z yes || -z _nslookup ]]
20 compdef:162> [[ -z yes || -z _nothing ]]
20 compdef:162> [[ -z yes || -z _nm ]]
20 compdef:162> [[ -z yes || -z _nginx ]]
20 compdef:162> [[ -z yes || -z _nftables ]]
20 compdef:162> [[ -z yes || -z _netstat ]]
20 compdef:162> [[ -z yes || -z _nedit ]]
20 compdef:162> [[ -z yes || -z _nautilus ]]
20 compdef:162> [[ -z yes || -z _mysql_utils ]]
20 compdef:162> [[ -z yes || -z _myrepos ]]
20 compdef:162> [[ -z yes || -z _mv ]]
20 compdef:162> [[ -z yes || -z _mtools ]]
20 compdef:162> [[ -z yes || -z _mtools ]]
20 compdef:162> [[ -z yes || -z _mozilla ]]
20 compdef:162> [[ -z yes || -z _mozilla ]]
20 compdef:162> [[ -z yes || -z _modutils ]]
20 compdef:162> [[ -z yes || -z _module-assistant ]]
20 compdef:162> [[ -z yes || -z _mknod ]]
20 compdef:162> [[ -z yes || -z _mkfifo ]]
20 compdef:162> [[ -z yes || -z _mixerctl ]]
20 compdef:162> [[ -z yes || -z _mii-tool ]]
20 compdef:162> [[ -z yes || -z _members ]]
20 compdef:162> [[ -z yes || -z _md5sum ]]
20 compdef:162> [[ -z yes || -z _md5sum ]]
20 compdef:162> [[ -z yes || -z _make ]]
20 compdef:162> [[ -z yes || -z _madison ]]
20 compdef:162> [[ -z yes || -z _lzop ]]
20 compdef:162> [[ -z yes || -z _lz4 ]]
20 compdef:162> [[ -z yes || -z _lunchy ]]
20 compdef:162> [[ -z yes || -z _lspv ]]
20 compdef:162> [[ -z yes || -z _lscfg ]]
20 compdef:162> [[ -z yes || -z _ls ]]
20 compdef:162> [[ -z yes || -z _losetup ]]
20 compdef:162> [[ -z yes || -z _look ]]
20 compdef:162> [[ -z yes || -z _localedef ]]
20 compdef:162> [[ -z yes || -z _locale ]]
20 compdef:162> [[ -z yes || -z _loadkeys ]]
20 compdef:162> [[ -z yes || -z _lldb ]]
20 compdef:162> [[ -z yes || -z _lintian ]]
20 compdef:162> [[ -z yes || -z _lintian ]]
20 compdef:162> [[ -z yes || -z _links ]]
20 compdef:162> [[ -z yes || -z _libvirt ]]
20 compdef:162> [[ -z yes || -z _less ]]
20 compdef:162> [[ -z yes || -z _ldd ]]
20 compdef:162> [[ -z yes || -z _ldap ]]
20 compdef:162> [[ -z yes || -z _kpartx ]]
20 compdef:162> [[ -z yes || -z _knock ]]
20 compdef:162> [[ -z yes || -z _knife ]]
20 compdef:162> [[ -z yes || -z _kld ]]
20 compdef:162> [[ -z yes || -z _killall ]]
20 compdef:162> [[ -z yes || -z _kdeconnect ]]
20 compdef:162> [[ -z yes || -z _kak ]]
20 compdef:162> [[ -z yes || -z _join ]]
20 compdef:162> [[ -z yes || -z _jobs_fg ]]
20 compdef:162> [[ -z yes || -z _java ]]
20 compdef:162> [[ -z yes || -z _java ]]
20 compdef:162> [[ -z yes || -z _iptables ]]
20 compdef:162> [[ -z yes || -z _iptables ]]
20 compdef:162> [[ -z yes || -z _inxi ]]
20 compdef:162> [[ -z yes || -z _imagemagick ]]
20 compdef:162> [[ -z yes || -z _iftop ]]
20 compdef:162> [[ -z yes || -z _host ]]
20 compdef:162> [[ -z yes || -z _homestead ]]
20 compdef:162> [[ -z yes || -z _hexdump ]]
20 compdef:162> [[ -z yes || -z _gzip ]]
20 compdef:162> [[ -z yes || -z _gzip ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _guilt ]]
20 compdef:162> [[ -z yes || -z _gstat ]]
20 compdef:162> [[ -z yes || -z _grep-excuses ]]
20 compdef:162> [[ -z yes || -z _grep ]]
20 compdef:162> [[ -z yes || -z _grep ]]
20 compdef:162> [[ -z yes || -z _gradle ]]
20 compdef:162> [[ -z yes || -z _gpg ]]
20 compdef:162> [[ -z yes || -z _gpg ]]
20 compdef:162> [[ -z yes || -z _golang ]]
20 compdef:162> [[ -z yes || -z _gnutls ]]
20 compdef:162> [[ -z yes || -z _gnome-gv ]]
20 compdef:162> [[ -z yes || -z _gnome-gv ]]
20 compdef:162> [[ -z yes || -z _global ]]
20 compdef:162> [[ -z yes || -z _git-wtf ]]
20 compdef:162> [[ -z yes || -z _git-buildpackage ]]
20 compdef:162> [[ -z yes || -z _ghc ]]
20 compdef:162> [[ -z yes || -z _getopt ]]
20 compdef:162> [[ -z yes || -z _getfacl ]]
20 compdef:162> [[ -z yes || -z _getfacl ]]
20 compdef:162> [[ -z yes || -z _getclip ]]
20 compdef:162> [[ -z yes || -z _geany ]]
20 compdef:162> [[ -z yes || -z _gcc ]]
20 compdef:162> [[ -z yes || -z _gcc ]]
20 compdef:162> [[ -z yes || -z _gcc ]]
20 compdef:162> [[ -z yes || -z _fusermount ]]
20 compdef:162> [[ -z yes || -z _fsh ]]
20 compdef:162> [[ -z yes || -z _freebsd-update ]]
20 compdef:162> [[ -z yes || -z _free ]]
20 compdef:162> [[ -z yes || -z _fold ]]
20 compdef:162> [[ -z yes || -z _fmt ]]
20 compdef:162> [[ -z yes || -z _fmt ]]
20 compdef:162> [[ -z yes || -z _flutter ]]
20 compdef:162> [[ -z yes || -z _floppy ]]
20 compdef:162> [[ -z yes || -z _floppy ]]
20 compdef:162> [[ -z yes || -z _flex ]]
20 compdef:162> [[ -z yes || -z _fleetctl ]]
20 compdef:162> [[ -z yes || -z _flac ]]
20 compdef:162> [[ -z yes || -z _finger ]]
20 compdef:162> [[ -z yes || -z _feh ]]
20 compdef:162> [[ -z yes || -z _exportfs ]]
20 compdef:162> [[ -z yes || -z _dvi ]]
20 compdef:162> [[ -z yes || -z _drush ]]
20 compdef:162> [[ -z yes || -z _dos2unix ]]
20 compdef:162> [[ -z yes || -z _dos2unix ]]
20 compdef:162> [[ -z yes || -z _docker-compose ]]
20 compdef:162> [[ -z yes || -z _docker ]]
20 compdef:162> [[ -z yes || -z _django ]]
20 compdef:162> [[ -z yes || -z _dget ]]
20 compdef:162> [[ -z yes || -z _dcop ]]
20 compdef:162> [[ -z yes || -z _dbus ]]
20 compdef:162> [[ -z yes || -z _dad ]]
20 compdef:162> [[ -z yes || -z _cppcheck ]]
20 compdef:162> [[ -z yes || -z _condition ]]
20 compdef:162> [[ -z yes || -z _composer ]]
20 compdef:162> [[ -z yes || -z _cockroach ]]
20 compdef:162> [[ -z yes || -z _cmake ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _cksum ]]
20 compdef:162> [[ -z yes || -z _chromium ]]
20 compdef:162> [[ -z yes || -z _choc ]]
20 compdef:162> [[ -z yes || -z _builtin ]]
20 compdef:162> [[ -z yes || -z _bug ]]
20 compdef:162> [[ -z yes || -z _bug ]]
20 compdef:162> [[ -z yes || -z _bsd_pkg ]]
20 compdef:162> [[ -z yes || -z _bpython ]]
20 compdef:162> [[ -z yes || -z _bower ]]
20 compdef:162> [[ -z yes || -z _bogofilter ]]
20 compdef:162> [[ -z yes || -z _bittorrent ]]
20 compdef:162> [[ -z yes || -z _bitcoin-cli ]]
20 compdef:162> [[ -z yes || -z _bison ]]
20 compdef:162> [[ -z yes || -z _bibtex ]]
20 compdef:162> [[ -z yes || -z _base64 ]]
20 compdef:162> [[ -z yes || -z _axi-cache ]]
20 compdef:162> [[ -z yes || -z _awk ]]
20 compdef:162> [[ -z yes || -z _avahi ]]
20 compdef:162> [[ -z yes || -z _avahi ]]
20 compdef:162> [[ -z yes || -z _auto-apt ]]
20 compdef:162> [[ -z yes || -z _attr ]]
20 compdef:162> [[ -z yes || -z _asdf ]]
20 compdef:162> [[ -z yes || -z _apt ]]
20 compdef:162> [[ -z yes || -z _apt ]]
20 compdef:162> [[ -z yes || -z _ant ]]
20 compdef:162> [[ -z yes || -z _android ]]
20 compdef:162> [[ -z yes || -z _alsa-utils ]]
20 compdef:162> [[ -z yes || -z _adb ]]
20 compdef:162> [[ -z yes || -z _ack ]]
20 compdef:162> [[ -z yes || -z _ack ]]
20 compdef:162> [[ -z yes || -z _abcde ]]
20 compdef:162> [[ -z yes || -z _a2utils ]]
20 compdef:162> [[ -z yes || -z _a2utils ]]
20 compdef:162> [[ -z yes || -z '' ]]
20 compdef:162> [[ -z yes || -z '' ]]
20 compdef:162> [[ -z yes || -z '' ]]
20 compdef:162> [[ -z yes || -z '' ]]
20 compdef:160> svc=''
20 compdef:160> svc=''
20 compdef:159> cmd=jobs
20 compdef:156> cmd='-redirect-,>,xz'
20 compdef:155> [[ xdvi = *=* ]]
20 compdef:155> [[ xargs = *=* ]]
20 compdef:155> [[ whereis = *=* ]]
20 compdef:155> [[ trash-list = *=* ]]
20 compdef:155> [[ sv = *=* ]]
20 compdef:155> [[ protoc = *=* ]]
20 compdef:155> [[ pfexec = *=* ]]
20 compdef:155> [[ mdutil = *=* ]]
20 compdef:155> [[ info = *=* ]]
20 compdef:155> [[ gstat = *=* ]]
20 compdef:155> [[ gprintenv = *=* ]]
20 compdef:155> [[ exec = *=* ]]
20 compdef:155> [[ ethtool = *=* ]]
20 compdef:155> [[ debsign = *=* ]]
20 compdef:155> [[ deborphan = *=* ]]
20 compdef:155> [[ darcs = *=* ]]
20 compdef:155> [[ cssh = *=* ]]
20 compdef:155> [[ cdrdao = *=* ]]
20 compdef:155> [[ caffeinate = *=* ]]
20 compdef:155> [[ -math- = *=* ]]
20 compdef:151> _postpatcomps[$1]=_pydoc
20 compdef:151> _postpatcomps[$1]=_directories
20 compdef:139> case  (postpattern)
20 compdef:139> case  (postpattern)
20 compdef:139> case  (postpattern)
20 compdef:139> case  (pattern)
20 compdef:139> case  (pattern)
20 compdef:139> case  (*)
20 compdef:139> case  (*)
20 compdef:139> case  (*)
20 compdef:139> case  (*)
20 compdef:139> case  (*)
20 compdef:136> [[ readshortcut.exe = -P ]]
20 compdef:136> [[ gprintenv = -P ]]
20 compdef:136> [[ bpython3-urwid = -P ]]
20 compdef:136> [[ 'ggpnp=git-checkout' = -P ]]
20 compdef:134> [[ top = -p ]]
20 compdef:134> [[ play = -p ]]
20 compdef:134> [[ pkginfo = -p ]]
20 compdef:134> [[ devtodo = -p ]]
20 compdef:134> [[ _rclone = -p ]]
20 compdef:134> [[ -value-,TERMINFO_DIRS,-default- = -p ]]
20 compdef:132> [[ zsocket = -N ]]
20 compdef:132> [[ zle = -N ]]
20 compdef:132> [[ zgetattr = -N ]]
20 compdef:132> [[ yast = -N ]]
20 compdef:132> [[ xxd = -N ]]
20 compdef:132> [[ xmlstarlet = -N ]]
20 compdef:132> [[ xli = -N ]]
20 compdef:132> [[ xfig = -N ]]
20 compdef:132> [[ wemux = -N ]]
20 compdef:132> [[ vnstat = -N ]]
20 compdef:132> [[ uname = -N ]]
20 compdef:132> [[ ufw = -N ]]
20 compdef:132> [[ twist = -N ]]
20 compdef:132> [[ trash-restore = -N ]]
20 compdef:132> [[ toilet = -N ]]
20 compdef:132> [[ teamocil = -N ]]
20 compdef:132> [[ subliminal = -N ]]
20 compdef:132> [[ setup.py = -N ]]
20 compdef:132> [[ setfacl = -N ]]
20 compdef:132> [[ scala = -N ]]
20 compdef:132> [[ rmdir = -N ]]
20 compdef:132> [[ rfkill = -N ]]
20 compdef:132> [[ rdesktop = -N ]]
20 compdef:132> [[ pygmentize = -N ]]
20 compdef:132> [[ pump = -N ]]
20 compdef:132> [[ pmpath = -N ]]
20 compdef:132> [[ pm2 = -N ]]
20 compdef:132> [[ phing = -N ]]
20 compdef:132> [[ pfctl = -N ]]
20 compdef:132> [[ pax = -N ]]
20 compdef:132> [[ open = -N ]]
20 compdef:132> [[ nkf = -N ]]
20 compdef:132> [[ mullvad = -N ]]
20 compdef:132> [[ mondoarchive = -N ]]
20 compdef:132> [[ mere = -N ]]
20 compdef:132> [[ mdfind = -N ]]
20 compdef:132> [[ md5sum = -N ]]
20 compdef:132> [[ lsattr = -N ]]
20 compdef:132> [[ ln = -N ]]
20 compdef:132> [[ ksh93 = -N ]]
20 compdef:132> [[ kdeconnect-cli = -N ]]
20 compdef:132> [[ include-what-you-use = -N ]]
20 compdef:132> [[ iftop = -N ]]
20 compdef:132> [[ iconvconfig = -N ]]
20 compdef:132> [[ grep-excuses = -N ]]
20 compdef:132> [[ gphoto2 = -N ]]
20 compdef:132> [[ gnutls-cli = -N ]]
20 compdef:132> [[ getmail = -N ]]
20 compdef:132> [[ figlet = -N ]]
20 compdef:132> [[ ffmpeg = -N ]]
20 compdef:132> [[ fakeroot = -N ]]
20 compdef:132> [[ eog = -N ]]
20 compdef:132> [[ emulate = -N ]]
20 compdef:132> [[ ed = -N ]]
20 compdef:132> [[ docker-compose = -N ]]
20 compdef:132> [[ dig = -N ]]
20 compdef:132> [[ delta = -N ]]
20 compdef:132> [[ cygserver = -N ]]
20 compdef:132> [[ cygrunsrv = -N ]]
20 compdef:132> [[ cvs = -N ]]
20 compdef:132> [[ cut = -N ]]
20 compdef:132> [[ cu = -N ]]
20 compdef:132> [[ csup = -N ]]
20 compdef:132> [[ cscope = -N ]]
20 compdef:132> [[ crontab = -N ]]
20 compdef:132> [[ cppcheck = -N ]]
20 compdef:132> [[ cplay = -N ]]
20 compdef:132> [[ composer = -N ]]
20 compdef:132> [[ compadd = -N ]]
20 compdef:132> [[ column = -N ]]
20 compdef:132> [[ code = -N ]]
20 compdef:132> [[ cmp = -N ]]
20 compdef:132> [[ clay = -N ]]
20 compdef:132> [[ chroot = -N ]]
20 compdef:132> [[ btdownloadcurses = -N ]]
20 compdef:132> [[ bsdinstall = -N ]]
20 compdef:132> [[ bogoutil = -N ]]
20 compdef:132> [[ bg = -N ]]
20 compdef:132> [[ basename = -N ]]
20 compdef:132> [[ autoload = -N ]]
20 compdef:132> [[ asciidoctor = -N ]]
20 compdef:132> [[ apt-show-versions = -N ]]
20 compdef:132> [[ alias = -N ]]
20 compdef:132> [[ afew = -N ]]
20 compdef:132> [[ add-zle-hook-widget = -N ]]
20 compdef:132> [[ -value-,LD_DEBUG,-default- = -N ]]
20 compdef:132> [[ -value-,DISPLAY,-default- = -N ]]
20 compdef:132> [[ -brace-parameter- = -N ]]
20 compdef:132> [[ - = -N ]]
20 compdef:132> [[ '(tiff*|*2tiff|pal2rgb)' = -N ]]
20 compdef:131> ((  9  ))
20 compdef:131> ((  1  ))
20 compdef:131> ((  1  ))
20 compdef:131> ((  1  ))
20 compdef:117> shift
20 compdef:92> [[ .list-choices = .menu-select ]]
20 compdef:92> [[ .complete-word = .menu-select ]]
20 compdef:92> [[ .complete-word = .menu-select ]]
20 compdef:83> case  (widgetkey)
20 compdef:83> case  (key)
20 compdef:83> case  (key)
20 compdef:83> case  (*)
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:81> shift
20 compdef:80> autoload -Uz _zfs
20 compdef:80> autoload -Uz _zcalc_line
20 compdef:80> autoload -Uz _zargs
20 compdef:80> autoload -Uz _yum
20 compdef:80> autoload -Uz _yp
20 compdef:80> autoload -Uz _yafc
20 compdef:80> autoload -Uz _xz
20 compdef:80> autoload -Uz _xournal
20 compdef:80> autoload -Uz _xmodmap
20 compdef:80> autoload -Uz _webbrowser
20 compdef:80> autoload -Uz _wajig
20 compdef:80> autoload -Uz _wait
20 compdef:80> autoload -Uz _vim-addons
20 compdef:80> autoload -Uz _value
20 compdef:80> autoload -Uz _valgrind
20 compdef:80> autoload -Uz _uniq
20 compdef:80> autoload -Uz _uml
20 compdef:80> autoload -Uz _tload
20 compdef:80> autoload -Uz _tla
20 compdef:80> autoload -Uz _tidy
20 compdef:80> autoload -Uz _texinfo
20 compdef:80> autoload -Uz _telnet
20 compdef:80> autoload -Uz _tcpdump
20 compdef:80> autoload -Uz _system_profiler
20 compdef:80> autoload -Uz _systat
20 compdef:80> autoload -Uz _sysrc
20 compdef:80> autoload -Uz _swift
20 compdef:80> autoload -Uz _swaks
20 compdef:80> autoload -Uz _surfraw
20 compdef:80> autoload -Uz _sshfs
20 compdef:80> autoload -Uz _sort
20 compdef:80> autoload -Uz _shred
20 compdef:80> autoload -Uz _scons
20 compdef:80> autoload -Uz _schedtool
20 compdef:80> autoload -Uz _rubber
20 compdef:80> autoload -Uz _rrdtool
20 compdef:80> autoload -Uz _rmdir
20 compdef:80> autoload -Uz _rm
20 compdef:80> autoload -Uz _readshortcut
20 compdef:80> autoload -Uz _rdesktop
20 compdef:80> autoload -Uz _putclip
20 compdef:80> autoload -Uz _ptree
20 compdef:80> autoload -Uz _psutils
20 compdef:80> autoload -Uz _prompt
20 compdef:80> autoload -Uz _portsnap
20 compdef:80> autoload -Uz _portmaster
20 compdef:80> autoload -Uz _pkginfo
20 compdef:80> autoload -Uz _pidof
20 compdef:80> autoload -Uz _php
20 compdef:80> autoload -Uz _pgrep
20 compdef:80> autoload -Uz _pfctl
20 compdef:80> autoload -Uz _perldoc
20 compdef:80> autoload -Uz _perl_modules
20 compdef:80> autoload -Uz _perforce
20 compdef:80> autoload -Uz _other_accounts
20 compdef:80> autoload -Uz _opkg
20 compdef:80> autoload -Uz _object_classes
20 compdef:80> autoload -Uz _objdump
20 compdef:80> autoload -Uz _normal
20 compdef:80> autoload -Uz _nm
20 compdef:80> autoload -Uz _next_tags
20 compdef:80> autoload -Uz _networksetup
20 compdef:80> autoload -Uz _netstat
20 compdef:80> autoload -Uz _net_interfaces
20 compdef:80> autoload -Uz _ncftp
20 compdef:80> autoload -Uz _nautilus
20 compdef:80> autoload -Uz _mysql_utils
20 compdef:80> autoload -Uz _mtr
20 compdef:80> autoload -Uz _mtools
20 compdef:80> autoload -Uz _mt
20 compdef:80> autoload -Uz _mpc
20 compdef:80> autoload -Uz _module-assistant
20 compdef:80> autoload -Uz _module
20 compdef:80> autoload -Uz _mkzsh
20 compdef:80> autoload -Uz _mktemp
20 compdef:80> autoload -Uz _mknod
20 compdef:80> autoload -Uz _mixerctl
20 compdef:80> autoload -Uz _mii-tool
20 compdef:80> autoload -Uz _members
20 compdef:80> autoload -Uz _mdutil
20 compdef:80> autoload -Uz _luarocks
20 compdef:80> autoload -Uz _lsusb
20 compdef:80> autoload -Uz _lp
20 compdef:80> autoload -Uz _localedef
20 compdef:80> autoload -Uz _loadkeys
20 compdef:80> autoload -Uz _lintian
20 compdef:80> autoload -Uz _less
20 compdef:80> autoload -Uz _kvno
20 compdef:80> autoload -Uz _kitchen
20 compdef:80> autoload -Uz _killall
20 compdef:80> autoload -Uz _kfmclient
20 compdef:80> autoload -Uz _kak
20 compdef:80> autoload -Uz _join
20 compdef:80> autoload -Uz _java
20 compdef:80> autoload -Uz _ionice
20 compdef:80> autoload -Uz _initctl
20 compdef:80> autoload -Uz _include-what-you-use
20 compdef:80> autoload -Uz _ifconfig
20 compdef:80> autoload -Uz _ibus
20 compdef:80> autoload -Uz _httpie
20 compdef:80> autoload -Uz _homestead
20 compdef:80> autoload -Uz _history_complete_word
20 compdef:80> autoload -Uz _grep-excuses
20 compdef:80> autoload -Uz _graphicsmagick
20 compdef:80> autoload -Uz _gradle
20 compdef:80> autoload -Uz _gphoto2
20 compdef:80> autoload -Uz _golang
20 compdef:80> autoload -Uz _gnutls
20 compdef:80> autoload -Uz _global
20 compdef:80> autoload -Uz _git-revise
20 compdef:80> autoload -Uz _git-journal
20 compdef:80> autoload -Uz _ghc
20 compdef:80> autoload -Uz _getent
20 compdef:80> autoload -Uz _gem
20 compdef:80> autoload -Uz _gcore
20 compdef:80> autoload -Uz _fwupdmgr
20 compdef:80> autoload -Uz _fusermount
20 compdef:80> autoload -Uz _functions
20 compdef:80> autoload -Uz _flac
20 compdef:80> autoload -Uz _first
20 compdef:80> autoload -Uz _findmnt
20 compdef:80> autoload -Uz _fetch
20 compdef:80> autoload -Uz _feh
20 compdef:80> autoload -Uz _fail2ban-client
20 compdef:80> autoload -Uz _fab
20 compdef:80> autoload -Uz _drush
20 compdef:80> autoload -Uz _docpad
20 compdef:80> autoload -Uz _cppcheck
20 compdef:80> autoload -Uz _correct_word
20 compdef:80> autoload -Uz _correct_filename
20 compdef:80> autoload -Uz _console
20 compdef:80> autoload -Uz _condition
20 compdef:80> autoload -Uz _composer
20 compdef:80> autoload -Uz _cmake
20 compdef:80> autoload -Uz _chromium
20 compdef:80> autoload -Uz _choc
20 compdef:80> autoload -Uz _ccache
20 compdef:80> autoload -Uz _bundle
20 compdef:80> autoload -Uz _bts
20 compdef:80> autoload -Uz _btrfs
20 compdef:80> autoload -Uz _bsdinstall
20 compdef:80> autoload -Uz _bsd_pkg
20 compdef:80> autoload -Uz _brace_parameter
20 compdef:80> autoload -Uz _bpython
20 compdef:80> autoload -Uz _bogofilter
20 compdef:80> autoload -Uz _bittorrent
20 compdef:80> autoload -Uz _bitcoin-cli
20 compdef:80> autoload -Uz _basename
20 compdef:80> autoload -Uz _axi-cache
20 compdef:80> autoload -Uz _awk
20 compdef:80> autoload -Uz _attr
20 compdef:80> autoload -Uz _at
20 compdef:80> autoload -Uz _arping
20 compdef:80> autoload -Uz _archlinux-java
20 compdef:80> autoload -Uz _aptitude
20 compdef:80> autoload -Uz _antiword
20 compdef:80> autoload -Uz _ansible
20 compdef:80> autoload -Uz _android
20 compdef:80> autoload -Uz _aliases
20 compdef:80> autoload -Uz _aap
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:80> [[ -n yes ]]
20 compdef:49> [[ _zypper = *=* ]]
20 compdef:49> [[ _yadm = *=* ]]
20 compdef:49> [[ _xwit = *=* ]]
20 compdef:49> [[ _trash-empty = *=* ]]
20 compdef:49> [[ _tmuxp = *=* ]]
20 compdef:49> [[ _tmuxinator = *=* ]]
20 compdef:49> [[ _time_zone = *=* ]]
20 compdef:49> [[ _rsvm = *=* ]]
20 compdef:49> [[ _restic = *=* ]]
20 compdef:49> [[ _ralio = *=* ]]
20 compdef:49> [[ _mpv = *=* ]]
20 compdef:49> [[ _ldconfig = *=* ]]
20 compdef:49> [[ _gstat = *=* ]]
20 compdef:49> [[ _gsettings = *=* ]]
20 compdef:49> [[ _expand_alias = *=* ]]
20 compdef:49> [[ _exec = *=* ]]
20 compdef:49> [[ _evince = *=* ]]
20 compdef:49> [[ _ethtool = *=* ]]
20 compdef:49> [[ _enscript = *=* ]]
20 compdef:49> [[ _dvi = *=* ]]
20 compdef:49> [[ _dumpadm = *=* ]]
20 compdef:49> [[ _dsh = *=* ]]
20 compdef:49> [[ _dput = *=* ]]
20 compdef:49> [[ _devtodo = *=* ]]
20 compdef:49> [[ _defaults = *=* ]]
20 compdef:49> [[ _debuild = *=* ]]
20 compdef:49> [[ _deborphan = *=* ]]
20 compdef:49> [[ _debfoster = *=* ]]
20 compdef:49> [[ _debcheckout = *=* ]]
20 compdef:49> [[ _dcut = *=* ]]
20 compdef:49> [[ _compress = *=* ]]
20 compdef:49> [[ _cksum = *=* ]]
20 compdef:49> [[ _chsh = *=* ]]
20 compdef:49> [[ _chown = *=* ]]
20 compdef:49> [[ _chcon = *=* ]]
20 compdef:49> [[ _chattr = *=* ]]
20 compdef:49> [[ _cdrecord = *=* ]]
20 compdef:49> [[ _cdrdao = *=* ]]
20 compdef:45> [[ -z '' ]]
20 compdef:45> [[ -z '' ]]
20 compdef:45> [[ -z '' ]]
20 compdef:45> [[ -z '' ]]
20 compdef:40> ((  ! 4  ))
20 compdef:40> ((  ! 3  ))
20 compdef:40> ((  ! 3  ))
20 compdef:40> ((  ! 2  ))
20 compdef:40> ((  ! 2  ))
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:38> shift OPTIND-1
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:17> new=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:16> autol=yes
20 compdef:15> case n (n)
20 compdef:15> case n (n)
20 compdef:15> case n (a)
20 compdef:15> case a (a)
20 compdef:15> case a (a)
20 compdef:15> case a (a)
20 compdef:15> case a (a)
20 compdef:15> case K ([pPkK])
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:14> getopts anpPkKde opt
20 compdef:9> ((  ! 39  ))
20 compdef:9> ((  ! 20  ))
20 compdef:9> ((  ! 20  ))
20 compdef:9> ((  ! 19  ))
20 compdef:9> ((  ! 17  ))
20 compdef:9> ((  ! 13  ))
20 compdef:9> ((  ! 12  ))
20 compdef:9> ((  ! 12  ))
20 compdef:9> ((  ! 9  ))
20 compdef:9> ((  ! 8  ))
20 compdef:9> ((  ! 8  ))
20 compdef:9> ((  ! 8  ))
20 compdef:9> ((  ! 7  ))
20 compdef:9> ((  ! 7  ))
20 compdef:9> ((  ! 7  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 6  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 5  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 4  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 3  ))
20 compdef:9> ((  ! 2  ))
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:5> setopt extendedglob
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:4> emulate -L zsh
20 compdef:2> local -a match mbegin mend
20 compdef:2> local -a match mbegin mend
20 compdef:2> local -a match mbegin mend
20 compdef:2> local -a match mbegin mend
20 compdef:2> local -a match mbegin mend
20 compaudit:92> _i_exes=( /proc/87947/exe /proc/87947/object/a.out )
20 compaudit:52> local _compdir=/usr/share/zsh/5.8.1/functions
20 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;45m'
20 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;40m'
20 colors:76> local k
20 bashcompinit:178> autoload -Uz bashcompinit
20 bashcompinit:178> autoload -Uz bashcompinit
20 antigen-remove-hook:8> hooks[$hooks[(I)$hook]]=( )
20 antigen-remove-hook:4> hooks=( antigen-bundle-cached antigen-bundle-parallel )
20 antigen-remove-hook:4> hooks=( antigen-bundle-cached )
20 antigen-ext:4> eval -antigen-parallel-init
20 antigen-ext:4> eval -antigen-defer-init
20 antigen-bundle-parallel-execute:40> bundle=zsh-users/zsh-autosuggestions
20 antigen-apply-defer:6> bundle=zsh-users/zsh-syntax-highlighting
20 antigen-apply-defer:6> bundle=deno
20 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-bundle
20 antigen-add-hook:22> local hook_function=-antigen-hook-antigen-apply
20 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-bundle-defer:antigen-bun...
20 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-apply-lock:antigen-apply...
20 antigen-add-hook:13> [[ antigen-bundle-defer:antigen-bundle-cached ==  ]]
20 antigen-add-hook:8> ((  ! 1  ))
20 add-zsh-hook:89> typeset -ga precmd_functions
20 add-zsh-hook:84> ((  0 == 0  ))
20 add-zsh-hook:66> local fn=omz_termsupport_preexec
20 add-zsh-hook:66> local fn=_zsh_autosuggest_start
20 add-zsh-hook:66> local fn=_zsh_autosuggest_start
20 add-zsh-hook:65> local hook=precmd_functions
20 add-zsh-hook:25> local -a autoopts
20 add-zsh-hook:25> local -a autoopts
20 add-zsh-hook:25> local -a autoopts
20 add-zsh-hook:25> local -a autoopts
20 add-zsh-hook:24> local opt
20 add-zsh-hook:17> local -a hooktypes
20 add-zle-hook-widget:103> zle -N -- _zsh_highlight__zle-line-pre-redraw
20 add-zle-hook-widget:102> autoload -- _zsh_highlight__zle-line-finish
20 add-zle-hook-widget:86> zle -A zle-line-finish user:zle-line-finish
20 add-zle-hook-widget:84> [[ user:zle-line-finish != user:azhw:zle-line-finish ]]
20 add-zle-hook-widget:7> local opt
20 add-zle-hook-widget:1> local -a hooktypes
20 _zsh_highlight_bind_widgets:50> zle -N visual-mode _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:50> zle -N vi-yank _zsh_highlight_widget_orig-s0....
20 _zsh_highlight_bind_widgets:50> zle -N vi-up-line-or-history _zsh_highlight_w...
20 _zsh_highlight_bind_widgets:50> zle -N vi-unindent _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:50> zle -N vi-undo-change _zsh_highlight_widget_o...
20 _zsh_highlight_bind_widgets:50> zle -N vi-swap-case _zsh_highlight_widget_ori...
20 _zsh_highlight_bind_widgets:50> zle -N vi-substitute _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:50> zle -N vi-replace _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N vi-put-before _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:50> zle -N vi-join _zsh_highlight_widget_orig-s0....
20 _zsh_highlight_bind_widgets:50> zle -N vi-insert _zsh_highlight_widget_orig-s...
20 _zsh_highlight_bind_widgets:50> zle -N vi-indent _zsh_highlight_widget_orig-s...
20 _zsh_highlight_bind_widgets:50> zle -N vi-goto-column _zsh_highlight_widget_o...
20 _zsh_highlight_bind_widgets:50> zle -N vi-forward-word _zsh_highlight_widget_...
20 _zsh_highlight_bind_widgets:50> zle -N vi-delete-char _zsh_highlight_widget_o...
20 _zsh_highlight_bind_widgets:50> zle -N vi-change-eol _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:50> zle -N vi-backward-char _zsh_highlight_widget...
20 _zsh_highlight_bind_widgets:50> zle -N up-history _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N split-undo _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N spell-word _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N reset-prompt _zsh_highlight_widget_ori...
20 _zsh_highlight_bind_widgets:50> zle -N redo _zsh_highlight_widget_orig-s0.000...
20 _zsh_highlight_bind_widgets:50> zle -N redisplay _zsh_highlight_widget_orig-s...
20 _zsh_highlight_bind_widgets:50> zle -N quote-line _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N push-input _zsh_highlight_widget_orig-...
20 _zsh_highlight_bind_widgets:50> zle -N pound-insert _zsh_highlight_widget_ori...
20 _zsh_highlight_bind_widgets:50> zle -N expand-word _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:50> zle -N end-of-list _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:50> zle -N end-of-line-hist _zsh_highlight_widget...
20 _zsh_highlight_bind_widgets:50> zle -N end-of-history _zsh_highlight_widget_o...
20 _zsh_highlight_bind_widgets:50> zle -N delete-char _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:50> zle -N backward-word _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:46> zle -N menu-expand-or-complete _zsh_highlight...
20 _zsh_highlight_bind_widgets:46> zle -N menu-complete _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:46> zle -N _correct_filename _zsh_highlight_widge...
20 _zsh_highlight_bind_widgets:46> zle -N _complete_tag _zsh_highlight_widget_or...
20 _zsh_highlight_bind_widgets:46> zle -N _complete_help _zsh_highlight_widget_o...
20 _zsh_highlight_bind_widgets:41> zle -N self-insert _zsh_highlight_widget_orig...
20 _zsh_highlight_bind_widgets:27> case builtin (user:*)
20 _zsh_highlight_bind_widgets:27> case builtin (user:*)
20 _zsh_highlight_bind_widgets:27> case builtin (builtin)
20 _zsh_highlight_bind_widgets:27> case builtin (builtin)
20 _zsh_highlight_bind_widgets:27> case builtin (builtin)
20 _zsh_highlight_bind_widgets:27> case builtin (builtin)
20 _zsh_highlight_bind_widgets:27> case builtin (builtin)
20 /usr/local/share/antigen/antigen.zsh:1399> _ANTIGEN_HOOKS_META=( )
20 /Users/matt/.zshrc:393> alias 'copydir=pwd | pbcopy'
20 /Users/matt/.zshrc:174> alias 'gmm=gmom'
20 /Users/matt/.zshrc:168> alias 'gop=git push'
20 /Users/matt/.zcompdump:1980> bindkey '^[/' _history-complete-older
20 /Users/matt/.zcompdump:1977> bindkey '^Xt' _complete_tag
20 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1814> bindkey '^[/' _history...
20 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1813> bindkey '^[,' _history...
20 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1812> bindkey '^X~' _bash_li...
20 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1806> bindkey '^Xd' _list_ex...
20 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1804> bindkey '^Xa' _expand_...
20 /Users/matt/.p10k.zsh:18> [[ ! -o sh_glob ]]
20 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:17> [[ '' != true ]]
20 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=fasd
20 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
20 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
20 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:87> plugin=git
20 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;112m%}'
20 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=131
20 /Users/matt/.oh-my-zsh/lib/misc.zsh:28> ((  0  ))
20 /Users/matt/.oh-my-zsh/lib/misc.zsh:21> env_default PAGER less
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:114> autoload -U edit-command-line
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:102> bindkey -M emacs '^[[1;5D' b...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:94> bindkey -M viins '^[[3;5~' ki...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:80> bindkey -M viins $'C-[[3~' de...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:78> [[ -n $'C-[[3~' ]]
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:69> bindkey -M viins $'C-[[Z' rev...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:68> bindkey -M emacs $'C-[[Z' rev...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:48> bindkey -M emacs $'C-[OB' dow...
20 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:40> bindkey -M viins $'C-[OA' up-...
20 /Users/matt/.oh-my-zsh/lib/history.zsh:37> setopt hist_ignore_dups
20 /Users/matt/.oh-my-zsh/lib/directories.zsh:14> alias '3=cd -3'
20 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:5> alias 'd=fasd -d'
20 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:4> alias 'sf=fasd -sif'
20 /Users/matt/.antigen/init.zsh:76> typeset -g _ANTIGEN_CACHE_LOADED
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:28> ((  0  ))
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /us...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:102>...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:99> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:93> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:68> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:54> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:49> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:37> ...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:39> setop...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:11> a...
20 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:8> al...
20 -antigen-use-oh-my-zsh:1> typeset -g ZSH ZSH_CACHE_DIR
20 -antigen-set-default:1> local arg_name=ANTIGEN_RSRC
20 -antigen-set-default:1> local arg_name=ANTIGEN_CACHE
20 -antigen-parse-args:160> args[name]=''robbyrussell/oh-my-zsh''
20 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/zsh-users/z...
20 -antigen-parse-args:87> [[ https://github.com/robbyrussell/oh-my-zsh.git != g...
20 -antigen-parse-args:81> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
20 -antigen-parse-args:61> args[$key]=zsh-users/zsh-syntax-highlighting
20 -antigen-parse-args:5> shift
20 -antigen-parse-args:5> shift
20 -antigen-parse-args:4> local var=bundle
20 -antigen-parse-args:4> local var=bundle
20 -antigen-parallel-init:2> _PARALLEL_BUNDLE=( )
20 -antigen-load:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-autosuggest...
20 -antigen-load:5> local location=/Users/matt/.antigen/bundles/zsh-users/zsh-sy...
20 -antigen-load-env-cached:2> typeset -A bundle
20 -antigen-hook-handler:51> [[ 0 == -1 ]]
20 -antigen-hook-handler:51> [[ 0 == -1 ]]
20 -antigen-hook-handler:51> [[ -1 == -1 ]]
20 -antigen-hook-handler:51> [[ -1 == -1 ]]
20 -antigen-hook-handler:44> local replace_hook=0 ret=0
20 -antigen-hook-handler:44> local replace_hook=0 ret=0
20 -antigen-hook-handler:44> local replace_hook=0 ret=0
20 -antigen-hook-handler:40> [[ 0 == -1 ]]
20 -antigen-hook-handler:40> [[ 0 == -1 ]]
20 -antigen-hook-handler:40> [[ 0 == -1 ]]
20 -antigen-hook-handler:40> [[ 0 == -1 ]]
20 -antigen-hook-handler:40> [[ 0 == -1 ]]
20 -antigen-hook-handler:37> hook=antigen-lock
20 -antigen-hook-handler:37> hook=antigen-bundle-cached
20 -antigen-hook-handler:37> hook=antigen-bundle-cached
20 -antigen-hook-handler:37> hook=antigen-bundle-cached
20 -antigen-hook-handler:37> hook=antigen-bundle-cached
20 -antigen-hook-handler:37> hook=antigen-bundle-cached
20 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-defer )
20 -antigen-hook-handler:17> let 'called=1+1'
20 -antigen-hook-handler:17> let 'called=0+1'
20 -antigen-hook-handler:14> continue
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:12> [[ repeat == once ]]
20 -antigen-hook-handler:4> typeset -a args
20 -antigen-hook-handler:4> typeset -a args
20 -antigen-hook-handler:4> args=( zsh-users/zsh-syntax-highlighting )
20 -antigen-hook-handler:4> args=( zsh-users/zsh-syntax-highlighting )
20 -antigen-hook-handler:4> args=( zsh-users/zsh-autosuggestions )
20 -antigen-hook-handler:4> args=( zsh-users/zsh-autosuggestions )
20 -antigen-hook-handler:4> args=( use oh-my-zsh )
20 -antigen-hook-handler:4> args=( '--loc=lib' )
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-handler:2> local hooks meta
20 -antigen-hook-antigen:1> local cmd=bundle
20 -antigen-hook-antigen:1> local cmd=bundle
20 -antigen-hook-antigen-bundle:13> local record='https://github.com/robbyrussel...
20 -antigen-cache-generate:21> _fpath+=( /Users/matt/.antigen/bundles/zsh-users/...
20 -antigen-cache-generate:20> _PATH+=( /Users/matt/.antigen/bundles/robbyrussel...
20 -antigen-cache-generate:19> [[ -d /Users/matt/.antigen/bundles/robbyrussell/o...
20 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
20 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
20 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
20 (eval):107> alias 'glol=git log --graph --pretty='''%Cred%h%Creset -%C(auto)%...
20 (anon):1548> typeset -g POWERLEVEL9K_INSTANT_PROMPT=quiet
20 (anon):1485> typeset -g POWERLEVEL9K_TIME_FOREGROUND=66
20 (anon):1446> typeset -g POWERLEVEL9K_BATTERY_LOW_THRESHOLD=20
20 (anon):1440> typeset -g POWERLEVEL9K_PROXY_FOREGROUND=68
20 (anon):1404> typeset -g POWERLEVEL9K_VPN_IP_FOREGROUND=81
20 (anon):1398> typeset -g POWERLEVEL9K_PUBLIC_IP_FOREGROUND=94
20 (anon):1032> typeset -g POWERLEVEL9K_RBENV_SHOW_SYSTEM=true
20 (anon):1025> typeset -g POWERLEVEL9K_RBENV_FOREGROUND=168
20 (anon):973> typeset -g POWERLEVEL9K_RUST_VERSION_FOREGROUND=37
20 (anon):965> typeset -g POWERLEVEL9K_GO_VERSION_FOREGROUND=37
20 (anon):947> typeset -g POWERLEVEL9K_NODEENV_FOREGROUND=70
20 (anon):753> typeset -g POWERLEVEL9K_LOAD_NORMAL_FOREGROUND=66
20 (anon):24> zle -N autosuggest-enable _zsh_autosuggest_widget_enable
20 (anon):22> zle -N autosuggest-clear _zsh_autosuggest_widget_clear
20 (anon):14> local action
19 regexp-replace:13> [[ -o re_match_pcre ]]
19 is-at-least:45> part=2
19 is-at-least:31> [[ 2 != <-> ]]
19 is-at-least:28> version=( 5 8 1 0 )
19 is-at-least:28> version=( 5 8 1 0 )
19 is-at-least:28> version=( 5 8 1 0 )
19 is-at-least:28> version=( 2 36 1 0 )
19 is-at-least:27> min_ver=( 5 8 0 2 )
19 is-at-least:27> min_ver=( 5 4 )
19 is-at-least:27> min_ver=( 5 1 )
19 is-at-least:27> min_ver=( 2 13 )
19 group_lazy_load:5> alias 'irb=lazy_load "rvm irb rake" ". /Users/matt/.rvm/sc...
19 compinit:530> _i_line=list-choices
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:516> [[ '' !=  # ]]
19 compinit:515> autoload -Uz _x_name
19 compinit:515> autoload -Uz _x_locale
19 compinit:515> autoload -Uz _x_cursor
19 compinit:515> autoload -Uz _ssh_hosts
19 compinit:515> autoload -Uz _signals
19 compinit:515> autoload -Uz _regex_arguments
19 compinit:515> autoload -Uz _oldlist
19 compinit:515> autoload -Uz _mac_files_for_application
19 compinit:515> autoload -Uz _gnu_generic
19 compinit:515> autoload -Uz _find_net_interfaces
19 compinit:515> autoload -Uz _file_descriptors
19 compinit:515> autoload -Uz _fbsd_device_types
19 compinit:515> autoload -Uz _dynamic_directory_name
19 compinit:515> autoload -Uz _dns_types
19 compinit:515> autoload -Uz _dispatch
19 compinit:515> autoload -Uz _comp_locale
19 compinit:515> autoload -Uz _command_names
19 compinit:515> autoload -Uz _cmdambivalent
19 compinit:508> [[ pandoc = -[pPkK](n|) ]]
19 compinit:508> [[ brctl = -[pPkK](n|) ]]
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #compdef (#compdef)
19 compinit:506> case #autoload (#compdef)
19 compinit:506> case #autoload (#compdef)
19 compinit:506> case #autoload (#compdef)
19 compinit:506> case #autoload (#compdef)
19 compinit:506> case #autoload (#compdef)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:506> case #autoload (#autoload)
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:505> shift _i_line
19 compinit:504> _i_tag='#compdef'
19 compinit:504> _i_tag='#autoload'
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:501> ((  0 + 0  ))
19 compinit:500> _i_name=_tune2fs
19 compinit:500> _i_name=_trash-empty
19 compinit:500> _i_name=_tmuxinator
19 compinit:500> _i_name=_psutils
19 compinit:500> _i_name=_mysqldiff
19 compinit:500> _i_name=_growisofs
19 compinit:500> _i_name=_debchange
19 compinit:500> _i_name=_call_program
19 compinit:500> _i_name=_artisan
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zfs
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_snoop
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rlogin
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_readelf
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mutt
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mount
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_guard
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_extensions
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_exec
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dumper
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dsh
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_df
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_defaults
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debsign
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debcheckout
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_deb_architectures
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_date
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_completers
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chflags
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chcon
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cdrecord
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cal
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apt-show-versions
19 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apt-move
19 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_yt-dlp
19 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_snap
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
19 compinit:496> _i_dir=/usr/share/zsh/site-functions
19 compinit:447> typeset _i_q
19 compinit:121> [[ -n /Users/matt/.antigen/.zcompdump ]]
19 compinit:121> [[ -n '/Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1' ]]
19 compinit:113> typeset -gHA _compautos
19 compinit:92> shift
19 compinit:81> [[ 1 -gt 0 && '/Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1'...
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:121> shift _d_als
19 compdump:117> _i=5
19 compdump:117> _i=5
19 compdump:117> _i=5
19 compdump:116> ((  ! --_i && 1090 > 1  ))
19 compdump:116> ((  ! --_i && 1087 > 1  ))
19 compdump:116> ((  ! --_i && 1053 > 1  ))
19 compdump:116> ((  ! --_i && 1033 > 1  ))
19 compdump:116> ((  ! --_i && 1032 > 1  ))
19 compdump:116> ((  ! --_i && 1031 > 1  ))
19 compdump:116> ((  ! --_i && 1026 > 1  ))
19 compdump:116> ((  ! --_i && 1023 > 1  ))
19 compdump:116> ((  ! --_i && 1022 > 1  ))
19 compdump:116> ((  ! --_i && 1009 > 1  ))
19 compdump:116> ((  ! --_i && 1007 > 1  ))
19 compdump:116> ((  ! --_i && 1004 > 1  ))
19 compdump:116> ((  ! --_i && 998 > 1  ))
19 compdump:116> ((  ! --_i && 996 > 1  ))
19 compdump:116> ((  ! --_i && 994 > 1  ))
19 compdump:116> ((  ! --_i && 993 > 1  ))
19 compdump:116> ((  ! --_i && 992 > 1  ))
19 compdump:116> ((  ! --_i && 989 > 1  ))
19 compdump:116> ((  ! --_i && 922 > 1  ))
19 compdump:116> ((  ! --_i && 920 > 1  ))
19 compdump:116> ((  ! --_i && 875 > 1  ))
19 compdump:116> ((  ! --_i && 870 > 1  ))
19 compdump:116> ((  ! --_i && 863 > 1  ))
19 compdump:116> ((  ! --_i && 861 > 1  ))
19 compdump:116> ((  ! --_i && 858 > 1  ))
19 compdump:116> ((  ! --_i && 852 > 1  ))
19 compdump:116> ((  ! --_i && 846 > 1  ))
19 compdump:116> ((  ! --_i && 837 > 1  ))
19 compdump:116> ((  ! --_i && 820 > 1  ))
19 compdump:116> ((  ! --_i && 805 > 1  ))
19 compdump:116> ((  ! --_i && 798 > 1  ))
19 compdump:116> ((  ! --_i && 796 > 1  ))
19 compdump:116> ((  ! --_i && 795 > 1  ))
19 compdump:116> ((  ! --_i && 787 > 1  ))
19 compdump:116> ((  ! --_i && 708 > 1  ))
19 compdump:116> ((  ! --_i && 615 > 1  ))
19 compdump:116> ((  ! --_i && 587 > 1  ))
19 compdump:116> ((  ! --_i && 460 > 1  ))
19 compdump:116> ((  ! --_i && 432 > 1  ))
19 compdump:116> ((  ! --_i && 371 > 1  ))
19 compdump:116> ((  ! --_i && 367 > 1  ))
19 compdump:116> ((  ! --_i && 278 > 1  ))
19 compdump:116> ((  ! --_i && 223 > 1  ))
19 compdump:116> ((  ! --_i && 206 > 1  ))
19 compdump:116> ((  ! --_i && 170 > 1  ))
19 compdump:115> print -n ' _ztodo'
19 compdump:115> print -n ' _zsh-mime-handler'
19 compdump:115> print -n ' _zpool'
19 compdump:115> print -n ' _zoneadm'
19 compdump:115> print -n ' _zmv'
19 compdump:115> print -n ' _zfs_keysource_props'
19 compdump:115> print -n ' _zfs'
19 compdump:115> print -n ' _zcalc_line'
19 compdump:115> print -n ' _zcalc'
19 compdump:115> print -n ' _zattr'
19 compdump:115> print -n ' _zargs'
19 compdump:115> print -n ' _yodl'
19 compdump:115> print -n ' _yast'
19 compdump:115> print -n ' _xt_session_id'
19 compdump:115> print -n ' _xset'
19 compdump:115> print -n ' _xsel'
19 compdump:115> print -n ' _xpdf'
19 compdump:115> print -n ' _xournal'
19 compdump:115> print -n ' _xmms2'
19 compdump:115> print -n ' _xmlstarlet'
19 compdump:115> print -n ' _xmlsoft'
19 compdump:115> print -n ' _xloadimage'
19 compdump:115> print -n ' _xdvi'
19 compdump:115> print -n ' _x_resource'
19 compdump:115> print -n ' _x_font'
19 compdump:115> print -n ' _x_extension'
19 compdump:115> print -n ' _x_display'
19 compdump:115> print -n ' _x_arguments'
19 compdump:115> print -n ' _wipefs'
19 compdump:115> print -n ' _whereis'
19 compdump:115> print -n ' _webbrowser'
19 compdump:115> print -n ' _watch-snoop'
19 compdump:115> print -n ' _wanted'
19 compdump:115> print -n ' _wanna-build'
19 compdump:115> print -n ' _w3m'
19 compdump:115> print -n ' _vorbis'
19 compdump:115> print -n ' _volume_groups'
19 compdump:115> print -n ' _vmstat'
19 compdump:115> print -n ' _visudo'
19 compdump:115> print -n ' _vcsh'
19 compdump:115> print -n ' _vars'
19 compdump:115> print -n ' _values'
19 compdump:115> print -n ' _valgrind'
19 compdump:115> print -n ' _vagrant'
19 compdump:115> print -n ' _user_at_host'
19 compdump:115> print -n ' _urxvt'
19 compdump:115> print -n ' _urpmi'
19 compdump:115> print -n ' _uptime'
19 compdump:115> print -n ' _units'
19 compdump:115> print -n ' _unison'
19 compdump:115> print -n ' _unace'
19 compdump:115> print -n ' _umountable'
19 compdump:115> print -n ' _ulimit'
19 compdump:115> print -n ' _udisksctl'
19 compdump:115> print -n ' _tune2fs'
19 compdump:115> print -n ' _ttyctl'
19 compdump:115> print -n ' _trash-restore'
19 compdump:115> print -n ' _trash-empty'
19 compdump:115> print -n ' _trap'
19 compdump:115> print -n ' _tput'
19 compdump:115> print -n ' _touch'
19 compdump:115> print -n ' _tmuxinator'
19 compdump:115> print -n ' _tmux'
19 compdump:115> print -n ' _tload'
19 compdump:115> print -n ' _tla'
19 compdump:115> print -n ' _timeout'
19 compdump:115> print -n ' _time_zone'
19 compdump:115> print -n ' _tilde_files'
19 compdump:115> print -n ' _tiff'
19 compdump:115> print -n ' _tidy'
19 compdump:115> print -n ' _texi'
19 compdump:115> print -n ' _tex'
19 compdump:115> print -n ' _telnet'
19 compdump:115> print -n ' _teamocil'
19 compdump:115> print -n ' _tcpdump'
19 compdump:115> print -n ' _tarsnap'
19 compdump:115> print -n ' _tac'
19 compdump:115> print -n ' _system_profiler'
19 compdump:115> print -n ' _swaks'
19 compdump:115> print -n ' _sw_vers'
19 compdump:115> print -n ' _svn-buildpackage'
19 compdump:115> print -n ' _svm'
19 compdump:115> print -n ' _svccfg'
19 compdump:115> print -n ' _supervisorctl'
19 compdump:115> print -n ' _sudo'
19 compdump:115> print -n ' _sublimetext'
19 compdump:115> print -n ' _su'
19 compdump:115> print -n ' _stty'
19 compdump:115> print -n ' _stat'
19 compdump:115> print -n ' _sshfs'
19 compdump:115> print -n ' _ssh_hosts'
19 compdump:115> print -n ' _srm'
19 compdump:115> print -n ' _sqsh'
19 compdump:115> print -n ' _smit'
19 compdump:115> print -n ' _sisu'
19 compdump:115> print -n ' _signals'
19 compdump:115> print -n ' _shred'
19 compdump:115> print -n ' _setup.py'
19 compdump:115> print -n ' _setup'
19 compdump:115> print -n ' _setopt'
19 compdump:115> print -n ' _setfacl'
19 compdump:115> print -n ' _service'
19 compdump:115> print -n ' _sequence'
19 compdump:115> print -n ' _sep_parts'
19 compdump:115> print -n ' _selinux_roles'
19 compdump:115> print -n ' _sed'
19 compdump:115> print -n ' _seafile'
19 compdump:115> print -n ' _scselect'
19 compdump:115> print -n ' _scl'
19 compdump:115> print -n ' _schedtool'
19 compdump:115> print -n ' _sched'
19 compdump:115> print -n ' _sbt'
19 compdump:115> print -n ' _samba'
19 compdump:115> print -n ' _ruby'
19 compdump:115> print -n ' _rmdir'
19 compdump:115> print -n ' _ri'
19 compdump:115> print -n ' _rfkill'
19 compdump:115> print -n ' _retrieve_cache'
19 compdump:115> print -n ' _requested'
19 compdump:115> print -n ' _regex_words'
19 compdump:115> print -n ' _rebootin'
19 compdump:115> print -n ' _readshortcut'
19 compdump:115> print -n ' _readlink'
19 compdump:115> print -n ' _read_comp'
19 compdump:115> print -n ' _rdesktop'
19 compdump:115> print -n ' _rar'
19 compdump:115> print -n ' _ranlib'
19 compdump:115> print -n ' _ralio'
19 compdump:115> print -n ' _quilt'
19 compdump:115> print -n ' _python'
19 compdump:115> print -n ' _pwgen'
19 compdump:115> print -n ' _pv'
19 compdump:115> print -n ' _pscp'
19 compdump:115> print -n ' _ps1234'
19 compdump:115> print -n ' _ps'
19 compdump:115> print -n ' _process_names'
19 compdump:115> print -n ' _portlint'
19 compdump:115> print -n ' _pon'
19 compdump:115> print -n ' _pkgtool'
19 compdump:115> print -n ' _pkgadd'
19 compdump:115> print -n ' _pkg5'
19 compdump:115> print -n ' _pkcon'
19 compdump:115> print -n ' _pixz'
19 compdump:115> print -n ' _ping'
19 compdump:115> print -n ' _pine'
19 compdump:115> print -n ' _pidof'
19 compdump:115> print -n ' _pick_variant'
19 compdump:115> print -n ' _physical_volumes'
19 compdump:115> print -n ' _pgsql_utils'
19 compdump:115> print -n ' _perldoc'
19 compdump:115> print -n ' _pdftk'
19 compdump:115> print -n ' _pandoc'
19 compdump:115> print -n ' _osascript'
19 compdump:115> print -n ' _optirun'
19 compdump:115> print -n ' _options_unset'
19 compdump:115> print -n ' _options_set'
19 compdump:115> print -n ' _open'
19 compdump:115> print -n ' _oldlist'
19 compdump:115> print -n ' _od'
19 compdump:115> print -n ' _objdump'
19 compdump:115> print -n ' _nslookup'
19 compdump:115> print -n ' _npm'
19 compdump:115> print -n ' _node'
19 compdump:115> print -n ' _nmap'
19 compdump:115> print -n ' _nkf'
19 compdump:115> print -n ' _ngrep'
19 compdump:115> print -n ' _next_tags'
19 compdump:115> print -n ' _networksetup'
19 compdump:115> print -n ' _networkmanager'
19 compdump:115> print -n ' _netscape'
19 compdump:115> print -n ' _net_interfaces'
19 compdump:115> print -n ' _nautilus'
19 compdump:115> print -n ' _mysqldiff'
19 compdump:115> print -n ' _mysql_utils'
19 compdump:115> print -n ' _mutt'
19 compdump:115> print -n ' _mussh'
19 compdump:115> print -n ' _mplayer'
19 compdump:115> print -n ' _mozilla'
19 compdump:115> print -n ' _moosic'
19 compdump:115> print -n ' _monotone'
19 compdump:115> print -n ' _mondo'
19 compdump:115> print -n ' _modutils'
19 compdump:115> print -n ' _module-assistant'
19 compdump:115> print -n ' _module'
19 compdump:115> print -n ' _mkzsh'
19 compdump:115> print -n ' _mknod'
19 compdump:115> print -n ' _mime_types'
19 compdump:115> print -n ' _mdls'
19 compdump:115> print -n ' _mac_applications'
19 compdump:115> print -n ' _lzop'
19 compdump:115> print -n ' _lynx'
19 compdump:115> print -n ' _lunchy'
19 compdump:115> print -n ' _lsattr'
19 compdump:115> print -n ' _locale'
19 compdump:115> print -n ' _lldb'
19 compdump:115> print -n ' _links'
19 compdump:115> print -n ' _limits'
19 compdump:115> print -n ' _ldap'
19 compdump:115> print -n ' _ld_debug'
19 compdump:115> print -n ' _language_codes'
19 compdump:115> print -n ' _kld'
19 compdump:115> print -n ' _kitchen'
19 compdump:115> print -n ' _jq'
19 compdump:115> print -n ' _jonas'
19 compdump:115> print -n ' _joe'
19 compdump:115> print -n ' _jobs_builtin'
19 compdump:115> print -n ' _jails'
19 compdump:115> print -n ' _iwconfig'
19 compdump:115> print -n ' _iptables'
19 compdump:115> print -n ' _iostat'
19 compdump:115> print -n ' _init_d'
19 compdump:115> print -n ' _inetadm'
19 compdump:115> print -n ' _include-what-you-use'
19 compdump:115> print -n ' _id'
19 compdump:115> print -n ' _iconv'
19 compdump:115> print -n ' _ibus'
19 compdump:115> print -n ' _httpie'
19 compdump:115> print -n ' _hostname'
19 compdump:115> print -n ' _host'
19 compdump:115> print -n ' _history_complete_word'
19 compdump:115> print -n ' _hash'
19 compdump:115> print -n ' _gzip'
19 compdump:115> print -n ' _gv'
19 compdump:115> print -n ' _gtk-launch'
19 compdump:115> print -n ' _gstat'
19 compdump:115> print -n ' _growisofs'
19 compdump:115> print -n ' _groups'
19 compdump:115> print -n ' _grep-excuses'
19 compdump:115> print -n ' _grep'
19 compdump:115> print -n ' _gradle'
19 compdump:115> print -n ' _gqview'
19 compdump:115> print -n ' _gprof'
19 compdump:115> print -n ' _gpasswd'
19 compdump:115> print -n ' _google'
19 compdump:115> print -n ' _gnome-gv'
19 compdump:115> print -n ' _globqual_delims'
19 compdump:115> print -n ' _globflags'
19 compdump:115> print -n ' _git-revise'
19 compdump:115> print -n ' _git-pulls'
19 compdump:115> print -n ' _git-journal'
19 compdump:115> print -n ' _git-buildpackage'
19 compdump:115> print -n ' _git'
19 compdump:115> print -n ' _ghostscript'
19 compdump:115> print -n ' _getopt'
19 compdump:115> print -n ' _getmail'
19 compdump:115> print -n ' _getent'
19 compdump:115> print -n ' _getconf'
19 compdump:115> print -n ' _genisoimage'
19 compdump:115> print -n ' _gcc'
19 compdump:115> print -n ' _fwupdmgr'
19 compdump:115> print -n ' _fuse_values'
19 compdump:115> print -n ' _fstat'
19 compdump:115> print -n ' _freebsd-update'
19 compdump:115> print -n ' _fortune'
19 compdump:115> print -n ' _force'
19 compdump:115> print -n ' _fmt'
19 compdump:115> print -n ' _flutter'
19 compdump:115> print -n ' _floppy'
19 compdump:115> print -n ' _finger'
19 compdump:115> print -n ' _findmnt'
19 compdump:115> print -n ' _files'
19 compdump:115> print -n ' _file_systems'
19 compdump:115> print -n ' _ffmpeg'
19 compdump:115> print -n ' _fc'
19 compdump:115> print -n ' _fbsd_architectures'
19 compdump:115> print -n ' _fakeroot'
19 compdump:115> print -n ' _ethtool'
19 compdump:115> print -n ' _etags'
19 compdump:115> print -n ' _equal'
19 compdump:115> print -n ' _eog'
19 compdump:115> print -n ' _envdir'
19 compdump:115> print -n ' _enscript'
19 compdump:115> print -n ' _emulate'
19 compdump:115> print -n ' _elinks'
19 compdump:115> print -n ' _ecdsautil'
19 compdump:115> print -n ' _e2label'
19 compdump:115> print -n ' _dvi'
19 compdump:115> print -n ' _dupload'
19 compdump:115> print -n ' _dsh'
19 compdump:115> print -n ' _drush'
19 compdump:115> print -n ' _drill'
19 compdump:115> print -n ' _dpkg-cross'
19 compdump:115> print -n ' _dnf'
19 compdump:115> print -n ' _dirs'
19 compdump:115> print -n ' _dir_list'
19 compdump:115> print -n ' _diffstat'
19 compdump:115> print -n ' _dict_words'
19 compdump:115> print -n ' _dhcpinfo'
19 compdump:115> print -n ' _dget'
19 compdump:115> print -n ' _devtodo'
19 compdump:115> print -n ' _description'
19 compdump:115> print -n ' _delimiters'
19 compdump:115> print -n ' _defaults'
19 compdump:115> print -n ' _deborphan'
19 compdump:115> print -n ' _debfoster'
19 compdump:115> print -n ' _debdiff'
19 compdump:115> print -n ' _debchange'
19 compdump:115> print -n ' _deb_packages'
19 compdump:115> print -n ' _deb_codenames'
19 compdump:115> print -n ' _deb_architectures'
19 compdump:115> print -n ' _dd'
19 compdump:115> print -n ' _dcut'
19 compdump:115> print -n ' _dconf'
19 compdump:115> print -n ' _dchroot-dsa'
19 compdump:115> print -n ' _dchroot'
19 compdump:115> print -n ' _dad'
19 compdump:115> print -n ' _cygrunsrv'
19 compdump:115> print -n ' _ctags_tags'
19 compdump:115> print -n ' _csup'
19 compdump:115> print -n ' _cssh'
19 compdump:115> print -n ' _cscope'
19 compdump:115> print -n ' _cryptsetup'
19 compdump:115> print -n ' _crontab'
19 compdump:115> print -n ' _cpupower'
19 compdump:115> print -n ' _cppcheck'
19 compdump:115> print -n ' _cplay'
19 compdump:115> print -n ' _cpio'
19 compdump:115> print -n ' _cowsay'
19 compdump:115> print -n ' _correct_word'
19 compdump:115> print -n ' _condition'
19 compdump:115> print -n ' _concourse'
19 compdump:115> print -n ' _composer'
19 compdump:115> print -n ' _composer'
19 compdump:115> print -n ' _completers'
19 compdump:115> print -n ' _complete_tag'
19 compdump:115> print -n ' _complete_help_generic'
19 compdump:115> print -n ' _complete_help'
19 compdump:115> print -n ' _complete_debug'
19 compdump:115> print -n ' _compadd'
19 compdump:115> print -n ' _column'
19 compdump:115> print -n ' _cmp'
19 compdump:115> print -n ' _cmdstring'
19 compdump:115> print -n ' _clay'
19 compdump:115> print -n ' _chromium'
19 compdump:115> print -n ' _chown'
19 compdump:115> print -n ' _chmod'
19 compdump:115> print -n ' _chflags'
19 compdump:115> print -n ' _chcon'
19 compdump:115> print -n ' _cf'
19 compdump:115> print -n ' _cdcd'
19 compdump:115> print -n ' _cdbs-edit-patch'
19 compdump:115> print -n ' _ccache'
19 compdump:115> print -n ' _cat'
19 compdump:115> print -n ' _cap'
19 compdump:115> print -n ' _call_function'
19 compdump:115> print -n ' _calendar'
19 compdump:115> print -n ' _caffeinate'
19 compdump:115> print -n ' _caffeinate'
19 compdump:115> print -n ' _bzr'
19 compdump:115> print -n ' _bzip2'
19 compdump:115> print -n ' _btrfs'
19 compdump:115> print -n ' _bsd_pkg'
19 compdump:115> print -n ' _bsd_disks'
19 compdump:115> print -n ' _brctl'
19 compdump:115> print -n ' _brace_parameter'
19 compdump:115> print -n ' _bogofilter'
19 compdump:115> print -n ' _bison'
19 compdump:115> print -n ' _baudrates'
19 compdump:115> print -n ' _bash_completions'
19 compdump:115> print -n ' _bash'
19 compdump:115> print -n ' _basename'
19 compdump:115> print -n ' _axi-cache'
19 compdump:115> print -n ' _atach'
19 compdump:115> print -n ' _assign'
19 compdump:115> print -n ' _asciinema'
19 compdump:115> print -n ' _artisan'
19 compdump:115> print -n ' _arping'
19 compdump:115> print -n ' _arp'
19 compdump:115> print -n ' _arg_compile'
19 compdump:115> print -n ' _aptitude'
19 compdump:115> print -n ' _apt-move'
19 compdump:115> print -n ' _apt-file'
19 compdump:115> print -n ' _apt'
19 compdump:115> print -n ' _approximate'
19 compdump:115> print -n ' _apachectl'
19 compdump:115> print -n ' _antiword'
19 compdump:115> print -n ' _alternative'
19 compdump:115> print -n ' _afew'
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:114> ((  ! 0  ))
19 compdump:113> ((  1091  ))
19 compdump:113> ((  853  ))
19 compdump:113> ((  750  ))
19 compdump:91> _d_bks+=( _expand_word )
19 compdump:91> _d_bks+=( _correct_filename )
19 compdump:91> _d_bks+=( _complete_help )
19 compdump:86> [[ -z '' && .list-choices = .menu-select ]]
19 compdump:86> [[ -z '' && .list-choices = .menu-select ]]
19 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
19 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
19 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
19 compdump:85> [[ vi-pound-insert = _* ]]
19 compdump:85> [[ vi-history-search-backward = _* ]]
19 compdump:85> [[ vi-forward-blank-word-end = _* ]]
19 compdump:85> [[ vi-find-next-char-skip = _* ]]
19 compdump:85> [[ vi-digit-or-beginning-of-line = _* ]]
19 compdump:85> [[ vi-beginning-of-line = _* ]]
19 compdump:85> [[ vi-backward-kill-word = _* ]]
19 compdump:85> [[ vi-backward-blank-word-end = _* ]]
19 compdump:85> [[ vi-backward-blank-word = _* ]]
19 compdump:85> [[ universal-argument = _* ]]
19 compdump:85> [[ select-in-shell-word = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-up-line-or-beginning-search = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-reverse-menu-complete = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-menu-select = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-menu-expand-or-complete = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-expand-or-complete = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-edit-command-line = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-complete-word = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_read_comp = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_expand_word = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_expand_alias = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_complete_tag = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_complete_help = _* ]]
19 compdump:85> [[ orig-s0.0000080000-r6249-_bash_complete-word = _* ]]
19 compdump:85> [[ infer-next-history = _* ]]
19 compdump:85> [[ history-search-forward = _* ]]
19 compdump:85> [[ history-incremental-search-backward = _* ]]
19 compdump:85> [[ history-incremental-pattern-search-forward = _* ]]
19 compdump:85> [[ history-beginning-search-forward = _* ]]
19 compdump:85> [[ expand-or-complete = _* ]]
19 compdump:85> [[ autosuggest-execute = _* ]]
19 compdump:85> [[ autosuggest-enable = _* ]]
19 compdump:85> [[ auto-suffix-remove = _* ]]
19 compdump:85> [[ accept-and-menu-complete = _* ]]
19 compdump:63> print -r - ''yodl(|2*)'' ''_yodl''
19 compdump:63> print -r - ''g++-*'' ''_gcc''
19 compdump:62> _d_f=*/X11(|R<4->)/*
19 compdump:50> print -r - ''lzcat'' ''unxz''
19 compdump:50> print -r - ''-redirect-,<,xz'' ''xz''
19 compdump:50> print -r - ''-redirect-,<,unxz'' ''unxz''
19 compdump:49> _d_f=-redirect-,<,bzip2
19 compdump:44> print -r - ''zsh'' ''_zsh''
19 compdump:44> print -r - ''zcash-cli'' ''_zcash-cli''
19 compdump:44> print -r - ''xsetbg'' ''_xloadimage''
19 compdump:44> print -r - ''xloadimage'' ''_xloadimage''
19 compdump:44> print -r - ''wanna-build'' ''_wanna-build''
19 compdump:44> print -r - ''virt-pki-validate'' ''_libvirt''
19 compdump:44> print -r - ''virt-admin'' ''_libvirt''
19 compdump:44> print -r - ''vim-addons'' ''_vim-addons''
19 compdump:44> print -r - ''val'' ''_sccs''
19 compdump:44> print -r - ''vacuumdb'' ''_postgresql''
19 compdump:44> print -r - ''urxvt256c-ml'' ''_urxvt''
19 compdump:44> print -r - ''urpmi.removemedia'' ''_urpmi''
19 compdump:44> print -r - ''uptime'' ''_uptime''
19 compdump:44> print -r - ''upgradepkg'' ''_pkgtool''
19 compdump:44> print -r - ''update-alternatives'' ''_update-alternatives''
19 compdump:44> print -r - ''unwrapdiff'' ''_patchutils''
19 compdump:44> print -r - ''unfunction'' ''_functions''
19 compdump:44> print -r - ''unexpand'' ''_unexpand''
19 compdump:44> print -r - ''ulimit'' ''_ulimit''
19 compdump:44> print -r - ''tryaffix'' ''_ispell''
19 compdump:44> print -r - ''trash-restore'' ''_trash-restore''
19 compdump:44> print -r - ''trash-empty'' ''_trash-empty''
19 compdump:44> print -r - ''tpkg-install-libc'' ''_toolchain-source''
19 compdump:44> print -r - ''tpkg-install'' ''_toolchain-source''
19 compdump:44> print -r - ''tpkg-debarch'' ''_toolchain-source''
19 compdump:44> print -r - ''timeout'' ''_timeout''
19 compdump:44> print -r - ''time'' ''_precommand''
19 compdump:44> print -r - ''texi2pdf'' ''_texinfo''
19 compdump:44> print -r - ''texi2dvi'' ''_texinfo''
19 compdump:44> print -r - ''teamocil'' ''_teamocil''
19 compdump:44> print -r - ''talk'' ''_other_accounts''
19 compdump:44> print -r - ''tacker'' ''_openstack''
19 compdump:44> print -r - ''svnlite'' ''_subversion''
19 compdump:44> print -r - ''svn-buildpackage'' ''_svn-buildpackage''
19 compdump:44> print -r - ''svcprop'' ''_svcprop''
19 compdump:44> print -r - ''ssh-copy-id'' ''_ssh''
19 compdump:44> print -r - ''spamassassin'' ''_spamassassin''
19 compdump:44> print -r - ''softwareupdate'' ''_softwareupdate''
19 compdump:44> print -r - ''slocate'' ''_locate''
19 compdump:44> print -r - ''skipstone'' ''_webbrowser''
19 compdump:44> print -r - ''shuf'' ''_shuf''
19 compdump:44> print -r - ''sha512'' ''_cksum''
19 compdump:44> print -r - ''sha224sum'' ''_md5sum''
19 compdump:44> print -r - ''setfattr'' ''_attr''
19 compdump:44> print -r - ''senlin'' ''_openstack''
19 compdump:44> print -r - ''scutil'' ''_scutil''
19 compdump:44> print -r - ''schroot'' ''_schroot''
19 compdump:44> print -r - ''sc_usage'' ''_sc_usage''
19 compdump:44> print -r - ''rview'' ''_vim''
19 compdump:44> print -r - ''rup'' ''_hosts''
19 compdump:44> print -r - ''reindexdb'' ''_postgresql''
19 compdump:44> print -r - ''readshortcut'' ''_readshortcut''
19 compdump:44> print -r - ''ranlib'' ''_ranlib''
19 compdump:44> print -r - ''pstoedit'' ''_pspdf''
19 compdump:44> print -r - ''psnup'' ''_psutils''
19 compdump:44> print -r - ''psbook'' ''_psutils''
19 compdump:44> print -r - ''ps2pdf14'' ''_postscript''
19 compdump:44> print -r - ''procstat'' ''_procstat''
19 compdump:44> print -r - ''portsnap'' ''_portsnap''
19 compdump:44> print -r - ''portlint'' ''_portlint''
19 compdump:44> print -r - ''podpath'' ''_perl_modules''
19 compdump:44> print -r - ''pmexp'' ''_perl_modules''
19 compdump:44> print -r - ''pkg_delete'' ''_bsd_pkg''
19 compdump:44> print -r - ''pg_restore'' ''_postgresql''
19 compdump:44> print -r - ''pg_dumpall'' ''_postgresql''
19 compdump:44> print -r - ''pg_config'' ''_postgresql''
19 compdump:44> print -r - ''pfiles'' ''_pids''
19 compdump:44> print -r - ''pfexec'' ''_pfexec''
19 compdump:44> print -r - ''periscope'' ''_periscope''
19 compdump:44> print -r - ''pdfjadetex'' ''_tex''
19 compdump:44> print -r - ''parsehdlist'' ''_urpmi''
19 compdump:44> print -r - ''opera'' ''_webbrowser''
19 compdump:44> print -r - ''odmshow'' ''_object_classes''
19 compdump:44> print -r - ''objdump'' ''_objdump''
19 compdump:44> print -r - ''numfmt'' ''_numfmt''
19 compdump:44> print -r - ''ntalk'' ''_other_accounts''
19 compdump:44> print -r - ''ns'' ''_hosts''
19 compdump:44> print -r - ''nohup'' ''_precommand''
19 compdump:44> print -r - ''nmcli'' ''_networkmanager''
19 compdump:44> print -r - ''nkf'' ''_nkf''
19 compdump:44> print -r - ''netscape'' ''_netscape''
19 compdump:44> print -r - ''nautilus'' ''_nautilus''
19 compdump:44> print -r - ''mysqlshow'' ''_mysql_utils''
19 compdump:44> print -r - ''mysqldump'' ''_mysql_utils''
19 compdump:44> print -r - ''mysqladmin'' ''_mysql_utils''
19 compdump:44> print -r - ''munchlist'' ''_ispell''
19 compdump:44> print -r - ''mtoolstest'' ''_mtools''
19 compdump:44> print -r - ''mozilla-xremote-client'' ''_mozilla''
19 compdump:44> print -r - ''mozilla-firefox'' ''_mozilla''
19 compdump:44> print -r - ''moosic'' ''_moosic''
19 compdump:44> print -r - ''montage'' ''_imagemagick''
19 compdump:44> print -r - ''monasca'' ''_openstack''
19 compdump:44> print -r - ''mlabel'' ''_mtools''
19 compdump:44> print -r - ''lua'' ''_lua''
19 compdump:44> print -r - ''lighty-enable-mod'' ''_lighttpd''
19 compdump:44> print -r - ''lighty-disable-mod'' ''_lighttpd''
19 compdump:44> print -r - ''lastb'' ''_last''
19 compdump:44> print -r - ''jmeter-plugins'' ''_jmeter-plugins''
19 compdump:44> print -r - ''include-what-you-use'' ''_include-what-you-use''
19 compdump:44> print -r - ''gunexpand'' ''_unexpand''
19 compdump:44> print -r - ''guilt-refresh'' ''_guilt''
19 compdump:44> print -r - ''guilt-rebase'' ''_guilt''
19 compdump:44> print -r - ''guilt-import-commit'' ''_guilt''
19 compdump:44> print -r - ''gtail'' ''_tail''
19 compdump:44> print -r - ''gslj'' ''_pspdf''
19 compdump:44> print -r - ''gshred'' ''_shred''
19 compdump:44> print -r - ''gsed'' ''_sed''
19 compdump:44> print -r - ''groupmod'' ''_user_admin''
19 compdump:44> print -r - ''groupdel'' ''_groups''
19 compdump:44> print -r - ''groupadd'' ''_user_admin''
19 compdump:44> print -r - ''grmdir'' ''_rmdir''
19 compdump:44> print -r - ''grail'' ''_webbrowser''
19 compdump:44> print -r - ''gradle'' ''_gradle''
19 compdump:44> print -r - ''gprintenv'' ''_printenv''
19 compdump:44> print -r - ''gpg'' ''_gpg''
19 compdump:44> print -r - ''gpaste'' ''_paste''
19 compdump:44> print -r - ''gnutls-cli-debug'' ''_gnutls''
19 compdump:44> print -r - ''gnupod_search.pl'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_search'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_check.pl'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_check'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_addsong.pl'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_addsong'' ''_gnupod''
19 compdump:44> print -r - ''gnupod_INIT'' ''_gnupod''
19 compdump:44> print -r - ''gnome-gv'' ''_gnome-gv''
19 compdump:44> print -r - ''gmv'' ''_mv''
19 compdump:44> print -r - ''gmd5sum'' ''_md5sum''
19 compdump:44> print -r - ''gm'' ''_graphicsmagick''
19 compdump:44> print -r - ''glocate'' ''_locate''
19 compdump:44> print -r - ''glances'' ''_glances''
19 compdump:44> print -r - ''git-pulls'' ''_git-pulls''
19 compdump:44> print -r - ''git-flow'' ''_git-flow''
19 compdump:44> print -r - ''ginstall'' ''_install''
19 compdump:44> print -r - ''ghostscript'' ''_ghostscript''
19 compdump:44> print -r - ''ghci'' ''_ghc''
19 compdump:44> print -r - ''ggrep'' ''_grep''
19 compdump:44> print -r - ''ggetopt'' ''_getopt''
19 compdump:44> print -r - ''gexpand'' ''_unexpand''
19 compdump:44> print -r - ''getfattr'' ''_attr''
19 compdump:44> print -r - ''getclip'' ''_getclip''
19 compdump:44> print -r - ''genv'' ''_env''
19 compdump:44> print -r - ''gdb'' ''_gdb''
19 compdump:44> print -r - ''gcomm'' ''_comm''
19 compdump:44> print -r - ''gcmp'' ''_cmp''
19 compdump:44> print -r - ''gcksum'' ''_cksum''
19 compdump:44> print -r - ''gchown'' ''_chown''
19 compdump:44> print -r - ''gbase64'' ''_base64''
19 compdump:44> print -r - ''gb2sum'' ''_md5sum''
19 compdump:44> print -r - ''gawk'' ''_awk''
19 compdump:44> print -r - ''galeon'' ''_webbrowser''
19 compdump:44> print -r - ''fwupdmgr'' ''_fwupdmgr''
19 compdump:44> print -r - ''fstat'' ''_fstat''
19 compdump:44> print -r - ''fs_usage'' ''_fs_usage''
19 compdump:44> print -r - ''freebsd-make'' ''_make''
19 compdump:44> print -r - ''fprev'' ''_mh''
19 compdump:44> print -r - ''fortune'' ''_fortune''
19 compdump:44> print -r - ''fnext'' ''_mh''
19 compdump:44> print -r - ''fmttest'' ''_mh''
19 compdump:44> print -r - ''fly'' ''_concourse''
19 compdump:44> print -r - ''flists'' ''_mh''
19 compdump:44> print -r - ''fleetctl'' ''_fleetctl''
19 compdump:44> print -r - ''fixwwps'' ''_psutils''
19 compdump:44> print -r - ''fixwfwps'' ''_psutils''
19 compdump:44> print -r - ''fixscribeps'' ''_psutils''
19 compdump:44> print -r - ''fixpsditps'' ''_psutils''
19 compdump:44> print -r - ''fixmacps'' ''_psutils''
19 compdump:44> print -r - ''fixfmps'' ''_psutils''
19 compdump:44> print -r - ''firefox'' ''_mozilla''
19 compdump:44> print -r - ''fink'' ''_fink''
19 compdump:44> print -r - ''find'' ''_find''
19 compdump:44> print -r - ''fetchmail'' ''_fetchmail''
19 compdump:44> print -r - ''extractres'' ''_psutils''
19 compdump:44> print -r - ''exportfs'' ''_exportfs''
19 compdump:44> print -r - ''expand'' ''_unexpand''
19 compdump:44> print -r - ''eval'' ''_precommand''
19 compdump:44> print -r - ''eu-readelf'' ''_readelf''
19 compdump:44> print -r - ''enscript'' ''_enscript''
19 compdump:44> print -r - ''emulate'' ''_emulate''
19 compdump:44> print -r - ''ecdsautil'' ''_ecdsautil''
19 compdump:44> print -r - ''e2label'' ''_e2label''
19 compdump:44> print -r - ''dvitodvi'' ''_dvi''
19 compdump:44> print -r - ''dumper.exe'' ''_dumper''
19 compdump:44> print -r - ''dropuser'' ''_postgresql''
19 compdump:44> print -r - ''dpkg-repack'' ''_dpkg-repack''
19 compdump:44> print -r - ''dpkg-reconfigure'' ''_dpkg''
19 compdump:44> print -r - ''dpkg-deb'' ''_dpkg''
19 compdump:44> print -r - ''dpatch-edit-patch'' ''_dpatch-edit-patch''
19 compdump:44> print -r - ''dockerd'' ''_docker''
19 compdump:44> print -r - ''docker'' ''_docker''
19 compdump:44> print -r - ''django-admin.py'' ''_django''
19 compdump:44> print -r - ''django-admin'' ''_django''
19 compdump:44> print -r - ''dillo'' ''_webbrowser''
19 compdump:44> print -r - ''dhclient3'' ''_dhclient''
19 compdump:44> print -r - ''dget'' ''_dget''
19 compdump:44> print -r - ''designate'' ''_openstack''
19 compdump:44> print -r - ''defaults'' ''_defaults''
19 compdump:44> print -r - ''debsign'' ''_debsign''
19 compdump:44> print -r - ''debdiff'' ''_debdiff''
19 compdump:44> print -r - ''debchange'' ''_debchange''
19 compdump:44> print -r - ''dcopref'' ''_dcop''
19 compdump:44> print -r - ''dcopclient'' ''_dcop''
19 compdump:44> print -r - ''dchroot'' ''_dchroot''
19 compdump:44> print -r - ''dbus-monitor'' ''_dbus''
19 compdump:44> print -r - ''cygstart.exe'' ''_cygstart''
19 compdump:44> print -r - ''cygserver.exe'' ''_cygserver''
19 compdump:44> print -r - ''cygrunsrv.exe'' ''_cygrunsrv''
19 compdump:44> print -r - ''cygcheck.exe'' ''_cygcheck''
19 compdump:44> print -r - ''cryptsetup'' ''_cryptsetup''
19 compdump:44> print -r - ''crontab'' ''_crontab''
19 compdump:44> print -r - ''createuser'' ''_postgresql''
19 compdump:44> print -r - ''cpupower'' ''_cpupower''
19 compdump:44> print -r - ''cowsay'' ''_cowsay''
19 compdump:44> print -r - ''convert'' ''_imagemagick''
19 compdump:44> print -r - ''console'' ''_console''
19 compdump:44> print -r - ''configure'' ''_configure''
19 compdump:44> print -r - ''concourse'' ''_concourse''
19 compdump:44> print -r - ''compress'' ''_compress''
19 compdump:44> print -r - ''composer'' ''_composer''
19 compdump:44> print -r - ''comp'' ''_mh''
19 compdump:44> print -r - ''combinediff'' ''_patchutils''
19 compdump:44> print -r - ''cockroach'' ''_cockroach''
19 compdump:44> print -r - ''cinder'' ''_openstack''
19 compdump:44> print -r - ''cifsiostat'' ''_sysstat''
19 compdump:44> print -r - ''chroot'' ''_chroot''
19 compdump:44> print -r - ''chimera'' ''_webbrowser''
19 compdump:44> print -r - ''cheat'' ''_cheat''
19 compdump:44> print -r - ''chattr'' ''_chattr''
19 compdump:44> print -r - ''cdrecord'' ''_cdrecord''
19 compdump:44> print -r - ''cdbs-edit-patch'' ''_cdbs-edit-patch''
19 compdump:44> print -r - ''catchsegv'' ''_precommand''
19 compdump:44> print -r - ''caffeinate'' ''_caffeinate''
19 compdump:44> print -r - ''cabal'' ''_cabal''
19 compdump:44> print -r - ''bzip2recover'' ''_bzip2''
19 compdump:44> print -r - ''burst'' ''_mh''
19 compdump:44> print -r - ''builtin'' ''_builtin''
19 compdump:44> print -r - ''bttrack'' ''_bittorrent''
19 compdump:44> print -r - ''btrfs'' ''_btrfs''
19 compdump:44> print -r - ''btlaunchmany'' ''_bittorrent''
19 compdump:44> print -r - ''brew'' ''_brew''
19 compdump:44> print -r - ''brctl'' ''_brctl''
19 compdump:44> print -r - ''bpython2-gtk'' ''_bpython''
19 compdump:44> print -r - ''bpython-urwid'' ''_bpython''
19 compdump:44> print -r - ''bpython'' ''_bpython''
19 compdump:44> print -r - ''bogoutil'' ''_bogofilter''
19 compdump:44> print -r - ''bogofilter'' ''_bogofilter''
19 compdump:44> print -r - ''bison'' ''_bison''
19 compdump:44> print -r - ''bibtex'' ''_bibtex''
19 compdump:44> print -r - ''bash'' ''_bash''
19 compdump:44> print -r - ''base64'' ''_base64''
19 compdump:44> print -r - ''barbican'' ''_openstack''
19 compdump:44> print -r - ''axi-cache'' ''_axi-cache''
19 compdump:44> print -r - ''awk'' ''_awk''
19 compdump:44> print -r - ''avahi-resolve-host-name'' ''_avahi''
19 compdump:44> print -r - ''avahi-browse-domains'' ''_avahi''
19 compdump:44> print -r - ''autoload'' ''_typeset''
19 compdump:44> print -r - ''at'' ''_at''
19 compdump:44> print -r - ''asciidoctor'' ''_asciidoctor''
19 compdump:44> print -r - ''arping'' ''_arping''
19 compdump:44> print -r - ''arecord'' ''_alsa-utils''
19 compdump:44> print -r - ''apt-file'' ''_apt-file''
19 compdump:44> print -r - ''apt-config'' ''_apt''
19 compdump:43> _d_f=tarsnap
19 compdump:43> _d_f=ruby
19 compdump:43> _d_f=grmdir
19 compdump:43> _d_f=chromium
19 compdump:43> _d_f=ccache
19 compdump:43> _d_f=SuSEconfig
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:169> shift
19 compdef:164> _services[$cmd]=xz
19 compdef:164> _services[$cmd]=unxz
19 compdef:164> _services[$cmd]=mktunes
19 compdef:164> _services[$cmd]=latex
19 compdef:162> [[ -z yes || -z _zmv ]]
19 compdef:162> [[ -z yes || -z _yum ]]
19 compdef:162> [[ -z yes || -z _yp ]]
19 compdef:162> [[ -z yes || -z _xz ]]
19 compdef:162> [[ -z yes || -z _xv ]]
19 compdef:162> [[ -z yes || -z _xloadimage ]]
19 compdef:162> [[ -z yes || -z _x_utils ]]
19 compdef:162> [[ -z yes || -z _x_utils ]]
19 compdef:162> [[ -z yes || -z _x_utils ]]
19 compdef:162> [[ -z yes || -z _wget ]]
19 compdef:162> [[ -z yes || -z _webbrowser ]]
19 compdef:162> [[ -z yes || -z _w ]]
19 compdef:162> [[ -z yes || -z _vorbis ]]
19 compdef:162> [[ -z yes || -z _vmstat ]]
19 compdef:162> [[ -z yes || -z _visudo ]]
19 compdef:162> [[ -z yes || -z _vim ]]
19 compdef:162> [[ -z yes || -z _vared ]]
19 compdef:162> [[ -z yes || -z _value ]]
19 compdef:162> [[ -z yes || -z _users ]]
19 compdef:162> [[ -z yes || -z _uscan ]]
19 compdef:162> [[ -z yes || -z _uptime ]]
19 compdef:162> [[ -z yes || -z _uname ]]
19 compdef:162> [[ -z yes || -z _unace ]]
19 compdef:162> [[ -z yes || -z _typeset ]]
19 compdef:162> [[ -z yes || -z _twisted ]]
19 compdef:162> [[ -z yes || -z _transmission ]]
19 compdef:162> [[ -z yes || -z _tracepath ]]
19 compdef:162> [[ -z yes || -z _tin ]]
19 compdef:162> [[ -z yes || -z _timeout ]]
19 compdef:162> [[ -z yes || -z _tex ]]
19 compdef:162> [[ -z yes || -z _tex ]]
19 compdef:162> [[ -z yes || -z _telnet ]]
19 compdef:162> [[ -z yes || -z _sysstat ]]
19 compdef:162> [[ -z yes || -z _sysctl ]]
19 compdef:162> [[ -z yes || -z _swift ]]
19 compdef:162> [[ -z yes || -z _swaks ]]
19 compdef:162> [[ -z yes || -z _sw_vers ]]
19 compdef:162> [[ -z yes || -z _svcprop ]]
19 compdef:162> [[ -z yes || -z _sudo ]]
19 compdef:162> [[ -z yes || -z _subversion ]]
19 compdef:162> [[ -z yes || -z _strings ]]
19 compdef:162> [[ -z yes || -z _ss ]]
19 compdef:162> [[ -z yes || -z _sqsh ]]
19 compdef:162> [[ -z yes || -z _sqlite ]]
19 compdef:162> [[ -z yes || -z _split ]]
19 compdef:162> [[ -z yes || -z _spamassassin ]]
19 compdef:162> [[ -z yes || -z _sort ]]
19 compdef:162> [[ -z yes || -z _snoop ]]
19 compdef:162> [[ -z yes || -z _smartmontools ]]
19 compdef:162> [[ -z yes || -z _slabtop ]]
19 compdef:162> [[ -z yes || -z _sisu ]]
19 compdef:162> [[ -z yes || -z _shred ]]
19 compdef:162> [[ -z yes || -z _showmount ]]
19 compdef:162> [[ -z yes || -z _sh ]]
19 compdef:162> [[ -z yes || -z _sh ]]
19 compdef:162> [[ -z yes || -z _setxkbmap ]]
19 compdef:162> [[ -z yes || -z _setopt ]]
19 compdef:162> [[ -z yes || -z _script ]]
19 compdef:162> [[ -z yes || -z _screen ]]
19 compdef:162> [[ -z yes || -z _scons ]]
19 compdef:162> [[ -z yes || -z _schroot ]]
19 compdef:162> [[ -z yes || -z _sccs ]]
19 compdef:162> [[ -z yes || -z _sccs ]]
19 compdef:162> [[ -z yes || -z _sc_usage ]]
19 compdef:162> [[ -z yes || -z _say ]]
19 compdef:162> [[ -z yes || -z _ruby ]]
19 compdef:162> [[ -z yes || -z _ruby ]]
19 compdef:162> [[ -z yes || -z _rubber ]]
19 compdef:162> [[ -z yes || -z _rpm ]]
19 compdef:162> [[ -z yes || -z _rpm ]]
19 compdef:162> [[ -z yes || -z _rm ]]
19 compdef:162> [[ -z yes || -z _reprepro ]]
19 compdef:162> [[ -z yes || -z _renice ]]
19 compdef:162> [[ -z yes || -z _redirect ]]
19 compdef:162> [[ -z yes || -z _rcs ]]
19 compdef:162> [[ -z yes || -z _rcs ]]
19 compdef:162> [[ -z yes || -z _qtplay ]]
19 compdef:162> [[ -z yes || -z _pwgen ]]
19 compdef:162> [[ -z yes || -z _pspdf ]]
19 compdef:162> [[ -z yes || -z _prompt ]]
19 compdef:162> [[ -z yes || -z _precommand ]]
19 compdef:162> [[ -z yes || -z _powerd ]]
19 compdef:162> [[ -z yes || -z _postscript ]]
19 compdef:162> [[ -z yes || -z _postgresql ]]
19 compdef:162> [[ -z yes || -z _postgresql ]]
19 compdef:162> [[ -z yes || -z _portaudit ]]
19 compdef:162> [[ -z yes || -z _pkg-config ]]
19 compdef:162> [[ -z yes || -z _pidof ]]
19 compdef:162> [[ -z yes || -z _pdf ]]
19 compdef:162> [[ -z yes || -z _pbcopy ]]
19 compdef:162> [[ -z yes || -z _patchutils ]]
19 compdef:162> [[ -z yes || -z _paste ]]
19 compdef:162> [[ -z yes || -z _pandoc ]]
19 compdef:162> [[ -z yes || -z _pack ]]
19 compdef:162> [[ -z yes || -z _otool ]]
19 compdef:162> [[ -z yes || -z _opkg ]]
19 compdef:162> [[ -z yes || -z _openstack ]]
19 compdef:162> [[ -z yes || -z _od ]]
19 compdef:162> [[ -z yes || -z _nvram ]]
19 compdef:162> [[ -z yes || -z _ngrep ]]
19 compdef:162> [[ -z yes || -z _netscape ]]
19 compdef:162> [[ -z yes || -z _netcat ]]
19 compdef:162> [[ -z yes || -z _mv ]]
19 compdef:162> [[ -z yes || -z _mozilla ]]
19 compdef:162> [[ -z yes || -z _modutils ]]
19 compdef:162> [[ -z yes || -z _mkfifo ]]
19 compdef:162> [[ -z yes || -z _mh ]]
19 compdef:162> [[ -z yes || -z _mergechanges ]]
19 compdef:162> [[ -z yes || -z _md5sum ]]
19 compdef:162> [[ -z yes || -z _md5sum ]]
19 compdef:162> [[ -z yes || -z _md5sum ]]
19 compdef:162> [[ -z yes || -z _md5sum ]]
19 compdef:162> [[ -z yes || -z _md5sum ]]
19 compdef:162> [[ -z yes || -z _make ]]
19 compdef:162> [[ -z yes || -z _make ]]
19 compdef:162> [[ -z yes || -z _luarocks ]]
19 compdef:162> [[ -z yes || -z _lsusb ]]
19 compdef:162> [[ -z yes || -z _lsof ]]
19 compdef:162> [[ -z yes || -z _lsblk ]]
19 compdef:162> [[ -z yes || -z _ls ]]
19 compdef:162> [[ -z yes || -z _locate ]]
19 compdef:162> [[ -z yes || -z _limits ]]
19 compdef:162> [[ -z yes || -z _less ]]
19 compdef:162> [[ -z yes || -z _kill ]]
19 compdef:162> [[ -z yes || -z _kfmclient ]]
19 compdef:162> [[ -z yes || -z _jrnl ]]
19 compdef:162> [[ -z yes || -z _jot ]]
19 compdef:162> [[ -z yes || -z _join ]]
19 compdef:162> [[ -z yes || -z _jmeter ]]
19 compdef:162> [[ -z yes || -z _java ]]
19 compdef:162> [[ -z yes || -z _java ]]
19 compdef:162> [[ -z yes || -z _jail ]]
19 compdef:162> [[ -z yes || -z _iwconfig ]]
19 compdef:162> [[ -z yes || -z _ipadm ]]
19 compdef:162> [[ -z yes || -z _iostat ]]
19 compdef:162> [[ -z yes || -z _ionice ]]
19 compdef:162> [[ -z yes || -z _initctl ]]
19 compdef:162> [[ -z yes || -z _inetadm ]]
19 compdef:162> [[ -z yes || -z _imagemagick ]]
19 compdef:162> [[ -z yes || -z _httpie ]]
19 compdef:162> [[ -z yes || -z _htop ]]
19 compdef:162> [[ -z yes || -z _guilt ]]
19 compdef:162> [[ -z yes || -z _guilt ]]
19 compdef:162> [[ -z yes || -z _guilt ]]
19 compdef:162> [[ -z yes || -z _guilt ]]
19 compdef:162> [[ -z yes || -z _guilt ]]
19 compdef:162> [[ -z yes || -z _gprof ]]
19 compdef:162> [[ -z yes || -z _google ]]
19 compdef:162> [[ -z yes || -z _go ]]
19 compdef:162> [[ -z yes || -z _gnupod ]]
19 compdef:162> [[ -z yes || -z _glances ]]
19 compdef:162> [[ -z yes || -z _getconf ]]
19 compdef:162> [[ -z yes || -z _first ]]
19 compdef:162> [[ -z yes || -z _fink ]]
19 compdef:162> [[ -z yes || -z _ffind ]]
19 compdef:162> [[ -z yes || -z _fetchmail ]]
19 compdef:162> [[ -z yes || -z _fetch ]]
19 compdef:162> [[ -z yes || -z _fail2ban-client ]]
19 compdef:162> [[ -z yes || -z _emulator ]]
19 compdef:162> [[ -z yes || -z _dvi ]]
19 compdef:162> [[ -z yes || -z _dvi ]]
19 compdef:162> [[ -z yes || -z _dvi ]]
19 compdef:162> [[ -z yes || -z _dpkg ]]
19 compdef:162> [[ -z yes || -z _dpkg ]]
19 compdef:162> [[ -z yes || -z _docker ]]
19 compdef:162> [[ -z yes || -z _dnf ]]
19 compdef:162> [[ -z yes || -z _cp ]]
19 compdef:162> [[ -z yes || -z _console ]]
19 compdef:162> [[ -z yes || -z _conan ]]
19 compdef:162> [[ -z yes || -z _cksum ]]
19 compdef:162> [[ -z yes || -z _cksum ]]
19 compdef:162> [[ -z yes || -z _cksum ]]
19 compdef:162> [[ -z yes || -z _cksum ]]
19 compdef:162> [[ -z yes || -z _cd ]]
19 compdef:162> [[ -z yes || -z _cap ]]
19 compdef:162> [[ -z yes || -z _bundle ]]
19 compdef:162> [[ -z yes || -z _bsdconfig ]]
19 compdef:162> [[ -z yes || -z _bsd_pkg ]]
19 compdef:162> [[ -z yes || -z _brew ]]
19 compdef:162> [[ -z yes || -z _brctl ]]
19 compdef:162> [[ -z yes || -z _bpython ]]
19 compdef:162> [[ -z yes || -z _bindkey ]]
19 compdef:162> [[ -z yes || -z _bash ]]
19 compdef:162> [[ -z yes || -z _aws ]]
19 compdef:162> [[ -z yes || -z _attr ]]
19 compdef:162> [[ -z yes || -z _atach ]]
19 compdef:162> [[ -z yes || -z _arrays ]]
19 compdef:162> [[ -z yes || -z _ant ]]
19 compdef:162> [[ -z yes || -z _alsa-utils ]]
19 compdef:162> [[ -z yes || -z _adb ]]
19 compdef:162> [[ -z yes || -z _acpitool ]]
19 compdef:162> [[ -z yes || -z _ack ]]
19 compdef:162> [[ -z yes || -z _aap ]]
19 compdef:162> [[ -z yes || -z '' ]]
19 compdef:162> [[ -z yes || -z '' ]]
19 compdef:162> [[ -z yes || -z '' ]]
19 compdef:160> svc=''
19 compdef:160> svc=''
19 compdef:160> svc=''
19 compdef:159> cmd=pstoedit
19 compdef:159> cmd=poff
19 compdef:159> cmd=ksh88
19 compdef:159> cmd=jrnl
19 compdef:159> cmd=isag
19 compdef:156> cmd=ggl
19 compdef:156> cmd=gchown
19 compdef:156> cmd=VBoxManage
19 compdef:155> [[ trash-empty = *=* ]]
19 compdef:155> [[ snap = *=* ]]
19 compdef:155> [[ smbcontrol = *=* ]]
19 compdef:155> [[ ri = *=* ]]
19 compdef:155> [[ mkisofs = *=* ]]
19 compdef:155> [[ groupdel = *=* ]]
19 compdef:155> [[ evince = *=* ]]
19 compdef:155> [[ entr = *=* ]]
19 compdef:155> [[ enscript = *=* ]]
19 compdef:155> [[ dumpadm = *=* ]]
19 compdef:155> [[ drill = *=* ]]
19 compdef:155> [[ dpkg-source = *=* ]]
19 compdef:155> [[ dhcpinfo = *=* ]]
19 compdef:155> [[ devtodo = *=* ]]
19 compdef:155> [[ defaults = *=* ]]
19 compdef:155> [[ debuild = *=* ]]
19 compdef:155> [[ debfoster = *=* ]]
19 compdef:155> [[ debchange = *=* ]]
19 compdef:155> [[ dd = *=* ]]
19 compdef:155> [[ compress = *=* ]]
19 compdef:155> [[ compdef = *=* ]]
19 compdef:155> [[ cksum = *=* ]]
19 compdef:155> [[ chsh = *=* ]]
19 compdef:155> [[ chkconfig = *=* ]]
19 compdef:155> [[ chcon = *=* ]]
19 compdef:155> [[ cdcd = *=* ]]
19 compdef:155> [[ cal = *=* ]]
19 compdef:155> [[ apt-move = *=* ]]
19 compdef:155> [[ _restic = *=* ]]
19 compdef:151> _postpatcomps[$1]=_urls
19 compdef:151> _postpatcomps[$1]=_locales
19 compdef:151> _postpatcomps[$1]=_golang
19 compdef:151> _postpatcomps[$1]=_gcc
19 compdef:151> _postpatcomps[$1]=_ccache
19 compdef:139> case postpattern (pattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (postpattern)
19 compdef:139> case  (pattern)
19 compdef:139> case  (pattern)
19 compdef:139> case  (pattern)
19 compdef:139> case  (pattern)
19 compdef:136> [[ play = -P ]]
19 compdef:136> [[ nano = -P ]]
19 compdef:136> [[ afew = -P ]]
19 compdef:134> [[ wipefs = -p ]]
19 compdef:134> [[ thor = -p ]]
19 compdef:134> [[ tarsnap = -p ]]
19 compdef:134> [[ newgrp = -p ]]
19 compdef:134> [[ gzgrep = -p ]]
19 compdef:134> [[ git-pulls = -p ]]
19 compdef:132> [[ ztodo = -N ]]
19 compdef:132> [[ zdump = -N ]]
19 compdef:132> [[ zcompile = -N ]]
19 compdef:132> [[ yum = -N ]]
19 compdef:132> [[ xscreensaver-command = -N ]]
19 compdef:132> [[ xournal = -N ]]
19 compdef:132> [[ which = -N ]]
19 compdef:132> [[ wget = -N ]]
19 compdef:132> [[ wanna-build = -N ]]
19 compdef:132> [[ update-rc.d = -N ]]
19 compdef:132> [[ unhash = -N ]]
19 compdef:132> [[ trash-put = -N ]]
19 compdef:132> [[ tput = -N ]]
19 compdef:132> [[ tg = -N ]]
19 compdef:132> [[ tcptraceroute = -N ]]
19 compdef:132> [[ system_profiler = -N ]]
19 compdef:132> [[ systat = -N ]]
19 compdef:132> [[ sv = -N ]]
19 compdef:132> [[ stack = -N ]]
19 compdef:132> [[ source = -N ]]
19 compdef:132> [[ shutdown = -N ]]
19 compdef:132> [[ setcap = -N ]]
19 compdef:132> [[ screen = -N ]]
19 compdef:132> [[ scons = -N ]]
19 compdef:132> [[ scl = -N ]]
19 compdef:132> [[ sched = -N ]]
19 compdef:132> [[ rslsync = -N ]]
19 compdef:132> [[ read = -N ]]
19 compdef:132> [[ quilt = -N ]]
19 compdef:132> [[ qdbus = -N ]]
19 compdef:132> [[ portaudit = -N ]]
19 compdef:132> [[ pipenv = -N ]]
19 compdef:132> [[ periscope = -N ]]
19 compdef:132> [[ perf = -N ]]
19 compdef:132> [[ pdf2dsc = -N ]]
19 compdef:132> [[ patool = -N ]]
19 compdef:132> [[ optirun = -N ]]
19 compdef:132> [[ openstack = -N ]]
19 compdef:132> [[ openssl = -N ]]
19 compdef:132> [[ okular = -N ]]
19 compdef:132> [[ objdump = -N ]]
19 compdef:132> [[ nvm = -N ]]
19 compdef:132> [[ ninja = -N ]]
19 compdef:132> [[ nanoc = -N ]]
19 compdef:132> [[ mysqldiff = -N ]]
19 compdef:132> [[ mysql = -N ]]
19 compdef:132> [[ mtn = -N ]]
19 compdef:132> [[ mozilla = -N ]]
19 compdef:132> [[ mount = -N ]]
19 compdef:132> [[ mix = -N ]]
19 compdef:132> [[ make-kpkg = -N ]]
19 compdef:132> [[ luarocks = -N ]]
19 compdef:132> [[ losetup = -N ]]
19 compdef:132> [[ look = -N ]]
19 compdef:132> [[ locale = -N ]]
19 compdef:132> [[ loadkeys = -N ]]
19 compdef:132> [[ limit = -N ]]
19 compdef:132> [[ kubectl = -N ]]
19 compdef:132> [[ knife = -N ]]
19 compdef:132> [[ kldload = -N ]]
19 compdef:132> [[ kill = -N ]]
19 compdef:132> [[ jls = -N ]]
19 compdef:132> [[ ip = -N ]]
19 compdef:132> [[ inxi = -N ]]
19 compdef:132> [[ hub = -N ]]
19 compdef:132> [[ hdiutil = -N ]]
19 compdef:132> [[ guniq = -N ]]
19 compdef:132> [[ getfacl = -N ]]
19 compdef:132> [[ getclip = -N ]]
19 compdef:132> [[ geany = -N ]]
19 compdef:132> [[ fwupdmgr = -N ]]
19 compdef:132> [[ fusermount = -N ]]
19 compdef:132> [[ ftp = -N ]]
19 compdef:132> [[ freebsd-update = -N ]]
19 compdef:132> [[ force = -N ]]
19 compdef:132> [[ fmt = -N ]]
19 compdef:132> [[ fmadm = -N ]]
19 compdef:132> [[ flowadm = -N ]]
19 compdef:132> [[ findmnt = -N ]]
19 compdef:132> [[ find = -N ]]
19 compdef:132> [[ feh = -N ]]
19 compdef:132> [[ fc-list = -N ]]
19 compdef:132> [[ fc = -N ]]
19 compdef:132> [[ etags = -N ]]
19 compdef:132> [[ espeak = -N ]]
19 compdef:132> [[ env = -N ]]
19 compdef:132> [[ enable = -N ]]
19 compdef:132> [[ elinks = -N ]]
19 compdef:132> [[ echotc = -N ]]
19 compdef:132> [[ e2label = -N ]]
19 compdef:132> [[ dupload = -N ]]
19 compdef:132> [[ du = -N ]]
19 compdef:132> [[ dtruss = -N ]]
19 compdef:132> [[ drush = -N ]]
19 compdef:132> [[ docpad = -N ]]
19 compdef:132> [[ dnf = -N ]]
19 compdef:132> [[ disable = -N ]]
19 compdef:132> [[ dircmp = -N ]]
19 compdef:132> [[ dict = -N ]]
19 compdef:132> [[ dcop = -N ]]
19 compdef:132> [[ dchroot = -N ]]
19 compdef:132> [[ date = -N ]]
19 compdef:132> [[ dak = -N ]]
19 compdef:132> [[ dad = -N ]]
19 compdef:132> [[ cryptsetup = -N ]]
19 compdef:132> [[ cmake = -N ]]
19 compdef:132> [[ chromium = -N ]]
19 compdef:132> [[ cd = -N ]]
19 compdef:132> [[ ccal = -N ]]
19 compdef:132> [[ cat = -N ]]
19 compdef:132> [[ calendar = -N ]]
19 compdef:132> [[ builtin = -N ]]
19 compdef:132> [[ bug = -N ]]
19 compdef:132> [[ bitcoin-cli = -N ]]
19 compdef:132> [[ auto-apt = -N ]]
19 compdef:132> [[ asciinema = -N ]]
19 compdef:132> [[ arping = -N ]]
19 compdef:132> [[ archlinux-java = -N ]]
19 compdef:132> [[ amaya = -N ]]
19 compdef:132> [[ add-zsh-hook = -N ]]
19 compdef:132> [[ -value-,PROMPT,-default- = -N ]]
19 compdef:132> [[ -subscript- = -N ]]
19 compdef:132> [[ -redirect- = -N ]]
19 compdef:132> [[ -equal- = -N ]]
19 compdef:132> [[ -condition- = -N ]]
19 compdef:132> [[ 'qemu(|-system-*)' = -N ]]
19 compdef:132> [[ '-redirect-,<,compress=compress' = -N ]]
19 compdef:132> [[ '*/(init|rc[0-9S]#).d/*' = -N ]]
19 compdef:131> ((  4  ))
19 compdef:131> ((  2  ))
19 compdef:131> ((  1  ))
19 compdef:131> ((  1  ))
19 compdef:131> ((  1  ))
19 compdef:117> shift
19 compdef:110> [[ complete-word = .* ]]
19 compdef:91> [[ complete-word = .* ]]
19 compdef:85> [[ -n _list_expansions ]]
19 compdef:83> case  (widgetkey)
19 compdef:83> case  (widgetkey)
19 compdef:83> case  (widgetkey)
19 compdef:83> case  (widgetkey)
19 compdef:83> case  (widgetkey)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:83> case  (*)
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:81> shift
19 compdef:80> autoload -Uz _zip
19 compdef:80> autoload -Uz _zftp
19 compdef:80> autoload -Uz _zeal
19 compdef:80> autoload -Uz _zcalc
19 compdef:80> autoload -Uz _zattr
19 compdef:80> autoload -Uz _xv
19 compdef:80> autoload -Uz _xterm
19 compdef:80> autoload -Uz _xmms2
19 compdef:80> autoload -Uz _who
19 compdef:80> autoload -Uz _wc
19 compdef:80> autoload -Uz _wanna-build
19 compdef:80> autoload -Uz _w3m
19 compdef:80> autoload -Uz _w
19 compdef:80> autoload -Uz _vpnc
19 compdef:80> autoload -Uz _vnc
19 compdef:80> autoload -Uz _vcsh
19 compdef:80> autoload -Uz _vared
19 compdef:80> autoload -Uz _users_on
19 compdef:80> autoload -Uz _uscan
19 compdef:80> autoload -Uz _urpmi
19 compdef:80> autoload -Uz _uptime
19 compdef:80> autoload -Uz _unexpand
19 compdef:80> autoload -Uz _uname
19 compdef:80> autoload -Uz _ulimit
19 compdef:80> autoload -Uz _typeset
19 compdef:80> autoload -Uz _ttyctl
19 compdef:80> autoload -Uz _truss
19 compdef:80> autoload -Uz _trash
19 compdef:80> autoload -Uz _trap
19 compdef:80> autoload -Uz _touch
19 compdef:80> autoload -Uz _totd
19 compdef:80> autoload -Uz _toolchain-source
19 compdef:80> autoload -Uz _tmux
19 compdef:80> autoload -Uz _timeout
19 compdef:80> autoload -Uz _tiff
19 compdef:80> autoload -Uz _tail
19 compdef:80> autoload -Uz _tac
19 compdef:80> autoload -Uz _sysstat
19 compdef:80> autoload -Uz _swanctl
19 compdef:80> autoload -Uz _svcs
19 compdef:80> autoload -Uz _svcadm
19 compdef:80> autoload -Uz _sudo
19 compdef:80> autoload -Uz _subversion
19 compdef:80> autoload -Uz _su
19 compdef:80> autoload -Uz _strftime
19 compdef:80> autoload -Uz _strace
19 compdef:80> autoload -Uz _ssh
19 compdef:80> autoload -Uz _ss
19 compdef:80> autoload -Uz _sqsh
19 compdef:80> autoload -Uz _spamassassin
19 compdef:80> autoload -Uz _source
19 compdef:80> autoload -Uz _snoop
19 compdef:80> autoload -Uz _slrn
19 compdef:80> autoload -Uz _shuf
19 compdef:80> autoload -Uz _sh
19 compdef:80> autoload -Uz _scutil
19 compdef:80> autoload -Uz _scselect
19 compdef:80> autoload -Uz _screen
19 compdef:80> autoload -Uz _schroot
19 compdef:80> autoload -Uz _sc_usage
19 compdef:80> autoload -Uz _sbuild
19 compdef:80> autoload -Uz _say
19 compdef:80> autoload -Uz _savecore
19 compdef:80> autoload -Uz _run-help
19 compdef:80> autoload -Uz _ruby
19 compdef:80> autoload -Uz _rpm
19 compdef:80> autoload -Uz _rebootin
19 compdef:80> autoload -Uz _readlink
19 compdef:80> autoload -Uz _read_comp
19 compdef:80> autoload -Uz _read
19 compdef:80> autoload -Uz _rar
19 compdef:80> autoload -Uz _ranlib
19 compdef:80> autoload -Uz _qtplay
19 compdef:80> autoload -Uz _qiv
19 compdef:80> autoload -Uz _qemu
19 compdef:80> autoload -Uz _python
19 compdef:80> autoload -Uz _pydoc
19 compdef:80> autoload -Uz _pwgen
19 compdef:80> autoload -Uz _pv
19 compdef:80> autoload -Uz _ps1234
19 compdef:80> autoload -Uz _ps
19 compdef:80> autoload -Uz _printers
19 compdef:80> autoload -Uz _powerd
19 compdef:80> autoload -Uz _postgresql
19 compdef:80> autoload -Uz _postfix
19 compdef:80> autoload -Uz _portaudit
19 compdef:80> autoload -Uz _pkgtool
19 compdef:80> autoload -Uz _pkgrm
19 compdef:80> autoload -Uz _pkgin
19 compdef:80> autoload -Uz _pine
19 compdef:80> autoload -Uz _pfexec
19 compdef:80> autoload -Uz _pbuilder
19 compdef:80> autoload -Uz _patchutils
19 compdef:80> autoload -Uz _parameter
19 compdef:80> autoload -Uz _osc
19 compdef:80> autoload -Uz _osascript
19 compdef:80> autoload -Uz _okular
19 compdef:80> autoload -Uz _od
19 compdef:80> autoload -Uz _nslookup
19 compdef:80> autoload -Uz _npm
19 compdef:80> autoload -Uz _nmap
19 compdef:80> autoload -Uz _ngrep
19 compdef:80> autoload -Uz _nedit
19 compdef:80> autoload -Uz _myrepos
19 compdef:80> autoload -Uz _mutt
19 compdef:80> autoload -Uz _mupdf
19 compdef:80> autoload -Uz _mplayer
19 compdef:80> autoload -Uz _mozilla
19 compdef:80> autoload -Uz _monotone
19 compdef:80> autoload -Uz _mondo
19 compdef:80> autoload -Uz _mkfifo
19 compdef:80> autoload -Uz _mkdir
19 compdef:80> autoload -Uz _mergechanges
19 compdef:80> autoload -Uz _make
19 compdef:80> autoload -Uz _mail
19 compdef:80> autoload -Uz _lz4
19 compdef:80> autoload -Uz _lsdev
19 compdef:80> autoload -Uz _lscfg
19 compdef:80> autoload -Uz _locate
19 compdef:80> autoload -Uz _limits
19 compdef:80> autoload -Uz _libvirt
19 compdef:80> autoload -Uz _lha
19 compdef:80> autoload -Uz _ldd
19 compdef:80> autoload -Uz _knock
19 compdef:80> autoload -Uz _knife
19 compdef:80> autoload -Uz _jrnl
19 compdef:80> autoload -Uz _jot
19 compdef:80> autoload -Uz _jonas
19 compdef:80> autoload -Uz _joe
19 compdef:80> autoload -Uz _jail
19 compdef:80> autoload -Uz _iptables
19 compdef:80> autoload -Uz _ipset
19 compdef:80> autoload -Uz _ipsec
19 compdef:80> autoload -Uz _ipadm
19 compdef:80> autoload -Uz _iostat
19 compdef:80> autoload -Uz _inxi
19 compdef:80> autoload -Uz _invoke-rc.d
19 compdef:80> autoload -Uz _install
19 compdef:80> autoload -Uz _init_d
19 compdef:80> autoload -Uz _in_vared
19 compdef:80> autoload -Uz _imagemagick
19 compdef:80> autoload -Uz _iftop
19 compdef:80> autoload -Uz _id
19 compdef:80> autoload -Uz _iconv
19 compdef:80> autoload -Uz _htop
19 compdef:80> autoload -Uz _hosts
19 compdef:80> autoload -Uz _host
19 compdef:80> autoload -Uz _hexdump
19 compdef:80> autoload -Uz _groff
19 compdef:80> autoload -Uz _gpg
19 compdef:80> autoload -Uz _google
19 compdef:80> autoload -Uz _go
19 compdef:80> autoload -Uz _glances
19 compdef:80> autoload -Uz _git-buildpackage
19 compdef:80> autoload -Uz _ghostscript
19 compdef:80> autoload -Uz _getfacl
19 compdef:80> autoload -Uz _getclip
19 compdef:80> autoload -Uz _geany
19 compdef:80> autoload -Uz _gdb
19 compdef:80> autoload -Uz _fstat
19 compdef:80> autoload -Uz _fold
19 compdef:80> autoload -Uz _fleetctl
19 compdef:80> autoload -Uz _finger
19 compdef:80> autoload -Uz _find
19 compdef:80> autoload -Uz _files
19 compdef:80> autoload -Uz _fc
19 compdef:80> autoload -Uz _fakeroot
19 compdef:80> autoload -Uz _dvc
19 compdef:80> autoload -Uz _docker
19 compdef:80> autoload -Uz _dget
19 compdef:80> autoload -Uz _conan
19 compdef:80> autoload -Uz _complete_tag
19 compdef:80> autoload -Uz _coffee
19 compdef:80> autoload -Uz _cockroach
19 compdef:80> autoload -Uz _cf
19 compdef:80> autoload -Uz _cask
19 compdef:80> autoload -Uz _cap
19 compdef:80> autoload -Uz _bzip2
19 compdef:80> autoload -Uz _bison
19 compdef:80> autoload -Uz _bindkey
19 compdef:80> autoload -Uz _bibtex
19 compdef:80> autoload -Uz _beep
19 compdef:80> autoload -Uz _bash
19 compdef:80> autoload -Uz _avahi
19 compdef:80> autoload -Uz _autocd
19 compdef:80> autoload -Uz _auto-apt
19 compdef:80> autoload -Uz _assign
19 compdef:80> autoload -Uz _asciinema
19 compdef:80> autoload -Uz _artisan
19 compdef:80> autoload -Uz _arrays
19 compdef:80> autoload -Uz _arp
19 compdef:80> autoload -Uz _apt-show-versions
19 compdef:80> autoload -Uz _apt-move
19 compdef:80> autoload -Uz _analyseplugin
19 compdef:80> autoload -Uz _adb
19 compdef:80> autoload -Uz _acroread
19 compdef:80> autoload -Uz _abcde
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:80> [[ -n yes ]]
19 compdef:79> func=_thor
19 compdef:79> func=_stgit
19 compdef:79> func=_seq
19 compdef:79> func=_protoc
19 compdef:79> func=_iwconfig
19 compdef:79> func=_debdiff
19 compdef:79> func=_chkconfig
19 compdef:49> [[ _zmodload = *=* ]]
19 compdef:49> [[ _wiggle = *=* ]]
19 compdef:49> [[ _trash-list = *=* ]]
19 compdef:49> [[ _rkt = *=* ]]
19 compdef:49> [[ _quilt = *=* ]]
19 compdef:49> [[ _printenv = *=* ]]
19 compdef:49> [[ _pm2 = *=* ]]
19 compdef:49> [[ _nl = *=* ]]
19 compdef:49> [[ _math = *=* ]]
19 compdef:49> [[ _jq = *=* ]]
19 compdef:49> [[ _growisofs = *=* ]]
19 compdef:49> [[ _gqview = *=* ]]
19 compdef:49> [[ _flex = *=* ]]
19 compdef:49> [[ _dd = *=* ]]
19 compdef:49> [[ _cdr = *=* ]]
19 compdef:49> [[ _cdcd = *=* ]]
19 compdef:49> [[ _cal = *=* ]]
19 compdef:49> [[ -z '' ]]
19 compdef:49> [[ -z '' ]]
19 compdef:49> [[ -z '' ]]
19 compdef:49> [[ -z '' ]]
19 compdef:45> [[ -z '' ]]
19 compdef:45> [[ -z '' ]]
19 compdef:45> [[ -z '' ]]
19 compdef:45> [[ -z '' ]]
19 compdef:45> [[ -z '' ]]
19 compdef:40> ((  ! 15  ))
19 compdef:40> ((  ! 10  ))
19 compdef:40> ((  ! 7  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 3  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:40> ((  ! 2  ))
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:38> shift OPTIND-1
19 compdef:29> type=widgetkey
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:17> new=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:16> autol=yes
19 compdef:15> case n (n)
19 compdef:15> case n (n)
19 compdef:15> case n (a)
19 compdef:15> case n (a)
19 compdef:15> case n (a)
19 compdef:15> case a (a)
19 compdef:15> case a (a)
19 compdef:15> case a (a)
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:14> getopts anpPkKde opt
19 compdef:9> ((  ! 24  ))
19 compdef:9> ((  ! 15  ))
19 compdef:9> ((  ! 14  ))
19 compdef:9> ((  ! 12  ))
19 compdef:9> ((  ! 11  ))
19 compdef:9> ((  ! 11  ))
19 compdef:9> ((  ! 9  ))
19 compdef:9> ((  ! 9  ))
19 compdef:9> ((  ! 8  ))
19 compdef:9> ((  ! 8  ))
19 compdef:9> ((  ! 8  ))
19 compdef:9> ((  ! 8  ))
19 compdef:9> ((  ! 8  ))
19 compdef:9> ((  ! 7  ))
19 compdef:9> ((  ! 7  ))
19 compdef:9> ((  ! 7  ))
19 compdef:9> ((  ! 7  ))
19 compdef:9> ((  ! 6  ))
19 compdef:9> ((  ! 6  ))
19 compdef:9> ((  ! 6  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 5  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 4  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 3  ))
19 compdef:9> ((  ! 2  ))
19 compdef:9> ((  ! 2  ))
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:5> setopt extendedglob
19 compdef:4> emulate -L zsh
19 compdef:4> emulate -L zsh
19 compdef:4> emulate -L zsh
19 compdef:4> emulate -L zsh
19 compdef:2> local -a match mbegin mend
19 compaudit:102> [[ -e /proc/87947/exe ]]
19 compaudit:91> local -a _i_exes
19 compaudit:27> ((  0  ))
19 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;36m'
19 colors:106> fg_bold[${k#fg-}]=$'C-[[01;37m'
19 colors:106> fg_bold[${k#fg-}]=$'C-[[01;31m'
19 colors:99> bold_color=$'C-[[01m'
19 antigen-remove-hook:4> local -a hooks
19 antigen-remove-hook:4> hooks=( -antigen-load-env-cached )
19 antigen-remove-hook:2> typeset -A meta
19 antigen-ext:2> local func=-antigen-parallel-init
19 antigen-bundle-parallel-execute:40> bundle=zsh-users/zsh-syntax-highlighting
19 antigen-bundle-parallel-execute:10> args=zsh-users/zsh-syntax-highlighting
19 antigen-bundle-parallel-execute:2> typeset -a pids
19 antigen-apply-defer:6> bundle=zsh-users/zsh-autosuggestions
19 antigen-apply-defer:6> bundle=--loc=lib
19 antigen-add-hook:22> local hook_function=-antigen-hook--antigen-load-source
19 antigen-add-hook:13> [[ antigen-apply-lock:antigen-apply-parallel:antigen-app...
19 antigen-add-hook:8> ((  ! 1  ))
19 antigen-add-hook:3> ((  ! 1  ))
19 antigen-add-hook:3> ((  ! 1  ))
19 add-zsh-hook:89> typeset -ga preexec_functions
19 add-zsh-hook:65> local hook=preexec_functions
19 add-zsh-hook:55> shift 0
19 add-zsh-hook:26> integer del list help
19 add-zsh-hook:24> local opt
19 add-zsh-hook:24> local opt
19 add-zle-hook-widget:178> case file shfunc shfunc shfunc shfunc shfunc shfunc ...
19 add-zle-hook-widget:103> zle -N -- _zsh_highlight__zle-line-finish
19 add-zle-hook-widget:95> i=0+1
19 add-zle-hook-widget:82> zstyle -g extant_hooks zle-line-finish widgets
19 add-zle-hook-widget:52> local fn=_zsh_highlight__zle-line-pre-redraw
19 add-zle-hook-widget:8> local -a autoopts
19 add-zle-hook-widget:7> local opt
19 _zsh_highlight_bind_widgets:50> zle -N vi-up-case _zsh_highlight_widget_orig-...
19 _zsh_highlight_bind_widgets:50> zle -N vi-insert-bol _zsh_highlight_widget_or...
19 _zsh_highlight_bind_widgets:50> zle -N vi-delete _zsh_highlight_widget_orig-s...
19 _zsh_highlight_bind_widgets:50> zle -N vi-add-eol _zsh_highlight_widget_orig-...
19 _zsh_highlight_bind_widgets:50> zle -N up-line _zsh_highlight_widget_orig-s0....
19 _zsh_highlight_bind_widgets:50> zle -N up-case-word _zsh_highlight_widget_ori...
19 _zsh_highlight_bind_widgets:50> zle -N undo _zsh_highlight_widget_orig-s0.000...
19 _zsh_highlight_bind_widgets:50> zle -N push-line _zsh_highlight_widget_orig-s...
19 _zsh_highlight_bind_widgets:50> zle -N forward-char _zsh_highlight_widget_ori...
19 _zsh_highlight_bind_widgets:50> zle -N clear-screen _zsh_highlight_widget_ori...
19 _zsh_highlight_bind_widgets:50> zle -N accept-line _zsh_highlight_widget_orig...
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:27> case builtin (builtin)
19 _zsh_highlight_bind_widgets:26> cur_widget=forward-word
19 _zsh_highlight_bind_widgets:26> cur_widget=copy-prev-word
19 _zsh_highlight__is_function_p:1> zmodload -e zsh/parameter
19 /usr/local/opt/powerlevel10k/powerlevel10k.zsh-theme:16> [[ ! -o sh_glob ]]
19 /Users/matt/.zshrc:383> alias 'c=clear'
19 /Users/matt/.zcompdump:1979> bindkey '^[,' _history-complete-newer
19 /Users/matt/.zcompdump:1975> bindkey '^Xm' _most_recent_file
19 /Users/matt/.zcompdump:1973> bindkey '^Xe' _expand_word
19 /Users/matt/.zcompdump:1971> bindkey '^Xc' _correct_word
19 /Users/matt/.zcompdump:1969> bindkey '^XC' _correct_filename
19 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1810> bindkey '^Xn' _next_tags
19 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1809> bindkey '^Xm' _most_re...
19 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1807> bindkey '^Xe' _expand_...
19 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1803> bindkey '^XC' _correct...
19 /Users/matt/.p10k.zsh:17> [[ ! -o aliases ]]
19 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
19 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:54> ZSH_THEME_GIT_PROMPT_...
19 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=175
19 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=087
19 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:61> bindkey -M emacs $'C-[OF' end...
19 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:55> bindkey -M emacs $'C-[OH' beg...
19 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:49> bindkey -M viins $'C-[OB' dow...
19 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:37> zle -N up-line-or-beginning-s...
19 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:35> [[ -n $'C-[OA' ]]
19 /Users/matt/.oh-my-zsh/lib/history.zsh:38> setopt hist_ignore_space
19 /Users/matt/.oh-my-zsh/lib/directories.zsh:8> alias -g '.....=../../../..'
19 /Users/matt/.oh-my-zsh/lib/directories.zsh:3> setopt pushd_ignore_dups
19 /Users/matt/.oh-my-zsh/lib/completion.zsh:17> [[ '' = true ]]
19 /Users/matt/.oh-my-zsh/lib/completion.zsh:9> setopt complete_in_word
19 /Users/matt/.oh-my-zsh/lib/completion.zsh:7> unsetopt flowcontrol
19 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
19 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:3> alias 'sd=fasd -sid'
19 /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-highlighting/highlighters/m...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:21> env_defa...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /us...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:103>...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:98> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:79> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:69> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:67> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:62> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:61> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:56> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:46> ...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:38> setop...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:22> a...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:20> a...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:18> a...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:13> a...
19 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:9> set...
19 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/robbyrussel...
19 -antigen-parse-args:135> local bpath=zsh-users/zsh-syntax-highlighting
19 -antigen-parse-args:135> local bpath=robbyrussell/oh-my-zsh
19 -antigen-parse-args:135> local bpath=robbyrussell/oh-my-zsh
19 -antigen-parse-args:135> local bpath=robbyrussell/oh-my-zsh
19 -antigen-parse-args:134> [[ true == true ]]
19 -antigen-parse-args:96> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:96> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:86> local url=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:86> local url=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:86> local url=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:81> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
19 -antigen-parse-args:65> shift
19 -antigen-parse-args:61> args[$key]=zsh-users/zsh-autosuggestions
19 -antigen-parse-args:27> args[$key]=lib
19 -antigen-parse-args:20> value=lib
19 -antigen-parse-args:19> key=zsh-users/zsh-syntax-highlighting
19 -antigen-parse-args:4> local var=bundle
19 -antigen-load:12> location=/Users/matt/.antigen/bundles/zsh-users/zsh-autosug...
19 -antigen-load:4> list=( )
19 -antigen-interactive-mode:2> [[ '' !=  ]]
19 -antigen-interactive-mode:2> [[ '' !=  ]]
19 -antigen-hook-handler:55> [[ 1 == 0 ]]
19 -antigen-hook-handler:55> [[ 1 == 0 ]]
19 -antigen-hook-handler:55> [[ 1 == 0 ]]
19 -antigen-hook-handler:55> [[ 1 == 0 ]]
19 -antigen-hook-handler:55> [[ 1 == 0 ]]
19 -antigen-hook-handler:55> [[ 0 == 0 ]]
19 -antigen-hook-handler:55> [[ 0 == 0 ]]
19 -antigen-hook-handler:55> [[ 0 == 0 ]]
19 -antigen-hook-handler:51> [[ 0 == -1 ]]
19 -antigen-hook-handler:51> [[ -1 == -1 ]]
19 -antigen-hook-handler:44> local replace_hook=0 ret=0
19 -antigen-hook-handler:44> local replace_hook=0 ret=0
19 -antigen-hook-handler:40> [[ 0 == -1 ]]
19 -antigen-hook-handler:40> [[ 0 == -1 ]]
19 -antigen-hook-handler:40> [[ 0 == -1 ]]
19 -antigen-hook-handler:37> hook=antigen-apply-parallel
19 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-defer )
19 -antigen-hook-handler:14> continue
19 -antigen-hook-handler:12> [[ repeat == once ]]
19 -antigen-hook-handler:12> [[ repeat == once ]]
19 -antigen-hook-handler:12> [[ repeat == once ]]
19 -antigen-hook-handler:9> typeset -A meta
19 -antigen-hook-handler:9> typeset -A meta
19 -antigen-hook-handler:9> typeset -A meta
19 -antigen-hook-handler:7> typeset -a hooks
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> typeset -a args
19 -antigen-hook-handler:4> args=( zsh-users/zsh-syntax-highlighting )
19 -antigen-hook-handler:4> args=( zsh-users/zsh-autosuggestions )
19 -antigen-hook-handler:4> args=( deno )
19 -antigen-hook-handler:4> args=( bundle deno )
19 -antigen-hook-handler:4> args=( apply )
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:3> shift
19 -antigen-hook-handler:2> local hooks meta
19 -antigen-hook-handler:2> local hooks meta
19 -antigen-hook-antigen:1> local cmd=bundle
19 -antigen-hook-antigen:1> local cmd=apply
19 -antigen-defer-init:1> typeset -ga _DEFERRED_BUNDLE
19 -antigen-cache-generate:10> [[ true == true && /Users/matt/.antigen/bundles/r...
19 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-a...
19 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/robbyrussell/oh...
19 (eval):197> alias 'gswc=git switch -c'
19 (eval):188> alias 'gwip=git add -A; git rm $(git ls-files --deleted) 2> /dev/...
19 (eval):168> alias 'gstd=git stash drop'
19 (eval):127> alias 'glola=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
19 (eval):126> alias 'glol=git log --graph --pretty='''%Cred%h%Creset -%C(auto)%...
19 (eval):108> alias 'glola=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
19 (eval):60> alias 'gcmsg=git commit -m'
19 (eval):40> alias 'gaa=git add --all'
19 (eval):36> alias 'gbda=git branch --no-color --merged | command grep -vE "^([...
19 (eval):4> alias -g '.....=../../../..'
19 (anon):1246> POWERLEVEL9K_KUBECONTEXT_DEFAULT_CONTENT_EXPANSION+='${${:-/$P9K...
19 (anon):1242> typeset -g POWERLEVEL9K_KUBECONTEXT_DEFAULT_CONTENT_EXPANSION=''
19 (anon):33> zle -N autosuggest-clear _zsh_autosuggest_widget_clear
19 (anon):2> action=modify
18 is-at-least:50> [[ 5 = <-> ]]
18 is-at-least:50> [[ 2 = <-> ]]
18 is-at-least:45> part=2
18 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
18 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
18 is-at-least:31> [[ 5 != <-> ]]
18 is-at-least:31> [[ 5 != <-> ]]
18 is-at-least:30> ((  0 <= 2  ))
18 is-at-least:28> version=( 5 8 1 0 )
18 is-at-least:27> min_ver=( 5 1 )
18 is-at-least:27> min_ver=( 5 0 8 )
18 env_default:1> [[ scalar-export = *-export* ]]
18 compinit:535> zle -la menu-select
18 compinit:533> zle -C menu-expand-or-complete .menu-expand-or-complete _main_c...
18 compinit:530> _i_line=expand-or-complete
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:516> [[ '' !=  # ]]
18 compinit:515> autoload -Uz _x_color
18 compinit:515> autoload -Uz _wanted
18 compinit:515> autoload -Uz _retrieve_mac_apps
18 compinit:515> autoload -Uz _multi_parts
18 compinit:515> autoload -Uz _logical_volumes
18 compinit:515> autoload -Uz _list_files
18 compinit:515> autoload -Uz _jobs
18 compinit:515> autoload -Uz _globqual_delims
18 compinit:515> autoload -Uz _fbsd_architectures
18 compinit:515> autoload -Uz _diff_options
18 compinit:515> autoload -Uz _complete
18 compinit:515> autoload -Uz _cmdstring
18 compinit:515> autoload -Uz _bpf_filters
18 compinit:515> autoload -Uz _arg_compile
18 compinit:515> autoload -Uz _arch_archives
18 compinit:515> autoload -Uz _all_matches
18 compinit:508> [[ trap = -[pPkK](n|) ]]
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #compdef (#compdef)
18 compinit:506> case #autoload (#compdef)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:506> case #autoload (#autoload)
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:505> shift _i_line
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:501> ((  0 + 0  ))
18 compinit:500> _i_name=_xmlstarlet
18 compinit:500> _i_name=_pkgrm
18 compinit:500> _i_name=_deb_codenames
18 compinit:500> _i_name=_deb_architectures
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_visual
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pgrep
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_eog
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_enable
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_drill
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dmidecode
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debuild
18 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_call_program
18 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_restic
18 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_mullvad
18 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_mpv
18 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_git
18 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
18 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
18 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
18 compinit:496> _i_dir=/usr/share/zsh/5.8.1/functions
18 compinit:479> [[ -f /Users/matt/.zcompdump ]]
18 compinit:446> [[ -n yes ]]
18 compinit:446> [[ -n '' ]]
18 compinit:440> typeset _i_wdirs _i_wfiles
18 compinit:187> comppostfuncs=( )
18 compinit:185> typeset -ga compprefuncs comppostfuncs
18 compinit:185> typeset -ga compprefuncs comppostfuncs
18 compinit:99> _i_check=''
18 compinit:76> [[ 0 -gt 0 ]]
18 compdump:121> shift _d_als
18 compdump:121> shift _d_als
18 compdump:121> shift _d_als
18 compdump:121> shift _d_als
18 compdump:121> shift _d_als
18 compdump:117> _i=5
18 compdump:116> ((  ! --_i && 1089 > 1  ))
18 compdump:116> ((  ! --_i && 1086 > 1  ))
18 compdump:116> ((  ! --_i && 1084 > 1  ))
18 compdump:116> ((  ! --_i && 1083 > 1  ))
18 compdump:116> ((  ! --_i && 1082 > 1  ))
18 compdump:116> ((  ! --_i && 1079 > 1  ))
18 compdump:116> ((  ! --_i && 1078 > 1  ))
18 compdump:116> ((  ! --_i && 1073 > 1  ))
18 compdump:116> ((  ! --_i && 1072 > 1  ))
18 compdump:116> ((  ! --_i && 1071 > 1  ))
18 compdump:116> ((  ! --_i && 1067 > 1  ))
18 compdump:116> ((  ! --_i && 1048 > 1  ))
18 compdump:116> ((  ! --_i && 1024 > 1  ))
18 compdump:116> ((  ! --_i && 1018 > 1  ))
18 compdump:116> ((  ! --_i && 1013 > 1  ))
18 compdump:116> ((  ! --_i && 1002 > 1  ))
18 compdump:116> ((  ! --_i && 988 > 1  ))
18 compdump:116> ((  ! --_i && 986 > 1  ))
18 compdump:116> ((  ! --_i && 976 > 1  ))
18 compdump:116> ((  ! --_i && 975 > 1  ))
18 compdump:116> ((  ! --_i && 970 > 1  ))
18 compdump:116> ((  ! --_i && 957 > 1  ))
18 compdump:116> ((  ! --_i && 953 > 1  ))
18 compdump:116> ((  ! --_i && 951 > 1  ))
18 compdump:116> ((  ! --_i && 943 > 1  ))
18 compdump:116> ((  ! --_i && 925 > 1  ))
18 compdump:116> ((  ! --_i && 917 > 1  ))
18 compdump:116> ((  ! --_i && 910 > 1  ))
18 compdump:116> ((  ! --_i && 885 > 1  ))
18 compdump:116> ((  ! --_i && 857 > 1  ))
18 compdump:116> ((  ! --_i && 848 > 1  ))
18 compdump:116> ((  ! --_i && 845 > 1  ))
18 compdump:116> ((  ! --_i && 830 > 1  ))
18 compdump:116> ((  ! --_i && 826 > 1  ))
18 compdump:116> ((  ! --_i && 822 > 1  ))
18 compdump:116> ((  ! --_i && 821 > 1  ))
18 compdump:116> ((  ! --_i && 812 > 1  ))
18 compdump:116> ((  ! --_i && 793 > 1  ))
18 compdump:116> ((  ! --_i && 792 > 1  ))
18 compdump:116> ((  ! --_i && 790 > 1  ))
18 compdump:116> ((  ! --_i && 788 > 1  ))
18 compdump:116> ((  ! --_i && 783 > 1  ))
18 compdump:116> ((  ! --_i && 776 > 1  ))
18 compdump:116> ((  ! --_i && 770 > 1  ))
18 compdump:116> ((  ! --_i && 767 > 1  ))
18 compdump:116> ((  ! --_i && 755 > 1  ))
18 compdump:116> ((  ! --_i && 753 > 1  ))
18 compdump:116> ((  ! --_i && 752 > 1  ))
18 compdump:116> ((  ! --_i && 742 > 1  ))
18 compdump:116> ((  ! --_i && 737 > 1  ))
18 compdump:116> ((  ! --_i && 736 > 1  ))
18 compdump:116> ((  ! --_i && 726 > 1  ))
18 compdump:116> ((  ! --_i && 723 > 1  ))
18 compdump:116> ((  ! --_i && 722 > 1  ))
18 compdump:116> ((  ! --_i && 717 > 1  ))
18 compdump:116> ((  ! --_i && 715 > 1  ))
18 compdump:116> ((  ! --_i && 707 > 1  ))
18 compdump:116> ((  ! --_i && 705 > 1  ))
18 compdump:116> ((  ! --_i && 702 > 1  ))
18 compdump:116> ((  ! --_i && 700 > 1  ))
18 compdump:116> ((  ! --_i && 685 > 1  ))
18 compdump:116> ((  ! --_i && 683 > 1  ))
18 compdump:116> ((  ! --_i && 682 > 1  ))
18 compdump:116> ((  ! --_i && 681 > 1  ))
18 compdump:116> ((  ! --_i && 680 > 1  ))
18 compdump:116> ((  ! --_i && 656 > 1  ))
18 compdump:116> ((  ! --_i && 653 > 1  ))
18 compdump:116> ((  ! --_i && 647 > 1  ))
18 compdump:116> ((  ! --_i && 643 > 1  ))
18 compdump:116> ((  ! --_i && 622 > 1  ))
18 compdump:116> ((  ! --_i && 618 > 1  ))
18 compdump:116> ((  ! --_i && 611 > 1  ))
18 compdump:116> ((  ! --_i && 606 > 1  ))
18 compdump:116> ((  ! --_i && 602 > 1  ))
18 compdump:116> ((  ! --_i && 597 > 1  ))
18 compdump:116> ((  ! --_i && 590 > 1  ))
18 compdump:116> ((  ! --_i && 586 > 1  ))
18 compdump:116> ((  ! --_i && 585 > 1  ))
18 compdump:116> ((  ! --_i && 580 > 1  ))
18 compdump:116> ((  ! --_i && 562 > 1  ))
18 compdump:116> ((  ! --_i && 560 > 1  ))
18 compdump:116> ((  ! --_i && 557 > 1  ))
18 compdump:116> ((  ! --_i && 547 > 1  ))
18 compdump:116> ((  ! --_i && 535 > 1  ))
18 compdump:116> ((  ! --_i && 532 > 1  ))
18 compdump:116> ((  ! --_i && 530 > 1  ))
18 compdump:116> ((  ! --_i && 528 > 1  ))
18 compdump:116> ((  ! --_i && 526 > 1  ))
18 compdump:116> ((  ! --_i && 523 > 1  ))
18 compdump:116> ((  ! --_i && 522 > 1  ))
18 compdump:116> ((  ! --_i && 517 > 1  ))
18 compdump:116> ((  ! --_i && 516 > 1  ))
18 compdump:116> ((  ! --_i && 512 > 1  ))
18 compdump:116> ((  ! --_i && 500 > 1  ))
18 compdump:116> ((  ! --_i && 491 > 1  ))
18 compdump:116> ((  ! --_i && 476 > 1  ))
18 compdump:116> ((  ! --_i && 467 > 1  ))
18 compdump:116> ((  ! --_i && 466 > 1  ))
18 compdump:116> ((  ! --_i && 465 > 1  ))
18 compdump:116> ((  ! --_i && 458 > 1  ))
18 compdump:116> ((  ! --_i && 455 > 1  ))
18 compdump:116> ((  ! --_i && 447 > 1  ))
18 compdump:116> ((  ! --_i && 436 > 1  ))
18 compdump:116> ((  ! --_i && 415 > 1  ))
18 compdump:116> ((  ! --_i && 401 > 1  ))
18 compdump:116> ((  ! --_i && 391 > 1  ))
18 compdump:116> ((  ! --_i && 365 > 1  ))
18 compdump:116> ((  ! --_i && 353 > 1  ))
18 compdump:116> ((  ! --_i && 338 > 1  ))
18 compdump:116> ((  ! --_i && 327 > 1  ))
18 compdump:116> ((  ! --_i && 321 > 1  ))
18 compdump:116> ((  ! --_i && 317 > 1  ))
18 compdump:116> ((  ! --_i && 315 > 1  ))
18 compdump:116> ((  ! --_i && 310 > 1  ))
18 compdump:116> ((  ! --_i && 283 > 1  ))
18 compdump:116> ((  ! --_i && 281 > 1  ))
18 compdump:116> ((  ! --_i && 275 > 1  ))
18 compdump:116> ((  ! --_i && 270 > 1  ))
18 compdump:116> ((  ! --_i && 260 > 1  ))
18 compdump:116> ((  ! --_i && 257 > 1  ))
18 compdump:116> ((  ! --_i && 256 > 1  ))
18 compdump:116> ((  ! --_i && 250 > 1  ))
18 compdump:116> ((  ! --_i && 247 > 1  ))
18 compdump:116> ((  ! --_i && 242 > 1  ))
18 compdump:116> ((  ! --_i && 237 > 1  ))
18 compdump:116> ((  ! --_i && 233 > 1  ))
18 compdump:116> ((  ! --_i && 222 > 1  ))
18 compdump:116> ((  ! --_i && 213 > 1  ))
18 compdump:116> ((  ! --_i && 205 > 1  ))
18 compdump:116> ((  ! --_i && 197 > 1  ))
18 compdump:116> ((  ! --_i && 178 > 1  ))
18 compdump:116> ((  ! --_i && 158 > 1  ))
18 compdump:116> ((  ! --_i && 155 > 1  ))
18 compdump:116> ((  ! --_i && 153 > 1  ))
18 compdump:116> ((  ! --_i && 128 > 1  ))
18 compdump:116> ((  ! --_i && 121 > 1  ))
18 compdump:116> ((  ! --_i && 110 > 1  ))
18 compdump:116> ((  ! --_i && 102 > 1  ))
18 compdump:116> ((  ! --_i && 101 > 1  ))
18 compdump:116> ((  ! --_i && 97 > 1  ))
18 compdump:116> ((  ! --_i && 85 > 1  ))
18 compdump:116> ((  ! --_i && 63 > 1  ))
18 compdump:116> ((  ! --_i && 6 > 1  ))
18 compdump:115> print -n ' _yarn'
18 compdump:115> print -n ' _xv'
18 compdump:115> print -n ' _xclip'
18 compdump:115> print -n ' _x_name'
18 compdump:115> print -n ' _x_colormapid'
18 compdump:115> print -n ' _wpa_cli'
18 compdump:115> print -n ' _whois'
18 compdump:115> print -n ' _wakeup_capable_devices'
18 compdump:115> print -n ' _typeset'
18 compdump:115> print -n ' _truss'
18 compdump:115> print -n ' _tpb'
18 compdump:115> print -n ' _todo.sh'
18 compdump:115> print -n ' _terminals'
18 compdump:115> print -n ' _tardy'
18 compdump:115> print -n ' _subl'
18 compdump:115> print -n ' _source'
18 compdump:115> print -n ' _showoff'
18 compdump:115> print -n ' _sh'
18 compdump:115> print -n ' _setcap'
18 compdump:115> print -n ' _scala'
18 compdump:115> print -n ' _sbuild'
18 compdump:115> print -n ' _rubocop'
18 compdump:115> print -n ' _rslsync'
18 compdump:115> print -n ' _rkt'
18 compdump:115> print -n ' _renice'
18 compdump:115> print -n ' _regex_arguments'
18 compdump:115> print -n ' _rclone'
18 compdump:115> print -n ' _qemu'
18 compdump:115> print -n ' _postgresql'
18 compdump:115> print -n ' _pkg_instance'
18 compdump:115> print -n ' _phing'
18 compdump:115> print -n ' _pgrep'
18 compdump:115> print -n ' _pdf'
18 compdump:115> print -n ' _path_commands'
18 compdump:115> print -n ' _other_accounts'
18 compdump:115> print -n ' _obsd_architectures'
18 compdump:115> print -n ' _nothing'
18 compdump:115> print -n ' _normal'
18 compdump:115> print -n ' _nbsd_architectures'
18 compdump:115> print -n ' _module_math_func'
18 compdump:115> print -n ' _mkfifo'
18 compdump:115> print -n ' _mii-tool'
18 compdump:115> print -n ' _middleman'
18 compdump:115> print -n ' _mergechanges'
18 compdump:115> print -n ' _menu'
18 compdump:115> print -n ' _mdadm'
18 compdump:115> print -n ' _md5sum'
18 compdump:115> print -n ' _matlab'
18 compdump:115> print -n ' _mail'
18 compdump:115> print -n ' _madison'
18 compdump:115> print -n ' _mac_files_for_application'
18 compdump:115> print -n ' _luarocks'
18 compdump:115> print -n ' _lspv'
18 compdump:115> print -n ' _lslv'
18 compdump:115> print -n ' _ls'
18 compdump:115> print -n ' _losetup'
18 compdump:115> print -n ' _locate'
18 compdump:115> print -n ' _lha'
18 compdump:115> print -n ' _less'
18 compdump:115> print -n ' _ldd'
18 compdump:115> print -n ' _last'
18 compdump:115> print -n ' _jobs_fg'
18 compdump:115> print -n ' _jls'
18 compdump:115> print -n ' _jexec'
18 compdump:115> print -n ' _history_modifiers'
18 compdump:115> print -n ' _gsettings'
18 compdump:115> print -n ' _groff'
18 compdump:115> print -n ' _gnu_generic'
18 compdump:115> print -n ' _git-wtf'
18 compdump:115> print -n ' _getfacl'
18 compdump:115> print -n ' _gdb'
18 compdump:115> print -n ' _functions'
18 compdump:115> print -n ' _free'
18 compdump:115> print -n ' _fmadm'
18 compdump:115> print -n ' _flowadm'
18 compdump:115> print -n ' _flac'
18 compdump:115> print -n ' _fail2ban-client'
18 compdump:115> print -n ' _echotc'
18 compdump:115> print -n ' _dumper'
18 compdump:115> print -n ' _dput'
18 compdump:115> print -n ' _dpkg-repack'
18 compdump:115> print -n ' _dpkg'
18 compdump:115> print -n ' _dos2unix'
18 compdump:115> print -n ' _directories'
18 compdump:115> print -n ' _dict'
18 compdump:115> print -n ' _dhclient'
18 compdump:115> print -n ' _debuild'
18 compdump:115> print -n ' _cygserver'
18 compdump:115> print -n ' _comp_locale'
18 compdump:115> print -n ' _command'
18 compdump:115> print -n ' _chsh'
18 compdump:115> print -n ' _chroot'
18 compdump:115> print -n ' _cache_invalid'
18 compdump:115> print -n ' _bundle'
18 compdump:115> print -n ' _bsdinstall'
18 compdump:115> print -n ' _bpython'
18 compdump:115> print -n ' _bibtex'
18 compdump:115> print -n ' _auto-apt'
18 compdump:115> print -n ' _apt-show-versions'
18 compdump:115> print -n ' _ant'
18 compdump:115> print -n ' _ansible'
18 compdump:115> print -n ' _alsa-utils'
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:114> ((  ! 0  ))
18 compdump:113> ((  1036  ))
18 compdump:113> ((  201  ))
18 compdump:91> _d_bks+=( _list_expansions )
18 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
18 compdump:85> [[ zle-line-init = _* ]]
18 compdump:85> [[ visual-mode = _* ]]
18 compdump:85> [[ vi-up-line-or-history = _* ]]
18 compdump:85> [[ vi-undo-change = _* ]]
18 compdump:85> [[ vi-swap-case = _* ]]
18 compdump:85> [[ vi-set-mark = _* ]]
18 compdump:85> [[ vi-replace = _* ]]
18 compdump:85> [[ vi-put-after = _* ]]
18 compdump:85> [[ vi-match-bracket = _* ]]
18 compdump:85> [[ vi-insert = _* ]]
18 compdump:85> [[ vi-indent = _* ]]
18 compdump:85> [[ vi-forward-word-end = _* ]]
18 compdump:85> [[ vi-forward-char = _* ]]
18 compdump:85> [[ vi-first-non-blank = _* ]]
18 compdump:85> [[ vi-find-prev-char-skip = _* ]]
18 compdump:85> [[ vi-find-prev-char = _* ]]
18 compdump:85> [[ vi-find-next-char = _* ]]
18 compdump:85> [[ vi-down-case = _* ]]
18 compdump:85> [[ vi-delete-char = _* ]]
18 compdump:85> [[ vi-caps-lock-panic = _* ]]
18 compdump:85> [[ up-line-or-search = _* ]]
18 compdump:85> [[ up-case-word = _* ]]
18 compdump:85> [[ undo = _* ]]
18 compdump:85> [[ undefined-key = _* ]]
18 compdump:85> [[ transpose-words = _* ]]
18 compdump:85> [[ split-undo = _* ]]
18 compdump:85> [[ self-insert = _* ]]
18 compdump:85> [[ redo = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-menu-complete = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-list-choices = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-_history-complete-older = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-_history-complete-newer = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-_correct_filename = _* ]]
18 compdump:85> [[ orig-s0.0000080000-r6249-_complete_debug = _* ]]
18 compdump:85> [[ fasd-complete = _* ]]
18 compdump:85> [[ expand-cmd-path = _* ]]
18 compdump:85> [[ end-of-line-hist = _* ]]
18 compdump:85> [[ end-of-line = _* ]]
18 compdump:85> [[ down-line-or-history = _* ]]
18 compdump:85> [[ down-line = _* ]]
18 compdump:85> [[ down-history = _* ]]
18 compdump:85> [[ digit-argument = _* ]]
18 compdump:85> [[ copy-prev-shell-word = _* ]]
18 compdump:85> [[ complete-word = _* ]]
18 compdump:85> [[ beginning-of-history = _* ]]
18 compdump:85> [[ backward-word = _* ]]
18 compdump:85> [[ backward-kill-word = _* ]]
18 compdump:85> [[ backward-kill-line = _* ]]
18 compdump:85> [[ autosuggest-capture-completion = _* ]]
18 compdump:85> [[ autosuggest-accept = _* ]]
18 compdump:85> [[ accept-and-hold = _* ]]
18 compdump:62> _d_f=(ruby|[ei]rb)[0-9.]#
18 compdump:50> print -r - ''svnlite'' ''svn''
18 compdump:50> print -r - ''pcat'' ''unpack''
18 compdump:50> print -r - ''nail'' ''mail''
18 compdump:44> print -r - ''zstat'' ''_stat''
18 compdump:44> print -r - ''zsetattr'' ''_zattr''
18 compdump:44> print -r - ''zpty'' ''_zpty''
18 compdump:44> print -r - ''zmodload'' ''_zmodload''
18 compdump:44> print -r - ''zmail'' ''_mail''
18 compdump:44> print -r - ''zipinfo'' ''_zip''
18 compdump:44> print -r - ''zip'' ''_zip''
18 compdump:44> print -r - ''zf_rmdir'' ''_rmdir''
18 compdump:44> print -r - ''zf_chown'' ''_chown''
18 compdump:44> print -r - ''zed'' ''_zed''
18 compdump:44> print -r - ''zeal'' ''_zeal''
18 compdump:44> print -r - ''zcat'' ''_zcat''
18 compdump:44> print -r - ''yum'' ''_yum''
18 compdump:44> print -r - ''ypserv'' ''_yp''
18 compdump:44> print -r - ''ypbind'' ''_yp''
18 compdump:44> print -r - ''xz'' ''_xz''
18 compdump:44> print -r - ''xxd'' ''_xxd''
18 compdump:44> print -r - ''xvncviewer'' ''_vnc''
18 compdump:44> print -r - ''xvnc4viewer'' ''_vnc''
18 compdump:44> print -r - ''xtightvncviewer'' ''_vnc''
18 compdump:44> print -r - ''xrdb'' ''_x_utils''
18 compdump:44> print -r - ''xournal'' ''_xournal''
18 compdump:44> print -r - ''xmms2'' ''_xmms2''
18 compdump:44> print -r - ''xmlstarlet'' ''_xmlstarlet''
18 compdump:44> print -r - ''xmllint'' ''_xmlsoft''
18 compdump:44> print -r - ''xml'' ''_xmlstarlet''
18 compdump:44> print -r - ''xfreerdp'' ''_rdesktop''
18 compdump:44> print -r - ''xetex'' ''_tex''
18 compdump:44> print -r - ''xelatex'' ''_tex''
18 compdump:44> print -r - ''xclip'' ''_xclip''
18 compdump:44> print -r - ''www'' ''_webbrowser''
18 compdump:44> print -r - ''write'' ''_users_on''
18 compdump:44> print -r - ''whom'' ''_mh''
18 compdump:44> print -r - ''which'' ''_which''
18 compdump:44> print -r - ''whereis'' ''_whereis''
18 compdump:44> print -r - ''wg-quick'' ''_wg-quick''
18 compdump:44> print -r - ''watch'' ''_watch''
18 compdump:44> print -r - ''vorbiscomment'' ''_vorbis''
18 compdump:44> print -r - ''vmstat'' ''_vmstat''
18 compdump:44> print -r - ''vmctl'' ''_vmctl''
18 compdump:44> print -r - ''uscan'' ''_uscan''
18 compdump:44> print -r - ''urxvtc'' ''_urxvt''
18 compdump:44> print -r - ''urxvt256c'' ''_urxvt''
18 compdump:44> print -r - ''urpme'' ''_urpmi''
18 compdump:44> print -r - ''unxz'' ''_xz''
18 compdump:44> print -r - ''unpigz'' ''_gzip''
18 compdump:44> print -r - ''unpack'' ''_pack''
18 compdump:44> print -r - ''unlzma'' ''_xz''
18 compdump:44> print -r - ''unix2dos'' ''_dos2unix''
18 compdump:44> print -r - ''unget'' ''_sccs''
18 compdump:44> print -r - ''unalias'' ''_aliases''
18 compdump:44> print -r - ''ufw'' ''_ufw''
18 compdump:44> print -r - ''tunes2pod.pl'' ''_gnupod''
18 compdump:44> print -r - ''tunes2pod'' ''_gnupod''
18 compdump:44> print -r - ''tty'' ''_tty''
18 compdump:44> print -r - ''tox'' ''_tox''
18 compdump:44> print -r - ''touch'' ''_touch''
18 compdump:44> print -r - ''todo.sh'' ''_todo.sh''
18 compdump:44> print -r - ''todo'' ''_devtodo''
18 compdump:44> print -r - ''tmuxp'' ''_tmuxp''
18 compdump:44> print -r - ''tla'' ''_tla''
18 compdump:44> print -r - ''tkinfo'' ''_texinfo''
18 compdump:44> print -r - ''tidy'' ''_tidy''
18 compdump:44> print -r - ''tdr'' ''_devtodo''
18 compdump:44> print -r - ''tail'' ''_tail''
18 compdump:44> print -r - ''swiftc'' ''_swift''
18 compdump:44> print -r - ''swift'' ''_swift''
18 compdump:44> print -r - ''sudoedit'' ''_sudo''
18 compdump:44> print -r - ''stty'' ''_stty''
18 compdump:44> print -r - ''strftime'' ''_strftime''
18 compdump:44> print -r - ''stg'' ''_stgit''
18 compdump:44> print -r - ''stdbuf'' ''_stdbuf''
18 compdump:44> print -r - ''stack'' ''_stack''
18 compdump:44> print -r - ''srptool'' ''_gnutls''
18 compdump:44> print -r - ''sr'' ''_surfraw''
18 compdump:44> print -r - ''sqlite3'' ''_sqlite''
18 compdump:44> print -r - ''snoop'' ''_snoop''
18 compdump:44> print -r - ''smbcontrol'' ''_samba''
18 compdump:44> print -r - ''smbclient'' ''_samba''
18 compdump:44> print -r - ''slogin'' ''_ssh''
18 compdump:44> print -r - ''signify'' ''_signify''
18 compdump:44> print -r - ''shred'' ''_shred''
18 compdump:44> print -r - ''show'' ''_mh''
18 compdump:44> print -r - ''sftp'' ''_ssh''
18 compdump:44> print -r - ''sfdx'' ''_sfdx''
18 compdump:44> print -r - ''setsid'' ''_setsid''
18 compdump:44> print -r - ''setopt'' ''_setopt''
18 compdump:44> print -r - ''setcap'' ''_setcap''
18 compdump:44> print -r - ''seaf-cli'' ''_seafile''
18 compdump:44> print -r - ''scrub'' ''_scrub''
18 compdump:44> print -r - ''scriptreplay'' ''_script''
18 compdump:44> print -r - ''sccs'' ''_sccs''
18 compdump:44> print -r - ''scan'' ''_mh''
18 compdump:44> print -r - ''sbuild'' ''_sbuild''
18 compdump:44> print -r - ''sar'' ''_sysstat''
18 compdump:44> print -r - ''s2p'' ''_sed''
18 compdump:44> print -r - ''rxvt'' ''_urxvt''
18 compdump:44> print -r - ''rubocop'' ''_rubocop''
18 compdump:44> print -r - ''rpmsign'' ''_rpm''
18 compdump:44> print -r - ''rpmquery'' ''_rpm''
18 compdump:44> print -r - ''rpmkeys'' ''_rpm''
18 compdump:44> print -r - ''rpmbuild'' ''_rpm''
18 compdump:44> print -r - ''rpm'' ''_rpm''
18 compdump:44> print -r - ''route'' ''_route''
18 compdump:44> print -r - ''rmmod'' ''_modutils''
18 compdump:44> print -r - ''rmm'' ''_mh''
18 compdump:44> print -r - ''rmiregistry'' ''_java''
18 compdump:44> print -r - ''rmic'' ''_java''
18 compdump:44> print -r - ''rmf'' ''_mh''
18 compdump:44> print -r - ''rmdir'' ''_rmdir''
18 compdump:44> print -r - ''reprepro'' ''_reprepro''
18 compdump:44> print -r - ''remsh'' ''_rlogin''
18 compdump:44> print -r - ''rehash'' ''_hash''
18 compdump:44> print -r - ''rec'' ''_redis-cli''
18 compdump:44> print -r - ''readshortcut.exe'' ''_readshortcut''
18 compdump:44> print -r - ''readelf'' ''_readelf''
18 compdump:44> print -r - ''read'' ''_read''
18 compdump:44> print -r - ''rcp'' ''_rlogin''
18 compdump:44> print -r - ''r'' ''_fc''
18 compdump:44> print -r - ''quilt'' ''_quilt''
18 compdump:44> print -r - ''qdbus'' ''_qdbus''
18 compdump:44> print -r - ''pwgen'' ''_pwgen''
18 compdump:44> print -r - ''pwdx'' ''_pids''
18 compdump:44> print -r - ''putclip'' ''_putclip''
18 compdump:44> print -r - ''pstotgif'' ''_pspdf''
18 compdump:44> print -r - ''pstack'' ''_pids''
18 compdump:44> print -r - ''ps2pdf13'' ''_postscript''
18 compdump:44> print -r - ''ps2epsi'' ''_postscript''
18 compdump:44> print -r - ''prstat'' ''_prstat''
18 compdump:44> print -r - ''prev'' ''_mh''
18 compdump:44> print -r - ''postmaster'' ''_postgresql''
18 compdump:44> print -r - ''postgres'' ''_postgresql''
18 compdump:44> print -r - ''postconf'' ''_postfix''
18 compdump:44> print -r - ''portaudit'' ''_portaudit''
18 compdump:44> print -r - ''pon'' ''_pon''
18 compdump:44> print -r - ''pmpath'' ''_perl_modules''
18 compdump:44> print -r - ''pmls'' ''_perl_modules''
18 compdump:44> print -r - ''pmcat'' ''_perl_modules''
18 compdump:44> print -r - ''pmake'' ''_make''
18 compdump:44> print -r - ''pm2'' ''_pm2''
18 compdump:44> print -r - ''pkgtool'' ''_pkgtool''
18 compdump:44> print -r - ''pkgin'' ''_pkgin''
18 compdump:44> print -r - ''pkg_create'' ''_bsd_pkg''
18 compdump:44> print -r - ''pkg'' ''_pkg5''
18 compdump:44> print -r - ''pkcon'' ''_pkcon''
18 compdump:44> print -r - ''ping6'' ''_ping''
18 compdump:44> print -r - ''pine'' ''_pine''
18 compdump:44> print -r - ''pick'' ''_mh''
18 compdump:44> print -r - ''pg_upgrade'' ''_postgresql''
18 compdump:44> print -r - ''pdftotext'' ''_pdf''
18 compdump:44> print -r - ''pdftops'' ''_pdf''
18 compdump:44> print -r - ''pdftex'' ''_tex''
18 compdump:44> print -r - ''pdfinfo'' ''_pdf''
18 compdump:44> print -r - ''pdf2dsc'' ''_pdf''
18 compdump:44> print -r - ''pbpaste'' ''_pbcopy''
18 compdump:44> print -r - ''patch'' ''_patch''
18 compdump:44> print -r - ''paste'' ''_paste''
18 compdump:44> print -r - ''p4d'' ''_perforce''
18 compdump:44> print -r - ''osascript'' ''_osascript''
18 compdump:44> print -r - ''optirun'' ''_optirun''
18 compdump:44> print -r - ''omz'' ''_omz''
18 compdump:44> print -r - ''oggenc'' ''_vorbis''
18 compdump:44> print -r - ''oggdec'' ''_vorbis''
18 compdump:44> print -r - ''odmget'' ''_object_classes''
18 compdump:44> print -r - ''noglob'' ''_precommand''
18 compdump:44> print -r - ''nm'' ''_nm''
18 compdump:44> print -r - ''nl'' ''_nl''
18 compdump:44> print -r - ''ninja'' ''_ninja''
18 compdump:44> print -r - ''nft'' ''_nftables''
18 compdump:44> print -r - ''next'' ''_mh''
18 compdump:44> print -r - ''neutron'' ''_openstack''
18 compdump:44> print -r - ''nedit-nc'' ''_nedit''
18 compdump:44> print -r - ''ncal'' ''_cal''
18 compdump:44> print -r - ''nail'' ''_mail''
18 compdump:44> print -r - ''mysql'' ''_mysql_utils''
18 compdump:44> print -r - ''mvim'' ''_vim''
18 compdump:44> print -r - ''mussh'' ''_mussh''
18 compdump:44> print -r - ''mush'' ''_mail''
18 compdump:44> print -r - ''mren'' ''_mtools''
18 compdump:44> print -r - ''mpv'' ''_mpv''
18 compdump:44> print -r - ''mpc'' ''_mpc''
18 compdump:44> print -r - ''mogrify'' ''_imagemagick''
18 compdump:44> print -r - ''module-assistant'' ''_module-assistant''
18 compdump:44> print -r - ''modinfo'' ''_modutils''
18 compdump:44> print -r - ''mmove'' ''_mtools''
18 compdump:44> print -r - ''mmount'' ''_mtools''
18 compdump:44> print -r - ''mkshortcut.exe'' ''_mkshortcut''
18 compdump:44> print -r - ''mkfifo'' ''_mkfifo''
18 compdump:44> print -r - ''mixerctl'' ''_mixerctl''
18 compdump:44> print -r - ''mix'' ''_mix''
18 compdump:44> print -r - ''mistral'' ''_openstack''
18 compdump:44> print -r - ''metaflac'' ''_flac''
18 compdump:44> print -r - ''meson'' ''_meson''
18 compdump:44> print -r - ''mdir'' ''_mtools''
18 compdump:44> print -r - ''mdfind'' ''_mdfind''
18 compdump:44> print -r - ''mdel'' ''_mtools''
18 compdump:44> print -r - ''md5sum'' ''_md5sum''
18 compdump:44> print -r - ''makeinfo'' ''_texinfo''
18 compdump:44> print -r - ''magnum'' ''_openstack''
18 compdump:44> print -r - ''madison'' ''_madison''
18 compdump:44> print -r - ''lsblk'' ''_lsblk''
18 compdump:44> print -r - ''lsattr'' ''_lsattr''
18 compdump:44> print -r - ''ls'' ''_ls''
18 compdump:44> print -r - ''lpstat'' ''_lp''
18 compdump:44> print -r - ''lprm'' ''_lp''
18 compdump:44> print -r - ''lpr'' ''_lp''
18 compdump:44> print -r - ''losetup'' ''_losetup''
18 compdump:44> print -r - ''llvm-otool'' ''_otool''
18 compdump:44> print -r - ''llvm-objdump'' ''_objdump''
18 compdump:44> print -r - ''less'' ''_less''
18 compdump:44> print -r - ''ldap'' ''_ldap''
18 compdump:44> print -r - ''kpartx'' ''_kpartx''
18 compdump:44> print -r - ''knock'' ''_knock''
18 compdump:44> print -r - ''knife'' ''_knife''
18 compdump:44> print -r - ''kldunload'' ''_kld''
18 compdump:44> print -r - ''killall'' ''_killall''
18 compdump:44> print -r - ''kill'' ''_kill''
18 compdump:44> print -r - ''kfmclient'' ''_kfmclient''
18 compdump:44> print -r - ''jobs'' ''_jobs_builtin''
18 compdump:44> print -r - ''jadetex'' ''_tex''
18 compdump:44> print -r - ''iwconfig'' ''_iwconfig''
18 compdump:44> print -r - ''iptables'' ''_iptables''
18 compdump:44> print -r - ''ip6tables'' ''_iptables''
18 compdump:44> print -r - ''installpkg'' ''_pkgtool''
18 compdump:44> print -r - ''infocmp'' ''_terminals''
18 compdump:44> print -r - ''ijoin'' ''_ispell''
18 compdump:44> print -r - ''ifup'' ''_net_interfaces''
18 compdump:44> print -r - ''iftop'' ''_iftop''
18 compdump:44> print -r - ''icombine'' ''_ispell''
18 compdump:44> print -r - ''iceweasel'' ''_mozilla''
18 compdump:44> print -r - ''homestead'' ''_homestead''
18 compdump:44> print -r - ''heat'' ''_openstack''
18 compdump:44> print -r - ''gzip'' ''_gzip''
18 compdump:44> print -r - ''gzilla'' ''_webbrowser''
18 compdump:44> print -r - ''gvimdiff'' ''_vim''
18 compdump:44> print -r - ''gvim'' ''_vim''
18 compdump:44> print -r - ''guilt-unapplied'' ''_guilt''
18 compdump:44> print -r - ''guilt-push'' ''_guilt''
18 compdump:44> print -r - ''guilt-init'' ''_guilt''
18 compdump:44> print -r - ''guilt-import'' ''_guilt''
18 compdump:44> print -r - ''guilt-help'' ''_guilt''
18 compdump:44> print -r - ''guilt-header'' ''_guilt''
18 compdump:44> print -r - ''guilt-applied'' ''_guilt''
18 compdump:44> print -r - ''gtar'' ''_tar''
18 compdump:44> print -r - ''gstty'' ''_stty''
18 compdump:44> print -r - ''gstat'' ''_gstat''
18 compdump:44> print -r - ''gslp'' ''_pspdf''
18 compdump:44> print -r - ''gsha384sum'' ''_md5sum''
18 compdump:44> print -r - ''gseq'' ''_seq''
18 compdump:44> print -r - ''gsdj'' ''_pspdf''
18 compdump:44> print -r - ''gsbj'' ''_pspdf''
18 compdump:44> print -r - ''growisofs'' ''_growisofs''
18 compdump:44> print -r - ''gpgv'' ''_gpg''
18 compdump:44> print -r - ''gpatch'' ''_patch''
18 compdump:44> print -r - ''god'' ''_od''
18 compdump:44> print -r - ''gmknod'' ''_mknod''
18 compdump:44> print -r - ''gln'' ''_ln''
18 compdump:44> print -r - ''git-buildpackage'' ''_git-buildpackage''
18 compdump:44> print -r - ''gh'' ''_gh''
18 compdump:44> print -r - ''ggl'' ''_git''
18 compdump:44> print -r - ''getopts'' ''_vars''
18 compdump:44> print -r - ''getfacl'' ''_getfacl''
18 compdump:44> print -r - ''getconf'' ''_getconf''
18 compdump:44> print -r - ''gem'' ''_gem''
18 compdump:44> print -r - ''gdv'' ''_git''
18 compdump:44> print -r - ''gdiff'' ''_diff''
18 compdump:44> print -r - ''gcp'' ''_cp''
18 compdump:44> print -r - ''gccgo'' ''_go''
18 compdump:44> print -r - ''gcat'' ''_cat''
18 compdump:44> print -r - ''fmt'' ''_fmt''
18 compdump:44> print -r - ''flowadm'' ''_flowadm''
18 compdump:44> print -r - ''finger'' ''_finger''
18 compdump:44> print -r - ''fg'' ''_jobs_fg''
18 compdump:44> print -r - ''extcheck'' ''_java''
18 compdump:44> print -r - ''evim'' ''_vim''
18 compdump:44> print -r - ''eview'' ''_vim''
18 compdump:44> print -r - ''eu-objdump'' ''_objdump''
18 compdump:44> print -r - ''eu-nm'' ''_nm''
18 compdump:44> print -r - ''ethtool'' ''_ethtool''
18 compdump:44> print -r - ''erb'' ''_ruby''
18 compdump:44> print -r - ''envdir'' ''_envdir''
18 compdump:44> print -r - ''ed'' ''_ed''
18 compdump:44> print -r - ''dvidvi'' ''_dvi''
18 compdump:44> print -r - ''dvibook'' ''_dvi''
18 compdump:44> print -r - ''du'' ''_du''
18 compdump:44> print -r - ''drill'' ''_drill''
18 compdump:44> print -r - ''dput'' ''_dput''
18 compdump:44> print -r - ''dos2unix'' ''_dos2unix''
18 compdump:44> print -r - ''docker-compose'' ''_docker-compose''
18 compdump:44> print -r - ''dnf-2'' ''_dnf''
18 compdump:44> print -r - ''dnf'' ''_dnf''
18 compdump:44> print -r - ''dmake'' ''_make''
18 compdump:44> print -r - ''dist'' ''_mh''
18 compdump:44> print -r - ''disable'' ''_disable''
18 compdump:44> print -r - ''dirs'' ''_dirs''
18 compdump:44> print -r - ''df'' ''_df''
18 compdump:44> print -r - ''dd'' ''_dd''
18 compdump:44> print -r - ''dchroot-dsa'' ''_dchroot-dsa''
18 compdump:44> print -r - ''dbus-send'' ''_dbus''
18 compdump:44> print -r - ''date'' ''_date''
18 compdump:44> print -r - ''csup'' ''_csup''
18 compdump:44> print -r - ''cscope'' ''_cscope''
18 compdump:44> print -r - ''cpio'' ''_cpio''
18 compdump:44> print -r - ''conch'' ''_twisted''
18 compdump:44> print -r - ''comb'' ''_sccs''
18 compdump:44> print -r - ''column'' ''_column''
18 compdump:44> print -r - ''cmake'' ''_cmake''
18 compdump:44> print -r - ''clear'' ''_nothing''
18 compdump:44> print -r - ''clang'' ''_gcc''
18 compdump:44> print -r - ''ci'' ''_rcs''
18 compdump:44> print -r - ''chmod'' ''_chmod''
18 compdump:44> print -r - ''chflags'' ''_chflags''
18 compdump:44> print -r - ''cf'' ''_cf''
18 compdump:44> print -r - ''cdr'' ''_cdr''
18 compdump:44> print -r - ''cdcd'' ''_cdcd''
18 compdump:44> print -r - ''cd'' ''_cd''
18 compdump:44> print -r - ''calendar'' ''_calendar''
18 compdump:44> print -r - ''bzfgrep'' ''_grep''
18 compdump:44> print -r - ''btshowmetainfo'' ''_bittorrent''
18 compdump:44> print -r - ''bts'' ''_bts''
18 compdump:44> print -r - ''bpython-gtk'' ''_bpython''
18 compdump:44> print -r - ''beep'' ''_beep''
18 compdump:44> print -r - ''baz'' ''_baz''
18 compdump:44> print -r - ''augtool'' ''_augeas''
18 compdump:44> print -r - ''atq'' ''_at''
18 compdump:44> print -r - ''arena'' ''_webbrowser''
18 compdump:44> print -r - ''apt-mark'' ''_apt''
18 compdump:44> print -r - ''apt-cache'' ''_apt''
18 compdump:43> _d_f=umount
18 compdump:43> _d_f=pigz
18 compdump:43> _d_f=gsha384sum
18 compdump:43> _d_f=git-buildpackage
18 compdump:43> _d_f=filterdiff
18 compdump:43> _d_f=diff3
18 compdump:43> _d_f=cygrunsrv
18 compdump:43> _d_f=apropos
18 compdump:43> _d_f=-value-,PROMPT4,-default-
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:169> shift
18 compdef:164> _services[$cmd]=unxz
18 compdef:164> [[ -n '' ]]
18 compdef:163> _comps[$cmd]=_yaourt
18 compdef:163> _comps[$cmd]=_gzip
18 compdef:163> _comps[$cmd]=_git
18 compdef:162> [[ -z yes || -z _zip ]]
18 compdef:162> [[ -z yes || -z _xterm ]]
18 compdef:162> [[ -z yes || -z _xrandr ]]
18 compdef:162> [[ -z yes || -z _xmms2 ]]
18 compdef:162> [[ -z yes || -z _x_utils ]]
18 compdef:162> [[ -z yes || -z _x_utils ]]
18 compdef:162> [[ -z yes || -z _x_utils ]]
18 compdef:162> [[ -z yes || -z _x_utils ]]
18 compdef:162> [[ -z yes || -z _x_utils ]]
18 compdef:162> [[ -z yes || -z _whereis ]]
18 compdef:162> [[ -z yes || -z _webbrowser ]]
18 compdef:162> [[ -z yes || -z _webbrowser ]]
18 compdef:162> [[ -z yes || -z _webbrowser ]]
18 compdef:162> [[ -z yes || -z _webbrowser ]]
18 compdef:162> [[ -z yes || -z _wc ]]
18 compdef:162> [[ -z yes || -z _vorbis ]]
18 compdef:162> [[ -z yes || -z _users ]]
18 compdef:162> [[ -z yes || -z _user_admin ]]
18 compdef:162> [[ -z yes || -z _user_admin ]]
18 compdef:162> [[ -z yes || -z _unhash ]]
18 compdef:162> [[ -z yes || -z _unexpand ]]
18 compdef:162> [[ -z yes || -z _uml ]]
18 compdef:162> [[ -z yes || -z _typeset ]]
18 compdef:162> [[ -z yes || -z _twisted ]]
18 compdef:162> [[ -z yes || -z _tty ]]
18 compdef:162> [[ -z yes || -z _trash ]]
18 compdef:162> [[ -z yes || -z _tr ]]
18 compdef:162> [[ -z yes || -z _totd ]]
18 compdef:162> [[ -z yes || -z _todo.sh ]]
18 compdef:162> [[ -z yes || -z _tidy ]]
18 compdef:162> [[ -z yes || -z _terminals ]]
18 compdef:162> [[ -z yes || -z _tcptraceroute ]]
18 compdef:162> [[ -z yes || -z _tcpdump ]]
18 compdef:162> [[ -z yes || -z _tar ]]
18 compdef:162> [[ -z yes || -z _svcs ]]
18 compdef:162> [[ -z yes || -z _strings ]]
18 compdef:162> [[ -z yes || -z _split ]]
18 compdef:162> [[ -z yes || -z _source ]]
18 compdef:162> [[ -z yes || -z _shutdown ]]
18 compdef:162> [[ -z yes || -z _setopt ]]
18 compdef:162> [[ -z yes || -z _seafile ]]
18 compdef:162> [[ -z yes || -z _schedtool ]]
18 compdef:162> [[ -z yes || -z _savecore ]]
18 compdef:162> [[ -z yes || -z _rm ]]
18 compdef:162> [[ -z yes || -z _readlink ]]
18 compdef:162> [[ -z yes || -z _read ]]
18 compdef:162> [[ -z yes || -z _ranlib ]]
18 compdef:162> [[ -z yes || -z _qiv ]]
18 compdef:162> [[ -z yes || -z _pv ]]
18 compdef:162> [[ -z yes || -z _psutils ]]
18 compdef:162> [[ -z yes || -z _pscp ]]
18 compdef:162> [[ -z yes || -z _ps1234 ]]
18 compdef:162> [[ -z yes || -z _prove ]]
18 compdef:162> [[ -z yes || -z _procstat ]]
18 compdef:162> [[ -z yes || -z _precommand ]]
18 compdef:162> [[ -z yes || -z _postscript ]]
18 compdef:162> [[ -z yes || -z _postscript ]]
18 compdef:162> [[ -z yes || -z _postgresql ]]
18 compdef:162> [[ -z yes || -z _postgresql ]]
18 compdef:162> [[ -z yes || -z _pine ]]
18 compdef:162> [[ -z yes || -z _pids ]]
18 compdef:162> [[ -z yes || -z _php ]]
18 compdef:162> [[ -z yes || -z _perl_modules ]]
18 compdef:162> [[ -z yes || -z _perl_modules ]]
18 compdef:162> [[ -z yes || -z _perl_modules ]]
18 compdef:162> [[ -z yes || -z _perforce ]]
18 compdef:162> [[ -z yes || -z _pdftk ]]
18 compdef:162> [[ -z yes || -z _pdf ]]
18 compdef:162> [[ -z yes || -z _pdf ]]
18 compdef:162> [[ -z yes || -z _pbcopy ]]
18 compdef:162> [[ -z yes || -z _osc ]]
18 compdef:162> [[ -z yes || -z _osascript ]]
18 compdef:162> [[ -z yes || -z _openstack ]]
18 compdef:162> [[ -z yes || -z _openstack ]]
18 compdef:162> [[ -z yes || -z _openstack ]]
18 compdef:162> [[ -z yes || -z _nothing ]]
18 compdef:162> [[ -z yes || -z _nothing ]]
18 compdef:162> [[ -z yes || -z _nothing ]]
18 compdef:162> [[ -z yes || -z _nothing ]]
18 compdef:162> [[ -z yes || -z _normal ]]
18 compdef:162> [[ -z yes || -z _mysql_utils ]]
18 compdef:162> [[ -z yes || -z _mysql_utils ]]
18 compdef:162> [[ -z yes || -z _mutt ]]
18 compdef:162> [[ -z yes || -z _mtr ]]
18 compdef:162> [[ -z yes || -z _mtools ]]
18 compdef:162> [[ -z yes || -z _mplayer ]]
18 compdef:162> [[ -z yes || -z _monotone ]]
18 compdef:162> [[ -z yes || -z _modutils ]]
18 compdef:162> [[ -z yes || -z _modutils ]]
18 compdef:162> [[ -z yes || -z _mh ]]
18 compdef:162> [[ -z yes || -z _mh ]]
18 compdef:162> [[ -z yes || -z _mh ]]
18 compdef:162> [[ -z yes || -z _mencal ]]
18 compdef:162> [[ -z yes || -z _md5sum ]]
18 compdef:162> [[ -z yes || -z _make ]]
18 compdef:162> [[ -z yes || -z _mail ]]
18 compdef:162> [[ -z yes || -z _lp ]]
18 compdef:162> [[ -z yes || -z _links ]]
18 compdef:162> [[ -z yes || -z _limit ]]
18 compdef:162> [[ -z yes || -z _libvirt ]]
18 compdef:162> [[ -z yes || -z _libvirt ]]
18 compdef:162> [[ -z yes || -z _less ]]
18 compdef:162> [[ -z yes || -z _kld ]]
18 compdef:162> [[ -z yes || -z _killall ]]
18 compdef:162> [[ -z yes || -z _jonas ]]
18 compdef:162> [[ -z yes || -z _joe ]]
18 compdef:162> [[ -z yes || -z _ispell ]]
18 compdef:162> [[ -z yes || -z _ispell ]]
18 compdef:162> [[ -z yes || -z _iptables ]]
18 compdef:162> [[ -z yes || -z _ipset ]]
18 compdef:162> [[ -z yes || -z _invoke-rc.d ]]
18 compdef:162> [[ -z yes || -z _initctl ]]
18 compdef:162> [[ -z yes || -z _in_vared ]]
18 compdef:162> [[ -z yes || -z _imagemagick ]]
18 compdef:162> [[ -z yes || -z _imagemagick ]]
18 compdef:162> [[ -z yes || -z _iconv ]]
18 compdef:162> [[ -z yes || -z _hwinfo ]]
18 compdef:162> [[ -z yes || -z _hosts ]]
18 compdef:162> [[ -z yes || -z _head ]]
18 compdef:162> [[ -z yes || -z _guilt ]]
18 compdef:162> [[ -z yes || -z _guilt ]]
18 compdef:162> [[ -z yes || -z _guilt ]]
18 compdef:162> [[ -z yes || -z _guilt ]]
18 compdef:162> [[ -z yes || -z _gradle ]]
18 compdef:162> [[ -z yes || -z _gpasswd ]]
18 compdef:162> [[ -z yes || -z _go ]]
18 compdef:162> [[ -z yes || -z _gnutls ]]
18 compdef:162> [[ -z yes || -z _git-revise ]]
18 compdef:162> [[ -z yes || -z _gem ]]
18 compdef:162> [[ -z yes || -z _fwupdmgr ]]
18 compdef:162> [[ -z yes || -z _fc ]]
18 compdef:162> [[ -z yes || -z _dvi ]]
18 compdef:162> [[ -z yes || -z _dvi ]]
18 compdef:162> [[ -z yes || -z _dvc ]]
18 compdef:162> [[ -z yes || -z _dcop ]]
18 compdef:162> [[ -z yes || -z _cp ]]
18 compdef:162> [[ -z yes || -z _coffee ]]
18 compdef:162> [[ -z yes || -z _cockroach ]]
18 compdef:162> [[ -z yes || -z _cksum ]]
18 compdef:162> [[ -z yes || -z _cksum ]]
18 compdef:162> [[ -z yes || -z _bsd_pkg ]]
18 compdef:162> [[ -z yes || -z _bogofilter ]]
18 compdef:162> [[ -z yes || -z _bittorrent ]]
18 compdef:162> [[ -z yes || -z _beep ]]
18 compdef:162> [[ -z yes || -z _beadm ]]
18 compdef:162> [[ -z yes || -z _base64 ]]
18 compdef:162> [[ -z yes || -z _augeas ]]
18 compdef:162> [[ -z yes || -z _attr ]]
18 compdef:162> [[ -z yes || -z _apt ]]
18 compdef:162> [[ -z yes || -z _apt ]]
18 compdef:162> [[ -z yes || -z _apt ]]
18 compdef:162> [[ -z yes || -z _ansible ]]
18 compdef:162> [[ -z yes || -z _ansible ]]
18 compdef:162> [[ -z yes || -z _acroread ]]
18 compdef:162> [[ -z yes || -z _SUSEconfig ]]
18 compdef:162> [[ -z yes || -z '' ]]
18 compdef:160> svc=''
18 compdef:160> svc=''
18 compdef:159> cmd=rclone
18 compdef:159> cmd=debdiff
18 compdef:155> [[ zypper = *=* ]]
18 compdef:155> [[ zstyle = *=* ]]
18 compdef:155> [[ zsh = *=* ]]
18 compdef:155> [[ yt-dlp = *=* ]]
18 compdef:155> [[ xxd = *=* ]]
18 compdef:155> [[ stdbuf = *=* ]]
18 compdef:155> [[ rubocop = *=* ]]
18 compdef:155> [[ lighty-enable-mod = *=* ]]
18 compdef:155> [[ gsettings = *=* ]]
18 compdef:155> [[ dvips = *=* ]]
18 compdef:155> [[ dumper = *=* ]]
18 compdef:155> [[ dput = *=* ]]
18 compdef:155> [[ dpkg-repack = *=* ]]
18 compdef:155> [[ debcheckout = *=* ]]
18 compdef:155> [[ dcut = *=* ]]
18 compdef:155> [[ chmod = *=* ]]
18 compdef:155> [[ chflags = *=* ]]
18 compdef:155> [[ chattr = *=* ]]
18 compdef:155> [[ cdrecord = *=* ]]
18 compdef:155> [[ cabal = *=* ]]
18 compdef:155> [[ a2ps = *=* ]]
18 compdef:155> [[ -default- = *=* ]]
18 compdef:151> _postpatcomps[$1]=_ruby
18 compdef:151> _postpatcomps[$1]=_php
18 compdef:151> _postpatcomps[$1]=_golang
18 compdef:141> [[ '*/(init|rc[0-9S]#).d/*' = (#b)(*)=(*) ]]
18 compdef:139> case  (postpattern)
18 compdef:139> case  (pattern)
18 compdef:137> type=postpattern
18 compdef:136> [[ swanctl = -P ]]
18 compdef:136> [[ pidstat = -P ]]
18 compdef:136> [[ ltrace = -P ]]
18 compdef:136> [[ ksh88 = -P ]]
18 compdef:136> [[ git-pulls = -P ]]
18 compdef:136> [[ delta = -P ]]
18 compdef:136> [[ cssh = -P ]]
18 compdef:136> [[ clear = -P ]]
18 compdef:136> [[ '_git_log_prettily=git-log' = -P ]]
18 compdef:134> [[ xml = -p ]]
18 compdef:134> [[ scl = -p ]]
18 compdef:134> [[ readshortcut.exe = -p ]]
18 compdef:134> [[ ltrace = -p ]]
18 compdef:134> [[ groupdel = -p ]]
18 compdef:134> [[ ethtool = -p ]]
18 compdef:134> [[ 'gchown=chown' = -p ]]
18 compdef:132> [[ zoneadm = -N ]]
18 compdef:132> [[ zmv = -N ]]
18 compdef:132> [[ zed = -N ]]
18 compdef:132> [[ zcalc = -N ]]
18 compdef:132> [[ zargs = -N ]]
18 compdef:132> [[ yaourt = -N ]]
18 compdef:132> [[ wipefs = -N ]]
18 compdef:132> [[ valgrind = -N ]]
18 compdef:132> [[ update-alternatives = -N ]]
18 compdef:132> [[ unison = -N ]]
18 compdef:132> [[ uniq = -N ]]
18 compdef:132> [[ unfunction = -N ]]
18 compdef:132> [[ uml_switch = -N ]]
18 compdef:132> [[ tr = -N ]]
18 compdef:132> [[ tar = -N ]]
18 compdef:132> [[ talk = -N ]]
18 compdef:132> [[ svccfg = -N ]]
18 compdef:132> [[ supervisorctl = -N ]]
18 compdef:132> [[ stow = -N ]]
18 compdef:132> [[ shred = -N ]]
18 compdef:132> [[ showoff = -N ]]
18 compdef:132> [[ shasum = -N ]]
18 compdef:132> [[ sfdx = -N ]]
18 compdef:132> [[ say = -N ]]
18 compdef:132> [[ rpm = -N ]]
18 compdef:132> [[ pv = -N ]]
18 compdef:132> [[ ptree = -N ]]
18 compdef:132> [[ prove = -N ]]
18 compdef:132> [[ pkgrm = -N ]]
18 compdef:132> [[ picocom = -N ]]
18 compdef:132> [[ php = -N ]]
18 compdef:132> [[ perldoc = -N ]]
18 compdef:132> [[ pbuilder = -N ]]
18 compdef:132> [[ omz = -N ]]
18 compdef:132> [[ nc = -N ]]
18 compdef:132> [[ nano = -N ]]
18 compdef:132> [[ mkfifo = -N ]]
18 compdef:132> [[ mixerctl = -N ]]
18 compdef:132> [[ mergechanges = -N ]]
18 compdef:132> [[ mencal = -N ]]
18 compdef:132> [[ mail = -N ]]
18 compdef:132> [[ madison = -N ]]
18 compdef:132> [[ lunchy = -N ]]
18 compdef:132> [[ lspv = -N ]]
18 compdef:132> [[ localedef = -N ]]
18 compdef:132> [[ ldap = -N ]]
18 compdef:132> [[ kfmclient = -N ]]
18 compdef:132> [[ jot = -N ]]
18 compdef:132> [[ joe = -N ]]
18 compdef:132> [[ jexec = -N ]]
18 compdef:132> [[ ifconfig = -N ]]
18 compdef:132> [[ ibus = -N ]]
18 compdef:132> [[ homestead = -N ]]
18 compdef:132> [[ groff = -N ]]
18 compdef:132> [[ git = -N ]]
18 compdef:132> [[ gist = -N ]]
18 compdef:132> [[ getopt = -N ]]
18 compdef:132> [[ getent = -N ]]
18 compdef:132> [[ gcc = -N ]]
18 compdef:132> [[ fuser = -N ]]
18 compdef:132> [[ fsh = -N ]]
18 compdef:132> [[ free = -N ]]
18 compdef:132> [[ fail2ban-client = -N ]]
18 compdef:132> [[ dos2unix = -N ]]
18 compdef:132> [[ dhcpcd = -N ]]
18 compdef:132> [[ df = -N ]]
18 compdef:132> [[ dbus-send = -N ]]
18 compdef:132> [[ console = -N ]]
18 compdef:132> [[ comm = -N ]]
18 compdef:132> [[ clusterdb = -N ]]
18 compdef:132> [[ cheat = -N ]]
18 compdef:132> [[ bundle = -N ]]
18 compdef:132> [[ bash = -N ]]
18 compdef:132> [[ attr = -N ]]
18 compdef:132> [[ artisan = -N ]]
18 compdef:132> [[ apt-file = -N ]]
18 compdef:132> [[ antiword = -N ]]
18 compdef:132> [[ ant = -N ]]
18 compdef:132> [[ analyseplugin = -N ]]
18 compdef:132> [[ ali = -N ]]
18 compdef:132> [[ adb = -N ]]
18 compdef:132> [[ ack = -N ]]
18 compdef:132> [[ _cockroach = -N ]]
18 compdef:131> ((  22  ))
18 compdef:131> ((  3  ))
18 compdef:131> ((  1  ))
18 compdef:131> ((  1  ))
18 compdef:131> ((  1  ))
18 compdef:117> shift
18 compdef:85> [[ -n _bash_list-choices ]]
18 compdef:83> case  (widgetkey)
18 compdef:83> case  (widgetkey)
18 compdef:83> case  (widgetkey)
18 compdef:83> case  (*)
18 compdef:83> case  (*)
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:81> shift
18 compdef:80> autoload -Uz _zed
18 compdef:80> autoload -Uz _yodl
18 compdef:80> autoload -Uz _xset
18 compdef:80> autoload -Uz _xscreensaver
18 compdef:80> autoload -Uz _xrandr
18 compdef:80> autoload -Uz _whois
18 compdef:80> autoload -Uz _wget
18 compdef:80> autoload -Uz _watch
18 compdef:80> autoload -Uz _vorbis
18 compdef:80> autoload -Uz _vmctl
18 compdef:80> autoload -Uz _visudo
18 compdef:80> autoload -Uz _vars
18 compdef:80> autoload -Uz _user_admin
18 compdef:80> autoload -Uz _update-alternatives
18 compdef:80> autoload -Uz _unace
18 compdef:80> autoload -Uz _twidge
18 compdef:80> autoload -Uz _tty
18 compdef:80> autoload -Uz _topgit
18 compdef:80> autoload -Uz _tin
18 compdef:80> autoload -Uz _terminals
18 compdef:80> autoload -Uz _tcptraceroute
18 compdef:80> autoload -Uz _tar
18 compdef:80> autoload -Uz _sysctl
18 compdef:80> autoload -Uz _sw_vers
18 compdef:80> autoload -Uz _svcprop
18 compdef:80> autoload -Uz _sublimetext
18 compdef:80> autoload -Uz _strings
18 compdef:80> autoload -Uz _sqlite
18 compdef:80> autoload -Uz _split
18 compdef:80> autoload -Uz _softwareupdate
18 compdef:80> autoload -Uz _smit
18 compdef:80> autoload -Uz _sisu
18 compdef:80> autoload -Uz _showmount
18 compdef:80> autoload -Uz _shasum
18 compdef:80> autoload -Uz _service
18 compdef:80> autoload -Uz _script
18 compdef:80> autoload -Uz _sched
18 compdef:80> autoload -Uz _samba
18 compdef:80> autoload -Uz _redirect
18 compdef:80> autoload -Uz _rcctl
18 compdef:80> autoload -Uz _pspdf
18 compdef:80> autoload -Uz _print
18 compdef:80> autoload -Uz _postscript
18 compdef:80> autoload -Uz _pids
18 compdef:80> autoload -Uz _picocom
18 compdef:80> autoload -Uz _perl
18 compdef:80> autoload -Uz _paste
18 compdef:80> autoload -Uz _pandoc
18 compdef:80> autoload -Uz _nvram
18 compdef:80> autoload -Uz _nothing
18 compdef:80> autoload -Uz _nftables
18 compdef:80> autoload -Uz _mosh
18 compdef:80> autoload -Uz _mh
18 compdef:80> autoload -Uz _mere
18 compdef:80> autoload -Uz _mdls
18 compdef:80> autoload -Uz _madison
18 compdef:80> autoload -Uz _lua
18 compdef:80> autoload -Uz _lspv
18 compdef:80> autoload -Uz _lslv
18 compdef:80> autoload -Uz _lsblk
18 compdef:80> autoload -Uz _ls
18 compdef:80> autoload -Uz _look
18 compdef:80> autoload -Uz _locale
18 compdef:80> autoload -Uz _links
18 compdef:80> autoload -Uz _limit
18 compdef:80> autoload -Uz _ldap
18 compdef:80> autoload -Uz _kld
18 compdef:80> autoload -Uz _kill
18 compdef:80> autoload -Uz _jobs_fg
18 compdef:80> autoload -Uz _irssi
18 compdef:80> autoload -Uz _inetadm
18 compdef:80> autoload -Uz _head
18 compdef:80> autoload -Uz _grep
18 compdef:80> autoload -Uz _gpasswd
18 compdef:80> autoload -Uz _gnupod
18 compdef:80> autoload -Uz _git-wtf
18 compdef:80> autoload -Uz _getopt
18 compdef:80> autoload -Uz _getconf
18 compdef:80> autoload -Uz _gcc
18 compdef:80> autoload -Uz _gas
18 compdef:80> autoload -Uz _fw_update
18 compdef:80> autoload -Uz _fuser
18 compdef:80> autoload -Uz _fsh
18 compdef:80> autoload -Uz _freebsd-update
18 compdef:80> autoload -Uz _free
18 compdef:80> autoload -Uz _flowadm
18 compdef:80> autoload -Uz _fink
18 compdef:80> autoload -Uz _ffind
18 compdef:80> autoload -Uz _fetchmail
18 compdef:80> autoload -Uz _exportfs
18 compdef:80> autoload -Uz _dad
18 compdef:80> autoload -Uz _bower
18 compdef:80> autoload -Uz _atach
18 compdef:80> autoload -Uz _asciidoctor
18 compdef:80> autoload -Uz _apt-file
18 compdef:80> autoload -Uz _apt
18 compdef:80> autoload -Uz _apm
18 compdef:80> autoload -Uz _alsa-utils
18 compdef:80> autoload -Uz _add-zsh-hook
18 compdef:80> autoload -Uz _acpitool
18 compdef:80> autoload -Uz _ack
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:80> [[ -n yes ]]
18 compdef:79> func=_rsync
18 compdef:79> func=_mount
18 compdef:79> func=_groups
18 compdef:49> [[ _zstyle = *=* ]]
18 compdef:49> [[ _zcat = *=* ]]
18 compdef:49> [[ _xmlsoft = *=* ]]
18 compdef:49> [[ _xloadimage = *=* ]]
18 compdef:49> [[ _wg-quick = *=* ]]
18 compdef:49> [[ _vagrant = *=* ]]
18 compdef:49> [[ _tree = *=* ]]
18 compdef:49> [[ _tox = *=* ]]
18 compdef:49> [[ _sdd = *=* ]]
18 compdef:49> [[ _scrub = *=* ]]
18 compdef:49> [[ _open = *=* ]]
18 compdef:49> [[ _middleman = *=* ]]
18 compdef:49> [[ _meson = *=* ]]
18 compdef:49> [[ _md5sum = *=* ]]
18 compdef:49> [[ _lighttpd = *=* ]]
18 compdef:49> [[ _fs_usage = *=* ]]
18 compdef:49> [[ _entr = *=* ]]
18 compdef:49> [[ _elinks = *=* ]]
18 compdef:49> [[ _ecasound = *=* ]]
18 compdef:49> [[ _drill = *=* ]]
18 compdef:49> [[ _dkms = *=* ]]
18 compdef:49> [[ _directories = *=* ]]
18 compdef:49> [[ _diffstat = *=* ]]
18 compdef:49> [[ _cygstart = *=* ]]
18 compdef:49> [[ _cvsup = *=* ]]
18 compdef:49> [[ _cpio = *=* ]]
18 compdef:49> [[ _complete_debug = *=* ]]
18 compdef:49> [[ _chmod = *=* ]]
18 compdef:49> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:45> [[ -z '' ]]
18 compdef:40> ((  ! 38  ))
18 compdef:40> ((  ! 17  ))
18 compdef:40> ((  ! 7  ))
18 compdef:40> ((  ! 3  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:40> ((  ! 2  ))
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:38> shift OPTIND-1
18 compdef:31> type=key
18 compdef:31> type=key
18 compdef:29> type=widgetkey
18 compdef:27> type=postpattern
18 compdef:27> type=postpattern
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:17> new=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:16> autol=yes
18 compdef:15> case n (n)
18 compdef:15> case n (a)
18 compdef:15> case n (a)
18 compdef:15> case n (a)
18 compdef:15> case a (a)
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:14> getopts anpPkKde opt
18 compdef:9> ((  ! 23  ))
18 compdef:9> ((  ! 11  ))
18 compdef:9> ((  ! 10  ))
18 compdef:9> ((  ! 6  ))
18 compdef:9> ((  ! 5  ))
18 compdef:9> ((  ! 5  ))
18 compdef:9> ((  ! 4  ))
18 compdef:9> ((  ! 4  ))
18 compdef:9> ((  ! 4  ))
18 compdef:9> ((  ! 4  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 3  ))
18 compdef:9> ((  ! 2  ))
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compdef:5> setopt extendedglob
18 compaudit:96> local _i_exe
18 colors:97> typeset -Hg reset_color bold_color
18 antigen-remove-hook:4> hooks=( -antigen-load-source-cached )
18 antigen-ext:4> eval -antigen-cache-init
18 antigen-ext:2> local func=-antigen-defer-init
18 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-apply-lock:antigen-apply...
18 antigen-add-hook:8> ((  ! 1  ))
18 antigen-add-hook:8> ((  ! 1  ))
18 antigen-add-hook:8> ((  ! 1  ))
18 antigen-add-hook:8> ((  ! 1  ))
18 antigen-add-hook:3> ((  ! 1  ))
18 add-zsh-hook:66> local fn=omz_termsupport_preexec
18 add-zsh-hook:25> local -a autoopts
18 add-zsh-hook:25> local -a autoopts
18 add-zle-hook-widget:101> ((  ! 0  ))
18 add-zle-hook-widget:92> [[ -z '' ]]
18 add-zle-hook-widget:52> local fn=_zsh_highlight__zle-line-finish
18 add-zle-hook-widget:42> ((  list  ))
18 _zsh_highlight_load_highlighters:13> highlighter=brackets
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:27> case builtin (builtin)
18 _zsh_highlight_bind_widgets:26> cur_widget=neg-argument
18 /Users/matt/.zcompdump:1968> bindkey '^X?' _complete_debug
18 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1811> bindkey '^Xt' _complet...
18 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1808> bindkey '^Xh' _complet...
18 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:14> update_mode=prompt
18 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=zsh-autosuggestions
18 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
18 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
18 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;186m%}'
18 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;135m%}'
18 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/functions...
18 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/custom/plugin...
18 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:115> zle -N edit-command-line
18 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:60> [[ -n $'C-[OF' ]]
18 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:44> [[ -n $'C-[OB' ]]
18 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:30> bindkey -M viins $'C-[[6~' do...
18 /Users/matt/.oh-my-zsh/lib/history.zsh:36> setopt hist_expire_dups_first
18 /Users/matt/.oh-my-zsh/lib/directories.zsh:12> alias '1=cd -1'
18 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
18 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
18 /Users/matt/.antigen/init.zsh:47> [[ -n /Users/matt/.oh-my-zsh ]]
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/termsupport.zsh:107> ...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:60> ...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:30> ...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:28> ...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:37> setop...
18 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:15> a...
18 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/zsh-users/z...
18 -antigen-parse-args:135> local bpath=zsh-users/zsh-autosuggestions
18 -antigen-parse-args:135> local bpath=robbyrussell/oh-my-zsh
18 -antigen-parse-args:134> [[ true == true ]]
18 -antigen-parse-args:134> [[ true == true ]]
18 -antigen-parse-args:130> args[name]=zsh-users/zsh-autosuggestions
18 -antigen-parse-args:87> [[ https://github.com/robbyrussell/oh-my-zsh.git != g...
18 -antigen-parse-args:86> local url=zsh-users/zsh-autosuggestions
18 -antigen-parse-args:65> shift
18 -antigen-parse-args:42> local url_path=zsh-users/zsh-autosuggestions
18 -antigen-parse-args:18> argkey=zsh-users/zsh-autosuggestions
18 -antigen-parse-args:17> [[ 0 -gt 0 ]]
18 -antigen-parse-args:17> [[ 0 -gt 0 ]]
18 -antigen-parse-args:4> local var=bundle
18 -antigen-parse-args:4> local var=bundle
18 -antigen-load:12> location=/Users/matt/.antigen/bundles/robbyrussell/oh-my-zs...
18 -antigen-load:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-syntax-high...
18 -antigen-load:5> local location=/Users/matt/.antigen/bundles/robbyrussell/oh-...
18 -antigen-load:4> list=( )
18 -antigen-hook-handler:55> [[ 0 == 0 ]]
18 -antigen-hook-handler:17> let 'called=11+1'
18 -antigen-hook-handler:17> let 'called=6+1'
18 -antigen-hook-handler:17> let 'called=3+1'
18 -antigen-hook-handler:17> let 'called=3+1'
18 -antigen-hook-handler:17> let 'called=1+1'
18 -antigen-hook-handler:17> let 'called=0+1'
18 -antigen-hook-handler:17> let 'called=0+1'
18 -antigen-hook-handler:9> typeset -A meta
18 -antigen-hook-handler:4> typeset -a args
18 -antigen-hook-handler:4> typeset -a args
18 -antigen-hook-handler:4> typeset -a args
18 -antigen-hook-handler:4> args=( '--loc=lib' )
18 -antigen-hook-handler:3> shift
18 -antigen-hook-handler:3> shift
18 -antigen-hook-handler:3> shift
18 -antigen-hook-handler:2> local hooks meta
18 -antigen-hook-handler:2> local hooks meta
18 -antigen-hook-handler:2> local hooks meta
18 -antigen-cache-generate:21> _fpath+=( /Users/matt/.antigen/bundles/robbyrusse...
18 -antigen-cache-generate:19> [[ -d /Users/matt/.antigen/bundles/zsh-users/zsh-...
18 -antigen-cache-generate:8> [[ -f /Users/matt/.antigen/bundles/zsh-users/zsh-s...
18 (eval):219> alias 'it2getvar=/Users/matt/.iterm2/it2getvar'
18 (eval):166> alias 'grmv=git remote rename'
18 (eval):150> alias 'grss=git restore --source'
18 (eval):100> alias 'glgm=git log --graph --max-count=10'
18 (eval):93> alias 'git-svn-dcommit-push=git svn dcommit && git push github $(g...
18 (eval):80> alias 'gcn!=git commit -v --no-edit --amend'
18 (eval):51> alias 'gcans!=git commit -v -a -s --no-edit --amend'
18 (eval):24> alias 'gamc=git am --continue'
18 (eval):22> alias 'db=deno bundle'
18 (eval):17> alias 'egrep=egrep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,....
18 (anon):33> zle -N autosuggest-accept _zsh_autosuggest_widget_accept
18 (anon):15> action=toggle
18 (anon):15> action=execute
18 (anon):15> action=enable
18 (anon):2> action=suggest
17 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
17 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
17 is-at-least:31> [[ 36 != <-> ]]
17 is-at-least:31> [[ 8 != <-> ]]
17 is-at-least:31> [[ 8 != <-> ]]
17 is-at-least:31> [[ 5 != <-> ]]
17 is-at-least:31> [[ 2 != <-> ]]
17 is-at-least:30> ((  0 <= 2  ))
17 is-at-least:28> version=( 5 8 1 0 0 0 )
17 is-at-least:27> min_ver=( 5 4 )
17 is-at-least:27> min_ver=( 2 8 )
17 group_lazy_load:5> alias 'node=lazy_load "nvm node npm" ". /Users/matt/.nvm/n...
17 group_lazy_load:4> cmd=workon
17 group_lazy_load:4> cmd=toggleglobalsitepackages
17 group_lazy_load:4> cmd=showvirtualenv
17 group_lazy_load:4> cmd=cdproject
17 group_lazy_load:3> shift 1
17 complete:2> local args void cmd print remove
17 compinit:533> zle -C menu-complete .menu-complete _main_complete
17 compinit:533> zle -C menu-complete .menu-complete _main_complete
17 compinit:533> zle -C list-choices .list-choices _main_complete
17 compinit:533> zle -C expand-or-complete .expand-or-complete _main_complete
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:516> [[ '' !=  # ]]
17 compinit:515> autoload -Uz _user_math_func
17 compinit:515> autoload -Uz _sub_commands
17 compinit:515> autoload -Uz _selinux_users
17 compinit:515> autoload -Uz _selinux_types
17 compinit:515> autoload -Uz _selinux_roles
17 compinit:515> autoload -Uz _retrieve_cache
17 compinit:515> autoload -Uz _pkg_instance
17 compinit:515> autoload -Uz _perl_basepods
17 compinit:515> autoload -Uz _options_unset
17 compinit:515> autoload -Uz _object_files
17 compinit:515> autoload -Uz _nbsd_architectures
17 compinit:515> autoload -Uz _module_math_func
17 compinit:515> autoload -Uz _mailboxes
17 compinit:515> autoload -Uz _mac_applications
17 compinit:515> autoload -Uz _java_class
17 compinit:515> autoload -Uz _global_tags
17 compinit:515> autoload -Uz _generic
17 compinit:515> autoload -Uz _fuse_values
17 compinit:515> autoload -Uz _fuse_arguments
17 compinit:515> autoload -Uz _domains
17 compinit:515> autoload -Uz _bsd_disks
17 compinit:515> autoload -Uz _alternative
17 compinit:515> autoload -Uz _absolute_command_paths
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #compdef (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#compdef)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:506> case #autoload (#autoload)
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:505> shift _i_line
17 compinit:501> continue
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:501> ((  0 + 0  ))
17 compinit:500> _i_name=_yadm
17 compinit:500> _i_name=_printers
17 compinit:500> _i_name=_pm2
17 compinit:500> _i_name=_math_params
17 compinit:500> _i_name=_figlet
17 compinit:500> _i_name=_dtrace
17 compinit:500> _i_name=_dict
17 compinit:500> _i_name=_debbugs_bugnumber
17 compinit:500> _i_name=_column
17 compinit:500> _i_name=_cache_invalid
17 compinit:500> _i_name=_baz
17 compinit:500> _i_name=_SUSEconfig
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_topgit
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_qiv
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_module-assistant
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_losetup
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_last
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kdeconnect
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gstat
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_freebsd-update
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fink
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_expand
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_env
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_entr
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dupload
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dtrace
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dput
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dict_words
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_delimiters
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_default
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dd
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cpupower
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cowsay
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_correct_word
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_complete_help_generic
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chsh
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chown
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chmod
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chattr
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cdrdao
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_calendar
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cache_invalid
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cabal
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_assign
17 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_aap
17 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_ninja
17 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_heroku
17 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_cockroach
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
17 compinit:497> [[ /usr/share/zsh/site-functions = . ]]
17 compinit:497> [[ /usr/share/zsh/5.8.1/functions = . ]]
17 compinit:493> [[ -z yes ]]
17 compinit:447> typeset _i_q
17 compinit:187> comppostfuncs=( )
17 compinit:185> typeset -ga compprefuncs comppostfuncs
17 compinit:121> [[ -n '' ]]
17 compinit:113> typeset -gHA _compautos
17 compinit:113> typeset -gHA _compautos
17 compinit:82> _i_dumpfile=/Users/matt/.antigen/.zcompdump
17 compinit:76> [[ 0 -gt 0 ]]
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:121> shift _d_als
17 compdump:117> _i=5
17 compdump:116> ((  ! --_i && 1088 > 1  ))
17 compdump:116> ((  ! --_i && 1066 > 1  ))
17 compdump:116> ((  ! --_i && 1063 > 1  ))
17 compdump:116> ((  ! --_i && 1062 > 1  ))
17 compdump:116> ((  ! --_i && 1059 > 1  ))
17 compdump:116> ((  ! --_i && 1058 > 1  ))
17 compdump:116> ((  ! --_i && 1054 > 1  ))
17 compdump:116> ((  ! --_i && 1047 > 1  ))
17 compdump:116> ((  ! --_i && 1042 > 1  ))
17 compdump:116> ((  ! --_i && 1039 > 1  ))
17 compdump:116> ((  ! --_i && 1037 > 1  ))
17 compdump:116> ((  ! --_i && 1034 > 1  ))
17 compdump:116> ((  ! --_i && 1027 > 1  ))
17 compdump:116> ((  ! --_i && 1017 > 1  ))
17 compdump:116> ((  ! --_i && 1014 > 1  ))
17 compdump:116> ((  ! --_i && 1011 > 1  ))
17 compdump:116> ((  ! --_i && 1010 > 1  ))
17 compdump:116> ((  ! --_i && 1008 > 1  ))
17 compdump:116> ((  ! --_i && 1006 > 1  ))
17 compdump:116> ((  ! --_i && 1003 > 1  ))
17 compdump:116> ((  ! --_i && 1001 > 1  ))
17 compdump:116> ((  ! --_i && 999 > 1  ))
17 compdump:116> ((  ! --_i && 997 > 1  ))
17 compdump:116> ((  ! --_i && 987 > 1  ))
17 compdump:116> ((  ! --_i && 984 > 1  ))
17 compdump:116> ((  ! --_i && 978 > 1  ))
17 compdump:116> ((  ! --_i && 973 > 1  ))
17 compdump:116> ((  ! --_i && 968 > 1  ))
17 compdump:116> ((  ! --_i && 966 > 1  ))
17 compdump:116> ((  ! --_i && 965 > 1  ))
17 compdump:116> ((  ! --_i && 962 > 1  ))
17 compdump:116> ((  ! --_i && 960 > 1  ))
17 compdump:116> ((  ! --_i && 956 > 1  ))
17 compdump:116> ((  ! --_i && 945 > 1  ))
17 compdump:116> ((  ! --_i && 941 > 1  ))
17 compdump:116> ((  ! --_i && 938 > 1  ))
17 compdump:116> ((  ! --_i && 933 > 1  ))
17 compdump:116> ((  ! --_i && 930 > 1  ))
17 compdump:116> ((  ! --_i && 926 > 1  ))
17 compdump:116> ((  ! --_i && 918 > 1  ))
17 compdump:116> ((  ! --_i && 906 > 1  ))
17 compdump:116> ((  ! --_i && 903 > 1  ))
17 compdump:116> ((  ! --_i && 902 > 1  ))
17 compdump:116> ((  ! --_i && 901 > 1  ))
17 compdump:116> ((  ! --_i && 897 > 1  ))
17 compdump:116> ((  ! --_i && 896 > 1  ))
17 compdump:116> ((  ! --_i && 893 > 1  ))
17 compdump:116> ((  ! --_i && 891 > 1  ))
17 compdump:116> ((  ! --_i && 883 > 1  ))
17 compdump:116> ((  ! --_i && 882 > 1  ))
17 compdump:116> ((  ! --_i && 880 > 1  ))
17 compdump:116> ((  ! --_i && 878 > 1  ))
17 compdump:116> ((  ! --_i && 866 > 1  ))
17 compdump:116> ((  ! --_i && 862 > 1  ))
17 compdump:116> ((  ! --_i && 860 > 1  ))
17 compdump:116> ((  ! --_i && 856 > 1  ))
17 compdump:116> ((  ! --_i && 855 > 1  ))
17 compdump:116> ((  ! --_i && 851 > 1  ))
17 compdump:116> ((  ! --_i && 850 > 1  ))
17 compdump:116> ((  ! --_i && 843 > 1  ))
17 compdump:116> ((  ! --_i && 842 > 1  ))
17 compdump:116> ((  ! --_i && 841 > 1  ))
17 compdump:116> ((  ! --_i && 840 > 1  ))
17 compdump:116> ((  ! --_i && 836 > 1  ))
17 compdump:116> ((  ! --_i && 835 > 1  ))
17 compdump:116> ((  ! --_i && 832 > 1  ))
17 compdump:116> ((  ! --_i && 831 > 1  ))
17 compdump:116> ((  ! --_i && 825 > 1  ))
17 compdump:116> ((  ! --_i && 817 > 1  ))
17 compdump:116> ((  ! --_i && 816 > 1  ))
17 compdump:116> ((  ! --_i && 815 > 1  ))
17 compdump:116> ((  ! --_i && 808 > 1  ))
17 compdump:116> ((  ! --_i && 806 > 1  ))
17 compdump:116> ((  ! --_i && 803 > 1  ))
17 compdump:116> ((  ! --_i && 802 > 1  ))
17 compdump:116> ((  ! --_i && 801 > 1  ))
17 compdump:116> ((  ! --_i && 800 > 1  ))
17 compdump:116> ((  ! --_i && 791 > 1  ))
17 compdump:116> ((  ! --_i && 781 > 1  ))
17 compdump:116> ((  ! --_i && 780 > 1  ))
17 compdump:116> ((  ! --_i && 775 > 1  ))
17 compdump:116> ((  ! --_i && 771 > 1  ))
17 compdump:116> ((  ! --_i && 768 > 1  ))
17 compdump:116> ((  ! --_i && 762 > 1  ))
17 compdump:116> ((  ! --_i && 761 > 1  ))
17 compdump:116> ((  ! --_i && 760 > 1  ))
17 compdump:116> ((  ! --_i && 758 > 1  ))
17 compdump:116> ((  ! --_i && 757 > 1  ))
17 compdump:116> ((  ! --_i && 748 > 1  ))
17 compdump:116> ((  ! --_i && 747 > 1  ))
17 compdump:116> ((  ! --_i && 746 > 1  ))
17 compdump:116> ((  ! --_i && 743 > 1  ))
17 compdump:116> ((  ! --_i && 741 > 1  ))
17 compdump:116> ((  ! --_i && 740 > 1  ))
17 compdump:116> ((  ! --_i && 731 > 1  ))
17 compdump:116> ((  ! --_i && 730 > 1  ))
17 compdump:116> ((  ! --_i && 727 > 1  ))
17 compdump:116> ((  ! --_i && 716 > 1  ))
17 compdump:116> ((  ! --_i && 713 > 1  ))
17 compdump:116> ((  ! --_i && 695 > 1  ))
17 compdump:116> ((  ! --_i && 693 > 1  ))
17 compdump:116> ((  ! --_i && 692 > 1  ))
17 compdump:116> ((  ! --_i && 688 > 1  ))
17 compdump:116> ((  ! --_i && 677 > 1  ))
17 compdump:116> ((  ! --_i && 671 > 1  ))
17 compdump:116> ((  ! --_i && 670 > 1  ))
17 compdump:116> ((  ! --_i && 650 > 1  ))
17 compdump:116> ((  ! --_i && 645 > 1  ))
17 compdump:116> ((  ! --_i && 642 > 1  ))
17 compdump:116> ((  ! --_i && 637 > 1  ))
17 compdump:116> ((  ! --_i && 633 > 1  ))
17 compdump:116> ((  ! --_i && 631 > 1  ))
17 compdump:116> ((  ! --_i && 630 > 1  ))
17 compdump:116> ((  ! --_i && 626 > 1  ))
17 compdump:116> ((  ! --_i && 621 > 1  ))
17 compdump:116> ((  ! --_i && 620 > 1  ))
17 compdump:116> ((  ! --_i && 616 > 1  ))
17 compdump:116> ((  ! --_i && 613 > 1  ))
17 compdump:116> ((  ! --_i && 612 > 1  ))
17 compdump:116> ((  ! --_i && 608 > 1  ))
17 compdump:116> ((  ! --_i && 603 > 1  ))
17 compdump:116> ((  ! --_i && 600 > 1  ))
17 compdump:116> ((  ! --_i && 598 > 1  ))
17 compdump:116> ((  ! --_i && 596 > 1  ))
17 compdump:116> ((  ! --_i && 591 > 1  ))
17 compdump:116> ((  ! --_i && 583 > 1  ))
17 compdump:116> ((  ! --_i && 578 > 1  ))
17 compdump:116> ((  ! --_i && 571 > 1  ))
17 compdump:116> ((  ! --_i && 570 > 1  ))
17 compdump:116> ((  ! --_i && 566 > 1  ))
17 compdump:116> ((  ! --_i && 565 > 1  ))
17 compdump:116> ((  ! --_i && 552 > 1  ))
17 compdump:116> ((  ! --_i && 550 > 1  ))
17 compdump:116> ((  ! --_i && 546 > 1  ))
17 compdump:116> ((  ! --_i && 545 > 1  ))
17 compdump:116> ((  ! --_i && 543 > 1  ))
17 compdump:116> ((  ! --_i && 541 > 1  ))
17 compdump:116> ((  ! --_i && 537 > 1  ))
17 compdump:116> ((  ! --_i && 536 > 1  ))
17 compdump:116> ((  ! --_i && 521 > 1  ))
17 compdump:116> ((  ! --_i && 520 > 1  ))
17 compdump:116> ((  ! --_i && 515 > 1  ))
17 compdump:116> ((  ! --_i && 511 > 1  ))
17 compdump:116> ((  ! --_i && 510 > 1  ))
17 compdump:116> ((  ! --_i && 507 > 1  ))
17 compdump:116> ((  ! --_i && 505 > 1  ))
17 compdump:116> ((  ! --_i && 502 > 1  ))
17 compdump:116> ((  ! --_i && 495 > 1  ))
17 compdump:116> ((  ! --_i && 490 > 1  ))
17 compdump:116> ((  ! --_i && 487 > 1  ))
17 compdump:116> ((  ! --_i && 486 > 1  ))
17 compdump:116> ((  ! --_i && 481 > 1  ))
17 compdump:116> ((  ! --_i && 478 > 1  ))
17 compdump:116> ((  ! --_i && 477 > 1  ))
17 compdump:116> ((  ! --_i && 473 > 1  ))
17 compdump:116> ((  ! --_i && 448 > 1  ))
17 compdump:116> ((  ! --_i && 446 > 1  ))
17 compdump:116> ((  ! --_i && 438 > 1  ))
17 compdump:116> ((  ! --_i && 433 > 1  ))
17 compdump:116> ((  ! --_i && 428 > 1  ))
17 compdump:116> ((  ! --_i && 423 > 1  ))
17 compdump:116> ((  ! --_i && 420 > 1  ))
17 compdump:116> ((  ! --_i && 418 > 1  ))
17 compdump:116> ((  ! --_i && 417 > 1  ))
17 compdump:116> ((  ! --_i && 413 > 1  ))
17 compdump:116> ((  ! --_i && 396 > 1  ))
17 compdump:116> ((  ! --_i && 392 > 1  ))
17 compdump:116> ((  ! --_i && 378 > 1  ))
17 compdump:116> ((  ! --_i && 373 > 1  ))
17 compdump:116> ((  ! --_i && 372 > 1  ))
17 compdump:116> ((  ! --_i && 366 > 1  ))
17 compdump:116> ((  ! --_i && 360 > 1  ))
17 compdump:116> ((  ! --_i && 355 > 1  ))
17 compdump:116> ((  ! --_i && 350 > 1  ))
17 compdump:116> ((  ! --_i && 344 > 1  ))
17 compdump:116> ((  ! --_i && 343 > 1  ))
17 compdump:116> ((  ! --_i && 340 > 1  ))
17 compdump:116> ((  ! --_i && 337 > 1  ))
17 compdump:116> ((  ! --_i && 336 > 1  ))
17 compdump:116> ((  ! --_i && 332 > 1  ))
17 compdump:116> ((  ! --_i && 328 > 1  ))
17 compdump:116> ((  ! --_i && 326 > 1  ))
17 compdump:116> ((  ! --_i && 323 > 1  ))
17 compdump:116> ((  ! --_i && 322 > 1  ))
17 compdump:116> ((  ! --_i && 320 > 1  ))
17 compdump:116> ((  ! --_i && 316 > 1  ))
17 compdump:116> ((  ! --_i && 307 > 1  ))
17 compdump:116> ((  ! --_i && 306 > 1  ))
17 compdump:116> ((  ! --_i && 305 > 1  ))
17 compdump:116> ((  ! --_i && 297 > 1  ))
17 compdump:116> ((  ! --_i && 296 > 1  ))
17 compdump:116> ((  ! --_i && 295 > 1  ))
17 compdump:116> ((  ! --_i && 292 > 1  ))
17 compdump:116> ((  ! --_i && 287 > 1  ))
17 compdump:116> ((  ! --_i && 286 > 1  ))
17 compdump:116> ((  ! --_i && 276 > 1  ))
17 compdump:116> ((  ! --_i && 271 > 1  ))
17 compdump:116> ((  ! --_i && 262 > 1  ))
17 compdump:116> ((  ! --_i && 261 > 1  ))
17 compdump:116> ((  ! --_i && 258 > 1  ))
17 compdump:116> ((  ! --_i && 253 > 1  ))
17 compdump:116> ((  ! --_i && 252 > 1  ))
17 compdump:116> ((  ! --_i && 251 > 1  ))
17 compdump:116> ((  ! --_i && 246 > 1  ))
17 compdump:116> ((  ! --_i && 240 > 1  ))
17 compdump:116> ((  ! --_i && 236 > 1  ))
17 compdump:116> ((  ! --_i && 235 > 1  ))
17 compdump:116> ((  ! --_i && 230 > 1  ))
17 compdump:116> ((  ! --_i && 228 > 1  ))
17 compdump:116> ((  ! --_i && 227 > 1  ))
17 compdump:116> ((  ! --_i && 226 > 1  ))
17 compdump:116> ((  ! --_i && 225 > 1  ))
17 compdump:116> ((  ! --_i && 221 > 1  ))
17 compdump:116> ((  ! --_i && 220 > 1  ))
17 compdump:116> ((  ! --_i && 217 > 1  ))
17 compdump:116> ((  ! --_i && 212 > 1  ))
17 compdump:116> ((  ! --_i && 211 > 1  ))
17 compdump:116> ((  ! --_i && 210 > 1  ))
17 compdump:116> ((  ! --_i && 208 > 1  ))
17 compdump:116> ((  ! --_i && 200 > 1  ))
17 compdump:116> ((  ! --_i && 196 > 1  ))
17 compdump:116> ((  ! --_i && 195 > 1  ))
17 compdump:116> ((  ! --_i && 192 > 1  ))
17 compdump:116> ((  ! --_i && 182 > 1  ))
17 compdump:116> ((  ! --_i && 180 > 1  ))
17 compdump:116> ((  ! --_i && 175 > 1  ))
17 compdump:116> ((  ! --_i && 173 > 1  ))
17 compdump:116> ((  ! --_i && 168 > 1  ))
17 compdump:116> ((  ! --_i && 156 > 1  ))
17 compdump:116> ((  ! --_i && 148 > 1  ))
17 compdump:116> ((  ! --_i && 143 > 1  ))
17 compdump:116> ((  ! --_i && 141 > 1  ))
17 compdump:116> ((  ! --_i && 136 > 1  ))
17 compdump:116> ((  ! --_i && 131 > 1  ))
17 compdump:116> ((  ! --_i && 127 > 1  ))
17 compdump:116> ((  ! --_i && 126 > 1  ))
17 compdump:116> ((  ! --_i && 125 > 1  ))
17 compdump:116> ((  ! --_i && 122 > 1  ))
17 compdump:116> ((  ! --_i && 111 > 1  ))
17 compdump:116> ((  ! --_i && 103 > 1  ))
17 compdump:116> ((  ! --_i && 95 > 1  ))
17 compdump:116> ((  ! --_i && 90 > 1  ))
17 compdump:116> ((  ! --_i && 68 > 1  ))
17 compdump:116> ((  ! --_i && 65 > 1  ))
17 compdump:116> ((  ! --_i && 62 > 1  ))
17 compdump:116> ((  ! --_i && 55 > 1  ))
17 compdump:116> ((  ! --_i && 53 > 1  ))
17 compdump:116> ((  ! --_i && 50 > 1  ))
17 compdump:116> ((  ! --_i && 22 > 1  ))
17 compdump:116> ((  ! --_i && 5 > 1  ))
17 compdump:115> print -n ' _zypper'
17 compdump:115> print -n ' _zstyle'
17 compdump:115> print -n ' _zparseopts'
17 compdump:115> print -n ' _zones'
17 compdump:115> print -n ' _zmodload'
17 compdump:115> print -n ' _zlogin'
17 compdump:115> print -n ' _zle'
17 compdump:115> print -n ' _zip'
17 compdump:115> print -n ' _zfs_pool'
17 compdump:115> print -n ' _zfs_dataset'
17 compdump:115> print -n ' _zed'
17 compdump:115> print -n ' _zeal'
17 compdump:115> print -n ' _zdump'
17 compdump:115> print -n ' _zcompile'
17 compdump:115> print -n ' _zcat'
17 compdump:115> print -n ' _yafc'
17 compdump:115> print -n ' _xz'
17 compdump:115> print -n ' _xxd'
17 compdump:115> print -n ' _xwit'
17 compdump:115> print -n ' _xt_arguments'
17 compdump:115> print -n ' _xscreensaver'
17 compdump:115> print -n ' _xrandr'
17 compdump:115> print -n ' _xmodmap'
17 compdump:115> print -n ' _xft_fonts'
17 compdump:115> print -n ' _xcode-select'
17 compdump:115> print -n ' _xautolock'
17 compdump:115> print -n ' _xauth'
17 compdump:115> print -n ' _xargs'
17 compdump:115> print -n ' _x_keysym'
17 compdump:115> print -n ' _x_cursor'
17 compdump:115> print -n ' _x_color'
17 compdump:115> print -n ' _widgets'
17 compdump:115> print -n ' _who'
17 compdump:115> print -n ' _wget'
17 compdump:115> print -n ' _wc'
17 compdump:115> print -n ' _watch'
17 compdump:115> print -n ' _wait'
17 compdump:115> print -n ' _w'
17 compdump:115> print -n ' _vpnc'
17 compdump:115> print -n ' _vnc'
17 compdump:115> print -n ' _vmctl'
17 compdump:115> print -n ' _virtualbox'
17 compdump:115> print -n ' _vim-addons'
17 compdump:115> print -n ' _vim'
17 compdump:115> print -n ' _vared'
17 compdump:115> print -n ' _value'
17 compdump:115> print -n ' _users'
17 compdump:115> print -n ' _user_math_func'
17 compdump:115> print -n ' _user_expand'
17 compdump:115> print -n ' _user_admin'
17 compdump:115> print -n ' _uscan'
17 compdump:115> print -n ' _urls'
17 compdump:115> print -n ' _uniq'
17 compdump:115> print -n ' _unhash'
17 compdump:115> print -n ' _uml'
17 compdump:115> print -n ' _ufw'
17 compdump:115> print -n ' _twidge'
17 compdump:115> print -n ' _ttys'
17 compdump:115> print -n ' _tty'
17 compdump:115> print -n ' _trash'
17 compdump:115> print -n ' _tox'
17 compdump:115> print -n ' _totd'
17 compdump:115> print -n ' _topgit'
17 compdump:115> print -n ' _top'
17 compdump:115> print -n ' _toilet'
17 compdump:115> print -n ' _tmuxp'
17 compdump:115> print -n ' _texinfo'
17 compdump:115> print -n ' _tee'
17 compdump:115> print -n ' _tcptraceroute'
17 compdump:115> print -n ' _tcpsys'
17 compdump:115> print -n ' _tar_archive'
17 compdump:115> print -n ' _tar'
17 compdump:115> print -n ' _tail'
17 compdump:115> print -n ' _tags'
17 compdump:115> print -n ' _systat'
17 compdump:115> print -n ' _sysstat'
17 compdump:115> print -n ' _sysrc'
17 compdump:115> print -n ' _svcs_fmri'
17 compdump:115> print -n ' _svcprop'
17 compdump:115> print -n ' _subliminal'
17 compdump:115> print -n ' _strace'
17 compdump:115> print -n ' _stack'
17 compdump:115> print -n ' _ss'
17 compdump:115> print -n ' _split'
17 compdump:115> print -n ' _snoop'
17 compdump:115> print -n ' _slabtop'
17 compdump:115> print -n ' _shuf'
17 compdump:115> print -n ' _shasum'
17 compdump:115> print -n ' _setxkbmap'
17 compdump:115> print -n ' _setsid'
17 compdump:115> print -n ' _set'
17 compdump:115> print -n ' _services'
17 compdump:115> print -n ' _seq'
17 compdump:115> print -n ' _selinux_users'
17 compdump:115> print -n ' _selinux_types'
17 compdump:115> print -n ' _selinux_contexts'
17 compdump:115> print -n ' _sdd'
17 compdump:115> print -n ' _scutil'
17 compdump:115> print -n ' _scrub'
17 compdump:115> print -n ' _script'
17 compdump:115> print -n ' _screen'
17 compdump:115> print -n ' _scons'
17 compdump:115> print -n ' _schroot'
17 compdump:115> print -n ' _savecore'
17 compdump:115> print -n ' _runit'
17 compdump:115> print -n ' _rubber'
17 compdump:115> print -n ' _rsync'
17 compdump:115> print -n ' _rspec'
17 compdump:115> print -n ' _rrdtool'
17 compdump:115> print -n ' _rpm'
17 compdump:115> print -n ' _route'
17 compdump:115> print -n ' _rlogin'
17 compdump:115> print -n ' _reprepro'
17 compdump:115> print -n ' _remote_files'
17 compdump:115> print -n ' _redis-cli'
17 compdump:115> print -n ' _redirect'
17 compdump:115> print -n ' _readelf'
17 compdump:115> print -n ' _read'
17 compdump:115> print -n ' _rcs'
17 compdump:115> print -n ' _rcctl'
17 compdump:115> print -n ' _qtplay'
17 compdump:115> print -n ' _qiv'
17 compdump:115> print -n ' _qdbus'
17 compdump:115> print -n ' _python_modules'
17 compdump:115> print -n ' _pygmentize'
17 compdump:115> print -n ' _pydoc'
17 compdump:115> print -n ' _putclip'
17 compdump:115> print -n ' _pump'
17 compdump:115> print -n ' _ptree'
17 compdump:115> print -n ' _psutils'
17 compdump:115> print -n ' _pspdf'
17 compdump:115> print -n ' _prstat'
17 compdump:115> print -n ' _prove'
17 compdump:115> print -n ' _protoc'
17 compdump:115> print -n ' _prompt'
17 compdump:115> print -n ' _printenv'
17 compdump:115> print -n ' _print'
17 compdump:115> print -n ' _prefix'
17 compdump:115> print -n ' _precommand'
17 compdump:115> print -n ' _powerd'
17 compdump:115> print -n ' _postscript'
17 compdump:115> print -n ' _postfix'
17 compdump:115> print -n ' _ports'
17 compdump:115> print -n ' _portmaster'
17 compdump:115> print -n ' _portaudit'
17 compdump:115> print -n ' _port'
17 compdump:115> print -n ' _pmap'
17 compdump:115> print -n ' _pm2'
17 compdump:115> print -n ' _plutil'
17 compdump:115> print -n ' _play'
17 compdump:115> print -n ' _pkgrm'
17 compdump:115> print -n ' _pkginfo'
17 compdump:115> print -n ' _pkgin'
17 compdump:115> print -n ' _pkg-config'
17 compdump:115> print -n ' _piuparts'
17 compdump:115> print -n ' _pids'
17 compdump:115> print -n ' _picocom'
17 compdump:115> print -n ' _php'
17 compdump:115> print -n ' _pfexec'
17 compdump:115> print -n ' _pfctl'
17 compdump:115> print -n ' _perl_modules'
17 compdump:115> print -n ' _perl_basepods'
17 compdump:115> print -n ' _perl'
17 compdump:115> print -n ' _periscope'
17 compdump:115> print -n ' _perforce'
17 compdump:115> print -n ' _pbuilder'
17 compdump:115> print -n ' _pbcopy'
17 compdump:115> print -n ' _pax'
17 compdump:115> print -n ' _patool'
17 compdump:115> print -n ' _patchutils'
17 compdump:115> print -n ' _patch'
17 compdump:115> print -n ' _paste'
17 compdump:115> print -n ' _parameters'
17 compdump:115> print -n ' _parameter'
17 compdump:115> print -n ' _pack'
17 compdump:115> print -n ' _otool'
17 compdump:115> print -n ' _osc'
17 compdump:115> print -n ' _options'
17 compdump:115> print -n ' _opkg'
17 compdump:115> print -n ' _openstack'
17 compdump:115> print -n ' _openssl'
17 compdump:115> print -n ' _okular'
17 compdump:115> print -n ' _object_files'
17 compdump:115> print -n ' _nvram'
17 compdump:115> print -n ' _nvm'
17 compdump:115> print -n ' _numfmt'
17 compdump:115> print -n ' _nm'
17 compdump:115> print -n ' _nl'
17 compdump:115> print -n ' _nice'
17 compdump:115> print -n ' _nginx'
17 compdump:115> print -n ' _nftables'
17 compdump:115> print -n ' _next_label'
17 compdump:115> print -n ' _newsgroups'
17 compdump:115> print -n ' _netstat'
17 compdump:115> print -n ' _ncftp'
17 compdump:115> print -n ' _nanoc'
17 compdump:115> print -n ' _myrepos'
17 compdump:115> print -n ' _my_accounts'
17 compdump:115> print -n ' _mv'
17 compdump:115> print -n ' _mupdf'
17 compdump:115> print -n ' _multi_parts'
17 compdump:115> print -n ' _mtr'
17 compdump:115> print -n ' _mtools'
17 compdump:115> print -n ' _mt'
17 compdump:115> print -n ' _mpc'
17 compdump:115> print -n ' _mount'
17 compdump:115> print -n ' _most_recent_file'
17 compdump:115> print -n ' _mosh'
17 compdump:115> print -n ' _mktemp'
17 compdump:115> print -n ' _mkshortcut'
17 compdump:115> print -n ' _mixerctl'
17 compdump:115> print -n ' _mix'
17 compdump:115> print -n ' _mina'
17 compdump:115> print -n ' _mh'
17 compdump:115> print -n ' _message'
17 compdump:115> print -n ' _mere'
17 compdump:115> print -n ' _mencal'
17 compdump:115> print -n ' _members'
17 compdump:115> print -n ' _mdutil'
17 compdump:115> print -n ' _mdfind'
17 compdump:115> print -n ' _mc'
17 compdump:115> print -n ' _math_params'
17 compdump:115> print -n ' _math'
17 compdump:115> print -n ' _match'
17 compdump:115> print -n ' _man'
17 compdump:115> print -n ' _make'
17 compdump:115> print -n ' _mailboxes'
17 compdump:115> print -n ' _lz4'
17 compdump:115> print -n ' _lua'
17 compdump:115> print -n ' _ltrace'
17 compdump:115> print -n ' _lsvg'
17 compdump:115> print -n ' _lsusb'
17 compdump:115> print -n ' _lsof'
17 compdump:115> print -n ' _lscfg'
17 compdump:115> print -n ' _lsblk'
17 compdump:115> print -n ' _look'
17 compdump:115> print -n ' _logical_volumes'
17 compdump:115> print -n ' _locales'
17 compdump:115> print -n ' _localedef'
17 compdump:115> print -n ' _ln'
17 compdump:115> print -n ' _list_files'
17 compdump:115> print -n ' _list'
17 compdump:115> print -n ' _lintian'
17 compdump:115> print -n ' _limit'
17 compdump:115> print -n ' _lighttpd'
17 compdump:115> print -n ' _ldconfig'
17 compdump:115> print -n ' _kvno'
17 compdump:115> print -n ' _knife'
17 compdump:115> print -n ' _killall'
17 compdump:115> print -n ' _kill'
17 compdump:115> print -n ' _kfmclient'
17 compdump:115> print -n ' _kak'
17 compdump:115> print -n ' _jrnl'
17 compdump:115> print -n ' _join'
17 compdump:115> print -n ' _jobs_bg'
17 compdump:115> print -n ' _jobs'
17 compdump:115> print -n ' _java_class'
17 compdump:115> print -n ' _ispell'
17 compdump:115> print -n ' _irssi'
17 compdump:115> print -n ' _ipset'
17 compdump:115> print -n ' _ipsec'
17 compdump:115> print -n ' _ipadm'
17 compdump:115> print -n ' _ionice'
17 compdump:115> print -n ' _inxi'
17 compdump:115> print -n ' _invoke-rc.d'
17 compdump:115> print -n ' _in_vared'
17 compdump:115> print -n ' _imagemagick'
17 compdump:115> print -n ' _ignored'
17 compdump:115> print -n ' _iftop'
17 compdump:115> print -n ' _ifconfig'
17 compdump:115> print -n ' _htop'
17 compdump:115> print -n ' _hosts'
17 compdump:115> print -n ' _homestead'
17 compdump:115> print -n ' _hledger'
17 compdump:115> print -n ' _hexdump'
17 compdump:115> print -n ' _head'
17 compdump:115> print -n ' _hdiutil'
17 compdump:115> print -n ' _have_glob_qual'
17 compdump:115> print -n ' _guilt'
17 compdump:115> print -n ' _guard'
17 compdump:115> print -n ' _golang'
17 compdump:115> print -n ' _go'
17 compdump:115> print -n ' _gnutls'
17 compdump:115> print -n ' _gnupod'
17 compdump:115> print -n ' _globquals'
17 compdump:115> print -n ' _global_tags'
17 compdump:115> print -n ' _global'
17 compdump:115> print -n ' _glances'
17 compdump:115> print -n ' _git-flow'
17 compdump:115> print -n ' _gist'
17 compdump:115> print -n ' _ghc'
17 compdump:115> print -n ' _geany'
17 compdump:115> print -n ' _gcore'
17 compdump:115> print -n ' _gas'
17 compdump:115> print -n ' _fusermount'
17 compdump:115> print -n ' _fuser'
17 compdump:115> print -n ' _fold'
17 compdump:115> print -n ' _flex'
17 compdump:115> print -n ' _fleetctl'
17 compdump:115> print -n ' _fink'
17 compdump:115> print -n ' _find'
17 compdump:115> print -n ' _figlet'
17 compdump:115> print -n ' _ffind'
17 compdump:115> print -n ' _feh'
17 compdump:115> print -n ' _fab'
17 compdump:115> print -n ' _exportfs'
17 compdump:115> print -n ' _expand_word'
17 compdump:115> print -n ' _expand_alias'
17 compdump:115> print -n ' _expand'
17 compdump:115> print -n ' _exec'
17 compdump:115> print -n ' _espeak'
17 compdump:115> print -n ' _env'
17 compdump:115> print -n ' _entr'
17 compdump:115> print -n ' _enable'
17 compdump:115> print -n ' _echoti'
17 compdump:115> print -n ' _dumpadm'
17 compdump:115> print -n ' _dtruss'
17 compdump:115> print -n ' _dtrace'
17 compdump:115> print -n ' _docpad'
17 compdump:115> print -n ' _doas'
17 compdump:115> print -n ' _disable'
17 compdump:115> print -n ' _diff_options'
17 compdump:115> print -n ' _diff3'
17 compdump:115> print -n ' _diana'
17 compdump:115> print -n ' _describe'
17 compdump:115> print -n ' _default'
17 compdump:115> print -n ' _debuild'
17 compdump:115> print -n ' _debsign'
17 compdump:115> print -n ' _dcop'
17 compdump:115> print -n ' _dbus'
17 compdump:115> print -n ' _curl'
17 compdump:115> print -n ' _cp'
17 compdump:115> print -n ' _correct_filename'
17 compdump:115> print -n ' _coreadm'
17 compdump:115> print -n ' _console'
17 compdump:115> print -n ' _conan'
17 compdump:115> print -n ' _complete'
17 compdump:115> print -n ' _command_names'
17 compdump:115> print -n ' _combination'
17 compdump:115> print -n ' _coffee'
17 compdump:115> print -n ' _code'
17 compdump:115> print -n ' _cmdambivalent'
17 compdump:115> print -n ' _choc'
17 compdump:115> print -n ' _chkconfig'
17 compdump:115> print -n ' _cheat'
17 compdump:115> print -n ' _cdrecord'
17 compdump:115> print -n ' _cdrdao'
17 compdump:115> print -n ' _cd'
17 compdump:115> print -n ' _cal'
17 compdump:115> print -n ' _cabal'
17 compdump:115> print -n ' _builtin'
17 compdump:115> print -n ' _bug'
17 compdump:115> print -n ' _bts'
17 compdump:115> print -n ' _bsdconfig'
17 compdump:115> print -n ' _bower'
17 compdump:115> print -n ' _bitcoin-cli'
17 compdump:115> print -n ' _bindkey'
17 compdump:115> print -n ' _baz'
17 compdump:115> print -n ' _base64'
17 compdump:115> print -n ' _awk'
17 compdump:115> print -n ' _autocd'
17 compdump:115> print -n ' _at'
17 compdump:115> print -n ' _arguments'
17 compdump:115> print -n ' _archlinux-java'
17 compdump:115> print -n ' _apm'
17 compdump:115> print -n ' _android'
17 compdump:115> print -n ' _analyseplugin'
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:114> ((  ! 0  ))
17 compdump:113> ((  1090  ))
17 compdump:113> ((  345  ))
17 compdump:91> _d_bks+=( _most_recent_file )
17 compdump:91> _d_bks+=( _correct_word )
17 compdump:91> _d_bks+=( _complete_tag )
17 compdump:86> [[ -z '' && .complete-word = .menu-select ]]
17 compdump:85> [[ zle-isearch-update = _* ]]
17 compdump:85> [[ what-cursor-position = _* ]]
17 compdump:85> [[ vi-yank-whole-line = _* ]]
17 compdump:85> [[ vi-yank-eol = _* ]]
17 compdump:85> [[ vi-up-case = _* ]]
17 compdump:85> [[ vi-rev-repeat-search = _* ]]
17 compdump:85> [[ vi-rev-repeat-find = _* ]]
17 compdump:85> [[ vi-repeat-find = _* ]]
17 compdump:85> [[ vi-quoted-insert = _* ]]
17 compdump:85> [[ vi-put-before = _* ]]
17 compdump:85> [[ vi-oper-swap-case = _* ]]
17 compdump:85> [[ vi-open-line-above = _* ]]
17 compdump:85> [[ vi-insert-bol = _* ]]
17 compdump:85> [[ vi-history-search-forward = _* ]]
17 compdump:85> [[ vi-goto-mark-line = _* ]]
17 compdump:85> [[ vi-forward-blank-word = _* ]]
17 compdump:85> [[ vi-fetch-history = _* ]]
17 compdump:85> [[ vi-down-line-or-history = _* ]]
17 compdump:85> [[ vi-change-whole-line = _* ]]
17 compdump:85> [[ vi-change-eol = _* ]]
17 compdump:85> [[ vi-change = _* ]]
17 compdump:85> [[ vi-backward-word-end = _* ]]
17 compdump:85> [[ vi-backward-word = _* ]]
17 compdump:85> [[ vi-add-next = _* ]]
17 compdump:85> [[ vi-add-eol = _* ]]
17 compdump:85> [[ up-line-or-history = _* ]]
17 compdump:85> [[ spell-word = _* ]]
17 compdump:85> [[ set-mark-command = _* ]]
17 compdump:85> [[ self-insert-unmeta = _* ]]
17 compdump:85> [[ select-in-blank-word = _* ]]
17 compdump:85> [[ select-a-shell-word = _* ]]
17 compdump:85> [[ select-a-blank-word = _* ]]
17 compdump:85> [[ reset-prompt = _* ]]
17 compdump:85> [[ redisplay = _* ]]
17 compdump:85> [[ quote-line = _* ]]
17 compdump:85> [[ put-replace-selection = _* ]]
17 compdump:85> [[ push-line = _* ]]
17 compdump:85> [[ pound-insert = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-zle-line-finish = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-delete-char-or-list = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-_next_tags = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-_most_recent_file = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-_list_expansions = _* ]]
17 compdump:85> [[ orig-s0.0000080000-r6249-_correct_word = _* ]]
17 compdump:85> [[ menu-complete = _* ]]
17 compdump:85> [[ magic-space = _* ]]
17 compdump:85> [[ list-choices = _* ]]
17 compdump:85> [[ kill-buffer = _* ]]
17 compdump:85> [[ insert-last-word = _* ]]
17 compdump:85> [[ history-search-backward = _* ]]
17 compdump:85> [[ history-incremental-search-forward = _* ]]
17 compdump:85> [[ history-beginning-search-backward = _* ]]
17 compdump:85> [[ fasd-complete-d = _* ]]
17 compdump:85> [[ expand-or-complete-prefix = _* ]]
17 compdump:85> [[ expand-history = _* ]]
17 compdump:85> [[ exchange-point-and-mark = _* ]]
17 compdump:85> [[ edit-command-line = _* ]]
17 compdump:85> [[ down-line-or-search = _* ]]
17 compdump:85> [[ down-case-word = _* ]]
17 compdump:85> [[ describe-key-briefly = _* ]]
17 compdump:85> [[ delete-char-or-list = _* ]]
17 compdump:85> [[ delete-char = _* ]]
17 compdump:85> [[ copy-region-as-kill = _* ]]
17 compdump:85> [[ copy-prev-word = _* ]]
17 compdump:85> [[ clear-screen = _* ]]
17 compdump:85> [[ beginning-of-buffer-or-history = _* ]]
17 compdump:85> [[ backward-delete-word = _* ]]
17 compdump:85> [[ backward-delete-char = _* ]]
17 compdump:85> [[ backward-char = _* ]]
17 compdump:85> [[ autosuggest-toggle = _* ]]
17 compdump:85> [[ autosuggest-suggest = _* ]]
17 compdump:85> [[ autosuggest-disable = _* ]]
17 compdump:85> [[ auto-suffix-retain = _* ]]
17 compdump:85> [[ accept-search = _* ]]
17 compdump:85> [[ accept-line-and-down-history = _* ]]
17 compdump:85> [[ accept-and-infer-next-history = _* ]]
17 compdump:62> _d_f=-value-,RUBY(LIB|OPT|PATH),-default-
17 compdump:62> _d_f=-value-,*PATH,-default-
17 compdump:49> _d_f=gnupod_check.pl
17 compdump:49> _d_f=-redirect-,<,xz
17 compdump:44> print -r - ''zstyle'' ''_zstyle''
17 compdump:44> print -r - ''zsocket'' ''_zsocket''
17 compdump:44> print -r - ''zpool'' ''_zpool''
17 compdump:44> print -r - ''zparseopts'' ''_zparseopts''
17 compdump:44> print -r - ''zone'' ''_hosts''
17 compdump:44> print -r - ''zle'' ''_zle''
17 compdump:44> print -r - ''zgrep'' ''_grep''
17 compdump:44> print -r - ''zfgrep'' ''_grep''
17 compdump:44> print -r - ''zf_rm'' ''_rm''
17 compdump:44> print -r - ''zf_mv'' ''_mv''
17 compdump:44> print -r - ''zf_ln'' ''_ln''
17 compdump:44> print -r - ''zf_chmod'' ''_chmod''
17 compdump:44> print -r - ''zen'' ''_webbrowser''
17 compdump:44> print -r - ''zegrep'' ''_grep''
17 compdump:44> print -r - ''zdump'' ''_zdump''
17 compdump:44> print -r - ''zcompile'' ''_zcompile''
17 compdump:44> print -r - ''zargs'' ''_zargs''
17 compdump:44> print -r - ''yumdb'' ''_yum''
17 compdump:44> print -r - ''ytalk'' ''_other_accounts''
17 compdump:44> print -r - ''ypwhich'' ''_yp''
17 compdump:44> print -r - ''yppush'' ''_yp''
17 compdump:44> print -r - ''yppoll'' ''_yp''
17 compdump:44> print -r - ''ypmatch'' ''_yp''
17 compdump:44> print -r - ''ypcat'' ''_yp''
17 compdump:44> print -r - ''yast'' ''_yast''
17 compdump:44> print -r - ''yarn'' ''_yarn''
17 compdump:44> print -r - ''yadm'' ''_yadm''
17 compdump:44> print -r - ''xwud'' ''_x_utils''
17 compdump:44> print -r - ''xwininfo'' ''_x_utils''
17 compdump:44> print -r - ''xwd'' ''_x_utils''
17 compdump:44> print -r - ''xview'' ''_xloadimage''
17 compdump:44> print -r - ''xtp'' ''_imagemagick''
17 compdump:44> print -r - ''xset'' ''_xset''
17 compdump:44> print -r - ''xsel'' ''_xsel''
17 compdump:44> print -r - ''xscreensaver-command'' ''_xscreensaver''
17 compdump:44> print -r - ''xrandr'' ''_xrandr''
17 compdump:44> print -r - ''xprop'' ''_x_utils''
17 compdump:44> print -r - ''xpdf'' ''_xpdf''
17 compdump:44> print -r - ''xon'' ''_x_utils''
17 compdump:44> print -r - ''xmodmap'' ''_xmodmap''
17 compdump:44> print -r - ''xlsclients'' ''_x_utils''
17 compdump:44> print -r - ''xlsatoms'' ''_x_utils''
17 compdump:44> print -r - ''xli'' ''_xloadimage''
17 compdump:44> print -r - ''xhost'' ''_x_utils''
17 compdump:44> print -r - ''xfontsel'' ''_x_utils''
17 compdump:44> print -r - ''xfd'' ''_x_utils''
17 compdump:44> print -r - ''xev'' ''_x_utils''
17 compdump:44> print -r - ''xdvi'' ''_xdvi''
17 compdump:44> print -r - ''xcode-select'' ''_xcode-select''
17 compdump:44> print -r - ''xautolock'' ''_xautolock''
17 compdump:44> print -r - ''xargs'' ''_xargs''
17 compdump:44> print -r - ''wpa_cli'' ''_wpa_cli''
17 compdump:44> print -r - ''wiggle'' ''_wiggle''
17 compdump:44> print -r - ''whois'' ''_whois''
17 compdump:44> print -r - ''whoami'' ''_nothing''
17 compdump:44> print -r - ''where'' ''_which''
17 compdump:44> print -r - ''whence'' ''_which''
17 compdump:44> print -r - ''what'' ''_sccs''
17 compdump:44> print -r - ''wget'' ''_wget''
17 compdump:44> print -r - ''wemux'' ''_wemux''
17 compdump:44> print -r - ''watcher'' ''_openstack''
17 compdump:44> print -r - ''wajig'' ''_wajig''
17 compdump:44> print -r - ''vpnc'' ''_vpnc''
17 compdump:44> print -r - ''vnstat'' ''_vnstat''
17 compdump:44> print -r - ''vncserver'' ''_vnc''
17 compdump:44> print -r - ''vitrage'' ''_openstack''
17 compdump:44> print -r - ''virt-xml-validate'' ''_libvirt''
17 compdump:44> print -r - ''virt-host-validate'' ''_libvirt''
17 compdump:44> print -r - ''virsh'' ''_libvirt''
17 compdump:44> print -r - ''vimdiff'' ''_vim''
17 compdump:44> print -r - ''vim'' ''_vim''
17 compdump:44> print -r - ''vcsh'' ''_vcsh''
17 compdump:44> print -r - ''valgrind'' ''_valgrind''
17 compdump:44> print -r - ''usermod'' ''_user_admin''
17 compdump:44> print -r - ''urxvt256cc'' ''_urxvt''
17 compdump:44> print -r - ''urxvt'' ''_urxvt''
17 compdump:44> print -r - ''urpmi.addmedia'' ''_urpmi''
17 compdump:44> print -r - ''urpmf'' ''_urpmi''
17 compdump:44> print -r - ''unlz4'' ''_lz4''
17 compdump:44> print -r - ''unlimit'' ''_limits''
17 compdump:44> print -r - ''unix2mac'' ''_dos2unix''
17 compdump:44> print -r - ''units'' ''_units''
17 compdump:44> print -r - ''uname'' ''_uname''
17 compdump:44> print -r - ''unace'' ''_unace''
17 compdump:44> print -r - ''umount'' ''_mount''
17 compdump:44> print -r - ''uml_switch'' ''_uml''
17 compdump:44> print -r - ''typeset'' ''_typeset''
17 compdump:44> print -r - ''twist'' ''_twisted''
17 compdump:44> print -r - ''twidge'' ''_twidge''
17 compdump:44> print -r - ''tune2fs'' ''_tune2fs''
17 compdump:44> print -r - ''ttyctl'' ''_ttyctl''
17 compdump:44> print -r - ''true'' ''_nothing''
17 compdump:44> print -r - ''trove'' ''_openstack''
17 compdump:44> print -r - ''trial'' ''_twisted''
17 compdump:44> print -r - ''tree'' ''_tree''
17 compdump:44> print -r - ''trash-put'' ''_trash-put''
17 compdump:44> print -r - ''trash-list'' ''_trash-list''
17 compdump:44> print -r - ''transmission-remote'' ''_transmission''
17 compdump:44> print -r - ''traceroute'' ''_hosts''
17 compdump:44> print -r - ''tr'' ''_tr''
17 compdump:44> print -r - ''tpkg-update'' ''_toolchain-source''
17 compdump:44> print -r - ''tpb'' ''_tpb''
17 compdump:44> print -r - ''totdconfig'' ''_totd''
17 compdump:44> print -r - ''tmuxinator'' ''_tmuxinator''
17 compdump:44> print -r - ''tmux'' ''_tmux''
17 compdump:44> print -r - ''tload'' ''_tload''
17 compdump:44> print -r - ''tkconch'' ''_twisted''
17 compdump:44> print -r - ''times'' ''_nothing''
17 compdump:44> print -r - ''thor'' ''_thor''
17 compdump:44> print -r - ''texindex'' ''_texinfo''
17 compdump:44> print -r - ''texi2any'' ''_texinfo''
17 compdump:44> print -r - ''tde'' ''_devtodo''
17 compdump:44> print -r - ''tcptraceroute'' ''_tcptraceroute''
17 compdump:44> print -r - ''tarsnap'' ''_tarsnap''
17 compdump:44> print -r - ''tar'' ''_tar''
17 compdump:44> print -r - ''system_profiler'' ''_system_profiler''
17 compdump:44> print -r - ''systat'' ''_systat''
17 compdump:44> print -r - ''sysrc'' ''_sysrc''
17 compdump:44> print -r - ''sysctl'' ''_sysctl''
17 compdump:44> print -r - ''swanctl'' ''_swanctl''
17 compdump:44> print -r - ''sw_vers'' ''_sw_vers''
17 compdump:44> print -r - ''svnadmin-static'' ''_subversion''
17 compdump:44> print -r - ''svcs'' ''_svcs''
17 compdump:44> print -r - ''svccfg'' ''_svccfg''
17 compdump:44> print -r - ''svcadm'' ''_svcadm''
17 compdump:44> print -r - ''surfraw'' ''_surfraw''
17 compdump:44> print -r - ''sum'' ''_cksum''
17 compdump:44> print -r - ''sudo'' ''_sudo''
17 compdump:44> print -r - ''subliminal'' ''_subliminal''
17 compdump:44> print -r - ''su'' ''_su''
17 compdump:44> print -r - ''strongswan'' ''_ipsec''
17 compdump:44> print -r - ''strings'' ''_strings''
17 compdump:44> print -r - ''strace64'' ''_strace''
17 compdump:44> print -r - ''stop'' ''_initctl''
17 compdump:44> print -r - ''status'' ''_initctl''
17 compdump:44> print -r - ''start'' ''_initctl''
17 compdump:44> print -r - ''star'' ''_tar''
17 compdump:44> print -r - ''ssh-keyscan'' ''_ssh''
17 compdump:44> print -r - ''ssh-agent'' ''_ssh''
17 compdump:44> print -r - ''ss'' ''_ss''
17 compdump:44> print -r - ''srm'' ''_srm''
17 compdump:44> print -r - ''sqsh'' ''_sqsh''
17 compdump:44> print -r - ''sqlite'' ''_sqlite''
17 compdump:44> print -r - ''source'' ''_source''
17 compdump:44> print -r - ''sort'' ''_sort''
17 compdump:44> print -r - ''sockstat'' ''_sockstat''
17 compdump:44> print -r - ''soa'' ''_hosts''
17 compdump:44> print -r - ''smitty'' ''_smit''
17 compdump:44> print -r - ''smartctl'' ''_smartmontools''
17 compdump:44> print -r - ''slrn'' ''_slrn''
17 compdump:44> print -r - ''skein512'' ''_cksum''
17 compdump:44> print -r - ''sisu'' ''_sisu''
17 compdump:44> print -r - ''shutdown'' ''_shutdown''
17 compdump:44> print -r - ''showoff'' ''_showoff''
17 compdump:44> print -r - ''showchar'' ''_psutils''
17 compdump:44> print -r - ''shift'' ''_arrays''
17 compdump:44> print -r - ''sha512sum'' ''_md5sum''
17 compdump:44> print -r - ''sha384sum'' ''_md5sum''
17 compdump:44> print -r - ''sh'' ''_sh''
17 compdump:44> print -r - ''setxkbmap'' ''_setxkbmap''
17 compdump:44> print -r - ''setup.py'' ''_setup.py''
17 compdump:44> print -r - ''setfacl'' ''_setfacl''
17 compdump:44> print -r - ''set'' ''_set''
17 compdump:44> print -r - ''seq'' ''_seq''
17 compdump:44> print -r - ''sed'' ''_sed''
17 compdump:44> print -r - ''sdd'' ''_sdd''
17 compdump:44> print -r - ''schedtool'' ''_schedtool''
17 compdump:44> print -r - ''scalac'' ''_scala''
17 compdump:44> print -r - ''savecore'' ''_savecore''
17 compdump:44> print -r - ''sahara'' ''_openstack''
17 compdump:44> print -r - ''sact'' ''_sccs''
17 compdump:44> print -r - ''rwho'' ''_hosts''
17 compdump:44> print -r - ''rusage'' ''_precommand''
17 compdump:44> print -r - ''run-help'' ''_run-help''
17 compdump:44> print -r - ''ruby'' ''_ruby''
17 compdump:44> print -r - ''rpmverify'' ''_rpm''
17 compdump:44> print -r - ''rpmspec'' ''_rpm''
17 compdump:44> print -r - ''rmdel'' ''_sccs''
17 compdump:44> print -r - ''rmd160'' ''_cksum''
17 compdump:44> print -r - ''rmadison'' ''_madison''
17 compdump:44> print -r - ''restart'' ''_initctl''
17 compdump:44> print -r - ''reportbug'' ''_bug''
17 compdump:44> print -r - ''renice'' ''_renice''
17 compdump:44> print -r - ''removepkg'' ''_pkgtool''
17 compdump:44> print -r - ''refile'' ''_mh''
17 compdump:44> print -r - ''redis-cli'' ''_redis-cli''
17 compdump:44> print -r - ''rebootin'' ''_rebootin''
17 compdump:44> print -r - ''rdesktop'' ''_rdesktop''
17 compdump:44> print -r - ''rcsdiff'' ''_rcs''
17 compdump:44> print -r - ''rcs'' ''_rcs''
17 compdump:44> print -r - ''rclone'' ''_rclone''
17 compdump:44> print -r - ''rc'' ''_sh''
17 compdump:44> print -r - ''ralio'' ''_ralio''
17 compdump:44> print -r - ''rake'' ''_rake''
17 compdump:44> print -r - ''rails'' ''_rails''
17 compdump:44> print -r - ''qtplay'' ''_qtplay''
17 compdump:44> print -r - ''qiv'' ''_qiv''
17 compdump:44> print -r - ''pyhtmlizer'' ''_twisted''
17 compdump:44> print -r - ''pygmentize'' ''_pygmentize''
17 compdump:44> print -r - ''pwait'' ''_pids''
17 compdump:44> print -r - ''pv'' ''_pv''
17 compdump:44> print -r - ''putclip.exe'' ''_putclip''
17 compdump:44> print -r - ''pushd'' ''_cd''
17 compdump:44> print -r - ''ptree'' ''_ptree''
17 compdump:44> print -r - ''pswrap'' ''_postscript''
17 compdump:44> print -r - ''pstops'' ''_psutils''
17 compdump:44> print -r - ''pstop'' ''_pids''
17 compdump:44> print -r - ''psselect'' ''_psutils''
17 compdump:44> print -r - ''psql'' ''_postgresql''
17 compdump:44> print -r - ''psig'' ''_pids''
17 compdump:44> print -r - ''pscp'' ''_pscp''
17 compdump:44> print -r - ''ps2ps'' ''_postscript''
17 compdump:44> print -r - ''ps2pdfwr'' ''_postscript''
17 compdump:44> print -r - ''ps2pdf12'' ''_postscript''
17 compdump:44> print -r - ''ps2pdf'' ''_postscript''
17 compdump:44> print -r - ''ps2ascii'' ''_pspdf''
17 compdump:44> print -r - ''prt'' ''_sccs''
17 compdump:44> print -r - ''prs'' ''_sccs''
17 compdump:44> print -r - ''prove'' ''_prove''
17 compdump:44> print -r - ''protoc'' ''_protoc''
17 compdump:44> print -r - ''prompt'' ''_prompt''
17 compdump:44> print -r - ''printf'' ''_print''
17 compdump:44> print -r - ''print'' ''_print''
17 compdump:44> print -r - ''powerd'' ''_powerd''
17 compdump:44> print -r - ''postqueue'' ''_postfix''
17 compdump:44> print -r - ''popd'' ''_directory_stack''
17 compdump:44> print -r - ''policytool'' ''_java''
17 compdump:44> print -r - ''podgrep'' ''_perl_modules''
17 compdump:44> print -r - ''pmvers'' ''_perl_modules''
17 compdump:44> print -r - ''pmload'' ''_perl_modules''
17 compdump:44> print -r - ''pmfunc'' ''_perl_modules''
17 compdump:44> print -r - ''pmdesc'' ''_perl_modules''
17 compdump:44> print -r - ''plutil'' ''_plutil''
17 compdump:44> print -r - ''pkill'' ''_pgrep''
17 compdump:44> print -r - ''pkgrm'' ''_pkgrm''
17 compdump:44> print -r - ''pkginfo'' ''_pkginfo''
17 compdump:44> print -r - ''pkgadd'' ''_pkgadd''
17 compdump:44> print -r - ''pkg_add'' ''_bsd_pkg''
17 compdump:44> print -r - ''pkg-config'' ''_pkg-config''
17 compdump:44> print -r - ''piuparts'' ''_piuparts''
17 compdump:44> print -r - ''pipenv'' ''_pipenv''
17 compdump:44> print -r - ''ping'' ''_ping''
17 compdump:44> print -r - ''pinef'' ''_pine''
17 compdump:44> print -r - ''picocom'' ''_picocom''
17 compdump:44> print -r - ''php'' ''_php''
17 compdump:44> print -r - ''pg_isready'' ''_postgresql''
17 compdump:44> print -r - ''pg_dump'' ''_postgresql''
17 compdump:44> print -r - ''pg_ctl'' ''_postgresql''
17 compdump:44> print -r - ''perl'' ''_perl''
17 compdump:44> print -r - ''pdksh'' ''_sh''
17 compdump:44> print -r - ''pdftexi2dvi'' ''_texinfo''
17 compdump:44> print -r - ''pdfopt'' ''_pdf''
17 compdump:44> print -r - ''pdfimages'' ''_pdf''
17 compdump:44> print -r - ''pdf2ps'' ''_pdf''
17 compdump:44> print -r - ''pcred'' ''_pids''
17 compdump:44> print -r - ''pbuilder'' ''_pbuilder''
17 compdump:44> print -r - ''pbcopy'' ''_pbcopy''
17 compdump:44> print -r - ''patool'' ''_patool''
17 compdump:44> print -r - ''passwd'' ''_users''
17 compdump:44> print -r - ''pandoc'' ''_pandoc''
17 compdump:44> print -r - ''pack'' ''_pack''
17 compdump:44> print -r - ''p4'' ''_perforce''
17 compdump:44> print -r - ''opkg'' ''_opkg''
17 compdump:44> print -r - ''opera-next'' ''_webbrowser''
17 compdump:44> print -r - ''openstack'' ''_openstack''
17 compdump:44> print -r - ''openssl'' ''_openssl''
17 compdump:44> print -r - ''open'' ''_open''
17 compdump:44> print -r - ''okular'' ''_okular''
17 compdump:44> print -r - ''ogg123'' ''_vorbis''
17 compdump:44> print -r - ''od'' ''_od''
17 compdump:44> print -r - ''nvram'' ''_nvram''
17 compdump:44> print -r - ''nslookup'' ''_nslookup''
17 compdump:44> print -r - ''npm'' ''_npm''
17 compdump:44> print -r - ''nmblookup'' ''_samba''
17 compdump:44> print -r - ''nmap'' ''_nmap''
17 compdump:44> print -r - ''nice'' ''_nice''
17 compdump:44> print -r - ''nginx'' ''_nginx''
17 compdump:44> print -r - ''newgrp'' ''_groups''
17 compdump:44> print -r - ''new'' ''_mh''
17 compdump:44> print -r - ''networksetup'' ''_networksetup''
17 compdump:44> print -r - ''netstat'' ''_netstat''
17 compdump:44> print -r - ''nedit'' ''_nedit''
17 compdump:44> print -r - ''ncftp'' ''_ncftp''
17 compdump:44> print -r - ''nc'' ''_netcat''
17 compdump:44> print -r - ''native2ascii'' ''_java''
17 compdump:44> print -r - ''nanoc'' ''_nanoc''
17 compdump:44> print -r - ''nano'' ''_nano''
17 compdump:44> print -r - ''mysqlimport'' ''_mysql_utils''
17 compdump:44> print -r - ''mysqldiff'' ''_mysqldiff''
17 compdump:44> print -r - ''mx'' ''_hosts''
17 compdump:44> print -r - ''mvn'' ''_mvn''
17 compdump:44> print -r - ''mv'' ''_mv''
17 compdump:44> print -r - ''murano'' ''_openstack''
17 compdump:44> print -r - ''mupdf'' ''_mupdf''
17 compdump:44> print -r - ''mullvad'' ''_mullvad''
17 compdump:44> print -r - ''mtr'' ''_mtr''
17 compdump:44> print -r - ''msgchk'' ''_mh''
17 compdump:44> print -r - ''mread'' ''_mtools''
17 compdump:44> print -r - ''mr'' ''_myrepos''
17 compdump:44> print -r - ''mpstat'' ''_sysstat''
17 compdump:44> print -r - ''mplayer'' ''_mplayer''
17 compdump:44> print -r - ''mozilla'' ''_mozilla''
17 compdump:44> print -r - ''modprobe'' ''_modutils''
17 compdump:44> print -r - ''mmm'' ''_webbrowser''
17 compdump:44> print -r - ''mmd'' ''_mtools''
17 compdump:44> print -r - ''mktunes'' ''_gnupod''
17 compdump:44> print -r - ''mktemp'' ''_mktemp''
17 compdump:44> print -r - ''mkshortcut'' ''_mkshortcut''
17 compdump:44> print -r - ''mknod'' ''_mknod''
17 compdump:44> print -r - ''mkisofs'' ''_growisofs''
17 compdump:44> print -r - ''mkdir'' ''_mkdir''
17 compdump:44> print -r - ''mhpath'' ''_mh''
17 compdump:44> print -r - ''mhparam'' ''_mh''
17 compdump:44> print -r - ''mhn'' ''_mh''
17 compdump:44> print -r - ''mhmail'' ''_mh''
17 compdump:44> print -r - ''mhlist'' ''_mh''
17 compdump:44> print -r - ''mergechanges'' ''_mergechanges''
17 compdump:44> print -r - ''mdeltree'' ''_mtools''
17 compdump:44> print -r - ''md5'' ''_cksum''
17 compdump:44> print -r - ''md4'' ''_cksum''
17 compdump:44> print -r - ''mcd'' ''_mtools''
17 compdump:44> print -r - ''mc'' ''_mc''
17 compdump:44> print -r - ''mattrib'' ''_mtools''
17 compdump:44> print -r - ''matlab'' ''_matlab''
17 compdump:44> print -r - ''manage.py'' ''_django''
17 compdump:44> print -r - ''man'' ''_man''
17 compdump:44> print -r - ''makepkg'' ''_pkgtool''
17 compdump:44> print -r - ''make-kpkg'' ''_make-kpkg''
17 compdump:44> print -r - ''mac2unix'' ''_dos2unix''
17 compdump:44> print -r - ''luarocks'' ''_luarocks''
17 compdump:44> print -r - ''ltrace'' ''_ltrace''
17 compdump:44> print -r - ''lsdev'' ''_lsdev''
17 compdump:44> print -r - ''lscfg'' ''_lscfg''
17 compdump:44> print -r - ''lpoptions'' ''_lp''
17 compdump:44> print -r - ''lpinfo'' ''_lp''
17 compdump:44> print -r - ''lpadmin'' ''_lp''
17 compdump:44> print -r - ''lp'' ''_lp''
17 compdump:44> print -r - ''look'' ''_look''
17 compdump:44> print -r - ''logname'' ''_nothing''
17 compdump:44> print -r - ''locate'' ''_locate''
17 compdump:44> print -r - ''loadkeys'' ''_loadkeys''
17 compdump:44> print -r - ''llvm-gcc'' ''_gcc''
17 compdump:44> print -r - ''llvm-g++'' ''_gcc''
17 compdump:44> print -r - ''linux'' ''_uml''
17 compdump:44> print -r - ''lintian-info'' ''_lintian''
17 compdump:44> print -r - ''links'' ''_links''
17 compdump:44> print -r - ''limit'' ''_limit''
17 compdump:44> print -r - ''let'' ''_math''
17 compdump:44> print -r - ''ldd'' ''_ldd''
17 compdump:44> print -r - ''ldconfig.real'' ''_ldconfig''
17 compdump:44> print -r - ''ldconfig'' ''_ldconfig''
17 compdump:44> print -r - ''latexmk'' ''_tex''
17 compdump:44> print -r - ''last'' ''_last''
17 compdump:44> print -r - ''konqueror'' ''_webbrowser''
17 compdump:44> print -r - ''kldload'' ''_kld''
17 compdump:44> print -r - ''kioclient'' ''_kfmclient''
17 compdump:44> print -r - ''killall5'' ''_killall''
17 compdump:44> print -r - ''keytool'' ''_java''
17 compdump:44> print -r - ''keystone'' ''_openstack''
17 compdump:44> print -r - ''kak'' ''_kak''
17 compdump:44> print -r - ''jrnl'' ''_jrnl''
17 compdump:44> print -r - ''jq'' ''_jq''
17 compdump:44> print -r - ''jot'' ''_jot''
17 compdump:44> print -r - ''jonas'' ''_jonas''
17 compdump:44> print -r - ''join'' ''_join''
17 compdump:44> print -r - ''joe'' ''_joe''
17 compdump:44> print -r - ''jmeter'' ''_jmeter''
17 compdump:44> print -r - ''javac'' ''_java''
17 compdump:44> print -r - ''java'' ''_java''
17 compdump:44> print -r - ''jarsigner'' ''_java''
17 compdump:44> print -r - ''jar'' ''_java''
17 compdump:44> print -r - ''ispell'' ''_ispell''
17 compdump:44> print -r - ''isag'' ''_sysstat''
17 compdump:44> print -r - ''irb'' ''_ruby''
17 compdump:44> print -r - ''iptables-save'' ''_iptables''
17 compdump:44> print -r - ''iptables-restore'' ''_iptables''
17 compdump:44> print -r - ''ipsec'' ''_ipsec''
17 compdump:44> print -r - ''ipkg'' ''_opkg''
17 compdump:44> print -r - ''ipadm'' ''_ipadm''
17 compdump:44> print -r - ''ip6tables-save'' ''_iptables''
17 compdump:44> print -r - ''ip6tables-restore'' ''_iptables''
17 compdump:44> print -r - ''ip'' ''_ip''
17 compdump:44> print -r - ''iostat'' ''_iostat''
17 compdump:44> print -r - ''ionice'' ''_ionice''
17 compdump:44> print -r - ''inxi'' ''_inxi''
17 compdump:44> print -r - ''invoke-rc.d'' ''_invoke-rc.d''
17 compdump:44> print -r - ''initdb'' ''_postgresql''
17 compdump:44> print -r - ''initctl'' ''_initctl''
17 compdump:44> print -r - ''inetadm'' ''_inetadm''
17 compdump:44> print -r - ''import'' ''_imagemagick''
17 compdump:44> print -r - ''ifdown'' ''_net_interfaces''
17 compdump:44> print -r - ''ifconfig'' ''_ifconfig''
17 compdump:44> print -r - ''identify'' ''_imagemagick''
17 compdump:44> print -r - ''id'' ''_id''
17 compdump:44> print -r - ''iconv'' ''_iconv''
17 compdump:44> print -r - ''hwinfo'' ''_hwinfo''
17 compdump:44> print -r - ''hub'' ''_hub''
17 compdump:44> print -r - ''host'' ''_host''
17 compdump:44> print -r - ''hledger'' ''_hledger''
17 compdump:44> print -r - ''history'' ''_fc''
17 compdump:44> print -r - ''heroku'' ''_heroku''
17 compdump:44> print -r - ''hdiutil'' ''_hdiutil''
17 compdump:44> print -r - ''gview'' ''_vim''
17 compdump:44> print -r - ''guptime'' ''_uptime''
17 compdump:44> print -r - ''guilt-top'' ''_guilt''
17 compdump:44> print -r - ''guilt-rm'' ''_guilt''
17 compdump:44> print -r - ''guilt-next'' ''_guilt''
17 compdump:44> print -r - ''guilt-new'' ''_guilt''
17 compdump:44> print -r - ''guilt-fork'' ''_guilt''
17 compdump:44> print -r - ''guilt-delete'' ''_guilt''
17 compdump:44> print -r - ''guilt-add'' ''_guilt''
17 compdump:44> print -r - ''guilt'' ''_guilt''
17 compdump:44> print -r - ''gtk-launch'' ''_gtk-launch''
17 compdump:44> print -r - ''gsum'' ''_cksum''
17 compdump:44> print -r - ''gstrings'' ''_strings''
17 compdump:44> print -r - ''gstdbuf'' ''_stdbuf''
17 compdump:44> print -r - ''gsplit'' ''_split''
17 compdump:44> print -r - ''gsnd'' ''_pspdf''
17 compdump:44> print -r - ''gsha512sum'' ''_md5sum''
17 compdump:44> print -r - ''gsha256sum'' ''_md5sum''
17 compdump:44> print -r - ''gsha224sum'' ''_md5sum''
17 compdump:44> print -r - ''gsha1sum'' ''_md5sum''
17 compdump:44> print -r - ''gsettings'' ''_gsettings''
17 compdump:44> print -r - ''groups'' ''_users''
17 compdump:44> print -r - ''groff'' ''_groff''
17 compdump:44> print -r - ''grep-excuses'' ''_grep-excuses''
17 compdump:44> print -r - ''grep'' ''_grep''
17 compdump:44> print -r - ''greadlink'' ''_readlink''
17 compdump:44> print -r - ''gradlew'' ''_gradle''
17 compdump:44> print -r - ''gqview'' ''_gqview''
17 compdump:44> print -r - ''gprof'' ''_gprof''
17 compdump:44> print -r - ''gphoto2'' ''_gphoto2''
17 compdump:44> print -r - ''gpg2'' ''_gpg''
17 compdump:44> print -r - ''gpg-zip'' ''_gpg''
17 compdump:44> print -r - ''go'' ''_golang''
17 compdump:44> print -r - ''gnupod_INIT.pl'' ''_gnupod''
17 compdump:44> print -r - ''gnumfmt'' ''_numfmt''
17 compdump:44> print -r - ''gnocchi'' ''_openstack''
17 compdump:44> print -r - ''gmplayer'' ''_mplayer''
17 compdump:44> print -r - ''gmktemp'' ''_mktemp''
17 compdump:44> print -r - ''gmkdir'' ''_mkdir''
17 compdump:44> print -r - ''gmake'' ''_make''
17 compdump:44> print -r - ''global'' ''_global''
17 compdump:44> print -r - ''glance'' ''_openstack''
17 compdump:44> print -r - ''gjoin'' ''_join''
17 compdump:44> print -r - ''gitk'' ''_git''
17 compdump:44> print -r - ''git-wtf'' ''_git-wtf''
17 compdump:44> print -r - ''git-revise'' ''_git-revise''
17 compdump:44> print -r - ''git-journal'' ''_git-journal''
17 compdump:44> print -r - ''git'' ''_git''
17 compdump:44> print -r - ''gist'' ''_gist''
17 compdump:44> print -r - ''gid'' ''_id''
17 compdump:44> print -r - ''ghostview'' ''_pspdf''
17 compdump:44> print -r - ''ghead'' ''_head''
17 compdump:44> print -r - ''ghc-pkg'' ''_ghc''
17 compdump:44> print -r - ''ghc'' ''_ghc''
17 compdump:44> print -r - ''ggu'' ''_git''
17 compdump:44> print -r - ''ggfl'' ''_git''
17 compdump:44> print -r - ''ggf'' ''_git''
17 compdump:44> print -r - ''gfold'' ''_fold''
17 compdump:44> print -r - ''gfind'' ''_find''
17 compdump:44> print -r - ''gfgrep'' ''_grep''
17 compdump:44> print -r - ''getopt'' ''_getopt''
17 compdump:44> print -r - ''getmail'' ''_getmail''
17 compdump:44> print -r - ''getfacl.exe'' ''_getfacl''
17 compdump:44> print -r - ''getclip.exe'' ''_getclip''
17 compdump:44> print -r - ''getafm'' ''_psutils''
17 compdump:44> print -r - ''get'' ''_sccs''
17 compdump:44> print -r - ''genisoimage'' ''_genisoimage''
17 compdump:44> print -r - ''geany'' ''_geany''
17 compdump:44> print -r - ''gdu'' ''_du''
17 compdump:44> print -r - ''gdnolock'' ''_git''
17 compdump:44> print -r - ''gdate'' ''_date''
17 compdump:44> print -r - ''gcut'' ''_cut''
17 compdump:44> print -r - ''gcore'' ''_gcore''
17 compdump:44> print -r - ''gchmod'' ''_chmod''
17 compdump:44> print -r - ''gchgrp'' ''_chown''
17 compdump:44> print -r - ''gcc'' ''_gcc''
17 compdump:44> print -r - ''gbasename'' ''_basename''
17 compdump:44> print -r - ''gbase32'' ''_base64''
17 compdump:44> print -r - ''g++'' ''_gcc''
17 compdump:44> print -r - ''fwhois'' ''_whois''
17 compdump:44> print -r - ''fw_update'' ''_fw_update''
17 compdump:44> print -r - ''fusermount'' ''_fusermount''
17 compdump:44> print -r - ''fuser'' ''_fuser''
17 compdump:44> print -r - ''functions'' ''_typeset''
17 compdump:44> print -r - ''freezer'' ''_openstack''
17 compdump:44> print -r - ''forw'' ''_mh''
17 compdump:44> print -r - ''folders'' ''_mh''
17 compdump:44> print -r - ''folder'' ''_mh''
17 compdump:44> print -r - ''fold'' ''_fold''
17 compdump:44> print -r - ''fned'' ''_zed''
17 compdump:44> print -r - ''float'' ''_typeset''
17 compdump:44> print -r - ''flist'' ''_mh''
17 compdump:44> print -r - ''flipdiff'' ''_patchutils''
17 compdump:44> print -r - ''flex++'' ''_flex''
17 compdump:44> print -r - ''flex'' ''_flex''
17 compdump:44> print -r - ''fixwpps'' ''_psutils''
17 compdump:44> print -r - ''fixtpps'' ''_psutils''
17 compdump:44> print -r - ''fixpspps'' ''_psutils''
17 compdump:44> print -r - ''fixdlsrps'' ''_psutils''
17 compdump:44> print -r - ''findmnt'' ''_findmnt''
17 compdump:44> print -r - ''findaffix'' ''_ispell''
17 compdump:44> print -r - ''ffmpeg'' ''_ffmpeg''
17 compdump:44> print -r - ''ffind'' ''_ffind''
17 compdump:44> print -r - ''fc-match'' ''_xft_fonts''
17 compdump:44> print -r - ''fc-list'' ''_xft_fonts''
17 compdump:44> print -r - ''false'' ''_nothing''
17 compdump:44> print -r - ''fakeroot'' ''_fakeroot''
17 compdump:44> print -r - ''express'' ''_webbrowser''
17 compdump:44> print -r - ''export'' ''_typeset''
17 compdump:44> print -r - ''explodepkg'' ''_pkgtool''
17 compdump:44> print -r - ''exec'' ''_exec''
17 compdump:44> print -r - ''eu-strings'' ''_strings''
17 compdump:44> print -r - ''etags'' ''_etags''
17 compdump:44> print -r - ''espeak'' ''_espeak''
17 compdump:44> print -r - ''epsffit'' ''_psutils''
17 compdump:44> print -r - ''eog'' ''_eog''
17 compdump:44> print -r - ''env'' ''_env''
17 compdump:44> print -r - ''entr'' ''_entr''
17 compdump:44> print -r - ''enable'' ''_enable''
17 compdump:44> print -r - ''elinks'' ''_elinks''
17 compdump:44> print -r - ''elfdump'' ''_elfdump''
17 compdump:44> print -r - ''egrep'' ''_grep''
17 compdump:44> print -r - ''echoti'' ''_echoti''
17 compdump:44> print -r - ''ecasound'' ''_ecasound''
17 compdump:44> print -r - ''eatmydata'' ''_precommand''
17 compdump:44> print -r - ''dwb'' ''_webbrowser''
17 compdump:44> print -r - ''dviselect'' ''_dvi''
17 compdump:44> print -r - ''dvips'' ''_dvi''
17 compdump:44> print -r - ''dvipdf'' ''_dvi''
17 compdump:44> print -r - ''dvicopy'' ''_dvi''
17 compdump:44> print -r - ''dviconcat'' ''_dvi''
17 compdump:44> print -r - ''dvc'' ''_dvc''
17 compdump:44> print -r - ''dupload'' ''_dupload''
17 compdump:44> print -r - ''dumper'' ''_dumper''
17 compdump:44> print -r - ''dumpadm'' ''_dumpadm''
17 compdump:44> print -r - ''dtruss'' ''_dtruss''
17 compdump:44> print -r - ''drush'' ''_drush''
17 compdump:44> print -r - ''dropdb'' ''_postgresql''
17 compdump:44> print -r - ''dpkg-source'' ''_dpkg_source''
17 compdump:44> print -r - ''dpkg-query'' ''_dpkg''
17 compdump:44> print -r - ''dpkg-cross'' ''_dpkg-cross''
17 compdump:44> print -r - ''dosdel'' ''_floppy''
17 compdump:44> print -r - ''domainname'' ''_yp''
17 compdump:44> print -r - ''dnf-3'' ''_dnf''
17 compdump:44> print -r - ''dmidecode'' ''_dmidecode''
17 compdump:44> print -r - ''dmesg'' ''_dmesg''
17 compdump:44> print -r - ''dlocate'' ''_dlocate''
17 compdump:44> print -r - ''dkms'' ''_dkms''
17 compdump:44> print -r - ''display'' ''_imagemagick''
17 compdump:44> print -r - ''disown'' ''_jobs_fg''
17 compdump:44> print -r - ''dircmp'' ''_directories''
17 compdump:44> print -r - ''dig'' ''_dig''
17 compdump:44> print -r - ''diff'' ''_diff''
17 compdump:44> print -r - ''devtodo'' ''_devtodo''
17 compdump:44> print -r - ''declare'' ''_typeset''
17 compdump:44> print -r - ''deborphan'' ''_deborphan''
17 compdump:44> print -r - ''debfoster'' ''_debfoster''
17 compdump:44> print -r - ''debcheckout'' ''_debcheckout''
17 compdump:44> print -r - ''dcut'' ''_dcut''
17 compdump:44> print -r - ''dcopobject'' ''_dcop''
17 compdump:44> print -r - ''dcop'' ''_dcop''
17 compdump:44> print -r - ''dbus-launch'' ''_dbus''
17 compdump:44> print -r - ''dash'' ''_sh''
17 compdump:44> print -r - ''dak'' ''_dak''
17 compdump:44> print -r - ''dad'' ''_dad''
17 compdump:44> print -r - ''cygstart'' ''_cygstart''
17 compdump:44> print -r - ''cygserver'' ''_cygserver''
17 compdump:44> print -r - ''cygrunsrv'' ''_cygrunsrv''
17 compdump:44> print -r - ''cygpath'' ''_cygpath''
17 compdump:44> print -r - ''cygcheck'' ''_cygcheck''
17 compdump:44> print -r - ''cvsup'' ''_cvsup''
17 compdump:44> print -r - ''cvs'' ''_cvs''
17 compdump:44> print -r - ''cssh'' ''_cssh''
17 compdump:44> print -r - ''csh'' ''_sh''
17 compdump:44> print -r - ''createdb'' ''_postgresql''
17 compdump:44> print -r - ''cppcheck'' ''_cppcheck''
17 compdump:44> print -r - ''cplay'' ''_cplay''
17 compdump:44> print -r - ''cp'' ''_cp''
17 compdump:44> print -r - ''cowthink'' ''_cowsay''
17 compdump:44> print -r - ''coreadm'' ''_coreadm''
17 compdump:44> print -r - ''config.status'' ''_configure''
17 compdump:44> print -r - ''conan'' ''_conan''
17 compdump:44> print -r - ''composite'' ''_imagemagick''
17 compdump:44> print -r - ''composer.phar'' ''_composer''
17 compdump:44> print -r - ''compdef'' ''_compdef''
17 compdump:44> print -r - ''compadd'' ''_compadd''
17 compdump:44> print -r - ''command'' ''_command''
17 compdump:44> print -r - ''combine'' ''_imagemagick''
17 compdump:44> print -r - ''coffee'' ''_coffee''
17 compdump:44> print -r - ''code'' ''_code''
17 compdump:44> print -r - ''clusterdb'' ''_postgresql''
17 compdump:44> print -r - ''cloudkitty'' ''_openstack''
17 compdump:44> print -r - ''clay'' ''_clay''
17 compdump:44> print -r - ''clang++'' ''_gcc''
17 compdump:44> print -r - ''cksum'' ''_cksum''
17 compdump:44> print -r - ''ckeygen'' ''_twisted''
17 compdump:44> print -r - ''chromium'' ''_chromium''
17 compdump:44> print -r - ''chpass'' ''_chsh''
17 compdump:44> print -r - ''chown'' ''_chown''
17 compdump:44> print -r - ''choc'' ''_choc''
17 compdump:44> print -r - ''chkstow'' ''_stow''
17 compdump:44> print -r - ''chkconfig'' ''_chkconfig''
17 compdump:44> print -r - ''chgrp'' ''_chown''
17 compdump:44> print -r - ''chfn'' ''_users''
17 compdump:44> print -r - ''chcon'' ''_chcon''
17 compdump:44> print -r - ''cftp'' ''_twisted''
17 compdump:44> print -r - ''certtool'' ''_gnutls''
17 compdump:44> print -r - ''ceilometer'' ''_openstack''
17 compdump:44> print -r - ''cdrdao'' ''_cdrdao''
17 compdump:44> print -r - ''cdc'' ''_sccs''
17 compdump:44> print -r - ''ccache'' ''_ccache''
17 compdump:44> print -r - ''cat'' ''_cat''
17 compdump:44> print -r - ''cap'' ''_cap''
17 compdump:44> print -r - ''bzr'' ''_bzr''
17 compdump:44> print -r - ''bzip2'' ''_bzip2''
17 compdump:44> print -r - ''bzgrep'' ''_grep''
17 compdump:44> print -r - ''bzegrep'' ''_grep''
17 compdump:44> print -r - ''bunzip2'' ''_bzip2''
17 compdump:44> print -r - ''bundle'' ''_bundle''
17 compdump:44> print -r - ''buildhash'' ''_ispell''
17 compdump:44> print -r - ''bug'' ''_bug''
17 compdump:44> print -r - ''btrename'' ''_bittorrent''
17 compdump:44> print -r - ''btreannounce'' ''_bittorrent''
17 compdump:44> print -r - ''btmakemetafile'' ''_bittorrent''
17 compdump:44> print -r - ''btlaunchmanycurses'' ''_bittorrent''
17 compdump:44> print -r - ''btdownloadgui'' ''_bittorrent''
17 compdump:44> print -r - ''btdownloadcurses'' ''_bittorrent''
17 compdump:44> print -r - ''bsdtar'' ''_tar''
17 compdump:44> print -r - ''bsdinstall'' ''_bsdinstall''
17 compdump:44> print -r - ''bsdgrep'' ''_grep''
17 compdump:44> print -r - ''bsdconfig'' ''_bsdconfig''
17 compdump:44> print -r - ''bpython2-urwid'' ''_bpython''
17 compdump:44> print -r - ''bpython2'' ''_bpython''
17 compdump:44> print -r - ''bower'' ''_bower''
17 compdump:44> print -r - ''bogotune'' ''_bogofilter''
17 compdump:44> print -r - ''bmake'' ''_make''
17 compdump:44> print -r - ''bindkey'' ''_bindkey''
17 compdump:44> print -r - ''bg'' ''_jobs_bg''
17 compdump:44> print -r - ''basename'' ''_basename''
17 compdump:44> print -r - ''base32'' ''_base64''
17 compdump:44> print -r - ''b2sum'' ''_md5sum''
17 compdump:44> print -r - ''aws'' ''_aws''
17 compdump:44> print -r - ''avahi-resolve'' ''_avahi''
17 compdump:44> print -r - ''avahi-browse'' ''_avahi''
17 compdump:44> print -r - ''auto-apt'' ''_auto-apt''
17 compdump:44> print -r - ''atach'' ''_atach''
17 compdump:44> print -r - ''asdf'' ''_asdf''
17 compdump:44> print -r - ''asciinema'' ''_asciinema''
17 compdump:44> print -r - ''arp'' ''_arp''
17 compdump:44> print -r - ''apvlv'' ''_pdf''
17 compdump:44> print -r - ''apt-move'' ''_apt-move''
17 compdump:44> print -r - ''apt-get'' ''_apt''
17 compdump:44> print -r - ''apt-cdrom'' ''_apt''
17 compdump:43> _d_f=wiggle
17 compdump:43> _d_f=transmission-remote
17 compdump:43> _d_f=system_profiler
17 compdump:43> _d_f=rview
17 compdump:43> _d_f=make-kpkg
17 compdump:43> _d_f=gsha224sum
17 compdump:43> _d_f=grep-excuses
17 compdump:43> _d_f=glocate
17 compdump:43> _d_f=glance
17 compdump:43> _d_f=git-wtf
17 compdump:43> _d_f=fw_update
17 compdump:43> _d_f=fuser
17 compdump:43> _d_f=freebsd-make
17 compdump:43> _d_f=folders
17 compdump:43> _d_f=flipdiff
17 compdump:43> _d_f=findmnt
17 compdump:43> _d_f=find
17 compdump:43> _d_f=fc-list
17 compdump:43> _d_f=dhcpinfo
17 compdump:43> _d_f=dak
17 compdump:43> _d_f=cvsup
17 compdump:43> _d_f=btrename
17 compdump:43> _d_f=btmakemetafile
17 compdump:43> _d_f=btdownloadgui
17 compdump:43> _d_f=bsdtar
17 compdump:43> _d_f=bsdgrep
17 compdump:43> _d_f=brew
17 compdump:43> _d_f=bash
17 compdump:43> _d_f=asdf
17 compdump:43> _d_f=apache2ctl
17 compdump:43> _d_f=add-zle-hook-widget
17 compdump:43> _d_f=5g
17 compdump:43> _d_f=-value-,TERMINFO_DIRS,-default-
17 compdump:43> _d_f=-value-,PROMPT,-default-
17 compdump:43> _d_f=-value-,P4USER,-default-
17 compdump:43> _d_f=-value-,LDFLAGS,-default-
17 compdump:43> _d_f=-value-,GZIP,-default-
17 compdump:43> _d_f=-value-,ANDROID_LOG_TAGS,-default-
17 compdump:43> _d_f=-redirect-,<,unxz
17 compdump:43> _d_f=-redirect-,<,gzip
17 compdump:43> _d_f=-equal-
17 compdump:43> _d_f=-assign-parameter-
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:169> shift
17 compdef:164> _services[$cmd]=nc
17 compdef:164> [[ -n yes ]]
17 compdef:163> _comps[$cmd]=_yt-dlp
17 compdef:163> _comps[$cmd]=_xz
17 compdef:163> _comps[$cmd]=_restic
17 compdef:163> _comps[$cmd]=_restic
17 compdef:163> _comps[$cmd]=_mozilla
17 compdef:163> _comps[$cmd]=_meson
17 compdef:163> _comps[$cmd]=_gzip
17 compdef:163> _comps[$cmd]=_chown
17 compdef:162> [[ -z yes || -z _zattr ]]
17 compdef:162> [[ -z yes || -z _zattr ]]
17 compdef:162> [[ -z yes || -z _yp ]]
17 compdef:162> [[ -z yes || -z _yp ]]
17 compdef:162> [[ -z yes || -z _whois ]]
17 compdef:162> [[ -z yes || -z _who ]]
17 compdef:162> [[ -z yes || -z _which ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _webbrowser ]]
17 compdef:162> [[ -z yes || -z _w3m ]]
17 compdef:162> [[ -z yes || -z _vorbis ]]
17 compdef:162> [[ -z yes || -z _vnc ]]
17 compdef:162> [[ -z yes || -z _vnc ]]
17 compdef:162> [[ -z yes || -z _vnc ]]
17 compdef:162> [[ -z yes || -z _vmctl ]]
17 compdef:162> [[ -z yes || -z _vim ]]
17 compdef:162> [[ -z yes || -z _vim ]]
17 compdef:162> [[ -z yes || -z _vcsh ]]
17 compdef:162> [[ -z yes || -z _urxvt ]]
17 compdef:162> [[ -z yes || -z _urpmi ]]
17 compdef:162> [[ -z yes || -z _urpmi ]]
17 compdef:162> [[ -z yes || -z _update-rc.d ]]
17 compdef:162> [[ -z yes || -z _uml ]]
17 compdef:162> [[ -z yes || -z _typeset ]]
17 compdef:162> [[ -z yes || -z _typeset ]]
17 compdef:162> [[ -z yes || -z _typeset ]]
17 compdef:162> [[ -z yes || -z _tune2fs ]]
17 compdef:162> [[ -z yes || -z _trap ]]
17 compdef:162> [[ -z yes || -z _touch ]]
17 compdef:162> [[ -z yes || -z _toolchain-source ]]
17 compdef:162> [[ -z yes || -z _toolchain-source ]]
17 compdef:162> [[ -z yes || -z _tmux ]]
17 compdef:162> [[ -z yes || -z _tload ]]
17 compdef:162> [[ -z yes || -z _texinfo ]]
17 compdef:162> [[ -z yes || -z _texinfo ]]
17 compdef:162> [[ -z yes || -z _tex ]]
17 compdef:162> [[ -z yes || -z _tail ]]
17 compdef:162> [[ -z yes || -z _tac ]]
17 compdef:162> [[ -z yes || -z _sysstat ]]
17 compdef:162> [[ -z yes || -z _swift ]]
17 compdef:162> [[ -z yes || -z _su ]]
17 compdef:162> [[ -z yes || -z _stty ]]
17 compdef:162> [[ -z yes || -z _strftime ]]
17 compdef:162> [[ -z yes || -z _stat ]]
17 compdef:162> [[ -z yes || -z _sshfs ]]
17 compdef:162> [[ -z yes || -z _ssh ]]
17 compdef:162> [[ -z yes || -z _socket ]]
17 compdef:162> [[ -z yes || -z _smit ]]
17 compdef:162> [[ -z yes || -z _signify ]]
17 compdef:162> [[ -z yes || -z _shuf ]]
17 compdef:162> [[ -z yes || -z _shasum ]]
17 compdef:162> [[ -z yes || -z _sh ]]
17 compdef:162> [[ -z yes || -z _sh ]]
17 compdef:162> [[ -z yes || -z _setsid ]]
17 compdef:162> [[ -z yes || -z _scselect ]]
17 compdef:162> [[ -z yes || -z _samba ]]
17 compdef:162> [[ -z yes || -z _run-help ]]
17 compdef:162> [[ -z yes || -z _rlogin ]]
17 compdef:162> [[ -z yes || -z _rebootin ]]
17 compdef:162> [[ -z yes || -z _readelf ]]
17 compdef:162> [[ -z yes || -z _rar ]]
17 compdef:162> [[ -z yes || -z _ptree ]]
17 compdef:162> [[ -z yes || -z _pspdf ]]
17 compdef:162> [[ -z yes || -z _pspdf ]]
17 compdef:162> [[ -z yes || -z _pspdf ]]
17 compdef:162> [[ -z yes || -z _ps1234 ]]
17 compdef:162> [[ -z yes || -z _ps ]]
17 compdef:162> [[ -z yes || -z _precommand ]]
17 compdef:162> [[ -z yes || -z _postgresql ]]
17 compdef:162> [[ -z yes || -z _postgresql ]]
17 compdef:162> [[ -z yes || -z _postgresql ]]
17 compdef:162> [[ -z yes || -z _postgresql ]]
17 compdef:162> [[ -z yes || -z _postfix ]]
17 compdef:162> [[ -z yes || -z _plutil ]]
17 compdef:162> [[ -z yes || -z _pkgrm ]]
17 compdef:162> [[ -z yes || -z _pkgadd ]]
17 compdef:162> [[ -z yes || -z _pkg5 ]]
17 compdef:162> [[ -z yes || -z _piuparts ]]
17 compdef:162> [[ -z yes || -z _pids ]]
17 compdef:162> [[ -z yes || -z _pids ]]
17 compdef:162> [[ -z yes || -z _pids ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _perl_modules ]]
17 compdef:162> [[ -z yes || -z _pdf ]]
17 compdef:162> [[ -z yes || -z _pbuilder ]]
17 compdef:162> [[ -z yes || -z _pax ]]
17 compdef:162> [[ -z yes || -z _patchutils ]]
17 compdef:162> [[ -z yes || -z _patchutils ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _openstack ]]
17 compdef:162> [[ -z yes || -z _objdump ]]
17 compdef:162> [[ -z yes || -z _npm ]]
17 compdef:162> [[ -z yes || -z _nothing ]]
17 compdef:162> [[ -z yes || -z _nmap ]]
17 compdef:162> [[ -z yes || -z _mtools ]]
17 compdef:162> [[ -z yes || -z _mtools ]]
17 compdef:162> [[ -z yes || -z _mtools ]]
17 compdef:162> [[ -z yes || -z _mh ]]
17 compdef:162> [[ -z yes || -z _mh ]]
17 compdef:162> [[ -z yes || -z _mh ]]
17 compdef:162> [[ -z yes || -z _mh ]]
17 compdef:162> [[ -z yes || -z _mh ]]
17 compdef:162> [[ -z yes || -z _mdls ]]
17 compdef:162> [[ -z yes || -z _lz4 ]]
17 compdef:162> [[ -z yes || -z _lz4 ]]
17 compdef:162> [[ -z yes || -z _lua ]]
17 compdef:162> [[ -z yes || -z _lp ]]
17 compdef:162> [[ -z yes || -z _ln ]]
17 compdef:162> [[ -z yes || -z _libvirt ]]
17 compdef:162> [[ -z yes || -z _lha ]]
17 compdef:162> [[ -z yes || -z _java ]]
17 compdef:162> [[ -z yes || -z _java ]]
17 compdef:162> [[ -z yes || -z _java ]]
17 compdef:162> [[ -z yes || -z _java ]]
17 compdef:162> [[ -z yes || -z _ispell ]]
17 compdef:162> [[ -z yes || -z _ispell ]]
17 compdef:162> [[ -z yes || -z _iptables ]]
17 compdef:162> [[ -z yes || -z _iptables ]]
17 compdef:162> [[ -z yes || -z _initctl ]]
17 compdef:162> [[ -z yes || -z _initctl ]]
17 compdef:162> [[ -z yes || -z _imagemagick ]]
17 compdef:162> [[ -z yes || -z _imagemagick ]]
17 compdef:162> [[ -z yes || -z _imagemagick ]]
17 compdef:162> [[ -z yes || -z _hosts ]]
17 compdef:162> [[ -z yes || -z _grep ]]
17 compdef:162> [[ -z yes || -z _grep ]]
17 compdef:162> [[ -z yes || -z _grep ]]
17 compdef:162> [[ -z yes || -z _gnutls ]]
17 compdef:162> [[ -z yes || -z _gnupod ]]
17 compdef:162> [[ -z yes || -z _gnupod ]]
17 compdef:162> [[ -z yes || -z _gnupod ]]
17 compdef:162> [[ -z yes || -z _gnupod ]]
17 compdef:162> [[ -z yes || -z _git-journal ]]
17 compdef:162> [[ -z yes || -z _git-flow ]]
17 compdef:162> [[ -z yes || -z _gdb ]]
17 compdef:162> [[ -z yes || -z _gcc ]]
17 compdef:162> [[ -z yes || -z _gas ]]
17 compdef:162> [[ -z yes || -z _fw_update ]]
17 compdef:162> [[ -z yes || -z _fold ]]
17 compdef:162> [[ -z yes || -z _coreadm ]]
17 compdef:162> [[ -z yes || -z _cf ]]
17 compdef:162> [[ -z yes || -z _ccache ]]
17 compdef:162> [[ -z yes || -z _cask ]]
17 compdef:162> [[ -z yes || -z _bzip2 ]]
17 compdef:162> [[ -z yes || -z _bug ]]
17 compdef:162> [[ -z yes || -z _bpython ]]
17 compdef:162> [[ -z yes || -z _bpython ]]
17 compdef:162> [[ -z yes || -z _bittorrent ]]
17 compdef:162> [[ -z yes || -z _bittorrent ]]
17 compdef:162> [[ -z yes || -z _bittorrent ]]
17 compdef:162> [[ -z yes || -z _baz ]]
17 compdef:162> [[ -z yes || -z _base64 ]]
17 compdef:162> [[ -z yes || -z _avahi ]]
17 compdef:162> [[ -z yes || -z _avahi ]]
17 compdef:162> [[ -z yes || -z _attr ]]
17 compdef:162> [[ -z yes || -z _at ]]
17 compdef:162> [[ -z yes || -z _at ]]
17 compdef:162> [[ -z yes || -z _assign ]]
17 compdef:162> [[ -z yes || -z _apt ]]
17 compdef:162> [[ -z yes || -z _ansible ]]
17 compdef:162> [[ -z yes || -z _ansible ]]
17 compdef:162> [[ -z yes || -z _ansible ]]
17 compdef:162> [[ -z yes || -z _adb ]]
17 compdef:162> [[ -z yes || -z _adb ]]
17 compdef:160> svc=''
17 compdef:160> svc=''
17 compdef:160> svc=''
17 compdef:160> svc=''
17 compdef:159> cmd=vagrant
17 compdef:159> cmd=thor
17 compdef:159> cmd=md5sum
17 compdef:159> cmd=man
17 compdef:159> cmd=gprintenv
17 compdef:159> cmd=debsign
17 compdef:156> cmd=yaourt.static
17 compdef:156> cmd=ggfl
17 compdef:156> cmd=dch
17 compdef:156> cmd=_git_log_prettily
17 compdef:155> [[ zcat = *=* ]]
17 compdef:155> [[ xinput = *=* ]]
17 compdef:155> [[ xcode-select = *=* ]]
17 compdef:155> [[ truss = *=* ]]
17 compdef:155> [[ tpb = *=* ]]
17 compdef:155> [[ tox = *=* ]]
17 compdef:155> [[ tmuxp = *=* ]]
17 compdef:155> [[ tar = *=* ]]
17 compdef:155> [[ sha1sum = *=* ]]
17 compdef:155> [[ sdd = *=* ]]
17 compdef:155> [[ rspec = *=* ]]
17 compdef:155> [[ readshortcut = *=* ]]
17 compdef:155> [[ rclone = *=* ]]
17 compdef:155> [[ rails = *=* ]]
17 compdef:155> [[ portsnap = *=* ]]
17 compdef:155> [[ mpv = *=* ]]
17 compdef:155> [[ mkzsh = *=* ]]
17 compdef:155> [[ meson = *=* ]]
17 compdef:155> [[ matlab = *=* ]]
17 compdef:155> [[ gxargs = *=* ]]
17 compdef:155> [[ gcore = *=* ]]
17 compdef:155> [[ fs_usage = *=* ]]
17 compdef:155> [[ elfdump = *=* ]]
17 compdef:155> [[ dsh = *=* ]]
17 compdef:155> [[ dpatch-edit-patch = *=* ]]
17 compdef:155> [[ dchroot-dsa = *=* ]]
17 compdef:155> [[ cygrunsrv = *=* ]]
17 compdef:155> [[ curl = *=* ]]
17 compdef:155> [[ cu = *=* ]]
17 compdef:155> [[ cryptsetup = *=* ]]
17 compdef:155> [[ concourse = *=* ]]
17 compdef:155> [[ chrt = *=* ]]
17 compdef:155> [[ chown = *=* ]]
17 compdef:155> [[ cdr = *=* ]]
17 compdef:155> [[ calendar = *=* ]]
17 compdef:155> [[ bzr = *=* ]]
17 compdef:155> [[ -value-,TERMINFO_DIRS,-default- = *=* ]]
17 compdef:155> [[ -value-,DISPLAY,-default- = *=* ]]
17 compdef:155> [[ -redirect-,-default-,-default- = *=* ]]
17 compdef:155> [[ 'dch=debchange' = *=* ]]
17 compdef:155> [[ 'VBoxManage=vboxmanage' = *=* ]]
17 compdef:155> [[ '-redirect-,<,uncompress=uncompress' = *=* ]]
17 compdef:151> _postpatcomps[$1]=_shasum
17 compdef:151> _postpatcomps[$1]=_lua
17 compdef:151> _postpatcomps[$1]=_gem
17 compdef:151> _postpatcomps[$1]=_gcc
17 compdef:139> case  (postpattern)
17 compdef:139> case  (postpattern)
17 compdef:139> case  (pattern)
17 compdef:139> case  (pattern)
17 compdef:139> case  (pattern)
17 compdef:139> case  (*)
17 compdef:139> case  (*)
17 compdef:136> [[ yadm = -P ]]
17 compdef:136> [[ thor = -P ]]
17 compdef:136> [[ tarsnap = -P ]]
17 compdef:136> [[ screen = -P ]]
17 compdef:136> [[ ps2pdf = -P ]]
17 compdef:136> [[ newgrp = -P ]]
17 compdef:136> [[ groupdel = -P ]]
17 compdef:136> [[ glance = -P ]]
17 compdef:136> [[ debdiff = -P ]]
17 compdef:136> [[ _rclone = -P ]]
17 compdef:136> [[ -value-,RPROMPT2,-default- = -P ]]
17 compdef:136> [[ 'svnadmin-static=svnadmin' = -P ]]
17 compdef:136> [[ 'ggf=git-checkout' = -P ]]
17 compdef:134> [[ yadm = -p ]]
17 compdef:134> [[ xinput = -p ]]
17 compdef:134> [[ uml_switch = -p ]]
17 compdef:134> [[ sccs = -p ]]
17 compdef:134> [[ gsum = -p ]]
17 compdef:134> [[ force = -p ]]
17 compdef:134> [[ delta = -p ]]
17 compdef:134> [[ dash = -p ]]
17 compdef:134> [[ -math- = -p ]]
17 compdef:132> [[ zpool = -N ]]
17 compdef:132> [[ zip = -N ]]
17 compdef:132> [[ zfs = -N ]]
17 compdef:132> [[ xset = -N ]]
17 compdef:132> [[ xsel = -N ]]
17 compdef:132> [[ xpdf = -N ]]
17 compdef:132> [[ xmms2 = -N ]]
17 compdef:132> [[ wpa_cli = -N ]]
17 compdef:132> [[ wc = -N ]]
17 compdef:132> [[ wajig = -N ]]
17 compdef:132> [[ vserver = -N ]]
17 compdef:132> [[ vpnc = -N ]]
17 compdef:132> [[ unalias = -N ]]
17 compdef:132> [[ tty = -N ]]
17 compdef:132> [[ transmission-remote = -N ]]
17 compdef:132> [[ touch = -N ]]
17 compdef:132> [[ totdconfig = -N ]]
17 compdef:132> [[ tin = -N ]]
17 compdef:132> [[ tidy = -N ]]
17 compdef:132> [[ tcpdump = -N ]]
17 compdef:132> [[ tail = -N ]]
17 compdef:132> [[ swift = -N ]]
17 compdef:132> [[ svm = -N ]]
17 compdef:132> [[ svcs = -N ]]
17 compdef:132> [[ svcadm = -N ]]
17 compdef:132> [[ sudo = -N ]]
17 compdef:132> [[ subl = -N ]]
17 compdef:132> [[ srm = -N ]]
17 compdef:132> [[ showmount = -N ]]
17 compdef:132> [[ seq = -N ]]
17 compdef:132> [[ seaf-cli = -N ]]
17 compdef:132> [[ scutil = -N ]]
17 compdef:132> [[ script = -N ]]
17 compdef:132> [[ sc_usage = -N ]]
17 compdef:132> [[ rsync = -N ]]
17 compdef:132> [[ rsvm = -N ]]
17 compdef:132> [[ rrdtool = -N ]]
17 compdef:132> [[ rm = -N ]]
17 compdef:132> [[ readlink = -N ]]
17 compdef:132> [[ rclone = -N ]]
17 compdef:132> [[ psql = -N ]]
17 compdef:132> [[ pscp = -N ]]
17 compdef:132> [[ prstat = -N ]]
17 compdef:132> [[ print = -N ]]
17 compdef:132> [[ portmaster = -N ]]
17 compdef:132> [[ port = -N ]]
17 compdef:132> [[ pkgin = -N ]]
17 compdef:132> [[ pkg_add = -N ]]
17 compdef:132> [[ pkcon = -N ]]
17 compdef:132> [[ pixz = -N ]]
17 compdef:132> [[ perl = -N ]]
17 compdef:132> [[ pdm = -N ]]
17 compdef:132> [[ p4 = -N ]]
17 compdef:132> [[ od = -N ]]
17 compdef:132> [[ nvram = -N ]]
17 compdef:132> [[ nm = -N ]]
17 compdef:132> [[ nice = -N ]]
17 compdef:132> [[ nft = -N ]]
17 compdef:132> [[ netstat = -N ]]
17 compdef:132> [[ ncftp = -N ]]
17 compdef:132> [[ nautilus = -N ]]
17 compdef:132> [[ mvn = -N ]]
17 compdef:132> [[ mutt = -N ]]
17 compdef:132> [[ mussh = -N ]]
17 compdef:132> [[ mupdf = -N ]]
17 compdef:132> [[ mt = -N ]]
17 compdef:132> [[ mpc = -N ]]
17 compdef:132> [[ mosh = -N ]]
17 compdef:132> [[ moosic = -N ]]
17 compdef:132> [[ module-assistant = -N ]]
17 compdef:132> [[ mktemp = -N ]]
17 compdef:132> [[ mknod = -N ]]
17 compdef:132> [[ mii-tool = -N ]]
17 compdef:132> [[ mdutil = -N ]]
17 compdef:132> [[ mattrib = -N ]]
17 compdef:132> [[ make = -N ]]
17 compdef:132> [[ lzop = -N ]]
17 compdef:132> [[ lynx = -N ]]
17 compdef:132> [[ lsusb = -N ]]
17 compdef:132> [[ lsof = -N ]]
17 compdef:132> [[ lsmod = -N ]]
17 compdef:132> [[ lslv = -N ]]
17 compdef:132> [[ lsdev = -N ]]
17 compdef:132> [[ lscfg = -N ]]
17 compdef:132> [[ ls = -N ]]
17 compdef:132> [[ locate = -N ]]
17 compdef:132> [[ links = -N ]]
17 compdef:132> [[ less = -N ]]
17 compdef:132> [[ ksh = -N ]]
17 compdef:132> [[ killall = -N ]]
17 compdef:132> [[ kak = -N ]]
17 compdef:132> [[ jail = -N ]]
17 compdef:132> [[ ispell = -N ]]
17 compdef:132> [[ installpkg = -N ]]
17 compdef:132> [[ initctl = -N ]]
17 compdef:132> [[ iconv = -N ]]
17 compdef:132> [[ hotjava = -N ]]
17 compdef:132> [[ host = -N ]]
17 compdef:132> [[ hledger = -N ]]
17 compdef:132> [[ gzip = -N ]]
17 compdef:132> [[ gv = -N ]]
17 compdef:132> [[ gs = -N ]]
17 compdef:132> [[ grep = -N ]]
17 compdef:132> [[ gprintenv = -N ]]
17 compdef:132> [[ gpg = -N ]]
17 compdef:132> [[ gnupod_addsong = -N ]]
17 compdef:132> [[ gnome-gv = -N ]]
17 compdef:132> [[ gm = -N ]]
17 compdef:132> [[ global = -N ]]
17 compdef:132> [[ git-revise = -N ]]
17 compdef:132> [[ gem = -N ]]
17 compdef:132> [[ gcore = -N ]]
17 compdef:132> [[ gccgo = -N ]]
17 compdef:132> [[ fstat = -N ]]
17 compdef:132> [[ fleetctl = -N ]]
17 compdef:132> [[ flac = -N ]]
17 compdef:132> [[ fetch = -N ]]
17 compdef:132> [[ exportfs = -N ]]
17 compdef:132> [[ epsffit = -N ]]
17 compdef:132> [[ echoti = -N ]]
17 compdef:132> [[ dtrace = -N ]]
17 compdef:132> [[ dpkg = -N ]]
17 compdef:132> [[ docker = -N ]]
17 compdef:132> [[ dladm = -N ]]
17 compdef:132> [[ disown = -N ]]
17 compdef:132> [[ diff = -N ]]
17 compdef:132> [[ dget = -N ]]
17 compdef:132> [[ coreadm = -N ]]
17 compdef:132> [[ btrfs = -N ]]
17 compdef:132> [[ bsdconfig = -N ]]
17 compdef:132> [[ brew = -N ]]
17 compdef:132> [[ beep = -N ]]
17 compdef:132> [[ axi-cache = -N ]]
17 compdef:132> [[ awk = -N ]]
17 compdef:132> [[ avahi-browse = -N ]]
17 compdef:132> [[ arp = -N ]]
17 compdef:132> [[ apm = -N ]]
17 compdef:132> [[ apachectl = -N ]]
17 compdef:132> [[ animate = -N ]]
17 compdef:132> [[ android = -N ]]
17 compdef:132> [[ acroread = -N ]]
17 compdef:132> [[ abcde = -N ]]
17 compdef:132> [[ -value-,PRINTER,-default- = -N ]]
17 compdef:132> [[ -command-line- = -N ]]
17 compdef:132> [[ -assign-parameter- = -N ]]
17 compdef:132> [[ 'zf*' = -N ]]
17 compdef:132> [[ 'python[0-9.]#' = -N ]]
17 compdef:131> ((  8  ))
17 compdef:131> ((  2  ))
17 compdef:131> ((  2  ))
17 compdef:131> ((  2  ))
17 compdef:131> ((  1  ))
17 compdef:131> ((  1  ))
17 compdef:131> ((  1  ))
17 compdef:131> ((  1  ))
17 compdef:131> ((  1  ))
17 compdef:131> ((  1  ))
17 compdef:117> shift
17 compdef:86> [[ 3 -lt 3 ]]
17 compdef:85> [[ -n _history-complete-newer ]]
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (widgetkey)
17 compdef:83> case  (key)
17 compdef:83> case  (*)
17 compdef:83> case  (*)
17 compdef:83> case  (*)
17 compdef:83> case  (*)
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:81> shift
17 compdef:80> autoload -Uz _update-rc.d
17 compdef:80> autoload -Uz _tune2fs
17 compdef:80> autoload -Uz _tracepath
17 compdef:80> autoload -Uz _tex
17 compdef:80> autoload -Uz _tee
17 compdef:80> autoload -Uz _svn-buildpackage
17 compdef:80> autoload -Uz _stty
17 compdef:80> autoload -Uz _stat
17 compdef:80> autoload -Uz _smartmontools
17 compdef:80> autoload -Uz _slabtop
17 compdef:80> autoload -Uz _signify
17 compdef:80> autoload -Uz _setxkbmap
17 compdef:80> autoload -Uz _setsid
17 compdef:80> autoload -Uz _setopt
17 compdef:80> autoload -Uz _set
17 compdef:80> autoload -Uz _sed
17 compdef:80> autoload -Uz _scl
17 compdef:80> autoload -Uz _runit
17 compdef:80> autoload -Uz _rlogin
17 compdef:80> autoload -Uz _reprepro
17 compdef:80> autoload -Uz _rcs
17 compdef:80> autoload -Uz _pump
17 compdef:80> autoload -Uz _procstat
17 compdef:80> autoload -Uz _portlint
17 compdef:80> autoload -Uz _pkgadd
17 compdef:80> autoload -Uz _pkg5
17 compdef:80> autoload -Uz _piuparts
17 compdef:80> autoload -Uz _ping
17 compdef:80> autoload -Uz _pdftk
17 compdef:80> autoload -Uz _pbcopy
17 compdef:80> autoload -Uz _pax
17 compdef:80> autoload -Uz _patch
17 compdef:80> autoload -Uz _otool
17 compdef:80> autoload -Uz _netcat
17 compdef:80> autoload -Uz _mv
17 compdef:80> autoload -Uz _jmeter
17 compdef:80> autoload -Uz _hwinfo
17 compdef:80> autoload -Uz _gprof
17 compdef:80> autoload -Uz _floppy
17 compdef:80> autoload -Uz _cp
17 compdef:80> autoload -Uz _coreadm
17 compdef:80> autoload -Uz _bsdconfig
17 compdef:80> autoload -Uz _brctl
17 compdef:80> autoload -Uz _beadm
17 compdef:80> autoload -Uz _baz
17 compdef:80> autoload -Uz _aws
17 compdef:80> autoload -Uz _augeas
17 compdef:80> autoload -Uz _asdf
17 compdef:80> autoload -Uz _SUSEconfig
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:80> [[ -n yes ]]
17 compdef:79> func=_uniq
17 compdef:79> func=_unhash
17 compdef:79> func=_toilet
17 compdef:79> func=_tarsnap
17 compdef:79> func=_route
17 compdef:79> func=_mina
17 compdef:79> func=_a2ps
17 compdef:49> [[ _zparseopts = *=* ]]
17 compdef:49> [[ _zfs = *=* ]]
17 compdef:49> [[ _xauth = *=* ]]
17 compdef:49> [[ _x_utils = *=* ]]
17 compdef:49> [[ _wemux = *=* ]]
17 compdef:49> [[ _udisksctl = *=* ]]
17 compdef:49> [[ _tardy = *=* ]]
17 compdef:49> [[ _sbt = *=* ]]
17 compdef:49> [[ _redis-cli = *=* ]]
17 compdef:49> [[ _port = *=* ]]
17 compdef:49> [[ _pkcon = *=* ]]
17 compdef:49> [[ _patool = *=* ]]
17 compdef:49> [[ _numfmt = *=* ]]
17 compdef:49> [[ _nkf = *=* ]]
17 compdef:49> [[ _networkmanager = *=* ]]
17 compdef:49> [[ _moosic = *=* ]]
17 compdef:49> [[ _mix = *=* ]]
17 compdef:49> [[ _mc = *=* ]]
17 compdef:49> [[ _man = *=* ]]
17 compdef:49> [[ _ltrace = *=* ]]
17 compdef:49> [[ _lsattr = *=* ]]
17 compdef:49> [[ _jobs_builtin = *=* ]]
17 compdef:49> [[ _ispell = *=* ]]
17 compdef:49> [[ _gh = *=* ]]
17 compdef:49> [[ _etags = *=* ]]
17 compdef:49> [[ _elfdump = *=* ]]
17 compdef:49> [[ _dtruss = *=* ]]
17 compdef:49> [[ _dpkg_source = *=* ]]
17 compdef:49> [[ _dpkg-repack = *=* ]]
17 compdef:49> [[ _dpkg-cross = *=* ]]
17 compdef:49> [[ _dpkg-buildpackage = *=* ]]
17 compdef:49> [[ _dpatch-edit-patch = *=* ]]
17 compdef:49> [[ _doas = *=* ]]
17 compdef:49> [[ _dmidecode = *=* ]]
17 compdef:49> [[ _dlocate = *=* ]]
17 compdef:49> [[ _diff3 = *=* ]]
17 compdef:49> [[ _dict = *=* ]]
17 compdef:49> [[ _dhclient = *=* ]]
17 compdef:49> [[ _dconf = *=* ]]
17 compdef:49> [[ _dchroot-dsa = *=* ]]
17 compdef:49> [[ _cygpath = *=* ]]
17 compdef:49> [[ _cygcheck = *=* ]]
17 compdef:49> [[ _cut = *=* ]]
17 compdef:49> [[ _cssh = *=* ]]
17 compdef:49> [[ _cscope = *=* ]]
17 compdef:49> [[ _cplay = *=* ]]
17 compdef:49> [[ _concourse = *=* ]]
17 compdef:49> [[ _compadd = *=* ]]
17 compdef:49> [[ _command = *=* ]]
17 compdef:49> [[ _comm = *=* ]]
17 compdef:49> [[ _column = *=* ]]
17 compdef:49> [[ _code = *=* ]]
17 compdef:49> [[ _cdbs-edit-patch = *=* ]]
17 compdef:49> [[ _apt-show-versions = *=* ]]
17 compdef:49> [[ _acpi = *=* ]]
17 compdef:49> [[ _a2utils = *=* ]]
17 compdef:49> [[ -z '' ]]
17 compdef:49> [[ -z '' ]]
17 compdef:49> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:45> [[ -z '' ]]
17 compdef:40> ((  ! 16  ))
17 compdef:40> ((  ! 3  ))
17 compdef:40> ((  ! 3  ))
17 compdef:40> ((  ! 3  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:40> ((  ! 2  ))
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:38> shift OPTIND-1
17 compdef:31> type=key
17 compdef:27> type=postpattern
17 compdef:25> type=pattern
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:17> new=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:16> autol=yes
17 compdef:15> case n (n)
17 compdef:15> case n (n)
17 compdef:15> case n (n)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case n (a)
17 compdef:15> case k ([pPkK])
17 compdef:15> case a (a)
17 compdef:15> case a (a)
17 compdef:15> case a (a)
17 compdef:15> case a (a)
17 compdef:15> case a (a)
17 compdef:15> case P (a)
17 compdef:15> case K ([pPkK])
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:14> getopts anpPkKde opt
17 compdef:9> ((  ! 16  ))
17 compdef:9> ((  ! 15  ))
17 compdef:9> ((  ! 12  ))
17 compdef:9> ((  ! 8  ))
17 compdef:9> ((  ! 7  ))
17 compdef:9> ((  ! 7  ))
17 compdef:9> ((  ! 7  ))
17 compdef:9> ((  ! 6  ))
17 compdef:9> ((  ! 6  ))
17 compdef:9> ((  ! 5  ))
17 compdef:9> ((  ! 5  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 4  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 3  ))
17 compdef:9> ((  ! 2  ))
17 compdef:9> ((  ! 2  ))
17 compdef:9> ((  ! 2  ))
17 compaudit:96> local _i_exe
17 compaudit:14> setopt extendedglob
17 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;45m'
17 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;41m'
17 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;35m'
17 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;31m'
17 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;30m'
17 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=antigen-bundle-cached:antig...
17 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=''
17 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=''
17 antigen-remove-hook:2> typeset -A meta
17 antigen-bundle-parallel-execute:40> bundle=deno
17 antigen-bundle-parallel-execute:40> bundle=--loc=lib
17 antigen-add-hook:13> [[ antigen-apply-lock ==  ]]
17 antigen-add-hook:8> ((  ! 1  ))
17 add-zsh-hook:68> ((  del  ))
17 add-zsh-hook:55> shift 0
17 add-zsh-hook:55> shift 0
17 add-zsh-hook:25> local -a autoopts
17 add-zsh-hook:24> local opt
17 add-zsh-hook:17> local -a hooktypes
17 add-zsh-hook:17> local -a hooktypes
17 add-zsh-hook:17> local -a hooktypes
17 add-zle-hook-widget:92> [[ -z '' ]]
17 add-zle-hook-widget:8> local -a autoopts
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:27> case builtin (builtin)
17 _zsh_highlight_bind_widgets:26> cur_widget=vi-set-mark
17 _zsh_highlight_bind_widgets:26> cur_widget=vi-kill-eol
17 _zsh_highlight_bind_widgets:26> cur_widget=vi-fetch-history
17 _zsh_highlight_bind_widgets:26> cur_widget=auto-suffix-remove
17 /usr/local/share/antigen/antigen.zsh:15> ANTIGEN_CACHE=/Users/matt/.antigen/i...
17 /Users/matt/.zshrc:389> alias 't=trash'
17 /Users/matt/.zcompdump:1978> bindkey '^X~' _bash_list-choices
17 /Users/matt/.zcompdump:1976> bindkey '^Xn' _next_tags
17 /Users/matt/.zcompdump:1972> bindkey '^Xd' _list_expansions
17 /Users/matt/.zcompdump:1970> bindkey '^Xa' _expand_alias
17 /Users/matt/.zcompdump-Mateo’s MacBook Pro-5.8.1:1805> bindkey '^Xc' _correct...
17 /Users/matt/.oh-my-zsh/tools/check_for_upgrade.sh:25> [[ prompt = disabled ]]
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=zsh-syntax-highlighting
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=zsh-completions
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=pyenv-lazy
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
17 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
17 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;015m%}'
17 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;000m%}'
17 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=219
17 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=000
17 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:79> bindkey -M emacs $'C-[[3~' de...
17 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:67> [[ -n $'C-[[Z' ]]
17 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:62> bindkey -M viins $'C-[OF' end...
17 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:54> [[ -n $'C-[OH' ]]
17 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:46> zle -N down-line-or-beginning...
17 /Users/matt/.oh-my-zsh/lib/history.zsh:39> setopt hist_verify
17 /Users/matt/.oh-my-zsh/lib/history.zsh:21> case  (yyyy-mm-dd)
17 /Users/matt/.oh-my-zsh/lib/directories.zsh:22> alias 'md=mkdir -p'
17 /Users/matt/.oh-my-zsh/lib/directories.zsh:18> alias '7=cd -7'
17 /Users/matt/.oh-my-zsh/lib/directories.zsh:17> alias '6=cd -6'
17 /Users/matt/.oh-my-zsh/lib/directories.zsh:11> alias -- '-=cd -'
17 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
17 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
17 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/plugins/deno/deno.plugin....
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:114>...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:78> ...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:55> ...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:35> ...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:19> a...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:16> a...
17 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:12> a...
17 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/zsh-users/z...
17 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/robbyrussel...
17 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/robbyrussel...
17 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/zsh-users/zsh-syn...
17 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/zsh-users/zsh-syn...
17 -antigen-parse-args:135> local bpath=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:135> local bpath=zsh-users/zsh-autosuggestions
17 -antigen-parse-args:134> [[ true == true ]]
17 -antigen-parse-args:134> [[ true == true ]]
17 -antigen-parse-args:134> [[ true == true ]]
17 -antigen-parse-args:134> [[ true == true ]]
17 -antigen-parse-args:130> args[name]=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:130> args[name]=zsh-users/zsh-autosuggestions
17 -antigen-parse-args:122> name=robbyrussell/oh-my-zsh.git
17 -antigen-parse-args:118> local branch=''
17 -antigen-parse-args:118> local branch=''
17 -antigen-parse-args:105> [[ ! -z '' ]]
17 -antigen-parse-args:105> [[ ! -z '' ]]
17 -antigen-parse-args:105> [[ ! -z '' ]]
17 -antigen-parse-args:105> [[ ! -z '' ]]
17 -antigen-parse-args:87> [[ https://github.com/robbyrussell/oh-my-zsh.git != g...
17 -antigen-parse-args:87> [[ https://github.com/robbyrussell/oh-my-zsh.git != g...
17 -antigen-parse-args:86> local url=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:86> local url=zsh-users/zsh-autosuggestions
17 -antigen-parse-args:86> local url=https://github.com/robbyrussell/oh-my-zsh.git
17 -antigen-parse-args:61> args[$key]=deno
17 -antigen-parse-args:61> args[$key]=deno
17 -antigen-parse-args:60> let 'index+=1'
17 -antigen-parse-args:42> local url_path=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:42> local url_path=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:27> args[$key]=lib
17 -antigen-parse-args:18> argkey=zsh-users/zsh-syntax-highlighting
17 -antigen-parse-args:17> [[ 0 -gt 0 ]]
17 -antigen-parse-args:17> [[ 0 -gt 0 ]]
17 -antigen-parse-args:17> [[ 0 -gt 0 ]]
17 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
17 -antigen-load:12> location=/Users/matt/.antigen/bundles/zsh-users/zsh-syntax-...
17 -antigen-load:12> location=/Users/matt/.antigen/bundles/robbyrussell/oh-my-zs...
17 -antigen-load:5> local location=/Users/matt/.antigen/bundles/robbyrussell/oh-...
17 -antigen-load:4> typeset -Ua list
17 -antigen-load:4> typeset -Ua list
17 -antigen-load:4> typeset -Ua list
17 -antigen-load:4> list=( )
17 -antigen-hook-handler:55> [[ 1 == 0 ]]
17 -antigen-hook-handler:55> [[ 1 == 0 ]]
17 -antigen-hook-handler:55> [[ 1 == 0 ]]
17 -antigen-hook-handler:55> [[ 1 == 0 ]]
17 -antigen-hook-handler:55> [[ 0 == 0 ]]
17 -antigen-hook-handler:55> [[ 0 == 0 ]]
17 -antigen-hook-handler:55> [[ 0 == 0 ]]
17 -antigen-hook-handler:27> replace_hooks+=( antigen-bundle-defer )
17 -antigen-hook-handler:22> case replace (pre)
17 -antigen-hook-handler:22> case pre (pre)
17 -antigen-hook-handler:22> case pre (pre)
17 -antigen-hook-handler:22> case pre (pre)
17 -antigen-hook-handler:17> let 'called=10+1'
17 -antigen-hook-handler:17> let 'called=9+1'
17 -antigen-hook-handler:17> let 'called=7+1'
17 -antigen-hook-handler:17> let 'called=3+1'
17 -antigen-hook-handler:17> let 'called=2+1'
17 -antigen-hook-handler:17> let 'called=2+1'
17 -antigen-hook-handler:17> let 'called=2+1'
17 -antigen-hook-handler:17> let 'called=1+1'
17 -antigen-hook-handler:17> let 'called=1+1'
17 -antigen-hook-handler:17> let 'called=0+1'
17 -antigen-hook-handler:17> let 'called=0+1'
17 -antigen-hook-handler:14> continue
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:9> typeset -A meta
17 -antigen-hook-handler:7> typeset -a hooks
17 -antigen-hook-handler:7> typeset -a hooks
17 -antigen-hook-handler:7> typeset -a hooks
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> typeset -a args
17 -antigen-hook-handler:4> args=( deno )
17 -antigen-hook-handler:4> args=( deno )
17 -antigen-hook-handler:4> args=( )
17 -antigen-hook-handler:3> shift
17 -antigen-hook-handler:3> shift
17 -antigen-hook-handler:3> shift
17 -antigen-hook-handler:3> shift
17 -antigen-hook-handler:3> shift
17 -antigen-hook-handler:3> shift
17 -antigen-hook-antigen:2> [[ -z bundle ]]
17 -antigen-cache-generate:65> zcompile /Users/matt/.zshrc
17 -antigen-cache-generate:21> _fpath+=( /Users/matt/.antigen/bundles/robbyrusse...
17 -antigen-cache-generate:20> _PATH+=( /Users/matt/.antigen/bundles/zsh-users/z...
17 -antigen-cache-generate:20> _PATH+=( /Users/matt/.antigen/bundles/robbyrussel...
17 -antigen-cache-generate:19> [[ -d /Users/matt/.antigen/bundles/robbyrussell/o...
17 (eval):238> alias 'sf=fasd -sif'
17 (eval):215> alias 'it2attention=/Users/matt/.iterm2/it2attention'
17 (eval):206> alias 'gupa=git pull --rebase --autostash'
17 (eval):186> alias 'gupv=git pull --rebase -v'
17 (eval):181> alias 'gunignore=git update-index --no-assume-unchanged'
17 (eval):160> alias 'grep=grep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,.s...
17 (eval):145> alias 'grmv=git remote rename'
17 (eval):143> alias 'gpoat=git push origin --all && git push origin --tags'
17 (eval):129> alias 'glp=_git_log_prettily'
17 (eval):128> alias 'glols=git log --graph --pretty='''%Cred%h%Creset -%C(auto)...
17 (eval):125> alias 'gloga=git log --oneline --decorate --graph --all'
17 (eval):121> alias 'glo=git log --oneline --decorate'
17 (eval):113> alias 'gma=git merge --abort'
17 (eval):96> alias 'gl=git pull'
17 (eval):78> alias 'gdup=git diff @{upstream}'
17 (eval):42> alias 'gbsg=git bisect good'
17 (eval):37> alias 'fgrep=fgrep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,....
17 (eval):18> alias 'brew=env PATH="${PATH//:($(pyenv root)/shims|$HOME/.platfor...
17 (eval):2> alias -g '...=../..'
17 (eval):1> test -z ''
17 (eval):1> alias -- '-=cd -'
17 (anon):1558> p10k reload
17 (anon):1244> POWERLEVEL9K_KUBECONTEXT_DEFAULT_CONTENT_EXPANSION+='${P9K_KUBEC...
17 (anon):33> zle -N autosuggest-suggest _zsh_autosuggest_widget_suggest
17 (anon):32> action=clear
17 (anon):15> action=suggest
17 (anon):15> action=partial_accept
17 (anon):15> action=fetch
17 (anon):15> action=accept
16 regexp-replace:23> 6=''
16 is-at-least:53> ((  part > min_ver[min_cnt]  ))
16 is-at-least:53> ((  part > min_ver[min_cnt]  ))
16 is-at-least:50> break
16 is-at-least:50> [[ 13 = <-> ]]
16 is-at-least:50> [[ 5 = <-> ]]
16 is-at-least:50> [[ 4 = <-> ]]
16 is-at-least:50> [[ 1 = <-> ]]
16 is-at-least:45> part=5
16 is-at-least:45> part=5
16 is-at-least:45> part=5
16 is-at-least:33> [[ 2 = *[0-9][^0-9]* ]]
16 is-at-least:32> ((  ++ver_cnt > 4  ))
16 is-at-least:31> [[ 8 != <-> ]]
16 is-at-least:31> [[ 5 != <-> ]]
16 is-at-least:28> version=( 5 8 1 0 )
16 group_lazy_load:5> alias 'rvm=lazy_load "rvm irb rake" ". /Users/matt/.rvm/sc...
16 group_lazy_load:4> cmd=wipeenv
16 group_lazy_load:4> cmd=setvirtualenvproject
16 group_lazy_load:4> cmd=node
16 group_lazy_load:4> cmd=mkvirtualenv
16 group_lazy_load:4> cmd=mktmpenv
16 group_lazy_load:4> cmd=mkproject
16 group_lazy_load:4> cmd=lsvirtualenv
16 group_lazy_load:4> cmd=cdvirtualenv
16 group_lazy_load:4> cmd=add2virtualenv
16 group_lazy_load:3> shift 1
16 group_lazy_load:2> script='pyenv virtualenvwrapper_lazy'
16 group_lazy_load:2> script='. /Users/matt/.rvm/scripts/rvm'
16 group_lazy_load:2> script='. /Users/matt/.nvm/nvm.sh'
16 group_lazy_load:1> local script
16 detect-clipboard:3> [[ darwin21.0 == darwin* ]]
16 compinit:530> _i_line=menu-complete
16 compinit:530> _i_line=expand-or-complete-prefix
16 compinit:530> _i_line=delete-char-or-list
16 compinit:530> _i_line=delete-char-or-list
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:516> [[ '' !=  # ]]
16 compinit:515> autoload -Uz _zfs_keysource_props
16 compinit:515> autoload -Uz _zfs_dataset
16 compinit:515> autoload -Uz _user_at_host
16 compinit:515> autoload -Uz _ttys
16 compinit:515> autoload -Uz _sys_calls
16 compinit:515> autoload -Uz _suffix_alias_files
16 compinit:515> autoload -Uz _services
16 compinit:515> autoload -Uz _sequence
16 compinit:515> autoload -Uz _sep_parts
16 compinit:515> autoload -Uz _selinux_contexts
16 compinit:515> autoload -Uz _remote_files
16 compinit:515> autoload -Uz _regex_words
16 compinit:515> autoload -Uz _ports
16 compinit:515> autoload -Uz _options_set
16 compinit:515> autoload -Uz _options
16 compinit:515> autoload -Uz _newsgroups
16 compinit:515> autoload -Uz _my_accounts
16 compinit:515> autoload -Uz _mime_types
16 compinit:515> autoload -Uz _message
16 compinit:515> autoload -Uz _menu
16 compinit:515> autoload -Uz _math_params
16 compinit:515> autoload -Uz _list
16 compinit:515> autoload -Uz _language_codes
16 compinit:515> autoload -Uz _ignored
16 compinit:515> autoload -Uz _have_glob_qual
16 compinit:515> autoload -Uz _globquals
16 compinit:515> autoload -Uz _globflags
16 compinit:515> autoload -Uz _file_systems
16 compinit:515> autoload -Uz _file_flags
16 compinit:515> autoload -Uz _external_pwds
16 compinit:515> autoload -Uz _correct
16 compinit:515> autoload -Uz _bind_addresses
16 compinit:515> autoload -Uz _be_name
16 compinit:515> autoload -Uz _arguments
16 compinit:515> autoload -Uz _arch_namespace
16 compinit:515> autoload -Uz _approximate
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #compdef (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#compdef)
16 compinit:506> case #autoload (#autoload)
16 compinit:506> case #autoload (#autoload)
16 compinit:506> case #autoload (#autoload)
16 compinit:505> shift _i_line
16 compinit:505> shift _i_line
16 compinit:505> shift _i_line
16 compinit:505> shift _i_line
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:501> ((  0 + 0  ))
16 compinit:500> _i_name=_zsh
16 compinit:500> _i_name=_yt-dlp
16 compinit:500> _i_name=_xargs
16 compinit:500> _i_name=_wg-quick
16 compinit:500> _i_name=_trash-list
16 compinit:500> _i_name=_restic
16 compinit:500> _i_name=_picocom
16 compinit:500> _i_name=_pick_variant
16 compinit:500> _i_name=_newsgroups
16 compinit:500> _i_name=_mullvad
16 compinit:500> _i_name=_math
16 compinit:500> _i_name=_guilt
16 compinit:500> _i_name=_guard
16 compinit:500> _i_name=_gstat
16 compinit:500> _i_name=_gsettings
16 compinit:500> _i_name=_fc
16 compinit:500> _i_name=_expand_alias
16 compinit:500> _i_name=_exec
16 compinit:500> _i_name=_evince
16 compinit:500> _i_name=_env
16 compinit:500> _i_name=_dupload
16 compinit:500> _i_name=_dumper
16 compinit:500> _i_name=_dumpadm
16 compinit:500> _i_name=_dsh
16 compinit:500> _i_name=_dput
16 compinit:500> _i_name=_description
16 compinit:500> _i_name=_defaults
16 compinit:500> _i_name=_default
16 compinit:500> _i_name=_debuild
16 compinit:500> _i_name=_debcheckout
16 compinit:500> _i_name=_deb_files
16 compinit:500> _i_name=_cksum
16 compinit:500> _i_name=_chkconfig
16 compinit:500> _i_name=_cdrdao
16 compinit:500> _i_name=_cdr
16 compinit:500> _i_name=_caffeinate
16 compinit:500> _i_name=_cabal
16 compinit:500> _i_name=_a2utils
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ztodo
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zmodload
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zcompile
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xautolock
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xauth
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_colormapid
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wipefs
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wget
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_uniq
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_seafile
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_psutils
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_postfix
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pdf
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nm
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_netstat
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_monotone
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mdls
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mdfind
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hosts
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_history_modifiers
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gradle
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_find
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_file_descriptors
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_evince
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ethtool
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_devtodo
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_deborphan
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debdiff
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debchange
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dbus
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cygcheck
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cut
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_csup
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cdcd
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cd
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_canonical_paths
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_asciinema
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_aliases
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_acpitool
16 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_absolute_command_paths
16 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_hub
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
16 compinit:493> [[ -z yes ]]
16 compinit:480> [[ -n '' ]]
16 compinit:473> autoload -Uz compdump compinstall
16 compinit:448> eval compaudit
16 compinit:440> typeset _i_wdirs _i_wfiles
16 compinit:130> typeset -gHa _comp_options
16 compinit:130> typeset -gHa _comp_options
16 compinit:100> shift
16 compinit:83> shift
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:121> shift _d_als
16 compdump:117> _i=5
16 compdump:117> _i=5
16 compdump:117> _i=5
16 compdump:117> _i=5
16 compdump:116> ((  ! --_i && 1081 > 1  ))
16 compdump:116> ((  ! --_i && 1074 > 1  ))
16 compdump:116> ((  ! --_i && 1069 > 1  ))
16 compdump:116> ((  ! --_i && 1068 > 1  ))
16 compdump:116> ((  ! --_i && 1064 > 1  ))
16 compdump:116> ((  ! --_i && 1061 > 1  ))
16 compdump:116> ((  ! --_i && 1057 > 1  ))
16 compdump:116> ((  ! --_i && 1056 > 1  ))
16 compdump:116> ((  ! --_i && 1049 > 1  ))
16 compdump:116> ((  ! --_i && 1046 > 1  ))
16 compdump:116> ((  ! --_i && 1044 > 1  ))
16 compdump:116> ((  ! --_i && 1043 > 1  ))
16 compdump:116> ((  ! --_i && 1041 > 1  ))
16 compdump:116> ((  ! --_i && 1036 > 1  ))
16 compdump:116> ((  ! --_i && 1029 > 1  ))
16 compdump:116> ((  ! --_i && 1021 > 1  ))
16 compdump:116> ((  ! --_i && 1019 > 1  ))
16 compdump:116> ((  ! --_i && 1016 > 1  ))
16 compdump:116> ((  ! --_i && 991 > 1  ))
16 compdump:116> ((  ! --_i && 982 > 1  ))
16 compdump:116> ((  ! --_i && 981 > 1  ))
16 compdump:116> ((  ! --_i && 977 > 1  ))
16 compdump:116> ((  ! --_i && 972 > 1  ))
16 compdump:116> ((  ! --_i && 971 > 1  ))
16 compdump:116> ((  ! --_i && 967 > 1  ))
16 compdump:116> ((  ! --_i && 961 > 1  ))
16 compdump:116> ((  ! --_i && 958 > 1  ))
16 compdump:116> ((  ! --_i && 955 > 1  ))
16 compdump:116> ((  ! --_i && 952 > 1  ))
16 compdump:116> ((  ! --_i && 950 > 1  ))
16 compdump:116> ((  ! --_i && 948 > 1  ))
16 compdump:116> ((  ! --_i && 947 > 1  ))
16 compdump:116> ((  ! --_i && 946 > 1  ))
16 compdump:116> ((  ! --_i && 942 > 1  ))
16 compdump:116> ((  ! --_i && 940 > 1  ))
16 compdump:116> ((  ! --_i && 937 > 1  ))
16 compdump:116> ((  ! --_i && 936 > 1  ))
16 compdump:116> ((  ! --_i && 935 > 1  ))
16 compdump:116> ((  ! --_i && 932 > 1  ))
16 compdump:116> ((  ! --_i && 931 > 1  ))
16 compdump:116> ((  ! --_i && 928 > 1  ))
16 compdump:116> ((  ! --_i && 927 > 1  ))
16 compdump:116> ((  ! --_i && 916 > 1  ))
16 compdump:116> ((  ! --_i && 908 > 1  ))
16 compdump:116> ((  ! --_i && 907 > 1  ))
16 compdump:116> ((  ! --_i && 900 > 1  ))
16 compdump:116> ((  ! --_i && 898 > 1  ))
16 compdump:116> ((  ! --_i && 895 > 1  ))
16 compdump:116> ((  ! --_i && 892 > 1  ))
16 compdump:116> ((  ! --_i && 890 > 1  ))
16 compdump:116> ((  ! --_i && 888 > 1  ))
16 compdump:116> ((  ! --_i && 887 > 1  ))
16 compdump:116> ((  ! --_i && 886 > 1  ))
16 compdump:116> ((  ! --_i && 881 > 1  ))
16 compdump:116> ((  ! --_i && 877 > 1  ))
16 compdump:116> ((  ! --_i && 873 > 1  ))
16 compdump:116> ((  ! --_i && 872 > 1  ))
16 compdump:116> ((  ! --_i && 847 > 1  ))
16 compdump:116> ((  ! --_i && 833 > 1  ))
16 compdump:116> ((  ! --_i && 828 > 1  ))
16 compdump:116> ((  ! --_i && 827 > 1  ))
16 compdump:116> ((  ! --_i && 823 > 1  ))
16 compdump:116> ((  ! --_i && 813 > 1  ))
16 compdump:116> ((  ! --_i && 811 > 1  ))
16 compdump:116> ((  ! --_i && 810 > 1  ))
16 compdump:116> ((  ! --_i && 786 > 1  ))
16 compdump:116> ((  ! --_i && 782 > 1  ))
16 compdump:116> ((  ! --_i && 778 > 1  ))
16 compdump:116> ((  ! --_i && 777 > 1  ))
16 compdump:116> ((  ! --_i && 766 > 1  ))
16 compdump:116> ((  ! --_i && 765 > 1  ))
16 compdump:116> ((  ! --_i && 763 > 1  ))
16 compdump:116> ((  ! --_i && 756 > 1  ))
16 compdump:116> ((  ! --_i && 751 > 1  ))
16 compdump:116> ((  ! --_i && 745 > 1  ))
16 compdump:116> ((  ! --_i && 738 > 1  ))
16 compdump:116> ((  ! --_i && 735 > 1  ))
16 compdump:116> ((  ! --_i && 728 > 1  ))
16 compdump:116> ((  ! --_i && 725 > 1  ))
16 compdump:116> ((  ! --_i && 721 > 1  ))
16 compdump:116> ((  ! --_i && 720 > 1  ))
16 compdump:116> ((  ! --_i && 718 > 1  ))
16 compdump:116> ((  ! --_i && 712 > 1  ))
16 compdump:116> ((  ! --_i && 711 > 1  ))
16 compdump:116> ((  ! --_i && 706 > 1  ))
16 compdump:116> ((  ! --_i && 703 > 1  ))
16 compdump:116> ((  ! --_i && 701 > 1  ))
16 compdump:116> ((  ! --_i && 698 > 1  ))
16 compdump:116> ((  ! --_i && 697 > 1  ))
16 compdump:116> ((  ! --_i && 696 > 1  ))
16 compdump:116> ((  ! --_i && 691 > 1  ))
16 compdump:116> ((  ! --_i && 690 > 1  ))
16 compdump:116> ((  ! --_i && 687 > 1  ))
16 compdump:116> ((  ! --_i && 686 > 1  ))
16 compdump:116> ((  ! --_i && 676 > 1  ))
16 compdump:116> ((  ! --_i && 675 > 1  ))
16 compdump:116> ((  ! --_i && 673 > 1  ))
16 compdump:116> ((  ! --_i && 672 > 1  ))
16 compdump:116> ((  ! --_i && 668 > 1  ))
16 compdump:116> ((  ! --_i && 667 > 1  ))
16 compdump:116> ((  ! --_i && 666 > 1  ))
16 compdump:116> ((  ! --_i && 665 > 1  ))
16 compdump:116> ((  ! --_i && 663 > 1  ))
16 compdump:116> ((  ! --_i && 662 > 1  ))
16 compdump:116> ((  ! --_i && 661 > 1  ))
16 compdump:116> ((  ! --_i && 660 > 1  ))
16 compdump:116> ((  ! --_i && 657 > 1  ))
16 compdump:116> ((  ! --_i && 655 > 1  ))
16 compdump:116> ((  ! --_i && 651 > 1  ))
16 compdump:116> ((  ! --_i && 648 > 1  ))
16 compdump:116> ((  ! --_i && 646 > 1  ))
16 compdump:116> ((  ! --_i && 641 > 1  ))
16 compdump:116> ((  ! --_i && 640 > 1  ))
16 compdump:116> ((  ! --_i && 638 > 1  ))
16 compdump:116> ((  ! --_i && 635 > 1  ))
16 compdump:116> ((  ! --_i && 632 > 1  ))
16 compdump:116> ((  ! --_i && 628 > 1  ))
16 compdump:116> ((  ! --_i && 625 > 1  ))
16 compdump:116> ((  ! --_i && 623 > 1  ))
16 compdump:116> ((  ! --_i && 617 > 1  ))
16 compdump:116> ((  ! --_i && 610 > 1  ))
16 compdump:116> ((  ! --_i && 607 > 1  ))
16 compdump:116> ((  ! --_i && 595 > 1  ))
16 compdump:116> ((  ! --_i && 593 > 1  ))
16 compdump:116> ((  ! --_i && 592 > 1  ))
16 compdump:116> ((  ! --_i && 588 > 1  ))
16 compdump:116> ((  ! --_i && 582 > 1  ))
16 compdump:116> ((  ! --_i && 577 > 1  ))
16 compdump:116> ((  ! --_i && 576 > 1  ))
16 compdump:116> ((  ! --_i && 575 > 1  ))
16 compdump:116> ((  ! --_i && 568 > 1  ))
16 compdump:116> ((  ! --_i && 567 > 1  ))
16 compdump:116> ((  ! --_i && 563 > 1  ))
16 compdump:116> ((  ! --_i && 561 > 1  ))
16 compdump:116> ((  ! --_i && 558 > 1  ))
16 compdump:116> ((  ! --_i && 556 > 1  ))
16 compdump:116> ((  ! --_i && 553 > 1  ))
16 compdump:116> ((  ! --_i && 551 > 1  ))
16 compdump:116> ((  ! --_i && 548 > 1  ))
16 compdump:116> ((  ! --_i && 542 > 1  ))
16 compdump:116> ((  ! --_i && 540 > 1  ))
16 compdump:116> ((  ! --_i && 538 > 1  ))
16 compdump:116> ((  ! --_i && 533 > 1  ))
16 compdump:116> ((  ! --_i && 531 > 1  ))
16 compdump:116> ((  ! --_i && 527 > 1  ))
16 compdump:116> ((  ! --_i && 525 > 1  ))
16 compdump:116> ((  ! --_i && 518 > 1  ))
16 compdump:116> ((  ! --_i && 513 > 1  ))
16 compdump:116> ((  ! --_i && 508 > 1  ))
16 compdump:116> ((  ! --_i && 506 > 1  ))
16 compdump:116> ((  ! --_i && 503 > 1  ))
16 compdump:116> ((  ! --_i && 501 > 1  ))
16 compdump:116> ((  ! --_i && 498 > 1  ))
16 compdump:116> ((  ! --_i && 497 > 1  ))
16 compdump:116> ((  ! --_i && 493 > 1  ))
16 compdump:116> ((  ! --_i && 492 > 1  ))
16 compdump:116> ((  ! --_i && 488 > 1  ))
16 compdump:116> ((  ! --_i && 485 > 1  ))
16 compdump:116> ((  ! --_i && 483 > 1  ))
16 compdump:116> ((  ! --_i && 480 > 1  ))
16 compdump:116> ((  ! --_i && 475 > 1  ))
16 compdump:116> ((  ! --_i && 472 > 1  ))
16 compdump:116> ((  ! --_i && 471 > 1  ))
16 compdump:116> ((  ! --_i && 468 > 1  ))
16 compdump:116> ((  ! --_i && 463 > 1  ))
16 compdump:116> ((  ! --_i && 462 > 1  ))
16 compdump:116> ((  ! --_i && 461 > 1  ))
16 compdump:116> ((  ! --_i && 457 > 1  ))
16 compdump:116> ((  ! --_i && 456 > 1  ))
16 compdump:116> ((  ! --_i && 451 > 1  ))
16 compdump:116> ((  ! --_i && 450 > 1  ))
16 compdump:116> ((  ! --_i && 445 > 1  ))
16 compdump:116> ((  ! --_i && 443 > 1  ))
16 compdump:116> ((  ! --_i && 442 > 1  ))
16 compdump:116> ((  ! --_i && 441 > 1  ))
16 compdump:116> ((  ! --_i && 437 > 1  ))
16 compdump:116> ((  ! --_i && 435 > 1  ))
16 compdump:116> ((  ! --_i && 427 > 1  ))
16 compdump:116> ((  ! --_i && 426 > 1  ))
16 compdump:116> ((  ! --_i && 425 > 1  ))
16 compdump:116> ((  ! --_i && 422 > 1  ))
16 compdump:116> ((  ! --_i && 421 > 1  ))
16 compdump:116> ((  ! --_i && 412 > 1  ))
16 compdump:116> ((  ! --_i && 411 > 1  ))
16 compdump:116> ((  ! --_i && 410 > 1  ))
16 compdump:116> ((  ! --_i && 408 > 1  ))
16 compdump:116> ((  ! --_i && 406 > 1  ))
16 compdump:116> ((  ! --_i && 405 > 1  ))
16 compdump:116> ((  ! --_i && 402 > 1  ))
16 compdump:116> ((  ! --_i && 400 > 1  ))
16 compdump:116> ((  ! --_i && 398 > 1  ))
16 compdump:116> ((  ! --_i && 397 > 1  ))
16 compdump:116> ((  ! --_i && 395 > 1  ))
16 compdump:116> ((  ! --_i && 393 > 1  ))
16 compdump:116> ((  ! --_i && 390 > 1  ))
16 compdump:116> ((  ! --_i && 388 > 1  ))
16 compdump:116> ((  ! --_i && 387 > 1  ))
16 compdump:116> ((  ! --_i && 386 > 1  ))
16 compdump:116> ((  ! --_i && 385 > 1  ))
16 compdump:116> ((  ! --_i && 382 > 1  ))
16 compdump:116> ((  ! --_i && 381 > 1  ))
16 compdump:116> ((  ! --_i && 380 > 1  ))
16 compdump:116> ((  ! --_i && 377 > 1  ))
16 compdump:116> ((  ! --_i && 376 > 1  ))
16 compdump:116> ((  ! --_i && 363 > 1  ))
16 compdump:116> ((  ! --_i && 361 > 1  ))
16 compdump:116> ((  ! --_i && 357 > 1  ))
16 compdump:116> ((  ! --_i && 352 > 1  ))
16 compdump:116> ((  ! --_i && 347 > 1  ))
16 compdump:116> ((  ! --_i && 345 > 1  ))
16 compdump:116> ((  ! --_i && 335 > 1  ))
16 compdump:116> ((  ! --_i && 333 > 1  ))
16 compdump:116> ((  ! --_i && 325 > 1  ))
16 compdump:116> ((  ! --_i && 313 > 1  ))
16 compdump:116> ((  ! --_i && 312 > 1  ))
16 compdump:116> ((  ! --_i && 308 > 1  ))
16 compdump:116> ((  ! --_i && 302 > 1  ))
16 compdump:116> ((  ! --_i && 301 > 1  ))
16 compdump:116> ((  ! --_i && 300 > 1  ))
16 compdump:116> ((  ! --_i && 298 > 1  ))
16 compdump:116> ((  ! --_i && 293 > 1  ))
16 compdump:116> ((  ! --_i && 291 > 1  ))
16 compdump:116> ((  ! --_i && 288 > 1  ))
16 compdump:116> ((  ! --_i && 285 > 1  ))
16 compdump:116> ((  ! --_i && 282 > 1  ))
16 compdump:116> ((  ! --_i && 280 > 1  ))
16 compdump:116> ((  ! --_i && 277 > 1  ))
16 compdump:116> ((  ! --_i && 273 > 1  ))
16 compdump:116> ((  ! --_i && 272 > 1  ))
16 compdump:116> ((  ! --_i && 268 > 1  ))
16 compdump:116> ((  ! --_i && 267 > 1  ))
16 compdump:116> ((  ! --_i && 266 > 1  ))
16 compdump:116> ((  ! --_i && 265 > 1  ))
16 compdump:116> ((  ! --_i && 255 > 1  ))
16 compdump:116> ((  ! --_i && 248 > 1  ))
16 compdump:116> ((  ! --_i && 245 > 1  ))
16 compdump:116> ((  ! --_i && 243 > 1  ))
16 compdump:116> ((  ! --_i && 241 > 1  ))
16 compdump:116> ((  ! --_i && 238 > 1  ))
16 compdump:116> ((  ! --_i && 232 > 1  ))
16 compdump:116> ((  ! --_i && 231 > 1  ))
16 compdump:116> ((  ! --_i && 218 > 1  ))
16 compdump:116> ((  ! --_i && 216 > 1  ))
16 compdump:116> ((  ! --_i && 215 > 1  ))
16 compdump:116> ((  ! --_i && 207 > 1  ))
16 compdump:116> ((  ! --_i && 203 > 1  ))
16 compdump:116> ((  ! --_i && 198 > 1  ))
16 compdump:116> ((  ! --_i && 193 > 1  ))
16 compdump:116> ((  ! --_i && 191 > 1  ))
16 compdump:116> ((  ! --_i && 190 > 1  ))
16 compdump:116> ((  ! --_i && 188 > 1  ))
16 compdump:116> ((  ! --_i && 187 > 1  ))
16 compdump:116> ((  ! --_i && 186 > 1  ))
16 compdump:116> ((  ! --_i && 185 > 1  ))
16 compdump:116> ((  ! --_i && 183 > 1  ))
16 compdump:116> ((  ! --_i && 181 > 1  ))
16 compdump:116> ((  ! --_i && 177 > 1  ))
16 compdump:116> ((  ! --_i && 176 > 1  ))
16 compdump:116> ((  ! --_i && 172 > 1  ))
16 compdump:116> ((  ! --_i && 167 > 1  ))
16 compdump:116> ((  ! --_i && 166 > 1  ))
16 compdump:116> ((  ! --_i && 163 > 1  ))
16 compdump:116> ((  ! --_i && 162 > 1  ))
16 compdump:116> ((  ! --_i && 161 > 1  ))
16 compdump:116> ((  ! --_i && 160 > 1  ))
16 compdump:116> ((  ! --_i && 157 > 1  ))
16 compdump:116> ((  ! --_i && 152 > 1  ))
16 compdump:116> ((  ! --_i && 151 > 1  ))
16 compdump:116> ((  ! --_i && 150 > 1  ))
16 compdump:116> ((  ! --_i && 147 > 1  ))
16 compdump:116> ((  ! --_i && 146 > 1  ))
16 compdump:116> ((  ! --_i && 140 > 1  ))
16 compdump:116> ((  ! --_i && 138 > 1  ))
16 compdump:116> ((  ! --_i && 135 > 1  ))
16 compdump:116> ((  ! --_i && 133 > 1  ))
16 compdump:116> ((  ! --_i && 132 > 1  ))
16 compdump:116> ((  ! --_i && 130 > 1  ))
16 compdump:116> ((  ! --_i && 123 > 1  ))
16 compdump:116> ((  ! --_i && 118 > 1  ))
16 compdump:116> ((  ! --_i && 117 > 1  ))
16 compdump:116> ((  ! --_i && 116 > 1  ))
16 compdump:116> ((  ! --_i && 115 > 1  ))
16 compdump:116> ((  ! --_i && 113 > 1  ))
16 compdump:116> ((  ! --_i && 108 > 1  ))
16 compdump:116> ((  ! --_i && 107 > 1  ))
16 compdump:116> ((  ! --_i && 106 > 1  ))
16 compdump:116> ((  ! --_i && 105 > 1  ))
16 compdump:116> ((  ! --_i && 100 > 1  ))
16 compdump:116> ((  ! --_i && 98 > 1  ))
16 compdump:116> ((  ! --_i && 96 > 1  ))
16 compdump:116> ((  ! --_i && 93 > 1  ))
16 compdump:116> ((  ! --_i && 92 > 1  ))
16 compdump:116> ((  ! --_i && 91 > 1  ))
16 compdump:116> ((  ! --_i && 88 > 1  ))
16 compdump:116> ((  ! --_i && 86 > 1  ))
16 compdump:116> ((  ! --_i && 82 > 1  ))
16 compdump:116> ((  ! --_i && 81 > 1  ))
16 compdump:116> ((  ! --_i && 80 > 1  ))
16 compdump:116> ((  ! --_i && 78 > 1  ))
16 compdump:116> ((  ! --_i && 77 > 1  ))
16 compdump:116> ((  ! --_i && 76 > 1  ))
16 compdump:116> ((  ! --_i && 75 > 1  ))
16 compdump:116> ((  ! --_i && 73 > 1  ))
16 compdump:116> ((  ! --_i && 72 > 1  ))
16 compdump:116> ((  ! --_i && 71 > 1  ))
16 compdump:116> ((  ! --_i && 70 > 1  ))
16 compdump:116> ((  ! --_i && 67 > 1  ))
16 compdump:116> ((  ! --_i && 61 > 1  ))
16 compdump:116> ((  ! --_i && 60 > 1  ))
16 compdump:116> ((  ! --_i && 58 > 1  ))
16 compdump:116> ((  ! --_i && 56 > 1  ))
16 compdump:116> ((  ! --_i && 52 > 1  ))
16 compdump:116> ((  ! --_i && 48 > 1  ))
16 compdump:116> ((  ! --_i && 46 > 1  ))
16 compdump:116> ((  ! --_i && 45 > 1  ))
16 compdump:116> ((  ! --_i && 41 > 1  ))
16 compdump:116> ((  ! --_i && 40 > 1  ))
16 compdump:116> ((  ! --_i && 38 > 1  ))
16 compdump:116> ((  ! --_i && 37 > 1  ))
16 compdump:116> ((  ! --_i && 35 > 1  ))
16 compdump:116> ((  ! --_i && 33 > 1  ))
16 compdump:116> ((  ! --_i && 32 > 1  ))
16 compdump:116> ((  ! --_i && 31 > 1  ))
16 compdump:116> ((  ! --_i && 30 > 1  ))
16 compdump:116> ((  ! --_i && 27 > 1  ))
16 compdump:116> ((  ! --_i && 26 > 1  ))
16 compdump:116> ((  ! --_i && 25 > 1  ))
16 compdump:116> ((  ! --_i && 23 > 1  ))
16 compdump:116> ((  ! --_i && 21 > 1  ))
16 compdump:116> ((  ! --_i && 20 > 1  ))
16 compdump:116> ((  ! --_i && 18 > 1  ))
16 compdump:116> ((  ! --_i && 16 > 1  ))
16 compdump:116> ((  ! --_i && 15 > 1  ))
16 compdump:116> ((  ! --_i && 12 > 1  ))
16 compdump:116> ((  ! --_i && 11 > 1  ))
16 compdump:116> ((  ! --_i && 10 > 1  ))
16 compdump:116> ((  ! --_i && 3 > 1  ))
16 compdump:115> print -n ' _zftp'
16 compdump:115> print -n ' _tilde'
16 compdump:115> print -n ' _thor'
16 compdump:115> print -n ' _svcs'
16 compdump:115> print -n ' _sfdx'
16 compdump:115> print -n ' _set_command'
16 compdump:115> print -n ' _sccs'
16 compdump:115> print -n ' _rsvm'
16 compdump:115> print -n ' _rm'
16 compdump:115> print -n ' _rails'
16 compdump:115> print -n ' _printers'
16 compdump:115> print -n ' _perf'
16 compdump:115> print -n ' _pbm'
16 compdump:115> print -n ' _netcat'
16 compdump:115> print -n ' _make-kpkg'
16 compdump:115> print -n ' _lsdev'
16 compdump:115> print -n ' _lp'
16 compdump:115> print -n ' _libvirt'
16 compdump:115> print -n ' _kpartx'
16 compdump:115> print -n ' _kdeconnect'
16 compdump:115> print -n ' _jot'
16 compdump:115> print -n ' _java'
16 compdump:115> print -n ' _jail'
16 compdump:115> print -n ' _ip'
16 compdump:115> print -n ' _diff'
16 compdump:115> print -n ' _df'
16 compdump:115> print -n ' _deb_files'
16 compdump:115> print -n ' _configure'
16 compdump:115> print -n ' _compdef'
16 compdump:115> print -n ' _comm'
16 compdump:115> print -n ' _cmake'
16 compdump:115> print -n ' _chrt'
16 compdump:115> print -n ' _chattr'
16 compdump:115> print -n ' _cdr'
16 compdump:114> ((  ! 1  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:114> ((  ! 0  ))
16 compdump:113> ((  1093  ))
16 compdump:113> ((  773  ))
16 compdump:113> ((  251  ))
16 compdump:85> [[ zle-line-finish = _* ]]
16 compdump:85> [[ where-is = _* ]]
16 compdump:85> [[ visual-line-mode = _* ]]
16 compdump:85> [[ vi-yank = _* ]]
16 compdump:85> [[ vi-unindent = _* ]]
16 compdump:85> [[ vi-substitute = _* ]]
16 compdump:85> [[ vi-set-buffer = _* ]]
16 compdump:85> [[ vi-replace-chars = _* ]]
16 compdump:85> [[ vi-repeat-search = _* ]]
16 compdump:85> [[ vi-repeat-change = _* ]]
16 compdump:85> [[ vi-open-line-below = _* ]]
16 compdump:85> [[ vi-kill-line = _* ]]
16 compdump:85> [[ vi-kill-eol = _* ]]
16 compdump:85> [[ vi-join = _* ]]
16 compdump:85> [[ vi-goto-mark = _* ]]
16 compdump:85> [[ vi-goto-column = _* ]]
16 compdump:85> [[ vi-forward-word = _* ]]
16 compdump:85> [[ vi-end-of-line = _* ]]
16 compdump:85> [[ vi-delete = _* ]]
16 compdump:85> [[ vi-backward-char = _* ]]
16 compdump:85> [[ up-history = _* ]]
16 compdump:85> [[ transpose-chars = _* ]]
16 compdump:85> [[ send-break = _* ]]
16 compdump:85> [[ select-in-word = _* ]]
16 compdump:85> [[ select-a-word = _* ]]
16 compdump:85> [[ reverse-menu-complete = _* ]]
16 compdump:85> [[ recursive-edit = _* ]]
16 compdump:85> [[ read-command = _* ]]
16 compdump:85> [[ quoted-insert = _* ]]
16 compdump:85> [[ quote-region = _* ]]
16 compdump:85> [[ push-line-or-edit = _* ]]
16 compdump:85> [[ push-input = _* ]]
16 compdump:85> [[ overwrite-mode = _* ]]
16 compdump:85> [[ neg-argument = _* ]]
16 compdump:85> [[ menu-select = _* ]]
16 compdump:85> [[ list-expand = _* ]]
16 compdump:85> [[ kill-word = _* ]]
16 compdump:85> [[ kill-whole-line = _* ]]
16 compdump:85> [[ kill-region = _* ]]
16 compdump:85> [[ kill-line = _* ]]
16 compdump:85> [[ gosmacs-transpose-chars = _* ]]
16 compdump:85> [[ get-line = _* ]]
16 compdump:85> [[ forward-word = _* ]]
16 compdump:85> [[ forward-char = _* ]]
16 compdump:85> [[ fasd-complete-f = _* ]]
16 compdump:85> [[ expand-word = _* ]]
16 compdump:85> [[ execute-named-cmd = _* ]]
16 compdump:85> [[ execute-last-named-cmd = _* ]]
16 compdump:85> [[ end-of-history = _* ]]
16 compdump:85> [[ emacs-forward-word = _* ]]
16 compdump:85> [[ emacs-backward-word = _* ]]
16 compdump:85> [[ down-line-or-beginning-search = _* ]]
16 compdump:85> [[ delete-word = _* ]]
16 compdump:85> [[ deactivate-region = _* ]]
16 compdump:85> [[ beginning-of-line-hist = _* ]]
16 compdump:85> [[ beginning-of-line = _* ]]
16 compdump:85> [[ autosuggest-fetch = _* ]]
16 compdump:85> [[ autosuggest-clear = _* ]]
16 compdump:85> [[ accept-line = _* ]]
16 compdump:85> [[ _most_recent_file = _* && _most_recent_file = _* ]]
16 compdump:85> [[ _history-complete-newer = _* && _history_complete_word = _* ]]
16 compdump:85> [[ _correct_filename = _* && _correct_filename = _* ]]
16 compdump:85> [[ _bash_list-choices = _* && _bash_completions = _* ]]
16 compdump:62> _d_f=shasum(|5).*
16 compdump:62> _d_f=qemu(|-system-*)
16 compdump:62> _d_f=php[0-9.-]
16 compdump:62> _d_f=lua[0-9.-]##
16 compdump:62> _d_f=c++-*
16 compdump:62> _d_f=-value-,LC_*,-default-
16 compdump:62> _d_f=-value-,CGO*,-default-
16 compdump:62> _d_f=-value-,CCACHE_*,-default-
16 compdump:62> _d_f=-value-,*path,-default-
16 compdump:62> _d_f=-value-,(ftp|http(|s))_proxy,-default-
16 compdump:62> _d_f=(tiff*|*2tiff|pal2rgb)
16 compdump:49> _d_f=svnlite
16 compdump:49> _d_f=ggpnp
16 compdump:49> _d_f=-redirect-,<,gzip
16 compdump:44> print -r - ''zxpdf'' ''_xpdf''
16 compdump:44> print -r - ''zun'' ''_openstack''
16 compdump:44> print -r - ''ztodo'' ''_ztodo''
16 compdump:44> print -r - ''zmv'' ''_zmv''
16 compdump:44> print -r - ''zlogin'' ''_zlogin''
16 compdump:44> print -r - ''zlistattr'' ''_zattr''
16 compdump:44> print -r - ''zgetattr'' ''_zattr''
16 compdump:44> print -r - ''zfs'' ''_zfs''
16 compdump:44> print -r - ''zf_mkdir'' ''_mkdir''
16 compdump:44> print -r - ''zf_chgrp'' ''_chown''
16 compdump:44> print -r - ''zdelattr'' ''_zattr''
16 compdump:44> print -r - ''zcp'' ''_zmv''
16 compdump:44> print -r - ''zcalc'' ''_zcalc''
16 compdump:44> print -r - ''yt-dlp'' ''_yt-dlp''
16 compdump:44> print -r - ''ypxfr'' ''_yp''
16 compdump:44> print -r - ''ypset'' ''_yp''
16 compdump:44> print -r - ''yppasswd'' ''_yp''
16 compdump:44> print -r - ''yast2'' ''_yast''
16 compdump:44> print -r - ''yash'' ''_sh''
16 compdump:44> print -r - ''yaourt'' ''_yaourt''
16 compdump:44> print -r - ''yafc'' ''_yafc''
16 compdump:44> print -r - ''xzcat'' ''_xz''
16 compdump:44> print -r - ''xwit'' ''_xwit''
16 compdump:44> print -r - ''xv'' ''_xv''
16 compdump:44> print -r - ''xterm'' ''_xterm''
16 compdump:44> print -r - ''xsltproc'' ''_xmlsoft''
16 compdump:44> print -r - ''xsetroot'' ''_x_utils''
16 compdump:44> print -r - ''xping'' ''_hosts''
16 compdump:44> print -r - ''xmosaic'' ''_webbrowser''
16 compdump:44> print -r - ''xkill'' ''_x_utils''
16 compdump:44> print -r - ''xinput'' ''_xinput''
16 compdump:44> print -r - ''xfig'' ''_xfig''
16 compdump:44> print -r - ''xdpyinfo'' ''_x_utils''
16 compdump:44> print -r - ''xauth'' ''_xauth''
16 compdump:44> print -r - ''xattr'' ''_attr''
16 compdump:44> print -r - ''who'' ''_who''
16 compdump:44> print -r - ''whatis'' ''_man''
16 compdump:44> print -r - ''wc'' ''_wc''
16 compdump:44> print -r - ''wait'' ''_wait''
16 compdump:44> print -r - ''vncviewer'' ''_vnc''
16 compdump:44> print -r - ''visudo'' ''_visudo''
16 compdump:44> print -r - ''vared'' ''_vared''
16 compdump:44> print -r - ''vagrant'' ''_vagrant''
16 compdump:44> print -r - ''userdel'' ''_users''
16 compdump:44> print -r - ''useradd'' ''_user_admin''
16 compdump:44> print -r - ''urxvt256c-mlc'' ''_urxvt''
16 compdump:44> print -r - ''urpmq'' ''_urpmi''
16 compdump:44> print -r - ''urpmi.update'' ''_urpmi''
16 compdump:44> print -r - ''urpmi'' ''_urpmi''
16 compdump:44> print -r - ''update-rc.d'' ''_update-rc.d''
16 compdump:44> print -r - ''unzip'' ''_zip''
16 compdump:44> print -r - ''unsetopt'' ''_setopt''
16 compdump:44> print -r - ''unset'' ''_vars''
16 compdump:44> print -r - ''unrar'' ''_rar''
16 compdump:44> print -r - ''unison'' ''_unison''
16 compdump:44> print -r - ''uniq'' ''_uniq''
16 compdump:44> print -r - ''unhash'' ''_unhash''
16 compdump:44> print -r - ''uncompress'' ''_compress''
16 compdump:44> print -r - ''uml_mconsole'' ''_uml''
16 compdump:44> print -r - ''type'' ''_which''
16 compdump:44> print -r - ''txt'' ''_hosts''
16 compdump:44> print -r - ''tunctl'' ''_uml''
16 compdump:44> print -r - ''trash'' ''_trash''
16 compdump:44> print -r - ''tracepath6'' ''_tracepath''
16 compdump:44> print -r - ''tput'' ''_tput''
16 compdump:44> print -r - ''top'' ''_top''
16 compdump:44> print -r - ''toilet'' ''_toilet''
16 compdump:44> print -r - ''tin'' ''_tin''
16 compdump:44> print -r - ''tg'' ''_topgit''
16 compdump:44> print -r - ''tex'' ''_tex''
16 compdump:44> print -r - ''telnet'' ''_telnet''
16 compdump:44> print -r - ''tee'' ''_tee''
16 compdump:44> print -r - ''tdd'' ''_devtodo''
16 compdump:44> print -r - ''tda'' ''_devtodo''
16 compdump:44> print -r - ''tardy'' ''_tardy''
16 compdump:44> print -r - ''sync'' ''_nothing''
16 compdump:44> print -r - ''swaks'' ''_swaks''
16 compdump:44> print -r - ''svnadmin'' ''_subversion''
16 compdump:44> print -r - ''svn'' ''_subversion''
16 compdump:44> print -r - ''svm'' ''_svm''
16 compdump:44> print -r - ''sv'' ''_runit''
16 compdump:44> print -r - ''subl'' ''_sublimetext''
16 compdump:44> print -r - ''strip'' ''_strip''
16 compdump:44> print -r - ''strace'' ''_strace''
16 compdump:44> print -r - ''stow'' ''_stow''
16 compdump:44> print -r - ''stat'' ''_stat''
16 compdump:44> print -r - ''sshfs'' ''_sshfs''
16 compdump:44> print -r - ''ssh-keygen'' ''_ssh''
16 compdump:44> print -r - ''ssh-add'' ''_ssh''
16 compdump:44> print -r - ''ssh'' ''_ssh''
16 compdump:44> print -r - ''splitdiff'' ''_patchutils''
16 compdump:44> print -r - ''split'' ''_split''
16 compdump:44> print -r - ''sortm'' ''_mh''
16 compdump:44> print -r - ''socket'' ''_socket''
16 compdump:44> print -r - ''snap'' ''_snap''
16 compdump:44> print -r - ''smit'' ''_smit''
16 compdump:44> print -r - ''smbstatus'' ''_samba''
16 compdump:44> print -r - ''slitex'' ''_tex''
16 compdump:44> print -r - ''skein1024'' ''_cksum''
16 compdump:44> print -r - ''skein256'' ''_cksum''
16 compdump:44> print -r - ''showmount'' ''_showmount''
16 compdump:44> print -r - ''shasum'' ''_shasum''
16 compdump:44> print -r - ''sha512t256'' ''_cksum''
16 compdump:44> print -r - ''sha256sum'' ''_md5sum''
16 compdump:44> print -r - ''sha1sum'' ''_md5sum''
16 compdump:44> print -r - ''sha1'' ''_cksum''
16 compdump:44> print -r - ''setfacl.exe'' ''_setfacl''
16 compdump:44> print -r - ''service'' ''_service''
16 compdump:44> print -r - ''serialver'' ''_java''
16 compdump:44> print -r - ''scl'' ''_scl''
16 compdump:44> print -r - ''sched'' ''_sched''
16 compdump:44> print -r - ''sccsdiff'' ''_sccs''
16 compdump:44> print -r - ''scala'' ''_scala''
16 compdump:44> print -r - ''sbt'' ''_sbt''
16 compdump:44> print -r - ''say'' ''_say''
16 compdump:44> print -r - ''sadf'' ''_sysstat''
16 compdump:44> print -r - ''rvim'' ''_vim''
16 compdump:44> print -r - ''rubber'' ''_rubber''
16 compdump:44> print -r - ''rtin'' ''_tin''
16 compdump:44> print -r - ''rsync'' ''_rsync''
16 compdump:44> print -r - ''rsvm'' ''_rsvm''
16 compdump:44> print -r - ''rspec'' ''_rspec''
16 compdump:44> print -r - ''rslsync'' ''_rslsync''
16 compdump:44> print -r - ''rsh'' ''_rlogin''
16 compdump:44> print -r - ''rrdtool'' ''_rrdtool''
16 compdump:44> print -r - ''rmid'' ''_java''
16 compdump:44> print -r - ''rkt'' ''_rkt''
16 compdump:44> print -r - ''ri'' ''_ri''
16 compdump:44> print -r - ''rgvim'' ''_vim''
16 compdump:44> print -r - ''rfkill'' ''_rfkill''
16 compdump:44> print -r - ''retawq'' ''_webbrowser''
16 compdump:44> print -r - ''restic'' ''_restic''
16 compdump:44> print -r - ''repl'' ''_mh''
16 compdump:44> print -r - ''reload'' ''_initctl''
16 compdump:44> print -r - ''readonly'' ''_typeset''
16 compdump:44> print -r - ''readlink'' ''_readlink''
16 compdump:44> print -r - ''rcctl'' ''_rcctl''
16 compdump:44> print -r - ''rar'' ''_rar''
16 compdump:44> print -r - ''querybts'' ''_bug''
16 compdump:44> print -r - ''pump'' ''_pump''
16 compdump:44> print -r - ''psresize'' ''_psutils''
16 compdump:44> print -r - ''psmulti'' ''_postscript''
16 compdump:44> print -r - ''psed'' ''_sed''
16 compdump:44> print -r - ''pscp.exe'' ''_pscp''
16 compdump:44> print -r - ''ps'' ''_ps''
16 compdump:44> print -r - ''prun'' ''_pids''
16 compdump:44> print -r - ''printenv'' ''_printenv''
16 compdump:44> print -r - ''postsuper'' ''_postfix''
16 compdump:44> print -r - ''portmaster'' ''_portmaster''
16 compdump:44> print -r - ''port'' ''_port''
16 compdump:44> print -r - ''poff'' ''_pon''
16 compdump:44> print -r - ''podtoc'' ''_perl_modules''
16 compdump:44> print -r - ''pmeth'' ''_perl_modules''
16 compdump:44> print -r - ''pmap'' ''_pmap''
16 compdump:44> print -r - ''pman'' ''_perl_modules''
16 compdump:44> print -r - ''pldd'' ''_pids''
16 compdump:44> print -r - ''play'' ''_play''
16 compdump:44> print -r - ''pkg_info'' ''_bsd_pkg''
16 compdump:44> print -r - ''pixz'' ''_pixz''
16 compdump:44> print -r - ''pinfo'' ''_texinfo''
16 compdump:44> print -r - ''pidof'' ''_pidof''
16 compdump:44> print -r - ''phing'' ''_phing''
16 compdump:44> print -r - ''pgrep'' ''_pgrep''
16 compdump:44> print -r - ''pflags'' ''_pids''
16 compdump:44> print -r - ''pfctl'' ''_pfctl''
16 compdump:44> print -r - ''perldoc'' ''_perldoc''
16 compdump:44> print -r - ''perf'' ''_perf''
16 compdump:44> print -r - ''pdm'' ''_pdm''
16 compdump:44> print -r - ''pdftopbm'' ''_pdf''
16 compdump:44> print -r - ''pdftk'' ''_pdftk''
16 compdump:44> print -r - ''pdflatex'' ''_tex''
16 compdump:44> print -r - ''pdffonts'' ''_pdf''
16 compdump:44> print -r - ''pcat'' ''_pack''
16 compdump:44> print -r - ''pax'' ''_pax''
16 compdump:44> print -r - ''packf'' ''_mh''
16 compdump:44> print -r - ''otool'' ''_otool''
16 compdump:44> print -r - ''osc'' ''_osc''
16 compdump:44> print -r - ''oksh'' ''_sh''
16 compdump:44> print -r - ''ogginfo'' ''_vorbis''
16 compdump:44> print -r - ''odme'' ''_object_classes''
16 compdump:44> print -r - ''nvm'' ''_nvm''
16 compdump:44> print -r - ''nvim'' ''_vim''
16 compdump:44> print -r - ''nova'' ''_openstack''
16 compdump:44> print -r - ''node'' ''_node''
16 compdump:44> print -r - ''ngrep'' ''_ngrep''
16 compdump:44> print -r - ''netrik'' ''_webbrowser''
16 compdump:44> print -r - ''netcat'' ''_netcat''
16 compdump:44> print -r - ''ncl'' ''_nedit''
16 compdump:44> print -r - ''nawk'' ''_awk''
16 compdump:44> print -r - ''mvnDebug'' ''_mvn''
16 compdump:44> print -r - ''mux'' ''_tmuxinator''
16 compdump:44> print -r - ''mutt'' ''_mutt''
16 compdump:44> print -r - ''mtype'' ''_mtools''
16 compdump:44> print -r - ''mtn'' ''_monotone''
16 compdump:44> print -r - ''mt'' ''_mt''
16 compdump:44> print -r - ''mrd'' ''_mtools''
16 compdump:44> print -r - ''mount'' ''_mount''
16 compdump:44> print -r - ''mosh'' ''_mosh''
16 compdump:44> print -r - ''mondoarchive'' ''_mondo''
16 compdump:44> print -r - ''mkzsh'' ''_mkzsh''
16 compdump:44> print -r - ''mktunes.pl'' ''_gnupod''
16 compdump:44> print -r - ''mksh'' ''_sh''
16 compdump:44> print -r - ''mina'' ''_mina''
16 compdump:44> print -r - ''mii-tool'' ''_mii-tool''
16 compdump:44> print -r - ''middleman'' ''_middleman''
16 compdump:44> print -r - ''mhstore'' ''_mh''
16 compdump:44> print -r - ''mhshow'' ''_mh''
16 compdump:44> print -r - ''mhfixmsg'' ''_mh''
16 compdump:44> print -r - ''mgv'' ''_pspdf''
16 compdump:44> print -r - ''mformat'' ''_mtools''
16 compdump:44> print -r - ''merge'' ''_rcs''
16 compdump:44> print -r - ''mere'' ''_mere''
16 compdump:44> print -r - ''mencal'' ''_mencal''
16 compdump:44> print -r - ''members'' ''_members''
16 compdump:44> print -r - ''mdutil'' ''_mdutil''
16 compdump:44> print -r - ''mdu'' ''_mtools''
16 compdump:44> print -r - ''mdls'' ''_mdls''
16 compdump:44> print -r - ''md2'' ''_cksum''
16 compdump:44> print -r - ''mcopy'' ''_mtools''
16 compdump:44> print -r - ''mark'' ''_mh''
16 compdump:44> print -r - ''manila'' ''_openstack''
16 compdump:44> print -r - ''mailx'' ''_mail''
16 compdump:44> print -r - ''mail'' ''_mail''
16 compdump:44> print -r - ''m-a'' ''_module-assistant''
16 compdump:44> print -r - ''lzma'' ''_xz''
16 compdump:44> print -r - ''lzcat'' ''_xz''
16 compdump:44> print -r - ''lz4cat'' ''_lz4''
16 compdump:44> print -r - ''lz4c32'' ''_lz4''
16 compdump:44> print -r - ''lz4c'' ''_lz4''
16 compdump:44> print -r - ''lz4'' ''_lz4''
16 compdump:44> print -r - ''lynx'' ''_lynx''
16 compdump:44> print -r - ''lunchy'' ''_lunchy''
16 compdump:44> print -r - ''lsvg'' ''_lsvg''
16 compdump:44> print -r - ''lsusb'' ''_lsusb''
16 compdump:44> print -r - ''lspv'' ''_lspv''
16 compdump:44> print -r - ''lsof'' ''_lsof''
16 compdump:44> print -r - ''lsmod'' ''_modutils''
16 compdump:44> print -r - ''lslv'' ''_lslv''
16 compdump:44> print -r - ''lsdiff'' ''_patchutils''
16 compdump:44> print -r - ''lpq'' ''_lp''
16 compdump:44> print -r - ''localedef'' ''_localedef''
16 compdump:44> print -r - ''locale'' ''_locale''
16 compdump:44> print -r - ''local'' ''_typeset''
16 compdump:44> print -r - ''ln'' ''_ln''
16 compdump:44> print -r - ''lldb'' ''_lldb''
16 compdump:44> print -r - ''links2'' ''_links''
16 compdump:44> print -r - ''light'' ''_webbrowser''
16 compdump:44> print -r - ''latex'' ''_tex''
16 compdump:44> print -r - ''ksh93'' ''_sh''
16 compdump:44> print -r - ''kitchen'' ''_kitchen''
16 compdump:44> print -r - ''kdeconnect-cli'' ''_kdeconnect''
16 compdump:44> print -r - ''jls'' ''_jls''
16 compdump:44> print -r - ''jexec'' ''_jexec''
16 compdump:44> print -r - ''javadoc'' ''_java''
16 compdump:44> print -r - ''jail'' ''_jail''
16 compdump:44> print -r - ''ipset'' ''_ipset''
16 compdump:44> print -r - ''interdiff'' ''_patchutils''
16 compdump:44> print -r - ''integer'' ''_typeset''
16 compdump:44> print -r - ''insmod'' ''_modutils''
16 compdump:44> print -r - ''info'' ''_texinfo''
16 compdump:44> print -r - ''includeres'' ''_psutils''
16 compdump:44> print -r - ''ibus'' ''_ibus''
16 compdump:44> print -r - ''http'' ''_httpie''
16 compdump:44> print -r - ''hotjava'' ''_webbrowser''
16 compdump:44> print -r - ''hostname'' ''_hostname''
16 compdump:44> print -r - ''hilite'' ''_precommand''
16 compdump:44> print -r - ''hexdump'' ''_hexdump''
16 compdump:44> print -r - ''help'' ''_sccs''
16 compdump:44> print -r - ''helm'' ''_helm''
16 compdump:44> print -r - ''head'' ''_head''
16 compdump:44> print -r - ''hd'' ''_hexdump''
16 compdump:44> print -r - ''hash'' ''_hash''
16 compdump:44> print -r - ''gzgrep'' ''_grep''
16 compdump:44> print -r - ''gzfgrep'' ''_grep''
16 compdump:44> print -r - ''gzegrep'' ''_grep''
16 compdump:44> print -r - ''gzcat'' ''_gzip''
16 compdump:44> print -r - ''gxargs'' ''_xargs''
16 compdump:44> print -r - ''gwho'' ''_who''
16 compdump:44> print -r - ''gwc'' ''_wc''
16 compdump:44> print -r - ''gv'' ''_gv''
16 compdump:44> print -r - ''gunzip'' ''_gzip''
16 compdump:44> print -r - ''guniq'' ''_uniq''
16 compdump:44> print -r - ''guilt-status'' ''_guilt''
16 compdump:44> print -r - ''guilt-series'' ''_guilt''
16 compdump:44> print -r - ''guilt-prev'' ''_guilt''
16 compdump:44> print -r - ''guilt-pop'' ''_guilt''
16 compdump:44> print -r - ''guilt-patchbomb'' ''_guilt''
16 compdump:44> print -r - ''guilt-fold'' ''_guilt''
16 compdump:44> print -r - ''guilt-files'' ''_guilt''
16 compdump:44> print -r - ''gtty'' ''_tty''
16 compdump:44> print -r - ''gtr'' ''_tr''
16 compdump:44> print -r - ''gtouch'' ''_touch''
16 compdump:44> print -r - ''gtee'' ''_tee''
16 compdump:44> print -r - ''gtac'' ''_tac''
16 compdump:44> print -r - ''gsort'' ''_sort''
16 compdump:44> print -r - ''gshuf'' ''_shuf''
16 compdump:44> print -r - ''gsdj500'' ''_pspdf''
16 compdump:44> print -r - ''gs'' ''_ghostscript''
16 compdump:44> print -r - ''gofmt'' ''_go''
16 compdump:44> print -r - ''gnutls-serv'' ''_gnutls''
16 compdump:44> print -r - ''gnutls-cli'' ''_gnutls''
16 compdump:44> print -r - ''gnl'' ''_nl''
16 compdump:44> print -r - ''gmkfifo'' ''_mkfifo''
16 compdump:44> print -r - ''gls'' ''_ls''
16 compdump:44> print -r - ''ggv'' ''_gnome-gv''
16 compdump:44> print -r - ''ggpnp'' ''_git''
16 compdump:44> print -r - ''ggp'' ''_git''
16 compdump:44> print -r - ''gex'' ''_vim''
16 compdump:44> print -r - ''getent'' ''_getent''
16 compdump:44> print -r - ''gegrep'' ''_grep''
16 compdump:44> print -r - ''gdf'' ''_df''
16 compdump:44> print -r - ''gdd'' ''_dd''
16 compdump:44> print -r - ''gchroot'' ''_chroot''
16 compdump:44> print -r - ''gccd'' ''_git''
16 compdump:44> print -r - ''gas'' ''_gas''
16 compdump:44> print -r - ''ftp'' ''_hosts''
16 compdump:44> print -r - ''fsh'' ''_fsh''
16 compdump:44> print -r - ''force'' ''_force''
16 compdump:44> print -r - ''fmadm'' ''_fmadm''
16 compdump:44> print -r - ''flutter'' ''_flutter''
16 compdump:44> print -r - ''flac'' ''_flac''
16 compdump:44> print -r - ''fetch'' ''_fetch''
16 compdump:44> print -r - ''fc'' ''_fc''
16 compdump:44> print -r - ''fab'' ''_fab''
16 compdump:44> print -r - ''evince'' ''_evince''
16 compdump:44> print -r - ''epdfview'' ''_pdf''
16 compdump:44> print -r - ''emulator'' ''_emulator''
16 compdump:44> print -r - ''echotc'' ''_echotc''
16 compdump:44> print -r - ''dvitype'' ''_dvi''
16 compdump:44> print -r - ''dtrace'' ''_dtrace''
16 compdump:44> print -r - ''dsh'' ''_dsh''
16 compdump:44> print -r - ''dpkg'' ''_dpkg''
16 compdump:44> print -r - ''dosread'' ''_floppy''
16 compdump:44> print -r - ''docpad'' ''_docpad''
16 compdump:44> print -r - ''doas'' ''_doas''
16 compdump:44> print -r - ''dladm'' ''_dladm''
16 compdump:44> print -r - ''diffstat'' ''_diffstat''
16 compdump:44> print -r - ''diff3'' ''_diff3''
16 compdump:44> print -r - ''dict'' ''_dict''
16 compdump:44> print -r - ''dhclient'' ''_dhclient''
16 compdump:44> print -r - ''deno'' ''_deno''
16 compdump:44> print -r - ''delta'' ''_sccs''
16 compdump:44> print -r - ''debuild'' ''_debuild''
16 compdump:44> print -r - ''dcopstart'' ''_dcop''
16 compdump:44> print -r - ''dcopfind'' ''_dcop''
16 compdump:44> print -r - ''dconf'' ''_dconf''
16 compdump:44> print -r - ''dch'' ''_debchange''
16 compdump:44> print -r - ''darcs'' ''_darcs''
16 compdump:44> print -r - ''d'' ''_dirs''
16 compdump:44> print -r - ''cut'' ''_cut''
16 compdump:44> print -r - ''curl'' ''_curl''
16 compdump:44> print -r - ''crsh'' ''_cssh''
16 compdump:44> print -r - ''comm'' ''_comm''
16 compdump:44> print -r - ''co'' ''_rcs''
16 compdump:44> print -r - ''cmp'' ''_cmp''
16 compdump:44> print -r - ''chsh'' ''_chsh''
16 compdump:44> print -r - ''chdir'' ''_cd''
16 compdump:44> print -r - ''chage'' ''_users''
16 compdump:44> print -r - ''ccal'' ''_ccal''
16 compdump:44> print -r - ''cc'' ''_gcc''
16 compdump:44> print -r - ''cask'' ''_cask''
16 compdump:44> print -r - ''cal'' ''_cal''
16 compdump:44> print -r - ''c++'' ''_gcc''
16 compdump:44> print -r - ''bzcat'' ''_bzip2''
16 compdump:44> print -r - ''beadm'' ''_beadm''
16 compdump:44> print -r - ''batch'' ''_at''
16 compdump:44> print -r - ''ash'' ''_sh''
16 compdump:44> print -r - ''artisan'' ''_artisan''
16 compdump:44> print -r - ''apt'' ''_apt''
16 compdump:43> _d_f=zxpdf
16 compdump:43> _d_f=zparseopts
16 compdump:43> _d_f=zlogin
16 compdump:43> _d_f=zln
16 compdump:43> _d_f=zf_mkdir
16 compdump:43> _d_f=zdelattr
16 compdump:43> _d_f=yt-dlp
16 compdump:43> _d_f=xtightvncviewer
16 compdump:43> _d_f=xsltproc
16 compdump:43> _d_f=xscreensaver-command
16 compdump:43> _d_f=xmosaic
16 compdump:43> _d_f=xmms2
16 compdump:43> _d_f=xkill
16 compdump:43> _d_f=xdpyinfo
16 compdump:43> _d_f=w
16 compdump:43> _d_f=vserver
16 compdump:43> _d_f=vitrage
16 compdump:43> _d_f=virt-host-validate
16 compdump:43> _d_f=val
16 compdump:43> _d_f=userdel
16 compdump:43> _d_f=urpmq
16 compdump:43> _d_f=update-rc.d
16 compdump:43> _d_f=update-alternatives
16 compdump:43> _d_f=unzip
16 compdump:43> _d_f=unsetopt
16 compdump:43> _d_f=uniq
16 compdump:43> _d_f=uml_switch
16 compdump:43> _d_f=uml_moo
16 compdump:43> _d_f=ufw
16 compdump:43> _d_f=txt
16 compdump:43> _d_f=trash
16 compdump:43> _d_f=trap
16 compdump:43> _d_f=tracepath6
16 compdump:43> _d_f=tpkg-update
16 compdump:43> _d_f=top
16 compdump:43> _d_f=tex
16 compdump:43> _d_f=tac
16 compdump:43> _d_f=svnadmin-static
16 compdump:43> _d_f=svn-buildpackage
16 compdump:43> _d_f=svn
16 compdump:43> _d_f=subliminal
16 compdump:43> _d_f=strace
16 compdump:43> _d_f=start
16 compdump:43> _d_f=sr
16 compdump:43> _d_f=splitdiff
16 compdump:43> _d_f=softwareupdate
16 compdump:43> _d_f=smit
16 compdump:43> _d_f=skein256
16 compdump:43> _d_f=shasum
16 compdump:43> _d_f=sha256sum
16 compdump:43> _d_f=sha1sum
16 compdump:43> _d_f=service
16 compdump:43> _d_f=scriptreplay
16 compdump:43> _d_f=sched
16 compdump:43> _d_f=say
16 compdump:43> _d_f=run-help
16 compdump:43> _d_f=ruby-mri
16 compdump:43> _d_f=rmadison
16 compdump:43> _d_f=rm
16 compdump:43> _d_f=rgview
16 compdump:43> _d_f=readonly
16 compdump:43> _d_f=rclone
16 compdump:43> _d_f=querybts
16 compdump:43> _d_f=psnup
16 compdump:43> _d_f=psmulti
16 compdump:43> _d_f=psed
16 compdump:43> _d_f=ps
16 compdump:43> _d_f=postsuper
16 compdump:43> _d_f=port
16 compdump:43> _d_f=poff
16 compdump:43> _d_f=pmeth
16 compdump:43> _d_f=pmcat
16 compdump:43> _d_f=pmap
16 compdump:43> _d_f=pkgrm
16 compdump:43> _d_f=phing
16 compdump:43> _d_f=pflags
16 compdump:43> _d_f=pfctl
16 compdump:43> _d_f=pdftopbm
16 compdump:43> _d_f=pcat
16 compdump:43> _d_f=parsehdlist
16 compdump:43> _d_f=otool
16 compdump:43> _d_f=oksh
16 compdump:43> _d_f=odmget
16 compdump:43> _d_f=nvm
16 compdump:43> _d_f=noglob
16 compdump:43> _d_f=networksetup
16 compdump:43> _d_f=netrik
16 compdump:43> _d_f=netcat
16 compdump:43> _d_f=nawk
16 compdump:43> _d_f=mux
16 compdump:43> _d_f=mtn
16 compdump:43> _d_f=mr
16 compdump:43> _d_f=mozilla-xremote-client
16 compdump:43> _d_f=mount
16 compdump:43> _d_f=mlabel
16 compdump:43> _d_f=mii-tool
16 compdump:43> _d_f=mdel
16 compdump:43> _d_f=m-a
16 compdump:43> _d_f=locale
16 compdump:43> _d_f=llvm-g++
16 compdump:43> _d_f=ksh93
16 compdump:43> _d_f=jdb
16 compdump:43> _d_f=javap
16 compdump:43> _d_f=javah
16 compdump:43> _d_f=invoke-rc.d
16 compdump:43> _d_f=include-what-you-use
16 compdump:43> _d_f=http
16 compdump:43> _d_f=htop
16 compdump:43> _d_f=hash
16 compdump:43> _d_f=gzegrep
16 compdump:43> _d_f=gunzip
16 compdump:43> _d_f=gunexpand
16 compdump:43> _d_f=guilt-pop
16 compdump:43> _d_f=guilt-import-commit
16 compdump:43> _d_f=guilt-fold
16 compdump:43> _d_f=gtimeout
16 compdump:43> _d_f=gstrings
16 compdump:43> _d_f=gsettings
16 compdump:43> _d_f=gsdj500
16 compdump:43> _d_f=gsbj
16 compdump:43> _d_f=gs
16 compdump:43> _d_f=growisofs
16 compdump:43> _d_f=groupadd
16 compdump:43> _d_f=groff
16 compdump:43> _d_f=grepdiff
16 compdump:43> _d_f=greadlink
16 compdump:43> _d_f=gprintenv
16 compdump:43> _d_f=gpgv
16 compdump:43> _d_f=google
16 compdump:43> _d_f=gofmt
16 compdump:43> _d_f=go
16 compdump:43> _d_f=gnutls-serv
16 compdump:43> _d_f=gnutls-cli-debug
16 compdump:43> _d_f=gnutls-cli
16 compdump:43> _d_f=gnupod_addsong.pl
16 compdump:43> _d_f=gnupod_INIT.pl
16 compdump:43> _d_f=gnocchi
16 compdump:43> _d_f=gmplayer
16 compdump:43> _d_f=gmknod
16 compdump:43> _d_f=gmkfifo
16 compdump:43> _d_f=gm
16 compdump:43> _d_f=git-revise
16 compdump:43> _d_f=git-journal
16 compdump:43> _d_f=ghostview
16 compdump:43> _d_f=gh
16 compdump:43> _d_f=ggv
16 compdump:43> _d_f=ggpnp
16 compdump:43> _d_f=ggp
16 compdump:43> _d_f=gfgrep
16 compdump:43> _d_f=gex
16 compdump:43> _d_f=getopt
16 compdump:43> _d_f=getfacl.exe
16 compdump:43> _d_f=getfacl
16 compdump:43> _d_f=getent
16 compdump:43> _d_f=getconf
16 compdump:43> _d_f=getclip
16 compdump:43> _d_f=genisoimage
16 compdump:43> _d_f=gem
16 compdump:43> _d_f=gegrep
16 compdump:43> _d_f=gdu
16 compdump:43> _d_f=gdiff
16 compdump:43> _d_f=gdf
16 compdump:43> _d_f=gcut
16 compdump:43> _d_f=gcmp
16 compdump:43> _d_f=gchroot
16 compdump:43> _d_f=gchmod
16 compdump:43> _d_f=gccgo
16 compdump:43> _d_f=gccd
16 compdump:43> _d_f=gcat
16 compdump:43> _d_f=gas
16 compdump:43> _d_f=fwhois
16 compdump:43> _d_f=fusermount
16 compdump:43> _d_f=functions
16 compdump:43> _d_f=ftp
16 compdump:43> _d_f=fsh
16 compdump:43> _d_f=fs_usage
16 compdump:43> _d_f=forw
16 compdump:43> _d_f=fortune
16 compdump:43> _d_f=force
16 compdump:43> _d_f=fmt
16 compdump:43> _d_f=fmadm
16 compdump:43> _d_f=fly
16 compdump:43> _d_f=flutter
16 compdump:43> _d_f=flowadm
16 compdump:43> _d_f=flist
16 compdump:43> _d_f=flex++
16 compdump:43> _d_f=fleetctl
16 compdump:43> _d_f=flac
16 compdump:43> _d_f=fixwpps
16 compdump:43> _d_f=fixscribeps
16 compdump:43> _d_f=fixpspps
16 compdump:43> _d_f=fixdlsrps
16 compdump:43> _d_f=findaffix
16 compdump:43> _d_f=fetch
16 compdump:43> _d_f=epsffit
16 compdump:43> _d_f=echoti
16 compdump:43> _d_f=dvicopy
16 compdump:43> _d_f=dtrace
16 compdump:43> _d_f=dpkg
16 compdump:43> _d_f=dpatch-edit-patch
16 compdump:43> _d_f=dosread
16 compdump:43> _d_f=domainname
16 compdump:43> _d_f=docker-compose
16 compdump:43> _d_f=dlocate
16 compdump:43> _d_f=diffstat
16 compdump:43> _d_f=designate
16 compdump:43> _d_f=deno
16 compdump:43> _d_f=declare
16 compdump:43> _d_f=dcopobject
16 compdump:43> _d_f=dch
16 compdump:43> _d_f=dbus-launch
16 compdump:43> _d_f=d
16 compdump:43> _d_f=cygserver.exe
16 compdump:43> _d_f=cygrunsrv.exe
16 compdump:43> _d_f=cut
16 compdump:43> _d_f=console
16 compdump:43> _d_f=composite
16 compdump:43> _d_f=command
16 compdump:43> _d_f=combinediff
16 compdump:43> _d_f=co
16 compdump:43> _d_f=cmp
16 compdump:43> _d_f=clusterdb
16 compdump:43> _d_f=clang++
16 compdump:43> _d_f=cinder
16 compdump:43> _d_f=chsh
16 compdump:43> _d_f=chage
16 compdump:43> _d_f=certtool
16 compdump:43> _d_f=ccal
16 compdump:43> _d_f=cask
16 compdump:43> _d_f=calendar
16 compdump:43> _d_f=bzegrep
16 compdump:43> _d_f=btreannounce
16 compdump:43> _d_f=btlaunchmanycurses
16 compdump:43> _d_f=btlaunchmany
16 compdump:43> _d_f=btdownloadheadless
16 compdump:43> _d_f=btdownloadcurses
16 compdump:43> _d_f=bsdinstall
16 compdump:43> _d_f=bsdconfig
16 compdump:43> _d_f=bpython3-gtk
16 compdump:43> _d_f=bpython2-urwid
16 compdump:43> _d_f=bpython2-gtk
16 compdump:43> _d_f=bogoutil
16 compdump:43> _d_f=bogotune
16 compdump:43> _d_f=bmake
16 compdump:43> _d_f=bindkey
16 compdump:43> _d_f=bg
16 compdump:43> _d_f=beep
16 compdump:43> _d_f=beadm
16 compdump:43> _d_f=baz
16 compdump:43> _d_f=batch
16 compdump:43> _d_f=base32
16 compdump:43> _d_f=avahi-resolve
16 compdump:43> _d_f=avahi-browse-domains
16 compdump:43> _d_f=auto-apt
16 compdump:43> _d_f=augtool
16 compdump:43> _d_f=ash
16 compdump:43> _d_f=asciinema
16 compdump:43> _d_f=asciidoctor
16 compdump:43> _d_f=artisan
16 compdump:43> _d_f=apt-move
16 compdump:43> _d_f=apt-mark
16 compdump:43> _d_f=apt-cdrom
16 compdump:43> _d_f=apt-cache
16 compdump:43> _d_f=apt
16 compdump:43> _d_f=apm
16 compdump:43> _d_f=apachectl
16 compdump:43> _d_f=aodh
16 compdump:43> _d_f=ant
16 compdump:43> _d_f=ansible-pull
16 compdump:43> _d_f=ansible-playbook
16 compdump:43> _d_f=ansible-doc
16 compdump:43> _d_f=ansible-console
16 compdump:43> _d_f=ansible
16 compdump:43> _d_f=anno
16 compdump:43> _d_f=amaya
16 compdump:43> _d_f=alias
16 compdump:43> _d_f=add-zsh-hook
16 compdump:43> _d_f=acroread
16 compdump:43> _d_f=acpitool
16 compdump:43> _d_f=acpi
16 compdump:43> _d_f=ack-standalone
16 compdump:43> _d_f=abcde
16 compdump:43> _d_f=aap
16 compdump:43> _d_f=aaaa
16 compdump:43> _d_f=a2ensite
16 compdump:43> _d_f=a2dissite
16 compdump:43> _d_f=_restic
16 compdump:43> _d_f=_rclone
16 compdump:43> _d_f=_helm
16 compdump:43> _d_f=_git_log_prettily
16 compdump:43> _d_f=_gh
16 compdump:43> _d_f=Mosaic
16 compdump:43> _d_f=Mail
16 compdump:43> _d_f=8l
16 compdump:43> _d_f=8g
16 compdump:43> _d_f=6l
16 compdump:43> _d_f=6g
16 compdump:43> _d_f=5l
16 compdump:43> _d_f=.
16 compdump:43> _d_f=-zcalc-line-
16 compdump:43> _d_f=-value-,XZ_DEFAULTS,-default-
16 compdump:43> _d_f=-value-,WWW_HOME,-default-
16 compdump:43> _d_f=-value-,VALGRIND_OPTS,-default-
16 compdump:43> _d_f=-value-,TZ,-default-
16 compdump:43> _d_f=-value-,TERM,-default-
16 compdump:43> _d_f=-value-,SPROMPT,-default-
16 compdump:43> _d_f=-value-,RPS1,-default-
16 compdump:43> _d_f=-value-,PS2,-default-
16 compdump:43> _d_f=-value-,PRINTER,-default-
16 compdump:43> _d_f=-value-,PERLDOC,-default-
16 compdump:43> _d_f=-value-,P4PORT,-default-
16 compdump:43> _d_f=-value-,MPD_HOST,-default
16 compdump:43> _d_f=-value-,LOOPDEV_DEBUG,-default-
16 compdump:43> _d_f=-value-,LESSCHARSET,-default-
16 compdump:43> _d_f=-value-,LD_DEBUG,-default-
16 compdump:43> _d_f=-value-,LANGUAGE,-default-
16 compdump:43> _d_f=-value-,LANG,-default-
16 compdump:43> _d_f=-value-,GREP_OPTIONS,-default-
16 compdump:43> _d_f=-value-,DISPLAY,-default-
16 compdump:43> _d_f=-value-,CXXFLAGS,-default-
16 compdump:43> _d_f=-value-,CPPFLAGS,-default-
16 compdump:43> _d_f=-value-,CMAKE_GENERATOR,-default-
16 compdump:43> _d_f=-value-,CFLAGS,-default-
16 compdump:43> _d_f=-value-,ANT_ARGS,-default-
16 compdump:43> _d_f=-value-,ANDROID_SERIAL,-default-
16 compdump:43> _d_f=-value-,ADB_TRACE,-default-
16 compdump:43> _d_f=-value-,-default-,-command-
16 compdump:43> _d_f=-value-
16 compdump:43> _d_f=-subscript-
16 compdump:43> _d_f=-redirect-,>,xz
16 compdump:43> _d_f=-redirect-,>,gzip
16 compdump:43> _d_f=-redirect-,>,bzip2
16 compdump:43> _d_f=-redirect-,<,xz
16 compdump:43> _d_f=-redirect-,<,gunzip
16 compdump:43> _d_f=-redirect-,<,compress
16 compdump:43> _d_f=-redirect-,<,bzip2
16 compdump:43> _d_f=-redirect-,<,bunzip2
16 compdump:43> _d_f=-redirect-,-default-,-default-
16 compdump:43> _d_f=-parameter-
16 compdump:43> _d_f=-math-
16 compdump:43> _d_f=-default-
16 compdump:43> _d_f=-command-line-
16 compdump:43> _d_f=-command-
16 compdump:43> _d_f=-brace-parameter-
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:169> shift
16 compdef:163> _comps[$cmd]=_rlogin
16 compdef:163> _comps[$cmd]=_mail
16 compdef:163> _comps[$cmd]=_git
16 compdef:162> [[ -z yes || -z _yp ]]
16 compdef:162> [[ -z yes || -z _yp ]]
16 compdef:162> [[ -z yes || -z _yp ]]
16 compdef:162> [[ -z yes || -z _yp ]]
16 compdef:162> [[ -z yes || -z _xz ]]
16 compdef:162> [[ -z yes || -z _which ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _webbrowser ]]
16 compdef:162> [[ -z yes || -z _vorbis ]]
16 compdef:162> [[ -z yes || -z _vorbis ]]
16 compdef:162> [[ -z yes || -z _vnc ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _vim ]]
16 compdef:162> [[ -z yes || -z _value ]]
16 compdef:162> [[ -z yes || -z _users ]]
16 compdef:162> [[ -z yes || -z _user_admin ]]
16 compdef:162> [[ -z yes || -z _urxvt ]]
16 compdef:162> [[ -z yes || -z _urxvt ]]
16 compdef:162> [[ -z yes || -z _urxvt ]]
16 compdef:162> [[ -z yes || -z _urpmi ]]
16 compdef:162> [[ -z yes || -z _urpmi ]]
16 compdef:162> [[ -z yes || -z _urpmi ]]
16 compdef:162> [[ -z yes || -z _uml ]]
16 compdef:162> [[ -z yes || -z _uml ]]
16 compdef:162> [[ -z yes || -z _typeset ]]
16 compdef:162> [[ -z yes || -z _typeset ]]
16 compdef:162> [[ -z yes || -z _twisted ]]
16 compdef:162> [[ -z yes || -z _twisted ]]
16 compdef:162> [[ -z yes || -z _twisted ]]
16 compdef:162> [[ -z yes || -z _twisted ]]
16 compdef:162> [[ -z yes || -z _toolchain-source ]]
16 compdef:162> [[ -z yes || -z _texinfo ]]
16 compdef:162> [[ -z yes || -z _texinfo ]]
16 compdef:162> [[ -z yes || -z _texinfo ]]
16 compdef:162> [[ -z yes || -z _texinfo ]]
16 compdef:162> [[ -z yes || -z _texinfo ]]
16 compdef:162> [[ -z yes || -z _tex ]]
16 compdef:162> [[ -z yes || -z _tex ]]
16 compdef:162> [[ -z yes || -z _ssh ]]
16 compdef:162> [[ -z yes || -z _sh ]]
16 compdef:162> [[ -z yes || -z _sh ]]
16 compdef:162> [[ -z yes || -z _sh ]]
16 compdef:162> [[ -z yes || -z _sh ]]
16 compdef:162> [[ -z yes || -z _sccs ]]
16 compdef:162> [[ -z yes || -z _sccs ]]
16 compdef:162> [[ -z yes || -z _sccs ]]
16 compdef:162> [[ -z yes || -z _sccs ]]
16 compdef:162> [[ -z yes || -z _ruby ]]
16 compdef:162> [[ -z yes || -z _rubber ]]
16 compdef:162> [[ -z yes || -z _rpm ]]
16 compdef:162> [[ -z yes || -z _rlogin ]]
16 compdef:162> [[ -z yes || -z _rcs ]]
16 compdef:162> [[ -z yes || -z _rcs ]]
16 compdef:162> [[ -z yes || -z _rcs ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _psutils ]]
16 compdef:162> [[ -z yes || -z _pspdf ]]
16 compdef:162> [[ -z yes || -z _pspdf ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _ps1234 ]]
16 compdef:162> [[ -z yes || -z _precommand ]]
16 compdef:162> [[ -z yes || -z _precommand ]]
16 compdef:162> [[ -z yes || -z _postscript ]]
16 compdef:162> [[ -z yes || -z _postscript ]]
16 compdef:162> [[ -z yes || -z _postscript ]]
16 compdef:162> [[ -z yes || -z _postscript ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _postgresql ]]
16 compdef:162> [[ -z yes || -z _pkgtool ]]
16 compdef:162> [[ -z yes || -z _pkgtool ]]
16 compdef:162> [[ -z yes || -z _pkgtool ]]
16 compdef:162> [[ -z yes || -z _pkgtool ]]
16 compdef:162> [[ -z yes || -z _pids ]]
16 compdef:162> [[ -z yes || -z _perl_modules ]]
16 compdef:162> [[ -z yes || -z _perl_modules ]]
16 compdef:162> [[ -z yes || -z _perforce ]]
16 compdef:162> [[ -z yes || -z _perforce ]]
16 compdef:162> [[ -z yes || -z _perforce ]]
16 compdef:162> [[ -z yes || -z _perforce ]]
16 compdef:162> [[ -z yes || -z _pdf ]]
16 compdef:162> [[ -z yes || -z _pdf ]]
16 compdef:162> [[ -z yes || -z _pdf ]]
16 compdef:162> [[ -z yes || -z _pdf ]]
16 compdef:162> [[ -z yes || -z _pdf ]]
16 compdef:162> [[ -z yes || -z _patchutils ]]
16 compdef:162> [[ -z yes || -z _patchutils ]]
16 compdef:162> [[ -z yes || -z _patchutils ]]
16 compdef:162> [[ -z yes || -z _patchutils ]]
16 compdef:162> [[ -z yes || -z _other_accounts ]]
16 compdef:162> [[ -z yes || -z _openstack ]]
16 compdef:162> [[ -z yes || -z _openstack ]]
16 compdef:162> [[ -z yes || -z _object_classes ]]
16 compdef:162> [[ -z yes || -z _nothing ]]
16 compdef:162> [[ -z yes || -z _mysql_utils ]]
16 compdef:162> [[ -z yes || -z _mysql_utils ]]
16 compdef:162> [[ -z yes || -z _mv ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mtools ]]
16 compdef:162> [[ -z yes || -z _mozilla ]]
16 compdef:162> [[ -z yes || -z _modutils ]]
16 compdef:162> [[ -z yes || -z _mkdir ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _mh ]]
16 compdef:162> [[ -z yes || -z _make ]]
16 compdef:162> [[ -z yes || -z _lz4 ]]
16 compdef:162> [[ -z yes || -z _lz4 ]]
16 compdef:162> [[ -z yes || -z _lp ]]
16 compdef:162> [[ -z yes || -z _lp ]]
16 compdef:162> [[ -z yes || -z _lp ]]
16 compdef:162> [[ -z yes || -z _locate ]]
16 compdef:162> [[ -z yes || -z _locate ]]
16 compdef:162> [[ -z yes || -z _java ]]
16 compdef:162> [[ -z yes || -z _java ]]
16 compdef:162> [[ -z yes || -z _java ]]
16 compdef:162> [[ -z yes || -z _java ]]
16 compdef:162> [[ -z yes || -z _java ]]
16 compdef:162> [[ -z yes || -z _ispell ]]
16 compdef:162> [[ -z yes || -z _iptables ]]
16 compdef:162> [[ -z yes || -z _imagemagick ]]
16 compdef:162> [[ -z yes || -z _imagemagick ]]
16 compdef:162> [[ -z yes || -z _hosts ]]
16 compdef:162> [[ -z yes || -z _hosts ]]
16 compdef:162> [[ -z yes || -z _hosts ]]
16 compdef:162> [[ -z yes || -z _hosts ]]
16 compdef:162> [[ -z yes || -z _hosts ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _grep ]]
16 compdef:162> [[ -z yes || -z _gpg ]]
16 compdef:162> [[ -z yes || -z _go ]]
16 compdef:162> [[ -z yes || -z _go ]]
16 compdef:162> [[ -z yes || -z _go ]]
16 compdef:162> [[ -z yes || -z _go ]]
16 compdef:162> [[ -z yes || -z _go ]]
16 compdef:162> [[ -z yes || -z _gnupod ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _gcc ]]
16 compdef:162> [[ -z yes || -z _bzip2 ]]
16 compdef:162> [[ -z yes || -z _bsd_pkg ]]
16 compdef:162> [[ -z yes || -z _bpython ]]
16 compdef:162> [[ -z yes || -z _bpython ]]
16 compdef:162> [[ -z yes || -z _bpython ]]
16 compdef:162> [[ -z yes || -z _bpython ]]
16 compdef:162> [[ -z yes || -z _bittorrent ]]
16 compdef:162> [[ -z yes || -z _bittorrent ]]
16 compdef:162> [[ -z yes || -z _bittorrent ]]
16 compdef:162> [[ -z yes || -z _base64 ]]
16 compdef:162> [[ -z yes || -z _awk ]]
16 compdef:162> [[ -z yes || -z _avahi ]]
16 compdef:162> [[ -z yes || -z _ansible ]]
16 compdef:162> [[ -z yes || -z _ansible ]]
16 compdef:162> [[ -z yes || -z _ansible ]]
16 compdef:162> [[ -z yes || -z _ansible ]]
16 compdef:162> [[ -z yes || -z _ack ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:162> [[ -z yes || -z '' ]]
16 compdef:160> svc=''
16 compdef:160> svc=''
16 compdef:160> svc=''
16 compdef:159> cmd=zargs
16 compdef:159> cmd=unexpand
16 compdef:159> cmd=tarsnap
16 compdef:159> cmd=printenv
16 compdef:159> cmd=play
16 compdef:159> cmd=newgrp
16 compdef:159> cmd=mix
16 compdef:159> cmd=mc
16 compdef:159> cmd=ksh
16 compdef:159> cmd=groupdel
16 compdef:159> cmd=freezer
16 compdef:159> cmd=envdir
16 compdef:159> cmd=curl
16 compdef:159> cmd=cpio
16 compdef:159> cmd=_rclone
16 compdef:156> cmd=gdnolock
16 compdef:155> [[ ztodo = *=* ]]
16 compdef:155> [[ zsocket = *=* ]]
16 compdef:155> [[ zsh-mime-handler = *=* ]]
16 compdef:155> [[ zpool = *=* ]]
16 compdef:155> [[ zparseopts = *=* ]]
16 compdef:155> [[ zmv = *=* ]]
16 compdef:155> [[ zlogin = *=* ]]
16 compdef:155> [[ zle = *=* ]]
16 compdef:155> [[ zcash-cli = *=* ]]
16 compdef:155> [[ yarn = *=* ]]
16 compdef:155> [[ xsltproc = *=* ]]
16 compdef:155> [[ xmlstarlet = *=* ]]
16 compdef:155> [[ xli = *=* ]]
16 compdef:155> [[ xdpyinfo = *=* ]]
16 compdef:155> [[ xclip = *=* ]]
16 compdef:155> [[ xauth = *=* ]]
16 compdef:155> [[ wipefs = *=* ]]
16 compdef:155> [[ wemux = *=* ]]
16 compdef:155> [[ vnstat = *=* ]]
16 compdef:155> [[ urpme = *=* ]]
16 compdef:155> [[ ufw = *=* ]]
16 compdef:155> [[ udisksctl = *=* ]]
16 compdef:155> [[ tunctl = *=* ]]
16 compdef:155> [[ top = *=* ]]
16 compdef:155> [[ teamocil = *=* ]]
16 compdef:155> [[ swanctl = *=* ]]
16 compdef:155> [[ supervisorctl = *=* ]]
16 compdef:155> [[ subliminal = *=* ]]
16 compdef:155> [[ sqlite = *=* ]]
16 compdef:155> [[ softwareupdate = *=* ]]
16 compdef:155> [[ showoff = *=* ]]
16 compdef:155> [[ scutil = *=* ]]
16 compdef:155> [[ scrub = *=* ]]
16 compdef:155> [[ scons = *=* ]]
16 compdef:155> [[ rslsync = *=* ]]
16 compdef:155> [[ rfkill = *=* ]]
16 compdef:155> [[ redis-cli = *=* ]]
16 compdef:155> [[ ralio = *=* ]]
16 compdef:155> [[ pixz = *=* ]]
16 compdef:155> [[ periscope = *=* ]]
16 compdef:155> [[ pdm = *=* ]]
16 compdef:155> [[ patool = *=* ]]
16 compdef:155> [[ patch = *=* ]]
16 compdef:155> [[ optirun = *=* ]]
16 compdef:155> [[ openstack = *=* ]]
16 compdef:155> [[ odmget = *=* ]]
16 compdef:155> [[ nmcli = *=* ]]
16 compdef:155> [[ nkf = *=* ]]
16 compdef:155> [[ networksetup = *=* ]]
16 compdef:155> [[ nanoc = *=* ]]
16 compdef:155> [[ nano = *=* ]]
16 compdef:155> [[ murano = *=* ]]
16 compdef:155> [[ mpc = *=* ]]
16 compdef:155> [[ middleman = *=* ]]
16 compdef:155> [[ mdfind = *=* ]]
16 compdef:155> [[ make-kpkg = *=* ]]
16 compdef:155> [[ lsattr = *=* ]]
16 compdef:155> [[ kvno = *=* ]]
16 compdef:155> [[ jobs = *=* ]]
16 compdef:155> [[ ip = *=* ]]
16 compdef:155> [[ iconvconfig = *=* ]]
16 compdef:155> [[ heroku = *=* ]]
16 compdef:155> [[ hash = *=* ]]
16 compdef:155> [[ gmd5sum = *=* ]]
16 compdef:155> [[ git = *=* ]]
16 compdef:155> [[ ftp = *=* ]]
16 compdef:155> [[ freezer = *=* ]]
16 compdef:155> [[ fortune = *=* ]]
16 compdef:155> [[ ffmpeg = *=* ]]
16 compdef:155> [[ fc-list = *=* ]]
16 compdef:155> [[ espeak = *=* ]]
16 compdef:155> [[ elinks = *=* ]]
16 compdef:155> [[ echoti = *=* ]]
16 compdef:155> [[ ecasound = *=* ]]
16 compdef:155> [[ dtrace = *=* ]]
16 compdef:155> [[ dpkg = *=* ]]
16 compdef:155> [[ doas = *=* ]]
16 compdef:155> [[ dmidecode = *=* ]]
16 compdef:155> [[ dlocate = *=* ]]
16 compdef:155> [[ django-admin.py = *=* ]]
16 compdef:155> [[ diffstat = *=* ]]
16 compdef:155> [[ diff3 = *=* ]]
16 compdef:155> [[ diana = *=* ]]
16 compdef:155> [[ dhclient = *=* ]]
16 compdef:155> [[ dbus-send = *=* ]]
16 compdef:155> [[ dak = *=* ]]
16 compdef:155> [[ cygserver = *=* ]]
16 compdef:155> [[ cygcheck = *=* ]]
16 compdef:155> [[ cut = *=* ]]
16 compdef:155> [[ crontab = *=* ]]
16 compdef:155> [[ cplay = *=* ]]
16 compdef:155> [[ configure = *=* ]]
16 compdef:155> [[ compadd = *=* ]]
16 compdef:155> [[ cmp = *=* ]]
16 compdef:155> [[ chroot = *=* ]]
16 compdef:155> [[ brew = *=* ]]
16 compdef:155> [[ a2ensite = *=* ]]
16 compdef:155> [[ _helm = *=* ]]
16 compdef:155> [[ _gh = *=* ]]
16 compdef:155> [[ -value-,XML_CATALOG_FILES,-default- = *=* ]]
16 compdef:155> [[ -value-,TZ,-default- = *=* ]]
16 compdef:155> [[ -value-,LD_DEBUG,-default- = *=* ]]
16 compdef:155> [[ 'ggl=git-checkout' = *=* ]]
16 compdef:155> [[ 'gchown=chown' = *=* ]]
16 compdef:151> _postpatcomps[$1]=_ruby
16 compdef:139> case  (postpattern)
16 compdef:139> case  (pattern)
16 compdef:139> case  (pattern)
16 compdef:139> case  (pattern)
16 compdef:139> case  (pattern)
16 compdef:139> case  (pattern)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:139> case  (*)
16 compdef:137> type=postpattern
16 compdef:137> type=postpattern
16 compdef:137> type=postpattern
16 compdef:136> [[ rclone = -P ]]
16 compdef:136> [[ popd = -P ]]
16 compdef:136> [[ mac2unix = -P ]]
16 compdef:136> [[ lp = -P ]]
16 compdef:136> [[ gdd = -P ]]
16 compdef:136> [[ dpkg-buildpackage = -P ]]
16 compdef:136> [[ dbus-monitor = -P ]]
16 compdef:136> [[ apt-move = -P ]]
16 compdef:136> [[ -value-,XML_CATALOG_FILES,-default- = -P ]]
16 compdef:136> [[ 'ggu=git-checkout' = -P ]]
16 compdef:136> [[ 'ggp=git-checkout' = -P ]]
16 compdef:136> [[ '-redirect-,<,uncompress=uncompress' = -P ]]
16 compdef:134> [[ stdbuf = -p ]]
16 compdef:134> [[ rspec = -p ]]
16 compdef:134> [[ route = -p ]]
16 compdef:134> [[ rclone = -p ]]
16 compdef:134> [[ pidstat = -p ]]
16 compdef:134> [[ mgv = -p ]]
16 compdef:134> [[ info = -p ]]
16 compdef:134> [[ gsha512sum = -p ]]
16 compdef:134> [[ exec = -p ]]
16 compdef:134> [[ dvicopy = -p ]]
16 compdef:134> [[ darcs = -p ]]
16 compdef:134> [[ cvsup = -p ]]
16 compdef:134> [[ chkconfig = -p ]]
16 compdef:134> [[ chflags = -p ]]
16 compdef:134> [[ cdrdao = -p ]]
16 compdef:134> [[ cdr = -p ]]
16 compdef:134> [[ cabal = -p ]]
16 compdef:134> [[ btmakemetafile = -p ]]
16 compdef:134> [[ apt-move = -p ]]
16 compdef:134> [[ a2ensite = -p ]]
16 compdef:134> [[ _restic = -p ]]
16 compdef:134> [[ '-redirect-,<,uncompress=uncompress' = -p ]]
16 compdef:132> [[ ypcat = -N ]]
16 compdef:132> [[ yafc = -N ]]
16 compdef:132> [[ xz = -N ]]
16 compdef:132> [[ xv = -N ]]
16 compdef:132> [[ xterm = -N ]]
16 compdef:132> [[ xmodmap = -N ]]
16 compdef:132> [[ write = -N ]]
16 compdef:132> [[ who = -N ]]
16 compdef:132> [[ whereis = -N ]]
16 compdef:132> [[ watch = -N ]]
16 compdef:132> [[ w3m = -N ]]
16 compdef:132> [[ vncserver = -N ]]
16 compdef:132> [[ vmstat = -N ]]
16 compdef:132> [[ virsh = -N ]]
16 compdef:132> [[ vim-addons = -N ]]
16 compdef:132> [[ vim = -N ]]
16 compdef:132> [[ vared = -N ]]
16 compdef:132> [[ uscan = -N ]]
16 compdef:132> [[ uptime = -N ]]
16 compdef:132> [[ unexpand = -N ]]
16 compdef:132> [[ twidge = -N ]]
16 compdef:132> [[ trash = -N ]]
16 compdef:132> [[ tracepath = -N ]]
16 compdef:132> [[ tmux = -N ]]
16 compdef:132> [[ tload = -N ]]
16 compdef:132> [[ timeout = -N ]]
16 compdef:132> [[ time = -N ]]
16 compdef:132> [[ telnet = -N ]]
16 compdef:132> [[ sysctl = -N ]]
16 compdef:132> [[ swaks = -N ]]
16 compdef:132> [[ sw_vers = -N ]]
16 compdef:132> [[ svn-buildpackage = -N ]]
16 compdef:132> [[ svn = -N ]]
16 compdef:132> [[ su = -N ]]
16 compdef:132> [[ strings = -N ]]
16 compdef:132> [[ strftime = -N ]]
16 compdef:132> [[ sshfs = -N ]]
16 compdef:132> [[ spamassassin = -N ]]
16 compdef:132> [[ snoop = -N ]]
16 compdef:132> [[ smartctl = -N ]]
16 compdef:132> [[ sisu = -N ]]
16 compdef:132> [[ signify = -N ]]
16 compdef:132> [[ sh = -N ]]
16 compdef:132> [[ setxkbmap = -N ]]
16 compdef:132> [[ setsid = -N ]]
16 compdef:132> [[ set = -N ]]
16 compdef:132> [[ service = -N ]]
16 compdef:132> [[ sed = -N ]]
16 compdef:132> [[ schroot = -N ]]
16 compdef:132> [[ savecore = -N ]]
16 compdef:132> [[ run-help = -N ]]
16 compdef:132> [[ ruby = -N ]]
16 compdef:132> [[ rebootin = -N ]]
16 compdef:132> [[ ranlib = -N ]]
16 compdef:132> [[ qiv = -N ]]
16 compdef:132> [[ ps2epsi = -N ]]
16 compdef:132> [[ procstat = -N ]]
16 compdef:132> [[ powerd = -N ]]
16 compdef:132> [[ portlint = -N ]]
16 compdef:132> [[ pmap = -N ]]
16 compdef:132> [[ pkg-config = -N ]]
16 compdef:132> [[ piuparts = -N ]]
16 compdef:132> [[ pgrep = -N ]]
16 compdef:132> [[ pdftk = -N ]]
16 compdef:132> [[ pbcopy = -N ]]
16 compdef:132> [[ patch = -N ]]
16 compdef:132> [[ passwd = -N ]]
16 compdef:132> [[ pandoc = -N ]]
16 compdef:132> [[ osascript = -N ]]
16 compdef:132> [[ nslookup = -N ]]
16 compdef:132> [[ npm = -N ]]
16 compdef:132> [[ node = -N ]]
16 compdef:132> [[ nmap = -N ]]
16 compdef:132> [[ ngrep = -N ]]
16 compdef:132> [[ nginx = -N ]]
16 compdef:132> [[ nedit = -N ]]
16 compdef:132> [[ mtr = -N ]]
16 compdef:132> [[ mr = -N ]]
16 compdef:132> [[ mpstat = -N ]]
16 compdef:132> [[ module = -N ]]
16 compdef:132> [[ members = -N ]]
16 compdef:132> [[ mdls = -N ]]
16 compdef:132> [[ lz4 = -N ]]
16 compdef:132> [[ lua = -N ]]
16 compdef:132> [[ lsblk = -N ]]
16 compdef:132> [[ lldb = -N ]]
16 compdef:132> [[ lintian = -N ]]
16 compdef:132> [[ ldd = -N ]]
16 compdef:132> [[ knock = -N ]]
16 compdef:132> [[ jrnl = -N ]]
16 compdef:132> [[ jmeter = -N ]]
16 compdef:132> [[ javac = -N ]]
16 compdef:132> [[ irssi = -N ]]
16 compdef:132> [[ iptables = -N ]]
16 compdef:132> [[ ipset = -N ]]
16 compdef:132> [[ ipadm = -N ]]
16 compdef:132> [[ ionice = -N ]]
16 compdef:132> [[ invoke-rc.d = -N ]]
16 compdef:132> [[ install = -N ]]
16 compdef:132> [[ id = -N ]]
16 compdef:132> [[ hwinfo = -N ]]
16 compdef:132> [[ groupdel = -N ]]
16 compdef:132> [[ gradle = -N ]]
16 compdef:132> [[ gprof = -N ]]
16 compdef:132> [[ gpasswd = -N ]]
16 compdef:132> [[ google = -N ]]
16 compdef:132> [[ go = -N ]]
16 compdef:132> [[ glances = -N ]]
16 compdef:132> [[ glance = -N ]]
16 compdef:132> [[ git-wtf = -N ]]
16 compdef:132> [[ git-journal = -N ]]
16 compdef:132> [[ git-buildpackage = -N ]]
16 compdef:132> [[ ghc = -N ]]
16 compdef:132> [[ getopts = -N ]]
16 compdef:132> [[ fold = -N ]]
16 compdef:132> [[ flutter = -N ]]
16 compdef:132> [[ finger = -N ]]
16 compdef:132> [[ ffind = -N ]]
16 compdef:132> [[ fetchmail = -N ]]
16 compdef:132> [[ dvc = -N ]]
16 compdef:132> [[ dosread = -N ]]
16 compdef:132> [[ deno = -N ]]
16 compdef:132> [[ conan = -N ]]
16 compdef:132> [[ combinediff = -N ]]
16 compdef:132> [[ choc = -N ]]
16 compdef:132> [[ bts = -N ]]
16 compdef:132> [[ brctl = -N ]]
16 compdef:132> [[ bpython = -N ]]
16 compdef:132> [[ bison = -N ]]
16 compdef:132> [[ bibtex = -N ]]
16 compdef:132> [[ beadm = -N ]]
16 compdef:132> [[ baz = -N ]]
16 compdef:132> [[ aws = -N ]]
16 compdef:132> [[ atach = -N ]]
16 compdef:132> [[ asdf = -N ]]
16 compdef:132> [[ apt = -N ]]
16 compdef:132> [[ aplay = -N ]]
16 compdef:132> [[ ansible = -N ]]
16 compdef:132> [[ acpitool = -N ]]
16 compdef:132> [[ aap = -N ]]
16 compdef:132> [[ -zcalc-line- = -N ]]
16 compdef:132> [[ -vared- = -N ]]
16 compdef:132> [[ -value- = -N ]]
16 compdef:132> [[ -tilde- = -N ]]
16 compdef:132> [[ -parameter- = -N ]]
16 compdef:132> [[ -first- = -N ]]
16 compdef:132> [[ 'yodl(|2*)' = -N ]]
16 compdef:132> [[ 'pydoc[0-9.]#' = -N ]]
16 compdef:132> [[ 'ggpnp=git-checkout' = -N ]]
16 compdef:132> [[ '-redirect-,<,uncompress=uncompress' = -N ]]
16 compdef:132> [[ '(texi(2*|ndex))' = -N ]]
16 compdef:131> ((  19  ))
16 compdef:131> ((  17  ))
16 compdef:131> ((  3  ))
16 compdef:131> ((  2  ))
16 compdef:131> ((  2  ))
16 compdef:131> ((  1  ))
16 compdef:131> ((  1  ))
16 compdef:91> [[ complete-word = .* ]]
16 compdef:90> [[ _expand_alias = _* ]]
16 compdef:85> [[ -n _expand_alias ]]
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (widgetkey)
16 compdef:83> case  (key)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:83> case  (*)
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:81> shift
16 compdef:80> autoload -Uz _pmap
16 compdef:80> autoload -Uz _brew
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:80> [[ -n yes ]]
16 compdef:79> func=_yt-dlp
16 compdef:79> func=_rclone
16 compdef:79> func=_rake
16 compdef:79> func=_play
16 compdef:79> func=_mdadm
16 compdef:79> func=_ip
16 compdef:79> func=_hledger
16 compdef:79> func=_ecdsautil
16 compdef:79> func=_debsign
16 compdef:79> func=_cscope
16 compdef:49> [[ _zsocket = *=* ]]
16 compdef:49> [[ _zsh-mime-handler = *=* ]]
16 compdef:49> [[ _zsh = *=* ]]
16 compdef:49> [[ _zpty = *=* ]]
16 compdef:49> [[ _zpool = *=* ]]
16 compdef:49> [[ _zmv = *=* ]]
16 compdef:49> [[ _zlogin = *=* ]]
16 compdef:49> [[ _zle = *=* ]]
16 compdef:49> [[ _zcash-cli = *=* ]]
16 compdef:49> [[ _yarn = *=* ]]
16 compdef:49> [[ _yaourt = *=* ]]
16 compdef:49> [[ _xsel = *=* ]]
16 compdef:49> [[ _xmlstarlet = *=* ]]
16 compdef:49> [[ _xfig = *=* ]]
16 compdef:49> [[ _xcode-select = *=* ]]
16 compdef:49> [[ _xclip = *=* ]]
16 compdef:49> [[ _xautolock = *=* ]]
16 compdef:49> [[ _x_display = *=* ]]
16 compdef:49> [[ _x_arguments = *=* ]]
16 compdef:49> [[ _wipefs = *=* ]]
16 compdef:49> [[ _vpnc = *=* ]]
16 compdef:49> [[ _vnstat = *=* ]]
16 compdef:49> [[ _virtualbox = *=* ]]
16 compdef:49> [[ _urls = *=* ]]
16 compdef:49> [[ _unexpand = *=* ]]
16 compdef:49> [[ _ufw = *=* ]]
16 compdef:49> [[ _twisted = *=* ]]
16 compdef:49> [[ _trash-restore = *=* ]]
16 compdef:49> [[ _trash-put = *=* ]]
16 compdef:49> [[ _tla = *=* ]]
16 compdef:49> [[ _teamocil = *=* ]]
16 compdef:49> [[ _supervisorctl = *=* ]]
16 compdef:49> [[ _subliminal = *=* ]]
16 compdef:49> [[ _subl = *=* ]]
16 compdef:49> [[ _stdbuf = *=* ]]
16 compdef:49> [[ _showoff = *=* ]]
16 compdef:49> [[ _sfdx = *=* ]]
16 compdef:49> [[ _setup.py = *=* ]]
16 compdef:49> [[ _schedtool = *=* ]]
16 compdef:49> [[ _scala = *=* ]]
16 compdef:49> [[ _rfkill = *=* ]]
16 compdef:49> [[ _rclone = *=* ]]
16 compdef:49> [[ _rails = *=* ]]
16 compdef:49> [[ _pygmentize = *=* ]]
16 compdef:49> [[ _phing = *=* ]]
16 compdef:49> [[ _periscope = *=* ]]
16 compdef:49> [[ _pdm = *=* ]]
16 compdef:49> [[ _pdf = *=* ]]
16 compdef:49> [[ _optirun = *=* ]]
16 compdef:49> [[ _openstack = *=* ]]
16 compdef:49> [[ _openssl = *=* ]]
16 compdef:49> [[ _object_classes = *=* ]]
16 compdef:49> [[ _node = *=* ]]
16 compdef:49> [[ _ninja = *=* ]]
16 compdef:49> [[ _nanoc = *=* ]]
16 compdef:49> [[ _mvn = *=* ]]
16 compdef:49> [[ _mullvad = *=* ]]
16 compdef:49> [[ _mplayer = *=* ]]
16 compdef:49> [[ _mkshortcut = *=* ]]
16 compdef:49> [[ _mii-tool = *=* ]]
16 compdef:49> [[ _mdfind = *=* ]]
16 compdef:49> [[ _matlab = *=* ]]
16 compdef:49> [[ _make-kpkg = *=* ]]
16 compdef:49> [[ _lsvg = *=* ]]
16 compdef:49> [[ _lp = *=* ]]
16 compdef:49> [[ _ldd = *=* ]]
16 compdef:49> [[ _kubectl = *=* ]]
16 compdef:49> [[ _jobs_bg = *=* ]]
16 compdef:49> [[ _jexec = *=* ]]
16 compdef:49> [[ _hub = *=* ]]
16 compdef:49> [[ _hosts = *=* ]]
16 compdef:49> [[ _hledger = *=* ]]
16 compdef:49> [[ _heroku = *=* ]]
16 compdef:49> [[ _helm = *=* ]]
16 compdef:49> [[ _hdiutil = *=* ]]
16 compdef:49> [[ _hash = *=* ]]
16 compdef:49> [[ _gzip = *=* ]]
16 compdef:49> [[ _guilt = *=* ]]
16 compdef:49> [[ _global = *=* ]]
16 compdef:49> [[ _git = *=* ]]
16 compdef:49> [[ _gist = *=* ]]
16 compdef:49> [[ _getmail = *=* ]]
16 compdef:49> [[ _gcore = *=* ]]
16 compdef:49> [[ _fortune = *=* ]]
16 compdef:49> [[ _figlet = *=* ]]
16 compdef:49> [[ _ffmpeg = *=* ]]
16 compdef:49> [[ _expand_word = *=* ]]
16 compdef:49> [[ _espeak = *=* ]]
16 compdef:49> [[ _eog = *=* ]]
16 compdef:49> [[ _envdir = *=* ]]
16 compdef:49> [[ _enable = *=* ]]
16 compdef:49> [[ _emulate = *=* ]]
16 compdef:49> [[ _ed = *=* ]]
16 compdef:49> [[ _e2label = *=* ]]
16 compdef:49> [[ _dupload = *=* ]]
16 compdef:49> [[ _dtrace = *=* ]]
16 compdef:49> [[ _dpkg = *=* ]]
16 compdef:49> [[ _dos2unix = *=* ]]
16 compdef:49> [[ _dladm = *=* ]]
16 compdef:49> [[ _django = *=* ]]
16 compdef:49> [[ _dir_list = *=* ]]
16 compdef:49> [[ _dig = *=* ]]
16 compdef:49> [[ _diff = *=* ]]
16 compdef:49> [[ _df = *=* ]]
16 compdef:49> [[ _dcop = *=* ]]
16 compdef:49> [[ _dchroot = *=* ]]
16 compdef:49> [[ _dbus = *=* ]]
16 compdef:49> [[ _darcs = *=* ]]
16 compdef:49> [[ _dak = *=* ]]
16 compdef:49> [[ _cygserver = *=* ]]
16 compdef:49> [[ _cygrunsrv = *=* ]]
16 compdef:49> [[ _cvs = *=* ]]
16 compdef:49> [[ _cu = *=* ]]
16 compdef:49> [[ _csup = *=* ]]
16 compdef:49> [[ _crontab = *=* ]]
16 compdef:49> [[ _cpupower = *=* ]]
16 compdef:49> [[ _configure = *=* ]]
16 compdef:49> [[ _condition = *=* ]]
16 compdef:49> [[ _compdef = *=* ]]
16 compdef:49> [[ _cmp = *=* ]]
16 compdef:49> [[ _chroot = *=* ]]
16 compdef:49> [[ _cd = *=* ]]
16 compdef:49> [[ _ccal = *=* ]]
16 compdef:49> [[ _cat = *=* ]]
16 compdef:49> [[ _at = *=* ]]
16 compdef:49> [[ _archlinux-java = *=* ]]
16 compdef:49> [[ _apm = *=* ]]
16 compdef:49> [[ _antiword = *=* ]]
16 compdef:49> [[ _alias = *=* ]]
16 compdef:49> [[ _afew = *=* ]]
16 compdef:49> [[ _add-zle-hook-widget = *=* ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:49> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:45> [[ -z '' ]]
16 compdef:40> ((  ! 9  ))
16 compdef:40> ((  ! 4  ))
16 compdef:40> ((  ! 4  ))
16 compdef:40> ((  ! 4  ))
16 compdef:40> ((  ! 4  ))
16 compdef:40> ((  ! 4  ))
16 compdef:40> ((  ! 3  ))
16 compdef:40> ((  ! 3  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:40> ((  ! 2  ))
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:38> shift OPTIND-1
16 compdef:31> type=key
16 compdef:31> type=key
16 compdef:31> type=key
16 compdef:31> type=key
16 compdef:29> type=widgetkey
16 compdef:27> type=postpattern
16 compdef:27> type=postpattern
16 compdef:27> type=postpattern
16 compdef:18> [[ -n '' ]]
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:17> new=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:16> autol=yes
16 compdef:15> case n (n)
16 compdef:15> case n (n)
16 compdef:15> case n (n)
16 compdef:15> case n (n)
16 compdef:15> case n (n)
16 compdef:15> case n (n)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case n (a)
16 compdef:15> case k ([pPkK])
16 compdef:15> case k ([pPkK])
16 compdef:15> case k ([pPkK])
16 compdef:15> case k ([pPkK])
16 compdef:15> case a (a)
16 compdef:15> case a (a)
16 compdef:15> case a (a)
16 compdef:15> case a (a)
16 compdef:15> case a (a)
16 compdef:15> case K ([pPkK])
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:14> getopts anpPkKde opt
16 compdef:9> ((  ! 11  ))
16 compdef:9> ((  ! 7  ))
16 compdef:9> ((  ! 4  ))
16 compdef:9> ((  ! 4  ))
16 compdef:9> ((  ! 3  ))
16 compdef:9> ((  ! 3  ))
16 compdef:9> ((  ! 3  ))
16 compdef:9> ((  ! 2  ))
16 compdef:9> ((  ! 2  ))
16 compaudit:102> [[ -e /proc/87947/object/a.out ]]
16 compaudit:101> _i_exe=/proc/87947/exe
16 compaudit:91> local -a _i_exes
16 compaudit:27> ((  0  ))
16 compaudit:14> setopt extendedglob
16 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;44m'
16 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;43m'
16 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;40m'
16 colors:115> bg_bold[${k#bg-}]=$'C-[[01;47m'
16 colors:115> bg_bold[${k#bg-}]=$'C-[[01;46m'
16 colors:115> bg_bold[${k#bg-}]=$'C-[[01;44m'
16 colors:114> bg[${k#bg-}]=$'C-[[46m'
16 colors:114> bg[${k#bg-}]=$'C-[[46m'
16 colors:114> bg[${k#bg-}]=$'C-[[45m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;37m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;34m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;33m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;32m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;31m'
16 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;30m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;39m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;35m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;34m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;33m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;32m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;31m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;30m'
16 colors:106> fg_bold[${k#fg-}]=$'C-[[01;30m'
16 colors:97> typeset -Hg reset_color bold_color
16 colors:77> color[${color[$k]}]=44
16 colors:77> color[${color[$k]}]=33
16 colors:77> color[${color[$k]}]=22
16 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=antigen-bundle-cached
16 antigen-remove-hook:7> [[ 5 > 0 ]]
16 antigen-remove-hook:4> local -a hooks
16 antigen-remove-hook:4> local -a hooks
16 antigen-remove-hook:2> typeset -A meta
16 antigen-remove-hook:2> typeset -A meta
16 antigen-ext:2> local func=-antigen-cache-init
16 antigen-add-hook:16> _ANTIGEN_HOOKS[$target]=antigen-bundle-defer:antigen-bun...
16 antigen-add-hook:13> [[ antigen-apply-lock:antigen-apply-parallel ==  ]]
16 antigen-add-hook:8> ((  ! 1  ))
16 antigen-add-hook:3> ((  ! 1  ))
16 antigen-add-hook:3> ((  ! 1  ))
16 add-zsh-hook:83> ((  0  ))
16 add-zsh-hook:83> ((  0  ))
16 add-zsh-hook:55> shift 0
16 add-zsh-hook:17> local -a hooktypes
16 add-zsh-hook:17> local -a hooktypes
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:27> case builtin (builtin)
16 _zsh_highlight_bind_widgets:26> cur_widget=vi-match-bracket
16 _zsh_highlight_bind_widgets:26> cur_widget=undefined-key
16 /usr/local/share/antigen/antigen.zsh:1399> typeset -Ag _ANTIGEN_HOOKS_META
16 /Users/matt/.zcompdump:1974> bindkey '^Xh' _complete_help
16 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
16 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
16 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
16 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:58> ZSH_THEME_RUBY_PROMPT...
16 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:56> ZSH_THEME_GIT_PROMPT_...
16 /Users/matt/.oh-my-zsh/lib/termsupport.zsh:107> [[ -z '' ]]
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;211m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;143m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;079m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;052m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;001m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;130m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;113m%}'
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=115
16 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=114
16 /Users/matt/.oh-my-zsh/lib/misc.zsh:6> [[ -e /Users/matt/.oh-my-zsh/completio...
16 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:45> autoload -U down-line-or-begi...
16 /Users/matt/.oh-my-zsh/lib/directories.zsh:19> alias '8=cd -8'
16 /Users/matt/.oh-my-zsh/lib/directories.zsh:16> alias '5=cd -5'
16 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
16 /Users/matt/.oh-my-zsh/custom/plugins/zsh-autosuggestions/zsh-autosuggestions...
16 /Users/matt/.iterm2_shell_integration.zsh:163> [[ -z 'omz_termsupport_preexec...
16 /Users/matt/.antigen/init.zsh:78> typeset -g _ANTIGEN_CACHE_VERSION
16 /Users/matt/.antigen/init.zsh:76> _ANTIGEN_CACHE_LOADED=true
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:80> ...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:45> ...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/key-bindings.zsh:36> ...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/directories.zsh:14> a...
16 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:17> [[...
16 -antigen-parse-args:154> args[url]=''https://github.com/zsh-users/zsh-syntax-...
16 -antigen-parse-args:154> args[url]=''https://github.com/zsh-users/zsh-autosug...
16 -antigen-parse-args:154> args[url]=''https://github.com/robbyrussell/oh-my-zs...
16 -antigen-parse-args:154> args[url]=''https://github.com/robbyrussell/oh-my-zs...
16 -antigen-parse-args:147> args[dir]=''/Users/matt/.antigen/bundles/robbyrussel...
16 -antigen-parse-args:130> args[name]=zsh-users/zsh-syntax-highlighting
16 -antigen-parse-args:124> name=zsh-users/zsh-syntax-highlighting
16 -antigen-parse-args:94> url=https://github.com/zsh-users/zsh-syntax-highlight...
16 -antigen-parse-args:94> url=https://github.com/zsh-users/zsh-syntax-highlight...
16 -antigen-parse-args:86> local url=zsh-users/zsh-syntax-highlighting
16 -antigen-parse-args:60> let 'index+=1'
16 -antigen-parse-args:60> let 'index+=1'
16 -antigen-parse-args:60> let 'index+=1'
16 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
16 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
16 -antigen-parse-args:42> local url_path=zsh-users/zsh-autosuggestions
16 -antigen-parse-args:22> case --loc (--url | --loc)
16 -antigen-parse-args:20> value=zsh-users/zsh-syntax-highlighting
16 -antigen-parse-args:20> value=zsh-users/zsh-autosuggestions
16 -antigen-parse-args:19> key=zsh-users/zsh-autosuggestions
16 -antigen-parse-args:19> key=zsh-users/zsh-autosuggestions
16 -antigen-parse-args:19> key=deno
16 -antigen-parse-args:19> key=deno
16 -antigen-parse-args:17> [[ 0 -gt 0 ]]
16 -antigen-parse-args:17> [[ 0 -gt 0 ]]
16 -antigen-parse-args:17> [[ 0 -gt 0 ]]
16 -antigen-parse-args:13> args[make_local_clone]=true
16 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
16 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
16 -antigen-load-env-cached:6> [[ lib == / ]]
16 -antigen-load-env-cached:2> typeset -A bundle
16 -antigen-load-env-cached:2> typeset -A bundle
16 -antigen-interactive-mode:2> [[ '' !=  ]]
16 -antigen-hook-handler:55> [[ 1 == 0 ]]
16 -antigen-hook-handler:55> [[ 0 == 0 ]]
16 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
16 -antigen-hook-handler:22> case replace (pre)
16 -antigen-hook-handler:22> case replace (pre)
16 -antigen-hook-handler:22> case pre (pre)
16 -antigen-hook-handler:22> case pre (pre)
16 -antigen-hook-handler:22> case pre (pre)
16 -antigen-hook-handler:22> case pre (pre)
16 -antigen-hook-handler:17> let 'called=5+1'
16 -antigen-hook-handler:17> let 'called=3+1'
16 -antigen-hook-handler:17> let 'called=2+1'
16 -antigen-hook-handler:17> let 'called=1+1'
16 -antigen-hook-handler:17> let 'called=0+1'
16 -antigen-hook-handler:17> let 'called=0+1'
16 -antigen-hook-handler:17> let 'called=0+1'
16 -antigen-hook-handler:17> let 'called=0+1'
16 -antigen-hook-handler:17> let 'called=0+1'
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:9> typeset -A meta
16 -antigen-hook-handler:7> typeset -a hooks
16 -antigen-hook-handler:7> typeset -a hooks
16 -antigen-hook-handler:7> typeset -a hooks
16 -antigen-hook-handler:7> typeset -a hooks
16 -antigen-hook-handler:7> typeset -a hooks
16 -antigen-hook-handler:4> args=( )
16 -antigen-hook-handler:4> args=( '--loc=lib' )
16 -antigen-hook-handler:3> shift
16 -antigen-hook-handler:3> shift
16 -antigen-hook-handler:3> shift
16 -antigen-hook-antigen:2> [[ -z bundle ]]
16 -antigen-hook-antigen:2> [[ -z bundle ]]
16 -antigen-hook-antigen:2> [[ -z apply ]]
16 -antigen-defer-init:1> _DEFERRED_BUNDLE=( )
16 -antigen-cache-init:5> _ZCACHE_CAPTURE_PREFIX=--zcache-
16 -antigen-cache-generate:21> _fpath+=( /Users/matt/.antigen/bundles/zsh-users/...
16 -antigen-cache-generate:19> [[ -d /Users/matt/.antigen/bundles/zsh-users/zsh-...
16 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
16 (eval):222> alias 'it2setkeylabel=/Users/matt/.iterm2/it2setkeylabel'
16 (eval):193> alias 'gstst=git move-staged'
16 (eval):184> alias 'gst=git status'
16 (eval):178> alias 'gtl=gtl(){ git tag --sort=-v:refname -n -l "${1}*" }; nogl...
16 (eval):167> alias 'groh=git reset origin/$(git_current_branch) --hard'
16 (eval):147> alias 'gpu=git push -u'
16 (eval):139> alias 'grep=grep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,.s...
16 (eval):131> alias 'grba=git rebase --abort'
16 (eval):122> alias 'gpoat=git push origin --all && git push origin --tags'
16 (eval):118> alias 'gp=git push'
16 (eval):116> alias 'glg=git log --stat'
16 (eval):103> alias 'gg=git gui citool'
16 (eval):93> alias 'gdct=git describe --tags $(git rev-list --tags --max-count=1)'
16 (eval):91> alias 'gignore=git update-index --assume-unchanged'
16 (eval):88> alias 'ggpush=git push origin "$(git_current_branch)"'
16 (eval):73> alias 'gdca=git diff --cached'
16 (eval):69> alias 'gcan!=git commit -v -a --no-edit --amend'
16 (eval):55> alias 'gcd=git checkout $(git_develop_branch)'
16 (eval):50> alias 'gcan!=git commit -v -a --no-edit --amend'
16 (eval):35> alias 'et=empty-trash'
16 (eval):34> alias 'egrep=egrep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,....
16 (eval):17> alias 'afind=ack -il'
16 (eval):15> alias '_=sudo '
16 (eval):1> alias -- '-=cd -'
16 (anon):1554> typeset -g POWERLEVEL9K_DISABLE_HOT_RELOAD=true
16 (anon):33> zle -N autosuggest-fetch _zsh_autosuggest_widget_fetch
16 (anon):33> zle -N autosuggest-execute _zsh_autosuggest_widget_execute
16 (anon):33> zle -N autosuggest-enable _zsh_autosuggest_widget_enable
16 (anon):33> zle -N autosuggest-disable _zsh_autosuggest_widget_disable
16 (anon):15> action=modify
16 (anon):15> action=disable
16 (anon):2> action=partial_accept
16 (anon):2> action=fetch
16 (anon):2> action=execute
16 (anon):2> action=accept
15 regexp-replace:21> 5=''
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:53> ((  part > min_ver[min_cnt]  ))
15 is-at-least:50> break
15 is-at-least:50> break
15 is-at-least:50> break
15 is-at-least:50> break
15 is-at-least:50> [[ 5 = <-> ]]
15 is-at-least:50> [[ 5 = <-> ]]
15 is-at-least:50> [[ 5 = <-> ]]
15 is-at-least:50> [[ 2 = <-> ]]
15 is-at-least:48> true
15 is-at-least:48> true
15 is-at-least:45> part=5
15 is-at-least:45> part=5
15 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
15 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
15 is-at-least:31> [[ 36 != <-> ]]
15 is-at-least:31> [[ 8 != <-> ]]
15 is-at-least:31> [[ 8 != <-> ]]
15 is-at-least:31> [[ 8 != <-> ]]
15 is-at-least:31> [[ 8 != <-> ]]
15 is-at-least:31> [[ 1 != <-> ]]
15 is-at-least:30> ((  0 <= 2  ))
15 is-at-least:30> ((  0 <= 2  ))
15 is-at-least:27> min_ver=( 5 1 )
15 group_lazy_load:4> cmd=rmvirtualenv
15 group_lazy_load:4> cmd=rake
15 group_lazy_load:4> cmd=irb
15 group_lazy_load:4> cmd=deactivate
15 group_lazy_load:4> cmd=cpvirtualenv
15 group_lazy_load:4> cmd=cdsitepackages
15 group_lazy_load:4> cmd=allvirtualenv
15 group_lazy_load:1> local script
15 group_lazy_load:1> local script
15 compinit:530> _i_line=reverse-menu-complete
15 compinit:530> _i_line=menu-expand-or-complete
15 compinit:530> _i_line=list-choices
15 compinit:530> _i_line=expand-or-complete-prefix
15 compinit:530> _i_line=expand-or-complete-prefix
15 compinit:530> _i_line=expand-or-complete
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:516> [[ '' !=  # ]]
15 compinit:515> autoload -Uz _zfs_pool
15 compinit:515> autoload -Uz _xt_arguments
15 compinit:515> autoload -Uz _wakeup_capable_devices
15 compinit:515> autoload -Uz _volume_groups
15 compinit:515> autoload -Uz _values
15 compinit:515> autoload -Uz _user_expand
15 compinit:515> autoload -Uz _tilde_files
15 compinit:515> autoload -Uz _svcs_fmri
15 compinit:515> autoload -Uz _store_cache
15 compinit:515> autoload -Uz _set_command
15 compinit:515> autoload -Uz _python_modules
15 compinit:515> autoload -Uz _process_names
15 compinit:515> autoload -Uz _path_files
15 compinit:515> autoload -Uz _path_commands
15 compinit:515> autoload -Uz _parameters
15 compinit:515> autoload -Uz _jails
15 compinit:515> autoload -Uz _history
15 compinit:515> autoload -Uz _file_modes
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #compdef (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#compdef)
15 compinit:506> case #autoload (#autoload)
15 compinit:501> continue
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:501> ((  0 + 0  ))
15 compinit:500> _i_name=_zsh-mime-handler
15 compinit:500> _i_name=_zcompile
15 compinit:500> _i_name=_zcash-cli
15 compinit:500> _i_name=_xxd
15 compinit:500> _i_name=_xcode-select
15 compinit:500> _i_name=_x_window
15 compinit:500> _i_name=_vagrant
15 compinit:500> _i_name=_uscan
15 compinit:500> _i_name=_ufw
15 compinit:500> _i_name=_tput
15 compinit:500> _i_name=_tmuxp
15 compinit:500> _i_name=_pygmentize
15 compinit:500> _i_name=_module-assistant
15 compinit:500> _i_name=_lsof
15 compinit:500> _i_name=_lsblk
15 compinit:500> _i_name=_localedef
15 compinit:500> _i_name=_limit
15 compinit:500> _i_name=_history_modifiers
15 compinit:500> _i_name=_file_systems
15 compinit:500> _i_name=_expand_word
15 compinit:500> _i_name=_expand
15 compinit:500> _i_name=_echoti
15 compinit:500> _i_name=_dynamic_directory_name
15 compinit:500> _i_name=_drill
15 compinit:500> _i_name=_dpkg-repack
15 compinit:500> _i_name=_domains
15 compinit:500> _i_name=_df
15 compinit:500> _i_name=_devtodo
15 compinit:500> _i_name=_describe
15 compinit:500> _i_name=_debsign
15 compinit:500> _i_name=_deborphan
15 compinit:500> _i_name=_debdiff
15 compinit:500> _i_name=_deb_packages
15 compinit:500> _i_name=_dd
15 compinit:500> _i_name=_dbus
15 compinit:500> _i_name=_cut
15 compinit:500> _i_name=_correct_word
15 compinit:500> _i_name=_complete_help_generic
15 compinit:500> _i_name=_complete_debug
15 compinit:500> _i_name=_command_names
15 compinit:500> _i_name=_combination
15 compinit:500> _i_name=_cmdstring
15 compinit:500> _i_name=_chsh
15 compinit:500> _i_name=_chown
15 compinit:500> _i_name=_chmod
15 compinit:500> _i_name=_chcon
15 compinit:500> _i_name=_chattr
15 compinit:500> _i_name=_cdrecord
15 compinit:500> _i_name=_cdbs-edit-patch
15 compinit:500> _i_name=_calendar
15 compinit:500> _i_name=_cal
15 compinit:500> _i_name=_afew
15 compinit:500> _i_name=_acroread
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zypper
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zstyle
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zsh-mime-handler
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zpool
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zfs_dataset
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zed
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zcalc_line
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xz
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xt_arguments
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xmlsoft
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xft_fonts
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xdvi
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xcode-select
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xclip
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xargs
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_window
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_arguments
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wpa_cli
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_whereis
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_w3m
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vpnc
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_user_admin
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_urpmi
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_transmission
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tr
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_totd
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_toolchain-source
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tload
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tilde_files
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svcs_fmri
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svcadm
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_source
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_services
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_samba
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rpm
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ranlib
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rake
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pon
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pids
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pidof
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_perldoc
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_openstack
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_objdump
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nl
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_networksetup
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nbsd_architectures
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mencal
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_md5sum
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_match
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mail
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lz4
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ltrace
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsusb
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lspv
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsdev
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsblk
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_localedef
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_limits
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ldap
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ld_debug
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_killall
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jobs
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jls
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_java_class
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jails
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_id
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hostname
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_groff
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gprof
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_global_tags
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getclip
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gem
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fw_update
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fusermount
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fuse_arguments
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_functions
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fsh
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_free
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_flac
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_finger
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fetch
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_etags
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_equal
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_enscript
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_elinks
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_elfdump
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ed
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_echotc
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dynamic_directory_name
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpkg_source
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpkg-repack
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dnf
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dmesg
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dladm
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dkms
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_disable
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_directories
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dir_list
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dig
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_diff_options
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dhcpinfo
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_describe
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dcut
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dcop
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dconf
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dchroot-dsa
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_darcs
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dak
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cygserver
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cygrunsrv
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cygpath
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cvs
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_curl
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ctags_tags
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cssh
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cryptsetup
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_crontab
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cplay
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cp
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_condition
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_complete
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_compdef
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_command_names
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_combination
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_code
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_clay
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chrt
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_chroot
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cdbs-edit-patch
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bzip2
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arch_archives
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_approximate
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_all_labels
15 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_add-zsh-hook
15 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_pdm
15 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_meson
15 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_kubectl
15 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_helm
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
15 compinit:448> eval compaudit
15 compinit:446> [[ -n yes ]]
15 compinit:445> autoload -Uz compaudit
15 compinit:445> autoload -Uz compaudit
15 compinit:443> _i_wfiles=( )
15 compinit:443> _i_wfiles=( )
15 compinit:130> typeset -gHa _comp_options
15 compinit:118> typeset -gHA _lastcomp
15 compinit:92> shift
15 compinit:91> _i_fail=ign
15 compinit:83> shift
15 compinit:81> [[ 1 -gt 0 && /Users/matt/.antigen/.zcompdump != -[dfQC] ]]
15 compinit:76> [[ 2 -gt 0 && -d = -[dDiuC] ]]
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:121> shift _d_als
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:117> _i=5
15 compdump:116> ((  ! --_i && 963 > 1  ))
15 compdump:116> ((  ! --_i && 905 > 1  ))
15 compdump:116> ((  ! --_i && 733 > 1  ))
15 compdump:116> ((  ! --_i && 710 > 1  ))
15 compdump:116> ((  ! --_i && 652 > 1  ))
15 compdump:116> ((  ! --_i && 636 > 1  ))
15 compdump:116> ((  ! --_i && 627 > 1  ))
15 compdump:116> ((  ! --_i && 581 > 1  ))
15 compdump:116> ((  ! --_i && 470 > 1  ))
15 compdump:116> ((  ! --_i && 440 > 1  ))
15 compdump:116> ((  ! --_i && 430 > 1  ))
15 compdump:116> ((  ! --_i && 407 > 1  ))
15 compdump:116> ((  ! --_i && 403 > 1  ))
15 compdump:116> ((  ! --_i && 348 > 1  ))
15 compdump:116> ((  ! --_i && 346 > 1  ))
15 compdump:116> ((  ! --_i && 318 > 1  ))
15 compdump:116> ((  ! --_i && 311 > 1  ))
15 compdump:116> ((  ! --_i && 165 > 1  ))
15 compdump:116> ((  ! --_i && 137 > 1  ))
15 compdump:116> ((  ! --_i && 120 > 1  ))
15 compdump:116> ((  ! --_i && 87 > 1  ))
15 compdump:116> ((  ! --_i && 83 > 1  ))
15 compdump:116> ((  ! --_i && 66 > 1  ))
15 compdump:116> ((  ! --_i && 64 > 1  ))
15 compdump:116> ((  ! --_i && 57 > 1  ))
15 compdump:116> ((  ! --_i && 51 > 1  ))
15 compdump:116> ((  ! --_i && 47 > 1  ))
15 compdump:116> ((  ! --_i && 42 > 1  ))
15 compdump:116> ((  ! --_i && 36 > 1  ))
15 compdump:116> ((  ! --_i && 28 > 1  ))
15 compdump:116> ((  ! --_i && 17 > 1  ))
15 compdump:116> ((  ! --_i && 13 > 1  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:114> ((  ! 0  ))
15 compdump:113> ((  1045  ))
15 compdump:113> ((  824  ))
15 compdump:113> ((  464  ))
15 compdump:113> ((  371  ))
15 compdump:113> ((  200  ))
15 compdump:85> [[ vi-cmd-mode = _* ]]
15 compdump:85> [[ end-of-list = _* ]]
15 compdump:85> [[ _list_expansions = _* && _expand_word = _* ]]
15 compdump:85> [[ _expand_word = _* && _expand_word = _* ]]
15 compdump:85> [[ _correct_word = _* && _correct_word = _* ]]
15 compdump:85> [[ _complete_tag = _* && _complete_tag = _* ]]
15 compdump:85> [[ _complete_help = _* && _complete_help = _* ]]
15 compdump:85> [[ _complete_debug = _* && _complete_debug = _* ]]
15 compdump:62> _d_f=zf*
15 compdump:62> _d_f=yodl(|2*)
15 compdump:62> _d_f=python[0-9.]#
15 compdump:62> _d_f=pydoc[0-9.]#
15 compdump:62> _d_f=gem[0-9.]#
15 compdump:62> _d_f=gcc-*
15 compdump:62> _d_f=g++-*
15 compdump:62> _d_f=-value-,GO*,-default-
15 compdump:62> _d_f=(texi(2*|ndex))
15 compdump:49> _d_f=zf_chgrp
15 compdump:49> _d_f=yaourt.static
15 compdump:49> _d_f=xelatex
15 compdump:49> _d_f=tunes2pod.pl
15 compdump:49> _d_f=svnadmin-static
15 compdump:49> _d_f=slogin
15 compdump:49> _d_f=remsh
15 compdump:49> _d_f=pcat
15 compdump:49> _d_f=nedit-nc
15 compdump:49> _d_f=ncl
15 compdump:49> _d_f=nail
15 compdump:49> _d_f=mktunes.pl
15 compdump:49> _d_f=lzma
15 compdump:49> _d_f=iceweasel
15 compdump:49> _d_f=gzcat
15 compdump:49> _d_f=gpg2
15 compdump:49> _d_f=gnupod_search.pl
15 compdump:49> _d_f=gnupod_addsong.pl
15 compdump:49> _d_f=gnupod_INIT.pl
15 compdump:49> _d_f=ggl
15 compdump:49> _d_f=ggfl
15 compdump:49> _d_f=gdnolock
15 compdump:49> _d_f=gchown
15 compdump:49> _d_f=gccd
15 compdump:49> _d_f=dch
15 compdump:49> _d_f=bzcat
15 compdump:49> _d_f=_git_log_prettily
15 compdump:49> _d_f=Mail
15 compdump:49> _d_f=-redirect-,>,xz
15 compdump:49> _d_f=-redirect-,>,gzip
15 compdump:49> _d_f=-redirect-,>,compress
15 compdump:49> _d_f=-redirect-,>,bzip2
15 compdump:49> _d_f=-redirect-,<,unxz
15 compdump:49> _d_f=-redirect-,<,gunzip
15 compdump:49> _d_f=-redirect-,<,compress
15 compdump:44> print -r - ''zln'' ''_zmv''
15 compdump:44> print -r - ''uml_moo'' ''_uml''
15 compdump:44> print -r - ''trap'' ''_trap''
15 compdump:44> print -r - ''tac'' ''_tac''
15 compdump:44> print -r - ''rm'' ''_rm''
15 compdump:44> print -r - ''rlogin'' ''_rlogin''
15 compdump:44> print -r - ''rgview'' ''_vim''
15 compdump:44> print -r - ''lzop'' ''_lzop''
15 compdump:44> print -r - ''jdb'' ''_java''
15 compdump:44> print -r - ''javap'' ''_java''
15 compdump:44> print -r - ''javah'' ''_java''
15 compdump:44> print -r - ''htop'' ''_htop''
15 compdump:43> _d_f=zypper
15 compdump:43> _d_f=zun
15 compdump:43> _d_f=ztodo
15 compdump:43> _d_f=zstyle
15 compdump:43> _d_f=zstat
15 compdump:43> _d_f=zsocket
15 compdump:43> _d_f=zsh-mime-handler
15 compdump:43> _d_f=zpty
15 compdump:43> _d_f=zpool
15 compdump:43> _d_f=zoneadm
15 compdump:43> _d_f=zone
15 compdump:43> _d_f=zmv
15 compdump:43> _d_f=zmail
15 compdump:43> _d_f=zlistattr
15 compdump:43> _d_f=zle
15 compdump:43> _d_f=zip
15 compdump:43> _d_f=zgrep
15 compdump:43> _d_f=zgetattr
15 compdump:43> _d_f=zfs
15 compdump:43> _d_f=zfgrep
15 compdump:43> _d_f=zf_rmdir
15 compdump:43> _d_f=zf_mv
15 compdump:43> _d_f=zf_ln
15 compdump:43> _d_f=zf_chown
15 compdump:43> _d_f=zf_chmod
15 compdump:43> _d_f=zf_chgrp
15 compdump:43> _d_f=zegrep
15 compdump:43> _d_f=zeal
15 compdump:43> _d_f=zdump
15 compdump:43> _d_f=zcp
15 compdump:43> _d_f=zcompile
15 compdump:43> _d_f=zcash-cli
15 compdump:43> _d_f=zcalc
15 compdump:43> _d_f=yumdb
15 compdump:43> _d_f=yum
15 compdump:43> _d_f=ytalk
15 compdump:43> _d_f=ypxfr
15 compdump:43> _d_f=ypwhich
15 compdump:43> _d_f=ypset
15 compdump:43> _d_f=ypserv
15 compdump:43> _d_f=yppoll
15 compdump:43> _d_f=yppasswd
15 compdump:43> _d_f=ypcat
15 compdump:43> _d_f=ypbind
15 compdump:43> _d_f=yast2
15 compdump:43> _d_f=yast
15 compdump:43> _d_f=yash
15 compdump:43> _d_f=yarn
15 compdump:43> _d_f=yaourt.static
15 compdump:43> _d_f=yaourt
15 compdump:43> _d_f=yafc
15 compdump:43> _d_f=yadm
15 compdump:43> _d_f=xzcat
15 compdump:43> _d_f=xxd
15 compdump:43> _d_f=xwud
15 compdump:43> _d_f=xwit
15 compdump:43> _d_f=xwd
15 compdump:43> _d_f=xvnc4viewer
15 compdump:43> _d_f=xview
15 compdump:43> _d_f=xv
15 compdump:43> _d_f=xtp
15 compdump:43> _d_f=xterm
15 compdump:43> _d_f=xsetroot
15 compdump:43> _d_f=xsetbg
15 compdump:43> _d_f=xsel
15 compdump:43> _d_f=xrdb
15 compdump:43> _d_f=xprop
15 compdump:43> _d_f=xping
15 compdump:43> _d_f=xpdf
15 compdump:43> _d_f=xournal
15 compdump:43> _d_f=xon
15 compdump:43> _d_f=xmlstarlet
15 compdump:43> _d_f=xml
15 compdump:43> _d_f=xlsclients
15 compdump:43> _d_f=xloadimage
15 compdump:43> _d_f=xli
15 compdump:43> _d_f=xinput
15 compdump:43> _d_f=xhost
15 compdump:43> _d_f=xfreerdp
15 compdump:43> _d_f=xfontsel
15 compdump:43> _d_f=xfig
15 compdump:43> _d_f=xev
15 compdump:43> _d_f=xdvi
15 compdump:43> _d_f=xcode-select
15 compdump:43> _d_f=xclip
15 compdump:43> _d_f=xautolock
15 compdump:43> _d_f=xauth
15 compdump:43> _d_f=xattr
15 compdump:43> _d_f=xargs
15 compdump:43> _d_f=write
15 compdump:43> _d_f=wipefs
15 compdump:43> _d_f=whom
15 compdump:43> _d_f=whois
15 compdump:43> _d_f=whoami
15 compdump:43> _d_f=who
15 compdump:43> _d_f=whereis
15 compdump:43> _d_f=whence
15 compdump:43> _d_f=whatis
15 compdump:43> _d_f=wget
15 compdump:43> _d_f=wg-quick
15 compdump:43> _d_f=wemux
15 compdump:43> _d_f=wc
15 compdump:43> _d_f=watcher
15 compdump:43> _d_f=wanna-build
15 compdump:43> _d_f=wajig
15 compdump:43> _d_f=w3m
15 compdump:43> _d_f=vpnc-connect
15 compdump:43> _d_f=vpnc
15 compdump:43> _d_f=vorbiscomment
15 compdump:43> _d_f=vnstat
15 compdump:43> _d_f=vncviewer
15 compdump:43> _d_f=vncserver
15 compdump:43> _d_f=visudo
15 compdump:43> _d_f=virt-xml-validate
15 compdump:43> _d_f=virt-pki-validate
15 compdump:43> _d_f=virt-admin
15 compdump:43> _d_f=vimdiff
15 compdump:43> _d_f=vim-addons
15 compdump:43> _d_f=vcsh
15 compdump:43> _d_f=vared
15 compdump:43> _d_f=valgrind
15 compdump:43> _d_f=vagrant
15 compdump:43> _d_f=vacuumdb
15 compdump:43> _d_f=usermod
15 compdump:43> _d_f=useradd
15 compdump:43> _d_f=urxvtc
15 compdump:43> _d_f=urxvt256cc
15 compdump:43> _d_f=urxvt256c-mlc
15 compdump:43> _d_f=urxvt
15 compdump:43> _d_f=urpmi.update
15 compdump:43> _d_f=urpmi.removemedia
15 compdump:43> _d_f=urpmi.addmedia
15 compdump:43> _d_f=urpmi
15 compdump:43> _d_f=urpmf
15 compdump:43> _d_f=upgradepkg
15 compdump:43> _d_f=unwrapdiff
15 compdump:43> _d_f=unset
15 compdump:43> _d_f=unrar
15 compdump:43> _d_f=unlzma
15 compdump:43> _d_f=unlimit
15 compdump:43> _d_f=unix2mac
15 compdump:43> _d_f=unix2dos
15 compdump:43> _d_f=units
15 compdump:43> _d_f=unison
15 compdump:43> _d_f=unhash
15 compdump:43> _d_f=unexpand
15 compdump:43> _d_f=uncompress
15 compdump:43> _d_f=uname
15 compdump:43> _d_f=unalias
15 compdump:43> _d_f=unace
15 compdump:43> _d_f=uml_mconsole
15 compdump:43> _d_f=udisksctl
15 compdump:43> _d_f=typeset
15 compdump:43> _d_f=type
15 compdump:43> _d_f=twist
15 compdump:43> _d_f=twidge
15 compdump:43> _d_f=tunes2pod
15 compdump:43> _d_f=tune2fs
15 compdump:43> _d_f=tunctl
15 compdump:43> _d_f=ttyctl
15 compdump:43> _d_f=tryaffix
15 compdump:43> _d_f=truss
15 compdump:43> _d_f=trove
15 compdump:43> _d_f=tree
15 compdump:43> _d_f=trash-restore
15 compdump:43> _d_f=trash-put
15 compdump:43> _d_f=trash-list
15 compdump:43> _d_f=trash-empty
15 compdump:43> _d_f=traceroute
15 compdump:43> _d_f=tracepath
15 compdump:43> _d_f=tr
15 compdump:43> _d_f=tput
15 compdump:43> _d_f=tpkg-install-libc
15 compdump:43> _d_f=tpkg-debarch
15 compdump:43> _d_f=tpb
15 compdump:43> _d_f=touch
15 compdump:43> _d_f=totdconfig
15 compdump:43> _d_f=toilet
15 compdump:43> _d_f=tmuxp
15 compdump:43> _d_f=tmuxinator
15 compdump:43> _d_f=tload
15 compdump:43> _d_f=tkinfo
15 compdump:43> _d_f=tkconch
15 compdump:43> _d_f=tin
15 compdump:43> _d_f=tidy
15 compdump:43> _d_f=thor
15 compdump:43> _d_f=tg
15 compdump:43> _d_f=texi2any
15 compdump:43> _d_f=telnet
15 compdump:43> _d_f=tee
15 compdump:43> _d_f=tdr
15 compdump:43> _d_f=tde
15 compdump:43> _d_f=tdd
15 compdump:43> _d_f=tda
15 compdump:43> _d_f=tcsh
15 compdump:43> _d_f=tcptraceroute
15 compdump:43> _d_f=tardy
15 compdump:43> _d_f=tacker
15 compdump:43> _d_f=sysrc
15 compdump:43> _d_f=sysctl
15 compdump:43> _d_f=sync
15 compdump:43> _d_f=swift
15 compdump:43> _d_f=swanctl
15 compdump:43> _d_f=swaks
15 compdump:43> _d_f=svnlite
15 compdump:43> _d_f=svnadmin
15 compdump:43> _d_f=svm
15 compdump:43> _d_f=svcprop
15 compdump:43> _d_f=svcadm
15 compdump:43> _d_f=sv
15 compdump:43> _d_f=surfraw
15 compdump:43> _d_f=supervisorctl
15 compdump:43> _d_f=sum
15 compdump:43> _d_f=sudoedit
15 compdump:43> _d_f=subl
15 compdump:43> _d_f=su
15 compdump:43> _d_f=stty
15 compdump:43> _d_f=strongswan
15 compdump:43> _d_f=strip
15 compdump:43> _d_f=strings
15 compdump:43> _d_f=strftime
15 compdump:43> _d_f=strace64
15 compdump:43> _d_f=stow
15 compdump:43> _d_f=stop
15 compdump:43> _d_f=stdbuf
15 compdump:43> _d_f=status
15 compdump:43> _d_f=stat
15 compdump:43> _d_f=stack
15 compdump:43> _d_f=sshfs
15 compdump:43> _d_f=ssh-keyscan
15 compdump:43> _d_f=ssh-keygen
15 compdump:43> _d_f=ssh-copy-id
15 compdump:43> _d_f=ssh-agent
15 compdump:43> _d_f=ssh-add
15 compdump:43> _d_f=ssh
15 compdump:43> _d_f=ss
15 compdump:43> _d_f=sqsh
15 compdump:43> _d_f=sqlite3
15 compdump:43> _d_f=sqlite
15 compdump:43> _d_f=split
15 compdump:43> _d_f=spamassassin
15 compdump:43> _d_f=source
15 compdump:43> _d_f=sortm
15 compdump:43> _d_f=sockstat
15 compdump:43> _d_f=socket
15 compdump:43> _d_f=soa
15 compdump:43> _d_f=snoop
15 compdump:43> _d_f=snap
15 compdump:43> _d_f=smitty
15 compdump:43> _d_f=smbstatus
15 compdump:43> _d_f=smbclient
15 compdump:43> _d_f=smartctl
15 compdump:43> _d_f=slrn
15 compdump:43> _d_f=slocate
15 compdump:43> _d_f=slitex
15 compdump:43> _d_f=slabtop
15 compdump:43> _d_f=skipstone
15 compdump:43> _d_f=skein1024
15 compdump:43> _d_f=skein512
15 compdump:43> _d_f=sisu
15 compdump:43> _d_f=signify
15 compdump:43> _d_f=shutdown
15 compdump:43> _d_f=shred
15 compdump:43> _d_f=showoff
15 compdump:43> _d_f=showmount
15 compdump:43> _d_f=showchar
15 compdump:43> _d_f=show
15 compdump:43> _d_f=shift
15 compdump:43> _d_f=sha512t256
15 compdump:43> _d_f=sha384sum
15 compdump:43> _d_f=sha256
15 compdump:43> _d_f=sha224sum
15 compdump:43> _d_f=sha1
15 compdump:43> _d_f=sh
15 compdump:43> _d_f=sfdx
15 compdump:43> _d_f=setxkbmap
15 compdump:43> _d_f=setup.py
15 compdump:43> _d_f=setfattr
15 compdump:43> _d_f=setfacl.exe
15 compdump:43> _d_f=setfacl
15 compdump:43> _d_f=setcap
15 compdump:43> _d_f=set
15 compdump:43> _d_f=serialver
15 compdump:43> _d_f=seq
15 compdump:43> _d_f=senlin
15 compdump:43> _d_f=sed
15 compdump:43> _d_f=scutil
15 compdump:43> _d_f=scselect
15 compdump:43> _d_f=screen
15 compdump:43> _d_f=scp
15 compdump:43> _d_f=scons
15 compdump:43> _d_f=scl
15 compdump:43> _d_f=schroot
15 compdump:43> _d_f=schedtool
15 compdump:43> _d_f=sccsdiff
15 compdump:43> _d_f=scan
15 compdump:43> _d_f=scalac
15 compdump:43> _d_f=scala
15 compdump:43> _d_f=sbuild
15 compdump:43> _d_f=sbt
15 compdump:43> _d_f=savecore
15 compdump:43> _d_f=sar
15 compdump:43> _d_f=sahara
15 compdump:43> _d_f=sadf
15 compdump:43> _d_f=sact
15 compdump:43> _d_f=rxvt
15 compdump:43> _d_f=rwho
15 compdump:43> _d_f=rvim
15 compdump:43> _d_f=rusage
15 compdump:43> _d_f=rup
15 compdump:43> _d_f=rubber
15 compdump:43> _d_f=rtin
15 compdump:43> _d_f=rsync
15 compdump:43> _d_f=rsvm
15 compdump:43> _d_f=rspec
15 compdump:43> _d_f=rslsync
15 compdump:43> _d_f=rsh
15 compdump:43> _d_f=rrdtool
15 compdump:43> _d_f=rmiregistry
15 compdump:43> _d_f=rlogin
15 compdump:43> _d_f=rkt
15 compdump:43> _d_f=ri
15 compdump:43> _d_f=rgvim
15 compdump:43> _d_f=rfkill
15 compdump:43> _d_f=retawq
15 compdump:43> _d_f=restic
15 compdump:43> _d_f=repl
15 compdump:43> _d_f=renice
15 compdump:43> _d_f=remsh
15 compdump:43> _d_f=removepkg
15 compdump:43> _d_f=reload
15 compdump:43> _d_f=rehash
15 compdump:43> _d_f=refile
15 compdump:43> _d_f=redis-cli
15 compdump:43> _d_f=rec
15 compdump:43> _d_f=rebootin
15 compdump:43> _d_f=readshortcut.exe
15 compdump:43> _d_f=readshortcut
15 compdump:43> _d_f=readlink
15 compdump:43> _d_f=read
15 compdump:43> _d_f=rdesktop
15 compdump:43> _d_f=rcs
15 compdump:43> _d_f=rcp
15 compdump:43> _d_f=rcctl
15 compdump:43> _d_f=rc
15 compdump:43> _d_f=rar
15 compdump:43> _d_f=ralio
15 compdump:43> _d_f=rails
15 compdump:43> _d_f=quilt
15 compdump:43> _d_f=qiv
15 compdump:43> _d_f=qdbus
15 compdump:43> _d_f=pyhtmlizer
15 compdump:43> _d_f=pygmentize
15 compdump:43> _d_f=pwdx
15 compdump:43> _d_f=pv
15 compdump:43> _d_f=putclip.exe
15 compdump:43> _d_f=putclip
15 compdump:43> _d_f=pushd
15 compdump:43> _d_f=pump
15 compdump:43> _d_f=ptree
15 compdump:43> _d_f=pswrap
15 compdump:43> _d_f=pstotgif
15 compdump:43> _d_f=pstops
15 compdump:43> _d_f=pstack
15 compdump:43> _d_f=psselect
15 compdump:43> _d_f=psresize
15 compdump:43> _d_f=psql
15 compdump:43> _d_f=psig
15 compdump:43> _d_f=pscp.exe
15 compdump:43> _d_f=psbook
15 compdump:43> _d_f=ps2ps
15 compdump:43> _d_f=ps2pdf13
15 compdump:43> _d_f=ps2pdf12
15 compdump:43> _d_f=ps2pdf
15 compdump:43> _d_f=ps2epsi
15 compdump:43> _d_f=ps2ascii
15 compdump:43> _d_f=prun
15 compdump:43> _d_f=prt
15 compdump:43> _d_f=prstat
15 compdump:43> _d_f=prove
15 compdump:43> _d_f=prompt
15 compdump:43> _d_f=procstat
15 compdump:43> _d_f=printf
15 compdump:43> _d_f=printenv
15 compdump:43> _d_f=print
15 compdump:43> _d_f=prev
15 compdump:43> _d_f=powerd
15 compdump:43> _d_f=postqueue
15 compdump:43> _d_f=postmaster
15 compdump:43> _d_f=postgres
15 compdump:43> _d_f=portsnap
15 compdump:43> _d_f=portmaster
15 compdump:43> _d_f=portaudit
15 compdump:43> _d_f=popd
15 compdump:43> _d_f=pon
15 compdump:43> _d_f=policytool
15 compdump:43> _d_f=podtoc
15 compdump:43> _d_f=podpath
15 compdump:43> _d_f=podgrep
15 compdump:43> _d_f=pmvers
15 compdump:43> _d_f=pmls
15 compdump:43> _d_f=pmload
15 compdump:43> _d_f=pmfunc
15 compdump:43> _d_f=pmexp
15 compdump:43> _d_f=pmdesc
15 compdump:43> _d_f=pman
15 compdump:43> _d_f=pm2
15 compdump:43> _d_f=plutil
15 compdump:43> _d_f=pldd
15 compdump:43> _d_f=play
15 compdump:43> _d_f=pkill
15 compdump:43> _d_f=pkgtool
15 compdump:43> _d_f=pkginfo
15 compdump:43> _d_f=pkgin
15 compdump:43> _d_f=pkgadd
15 compdump:43> _d_f=pkg_info
15 compdump:43> _d_f=pkg_create
15 compdump:43> _d_f=pkg_add
15 compdump:43> _d_f=pkg-config
15 compdump:43> _d_f=pkcon
15 compdump:43> _d_f=pixz
15 compdump:43> _d_f=piuparts
15 compdump:43> _d_f=pipenv
15 compdump:43> _d_f=ping6
15 compdump:43> _d_f=ping
15 compdump:43> _d_f=pinfo
15 compdump:43> _d_f=pinef
15 compdump:43> _d_f=pidof
15 compdump:43> _d_f=picocom
15 compdump:43> _d_f=pick
15 compdump:43> _d_f=php
15 compdump:43> _d_f=pgrep
15 compdump:43> _d_f=pg_restore
15 compdump:43> _d_f=pg_isready
15 compdump:43> _d_f=pg_dumpall
15 compdump:43> _d_f=pg_dump
15 compdump:43> _d_f=pg_ctl
15 compdump:43> _d_f=pg_config
15 compdump:43> _d_f=pfexec
15 compdump:43> _d_f=perldoc
15 compdump:43> _d_f=perl
15 compdump:43> _d_f=periscope
15 compdump:43> _d_f=perf
15 compdump:43> _d_f=pdm
15 compdump:43> _d_f=pdksh
15 compdump:43> _d_f=pdftops
15 compdump:43> _d_f=pdftk
15 compdump:43> _d_f=pdftexi2dvi
15 compdump:43> _d_f=pdftex
15 compdump:43> _d_f=pdfopt
15 compdump:43> _d_f=pdflatex
15 compdump:43> _d_f=pdfinfo
15 compdump:43> _d_f=pdfimages
15 compdump:43> _d_f=pdffonts
15 compdump:43> _d_f=pdf2ps
15 compdump:43> _d_f=pdf2dsc
15 compdump:43> _d_f=pcred
15 compdump:43> _d_f=pbuilder
15 compdump:43> _d_f=pbpaste
15 compdump:43> _d_f=pbcopy
15 compdump:43> _d_f=pax
15 compdump:43> _d_f=patool
15 compdump:43> _d_f=paste
15 compdump:43> _d_f=passwd
15 compdump:43> _d_f=pandoc
15 compdump:43> _d_f=packf
15 compdump:43> _d_f=pack
15 compdump:43> _d_f=p4d
15 compdump:43> _d_f=p4
15 compdump:43> _d_f=osc
15 compdump:43> _d_f=optirun
15 compdump:43> _d_f=opkg
15 compdump:43> _d_f=opera-next
15 compdump:43> _d_f=opera
15 compdump:43> _d_f=openstack
15 compdump:43> _d_f=open
15 compdump:43> _d_f=omz
15 compdump:43> _d_f=okular
15 compdump:43> _d_f=ogginfo
15 compdump:43> _d_f=oggdec
15 compdump:43> _d_f=ogg123
15 compdump:43> _d_f=odme
15 compdump:43> _d_f=od
15 compdump:43> _d_f=nvram
15 compdump:43> _d_f=nvim
15 compdump:43> _d_f=ntalk
15 compdump:43> _d_f=nslookup
15 compdump:43> _d_f=ns
15 compdump:43> _d_f=npm
15 compdump:43> _d_f=nova
15 compdump:43> _d_f=node
15 compdump:43> _d_f=nmcli
15 compdump:43> _d_f=nmblookup
15 compdump:43> _d_f=nmap
15 compdump:43> _d_f=nl
15 compdump:43> _d_f=nkf
15 compdump:43> _d_f=ninja
15 compdump:43> _d_f=nice
15 compdump:43> _d_f=ngrep
15 compdump:43> _d_f=nginx
15 compdump:43> _d_f=next
15 compdump:43> _d_f=newgrp
15 compdump:43> _d_f=new
15 compdump:43> _d_f=neutron
15 compdump:43> _d_f=netstat
15 compdump:43> _d_f=netscape
15 compdump:43> _d_f=nedit-nc
15 compdump:43> _d_f=nedit
15 compdump:43> _d_f=ncl
15 compdump:43> _d_f=ncftp
15 compdump:43> _d_f=ncal
15 compdump:43> _d_f=nc
15 compdump:43> _d_f=nautilus
15 compdump:43> _d_f=native2ascii
15 compdump:43> _d_f=nanoc
15 compdump:43> _d_f=nano
15 compdump:43> _d_f=mysqlshow
15 compdump:43> _d_f=mysqlimport
15 compdump:43> _d_f=mysqldump
15 compdump:43> _d_f=mysqldiff
15 compdump:43> _d_f=mysql
15 compdump:43> _d_f=mx
15 compdump:43> _d_f=mvnDebug
15 compdump:43> _d_f=mvn
15 compdump:43> _d_f=mvim
15 compdump:43> _d_f=mv
15 compdump:43> _d_f=mutt
15 compdump:43> _d_f=mush
15 compdump:43> _d_f=murano
15 compdump:43> _d_f=mupdf
15 compdump:43> _d_f=munchlist
15 compdump:43> _d_f=mullvad
15 compdump:43> _d_f=mtype
15 compdump:43> _d_f=mtr
15 compdump:43> _d_f=mtoolstest
15 compdump:43> _d_f=mt
15 compdump:43> _d_f=msgchk
15 compdump:43> _d_f=mren
15 compdump:43> _d_f=mread
15 compdump:43> _d_f=mrd
15 compdump:43> _d_f=mpv
15 compdump:43> _d_f=mpstat
15 compdump:43> _d_f=mplayer
15 compdump:43> _d_f=mozilla-firefox
15 compdump:43> _d_f=mozilla
15 compdump:43> _d_f=mosh
15 compdump:43> _d_f=montage
15 compdump:43> _d_f=mondoarchive
15 compdump:43> _d_f=mogrify
15 compdump:43> _d_f=module-assistant
15 compdump:43> _d_f=modprobe
15 compdump:43> _d_f=mmount
15 compdump:43> _d_f=mmd
15 compdump:43> _d_f=mkzsh
15 compdump:43> _d_f=mktunes.pl
15 compdump:43> _d_f=mktemp
15 compdump:43> _d_f=mkshortcut.exe
15 compdump:43> _d_f=mkshortcut
15 compdump:43> _d_f=mksh
15 compdump:43> _d_f=mknod
15 compdump:43> _d_f=mistral
15 compdump:43> _d_f=mina
15 compdump:43> _d_f=middleman
15 compdump:43> _d_f=mhstore
15 compdump:43> _d_f=mhlist
15 compdump:43> _d_f=mhfixmsg
15 compdump:43> _d_f=mgv
15 compdump:43> _d_f=mformat
15 compdump:43> _d_f=meson
15 compdump:43> _d_f=mergechanges
15 compdump:43> _d_f=merge
15 compdump:43> _d_f=mere
15 compdump:43> _d_f=mencal
15 compdump:43> _d_f=members
15 compdump:43> _d_f=mdutil
15 compdump:43> _d_f=mdu
15 compdump:43> _d_f=mdls
15 compdump:43> _d_f=md4
15 compdump:43> _d_f=md2
15 compdump:43> _d_f=mcopy
15 compdump:43> _d_f=matlab
15 compdump:43> _d_f=mark
15 compdump:43> _d_f=manila
15 compdump:43> _d_f=makepkg
15 compdump:43> _d_f=mailx
15 compdump:43> _d_f=mail
15 compdump:43> _d_f=madison
15 compdump:43> _d_f=mac2unix
15 compdump:43> _d_f=lzop
15 compdump:43> _d_f=lzma
15 compdump:43> _d_f=lzcat
15 compdump:43> _d_f=lz4cat
15 compdump:43> _d_f=lz4c32
15 compdump:43> _d_f=lz4c
15 compdump:43> _d_f=lz4
15 compdump:43> _d_f=lynx
15 compdump:43> _d_f=lunchy
15 compdump:43> _d_f=luarocks
15 compdump:43> _d_f=ltrace
15 compdump:43> _d_f=lsvg
15 compdump:43> _d_f=lsusb
15 compdump:43> _d_f=lspv
15 compdump:43> _d_f=lsof
15 compdump:43> _d_f=lsmod
15 compdump:43> _d_f=lslv
15 compdump:43> _d_f=lsdiff
15 compdump:43> _d_f=lpoptions
15 compdump:43> _d_f=look
15 compdump:43> _d_f=locate
15 compdump:43> _d_f=localedef
15 compdump:43> _d_f=loadkeys
15 compdump:43> _d_f=ln
15 compdump:43> _d_f=llvm-objdump
15 compdump:43> _d_f=lldb
15 compdump:43> _d_f=lintian-info
15 compdump:43> _d_f=links2
15 compdump:43> _d_f=lighty-disable-mod
15 compdump:43> _d_f=light
15 compdump:43> _d_f=lha
15 compdump:43> _d_f=lftp
15 compdump:43> _d_f=let
15 compdump:43> _d_f=less
15 compdump:43> _d_f=ldd
15 compdump:43> _d_f=ldconfig.real
15 compdump:43> _d_f=ldconfig
15 compdump:43> _d_f=ldap
15 compdump:43> _d_f=latexmk
15 compdump:43> _d_f=latex
15 compdump:43> _d_f=ksh88
15 compdump:43> _d_f=ksh
15 compdump:43> _d_f=konqueror
15 compdump:43> _d_f=kldunload
15 compdump:43> _d_f=kldload
15 compdump:43> _d_f=kitchen
15 compdump:43> _d_f=killall5
15 compdump:43> _d_f=kfmclient
15 compdump:43> _d_f=keystone
15 compdump:43> _d_f=kdeconnect-cli
15 compdump:43> _d_f=jmeter
15 compdump:43> _d_f=jls
15 compdump:43> _d_f=jexec
15 compdump:43> _d_f=jar
15 compdump:43> _d_f=jail
15 compdump:43> _d_f=iwconfig
15 compdump:43> _d_f=iptables-save
15 compdump:43> _d_f=iptables-restore
15 compdump:43> _d_f=iptables
15 compdump:43> _d_f=ipset
15 compdump:43> _d_f=ip6tables-save
15 compdump:43> _d_f=ip6tables-restore
15 compdump:43> _d_f=ip
15 compdump:43> _d_f=interdiff
15 compdump:43> _d_f=integer
15 compdump:43> _d_f=install-info
15 compdump:43> _d_f=install
15 compdump:43> _d_f=insmod
15 compdump:43> _d_f=initctl
15 compdump:43> _d_f=infocmp
15 compdump:43> _d_f=info
15 compdump:43> _d_f=inetadm
15 compdump:43> _d_f=includeres
15 compdump:43> _d_f=import
15 compdump:43> _d_f=ifdown
15 compdump:43> _d_f=ifconfig
15 compdump:43> _d_f=id
15 compdump:43> _d_f=iconvconfig
15 compdump:43> _d_f=iceweasel
15 compdump:43> _d_f=ibus
15 compdump:43> _d_f=hotjava
15 compdump:43> _d_f=hostname
15 compdump:43> _d_f=host
15 compdump:43> _d_f=homestead
15 compdump:43> _d_f=history
15 compdump:43> _d_f=hilite
15 compdump:43> _d_f=hexdump
15 compdump:43> _d_f=heroku
15 compdump:43> _d_f=help
15 compdump:43> _d_f=helm
15 compdump:43> _d_f=heat
15 compdump:43> _d_f=head
15 compdump:43> _d_f=hdiutil
15 compdump:43> _d_f=hd
15 compdump:43> _d_f=gzilla
15 compdump:43> _d_f=gzgrep
15 compdump:43> _d_f=gzfgrep
15 compdump:43> _d_f=gzcat
15 compdump:43> _d_f=gxargs
15 compdump:43> _d_f=gwho
15 compdump:43> _d_f=gwc
15 compdump:43> _d_f=gview
15 compdump:43> _d_f=gv
15 compdump:43> _d_f=guptime
15 compdump:43> _d_f=guname
15 compdump:43> _d_f=guilt-unapplied
15 compdump:43> _d_f=guilt-top
15 compdump:43> _d_f=guilt-status
15 compdump:43> _d_f=guilt-series
15 compdump:43> _d_f=guilt-push
15 compdump:43> _d_f=guilt-prev
15 compdump:43> _d_f=guilt-patchbomb
15 compdump:43> _d_f=guilt-new
15 compdump:43> _d_f=guilt-header
15 compdump:43> _d_f=guilt-files
15 compdump:43> _d_f=guilt-delete
15 compdump:43> _d_f=guilt-applied
15 compdump:43> _d_f=guilt
15 compdump:43> _d_f=gtty
15 compdump:43> _d_f=gtr
15 compdump:43> _d_f=gtouch
15 compdump:43> _d_f=gtk-launch
15 compdump:43> _d_f=gtee
15 compdump:43> _d_f=gtail
15 compdump:43> _d_f=gtac
15 compdump:43> _d_f=gsum
15 compdump:43> _d_f=gstty
15 compdump:43> _d_f=gstdbuf
15 compdump:43> _d_f=gstat
15 compdump:43> _d_f=gsplit
15 compdump:43> _d_f=gsort
15 compdump:43> _d_f=gsnd
15 compdump:43> _d_f=gslj
15 compdump:43> _d_f=gshuf
15 compdump:43> _d_f=gshred
15 compdump:43> _d_f=gsha512sum
15 compdump:43> _d_f=gsha256sum
15 compdump:43> _d_f=gsha1sum
15 compdump:43> _d_f=gsed
15 compdump:43> _d_f=groups
15 compdump:43> _d_f=groupdel
15 compdump:43> _d_f=grep
15 compdump:43> _d_f=grail
15 compdump:43> _d_f=gradlew
15 compdump:43> _d_f=gradle
15 compdump:43> _d_f=gqview
15 compdump:43> _d_f=gprof
15 compdump:43> _d_f=gphoto2
15 compdump:43> _d_f=gpg2
15 compdump:43> _d_f=gpg-zip
15 compdump:43> _d_f=gpg
15 compdump:43> _d_f=gpatch
15 compdump:43> _d_f=gpaste
15 compdump:43> _d_f=god
15 compdump:43> _d_f=gnupod_search.pl
15 compdump:43> _d_f=gnupod_check.pl
15 compdump:43> _d_f=gnupod_addsong
15 compdump:43> _d_f=gnupod_INIT
15 compdump:43> _d_f=gnumfmt
15 compdump:43> _d_f=gnome-gv
15 compdump:43> _d_f=gnl
15 compdump:43> _d_f=gmv
15 compdump:43> _d_f=gmktemp
15 compdump:43> _d_f=gmkdir
15 compdump:43> _d_f=gmd5sum
15 compdump:43> _d_f=gmake
15 compdump:43> _d_f=gls
15 compdump:43> _d_f=global
15 compdump:43> _d_f=glances
15 compdump:43> _d_f=gjoin
15 compdump:43> _d_f=gitk
15 compdump:43> _d_f=git-pulls
15 compdump:43> _d_f=git-flow
15 compdump:43> _d_f=git
15 compdump:43> _d_f=gist
15 compdump:43> _d_f=ginstall
15 compdump:43> _d_f=gid
15 compdump:43> _d_f=ghostscript
15 compdump:43> _d_f=ghead
15 compdump:43> _d_f=ghci
15 compdump:43> _d_f=ghc-pkg
15 compdump:43> _d_f=ghc
15 compdump:43> _d_f=ggu
15 compdump:43> _d_f=ggrep
15 compdump:43> _d_f=ggl
15 compdump:43> _d_f=ggfl
15 compdump:43> _d_f=ggf
15 compdump:43> _d_f=ggetopt
15 compdump:43> _d_f=gfold
15 compdump:43> _d_f=gfmt
15 compdump:43> _d_f=gfind
15 compdump:43> _d_f=gexpand
15 compdump:43> _d_f=getopts
15 compdump:43> _d_f=getmail
15 compdump:43> _d_f=getfattr
15 compdump:43> _d_f=getclip.exe
15 compdump:43> _d_f=getafm
15 compdump:43> _d_f=get
15 compdump:43> _d_f=genv
15 compdump:43> _d_f=geany
15 compdump:43> _d_f=gdv
15 compdump:43> _d_f=gdnolock
15 compdump:43> _d_f=gdd
15 compdump:43> _d_f=gdb
15 compdump:43> _d_f=gdate
15 compdump:43> _d_f=gcp
15 compdump:43> _d_f=gcore
15 compdump:43> _d_f=gcksum
15 compdump:43> _d_f=gchown
15 compdump:43> _d_f=gchgrp
15 compdump:43> _d_f=gcc
15 compdump:43> _d_f=gbasename
15 compdump:43> _d_f=gbase64
15 compdump:43> _d_f=gbase32
15 compdump:43> _d_f=gawk
15 compdump:43> _d_f=galeon
15 compdump:43> _d_f=g++
15 compdump:43> _d_f=fwupdmgr
15 compdump:43> _d_f=fstat
15 compdump:43> _d_f=freezer
15 compdump:43> _d_f=freebsd-update
15 compdump:43> _d_f=free
15 compdump:43> _d_f=fprev
15 compdump:43> _d_f=folder
15 compdump:43> _d_f=fold
15 compdump:43> _d_f=fnext
15 compdump:43> _d_f=fned
15 compdump:43> _d_f=float
15 compdump:43> _d_f=flists
15 compdump:43> _d_f=flex
15 compdump:43> _d_f=fixwwps
15 compdump:43> _d_f=fixwfwps
15 compdump:43> _d_f=fixtpps
15 compdump:43> _d_f=fixpsditps
15 compdump:43> _d_f=fixfmps
15 compdump:43> _d_f=firefox
15 compdump:43> _d_f=fink
15 compdump:43> _d_f=fg
15 compdump:43> _d_f=ffmpeg
15 compdump:43> _d_f=ffind
15 compdump:43> _d_f=fetchmail
15 compdump:43> _d_f=feh
15 compdump:43> _d_f=fc-match
15 compdump:43> _d_f=fc
15 compdump:43> _d_f=false
15 compdump:43> _d_f=fakeroot
15 compdump:43> _d_f=fail2ban-client
15 compdump:43> _d_f=fab
15 compdump:43> _d_f=extcheck
15 compdump:43> _d_f=express
15 compdump:43> _d_f=exportfs
15 compdump:43> _d_f=export
15 compdump:43> _d_f=explodepkg
15 compdump:43> _d_f=expand
15 compdump:43> _d_f=exec
15 compdump:43> _d_f=evince
15 compdump:43> _d_f=eval
15 compdump:43> _d_f=eu-strings
15 compdump:43> _d_f=eu-readelf
15 compdump:43> _d_f=eu-objdump
15 compdump:43> _d_f=ethtool
15 compdump:43> _d_f=etags
15 compdump:43> _d_f=espeak
15 compdump:43> _d_f=erb
15 compdump:43> _d_f=epdfview
15 compdump:43> _d_f=eog
15 compdump:43> _d_f=envdir
15 compdump:43> _d_f=env
15 compdump:43> _d_f=entr
15 compdump:43> _d_f=enscript
15 compdump:43> _d_f=enable
15 compdump:43> _d_f=emulator
15 compdump:43> _d_f=emulate
15 compdump:43> _d_f=elinks
15 compdump:43> _d_f=elfdump
15 compdump:43> _d_f=egrep
15 compdump:43> _d_f=ed
15 compdump:43> _d_f=echotc
15 compdump:43> _d_f=ecdsautil
15 compdump:43> _d_f=ecasound
15 compdump:43> _d_f=eatmydata
15 compdump:43> _d_f=e2label
15 compdump:43> _d_f=dwb
15 compdump:43> _d_f=dvitype
15 compdump:43> _d_f=dvitodvi
15 compdump:43> _d_f=dviselect
15 compdump:43> _d_f=dvips
15 compdump:43> _d_f=dvipdf
15 compdump:43> _d_f=dvidvi
15 compdump:43> _d_f=dviconcat
15 compdump:43> _d_f=dvibook
15 compdump:43> _d_f=dvc
15 compdump:43> _d_f=dupload
15 compdump:43> _d_f=dumper.exe
15 compdump:43> _d_f=dumper
15 compdump:43> _d_f=dumpadm
15 compdump:43> _d_f=du
15 compdump:43> _d_f=dtruss
15 compdump:43> _d_f=dsh
15 compdump:43> _d_f=drush
15 compdump:43> _d_f=dropuser
15 compdump:43> _d_f=dropdb
15 compdump:43> _d_f=dput
15 compdump:43> _d_f=dpkg-source
15 compdump:43> _d_f=dpkg-reconfigure
15 compdump:43> _d_f=dpkg-query
15 compdump:43> _d_f=dpkg-deb
15 compdump:43> _d_f=dpkg-cross
15 compdump:43> _d_f=dpkg-buildpackage
15 compdump:43> _d_f=dosdel
15 compdump:43> _d_f=dos2unix
15 compdump:43> _d_f=docpad
15 compdump:43> _d_f=dockerd
15 compdump:43> _d_f=docker
15 compdump:43> _d_f=doas
15 compdump:43> _d_f=dnf-3
15 compdump:43> _d_f=dnf
15 compdump:43> _d_f=dmidecode
15 compdump:43> _d_f=dmesg
15 compdump:43> _d_f=dmake
15 compdump:43> _d_f=dladm
15 compdump:43> _d_f=dkms
15 compdump:43> _d_f=django-admin.py
15 compdump:43> _d_f=dist
15 compdump:43> _d_f=display
15 compdump:43> _d_f=disown
15 compdump:43> _d_f=dirs
15 compdump:43> _d_f=dircmp
15 compdump:43> _d_f=dillo
15 compdump:43> _d_f=dig
15 compdump:43> _d_f=diff
15 compdump:43> _d_f=dict
15 compdump:43> _d_f=dhclient3
15 compdump:43> _d_f=dhclient
15 compdump:43> _d_f=df
15 compdump:43> _d_f=devtodo
15 compdump:43> _d_f=delta
15 compdump:43> _d_f=defaults
15 compdump:43> _d_f=debuild
15 compdump:43> _d_f=debsign
15 compdump:43> _d_f=deborphan
15 compdump:43> _d_f=debfoster
15 compdump:43> _d_f=debdiff
15 compdump:43> _d_f=debcheckout
15 compdump:43> _d_f=dd
15 compdump:43> _d_f=dcut
15 compdump:43> _d_f=dcopstart
15 compdump:43> _d_f=dcopref
15 compdump:43> _d_f=dcopfind
15 compdump:43> _d_f=dcopclient
15 compdump:43> _d_f=dcop
15 compdump:43> _d_f=dconf
15 compdump:43> _d_f=dchroot-dsa
15 compdump:43> _d_f=dchroot
15 compdump:43> _d_f=dbus-monitor
15 compdump:43> _d_f=date
15 compdump:43> _d_f=dash
15 compdump:43> _d_f=darcs
15 compdump:43> _d_f=dad
15 compdump:43> _d_f=cygstart
15 compdump:43> _d_f=cygserver
15 compdump:43> _d_f=cygpath.exe
15 compdump:43> _d_f=cygpath
15 compdump:43> _d_f=cygcheck.exe
15 compdump:43> _d_f=cygcheck
15 compdump:43> _d_f=cvs
15 compdump:43> _d_f=curl
15 compdump:43> _d_f=cu
15 compdump:43> _d_f=csup
15 compdump:43> _d_f=cssh
15 compdump:43> _d_f=csh
15 compdump:43> _d_f=cryptsetup
15 compdump:43> _d_f=crsh
15 compdump:43> _d_f=createuser
15 compdump:43> _d_f=createdb
15 compdump:43> _d_f=cpupower
15 compdump:43> _d_f=cppcheck
15 compdump:43> _d_f=cplay
15 compdump:43> _d_f=cpio
15 compdump:43> _d_f=cp
15 compdump:43> _d_f=cowthink
15 compdump:43> _d_f=cowsay
15 compdump:43> _d_f=coreadm
15 compdump:43> _d_f=configure
15 compdump:43> _d_f=config.status
15 compdump:43> _d_f=conch
15 compdump:43> _d_f=conan
15 compdump:43> _d_f=compress
15 compdump:43> _d_f=composer.phar
15 compdump:43> _d_f=composer
15 compdump:43> _d_f=compdef
15 compdump:43> _d_f=compadd
15 compdump:43> _d_f=comm
15 compdump:43> _d_f=combine
15 compdump:43> _d_f=column
15 compdump:43> _d_f=coffee
15 compdump:43> _d_f=code
15 compdump:43> _d_f=cockroach
15 compdump:43> _d_f=cmake
15 compdump:43> _d_f=cloudkitty
15 compdump:43> _d_f=clear
15 compdump:43> _d_f=clay
15 compdump:43> _d_f=clang
15 compdump:43> _d_f=cksum
15 compdump:43> _d_f=ckeygen
15 compdump:43> _d_f=ci
15 compdump:43> _d_f=chroot
15 compdump:43> _d_f=chpass
15 compdump:43> _d_f=chown
15 compdump:43> _d_f=choc
15 compdump:43> _d_f=chmod
15 compdump:43> _d_f=chkstow
15 compdump:43> _d_f=chkconfig
15 compdump:43> _d_f=chimera
15 compdump:43> _d_f=chgrp
15 compdump:43> _d_f=chfn
15 compdump:43> _d_f=cheat
15 compdump:43> _d_f=chdir
15 compdump:43> _d_f=chcon
15 compdump:43> _d_f=chattr
15 compdump:43> _d_f=cftp
15 compdump:43> _d_f=cf
15 compdump:43> _d_f=ceilometer
15 compdump:43> _d_f=cdrecord
15 compdump:43> _d_f=cdrdao
15 compdump:43> _d_f=cdcd
15 compdump:43> _d_f=cdc
15 compdump:43> _d_f=cd
15 compdump:43> _d_f=cc
15 compdump:43> _d_f=catchsegv
15 compdump:43> _d_f=cat
15 compdump:43> _d_f=cap
15 compdump:43> _d_f=cal
15 compdump:43> _d_f=cabal
15 compdump:43> _d_f=c++
15 compdump:43> _d_f=bzr
15 compdump:43> _d_f=bzip2recover
15 compdump:43> _d_f=bzip2
15 compdump:43> _d_f=bzgrep
15 compdump:43> _d_f=bzfgrep
15 compdump:43> _d_f=bzcat
15 compdump:43> _d_f=burst
15 compdump:43> _d_f=bunzip2
15 compdump:43> _d_f=bundle
15 compdump:43> _d_f=builtin
15 compdump:43> _d_f=buildhash
15 compdump:43> _d_f=bug
15 compdump:43> _d_f=bttrack
15 compdump:43> _d_f=btshowmetainfo
15 compdump:43> _d_f=btrfs
15 compdump:43> _d_f=bpython3
15 compdump:43> _d_f=bpython2
15 compdump:43> _d_f=bpython-urwid
15 compdump:43> _d_f=bpython-gtk
15 compdump:43> _d_f=bpython
15 compdump:43> _d_f=bower
15 compdump:43> _d_f=bogofilter
15 compdump:43> _d_f=bison
15 compdump:43> _d_f=bibtex
15 compdump:43> _d_f=basename
15 compdump:43> _d_f=base64
15 compdump:43> _d_f=barbican
15 compdump:43> _d_f=b2sum
15 compdump:43> _d_f=axi-cache
15 compdump:43> _d_f=aws
15 compdump:43> _d_f=avahi-resolve-host-name
15 compdump:43> _d_f=avahi-resolve-address
15 compdump:43> _d_f=avahi-browse
15 compdump:43> _d_f=autoload
15 compdump:43> _d_f=atrm
15 compdump:43> _d_f=atach
15 compdump:43> _d_f=at
15 compdump:43> _d_f=arping
15 compdump:43> _d_f=arp
15 compdump:43> _d_f=arena
15 compdump:43> _d_f=arecord
15 compdump:43> _d_f=archlinux-java
15 compdump:43> _d_f=apvlv
15 compdump:43> _d_f=aptitude
15 compdump:43> _d_f=apt-show-versions
15 compdump:43> _d_f=apt-get
15 compdump:43> _d_f=apt-config
15 compdump:43> _d_f=appletviewer
15 compdump:43> _d_f=aplay
15 compdump:43> _d_f=aoss
15 compdump:43> _d_f=antiword
15 compdump:43> _d_f=ansible-vault
15 compdump:43> _d_f=ansible-inventory
15 compdump:43> _d_f=ansible-galaxy
15 compdump:43> _d_f=animate
15 compdump:43> _d_f=android
15 compdump:43> _d_f=analyseplugin
15 compdump:43> _d_f=ali
15 compdump:43> _d_f=afew
15 compdump:43> _d_f=admin
15 compdump:43> _d_f=adb
15 compdump:43> _d_f=ack2
15 compdump:43> _d_f=ack-grep
15 compdump:43> _d_f=ack
15 compdump:43> _d_f=a2ps
15 compdump:43> _d_f=a2enmod
15 compdump:43> _d_f=_cockroach
15 compdump:43> _d_f=VBoxManage
15 compdump:43> _d_f=VBoxHeadless
15 compdump:43> _d_f=-vared-
15 compdump:43> _d_f=-value-,XZ_OPT,-default-
15 compdump:43> _d_f=-value-,XML_CATALOG_FILES,-default-
15 compdump:43> _d_f=-value-,RPS2,-default-
15 compdump:43> _d_f=-value-,RPROMPT2,-default-
15 compdump:43> _d_f=-value-,PS1,-default-
15 compdump:43> _d_f=-value-,PROMPT3,-default-
15 compdump:43> _d_f=-value-,PROMPT2,-default-
15 compdump:43> _d_f=-value-,P4MERGE,-default-
15 compdump:43> _d_f=-value-,P4CLIENT,-default-
15 compdump:43> _d_f=-value-,LPDEST,-default-
15 compdump:43> _d_f=-value-,LESS,-default-
15 compdump:43> _d_f=-value-,ANSIBLE_STDOUT_CALLBACK,-default-
15 compdump:43> _d_f=-value-,-default-,-default-
15 compdump:43> _d_f=-tilde-
15 compdump:43> _d_f=-redirect-,>,compress
15 compdump:43> _d_f=-redirect-
15 compdump:43> _d_f=-first-
15 compdump:43> _d_f=-condition-
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:169> shift
15 compdef:164> [[ -n yes ]]
15 compdef:163> _comps[$cmd]=_tex
15 compdef:163> _comps[$cmd]=_pack
15 compdef:163> _comps[$cmd]=_nedit
15 compdef:163> _comps[$cmd]=_mail
15 compdef:163> _comps[$cmd]=_gnupod
15 compdef:163> _comps[$cmd]=_git
15 compdef:163> _comps[$cmd]=_git
15 compdef:163> _comps[$cmd]=_bzip2
15 compdef:163> _comps[$cmd]=_bzip2
15 compdef:162> [[ -z yes || -z _yp ]]
15 compdef:162> [[ -z yes || -z _yp ]]
15 compdef:162> [[ -z yes || -z _xz ]]
15 compdef:162> [[ -z yes || -z _vnc ]]
15 compdef:162> [[ -z yes || -z _vim ]]
15 compdef:162> [[ -z yes || -z _vim ]]
15 compdef:162> [[ -z yes || -z _vim ]]
15 compdef:162> [[ -z yes || -z _urpmi ]]
15 compdef:162> [[ -z yes || -z _twisted ]]
15 compdef:162> [[ -z yes || -z _toolchain-source ]]
15 compdef:162> [[ -z yes || -z _tex ]]
15 compdef:162> [[ -z yes || -z _tex ]]
15 compdef:162> [[ -z yes || -z _tex ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _ssh ]]
15 compdef:162> [[ -z yes || -z _sccs ]]
15 compdef:162> [[ -z yes || -z _sccs ]]
15 compdef:162> [[ -z yes || -z _sccs ]]
15 compdef:162> [[ -z yes || -z _sccs ]]
15 compdef:162> [[ -z yes || -z _sccs ]]
15 compdef:162> [[ -z yes || -z _ruby ]]
15 compdef:162> [[ -z yes || -z _rpm ]]
15 compdef:162> [[ -z yes || -z _rpm ]]
15 compdef:162> [[ -z yes || -z _rpm ]]
15 compdef:162> [[ -z yes || -z _rmdir ]]
15 compdef:162> [[ -z yes || -z _psutils ]]
15 compdef:162> [[ -z yes || -z _psutils ]]
15 compdef:162> [[ -z yes || -z _psutils ]]
15 compdef:162> [[ -z yes || -z _psutils ]]
15 compdef:162> [[ -z yes || -z _ps1234 ]]
15 compdef:162> [[ -z yes || -z _ps1234 ]]
15 compdef:162> [[ -z yes || -z _precommand ]]
15 compdef:162> [[ -z yes || -z _postscript ]]
15 compdef:162> [[ -z yes || -z _postgresql ]]
15 compdef:162> [[ -z yes || -z _pids ]]
15 compdef:162> [[ -z yes || -z _pids ]]
15 compdef:162> [[ -z yes || -z _pids ]]
15 compdef:162> [[ -z yes || -z _pdf ]]
15 compdef:162> [[ -z yes || -z _mtools ]]
15 compdef:162> [[ -z yes || -z _mtools ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _mh ]]
15 compdef:162> [[ -z yes || -z _lp ]]
15 compdef:162> [[ -z yes || -z _java ]]
15 compdef:162> [[ -z yes || -z _hosts ]]
15 compdef:162> [[ -z yes || -z _grep ]]
15 compdef:162> [[ -z yes || -z _grep ]]
15 compdef:162> [[ -z yes || -z _gnutls ]]
15 compdef:162> [[ -z yes || -z _gcc ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:162> [[ -z yes || -z '' ]]
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:160> svc=''
15 compdef:159> cmd=yast
15 compdef:159> cmd=yadm
15 compdef:159> cmd=xinput
15 compdef:159> cmd=uncompress
15 compdef:159> cmd=pack
15 compdef:159> cmd=murano
15 compdef:159> cmd=mina
15 compdef:159> cmd=mdadm
15 compdef:159> cmd=eval
15 compdef:159> cmd=devtodo
15 compdef:159> cmd=debcheckout
15 compdef:159> cmd=dash
15 compdef:159> cmd=cygrunsrv.exe
15 compdef:159> cmd=compress
15 compdef:159> cmd=chkconfig
15 compdef:159> cmd=-value-,TZ,-default-
15 compdef:159> cmd=-value-,TERMINFO_DIRS,-default-
15 compdef:156> cmd=svnlite
15 compdef:156> cmd=gzcat
15 compdef:156> cmd=gnupod_search.pl
15 compdef:156> cmd=ggu
15 compdef:156> cmd=ggf
15 compdef:156> cmd=gdv
15 compdef:156> cmd=VBoxHeadless
15 compdef:156> cmd='-redirect-,>,compress'
15 compdef:156> cmd='-redirect-,<,gzip'
15 compdef:156> cmd='-redirect-,<,gunzip'
15 compdef:155> [[ zoneadm = *=* ]]
15 compdef:155> [[ zf_chmod = *=* ]]
15 compdef:155> [[ zeal = *=* ]]
15 compdef:155> [[ zcompile = *=* ]]
15 compdef:155> [[ yaourt = *=* ]]
15 compdef:155> [[ xz = *=* ]]
15 compdef:155> [[ xv = *=* ]]
15 compdef:155> [[ xsel = *=* ]]
15 compdef:155> [[ xscreensaver-command = *=* ]]
15 compdef:155> [[ xpdf = *=* ]]
15 compdef:155> [[ xournal = *=* ]]
15 compdef:155> [[ xmodmap = *=* ]]
15 compdef:155> [[ xmms2 = *=* ]]
15 compdef:155> [[ xfig = *=* ]]
15 compdef:155> [[ wodim = *=* ]]
15 compdef:155> [[ wiggle = *=* ]]
15 compdef:155> [[ wg-quick = *=* ]]
15 compdef:155> [[ wajig = *=* ]]
15 compdef:155> [[ vserver = *=* ]]
15 compdef:155> [[ urxvtc = *=* ]]
15 compdef:155> [[ update-rc.d = *=* ]]
15 compdef:155> [[ unrar = *=* ]]
15 compdef:155> [[ units = *=* ]]
15 compdef:155> [[ unison = *=* ]]
15 compdef:155> [[ unalias = *=* ]]
15 compdef:155> [[ ttyctl = *=* ]]
15 compdef:155> [[ trash-restore = *=* ]]
15 compdef:155> [[ trash-put = *=* ]]
15 compdef:155> [[ tkinfo = *=* ]]
15 compdef:155> [[ tg = *=* ]]
15 compdef:155> [[ tda = *=* ]]
15 compdef:155> [[ svnadmin = *=* ]]
15 compdef:155> [[ svn-buildpackage = *=* ]]
15 compdef:155> [[ svm = *=* ]]
15 compdef:155> [[ subl = *=* ]]
15 compdef:155> [[ strip = *=* ]]
15 compdef:155> [[ stack = *=* ]]
15 compdef:155> [[ srm = *=* ]]
15 compdef:155> [[ sort = *=* ]]
15 compdef:155> [[ slabtop = *=* ]]
15 compdef:155> [[ sfdx = *=* ]]
15 compdef:155> [[ setup.py = *=* ]]
15 compdef:155> [[ setcap = *=* ]]
15 compdef:155> [[ service = *=* ]]
15 compdef:155> [[ script = *=* ]]
15 compdef:155> [[ scalac = *=* ]]
15 compdef:155> [[ scala = *=* ]]
15 compdef:155> [[ sbt = *=* ]]
15 compdef:155> [[ rsvm = *=* ]]
15 compdef:155> [[ rm = *=* ]]
15 compdef:155> [[ rkt = *=* ]]
15 compdef:155> [[ read = *=* ]]
15 compdef:155> [[ rdesktop = *=* ]]
15 compdef:155> [[ pygmentize = *=* ]]
15 compdef:155> [[ putclip = *=* ]]
15 compdef:155> [[ psql = *=* ]]
15 compdef:155> [[ prstat = *=* ]]
15 compdef:155> [[ postconf = *=* ]]
15 compdef:155> [[ port = *=* ]]
15 compdef:155> [[ popd = *=* ]]
15 compdef:155> [[ pkcon = *=* ]]
15 compdef:155> [[ pipenv = *=* ]]
15 compdef:155> [[ phing = *=* ]]
15 compdef:155> [[ perf = *=* ]]
15 compdef:155> [[ opera = *=* ]]
15 compdef:155> [[ openssl = *=* ]]
15 compdef:155> [[ objdump = *=* ]]
15 compdef:155> [[ nvm = *=* ]]
15 compdef:155> [[ ninja = *=* ]]
15 compdef:155> [[ nice = *=* ]]
15 compdef:155> [[ netscape = *=* ]]
15 compdef:155> [[ ncftp = *=* ]]
15 compdef:155> [[ nautilus = *=* ]]
15 compdef:155> [[ mussh = *=* ]]
15 compdef:155> [[ mullvad = *=* ]]
15 compdef:155> [[ moosic = *=* ]]
15 compdef:155> [[ mkshortcut = *=* ]]
15 compdef:155> [[ mkdir = *=* ]]
15 compdef:155> [[ mere = *=* ]]
15 compdef:155> [[ mdadm = *=* ]]
15 compdef:155> [[ mc = *=* ]]
15 compdef:155> [[ lslv = *=* ]]
15 compdef:155> [[ lpr = *=* ]]
15 compdef:155> [[ lp = *=* ]]
15 compdef:155> [[ ln = *=* ]]
15 compdef:155> [[ let = *=* ]]
15 compdef:155> [[ kubectl = *=* ]]
15 compdef:155> [[ ipsec = *=* ]]
15 compdef:155> [[ ipadm = *=* ]]
15 compdef:155> [[ include-what-you-use = *=* ]]
15 compdef:155> [[ iftop = *=* ]]
15 compdef:155> [[ hub = *=* ]]
15 compdef:155> [[ host = *=* ]]
15 compdef:155> [[ homestead = *=* ]]
15 compdef:155> [[ gzip = *=* ]]
15 compdef:155> [[ gv = *=* ]]
15 compdef:155> [[ guilt-files = *=* ]]
15 compdef:155> [[ guilt-delete = *=* ]]
15 compdef:155> [[ guilt = *=* ]]
15 compdef:155> [[ growisofs = *=* ]]
15 compdef:155> [[ grep-excuses = *=* ]]
15 compdef:155> [[ gqview = *=* ]]
15 compdef:155> [[ gnumfmt = *=* ]]
15 compdef:155> [[ git-wtf = *=* ]]
15 compdef:155> [[ gist = *=* ]]
15 compdef:155> [[ ghc = *=* ]]
15 compdef:155> [[ getmail = *=* ]]
15 compdef:155> [[ gdd = *=* ]]
15 compdef:155> [[ gchmod = *=* ]]
15 compdef:155> [[ fmadm = *=* ]]
15 compdef:155> [[ find = *=* ]]
15 compdef:155> [[ fail2ban-client = *=* ]]
15 compdef:155> [[ exportfs = *=* ]]
15 compdef:155> [[ etags = *=* ]]
15 compdef:155> [[ eog = *=* ]]
15 compdef:155> [[ envdir = *=* ]]
15 compdef:155> [[ env = *=* ]]
15 compdef:155> [[ enable = *=* ]]
15 compdef:155> [[ emulator = *=* ]]
15 compdef:155> [[ emulate = *=* ]]
15 compdef:155> [[ ed = *=* ]]
15 compdef:155> [[ echotc = *=* ]]
15 compdef:155> [[ ecdsautil = *=* ]]
15 compdef:155> [[ e2label = *=* ]]
15 compdef:155> [[ dviconcat = *=* ]]
15 compdef:155> [[ dupload = *=* ]]
15 compdef:155> [[ dumper.exe = *=* ]]
15 compdef:155> [[ du = *=* ]]
15 compdef:155> [[ dtruss = *=* ]]
15 compdef:155> [[ drush = *=* ]]
15 compdef:155> [[ dpkg-cross = *=* ]]
15 compdef:155> [[ dpkg-buildpackage = *=* ]]
15 compdef:155> [[ dos2unix = *=* ]]
15 compdef:155> [[ docker-compose = *=* ]]
15 compdef:155> [[ dnf = *=* ]]
15 compdef:155> [[ dmesg = *=* ]]
15 compdef:155> [[ dladm = *=* ]]
15 compdef:155> [[ disable = *=* ]]
15 compdef:155> [[ dirs = *=* ]]
15 compdef:155> [[ dircmp = *=* ]]
15 compdef:155> [[ diff = *=* ]]
15 compdef:155> [[ dict = *=* ]]
15 compdef:155> [[ dcop = *=* ]]
15 compdef:155> [[ dconf = *=* ]]
15 compdef:155> [[ dchroot = *=* ]]
15 compdef:155> [[ date = *=* ]]
15 compdef:155> [[ cygstart = *=* ]]
15 compdef:155> [[ cygrunsrv.exe = *=* ]]
15 compdef:155> [[ cygpath = *=* ]]
15 compdef:155> [[ cvs = *=* ]]
15 compdef:155> [[ cscope = *=* ]]
15 compdef:155> [[ createuser = *=* ]]
15 compdef:155> [[ cppcheck = *=* ]]
15 compdef:155> [[ cowsay = *=* ]]
15 compdef:155> [[ command = *=* ]]
15 compdef:155> [[ comm = *=* ]]
15 compdef:155> [[ column = *=* ]]
15 compdef:155> [[ code = *=* ]]
15 compdef:155> [[ clay = *=* ]]
15 compdef:155> [[ cdbs-edit-patch = *=* ]]
15 compdef:155> [[ cd = *=* ]]
15 compdef:155> [[ ccal = *=* ]]
15 compdef:155> [[ cat = *=* ]]
15 compdef:155> [[ bg = *=* ]]
15 compdef:155> [[ awk = *=* ]]
15 compdef:155> [[ avahi-browse = *=* ]]
15 compdef:155> [[ asciidoctor = *=* ]]
15 compdef:155> [[ apt-show-versions = *=* ]]
15 compdef:155> [[ apachectl = *=* ]]
15 compdef:155> [[ animate = *=* ]]
15 compdef:155> [[ alias = *=* ]]
15 compdef:155> [[ -value-,WWW_HOME,-default- = *=* ]]
15 compdef:155> [[ -value-,GZIP,-default- = *=* ]]
15 compdef:155> [[ -equal- = *=* ]]
15 compdef:155> [[ -command- = *=* ]]
15 compdef:148> [[ '-value-,CGO*,-default-' = (#b)(*)=(*) ]]
15 compdef:148> [[ '-value-,*path,-default-' = (#b)(*)=(*) ]]
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (postpattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (pattern)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:139> case  (*)
15 compdef:137> type=postpattern
15 compdef:137> type=postpattern
15 compdef:137> type=postpattern
15 compdef:137> type=postpattern
15 compdef:136> [[ zypper = -P ]]
15 compdef:136> [[ yt-dlp = -P ]]
15 compdef:136> [[ xinput = -P ]]
15 compdef:136> [[ xdvi = -P ]]
15 compdef:136> [[ urxvt256c-mlc = -P ]]
15 compdef:136> [[ uml_switch = -P ]]
15 compdef:136> [[ tunctl = -P ]]
15 compdef:136> [[ trash-list = -P ]]
15 compdef:136> [[ trash-empty = -P ]]
15 compdef:136> [[ tox = -P ]]
15 compdef:136> [[ smbclient = -P ]]
15 compdef:136> [[ putclip = -P ]]
15 compdef:136> [[ mpv = -P ]]
15 compdef:136> [[ ksh93 = -P ]]
15 compdef:136> [[ gsha384sum = -P ]]
15 compdef:136> [[ gsettings = -P ]]
15 compdef:136> [[ gdate = -P ]]
15 compdef:136> [[ force = -P ]]
15 compdef:136> [[ ethtool = -P ]]
15 compdef:136> [[ dvips = -P ]]
15 compdef:136> [[ dumper = -P ]]
15 compdef:136> [[ dput = -P ]]
15 compdef:136> [[ debuild = -P ]]
15 compdef:136> [[ debcheckout = -P ]]
15 compdef:136> [[ debchange = -P ]]
15 compdef:136> [[ dcut = -P ]]
15 compdef:136> [[ darcs = -P ]]
15 compdef:136> [[ d = -P ]]
15 compdef:136> [[ chrt = -P ]]
15 compdef:136> [[ chown = -P ]]
15 compdef:136> [[ chflags = -P ]]
15 compdef:136> [[ chattr = -P ]]
15 compdef:136> [[ caffeinate = -P ]]
15 compdef:136> [[ cabal = -P ]]
15 compdef:136> [[ bzr = -P ]]
15 compdef:136> [[ a2ps = -P ]]
15 compdef:136> [[ _restic = -P ]]
15 compdef:136> [[ -value-,TERMINFO_DIRS,-default- = -P ]]
15 compdef:136> [[ -math- = -P ]]
15 compdef:136> [[ -default- = -P ]]
15 compdef:136> [[ 'ggfl=git-checkout' = -P ]]
15 compdef:136> [[ 'gdv=git-diff' = -P ]]
15 compdef:136> [[ 'gdnolock=git-diff' = -P ]]
15 compdef:136> [[ 'gchown=chown' = -P ]]
15 compdef:136> [[ 'gccd=git-clone' = -P ]]
15 compdef:134> [[ zypper = -p ]]
15 compdef:134> [[ zstyle = -p ]]
15 compdef:134> [[ zmail = -p ]]
15 compdef:134> [[ yt-dlp = -p ]]
15 compdef:134> [[ xxd = -p ]]
15 compdef:134> [[ xmllint = -p ]]
15 compdef:134> [[ xdvi = -p ]]
15 compdef:134> [[ vagrant = -p ]]
15 compdef:134> [[ trash-empty = -p ]]
15 compdef:134> [[ tpb = -p ]]
15 compdef:134> [[ tox = -p ]]
15 compdef:134> [[ tmuxp = -p ]]
15 compdef:134> [[ sysrc = -p ]]
15 compdef:134> [[ snap = -p ]]
15 compdef:134> [[ showoff = -p ]]
15 compdef:134> [[ rubocop = -p ]]
15 compdef:134> [[ readshortcut = -p ]]
15 compdef:134> [[ ralio = -p ]]
15 compdef:134> [[ pstoedit = -p ]]
15 compdef:134> [[ protoc = -p ]]
15 compdef:134> [[ mpv = -p ]]
15 compdef:134> [[ mkisofs = -p ]]
15 compdef:134> [[ meson = -p ]]
15 compdef:134> [[ heroku = -p ]]
15 compdef:134> [[ gtk-launch = -p ]]
15 compdef:134> [[ glance = -p ]]
15 compdef:134> [[ evince = -p ]]
15 compdef:134> [[ entr = -p ]]
15 compdef:134> [[ dvips = -p ]]
15 compdef:134> [[ dumper = -p ]]
15 compdef:134> [[ dumpadm = -p ]]
15 compdef:134> [[ dsh = -p ]]
15 compdef:134> [[ drill = -p ]]
15 compdef:134> [[ dput = -p ]]
15 compdef:134> [[ dpkg-deb = -p ]]
15 compdef:134> [[ debuild = -p ]]
15 compdef:134> [[ debsign = -p ]]
15 compdef:134> [[ deborphan = -p ]]
15 compdef:134> [[ debfoster = -p ]]
15 compdef:134> [[ dd = -p ]]
15 compdef:134> [[ dcut = -p ]]
15 compdef:134> [[ cpupower = -p ]]
15 compdef:134> [[ compress = -p ]]
15 compdef:134> [[ cksum = -p ]]
15 compdef:134> [[ chrt = -p ]]
15 compdef:134> [[ chmod = -p ]]
15 compdef:134> [[ chcon = -p ]]
15 compdef:134> [[ chattr = -p ]]
15 compdef:134> [[ cdrecord = -p ]]
15 compdef:134> [[ cdcd = -p ]]
15 compdef:134> [[ caffeinate = -p ]]
15 compdef:134> [[ -default- = -p ]]
15 compdef:134> [[ 'dch=debchange' = -p ]]
15 compdef:132> [[ xrandr = -N ]]
15 compdef:132> [[ xmllint = -N ]]
15 compdef:132> [[ whois = -N ]]
15 compdef:132> [[ vmctl = -N ]]
15 compdef:132> [[ visudo = -N ]]
15 compdef:132> [[ vcsh = -N ]]
15 compdef:132> [[ useradd = -N ]]
15 compdef:132> [[ unlimit = -N ]]
15 compdef:132> [[ ulimit = -N ]]
15 compdef:132> [[ tune2fs = -N ]]
15 compdef:132> [[ truss = -N ]]
15 compdef:132> [[ true = -N ]]
15 compdef:132> [[ trap = -N ]]
15 compdef:132> [[ tex = -N ]]
15 compdef:132> [[ tee = -N ]]
15 compdef:132> [[ tac = -N ]]
15 compdef:132> [[ sysrc = -N ]]
15 compdef:132> [[ svcprop = -N ]]
15 compdef:132> [[ subl = -N ]]
15 compdef:132> [[ strace = -N ]]
15 compdef:132> [[ stat = -N ]]
15 compdef:132> [[ ssh = -N ]]
15 compdef:132> [[ socket = -N ]]
15 compdef:132> [[ slrn = -N ]]
15 compdef:132> [[ slabtop = -N ]]
15 compdef:132> [[ shuf = -N ]]
15 compdef:132> [[ shift = -N ]]
15 compdef:132> [[ setopt = -N ]]
15 compdef:132> [[ scselect = -N ]]
15 compdef:132> [[ sbuild = -N ]]
15 compdef:132> [[ rubber = -N ]]
15 compdef:132> [[ rlogin = -N ]]
15 compdef:132> [[ reprepro = -N ]]
15 compdef:132> [[ renice = -N ]]
15 compdef:132> [[ readelf = -N ]]
15 compdef:132> [[ rar = -N ]]
15 compdef:132> [[ qtplay = -N ]]
15 compdef:132> [[ pwgen = -N ]]
15 compdef:132> [[ putclip = -N ]]
15 compdef:132> [[ ps = -N ]]
15 compdef:132> [[ prompt = -N ]]
15 compdef:132> [[ plutil = -N ]]
15 compdef:132> [[ pkgadd = -N ]]
15 compdef:132> [[ pine = -N ]]
15 compdef:132> [[ pidof = -N ]]
15 compdef:132> [[ pflags = -N ]]
15 compdef:132> [[ paste = -N ]]
15 compdef:132> [[ pack = -N ]]
15 compdef:132> [[ otool = -N ]]
15 compdef:132> [[ osc = -N ]]
15 compdef:132> [[ opkg = -N ]]
15 compdef:132> [[ oggenc = -N ]]
15 compdef:132> [[ mv = -N ]]
15 compdef:132> [[ linux = -N ]]
15 compdef:132> [[ lha = -N ]]
15 compdef:132> [[ jonas = -N ]]
15 compdef:132> [[ join = -N ]]
15 compdef:132> [[ ipsec = -N ]]
15 compdef:132> [[ iostat = -N ]]
15 compdef:132> [[ infocmp = -N ]]
15 compdef:132> [[ inetadm = -N ]]
15 compdef:132> [[ http = -N ]]
15 compdef:132> [[ htop = -N ]]
15 compdef:132> [[ hexdump = -N ]]
15 compdef:132> [[ head = -N ]]
15 compdef:132> [[ guilt-init = -N ]]
15 compdef:132> [[ guilt-help = -N ]]
15 compdef:132> [[ guilt-delete = -N ]]
15 compdef:132> [[ growisofs = -N ]]
15 compdef:132> [[ getconf = -N ]]
15 compdef:132> [[ gdb = -N ]]
15 compdef:132> [[ gas = -N ]]
15 compdef:132> [[ fw_update = -N ]]
15 compdef:132> [[ fink = -N ]]
15 compdef:132> [[ fab = -N ]]
15 compdef:132> [[ dumper.exe = -N ]]
15 compdef:132> [[ cp = -N ]]
15 compdef:132> [[ chpass = -N ]]
15 compdef:132> [[ ccache = -N ]]
15 compdef:132> [[ cask = -N ]]
15 compdef:132> [[ cap = -N ]]
15 compdef:132> [[ bzip2 = -N ]]
15 compdef:132> [[ bower = -N ]]
15 compdef:132> [[ bogofilter = -N ]]
15 compdef:132> [[ bindkey = -N ]]
15 compdef:132> [[ base64 = -N ]]
15 compdef:132> [[ augtool = -N ]]
15 compdef:132> [[ SuSEconfig = -N ]]
15 compdef:132> [[ -value-,XML_CATALOG_FILES,-default- = -N ]]
15 compdef:132> [[ 'gchown=chown' = -N ]]
15 compdef:132> [[ 'dch=debchange' = -N ]]
15 compdef:131> ((  15  ))
15 compdef:131> ((  2  ))
15 compdef:131> ((  2  ))
15 compdef:131> ((  2  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:131> ((  1  ))
15 compdef:104> [[ 2 -lt 2 ]]
15 compdef:91> 2=.list-choices
15 compdef:91> 2=.complete-word
15 compdef:90> [[ _list_expansions = _* ]]
15 compdef:86> [[ 6 -lt 3 ]]
15 compdef:83> case widgetkey (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (widgetkey)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (key)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:83> case  (*)
15 compdef:81> shift
15 compdef:81> shift
15 compdef:81> shift
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:80> [[ -n yes ]]
15 compdef:79> func=_xinput
15 compdef:79> func=_xargs
15 compdef:79> func=_vnstat
15 compdef:79> func=_twisted
15 compdef:79> func=_trash-empty
15 compdef:79> func=_ralio
15 compdef:79> func=_quilt
15 compdef:79> func=_pon
15 compdef:79> func=_openstack
15 compdef:79> func=_next_tags
15 compdef:79> func=_meson
15 compdef:79> func=_initctl
15 compdef:79> func=_growisofs
15 compdef:79> func=_expand_alias
15 compdef:79> func=_exec
15 compdef:79> func=_evince
15 compdef:79> func=_ethtool
15 compdef:79> func=_equal
15 compdef:79> func=_entr
15 compdef:79> func=_enscript
15 compdef:79> func=_ed
15 compdef:79> func=_dumper
15 compdef:79> func=_dumpadm
15 compdef:79> func=_doas
15 compdef:79> func=_disable
15 compdef:79> func=_directory_stack
15 compdef:79> func=_dhcpinfo
15 compdef:79> func=_devtodo
15 compdef:79> func=_defaults
15 compdef:79> func=_debuild
15 compdef:79> func=_debcheckout
15 compdef:79> func=_dd
15 compdef:79> func=_cksum
15 compdef:79> func=_chsh
15 compdef:79> func=_chmod
15 compdef:79> func=_cal
15 compdef:49> [[ _ztodo = *=* ]]
15 compdef:49> [[ _zoneadm = *=* ]]
15 compdef:49> [[ _zip = *=* ]]
15 compdef:49> [[ _zed = *=* ]]
15 compdef:49> [[ _zeal = *=* ]]
15 compdef:49> [[ _zargs = *=* ]]
15 compdef:49> [[ _xset = *=* ]]
15 compdef:49> [[ _xscreensaver = *=* ]]
15 compdef:49> [[ _xpdf = *=* ]]
15 compdef:49> [[ _xournal = *=* ]]
15 compdef:49> [[ _xft_fonts = *=* ]]
15 compdef:49> [[ _wpa_cli = *=* ]]
15 compdef:49> [[ _whois = *=* ]]
15 compdef:49> [[ _which = *=* ]]
15 compdef:49> [[ _whereis = *=* ]]
15 compdef:49> [[ _webbrowser = *=* ]]
15 compdef:49> [[ _watch = *=* ]]
15 compdef:49> [[ _wanna-build = *=* ]]
15 compdef:49> [[ _wajig = *=* ]]
15 compdef:49> [[ _w = *=* ]]
15 compdef:49> [[ _vorbis = *=* ]]
15 compdef:49> [[ _vim = *=* ]]
15 compdef:49> [[ _valgrind = *=* ]]
15 compdef:49> [[ _uscan = *=* ]]
15 compdef:49> [[ _urxvt = *=* ]]
15 compdef:49> [[ _update-rc.d = *=* ]]
15 compdef:49> [[ _uniq = *=* ]]
15 compdef:49> [[ _topgit = *=* ]]
15 compdef:49> [[ _tin = *=* ]]
15 compdef:49> [[ _tcptraceroute = *=* ]]
15 compdef:49> [[ _tcpsys = *=* ]]
15 compdef:49> [[ _sw_vers = *=* ]]
15 compdef:49> [[ _svm = *=* ]]
15 compdef:49> [[ _subscript = *=* ]]
15 compdef:49> [[ _stack = *=* ]]
15 compdef:49> [[ _srm = *=* ]]
15 compdef:49> [[ _sqsh = *=* ]]
15 compdef:49> [[ _sqlite = *=* ]]
15 compdef:49> [[ _softwareupdate = *=* ]]
15 compdef:49> [[ _setcap = *=* ]]
15 compdef:49> [[ _scutil = *=* ]]
15 compdef:49> [[ _script = *=* ]]
15 compdef:49> [[ _sched = *=* ]]
15 compdef:49> [[ _samba = *=* ]]
15 compdef:49> [[ _rslsync = *=* ]]
15 compdef:49> [[ _ri = *=* ]]
15 compdef:49> [[ _reprepro = *=* ]]
15 compdef:49> [[ _redirect = *=* ]]
15 compdef:49> [[ _read = *=* ]]
15 compdef:49> [[ _qdbus = *=* ]]
15 compdef:49> [[ _psutils = *=* ]]
15 compdef:49> [[ _print = *=* ]]
15 compdef:49> [[ _powerd = *=* ]]
15 compdef:49> [[ _portlint = *=* ]]
15 compdef:49> [[ _portaudit = *=* ]]
15 compdef:49> [[ _pixz = *=* ]]
15 compdef:49> [[ _pipenv = *=* ]]
15 compdef:49> [[ _picocom = *=* ]]
15 compdef:49> [[ _pgsql_utils = *=* ]]
15 compdef:49> [[ _pgrep = *=* ]]
15 compdef:49> [[ _perl_modules = *=* ]]
15 compdef:49> [[ _perforce = *=* ]]
15 compdef:49> [[ _perf = *=* ]]
15 compdef:49> [[ _opkg = *=* ]]
15 compdef:49> [[ _omz = *=* ]]
15 compdef:49> [[ _objdump = *=* ]]
15 compdef:49> [[ _nvram = *=* ]]
15 compdef:49> [[ _nvm = *=* ]]
15 compdef:49> [[ _nice = *=* ]]
15 compdef:49> [[ _networksetup = *=* ]]
15 compdef:49> [[ _netscape = *=* ]]
15 compdef:49> [[ _net_interfaces = *=* ]]
15 compdef:49> [[ _ncftp = *=* ]]
15 compdef:49> [[ _nano = *=* ]]
15 compdef:49> [[ _mysqldiff = *=* ]]
15 compdef:49> [[ _mussh = *=* ]]
15 compdef:49> [[ _mupdf = *=* ]]
15 compdef:49> [[ _mtools = *=* ]]
15 compdef:49> [[ _mktemp = *=* ]]
15 compdef:49> [[ _mkdir = *=* ]]
15 compdef:49> [[ _mixerctl = *=* ]]
15 compdef:49> [[ _mere = *=* ]]
15 compdef:49> [[ _mencal = *=* ]]
15 compdef:49> [[ _mdls = *=* ]]
15 compdef:49> [[ _make = *=* ]]
15 compdef:49> [[ _lynx = *=* ]]
15 compdef:49> [[ _lua = *=* ]]
15 compdef:49> [[ _lspv = *=* ]]
15 compdef:49> [[ _lslv = *=* ]]
15 compdef:49> [[ _lsdev = *=* ]]
15 compdef:49> [[ _lsblk = *=* ]]
15 compdef:49> [[ _losetup = *=* ]]
15 compdef:49> [[ _look = *=* ]]
15 compdef:49> [[ _locale = *=* ]]
15 compdef:49> [[ _ln = *=* ]]
15 compdef:49> [[ _limit = *=* ]]
15 compdef:49> [[ _ldap = *=* ]]
15 compdef:49> [[ _ld_debug = *=* ]]
15 compdef:49> [[ _kpartx = *=* ]]
15 compdef:49> [[ _kitchen = *=* ]]
15 compdef:49> [[ _kill = *=* ]]
15 compdef:49> [[ _kdeconnect = *=* ]]
15 compdef:49> [[ _joe = *=* ]]
15 compdef:49> [[ _jmeter-plugins = *=* ]]
15 compdef:49> [[ _jls = *=* ]]
15 compdef:49> [[ _jail = *=* ]]
15 compdef:49> [[ _ipsec = *=* ]]
15 compdef:49> [[ _ip = *=* ]]
15 compdef:49> [[ _initctl = *=* ]]
15 compdef:49> [[ _include-what-you-use = *=* ]]
15 compdef:49> [[ _imagemagick = *=* ]]
15 compdef:49> [[ _ifconfig = *=* ]]
15 compdef:49> [[ _iconvconfig = *=* ]]
15 compdef:49> [[ _hostname = *=* ]]
15 compdef:49> [[ _host = *=* ]]
15 compdef:49> [[ _gv = *=* ]]
15 compdef:49> [[ _groff = *=* ]]
15 compdef:49> [[ _grep-excuses = *=* ]]
15 compdef:49> [[ _graphicsmagick = *=* ]]
15 compdef:49> [[ _gphoto2 = *=* ]]
15 compdef:49> [[ _gpg = *=* ]]
15 compdef:49> [[ _git-wtf = *=* ]]
15 compdef:49> [[ _git-flow = *=* ]]
15 compdef:49> [[ _git = *=* ]]
15 compdef:49> [[ _git = *=* ]]
15 compdef:49> [[ _getfacl = *=* ]]
15 compdef:49> [[ _getent = *=* ]]
15 compdef:49> [[ _getconf = *=* ]]
15 compdef:49> [[ _getclip = *=* ]]
15 compdef:49> [[ _geany = *=* ]]
15 compdef:49> [[ _gcc = *=* ]]
15 compdef:49> [[ _fusermount = *=* ]]
15 compdef:49> [[ _fuser = *=* ]]
15 compdef:49> [[ _functions = *=* ]]
15 compdef:49> [[ _freebsd-update = *=* ]]
15 compdef:49> [[ _finger = *=* ]]
15 compdef:49> [[ _fc = *=* ]]
15 compdef:49> [[ _fakeroot = *=* ]]
15 compdef:49> [[ _fail2ban-client = *=* ]]
15 compdef:49> [[ _equal = *=* ]]
15 compdef:49> [[ _emulator = *=* ]]
15 compdef:49> [[ _echoti = *=* ]]
15 compdef:49> [[ _echotc = *=* ]]
15 compdef:49> [[ _du = *=* ]]
15 compdef:49> [[ _docker_compose = *=* ]]
15 compdef:49> [[ _dnf = *=* ]]
15 compdef:49> [[ _dirs = *=* ]]
15 compdef:49> [[ _diana = *=* ]]
15 compdef:49> [[ _dhcpcd = *=* ]]
15 compdef:49> [[ _dget = *=* ]]
15 compdef:49> [[ _date = *=* ]]
15 compdef:49> [[ _dad = *=* ]]
15 compdef:49> [[ _cryptsetup = *=* ]]
15 compdef:49> [[ _cppcheck = *=* ]]
15 compdef:49> [[ _correct_word = *=* ]]
15 compdef:49> [[ _composer = *=* ]]
15 compdef:49> [[ _complete_tag = *=* ]]
15 compdef:49> [[ _complete_help = *=* ]]
15 compdef:49> [[ _cmake = *=* ]]
15 compdef:49> [[ _clay = *=* ]]
15 compdef:49> [[ _cheat = *=* ]]
15 compdef:49> [[ _calendar = *=* ]]
15 compdef:49> [[ _bsdinstall = *=* ]]
15 compdef:49> [[ _bsd_pkg = *=* ]]
15 compdef:49> [[ _brew_services = *=* ]]
15 compdef:49> [[ _brace_parameter = *=* ]]
15 compdef:49> [[ _bogofilter = *=* ]]
15 compdef:49> [[ _bitcoin-cli = *=* ]]
15 compdef:49> [[ _bindkey = *=* ]]
15 compdef:49> [[ _beep = *=* ]]
15 compdef:49> [[ _bash = *=* ]]
15 compdef:49> [[ _basename = *=* ]]
15 compdef:49> [[ _awk = *=* ]]
15 compdef:49> [[ _arp = *=* ]]
15 compdef:49> [[ _aptitude = *=* ]]
15 compdef:49> [[ _apachectl = *=* ]]
15 compdef:49> [[ _ant = *=* ]]
15 compdef:49> [[ _ansible = *=* ]]
15 compdef:49> [[ _android = *=* ]]
15 compdef:49> [[ _analyseplugin = *=* ]]
15 compdef:49> [[ _alsa-utils = *=* ]]
15 compdef:49> [[ _adb = *=* ]]
15 compdef:49> [[ _acpitool = *=* ]]
15 compdef:49> [[ _abcde = *=* ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:49> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:45> [[ -z '' ]]
15 compdef:40> ((  ! 26  ))
15 compdef:40> ((  ! 7  ))
15 compdef:40> ((  ! 6  ))
15 compdef:40> ((  ! 5  ))
15 compdef:40> ((  ! 5  ))
15 compdef:40> ((  ! 5  ))
15 compdef:40> ((  ! 5  ))
15 compdef:40> ((  ! 4  ))
15 compdef:40> ((  ! 4  ))
15 compdef:40> ((  ! 4  ))
15 compdef:40> ((  ! 4  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 3  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:40> ((  ! 2  ))
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:38> shift OPTIND-1
15 compdef:31> type=key
15 compdef:27> type=postpattern
15 compdef:27> type=postpattern
15 compdef:18> [[ -n '' ]]
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:17> new=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:16> autol=yes
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (n)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case n (a)
15 compdef:15> case k ([pPkK])
15 compdef:15> case a (a)
15 compdef:15> case a (a)
15 compdef:15> case a (a)
15 compdef:15> case a (a)
15 compdef:15> case a (a)
15 compdef:15> case a (a)
15 compdef:15> case P ([pPkK])
15 compdef:15> case P ([pPkK])
15 compdef:15> case P ([pPkK])
15 compdef:15> case P ([pPkK])
15 compdef:15> case P ([pPkK])
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compdef:14> getopts anpPkKde opt
15 compaudit:157> _i_q=''
15 compaudit:132> ((  0  ))
15 compaudit:102> [[ -e /proc/87947/exe ]]
15 compaudit:53> [[ -z /usr/share/zsh/5.8.1/functions ]]
15 compaudit:40> ((  1  ))
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;47m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;47m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;46m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;46m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;42m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;42m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;41m'
15 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;40m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;49m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;49m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;46m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;45m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;45m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;44m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;43m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;40m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;40m'
15 colors:115> bg_bold[${k#bg-}]=$'C-[[01;40m'
15 colors:114> bg[${k#bg-}]=$'C-[[47m'
15 colors:114> bg[${k#bg-}]=$'C-[[43m'
15 colors:114> bg[${k#bg-}]=$'C-[[42m'
15 colors:114> bg[${k#bg-}]=$'C-[[41m'
15 colors:114> bg[${k#bg-}]=$'C-[[40m'
15 colors:114> bg[${k#bg-}]=$'C-[[40m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;39m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;39m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;34m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;33m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;32m'
15 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;30m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;39m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;36m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;36m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;35m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;32m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;30m'
15 colors:106> fg_bold[${k#fg-}]=$'C-[[01;30m'
15 colors:105> fg[${k#fg-}]=$'C-[[39m'
15 colors:105> fg[${k#fg-}]=$'C-[[37m'
15 colors:105> fg[${k#fg-}]=$'C-[[36m'
15 colors:105> fg[${k#fg-}]=$'C-[[33m'
15 colors:105> fg[${k#fg-}]=$'C-[[32m'
15 colors:105> fg[${k#fg-}]=$'C-[[30m'
15 colors:81> color[fg-${color[$k]}]=36
15 colors:77> color[${color[$k]}]=44
15 colors:77> color[${color[$k]}]=33
15 antigen-remove-hook:10> _ANTIGEN_HOOKS[${target}]=''
15 antigen-remove-hook:4> local -a hooks
15 antigen-remove-hook:4> local -a hooks
15 antigen-remove-hook:4> local -a hooks
15 antigen-remove-hook:2> typeset -A meta
15 antigen-remove-hook:2> typeset -A meta
15 antigen-bundle-parallel-execute:10> args=deno
15 antigen-bundle-parallel-execute:10> args=--loc=lib
15 antigen-bundle-parallel-execute:2> pids=( )
15 antigen-add-hook:14> _ANTIGEN_HOOKS[$target]=-antigen-load-source-cached
15 antigen-add-hook:13> [[ antigen-bundle-defer ==  ]]
15 antigen-add-hook:13> [[ '' ==  ]]
15 antigen-add-hook:13> [[ '' ==  ]]
15 antigen-add-hook:3> ((  ! 1  ))
15 add-zsh-hook:55> shift 0
15 add-zsh-hook:55> shift 0
15 add-zsh-hook:55> shift 0
15 add-zsh-hook:55> shift 0
15 add-zle-hook-widget:178> case file shfunc shfunc shfunc shfunc shfunc shfunc ...
15 add-zle-hook-widget:40> 1=line-finish
15 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
15 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
15 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
15 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
15 _zsh_highlight_bind_widgets:27> case builtin (user:*)
15 _zsh_highlight_bind_widgets:27> case builtin (builtin)
15 _zsh_highlight_bind_widgets:27> case builtin (builtin)
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-replace-chars
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-repeat-change
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-pound-insert
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-history-search-backward
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-forward-char
15 _zsh_highlight_bind_widgets:26> cur_widget=vi-change-eol
15 _zsh_highlight_bind_widgets:26> cur_widget=up-history
15 _zsh_highlight_bind_widgets:26> cur_widget=menu-select
15 _zsh_highlight_bind_widgets:26> cur_widget=history-incremental-search-backward
15 _zsh_highlight_bind_widgets:26> cur_widget=history-incremental-pattern-search...
15 _zsh_highlight_bind_widgets:26> cur_widget=describe-key-briefly
15 _zsh_highlight_bind_widgets:26> cur_widget=beginning-of-history
15 _zsh_highlight_bind_widgets:26> cur_widget=_expand_word
15 _zsh_highlight_bind_widgets:26> cur_widget=_complete_tag
15 /usr/local/share/antigen/antigen.zsh:1401> typeset -g _ANTIGEN_EXTENSIONS
15 /usr/local/share/antigen/antigen.zsh:49> [[ -z '' ]]
15 /usr/local/opt/asdf/libexec/asdf.sh:7> [ -n '' ']'
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:155> plugin=zshfl
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:74> [[ -z '' ]]
15 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:46> [[ -z '' ]]
15 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:57> ZSH_THEME_GIT_PROMPT_...
15 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:55> ZSH_THEME_GIT_PROMPT_...
15 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:15> [[ darwin21.0 == open...
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;206m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;155m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;104m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;000m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;232m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;175m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;079m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;027m%}'
15 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;001m%}'
15 /Users/matt/.oh-my-zsh/lib/key-bindings.zsh:36> autoload -U up-line-or-beginn...
15 /Users/matt/.oh-my-zsh/lib/history.zsh:31> [ 2000 -lt 50000 ']'
15 /Users/matt/.oh-my-zsh/lib/directories.zsh:15> alias '4=cd -4'
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:6> [[ -e /Us...
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:21> case  ()
15 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/completion.zsh:20> [[...
15 -antigen-parse-args:155> [[ -n '' ]]
15 -antigen-parse-args:154> args[url]=''https://github.com/zsh-users/zsh-syntax-...
15 -antigen-parse-args:154> args[url]=''https://github.com/robbyrussell/oh-my-zs...
15 -antigen-parse-args:130> args[name]=robbyrussell/oh-my-zsh
15 -antigen-parse-args:124> name=zsh-users/zsh-autosuggestions
15 -antigen-parse-args:124> name=zsh-users/zsh-autosuggestions
15 -antigen-parse-args:124> name=robbyrussell/oh-my-zsh
15 -antigen-parse-args:124> name=robbyrussell/oh-my-zsh
15 -antigen-parse-args:122> name=robbyrussell/oh-my-zsh.git
15 -antigen-parse-args:118> local branch=''
15 -antigen-parse-args:118> local branch=''
15 -antigen-parse-args:118> local branch=''
15 -antigen-parse-args:118> local branch=''
15 -antigen-parse-args:99> [[ https://github.com/robbyrussell/oh-my-zsh.git == /...
15 -antigen-parse-args:96> args[url]=https://github.com/zsh-users/zsh-syntax-hig...
15 -antigen-parse-args:96> args[url]=https://github.com/zsh-users/zsh-autosugges...
15 -antigen-parse-args:96> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
15 -antigen-parse-args:94> url=https://github.com/zsh-users/zsh-autosuggestions.git
15 -antigen-parse-args:94> url=https://github.com/zsh-users/zsh-autosuggestions.git
15 -antigen-parse-args:69> [[ deno != */* ]]
15 -antigen-parse-args:60> let 'index+=1'
15 -antigen-parse-args:60> let 'index+=1'
15 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
15 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
15 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
15 -antigen-parse-args:51> [[ "$url_path" -regex-match '@' ]]
15 -antigen-parse-args:42> local url_path=deno
15 -antigen-parse-args:42> local url_path=deno
15 -antigen-parse-args:40> key=url
15 -antigen-parse-args:40> key=url
15 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--url | --loc...
15 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (*)
15 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (*)
15 -antigen-parse-args:20> value=zsh-users/zsh-autosuggestions
15 -antigen-parse-args:20> value=lib
15 -antigen-parse-args:18> argkey=zsh-users/zsh-autosuggestions
15 -antigen-parse-args:18> argkey=--loc
15 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
15 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
15 -antigen-parse-args:10> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
15 -antigen-parse-args:9> typeset -A args
15 -antigen-parse-args:9> typeset -A args
15 -antigen-parse-args:9> typeset -A args
15 -antigen-load:20> [[ 0 == 0 ]]
15 -antigen-load:2> typeset -A bundle
15 -antigen-load:2> typeset -A bundle
15 -antigen-load:2> typeset -A bundle
15 -antigen-load-env-cached:2> typeset -A bundle
15 -antigen-hook-handler:30> post_hooks+=( antigen-apply-lock )
15 -antigen-hook-handler:27> replace_hooks+=( antigen-apply-parallel-execute )
15 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
15 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
15 -antigen-hook-handler:24> pre_hooks+=( antigen-bundle-cached )
15 -antigen-hook-handler:24> pre_hooks+=( antigen-apply-parallel )
15 -antigen-hook-handler:24> pre_hooks+=( antigen-apply-defer )
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case replace (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:22> case pre (pre)
15 -antigen-hook-handler:17> let 'called=8+1'
15 -antigen-hook-handler:17> let 'called=4+1'
15 -antigen-hook-handler:17> let 'called=0+1'
15 -antigen-hook-handler:10> hook=-antigen-load-env-cached
15 -antigen-hook-handler:9> typeset -A meta
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-handler:7> typeset -a hooks
15 -antigen-hook-antigen:7> shift
15 -antigen-hook-antigen:7> shift
15 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
15 (eval):229> alias 'ls=ls -G'
15 (eval):228> alias 'll=ls -lh'
15 (eval):226> alias 'l=ls -lah'
15 (eval):209> alias 'gwch=git whatchanged -p --abbrev-commit --pretty=medium'
15 (eval):200> alias 'gtl=gtl(){ git tag --sort=-v:refname -n -l "${1}*" }; nogl...
15 (eval):195> alias 'md=mkdir -p'
15 (eval):193> alias 'ls=ls -G'
15 (eval):189> alias 'gstd=git stash drop'
15 (eval):188> alias 'gstc=git stash clear'
15 (eval):182> alias 'gunwip=git log -n 1 | grep -q -c "--wip--" && git reset HE...
15 (eval):179> alias 'gsh=git show'
15 (eval):177> alias 'gswm=git switch $(git_main_branch)'
15 (eval):174> alias 'gru=git reset --'
15 (eval):172> alias 'gstu=gsta --include-untracked'
15 (eval):161> alias 'grev=git revert'
15 (eval):159> alias 'gsi=git submodule init'
15 (eval):156> alias 'grbm=git rebase $(git_main_branch)'
15 (eval):152> alias 'grt=cd "$(git rev-parse --show-toplevel || echo .)"'
15 (eval):152> alias 'grba=git rebase --abort'
15 (eval):146> alias 'gpsup=git push --set-upstream origin $(git_current_branch)'
15 (eval):140> alias 'grev=git revert'
15 (eval):138> alias 'grbs=git rebase --skip'
15 (eval):137> alias 'grbom=git rebase origin/$(git_main_branch)'
15 (eval):136> alias 'grbo=git rebase --onto'
15 (eval):136> alias 'gmtlvim=git mergetool --no-prompt --tool=vimdiff'
15 (eval):135> alias 'gmtl=git mergetool --no-prompt'
15 (eval):134> alias 'gmom=git merge origin/$(git_main_branch)'
15 (eval):127> alias 'gpv=git push -v'
15 (eval):125> alias 'gpsup=git push --set-upstream origin $(git_current_branch)'
15 (eval):115> alias 'gmtl=git mergetool --no-prompt'
15 (eval):113> alias 'gk=gitk --all --branches &!'
15 (eval):108> alias 'ggsup=git branch --set-upstream-to=origin/$(git_current_br...
15 (eval):98> alias 'gdw=git diff --word-diff'
15 (eval):92> alias 'gignored=git ls-files -v | grep "^[[:lower:]]"'
15 (eval):89> alias 'ggsup=git branch --set-upstream-to=origin/$(git_current_bra...
15 (eval):89> alias 'gcss=git commit -S -s'
15 (eval):85> alias 'gcpa=git cherry-pick --abort'
15 (eval):82> alias 'gfg=git ls-files | grep'
15 (eval):74> alias 'gdct=git describe --tags $(git rev-list --tags --max-count=1)'
15 (eval):72> alias 'gcasm=git commit -a -s -m'
15 (eval):71> alias 'gcas=git commit -a -s'
15 (eval):69> alias 'gcsm=git commit -s -m'
15 (eval):67> alias 'gca!=git commit -v -a --amend'
15 (eval):62> alias 'gbsr=git bisect reset'
15 (eval):57> alias 'gbnm=git branch --no-merged'
15 (eval):49> alias 'gau=git add --update'
15 (eval):46> alias 'gc!=git commit -v --amend'
15 (eval):37> alias 'gbl=git blame -b -w'
15 (eval):33> alias 'gbD=git branch -D'
15 (eval):28> alias 'gapa=git add --patch'
15 (eval):18> alias 'fgrep=fgrep --color=auto --exclude-dir={.bzr,CVS,.git,.hg,....
15 (eval):8> alias '3=cd -3'
15 (eval):6> alias '1=cd -1'
15 (eval):5> alias -g '......=../../../../..'
15 (eval):2> alias -g '...=../..'
15 (eval):1> test -z ''
15 (eval):1> test -z ''
15 (eval):1> test -z ''
15 (eval):1> test -z ''
15 (eval):1> test -z ''
15 (eval):1> test -z ''
15 (anon):32> action=toggle
15 (anon):32> action=fetch
15 (anon):32> action=execute
15 (anon):32> action=disable
15 (anon):2> action=toggle
15 (anon):2> action=disable
14 is-at-least:53> ((  part > min_ver[min_cnt]  ))
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> break
14 is-at-least:50> [[ 8 = <-> ]]
14 is-at-least:50> [[ 5 = <-> ]]
14 is-at-least:50> [[ 1 = <-> ]]
14 is-at-least:50> [[ 1 = <-> ]]
14 is-at-least:50> [[ 0 = <-> ]]
14 is-at-least:50> [[ 0 = <-> ]]
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:48> true
14 is-at-least:45> part=36
14 is-at-least:45> part=8
14 is-at-least:45> part=8
14 is-at-least:33> [[ 36 = *[0-9][^0-9]* ]]
14 is-at-least:32> ((  ++ver_cnt > 4  ))
14 is-at-least:32> ((  ++ver_cnt > 4  ))
14 is-at-least:32> ((  ++ver_cnt > 4  ))
14 is-at-least:30> ((  0 <= 2  ))
14 group_lazy_load:4> cmd=npm
14 group_lazy_load:4> cmd=lssitepackages
14 detect-clipboard:3> ((  1  ))
14 compinit:530> _i_line=menu-expand-or-complete
14 compinit:530> _i_line=menu-complete
14 compinit:530> _i_line=menu-complete
14 compinit:530> _i_line=list-choices
14 compinit:530> _i_line=expand-or-complete
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:516> [[ '' !=  # ]]
14 compinit:515> autoload -Uz _tags
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #compdef (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:506> case #autoload (#compdef)
14 compinit:501> continue
14 compinit:501> continue
14 compinit:501> continue
14 compinit:501> ((  0 + 0  ))
14 compinit:501> ((  0 + 0  ))
14 compinit:500> _i_name=_ztodo
14 compinit:500> _i_name=_zstyle
14 compinit:500> _i_name=_zparseopts
14 compinit:500> _i_name=_zmodload
14 compinit:500> _i_name=_zlogin
14 compinit:500> _i_name=_zattr
14 compinit:500> _i_name=_xsel
14 compinit:500> _i_name=_xmms2
14 compinit:500> _i_name=_xft_fonts
14 compinit:500> _i_name=_xfig
14 compinit:500> _i_name=_xdvi
14 compinit:500> _i_name=_xautolock
14 compinit:500> _i_name=_xauth
14 compinit:500> _i_name=_x_resource
14 compinit:500> _i_name=_x_modifier
14 compinit:500> _i_name=_x_extension
14 compinit:500> _i_name=_x_colormapid
14 compinit:500> _i_name=_x_color
14 compinit:500> _i_name=_wipefs
14 compinit:500> _i_name=_wiggle
14 compinit:500> _i_name=_wakeup_capable_devices
14 compinit:500> _i_name=_virtualbox
14 compinit:500> _i_name=_update-alternatives
14 compinit:500> _i_name=_tarsnap
14 compinit:500> _i_name=_sysstat
14 compinit:500> _i_name=_stdbuf
14 compinit:500> _i_name=_snap
14 compinit:500> _i_name=_smartmontools
14 compinit:500> _i_name=_sfdx
14 compinit:500> _i_name=_setcap
14 compinit:500> _i_name=_sdd
14 compinit:500> _i_name=_scrub
14 compinit:500> _i_name=_scala
14 compinit:500> _i_name=_rubocop
14 compinit:500> _i_name=_rfkill
14 compinit:500> _i_name=_pkcon
14 compinit:500> _i_name=_pidof
14 compinit:500> _i_name=_pgsql_utils
14 compinit:500> _i_name=_periscope
14 compinit:500> _i_name=_patool
14 compinit:500> _i_name=_other_accounts
14 compinit:500> _i_name=_optirun
14 compinit:500> _i_name=_od
14 compinit:500> _i_name=_ninja
14 compinit:500> _i_name=_nftables
14 compinit:500> _i_name=_nedit
14 compinit:500> _i_name=_mussh
14 compinit:500> _i_name=_mpv
14 compinit:500> _i_name=_middleman
14 compinit:500> _i_name=_mdls
14 compinit:500> _i_name=_mdfind
14 compinit:500> _i_name=_md5sum
14 compinit:500> _i_name=_make-kpkg
14 compinit:500> _i_name=_mac_files_for_application
14 compinit:500> _i_name=_lldb
14 compinit:500> _i_name=_jonas
14 compinit:500> _i_name=_jobs_builtin
14 compinit:500> _i_name=_include-what-you-use
14 compinit:500> _i_name=_hub
14 compinit:500> _i_name=_hosts
14 compinit:500> _i_name=_head
14 compinit:500> _i_name=_gv
14 compinit:500> _i_name=_gist
14 compinit:500> _i_name=_freebsd-update
14 compinit:500> _i_name=_free
14 compinit:500> _i_name=_find
14 compinit:500> _i_name=_file_descriptors
14 compinit:500> _i_name=_fetchmail
14 compinit:500> _i_name=_ethtool
14 compinit:500> _i_name=_entr
14 compinit:500> _i_name=_elinks
14 compinit:500> _i_name=_du
14 compinit:500> _i_name=_dpkg_source
14 compinit:500> _i_name=_dpkg-cross
14 compinit:500> _i_name=_dpatch-edit-patch
14 compinit:500> _i_name=_dlocate
14 compinit:500> _i_name=_dirs
14 compinit:500> _i_name=_dir_list
14 compinit:500> _i_name=_diff
14 compinit:500> _i_name=_dchroot
14 compinit:500> _i_name=_dates
14 compinit:500> _i_name=_cygrunsrv
14 compinit:500> _i_name=_cygpath
14 compinit:500> _i_name=_cvsup
14 compinit:500> _i_name=_cvs
14 compinit:500> _i_name=_csup
14 compinit:500> _i_name=_cryptsetup
14 compinit:500> _i_name=_crontab
14 compinit:500> _i_name=_completers
14 compinit:500> _i_name=_compadd
14 compinit:500> _i_name=_comp_locale
14 compinit:500> _i_name=_cmdambivalent
14 compinit:500> _i_name=_cdcd
14 compinit:500> _i_name=_cd
14 compinit:500> _i_name=_ccal
14 compinit:500> _i_name=_cat
14 compinit:500> _i_name=_arrays
14 compinit:500> _i_name=_arping
14 compinit:500> _i_name=_apt-move
14 compinit:500> _i_name=_android
14 compinit:500> _i_name=_aliases
14 compinit:500> _i_name=_add-zsh-hook
14 compinit:500> _i_name=_absolute_command_paths
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zsocket
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zones
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zoneadm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zdump
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_yum
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_yp
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_yast
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xwit
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xpdf
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xmms2
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_title
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_borderwidth
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_webbrowser
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wanted
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wait
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_value
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_uptime
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_update-rc.d
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_unison
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_uname
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ttyctl
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tin
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tcpsys
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tcpdump
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svccfg
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ss
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sqsh
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_signals
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_set_command
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_selinux_contexts
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_script
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_screen
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_scl
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_schroot
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sccs
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sbuild
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rsync
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rrdtool
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rmdir
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_regex_arguments
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_qtplay
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_qemu
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_putclip
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pump
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ports
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pick_variant
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pbuilder
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pbm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pbcopy
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_od
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_object_classes
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nkf
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ngrep
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_networkmanager
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_netcat
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_net_interfaces
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nautilus
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_multi_parts
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mtools
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mplayer
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mozilla
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_most_recent_file
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_moosic
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_module
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mkfifo
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mkdir
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mime_types
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mdadm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_math_params
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_math
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_make-kpkg
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lynx
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsvg
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsof
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lsattr
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_logical_volumes
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_locale
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_list_files
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ldd
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ldconfig
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jail
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ipset
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ipadm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ionice
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_initctl
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iftop
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gv
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_groups
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_git
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getopt
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_generic
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gdb
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fs_usage
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fmadm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fbsd_architectures
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_expand_alias
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_espeak
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_email_addresses
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_echoti
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dvi
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dumpadm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_du
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpkg-buildpackage
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dns_types
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dlocate
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dispatch
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dirs
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_directory_stack
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_diff
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_deb_packages
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_deb_files
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_date_formats
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cvsup
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cu
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cscope
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_configure
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_compress
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_command
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cmdambivalent
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ccal
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_call_function
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_caffeinate
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_builtin
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bts
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_btrfs
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_brctl
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_brace_parameter
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bogofilter
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bittorrent
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bind_addresses
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bibtex
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_baz
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bash_completions
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bash
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arrays
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_aptitude
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apm
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apachectl
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ant
14 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_alias
14 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_rclone
14 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_dvc
14 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_asdf
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
14 compinit:118> typeset -gHA _lastcomp
14 compinit:80> shift
14 compinit:79> _i_autodump=1
14 compinit:76> [[ 2 -gt 0 && -d = -[dDiuC] ]]
14 compdump:121> shift _d_als
14 compdump:121> shift _d_als
14 compdump:121> shift _d_als
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:117> _i=5
14 compdump:116> ((  ! --_i && 714 > 1  ))
14 compdump:116> ((  ! --_i && 709 > 1  ))
14 compdump:116> ((  ! --_i && 439 > 1  ))
14 compdump:116> ((  ! --_i && 379 > 1  ))
14 compdump:116> ((  ! --_i && 374 > 1  ))
14 compdump:116> ((  ! --_i && 224 > 1  ))
14 compdump:116> ((  ! --_i && 144 > 1  ))
14 compdump:113> ((  981  ))
14 compdump:113> ((  877  ))
14 compdump:113> ((  837  ))
14 compdump:113> ((  488  ))
14 compdump:113> ((  453  ))
14 compdump:113> ((  374  ))
14 compdump:113> ((  340  ))
14 compdump:113> ((  135  ))
14 compdump:113> ((  128  ))
14 compdump:85> [[ _next_tags = _* && _next_tags = _* ]]
14 compdump:49> _d_f=xzcat
14 compdump:49> _d_f=unlzma
14 compdump:49> _d_f=mailx
14 compdump:49> _d_f=lzcat
14 compdump:49> _d_f=ggp
14 compdump:49> _d_f=ggf
14 compdump:49> _d_f=gdv
14 compdump:49> _d_f=gchgrp
14 compdump:49> _d_f=-redirect-,<,uncompress
14 compdump:43> _d_f=zsh
14 compdump:43> _d_f=zmodload
14 compdump:43> _d_f=zf_rm
14 compdump:43> _d_f=zen
14 compdump:43> _d_f=zargs
14 compdump:43> _d_f=yppush
14 compdump:43> _d_f=ypmatch
14 compdump:43> _d_f=xwininfo
14 compdump:43> _d_f=xvncviewer
14 compdump:43> _d_f=xset
14 compdump:43> _d_f=xrandr
14 compdump:43> _d_f=xmodmap
14 compdump:43> _d_f=xmllint
14 compdump:43> _d_f=xlsatoms
14 compdump:43> _d_f=xfd
14 compdump:43> _d_f=xetex
14 compdump:43> _d_f=xelatex
14 compdump:43> _d_f=www
14 compdump:43> _d_f=which
14 compdump:43> _d_f=where
14 compdump:43> _d_f=what
14 compdump:43> _d_f=vmstat
14 compdump:43> _d_f=vmctl
14 compdump:43> _d_f=virsh
14 compdump:43> _d_f=vim
14 compdump:43> _d_f=uscan
14 compdump:43> _d_f=urxvt256c-ml
14 compdump:43> _d_f=urxvt256c
14 compdump:43> _d_f=unpack
14 compdump:43> _d_f=unlz4
14 compdump:43> _d_f=twistd
14 compdump:43> _d_f=tunes2pod.pl
14 compdump:43> _d_f=true
14 compdump:43> _d_f=trial
14 compdump:43> _d_f=tpkg-make
14 compdump:43> _d_f=tpkg-install
14 compdump:43> _d_f=todo
14 compdump:43> _d_f=tmux
14 compdump:43> _d_f=times
14 compdump:43> _d_f=texindex
14 compdump:43> _d_f=texi2dvi
14 compdump:43> _d_f=tar
14 compdump:43> _d_f=talk
14 compdump:43> _d_f=systat
14 compdump:43> _d_f=swiftc
14 compdump:43> _d_f=sw_vers
14 compdump:43> _d_f=svcs
14 compdump:43> _d_f=svccfg
14 compdump:43> _d_f=sudo
14 compdump:43> _d_f=star
14 compdump:43> _d_f=srptool
14 compdump:43> _d_f=srm
14 compdump:43> _d_f=sort
14 compdump:43> _d_f=smbcontrol
14 compdump:43> _d_f=slogin
14 compdump:43> _d_f=shuf
14 compdump:43> _d_f=setsid
14 compdump:43> _d_f=seaf-cli
14 compdump:43> _d_f=sdd
14 compdump:43> _d_f=scrub
14 compdump:43> _d_f=sccs
14 compdump:43> _d_f=sc_usage
14 compdump:43> _d_f=s2p
14 compdump:43> _d_f=rpmverify
14 compdump:43> _d_f=rpmspec
14 compdump:43> _d_f=rmdir
14 compdump:43> _d_f=rmdel
14 compdump:43> _d_f=rmd160
14 compdump:43> _d_f=restart
14 compdump:43> _d_f=reprepro
14 compdump:43> _d_f=reindexdb
14 compdump:43> _d_f=readelf
14 compdump:43> _d_f=rcsdiff
14 compdump:43> _d_f=ranlib
14 compdump:43> _d_f=rake
14 compdump:43> _d_f=r
14 compdump:43> _d_f=qtplay
14 compdump:43> _d_f=pwgen
14 compdump:43> _d_f=pwait
14 compdump:43> _d_f=pstop
14 compdump:43> _d_f=pstoedit
14 compdump:43> _d_f=pscp
14 compdump:43> _d_f=ps2pdfwr
14 compdump:43> _d_f=ps2pdf14
14 compdump:43> _d_f=prs
14 compdump:43> _d_f=protoc
14 compdump:43> _d_f=postconf
14 compdump:43> _d_f=portlint
14 compdump:43> _d_f=pmpath
14 compdump:43> _d_f=pmake
14 compdump:43> _d_f=pkg_delete
14 compdump:43> _d_f=pkg
14 compdump:43> _d_f=pine
14 compdump:43> _d_f=pg_upgrade
14 compdump:43> _d_f=pdftotext
14 compdump:43> _d_f=pdfjadetex
14 compdump:43> _d_f=patch
14 compdump:43> _d_f=osascript
14 compdump:43> _d_f=openssl
14 compdump:43> _d_f=oggenc
14 compdump:43> _d_f=odmshow
14 compdump:43> _d_f=objdump
14 compdump:43> _d_f=nohup
14 compdump:43> _d_f=nft
14 compdump:43> _d_f=mysqladmin
14 compdump:43> _d_f=mussh
14 compdump:43> _d_f=monasca
14 compdump:43> _d_f=module
14 compdump:43> _d_f=mmm
14 compdump:43> _d_f=mktunes
14 compdump:43> _d_f=mkisofs
14 compdump:43> _d_f=mkfifo
14 compdump:43> _d_f=mkdir
14 compdump:43> _d_f=mhshow
14 compdump:43> _d_f=mhpath
14 compdump:43> _d_f=mhparam
14 compdump:43> _d_f=mhn
14 compdump:43> _d_f=mhmail
14 compdump:43> _d_f=mdfind
14 compdump:43> _d_f=mdeltree
14 compdump:43> _d_f=md5sum
14 compdump:43> _d_f=md5
14 compdump:43> _d_f=mcd
14 compdump:43> _d_f=mc
14 compdump:43> _d_f=mattrib
14 compdump:43> _d_f=manage.py
14 compdump:43> _d_f=man
14 compdump:43> _d_f=lua
14 compdump:43> _d_f=lsdev
14 compdump:43> _d_f=lscfg
14 compdump:43> _d_f=lpq
14 compdump:43> _d_f=lpinfo
14 compdump:43> _d_f=lpadmin
14 compdump:43> _d_f=losetup
14 compdump:43> _d_f=logname
14 compdump:43> _d_f=local
14 compdump:43> _d_f=llvm-gcc
14 compdump:43> _d_f=linux
14 compdump:43> _d_f=links
14 compdump:43> _d_f=limit
14 compdump:43> _d_f=kpdf
14 compdump:43> _d_f=kioclient
14 compdump:43> _d_f=keytool
14 compdump:43> _d_f=kak
14 compdump:43> _d_f=jrnl
14 compdump:43> _d_f=jq
14 compdump:43> _d_f=jot
14 compdump:43> _d_f=jonas
14 compdump:43> _d_f=join
14 compdump:43> _d_f=joe
14 compdump:43> _d_f=jobs
14 compdump:43> _d_f=jmeter-plugins
14 compdump:43> _d_f=javadoc
14 compdump:43> _d_f=javac
14 compdump:43> _d_f=java
14 compdump:43> _d_f=jarsigner
14 compdump:43> _d_f=ispell
14 compdump:43> _d_f=ironic
14 compdump:43> _d_f=irb
14 compdump:43> _d_f=ipsec
14 compdump:43> _d_f=ipkg
14 compdump:43> _d_f=ipadm
14 compdump:43> _d_f=ip6tables
14 compdump:43> _d_f=iostat
14 compdump:43> _d_f=ionice
14 compdump:43> _d_f=inxi
14 compdump:43> _d_f=installpkg
14 compdump:43> _d_f=initdb
14 compdump:43> _d_f=inc
14 compdump:43> _d_f=ifup
14 compdump:43> _d_f=iftop
14 compdump:43> _d_f=identify
14 compdump:43> _d_f=iconv
14 compdump:43> _d_f=icombine
14 compdump:43> _d_f=hwinfo
14 compdump:43> _d_f=hub
14 compdump:43> _d_f=hledger
14 compdump:43> _d_f=gzip
14 compdump:43> _d_f=gvim
14 compdump:43> _d_f=guniq
14 compdump:43> _d_f=guilt-rm
14 compdump:43> _d_f=guilt-next
14 compdump:43> _d_f=guilt-import
14 compdump:43> _d_f=guilt-fork
14 compdump:43> _d_f=guilt-add
14 compdump:43> _d_f=gtar
14 compdump:43> _d_f=gslp
14 compdump:43> _d_f=gsdj
14 compdump:43> _d_f=groupmod
14 compdump:43> _d_f=gnupod_search
14 compdump:43> _d_f=gnupod_check
14 compdump:43> _d_f=gln
14 compdump:43> _d_f=gcomm
14 compdump:43> _d_f=gb2sum
14 compdump:43> _d_f=fmttest
14 compdump:43> _d_f=fixmacps
14 compdump:43> _d_f=fgrep
14 compdump:43> _d_f=extractres
14 compdump:43> _d_f=evim
14 compdump:43> _d_f=eview
14 compdump:43> _d_f=eu-nm
14 compdump:43> _d_f=drill
14 compdump:43> _d_f=dpkg-repack
14 compdump:43> _d_f=dnf-2
14 compdump:43> _d_f=django-admin
14 compdump:43> _d_f=disable
14 compdump:43> _d_f=dhcpcd
14 compdump:43> _d_f=dget
14 compdump:43> _d_f=debchange
14 compdump:43> _d_f=dbus-send
14 compdump:43> _d_f=cscope
14 compdump:43> _d_f=crontab
14 compdump:43> _d_f=convert
14 compdump:43> _d_f=concourse
14 compdump:43> _d_f=comp
14 compdump:43> _d_f=comb
14 compdump:43> _d_f=cifsiostat
14 compdump:43> _d_f=chflags
14 compdump:43> _d_f=cdr
14 compdump:43> _d_f=cdbs-edit-patch
14 compdump:43> _d_f=caffeinate
14 compdump:43> _d_f=bts
14 compdump:43> _d_f=bitcoin-cli
14 compdump:43> _d_f=awk
14 compdump:43> _d_f=apt-file
14 compdump:43> _d_f=a2dismod
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:169> shift
14 compdef:164> [[ -n yes ]]
14 compdef:164> [[ -n yes ]]
14 compdef:163> _comps[$cmd]=_xz
14 compdef:163> _comps[$cmd]=_virtualbox
14 compdef:163> _comps[$cmd]=_gzip
14 compdef:163> _comps[$cmd]=_gnupod
14 compdef:163> _comps[$cmd]=_gnupod
14 compdef:163> _comps[$cmd]=_git
14 compdef:163> _comps[$cmd]=_git
14 compdef:163> _comps[$cmd]=_chown
14 compdef:162> [[ -z yes || -z _sed ]]
14 compdef:162> [[ -z yes || -z '' ]]
14 compdef:162> [[ -z yes || -z '' ]]
14 compdef:162> [[ -z yes || -z '' ]]
14 compdef:162> [[ -z yes || -z '' ]]
14 compdef:162> [[ -z yes || -z '' ]]
14 compdef:160> svc=''
14 compdef:160> svc=''
14 compdef:160> svc=''
14 compdef:160> svc=''
14 compdef:160> svc=''
14 compdef:160> svc=''
14 compdef:159> cmd=zypper
14 compdef:159> cmd=zf_chmod
14 compdef:159> cmd=xargs
14 compdef:159> cmd=update-alternatives
14 compdef:159> cmd=tox
14 compdef:159> cmd=tmuxp
14 compdef:159> cmd=tde
14 compdef:159> cmd=stg
14 compdef:159> cmd=sha1sum
14 compdef:159> cmd=restic
14 compdef:159> cmd=readshortcut
14 compdef:159> cmd=ps2pdf14
14 compdef:159> cmd=ncal
14 compdef:159> cmd=mpv
14 compdef:159> cmd=meson
14 compdef:159> cmd=madison
14 compdef:159> cmd=heat
14 compdef:159> cmd=gsettings
14 compdef:159> cmd=git-pulls
14 compdef:159> cmd=gchmod
14 compdef:159> cmd=dvips
14 compdef:159> cmd=dviconcat
14 compdef:159> cmd=dvibook
14 compdef:159> cmd=dsh
14 compdef:159> cmd=dropuser
14 compdef:159> cmd=dput
14 compdef:159> cmd=deborphan
14 compdef:159> cmd=debfoster
14 compdef:159> cmd=dd
14 compdef:159> cmd=dcut
14 compdef:159> cmd=cpupower
14 compdef:159> cmd=chrt
14 compdef:159> cmd=chown
14 compdef:159> cmd=chmod
14 compdef:159> cmd=chgrp
14 compdef:159> cmd=chflags
14 compdef:159> cmd=chattr
14 compdef:159> cmd=cdrecord
14 compdef:159> cmd=cdr
14 compdef:159> cmd=cdcd
14 compdef:159> cmd=cabal
14 compdef:159> cmd=bzr
14 compdef:159> cmd=btdownloadcurses
14 compdef:159> cmd=a2ps
14 compdef:159> cmd=-math-
14 compdef:159> cmd=-default-
14 compdef:157> svc=yes
14 compdef:156> cmd=xzcat
14 compdef:156> cmd=svnadmin-static
14 compdef:156> cmd=remsh
14 compdef:156> cmd=pcat
14 compdef:156> cmd=nedit-nc
14 compdef:156> cmd=iceweasel
14 compdef:156> cmd=gpg2
14 compdef:156> cmd=gnupod_addsong.pl
14 compdef:156> cmd='-redirect-,>,gzip'
14 compdef:156> cmd='-redirect-,<,bunzip2'
14 compdef:155> [[ zgetattr = *=* ]]
14 compdef:155> [[ zfs = *=* ]]
14 compdef:155> [[ zed = *=* ]]
14 compdef:155> [[ zdump = *=* ]]
14 compdef:155> [[ ypcat = *=* ]]
14 compdef:155> [[ yafc = *=* ]]
14 compdef:155> [[ xwit = *=* ]]
14 compdef:155> [[ xmllint = *=* ]]
14 compdef:155> [[ wpa_cli = *=* ]]
14 compdef:155> [[ watch = *=* ]]
14 compdef:155> [[ vmctl = *=* ]]
14 compdef:155> [[ visudo = *=* ]]
14 compdef:155> [[ virsh = *=* ]]
14 compdef:155> [[ vim = *=* ]]
14 compdef:155> [[ valgrind = *=* ]]
14 compdef:155> [[ uscan = *=* ]]
14 compdef:155> [[ unlimit = *=* ]]
14 compdef:155> [[ uniq = *=* ]]
14 compdef:155> [[ unfunction = *=* ]]
14 compdef:155> [[ uncompress = *=* ]]
14 compdef:155> [[ uname = *=* ]]
14 compdef:155> [[ tty = *=* ]]
14 compdef:155> [[ tree = *=* ]]
14 compdef:155> [[ trash = *=* ]]
14 compdef:155> [[ transmission-remote = *=* ]]
14 compdef:155> [[ tracepath = *=* ]]
14 compdef:155> [[ tput = *=* ]]
14 compdef:155> [[ touch = *=* ]]
14 compdef:155> [[ tload = *=* ]]
14 compdef:155> [[ tin = *=* ]]
14 compdef:155> [[ tex = *=* ]]
14 compdef:155> [[ telnet = *=* ]]
14 compdef:155> [[ tdr = *=* ]]
14 compdef:155> [[ system_profiler = *=* ]]
14 compdef:155> [[ systat = *=* ]]
14 compdef:155> [[ sysctl = *=* ]]
14 compdef:155> [[ svccfg = *=* ]]
14 compdef:155> [[ svcadm = *=* ]]
14 compdef:155> [[ surfraw = *=* ]]
14 compdef:155> [[ sum = *=* ]]
14 compdef:155> [[ subl = *=* ]]
14 compdef:155> [[ strftime = *=* ]]
14 compdef:155> [[ strace = *=* ]]
14 compdef:155> [[ stow = *=* ]]
14 compdef:155> [[ spamassassin = *=* ]]
14 compdef:155> [[ source = *=* ]]
14 compdef:155> [[ smartctl = *=* ]]
14 compdef:155> [[ slrn = *=* ]]
14 compdef:155> [[ sisu = *=* ]]
14 compdef:155> [[ shred = *=* ]]
14 compdef:155> [[ showmount = *=* ]]
14 compdef:155> [[ shasum = *=* ]]
14 compdef:155> [[ setxkbmap = *=* ]]
14 compdef:155> [[ setfacl = *=* ]]
14 compdef:155> [[ set = *=* ]]
14 compdef:155> [[ seq = *=* ]]
14 compdef:155> [[ sed = *=* ]]
14 compdef:155> [[ screen = *=* ]]
14 compdef:155> [[ schroot = *=* ]]
14 compdef:155> [[ sc_usage = *=* ]]
14 compdef:155> [[ say = *=* ]]
14 compdef:155> [[ sadf = *=* ]]
14 compdef:155> [[ rxvt = *=* ]]
14 compdef:155> [[ rsync = *=* ]]
14 compdef:155> [[ rrdtool = *=* ]]
14 compdef:155> [[ rpm = *=* ]]
14 compdef:155> [[ route = *=* ]]
14 compdef:155> [[ rmdir = *=* ]]
14 compdef:155> [[ restic = *=* ]]
14 compdef:155> [[ rehash = *=* ]]
14 compdef:155> [[ rec = *=* ]]
14 compdef:155> [[ readelf = *=* ]]
14 compdef:155> [[ rcctl = *=* ]]
14 compdef:155> [[ rake = *=* ]]
14 compdef:155> [[ quilt = *=* ]]
14 compdef:155> [[ pwgen = *=* ]]
14 compdef:155> [[ ps2epsi = *=* ]]
14 compdef:155> [[ prompt = *=* ]]
14 compdef:155> [[ powerd = *=* ]]
14 compdef:155> [[ portmaster = *=* ]]
14 compdef:155> [[ portlint = *=* ]]
14 compdef:155> [[ portaudit = *=* ]]
14 compdef:155> [[ pmpath = *=* ]]
14 compdef:155> [[ pmap = *=* ]]
14 compdef:155> [[ pm2 = *=* ]]
14 compdef:155> [[ plutil = *=* ]]
14 compdef:155> [[ pidof = *=* ]]
14 compdef:155> [[ pgrep = *=* ]]
14 compdef:155> [[ pfctl = *=* ]]
14 compdef:155> [[ perl = *=* ]]
14 compdef:155> [[ pdf2dsc = *=* ]]
14 compdef:155> [[ pbcopy = *=* ]]
14 compdef:155> [[ passwd = *=* ]]
14 compdef:155> [[ pandoc = *=* ]]
14 compdef:155> [[ pack = *=* ]]
14 compdef:155> [[ opkg = *=* ]]
14 compdef:155> [[ open = *=* ]]
14 compdef:155> [[ od = *=* ]]
14 compdef:155> [[ nslookup = *=* ]]
14 compdef:155> [[ node = *=* ]]
14 compdef:155> [[ nm = *=* ]]
14 compdef:155> [[ nl = *=* ]]
14 compdef:155> [[ nginx = *=* ]]
14 compdef:155> [[ nft = *=* ]]
14 compdef:155> [[ netstat = *=* ]]
14 compdef:155> [[ nedit = *=* ]]
14 compdef:155> [[ mysql = *=* ]]
14 compdef:155> [[ mvnDebug = *=* ]]
14 compdef:155> [[ mvn = *=* ]]
14 compdef:155> [[ mux = *=* ]]
14 compdef:155> [[ mutt = *=* ]]
14 compdef:155> [[ mt = *=* ]]
14 compdef:155> [[ mr = *=* ]]
14 compdef:155> [[ mozilla = *=* ]]
14 compdef:155> [[ mosh = *=* ]]
14 compdef:155> [[ module-assistant = *=* ]]
14 compdef:155> [[ mktemp = *=* ]]
14 compdef:155> [[ mknod = *=* ]]
14 compdef:155> [[ mkfifo = *=* ]]
14 compdef:155> [[ mixerctl = *=* ]]
14 compdef:155> [[ mii-tool = *=* ]]
14 compdef:155> [[ mergechanges = *=* ]]
14 compdef:155> [[ members = *=* ]]
14 compdef:155> [[ make = *=* ]]
14 compdef:155> [[ madison = *=* ]]
14 compdef:155> [[ lzop = *=* ]]
14 compdef:155> [[ lynx = *=* ]]
14 compdef:155> [[ lsvg = *=* ]]
14 compdef:155> [[ lspv = *=* ]]
14 compdef:155> [[ lsof = *=* ]]
14 compdef:155> [[ lsmod = *=* ]]
14 compdef:155> [[ lsdev = *=* ]]
14 compdef:155> [[ ls = *=* ]]
14 compdef:155> [[ look = *=* ]]
14 compdef:155> [[ locate = *=* ]]
14 compdef:155> [[ localedef = *=* ]]
14 compdef:155> [[ lintian = *=* ]]
14 compdef:155> [[ links = *=* ]]
14 compdef:155> [[ ldd = *=* ]]
14 compdef:155> [[ last = *=* ]]
14 compdef:155> [[ ksh = *=* ]]
14 compdef:155> [[ knock = *=* ]]
14 compdef:155> [[ knife = *=* ]]
14 compdef:155> [[ killall = *=* ]]
14 compdef:155> [[ kfmclient = *=* ]]
14 compdef:155> [[ kdeconnect-cli = *=* ]]
14 compdef:155> [[ join = *=* ]]
14 compdef:155> [[ jls = *=* ]]
14 compdef:155> [[ jexec = *=* ]]
14 compdef:155> [[ javac = *=* ]]
14 compdef:155> [[ irssi = *=* ]]
14 compdef:155> [[ iptables = *=* ]]
14 compdef:155> [[ iostat = *=* ]]
14 compdef:155> [[ ionice = *=* ]]
14 compdef:155> [[ inxi = *=* ]]
14 compdef:155> [[ invoke-rc.d = *=* ]]
14 compdef:155> [[ installpkg = *=* ]]
14 compdef:155> [[ inetadm = *=* ]]
14 compdef:155> [[ ibus = *=* ]]
14 compdef:155> [[ hledger = *=* ]]
14 compdef:155> [[ hexdump = *=* ]]
14 compdef:155> [[ gwho = *=* ]]
14 compdef:155> [[ guilt-init = *=* ]]
14 compdef:155> [[ gsha1sum = *=* ]]
14 compdef:155> [[ grep = *=* ]]
14 compdef:155> [[ gprof = *=* ]]
14 compdef:155> [[ gphoto2 = *=* ]]
14 compdef:155> [[ go = *=* ]]
14 compdef:155> [[ gnupod_addsong = *=* ]]
14 compdef:155> [[ gnome-gv = *=* ]]
14 compdef:155> [[ gmkdir = *=* ]]
14 compdef:155> [[ global = *=* ]]
14 compdef:155> [[ glances = *=* ]]
14 compdef:155> [[ git-buildpackage = *=* ]]
14 compdef:155> [[ getopts = *=* ]]
14 compdef:155> [[ getopt = *=* ]]
14 compdef:155> [[ getclip = *=* ]]
14 compdef:155> [[ genisoimage = *=* ]]
14 compdef:155> [[ gcksum = *=* ]]
14 compdef:155> [[ gcc = *=* ]]
14 compdef:155> [[ fusermount = *=* ]]
14 compdef:155> [[ fsh = *=* ]]
14 compdef:155> [[ flutter = *=* ]]
14 compdef:155> [[ flowadm = *=* ]]
14 compdef:155> [[ flex = *=* ]]
14 compdef:155> [[ fleetctl = *=* ]]
14 compdef:155> [[ flac = *=* ]]
14 compdef:155> [[ fink = *=* ]]
14 compdef:155> [[ finger = *=* ]]
14 compdef:155> [[ findmnt = *=* ]]
14 compdef:155> [[ ffind = *=* ]]
14 compdef:155> [[ fetchmail = *=* ]]
14 compdef:155> [[ feh = *=* ]]
14 compdef:155> [[ fc = *=* ]]
14 compdef:155> [[ fakeroot = *=* ]]
14 compdef:155> [[ dvibook = *=* ]]
14 compdef:155> [[ dosread = *=* ]]
14 compdef:155> [[ docpad = *=* ]]
14 compdef:155> [[ docker = *=* ]]
14 compdef:155> [[ dkms = *=* ]]
14 compdef:155> [[ django-admin = *=* ]]
14 compdef:155> [[ disown = *=* ]]
14 compdef:155> [[ dhcpcd = *=* ]]
14 compdef:155> [[ dhclient3 = *=* ]]
14 compdef:155> [[ df = *=* ]]
14 compdef:155> [[ dcopstart = *=* ]]
14 compdef:155> [[ cygstart.exe = *=* ]]
14 compdef:155> [[ cygcheck.exe = *=* ]]
14 compdef:155> [[ csup = *=* ]]
14 compdef:155> [[ cpio = *=* ]]
14 compdef:155> [[ coreadm = *=* ]]
14 compdef:155> [[ console = *=* ]]
14 compdef:155> [[ combinediff = *=* ]]
14 compdef:155> [[ coffee = *=* ]]
14 compdef:155> [[ co = *=* ]]
14 compdef:155> [[ cloudkitty = *=* ]]
14 compdef:155> [[ chromium = *=* ]]
14 compdef:155> [[ chgrp = *=* ]]
14 compdef:155> [[ bundle = *=* ]]
14 compdef:155> [[ bug = *=* ]]
14 compdef:155> [[ bts = *=* ]]
14 compdef:155> [[ btrfs = *=* ]]
14 compdef:155> [[ bsdconfig = *=* ]]
14 compdef:155> [[ bpython3-urwid = *=* ]]
14 compdef:155> [[ bpython = *=* ]]
14 compdef:155> [[ bower = *=* ]]
14 compdef:155> [[ bogoutil = *=* ]]
14 compdef:155> [[ b2sum = *=* ]]
14 compdef:155> [[ axi-cache = *=* ]]
14 compdef:155> [[ auto-apt = *=* ]]
14 compdef:155> [[ attr = *=* ]]
14 compdef:155> [[ atrm = *=* ]]
14 compdef:155> [[ arping = *=* ]]
14 compdef:155> [[ arp = *=* ]]
14 compdef:155> [[ archlinux-java = *=* ]]
14 compdef:155> [[ aptitude = *=* ]]
14 compdef:155> [[ apt-file = *=* ]]
14 compdef:155> [[ apt = *=* ]]
14 compdef:155> [[ apm = *=* ]]
14 compdef:155> [[ antiword = *=* ]]
14 compdef:155> [[ ant = *=* ]]
14 compdef:155> [[ ansible = *=* ]]
14 compdef:155> [[ analyseplugin = *=* ]]
14 compdef:155> [[ acpi = *=* ]]
14 compdef:155> [[ ack = *=* ]]
14 compdef:155> [[ aap = *=* ]]
14 compdef:155> [[ -zcalc-line- = *=* ]]
14 compdef:155> [[ -value-,PROMPT2,-default- = *=* ]]
14 compdef:155> [[ -value-,PROMPT,-default- = *=* ]]
14 compdef:155> [[ -value-,PRINTER,-default- = *=* ]]
14 compdef:155> [[ -value-,PERLDOC,-default- = *=* ]]
14 compdef:155> [[ -value-,CFLAGS,-default- = *=* ]]
14 compdef:155> [[ -value-,ANSIBLE_STDOUT_CALLBACK,-default- = *=* ]]
14 compdef:155> [[ -value- = *=* ]]
14 compdef:155> [[ -tilde- = *=* ]]
14 compdef:155> [[ -parameter- = *=* ]]
14 compdef:155> [[ -condition- = *=* ]]
14 compdef:155> [[ -command-line- = *=* ]]
14 compdef:155> [[ -brace-parameter- = *=* ]]
14 compdef:155> [[ -assign-parameter- = *=* ]]
14 compdef:155> [[ - = *=* ]]
14 compdef:155> [[ 'zf_chown=chown' = *=* ]]
14 compdef:155> [[ 'zf_chgrp=chgrp' = *=* ]]
14 compdef:155> [[ 'yaourt.static=yaourt' = *=* ]]
14 compdef:155> [[ 'gchgrp=chgrp' = *=* ]]
14 compdef:155> [[ 'VBoxHeadless=vboxheadless' = *=* ]]
14 compdef:155> [[ '-redirect-,<,gzip=gzip' = *=* ]]
14 compdef:155> [[ '-redirect-,<,compress=compress' = *=* ]]
14 compdef:148> [[ '-value-,(ftp|http(|s))_proxy,-default-' = (#b)(*)=(*) ]]
14 compdef:148> [[ '*/X11(|R<4->)/*' = (#b)(*)=(*) ]]
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (postpattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (pattern)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:139> case  (*)
14 compdef:137> type=postpattern
14 compdef:137> type=postpattern
14 compdef:137> type=postpattern
14 compdef:137> type=postpattern
14 compdef:137> type=postpattern
14 compdef:136> [[ xautolock = -P ]]
14 compdef:136> [[ vagrant = -P ]]
14 compdef:136> [[ uncompress = -P ]]
14 compdef:136> [[ todo = -P ]]
14 compdef:136> [[ tmuxp = -P ]]
14 compdef:136> [[ tmuxinator = -P ]]
14 compdef:136> [[ tla = -P ]]
14 compdef:136> [[ tdr = -P ]]
14 compdef:136> [[ tde = -P ]]
14 compdef:136> [[ tdd = -P ]]
14 compdef:136> [[ tardy = -P ]]
14 compdef:136> [[ sum = -P ]]
14 compdef:136> [[ stg = -P ]]
14 compdef:136> [[ stdbuf = -P ]]
14 compdef:136> [[ restic = -P ]]
14 compdef:136> [[ protoc = -P ]]
14 compdef:136> [[ postconf = -P ]]
14 compdef:136> [[ omz = -P ]]
14 compdef:136> [[ nmblookup = -P ]]
14 compdef:136> [[ ncal = -P ]]
14 compdef:136> [[ mux = -P ]]
14 compdef:136> [[ mkzsh = -P ]]
14 compdef:136> [[ meson = -P ]]
14 compdef:136> [[ kpartx = -P ]]
14 compdef:136> [[ guniq = -P ]]
14 compdef:136> [[ guilt-import-commit = -P ]]
14 compdef:136> [[ gstat = -P ]]
14 compdef:136> [[ growisofs = -P ]]
14 compdef:136> [[ gphoto2 = -P ]]
14 compdef:136> [[ gid = -P ]]
14 compdef:136> [[ gcksum = -P ]]
14 compdef:136> [[ gchmod = -P ]]
14 compdef:136> [[ evince = -P ]]
14 compdef:136> [[ enscript = -P ]]
14 compdef:136> [[ dviconcat = -P ]]
14 compdef:136> [[ dumper.exe = -P ]]
14 compdef:136> [[ dsh = -P ]]
14 compdef:136> [[ defaults = -P ]]
14 compdef:136> [[ debsign = -P ]]
14 compdef:136> [[ cvsup = -P ]]
14 compdef:136> [[ createdb = -P ]]
14 compdef:136> [[ cpupower = -P ]]
14 compdef:136> [[ compress = -P ]]
14 compdef:136> [[ chsh = -P ]]
14 compdef:136> [[ chpass = -P ]]
14 compdef:136> [[ chmod = -P ]]
14 compdef:136> [[ chkconfig = -P ]]
14 compdef:136> [[ chgrp = -P ]]
14 compdef:136> [[ cdrecord = -P ]]
14 compdef:136> [[ cdr = -P ]]
14 compdef:136> [[ cdcd = -P ]]
14 compdef:136> [[ cal = -P ]]
14 compdef:136> [[ a2ensite = -P ]]
14 compdef:136> [[ 'ggl=git-checkout' = -P ]]
14 compdef:136> [[ 'dch=debchange' = -P ]]
14 compdef:136> [[ 'VBoxHeadless=vboxheadless' = -P ]]
14 compdef:134> [[ zmodload = -p ]]
14 compdef:134> [[ zlogin = -p ]]
14 compdef:134> [[ zcat = -p ]]
14 compdef:134> [[ xsltproc = -p ]]
14 compdef:134> [[ xfreerdp = -p ]]
14 compdef:134> [[ xfig = -p ]]
14 compdef:134> [[ xcode-select = -p ]]
14 compdef:134> [[ xauth = -p ]]
14 compdef:134> [[ wodim = -p ]]
14 compdef:134> [[ wemux = -p ]]
14 compdef:134> [[ vnstat = -p ]]
14 compdef:134> [[ uncompress = -p ]]
14 compdef:134> [[ ufw = -p ]]
14 compdef:134> [[ trash-list = -p ]]
14 compdef:134> [[ tda = -p ]]
14 compdef:134> [[ svcadm = -p ]]
14 compdef:134> [[ sdd = -p ]]
14 compdef:134> [[ scala = -p ]]
14 compdef:134> [[ rkt = -p ]]
14 compdef:134> [[ ri = -p ]]
14 compdef:134> [[ rfkill = -p ]]
14 compdef:134> [[ rake = -p ]]
14 compdef:134> [[ pixz = -p ]]
14 compdef:134> [[ pfexec = -p ]]
14 compdef:134> [[ open = -p ]]
14 compdef:134> [[ node = -p ]]
14 compdef:134> [[ nice = -p ]]
14 compdef:134> [[ nano = -p ]]
14 compdef:134> [[ moosic = -p ]]
14 compdef:134> [[ middleman = -p ]]
14 compdef:134> [[ merge = -p ]]
14 compdef:134> [[ mdadm = -p ]]
14 compdef:134> [[ let = -p ]]
14 compdef:134> [[ ksh88 = -p ]]
14 compdef:134> [[ guilt-files = -p ]]
14 compdef:134> [[ gsettings = -p ]]
14 compdef:134> [[ ffmpeg = -p ]]
14 compdef:134> [[ espeak = -p ]]
14 compdef:134> [[ envdir = -p ]]
14 compdef:134> [[ echoti = -p ]]
14 compdef:134> [[ dviconcat = -p ]]
14 compdef:134> [[ dvibook = -p ]]
14 compdef:134> [[ du = -p ]]
14 compdef:134> [[ dtrace = -p ]]
14 compdef:134> [[ dmesg = -p ]]
14 compdef:134> [[ dlocate = -p ]]
14 compdef:134> [[ dladm = -p ]]
14 compdef:134> [[ dkms = -p ]]
14 compdef:134> [[ debcheckout = -p ]]
14 compdef:134> [[ debchange = -p ]]
14 compdef:134> [[ dcop = -p ]]
14 compdef:134> [[ dbus-send = -p ]]
14 compdef:134> [[ cygpath = -p ]]
14 compdef:134> [[ csup = -p ]]
14 compdef:134> [[ cscope = -p ]]
14 compdef:134> [[ cowsay = -p ]]
14 compdef:134> [[ configure = -p ]]
14 compdef:134> [[ command = -p ]]
14 compdef:134> [[ comm = -p ]]
14 compdef:134> [[ cmp = -p ]]
14 compdef:134> [[ chroot = -p ]]
14 compdef:134> [[ chown = -p ]]
14 compdef:134> [[ ccal = -p ]]
14 compdef:134> [[ cal = -p ]]
14 compdef:134> [[ acpi = -p ]]
14 compdef:134> [[ -value-,XML_CATALOG_FILES,-default- = -p ]]
14 compdef:134> [[ -value-,DISPLAY,-default- = -p ]]
14 compdef:134> [[ 'VBoxManage=vboxmanage' = -p ]]
14 compdef:134> [[ '-value-,*PATH,-default-' = -p ]]
14 compdef:134> [[ '-redirect-,<,gunzip=gunzip' = -p ]]
14 compdef:132> [[ todo = -N ]]
14 compdef:132> [[ tdr = -N ]]
14 compdef:132> [[ tde = -N ]]
14 compdef:132> [[ tdd = -N ]]
14 compdef:132> [[ stty = -N ]]
14 compdef:132> [[ smit = -N ]]
14 compdef:132> [[ sha1sum = -N ]]
14 compdef:132> [[ sadf = -N ]]
14 compdef:132> [[ restic = -N ]]
14 compdef:132> [[ pkg = -N ]]
14 compdef:132> [[ ncal = -N ]]
14 compdef:132> [[ mux = -N ]]
14 compdef:132> [[ ironic = -N ]]
14 compdef:132> [[ gsum = -N ]]
14 compdef:132> [[ gpgv = -N ]]
14 compdef:132> [[ gcksum = -N ]]
14 compdef:132> [[ dvicopy = -N ]]
14 compdef:132> [[ createdb = -N ]]
14 compdef:132> [[ 'yaourt.static=yaourt' = -N ]]
14 compdef:132> [[ '_git_log_prettily=git-log' = -N ]]
14 compdef:132> [[ 'VBoxHeadless=vboxheadless' = -N ]]
14 compdef:131> ((  14  ))
14 compdef:131> ((  9  ))
14 compdef:131> ((  8  ))
14 compdef:131> ((  7  ))
14 compdef:131> ((  6  ))
14 compdef:131> ((  6  ))
14 compdef:131> ((  6  ))
14 compdef:131> ((  6  ))
14 compdef:131> ((  5  ))
14 compdef:131> ((  5  ))
14 compdef:131> ((  4  ))
14 compdef:131> ((  4  ))
14 compdef:131> ((  3  ))
14 compdef:131> ((  3  ))
14 compdef:131> ((  3  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  2  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:131> ((  1  ))
14 compdef:110> [[ complete-word = .* ]]
14 compdef:104> [[ 2 -lt 2 ]]
14 compdef:91> 2=.list-choices
14 compdef:91> 2=.complete-word
14 compdef:90> [[ _bash_complete-word = _* ]]
14 compdef:86> [[ 3 -lt 3 ]]
14 compdef:85> [[ -n _expand_word ]]
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (widgetkey)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (key)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:83> case  (*)
14 compdef:81> shift
14 compdef:81> shift
14 compdef:81> shift
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n yes ]]
14 compdef:80> [[ -n '' ]]
14 compdef:80> [[ -n '' ]]
14 compdef:80> [[ -n '' ]]
14 compdef:79> func=_zypper
14 compdef:79> func=_zlogin
14 compdef:79> func=_yodl
14 compdef:79> func=_wiggle
14 compdef:79> func=_trash-list
14 compdef:79> func=_tox
14 compdef:79> func=_tail
14 compdef:79> func=_snap
14 compdef:79> func=_ptree
14 compdef:79> func=_precommand
14 compdef:79> func=_numfmt
14 compdef:79> func=_math
14 compdef:79> func=_ltrace
14 compdef:79> func=_iconvconfig
14 compdef:79> func=_gstat
14 compdef:79> func=_gsettings
14 compdef:79> func=_dvi
14 compdef:79> func=_dsh
14 compdef:79> func=_drill
14 compdef:79> func=_dpkg-buildpackage
14 compdef:79> func=_diana
14 compdef:79> func=_default
14 compdef:79> func=_deborphan
14 compdef:79> func=_debchange
14 compdef:79> func=_curl
14 compdef:79> func=_compress
14 compdef:79> func=_chrt
14 compdef:79> func=_chown
14 compdef:79> func=_cdr
14 compdef:79> func=_cdcd
14 compdef:79> func=_cdbs-edit-patch
14 compdef:79> func=_caffeinate
14 compdef:79> func=_bzr
14 compdef:79> func=_a2utils
14 compdef:49> [[ _zftp = *=* ]]
14 compdef:49> [[ _zcompile = *=* ]]
14 compdef:49> [[ _zcalc_line = *=* ]]
14 compdef:49> [[ _zcalc = *=* ]]
14 compdef:49> [[ _yp = *=* ]]
14 compdef:49> [[ _yodl = *=* ]]
14 compdef:49> [[ _yast = *=* ]]
14 compdef:49> [[ _yafc = *=* ]]
14 compdef:49> [[ _xz = *=* ]]
14 compdef:49> [[ _xrandr = *=* ]]
14 compdef:49> [[ _xmodmap = *=* ]]
14 compdef:49> [[ _xmms2 = *=* ]]
14 compdef:49> [[ _wget = *=* ]]
14 compdef:49> [[ _w3m = *=* ]]
14 compdef:49> [[ _vars = *=* ]]
14 compdef:49> [[ _vared = *=* ]]
14 compdef:49> [[ _users_on = *=* ]]
14 compdef:49> [[ _user_admin = *=* ]]
14 compdef:49> [[ _urpmi = *=* ]]
14 compdef:49> [[ _uptime = *=* ]]
14 compdef:49> [[ _unison = *=* ]]
14 compdef:49> [[ _unace = *=* ]]
14 compdef:49> [[ _uml = *=* ]]
14 compdef:49> [[ _typeset = *=* ]]
14 compdef:49> [[ _tune2fs = *=* ]]
14 compdef:49> [[ _tty = *=* ]]
14 compdef:49> [[ _transmission = *=* ]]
14 compdef:49> [[ _touch = *=* ]]
14 compdef:49> [[ _top = *=* ]]
14 compdef:49> [[ _toolchain-source = *=* ]]
14 compdef:49> [[ _tmux = *=* ]]
14 compdef:49> [[ _tload = *=* ]]
14 compdef:49> [[ _timeout = *=* ]]
14 compdef:49> [[ _tilde = *=* ]]
14 compdef:49> [[ _texi = *=* ]]
14 compdef:49> [[ _terminals = *=* ]]
14 compdef:49> [[ _tcpdump = *=* ]]
14 compdef:49> [[ _tar = *=* ]]
14 compdef:49> [[ _tac = *=* ]]
14 compdef:49> [[ _sysstat = *=* ]]
14 compdef:49> [[ _sysctl = *=* ]]
14 compdef:49> [[ _swanctl = *=* ]]
14 compdef:49> [[ _svn-buildpackage = *=* ]]
14 compdef:49> [[ _svcprop = *=* ]]
14 compdef:49> [[ _svcadm = *=* ]]
14 compdef:49> [[ _subversion = *=* ]]
14 compdef:49> [[ _sublimetext = *=* ]]
14 compdef:49> [[ _stty = *=* ]]
14 compdef:49> [[ _strftime = *=* ]]
14 compdef:49> [[ _sshfs = *=* ]]
14 compdef:49> [[ _ssh = *=* ]]
14 compdef:49> [[ _ss = *=* ]]
14 compdef:49> [[ _split = *=* ]]
14 compdef:49> [[ _spamassassin = *=* ]]
14 compdef:49> [[ _sort = *=* ]]
14 compdef:49> [[ _sockstat = *=* ]]
14 compdef:49> [[ _smit = *=* ]]
14 compdef:49> [[ _smartmontools = *=* ]]
14 compdef:49> [[ _slrn = *=* ]]
14 compdef:49> [[ _sisu = *=* ]]
14 compdef:49> [[ _signify = *=* ]]
14 compdef:49> [[ _shuf = *=* ]]
14 compdef:49> [[ _shasum = *=* ]]
14 compdef:49> [[ _setxkbmap = *=* ]]
14 compdef:49> [[ _set = *=* ]]
14 compdef:49> [[ _service = *=* ]]
14 compdef:49> [[ _seafile = *=* ]]
14 compdef:49> [[ _screen = *=* ]]
14 compdef:49> [[ _scons = *=* ]]
14 compdef:49> [[ _sc_usage = *=* ]]
14 compdef:49> [[ _sbuild = *=* ]]
14 compdef:49> [[ _say = *=* ]]
14 compdef:49> [[ _run-help = *=* ]]
14 compdef:49> [[ _ruby = *=* ]]
14 compdef:49> [[ _rrdtool = *=* ]]
14 compdef:49> [[ _rmdir = *=* ]]
14 compdef:49> [[ _rm = *=* ]]
14 compdef:49> [[ _renice = *=* ]]
14 compdef:49> [[ _rebootin = *=* ]]
14 compdef:49> [[ _readlink = *=* ]]
14 compdef:49> [[ _rdesktop = *=* ]]
14 compdef:49> [[ _rar = *=* ]]
14 compdef:49> [[ _ranlib = *=* ]]
14 compdef:49> [[ _qiv = *=* ]]
14 compdef:49> [[ _qemu = *=* ]]
14 compdef:49> [[ _python = *=* ]]
14 compdef:49> [[ _pv = *=* ]]
14 compdef:49> [[ _pump = *=* ]]
14 compdef:49> [[ _pspdf = *=* ]]
14 compdef:49> [[ _ps1234 = *=* ]]
14 compdef:49> [[ _ps = *=* ]]
14 compdef:49> [[ _prstat = *=* ]]
14 compdef:49> [[ _printers = *=* ]]
14 compdef:49> [[ _postgresql = *=* ]]
14 compdef:49> [[ _postfix = *=* ]]
14 compdef:49> [[ _portsnap = *=* ]]
14 compdef:49> [[ _portmaster = *=* ]]
14 compdef:49> [[ _pkgtool = *=* ]]
14 compdef:49> [[ _pkgrm = *=* ]]
14 compdef:49> [[ _pkgin = *=* ]]
14 compdef:49> [[ _php = *=* ]]
14 compdef:49> [[ _pfexec = *=* ]]
14 compdef:49> [[ _pfctl = *=* ]]
14 compdef:49> [[ _perldoc = *=* ]]
14 compdef:49> [[ _perl = *=* ]]
14 compdef:49> [[ _pbuilder = *=* ]]
14 compdef:49> [[ _pbm = *=* ]]
14 compdef:49> [[ _pbcopy = *=* ]]
14 compdef:49> [[ _pax = *=* ]]
14 compdef:49> [[ _patchutils = *=* ]]
14 compdef:49> [[ _paste = *=* ]]
14 compdef:49> [[ _otool = *=* ]]
14 compdef:49> [[ _other_accounts = *=* ]]
14 compdef:49> [[ _osascript = *=* ]]
14 compdef:49> [[ _nslookup = *=* ]]
14 compdef:49> [[ _nothing = *=* ]]
14 compdef:49> [[ _nmap = *=* ]]
14 compdef:49> [[ _nm = *=* ]]
14 compdef:49> [[ _ngrep = *=* ]]
14 compdef:49> [[ _next_tags = *=* ]]
14 compdef:49> [[ _netstat = *=* ]]
14 compdef:49> [[ _netcat = *=* ]]
14 compdef:49> [[ _nedit = *=* ]]
14 compdef:49> [[ _nautilus = *=* ]]
14 compdef:49> [[ _mysql_utils = *=* ]]
14 compdef:49> [[ _myrepos = *=* ]]
14 compdef:49> [[ _mv = *=* ]]
14 compdef:49> [[ _mpc = *=* ]]
14 compdef:49> [[ _mozilla = *=* ]]
14 compdef:49> [[ _most_recent_file = *=* ]]
14 compdef:49> [[ _mosh = *=* ]]
14 compdef:49> [[ _monotone = *=* ]]
14 compdef:49> [[ _mondo = *=* ]]
14 compdef:49> [[ _modutils = *=* ]]
14 compdef:49> [[ _module = *=* ]]
14 compdef:49> [[ _mkfifo = *=* ]]
14 compdef:49> [[ _mergechanges = *=* ]]
14 compdef:49> [[ _members = *=* ]]
14 compdef:49> [[ _lzop = *=* ]]
14 compdef:49> [[ _lsof = *=* ]]
14 compdef:49> [[ _lscfg = *=* ]]
14 compdef:49> [[ _loadkeys = *=* ]]
14 compdef:49> [[ _limits = *=* ]]
14 compdef:49> [[ _lha = *=* ]]
14 compdef:49> [[ _less = *=* ]]
14 compdef:49> [[ _knife = *=* ]]
14 compdef:49> [[ _kld = *=* ]]
14 compdef:49> [[ _killall = *=* ]]
14 compdef:49> [[ _kfmclient = *=* ]]
14 compdef:49> [[ _jrnl = *=* ]]
14 compdef:49> [[ _jot = *=* ]]
14 compdef:49> [[ _jobs_fg = *=* ]]
14 compdef:49> [[ _jmeter = *=* ]]
14 compdef:49> [[ _irssi = *=* ]]
14 compdef:49> [[ _iptables = *=* ]]
14 compdef:49> [[ _ipset = *=* ]]
14 compdef:49> [[ _ionice = *=* ]]
14 compdef:49> [[ _inxi = *=* ]]
14 compdef:49> [[ _inetadm = *=* ]]
14 compdef:49> [[ _in_vared = *=* ]]
14 compdef:49> [[ _id = *=* ]]
14 compdef:49> [[ _hwinfo = *=* ]]
14 compdef:49> [[ _httpie = *=* ]]
14 compdef:49> [[ _hexdump = *=* ]]
14 compdef:49> [[ _head = *=* ]]
14 compdef:49> [[ _grep = *=* ]]
14 compdef:49> [[ _gprof = *=* ]]
14 compdef:49> [[ _gpasswd = *=* ]]
14 compdef:49> [[ _go = *=* ]]
14 compdef:49> [[ _gnutls = *=* ]]
14 compdef:49> [[ _gnupod = *=* ]]
14 compdef:49> [[ _gnome-gv = *=* ]]
14 compdef:49> [[ _git = *=* ]]
14 compdef:49> [[ _ghostscript = *=* ]]
14 compdef:49> [[ _getopt = *=* ]]
14 compdef:49> [[ _gas = *=* ]]
14 compdef:49> [[ _fwupdmgr = *=* ]]
14 compdef:49> [[ _fw_update = *=* ]]
14 compdef:49> [[ _fstat = *=* ]]
14 compdef:49> [[ _fsh = *=* ]]
14 compdef:49> [[ _free = *=* ]]
14 compdef:49> [[ _fold = *=* ]]
14 compdef:49> [[ _flutter = *=* ]]
14 compdef:49> [[ _flowadm = *=* ]]
14 compdef:49> [[ _floppy = *=* ]]
14 compdef:49> [[ _fleetctl = *=* ]]
14 compdef:49> [[ _flac = *=* ]]
14 compdef:49> [[ _fink = *=* ]]
14 compdef:49> [[ _find = *=* ]]
14 compdef:49> [[ _files = *=* ]]
14 compdef:49> [[ _ffind = *=* ]]
14 compdef:49> [[ _fetch = *=* ]]
14 compdef:49> [[ _feh = *=* ]]
14 compdef:49> [[ _fab = *=* ]]
14 compdef:49> [[ _exportfs = *=* ]]
14 compdef:49> [[ _env = *=* ]]
14 compdef:49> [[ _docpad = *=* ]]
14 compdef:49> [[ _docker = *=* ]]
14 compdef:49> [[ _dirs = *=* ]]
14 compdef:49> [[ _deno = *=* ]]
14 compdef:49> [[ _correct_filename = *=* ]]
14 compdef:49> [[ _console = *=* ]]
14 compdef:49> [[ _cf = *=* ]]
14 compdef:49> [[ _ccache = *=* ]]
14 compdef:49> [[ _cask = *=* ]]
14 compdef:49> [[ _cap = *=* ]]
14 compdef:49> [[ _builtin = *=* ]]
14 compdef:49> [[ _bug = *=* ]]
14 compdef:49> [[ _bts = *=* ]]
14 compdef:49> [[ _bsdconfig = *=* ]]
14 compdef:49> [[ _brctl = *=* ]]
14 compdef:49> [[ _bower = *=* ]]
14 compdef:49> [[ _bittorrent = *=* ]]
14 compdef:49> [[ _bison = *=* ]]
14 compdef:49> [[ _bash_completions = *=* ]]
14 compdef:49> [[ _base64 = *=* ]]
14 compdef:49> [[ _axi-cache = *=* ]]
14 compdef:49> [[ _avahi = *=* ]]
14 compdef:49> [[ _auto-apt = *=* ]]
14 compdef:49> [[ _augeas = *=* ]]
14 compdef:49> [[ _attr = *=* ]]
14 compdef:49> [[ _atach = *=* ]]
14 compdef:49> [[ _asciidoctor = *=* ]]
14 compdef:49> [[ _arrays = *=* ]]
14 compdef:49> [[ _apt-move = *=* ]]
14 compdef:49> [[ _apt-file = *=* ]]
14 compdef:49> [[ _apt = *=* ]]
14 compdef:49> [[ _aliases = *=* ]]
14 compdef:49> [[ _add-zsh-hook = *=* ]]
14 compdef:49> [[ _ack = *=* ]]
14 compdef:49> [[ _aap = *=* ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:49> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:45> [[ -z '' ]]
14 compdef:40> ((  ! 28  ))
14 compdef:40> ((  ! 23  ))
14 compdef:40> ((  ! 15  ))
14 compdef:40> ((  ! 12  ))
14 compdef:40> ((  ! 11  ))
14 compdef:40> ((  ! 11  ))
14 compdef:40> ((  ! 9  ))
14 compdef:40> ((  ! 9  ))
14 compdef:40> ((  ! 9  ))
14 compdef:40> ((  ! 8  ))
14 compdef:40> ((  ! 7  ))
14 compdef:40> ((  ! 7  ))
14 compdef:40> ((  ! 6  ))
14 compdef:40> ((  ! 5  ))
14 compdef:40> ((  ! 4  ))
14 compdef:40> ((  ! 4  ))
14 compdef:40> ((  ! 4  ))
14 compdef:40> ((  ! 4  ))
14 compdef:40> ((  ! 4  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 3  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:40> ((  ! 2  ))
14 compdef:38> shift OPTIND-1
14 compdef:26> [[ K = P ]]
14 compdef:24> [[ K = p ]]
14 compdef:18> [[ -n '' ]]
14 compdef:18> [[ -n '' ]]
14 compdef:17> new=yes
14 compdef:17> new=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:16> autol=yes
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (n)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case n (a)
14 compdef:15> case k ([pPkK])
14 compdef:15> case k ([pPkK])
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case a (a)
14 compdef:15> case P ([pPkK])
14 compdef:15> case P ([pPkK])
14 compdef:15> case K (a)
14 compdef:15> case K ([pPkK])
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compdef:14> getopts anpPkKde opt
14 compaudit:157> _i_q=''
14 compaudit:132> ((  0  ))
14 compaudit:53> [[ -z /usr/share/zsh/5.8.1/functions ]]
14 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;43m'
14 colors:115> bg_bold[${k#bg-}]=$'C-[[01;47m'
14 colors:115> bg_bold[${k#bg-}]=$'C-[[01;40m'
14 colors:114> bg[${k#bg-}]=$'C-[[49m'
14 colors:114> bg[${k#bg-}]=$'C-[[44m'
14 colors:114> bg[${k#bg-}]=$'C-[[43m'
14 colors:114> bg[${k#bg-}]=$'C-[[42m'
14 colors:114> bg[${k#bg-}]=$'C-[[41m'
14 colors:114> bg[${k#bg-}]=$'C-[[40m'
14 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;37m'
14 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;30m'
14 colors:106> fg_bold[${k#fg-}]=$'C-[[01;37m'
14 colors:106> fg_bold[${k#fg-}]=$'C-[[01;33m'
14 colors:105> fg[${k#fg-}]=$'C-[[39m'
14 colors:105> fg[${k#fg-}]=$'C-[[37m'
14 colors:105> fg[${k#fg-}]=$'C-[[36m'
14 colors:105> fg[${k#fg-}]=$'C-[[35m'
14 colors:105> fg[${k#fg-}]=$'C-[[34m'
14 colors:105> fg[${k#fg-}]=$'C-[[34m'
14 colors:105> fg[${k#fg-}]=$'C-[[30m'
14 colors:81> color[fg-${color[$k]}]=31
14 colors:81> color[fg-${color[$k]}]=30
14 colors:77> color[${color[$k]}]=43
14 colors:77> color[${color[$k]}]=07
14 antigen-add-hook:14> _ANTIGEN_HOOKS[$target]=antigen-lock
14 antigen-add-hook:14> _ANTIGEN_HOOKS[$target]=antigen-bundle-defer
14 antigen-add-hook:14> _ANTIGEN_HOOKS[$target]=antigen-apply-lock
14 antigen-add-hook:8> ((  ! 1  ))
14 antigen-add-hook:8> ((  ! 1  ))
14 add-zsh-hook:83> ((  1  ))
14 add-zsh-hook:57> ((  list  ))
14 add-zle-hook-widget:38> shift 0
14 _zsh_highlight_load_highlighters:13> highlighter=main
14 _zsh_highlight_load_highlighters:13> highlighter=line
14 _zsh_highlight_load_highlighters:13> highlighter=cursor
14 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
14 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
14 _zsh_highlight_bind_widgets:26> cur_widget=zle-line-init
14 _zsh_highlight_bind_widgets:26> cur_widget=zle-isearch-update
14 _zsh_highlight_bind_widgets:26> cur_widget=where-is
14 _zsh_highlight_bind_widgets:26> cur_widget=visual-line-mode
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-yank-eol
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-yank
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-up-case
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-set-buffer
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-rev-repeat-search
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-put-before
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-put-after
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-open-line-below
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-join
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-insert
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-indent
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-history-search-forward
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-goto-mark-line
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-goto-column
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-forward-blank-word
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-find-prev-char
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-find-next-char
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-end-of-line
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-down-case
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-digit-or-beginning-of-line
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-delete-char
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-delete
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-cmd-mode
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-change-whole-line
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-change
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-word-end
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-kill-word
14 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-char
14 _zsh_highlight_bind_widgets:26> cur_widget=up-line-or-beginning-search
14 _zsh_highlight_bind_widgets:26> cur_widget=up-line
14 _zsh_highlight_bind_widgets:26> cur_widget=universal-argument
14 _zsh_highlight_bind_widgets:26> cur_widget=undo
14 _zsh_highlight_bind_widgets:26> cur_widget=transpose-chars
14 _zsh_highlight_bind_widgets:26> cur_widget=self-insert
14 _zsh_highlight_bind_widgets:26> cur_widget=select-in-word
14 _zsh_highlight_bind_widgets:26> cur_widget=select-in-blank-word
14 _zsh_highlight_bind_widgets:26> cur_widget=select-a-blank-word
14 _zsh_highlight_bind_widgets:26> cur_widget=reverse-menu-complete
14 _zsh_highlight_bind_widgets:26> cur_widget=redo
14 _zsh_highlight_bind_widgets:26> cur_widget=redisplay
14 _zsh_highlight_bind_widgets:26> cur_widget=recursive-edit
14 _zsh_highlight_bind_widgets:26> cur_widget=read-command
14 _zsh_highlight_bind_widgets:26> cur_widget=quote-region
14 _zsh_highlight_bind_widgets:26> cur_widget=put-replace-selection
14 _zsh_highlight_bind_widgets:26> cur_widget=push-line
14 _zsh_highlight_bind_widgets:26> cur_widget=overwrite-mode
14 _zsh_highlight_bind_widgets:26> cur_widget=magic-space
14 _zsh_highlight_bind_widgets:26> cur_widget=kill-word
14 _zsh_highlight_bind_widgets:26> cur_widget=kill-whole-line
14 _zsh_highlight_bind_widgets:26> cur_widget=history-search-forward
14 _zsh_highlight_bind_widgets:26> cur_widget=history-search-backward
14 _zsh_highlight_bind_widgets:26> cur_widget=gosmacs-transpose-chars
14 _zsh_highlight_bind_widgets:26> cur_widget=expand-or-complete-prefix
14 _zsh_highlight_bind_widgets:26> cur_widget=expand-or-complete
14 _zsh_highlight_bind_widgets:26> cur_widget=expand-history
14 _zsh_highlight_bind_widgets:26> cur_widget=expand-cmd-path
14 _zsh_highlight_bind_widgets:26> cur_widget=execute-named-cmd
14 _zsh_highlight_bind_widgets:26> cur_widget=execute-last-named-cmd
14 _zsh_highlight_bind_widgets:26> cur_widget=end-of-line-hist
14 _zsh_highlight_bind_widgets:26> cur_widget=end-of-line
14 _zsh_highlight_bind_widgets:26> cur_widget=end-of-buffer-or-history
14 _zsh_highlight_bind_widgets:26> cur_widget=emacs-forward-word
14 _zsh_highlight_bind_widgets:26> cur_widget=down-line
14 _zsh_highlight_bind_widgets:26> cur_widget=down-history
14 _zsh_highlight_bind_widgets:26> cur_widget=delete-char-or-list
14 _zsh_highlight_bind_widgets:26> cur_widget=complete-word
14 _zsh_highlight_bind_widgets:26> cur_widget=capitalize-word
14 _zsh_highlight_bind_widgets:26> cur_widget=backward-kill-word
14 _zsh_highlight_bind_widgets:26> cur_widget=backward-kill-line
14 _zsh_highlight_bind_widgets:26> cur_widget=backward-delete-char
14 _zsh_highlight_bind_widgets:26> cur_widget=auto-suffix-retain
14 _zsh_highlight_bind_widgets:26> cur_widget=accept-line-and-down-history
14 _zsh_highlight_bind_widgets:26> cur_widget=accept-and-hold
14 _zsh_highlight_bind_widgets:26> cur_widget=_read_comp
14 _zsh_highlight_bind_widgets:26> cur_widget=_next_tags
14 _zsh_highlight_bind_widgets:26> cur_widget=_correct_filename
14 _zsh_highlight_bind_widgets:26> cur_widget=_complete_debug
14 _zsh_highlight_bind_widgets:26> cur_widget=_bash_complete-word
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
14 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:51> [[ -n '' ]]
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;248m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;240m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;228m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;222m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;220m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;212m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;207m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;200m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;198m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;188m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;181m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;176m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;173m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;171m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;158m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;156m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;147m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;141m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;139m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;137m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;135m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;131m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;130m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;124m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;122m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;115m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;110m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;108m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;106m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;097m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;095m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;091m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;089m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;080m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;077m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;075m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;072m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;065m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;063m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;056m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;055m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;053m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;050m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;048m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;043m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;040m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;034m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;033m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;023m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;022m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;020m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;017m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;010m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;009m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;007m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;006m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;004m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;003m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;002m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;254m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;235m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;231m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;226m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;221m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;219m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;216m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;211m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;208m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;201m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;190m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;185m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;181m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;157m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;148m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;142m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;140m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;138m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;136m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;133m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;132m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;126m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;125m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;121m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;111m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;109m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;107m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;105m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;101m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;098m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;096m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;092m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;090m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;088m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;087m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;081m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;078m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;076m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;066m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;064m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;062m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;058m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;057m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;051m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;049m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;045m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;044m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;024m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;021m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;016m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;014m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;011m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;008m%}'
14 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;005m%}'
14 /Users/matt/.oh-my-zsh/lib/history.zsh:32> [ 1000 -lt 10000 ']'
14 /Users/matt/.oh-my-zsh/lib/history.zsh:21> case  ()
14 /Users/matt/.iterm2_shell_integration.zsh:17> ITERM_SHELL_INTEGRATION_INSTALL...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
14 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:21> case ...
14 -antigen-parse-args:154> args[url]=''https://github.com/zsh-users/zsh-autosug...
14 -antigen-parse-args:154> args[url]=''https://github.com/robbyrussell/oh-my-zs...
14 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/zsh-users/zsh-aut...
14 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/robbyrussell/oh-m...
14 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/robbyrussell/oh-m...
14 -antigen-parse-args:137> [[ -n '' ]]
14 -antigen-parse-args:130> args[name]=robbyrussell/oh-my-zsh
14 -antigen-parse-args:130> args[name]=robbyrussell/oh-my-zsh
14 -antigen-parse-args:130> args[name]=robbyrussell/oh-my-zsh
14 -antigen-parse-args:124> name=zsh-users/zsh-syntax-highlighting
14 -antigen-parse-args:124> name=robbyrussell/oh-my-zsh
14 -antigen-parse-args:122> name=zsh-users/zsh-syntax-highlighting.git
14 -antigen-parse-args:122> name=zsh-users/zsh-autosuggestions.git
14 -antigen-parse-args:122> name=zsh-users/zsh-autosuggestions.git
14 -antigen-parse-args:118> local branch=''
14 -antigen-parse-args:99> [[ https://github.com/zsh-users/zsh-syntax-highlighti...
14 -antigen-parse-args:99> [[ https://github.com/zsh-users/zsh-syntax-highlighti...
14 -antigen-parse-args:99> [[ https://github.com/zsh-users/zsh-autosuggestions.g...
14 -antigen-parse-args:96> args[url]=https://github.com/zsh-users/zsh-syntax-hig...
14 -antigen-parse-args:96> args[url]=https://github.com/zsh-users/zsh-autosugges...
14 -antigen-parse-args:96> args[url]=https://github.com/robbyrussell/oh-my-zsh.git
14 -antigen-parse-args:69> [[ deno != */* ]]
14 -antigen-parse-args:65> shift
14 -antigen-parse-args:65> shift
14 -antigen-parse-args:65> shift
14 -antigen-parse-args:65> shift
14 -antigen-parse-args:40> key=url
14 -antigen-parse-args:40> key=url
14 -antigen-parse-args:37> value=zsh-users/zsh-syntax-highlighting
14 -antigen-parse-args:37> value=zsh-users/zsh-syntax-highlighting
14 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--url | --loc | -...
14 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (*)
14 -antigen-parse-args:22> case deno (*)
14 -antigen-parse-args:20> value=deno
14 -antigen-parse-args:19> key=loc
14 -antigen-parse-args:19> key=loc
14 -antigen-parse-args:18> argkey=deno
14 -antigen-parse-args:13> args[make_local_clone]=true
14 -antigen-parse-args:13> args[make_local_clone]=true
14 -antigen-parse-args:13> args[make_local_clone]=true
14 -antigen-parse-args:13> args[make_local_clone]=true
14 -antigen-parse-args:9> typeset -A args
14 -antigen-parse-args:9> typeset -A args
14 -antigen-load:15> [[ plugin == theme ]]
14 -antigen-load:15> [[ plugin == theme ]]
14 -antigen-load:15> [[ plugin == theme ]]
14 -antigen-load-env-cached:6> [[ / == / ]]
14 -antigen-load-env-cached:6> [[ / == / ]]
14 -antigen-hook-handler:46> replace_hook=1
14 -antigen-hook-handler:22> case replace (pre)
14 -antigen-hook-handler:22> case replace (pre)
14 -antigen-hook-handler:22> case replace (pre)
14 -antigen-hook-handler:22> case replace (pre)
14 -antigen-hook-handler:22> case replace (pre)
14 -antigen-hook-handler:22> case pre (pre)
14 -antigen-hook-handler:22> case post (pre)
14 -antigen-hook-handler:10> hook=-antigen-load-env-cached
14 -antigen-hook-handler:7> typeset -a hooks
14 -antigen-hook-handler:7> typeset -a hooks
14 -antigen-hook-handler:7> typeset -a hooks
14 -antigen-hook-antigen:7> shift
14 -antigen-hook-antigen:7> shift
14 (eval):223> alias 'it2ul=/Users/matt/.iterm2/it2ul'
14 (eval):220> alias 'it2git=/Users/matt/.iterm2/it2git'
14 (eval):218> alias 'it2dl=/Users/matt/.iterm2/it2dl'
14 (eval):217> alias 'it2copy=/Users/matt/.iterm2/it2copy'
14 (eval):213> alias 'imgls=/Users/matt/.iterm2/imgls'
14 (eval):211> alias 'history=omz_history'
14 (eval):207> alias 'gupav=git pull --rebase --autostash -v'
14 (eval):204> alias 'gunwip=git log -n 1 | grep -q -c "--wip--" && git reset HE...
14 (eval):198> alias 'gswd=git switch $(git_develop_branch)'
14 (eval):194> alias 'gstu=gsta --include-untracked'
14 (eval):192> alias 'gsts=git stash show --text'
14 (eval):190> alias 'l=ls -lah'
14 (eval):185> alias 'gupav=git pull --rebase --autostash -v'
14 (eval):183> alias 'gup=git pull --rebase'
14 (eval):183> alias 'gss=git status -s'
14 (eval):180> alias 'gsi=git submodule init'
14 (eval):173> alias 'grt=cd "$(git rev-parse --show-toplevel || echo .)"'
14 (eval):171> alias 'gsts=git stash show --text'
14 (eval):170> alias 'grset=git remote set-url'
14 (eval):163> alias 'gst=git status'
14 (eval):160> alias 'gsps=git show --pretty=short --show-signature'
14 (eval):158> alias 'grbom=git rebase origin/$(git_main_branch)'
14 (eval):155> alias 'grv=git remote -v'
14 (eval):154> alias 'grup=git remote update'
14 (eval):153> alias 'grbc=git rebase --continue'
14 (eval):148> alias 'gpv=git push -v'
14 (eval):147> alias 'grrm=git remote remove'
14 (eval):145> alias 'gpristine=git reset --hard && git clean -dffx'
14 (eval):138> alias 'gop=git push'
14 (eval):132> alias 'grbc=git rebase --continue'
14 (eval):130> alias 'glum=git pull upstream $(git_main_branch)'
14 (eval):124> alias 'glog=git log --oneline --decorate --graph'
14 (eval):123> alias 'gpr=git pull --rebase'
14 (eval):121> alias 'gpf!=git push --force'
14 (eval):119> alias 'gpd=git push --dry-run'
14 (eval):119> alias 'glgm=git log --graph --max-count=10'
14 (eval):117> alias 'gmum=git merge upstream/$(git_main_branch)'
14 (eval):117> alias 'glgg=git log --graph'
14 (eval):114> alias 'gmom=git merge origin/$(git_main_branch)'
14 (eval):114> alias 'gke=gitk --all $(git log -g --pretty=%h) &!'
14 (eval):111> alias 'glum=git pull upstream $(git_main_branch)'
14 (eval):106> alias 'gloga=git log --oneline --decorate --graph --all'
14 (eval):105> alias 'glog=git log --oneline --decorate --graph'
14 (eval):105> alias 'ggpull=git pull origin "$(git_current_branch)"'
14 (eval):102> alias 'glo=git log --oneline --decorate'
14 (eval):100> alias 'gfa=git fetch --all --prune --jobs=10'
14 (eval):98> alias 'glgg=git log --graph'
14 (eval):95> alias 'gke=gitk --all $(git log -g --pretty=%h) &!'
14 (eval):91> alias 'gd=git diff'
14 (eval):87> alias 'ggpur=ggu'
14 (eval):85> alias 'gga=git gui citool --amend'
14 (eval):84> alias 'gcp=git cherry-pick'
14 (eval):83> alias 'gfo=git fetch origin'
14 (eval):82> alias 'gcor=git checkout --recurse-submodules'
14 (eval):79> alias 'gdw=git diff --word-diff'
14 (eval):77> alias 'gdt=git diff-tree --no-commit-id --name-only -r'
14 (eval):75> alias 'gdcw=git diff --cached --word-diff'
14 (eval):75> alias 'gcf=git config --list'
14 (eval):70> alias 'gcss=git commit -S -s'
14 (eval):70> alias 'gcans!=git commit -v -a -s --no-edit --amend'
14 (eval):65> alias 'gcp=git cherry-pick'
14 (eval):64> alias 'gcount=git shortlog -sn'
14 (eval):63> alias 'gcor=git checkout --recurse-submodules'
14 (eval):58> alias 'gclean=git clean -id'
14 (eval):53> alias 'gba=git branch -a'
14 (eval):49> alias 'gcam=git commit -a -m'
14 (eval):38> alias 'gbnm=git branch --no-merged'
14 (eval):35> alias 'gbd=git branch -d'
14 (eval):30> alias 'gau=git add --update'
14 (eval):26> alias 'gamscp=git am --show-current-patch'
14 (eval):25> alias 'dfmt=deno fmt'
14 (eval):22> alias 'gam=git am'
14 (eval):5> alias -g '......=../../../../..'
14 (eval):3> alias -g '....=../../..'
14 (eval):1> test -z ''
14 (eval):1> test -z ''
14 (eval):1> test -z ''
14 (eval):1> test -z ''
14 (eval):1> test -z ''
14 (eval):1> test -z ''
14 (anon):32> action=suggest
14 (anon):32> action=enable
14 (anon):32> action=accept
13 is-at-least:50> [[ 8 = <-> ]]
13 is-at-least:50> [[ 4 = <-> ]]
13 is-at-least:48> true
13 is-at-least:48> true
13 is-at-least:48> true
13 is-at-least:48> true
13 is-at-least:45> part=8
13 is-at-least:45> part=8
13 is-at-least:45> part=5
13 is-at-least:33> [[ 36 = *[0-9][^0-9]* ]]
13 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
13 is-at-least:33> [[ 2 = *[0-9][^0-9]* ]]
13 is-at-least:32> ((  ++ver_cnt > 4  ))
13 is-at-least:32> ((  ++ver_cnt > 4  ))
13 is-at-least:31> [[ '' != <-> ]]
13 is-at-least:30> ((  0 <= 3  ))
13 complete:6> [[ -n '' ]]
13 compinit:530> _i_line=reverse-menu-complete
13 compinit:516> [[ '' !=  # ]]
13 compinit:516> [[ '' !=  # ]]
13 compinit:516> [[ '' !=  # ]]
13 compinit:516> [[ '' !=  # ]]
13 compinit:516> [[ '' !=  # ]]
13 compinit:515> autoload -Uz _setup
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #compdef (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:506> case #autoload (#compdef)
13 compinit:501> continue
13 compinit:500> _i_name=_zpty
13 compinit:500> _i_name=_xrandr
13 compinit:500> _i_name=_xpdf
13 compinit:500> _i_name=_xmodmap
13 compinit:500> _i_name=_xloadimage
13 compinit:500> _i_name=_xinput
13 compinit:500> _i_name=_x_selection_timeout
13 compinit:500> _i_name=_x_name
13 compinit:500> _i_name=_x_font
13 compinit:500> _i_name=_x_display
13 compinit:500> _i_name=_x_borderwidth
13 compinit:500> _i_name=_whereis
13 compinit:500> _i_name=_wget
13 compinit:500> _i_name=_twisted
13 compinit:500> _i_name=_thor
13 compinit:500> _i_name=_tcptraceroute
13 compinit:500> _i_name=_systat
13 compinit:500> _i_name=_swaks
13 compinit:500> _i_name=_supervisorctl
13 compinit:500> _i_name=_subl
13 compinit:500> _i_name=_setup.py
13 compinit:500> _i_name=_seafile
13 compinit:500> _i_name=_schedtool
13 compinit:500> _i_name=_remote_files
13 compinit:500> _i_name=_regex_words
13 compinit:500> _i_name=_redis-cli
13 compinit:500> _i_name=_protoc
13 compinit:500> _i_name=_portlint
13 compinit:500> _i_name=_portaudit
13 compinit:500> _i_name=_pipenv
13 compinit:500> _i_name=_pfexec
13 compinit:500> _i_name=_perl_basepods
13 compinit:500> _i_name=_pdf
13 compinit:500> _i_name=_object_files
13 compinit:500> _i_name=_objdump
13 compinit:500> _i_name=_networksetup
13 compinit:500> _i_name=_netstat
13 compinit:500> _i_name=_nanoc
13 compinit:500> _i_name=_mosh
13 compinit:500> _i_name=_monotone
13 compinit:500> _i_name=_modutils
13 compinit:500> _i_name=_mkzsh
13 compinit:500> _i_name=_mkdir
13 compinit:500> _i_name=_mina
13 compinit:500> _i_name=_meson
13 compinit:500> _i_name=_menu
13 compinit:500> _i_name=_mdadm
13 compinit:500> _i_name=_man
13 compinit:500> _i_name=_mac_applications
13 compinit:500> _i_name=_lintian
13 compinit:500> _i_name=_less
13 compinit:500> _i_name=_ldap
13 compinit:500> _i_name=_last
13 compinit:500> _i_name=_kdeconnect
13 compinit:500> _i_name=_jq
13 compinit:500> _i_name=_join
13 compinit:500> _i_name=_jobs_bg
13 compinit:500> _i_name=_inxi
13 compinit:500> _i_name=_ignored
13 compinit:500> _i_name=_hwinfo
13 compinit:500> _i_name=_host
13 compinit:500> _i_name=_history_complete_word
13 compinit:500> _i_name=_helm
13 compinit:500> _i_name=_hash
13 compinit:500> _i_name=_gzip
13 compinit:500> _i_name=_grep
13 compinit:500> _i_name=_gradle
13 compinit:500> _i_name=_globqual_delims
13 compinit:500> _i_name=_globflags
13 compinit:500> _i_name=_git-flow
13 compinit:500> _i_name=_ghostscript
13 compinit:500> _i_name=_fuser
13 compinit:500> _i_name=_fuse_arguments
13 compinit:500> _i_name=_fstat
13 compinit:500> _i_name=_fmadm
13 compinit:500> _i_name=_floppy
13 compinit:500> _i_name=_fink
13 compinit:500> _i_name=_file_flags
13 compinit:500> _i_name=_fetch
13 compinit:500> _i_name=_feh
13 compinit:500> _i_name=_fbsd_device_types
13 compinit:500> _i_name=_email_addresses
13 compinit:500> _i_name=_ecasound
13 compinit:500> _i_name=_dtruss
13 compinit:500> _i_name=_dpkg
13 compinit:500> _i_name=_doas
13 compinit:500> _i_name=_dmidecode
13 compinit:500> _i_name=_dmesg
13 compinit:500> _i_name=_directories
13 compinit:500> _i_name=_dhclient
13 compinit:500> _i_name=_date_formats
13 compinit:500> _i_name=_date
13 compinit:500> _i_name=_cygstart
13 compinit:500> _i_name=_cygserver
13 compinit:500> _i_name=_cygcheck
13 compinit:500> _i_name=_cu
13 compinit:500> _i_name=_cpupower
13 compinit:500> _i_name=_cowsay
13 compinit:500> _i_name=_configure
13 compinit:500> _i_name=_complete
13 compinit:500> _i_name=_command
13 compinit:500> _i_name=_comm
13 compinit:500> _i_name=_cockroach
13 compinit:500> _i_name=_cmp
13 compinit:500> _i_name=_cmake
13 compinit:500> _i_name=_choc
13 compinit:500> _i_name=_bpf_filters
13 compinit:500> _i_name=_bash_completions
13 compinit:500> _i_name=_autocd
13 compinit:500> _i_name=_assign
13 compinit:500> _i_name=_arch_archives
13 compinit:500> _i_name=_add-zle-hook-widget
13 compinit:500> _i_name=_acpitool
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zpty
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zlogin
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zle
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zargs
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xv
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xrandr
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xfig
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_utils
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_selection_timeout
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_locale
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_keysym
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_geometry
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_font
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_who
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_which
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wajig
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_volume_groups
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vnc
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vars
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_values
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_urxvt
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_urls
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_units
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_typeset
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tracepath
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tpb
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_top
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tilde
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tidy
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tac
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_swift
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_subscript
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sub_commands
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_su
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_stgit
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_spamassassin
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_shuf
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_schedtool
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_redirect
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rebootin
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rdesktop
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rar
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_quilt
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ptree
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pspdf
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_prstat
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_process_names
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_prefix
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_precommand
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pfexec
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pfctl
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_perl_basepods
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_osc
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_open
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_okular
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_object_files
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_numfmt
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nmap
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nice
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mysql_utils
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mv
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mosh
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mkshortcut
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_message
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_menu
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_members
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lzop
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_less
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kpartx
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kld
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_joe
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iwconfig
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iconvconfig
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hash
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gzip
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_graphicsmagick
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gqview
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gphoto2
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gpasswd
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getfacl
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fstat
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fmt
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_floppy
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_find_net_interfaces
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fetchmail
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_feh
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ecasound
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dtruss
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpkg-cross
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpkg
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dpatch-edit-patch
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dhclient
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dchroot
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cygstart
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_complete_tag
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bug
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_base64
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_axi-cache
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_avahi
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_autocd
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apt-file
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ansible
13 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_adb
13 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_pipenv
13 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_gh
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
13 compinit:499> _i_file=/Users/matt/.oh-my-zsh/cache/completions/_deno
13 compinit:477> _i_done=''
13 compinit:443> _i_wfiles=( )
13 compinit:442> _i_wdirs=( )
13 compdump:121> shift _d_als
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:117> _i=5
13 compdump:116> ((  ! --_i && 1050 > 1  ))
13 compdump:116> ((  ! --_i && 874 > 1  ))
13 compdump:116> ((  ! --_i && 564 > 1  ))
13 compdump:116> ((  ! --_i && 364 > 1  ))
13 compdump:116> ((  ! --_i && 319 > 1  ))
13 compdump:116> ((  ! --_i && 79 > 1  ))
13 compdump:113> ((  1051  ))
13 compdump:113> ((  1049  ))
13 compdump:113> ((  1029  ))
13 compdump:113> ((  1027  ))
13 compdump:113> ((  1024  ))
13 compdump:113> ((  1017  ))
13 compdump:113> ((  991  ))
13 compdump:113> ((  984  ))
13 compdump:113> ((  923  ))
13 compdump:113> ((  913  ))
13 compdump:113> ((  875  ))
13 compdump:113> ((  871  ))
13 compdump:113> ((  862  ))
13 compdump:113> ((  855  ))
13 compdump:113> ((  851  ))
13 compdump:113> ((  840  ))
13 compdump:113> ((  836  ))
13 compdump:113> ((  826  ))
13 compdump:113> ((  816  ))
13 compdump:113> ((  784  ))
13 compdump:113> ((  516  ))
13 compdump:113> ((  502  ))
13 compdump:113> ((  389  ))
13 compdump:113> ((  272  ))
13 compdump:113> ((  248  ))
13 compdump:113> ((  50  ))
13 compdump:49> _d_f=zf_chown
13 compdump:49> _d_f=xetex
13 compdump:49> _d_f=ggu
13 compdump:43> _d_f=zsetattr
13 compdump:43> _d_f=zipinfo
13 compdump:43> _d_f=zed
13 compdump:43> _d_f=zcat
13 compdump:43> _d_f=xz
13 compdump:43> _d_f=watch
13 compdump:43> _d_f=urpme
13 compdump:43> _d_f=uptime
13 compdump:43> _d_f=unxz
13 compdump:43> _d_f=unpigz
13 compdump:43> _d_f=unget
13 compdump:43> _d_f=unfunction
13 compdump:43> _d_f=ulimit
13 compdump:43> _d_f=tty
13 compdump:43> _d_f=tox
13 compdump:43> _d_f=todo.sh
13 compdump:43> _d_f=tla
13 compdump:43> _d_f=timeout
13 compdump:43> _d_f=time
13 compdump:43> _d_f=texi2pdf
13 compdump:43> _d_f=teamocil
13 compdump:43> _d_f=tail
13 compdump:43> _d_f=stg
13 compdump:43> _d_f=sftp
13 compdump:43> _d_f=setopt
13 compdump:43> _d_f=rpmsign
13 compdump:43> _d_f=rpmquery
13 compdump:43> _d_f=rpmkeys
13 compdump:43> _d_f=rpmbuild
13 compdump:43> _d_f=rpm
13 compdump:43> _d_f=route
13 compdump:43> _d_f=rmmod
13 compdump:43> _d_f=rmm
13 compdump:43> _d_f=rmid
13 compdump:43> _d_f=rmic
13 compdump:43> _d_f=rmf
13 compdump:43> _d_f=pfiles
13 compdump:43> _d_f=numfmt
13 compdump:43> _d_f=nm
13 compdump:43> _d_f=nail
13 compdump:43> _d_f=mpc
13 compdump:43> _d_f=moosic
13 compdump:43> _d_f=modinfo
13 compdump:43> _d_f=mmove
13 compdump:43> _d_f=mixerctl
13 compdump:43> _d_f=mix
13 compdump:43> _d_f=metaflac
13 compdump:43> _d_f=mdir
13 compdump:43> _d_f=mdadm
13 compdump:43> _d_f=magnum
13 compdump:43> _d_f=lsblk
13 compdump:43> _d_f=lsattr
13 compdump:43> _d_f=ls
13 compdump:43> _d_f=lpstat
13 compdump:43> _d_f=lprm
13 compdump:43> _d_f=lpr
13 compdump:43> _d_f=lp
13 compdump:43> _d_f=llvm-otool
13 compdump:43> _d_f=lighty-enable-mod
13 compdump:43> _d_f=knock
13 compdump:43> _d_f=knife
13 compdump:43> _d_f=killall
13 compdump:43> _d_f=kill
13 compdump:43> _d_f=jadetex
13 compdump:43> _d_f=ijoin
13 compdump:43> _d_f=gvimdiff
13 compdump:43> _d_f=guilt-refresh
13 compdump:43> _d_f=guilt-rebase
13 compdump:43> _d_f=guilt-init
13 compdump:43> _d_f=guilt-help
13 compdump:43> _d_f=gseq
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:169> shift
13 compdef:164> [[ -n yes ]]
13 compdef:164> [[ -n '' ]]
13 compdef:163> _comps[$cmd]=_ssh
13 compdef:163> _comps[$cmd]=_compress
13 compdef:163> _comps[$cmd]=_bzip2
13 compdef:162> [[ -z yes || -z '' ]]
13 compdef:162> [[ -z yes || -z '' ]]
13 compdef:162> [[ -z yes || -z '' ]]
13 compdef:162> [[ -z '' ]]
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:160> svc=''
13 compdef:159> cmd=zsh-mime-handler
13 compdef:159> cmd=zlistattr
13 compdef:159> cmd=xcode-select
13 compdef:159> cmd=xautolock
13 compdef:159> cmd=wiggle
13 compdef:159> cmd=tunctl
13 compdef:159> cmd=trash-empty
13 compdef:159> cmd=top
13 compdef:159> cmd=todo
13 compdef:159> cmd=tla
13 compdef:159> cmd=tdd
13 compdef:159> cmd=tcp_open
13 compdef:159> cmd=sv
13 compdef:159> cmd=snap
13 compdef:159> cmd=setup.py
13 compdef:159> cmd=rec
13 compdef:159> cmd=ralio
13 compdef:159> cmd=pygmentize
13 compdef:159> cmd=pump
13 compdef:159> cmd=portsnap
13 compdef:159> cmd=perl
13 compdef:159> cmd=mdeltree
13 compdef:159> cmd=lighty-enable-mod
13 compdef:159> cmd=let
13 compdef:159> cmd=kitchen
13 compdef:159> cmd=iwconfig
13 compdef:159> cmd=iconvconfig
13 compdef:159> cmd=guilt-fold
13 compdef:159> cmd=guilt-applied
13 compdef:159> cmd=guilt-add
13 compdef:159> cmd=gnocchi
13 compdef:159> cmd=gcksum
13 compdef:159> cmd=freebsd-make
13 compdef:159> cmd=fortune
13 compdef:159> cmd=evince
13 compdef:159> cmd=ethtool
13 compdef:159> cmd=dumper
13 compdef:159> cmd=drill
13 compdef:159> cmd=defaults
13 compdef:159> cmd=debchange
13 compdef:159> cmd=dconf
13 compdef:159> cmd=cygstart
13 compdef:159> cmd=crontab
13 compdef:159> cmd=comb
13 compdef:159> cmd=caffeinate
13 compdef:159> cmd=a2dissite
13 compdef:159> cmd=-value-,WWW_HOME,-default-
13 compdef:157> svc=yes
13 compdef:156> cmd=tunes2pod.pl
13 compdef:156> cmd=slogin
13 compdef:156> cmd=mktunes.pl
13 compdef:156> cmd=gnupod_INIT.pl
13 compdef:156> cmd=ggp
13 compdef:156> cmd=gccd
13 compdef:156> cmd=bzcat
13 compdef:156> cmd='-redirect-,<,xz'
13 compdef:156> cmd='-redirect-,<,compress'
13 compdef:155> [[ zln = *=* ]]
13 compdef:155> [[ zip = *=* ]]
13 compdef:155> [[ zgrep = *=* ]]
13 compdef:155> [[ yum = *=* ]]
13 compdef:155> [[ xwininfo = *=* ]]
13 compdef:155> [[ xview = *=* ]]
13 compdef:155> [[ xterm = *=* ]]
13 compdef:155> [[ xsetbg = *=* ]]
13 compdef:155> [[ xset = *=* ]]
13 compdef:155> [[ xloadimage = *=* ]]
13 compdef:155> [[ write = *=* ]]
13 compdef:155> [[ which = *=* ]]
13 compdef:155> [[ wget = *=* ]]
13 compdef:155> [[ wc = *=* ]]
13 compdef:155> [[ wanna-build = *=* ]]
13 compdef:155> [[ wait = *=* ]]
13 compdef:155> [[ w = *=* ]]
13 compdef:155> [[ vpnc = *=* ]]
13 compdef:155> [[ useradd = *=* ]]
13 compdef:155> [[ uptime = *=* ]]
13 compdef:155> [[ unix2dos = *=* ]]
13 compdef:155> [[ unace = *=* ]]
13 compdef:155> [[ ulimit = *=* ]]
13 compdef:155> [[ twist = *=* ]]
13 compdef:155> [[ trash = *=* ]]
13 compdef:155> [[ totdconfig = *=* ]]
13 compdef:155> [[ toilet = *=* ]]
13 compdef:155> [[ todo = *=* ]]
13 compdef:155> [[ timeout = *=* ]]
13 compdef:155> [[ tee = *=* ]]
13 compdef:155> [[ tde = *=* ]]
13 compdef:155> [[ tcptraceroute = *=* ]]
13 compdef:155> [[ svcs = *=* ]]
13 compdef:155> [[ sudo = *=* ]]
13 compdef:155> [[ sr = *=* ]]
13 compdef:155> [[ sqsh = *=* ]]
13 compdef:155> [[ sha512sum = *=* ]]
13 compdef:155> [[ sha224sum = *=* ]]
13 compdef:155> [[ sh = *=* ]]
13 compdef:155> [[ sched = *=* ]]
13 compdef:155> [[ rmiregistry = *=* ]]
13 compdef:155> [[ rmd160 = *=* ]]
13 compdef:155> [[ renice = *=* ]]
13 compdef:155> [[ qtplay = *=* ]]
13 compdef:155> [[ pkginfo = *=* ]]
13 compdef:155> [[ pkg_add = *=* ]]
13 compdef:155> [[ pidstat = *=* ]]
13 compdef:155> [[ pg_dumpall = *=* ]]
13 compdef:155> [[ perldoc = *=* ]]
13 compdef:155> [[ pdftk = *=* ]]
13 compdef:155> [[ paste = *=* ]]
13 compdef:155> [[ p4 = *=* ]]
13 compdef:155> [[ osascript = *=* ]]
13 compdef:155> [[ nvram = *=* ]]
13 compdef:155> [[ numfmt = *=* ]]
13 compdef:155> [[ new = *=* ]]
13 compdef:155> [[ ncal = *=* ]]
13 compdef:155> [[ mysqldiff = *=* ]]
13 compdef:155> [[ mv = *=* ]]
13 compdef:155> [[ mupdf = *=* ]]
13 compdef:155> [[ mtn = *=* ]]
13 compdef:155> [[ mplayer = *=* ]]
13 compdef:155> [[ mozilla-xremote-client = *=* ]]
13 compdef:155> [[ mondoarchive = *=* ]]
13 compdef:155> [[ module = *=* ]]
13 compdef:155> [[ mencal = *=* ]]
13 compdef:155> [[ mattrib = *=* ]]
13 compdef:155> [[ lz4 = *=* ]]
13 compdef:155> [[ luarocks = *=* ]]
13 compdef:155> [[ lsblk = *=* ]]
13 compdef:155> [[ losetup = *=* ]]
13 compdef:155> [[ linux = *=* ]]
13 compdef:155> [[ lighty-disable-mod = *=* ]]
13 compdef:155> [[ kpartx = *=* ]]
13 compdef:155> [[ kldload = *=* ]]
13 compdef:155> [[ kak = *=* ]]
13 compdef:155> [[ jot = *=* ]]
13 compdef:155> [[ joe = *=* ]]
13 compdef:155> [[ iwconfig = *=* ]]
13 compdef:155> [[ ifup = *=* ]]
13 compdef:155> [[ hdiutil = *=* ]]
13 compdef:155> [[ guniq = *=* ]]
13 compdef:155> [[ guilt-unapplied = *=* ]]
13 compdef:155> [[ guilt-status = *=* ]]
13 compdef:155> [[ guilt-series = *=* ]]
13 compdef:155> [[ guilt-rebase = *=* ]]
13 compdef:155> [[ guilt-push = *=* ]]
13 compdef:155> [[ guilt-header = *=* ]]
13 compdef:155> [[ guilt-fork = *=* ]]
13 compdef:155> [[ guilt-add = *=* ]]
13 compdef:155> [[ gtk-launch = *=* ]]
13 compdef:155> [[ gsum = *=* ]]
13 compdef:155> [[ gsha256sum = *=* ]]
13 compdef:155> [[ gsha224sum = *=* ]]
13 compdef:155> [[ groff = *=* ]]
13 compdef:155> [[ gpasswd = *=* ]]
13 compdef:155> [[ google = *=* ]]
13 compdef:155> [[ gm = *=* ]]
13 compdef:155> [[ gln = *=* ]]
13 compdef:155> [[ gitk = *=* ]]
13 compdef:155> [[ git-journal = *=* ]]
13 compdef:155> [[ git-flow = *=* ]]
13 compdef:155> [[ getent = *=* ]]
13 compdef:155> [[ gcmp = *=* ]]
13 compdef:155> [[ gchroot = *=* ]]
13 compdef:155> [[ fuser = *=* ]]
13 compdef:155> [[ freebsd-update = *=* ]]
13 compdef:155> [[ force = *=* ]]
13 compdef:155> [[ fned = *=* ]]
13 compdef:155> [[ fmt = *=* ]]
13 compdef:155> [[ dvipdf = *=* ]]
13 compdef:155> [[ dvidvi = *=* ]]
13 compdef:155> [[ dpkg-reconfigure = *=* ]]
13 compdef:155> [[ dget = *=* ]]
13 compdef:155> [[ designate = *=* ]]
13 compdef:155> [[ dcopclient = *=* ]]
13 compdef:155> [[ dad = *=* ]]
13 compdef:155> [[ cygserver.exe = *=* ]]
13 compdef:155> [[ composer = *=* ]]
13 compdef:155> [[ cmake = *=* ]]
13 compdef:155> [[ clusterdb = *=* ]]
13 compdef:155> [[ chdir = *=* ]]
13 compdef:155> [[ btdownloadcurses = *=* ]]
13 compdef:155> [[ bpython2-urwid = *=* ]]
13 compdef:155> [[ bitcoin-cli = *=* ]]
13 compdef:155> [[ baz = *=* ]]
13 compdef:155> [[ bash = *=* ]]
13 compdef:155> [[ aws = *=* ]]
13 compdef:155> [[ atach = *=* ]]
13 compdef:155> [[ asdf = *=* ]]
13 compdef:155> [[ aodh = *=* ]]
13 compdef:155> [[ android = *=* ]]
13 compdef:155> [[ add-zsh-hook = *=* ]]
13 compdef:155> [[ add-zle-hook-widget = *=* ]]
13 compdef:155> [[ _cockroach = *=* ]]
13 compdef:155> [[ -value-,VALGRIND_OPTS,-default- = *=* ]]
13 compdef:155> [[ -value-,LESSCHARSET,-default- = *=* ]]
13 compdef:155> [[ -redirect- = *=* ]]
13 compdef:155> [[ 'gzcat=gunzip' = *=* ]]
13 compdef:155> [[ 'gnupod_check.pl=gnupod_check' = *=* ]]
13 compdef:155> [[ 'gnupod_addsong.pl=gnupod_addsong' = *=* ]]
13 compdef:155> [[ 'ggu=git-checkout' = *=* ]]
13 compdef:155> [[ '_git_log_prettily=git-log' = *=* ]]
13 compdef:155> [[ '-redirect-,>,gzip=gunzip' = *=* ]]
13 compdef:155> [[ '-redirect-,>,bzip2=bunzip2' = *=* ]]
13 compdef:155> [[ '-redirect-,<,gunzip=gunzip' = *=* ]]
13 compdef:148> [[ 'qemu(|-system-*)' = (#b)(*)=(*) ]]
13 compdef:148> [[ '(p[bgpn]m*|*top[bgpn]m)' = (#b)(*)=(*) ]]
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (postpattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (pattern)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:139> case  (*)
13 compdef:136> [[ zsocket = -P ]]
13 compdef:136> [[ zsh-mime-handler = -P ]]
13 compdef:136> [[ zle = -P ]]
13 compdef:136> [[ zf_chmod = -P ]]
13 compdef:136> [[ zcash-cli = -P ]]
13 compdef:136> [[ xml = -P ]]
13 compdef:136> [[ xlsclients = -P ]]
13 compdef:136> [[ xloadimage = -P ]]
13 compdef:136> [[ xdpyinfo = -P ]]
13 compdef:136> [[ xclip = -P ]]
13 compdef:136> [[ wpa_cli = -P ]]
13 compdef:136> [[ wiggle = -P ]]
13 compdef:136> [[ usermod = -P ]]
13 compdef:136> [[ snap = -P ]]
13 compdef:136> [[ sha512sum = -P ]]
13 compdef:136> [[ sha224sum = -P ]]
13 compdef:136> [[ setup.py = -P ]]
13 compdef:136> [[ scalac = -P ]]
13 compdef:136> [[ rxvt = -P ]]
13 compdef:136> [[ rsvm = -P ]]
13 compdef:136> [[ redis-cli = -P ]]
13 compdef:136> [[ rcctl = -P ]]
13 compdef:136> [[ psql = -P ]]
13 compdef:136> [[ pipenv = -P ]]
13 compdef:136> [[ phing = -P ]]
13 compdef:136> [[ periscope = -P ]]
13 compdef:136> [[ perf = -P ]]
13 compdef:136> [[ odmget = -P ]]
13 compdef:136> [[ ninja = -P ]]
13 compdef:136> [[ nice = -P ]]
13 compdef:136> [[ mullvad = -P ]]
13 compdef:136> [[ mdfind = -P ]]
13 compdef:136> [[ mc = -P ]]
13 compdef:136> [[ lsattr = -P ]]
13 compdef:136> [[ last = -P ]]
13 compdef:136> [[ jobs = -P ]]
13 compdef:136> [[ iconvconfig = -P ]]
13 compdef:136> [[ gzip = -P ]]
13 compdef:136> [[ guilt-prev = -P ]]
13 compdef:136> [[ guilt-fork = -P ]]
13 compdef:136> [[ guilt-applied = -P ]]
13 compdef:136> [[ guilt-add = -P ]]
13 compdef:136> [[ guilt = -P ]]
13 compdef:136> [[ gsha256sum = -P ]]
13 compdef:136> [[ gsha224sum = -P ]]
13 compdef:136> [[ gqview = -P ]]
13 compdef:136> [[ ftp = -P ]]
13 compdef:136> [[ figlet = -P ]]
13 compdef:136> [[ exec = -P ]]
13 compdef:136> [[ etags = -P ]]
13 compdef:136> [[ eog = -P ]]
13 compdef:136> [[ entr = -P ]]
13 compdef:136> [[ ecasound = -P ]]
13 compdef:136> [[ dvicopy = -P ]]
13 compdef:136> [[ dumpadm = -P ]]
13 compdef:136> [[ dpkg-repack = -P ]]
13 compdef:136> [[ diffstat = -P ]]
13 compdef:136> [[ dhcpinfo = -P ]]
13 compdef:136> [[ designate = -P ]]
13 compdef:136> [[ deborphan = -P ]]
13 compdef:136> [[ debfoster = -P ]]
13 compdef:136> [[ dd = -P ]]
13 compdef:136> [[ dbus-launch = -P ]]
13 compdef:136> [[ cygstart = -P ]]
13 compdef:136> [[ cygserver.exe = -P ]]
13 compdef:136> [[ cygserver = -P ]]
13 compdef:136> [[ cygcheck.exe = -P ]]
13 compdef:136> [[ cut = -P ]]
13 compdef:136> [[ cu = -P ]]
13 compdef:136> [[ cryptsetup = -P ]]
13 compdef:136> [[ crontab = -P ]]
13 compdef:136> [[ convert = -P ]]
13 compdef:136> [[ compdef = -P ]]
13 compdef:136> [[ cloudkitty = -P ]]
13 compdef:136> [[ cksum = -P ]]
13 compdef:136> [[ chcon = -P ]]
13 compdef:136> [[ cdrdao = -P ]]
13 compdef:136> [[ cat = -P ]]
13 compdef:136> [[ -value-,WWW_HOME,-default- = -P ]]
13 compdef:136> [[ -value-,GZIP,-default- = -P ]]
13 compdef:136> [[ -value-,ANSIBLE_STDOUT_CALLBACK,-default- = -P ]]
13 compdef:136> [[ -value-,ANDROID_SERIAL,-default- = -P ]]
13 compdef:136> [[ -redirect-,-default-,-default- = -P ]]
13 compdef:136> [[ 'zf_chgrp=chgrp' = -P ]]
13 compdef:136> [[ 'gchgrp=chgrp' = -P ]]
13 compdef:136> [[ '-redirect-,<,gzip=gzip' = -P ]]
13 compdef:136> [[ '*/X11(|R<4->)/*' = -P ]]
13 compdef:134> [[ zsocket = -p ]]
13 compdef:134> [[ zsh = -p ]]
13 compdef:134> [[ zpool = -p ]]
13 compdef:134> [[ zparseopts = -p ]]
13 compdef:134> [[ zoneadm = -p ]]
13 compdef:134> [[ zmv = -p ]]
13 compdef:134> [[ yaourt = -p ]]
13 compdef:134> [[ xsel = -p ]]
13 compdef:134> [[ wg-quick = -p ]]
13 compdef:134> [[ unexpand = -p ]]
13 compdef:134> [[ udisksctl = -p ]]
13 compdef:134> [[ tmuxinator = -p ]]
13 compdef:134> [[ tcp_open = -p ]]
13 compdef:134> [[ svccfg = -p ]]
13 compdef:134> [[ supervisorctl = -p ]]
13 compdef:134> [[ sum = -p ]]
13 compdef:134> [[ srm = -p ]]
13 compdef:134> [[ sort = -p ]]
13 compdef:134> [[ sfdx = -p ]]
13 compdef:134> [[ scrub = -p ]]
13 compdef:134> [[ rails = -p ]]
13 compdef:134> [[ port = -p ]]
13 compdef:134> [[ popd = -p ]]
13 compdef:134> [[ pon = -p ]]
13 compdef:134> [[ pkcon = -p ]]
13 compdef:134> [[ openstack = -p ]]
13 compdef:134> [[ openssl = -p ]]
13 compdef:134> [[ nvram = -p ]]
13 compdef:134> [[ numfmt = -p ]]
13 compdef:134> [[ nmcli = -p ]]
13 compdef:134> [[ nkf = -p ]]
13 compdef:134> [[ mvn = -p ]]
13 compdef:134> [[ mussh = -p ]]
13 compdef:134> [[ mondoarchive = -p ]]
13 compdef:134> [[ mix = -p ]]
13 compdef:134> [[ man = -p ]]
13 compdef:134> [[ last = -p ]]
13 compdef:134> [[ jexec = -p ]]
13 compdef:134> [[ gstat = -p ]]
13 compdef:134> [[ git = -p ]]
13 compdef:134> [[ gist = -p ]]
13 compdef:134> [[ genisoimage = -p ]]
13 compdef:134> [[ gdd = -p ]]
13 compdef:134> [[ gchmod = -p ]]
13 compdef:134> [[ fetch = -p ]]
13 compdef:134> [[ enscript = -p ]]
13 compdef:134> [[ elfdump = -p ]]
13 compdef:134> [[ dtruss = -p ]]
13 compdef:134> [[ dpkg-cross = -p ]]
13 compdef:134> [[ dpkg-buildpackage = -p ]]
13 compdef:134> [[ dpkg = -p ]]
13 compdef:134> [[ dpatch-edit-patch = -p ]]
13 compdef:134> [[ dos2unix = -p ]]
13 compdef:134> [[ doas = -p ]]
13 compdef:134> [[ dmidecode = -p ]]
13 compdef:134> [[ django-admin.py = -p ]]
13 compdef:134> [[ diff = -p ]]
13 compdef:134> [[ dhcpcd = -p ]]
13 compdef:134> [[ dget = -p ]]
13 compdef:134> [[ defaults = -p ]]
13 compdef:134> [[ dak = -p ]]
13 compdef:134> [[ cygserver = -p ]]
13 compdef:134> [[ cygrunsrv = -p ]]
13 compdef:134> [[ cvs = -p ]]
13 compdef:134> [[ config.status = -p ]]
13 compdef:134> [[ column = -p ]]
13 compdef:134> [[ code = -p ]]
13 compdef:134> [[ clay = -p ]]
13 compdef:134> [[ chsh = -p ]]
13 compdef:134> [[ chgrp = -p ]]
13 compdef:134> [[ cheat = -p ]]
13 compdef:134> [[ cd = -p ]]
13 compdef:134> [[ calendar = -p ]]
13 compdef:134> [[ bzr = -p ]]
13 compdef:134> [[ alias = -p ]]
13 compdef:134> [[ _helm = -p ]]
13 compdef:134> [[ '-value-,*path,-default-' = -p ]]
13 compdef:134> [[ '-redirect-,>,gzip=gunzip' = -p ]]
13 compdef:132> [[ zf_chmod = -N ]]
13 compdef:132> [[ yumdb = -N ]]
13 compdef:132> [[ xlsclients = -N ]]
13 compdef:132> [[ wodim = -N ]]
13 compdef:132> [[ uncompress = -N ]]
13 compdef:132> [[ ss = -N ]]
13 compdef:132> [[ split = -N ]]
13 compdef:132> [[ murano = -N ]]
13 compdef:132> [[ manage.py = -N ]]
13 compdef:132> [[ let = -N ]]
13 compdef:132> [[ keytool = -N ]]
13 compdef:132> [[ guilt-refresh = -N ]]
13 compdef:132> [[ guilt-rebase = -N ]]
13 compdef:132> [[ guilt-push = -N ]]
13 compdef:132> [[ gsha512sum = -N ]]
13 compdef:132> [[ gsha1sum = -N ]]
13 compdef:132> [[ gmd5sum = -N ]]
13 compdef:132> [[ gdd = -N ]]
13 compdef:132> [[ gchroot = -N ]]
13 compdef:132> [[ gchmod = -N ]]
13 compdef:132> [[ dviconcat = -N ]]
13 compdef:132> [[ dvibook = -N ]]
13 compdef:132> [[ dcopstart = -N ]]
13 compdef:132> [[ dcopobject = -N ]]
13 compdef:132> [[ dcopfind = -N ]]
13 compdef:132> [[ dbus-monitor = -N ]]
13 compdef:132> [[ cygstart.exe = -N ]]
13 compdef:132> [[ cygrunsrv.exe = -N ]]
13 compdef:132> [[ cowthink = -N ]]
13 compdef:132> [[ co = -N ]]
13 compdef:132> [[ cinder = -N ]]
13 compdef:132> [[ chgrp = -N ]]
13 compdef:132> [[ chdir = -N ]]
13 compdef:132> [[ cf = -N ]]
13 compdef:132> [[ a2dismod = -N ]]
13 compdef:132> [[ -value-,XZ_DEFAULTS,-default- = -N ]]
13 compdef:132> [[ -value-,LOOPDEV_DEBUG,-default- = -N ]]
13 compdef:132> [[ -value-,ANDROID_LOG_TAGS,-default- = -N ]]
13 compdef:132> [[ '-value-,CCACHE_*,-default-' = -N ]]
13 compdef:132> [[ '-value-,(ftp|http(|s))_proxy,-default-' = -N ]]
13 compdef:132> [[ '-redirect-,>,compress=uncompress' = -N ]]
13 compdef:131> ((  25  ))
13 compdef:131> ((  20  ))
13 compdef:131> ((  5  ))
13 compdef:131> ((  5  ))
13 compdef:131> ((  3  ))
13 compdef:131> ((  2  ))
13 compdef:131> ((  2  ))
13 compdef:131> ((  2  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:131> ((  1  ))
13 compdef:120> i=C-x?
13 compdef:104> [[ 2 -lt 2 ]]
13 compdef:104> [[ 2 -lt 2 ]]
13 compdef:104> [[ 2 -lt 2 ]]
13 compdef:104> [[ 2 -lt 2 ]]
13 compdef:86> [[ 3 -lt 3 ]]
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (widgetkey)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (key)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:83> case  (*)
13 compdef:81> shift
13 compdef:81> shift
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n yes ]]
13 compdef:80> [[ -n '' ]]
13 compdef:80> [[ -n '' ]]
13 compdef:79> func=_zsh-mime-handler
13 compdef:79> func=_zsh
13 compdef:79> func=_zoneadm
13 compdef:79> func=_zcash-cli
13 compdef:79> func=_yadm
13 compdef:79> func=_xmlstarlet
13 compdef:79> func=_xcode-select
13 compdef:79> func=_xclip
13 compdef:79> func=_xautolock
13 compdef:79> func=_xauth
13 compdef:79> func=_x_utils
13 compdef:79> func=_x_display
13 compdef:79> func=_x_arguments
13 compdef:79> func=_virtualbox
13 compdef:79> func=_ufw
13 compdef:79> func=_trash-restore
13 compdef:79> func=_trash-put
13 compdef:79> func=_tmuxp
13 compdef:79> func=_tmuxinator
13 compdef:79> func=_teamocil
13 compdef:79> func=_supervisorctl
13 compdef:79> func=_srm
13 compdef:79> func=_setup.py
13 compdef:79> func=_scala
13 compdef:79> func=_rfkill
13 compdef:79> func=_restic
13 compdef:79> func=_pm2
13 compdef:79> func=_pkgadd
13 compdef:79> func=_mkshortcut
13 compdef:79> func=_make-kpkg
13 compdef:79> func=_lp
13 compdef:79> func=_ldconfig
13 compdef:79> func=_kubectl
13 compdef:79> func=_jobs_builtin
13 compdef:79> func=_helm
13 compdef:79> func=_guilt
13 compdef:79> func=_fortune
13 compdef:79> func=_espeak
13 compdef:79> func=_envdir
13 compdef:79> func=_env
13 compdef:79> func=_dpkg_source
13 compdef:79> func=_dpkg-repack
13 compdef:79> func=_dpatch-edit-patch
13 compdef:79> func=_directories
13 compdef:79> func=_debfoster
13 compdef:79> func=_dcop
13 compdef:79> func=_dchroot-dsa
13 compdef:79> func=_dchroot
13 compdef:79> func=_darcs
13 compdef:79> func=_dak
13 compdef:79> func=_compadd
13 compdef:79> func=_chflags
13 compdef:79> func=_chcon
13 compdef:79> func=_chattr
13 compdef:79> func=_cdrecord
13 compdef:79> func=_cdrdao
13 compdef:79> func=_cabal
13 compdef:49> [[ _zattr = *=* ]]
13 compdef:49> [[ _yum = *=* ]]
13 compdef:49> [[ _xxd = *=* ]]
13 compdef:49> [[ _xv = *=* ]]
13 compdef:49> [[ _wc = *=* ]]
13 compdef:49> [[ _vserver = *=* ]]
13 compdef:49> [[ _update-alternatives = *=* ]]
13 compdef:49> [[ _truss = *=* ]]
13 compdef:49> [[ _tput = *=* ]]
13 compdef:49> [[ _tpb = *=* ]]
13 compdef:49> [[ _totd = *=* ]]
13 compdef:49> [[ _tiff = *=* ]]
13 compdef:49> [[ _tidy = *=* ]]
13 compdef:49> [[ _texinfo = *=* ]]
13 compdef:49> [[ _sysrc = *=* ]]
13 compdef:49> [[ _swaks = *=* ]]
13 compdef:49> [[ _svcs = *=* ]]
13 compdef:49> [[ _svccfg = *=* ]]
13 compdef:49> [[ _surfraw = *=* ]]
13 compdef:49> [[ _sudo = *=* ]]
13 compdef:49> [[ _su = *=* ]]
13 compdef:49> [[ _strings = *=* ]]
13 compdef:49> [[ _stow = *=* ]]
13 compdef:49> [[ _shred = *=* ]]
13 compdef:49> [[ _sh = *=* ]]
13 compdef:49> [[ _sed = *=* ]]
13 compdef:49> [[ _sccs = *=* ]]
13 compdef:49> [[ _rubber = *=* ]]
13 compdef:49> [[ _readshortcut = *=* ]]
13 compdef:49> [[ _putclip = *=* ]]
13 compdef:49> [[ _ptree = *=* ]]
13 compdef:49> [[ _pine = *=* ]]
13 compdef:49> [[ _pdftk = *=* ]]
13 compdef:49> [[ _okular = *=* ]]
13 compdef:49> [[ _od = *=* ]]
13 compdef:49> [[ _normal = *=* ]]
13 compdef:49> [[ _nginx = *=* ]]
13 compdef:49> [[ _nftables = *=* ]]
13 compdef:49> [[ _mutt = *=* ]]
13 compdef:49> [[ _mt = *=* ]]
13 compdef:49> [[ _module-assistant = *=* ]]
13 compdef:49> [[ _mkzsh = *=* ]]
13 compdef:49> [[ _mknod = *=* ]]
13 compdef:49> [[ _mdutil = *=* ]]
13 compdef:49> [[ _madison = *=* ]]
13 compdef:49> [[ _lunchy = *=* ]]
13 compdef:49> [[ _luarocks = *=* ]]
13 compdef:49> [[ _lsusb = *=* ]]
13 compdef:49> [[ _localedef = *=* ]]
13 compdef:49> [[ _lldb = *=* ]]
13 compdef:49> [[ _lintian = *=* ]]
13 compdef:49> [[ _links = *=* ]]
13 compdef:49> [[ _libvirt = *=* ]]
13 compdef:49> [[ _kvno = *=* ]]
13 compdef:49> [[ _jonas = *=* ]]
13 compdef:49> [[ _join = *=* ]]
13 compdef:49> [[ _java = *=* ]]
13 compdef:49> [[ _ipadm = *=* ]]
13 compdef:49> [[ _iostat = *=* ]]
13 compdef:49> [[ _invoke-rc.d = *=* ]]
13 compdef:49> [[ _iconv = *=* ]]
13 compdef:49> [[ _ibus = *=* ]]
13 compdef:49> [[ _htop = *=* ]]
13 compdef:49> [[ _history_complete_word = *=* ]]
13 compdef:49> [[ _gtk-launch = *=* ]]
13 compdef:49> [[ _google = *=* ]]
13 compdef:49> [[ _glances = *=* ]]
13 compdef:49> [[ _git-revise = *=* ]]
13 compdef:49> [[ _git-buildpackage = *=* ]]
13 compdef:49> [[ _git = *=* ]]
13 compdef:49> [[ _git = *=* ]]
13 compdef:49> [[ _git = *=* ]]
13 compdef:49> [[ _ghc = *=* ]]
13 compdef:49> [[ _gdb = *=* ]]
13 compdef:49> [[ _force = *=* ]]
13 compdef:49> [[ _findmnt = *=* ]]
13 compdef:49> [[ _drush = *=* ]]
13 compdef:49> [[ _conan = *=* ]]
13 compdef:49> [[ _coffee = *=* ]]
13 compdef:49> [[ _chromium = *=* ]]
13 compdef:49> [[ _choc = *=* ]]
13 compdef:49> [[ _bzip2 = *=* ]]
13 compdef:49> [[ _bundle = *=* ]]
13 compdef:49> [[ _btrfs = *=* ]]
13 compdef:49> [[ _bpython = *=* ]]
13 compdef:49> [[ _bibtex = *=* ]]
13 compdef:49> [[ _beadm = *=* ]]
13 compdef:49> [[ _autocd = *=* ]]
13 compdef:49> [[ _asciinema = *=* ]]
13 compdef:49> [[ _artisan = *=* ]]
13 compdef:49> [[ _arping = *=* ]]
13 compdef:49> [[ _acroread = *=* ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:49> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:45> [[ -z '' ]]
13 compdef:40> ((  ! 22  ))
13 compdef:40> ((  ! 19  ))
13 compdef:40> ((  ! 18  ))
13 compdef:40> ((  ! 14  ))
13 compdef:40> ((  ! 11  ))
13 compdef:40> ((  ! 11  ))
13 compdef:40> ((  ! 11  ))
13 compdef:40> ((  ! 10  ))
13 compdef:40> ((  ! 10  ))
13 compdef:40> ((  ! 10  ))
13 compdef:40> ((  ! 8  ))
13 compdef:40> ((  ! 7  ))
13 compdef:40> ((  ! 7  ))
13 compdef:40> ((  ! 6  ))
13 compdef:40> ((  ! 6  ))
13 compdef:40> ((  ! 6  ))
13 compdef:40> ((  ! 6  ))
13 compdef:40> ((  ! 5  ))
13 compdef:40> ((  ! 5  ))
13 compdef:40> ((  ! 5  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 4  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 3  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:40> ((  ! 2  ))
13 compdef:18> [[ -n '' ]]
13 compdef:18> [[ -n '' ]]
13 compdef:17> new=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:16> autol=yes
13 compdef:15> case p ([pPkK])
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (n)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case n (a)
13 compdef:15> case k (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case a (a)
13 compdef:15> case P ([pPkK])
13 colors:116> bg_no_bold[${k#bg-}]=$'C-[[22;40m'
13 colors:115> bg_bold[${k#bg-}]=$'C-[[01;43m'
13 colors:115> bg_bold[${k#bg-}]=$'C-[[01;42m'
13 colors:114> bg[${k#bg-}]=$'C-[[49m'
13 colors:114> bg[${k#bg-}]=$'C-[[47m'
13 colors:114> bg[${k#bg-}]=$'C-[[40m'
13 colors:107> fg_no_bold[${k#fg-}]=$'C-[[22;35m'
13 colors:106> fg_bold[${k#fg-}]=$'C-[[01;34m'
13 colors:105> fg[${k#fg-}]=$'C-[[35m'
13 colors:105> fg[${k#fg-}]=$'C-[[33m'
13 colors:105> fg[${k#fg-}]=$'C-[[30m'
13 colors:104> k=fg-green
13 colors:98> reset_color=$'C-[[00m'
13 colors:81> color[fg-${color[$k]}]=39
13 colors:81> color[fg-${color[$k]}]=37
13 colors:81> color[fg-${color[$k]}]=35
13 colors:81> color[fg-${color[$k]}]=31
13 colors:77> color[${color[$k]}]=46
13 colors:77> color[${color[$k]}]=41
13 colors:77> color[${color[$k]}]=40
13 colors:77> color[${color[$k]}]=37
13 colors:77> color[${color[$k]}]=35
13 colors:77> color[${color[$k]}]=30
13 colors:77> color[${color[$k]}]=28
13 colors:77> color[${color[$k]}]=24
13 colors:77> color[${color[$k]}]=04
13 colors:77> color[${color[$k]}]=03
13 antigen-remove-hook:7> [[ 3 > 0 ]]
13 antigen-remove-hook:7> [[ 1 > 0 ]]
13 antigen-add-hook:13> [[ '' ==  ]]
13 antigen-add-hook:13> [[ '' ==  ]]
13 add-zsh-hook:83> ((  1  ))
13 add-zsh-hook:83> ((  1  ))
13 _zsh_highlight_load_highlighters:13> highlighter=pattern
13 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
13 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
13 _zsh_highlight_bind_widgets:27> case completion:.menu-select:_main_complete (...
13 _zsh_highlight_bind_widgets:27> case completion:.menu-expand-or-complete:_mai...
13 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_main_complete ...
13 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_expand_word (u...
13 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_bash_completio...
13 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_most_recent_f...
13 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
13 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
13 _zsh_highlight_bind_widgets:26> cur_widget=what-cursor-position
13 _zsh_highlight_bind_widgets:26> cur_widget=visual-mode
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-swap-case
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-rev-repeat-find
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-repeat-find
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-insert-bol
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-first-non-blank
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-find-prev-char-skip
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-caps-lock-panic
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-delete-char
13 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-blank-word-end
13 _zsh_highlight_bind_widgets:26> cur_widget=up-case-word
13 _zsh_highlight_bind_widgets:26> cur_widget=transpose-words
13 _zsh_highlight_bind_widgets:26> cur_widget=split-undo
13 _zsh_highlight_bind_widgets:26> cur_widget=self-insert-unmeta
13 _zsh_highlight_bind_widgets:26> cur_widget=push-input
13 _zsh_highlight_bind_widgets:26> cur_widget=history-incremental-search-forward
13 _zsh_highlight_bind_widgets:26> cur_widget=history-incremental-pattern-search...
13 _zsh_highlight_bind_widgets:26> cur_widget=history-beginning-search-backward
13 _zsh_highlight_bind_widgets:26> cur_widget=exchange-point-and-mark
13 _zsh_highlight_bind_widgets:26> cur_widget=end-of-list
13 _zsh_highlight_bind_widgets:26> cur_widget=end-of-history
13 _zsh_highlight_bind_widgets:26> cur_widget=emacs-backward-word
13 _zsh_highlight_bind_widgets:26> cur_widget=down-line-or-beginning-search
13 _zsh_highlight_bind_widgets:26> cur_widget=down-case-word
13 _zsh_highlight_bind_widgets:26> cur_widget=backward-word
13 _zsh_highlight_bind_widgets:26> cur_widget=_history-complete-older
13 _zsh_highlight_bind_widgets:26> cur_widget=_expand_alias
13 _zsh_highlight_bind_widgets:26> cur_widget=_correct_word
13 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
13 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:148> custom_config_file=/Users/matt/.oh-m...
13 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
13 /Users/matt/.oh-my-zsh/lib/theme-and-appearance.zsh:11> [[ darwin21.0 == netb...
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;253m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;250m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;245m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;242m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;239m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;237m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;234m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;232m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;225m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;223m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;218m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;215m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;209m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;205m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;197m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;195m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;193m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;191m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;184m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;182m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;180m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;178m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;169m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;167m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;165m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;163m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;161m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;153m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;151m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;149m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;144m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;129m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;117m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;112m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;102m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;093m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;087m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;086m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;084m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;082m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;073m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;067m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;061m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;059m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;046m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;038m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;036m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;031m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;029m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;025m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;018m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;013m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;012m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;251m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;246m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;243m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;238m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;233m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;229m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;213m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;202m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;199m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;187m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;183m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;168m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;166m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;164m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;162m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;159m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;154m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;152m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;150m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;146m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;145m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;128m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;123m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;119m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;099m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;094m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;085m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;083m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;074m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;071m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;069m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;060m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;047m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;041m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;039m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;037m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;035m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;032m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;030m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;026m%}'
13 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;019m%}'
13 /Users/matt/.antigen/init.zsh:48> ZSH=/Users/matt/.oh-my-zsh
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
13 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
13 -antigen-parse-args:155> [[ -n '' ]]
13 -antigen-parse-args:124> name=robbyrussell/oh-my-zsh
13 -antigen-parse-args:122> name=zsh-users/zsh-syntax-highlighting.git
13 -antigen-parse-args:122> name=robbyrussell/oh-my-zsh.git
13 -antigen-parse-args:99> [[ https://github.com/robbyrussell/oh-my-zsh.git == /...
13 -antigen-parse-args:65> shift
13 -antigen-parse-args:40> key=url
13 -antigen-parse-args:40> key=url
13 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--url | --loc | -...
13 -antigen-parse-args:20> value=deno
13 -antigen-parse-args:17> [[ 1 -gt 0 ]]
13 -antigen-parse-args:14> args[btype]=plugin
13 -antigen-parse-args:14> args[btype]=plugin
13 -antigen-parse-args:14> args[btype]=plugin
13 -antigen-parse-args:14> args[btype]=plugin
13 -antigen-parse-args:14> args[btype]=plugin
13 -antigen-parse-args:13> args[make_local_clone]=true
13 -antigen-parse-args:9> typeset -A args
13 -antigen-parse-args:9> typeset -A args
13 -antigen-hook-handler:45> hook=-antigen-load-source-cached
13 -antigen-hook-handler:40> [[ 0 == -1 ]]
13 -antigen-hook-handler:22> case replace (pre)
13 -antigen-hook-handler:22> case pre (pre)
13 -antigen-hook-handler:22> case post (pre)
13 -antigen-hook-handler:22> case post (post)
13 -antigen-hook-handler:18> meta[called]=9
13 -antigen-hook-handler:18> meta[called]=4
13 -antigen-hook-handler:18> meta[called]=4
13 -antigen-hook-handler:18> meta[called]=3
13 -antigen-hook-handler:18> meta[called]=2
13 -antigen-hook-handler:18> meta[called]=2
13 -antigen-hook-handler:18> meta[called]=1
13 -antigen-hook-handler:18> meta[called]=1
13 (eval):243> alias 'vv=f -e '''nvim''
13 (eval):242> alias 'vim=nvim'
13 (eval):240> alias 'v=nvim'
13 (eval):237> alias 'sd=fasd -sid'
13 (eval):234> alias 'rd=rmdir'
13 (eval):233> alias 'nrr=npm run release'
13 (eval):232> alias 'nrc=npm run commit'
13 (eval):221> alias 'it2setcolor=/Users/matt/.iterm2/it2setcolor'
13 (eval):205> alias 'gup=git pull --rebase'
13 (eval):201> alias 'gts=git tag -s'
13 (eval):199> alias 'gswm=git switch $(git_main_branch)'
13 (eval):189> alias 'history=omz_history'
13 (eval):187> alias 'gstall=git stash --all'
13 (eval):182> alias 'gsr=git svn rebase'
13 (eval):181> alias 'gsps=git show --pretty=short --show-signature'
13 (eval):179> alias 'gts=git tag -s'
13 (eval):174> alias 'gsw=git switch'
13 (eval):171> alias 'grss=git restore --source'
13 (eval):169> alias 'grs=git restore'
13 (eval):162> alias 'grh=git reset'
13 (eval):157> alias 'gsd=git svn dcommit'
13 (eval):155> alias 'grbi=git rebase -i'
13 (eval):153> alias 'gru=git reset --'
13 (eval):146> alias 'groh=git reset origin/$(git_current_branch) --hard'
13 (eval):142> alias 'grhh=git reset --hard'
13 (eval):142> alias 'gpf!=git push --force'
13 (eval):140> alias 'gpd=git push --dry-run'
13 (eval):137> alias 'gmum=git merge upstream/$(git_main_branch)'
13 (eval):134> alias 'grbi=git rebase -i'
13 (eval):133> alias 'grbd=git rebase $(git_develop_branch)'
13 (eval):132> alias 'gma=git merge --abort'
13 (eval):126> alias 'gpu=git push upstream'
13 (eval):124> alias 'gpristine=git reset --hard && git clean -dffx'
13 (eval):116> alias 'gmtlvim=git mergetool --no-prompt --tool=vimdiff'
13 (eval):109> alias 'ghh=git help'
13 (eval):97> alias 'gdup=git diff @{upstream}'
13 (eval):96> alias 'gdt=git diff-tree --no-commit-id --name-only -r'
13 (eval):95> alias 'gds=git diff --staged'
13 (eval):87> alias 'gcs=git commit -S'
13 (eval):86> alias 'ggpull=git pull origin "$(git_current_branch)"'
13 (eval):81> alias 'gfa=git fetch --all --prune --jobs=10'
13 (eval):66> alias 'gcpa=git cherry-pick --abort'
13 (eval):66> alias 'gca=git commit -v -a'
13 (eval):64> alias 'gc=git commit -v'
13 (eval):62> alias 'gco=git checkout'
13 (eval):59> alias 'gbs=git bisect'
13 (eval):54> alias 'gcb=git checkout -b'
13 (eval):54> alias 'gbd=git branch -d'
13 (eval):51> alias 'gb=git branch'
13 (eval):45> alias 'gc=git commit -v'
13 (eval):43> alias 'gbsr=git bisect reset'
13 (eval):40> alias 'gbs=git bisect'
13 (eval):39> alias 'ga=git add'
13 (eval):38> alias 'g=git'
13 (eval):36> alias 'f=fasd -f'
13 (eval):32> alias 'gb=git branch'
13 (eval):32> alias 'dup=deno upgrade'
13 (eval):31> alias 'dts=deno test'
13 (eval):30> alias 'drw=deno run --watch'
13 (eval):27> alias 'dli=deno lint'
13 (eval):26> alias 'dh=deno help'
13 (eval):20> alias 'ga=git add'
13 (eval):19> alias 'g=git'
13 (eval):19> alias 'c=clear'
13 (eval):13> alias '8=cd -8'
13 (eval):12> alias '7=cd -7'
13 (eval):11> alias '6=cd -6'
13 (eval):10> alias '5=cd -5'
13 (eval):1> test -z ''
13 (eval):1> test -z ''
12 is-at-least:53> ((  part > min_ver[min_cnt]  ))
12 is-at-least:53> ((  part > min_ver[min_cnt]  ))
12 is-at-least:50> break
12 is-at-least:50> break
12 is-at-least:50> break
12 is-at-least:49> ((  ++min_cnt > 3  ))
12 is-at-least:49> ((  ++min_cnt > 3  ))
12 is-at-least:49> ((  ++min_cnt > 2  ))
12 is-at-least:48> true
12 is-at-least:48> true
12 is-at-least:48> true
12 is-at-least:48> true
12 is-at-least:48> true
12 is-at-least:45> part=36
12 is-at-least:45> part=8
12 is-at-least:45> part=8
12 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
12 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
12 is-at-least:33> [[ 1 = *[0-9][^0-9]* ]]
12 is-at-least:32> ((  ++ver_cnt > 6  ))
12 is-at-least:32> ((  ++ver_cnt > 4  ))
12 is-at-least:32> ((  ++ver_cnt > 4  ))
12 is-at-least:31> [[ '' != <-> ]]
12 is-at-least:31> [[ '' != <-> ]]
12 is-at-least:31> [[ '' != <-> ]]
12 is-at-least:30> ((  1 <= 2  ))
12 is-at-least:30> ((  0 <= 4  ))
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #compdef (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:506> case #autoload (#compdef)
12 compinit:500> _i_name=_zsocket
12 compinit:500> _i_name=_zpool
12 compinit:500> _i_name=_zones
12 compinit:500> _i_name=_zoneadm
12 compinit:500> _i_name=_zfs_dataset
12 compinit:500> _i_name=_zdump
12 compinit:500> _i_name=_zcalc
12 compinit:500> _i_name=_zargs
12 compinit:500> _i_name=_yaourt
12 compinit:500> _i_name=_xwit
12 compinit:500> _i_name=_xt_arguments
12 compinit:500> _i_name=_xournal
12 compinit:500> _i_name=_xmlsoft
12 compinit:500> _i_name=_xclip
12 compinit:500> _i_name=_x_visual
12 compinit:500> _i_name=_x_utils
12 compinit:500> _i_name=_x_title
12 compinit:500> _i_name=_x_locale
12 compinit:500> _i_name=_x_keysym
12 compinit:500> _i_name=_x_geometry
12 compinit:500> _i_name=_x_arguments
12 compinit:500> _i_name=_wpa_cli
12 compinit:500> _i_name=_wemux
12 compinit:500> _i_name=_watch
12 compinit:500> _i_name=_wanted
12 compinit:500> _i_name=_vserver
12 compinit:500> _i_name=_vnstat
12 compinit:500> _i_name=_valgrind
12 compinit:500> _i_name=_uptime
12 compinit:500> _i_name=_trash-restore
12 compinit:500> _i_name=_touch
12 compinit:500> _i_name=_tilde_files
12 compinit:500> _i_name=_tiff
12 compinit:500> _i_name=_svccfg
12 compinit:500> _i_name=_surfraw
12 compinit:500> _i_name=_subliminal
12 compinit:500> _i_name=_stat
12 compinit:500> _i_name=_stack
12 compinit:500> _i_name=_sshfs
12 compinit:500> _i_name=_signals
12 compinit:500> _i_name=_showoff
12 compinit:500> _i_name=_shasum
12 compinit:500> _i_name=_seq
12 compinit:500> _i_name=_selinux_contexts
12 compinit:500> _i_name=_scselect
12 compinit:500> _i_name=_schroot
12 compinit:500> _i_name=_sbt
12 compinit:500> _i_name=_rsvm
12 compinit:500> _i_name=_rspec
12 compinit:500> _i_name=_rslsync
12 compinit:500> _i_name=_rlogin
12 compinit:500> _i_name=_readelf
12 compinit:500> _i_name=_read_comp
12 compinit:500> _i_name=_rclone
12 compinit:500> _i_name=_ralio
12 compinit:500> _i_name=_rails
12 compinit:500> _i_name=_putclip
12 compinit:500> _i_name=_ps
12 compinit:500> _i_name=_port
12 compinit:500> _i_name=_plutil
12 compinit:500> _i_name=_play
12 compinit:500> _i_name=_pixz
12 compinit:500> _i_name=_physical_volumes
12 compinit:500> _i_name=_pgrep
12 compinit:500> _i_name=_perl
12 compinit:500> _i_name=_perf
12 compinit:500> _i_name=_patchutils
12 compinit:500> _i_name=_options_set
12 compinit:500> _i_name=_opkg
12 compinit:500> _i_name=_openstack
12 compinit:500> _i_name=_openssl
12 compinit:500> _i_name=_open
12 compinit:500> _i_name=_object_classes
12 compinit:500> _i_name=_nvram
12 compinit:500> _i_name=_nvm
12 compinit:500> _i_name=_nl
12 compinit:500> _i_name=_nkf
12 compinit:500> _i_name=_ngrep
12 compinit:500> _i_name=_nginx
12 compinit:500> _i_name=_networkmanager
12 compinit:500> _i_name=_net_interfaces
12 compinit:500> _i_name=_nbsd_architectures
12 compinit:500> _i_name=_nautilus
12 compinit:500> _i_name=_mvn
12 compinit:500> _i_name=_mutt
12 compinit:500> _i_name=_multi_parts
12 compinit:500> _i_name=_mtools
12 compinit:500> _i_name=_mount
12 compinit:500> _i_name=_most_recent_file
12 compinit:500> _i_name=_mondo
12 compinit:500> _i_name=_mknod
12 compinit:500> _i_name=_mixerctl
12 compinit:500> _i_name=_mix
12 compinit:500> _i_name=_mime_types
12 compinit:500> _i_name=_mergechanges
12 compinit:500> _i_name=_match
12 compinit:500> _i_name=_mailboxes
12 compinit:500> _i_name=_ltrace
12 compinit:500> _i_name=_lsvg
12 compinit:500> _i_name=_lsattr
12 compinit:500> _i_name=_lp
12 compinit:500> _i_name=_losetup
12 compinit:500> _i_name=_logical_volumes
12 compinit:500> _i_name=_list_files
12 compinit:500> _i_name=_lighttpd
12 compinit:500> _i_name=_ldconfig
12 compinit:500> _i_name=_knife
12 compinit:500> _i_name=_killall
12 compinit:500> _i_name=_kfmclient
12 compinit:500> _i_name=_kak
12 compinit:500> _i_name=_jmeter-plugins
12 compinit:500> _i_name=_jmeter
12 compinit:500> _i_name=_java_class
12 compinit:500> _i_name=_ispell
12 compinit:500> _i_name=_iptables
12 compinit:500> _i_name=_iconv
12 compinit:500> _i_name=_hostname
12 compinit:500> _i_name=_heroku
12 compinit:500> _i_name=_have_glob_qual
12 compinit:500> _i_name=_groups
12 compinit:500> _i_name=_gprof
12 compinit:500> _i_name=_gpasswd
12 compinit:500> _i_name=_gnutls
12 compinit:500> _i_name=_global_tags
12 compinit:500> _i_name=_git-revise
12 compinit:500> _i_name=_git
12 compinit:500> _i_name=_getopt
12 compinit:500> _i_name=_getmail
12 compinit:500> _i_name=_getfacl
12 compinit:500> _i_name=_gdb
12 compinit:500> _i_name=_functions
12 compinit:500> _i_name=_fsh
12 compinit:500> _i_name=_fold
12 compinit:500> _i_name=_finger
12 compinit:500> _i_name=_findmnt
12 compinit:500> _i_name=_find_net_interfaces
12 compinit:500> _i_name=_fbsd_architectures
12 compinit:500> _i_name=_extensions
12 compinit:500> _i_name=_etags
12 compinit:500> _i_name=_espeak
12 compinit:500> _i_name=_equal
12 compinit:500> _i_name=_eog
12 compinit:500> _i_name=_envdir
12 compinit:500> _i_name=_enable
12 compinit:500> _i_name=_emulate
12 compinit:500> _i_name=_elfdump
12 compinit:500> _i_name=_echotc
12 compinit:500> _i_name=_e2label
12 compinit:500> _i_name=_dvi
12 compinit:500> _i_name=_dpkg-buildpackage
12 compinit:500> _i_name=_dos2unix
12 compinit:500> _i_name=_docpad
12 compinit:500> _i_name=_docker_compose
12 compinit:500> _i_name=_dnf
12 compinit:500> _i_name=_dladm
12 compinit:500> _i_name=_dkms
12 compinit:500> _i_name=_dispatch
12 compinit:500> _i_name=_disable
12 compinit:500> _i_name=_directory_stack
12 compinit:500> _i_name=_dig
12 compinit:500> _i_name=_diffstat
12 compinit:500> _i_name=_diff_options
12 compinit:500> _i_name=_diff3
12 compinit:500> _i_name=_dict_words
12 compinit:500> _i_name=_diana
12 compinit:500> _i_name=_dhcpinfo
12 compinit:500> _i_name=_dhcpcd
12 compinit:500> _i_name=_debuild
12 compinit:500> _i_name=_dcut
12 compinit:500> _i_name=_dcop
12 compinit:500> _i_name=_dconf
12 compinit:500> _i_name=_dchroot-dsa
12 compinit:500> _i_name=_darcs
12 compinit:500> _i_name=_dak
12 compinit:500> _i_name=_curl
12 compinit:500> _i_name=_ctags_tags
12 compinit:500> _i_name=_cssh
12 compinit:500> _i_name=_cscope
12 compinit:500> _i_name=_correct_filename
12 compinit:500> _i_name=_condition
12 compinit:500> _i_name=_complete_help
12 compinit:500> _i_name=_compdef
12 compinit:500> _i_name=_code
12 compinit:500> _i_name=_clay
12 compinit:500> _i_name=_chrt
12 compinit:500> _i_name=_chroot
12 compinit:500> _i_name=_call_function
12 compinit:500> _i_name=_bzip2
12 compinit:500> _i_name=_bug
12 compinit:500> _i_name=_btrfs
12 compinit:500> _i_name=_bsdconfig
12 compinit:500> _i_name=_bsd_pkg
12 compinit:500> _i_name=_brctl
12 compinit:500> _i_name=_brace_parameter
12 compinit:500> _i_name=_bower
12 compinit:500> _i_name=_beep
12 compinit:500> _i_name=_arg_compile
12 compinit:500> _i_name=_archlinux-java
12 compinit:500> _i_name=_aptitude
12 compinit:500> _i_name=_apt-show-versions
12 compinit:500> _i_name=_apt-file
12 compinit:500> _i_name=_apt
12 compinit:500> _i_name=_apachectl
12 compinit:500> _i_name=_ansible
12 compinit:500> _i_name=_analyseplugin
12 compinit:500> _i_name=_all_labels
12 compinit:500> _i_name=_acpi
12 compinit:500> _i_name=_ack
12 compinit:500> _i_name=_aap
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zcat
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zcalc
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xmodmap
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_name
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_extension
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wiggle
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_widgets
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_whois
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_watch-snoop
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wakeup_capable_devices
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vserver
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vcsh
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_valgrind
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_update-alternatives
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_unhash
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_umountable
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ulimit
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_twisted
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ttys
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tty
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tree
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_touch
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_toilet
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tla
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_texinfo
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tcptraceroute
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tardy
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tar
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tags
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_system_profiler
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_systat
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sysrc
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sys_calls
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_swaks
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sudo
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_store_cache
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sshfs
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_shred
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_showmount
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_shasum
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sh
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_setopt
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_scselect
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sched
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_run-help
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rubber
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_readlink
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_read_comp
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_read
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rclone
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pv
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pscp
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_powerd
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_postscript
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_portmaster
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_portlint
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_plutil
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkgin
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_piuparts
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_physical_volumes
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_php
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_perforce
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pdftk
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_patchutils
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pandoc
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_opkg
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nvram
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_npm
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_normal
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_netscape
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nedit
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mysqldiff
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mtr
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mt
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mpc
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mkzsh
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mktemp
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mknod
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mergechanges
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_man
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mailboxes
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mac_applications
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lscfg
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lp
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_locate
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_loadkeys
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_list
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lintian
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_limit
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_libvirt
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lha
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kfmclient
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jq
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jot
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_join
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jobs_builtin
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ispell
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iptables
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ipsec
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_install
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_init_d
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ignored
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ifconfig
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_head
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_guilt
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_grep-excuses
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_grep
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_go
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gnutls
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gnu_generic
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_global
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getmail
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getconf
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_geany
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gcore
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fold
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_flex
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_emulate
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dos2unix
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_diff3
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_description
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_debbugs_bugnumber
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_coreadm
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bsdconfig
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bsd_pkg
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bpf_filters
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_beep
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_awk
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_augeas
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_asciidoctor
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_antiword
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_add-zle-hook-widget
12 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_acpi
12 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_docker_compose
12 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_deno
12 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_aws
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
12 compinit:497> [[ /Users/matt/.oh-my-zsh/functions = . ]]
12 compinit:497> [[ /Users/matt/.oh-my-zsh/cache/completions = . ]]
12 compinit:496> _i_dir=/usr/local/share/zsh/site-functions
12 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/functions
12 compinit:477> _i_done=''
12 compinit:442> _i_wdirs=( )
12 compinit:80> shift
12 compinit:79> _i_autodump=1
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:117> _i=5
12 compdump:116> ((  ! --_i && 1025 > 1  ))
12 compdump:116> ((  ! --_i && 979 > 1  ))
12 compdump:116> ((  ! --_i && 924 > 1  ))
12 compdump:116> ((  ! --_i && 864 > 1  ))
12 compdump:116> ((  ! --_i && 854 > 1  ))
12 compdump:116> ((  ! --_i && 839 > 1  ))
12 compdump:116> ((  ! --_i && 819 > 1  ))
12 compdump:116> ((  ! --_i && 784 > 1  ))
12 compdump:116> ((  ! --_i && 729 > 1  ))
12 compdump:116> ((  ! --_i && 699 > 1  ))
12 compdump:116> ((  ! --_i && 694 > 1  ))
12 compdump:116> ((  ! --_i && 529 > 1  ))
12 compdump:116> ((  ! --_i && 299 > 1  ))
12 compdump:113> ((  1089  ))
12 compdump:113> ((  1080  ))
12 compdump:113> ((  1075  ))
12 compdump:113> ((  1050  ))
12 compdump:113> ((  1030  ))
12 compdump:113> ((  1020  ))
12 compdump:113> ((  1014  ))
12 compdump:113> ((  1010  ))
12 compdump:113> ((  1009  ))
12 compdump:113> ((  1007  ))
12 compdump:113> ((  1006  ))
12 compdump:113> ((  1004  ))
12 compdump:113> ((  994  ))
12 compdump:113> ((  990  ))
12 compdump:113> ((  985  ))
12 compdump:113> ((  983  ))
12 compdump:113> ((  966  ))
12 compdump:113> ((  959  ))
12 compdump:113> ((  956  ))
12 compdump:113> ((  947  ))
12 compdump:113> ((  922  ))
12 compdump:113> ((  920  ))
12 compdump:113> ((  918  ))
12 compdump:113> ((  914  ))
12 compdump:113> ((  893  ))
12 compdump:113> ((  873  ))
12 compdump:113> ((  863  ))
12 compdump:113> ((  860  ))
12 compdump:113> ((  856  ))
12 compdump:113> ((  846  ))
12 compdump:113> ((  841  ))
12 compdump:113> ((  838  ))
12 compdump:113> ((  825  ))
12 compdump:113> ((  818  ))
12 compdump:113> ((  814  ))
12 compdump:113> ((  810  ))
12 compdump:113> ((  806  ))
12 compdump:113> ((  800  ))
12 compdump:113> ((  799  ))
12 compdump:113> ((  796  ))
12 compdump:113> ((  794  ))
12 compdump:113> ((  791  ))
12 compdump:113> ((  782  ))
12 compdump:113> ((  781  ))
12 compdump:113> ((  743  ))
12 compdump:113> ((  742  ))
12 compdump:113> ((  715  ))
12 compdump:113> ((  708  ))
12 compdump:113> ((  662  ))
12 compdump:113> ((  657  ))
12 compdump:113> ((  635  ))
12 compdump:113> ((  610  ))
12 compdump:113> ((  604  ))
12 compdump:113> ((  599  ))
12 compdump:113> ((  585  ))
12 compdump:113> ((  570  ))
12 compdump:113> ((  560  ))
12 compdump:113> ((  555  ))
12 compdump:113> ((  554  ))
12 compdump:113> ((  544  ))
12 compdump:113> ((  538  ))
12 compdump:113> ((  530  ))
12 compdump:113> ((  528  ))
12 compdump:113> ((  522  ))
12 compdump:113> ((  509  ))
12 compdump:113> ((  495  ))
12 compdump:113> ((  482  ))
12 compdump:113> ((  480  ))
12 compdump:113> ((  441  ))
12 compdump:113> ((  428  ))
12 compdump:113> ((  418  ))
12 compdump:113> ((  388  ))
12 compdump:113> ((  367  ))
12 compdump:113> ((  352  ))
12 compdump:113> ((  342  ))
12 compdump:113> ((  341  ))
12 compdump:113> ((  337  ))
12 compdump:113> ((  332  ))
12 compdump:113> ((  330  ))
12 compdump:113> ((  327  ))
12 compdump:113> ((  323  ))
12 compdump:113> ((  313  ))
12 compdump:113> ((  298  ))
12 compdump:113> ((  276  ))
12 compdump:113> ((  268  ))
12 compdump:113> ((  262  ))
12 compdump:113> ((  260  ))
12 compdump:113> ((  257  ))
12 compdump:113> ((  252  ))
12 compdump:113> ((  244  ))
12 compdump:113> ((  121  ))
12 compdump:113> ((  4  ))
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:169> shift
12 compdef:164> [[ -n yes ]]
12 compdef:163> _comps[$cmd]=_xz
12 compdef:163> _comps[$cmd]=_subversion
12 compdef:163> _comps[$cmd]=_gzip
12 compdef:163> _comps[$cmd]=_gpg
12 compdef:163> _comps[$cmd]=_gnupod
12 compdef:163> _comps[$cmd]=_gnupod
12 compdef:163> _comps[$cmd]=_git
12 compdef:163> _comps[$cmd]=_git
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:162> [[ -z yes || -z '' ]]
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:160> svc=''
12 compdef:159> cmd=zstyle
12 compdef:159> cmd=zln
12 compdef:159> cmd=zle
12 compdef:159> cmd=xsetroot
12 compdef:159> cmd=xrdb
12 compdef:159> cmd=xdpyinfo
12 compdef:159> cmd=wpa_cli
12 compdef:159> cmd=wodim
12 compdef:159> cmd=trash-restore
12 compdef:159> cmd=trash-put
12 compdef:159> cmd=trash-list
12 compdef:159> cmd=tmuxinator
12 compdef:159> cmd=tdr
12 compdef:159> cmd=supervisorctl
12 compdef:159> cmd=sum
12 compdef:159> cmd=sdd
12 compdef:159> cmd=scalac
12 compdef:159> cmd=rubocop
12 compdef:159> cmd=rsvm
12 compdef:159> cmd=rspec
12 compdef:159> cmd=ri
12 compdef:159> cmd=rfkill
12 compdef:159> cmd=redis-cli
12 compdef:159> cmd=protoc
12 compdef:159> cmd=pm2
12 compdef:159> cmd=pg_dump
12 compdef:159> cmd=pfexec
12 compdef:159> cmd=periscope
12 compdef:159> cmd=openstack
12 compdef:159> cmd=numfmt
12 compdef:159> cmd=node
12 compdef:159> cmd=nano
12 compdef:159> cmd=mvn
12 compdef:159> cmd=mux
12 compdef:159> cmd=mullvad
12 compdef:159> cmd=mondoarchive
12 compdef:159> cmd=mkisofs
12 compdef:159> cmd=mdfind
12 compdef:159> cmd=md4
12 compdef:159> cmd=lzop
12 compdef:159> cmd=info
12 compdef:159> cmd=gxargs
12 compdef:159> cmd=gunzip
12 compdef:159> cmd=guilt-unapplied
12 compdef:159> cmd=guilt-top
12 compdef:159> cmd=guilt-prev
12 compdef:159> cmd=guilt-new
12 compdef:159> cmd=guilt-delete
12 compdef:159> cmd=gtk-launch
12 compdef:159> cmd=gsum
12 compdef:159> cmd=gstat
12 compdef:159> cmd=gsha512sum
12 compdef:159> cmd=growisofs
12 compdef:159> cmd=gqview
12 compdef:159> cmd=gcomm
12 compdef:159> cmd=figlet
12 compdef:159> cmd=exec
12 compdef:159> cmd=entr
12 compdef:159> cmd=enscript
12 compdef:159> cmd=dvicopy
12 compdef:159> cmd=dumper.exe
12 compdef:159> cmd=dumpadm
12 compdef:159> cmd=dpkg-source
12 compdef:159> cmd=dpkg-query
12 compdef:159> cmd=dpkg-buildpackage
12 compdef:159> cmd=dpatch-edit-patch
12 compdef:159> cmd=dkms
12 compdef:159> cmd=dhcpinfo
12 compdef:159> cmd=debuild
12 compdef:159> cmd=dcopstart
12 compdef:159> cmd=dchroot-dsa
12 compdef:159> cmd=dbus-launch
12 compdef:159> cmd=cygserver.exe
12 compdef:159> cmd=cygpath
12 compdef:159> cmd=cvs
12 compdef:159> cmd=cowsay
12 compdef:159> cmd=configure
12 compdef:159> cmd=compdef
12 compdef:159> cmd=compadd
12 compdef:159> cmd=cksum
12 compdef:159> cmd=chsh
12 compdef:159> cmd=cheat
12 compdef:159> cmd=chcon
12 compdef:159> cmd=cdrdao
12 compdef:159> cmd=cdbs-edit-patch
12 compdef:159> cmd=cal
12 compdef:159> cmd=auto-apt
12 compdef:159> cmd=arping
12 compdef:159> cmd=apt-move
12 compdef:159> cmd=apt-cache
12 compdef:159> cmd=aodh
12 compdef:159> cmd=a2ensite
12 compdef:159> cmd=_restic
12 compdef:159> cmd=-value-,XML_CATALOG_FILES,-default-
12 compdef:159> cmd=-value-,LESS,-default-
12 compdef:159> cmd=-value-,DISPLAY,-default-
12 compdef:159> cmd=-value-,CMAKE_GENERATOR,-default-
12 compdef:159> cmd=-value-,ANSIBLE_STDOUT_CALLBACK,-default-
12 compdef:159> cmd=-redirect-,-default-,-default-
12 compdef:157> svc=yes
12 compdef:156> cmd=zf_chown
12 compdef:156> cmd=zf_chgrp
12 compdef:156> cmd=xetex
12 compdef:156> cmd=xelatex
12 compdef:156> cmd=nail
12 compdef:156> cmd=mailx
12 compdef:156> cmd=gnupod_check.pl
12 compdef:156> cmd=gchgrp
12 compdef:156> cmd='-redirect-,>,bzip2'
12 compdef:156> cmd='-redirect-,<,unxz'
12 compdef:156> cmd='-redirect-,<,bzip2'
12 compdef:155> [[ zmail = *=* ]]
12 compdef:155> [[ zcalc = *=* ]]
12 compdef:155> [[ yppoll = *=* ]]
12 compdef:155> [[ xwd = *=* ]]
12 compdef:155> [[ xsetroot = *=* ]]
12 compdef:155> [[ xrdb = *=* ]]
12 compdef:155> [[ xrandr = *=* ]]
12 compdef:155> [[ xlsclients = *=* ]]
12 compdef:155> [[ xlsatoms = *=* ]]
12 compdef:155> [[ xfd = *=* ]]
12 compdef:155> [[ xev = *=* ]]
12 compdef:155> [[ who = *=* ]]
12 compdef:155> [[ whatis = *=* ]]
12 compdef:155> [[ w3m = *=* ]]
12 compdef:155> [[ vncviewer = *=* ]]
12 compdef:155> [[ vncserver = *=* ]]
12 compdef:155> [[ vim-addons = *=* ]]
12 compdef:155> [[ vared = *=* ]]
12 compdef:155> [[ vacuumdb = *=* ]]
12 compdef:155> [[ usermod = *=* ]]
12 compdef:155> [[ unhash = *=* ]]
12 compdef:155> [[ tune2fs = *=* ]]
12 compdef:155> [[ true = *=* ]]
12 compdef:155> [[ tpkg-install = *=* ]]
12 compdef:155> [[ todo.sh = *=* ]]
12 compdef:155> [[ tmux = *=* ]]
12 compdef:155> [[ tidy = *=* ]]
12 compdef:155> [[ tdd = *=* ]]
12 compdef:155> [[ tcpdump = *=* ]]
12 compdef:155> [[ talk = *=* ]]
12 compdef:155> [[ tail = *=* ]]
12 compdef:155> [[ swift = *=* ]]
12 compdef:155> [[ swaks = *=* ]]
12 compdef:155> [[ sw_vers = *=* ]]
12 compdef:155> [[ svn = *=* ]]
12 compdef:155> [[ svcprop = *=* ]]
12 compdef:155> [[ su = *=* ]]
12 compdef:155> [[ stty = *=* ]]
12 compdef:155> [[ strings = *=* ]]
12 compdef:155> [[ stat = *=* ]]
12 compdef:155> [[ sshfs = *=* ]]
12 compdef:155> [[ ssh = *=* ]]
12 compdef:155> [[ sockstat = *=* ]]
12 compdef:155> [[ snoop = *=* ]]
12 compdef:155> [[ smit = *=* ]]
12 compdef:155> [[ skein256 = *=* ]]
12 compdef:155> [[ signify = *=* ]]
12 compdef:155> [[ shutdown = *=* ]]
12 compdef:155> [[ shuf = *=* ]]
12 compdef:155> [[ shift = *=* ]]
12 compdef:155> [[ sha512t256 = *=* ]]
12 compdef:155> [[ sha384sum = *=* ]]
12 compdef:155> [[ sha384 = *=* ]]
12 compdef:155> [[ setsid = *=* ]]
12 compdef:155> [[ seaf-cli = *=* ]]
12 compdef:155> [[ scselect = *=* ]]
12 compdef:155> [[ schedtool = *=* ]]
12 compdef:155> [[ run-help = *=* ]]
12 compdef:155> [[ ruby = *=* ]]
12 compdef:155> [[ rubber = *=* ]]
12 compdef:155> [[ rlogin = *=* ]]
12 compdef:155> [[ reprepro = *=* ]]
12 compdef:155> [[ rebootin = *=* ]]
12 compdef:155> [[ readshortcut.exe = *=* ]]
12 compdef:155> [[ readlink = *=* ]]
12 compdef:155> [[ rar = *=* ]]
12 compdef:155> [[ ranlib = *=* ]]
12 compdef:155> [[ qiv = *=* ]]
12 compdef:155> [[ pv = *=* ]]
12 compdef:155> [[ ptree = *=* ]]
12 compdef:155> [[ ps2pdf = *=* ]]
12 compdef:155> [[ ps = *=* ]]
12 compdef:155> [[ prove = *=* ]]
12 compdef:155> [[ procstat = *=* ]]
12 compdef:155> [[ print = *=* ]]
12 compdef:155> [[ pon = *=* ]]
12 compdef:155> [[ pkgrm = *=* ]]
12 compdef:155> [[ pkgadd = *=* ]]
12 compdef:155> [[ pkg-config = *=* ]]
12 compdef:155> [[ piuparts = *=* ]]
12 compdef:155> [[ ping = *=* ]]
12 compdef:155> [[ pine = *=* ]]
12 compdef:155> [[ picocom = *=* ]]
12 compdef:155> [[ php = *=* ]]
12 compdef:155> [[ pg_restore = *=* ]]
12 compdef:155> [[ pg_dump = *=* ]]
12 compdef:155> [[ pflags = *=* ]]
12 compdef:155> [[ pbuilder = *=* ]]
12 compdef:155> [[ osc = *=* ]]
12 compdef:155> [[ opera-next = *=* ]]
12 compdef:155> [[ okular = *=* ]]
12 compdef:155> [[ oggenc = *=* ]]
12 compdef:155> [[ npm = *=* ]]
12 compdef:155> [[ nmap = *=* ]]
12 compdef:155> [[ ngrep = *=* ]]
12 compdef:155> [[ nc = *=* ]]
12 compdef:155> [[ mush = *=* ]]
12 compdef:155> [[ mtr = *=* ]]
12 compdef:155> [[ mpstat = *=* ]]
12 compdef:155> [[ mount = *=* ]]
12 compdef:155> [[ mkshortcut.exe = *=* ]]
12 compdef:155> [[ mdls = *=* ]]
12 compdef:155> [[ manage.py = *=* ]]
12 compdef:155> [[ mail = *=* ]]
12 compdef:155> [[ lunchy = *=* ]]
12 compdef:155> [[ lua = *=* ]]
12 compdef:155> [[ lsusb = *=* ]]
12 compdef:155> [[ lscfg = *=* ]]
12 compdef:155> [[ lpadmin = *=* ]]
12 compdef:155> [[ locale = *=* ]]
12 compdef:155> [[ loadkeys = *=* ]]
12 compdef:155> [[ limit = *=* ]]
12 compdef:155> [[ less = *=* ]]
12 compdef:155> [[ ldconfig.real = *=* ]]
12 compdef:155> [[ ldap = *=* ]]
12 compdef:155> [[ kldunload = *=* ]]
12 compdef:155> [[ killall5 = *=* ]]
12 compdef:155> [[ kill = *=* ]]
12 compdef:155> [[ jrnl = *=* ]]
12 compdef:155> [[ jq = *=* ]]
12 compdef:155> [[ jonas = *=* ]]
12 compdef:155> [[ jmeter = *=* ]]
12 compdef:155> [[ jail = *=* ]]
12 compdef:155> [[ ispell = *=* ]]
12 compdef:155> [[ ipset = *=* ]]
12 compdef:155> [[ ip6tables-restore = *=* ]]
12 compdef:155> [[ install = *=* ]]
12 compdef:155> [[ infocmp = *=* ]]
12 compdef:155> [[ id = *=* ]]
12 compdef:155> [[ iconv = *=* ]]
12 compdef:155> [[ icombine = *=* ]]
12 compdef:155> [[ hwinfo = *=* ]]
12 compdef:155> [[ http = *=* ]]
12 compdef:155> [[ htop = *=* ]]
12 compdef:155> [[ hostname = *=* ]]
12 compdef:155> [[ history = *=* ]]
12 compdef:155> [[ helm = *=* ]]
12 compdef:155> [[ heat = *=* ]]
12 compdef:155> [[ gunzip = *=* ]]
12 compdef:155> [[ guilt-prev = *=* ]]
12 compdef:155> [[ guilt-patchbomb = *=* ]]
12 compdef:155> [[ guilt-next = *=* ]]
12 compdef:155> [[ guilt-new = *=* ]]
12 compdef:155> [[ guilt-import-commit = *=* ]]
12 compdef:155> [[ guilt-fold = *=* ]]
12 compdef:155> [[ guilt-applied = *=* ]]
12 compdef:155> [[ gsha512sum = *=* ]]
12 compdef:155> [[ gsbj = *=* ]]
12 compdef:155> [[ gs = *=* ]]
12 compdef:155> [[ gradle = *=* ]]
12 compdef:155> [[ gpg = *=* ]]
12 compdef:155> [[ gnutls-cli = *=* ]]
12 compdef:155> [[ git-revise = *=* ]]
12 compdef:155> [[ gid = *=* ]]
12 compdef:155> [[ gh = *=* ]]
12 compdef:155> [[ getfacl = *=* ]]
12 compdef:155> [[ getconf = *=* ]]
12 compdef:155> [[ genv = *=* ]]
12 compdef:155> [[ gem = *=* ]]
12 compdef:155> [[ gdiff = *=* ]]
12 compdef:155> [[ gdate = *=* ]]
12 compdef:155> [[ gcomm = *=* ]]
12 compdef:155> [[ gccgo = *=* ]]
12 compdef:155> [[ gas = *=* ]]
12 compdef:155> [[ fwupdmgr = *=* ]]
12 compdef:155> [[ fw_update = *=* ]]
12 compdef:155> [[ fstat = *=* ]]
12 compdef:155> [[ freebsd-make = *=* ]]
12 compdef:155> [[ free = *=* ]]
12 compdef:155> [[ fetch = *=* ]]
12 compdef:155> [[ fab = *=* ]]
12 compdef:155> [[ epsffit = *=* ]]
12 compdef:155> [[ dvitype = *=* ]]
12 compdef:155> [[ dviselect = *=* ]]
12 compdef:155> [[ dvc = *=* ]]
12 compdef:155> [[ dropuser = *=* ]]
12 compdef:155> [[ dpkg-query = *=* ]]
12 compdef:155> [[ dnf-3 = *=* ]]
12 compdef:155> [[ dist = *=* ]]
12 compdef:155> [[ deno = *=* ]]
12 compdef:155> [[ dbus-monitor = *=* ]]
12 compdef:155> [[ dbus-launch = *=* ]]
12 compdef:155> [[ cygpath.exe = *=* ]]
12 compdef:155> [[ createdb = *=* ]]
12 compdef:155> [[ cp = *=* ]]
12 compdef:155> [[ config.status = *=* ]]
12 compdef:155> [[ conan = *=* ]]
12 compdef:155> [[ choc = *=* ]]
12 compdef:155> [[ cf = *=* ]]
12 compdef:155> [[ ceilometer = *=* ]]
12 compdef:155> [[ ccache = *=* ]]
12 compdef:155> [[ bzip2recover = *=* ]]
12 compdef:155> [[ builtin = *=* ]]
12 compdef:155> [[ btdownloadgui = *=* ]]
12 compdef:155> [[ bsdinstall = *=* ]]
12 compdef:155> [[ brew = *=* ]]
12 compdef:155> [[ brctl = *=* ]]
12 compdef:155> [[ bibtex = *=* ]]
12 compdef:155> [[ beep = *=* ]]
12 compdef:155> [[ beadm = *=* ]]
12 compdef:155> [[ basename = *=* ]]
12 compdef:155> [[ base64 = *=* ]]
12 compdef:155> [[ augtool = *=* ]]
12 compdef:155> [[ asciinema = *=* ]]
12 compdef:155> [[ artisan = *=* ]]
12 compdef:155> [[ apropos = *=* ]]
12 compdef:155> [[ aplay = *=* ]]
12 compdef:155> [[ amaya = *=* ]]
12 compdef:155> [[ ali = *=* ]]
12 compdef:155> [[ adb = *=* ]]
12 compdef:155> [[ acroread = *=* ]]
12 compdef:155> [[ acpitool = *=* ]]
12 compdef:155> [[ abcde = *=* ]]
12 compdef:155> [[ a2dissite = *=* ]]
12 compdef:155> [[ a2dismod = *=* ]]
12 compdef:155> [[ SuSEconfig = *=* ]]
12 compdef:155> [[ -vared- = *=* ]]
12 compdef:155> [[ -value-,TERM,-default- = *=* ]]
12 compdef:155> [[ -value-,RPS2,-default- = *=* ]]
12 compdef:155> [[ -value-,RPROMPT2,-default- = *=* ]]
12 compdef:155> [[ -value-,PROMPT3,-default- = *=* ]]
12 compdef:155> [[ -value-,P4PORT,-default- = *=* ]]
12 compdef:155> [[ -value-,MPD_HOST,-default = *=* ]]
12 compdef:155> [[ -value-,LESS,-default- = *=* ]]
12 compdef:155> [[ -value-,LDFLAGS,-default- = *=* ]]
12 compdef:155> [[ -value-,ANT_ARGS,-default- = *=* ]]
12 compdef:155> [[ -value-,ANDROID_SERIAL,-default- = *=* ]]
12 compdef:155> [[ -value-,ANDROID_LOG_TAGS,-default- = *=* ]]
12 compdef:155> [[ -value-,ADB_TRACE,-default- = *=* ]]
12 compdef:155> [[ -value-,-default-,-command- = *=* ]]
12 compdef:155> [[ -subscript- = *=* ]]
12 compdef:155> [[ -first- = *=* ]]
12 compdef:155> [[ 'svnadmin-static=svnadmin' = *=* ]]
12 compdef:155> [[ 'pcat=unpack' = *=* ]]
12 compdef:155> [[ 'ggp=git-checkout' = *=* ]]
12 compdef:155> [[ 'ggfl=git-checkout' = *=* ]]
12 compdef:148> [[ 'yodl(|2*)' = (#b)(*)=(*) ]]
12 compdef:148> [[ 'python[0-9.]#' = (#b)(*)=(*) ]]
12 compdef:148> [[ '-value-,RUBY(LIB|OPT|PATH),-default-' = (#b)(*)=(*) ]]
12 compdef:148> [[ '-value-,CCACHE_*,-default-' = (#b)(*)=(*) ]]
12 compdef:148> [[ '(tiff*|*2tiff|pal2rgb)' = (#b)(*)=(*) ]]
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (postpattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (pattern)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:139> case  (*)
12 compdef:137> type=postpattern
12 compdef:137> type=postpattern
12 compdef:136> [[ ztodo = -P ]]
12 compdef:136> [[ zpool = -P ]]
12 compdef:136> [[ zparseopts = -P ]]
12 compdef:136> [[ zcompile = -P ]]
12 compdef:136> [[ xwininfo = -P ]]
12 compdef:136> [[ xsltproc = -P ]]
12 compdef:136> [[ xmllint = -P ]]
12 compdef:136> [[ xauth = -P ]]
12 compdef:136> [[ wodim = -P ]]
12 compdef:136> [[ vnstat = -P ]]
12 compdef:136> [[ unrar = -P ]]
12 compdef:136> [[ ttyctl = -P ]]
12 compdef:136> [[ teamocil = -P ]]
12 compdef:136> [[ tda = -P ]]
12 compdef:136> [[ svnadmin = -P ]]
12 compdef:136> [[ supervisorctl = -P ]]
12 compdef:136> [[ subliminal = -P ]]
12 compdef:136> [[ subl = -P ]]
12 compdef:136> [[ strongswan = -P ]]
12 compdef:136> [[ sqlite = -P ]]
12 compdef:136> [[ skein512 = -P ]]
12 compdef:136> [[ showoff = -P ]]
12 compdef:136> [[ sha512t256 = -P ]]
12 compdef:136> [[ sha1 = -P ]]
12 compdef:136> [[ setsid = -P ]]
12 compdef:136> [[ sdd = -P ]]
12 compdef:136> [[ scrub = -P ]]
12 compdef:136> [[ rubocop = -P ]]
12 compdef:136> [[ rspec = -P ]]
12 compdef:136> [[ ri = -P ]]
12 compdef:136> [[ rails = -P ]]
12 compdef:136> [[ pygmentize = -P ]]
12 compdef:136> [[ postqueue = -P ]]
12 compdef:136> [[ pdm = -P ]]
12 compdef:136> [[ openstack = -P ]]
12 compdef:136> [[ openssl = -P ]]
12 compdef:136> [[ nm = -P ]]
12 compdef:136> [[ nl = -P ]]
12 compdef:136> [[ nkf = -P ]]
12 compdef:136> [[ mysql = -P ]]
12 compdef:136> [[ mvn = -P ]]
12 compdef:136> [[ mupdf = -P ]]
12 compdef:136> [[ mkisofs = -P ]]
12 compdef:136> [[ matlab = -P ]]
12 compdef:136> [[ man = -P ]]
12 compdef:136> [[ madison = -P ]]
12 compdef:136> [[ let = -P ]]
12 compdef:136> [[ ldconfig.real = -P ]]
12 compdef:136> [[ jq = -P ]]
12 compdef:136> [[ hub = -P ]]
12 compdef:136> [[ helm = -P ]]
12 compdef:136> [[ hash = -P ]]
12 compdef:136> [[ gwc = -P ]]
12 compdef:136> [[ guilt-unapplied = -P ]]
12 compdef:136> [[ guilt-status = -P ]]
12 compdef:136> [[ guilt-files = -P ]]
12 compdef:136> [[ gseq = -P ]]
12 compdef:136> [[ gmd5sum = -P ]]
12 compdef:136> [[ gitk = -P ]]
12 compdef:136> [[ getmail = -P ]]
12 compdef:136> [[ gdiff = -P ]]
12 compdef:136> [[ gcomm = -P ]]
12 compdef:136> [[ gcc = -P ]]
12 compdef:136> [[ fs_usage = -P ]]
12 compdef:136> [[ fned = -P ]]
12 compdef:136> [[ flex++ = -P ]]
12 compdef:136> [[ espeak = -P ]]
12 compdef:136> [[ emulate = -P ]]
12 compdef:136> [[ elinks = -P ]]
12 compdef:136> [[ elfdump = -P ]]
12 compdef:136> [[ ed = -P ]]
12 compdef:136> [[ dvitype = -P ]]
12 compdef:136> [[ dvibook = -P ]]
12 compdef:136> [[ drill = -P ]]
12 compdef:136> [[ dpkg-reconfigure = -P ]]
12 compdef:136> [[ dpkg-query = -P ]]
12 compdef:136> [[ dpatch-edit-patch = -P ]]
12 compdef:136> [[ docker = -P ]]
12 compdef:136> [[ dmesg = -P ]]
12 compdef:136> [[ dlocate = -P ]]
12 compdef:136> [[ dkms = -P ]]
12 compdef:136> [[ django-admin.py = -P ]]
12 compdef:136> [[ dhclient3 = -P ]]
12 compdef:136> [[ dhclient = -P ]]
12 compdef:136> [[ dcop = -P ]]
12 compdef:136> [[ dconf = -P ]]
12 compdef:136> [[ dchroot-dsa = -P ]]
12 compdef:136> [[ date = -P ]]
12 compdef:136> [[ cygpath.exe = -P ]]
12 compdef:136> [[ cygpath = -P ]]
12 compdef:136> [[ cvs = -P ]]
12 compdef:136> [[ curl = -P ]]
12 compdef:136> [[ cplay = -P ]]
12 compdef:136> [[ cowsay = -P ]]
12 compdef:136> [[ config.status = -P ]]
12 compdef:136> [[ compadd = -P ]]
12 compdef:136> [[ column = -P ]]
12 compdef:136> [[ clay = -P ]]
12 compdef:136> [[ cheat = -P ]]
12 compdef:136> [[ ceilometer = -P ]]
12 compdef:136> [[ calendar = -P ]]
12 compdef:136> [[ brew = -P ]]
12 compdef:136> [[ bogoutil = -P ]]
12 compdef:136> [[ bg = -P ]]
12 compdef:136> [[ alias = -P ]]
12 compdef:136> [[ add-zle-hook-widget = -P ]]
12 compdef:136> [[ _gh = -P ]]
12 compdef:136> [[ -value-,VALGRIND_OPTS,-default- = -P ]]
12 compdef:136> [[ -value-,MPD_HOST,-default = -P ]]
12 compdef:136> [[ -value-,LESSCHARSET,-default- = -P ]]
12 compdef:136> [[ -value-,LESS,-default- = -P ]]
12 compdef:136> [[ -value-,DISPLAY,-default- = -P ]]
12 compdef:136> [[ -value-,ANDROID_LOG_TAGS,-default- = -P ]]
12 compdef:136> [[ -value-,-default-,-command- = -P ]]
12 compdef:136> [[ 'yaourt.static=yaourt' = -P ]]
12 compdef:136> [[ 'gzcat=gunzip' = -P ]]
12 compdef:136> [[ 'gnupod_check.pl=gnupod_check' = -P ]]
12 compdef:136> [[ 'VBoxManage=vboxmanage' = -P ]]
12 compdef:136> [[ '-value-,*path,-default-' = -P ]]
12 compdef:136> [[ '-redirect-,>,bzip2=bunzip2' = -P ]]
12 compdef:136> [[ '-redirect-,<,gunzip=gunzip' = -P ]]
12 compdef:134> [[ ztodo = -p ]]
12 compdef:134> [[ zle = -p ]]
12 compdef:134> [[ zfs = -p ]]
12 compdef:134> [[ zf_ln = -p ]]
12 compdef:134> [[ zcash-cli = -p ]]
12 compdef:134> [[ yarn = -p ]]
12 compdef:134> [[ xsetroot = -p ]]
12 compdef:134> [[ xsetbg = -p ]]
12 compdef:134> [[ xset = -p ]]
12 compdef:134> [[ xournal = -p ]]
12 compdef:134> [[ xmodmap = -p ]]
12 compdef:134> [[ xmlstarlet = -p ]]
12 compdef:134> [[ xli = -p ]]
12 compdef:134> [[ xdpyinfo = -p ]]
12 compdef:134> [[ xclip = -p ]]
12 compdef:134> [[ xautolock = -p ]]
12 compdef:134> [[ wpa_cli = -p ]]
12 compdef:134> [[ wc = -p ]]
12 compdef:134> [[ wajig = -p ]]
12 compdef:134> [[ w = -p ]]
12 compdef:134> [[ vpnc = -p ]]
12 compdef:134> [[ virt-xml-validate = -p ]]
12 compdef:134> [[ uscan = -p ]]
12 compdef:134> [[ unix2dos = -p ]]
12 compdef:134> [[ unfunction = -p ]]
12 compdef:134> [[ tree = -p ]]
12 compdef:134> [[ trash-put = -p ]]
12 compdef:134> [[ transmission-remote = -p ]]
12 compdef:134> [[ todo.sh = -p ]]
12 compdef:134> [[ todo = -p ]]
12 compdef:134> [[ tin = -p ]]
12 compdef:134> [[ time = -p ]]
12 compdef:134> [[ teamocil = -p ]]
12 compdef:134> [[ tdr = -p ]]
12 compdef:134> [[ tde = -p ]]
12 compdef:134> [[ tdd = -p ]]
12 compdef:134> [[ tardy = -p ]]
12 compdef:134> [[ swaks = -p ]]
12 compdef:134> [[ sv = -p ]]
12 compdef:134> [[ subl = -p ]]
12 compdef:134> [[ sqlite = -p ]]
12 compdef:134> [[ setcap = -p ]]
12 compdef:134> [[ scselect = -p ]]
12 compdef:134> [[ script = -p ]]
12 compdef:134> [[ rxvt = -p ]]
12 compdef:134> [[ rsvm = -p ]]
12 compdef:134> [[ rslsync = -p ]]
12 compdef:134> [[ rpm = -p ]]
12 compdef:134> [[ restic = -p ]]
12 compdef:134> [[ redis-cli = -p ]]
12 compdef:134> [[ readelf = -p ]]
12 compdef:134> [[ pygmentize = -p ]]
12 compdef:134> [[ printenv = -p ]]
12 compdef:134> [[ portsnap = -p ]]
12 compdef:134> [[ pkg_add = -p ]]
12 compdef:134> [[ perldoc = -p ]]
12 compdef:134> [[ periscope = -p ]]
12 compdef:134> [[ pdm = -p ]]
12 compdef:134> [[ patool = -p ]]
12 compdef:134> [[ optirun = -p ]]
12 compdef:134> [[ odmget = -p ]]
12 compdef:134> [[ nvm = -p ]]
12 compdef:134> [[ nm = -p ]]
12 compdef:134> [[ nl = -p ]]
12 compdef:134> [[ ninja = -p ]]
12 compdef:134> [[ nft = -p ]]
12 compdef:134> [[ ncal = -p ]]
12 compdef:134> [[ mvnDebug = -p ]]
12 compdef:134> [[ mux = -p ]]
12 compdef:134> [[ mullvad = -p ]]
12 compdef:134> [[ mplayer = -p ]]
12 compdef:134> [[ mkdir = -p ]]
12 compdef:134> [[ mdfind = -p ]]
12 compdef:134> [[ md5sum = -p ]]
12 compdef:134> [[ mc = -p ]]
12 compdef:134> [[ matlab = -p ]]
12 compdef:134> [[ make-kpkg = -p ]]
12 compdef:134> [[ lz4c32 = -p ]]
12 compdef:134> [[ lz4 = -p ]]
12 compdef:134> [[ lsusb = -p ]]
12 compdef:134> [[ look = -p ]]
12 compdef:134> [[ locate = -p ]]
12 compdef:134> [[ ln = -p ]]
12 compdef:134> [[ lintian = -p ]]
12 compdef:134> [[ links = -p ]]
12 compdef:134> [[ kubectl = -p ]]
12 compdef:134> [[ jq = -p ]]
12 compdef:134> [[ jls = -p ]]
12 compdef:134> [[ ip = -p ]]
12 compdef:134> [[ iconvconfig = -p ]]
12 compdef:134> [[ ibus = -p ]]
12 compdef:134> [[ hub = -p ]]
12 compdef:134> [[ hledger = -p ]]
12 compdef:134> [[ hash = -p ]]
12 compdef:134> [[ gzip = -p ]]
12 compdef:134> [[ gv = -p ]]
12 compdef:134> [[ guilt-unapplied = -p ]]
12 compdef:134> [[ guilt-top = -p ]]
12 compdef:134> [[ guilt-status = -p ]]
12 compdef:134> [[ guilt-series = -p ]]
12 compdef:134> [[ guilt-init = -p ]]
12 compdef:134> [[ guilt-delete = -p ]]
12 compdef:134> [[ gsha1sum = -p ]]
12 compdef:134> [[ growisofs = -p ]]
12 compdef:134> [[ gqview = -p ]]
12 compdef:134> [[ gnupod_addsong = -p ]]
12 compdef:134> [[ gid = -p ]]
12 compdef:134> [[ gcksum = -p ]]
12 compdef:134> [[ gb2sum = -p ]]
12 compdef:134> [[ fuser = -p ]]
12 compdef:134> [[ ftp = -p ]]
12 compdef:134> [[ fstat = -p ]]
12 compdef:134> [[ fs_usage = -p ]]
12 compdef:134> [[ freezer = -p ]]
12 compdef:134> [[ fortune = -p ]]
12 compdef:134> [[ finger = -p ]]
12 compdef:134> [[ figlet = -p ]]
12 compdef:134> [[ etags = -p ]]
12 compdef:134> [[ eog = -p ]]
12 compdef:134> [[ env = -p ]]
12 compdef:134> [[ enable = -p ]]
12 compdef:134> [[ emulate = -p ]]
12 compdef:134> [[ elinks = -p ]]
12 compdef:134> [[ ed = -p ]]
12 compdef:134> [[ echotc = -p ]]
12 compdef:134> [[ ecasound = -p ]]
12 compdef:134> [[ e2label = -p ]]
12 compdef:134> [[ dvidvi = -p ]]
12 compdef:134> [[ dupload = -p ]]
12 compdef:134> [[ dumper.exe = -p ]]
12 compdef:134> [[ dpkg-source = -p ]]
12 compdef:134> [[ dpkg-repack = -p ]]
12 compdef:134> [[ dpkg-reconfigure = -p ]]
12 compdef:134> [[ docpad = -p ]]
12 compdef:134> [[ dnf = -p ]]
12 compdef:134> [[ disable = -p ]]
12 compdef:134> [[ dircmp = -p ]]
12 compdef:134> [[ dig = -p ]]
12 compdef:134> [[ diff3 = -p ]]
12 compdef:134> [[ dict = -p ]]
12 compdef:134> [[ dhclient = -p ]]
12 compdef:134> [[ dcopclient = -p ]]
12 compdef:134> [[ dconf = -p ]]
12 compdef:134> [[ dchroot = -p ]]
12 compdef:134> [[ date = -p ]]
12 compdef:134> [[ cygrunsrv.exe = -p ]]
12 compdef:134> [[ cygpath.exe = -p ]]
12 compdef:134> [[ cygcheck = -p ]]
12 compdef:134> [[ cut = -p ]]
12 compdef:134> [[ curl = -p ]]
12 compdef:134> [[ cu = -p ]]
12 compdef:134> [[ cryptsetup = -p ]]
12 compdef:134> [[ crontab = -p ]]
12 compdef:134> [[ cplay = -p ]]
12 compdef:134> [[ compdef = -p ]]
12 compdef:134> [[ compadd = -p ]]
12 compdef:134> [[ coffee = -p ]]
12 compdef:134> [[ chpass = -p ]]
12 compdef:134> [[ ceilometer = -p ]]
12 compdef:134> [[ cdbs-edit-patch = -p ]]
12 compdef:134> [[ cat = -p ]]
12 compdef:134> [[ bug = -p ]]
12 compdef:134> [[ bogoutil = -p ]]
12 compdef:134> [[ bg = -p ]]
12 compdef:134> [[ attr = -p ]]
12 compdef:134> [[ artisan = -p ]]
12 compdef:134> [[ aptitude = -p ]]
12 compdef:134> [[ apm = -p ]]
12 compdef:134> [[ analyseplugin = -p ]]
12 compdef:134> [[ add-zsh-hook = -p ]]
12 compdef:134> [[ aap = -p ]]
12 compdef:134> [[ _gh = -p ]]
12 compdef:134> [[ -value-,WWW_HOME,-default- = -p ]]
12 compdef:134> [[ -value-,SPROMPT,-default- = -p ]]
12 compdef:134> [[ -value-,PRINTER,-default- = -p ]]
12 compdef:134> [[ -value-,CFLAGS,-default- = -p ]]
12 compdef:134> [[ -value-,ANDROID_SERIAL,-default- = -p ]]
12 compdef:134> [[ -value- = -p ]]
12 compdef:134> [[ -equal- = -p ]]
12 compdef:134> [[ -assign-parameter- = -p ]]
12 compdef:134> [[ -P = -p ]]
12 compdef:134> [[ 'zf_chown=chown' = -p ]]
12 compdef:134> [[ 'yodl(|2*)' = -p ]]
12 compdef:134> [[ 'gzcat=gunzip' = -p ]]
12 compdef:134> [[ 'VBoxHeadless=vboxheadless' = -p ]]
12 compdef:134> [[ '-value-,CCACHE_*,-default-' = -p ]]
12 compdef:134> [[ '-redirect-,<,gzip=gzip' = -p ]]
12 compdef:134> [[ '*/X11(|R<4->)/*' = -p ]]
12 compdef:132> [[ xlsatoms = -N ]]
12 compdef:132> [[ whatis = -N ]]
12 compdef:132> [[ typeset = -N ]]
12 compdef:132> [[ trash = -N ]]
12 compdef:132> [[ tda = -N ]]
12 compdef:132> [[ sum = -N ]]
12 compdef:132> [[ sha512t256 = -N ]]
12 compdef:132> [[ scalac = -N ]]
12 compdef:132> [[ rwho = -N ]]
12 compdef:132> [[ rec = -N ]]
12 compdef:132> [[ pushd = -N ]]
12 compdef:132> [[ psselect = -N ]]
12 compdef:132> [[ ps2pdf14 = -N ]]
12 compdef:132> [[ pg_dumpall = -N ]]
12 compdef:132> [[ opera-next = -N ]]
12 compdef:132> [[ native2ascii = -N ]]
12 compdef:132> [[ mvnDebug = -N ]]
12 compdef:132> [[ mac2unix = -N ]]
12 compdef:132> [[ lighty-disable-mod = -N ]]
12 compdef:132> [[ ldconfig.real = -N ]]
12 compdef:132> [[ gxargs = -N ]]
12 compdef:132> [[ guilt-unapplied = -N ]]
12 compdef:132> [[ guilt-prev = -N ]]
12 compdef:132> [[ guilt-import-commit = -N ]]
12 compdef:132> [[ guilt-fold = -N ]]
12 compdef:132> [[ gln = -N ]]
12 compdef:132> [[ gdiff = -N ]]
12 compdef:132> [[ gcmp = -N ]]
12 compdef:132> [[ gb2sum = -N ]]
12 compdef:132> [[ fnext = -N ]]
12 compdef:132> [[ fc-match = -N ]]
12 compdef:132> [[ dpkg-reconfigure = -N ]]
12 compdef:132> [[ dcopref = -N ]]
12 compdef:132> [[ dcopclient = -N ]]
12 compdef:132> [[ cygserver.exe = -N ]]
12 compdef:132> [[ cygpath.exe = -N ]]
12 compdef:132> [[ createuser = -N ]]
12 compdef:132> [[ ceilometer = -N ]]
12 compdef:132> [[ cdc = -N ]]
12 compdef:132> [[ ansible-inventory = -N ]]
12 compdef:132> [[ ansible-config = -N ]]
12 compdef:132> [[ a2enmod = -N ]]
12 compdef:132> [[ -value-,TERM,-default- = -N ]]
12 compdef:132> [[ -value-,PERLDOC,-default- = -N ]]
12 compdef:132> [[ -value-,P4CLIENT,-default- = -N ]]
12 compdef:132> [[ -value-,MPD_HOST,-default = -N ]]
12 compdef:132> [[ -value-,LDFLAGS,-default- = -N ]]
12 compdef:132> [[ -value-,GZIP,-default- = -N ]]
12 compdef:132> [[ -value-,ANT_ARGS,-default- = -N ]]
12 compdef:132> [[ -value-,ANSIBLE_STDOUT_CALLBACK,-default- = -N ]]
12 compdef:132> [[ -P = -N ]]
12 compdef:132> [[ 'zf_chown=chown' = -N ]]
12 compdef:132> [[ 'gzcat=gunzip' = -N ]]
12 compdef:132> [[ 'gdnolock=git-diff' = -N ]]
12 compdef:132> [[ '-value-,LC_*,-default-' = -N ]]
12 compdef:132> [[ '-value-,GO*,-default-' = -N ]]
12 compdef:132> [[ '-value-,*path,-default-' = -N ]]
12 compdef:132> [[ '-value-,*PATH,-default-' = -N ]]
12 compdef:132> [[ '-redirect-,>,gzip=gunzip' = -N ]]
12 compdef:132> [[ '-redirect-,<,unxz=unxz' = -N ]]
12 compdef:132> [[ '-redirect-,<,gzip=gzip' = -N ]]
12 compdef:132> [[ '-redirect-,<,gunzip=gunzip' = -N ]]
12 compdef:132> [[ '-redirect-,<,bunzip2=bunzip2' = -N ]]
12 compdef:131> ((  27  ))
12 compdef:131> ((  21  ))
12 compdef:131> ((  20  ))
12 compdef:131> ((  19  ))
12 compdef:131> ((  16  ))
12 compdef:131> ((  15  ))
12 compdef:131> ((  15  ))
12 compdef:131> ((  13  ))
12 compdef:131> ((  13  ))
12 compdef:131> ((  13  ))
12 compdef:131> ((  11  ))
12 compdef:131> ((  10  ))
12 compdef:131> ((  10  ))
12 compdef:131> ((  10  ))
12 compdef:131> ((  9  ))
12 compdef:131> ((  9  ))
12 compdef:131> ((  7  ))
12 compdef:131> ((  7  ))
12 compdef:131> ((  6  ))
12 compdef:131> ((  6  ))
12 compdef:131> ((  6  ))
12 compdef:131> ((  4  ))
12 compdef:131> ((  4  ))
12 compdef:131> ((  4  ))
12 compdef:131> ((  4  ))
12 compdef:131> ((  4  ))
12 compdef:131> ((  3  ))
12 compdef:131> ((  3  ))
12 compdef:131> ((  3  ))
12 compdef:131> ((  3  ))
12 compdef:131> ((  3  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  2  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:131> ((  1  ))
12 compdef:110> [[ list-choices = .* ]]
12 compdef:110> [[ complete-word = .* ]]
12 compdef:104> [[ 2 -lt 2 ]]
12 compdef:91> 2=.complete-word
12 compdef:91> 2=.complete-word
12 compdef:90> [[ _history-complete-newer = _* ]]
12 compdef:86> [[ 3 -lt 3 ]]
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (widgetkey)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (key)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:83> case  (*)
12 compdef:81> shift
12 compdef:80> [[ -n '' ]]
12 compdef:80> [[ -n '' ]]
12 compdef:80> [[ -n '' ]]
12 compdef:80> [[ -n '' ]]
12 compdef:80> [[ -n '' ]]
12 compdef:79> func=_ztodo
12 compdef:79> func=_zsocket
12 compdef:79> func=_zmodload
12 compdef:79> func=_zle
12 compdef:79> func=_zattr
12 compdef:79> func=_xmlsoft
12 compdef:79> func=_xloadimage
12 compdef:79> func=_xft_fonts
12 compdef:79> func=_update-alternatives
12 compdef:79> func=_tree
12 compdef:79> func=_tardy
12 compdef:79> func=_stack
12 compdef:79> func=_setcap
12 compdef:79> func=_sdd
12 compdef:79> func=_scrub
12 compdef:79> func=_rsvm
12 compdef:79> func=_rslsync
12 compdef:79> func=_rmdir
12 compdef:79> func=_rm
12 compdef:79> func=_pygmentize
12 compdef:79> func=_pkcon
12 compdef:79> func=_pixz
12 compdef:79> func=_pgsql_utils
12 compdef:79> func=_perf
12 compdef:79> func=_patool
12 compdef:79> func=_nl
12 compdef:79> func=_nice
12 compdef:79> func=_networkmanager
12 compdef:79> func=_nano
12 compdef:79> func=_mussh
12 compdef:79> func=_mullvad
12 compdef:79> func=_mpv
12 compdef:79> func=_moosic
12 compdef:79> func=_madison
12 compdef:79> func=_lighttpd
12 compdef:79> func=_ispell
12 compdef:79> func=_gv
12 compdef:79> func=_gtk-launch
12 compdef:79> func=_git-flow
12 compdef:79> func=_git
12 compdef:79> func=_gist
12 compdef:79> func=_fs_usage
12 compdef:79> func=_fmt
12 compdef:79> func=_expand_word
12 compdef:79> func=_elinks
12 compdef:79> func=_ecasound
12 compdef:79> func=_dput
12 compdef:79> func=_dmidecode
12 compdef:79> func=_diff3
12 compdef:79> func=_dict
12 compdef:79> func=_dhclient
12 compdef:79> func=_df
12 compdef:79> func=_dcut
12 compdef:79> func=_cvsup
12 compdef:79> func=_cvs
12 compdef:79> func=_cu
12 compdef:79> func=_cryptsetup
12 compdef:79> func=_cpio
12 compdef:79> func=_configure
12 compdef:79> func=_complete_debug
12 compdef:79> func=_comm
12 compdef:79> func=_column
12 compdef:79> func=_coffee
12 compdef:79> func=_cmp
12 compdef:79> func=_clay
12 compdef:79> func=_calendar
12 compdef:79> func=_bundle
12 compdef:79> func=_alias
12 compdef:79> func=_afew
12 compdef:49> [[ _xterm = *=* ]]
12 compdef:49> [[ _who = *=* ]]
12 compdef:49> [[ _vnc = *=* ]]
12 compdef:49> [[ _vmstat = *=* ]]
12 compdef:49> [[ _vmctl = *=* ]]
12 compdef:49> [[ _visudo = *=* ]]
12 compdef:49> [[ _vim-addons = *=* ]]
12 compdef:49> [[ _vcsh = *=* ]]
12 compdef:49> [[ _users = *=* ]]
12 compdef:49> [[ _uname = *=* ]]
12 compdef:49> [[ _ulimit = *=* ]]
12 compdef:49> [[ _twidge = *=* ]]
12 compdef:49> [[ _ttyctl = *=* ]]
12 compdef:49> [[ _trash = *=* ]]
12 compdef:49> [[ _trap = *=* ]]
12 compdef:49> [[ _tracepath = *=* ]]
12 compdef:49> [[ _tr = *=* ]]
12 compdef:49> [[ _tex = *=* ]]
12 compdef:49> [[ _telnet = *=* ]]
12 compdef:49> [[ _tee = *=* ]]
12 compdef:49> [[ _tail = *=* ]]
12 compdef:49> [[ _system_profiler = *=* ]]
12 compdef:49> [[ _systat = *=* ]]
12 compdef:49> [[ _swift = *=* ]]
12 compdef:49> [[ _strace = *=* ]]
12 compdef:49> [[ _stat = *=* ]]
12 compdef:49> [[ _source = *=* ]]
12 compdef:49> [[ _socket = *=* ]]
12 compdef:49> [[ _snoop = *=* ]]
12 compdef:49> [[ _slabtop = *=* ]]
12 compdef:49> [[ _showmount = *=* ]]
12 compdef:49> [[ _setsid = *=* ]]
12 compdef:49> [[ _setopt = *=* ]]
12 compdef:49> [[ _scselect = *=* ]]
12 compdef:49> [[ _scl = *=* ]]
12 compdef:49> [[ _schroot = *=* ]]
12 compdef:49> [[ _savecore = *=* ]]
12 compdef:49> [[ _runit = *=* ]]
12 compdef:49> [[ _rpm = *=* ]]
12 compdef:49> [[ _rlogin = *=* ]]
12 compdef:49> [[ _readelf = *=* ]]
12 compdef:49> [[ _read_comp = *=* ]]
12 compdef:49> [[ _rcctl = *=* ]]
12 compdef:49> [[ _qtplay = *=* ]]
12 compdef:49> [[ _pydoc = *=* ]]
12 compdef:49> [[ _pwgen = *=* ]]
12 compdef:49> [[ _pscp = *=* ]]
12 compdef:49> [[ _prove = *=* ]]
12 compdef:49> [[ _prompt = *=* ]]
12 compdef:49> [[ _procstat = *=* ]]
12 compdef:49> [[ _postscript = *=* ]]
12 compdef:49> [[ _pmap = *=* ]]
12 compdef:49> [[ _plutil = *=* ]]
12 compdef:49> [[ _pkgadd = *=* ]]
12 compdef:49> [[ _pkg5 = *=* ]]
12 compdef:49> [[ _pkg-config = *=* ]]
12 compdef:49> [[ _piuparts = *=* ]]
12 compdef:49> [[ _ping = *=* ]]
12 compdef:49> [[ _pids = *=* ]]
12 compdef:49> [[ _pidof = *=* ]]
12 compdef:49> [[ _patch = *=* ]]
12 compdef:49> [[ _parameter = *=* ]]
12 compdef:49> [[ _pandoc = *=* ]]
12 compdef:49> [[ _pack = *=* ]]
12 compdef:49> [[ _osc = *=* ]]
12 compdef:49> [[ _mail = *=* ]]
12 compdef:49> [[ _lz4 = *=* ]]
12 compdef:49> [[ _ls = *=* ]]
12 compdef:49> [[ _knock = *=* ]]
12 compdef:49> [[ _kak = *=* ]]
12 compdef:49> [[ _install = *=* ]]
12 compdef:49> [[ _homestead = *=* ]]
12 compdef:49> [[ _gradle = *=* ]]
12 compdef:49> [[ _golang = *=* ]]
12 compdef:49> [[ _git-journal = *=* ]]
12 compdef:49> [[ _git = *=* ]]
12 compdef:49> [[ _git = *=* ]]
12 compdef:49> [[ _git = *=* ]]
12 compdef:49> [[ _gem = *=* ]]
12 compdef:49> [[ _first = *=* ]]
12 compdef:49> [[ _fetchmail = *=* ]]
12 compdef:49> [[ _dvc = *=* ]]
12 compdef:49> [[ _cp = *=* ]]
12 compdef:49> [[ _coreadm = *=* ]]
12 compdef:49> [[ _cockroach = *=* ]]
12 compdef:49> [[ _baz = *=* ]]
12 compdef:49> [[ _aws = *=* ]]
12 compdef:49> [[ _assign = *=* ]]
12 compdef:49> [[ _asdf = *=* ]]
12 compdef:49> [[ _SUSEconfig = *=* ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:49> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:45> [[ -z '' ]]
12 compdef:40> ((  ! 18  ))
12 compdef:40> ((  ! 16  ))
12 compdef:40> ((  ! 14  ))
12 compdef:40> ((  ! 14  ))
12 compdef:40> ((  ! 12  ))
12 compdef:40> ((  ! 12  ))
12 compdef:40> ((  ! 11  ))
12 compdef:40> ((  ! 11  ))
12 compdef:40> ((  ! 10  ))
12 compdef:40> ((  ! 8  ))
12 compdef:40> ((  ! 8  ))
12 compdef:40> ((  ! 7  ))
12 compdef:40> ((  ! 7  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 6  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 5  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 4  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 3  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:40> ((  ! 2  ))
12 compdef:28> [[ K = K ]]
12 compdef:24> [[ k = p ]]
12 compdef:24> [[ K = p ]]
12 compdef:18> [[ -n '' ]]
12 compdef:18> [[ -n '' ]]
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (n)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case n (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case a (a)
12 compdef:15> case K (n)
12 compdef:15> case K (a)
12 colors:114> bg[${k#bg-}]=$'C-[[45m'
12 colors:114> bg[${k#bg-}]=$'C-[[44m'
12 colors:105> fg[${k#fg-}]=$'C-[[32m'
12 colors:105> fg[${k#fg-}]=$'C-[[30m'
12 colors:98> reset_color=$'C-[[00m'
12 colors:87> color[bg-grey]=40
12 colors:85> color[grey]=30
12 colors:81> color[fg-${color[$k]}]=36
12 colors:81> color[fg-${color[$k]}]=35
12 colors:81> color[fg-${color[$k]}]=34
12 colors:81> color[fg-${color[$k]}]=33
12 colors:81> color[fg-${color[$k]}]=32
12 colors:81> color[fg-${color[$k]}]=30
12 colors:77> k=44
12 colors:77> color[${color[$k]}]=49
12 colors:77> color[${color[$k]}]=45
12 colors:77> color[${color[$k]}]=39
12 colors:77> color[${color[$k]}]=25
12 colors:77> color[${color[$k]}]=24
12 colors:77> color[${color[$k]}]=23
12 colors:77> color[${color[$k]}]=22
12 colors:77> color[${color[$k]}]=08
12 colors:77> color[${color[$k]}]=07
12 colors:77> color[${color[$k]}]=02
12 colors:77> color[${color[$k]}]=01
12 antigen-ext-init:3> ext=parallel
12 antigen-ext-init:3> ext=lock
12 antigen-ext-init:3> ext=defer
12 antigen-add-hook:14> _ANTIGEN_HOOKS[$target]=-antigen-load-env-cached
12 add-zsh-hook:83> ((  1  ))
12 add-zsh-hook:68> ((  del  ))
12 add-zsh-hook:68> ((  del  ))
12 add-zle-hook-widget:54> ((  del  ))
12 _zsh_highlight_load_highlighters:13> highlighter=regexp
12 _zsh_highlight_load_highlighters:13> highlighter=regexp
12 _zsh_highlight_load_highlighters:13> highlighter=main
12 _zsh_highlight_load_highlighters:13> highlighter=line
12 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
12 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
12 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
12 _zsh_highlight_bind_widgets:54> [[ zle-isearch-update == zle-* ]]
12 _zsh_highlight_bind_widgets:27> case user:up-line-or-beginning-search (user:_...
12 _zsh_highlight_bind_widgets:27> case user:edit-command-line (user:_zsh_highli...
12 _zsh_highlight_bind_widgets:27> case completion:.menu-complete:_main_complete...
12 _zsh_highlight_bind_widgets:27> case completion:.delete-char-or-list:_main_co...
12 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_read_comp (us...
12 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
12 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_help...
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
12 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
12 _zsh_highlight_bind_widgets:26> cur_widget=zle-line-finish
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-yank-whole-line
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-up-line-or-history
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-unindent
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-substitute
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-repeat-search
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-quoted-insert
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-oper-swap-case
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-open-line-above
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-kill-line
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-goto-mark
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-forward-word-end
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-forward-word
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-forward-blank-word-end
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-find-next-char-skip
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-down-line-or-history
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-beginning-of-line
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-word
12 _zsh_highlight_bind_widgets:26> cur_widget=vi-backward-blank-word
12 _zsh_highlight_bind_widgets:26> cur_widget=up-line-or-search
12 _zsh_highlight_bind_widgets:26> cur_widget=up-line-or-history
12 _zsh_highlight_bind_widgets:26> cur_widget=spell-word
12 _zsh_highlight_bind_widgets:26> cur_widget=set-mark-command
12 _zsh_highlight_bind_widgets:26> cur_widget=send-break
12 _zsh_highlight_bind_widgets:26> cur_widget=select-in-shell-word
12 _zsh_highlight_bind_widgets:26> cur_widget=select-a-word
12 _zsh_highlight_bind_widgets:26> cur_widget=select-a-shell-word
12 _zsh_highlight_bind_widgets:26> cur_widget=reset-prompt
12 _zsh_highlight_bind_widgets:26> cur_widget=quote-line
12 _zsh_highlight_bind_widgets:26> cur_widget=push-line-or-edit
12 _zsh_highlight_bind_widgets:26> cur_widget=pound-insert
12 _zsh_highlight_bind_widgets:26> cur_widget=menu-expand-or-complete
12 _zsh_highlight_bind_widgets:26> cur_widget=menu-complete
12 _zsh_highlight_bind_widgets:26> cur_widget=list-expand
12 _zsh_highlight_bind_widgets:26> cur_widget=list-choices
12 _zsh_highlight_bind_widgets:26> cur_widget=kill-region
12 _zsh_highlight_bind_widgets:26> cur_widget=kill-line
12 _zsh_highlight_bind_widgets:26> cur_widget=insert-last-word
12 _zsh_highlight_bind_widgets:26> cur_widget=infer-next-history
12 _zsh_highlight_bind_widgets:26> cur_widget=forward-char
12 _zsh_highlight_bind_widgets:26> cur_widget=edit-command-line
12 _zsh_highlight_bind_widgets:26> cur_widget=down-line-or-search
12 _zsh_highlight_bind_widgets:26> cur_widget=down-line-or-history
12 _zsh_highlight_bind_widgets:26> cur_widget=digit-argument
12 _zsh_highlight_bind_widgets:26> cur_widget=delete-word
12 _zsh_highlight_bind_widgets:26> cur_widget=delete-char
12 _zsh_highlight_bind_widgets:26> cur_widget=deactivate-region
12 _zsh_highlight_bind_widgets:26> cur_widget=copy-region-as-kill
12 _zsh_highlight_bind_widgets:26> cur_widget=copy-prev-shell-word
12 _zsh_highlight_bind_widgets:26> cur_widget=clear-screen
12 _zsh_highlight_bind_widgets:26> cur_widget=bracketed-paste
12 _zsh_highlight_bind_widgets:26> cur_widget=beginning-of-line-hist
12 _zsh_highlight_bind_widgets:26> cur_widget=beginning-of-line
12 _zsh_highlight_bind_widgets:26> cur_widget=beginning-of-buffer-or-history
12 _zsh_highlight_bind_widgets:26> cur_widget=backward-delete-word
12 _zsh_highlight_bind_widgets:26> cur_widget=backward-char
12 _zsh_highlight_bind_widgets:26> cur_widget=argument-base
12 _zsh_highlight_bind_widgets:26> cur_widget=accept-search
12 _zsh_highlight_bind_widgets:26> cur_widget=accept-and-menu-complete
12 _zsh_highlight_bind_widgets:26> cur_widget=accept-and-infer-next-history
12 _zsh_highlight_bind_widgets:26> cur_widget=_most_recent_file
12 _zsh_highlight_bind_widgets:26> cur_widget=_list_expansions
12 _zsh_highlight_bind_widgets:26> cur_widget=_history-complete-newer
12 _zsh_highlight_bind_widgets:26> cur_widget=_complete_help
12 _zsh_highlight_bind_widgets:26> cur_widget=_bash_list-choices
12 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
12 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:147> config_file=/Users/matt/.oh-my-zsh/l...
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;251m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;247m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;244m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;243m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;236m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;231m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;230m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;227m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;219m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;217m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;216m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;213m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;210m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;208m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;204m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;203m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;202m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;199m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;196m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;194m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;192m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;187m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;183m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;179m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;177m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;174m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;172m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;170m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;168m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;166m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;164m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;162m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;160m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;159m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;154m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;152m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;150m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;146m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;140m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;134m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;133m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;132m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;128m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;127m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;126m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;125m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;123m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;120m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;119m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;118m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;116m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;103m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;100m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;099m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;098m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;094m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;085m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;083m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;078m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;074m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;071m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;069m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;068m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;066m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;060m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;058m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;054m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;047m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;045m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;041m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;039m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;037m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;035m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;032m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;030m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;028m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;027m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;026m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;024m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;021m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;019m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;016m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;014m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;011m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;255m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;253m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;252m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;250m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;249m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;244m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;241m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;240m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;239m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;237m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;236m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;234m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;228m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;227m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;224m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;223m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;218m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;217m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;210m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;209m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;207m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;206m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;205m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;203m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;200m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;197m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;196m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;195m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;194m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;193m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;192m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;191m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;189m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;184m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;182m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;180m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;179m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;178m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;177m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;174m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;173m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;172m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;171m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;170m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;169m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;167m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;165m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;163m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;161m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;158m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;156m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;155m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;153m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;151m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;149m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;147m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;144m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;134m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;131m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;129m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;127m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;124m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;120m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;118m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;117m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;104m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;103m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;102m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;100m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;095m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;093m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;086m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;084m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;077m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;075m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;073m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;070m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;068m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;067m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;061m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;059m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;055m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;054m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;053m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;046m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;043m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;042m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;040m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;038m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;036m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;031m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;029m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;025m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;023m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;022m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;020m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;018m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;017m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;015m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;012m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;010m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;009m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;007m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;006m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;004m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;003m%}'
12 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;002m%}'
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/usr/share/zsh/5.8.1/functions
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/usr/local/share/zsh/site-functions
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/plugins/git
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/plugins/fasd
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/functions
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/custom/plugin...
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/custom/plugin...
12 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/custom/plugin...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/theme-and-appearance....
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:18> BG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:17> FG[$...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
12 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/history.zsh:21> case ...
12 -antigen-use-oh-my-zsh:3> [[ -z /Users/matt/.oh-my-zsh ]]
12 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/zsh-users/zsh-aut...
12 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/robbyrussell/oh-m...
12 -antigen-parse-args:146> bpath=/Users/matt/.antigen/bundles/robbyrussell/oh-m...
12 -antigen-parse-args:137> [[ -n '' ]]
12 -antigen-parse-args:137> [[ -n '' ]]
12 -antigen-parse-args:137> [[ -n '' ]]
12 -antigen-parse-args:127> [[ -n '' ]]
12 -antigen-parse-args:122> name=robbyrussell/oh-my-zsh.git
12 -antigen-parse-args:99> [[ https://github.com/zsh-users/zsh-autosuggestions.g...
12 -antigen-parse-args:99> [[ https://github.com/robbyrussell/oh-my-zsh.git == /...
12 -antigen-parse-args:99> [[ https://github.com/robbyrussell/oh-my-zsh.git == /...
12 -antigen-parse-args:72> args[loc]=plugins/deno
12 -antigen-parse-args:70> case https://github.com/robbyrussell/oh-my-zsh.git (h...
12 -antigen-parse-args:37> value=zsh-users/zsh-autosuggestions
12 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (*)
12 -antigen-parse-args:22> case deno (--url | --loc | --branch | --btype)
12 -antigen-parse-args:22> case deno (*)
12 -antigen-parse-args:18> argkey=deno
12 -antigen-parse-args:18> argkey=--loc
12 -antigen-parse-args:13> args[make_local_clone]=true
12 -antigen-load:15> [[ plugin == theme ]]
12 -antigen-hook-handler:46> replace_hook=1
12 -antigen-hook-handler:22> case replace (pre)
12 -antigen-hook-handler:18> meta[called]=12
12 -antigen-hook-handler:18> meta[called]=10
12 -antigen-hook-handler:18> meta[called]=3
12 -antigen-hook-handler:18> meta[called]=3
12 -antigen-hook-handler:18> meta[called]=3
12 -antigen-hook-handler:18> meta[called]=2
12 -antigen-hook-handler:18> meta[called]=1
12 -antigen-hook-handler:18> meta[called]=1
12 -antigen-hook-handler:18> meta[called]=1
12 -antigen-hook-handler:18> meta[called]=1
12 -antigen-hook-handler:10> hook=antigen-bundle-defer
12 -antigen-hook-handler:10> hook=antigen-bundle-defer
12 -antigen-hook-handler:10> hook=-antigen-load-source-cached
12 (eval):245> alias 'z=fasd_cd -d'
12 (eval):216> alias 'it2check=/Users/matt/.iterm2/it2check'
12 (eval):214> alias 'it2api=/Users/matt/.iterm2/it2api'
12 (eval):212> alias 'imgcat=/Users/matt/.iterm2/imgcat'
12 (eval):208> alias 'gupv=git pull --rebase -v'
12 (eval):197> alias 'run-help=man'
12 (eval):191> alias 'la=ls -lAh'
12 (eval):191> alias 'gstp=git stash pop'
12 (eval):190> alias 'gstl=git stash list'
12 (eval):186> alias 'gstaa=git stash apply'
12 (eval):185> alias 'gsta=git stash push'
12 (eval):184> alias 'gupa=git pull --rebase --autostash'
12 (eval):180> alias 'gtv=git tag | sort -V'
12 (eval):176> alias 'grv=git remote -v'
12 (eval):173> alias 'gsu=git submodule update'
12 (eval):172> alias 'grst=git restore --staged'
12 (eval):170> alias 'gstp=git stash pop'
12 (eval):169> alias 'gstl=git stash list'
12 (eval):165> alias 'grmc=git rm --cached'
12 (eval):161> alias 'gsr=git svn rebase'
12 (eval):159> alias 'grbs=git rebase --skip'
12 (eval):158> alias 'gsh=git show'
12 (eval):157> alias 'grbo=git rebase --onto'
12 (eval):154> alias 'grbd=git rebase $(git_develop_branch)'
12 (eval):151> alias 'grst=git restore --staged'
12 (eval):149> alias 'grset=git remote set-url'
12 (eval):149> alias 'gr=git remote'
12 (eval):144> alias 'grmc=git rm --cached'
12 (eval):141> alias 'grh=git reset'
12 (eval):141> alias 'gpf=git push --force-with-lease'
12 (eval):139> alias 'gp=git push'
12 (eval):135> alias 'grbm=git rebase $(git_main_branch)'
12 (eval):133> alias 'gmm=gmom'
12 (eval):130> alias 'grb=git rebase'
12 (eval):128> alias 'gr=git remote'
12 (eval):120> alias 'gpf=git push --force-with-lease'
12 (eval):120> alias 'glgp=git log --stat -p'
12 (eval):118> alias 'glgga=git log --graph --decorate --all'
12 (eval):110> alias 'glp=_git_log_prettily'
12 (eval):101> alias 'glgp=git log --stat -p'
12 (eval):101> alias 'gfg=git ls-files | grep'
12 (eval):99> alias 'glgga=git log --graph --decorate --all'
12 (eval):94> alias 'gk=gitk --all --branches &!'
12 (eval):88> alias 'gcsm=git commit -s -m'
12 (eval):86> alias 'gcpc=git cherry-pick --continue'
12 (eval):81> alias 'gco=git checkout'
12 (eval):79> alias 'gcmsg=git commit -m'
12 (eval):76> alias 'gds=git diff --staged'
12 (eval):74> alias 'gcd=git checkout $(git_develop_branch)'
12 (eval):73> alias 'gcb=git checkout -b'
12 (eval):71> alias 'gcssm=git commit -S -s -m'
12 (eval):68> alias 'gcam=git commit -a -m'
12 (eval):67> alias 'gcpc=git cherry-pick --continue'
12 (eval):65> alias 'gc!=git commit -v --amend'
12 (eval):63> alias 'gbss=git bisect start'
12 (eval):61> alias 'gcn!=git commit -v --no-edit --amend'
12 (eval):60> alias 'gbsb=git bisect bad'
12 (eval):59> alias 'gcm=git checkout $(git_main_branch)'
12 (eval):56> alias 'gcf=git config --list'
12 (eval):53> alias 'gcasm=git commit -a -s -m'
12 (eval):52> alias 'gcas=git commit -a -s'
12 (eval):50> alias 'gav=git add --verbose'
12 (eval):48> alias 'gca!=git commit -v -a --amend'
12 (eval):47> alias 'gca=git commit -v -a'
12 (eval):44> alias 'gbss=git bisect start'
12 (eval):42> alias 'gama=git am --abort'
12 (eval):39> alias 'gbr=git branch --remote'
12 (eval):34> alias 'gba=git branch -a'
12 (eval):29> alias 'gapt=git apply --3way'
12 (eval):29> alias 'drn=deno run'
12 (eval):27> alias 'gap=git apply'
12 (eval):25> alias 'gams=git am --skip'
12 (eval):23> alias 'dc=deno compile'
12 (eval):14> alias '9=cd -9'
12 (eval):9> alias '4=cd -4'
12 (eval):8> alias '3=cd -3'
12 (eval):4> alias -g '.....=../../../..'
12 (eval):1> test -z ''
12 (eval):1> test -z ''
12 (eval):1> test -z ''
11 regexp-replace:16> ((  pcre  ))
11 is-at-least:54> ((  part < min_ver[min_cnt]  ))
11 is-at-least:54> ((  part < min_ver[min_cnt]  ))
11 is-at-least:53> ((  part > min_ver[min_cnt]  ))
11 is-at-least:53> ((  part > min_ver[min_cnt]  ))
11 is-at-least:53> ((  part > min_ver[min_cnt]  ))
11 is-at-least:53> ((  part > min_ver[min_cnt]  ))
11 is-at-least:49> ((  ++min_cnt > 4  ))
11 is-at-least:49> ((  ++min_cnt > 2  ))
11 is-at-least:49> ((  ++min_cnt > 2  ))
11 is-at-least:49> ((  ++min_cnt > 2  ))
11 is-at-least:45> part=8
11 is-at-least:45> part=1
11 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
11 is-at-least:33> [[ 8 = *[0-9][^0-9]* ]]
11 is-at-least:32> ((  ++ver_cnt > 4  ))
11 is-at-least:32> ((  ++ver_cnt > 4  ))
11 is-at-least:31> [[ '' != <-> ]]
11 is-at-least:31> [[ '' != <-> ]]
11 is-at-least:31> [[ '' != <-> ]]
11 is-at-least:30> ((  1 <= 2  ))
11 is-at-least:30> ((  0 <= 2  ))
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #compdef (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:506> case #autoload (#compdef)
11 compinit:500> _i_name=_zypper
11 compinit:500> _i_name=_zle
11 compinit:500> _i_name=_zfs_keysource_props
11 compinit:500> _i_name=_zfs
11 compinit:500> _i_name=_zed
11 compinit:500> _i_name=_zeal
11 compinit:500> _i_name=_zcat
11 compinit:500> _i_name=_zcalc_line
11 compinit:500> _i_name=_yp
11 compinit:500> _i_name=_yodl
11 compinit:500> _i_name=_yast
11 compinit:500> _i_name=_yarn
11 compinit:500> _i_name=_yafc
11 compinit:500> _i_name=_xz
11 compinit:500> _i_name=_xt_session_id
11 compinit:500> _i_name=_xset
11 compinit:500> _i_name=_xscreensaver
11 compinit:500> _i_name=_which
11 compinit:500> _i_name=_webbrowser
11 compinit:500> _i_name=_watch-snoop
11 compinit:500> _i_name=_wanna-build
11 compinit:500> _i_name=_wajig
11 compinit:500> _i_name=_wait
11 compinit:500> _i_name=_w3m
11 compinit:500> _i_name=_w
11 compinit:500> _i_name=_volume_groups
11 compinit:500> _i_name=_vmstat
11 compinit:500> _i_name=_visudo
11 compinit:500> _i_name=_vim-addons
11 compinit:500> _i_name=_vared
11 compinit:500> _i_name=_value
11 compinit:500> _i_name=_user_at_host
11 compinit:500> _i_name=_user_admin
11 compinit:500> _i_name=_urxvt
11 compinit:500> _i_name=_urpmi
11 compinit:500> _i_name=_update-rc.d
11 compinit:500> _i_name=_units
11 compinit:500> _i_name=_unison
11 compinit:500> _i_name=_uniq
11 compinit:500> _i_name=_unhash
11 compinit:500> _i_name=_udisksctl
11 compinit:500> _i_name=_typeset
11 compinit:500> _i_name=_ttyctl
11 compinit:500> _i_name=_tty
11 compinit:500> _i_name=_truss
11 compinit:500> _i_name=_tree
11 compinit:500> _i_name=_trash-put
11 compinit:500> _i_name=_trash
11 compinit:500> _i_name=_transmission
11 compinit:500> _i_name=_tracepath
11 compinit:500> _i_name=_tr
11 compinit:500> _i_name=_tpb
11 compinit:500> _i_name=_totd
11 compinit:500> _i_name=_toolchain-source
11 compinit:500> _i_name=_todo.sh
11 compinit:500> _i_name=_tload
11 compinit:500> _i_name=_time_zone
11 compinit:500> _i_name=_tilde
11 compinit:500> _i_name=_tidy
11 compinit:500> _i_name=_telnet
11 compinit:500> _i_name=_tardy
11 compinit:500> _i_name=_tail
11 compinit:500> _i_name=_tags
11 compinit:500> _i_name=_system_profiler
11 compinit:500> _i_name=_sysctl
11 compinit:500> _i_name=_sys_calls
11 compinit:500> _i_name=_svn-buildpackage
11 compinit:500> _i_name=_svm
11 compinit:500> _i_name=_svcs_fmri
11 compinit:500> _i_name=_svcadm
11 compinit:500> _i_name=_suffix_alias_files
11 compinit:500> _i_name=_subscript
11 compinit:500> _i_name=_sublimetext
11 compinit:500> _i_name=_strace
11 compinit:500> _i_name=_store_cache
11 compinit:500> _i_name=_stgit
11 compinit:500> _i_name=_ss
11 compinit:500> _i_name=_srm
11 compinit:500> _i_name=_split
11 compinit:500> _i_name=_sort
11 compinit:500> _i_name=_softwareupdate
11 compinit:500> _i_name=_sockstat
11 compinit:500> _i_name=_snoop
11 compinit:500> _i_name=_sisu
11 compinit:500> _i_name=_showmount
11 compinit:500> _i_name=_set_command
11 compinit:500> _i_name=_set
11 compinit:500> _i_name=_sequence
11 compinit:500> _i_name=_sep_parts
11 compinit:500> _i_name=_selinux_types
11 compinit:500> _i_name=_selinux_roles
11 compinit:500> _i_name=_sed
11 compinit:500> _i_name=_script
11 compinit:500> _i_name=_screen
11 compinit:500> _i_name=_scl
11 compinit:500> _i_name=_samba
11 compinit:500> _i_name=_rubber
11 compinit:500> _i_name=_rsync
11 compinit:500> _i_name=_rrdtool
11 compinit:500> _i_name=_route
11 compinit:500> _i_name=_rkt
11 compinit:500> _i_name=_ri
11 compinit:500> _i_name=_retrieve_mac_apps
11 compinit:500> _i_name=_retrieve_cache
11 compinit:500> _i_name=_regex_arguments
11 compinit:500> _i_name=_rebootin
11 compinit:500> _i_name=_read
11 compinit:500> _i_name=_rdesktop
11 compinit:500> _i_name=_rake
11 compinit:500> _i_name=_qtplay
11 compinit:500> _i_name=_qiv
11 compinit:500> _i_name=_qemu
11 compinit:500> _i_name=_python_modules
11 compinit:500> _i_name=_pump
11 compinit:500> _i_name=_ptree
11 compinit:500> _i_name=_pscp
11 compinit:500> _i_name=_procstat
11 compinit:500> _i_name=_process_names
11 compinit:500> _i_name=_postscript
11 compinit:500> _i_name=_postgresql
11 compinit:500> _i_name=_ports
11 compinit:500> _i_name=_portmaster
11 compinit:500> _i_name=_pon
11 compinit:500> _i_name=_pkg_instance
11 compinit:500> _i_name=_pine
11 compinit:500> _i_name=_php
11 compinit:500> _i_name=_phing
11 compinit:500> _i_name=_perldoc
11 compinit:500> _i_name=_perl_modules
11 compinit:500> _i_name=_perforce
11 compinit:500> _i_name=_pdm
11 compinit:500> _i_name=_pdftk
11 compinit:500> _i_name=_pbuilder
11 compinit:500> _i_name=_pbm
11 compinit:500> _i_name=_pax
11 compinit:500> _i_name=_path_commands
11 compinit:500> _i_name=_parameters
11 compinit:500> _i_name=_parameter
11 compinit:500> _i_name=_pack
11 compinit:500> _i_name=_osascript
11 compinit:500> _i_name=_options_unset
11 compinit:500> _i_name=_options
11 compinit:500> _i_name=_oldlist
11 compinit:500> _i_name=_obsd_architectures
11 compinit:500> _i_name=_nslookup
11 compinit:500> _i_name=_node
11 compinit:500> _i_name=_nmap
11 compinit:500> _i_name=_nm
11 compinit:500> _i_name=_next_tags
11 compinit:500> _i_name=_next_label
11 compinit:500> _i_name=_netscape
11 compinit:500> _i_name=_netcat
11 compinit:500> _i_name=_ncftp
11 compinit:500> _i_name=_nano
11 compinit:500> _i_name=_mysql_utils
11 compinit:500> _i_name=_my_accounts
11 compinit:500> _i_name=_mupdf
11 compinit:500> _i_name=_mtr
11 compinit:500> _i_name=_mt
11 compinit:500> _i_name=_mplayer
11 compinit:500> _i_name=_mpc
11 compinit:500> _i_name=_moosic
11 compinit:500> _i_name=_module_math_func
11 compinit:500> _i_name=_module
11 compinit:500> _i_name=_mktemp
11 compinit:500> _i_name=_mkshortcut
11 compinit:500> _i_name=_mii-tool
11 compinit:500> _i_name=_mere
11 compinit:500> _i_name=_mencal
11 compinit:500> _i_name=_members
11 compinit:500> _i_name=_mdutil
11 compinit:500> _i_name=_mc
11 compinit:500> _i_name=_matlab
11 compinit:500> _i_name=_make
11 compinit:500> _i_name=_main_complete
11 compinit:500> _i_name=_madison
11 compinit:500> _i_name=_lz4
11 compinit:500> _i_name=_lynx
11 compinit:500> _i_name=_lunchy
11 compinit:500> _i_name=_luarocks
11 compinit:500> _i_name=_lsusb
11 compinit:500> _i_name=_lspv
11 compinit:500> _i_name=_lslv
11 compinit:500> _i_name=_lscfg
11 compinit:500> _i_name=_ls
11 compinit:500> _i_name=_look
11 compinit:500> _i_name=_locales
11 compinit:500> _i_name=_locale
11 compinit:500> _i_name=_loadkeys
11 compinit:500> _i_name=_ln
11 compinit:500> _i_name=_list
11 compinit:500> _i_name=_limits
11 compinit:500> _i_name=_ldd
11 compinit:500> _i_name=_language_codes
11 compinit:500> _i_name=_kvno
11 compinit:500> _i_name=_kubectl
11 compinit:500> _i_name=_kpartx
11 compinit:500> _i_name=_knock
11 compinit:500> _i_name=_kld
11 compinit:500> _i_name=_kitchen
11 compinit:500> _i_name=_kill
11 compinit:500> _i_name=_jobs
11 compinit:500> _i_name=_jls
11 compinit:500> _i_name=_jexec
11 compinit:500> _i_name=_java
11 compinit:500> _i_name=_jails
11 compinit:500> _i_name=_jail
11 compinit:500> _i_name=_iwconfig
11 compinit:500> _i_name=_irssi
11 compinit:500> _i_name=_ipsec
11 compinit:500> _i_name=_ipadm
11 compinit:500> _i_name=_invoke-rc.d
11 compinit:500> _i_name=_install
11 compinit:500> _i_name=_initctl
11 compinit:500> _i_name=_inetadm
11 compinit:500> _i_name=_in_vared
11 compinit:500> _i_name=_imagemagick
11 compinit:500> _i_name=_ifconfig
11 compinit:500> _i_name=_id
11 compinit:500> _i_name=_iconvconfig
11 compinit:500> _i_name=_ibus
11 compinit:500> _i_name=_homestead
11 compinit:500> _i_name=_history
11 compinit:500> _i_name=_hexdump
11 compinit:500> _i_name=_hdiutil
11 compinit:500> _i_name=_gtk-launch
11 compinit:500> _i_name=_grep-excuses
11 compinit:500> _i_name=_graphicsmagick
11 compinit:500> _i_name=_gqview
11 compinit:500> _i_name=_gphoto2
11 compinit:500> _i_name=_google
11 compinit:500> _i_name=_gnu_generic
11 compinit:500> _i_name=_gnome-gv
11 compinit:500> _i_name=_globquals
11 compinit:500> _i_name=_git-wtf
11 compinit:500> _i_name=_git-pulls
11 compinit:500> _i_name=_git-journal
11 compinit:500> _i_name=_git-buildpackage
11 compinit:500> _i_name=_git
11 compinit:500> _i_name=_getent
11 compinit:500> _i_name=_getconf
11 compinit:500> _i_name=_getclip
11 compinit:500> _i_name=_genisoimage
11 compinit:500> _i_name=_generic
11 compinit:500> _i_name=_gem
11 compinit:500> _i_name=_gas
11 compinit:500> _i_name=_fw_update
11 compinit:500> _i_name=_fusermount
11 compinit:500> _i_name=_fs_usage
11 compinit:500> _i_name=_fortune
11 compinit:500> _i_name=_force
11 compinit:500> _i_name=_fmt
11 compinit:500> _i_name=_flutter
11 compinit:500> _i_name=_flowadm
11 compinit:500> _i_name=_flex
11 compinit:500> _i_name=_fleetctl
11 compinit:500> _i_name=_files
11 compinit:500> _i_name=_fakeroot
11 compinit:500> _i_name=_fail2ban-client
11 compinit:500> _i_name=_fab
11 compinit:500> _i_name=_external_pwds
11 compinit:500> _i_name=_exportfs
11 compinit:500> _i_name=_enscript
11 compinit:500> _i_name=_emulator
11 compinit:500> _i_name=_ed
11 compinit:500> _i_name=_ecdsautil
11 compinit:500> _i_name=_dvc
11 compinit:500> _i_name=_drush
11 compinit:500> _i_name=_dns_types
11 compinit:500> _i_name=_django
11 compinit:500> _i_name=_deno
11 compinit:500> _i_name=_dad
11 compinit:500> _i_name=_cppcheck
11 compinit:500> _i_name=_cplay
11 compinit:500> _i_name=_cpio
11 compinit:500> _i_name=_cp
11 compinit:500> _i_name=_coreadm
11 compinit:500> _i_name=_concourse
11 compinit:500> _i_name=_composer
11 compinit:500> _i_name=_composer
11 compinit:500> _i_name=_complete_tag
11 compinit:500> _i_name=_coffee
11 compinit:500> _i_name=_chromium
11 compinit:500> _i_name=_ccache
11 compinit:500> _i_name=_cask
11 compinit:500> _i_name=_caffeinate
11 compinit:500> _i_name=_bzr
11 compinit:500> _i_name=_bundle
11 compinit:500> _i_name=_builtin
11 compinit:500> _i_name=_bts
11 compinit:500> _i_name=_bsd_disks
11 compinit:500> _i_name=_brew_services
11 compinit:500> _i_name=_brew
11 compinit:500> _i_name=_bogofilter
11 compinit:500> _i_name=_bitcoin-cli
11 compinit:500> _i_name=_bindkey
11 compinit:500> _i_name=_bind_addresses
11 compinit:500> _i_name=_bibtex
11 compinit:500> _i_name=_beadm
11 compinit:500> _i_name=_bash
11 compinit:500> _i_name=_base64
11 compinit:500> _i_name=_axi-cache
11 compinit:500> _i_name=_awk
11 compinit:500> _i_name=_avahi
11 compinit:500> _i_name=_auto-apt
11 compinit:500> _i_name=_augeas
11 compinit:500> _i_name=_attr
11 compinit:500> _i_name=_atach
11 compinit:500> _i_name=_asciinema
11 compinit:500> _i_name=_asciidoctor
11 compinit:500> _i_name=_arguments
11 compinit:500> _i_name=_approximate
11 compinit:500> _i_name=_apm
11 compinit:500> _i_name=_antiword
11 compinit:500> _i_name=_ant
11 compinit:500> _i_name=_alternative
11 compinit:500> _i_name=_alsa-utils
11 compinit:500> _i_name=_alias
11 compinit:500> _i_name=_abcde
11 compinit:500> _i_name=_a2ps
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zip
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zfs_pool
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zeal
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_yodl
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_yafc
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xset
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xscreensaver
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_resource
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_modifier
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_display
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_x_color
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_w
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vmstat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vmctl
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_visudo
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vim-addons
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vim
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_user_at_host
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_unexpand
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_uml
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_twidge
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_truss
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_trap
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_todo.sh
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_timeout
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tiff
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_texi
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tex
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_terminals
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_telnet
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tee
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sysstat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_swanctl
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sw_vers
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svcs
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_suffix_alias_files
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_subversion
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_strip
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_strings
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_strftime
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_strace
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_stat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ssh_hosts
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ssh
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_split
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_softwareupdate
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sockstat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_socket
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_smit
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_slabtop
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_shutdown
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_setup
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sequence
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_scutil
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_say
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_savecore
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_runit
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ruby
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_route
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rm
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_retrieve_cache
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_reprepro
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_regex_words
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_readshortcut
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rcctl
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pydoc
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pwgen
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ps1234
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_prove
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_prompt
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_postgresql
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pmap
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkgtool
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkg5
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkg-config
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ping
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pine
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_perl
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_path_commands
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_patch
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_parameter
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pack
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_otool
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_options
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nslookup
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_nothing
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_next_tags
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_my_accounts
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mondo
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_module_math_func
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mii-tool
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mdutil
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_matlab
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_luarocks
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lslv
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ls
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_locales
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ln
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lldb
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_links
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_lighttpd
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kvno
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_knock
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_kill
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jobs_bg
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_irssi
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ip
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iostat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_invoke-rc.d
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_inetadm
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_in_vared
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_imagemagick
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_iconv
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_host
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_history
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hexdump
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_have_glob_qual
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gpg
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_globflags
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ghostscript
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_getent
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gcc
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fortune
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_first
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_file_flags
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ffmpeg
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_django
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_diffstat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_dates
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cpio
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_correct
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_complete_debug
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_comm
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cmp
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cmdstring
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_cat
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bzr
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bsdinstall
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bsd_disks
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bpython
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bison
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_be_name
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_basename
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_auto-apt
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_attr
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_at
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arp
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arg_compile
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_alternative
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_abcde
11 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_a2ps
11 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_brew_services
11 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_brew
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
11 compinit:497> [[ /usr/local/share/zsh/site-functions = . ]]
11 compinit:497> [[ /Users/matt/.oh-my-zsh/plugins/zshfl = . ]]
11 compinit:497> [[ /Users/matt/.oh-my-zsh/completions = . ]]
11 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/plugins/zshfl
11 compinit:477> _i_done=''
11 compinit:442> _i_wdirs=( )
11 compinit:186> compprefuncs=( )
11 compinit:186> compprefuncs=( )
11 compinit:77> case -i (-d)
11 compdump:117> _i=5
11 compdump:117> _i=5
11 compdump:116> ((  ! --_i && 1080 > 1  ))
11 compdump:116> ((  ! --_i && 1075 > 1  ))
11 compdump:116> ((  ! --_i && 1060 > 1  ))
11 compdump:116> ((  ! --_i && 1055 > 1  ))
11 compdump:116> ((  ! --_i && 1045 > 1  ))
11 compdump:116> ((  ! --_i && 1040 > 1  ))
11 compdump:116> ((  ! --_i && 1030 > 1  ))
11 compdump:116> ((  ! --_i && 1020 > 1  ))
11 compdump:116> ((  ! --_i && 1015 > 1  ))
11 compdump:116> ((  ! --_i && 1005 > 1  ))
11 compdump:116> ((  ! --_i && 1000 > 1  ))
11 compdump:116> ((  ! --_i && 995 > 1  ))
11 compdump:116> ((  ! --_i && 990 > 1  ))
11 compdump:116> ((  ! --_i && 985 > 1  ))
11 compdump:116> ((  ! --_i && 974 > 1  ))
11 compdump:116> ((  ! --_i && 969 > 1  ))
11 compdump:116> ((  ! --_i && 964 > 1  ))
11 compdump:116> ((  ! --_i && 884 > 1  ))
11 compdump:116> ((  ! --_i && 859 > 1  ))
11 compdump:116> ((  ! --_i && 849 > 1  ))
11 compdump:116> ((  ! --_i && 844 > 1  ))
11 compdump:116> ((  ! --_i && 824 > 1  ))
11 compdump:116> ((  ! --_i && 814 > 1  ))
11 compdump:116> ((  ! --_i && 804 > 1  ))
11 compdump:116> ((  ! --_i && 799 > 1  ))
11 compdump:116> ((  ! --_i && 794 > 1  ))
11 compdump:116> ((  ! --_i && 779 > 1  ))
11 compdump:116> ((  ! --_i && 774 > 1  ))
11 compdump:116> ((  ! --_i && 769 > 1  ))
11 compdump:116> ((  ! --_i && 754 > 1  ))
11 compdump:116> ((  ! --_i && 749 > 1  ))
11 compdump:116> ((  ! --_i && 719 > 1  ))
11 compdump:116> ((  ! --_i && 629 > 1  ))
11 compdump:116> ((  ! --_i && 619 > 1  ))
11 compdump:116> ((  ! --_i && 614 > 1  ))
11 compdump:116> ((  ! --_i && 604 > 1  ))
11 compdump:116> ((  ! --_i && 579 > 1  ))
11 compdump:116> ((  ! --_i && 549 > 1  ))
11 compdump:116> ((  ! --_i && 544 > 1  ))
11 compdump:116> ((  ! --_i && 519 > 1  ))
11 compdump:116> ((  ! --_i && 514 > 1  ))
11 compdump:116> ((  ! --_i && 279 > 1  ))
11 compdump:116> ((  ! --_i && 274 > 1  ))
11 compdump:116> ((  ! --_i && 219 > 1  ))
11 compdump:116> ((  ! --_i && 194 > 1  ))
11 compdump:116> ((  ! --_i && 169 > 1  ))
11 compdump:116> ((  ! --_i && 14 > 1  ))
11 compdump:113> ((  1088  ))
11 compdump:113> ((  1087  ))
11 compdump:113> ((  1086  ))
11 compdump:113> ((  1084  ))
11 compdump:113> ((  1083  ))
11 compdump:113> ((  1082  ))
11 compdump:113> ((  1081  ))
11 compdump:113> ((  1079  ))
11 compdump:113> ((  1074  ))
11 compdump:113> ((  1073  ))
11 compdump:113> ((  1072  ))
11 compdump:113> ((  1070  ))
11 compdump:113> ((  1069  ))
11 compdump:113> ((  1068  ))
11 compdump:113> ((  1067  ))
11 compdump:113> ((  1066  ))
11 compdump:113> ((  1065  ))
11 compdump:113> ((  1064  ))
11 compdump:113> ((  1063  ))
11 compdump:113> ((  1062  ))
11 compdump:113> ((  1059  ))
11 compdump:113> ((  1057  ))
11 compdump:113> ((  1056  ))
11 compdump:113> ((  1055  ))
11 compdump:113> ((  1054  ))
11 compdump:113> ((  1052  ))
11 compdump:113> ((  1048  ))
11 compdump:113> ((  1047  ))
11 compdump:113> ((  1046  ))
11 compdump:113> ((  1041  ))
11 compdump:113> ((  1040  ))
11 compdump:113> ((  1039  ))
11 compdump:113> ((  1038  ))
11 compdump:113> ((  1035  ))
11 compdump:113> ((  1034  ))
11 compdump:113> ((  1033  ))
11 compdump:113> ((  1032  ))
11 compdump:113> ((  1031  ))
11 compdump:113> ((  1028  ))
11 compdump:113> ((  1026  ))
11 compdump:113> ((  1023  ))
11 compdump:113> ((  1022  ))
11 compdump:113> ((  1021  ))
11 compdump:113> ((  1019  ))
11 compdump:113> ((  1018  ))
11 compdump:113> ((  1016  ))
11 compdump:113> ((  1013  ))
11 compdump:113> ((  1011  ))
11 compdump:113> ((  1008  ))
11 compdump:113> ((  1005  ))
11 compdump:113> ((  1003  ))
11 compdump:113> ((  1002  ))
11 compdump:113> ((  1001  ))
11 compdump:113> ((  999  ))
11 compdump:113> ((  997  ))
11 compdump:113> ((  996  ))
11 compdump:113> ((  995  ))
11 compdump:113> ((  993  ))
11 compdump:113> ((  992  ))
11 compdump:113> ((  989  ))
11 compdump:113> ((  987  ))
11 compdump:113> ((  986  ))
11 compdump:113> ((  982  ))
11 compdump:113> ((  979  ))
11 compdump:113> ((  978  ))
11 compdump:113> ((  977  ))
11 compdump:113> ((  976  ))
11 compdump:113> ((  975  ))
11 compdump:113> ((  974  ))
11 compdump:113> ((  973  ))
11 compdump:113> ((  971  ))
11 compdump:113> ((  970  ))
11 compdump:113> ((  969  ))
11 compdump:113> ((  968  ))
11 compdump:113> ((  967  ))
11 compdump:113> ((  964  ))
11 compdump:113> ((  961  ))
11 compdump:113> ((  958  ))
11 compdump:113> ((  957  ))
11 compdump:113> ((  954  ))
11 compdump:113> ((  953  ))
11 compdump:113> ((  951  ))
11 compdump:113> ((  950  ))
11 compdump:113> ((  949  ))
11 compdump:113> ((  946  ))
11 compdump:113> ((  945  ))
11 compdump:113> ((  943  ))
11 compdump:113> ((  941  ))
11 compdump:113> ((  939  ))
11 compdump:113> ((  938  ))
11 compdump:113> ((  936  ))
11 compdump:113> ((  932  ))
11 compdump:113> ((  931  ))
11 compdump:113> ((  930  ))
11 compdump:113> ((  929  ))
11 compdump:113> ((  926  ))
11 compdump:113> ((  925  ))
11 compdump:113> ((  924  ))
11 compdump:113> ((  919  ))
11 compdump:113> ((  916  ))
11 compdump:113> ((  911  ))
11 compdump:113> ((  910  ))
11 compdump:113> ((  909  ))
11 compdump:113> ((  908  ))
11 compdump:113> ((  906  ))
11 compdump:113> ((  905  ))
11 compdump:113> ((  904  ))
11 compdump:113> ((  903  ))
11 compdump:113> ((  902  ))
11 compdump:113> ((  901  ))
11 compdump:113> ((  900  ))
11 compdump:113> ((  894  ))
11 compdump:113> ((  891  ))
11 compdump:113> ((  889  ))
11 compdump:113> ((  888  ))
11 compdump:113> ((  886  ))
11 compdump:113> ((  885  ))
11 compdump:113> ((  882  ))
11 compdump:113> ((  880  ))
11 compdump:113> ((  879  ))
11 compdump:113> ((  874  ))
11 compdump:113> ((  872  ))
11 compdump:113> ((  866  ))
11 compdump:113> ((  861  ))
11 compdump:113> ((  859  ))
11 compdump:113> ((  858  ))
11 compdump:113> ((  857  ))
11 compdump:113> ((  852  ))
11 compdump:113> ((  850  ))
11 compdump:113> ((  848  ))
11 compdump:113> ((  847  ))
11 compdump:113> ((  845  ))
11 compdump:113> ((  844  ))
11 compdump:113> ((  843  ))
11 compdump:113> ((  842  ))
11 compdump:113> ((  839  ))
11 compdump:113> ((  835  ))
11 compdump:113> ((  834  ))
11 compdump:113> ((  833  ))
11 compdump:113> ((  832  ))
11 compdump:113> ((  830  ))
11 compdump:113> ((  829  ))
11 compdump:113> ((  828  ))
11 compdump:113> ((  827  ))
11 compdump:113> ((  823  ))
11 compdump:113> ((  822  ))
11 compdump:113> ((  821  ))
11 compdump:113> ((  819  ))
11 compdump:113> ((  817  ))
11 compdump:113> ((  815  ))
11 compdump:113> ((  813  ))
11 compdump:113> ((  812  ))
11 compdump:113> ((  811  ))
11 compdump:113> ((  809  ))
11 compdump:113> ((  808  ))
11 compdump:113> ((  807  ))
11 compdump:113> ((  805  ))
11 compdump:113> ((  804  ))
11 compdump:113> ((  803  ))
11 compdump:113> ((  802  ))
11 compdump:113> ((  801  ))
11 compdump:113> ((  798  ))
11 compdump:113> ((  795  ))
11 compdump:113> ((  793  ))
11 compdump:113> ((  792  ))
11 compdump:113> ((  790  ))
11 compdump:113> ((  788  ))
11 compdump:113> ((  787  ))
11 compdump:113> ((  786  ))
11 compdump:113> ((  780  ))
11 compdump:113> ((  779  ))
11 compdump:113> ((  778  ))
11 compdump:113> ((  777  ))
11 compdump:113> ((  776  ))
11 compdump:113> ((  775  ))
11 compdump:113> ((  774  ))
11 compdump:113> ((  772  ))
11 compdump:113> ((  771  ))
11 compdump:113> ((  770  ))
11 compdump:113> ((  768  ))
11 compdump:113> ((  767  ))
11 compdump:113> ((  766  ))
11 compdump:113> ((  765  ))
11 compdump:113> ((  759  ))
11 compdump:113> ((  756  ))
11 compdump:113> ((  755  ))
11 compdump:113> ((  754  ))
11 compdump:113> ((  753  ))
11 compdump:113> ((  752  ))
11 compdump:113> ((  749  ))
11 compdump:113> ((  748  ))
11 compdump:113> ((  747  ))
11 compdump:113> ((  746  ))
11 compdump:113> ((  745  ))
11 compdump:113> ((  744  ))
11 compdump:113> ((  741  ))
11 compdump:113> ((  739  ))
11 compdump:113> ((  738  ))
11 compdump:113> ((  737  ))
11 compdump:113> ((  736  ))
11 compdump:113> ((  735  ))
11 compdump:113> ((  733  ))
11 compdump:113> ((  732  ))
11 compdump:113> ((  731  ))
11 compdump:113> ((  730  ))
11 compdump:113> ((  729  ))
11 compdump:113> ((  725  ))
11 compdump:113> ((  723  ))
11 compdump:113> ((  722  ))
11 compdump:113> ((  719  ))
11 compdump:113> ((  718  ))
11 compdump:113> ((  717  ))
11 compdump:113> ((  714  ))
11 compdump:113> ((  713  ))
11 compdump:113> ((  707  ))
11 compdump:113> ((  706  ))
11 compdump:113> ((  705  ))
11 compdump:113> ((  704  ))
11 compdump:113> ((  702  ))
11 compdump:113> ((  700  ))
11 compdump:113> ((  699  ))
11 compdump:113> ((  696  ))
11 compdump:113> ((  695  ))
11 compdump:113> ((  694  ))
11 compdump:113> ((  693  ))
11 compdump:113> ((  691  ))
11 compdump:113> ((  687  ))
11 compdump:113> ((  685  ))
11 compdump:113> ((  684  ))
11 compdump:113> ((  683  ))
11 compdump:113> ((  681  ))
11 compdump:113> ((  680  ))
11 compdump:113> ((  678  ))
11 compdump:113> ((  677  ))
11 compdump:113> ((  676  ))
11 compdump:113> ((  672  ))
11 compdump:113> ((  671  ))
11 compdump:113> ((  669  ))
11 compdump:113> ((  668  ))
11 compdump:113> ((  659  ))
11 compdump:113> ((  658  ))
11 compdump:113> ((  656  ))
11 compdump:113> ((  655  ))
11 compdump:113> ((  654  ))
11 compdump:113> ((  653  ))
11 compdump:113> ((  650  ))
11 compdump:113> ((  649  ))
11 compdump:113> ((  648  ))
11 compdump:113> ((  647  ))
11 compdump:113> ((  643  ))
11 compdump:113> ((  641  ))
11 compdump:113> ((  640  ))
11 compdump:113> ((  638  ))
11 compdump:113> ((  636  ))
11 compdump:113> ((  634  ))
11 compdump:113> ((  633  ))
11 compdump:113> ((  631  ))
11 compdump:113> ((  629  ))
11 compdump:113> ((  625  ))
11 compdump:113> ((  624  ))
11 compdump:113> ((  622  ))
11 compdump:113> ((  617  ))
11 compdump:113> ((  607  ))
11 compdump:113> ((  603  ))
11 compdump:113> ((  602  ))
11 compdump:113> ((  597  ))
11 compdump:113> ((  596  ))
11 compdump:113> ((  595  ))
11 compdump:113> ((  592  ))
11 compdump:113> ((  591  ))
11 compdump:113> ((  590  ))
11 compdump:113> ((  588  ))
11 compdump:113> ((  587  ))
11 compdump:113> ((  586  ))
11 compdump:113> ((  584  ))
11 compdump:113> ((  583  ))
11 compdump:113> ((  582  ))
11 compdump:113> ((  581  ))
11 compdump:113> ((  580  ))
11 compdump:113> ((  578  ))
11 compdump:113> ((  575  ))
11 compdump:113> ((  574  ))
11 compdump:113> ((  573  ))
11 compdump:113> ((  571  ))
11 compdump:113> ((  566  ))
11 compdump:113> ((  559  ))
11 compdump:113> ((  558  ))
11 compdump:113> ((  553  ))
11 compdump:113> ((  552  ))
11 compdump:113> ((  551  ))
11 compdump:113> ((  550  ))
11 compdump:113> ((  548  ))
11 compdump:113> ((  547  ))
11 compdump:113> ((  546  ))
11 compdump:113> ((  545  ))
11 compdump:113> ((  541  ))
11 compdump:113> ((  540  ))
11 compdump:113> ((  537  ))
11 compdump:113> ((  536  ))
11 compdump:113> ((  533  ))
11 compdump:113> ((  532  ))
11 compdump:113> ((  531  ))
11 compdump:113> ((  527  ))
11 compdump:113> ((  523  ))
11 compdump:113> ((  521  ))
11 compdump:113> ((  519  ))
11 compdump:113> ((  518  ))
11 compdump:113> ((  515  ))
11 compdump:113> ((  514  ))
11 compdump:113> ((  513  ))
11 compdump:113> ((  512  ))
11 compdump:113> ((  511  ))
11 compdump:113> ((  510  ))
11 compdump:113> ((  507  ))
11 compdump:113> ((  506  ))
11 compdump:113> ((  503  ))
11 compdump:113> ((  501  ))
11 compdump:113> ((  499  ))
11 compdump:113> ((  498  ))
11 compdump:113> ((  492  ))
11 compdump:113> ((  491  ))
11 compdump:113> ((  489  ))
11 compdump:113> ((  486  ))
11 compdump:113> ((  485  ))
11 compdump:113> ((  484  ))
11 compdump:113> ((  483  ))
11 compdump:113> ((  478  ))
11 compdump:113> ((  475  ))
11 compdump:113> ((  471  ))
11 compdump:113> ((  467  ))
11 compdump:113> ((  466  ))
11 compdump:113> ((  463  ))
11 compdump:113> ((  462  ))
11 compdump:113> ((  460  ))
11 compdump:113> ((  459  ))
11 compdump:113> ((  457  ))
11 compdump:113> ((  456  ))
11 compdump:113> ((  455  ))
11 compdump:113> ((  451  ))
11 compdump:113> ((  448  ))
11 compdump:113> ((  445  ))
11 compdump:113> ((  443  ))
11 compdump:113> ((  442  ))
11 compdump:113> ((  439  ))
11 compdump:113> ((  438  ))
11 compdump:113> ((  437  ))
11 compdump:113> ((  432  ))
11 compdump:113> ((  429  ))
11 compdump:113> ((  426  ))
11 compdump:113> ((  425  ))
11 compdump:113> ((  423  ))
11 compdump:113> ((  421  ))
11 compdump:113> ((  419  ))
11 compdump:113> ((  417  ))
11 compdump:113> ((  414  ))
11 compdump:113> ((  411  ))
11 compdump:113> ((  409  ))
11 compdump:113> ((  408  ))
11 compdump:113> ((  396  ))
11 compdump:113> ((  386  ))
11 compdump:113> ((  384  ))
11 compdump:113> ((  376  ))
11 compdump:113> ((  373  ))
11 compdump:113> ((  372  ))
11 compdump:113> ((  363  ))
11 compdump:113> ((  362  ))
11 compdump:113> ((  360  ))
11 compdump:113> ((  358  ))
11 compdump:113> ((  355  ))
11 compdump:113> ((  354  ))
11 compdump:113> ((  348  ))
11 compdump:113> ((  346  ))
11 compdump:113> ((  343  ))
11 compdump:113> ((  339  ))
11 compdump:113> ((  334  ))
11 compdump:113> ((  331  ))
11 compdump:113> ((  328  ))
11 compdump:113> ((  325  ))
11 compdump:113> ((  324  ))
11 compdump:113> ((  321  ))
11 compdump:113> ((  318  ))
11 compdump:113> ((  311  ))
11 compdump:113> ((  304  ))
11 compdump:113> ((  289  ))
11 compdump:113> ((  288  ))
11 compdump:113> ((  286  ))
11 compdump:113> ((  285  ))
11 compdump:113> ((  284  ))
11 compdump:113> ((  283  ))
11 compdump:113> ((  278  ))
11 compdump:113> ((  275  ))
11 compdump:113> ((  274  ))
11 compdump:113> ((  273  ))
11 compdump:113> ((  271  ))
11 compdump:113> ((  267  ))
11 compdump:113> ((  265  ))
11 compdump:113> ((  264  ))
11 compdump:113> ((  263  ))
11 compdump:113> ((  256  ))
11 compdump:113> ((  255  ))
11 compdump:113> ((  253  ))
11 compdump:113> ((  246  ))
11 compdump:113> ((  245  ))
11 compdump:113> ((  241  ))
11 compdump:113> ((  240  ))
11 compdump:113> ((  237  ))
11 compdump:113> ((  234  ))
11 compdump:113> ((  228  ))
11 compdump:113> ((  224  ))
11 compdump:113> ((  223  ))
11 compdump:113> ((  222  ))
11 compdump:113> ((  221  ))
11 compdump:113> ((  219  ))
11 compdump:113> ((  213  ))
11 compdump:113> ((  209  ))
11 compdump:113> ((  206  ))
11 compdump:113> ((  204  ))
11 compdump:113> ((  203  ))
11 compdump:113> ((  202  ))
11 compdump:113> ((  199  ))
11 compdump:113> ((  198  ))
11 compdump:113> ((  188  ))
11 compdump:113> ((  187  ))
11 compdump:113> ((  181  ))
11 compdump:113> ((  173  ))
11 compdump:113> ((  172  ))
11 compdump:113> ((  156  ))
11 compdump:113> ((  149  ))
11 compdump:113> ((  126  ))
11 compdump:113> ((  125  ))
11 compdump:113> ((  112  ))
11 compdump:113> ((  99  ))
11 compdump:113> ((  90  ))
11 compdump:113> ((  74  ))
11 compdump:113> ((  63  ))
11 compdump:113> ((  62  ))
11 compdump:113> ((  24  ))
11 compdump:113> ((  23  ))
11 compdump:113> ((  13  ))
11 compdump:113> ((  5  ))
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:169> shift
11 compdef:164> [[ -n yes ]]
11 compdef:164> [[ -n yes ]]
11 compdef:164> [[ -n yes ]]
11 compdef:163> _comps[$cmd]=_xz
11 compdef:163> _comps[$cmd]=_xz
11 compdef:163> _comps[$cmd]=_xz
11 compdef:163> _comps[$cmd]=_xz
11 compdef:163> _comps[$cmd]=_tex
11 compdef:163> _comps[$cmd]=_nedit
11 compdef:163> _comps[$cmd]=_gnupod
11 compdef:163> _comps[$cmd]=_git
11 compdef:163> _comps[$cmd]=_compress
11 compdef:163> _comps[$cmd]=_chown
11 compdef:163> _comps[$cmd]=_bzip2
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:162> [[ -z yes || -z '' ]]
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:160> svc=''
11 compdef:159> cmd=zsocket
11 compdef:159> cmd=zsh
11 compdef:159> cmd=zparseopts
11 compdef:159> cmd=zoneadm
11 compdef:159> cmd=zmail
11 compdef:159> cmd=zlogin
11 compdef:159> cmd=zcompile
11 compdef:159> cmd=zcash-cli
11 compdef:159> cmd=yarn
11 compdef:159> cmd=yaourt
11 compdef:159> cmd=xxd
11 compdef:159> cmd=xwud
11 compdef:159> cmd=xwininfo
11 compdef:159> cmd=xsltproc
11 compdef:159> cmd=xprop
11 compdef:159> cmd=xmodmap
11 compdef:159> cmd=xmlstarlet
11 compdef:159> cmd=xmllint
11 compdef:159> cmd=xlsclients
11 compdef:159> cmd=xlsatoms
11 compdef:159> cmd=xloadimage
11 compdef:159> cmd=xli
11 compdef:159> cmd=xkill
11 compdef:159> cmd=xfreerdp
11 compdef:159> cmd=xfig
11 compdef:159> cmd=xclip
11 compdef:159> cmd=xauth
11 compdef:159> cmd=wg-quick
11 compdef:159> cmd=wemux
11 compdef:159> cmd=vnstat
11 compdef:159> cmd=unix2mac
11 compdef:159> cmd=unix2dos
11 compdef:159> cmd=tryaffix
11 compdef:159> cmd=trash
11 compdef:159> cmd=teamocil
11 compdef:159> cmd=tda
11 compdef:159> cmd=tcpdump
11 compdef:159> cmd=tardy
11 compdef:159> cmd=svm
11 compdef:159> cmd=subl
11 compdef:159> cmd=strip
11 compdef:159> cmd=stdbuf
11 compdef:159> cmd=stack
11 compdef:159> cmd=srm
11 compdef:159> cmd=softwareupdate
11 compdef:159> cmd=skein1024
11 compdef:159> cmd=skein512
11 compdef:159> cmd=showoff
11 compdef:159> cmd=sha512sum
11 compdef:159> cmd=sha512
11 compdef:159> cmd=sha384sum
11 compdef:159> cmd=sha256sum
11 compdef:159> cmd=sha224sum
11 compdef:159> cmd=sfdx
11 compdef:159> cmd=setcap
11 compdef:159> cmd=scrub
11 compdef:159> cmd=scala
11 compdef:159> cmd=sbt
11 compdef:159> cmd=sadf
11 compdef:159> cmd=rxvt
11 compdef:159> cmd=rslsync
11 compdef:159> cmd=rmiregistry
11 compdef:159> cmd=rmd160
11 compdef:159> cmd=rkt
11 compdef:159> cmd=rehash
11 compdef:159> cmd=readshortcut.exe
11 compdef:159> cmd=read
11 compdef:159> cmd=rails
11 compdef:159> cmd=pushd
11 compdef:159> cmd=psql
11 compdef:159> cmd=postqueue
11 compdef:159> cmd=port
11 compdef:159> cmd=popd
11 compdef:159> cmd=pmcat
11 compdef:159> cmd=pipenv
11 compdef:159> cmd=pidstat
11 compdef:159> cmd=phing
11 compdef:159> cmd=pg_dumpall
11 compdef:159> cmd=perf
11 compdef:159> cmd=pdf2dsc
11 compdef:159> cmd=patool
11 compdef:159> cmd=optirun
11 compdef:159> cmd=opkg
11 compdef:159> cmd=openssl
11 compdef:159> cmd=omz
11 compdef:159> cmd=nvm
11 compdef:159> cmd=nmcli
11 compdef:159> cmd=nkf
11 compdef:159> cmd=ninja
11 compdef:159> cmd=nice
11 compdef:159> cmd=networksetup
11 compdef:159> cmd=netscape
11 compdef:159> cmd=mvnDebug
11 compdef:159> cmd=mussh
11 compdef:159> cmd=mush
11 compdef:159> cmd=mtn
11 compdef:159> cmd=moosic
11 compdef:159> cmd=module
11 compdef:159> cmd=modinfo
11 compdef:159> cmd=middleman
11 compdef:159> cmd=md2
11 compdef:159> cmd=matlab
11 compdef:159> cmd=manage.py
11 compdef:159> cmd=make-kpkg
11 compdef:159> cmd=mail
11 compdef:159> cmd=mac2unix
11 compdef:159> cmd=lsattr
11 compdef:159> cmd=lpr
11 compdef:159> cmd=ln
11 compdef:159> cmd=lighty-disable-mod
11 compdef:159> cmd=ldconfig
11 compdef:159> cmd=kvno
11 compdef:159> cmd=kubectl
11 compdef:159> cmd=keystone
11 compdef:159> cmd=jls
11 compdef:159> cmd=ipsec
11 compdef:159> cmd=ip6tables-save
11 compdef:159> cmd=initctl
11 compdef:159> cmd=ifconfig
11 compdef:159> cmd=hub
11 compdef:159> cmd=heroku
11 compdef:159> cmd=hash
11 compdef:159> cmd=gzip
11 compdef:159> cmd=gv
11 compdef:159> cmd=guilt-status
11 compdef:159> cmd=guilt-series
11 compdef:159> cmd=guilt-rm
11 compdef:159> cmd=guilt-refresh
11 compdef:159> cmd=guilt-rebase
11 compdef:159> cmd=guilt-pop
11 compdef:159> cmd=guilt-patchbomb
11 compdef:159> cmd=guilt-next
11 compdef:159> cmd=guilt-init
11 compdef:159> cmd=guilt-import-commit
11 compdef:159> cmd=guilt-import
11 compdef:159> cmd=guilt-help
11 compdef:159> cmd=guilt-header
11 compdef:159> cmd=guilt-fork
11 compdef:159> cmd=guilt-files
11 compdef:159> cmd=guilt
11 compdef:159> cmd=gsha384sum
11 compdef:159> cmd=gsha256sum
11 compdef:159> cmd=gsha224sum
11 compdef:159> cmd=gsha1sum
11 compdef:159> cmd=git
11 compdef:159> cmd=gist
11 compdef:159> cmd=ghc-pkg
11 compdef:159> cmd=ghc
11 compdef:159> cmd=getopts
11 compdef:159> cmd=getmail
11 compdef:159> cmd=genisoimage
11 compdef:159> cmd=gdu
11 compdef:159> cmd=gdf
11 compdef:159> cmd=gdd
11 compdef:159> cmd=gcut
11 compdef:159> cmd=gcmp
11 compdef:159> cmd=fstat
11 compdef:159> cmd=fs_usage
11 compdef:159> cmd=fned
11 compdef:159> cmd=ffmpeg
11 compdef:159> cmd=fc-match
11 compdef:159> cmd=eu-strings
11 compdef:159> cmd=etags
11 compdef:159> cmd=espeak
11 compdef:159> cmd=eog
11 compdef:159> cmd=env
11 compdef:159> cmd=enable
11 compdef:159> cmd=emulate
11 compdef:159> cmd=elinks
11 compdef:159> cmd=elfdump
11 compdef:159> cmd=ed
11 compdef:159> cmd=ecasound
11 compdef:159> cmd=e2label
11 compdef:159> cmd=dvitodvi
11 compdef:159> cmd=dvipdf
11 compdef:159> cmd=dvidvi
11 compdef:159> cmd=dupload
11 compdef:159> cmd=du
11 compdef:159> cmd=dtruss
11 compdef:159> cmd=dpkg-repack
11 compdef:159> cmd=dpkg-reconfigure
11 compdef:159> cmd=dpkg-deb
11 compdef:159> cmd=dpkg-cross
11 compdef:159> cmd=dos2unix
11 compdef:159> cmd=docker-compose
11 compdef:159> cmd=doas
11 compdef:159> cmd=dnf-2
11 compdef:159> cmd=dnf
11 compdef:159> cmd=dmidecode
11 compdef:159> cmd=dmesg
11 compdef:159> cmd=dladm
11 compdef:159> cmd=django-admin.py
11 compdef:159> cmd=django-admin
11 compdef:159> cmd=disable
11 compdef:159> cmd=dirs
11 compdef:159> cmd=dircmp
11 compdef:159> cmd=dig
11 compdef:159> cmd=diffstat
11 compdef:159> cmd=diff3
11 compdef:159> cmd=dhclient3
11 compdef:159> cmd=dhclient
11 compdef:159> cmd=df
11 compdef:159> cmd=designate
11 compdef:159> cmd=dcopobject
11 compdef:159> cmd=dcopfind
11 compdef:159> cmd=dcopclient
11 compdef:159> cmd=dcop
11 compdef:159> cmd=dchroot
11 compdef:159> cmd=dbus-send
11 compdef:159> cmd=dbus-monitor
11 compdef:159> cmd=date
11 compdef:159> cmd=darcs
11 compdef:159> cmd=dak
11 compdef:159> cmd=d
11 compdef:159> cmd=cygstart.exe
11 compdef:159> cmd=cygserver
11 compdef:159> cmd=cygrunsrv
11 compdef:159> cmd=cygpath.exe
11 compdef:159> cmd=cygcheck
11 compdef:159> cmd=cvsup
11 compdef:159> cmd=cut
11 compdef:159> cmd=cu
11 compdef:159> cmd=cssh
11 compdef:159> cmd=cscope
11 compdef:159> cmd=cryptsetup
11 compdef:159> cmd=crsh
11 compdef:159> cmd=createuser
11 compdef:159> cmd=config.status
11 compdef:159> cmd=command
11 compdef:159> cmd=comm
11 compdef:159> cmd=column
11 compdef:159> cmd=code
11 compdef:159> cmd=cmp
11 compdef:159> cmd=cloudkitty
11 compdef:159> cmd=clay
11 compdef:159> cmd=cinder
11 compdef:159> cmd=chroot
11 compdef:159> cmd=ceilometer
11 compdef:159> cmd=cd
11 compdef:159> cmd=ccal
11 compdef:159> cmd=cat
11 compdef:159> cmd=calendar
11 compdef:159> cmd=bpython3-urwid
11 compdef:159> cmd=bogotune
11 compdef:159> cmd=bmake
11 compdef:159> cmd=baz
11 compdef:159> cmd=bash
11 compdef:159> cmd=barbican
11 compdef:159> cmd=b2sum
11 compdef:159> cmd=avahi-browse-domains
11 compdef:159> cmd=atrm
11 compdef:159> cmd=arp
11 compdef:159> cmd=ansible-inventory
11 compdef:159> cmd=ansible-config
11 compdef:159> cmd=alias
11 compdef:159> cmd=afew
11 compdef:159> cmd=add-zle-hook-widget
11 compdef:159> cmd=a2enmod
11 compdef:159> cmd=_helm
11 compdef:159> cmd=-value-,XZ_OPT,-default-
11 compdef:159> cmd=-value-,XZ_DEFAULTS,-default-
11 compdef:159> cmd=-value-,RPS1,-default-
11 compdef:159> cmd=-value-,PROMPT4,-default-
11 compdef:159> cmd=-value-,PROMPT2,-default-
11 compdef:159> cmd=-value-,PRINTER,-default-
11 compdef:159> cmd=-value-,PERLDOC,-default-
11 compdef:159> cmd=-value-,P4USER,-default-
11 compdef:159> cmd=-value-,P4CLIENT,-default-
11 compdef:159> cmd=-value-,MPD_HOST,-default
11 compdef:159> cmd=-value-,LOOPDEV_DEBUG,-default-
11 compdef:159> cmd=-value-,LESSCHARSET,-default-
11 compdef:159> cmd=-value-,LD_DEBUG,-default-
11 compdef:159> cmd=-value-,CPPFLAGS,-default-
11 compdef:159> cmd=-value-,CFLAGS,-default-
11 compdef:159> cmd=-value-,ANDROID_SERIAL,-default-
11 compdef:159> cmd=-value-,-default-,-command-
11 compdef:159> cmd=-equal-
11 compdef:159> cmd=-command-line-
11 compdef:159> cmd=-command-
11 compdef:159> cmd=-brace-parameter-
11 compdef:157> svc=yes
11 compdef:156> cmd=unlzma
11 compdef:156> cmd=ncl
11 compdef:156> cmd=lzma
11 compdef:156> cmd=lzcat
11 compdef:156> cmd=Mail
11 compdef:155> [[ zsetattr = *=* ]]
11 compdef:155> [[ zipinfo = *=* ]]
11 compdef:155> [[ zcp = *=* ]]
11 compdef:155> [[ ypwhich = *=* ]]
11 compdef:155> [[ ypmatch = *=* ]]
11 compdef:155> [[ xwud = *=* ]]
11 compdef:155> [[ xprop = *=* ]]
11 compdef:155> [[ xon = *=* ]]
11 compdef:155> [[ xml = *=* ]]
11 compdef:155> [[ xkill = *=* ]]
11 compdef:155> [[ xhost = *=* ]]
11 compdef:155> [[ xfreerdp = *=* ]]
11 compdef:155> [[ xfontsel = *=* ]]
11 compdef:155> [[ whois = *=* ]]
11 compdef:155> [[ whoami = *=* ]]
11 compdef:155> [[ where = *=* ]]
11 compdef:155> [[ vpnc-connect = *=* ]]
11 compdef:155> [[ vmstat = *=* ]]
11 compdef:155> [[ virt-xml-validate = *=* ]]
11 compdef:155> [[ virt-host-validate = *=* ]]
11 compdef:155> [[ vcsh = *=* ]]
11 compdef:155> [[ urxvt256c = *=* ]]
11 compdef:155> [[ urpmi.update = *=* ]]
11 compdef:155> [[ urpmi.removemedia = *=* ]]
11 compdef:155> [[ urpmi.addmedia = *=* ]]
11 compdef:155> [[ unpigz = *=* ]]
11 compdef:155> [[ unix2mac = *=* ]]
11 compdef:155> [[ uml_mconsole = *=* ]]
11 compdef:155> [[ trove = *=* ]]
11 compdef:155> [[ trap = *=* ]]
11 compdef:155> [[ tr = *=* ]]
11 compdef:155> [[ tac = *=* ]]
11 compdef:155> [[ sync = *=* ]]
11 compdef:155> [[ start = *=* ]]
11 compdef:155> [[ ssh-add = *=* ]]
11 compdef:155> [[ ss = *=* ]]
11 compdef:155> [[ split = *=* ]]
11 compdef:155> [[ smbstatus = *=* ]]
11 compdef:155> [[ smbclient = *=* ]]
11 compdef:155> [[ skein1024 = *=* ]]
11 compdef:155> [[ skein512 = *=* ]]
11 compdef:155> [[ sha512 = *=* ]]
11 compdef:155> [[ sha256sum = *=* ]]
11 compdef:155> [[ sha256 = *=* ]]
11 compdef:155> [[ sha1 = *=* ]]
11 compdef:155> [[ setopt = *=* ]]
11 compdef:155> [[ serialver = *=* ]]
11 compdef:155> [[ scriptreplay = *=* ]]
11 compdef:155> [[ savecore = *=* ]]
11 compdef:155> [[ rubber-pipe = *=* ]]
11 compdef:155> [[ restart = *=* ]]
11 compdef:155> [[ qdbus = *=* ]]
11 compdef:155> [[ pushd = *=* ]]
11 compdef:155> [[ pscp = *=* ]]
11 compdef:155> [[ printf = *=* ]]
11 compdef:155> [[ policytool = *=* ]]
11 compdef:155> [[ podgrep = *=* ]]
11 compdef:155> [[ pmeth = *=* ]]
11 compdef:155> [[ pkgin = *=* ]]
11 compdef:155> [[ pkg = *=* ]]
11 compdef:155> [[ pinfo = *=* ]]
11 compdef:155> [[ pigz = *=* ]]
11 compdef:155> [[ pdftotext = *=* ]]
11 compdef:155> [[ pdftops = *=* ]]
11 compdef:155> [[ pdfimages = *=* ]]
11 compdef:155> [[ pax = *=* ]]
11 compdef:155> [[ otool = *=* ]]
11 compdef:155> [[ nova = *=* ]]
11 compdef:155> [[ nmblookup = *=* ]]
11 compdef:155> [[ mozilla-firefox = *=* ]]
11 compdef:155> [[ mksh = *=* ]]
11 compdef:155> [[ md5 = *=* ]]
11 compdef:155> [[ md4 = *=* ]]
11 compdef:155> [[ lpoptions = *=* ]]
11 compdef:155> [[ lldb = *=* ]]
11 compdef:155> [[ lintian-info = *=* ]]
11 compdef:155> [[ lha = *=* ]]
11 compdef:155> [[ ksh93 = *=* ]]
11 compdef:155> [[ kpdf = *=* ]]
11 compdef:155> [[ kioclient = *=* ]]
11 compdef:155> [[ keytool = *=* ]]
11 compdef:155> [[ ironic = *=* ]]
11 compdef:155> [[ iptables-save = *=* ]]
11 compdef:155> [[ initdb = *=* ]]
11 compdef:155> [[ hotjava = *=* ]]
11 compdef:155> [[ head = *=* ]]
11 compdef:155> [[ gwc = *=* ]]
11 compdef:155> [[ gunexpand = *=* ]]
11 compdef:155> [[ guilt-top = *=* ]]
11 compdef:155> [[ guilt-refresh = *=* ]]
11 compdef:155> [[ guilt-pop = *=* ]]
11 compdef:155> [[ guilt-import = *=* ]]
11 compdef:155> [[ guilt-help = *=* ]]
11 compdef:155> [[ gstrings = *=* ]]
11 compdef:155> [[ gstdbuf = *=* ]]
11 compdef:155> [[ gsnd = *=* ]]
11 compdef:155> [[ gsha384sum = *=* ]]
11 compdef:155> [[ gnutls-cli-debug = *=* ]]
11 compdef:155> [[ gnupod_INIT = *=* ]]
11 compdef:155> [[ gls = *=* ]]
11 compdef:155> [[ glance = *=* ]]
11 compdef:155> [[ ghci = *=* ]]
11 compdef:155> [[ ghc-pkg = *=* ]]
11 compdef:155> [[ getfattr = *=* ]]
11 compdef:155> [[ getfacl.exe = *=* ]]
11 compdef:155> [[ geany = *=* ]]
11 compdef:155> [[ gdu = *=* ]]
11 compdef:155> [[ gdb = *=* ]]
11 compdef:155> [[ gcut = *=* ]]
11 compdef:155> [[ gcat = *=* ]]
11 compdef:155> [[ functions = *=* ]]
11 compdef:155> [[ fold = *=* ]]
11 compdef:155> [[ fixscribeps = *=* ]]
11 compdef:155> [[ firefox = *=* ]]
11 compdef:155> [[ fc-match = *=* ]]
11 compdef:155> [[ extractres = *=* ]]
11 compdef:155> [[ expand = *=* ]]
11 compdef:155> [[ eu-readelf = *=* ]]
11 compdef:155> [[ dvitodvi = *=* ]]
11 compdef:155> [[ dropdb = *=* ]]
11 compdef:155> [[ dockerd = *=* ]]
11 compdef:155> [[ dnf-2 = *=* ]]
11 compdef:155> [[ dillo = *=* ]]
11 compdef:155> [[ declare = *=* ]]
11 compdef:155> [[ dcopref = *=* ]]
11 compdef:155> [[ dcopobject = *=* ]]
11 compdef:155> [[ dcopfind = *=* ]]
11 compdef:155> [[ crsh = *=* ]]
11 compdef:155> [[ cowthink = *=* ]]
11 compdef:155> [[ composer.phar = *=* ]]
11 compdef:155> [[ clang++ = *=* ]]
11 compdef:155> [[ cinder = *=* ]]
11 compdef:155> [[ cask = *=* ]]
11 compdef:155> [[ cap = *=* ]]
11 compdef:155> [[ bzip2 = *=* ]]
11 compdef:155> [[ buildhash = *=* ]]
11 compdef:155> [[ btshowmetainfo = *=* ]]
11 compdef:155> [[ btreannounce = *=* ]]
11 compdef:155> [[ btmakemetafile = *=* ]]
11 compdef:155> [[ btlaunchmanycurses = *=* ]]
11 compdef:155> [[ bpython3-gtk = *=* ]]
11 compdef:155> [[ bpython-urwid = *=* ]]
11 compdef:155> [[ bpython-gtk = *=* ]]
11 compdef:155> [[ bogotune = *=* ]]
11 compdef:155> [[ bogofilter = *=* ]]
11 compdef:155> [[ bison = *=* ]]
11 compdef:155> [[ bindkey = *=* ]]
11 compdef:155> [[ barbican = *=* ]]
11 compdef:155> [[ avahi-resolve-host-name = *=* ]]
11 compdef:155> [[ avahi-resolve-address = *=* ]]
11 compdef:155> [[ avahi-resolve = *=* ]]
11 compdef:155> [[ avahi-browse-domains = *=* ]]
11 compdef:155> [[ atq = *=* ]]
11 compdef:155> [[ apt-get = *=* ]]
11 compdef:155> [[ apt-cdrom = *=* ]]
11 compdef:155> [[ ansible-doc = *=* ]]
11 compdef:155> [[ anno = *=* ]]
11 compdef:155> [[ a2enmod = *=* ]]
11 compdef:155> [[ -value-,XZ_OPT,-default- = *=* ]]
11 compdef:155> [[ -value-,XZ_DEFAULTS,-default- = *=* ]]
11 compdef:155> [[ -value-,SPROMPT,-default- = *=* ]]
11 compdef:155> [[ -value-,RPROMPT,-default- = *=* ]]
11 compdef:155> [[ -value-,PS4,-default- = *=* ]]
11 compdef:155> [[ -value-,PS3,-default- = *=* ]]
11 compdef:155> [[ -value-,PS2,-default- = *=* ]]
11 compdef:155> [[ -value-,PS1,-default- = *=* ]]
11 compdef:155> [[ -value-,PROMPT4,-default- = *=* ]]
11 compdef:155> [[ -value-,P4MERGE,-default- = *=* ]]
11 compdef:155> [[ -value-,LPDEST,-default- = *=* ]]
11 compdef:155> [[ -value-,LOOPDEV_DEBUG,-default- = *=* ]]
11 compdef:155> [[ -value-,LANGUAGE,-default- = *=* ]]
11 compdef:155> [[ -value-,GREP_OPTIONS,-default- = *=* ]]
11 compdef:155> [[ -value-,CXXFLAGS,-default- = *=* ]]
11 compdef:155> [[ -value-,CPPFLAGS,-default- = *=* ]]
11 compdef:155> [[ -value-,CMAKE_GENERATOR,-default- = *=* ]]
11 compdef:155> [[ -value-,-default-,-default- = *=* ]]
11 compdef:155> [[ 'xelatex=latex' = *=* ]]
11 compdef:155> [[ 'tunes2pod.pl=tunes2pod' = *=* ]]
11 compdef:155> [[ 'slogin=ssh' = *=* ]]
11 compdef:155> [[ 'nail=mail' = *=* ]]
11 compdef:155> [[ 'mktunes.pl=mktunes' = *=* ]]
11 compdef:155> [[ 'lzcat=unxz' = *=* ]]
11 compdef:155> [[ 'iceweasel=firefox' = *=* ]]
11 compdef:155> [[ 'gpg2=gpg' = *=* ]]
11 compdef:155> [[ 'gnupod_search.pl=gnupod_search' = *=* ]]
11 compdef:155> [[ 'gnupod_INIT.pl=gnupod_INIT' = *=* ]]
11 compdef:155> [[ 'ggf=git-checkout' = *=* ]]
11 compdef:155> [[ 'gdv=git-diff' = *=* ]]
11 compdef:155> [[ 'gccd=git-clone' = *=* ]]
11 compdef:155> [[ 'bzcat=bunzip2' = *=* ]]
11 compdef:155> [[ '-redirect-,>,xz=unxz' = *=* ]]
11 compdef:155> [[ '-redirect-,>,compress=uncompress' = *=* ]]
11 compdef:155> [[ '-redirect-,<,xz=xz' = *=* ]]
11 compdef:155> [[ '-redirect-,<,unxz=unxz' = *=* ]]
11 compdef:155> [[ '-redirect-,<,bzip2=bzip2' = *=* ]]
11 compdef:155> [[ '-redirect-,<,bunzip2=bunzip2' = *=* ]]
11 compdef:148> [[ 'php[0-9.-]' = (#b)(*)=(*) ]]
11 compdef:148> [[ 'lua[0-9.-]##' = (#b)(*)=(*) ]]
11 compdef:148> [[ 'gem[0-9.]#' = (#b)(*)=(*) ]]
11 compdef:148> [[ '-value-,LC_*,-default-' = (#b)(*)=(*) ]]
11 compdef:148> [[ '-value-,GO*,-default-' = (#b)(*)=(*) ]]
11 compdef:148> [[ '(texi(2*|ndex))' = (#b)(*)=(*) ]]
11 compdef:148> [[ '(ruby|[ei]rb)[0-9.]#' = (#b)(*)=(*) ]]
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (postpattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (pattern)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:139> case  (*)
11 compdef:136> [[ zstyle = -P ]]
11 compdef:136> [[ zsh = -P ]]
11 compdef:136> [[ zoneadm = -P ]]
11 compdef:136> [[ zmv = -P ]]
11 compdef:136> [[ zmodload = -P ]]
11 compdef:136> [[ zmail = -P ]]
11 compdef:136> [[ zlogin = -P ]]
11 compdef:136> [[ zf_ln = -P ]]
11 compdef:136> [[ zeal = -P ]]
11 compdef:136> [[ zcp = -P ]]
11 compdef:136> [[ zcat = -P ]]
11 compdef:136> [[ yarn = -P ]]
11 compdef:136> [[ yaourt = -P ]]
11 compdef:136> [[ xxd = -P ]]
11 compdef:136> [[ xwd = -P ]]
11 compdef:136> [[ xview = -P ]]
11 compdef:136> [[ xtightvncviewer = -P ]]
11 compdef:136> [[ xsetroot = -P ]]
11 compdef:136> [[ xsetbg = -P ]]
11 compdef:136> [[ xsel = -P ]]
11 compdef:136> [[ xrdb = -P ]]
11 compdef:136> [[ xpdf = -P ]]
11 compdef:136> [[ xon = -P ]]
11 compdef:136> [[ xmlstarlet = -P ]]
11 compdef:136> [[ xlsatoms = -P ]]
11 compdef:136> [[ xli = -P ]]
11 compdef:136> [[ xkill = -P ]]
11 compdef:136> [[ xhost = -P ]]
11 compdef:136> [[ xfontsel = -P ]]
11 compdef:136> [[ xfig = -P ]]
11 compdef:136> [[ xfd = -P ]]
11 compdef:136> [[ xcode-select = -P ]]
11 compdef:136> [[ wipefs = -P ]]
11 compdef:136> [[ whatis = -P ]]
11 compdef:136> [[ wg-quick = -P ]]
11 compdef:136> [[ wemux = -P ]]
11 compdef:136> [[ wanna-build = -P ]]
11 compdef:136> [[ w3m = -P ]]
11 compdef:136> [[ vpnc = -P ]]
11 compdef:136> [[ vacuumdb = -P ]]
11 compdef:136> [[ uscan = -P ]]
11 compdef:136> [[ update-alternatives = -P ]]
11 compdef:136> [[ unpigz = -P ]]
11 compdef:136> [[ unix2mac = -P ]]
11 compdef:136> [[ unix2dos = -P ]]
11 compdef:136> [[ unalias = -P ]]
11 compdef:136> [[ ufw = -P ]]
11 compdef:136> [[ udisksctl = -P ]]
11 compdef:136> [[ tree = -P ]]
11 compdef:136> [[ trash-restore = -P ]]
11 compdef:136> [[ trash-put = -P ]]
11 compdef:136> [[ traceroute = -P ]]
11 compdef:136> [[ tpb = -P ]]
11 compdef:136> [[ toilet = -P ]]
11 compdef:136> [[ svm = -P ]]
11 compdef:136> [[ svcadm = -P ]]
11 compdef:136> [[ sv = -P ]]
11 compdef:136> [[ stack = -P ]]
11 compdef:136> [[ srm = -P ]]
11 compdef:136> [[ sort = -P ]]
11 compdef:136> [[ softwareupdate = -P ]]
11 compdef:136> [[ smitty = -P ]]
11 compdef:136> [[ skein1024 = -P ]]
11 compdef:136> [[ skein256 = -P ]]
11 compdef:136> [[ sha512 = -P ]]
11 compdef:136> [[ sha384sum = -P ]]
11 compdef:136> [[ sha384 = -P ]]
11 compdef:136> [[ sha256sum = -P ]]
11 compdef:136> [[ sha256 = -P ]]
11 compdef:136> [[ sha1sum = -P ]]
11 compdef:136> [[ sfdx = -P ]]
11 compdef:136> [[ setcap = -P ]]
11 compdef:136> [[ scala = -P ]]
11 compdef:136> [[ sbt = -P ]]
11 compdef:136> [[ rwho = -P ]]
11 compdef:136> [[ rslsync = -P ]]
11 compdef:136> [[ route = -P ]]
11 compdef:136> [[ rmd160 = -P ]]
11 compdef:136> [[ rlogin = -P ]]
11 compdef:136> [[ rkt = -P ]]
11 compdef:136> [[ rfkill = -P ]]
11 compdef:136> [[ rec = -P ]]
11 compdef:136> [[ ralio = -P ]]
11 compdef:136> [[ quilt = -P ]]
11 compdef:136> [[ qtplay = -P ]]
11 compdef:136> [[ pushd = -P ]]
11 compdef:136> [[ ps2ascii = -P ]]
11 compdef:136> [[ powerd = -P ]]
11 compdef:136> [[ postmaster = -P ]]
11 compdef:136> [[ port = -P ]]
11 compdef:136> [[ policytool = -P ]]
11 compdef:136> [[ pm2 = -P ]]
11 compdef:136> [[ pkg_add = -P ]]
11 compdef:136> [[ pkcon = -P ]]
11 compdef:136> [[ pg_dumpall = -P ]]
11 compdef:136> [[ pg_dump = -P ]]
11 compdef:136> [[ pfexec = -P ]]
11 compdef:136> [[ pfctl = -P ]]
11 compdef:136> [[ patool = -P ]]
11 compdef:136> [[ osascript = -P ]]
11 compdef:136> [[ optirun = -P ]]
11 compdef:136> [[ open = -P ]]
11 compdef:136> [[ okular = -P ]]
11 compdef:136> [[ nvm = -P ]]
11 compdef:136> [[ node = -P ]]
11 compdef:136> [[ nmcli = -P ]]
11 compdef:136> [[ nanoc = -P ]]
11 compdef:136> [[ mysqldump = -P ]]
11 compdef:136> [[ mysqldiff = -P ]]
11 compdef:136> [[ mvnDebug = -P ]]
11 compdef:136> [[ mussh = -P ]]
11 compdef:136> [[ mush = -P ]]
11 compdef:136> [[ mplayer = -P ]]
11 compdef:136> [[ mondoarchive = -P ]]
11 compdef:136> [[ mix = -P ]]
11 compdef:136> [[ middleman = -P ]]
11 compdef:136> [[ md5sum = -P ]]
11 compdef:136> [[ md2 = -P ]]
11 compdef:136> [[ mattrib = -P ]]
11 compdef:136> [[ manage.py = -P ]]
11 compdef:136> [[ losetup = -P ]]
11 compdef:136> [[ loadkeys = -P ]]
11 compdef:136> [[ ln = -P ]]
11 compdef:136> [[ lastb = -P ]]
11 compdef:136> [[ kvno = -P ]]
11 compdef:136> [[ kubectl = -P ]]
11 compdef:136> [[ jrnl = -P ]]
11 compdef:136> [[ jls = -P ]]
11 compdef:136> [[ jexec = -P ]]
11 compdef:136> [[ include-what-you-use = -P ]]
11 compdef:136> [[ history = -P ]]
11 compdef:136> [[ gzegrep = -P ]]
11 compdef:136> [[ gxargs = -P ]]
11 compdef:136> [[ gv = -P ]]
11 compdef:136> [[ guilt-top = -P ]]
11 compdef:136> [[ guilt-series = -P ]]
11 compdef:136> [[ guilt-rm = -P ]]
11 compdef:136> [[ guilt-refresh = -P ]]
11 compdef:136> [[ guilt-rebase = -P ]]
11 compdef:136> [[ guilt-push = -P ]]
11 compdef:136> [[ guilt-pop = -P ]]
11 compdef:136> [[ guilt-patchbomb = -P ]]
11 compdef:136> [[ guilt-next = -P ]]
11 compdef:136> [[ guilt-new = -P ]]
11 compdef:136> [[ guilt-init = -P ]]
11 compdef:136> [[ guilt-import = -P ]]
11 compdef:136> [[ guilt-help = -P ]]
11 compdef:136> [[ guilt-header = -P ]]
11 compdef:136> [[ guilt-fold = -P ]]
11 compdef:136> [[ guilt-delete = -P ]]
11 compdef:136> [[ gtk-launch = -P ]]
11 compdef:136> [[ gsnd = -P ]]
11 compdef:136> [[ gsha512sum = -P ]]
11 compdef:136> [[ gsha1sum = -P ]]
11 compdef:136> [[ gpatch = -P ]]
11 compdef:136> [[ gnupod_check = -P ]]
11 compdef:136> [[ gnumfmt = -P ]]
11 compdef:136> [[ gln = -P ]]
11 compdef:136> [[ gist = -P ]]
11 compdef:136> [[ ghci = -P ]]
11 compdef:136> [[ ghc-pkg = -P ]]
11 compdef:136> [[ ghc = -P ]]
11 compdef:136> [[ gh = -P ]]
11 compdef:136> [[ getopts = -P ]]
11 compdef:136> [[ genv = -P ]]
11 compdef:136> [[ gdu = -P ]]
11 compdef:136> [[ gdf = -P ]]
11 compdef:136> [[ gcmp = -P ]]
11 compdef:136> [[ gchroot = -P ]]
11 compdef:136> [[ gccgo = -P ]]
11 compdef:136> [[ gcat = -P ]]
11 compdef:136> [[ gb2sum = -P ]]
11 compdef:136> [[ fuser = -P ]]
11 compdef:136> [[ freebsd-make = -P ]]
11 compdef:136> [[ fortune = -P ]]
11 compdef:136> [[ ffmpeg = -P ]]
11 compdef:136> [[ fc-match = -P ]]
11 compdef:136> [[ fc-list = -P ]]
11 compdef:136> [[ eu-nm = -P ]]
11 compdef:136> [[ envdir = -P ]]
11 compdef:136> [[ echotc = -P ]]
11 compdef:136> [[ e2label = -P ]]
11 compdef:136> [[ dvitodvi = -P ]]
11 compdef:136> [[ dviselect = -P ]]
11 compdef:136> [[ dvipdf = -P ]]
11 compdef:136> [[ dvidvi = -P ]]
11 compdef:136> [[ du = -P ]]
11 compdef:136> [[ dtruss = -P ]]
11 compdef:136> [[ drush = -P ]]
11 compdef:136> [[ dropuser = -P ]]
11 compdef:136> [[ dropdb = -P ]]
11 compdef:136> [[ dpkg-source = -P ]]
11 compdef:136> [[ dpkg-deb = -P ]]
11 compdef:136> [[ dpkg-cross = -P ]]
11 compdef:136> [[ dpkg = -P ]]
11 compdef:136> [[ dos2unix = -P ]]
11 compdef:136> [[ doas = -P ]]
11 compdef:136> [[ dnf-3 = -P ]]
11 compdef:136> [[ dnf-2 = -P ]]
11 compdef:136> [[ dmidecode = -P ]]
11 compdef:136> [[ dladm = -P ]]
11 compdef:136> [[ disable = -P ]]
11 compdef:136> [[ dirs = -P ]]
11 compdef:136> [[ dig = -P ]]
11 compdef:136> [[ diff3 = -P ]]
11 compdef:136> [[ diff = -P ]]
11 compdef:136> [[ dict = -P ]]
11 compdef:136> [[ diana = -P ]]
11 compdef:136> [[ dhcpcd = -P ]]
11 compdef:136> [[ df = -P ]]
11 compdef:136> [[ declare = -P ]]
11 compdef:136> [[ dcopref = -P ]]
11 compdef:136> [[ dcopclient = -P ]]
11 compdef:136> [[ dchroot = -P ]]
11 compdef:136> [[ dak = -P ]]
11 compdef:136> [[ cygstart.exe = -P ]]
11 compdef:136> [[ cygrunsrv.exe = -P ]]
11 compdef:136> [[ cygrunsrv = -P ]]
11 compdef:136> [[ cygcheck = -P ]]
11 compdef:136> [[ csup = -P ]]
11 compdef:136> [[ cscope = -P ]]
11 compdef:136> [[ createuser = -P ]]
11 compdef:136> [[ createdb = -P ]]
11 compdef:136> [[ cppcheck = -P ]]
11 compdef:136> [[ configure = -P ]]
11 compdef:136> [[ concourse = -P ]]
11 compdef:136> [[ composer.phar = -P ]]
11 compdef:136> [[ command = -P ]]
11 compdef:136> [[ comm = -P ]]
11 compdef:136> [[ code = -P ]]
11 compdef:136> [[ cmp = -P ]]
11 compdef:136> [[ cmake = -P ]]
11 compdef:136> [[ cinder = -P ]]
11 compdef:136> [[ chroot = -P ]]
11 compdef:136> [[ chdir = -P ]]
11 compdef:136> [[ cdbs-edit-patch = -P ]]
11 compdef:136> [[ cd = -P ]]
11 compdef:136> [[ ccal = -P ]]
11 compdef:136> [[ bsdinstall = -P ]]
11 compdef:136> [[ bogofilter = -P ]]
11 compdef:136> [[ bmake = -P ]]
11 compdef:136> [[ basename = -P ]]
11 compdef:136> [[ base64 = -P ]]
11 compdef:136> [[ barbican = -P ]]
11 compdef:136> [[ b2sum = -P ]]
11 compdef:136> [[ atrm = -P ]]
11 compdef:136> [[ atq = -P ]]
11 compdef:136> [[ arping = -P ]]
11 compdef:136> [[ archlinux-java = -P ]]
11 compdef:136> [[ aptitude = -P ]]
11 compdef:136> [[ apropos = -P ]]
11 compdef:136> [[ apachectl = -P ]]
11 compdef:136> [[ aodh = -P ]]
11 compdef:136> [[ amaya = -P ]]
11 compdef:136> [[ a2enmod = -P ]]
11 compdef:136> [[ a2dissite = -P ]]
11 compdef:136> [[ a2dismod = -P ]]
11 compdef:136> [[ _helm = -P ]]
11 compdef:136> [[ 8g = -P ]]
11 compdef:136> [[ -value-,XZ_DEFAULTS,-default- = -P ]]
11 compdef:136> [[ -value-,RPS2,-default- = -P ]]
11 compdef:136> [[ -value-,RPROMPT,-default- = -P ]]
11 compdef:136> [[ -value-,PS1,-default- = -P ]]
11 compdef:136> [[ -value-,PROMPT4,-default- = -P ]]
11 compdef:136> [[ -value-,PROMPT3,-default- = -P ]]
11 compdef:136> [[ -value-,PROMPT2,-default- = -P ]]
11 compdef:136> [[ -value-,PRINTER,-default- = -P ]]
11 compdef:136> [[ -value-,P4CLIENT,-default- = -P ]]
11 compdef:136> [[ -value-,LOOPDEV_DEBUG,-default- = -P ]]
11 compdef:136> [[ -value-,LD_DEBUG,-default- = -P ]]
11 compdef:136> [[ -value-,LDFLAGS,-default- = -P ]]
11 compdef:136> [[ -value-,LANGUAGE,-default- = -P ]]
11 compdef:136> [[ -value-,LANG,-default- = -P ]]
11 compdef:136> [[ -value-,GREP_OPTIONS,-default- = -P ]]
11 compdef:136> [[ -value-,CXXFLAGS,-default- = -P ]]
11 compdef:136> [[ -value-,CPPFLAGS,-default- = -P ]]
11 compdef:136> [[ -value-,CMAKE_GENERATOR,-default- = -P ]]
11 compdef:136> [[ -value-,ANT_ARGS,-default- = -P ]]
11 compdef:136> [[ -value-,-default-,-default- = -P ]]
11 compdef:136> [[ -equal- = -P ]]
11 compdef:136> [[ -condition- = -P ]]
11 compdef:136> [[ -command- = -P ]]
11 compdef:136> [[ -brace-parameter- = -P ]]
11 compdef:136> [[ -P = -P ]]
11 compdef:136> [[ -P = -P ]]
11 compdef:136> [[ 'zf_chown=chown' = -P ]]
11 compdef:136> [[ 'gnupod_addsong.pl=gnupod_addsong' = -P ]]
11 compdef:136> [[ 'gnupod_INIT.pl=gnupod_INIT' = -P ]]
11 compdef:136> [[ '-value-,RUBY(LIB|OPT|PATH),-default-' = -P ]]
11 compdef:136> [[ '-value-,LC_*,-default-' = -P ]]
11 compdef:136> [[ '-value-,GO*,-default-' = -P ]]
11 compdef:136> [[ '-value-,CCACHE_*,-default-' = -P ]]
11 compdef:136> [[ '-value-,*PATH,-default-' = -P ]]
11 compdef:136> [[ '-value-,(ftp|http(|s))_proxy,-default-' = -P ]]
11 compdef:136> [[ '-redirect-,>,xz=unxz' = -P ]]
11 compdef:136> [[ '-redirect-,>,gzip=gunzip' = -P ]]
11 compdef:136> [[ '-redirect-,<,compress=compress' = -P ]]
11 compdef:136> [[ '-redirect-,<,bzip2=bzip2' = -P ]]
11 compdef:136> [[ '-redirect-,<,bunzip2=bunzip2' = -P ]]
11 compdef:136> [[ '(tiff*|*2tiff|pal2rgb)' = -P ]]
11 compdef:136> [[ '(texi(2*|ndex))' = -P ]]
11 compdef:134> [[ zsh-mime-handler = -p ]]
11 compdef:134> [[ zln = -p ]]
11 compdef:134> [[ zip = -p ]]
11 compdef:134> [[ zgetattr = -p ]]
11 compdef:134> [[ zed = -p ]]
11 compdef:134> [[ zeal = -p ]]
11 compdef:134> [[ zcalc = -p ]]
11 compdef:134> [[ zargs = -p ]]
11 compdef:134> [[ yum = -p ]]
11 compdef:134> [[ ypcat = -p ]]
11 compdef:134> [[ yast = -p ]]
11 compdef:134> [[ yafc = -p ]]
11 compdef:134> [[ xz = -p ]]
11 compdef:134> [[ xwit = -p ]]
11 compdef:134> [[ xwininfo = -p ]]
11 compdef:134> [[ xv = -p ]]
11 compdef:134> [[ xscreensaver-command = -p ]]
11 compdef:134> [[ xrandr = -p ]]
11 compdef:134> [[ xpdf = -p ]]
11 compdef:134> [[ xmms2 = -p ]]
11 compdef:134> [[ xlsatoms = -p ]]
11 compdef:134> [[ xloadimage = -p ]]
11 compdef:134> [[ wiggle = -p ]]
11 compdef:134> [[ whois = -p ]]
11 compdef:134> [[ whatis = -p ]]
11 compdef:134> [[ wget = -p ]]
11 compdef:134> [[ watch = -p ]]
11 compdef:134> [[ wanna-build = -p ]]
11 compdef:134> [[ wait = -p ]]
11 compdef:134> [[ vserver = -p ]]
11 compdef:134> [[ virsh = -p ]]
11 compdef:134> [[ vacuumdb = -p ]]
11 compdef:134> [[ useradd = -p ]]
11 compdef:134> [[ urpme = -p ]]
11 compdef:134> [[ unlimit = -p ]]
11 compdef:134> [[ unhash = -p ]]
11 compdef:134> [[ unace = -p ]]
11 compdef:134> [[ tunctl = -p ]]
11 compdef:134> [[ tty = -p ]]
11 compdef:134> [[ truss = -p ]]
11 compdef:134> [[ trash-restore = -p ]]
11 compdef:134> [[ trash = -p ]]
11 compdef:134> [[ touch = -p ]]
11 compdef:134> [[ totdconfig = -p ]]
11 compdef:134> [[ toilet = -p ]]
11 compdef:134> [[ timeout = -p ]]
11 compdef:134> [[ tidy = -p ]]
11 compdef:134> [[ sw_vers = -p ]]
11 compdef:134> [[ svm = -p ]]
11 compdef:134> [[ svcprop = -p ]]
11 compdef:134> [[ surfraw = -p ]]
11 compdef:134> [[ sudo = -p ]]
11 compdef:134> [[ subliminal = -p ]]
11 compdef:134> [[ strongswan = -p ]]
11 compdef:134> [[ stack = -p ]]
11 compdef:134> [[ sr = -p ]]
11 compdef:134> [[ sqsh = -p ]]
11 compdef:134> [[ softwareupdate = -p ]]
11 compdef:134> [[ skein1024 = -p ]]
11 compdef:134> [[ skein256 = -p ]]
11 compdef:134> [[ shift = -p ]]
11 compdef:134> [[ sha512sum = -p ]]
11 compdef:134> [[ sha512 = -p ]]
11 compdef:134> [[ sha384sum = -p ]]
11 compdef:134> [[ sha384 = -p ]]
11 compdef:134> [[ sha256sum = -p ]]
11 compdef:134> [[ sha224sum = -p ]]
11 compdef:134> [[ sha1sum = -p ]]
11 compdef:134> [[ setup.py = -p ]]
11 compdef:134> [[ service = -p ]]
11 compdef:134> [[ sed = -p ]]
11 compdef:134> [[ scutil = -p ]]
11 compdef:134> [[ schroot = -p ]]
11 compdef:134> [[ sched = -p ]]
11 compdef:134> [[ sc_usage = -p ]]
11 compdef:134> [[ sbt = -p ]]
11 compdef:134> [[ say = -p ]]
11 compdef:134> [[ rubber = -p ]]
11 compdef:134> [[ rmd160 = -p ]]
11 compdef:134> [[ rm = -p ]]
11 compdef:134> [[ rlogin = -p ]]
11 compdef:134> [[ ranlib = -p ]]
11 compdef:134> [[ qtplay = -p ]]
11 compdef:134> [[ qiv = -p ]]
11 compdef:134> [[ qdbus = -p ]]
11 compdef:134> [[ pyhtmlizer = -p ]]
11 compdef:134> [[ putclip = -p ]]
11 compdef:134> [[ ptree = -p ]]
11 compdef:134> [[ psql = -p ]]
11 compdef:134> [[ prstat = -p ]]
11 compdef:134> [[ portmaster = -p ]]
11 compdef:134> [[ pm2 = -p ]]
11 compdef:134> [[ pipenv = -p ]]
11 compdef:134> [[ pigz = -p ]]
11 compdef:134> [[ pidof = -p ]]
11 compdef:134> [[ picocom = -p ]]
11 compdef:134> [[ php = -p ]]
11 compdef:134> [[ phing = -p ]]
11 compdef:134> [[ pgrep = -p ]]
11 compdef:134> [[ pg_restore = -p ]]
11 compdef:134> [[ pg_dumpall = -p ]]
11 compdef:134> [[ pflags = -p ]]
11 compdef:134> [[ perl = -p ]]
11 compdef:134> [[ perf = -p ]]
11 compdef:134> [[ pdf2dsc = -p ]]
11 compdef:134> [[ pbcopy = -p ]]
11 compdef:134> [[ opkg = -p ]]
11 compdef:134> [[ okular = -p ]]
11 compdef:134> [[ od = -p ]]
11 compdef:134> [[ objdump = -p ]]
11 compdef:134> [[ nginx = -p ]]
11 compdef:134> [[ networksetup = -p ]]
11 compdef:134> [[ netstat = -p ]]
11 compdef:134> [[ ncftp = -p ]]
11 compdef:134> [[ nc = -p ]]
11 compdef:134> [[ nautilus = -p ]]
11 compdef:134> [[ nanoc = -p ]]
11 compdef:134> [[ mysql = -p ]]
11 compdef:134> [[ mupdf = -p ]]
11 compdef:134> [[ mtr = -p ]]
11 compdef:134> [[ mpc = -p ]]
11 compdef:134> [[ mozilla = -p ]]
11 compdef:134> [[ mount = -p ]]
11 compdef:134> [[ module = -p ]]
11 compdef:134> [[ mktemp = -p ]]
11 compdef:134> [[ mkfifo = -p ]]
11 compdef:134> [[ mii-tool = -p ]]
11 compdef:134> [[ mere = -p ]]
11 compdef:134> [[ mencal = -p ]]
11 compdef:134> [[ members = -p ]]
11 compdef:134> [[ md5 = -p ]]
11 compdef:134> [[ md4 = -p ]]
11 compdef:134> [[ mail = -p ]]
11 compdef:134> [[ madison = -p ]]
11 compdef:134> [[ mac2unix = -p ]]
11 compdef:134> [[ lynx = -p ]]
11 compdef:134> [[ lunchy = -p ]]
11 compdef:134> [[ luarocks = -p ]]
11 compdef:134> [[ lsvg = -p ]]
11 compdef:134> [[ lspv = -p ]]
11 compdef:134> [[ lsmod = -p ]]
11 compdef:134> [[ lslv = -p ]]
11 compdef:134> [[ lsdev = -p ]]
11 compdef:134> [[ lsattr = -p ]]
11 compdef:134> [[ losetup = -p ]]
11 compdef:134> [[ locale = -p ]]
11 compdef:134> [[ llvm-otool = -p ]]
11 compdef:134> [[ lighty-enable-mod = -p ]]
11 compdef:134> [[ lha = -p ]]
11 compdef:134> [[ ldd = -p ]]
11 compdef:134> [[ ldconfig.real = -p ]]
11 compdef:134> [[ ldap = -p ]]
11 compdef:134> [[ kvno = -p ]]
11 compdef:134> [[ ksh = -p ]]
11 compdef:134> [[ kldload = -p ]]
11 compdef:134> [[ killall = -p ]]
11 compdef:134> [[ kill = -p ]]
11 compdef:134> [[ kdeconnect-cli = -p ]]
11 compdef:134> [[ jot = -p ]]
11 compdef:134> [[ join = -p ]]
11 compdef:134> [[ joe = -p ]]
11 compdef:134> [[ jobs = -p ]]
11 compdef:134> [[ javac = -p ]]
11 compdef:134> [[ jail = -p ]]
11 compdef:134> [[ iwconfig = -p ]]
11 compdef:134> [[ ispell = -p ]]
11 compdef:134> [[ irssi = -p ]]
11 compdef:134> [[ iptables-restore = -p ]]
11 compdef:134> [[ iostat = -p ]]
11 compdef:134> [[ ionice = -p ]]
11 compdef:134> [[ inxi = -p ]]
11 compdef:134> [[ invoke-rc.d = -p ]]
11 compdef:134> [[ initdb = -p ]]
11 compdef:134> [[ initctl = -p ]]
11 compdef:134> [[ inetadm = -p ]]
11 compdef:134> [[ include-what-you-use = -p ]]
11 compdef:134> [[ iftop = -p ]]
11 compdef:134> [[ ifconfig = -p ]]
11 compdef:134> [[ iconv = -p ]]
11 compdef:134> [[ http = -p ]]
11 compdef:134> [[ htop = -p ]]
11 compdef:134> [[ hostname = -p ]]
11 compdef:134> [[ host = -p ]]
11 compdef:134> [[ history = -p ]]
11 compdef:134> [[ hexdump = -p ]]
11 compdef:134> [[ head = -p ]]
11 compdef:134> [[ hdiutil = -p ]]
11 compdef:134> [[ gxargs = -p ]]
11 compdef:134> [[ gunzip = -p ]]
11 compdef:134> [[ guniq = -p ]]
11 compdef:134> [[ guilt-refresh = -p ]]
11 compdef:134> [[ guilt-rebase = -p ]]
11 compdef:134> [[ guilt-push = -p ]]
11 compdef:134> [[ guilt-patchbomb = -p ]]
11 compdef:134> [[ guilt-next = -p ]]
11 compdef:134> [[ guilt-new = -p ]]
11 compdef:134> [[ guilt-import-commit = -p ]]
11 compdef:134> [[ guilt-import = -p ]]
11 compdef:134> [[ guilt-help = -p ]]
11 compdef:134> [[ guilt-header = -p ]]
11 compdef:134> [[ guilt-fork = -p ]]
11 compdef:134> [[ guilt-applied = -p ]]
11 compdef:134> [[ guilt = -p ]]
11 compdef:134> [[ gsha384sum = -p ]]
11 compdef:134> [[ gsha256sum = -p ]]
11 compdef:134> [[ gsha224sum = -p ]]
11 compdef:134> [[ groff = -p ]]
11 compdef:134> [[ grep-excuses = -p ]]
11 compdef:134> [[ grep = -p ]]
11 compdef:134> [[ gradle = -p ]]
11 compdef:134> [[ gphoto2 = -p ]]
11 compdef:134> [[ gpg = -p ]]
11 compdef:134> [[ gpasswd = -p ]]
11 compdef:134> [[ gnutls-cli = -p ]]
11 compdef:134> [[ gnupod_check = -p ]]
11 compdef:134> [[ gmd5sum = -p ]]
11 compdef:134> [[ global = -p ]]
11 compdef:134> [[ gitk = -p ]]
11 compdef:134> [[ git-wtf = -p ]]
11 compdef:134> [[ git-buildpackage = -p ]]
11 compdef:134> [[ ghci = -p ]]
11 compdef:134> [[ ghc-pkg = -p ]]
11 compdef:134> [[ getopt = -p ]]
11 compdef:134> [[ getmail = -p ]]
11 compdef:134> [[ getent = -p ]]
11 compdef:134> [[ getconf = -p ]]
11 compdef:134> [[ gem = -p ]]
11 compdef:134> [[ gcut = -p ]]
11 compdef:134> [[ gcore = -p ]]
11 compdef:134> [[ gcomm = -p ]]
11 compdef:134> [[ fw_update = -p ]]
11 compdef:134> [[ freebsd-make = -p ]]
11 compdef:134> [[ free = -p ]]
11 compdef:134> [[ fmadm = -p ]]
11 compdef:134> [[ flutter = -p ]]
11 compdef:134> [[ flex = -p ]]
11 compdef:134> [[ flac = -p ]]
11 compdef:134> [[ findmnt = -p ]]
11 compdef:134> [[ fc-match = -p ]]
11 compdef:134> [[ fc-list = -p ]]
11 compdef:134> [[ epsffit = -p ]]
11 compdef:134> [[ emulator = -p ]]
11 compdef:134> [[ ecdsautil = -p ]]
11 compdef:134> [[ dvitype = -p ]]
11 compdef:134> [[ dvitodvi = -p ]]
11 compdef:134> [[ dviselect = -p ]]
11 compdef:134> [[ dropuser = -p ]]
11 compdef:134> [[ docker-compose = -p ]]
11 compdef:134> [[ docker = -p ]]
11 compdef:134> [[ dnf-2 = -p ]]
11 compdef:134> [[ django-admin = -p ]]
11 compdef:134> [[ dirs = -p ]]
11 compdef:134> [[ diffstat = -p ]]
11 compdef:134> [[ dhcpinfo = -p ]]
11 compdef:134> [[ dhclient3 = -p ]]
11 compdef:134> [[ df = -p ]]
11 compdef:134> [[ designate = -p ]]
11 compdef:134> [[ deno = -p ]]
11 compdef:134> [[ dcopobject = -p ]]
11 compdef:134> [[ dcopfind = -p ]]
11 compdef:134> [[ dchroot-dsa = -p ]]
11 compdef:134> [[ dbus-monitor = -p ]]
11 compdef:134> [[ dbus-launch = -p ]]
11 compdef:134> [[ dad = -p ]]
11 compdef:134> [[ cygstart.exe = -p ]]
11 compdef:134> [[ cygstart = -p ]]
11 compdef:134> [[ cygserver.exe = -p ]]
11 compdef:134> [[ cygcheck.exe = -p ]]
11 compdef:134> [[ crsh = -p ]]
11 compdef:134> [[ createdb = -p ]]
11 compdef:134> [[ cp = -p ]]
11 compdef:134> [[ composer = -p ]]
11 compdef:134> [[ cmake = -p ]]
11 compdef:134> [[ cloudkitty = -p ]]
11 compdef:134> [[ chromium = -p ]]
11 compdef:134> [[ cask = -p ]]
11 compdef:134> [[ bundle = -p ]]
11 compdef:134> [[ builtin = -p ]]
11 compdef:134> [[ bts = -p ]]
11 compdef:134> [[ btrfs = -p ]]
11 compdef:134> [[ btdownloadcurses = -p ]]
11 compdef:134> [[ brew = -p ]]
11 compdef:134> [[ bpython2-gtk = -p ]]
11 compdef:134> [[ bpython = -p ]]
11 compdef:134> [[ bower = -p ]]
11 compdef:134> [[ bogofilter = -p ]]
11 compdef:134> [[ bmake = -p ]]
11 compdef:134> [[ bitcoin-cli = -p ]]
11 compdef:134> [[ bibtex = -p ]]
11 compdef:134> [[ beep = -p ]]
11 compdef:134> [[ bash = -p ]]
11 compdef:134> [[ barbican = -p ]]
11 compdef:134> [[ b2sum = -p ]]
11 compdef:134> [[ awk = -p ]]
11 compdef:134> [[ avahi-resolve-address = -p ]]
11 compdef:134> [[ avahi-browse = -p ]]
11 compdef:134> [[ autoload = -p ]]
11 compdef:134> [[ augtool = -p ]]
11 compdef:134> [[ atrm = -p ]]
11 compdef:134> [[ asciinema = -p ]]
11 compdef:134> [[ asciidoctor = -p ]]
11 compdef:134> [[ arp = -p ]]
11 compdef:134> [[ arena = -p ]]
11 compdef:134> [[ apt-show-versions = -p ]]
11 compdef:134> [[ apt = -p ]]
11 compdef:134> [[ apropos = -p ]]
11 compdef:134> [[ ant = -p ]]
11 compdef:134> [[ ansible-galaxy = -p ]]
11 compdef:134> [[ ansible = -p ]]
11 compdef:134> [[ ali = -p ]]
11 compdef:134> [[ add-zle-hook-widget = -p ]]
11 compdef:134> [[ adb = -p ]]
11 compdef:134> [[ ack = -p ]]
11 compdef:134> [[ a2dissite = -p ]]
11 compdef:134> [[ a2dismod = -p ]]
11 compdef:134> [[ -vared- = -p ]]
11 compdef:134> [[ -value-,XZ_OPT,-default- = -p ]]
11 compdef:134> [[ -value-,TZ,-default- = -p ]]
11 compdef:134> [[ -value-,RPROMPT2,-default- = -p ]]
11 compdef:134> [[ -value-,PS4,-default- = -p ]]
11 compdef:134> [[ -value-,PS2,-default- = -p ]]
11 compdef:134> [[ -value-,PROMPT3,-default- = -p ]]
11 compdef:134> [[ -value-,PROMPT,-default- = -p ]]
11 compdef:134> [[ -value-,PERLDOC,-default- = -p ]]
11 compdef:134> [[ -value-,LOOPDEV_DEBUG,-default- = -p ]]
11 compdef:134> [[ -value-,LESSCHARSET,-default- = -p ]]
11 compdef:134> [[ -value-,LD_DEBUG,-default- = -p ]]
11 compdef:134> [[ -value-,GZIP,-default- = -p ]]
11 compdef:134> [[ -value-,GREP_OPTIONS,-default- = -p ]]
11 compdef:134> [[ -value-,CMAKE_GENERATOR,-default- = -p ]]
11 compdef:134> [[ -value-,ANSIBLE_STDOUT_CALLBACK,-default- = -p ]]
11 compdef:134> [[ -value-,ADB_TRACE,-default- = -p ]]
11 compdef:134> [[ -value-,-default-,-default- = -p ]]
11 compdef:134> [[ -value-,-default-,-command- = -p ]]
11 compdef:134> [[ -tilde- = -p ]]
11 compdef:134> [[ -redirect-,-default-,-default- = -p ]]
11 compdef:134> [[ -first- = -p ]]
11 compdef:134> [[ -condition- = -p ]]
11 compdef:134> [[ -command-line- = -p ]]
11 compdef:134> [[ -command- = -p ]]
11 compdef:134> [[ 'zf_chgrp=chgrp' = -p ]]
11 compdef:134> [[ 'zf*' = -p ]]
11 compdef:134> [[ 'yaourt.static=yaourt' = -p ]]
11 compdef:134> [[ 'tunes2pod.pl=tunes2pod' = -p ]]
11 compdef:134> [[ 'qemu(|-system-*)' = -p ]]
11 compdef:134> [[ 'gnupod_search.pl=gnupod_search' = -p ]]
11 compdef:134> [[ 'gnupod_addsong.pl=gnupod_addsong' = -p ]]
11 compdef:134> [[ 'gnupod_INIT.pl=gnupod_INIT' = -p ]]
11 compdef:134> [[ 'gchgrp=chgrp' = -p ]]
11 compdef:134> [[ 'gccd=git-clone' = -p ]]
11 compdef:134> [[ 'bzcat=bunzip2' = -p ]]
11 compdef:134> [[ '_git_log_prettily=git-log' = -p ]]
11 compdef:134> [[ '-value-,RUBY(LIB|OPT|PATH),-default-' = -p ]]
11 compdef:134> [[ '-value-,CGO*,-default-' = -p ]]
11 compdef:134> [[ '-value-,(ftp|http(|s))_proxy,-default-' = -p ]]
11 compdef:134> [[ '-redirect-,>,compress=uncompress' = -p ]]
11 compdef:134> [[ '-redirect-,>,bzip2=bunzip2' = -p ]]
11 compdef:134> [[ '-redirect-,<,unxz=unxz' = -p ]]
11 compdef:134> [[ '-redirect-,<,bunzip2=bunzip2' = -p ]]
11 compdef:134> [[ '*/(init|rc[0-9S]#).d/*' = -p ]]
11 compdef:134> [[ '(p[bgpn]m*|*top[bgpn]m)' = -p ]]
11 compdef:132> [[ zxpdf = -N ]]
11 compdef:132> [[ zf_ln = -N ]]
11 compdef:132> [[ zcp = -N ]]
11 compdef:132> [[ xwud = -N ]]
11 compdef:132> [[ xwininfo = -N ]]
11 compdef:132> [[ xview = -N ]]
11 compdef:132> [[ xsetroot = -N ]]
11 compdef:132> [[ xsetbg = -N ]]
11 compdef:132> [[ xrdb = -N ]]
11 compdef:132> [[ xprop = -N ]]
11 compdef:132> [[ xml = -N ]]
11 compdef:132> [[ xloadimage = -N ]]
11 compdef:132> [[ xkill = -N ]]
11 compdef:132> [[ xhost = -N ]]
11 compdef:132> [[ xfontsel = -N ]]
11 compdef:132> [[ xfd = -N ]]
11 compdef:132> [[ xev = -N ]]
11 compdef:132> [[ whence = -N ]]
11 compdef:132> [[ virt-host-validate = -N ]]
11 compdef:132> [[ vacuumdb = -N ]]
11 compdef:132> [[ urpmi.removemedia = -N ]]
11 compdef:132> [[ unpigz = -N ]]
11 compdef:132> [[ unix2mac = -N ]]
11 compdef:132> [[ unix2dos = -N ]]
11 compdef:132> [[ svnadmin = -N ]]
11 compdef:132> [[ strongswan = -N ]]
11 compdef:132> [[ skein1024 = -N ]]
11 compdef:132> [[ skein512 = -N ]]
11 compdef:132> [[ skein256 = -N ]]
11 compdef:132> [[ sha512sum = -N ]]
11 compdef:132> [[ sha384sum = -N ]]
11 compdef:132> [[ sha384 = -N ]]
11 compdef:132> [[ sha256sum = -N ]]
11 compdef:132> [[ sha256 = -N ]]
11 compdef:132> [[ sha224sum = -N ]]
11 compdef:132> [[ sha1 = -N ]]
11 compdef:132> [[ serialver = -N ]]
11 compdef:132> [[ rmd160 = -N ]]
11 compdef:132> [[ reload = -N ]]
11 compdef:132> [[ psmulti = -N ]]
11 compdef:132> [[ postqueue = -N ]]
11 compdef:132> [[ pkgtool = -N ]]
11 compdef:132> [[ pkg_create = -N ]]
11 compdef:132> [[ pg_restore = -N ]]
11 compdef:132> [[ pg_dump = -N ]]
11 compdef:132> [[ pg_config = -N ]]
11 compdef:132> [[ parsehdlist = -N ]]
11 compdef:132> [[ mysqlshow = -N ]]
11 compdef:132> [[ mozilla-xremote-client = -N ]]
11 compdef:132> [[ mozilla-firefox = -N ]]
11 compdef:132> [[ md2 = -N ]]
11 compdef:132> [[ lpoptions = -N ]]
11 compdef:132> [[ logname = -N ]]
11 compdef:132> [[ javah = -N ]]
11 compdef:132> [[ ip6tables-save = -N ]]
11 compdef:132> [[ integer = -N ]]
11 compdef:132> [[ initdb = -N ]]
11 compdef:132> [[ history = -N ]]
11 compdef:132> [[ helm = -N ]]
11 compdef:132> [[ gunzip = -N ]]
11 compdef:132> [[ gunexpand = -N ]]
11 compdef:132> [[ guilt-top = -N ]]
11 compdef:132> [[ guilt-status = -N ]]
11 compdef:132> [[ guilt-series = -N ]]
11 compdef:132> [[ guilt-rm = -N ]]
11 compdef:132> [[ guilt-pop = -N ]]
11 compdef:132> [[ guilt-patchbomb = -N ]]
11 compdef:132> [[ guilt-next = -N ]]
11 compdef:132> [[ guilt-import = -N ]]
11 compdef:132> [[ guilt-header = -N ]]
11 compdef:132> [[ guilt-applied = -N ]]
11 compdef:132> [[ guilt-add = -N ]]
11 compdef:132> [[ gsnd = -N ]]
11 compdef:132> [[ gsha224sum = -N ]]
11 compdef:132> [[ gmv = -N ]]
11 compdef:132> [[ gitk = -N ]]
11 compdef:132> [[ gid = -N ]]
11 compdef:132> [[ gh = -N ]]
11 compdef:132> [[ genv = -N ]]
11 compdef:132> [[ gdu = -N ]]
11 compdef:132> [[ gdf = -N ]]
11 compdef:132> [[ gdate = -N ]]
11 compdef:132> [[ gcomm = -N ]]
11 compdef:132> [[ gcat = -N ]]
11 compdef:132> [[ gbase32 = -N ]]
11 compdef:132> [[ freebsd-make = -N ]]
11 compdef:132> [[ dvitype = -N ]]
11 compdef:132> [[ dvitodvi = -N ]]
11 compdef:132> [[ dviselect = -N ]]
11 compdef:132> [[ dvipdf = -N ]]
11 compdef:132> [[ dvidvi = -N ]]
11 compdef:132> [[ dropdb = -N ]]
11 compdef:132> [[ dpkg-query = -N ]]
11 compdef:132> [[ dpkg-deb = -N ]]
11 compdef:132> [[ dnf-3 = -N ]]
11 compdef:132> [[ django-admin = -N ]]
11 compdef:132> [[ dhclient3 = -N ]]
11 compdef:132> [[ dbus-launch = -N ]]
11 compdef:132> [[ cygcheck.exe = -N ]]
11 compdef:132> [[ crsh = -N ]]
11 compdef:132> [[ config.status = -N ]]
11 compdef:132> [[ composer.phar = -N ]]
11 compdef:132> [[ comb = -N ]]
11 compdef:132> [[ cloudkitty = -N ]]
11 compdef:132> [[ chage = -N ]]
11 compdef:132> [[ cftp = -N ]]
11 compdef:132> [[ buildhash = -N ]]
11 compdef:132> [[ bmake = -N ]]
11 compdef:132> [[ barbican = -N ]]
11 compdef:132> [[ b2sum = -N ]]
11 compdef:132> [[ avahi-resolve-host-name = -N ]]
11 compdef:132> [[ avahi-browse-domains = -N ]]
11 compdef:132> [[ arecord = -N ]]
11 compdef:132> [[ apvlv = -N ]]
11 compdef:132> [[ apropos = -N ]]
11 compdef:132> [[ aodh = -N ]]
11 compdef:132> [[ ack-standalone = -N ]]
11 compdef:132> [[ a2dissite = -N ]]
11 compdef:132> [[ -value-,VALGRIND_OPTS,-default- = -N ]]
11 compdef:132> [[ -value-,RPS2,-default- = -N ]]
11 compdef:132> [[ -value-,RPROMPT,-default- = -N ]]
11 compdef:132> [[ -value-,PROMPT4,-default- = -N ]]
11 compdef:132> [[ -value-,PROMPT3,-default- = -N ]]
11 compdef:132> [[ -value-,PROMPT2,-default- = -N ]]
11 compdef:132> [[ -value-,LESSCHARSET,-default- = -N ]]
11 compdef:132> [[ -value-,LESS,-default- = -N ]]
11 compdef:132> [[ -value-,LANGUAGE,-default- = -N ]]
11 compdef:132> [[ -value-,GREP_OPTIONS,-default- = -N ]]
11 compdef:132> [[ -value-,CXXFLAGS,-default- = -N ]]
11 compdef:132> [[ -value-,CPPFLAGS,-default- = -N ]]
11 compdef:132> [[ -value-,CMAKE_GENERATOR,-default- = -N ]]
11 compdef:132> [[ -value-,ADB_TRACE,-default- = -N ]]
11 compdef:132> [[ -value-,-default-,-default- = -N ]]
11 compdef:132> [[ -value-,-default-,-command- = -N ]]
11 compdef:132> [[ -P = -N ]]
11 compdef:132> [[ -P = -N ]]
11 compdef:132> [[ 'zf_chgrp=chgrp' = -N ]]
11 compdef:132> [[ 'svnlite=svn' = -N ]]
11 compdef:132> [[ 'svnadmin-static=svnadmin' = -N ]]
11 compdef:132> [[ 'nedit-nc=nc' = -N ]]
11 compdef:132> [[ 'mailx=mail' = -N ]]
11 compdef:132> [[ 'lzma=xz' = -N ]]
11 compdef:132> [[ 'iceweasel=firefox' = -N ]]
11 compdef:132> [[ 'gnupod_search.pl=gnupod_search' = -N ]]
11 compdef:132> [[ 'gnupod_check.pl=gnupod_check' = -N ]]
11 compdef:132> [[ 'gnupod_addsong.pl=gnupod_addsong' = -N ]]
11 compdef:132> [[ 'ggu=git-checkout' = -N ]]
11 compdef:132> [[ 'ggp=git-checkout' = -N ]]
11 compdef:132> [[ 'ggl=git-checkout' = -N ]]
11 compdef:132> [[ 'ggf=git-checkout' = -N ]]
11 compdef:132> [[ 'gchgrp=chgrp' = -N ]]
11 compdef:132> [[ '-value-,RUBY(LIB|OPT|PATH),-default-' = -N ]]
11 compdef:132> [[ '-redirect-,>,bzip2=bunzip2' = -N ]]
11 compdef:132> [[ '-redirect-,<,bzip2=bzip2' = -N ]]
11 compdef:132> [[ '(ruby|[ei]rb)[0-9.]#' = -N ]]
11 compdef:131> ((  26  ))
11 compdef:131> ((  24  ))
11 compdef:131> ((  23  ))
11 compdef:131> ((  23  ))
11 compdef:131> ((  18  ))
11 compdef:131> ((  17  ))
11 compdef:131> ((  16  ))
11 compdef:131> ((  15  ))
11 compdef:131> ((  14  ))
11 compdef:131> ((  14  ))
11 compdef:131> ((  12  ))
11 compdef:131> ((  12  ))
11 compdef:131> ((  11  ))
11 compdef:131> ((  11  ))
11 compdef:131> ((  11  ))
11 compdef:131> ((  10  ))
11 compdef:131> ((  10  ))
11 compdef:131> ((  10  ))
11 compdef:131> ((  10  ))
11 compdef:131> ((  9  ))
11 compdef:131> ((  9  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  8  ))
11 compdef:131> ((  7  ))
11 compdef:131> ((  7  ))
11 compdef:131> ((  6  ))
11 compdef:131> ((  6  ))
11 compdef:131> ((  6  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  5  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  4  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  3  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  2  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:131> ((  1  ))
11 compdef:120> i=C-xn
11 compdef:120> i=C-xm
11 compdef:120> i=C-xc
11 compdef:120> i=C-xC
11 compdef:110> [[ complete-word = .* ]]
11 compdef:110> [[ complete-word = .* ]]
11 compdef:110> [[ complete-word = .* ]]
11 compdef:91> [[ list-choices = .* ]]
11 compdef:91> [[ list-choices = .* ]]
11 compdef:90> [[ _history-complete-older = _* ]]
11 compdef:90> [[ _expand_word = _* ]]
11 compdef:90> [[ _bash_list-choices = _* ]]
11 compdef:86> [[ 6 -lt 3 ]]
11 compdef:86> [[ 6 -lt 3 ]]
11 compdef:85> [[ -n _history-complete-older ]]
11 compdef:85> [[ -n _bash_complete-word ]]
11 compdef:83> case widgetkey (widgetkey)
11 compdef:83> case widgetkey (widgetkey)
11 compdef:83> case postpattern (widgetkey)
11 compdef:83> case postpattern (widgetkey)
11 compdef:83> case postpattern (*)
11 compdef:83> case key (key)
11 compdef:83> case key (key)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (widgetkey)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (key)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:83> case  (*)
11 compdef:79> func=_zstyle
11 compdef:79> func=_zpool
11 compdef:79> func=_zparseopts
11 compdef:79> func=_zmv
11 compdef:79> func=_zcompile
11 compdef:79> func=_zcat
11 compdef:79> func=_zcalc
11 compdef:79> func=_yarn
11 compdef:79> func=_yaourt
11 compdef:79> func=_xwit
11 compdef:79> func=_xsel
11 compdef:79> func=_xfig
11 compdef:79> func=_wpa_cli
11 compdef:79> func=_wipefs
11 compdef:79> func=_wg-quick
11 compdef:79> func=_wemux
11 compdef:79> func=_wait
11 compdef:79> func=_vmctl
11 compdef:79> func=_vagrant
11 compdef:79> func=_urxvt
11 compdef:79> func=_urls
11 compdef:79> func=_udisksctl
11 compdef:79> func=_time_zone
11 compdef:79> func=_tiff
11 compdef:79> func=_svm
11 compdef:79> func=_subscript
11 compdef:79> func=_subliminal
11 compdef:79> func=_subl
11 compdef:79> func=_showoff
11 compdef:79> func=_sfdx
11 compdef:79> func=_rrdtool
11 compdef:79> func=_redis-cli
11 compdef:79> func=_rdesktop
11 compdef:79> func=_rails
11 compdef:79> func=_portsnap
11 compdef:79> func=_port
11 compdef:79> func=_pipenv
11 compdef:79> func=_pids
11 compdef:79> func=_phing
11 compdef:79> func=_pfctl
11 compdef:79> func=_periscope
11 compdef:79> func=_pdm
11 compdef:79> func=_other_accounts
11 compdef:79> func=_openssl
11 compdef:79> func=_open
11 compdef:79> func=_object_classes
11 compdef:79> func=_nvm
11 compdef:79> func=_node
11 compdef:79> func=_nkf
11 compdef:79> func=_ninja
11 compdef:79> func=_nftables
11 compdef:79> func=_networksetup
11 compdef:79> func=_netscape
11 compdef:79> func=_nautilus
11 compdef:79> func=_nanoc
11 compdef:79> func=_mvn
11 compdef:79> func=_mozilla
11 compdef:79> func=_most_recent_file
11 compdef:79> func=_monotone
11 compdef:79> func=_module-assistant
11 compdef:79> func=_mktemp
11 compdef:79> func=_mix
11 compdef:79> func=_middleman
11 compdef:79> func=_mdfind
11 compdef:79> func=_md5sum
11 compdef:79> func=_mc
11 compdef:79> func=_matlab
11 compdef:79> func=_man
11 compdef:79> func=_mail
11 compdef:79> func=_lzop
11 compdef:79> func=_lsvg
11 compdef:79> func=_lspv
11 compdef:79> func=_lscfg
11 compdef:79> func=_lsattr
11 compdef:79> func=_ln
11 compdef:79> func=_less
11 compdef:79> func=_last
11 compdef:79> func=_jobs_fg
11 compdef:79> func=_jobs_bg
11 compdef:79> func=_jexec
11 compdef:79> func=_init_d
11 compdef:79> func=_include-what-you-use
11 compdef:79> func=_iftop
11 compdef:79> func=_ifconfig
11 compdef:79> func=_hwinfo
11 compdef:79> func=_hub
11 compdef:79> func=_history_complete_word
11 compdef:79> func=_heroku
11 compdef:79> func=_hash
11 compdef:79> func=_gzip
11 compdef:79> func=_grep-excuses
11 compdef:79> func=_gqview
11 compdef:79> func=_gnutls
11 compdef:79> func=_git-buildpackage
11 compdef:79> func=_git
11 compdef:79> func=_ghostscript
11 compdef:79> func=_gh
11 compdef:79> func=_flex
11 compdef:79> func=_flac
11 compdef:79> func=_figlet
11 compdef:79> func=_ffmpeg
11 compdef:79> func=_feh
11 compdef:79> func=_eog
11 compdef:79> func=_enable
11 compdef:79> func=_echoti
11 compdef:79> func=_e2label
11 compdef:79> func=_dupload
11 compdef:79> func=_du
11 compdef:79> func=_dtruss
11 compdef:79> func=_dtrace
11 compdef:79> func=_dpkg-cross
11 compdef:79> func=_dpkg
11 compdef:79> func=_dos2unix
11 compdef:79> func=_docker_compose
11 compdef:79> func=_dnf
11 compdef:79> func=_dlocate
11 compdef:79> func=_dladm
11 compdef:79> func=_dkms
11 compdef:79> func=_django
11 compdef:79> func=_dirs
11 compdef:79> func=_dig
11 compdef:79> func=_diffstat
11 compdef:79> func=_dconf
11 compdef:79> func=_dbus
11 compdef:79> func=_date
11 compdef:79> func=_cygstart
11 compdef:79> func=_cygserver
11 compdef:79> func=_cygrunsrv
11 compdef:79> func=_cygpath
11 compdef:79> func=_cygcheck
11 compdef:79> func=_cut
11 compdef:79> func=_csup
11 compdef:79> func=_cssh
11 compdef:79> func=_crontab
11 compdef:79> func=_cpupower
11 compdef:79> func=_cowsay
11 compdef:79> func=_correct_filename
11 compdef:79> func=_concourse
11 compdef:79> func=_compdef
11 compdef:79> func=_command
11 compdef:79> func=_chroot
11 compdef:79> func=_cheat
11 compdef:79> func=_cd
11 compdef:79> func=_ccal
11 compdef:79> func=_cat
11 compdef:79> func=_brew_services
11 compdef:79> func=_at
11 compdef:79> func=_artisan
11 compdef:79> func=_aptitude
11 compdef:79> func=_analyseplugin
11 compdef:79> func=_add-zle-hook-widget
11 compdef:79> func=_aap
11 compdef:49> [[ _rcs = *=* ]]
11 compdef:49> [[ _npm = *=* ]]
11 compdef:49> [[ _init_d = *=* ]]
11 compdef:49> [[ _brew = *=* ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:49> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:45> [[ -z '' ]]
11 compdef:40> ((  ! 19  ))
11 compdef:40> ((  ! 18  ))
11 compdef:40> ((  ! 13  ))
11 compdef:40> ((  ! 12  ))
11 compdef:40> ((  ! 10  ))
11 compdef:40> ((  ! 9  ))
11 compdef:40> ((  ! 8  ))
11 compdef:40> ((  ! 7  ))
11 compdef:40> ((  ! 7  ))
11 compdef:40> ((  ! 7  ))
11 compdef:40> ((  ! 7  ))
11 compdef:40> ((  ! 7  ))
11 compdef:40> ((  ! 6  ))
11 compdef:40> ((  ! 6  ))
11 compdef:40> ((  ! 5  ))
11 compdef:40> ((  ! 5  ))
11 compdef:40> ((  ! 5  ))
11 compdef:40> ((  ! 5  ))
11 compdef:40> ((  ! 5  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 4  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 3  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:40> ((  ! 2  ))
11 compdef:26> [[ P = P ]]
11 compdef:24> [[ P = p ]]
11 compdef:24> [[ P = p ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:18> [[ -n '' ]]
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (n)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case n (a)
11 compdef:15> case k (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case a (a)
11 compdef:15> case P (n)
11 compdef:15> case P (a)
11 compdef:15> case P (a)
11 compaudit:57> _i_wdirs=( )
11 compaudit:40> ((  1  ))
11 colors:87> color[bg-grey]=40
11 colors:81> color[fg-${color[$k]}]=39
11 colors:81> color[fg-${color[$k]}]=37
11 colors:81> color[fg-${color[$k]}]=34
11 colors:81> color[fg-${color[$k]}]=33
11 colors:81> color[fg-${color[$k]}]=32
11 colors:77> k=43
11 colors:77> color[${color[$k]}]=49
11 colors:77> color[${color[$k]}]=47
11 colors:77> color[${color[$k]}]=47
11 colors:77> color[${color[$k]}]=46
11 colors:77> color[${color[$k]}]=45
11 colors:77> color[${color[$k]}]=42
11 colors:77> color[${color[$k]}]=40
11 colors:77> color[${color[$k]}]=39
11 colors:77> color[${color[$k]}]=37
11 colors:77> color[${color[$k]}]=36
11 colors:77> color[${color[$k]}]=36
11 colors:77> color[${color[$k]}]=34
11 colors:77> color[${color[$k]}]=34
11 colors:77> color[${color[$k]}]=31
11 colors:77> color[${color[$k]}]=28
11 colors:77> color[${color[$k]}]=27
11 colors:77> color[${color[$k]}]=27
11 colors:77> color[${color[$k]}]=23
11 colors:77> color[${color[$k]}]=08
11 colors:77> color[${color[$k]}]=05
11 colors:77> color[${color[$k]}]=05
11 colors:77> color[${color[$k]}]=04
11 colors:77> color[${color[$k]}]=03
11 colors:77> color[${color[$k]}]=02
11 colors:77> color[${color[$k]}]=01
11 colors:77> color[${color[$k]}]=00
11 antigen-remove-hook:7> [[ 2 > 0 ]]
11 antigen-remove-hook:7> [[ 1 > 0 ]]
11 antigen-remove-hook:7> [[ 1 > 0 ]]
11 antigen-ext-init:3> ext=cache
11 add-zsh-hook:83> ((  1  ))
11 _zsh_highlight_load_highlighters:13> highlighter=root
11 _zsh_highlight_load_highlighters:13> highlighter=root
11 _zsh_highlight_load_highlighters:13> highlighter=pattern
11 _zsh_highlight_load_highlighters:13> highlighter=cursor
11 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
11 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.oh-my-zsh/c...
11 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
11 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
11 _zsh_highlight_load_highlighters:12> highlighter_dir=/Users/matt/.antigen/bun...
11 _zsh_highlight_bind_widgets:27> case user:zle-line-init (user:_zsh_highlight_...
11 _zsh_highlight_bind_widgets:27> case user:url-quote-magic (user:_zsh_highligh...
11 _zsh_highlight_bind_widgets:27> case user:down-line-or-beginning-search (user...
11 _zsh_highlight_bind_widgets:27> case user:bracketed-paste-magic (user:_zsh_hi...
11 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_next_tags (use...
11 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete:_main_com...
11 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete-prefix:_m...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_main_complete...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_word (...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_alias ...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_word ...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_filen...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_tag ...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_debu...
11 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_bash_completi...
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:*)
11 _zsh_highlight_bind_widgets:27> case builtin (user:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
11 _zsh_highlight_bind_widgets:27> case  (user:_zsh_highlight_widget_*)
11 _zsh_highlight_bind_widgets:26> cur_widget=vi-replace
11 _zsh_highlight_bind_widgets:26> cur_widget=vi-add-eol
11 _zsh_highlight_bind_widgets:26> cur_widget=accept-line
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;254m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;252m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;249m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;246m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;241m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;238m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;235m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;229m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;226m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;224m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;221m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;214m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;201m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;190m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;185m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;175m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;157m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;148m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;142m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;138m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;136m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;121m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;111m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;109m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;107m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;105m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;096m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;092m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;090m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;088m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;081m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;076m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;064m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;062m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;051m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;049m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;044m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;008m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:18> BG[$color]=$'%{C-[[48;5;005m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;247m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;245m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;242m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;230m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;225m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;222m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;220m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;215m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;212m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;198m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;188m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;186m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;176m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;143m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;141m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;139m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;137m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;122m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;110m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;108m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;106m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;097m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;091m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;089m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;082m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;080m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;065m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;063m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;056m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;052m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;050m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;048m%}'
11 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:17> FG[$color]=$'%{C-[[38;5;034m%}'
11 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/usr/share/zsh/site-functions
11 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/plugins/zshfl
11 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/completions
11 /Users/matt/.oh-my-zsh/lib/misc.zsh:5> d=/Users/matt/.oh-my-zsh/cache/complet...
11 /Users/matt/.oh-my-zsh/lib/history.zsh:21> case  (dd.mm.yyyy)
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/usr/lo...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
11 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
11 -antigen-parse-args:155> [[ -n '' ]]
11 -antigen-parse-args:155> [[ -n '' ]]
11 -antigen-parse-args:137> [[ -n '' ]]
11 -antigen-parse-args:137> [[ -n '' ]]
11 -antigen-parse-args:127> [[ -n '' ]]
11 -antigen-parse-args:105> [[ ! -z '' ]]
11 -antigen-parse-args:105> [[ ! -z '' ]]
11 -antigen-parse-args:72> args[loc]=plugins/deno
11 -antigen-parse-args:65> shift
11 -antigen-parse-args:37> value=zsh-users/zsh-autosuggestions
11 -antigen-parse-args:37> value=deno
11 -antigen-parse-args:37> value=deno
11 -antigen-parse-args:24> [[ lib == --loc ]]
11 -antigen-parse-args:22> case --loc (--url | --loc)
11 -antigen-parse-args:17> [[ 1 -gt 0 ]]
11 -antigen-parse-args:17> [[ 1 -gt 0 ]]
11 -antigen-parse-args:17> [[ 1 -gt 0 ]]
11 -antigen-parse-args:14> args[btype]=plugin
11 -antigen-parse-args:14> args[btype]=plugin
11 -antigen-load:20> [[ 0 == 0 ]]
11 -antigen-load:20> [[ 0 == 0 ]]
11 -antigen-hook-handler:46> replace_hook=1
11 -antigen-hook-handler:46> replace_hook=1
11 -antigen-hook-handler:46> replace_hook=1
11 -antigen-hook-handler:46> replace_hook=1
11 -antigen-hook-handler:46> replace_hook=1
11 -antigen-hook-handler:45> hook=-antigen-load-env-cached
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:22> case replace (replace)
11 -antigen-hook-handler:18> meta[called]=8
11 -antigen-hook-handler:18> meta[called]=7
11 -antigen-hook-handler:18> meta[called]=6
11 -antigen-hook-handler:18> meta[called]=5
11 -antigen-hook-handler:18> meta[called]=4
11 -antigen-hook-handler:18> meta[called]=4
11 -antigen-hook-handler:18> meta[called]=4
11 -antigen-hook-handler:18> meta[called]=3
11 -antigen-hook-handler:18> meta[called]=2
11 -antigen-hook-handler:18> meta[called]=2
11 -antigen-hook-handler:18> meta[called]=1
11 -antigen-hook-handler:18> meta[called]=1
11 -antigen-hook-handler:18> meta[called]=1
11 -antigen-hook-handler:18> meta[called]=1
11 -antigen-hook-handler:10> hook=antigen-lock
11 -antigen-hook-handler:10> hook=antigen-bundle-cached
11 -antigen-hook-handler:10> hook=antigen-bundle-cached
11 -antigen-hook-handler:10> hook=antigen-bundle-cached
11 -antigen-hook-handler:10> hook=antigen-apply-parallel
11 -antigen-hook-handler:10> hook=antigen-apply-lock
11 -antigen-hook-handler:10> hook=-antigen-load-source-cached
11 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
11 (eval):244> alias 'which-command=whence'
11 (eval):241> alias 'vi=nvim'
11 (eval):239> alias 't=trash'
11 (eval):236> alias 's=fasd -si'
11 (eval):235> alias 'run-help=man'
11 (eval):231> alias 'md=mkdir -p'
11 (eval):230> alias 'lsa=ls -lah'
11 (eval):227> alias 'la=ls -lAh'
11 (eval):225> alias 'j=zz'
11 (eval):196> alias 'gsw=git switch'
11 (eval):195> alias 'gsu=git submodule update'
11 (eval):194> alias 'lsa=ls -lah'
11 (eval):192> alias 'll=ls -lh'
11 (eval):178> alias 'gsd=git svn dcommit'
11 (eval):168> alias 'grrm=git remote remove'
11 (eval):166> alias 'gstall=git stash --all'
11 (eval):164> alias 'grm=git rm'
11 (eval):163> alias 'grhh=git reset --hard'
11 (eval):156> alias 'gsb=git status -sb'
11 (eval):151> alias 'grb=git rebase'
11 (eval):150> alias 'gra=git remote add'
11 (eval):148> alias 'grs=git restore'
11 (eval):144> alias 'gpr=git pull --rebase'
11 (eval):143> alias 'grm=git rm'
11 (eval):131> alias 'gm=git merge'
11 (eval):115> alias 'gl=git pull'
11 (eval):112> alias 'gm=git merge'
11 (eval):102> alias 'gfo=git fetch origin'
11 (eval):99> alias 'gf=git fetch'
11 (eval):97> alias 'glg=git log --stat'
11 (eval):90> alias 'ghh=git help'
11 (eval):90> alias 'gcssm=git commit -S -s -m'
11 (eval):84> alias 'gg=git gui citool'
11 (eval):72> alias 'gd=git diff'
11 (eval):68> alias 'gcs=git commit -S'
11 (eval):61> alias 'gbsg=git bisect good'
11 (eval):52> alias 'gbD=git branch -D'
11 (eval):41> alias 'gbsb=git bisect bad'
11 (eval):41> alias 'gam=git am'
11 (eval):33> alias 'e=exit'
11 (eval):31> alias 'gav=git add --verbose'
11 (eval):28> alias 'drA=deno run -A'
11 (eval):24> alias 'dca=deno cache'
11 (eval):23> alias 'gama=git am --abort'
11 (eval):21> alias 'd=fasd -d'
11 (eval):20> alias 'copydir=pwd | pbcopy'
11 (eval):16> alias 'afind=ack -il'
11 (eval):16> alias 'a=fasd -a'
11 (eval):15> alias '_=sudo '
11 (eval):13> alias '8=cd -8'
11 (eval):12> alias '7=cd -7'
11 (eval):11> alias '6=cd -6'
11 (eval):10> alias '5=cd -5'
11 (eval):9> alias '4=cd -4'
11 (eval):7> alias '2=cd -2'
11 (eval):6> alias '1=cd -1'
11 (eval):3> alias -g '....=../../..'
10 is-at-least:55> part=''
10 is-at-least:55> part=''
10 is-at-least:54> ((  part < min_ver[min_cnt]  ))
10 is-at-least:54> ((  part < min_ver[min_cnt]  ))
10 is-at-least:54> ((  part < min_ver[min_cnt]  ))
10 is-at-least:54> ((  part < min_ver[min_cnt]  ))
10 is-at-least:54> ((  part < min_ver[min_cnt]  ))
10 is-at-least:53> ((  part > min_ver[min_cnt]  ))
10 is-at-least:53> ((  part > min_ver[min_cnt]  ))
10 is-at-least:53> ((  part > min_ver[min_cnt]  ))
10 is-at-least:49> ((  ++min_cnt > 4  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:49> ((  ++min_cnt > 2  ))
10 is-at-least:32> ((  ++ver_cnt > 6  ))
10 is-at-least:32> ((  ++ver_cnt > 6  ))
10 is-at-least:32> ((  ++ver_cnt > 4  ))
10 is-at-least:32> ((  ++ver_cnt > 4  ))
10 is-at-least:32> ((  ++ver_cnt > 4  ))
10 is-at-least:32> ((  ++ver_cnt > 4  ))
10 is-at-least:32> ((  ++ver_cnt > 4  ))
10 is-at-least:31> [[ '' != <-> ]]
10 is-at-least:31> [[ '' != <-> ]]
10 is-at-least:31> [[ '' != <-> ]]
10 is-at-least:31> [[ '' != <-> ]]
10 is-at-least:31> [[ '' != <-> ]]
10 is-at-least:30> ((  2 <= 4  ))
10 is-at-least:30> ((  1 <= 4  ))
10 is-at-least:30> ((  1 <= 3  ))
10 is-at-least:30> ((  1 <= 2  ))
10 is-at-least:30> ((  1 <= 2  ))
10 is-at-least:30> ((  1 <= 2  ))
10 is-at-least:30> ((  1 <= 2  ))
10 is-at-least:30> ((  1 <= 2  ))
10 complete:6> [[ -n '' ]]
10 complete:6> [[ -n '' ]]
10 compinit:506> case #compdef (#compdef)
10 compinit:506> case #compdef (#compdef)
10 compinit:506> case #compdef (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:506> case #autoload (#compdef)
10 compinit:500> _i_name=_zip
10 compinit:500> _i_name=_zftp
10 compinit:500> _i_name=_zfs_pool
10 compinit:500> _i_name=_yum
10 compinit:500> _i_name=_xterm
10 compinit:500> _i_name=_widgets
10 compinit:500> _i_name=_whois
10 compinit:500> _i_name=_who
10 compinit:500> _i_name=_vpnc
10 compinit:500> _i_name=_vnc
10 compinit:500> _i_name=_vmctl
10 compinit:500> _i_name=_vim
10 compinit:500> _i_name=_vcsh
10 compinit:500> _i_name=_vars
10 compinit:500> _i_name=_values
10 compinit:500> _i_name=_users
10 compinit:500> _i_name=_user_math_func
10 compinit:500> _i_name=_user_expand
10 compinit:500> _i_name=_unexpand
10 compinit:500> _i_name=_uname
10 compinit:500> _i_name=_umountable
10 compinit:500> _i_name=_uml
10 compinit:500> _i_name=_ulimit
10 compinit:500> _i_name=_twidge
10 compinit:500> _i_name=_ttys
10 compinit:500> _i_name=_trap
10 compinit:500> _i_name=_toilet
10 compinit:500> _i_name=_tmux
10 compinit:500> _i_name=_tla
10 compinit:500> _i_name=_tin
10 compinit:500> _i_name=_timeout
10 compinit:500> _i_name=_texinfo
10 compinit:500> _i_name=_texi
10 compinit:500> _i_name=_tex
10 compinit:500> _i_name=_terminals
10 compinit:500> _i_name=_tee
10 compinit:500> _i_name=_tcpsys
10 compinit:500> _i_name=_tcpdump
10 compinit:500> _i_name=_tar
10 compinit:500> _i_name=_tac
10 compinit:500> _i_name=_sysrc
10 compinit:500> _i_name=_swanctl
10 compinit:500> _i_name=_sw_vers
10 compinit:500> _i_name=_svcs
10 compinit:500> _i_name=_sudo
10 compinit:500> _i_name=_subversion
10 compinit:500> _i_name=_sub_commands
10 compinit:500> _i_name=_su
10 compinit:500> _i_name=_strip
10 compinit:500> _i_name=_strings
10 compinit:500> _i_name=_strftime
10 compinit:500> _i_name=_stow
10 compinit:500> _i_name=_ssh_hosts
10 compinit:500> _i_name=_ssh
10 compinit:500> _i_name=_sqsh
10 compinit:500> _i_name=_sqlite
10 compinit:500> _i_name=_spamassassin
10 compinit:500> _i_name=_source
10 compinit:500> _i_name=_socket
10 compinit:500> _i_name=_smit
10 compinit:500> _i_name=_slrn
10 compinit:500> _i_name=_slabtop
10 compinit:500> _i_name=_shutdown
10 compinit:500> _i_name=_shuf
10 compinit:500> _i_name=_shred
10 compinit:500> _i_name=_sh
10 compinit:500> _i_name=_setxkbmap
10 compinit:500> _i_name=_setup
10 compinit:500> _i_name=_setopt
10 compinit:500> _i_name=_setfacl
10 compinit:500> _i_name=_services
10 compinit:500> _i_name=_service
10 compinit:500> _i_name=_scutil
10 compinit:500> _i_name=_sched
10 compinit:500> _i_name=_sccs
10 compinit:500> _i_name=_sc_usage
10 compinit:500> _i_name=_sbuild
10 compinit:500> _i_name=_say
10 compinit:500> _i_name=_savecore
10 compinit:500> _i_name=_runit
10 compinit:500> _i_name=_run-help
10 compinit:500> _i_name=_ruby
10 compinit:500> _i_name=_rpm
10 compinit:500> _i_name=_rmdir
10 compinit:500> _i_name=_rm
10 compinit:500> _i_name=_reprepro
10 compinit:500> _i_name=_renice
10 compinit:500> _i_name=_redirect
10 compinit:500> _i_name=_readshortcut
10 compinit:500> _i_name=_readlink
10 compinit:500> _i_name=_rcs
10 compinit:500> _i_name=_rclone
10 compinit:500> _i_name=_rcctl
10 compinit:500> _i_name=_rar
10 compinit:500> _i_name=_qdbus
10 compinit:500> _i_name=_pydoc
10 compinit:500> _i_name=_pwgen
10 compinit:500> _i_name=_pv
10 compinit:500> _i_name=_pspdf
10 compinit:500> _i_name=_ps1234
10 compinit:500> _i_name=_prstat
10 compinit:500> _i_name=_prove
10 compinit:500> _i_name=_prompt
10 compinit:500> _i_name=_precommand
10 compinit:500> _i_name=_powerd
10 compinit:500> _i_name=_postfix
10 compinit:500> _i_name=_pmap
10 compinit:500> _i_name=_pkgtool
10 compinit:500> _i_name=_pkgin
10 compinit:500> _i_name=_pkgadd
10 compinit:500> _i_name=_pkg5
10 compinit:500> _i_name=_pkg-config
10 compinit:500> _i_name=_ping
10 compinit:500> _i_name=_pids
10 compinit:500> _i_name=_pfctl
10 compinit:500> _i_name=_pbcopy
10 compinit:500> _i_name=_path_files
10 compinit:500> _i_name=_patch
10 compinit:500> _i_name=_pandoc
10 compinit:500> _i_name=_otool
10 compinit:500> _i_name=_osc
10 compinit:500> _i_name=_okular
10 compinit:500> _i_name=_numfmt
10 compinit:500> _i_name=_npm
10 compinit:500> _i_name=_nothing
10 compinit:500> _i_name=_normal
10 compinit:500> _i_name=_nice
10 compinit:500> _i_name=_myrepos
10 compinit:500> _i_name=_mv
10 compinit:500> _i_name=_mozilla
10 compinit:500> _i_name=_mkfifo
10 compinit:500> _i_name=_mh
10 compinit:500> _i_name=_message
10 compinit:500> _i_name=_mail
10 compinit:500> _i_name=_lzop
10 compinit:500> _i_name=_locate
10 compinit:500> _i_name=_links
10 compinit:500> _i_name=_libvirt
10 compinit:500> _i_name=_lha
10 compinit:500> _i_name=_ld_debug
10 compinit:500> _i_name=_jrnl
10 compinit:500> _i_name=_jot
10 compinit:500> _i_name=_joe
10 compinit:500> _i_name=_ipset
10 compinit:500> _i_name=_ip
10 compinit:500> _i_name=_iostat
10 compinit:500> _i_name=_init_d
10 compinit:500> _i_name=_iftop
10 compinit:500> _i_name=_httpie
10 compinit:500> _i_name=_groff
10 compinit:500> _i_name=_gpg
10 compinit:500> _i_name=_golang
10 compinit:500> _i_name=_go
10 compinit:500> _i_name=_gnupod
10 compinit:500> _i_name=_global
10 compinit:500> _i_name=_glances
10 compinit:500> _i_name=_geany
10 compinit:500> _i_name=_gcore
10 compinit:500> _i_name=_gcc
10 compinit:500> _i_name=_fwupdmgr
10 compinit:500> _i_name=_flac
10 compinit:500> _i_name=_first
10 compinit:500> _i_name=_file_modes
10 compinit:500> _i_name=_ffmpeg
10 compinit:500> _i_name=_ffind
10 compinit:500> _i_name=_docker
10 compinit:500> _i_name=_deno
10 compinit:500> _i_name=_correct
10 compinit:500> _i_name=_conan
10 compinit:500> _i_name=_compress
10 compinit:500> _i_name=_cheat
10 compinit:500> _i_name=_cf
10 compinit:500> _i_name=_cap
10 compinit:500> _i_name=_bsdinstall
10 compinit:500> _i_name=_bpython
10 compinit:500> _i_name=_bittorrent
10 compinit:500> _i_name=_bison
10 compinit:500> _i_name=_be_name
10 compinit:500> _i_name=_basename
10 compinit:500> _i_name=_aws
10 compinit:500> _i_name=_at
10 compinit:500> _i_name=_asdf
10 compinit:500> _i_name=_arch_namespace
10 compinit:500> _i_name=_all_matches
10 compinit:500> _i_name=_adb
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zparseopts
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zfs_keysource_props
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_watch
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_wanna-build
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_user_math_func
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_user_expand
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_trash
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tmux
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_tail
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sysctl
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_svn-buildpackage
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sqlite
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_slrn
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sisu
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_signify
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_setfacl
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_service
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sep_parts
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_selinux_types
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_selinux_roles
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sed
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ri
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_retrieve_mac_apps
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_renice
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_remote_files
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_python_modules
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_portsnap
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkgadd
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pkg_instance
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_perl_modules
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_parameters
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_obsd_architectures
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_next_label
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ncftp
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mupdf
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_modutils
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mixerctl
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mh
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mere
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_make
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_main_complete
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_madison
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_mac_files_for_application
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_look
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_jexec
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gnupod
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_gnome-gv
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_globquals
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_globqual_delims
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_genisoimage
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fuser
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fuse_values
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_flowadm
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_findmnt
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_files
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_file_modes
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fc
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fbsd_device_types
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_fakeroot
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_external_pwds
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_e2label
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_doas
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_correct_filename
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_composer
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_compadd
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_comp_locale
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arguments
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_arch_namespace
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_apt
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_analyseplugin
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_alsa-utils
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_all_matches
10 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_ack
10 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
10 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
10 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
10 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/completions
10 compinit:186> compprefuncs=( )
10 compinit:77> case -i (-d)
10 compinit:77> case -d (-d)
10 compinit:77> case -C (-d)
10 compdump:116> ((  ! --_i && 1085 > 1  ))
10 compdump:116> ((  ! --_i && 1070 > 1  ))
10 compdump:116> ((  ! --_i && 1065 > 1  ))
10 compdump:116> ((  ! --_i && 1035 > 1  ))
10 compdump:116> ((  ! --_i && 959 > 1  ))
10 compdump:116> ((  ! --_i && 954 > 1  ))
10 compdump:116> ((  ! --_i && 944 > 1  ))
10 compdump:116> ((  ! --_i && 939 > 1  ))
10 compdump:116> ((  ! --_i && 934 > 1  ))
10 compdump:116> ((  ! --_i && 929 > 1  ))
10 compdump:116> ((  ! --_i && 919 > 1  ))
10 compdump:116> ((  ! --_i && 914 > 1  ))
10 compdump:116> ((  ! --_i && 909 > 1  ))
10 compdump:116> ((  ! --_i && 904 > 1  ))
10 compdump:116> ((  ! --_i && 899 > 1  ))
10 compdump:116> ((  ! --_i && 894 > 1  ))
10 compdump:116> ((  ! --_i && 889 > 1  ))
10 compdump:116> ((  ! --_i && 879 > 1  ))
10 compdump:116> ((  ! --_i && 834 > 1  ))
10 compdump:116> ((  ! --_i && 829 > 1  ))
10 compdump:116> ((  ! --_i && 809 > 1  ))
10 compdump:116> ((  ! --_i && 789 > 1  ))
10 compdump:116> ((  ! --_i && 764 > 1  ))
10 compdump:116> ((  ! --_i && 759 > 1  ))
10 compdump:116> ((  ! --_i && 744 > 1  ))
10 compdump:116> ((  ! --_i && 739 > 1  ))
10 compdump:116> ((  ! --_i && 724 > 1  ))
10 compdump:116> ((  ! --_i && 704 > 1  ))
10 compdump:116> ((  ! --_i && 689 > 1  ))
10 compdump:116> ((  ! --_i && 679 > 1  ))
10 compdump:116> ((  ! --_i && 674 > 1  ))
10 compdump:116> ((  ! --_i && 669 > 1  ))
10 compdump:116> ((  ! --_i && 659 > 1  ))
10 compdump:116> ((  ! --_i && 654 > 1  ))
10 compdump:116> ((  ! --_i && 649 > 1  ))
10 compdump:116> ((  ! --_i && 644 > 1  ))
10 compdump:116> ((  ! --_i && 639 > 1  ))
10 compdump:116> ((  ! --_i && 624 > 1  ))
10 compdump:116> ((  ! --_i && 609 > 1  ))
10 compdump:116> ((  ! --_i && 599 > 1  ))
10 compdump:116> ((  ! --_i && 594 > 1  ))
10 compdump:116> ((  ! --_i && 589 > 1  ))
10 compdump:116> ((  ! --_i && 584 > 1  ))
10 compdump:116> ((  ! --_i && 574 > 1  ))
10 compdump:116> ((  ! --_i && 569 > 1  ))
10 compdump:116> ((  ! --_i && 559 > 1  ))
10 compdump:116> ((  ! --_i && 554 > 1  ))
10 compdump:116> ((  ! --_i && 539 > 1  ))
10 compdump:116> ((  ! --_i && 534 > 1  ))
10 compdump:116> ((  ! --_i && 509 > 1  ))
10 compdump:116> ((  ! --_i && 504 > 1  ))
10 compdump:116> ((  ! --_i && 499 > 1  ))
10 compdump:116> ((  ! --_i && 494 > 1  ))
10 compdump:116> ((  ! --_i && 489 > 1  ))
10 compdump:116> ((  ! --_i && 484 > 1  ))
10 compdump:116> ((  ! --_i && 479 > 1  ))
10 compdump:116> ((  ! --_i && 474 > 1  ))
10 compdump:116> ((  ! --_i && 469 > 1  ))
10 compdump:116> ((  ! --_i && 464 > 1  ))
10 compdump:116> ((  ! --_i && 459 > 1  ))
10 compdump:116> ((  ! --_i && 454 > 1  ))
10 compdump:116> ((  ! --_i && 449 > 1  ))
10 compdump:116> ((  ! --_i && 444 > 1  ))
10 compdump:116> ((  ! --_i && 434 > 1  ))
10 compdump:116> ((  ! --_i && 429 > 1  ))
10 compdump:116> ((  ! --_i && 424 > 1  ))
10 compdump:116> ((  ! --_i && 419 > 1  ))
10 compdump:116> ((  ! --_i && 414 > 1  ))
10 compdump:116> ((  ! --_i && 404 > 1  ))
10 compdump:116> ((  ! --_i && 399 > 1  ))
10 compdump:116> ((  ! --_i && 394 > 1  ))
10 compdump:116> ((  ! --_i && 389 > 1  ))
10 compdump:116> ((  ! --_i && 384 > 1  ))
10 compdump:116> ((  ! --_i && 359 > 1  ))
10 compdump:116> ((  ! --_i && 354 > 1  ))
10 compdump:116> ((  ! --_i && 349 > 1  ))
10 compdump:116> ((  ! --_i && 339 > 1  ))
10 compdump:116> ((  ! --_i && 334 > 1  ))
10 compdump:116> ((  ! --_i && 324 > 1  ))
10 compdump:116> ((  ! --_i && 314 > 1  ))
10 compdump:116> ((  ! --_i && 309 > 1  ))
10 compdump:116> ((  ! --_i && 304 > 1  ))
10 compdump:116> ((  ! --_i && 294 > 1  ))
10 compdump:116> ((  ! --_i && 289 > 1  ))
10 compdump:116> ((  ! --_i && 284 > 1  ))
10 compdump:116> ((  ! --_i && 269 > 1  ))
10 compdump:116> ((  ! --_i && 259 > 1  ))
10 compdump:116> ((  ! --_i && 254 > 1  ))
10 compdump:116> ((  ! --_i && 244 > 1  ))
10 compdump:116> ((  ! --_i && 239 > 1  ))
10 compdump:116> ((  ! --_i && 234 > 1  ))
10 compdump:116> ((  ! --_i && 229 > 1  ))
10 compdump:116> ((  ! --_i && 214 > 1  ))
10 compdump:116> ((  ! --_i && 209 > 1  ))
10 compdump:116> ((  ! --_i && 204 > 1  ))
10 compdump:116> ((  ! --_i && 199 > 1  ))
10 compdump:116> ((  ! --_i && 189 > 1  ))
10 compdump:116> ((  ! --_i && 184 > 1  ))
10 compdump:116> ((  ! --_i && 174 > 1  ))
10 compdump:116> ((  ! --_i && 164 > 1  ))
10 compdump:116> ((  ! --_i && 159 > 1  ))
10 compdump:116> ((  ! --_i && 154 > 1  ))
10 compdump:116> ((  ! --_i && 149 > 1  ))
10 compdump:116> ((  ! --_i && 139 > 1  ))
10 compdump:116> ((  ! --_i && 134 > 1  ))
10 compdump:116> ((  ! --_i && 124 > 1  ))
10 compdump:116> ((  ! --_i && 119 > 1  ))
10 compdump:116> ((  ! --_i && 114 > 1  ))
10 compdump:116> ((  ! --_i && 109 > 1  ))
10 compdump:116> ((  ! --_i && 104 > 1  ))
10 compdump:116> ((  ! --_i && 99 > 1  ))
10 compdump:116> ((  ! --_i && 94 > 1  ))
10 compdump:116> ((  ! --_i && 89 > 1  ))
10 compdump:116> ((  ! --_i && 84 > 1  ))
10 compdump:116> ((  ! --_i && 74 > 1  ))
10 compdump:116> ((  ! --_i && 59 > 1  ))
10 compdump:116> ((  ! --_i && 54 > 1  ))
10 compdump:116> ((  ! --_i && 49 > 1  ))
10 compdump:116> ((  ! --_i && 39 > 1  ))
10 compdump:116> ((  ! --_i && 34 > 1  ))
10 compdump:116> ((  ! --_i && 24 > 1  ))
10 compdump:116> ((  ! --_i && 19 > 1  ))
10 compdump:113> ((  1085  ))
10 compdump:113> ((  1078  ))
10 compdump:113> ((  1077  ))
10 compdump:113> ((  1071  ))
10 compdump:113> ((  1061  ))
10 compdump:113> ((  1060  ))
10 compdump:113> ((  1058  ))
10 compdump:113> ((  1044  ))
10 compdump:113> ((  1043  ))
10 compdump:113> ((  1042  ))
10 compdump:113> ((  1015  ))
10 compdump:113> ((  1000  ))
10 compdump:113> ((  998  ))
10 compdump:113> ((  988  ))
10 compdump:113> ((  972  ))
10 compdump:113> ((  965  ))
10 compdump:113> ((  963  ))
10 compdump:113> ((  962  ))
10 compdump:113> ((  960  ))
10 compdump:113> ((  955  ))
10 compdump:113> ((  952  ))
10 compdump:113> ((  948  ))
10 compdump:113> ((  944  ))
10 compdump:113> ((  942  ))
10 compdump:113> ((  940  ))
10 compdump:113> ((  937  ))
10 compdump:113> ((  935  ))
10 compdump:113> ((  934  ))
10 compdump:113> ((  933  ))
10 compdump:113> ((  928  ))
10 compdump:113> ((  927  ))
10 compdump:113> ((  915  ))
10 compdump:113> ((  907  ))
10 compdump:113> ((  899  ))
10 compdump:113> ((  898  ))
10 compdump:113> ((  897  ))
10 compdump:113> ((  896  ))
10 compdump:113> ((  895  ))
10 compdump:113> ((  892  ))
10 compdump:113> ((  890  ))
10 compdump:113> ((  887  ))
10 compdump:113> ((  884  ))
10 compdump:113> ((  883  ))
10 compdump:113> ((  881  ))
10 compdump:113> ((  878  ))
10 compdump:113> ((  854  ))
10 compdump:113> ((  849  ))
10 compdump:113> ((  831  ))
10 compdump:113> ((  820  ))
10 compdump:113> ((  789  ))
10 compdump:113> ((  783  ))
10 compdump:113> ((  769  ))
10 compdump:113> ((  764  ))
10 compdump:113> ((  763  ))
10 compdump:113> ((  761  ))
10 compdump:113> ((  760  ))
10 compdump:113> ((  758  ))
10 compdump:113> ((  757  ))
10 compdump:113> ((  751  ))
10 compdump:113> ((  740  ))
10 compdump:113> ((  734  ))
10 compdump:113> ((  728  ))
10 compdump:113> ((  727  ))
10 compdump:113> ((  726  ))
10 compdump:113> ((  720  ))
10 compdump:113> ((  716  ))
10 compdump:113> ((  712  ))
10 compdump:113> ((  711  ))
10 compdump:113> ((  710  ))
10 compdump:113> ((  703  ))
10 compdump:113> ((  701  ))
10 compdump:113> ((  698  ))
10 compdump:113> ((  697  ))
10 compdump:113> ((  692  ))
10 compdump:113> ((  690  ))
10 compdump:113> ((  689  ))
10 compdump:113> ((  688  ))
10 compdump:113> ((  686  ))
10 compdump:113> ((  682  ))
10 compdump:113> ((  679  ))
10 compdump:113> ((  675  ))
10 compdump:113> ((  674  ))
10 compdump:113> ((  673  ))
10 compdump:113> ((  670  ))
10 compdump:113> ((  667  ))
10 compdump:113> ((  666  ))
10 compdump:113> ((  665  ))
10 compdump:113> ((  661  ))
10 compdump:113> ((  660  ))
10 compdump:113> ((  652  ))
10 compdump:113> ((  651  ))
10 compdump:113> ((  646  ))
10 compdump:113> ((  645  ))
10 compdump:113> ((  644  ))
10 compdump:113> ((  642  ))
10 compdump:113> ((  639  ))
10 compdump:113> ((  637  ))
10 compdump:113> ((  632  ))
10 compdump:113> ((  630  ))
10 compdump:113> ((  628  ))
10 compdump:113> ((  627  ))
10 compdump:113> ((  626  ))
10 compdump:113> ((  623  ))
10 compdump:113> ((  621  ))
10 compdump:113> ((  620  ))
10 compdump:113> ((  619  ))
10 compdump:113> ((  618  ))
10 compdump:113> ((  616  ))
10 compdump:113> ((  615  ))
10 compdump:113> ((  614  ))
10 compdump:113> ((  613  ))
10 compdump:113> ((  612  ))
10 compdump:113> ((  609  ))
10 compdump:113> ((  608  ))
10 compdump:113> ((  606  ))
10 compdump:113> ((  601  ))
10 compdump:113> ((  600  ))
10 compdump:113> ((  598  ))
10 compdump:113> ((  594  ))
10 compdump:113> ((  593  ))
10 compdump:113> ((  589  ))
10 compdump:113> ((  579  ))
10 compdump:113> ((  577  ))
10 compdump:113> ((  576  ))
10 compdump:113> ((  569  ))
10 compdump:113> ((  568  ))
10 compdump:113> ((  567  ))
10 compdump:113> ((  565  ))
10 compdump:113> ((  564  ))
10 compdump:113> ((  563  ))
10 compdump:113> ((  562  ))
10 compdump:113> ((  561  ))
10 compdump:113> ((  557  ))
10 compdump:113> ((  556  ))
10 compdump:113> ((  549  ))
10 compdump:113> ((  543  ))
10 compdump:113> ((  542  ))
10 compdump:113> ((  539  ))
10 compdump:113> ((  535  ))
10 compdump:113> ((  529  ))
10 compdump:113> ((  526  ))
10 compdump:113> ((  525  ))
10 compdump:113> ((  520  ))
10 compdump:113> ((  517  ))
10 compdump:113> ((  508  ))
10 compdump:113> ((  505  ))
10 compdump:113> ((  504  ))
10 compdump:113> ((  500  ))
10 compdump:113> ((  497  ))
10 compdump:113> ((  496  ))
10 compdump:113> ((  494  ))
10 compdump:113> ((  493  ))
10 compdump:113> ((  490  ))
10 compdump:113> ((  487  ))
10 compdump:113> ((  479  ))
10 compdump:113> ((  477  ))
10 compdump:113> ((  476  ))
10 compdump:113> ((  474  ))
10 compdump:113> ((  473  ))
10 compdump:113> ((  472  ))
10 compdump:113> ((  470  ))
10 compdump:113> ((  469  ))
10 compdump:113> ((  468  ))
10 compdump:113> ((  465  ))
10 compdump:113> ((  461  ))
10 compdump:113> ((  454  ))
10 compdump:113> ((  452  ))
10 compdump:113> ((  450  ))
10 compdump:113> ((  449  ))
10 compdump:113> ((  447  ))
10 compdump:113> ((  446  ))
10 compdump:113> ((  444  ))
10 compdump:113> ((  440  ))
10 compdump:113> ((  436  ))
10 compdump:113> ((  435  ))
10 compdump:113> ((  434  ))
10 compdump:113> ((  433  ))
10 compdump:113> ((  431  ))
10 compdump:113> ((  430  ))
10 compdump:113> ((  427  ))
10 compdump:113> ((  424  ))
10 compdump:113> ((  422  ))
10 compdump:113> ((  420  ))
10 compdump:113> ((  415  ))
10 compdump:113> ((  413  ))
10 compdump:113> ((  412  ))
10 compdump:113> ((  410  ))
10 compdump:113> ((  407  ))
10 compdump:113> ((  406  ))
10 compdump:113> ((  405  ))
10 compdump:113> ((  404  ))
10 compdump:113> ((  403  ))
10 compdump:113> ((  402  ))
10 compdump:113> ((  401  ))
10 compdump:113> ((  400  ))
10 compdump:113> ((  399  ))
10 compdump:113> ((  398  ))
10 compdump:113> ((  397  ))
10 compdump:113> ((  395  ))
10 compdump:113> ((  394  ))
10 compdump:113> ((  393  ))
10 compdump:113> ((  392  ))
10 compdump:113> ((  391  ))
10 compdump:113> ((  390  ))
10 compdump:113> ((  387  ))
10 compdump:113> ((  385  ))
10 compdump:113> ((  383  ))
10 compdump:113> ((  381  ))
10 compdump:113> ((  380  ))
10 compdump:113> ((  379  ))
10 compdump:113> ((  377  ))
10 compdump:113> ((  375  ))
10 compdump:113> ((  366  ))
10 compdump:113> ((  365  ))
10 compdump:113> ((  364  ))
10 compdump:113> ((  359  ))
10 compdump:113> ((  353  ))
10 compdump:113> ((  351  ))
10 compdump:113> ((  349  ))
10 compdump:113> ((  347  ))
10 compdump:113> ((  338  ))
10 compdump:113> ((  336  ))
10 compdump:113> ((  335  ))
10 compdump:113> ((  333  ))
10 compdump:113> ((  326  ))
10 compdump:113> ((  322  ))
10 compdump:113> ((  320  ))
10 compdump:113> ((  319  ))
10 compdump:113> ((  317  ))
10 compdump:113> ((  316  ))
10 compdump:113> ((  315  ))
10 compdump:113> ((  314  ))
10 compdump:113> ((  312  ))
10 compdump:113> ((  310  ))
10 compdump:113> ((  309  ))
10 compdump:113> ((  308  ))
10 compdump:113> ((  307  ))
10 compdump:113> ((  306  ))
10 compdump:113> ((  305  ))
10 compdump:113> ((  301  ))
10 compdump:113> ((  300  ))
10 compdump:113> ((  297  ))
10 compdump:113> ((  296  ))
10 compdump:113> ((  295  ))
10 compdump:113> ((  294  ))
10 compdump:113> ((  293  ))
10 compdump:113> ((  291  ))
10 compdump:113> ((  287  ))
10 compdump:113> ((  282  ))
10 compdump:113> ((  281  ))
10 compdump:113> ((  280  ))
10 compdump:113> ((  279  ))
10 compdump:113> ((  277  ))
10 compdump:113> ((  270  ))
10 compdump:113> ((  266  ))
10 compdump:113> ((  261  ))
10 compdump:113> ((  259  ))
10 compdump:113> ((  258  ))
10 compdump:113> ((  254  ))
10 compdump:113> ((  250  ))
10 compdump:113> ((  249  ))
10 compdump:113> ((  247  ))
10 compdump:113> ((  243  ))
10 compdump:113> ((  242  ))
10 compdump:113> ((  239  ))
10 compdump:113> ((  238  ))
10 compdump:113> ((  236  ))
10 compdump:113> ((  235  ))
10 compdump:113> ((  233  ))
10 compdump:113> ((  232  ))
10 compdump:113> ((  231  ))
10 compdump:113> ((  230  ))
10 compdump:113> ((  229  ))
10 compdump:113> ((  227  ))
10 compdump:113> ((  226  ))
10 compdump:113> ((  225  ))
10 compdump:113> ((  220  ))
10 compdump:113> ((  218  ))
10 compdump:113> ((  217  ))
10 compdump:113> ((  216  ))
10 compdump:113> ((  215  ))
10 compdump:113> ((  214  ))
10 compdump:113> ((  212  ))
10 compdump:113> ((  211  ))
10 compdump:113> ((  210  ))
10 compdump:113> ((  208  ))
10 compdump:113> ((  207  ))
10 compdump:113> ((  205  ))
10 compdump:113> ((  197  ))
10 compdump:113> ((  196  ))
10 compdump:113> ((  195  ))
10 compdump:113> ((  194  ))
10 compdump:113> ((  193  ))
10 compdump:113> ((  192  ))
10 compdump:113> ((  191  ))
10 compdump:113> ((  190  ))
10 compdump:113> ((  189  ))
10 compdump:113> ((  185  ))
10 compdump:113> ((  184  ))
10 compdump:113> ((  183  ))
10 compdump:113> ((  182  ))
10 compdump:113> ((  180  ))
10 compdump:113> ((  179  ))
10 compdump:113> ((  178  ))
10 compdump:113> ((  177  ))
10 compdump:113> ((  176  ))
10 compdump:113> ((  175  ))
10 compdump:113> ((  171  ))
10 compdump:113> ((  170  ))
10 compdump:113> ((  168  ))
10 compdump:113> ((  167  ))
10 compdump:113> ((  166  ))
10 compdump:113> ((  165  ))
10 compdump:113> ((  164  ))
10 compdump:113> ((  163  ))
10 compdump:113> ((  162  ))
10 compdump:113> ((  161  ))
10 compdump:113> ((  160  ))
10 compdump:113> ((  159  ))
10 compdump:113> ((  158  ))
10 compdump:113> ((  157  ))
10 compdump:113> ((  155  ))
10 compdump:113> ((  154  ))
10 compdump:113> ((  153  ))
10 compdump:113> ((  152  ))
10 compdump:113> ((  150  ))
10 compdump:113> ((  148  ))
10 compdump:113> ((  147  ))
10 compdump:113> ((  146  ))
10 compdump:113> ((  145  ))
10 compdump:113> ((  142  ))
10 compdump:113> ((  141  ))
10 compdump:113> ((  140  ))
10 compdump:113> ((  139  ))
10 compdump:113> ((  138  ))
10 compdump:113> ((  137  ))
10 compdump:113> ((  136  ))
10 compdump:113> ((  134  ))
10 compdump:113> ((  133  ))
10 compdump:113> ((  131  ))
10 compdump:113> ((  130  ))
10 compdump:113> ((  129  ))
10 compdump:113> ((  127  ))
10 compdump:113> ((  124  ))
10 compdump:113> ((  123  ))
10 compdump:113> ((  122  ))
10 compdump:113> ((  120  ))
10 compdump:113> ((  119  ))
10 compdump:113> ((  118  ))
10 compdump:113> ((  117  ))
10 compdump:113> ((  116  ))
10 compdump:113> ((  115  ))
10 compdump:113> ((  113  ))
10 compdump:113> ((  111  ))
10 compdump:113> ((  110  ))
10 compdump:113> ((  109  ))
10 compdump:113> ((  108  ))
10 compdump:113> ((  107  ))
10 compdump:113> ((  106  ))
10 compdump:113> ((  105  ))
10 compdump:113> ((  103  ))
10 compdump:113> ((  102  ))
10 compdump:113> ((  101  ))
10 compdump:113> ((  100  ))
10 compdump:113> ((  98  ))
10 compdump:113> ((  97  ))
10 compdump:113> ((  96  ))
10 compdump:113> ((  95  ))
10 compdump:113> ((  94  ))
10 compdump:113> ((  93  ))
10 compdump:113> ((  92  ))
10 compdump:113> ((  91  ))
10 compdump:113> ((  89  ))
10 compdump:113> ((  87  ))
10 compdump:113> ((  86  ))
10 compdump:113> ((  85  ))
10 compdump:113> ((  84  ))
10 compdump:113> ((  83  ))
10 compdump:113> ((  82  ))
10 compdump:113> ((  81  ))
10 compdump:113> ((  80  ))
10 compdump:113> ((  79  ))
10 compdump:113> ((  78  ))
10 compdump:113> ((  77  ))
10 compdump:113> ((  76  ))
10 compdump:113> ((  73  ))
10 compdump:113> ((  72  ))
10 compdump:113> ((  71  ))
10 compdump:113> ((  70  ))
10 compdump:113> ((  69  ))
10 compdump:113> ((  68  ))
10 compdump:113> ((  67  ))
10 compdump:113> ((  66  ))
10 compdump:113> ((  65  ))
10 compdump:113> ((  64  ))
10 compdump:113> ((  61  ))
10 compdump:113> ((  60  ))
10 compdump:113> ((  59  ))
10 compdump:113> ((  58  ))
10 compdump:113> ((  57  ))
10 compdump:113> ((  56  ))
10 compdump:113> ((  55  ))
10 compdump:113> ((  54  ))
10 compdump:113> ((  53  ))
10 compdump:113> ((  52  ))
10 compdump:113> ((  49  ))
10 compdump:113> ((  48  ))
10 compdump:113> ((  47  ))
10 compdump:113> ((  44  ))
10 compdump:113> ((  43  ))
10 compdump:113> ((  42  ))
10 compdump:113> ((  40  ))
10 compdump:113> ((  39  ))
10 compdump:113> ((  38  ))
10 compdump:113> ((  36  ))
10 compdump:113> ((  35  ))
10 compdump:113> ((  34  ))
10 compdump:113> ((  32  ))
10 compdump:113> ((  31  ))
10 compdump:113> ((  30  ))
10 compdump:113> ((  29  ))
10 compdump:113> ((  28  ))
10 compdump:113> ((  26  ))
10 compdump:113> ((  25  ))
10 compdump:113> ((  22  ))
10 compdump:113> ((  21  ))
10 compdump:113> ((  19  ))
10 compdump:113> ((  18  ))
10 compdump:113> ((  17  ))
10 compdump:113> ((  16  ))
10 compdump:113> ((  14  ))
10 compdump:113> ((  12  ))
10 compdump:113> ((  11  ))
10 compdump:113> ((  10  ))
10 compdump:113> ((  8  ))
10 compdump:113> ((  6  ))
10 compdump:113> ((  3  ))
10 compdump:113> ((  2  ))
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:164> [[ -n yes ]]
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:160> svc=''
10 compdef:159> cmd=ztodo
10 compdef:159> cmd=zsetattr
10 compdef:159> cmd=zpool
10 compdef:159> cmd=zmv
10 compdef:159> cmd=zip
10 compdef:159> cmd=zgetattr
10 compdef:159> cmd=zdump
10 compdef:159> cmd=zcp
10 compdef:159> cmd=zcat
10 compdef:159> cmd=zcalc
10 compdef:159> cmd=yumdb
10 compdef:159> cmd=yppush
10 compdef:159> cmd=yppasswd
10 compdef:159> cmd=ypcat
10 compdef:159> cmd=yast2
10 compdef:159> cmd=yash
10 compdef:159> cmd=yafc
10 compdef:159> cmd=xwit
10 compdef:159> cmd=xwd
10 compdef:159> cmd=xview
10 compdef:159> cmd=xv
10 compdef:159> cmd=xtp
10 compdef:159> cmd=xtightvncviewer
10 compdef:159> cmd=xsetbg
10 compdef:159> cmd=xset
10 compdef:159> cmd=xsel
10 compdef:159> cmd=xscreensaver-command
10 compdef:159> cmd=xrandr
10 compdef:159> cmd=xpdf
10 compdef:159> cmd=xournal
10 compdef:159> cmd=xon
10 compdef:159> cmd=xmosaic
10 compdef:159> cmd=xmms2
10 compdef:159> cmd=xml
10 compdef:159> cmd=xhost
10 compdef:159> cmd=xfontsel
10 compdef:159> cmd=xfd
10 compdef:159> cmd=xev
10 compdef:159> cmd=xattr
10 compdef:159> cmd=www
10 compdef:159> cmd=wipefs
10 compdef:159> cmd=whois
10 compdef:159> cmd=which
10 compdef:159> cmd=whence
10 compdef:159> cmd=whatis
10 compdef:159> cmd=wget
10 compdef:159> cmd=watcher
10 compdef:159> cmd=wanna-build
10 compdef:159> cmd=wait
10 compdef:159> cmd=vserver
10 compdef:159> cmd=vpnc-connect
10 compdef:159> cmd=vpnc
10 compdef:159> cmd=vncserver
10 compdef:159> cmd=vmstat
10 compdef:159> cmd=vitrage
10 compdef:159> cmd=virt-xml-validate
10 compdef:159> cmd=virt-host-validate
10 compdef:159> cmd=virt-admin
10 compdef:159> cmd=virsh
10 compdef:159> cmd=vcsh
10 compdef:159> cmd=vared
10 compdef:159> cmd=vacuumdb
10 compdef:159> cmd=vacuumdb
10 compdef:159> cmd=uscan
10 compdef:159> cmd=urpmi.removemedia
10 compdef:159> cmd=urpmi.addmedia
10 compdef:159> cmd=urpme
10 compdef:159> cmd=uptime
10 compdef:159> cmd=upgradepkg
10 compdef:159> cmd=update-rc.d
10 compdef:159> cmd=unzip
10 compdef:159> cmd=unrar
10 compdef:159> cmd=unpigz
10 compdef:159> cmd=unpack
10 compdef:159> cmd=units
10 compdef:159> cmd=unison
10 compdef:159> cmd=uniq
10 compdef:159> cmd=unhash
10 compdef:159> cmd=unfunction
10 compdef:159> cmd=unalias
10 compdef:159> cmd=umount
10 compdef:159> cmd=uml_switch
10 compdef:159> cmd=uml_moo
10 compdef:159> cmd=ufw
10 compdef:159> cmd=udisksctl
10 compdef:159> cmd=type
10 compdef:159> cmd=ttyctl
10 compdef:159> cmd=tty
10 compdef:159> cmd=truss
10 compdef:159> cmd=true
10 compdef:159> cmd=tree
10 compdef:159> cmd=trap
10 compdef:159> cmd=transmission-remote
10 compdef:159> cmd=traceroute
10 compdef:159> cmd=tracepath
10 compdef:159> cmd=tr
10 compdef:159> cmd=tput
10 compdef:159> cmd=tpkg-install-libc
10 compdef:159> cmd=tpb
10 compdef:159> cmd=toilet
10 compdef:159> cmd=todo.sh
10 compdef:159> cmd=tkinfo
10 compdef:159> cmd=tin
10 compdef:159> cmd=times
10 compdef:159> cmd=time
10 compdef:159> cmd=texi2dvi
10 compdef:159> cmd=tcsh
10 compdef:159> cmd=tar
10 compdef:159> cmd=tac
10 compdef:159> cmd=sysctl
10 compdef:159> cmd=swiftc
10 compdef:159> cmd=swanctl
10 compdef:159> cmd=swaks
10 compdef:159> cmd=sw_vers
10 compdef:159> cmd=svnadmin
10 compdef:159> cmd=svn-buildpackage
10 compdef:159> cmd=svn
10 compdef:159> cmd=svcprop
10 compdef:159> cmd=surfraw
10 compdef:159> cmd=subliminal
10 compdef:159> cmd=strongswan
10 compdef:159> cmd=stop
10 compdef:159> cmd=status
10 compdef:159> cmd=star
10 compdef:159> cmd=ssh-keyscan
10 compdef:159> cmd=ssh-keygen
10 compdef:159> cmd=ssh-agent
10 compdef:159> cmd=ss
10 compdef:159> cmd=sqlite3
10 compdef:159> cmd=sqlite
10 compdef:159> cmd=spamassassin
10 compdef:159> cmd=sort
10 compdef:159> cmd=sockstat
10 compdef:159> cmd=smbcontrol
10 compdef:159> cmd=skein256
10 compdef:159> cmd=shutdown
10 compdef:159> cmd=show
10 compdef:159> cmd=shift
10 compdef:159> cmd=sha512t256
10 compdef:159> cmd=sha384
10 compdef:159> cmd=sha256
10 compdef:159> cmd=sha1
10 compdef:159> cmd=setfacl
10 compdef:159> cmd=scutil
10 compdef:159> cmd=scriptreplay
10 compdef:159> cmd=script
10 compdef:159> cmd=screen
10 compdef:159> cmd=scons
10 compdef:159> cmd=schedtool
10 compdef:159> cmd=sched
10 compdef:159> cmd=sccs
10 compdef:159> cmd=sbuild
10 compdef:159> cmd=savecore
10 compdef:159> cmd=sar
10 compdef:159> cmd=sact
10 compdef:159> cmd=s2p
10 compdef:159> cmd=ruby
10 compdef:159> cmd=rubber
10 compdef:159> cmd=rsh
10 compdef:159> cmd=rrdtool
10 compdef:159> cmd=rpmverify
10 compdef:159> cmd=rpmbuild
10 compdef:159> cmd=rpm
10 compdef:159> cmd=route
10 compdef:159> cmd=rmid
10 compdef:159> cmd=rmic
10 compdef:159> cmd=rmadison
10 compdef:159> cmd=reprepro
10 compdef:159> cmd=reportbug
10 compdef:159> cmd=renice
10 compdef:159> cmd=reload
10 compdef:159> cmd=reindexdb
10 compdef:159> cmd=readonly
10 compdef:159> cmd=rcp
10 compdef:159> cmd=rcctl
10 compdef:159> cmd=rake
10 compdef:159> cmd=quilt
10 compdef:159> cmd=querybts
10 compdef:159> cmd=qdbus
10 compdef:159> cmd=ptree
10 compdef:159> cmd=pstotgif
10 compdef:159> cmd=pstop
10 compdef:159> cmd=psresize
10 compdef:159> cmd=pscp.exe
10 compdef:159> cmd=pscp
10 compdef:159> cmd=ps2ps
10 compdef:159> cmd=ps2pdf13
10 compdef:159> cmd=ps2pdf
10 compdef:159> cmd=prstat
10 compdef:159> cmd=procstat
10 compdef:159> cmd=print
10 compdef:159> cmd=prev
10 compdef:159> cmd=postgres
10 compdef:159> cmd=postconf
10 compdef:159> cmd=portmaster
10 compdef:159> cmd=portaudit
10 compdef:159> cmd=pon
10 compdef:159> cmd=podtoc
10 compdef:159> cmd=podpath
10 compdef:159> cmd=pmpath
10 compdef:159> cmd=pmls
10 compdef:159> cmd=pmap
10 compdef:159> cmd=pkgrm
10 compdef:159> cmd=pkginfo
10 compdef:159> cmd=pkgin
10 compdef:159> cmd=pkg_info
10 compdef:159> cmd=pkg_delete
10 compdef:159> cmd=pkg_create
10 compdef:159> cmd=pkg_add
10 compdef:159> cmd=pkcon
10 compdef:159> cmd=pixz
10 compdef:159> cmd=ping
10 compdef:159> cmd=pinfo
10 compdef:159> cmd=pigz
10 compdef:159> cmd=pidof
10 compdef:159> cmd=php
10 compdef:159> cmd=pg_restore
10 compdef:159> cmd=pg_dump
10 compdef:159> cmd=pg_config
10 compdef:159> cmd=perldoc
10 compdef:159> cmd=pdm
10 compdef:159> cmd=pdftopbm
10 compdef:159> cmd=pdftexi2dvi
10 compdef:159> cmd=pdfimages
10 compdef:159> cmd=pdf2ps
10 compdef:159> cmd=pax
10 compdef:159> cmd=patch
10 compdef:159> cmd=passwd
10 compdef:159> cmd=otool
10 compdef:159> cmd=opera
10 compdef:159> cmd=open
10 compdef:159> cmd=okular
10 compdef:159> cmd=ogginfo
10 compdef:159> cmd=odmshow
10 compdef:159> cmd=odmget
10 compdef:159> cmd=objdump
10 compdef:159> cmd=nvim
10 compdef:159> cmd=ns
10 compdef:159> cmd=nmblookup
10 compdef:159> cmd=nl
10 compdef:159> cmd=ngrep
10 compdef:159> cmd=neutron
10 compdef:159> cmd=netstat
10 compdef:159> cmd=netrik
10 compdef:159> cmd=nc
10 compdef:159> cmd=nanoc
10 compdef:159> cmd=mysqlimport
10 compdef:159> cmd=mysqldump
10 compdef:159> cmd=mysqldiff
10 compdef:159> cmd=mysqladmin
10 compdef:159> cmd=mysql
10 compdef:159> cmd=mx
10 compdef:159> cmd=mutt
10 compdef:159> cmd=mupdf
10 compdef:159> cmd=munchlist
10 compdef:159> cmd=mt
10 compdef:159> cmd=mplayer
10 compdef:159> cmd=mozilla-xremote-client
10 compdef:159> cmd=mozilla-firefox
10 compdef:159> cmd=mozilla
10 compdef:159> cmd=mount
10 compdef:159> cmd=montage
10 compdef:159> cmd=monasca
10 compdef:159> cmd=module-assistant
10 compdef:159> cmd=modprobe
10 compdef:159> cmd=mmount
10 compdef:159> cmd=mkzsh.exe
10 compdef:159> cmd=mkzsh
10 compdef:159> cmd=mktemp
10 compdef:159> cmd=mkshortcut.exe
10 compdef:159> cmd=mksh
10 compdef:159> cmd=mkfifo
10 compdef:159> cmd=mkdir
10 compdef:159> cmd=mixerctl
10 compdef:159> cmd=mhpath
10 compdef:159> cmd=mhlist
10 compdef:159> cmd=mformat
10 compdef:159> cmd=mergechanges
10 compdef:159> cmd=mencal
10 compdef:159> cmd=members
10 compdef:159> cmd=mdls
10 compdef:159> cmd=mdir
10 compdef:159> cmd=md5
10 compdef:159> cmd=makeinfo
10 compdef:159> cmd=make
10 compdef:159> cmd=magnum
10 compdef:159> cmd=lz4cat
10 compdef:159> cmd=lz4c
10 compdef:159> cmd=lynx
10 compdef:159> cmd=lunchy
10 compdef:159> cmd=lua
10 compdef:159> cmd=lsvg
10 compdef:159> cmd=lsusb
10 compdef:159> cmd=lspv
10 compdef:159> cmd=lscfg
10 compdef:159> cmd=lprm
10 compdef:159> cmd=lpq
10 compdef:159> cmd=look
10 compdef:159> cmd=logname
10 compdef:159> cmd=locate
10 compdef:159> cmd=localedef
10 compdef:159> cmd=locale
10 compdef:159> cmd=local
10 compdef:159> cmd=loadkeys
10 compdef:159> cmd=llvm-gcc
10 compdef:159> cmd=lldb
10 compdef:159> cmd=lintian
10 compdef:159> cmd=links2
10 compdef:159> cmd=links
10 compdef:159> cmd=limit
10 compdef:159> cmd=ldd
10 compdef:159> cmd=ldconfig.real
10 compdef:159> cmd=ldap
10 compdef:159> cmd=lastb
10 compdef:159> cmd=last
10 compdef:159> cmd=kpartx
10 compdef:159> cmd=konqueror
10 compdef:159> cmd=kill
10 compdef:159> cmd=keytool
10 compdef:159> cmd=kdeconnect-cli
10 compdef:159> cmd=jq
10 compdef:159> cmd=jonas
10 compdef:159> cmd=jmeter
10 compdef:159> cmd=jexec
10 compdef:159> cmd=javah
10 compdef:159> cmd=jarsigner
10 compdef:159> cmd=jail
10 compdef:159> cmd=ispell
10 compdef:159> cmd=ironic
10 compdef:159> cmd=irb
10 compdef:159> cmd=iptables-save
10 compdef:159> cmd=iptables-restore
10 compdef:159> cmd=iptables
10 compdef:159> cmd=ipkg
10 compdef:159> cmd=ip6tables-restore
10 compdef:159> cmd=ip6tables
10 compdef:159> cmd=ip
10 compdef:159> cmd=iostat
10 compdef:159> cmd=inxi
10 compdef:159> cmd=invoke-rc.d
10 compdef:159> cmd=integer
10 compdef:159> cmd=install-info
10 compdef:159> cmd=initdb
10 compdef:159> cmd=inetadm
10 compdef:159> cmd=includeres
10 compdef:159> cmd=include-what-you-use
10 compdef:159> cmd=import
10 compdef:159> cmd=identify
10 compdef:159> cmd=id
10 compdef:159> cmd=iconv
10 compdef:159> cmd=hwinfo
10 compdef:159> cmd=hostname
10 compdef:159> cmd=hledger
10 compdef:159> cmd=history
10 compdef:159> cmd=helm
10 compdef:159> cmd=head
10 compdef:159> cmd=gzilla
10 compdef:159> cmd=gzfgrep
10 compdef:159> cmd=gzegrep
10 compdef:159> cmd=gwc
10 compdef:159> cmd=gview
10 compdef:159> cmd=guniq
10 compdef:159> cmd=guilt-push
10 compdef:159> cmd=gtty
10 compdef:159> cmd=gtimeout
10 compdef:159> cmd=gsnd
10 compdef:159> cmd=gshred
10 compdef:159> cmd=groups
10 compdef:159> cmd=groupmod
10 compdef:159> cmd=groupadd
10 compdef:159> cmd=groff
10 compdef:159> cmd=grmdir
10 compdef:159> cmd=grep-excuses
10 compdef:159> cmd=gradle
10 compdef:159> cmd=gphoto2
10 compdef:159> cmd=gpgv
10 compdef:159> cmd=gpg-zip
10 compdef:159> cmd=gpg
10 compdef:159> cmd=gofmt
10 compdef:159> cmd=god
10 compdef:159> cmd=gnutls-serv
10 compdef:159> cmd=gnutls-cli-debug
10 compdef:159> cmd=gnutls-cli
10 compdef:159> cmd=gnupod_search
10 compdef:159> cmd=gnupod_check
10 compdef:159> cmd=gnupod_addsong
10 compdef:159> cmd=gnupod_INIT
10 compdef:159> cmd=gnumfmt
10 compdef:159> cmd=gmv
10 compdef:159> cmd=gmplayer
10 compdef:159> cmd=gmktemp
10 compdef:159> cmd=gmkdir
10 compdef:159> cmd=global
10 compdef:159> cmd=gln
10 compdef:159> cmd=glances
10 compdef:159> cmd=glance
10 compdef:159> cmd=gjoin
10 compdef:159> cmd=git-revise
10 compdef:159> cmd=git-buildpackage
10 compdef:159> cmd=ginstall
10 compdef:159> cmd=ghostscript
10 compdef:159> cmd=ghci
10 compdef:159> cmd=gh
10 compdef:159> cmd=ggetopt
10 compdef:159> cmd=gfind
10 compdef:159> cmd=getopt
10 compdef:159> cmd=getfacl
10 compdef:159> cmd=getent
10 compdef:159> cmd=getconf
10 compdef:159> cmd=getclip.exe
10 compdef:159> cmd=getclip
10 compdef:159> cmd=get
10 compdef:159> cmd=genv
10 compdef:159> cmd=gegrep
10 compdef:159> cmd=geany
10 compdef:159> cmd=gdiff
10 compdef:159> cmd=gdb
10 compdef:159> cmd=gdate
10 compdef:159> cmd=gcp
10 compdef:159> cmd=gcore
10 compdef:159> cmd=gchroot
10 compdef:159> cmd=gccgo
10 compdef:159> cmd=gcat
10 compdef:159> cmd=gbasename
10 compdef:159> cmd=fwupdmgr
10 compdef:159> cmd=fw_update
10 compdef:159> cmd=fusermount
10 compdef:159> cmd=ftp
10 compdef:159> cmd=fsh
10 compdef:159> cmd=freebsd-update
10 compdef:159> cmd=free
10 compdef:159> cmd=fprev
10 compdef:159> cmd=force
10 compdef:159> cmd=fold
10 compdef:159> cmd=fnext
10 compdef:159> cmd=fmttest
10 compdef:159> cmd=fmadm
10 compdef:159> cmd=fly
10 compdef:159> cmd=flowadm
10 compdef:159> cmd=flists
10 compdef:159> cmd=flist
10 compdef:159> cmd=flex++
10 compdef:159> cmd=flex
10 compdef:159> cmd=flac
10 compdef:159> cmd=fixpsditps
10 compdef:159> cmd=fixfmps
10 compdef:159> cmd=finger
10 compdef:159> cmd=findmnt
10 compdef:159> cmd=findaffix
10 compdef:159> cmd=filterdiff
10 compdef:159> cmd=fg
10 compdef:159> cmd=fetchmail
10 compdef:159> cmd=fetch
10 compdef:159> cmd=fc-list
10 compdef:159> cmd=fakeroot
10 compdef:159> cmd=fail2ban-client
10 compdef:159> cmd=eu-objdump
10 compdef:159> cmd=eu-nm
10 compdef:159> cmd=epsffit
10 compdef:159> cmd=emulator
10 compdef:159> cmd=echoti
10 compdef:159> cmd=echotc
10 compdef:159> cmd=ecdsautil
10 compdef:159> cmd=dvitype
10 compdef:159> cmd=dviselect
10 compdef:159> cmd=dtrace
10 compdef:159> cmd=drush
10 compdef:159> cmd=dropdb
10 compdef:159> cmd=dpkg
10 compdef:159> cmd=domainname
10 compdef:159> cmd=docpad
10 compdef:159> cmd=docker
10 compdef:159> cmd=dnf-3
10 compdef:159> cmd=dlocate
10 compdef:159> cmd=diff
10 compdef:159> cmd=dict
10 compdef:159> cmd=diana
10 compdef:159> cmd=dhcpcd
10 compdef:159> cmd=dget
10 compdef:159> cmd=declare
10 compdef:159> cmd=dcopref
10 compdef:159> cmd=cygcheck.exe
10 compdef:159> cmd=csup
10 compdef:159> cmd=createuser
10 compdef:159> cmd=createdb
10 compdef:159> cmd=cplay
10 compdef:159> cmd=cp
10 compdef:159> cmd=coreadm
10 compdef:159> cmd=console
10 compdef:159> cmd=concourse
10 compdef:159> cmd=conan
10 compdef:159> cmd=composite
10 compdef:159> cmd=composer
10 compdef:159> cmd=coffee
10 compdef:159> cmd=cockroach
10 compdef:159> cmd=clear
10 compdef:159> cmd=cifsiostat
10 compdef:159> cmd=choc
10 compdef:159> cmd=chfn
10 compdef:159> cmd=chdir
10 compdef:159> cmd=certtool
10 compdef:159> cmd=cask
10 compdef:159> cmd=cap
10 compdef:159> cmd=c++
10 compdef:159> cmd=bzfgrep
10 compdef:159> cmd=bunzip2
10 compdef:159> cmd=bundle
10 compdef:159> cmd=builtin
10 compdef:159> cmd=buildhash
10 compdef:159> cmd=bug
10 compdef:159> cmd=btshowmetainfo
10 compdef:159> cmd=btlaunchmanycurses
10 compdef:159> cmd=btlaunchmany
10 compdef:159> cmd=btdownloadheadless
10 compdef:159> cmd=btdownloadgui
10 compdef:159> cmd=bsdinstall
10 compdef:159> cmd=bsdgrep
10 compdef:159> cmd=bsdconfig
10 compdef:159> cmd=brew
10 compdef:159> cmd=brctl
10 compdef:159> cmd=bpython2
10 compdef:159> cmd=bpython-gtk
10 compdef:159> cmd=bogoutil
10 compdef:159> cmd=bogofilter
10 compdef:159> cmd=bitcoin-cli
10 compdef:159> cmd=bison
10 compdef:159> cmd=bindkey
10 compdef:159> cmd=bg
10 compdef:159> cmd=beep
10 compdef:159> cmd=basename
10 compdef:159> cmd=avahi-resolve-host-name
10 compdef:159> cmd=avahi-resolve-address
10 compdef:159> cmd=avahi-resolve
10 compdef:159> cmd=avahi-browse
10 compdef:159> cmd=attr
10 compdef:159> cmd=atq
10 compdef:159> cmd=at
10 compdef:159> cmd=asciinema
10 compdef:159> cmd=asciidoctor
10 compdef:159> cmd=artisan
10 compdef:159> cmd=arecord
10 compdef:159> cmd=archlinux-java
10 compdef:159> cmd=aptitude
10 compdef:159> cmd=apt-show-versions
10 compdef:159> cmd=apt-mark
10 compdef:159> cmd=apt-file
10 compdef:159> cmd=apt-config
10 compdef:159> cmd=apropos
10 compdef:159> cmd=appletviewer
10 compdef:159> cmd=aplay
10 compdef:159> cmd=apachectl
10 compdef:159> cmd=apache2ctl
10 compdef:159> cmd=antiword
10 compdef:159> cmd=ansible-vault
10 compdef:159> cmd=ansible-pull
10 compdef:159> cmd=ansible-playbook
10 compdef:159> cmd=ansible-doc
10 compdef:159> cmd=ansible-console
10 compdef:159> cmd=android
10 compdef:159> cmd=analyseplugin
10 compdef:159> cmd=amaya
10 compdef:159> cmd=ali
10 compdef:159> cmd=add-zsh-hook
10 compdef:159> cmd=adb
10 compdef:159> cmd=acroread
10 compdef:159> cmd=acpi
10 compdef:159> cmd=ack-standalone
10 compdef:159> cmd=ack-grep
10 compdef:159> cmd=ack
10 compdef:159> cmd=abcde
10 compdef:159> cmd=a2dismod
10 compdef:159> cmd=_gh
10 compdef:159> cmd=_cockroach
10 compdef:159> cmd=Mosaic
10 compdef:159> cmd=-zcalc-line-
10 compdef:159> cmd=-value-,VALGRIND_OPTS,-default-
10 compdef:159> cmd=-value-,TERM,-default-
10 compdef:159> cmd=-value-,SPROMPT,-default-
10 compdef:159> cmd=-value-,RPROMPT,-default-
10 compdef:159> cmd=-value-,PS4,-default-
10 compdef:159> cmd=-value-,PS3,-default-
10 compdef:159> cmd=-value-,PS2,-default-
10 compdef:159> cmd=-value-,PS1,-default-
10 compdef:159> cmd=-value-,PROMPT3,-default-
10 compdef:159> cmd=-value-,P4PORT,-default-
10 compdef:159> cmd=-value-,P4MERGE,-default-
10 compdef:159> cmd=-value-,LPDEST,-default-
10 compdef:159> cmd=-value-,LDFLAGS,-default-
10 compdef:159> cmd=-value-,LANGUAGE,-default-
10 compdef:159> cmd=-value-,LANG,-default-
10 compdef:159> cmd=-value-,GZIP,-default-
10 compdef:159> cmd=-value-,GREP_OPTIONS,-default-
10 compdef:159> cmd=-value-,CXXFLAGS,-default-
10 compdef:159> cmd=-value-,ANT_ARGS,-default-
10 compdef:159> cmd=-value-,ANDROID_LOG_TAGS,-default-
10 compdef:159> cmd=-value-,ADB_TRACE,-default-
10 compdef:159> cmd=-value-,-default-,-default-
10 compdef:159> cmd=-value-
10 compdef:159> cmd=-subscript-
10 compdef:159> cmd=-first-
10 compdef:159> cmd=-condition-
10 compdef:159> cmd=-assign-parameter-
10 compdef:159> cmd=-array-value-
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:157> svc=yes
10 compdef:155> [[ zxpdf = *=* ]]
10 compdef:155> [[ zstat = *=* ]]
10 compdef:155> [[ zone = *=* ]]
10 compdef:155> [[ zfgrep = *=* ]]
10 compdef:155> [[ zf_rmdir = *=* ]]
10 compdef:155> [[ zf_rm = *=* ]]
10 compdef:155> [[ zf_mv = *=* ]]
10 compdef:155> [[ zf_mkdir = *=* ]]
10 compdef:155> [[ zf_ln = *=* ]]
10 compdef:155> [[ zen = *=* ]]
10 compdef:155> [[ zegrep = *=* ]]
10 compdef:155> [[ zdelattr = *=* ]]
10 compdef:155> [[ yumdb = *=* ]]
10 compdef:155> [[ ytalk = *=* ]]
10 compdef:155> [[ ypxfr = *=* ]]
10 compdef:155> [[ ypset = *=* ]]
10 compdef:155> [[ ypserv = *=* ]]
10 compdef:155> [[ yppush = *=* ]]
10 compdef:155> [[ yppasswd = *=* ]]
10 compdef:155> [[ ypbind = *=* ]]
10 compdef:155> [[ yast2 = *=* ]]
10 compdef:155> [[ xvncviewer = *=* ]]
10 compdef:155> [[ xvnc4viewer = *=* ]]
10 compdef:155> [[ xtp = *=* ]]
10 compdef:155> [[ xtightvncviewer = *=* ]]
10 compdef:155> [[ xping = *=* ]]
10 compdef:155> [[ xmosaic = *=* ]]
10 compdef:155> [[ www = *=* ]]
10 compdef:155> [[ whence = *=* ]]
10 compdef:155> [[ what = *=* ]]
10 compdef:155> [[ watcher = *=* ]]
10 compdef:155> [[ vorbiscomment = *=* ]]
10 compdef:155> [[ vitrage = *=* ]]
10 compdef:155> [[ virt-pki-validate = *=* ]]
10 compdef:155> [[ virt-admin = *=* ]]
10 compdef:155> [[ vimdiff = *=* ]]
10 compdef:155> [[ vacuumdb = *=* ]]
10 compdef:155> [[ userdel = *=* ]]
10 compdef:155> [[ urxvt256cc = *=* ]]
10 compdef:155> [[ urxvt256c-ml = *=* ]]
10 compdef:155> [[ urxvt = *=* ]]
10 compdef:155> [[ urpmq = *=* ]]
10 compdef:155> [[ urpmi = *=* ]]
10 compdef:155> [[ urpmf = *=* ]]
10 compdef:155> [[ upgradepkg = *=* ]]
10 compdef:155> [[ unzip = *=* ]]
10 compdef:155> [[ unwrapdiff = *=* ]]
10 compdef:155> [[ unsetopt = *=* ]]
10 compdef:155> [[ unpack = *=* ]]
10 compdef:155> [[ unlz4 = *=* ]]
10 compdef:155> [[ unget = *=* ]]
10 compdef:155> [[ umount = *=* ]]
10 compdef:155> [[ uml_switch = *=* ]]
10 compdef:155> [[ uml_moo = *=* ]]
10 compdef:155> [[ typeset = *=* ]]
10 compdef:155> [[ type = *=* ]]
10 compdef:155> [[ tunes2pod = *=* ]]
10 compdef:155> [[ tryaffix = *=* ]]
10 compdef:155> [[ tpkg-update = *=* ]]
10 compdef:155> [[ tpkg-make = *=* ]]
10 compdef:155> [[ tpkg-install-libc = *=* ]]
10 compdef:155> [[ tpkg-debarch = *=* ]]
10 compdef:155> [[ tkconch = *=* ]]
10 compdef:155> [[ times = *=* ]]
10 compdef:155> [[ time = *=* ]]
10 compdef:155> [[ texindex = *=* ]]
10 compdef:155> [[ texi2pdf = *=* ]]
10 compdef:155> [[ texi2dvi = *=* ]]
10 compdef:155> [[ texi2any = *=* ]]
10 compdef:155> [[ tacker = *=* ]]
10 compdef:155> [[ sudoedit = *=* ]]
10 compdef:155> [[ strongswan = *=* ]]
10 compdef:155> [[ strace64 = *=* ]]
10 compdef:155> [[ stop = *=* ]]
10 compdef:155> [[ status = *=* ]]
10 compdef:155> [[ ssh-keyscan = *=* ]]
10 compdef:155> [[ ssh-keygen = *=* ]]
10 compdef:155> [[ ssh-copy-id = *=* ]]
10 compdef:155> [[ ssh-agent = *=* ]]
10 compdef:155> [[ srptool = *=* ]]
10 compdef:155> [[ sqlite3 = *=* ]]
10 compdef:155> [[ splitdiff = *=* ]]
10 compdef:155> [[ sortm = *=* ]]
10 compdef:155> [[ soa = *=* ]]
10 compdef:155> [[ smitty = *=* ]]
10 compdef:155> [[ slitex = *=* ]]
10 compdef:155> [[ skipstone = *=* ]]
10 compdef:155> [[ showchar = *=* ]]
10 compdef:155> [[ show = *=* ]]
10 compdef:155> [[ sftp = *=* ]]
10 compdef:155> [[ setfattr = *=* ]]
10 compdef:155> [[ setfacl.exe = *=* ]]
10 compdef:155> [[ senlin = *=* ]]
10 compdef:155> [[ scp = *=* ]]
10 compdef:155> [[ sccsdiff = *=* ]]
10 compdef:155> [[ sar = *=* ]]
10 compdef:155> [[ sahara = *=* ]]
10 compdef:155> [[ rwho = *=* ]]
10 compdef:155> [[ rvim = *=* ]]
10 compdef:155> [[ rview = *=* ]]
10 compdef:155> [[ rup = *=* ]]
10 compdef:155> [[ ruby-mri = *=* ]]
10 compdef:155> [[ rubber-info = *=* ]]
10 compdef:155> [[ rpmverify = *=* ]]
10 compdef:155> [[ rpmquery = *=* ]]
10 compdef:155> [[ rpmbuild = *=* ]]
10 compdef:155> [[ rmmod = *=* ]]
10 compdef:155> [[ rmm = *=* ]]
10 compdef:155> [[ rmid = *=* ]]
10 compdef:155> [[ rmf = *=* ]]
10 compdef:155> [[ rmdel = *=* ]]
10 compdef:155> [[ rgvim = *=* ]]
10 compdef:155> [[ retawq = *=* ]]
10 compdef:155> [[ reportbug = *=* ]]
10 compdef:155> [[ removepkg = *=* ]]
10 compdef:155> [[ reload = *=* ]]
10 compdef:155> [[ reindexdb = *=* ]]
10 compdef:155> [[ refile = *=* ]]
10 compdef:155> [[ rcsdiff = *=* ]]
10 compdef:155> [[ rcs = *=* ]]
10 compdef:155> [[ r = *=* ]]
10 compdef:155> [[ querybts = *=* ]]
10 compdef:155> [[ pyhtmlizer = *=* ]]
10 compdef:155> [[ putclip.exe = *=* ]]
10 compdef:155> [[ pswrap = *=* ]]
10 compdef:155> [[ pstotgif = *=* ]]
10 compdef:155> [[ pstops = *=* ]]
10 compdef:155> [[ pstop = *=* ]]
10 compdef:155> [[ pstack = *=* ]]
10 compdef:155> [[ psselect = *=* ]]
10 compdef:155> [[ psresize = *=* ]]
10 compdef:155> [[ psql = *=* ]]
10 compdef:155> [[ psig = *=* ]]
10 compdef:155> [[ pscp.exe = *=* ]]
10 compdef:155> [[ ps2pdf14 = *=* ]]
10 compdef:155> [[ ps2pdf12 = *=* ]]
10 compdef:155> [[ ps2ascii = *=* ]]
10 compdef:155> [[ postsuper = *=* ]]
10 compdef:155> [[ postqueue = *=* ]]
10 compdef:155> [[ postmaster = *=* ]]
10 compdef:155> [[ postgres = *=* ]]
10 compdef:155> [[ podtoc = *=* ]]
10 compdef:155> [[ podpath = *=* ]]
10 compdef:155> [[ pmvers = *=* ]]
10 compdef:155> [[ pmls = *=* ]]
10 compdef:155> [[ pmfunc = *=* ]]
10 compdef:155> [[ pmexp = *=* ]]
10 compdef:155> [[ pmdesc = *=* ]]
10 compdef:155> [[ pmcat = *=* ]]
10 compdef:155> [[ pman = *=* ]]
10 compdef:155> [[ pmake = *=* ]]
10 compdef:155> [[ pkill = *=* ]]
10 compdef:155> [[ pkgtool = *=* ]]
10 compdef:155> [[ pkg_info = *=* ]]
10 compdef:155> [[ pkg_delete = *=* ]]
10 compdef:155> [[ pkg_create = *=* ]]
10 compdef:155> [[ ping6 = *=* ]]
10 compdef:155> [[ pinef = *=* ]]
10 compdef:155> [[ pg_upgrade = *=* ]]
10 compdef:155> [[ pg_restore = *=* ]]
10 compdef:155> [[ pg_isready = *=* ]]
10 compdef:155> [[ pg_dumpall = *=* ]]
10 compdef:155> [[ pg_config = *=* ]]
10 compdef:155> [[ pfiles = *=* ]]
10 compdef:155> [[ pdksh = *=* ]]
10 compdef:155> [[ pdftopbm = *=* ]]
10 compdef:155> [[ pdfopt = *=* ]]
10 compdef:155> [[ pdfjadetex = *=* ]]
10 compdef:155> [[ pdfinfo = *=* ]]
10 compdef:155> [[ pdffonts = *=* ]]
10 compdef:155> [[ pdf2ps = *=* ]]
10 compdef:155> [[ pcred = *=* ]]
10 compdef:155> [[ parsehdlist = *=* ]]
10 compdef:155> [[ packf = *=* ]]
10 compdef:155> [[ p4d = *=* ]]
10 compdef:155> [[ omz = *=* ]]
10 compdef:155> [[ ogginfo = *=* ]]
10 compdef:155> [[ oggdec = *=* ]]
10 compdef:155> [[ ogg123 = *=* ]]
10 compdef:155> [[ odmshow = *=* ]]
10 compdef:155> [[ odme = *=* ]]
10 compdef:155> [[ nvim = *=* ]]
10 compdef:155> [[ ntalk = *=* ]]
10 compdef:155> [[ nohup = *=* ]]
10 compdef:155> [[ noglob = *=* ]]
10 compdef:155> [[ next = *=* ]]
10 compdef:155> [[ neutron = *=* ]]
10 compdef:155> [[ netrik = *=* ]]
10 compdef:155> [[ netcat = *=* ]]
10 compdef:155> [[ nawk = *=* ]]
10 compdef:155> [[ mysqlimport = *=* ]]
10 compdef:155> [[ mysqldump = *=* ]]
10 compdef:155> [[ mysqladmin = *=* ]]
10 compdef:155> [[ mx = *=* ]]
10 compdef:155> [[ munchlist = *=* ]]
10 compdef:155> [[ mtype = *=* ]]
10 compdef:155> [[ mtoolstest = *=* ]]
10 compdef:155> [[ msgchk = *=* ]]
10 compdef:155> [[ mren = *=* ]]
10 compdef:155> [[ mread = *=* ]]
10 compdef:155> [[ mrd = *=* ]]
10 compdef:155> [[ montage = *=* ]]
10 compdef:155> [[ monasca = *=* ]]
10 compdef:155> [[ mogrify = *=* ]]
10 compdef:155> [[ modprobe = *=* ]]
10 compdef:155> [[ modinfo = *=* ]]
10 compdef:155> [[ mmove = *=* ]]
10 compdef:155> [[ mmount = *=* ]]
10 compdef:155> [[ mlocate = *=* ]]
10 compdef:155> [[ mlabel = *=* ]]
10 compdef:155> [[ mkzsh.exe = *=* ]]
10 compdef:155> [[ mktunes = *=* ]]
10 compdef:155> [[ mistral = *=* ]]
10 compdef:155> [[ mhstore = *=* ]]
10 compdef:155> [[ mhshow = *=* ]]
10 compdef:155> [[ mhpath = *=* ]]
10 compdef:155> [[ mhparam = *=* ]]
10 compdef:155> [[ mhmail = *=* ]]
10 compdef:155> [[ mhlist = *=* ]]
10 compdef:155> [[ mhfixmsg = *=* ]]
10 compdef:155> [[ mgv = *=* ]]
10 compdef:155> [[ mformat = *=* ]]
10 compdef:155> [[ metaflac = *=* ]]
10 compdef:155> [[ merge = *=* ]]
10 compdef:155> [[ mdir = *=* ]]
10 compdef:155> [[ mdeltree = *=* ]]
10 compdef:155> [[ md2 = *=* ]]
10 compdef:155> [[ mcopy = *=* ]]
10 compdef:155> [[ mark = *=* ]]
10 compdef:155> [[ manila = *=* ]]
10 compdef:155> [[ makeinfo = *=* ]]
10 compdef:155> [[ magnum = *=* ]]
10 compdef:155> [[ mac2unix = *=* ]]
10 compdef:155> [[ m-a = *=* ]]
10 compdef:155> [[ lz4cat = *=* ]]
10 compdef:155> [[ lz4c32 = *=* ]]
10 compdef:155> [[ lz4c = *=* ]]
10 compdef:155> [[ lsdiff = *=* ]]
10 compdef:155> [[ lpstat = *=* ]]
10 compdef:155> [[ lprm = *=* ]]
10 compdef:155> [[ lpq = *=* ]]
10 compdef:155> [[ lpinfo = *=* ]]
10 compdef:155> [[ logname = *=* ]]
10 compdef:155> [[ llvm-otool = *=* ]]
10 compdef:155> [[ llvm-objdump = *=* ]]
10 compdef:155> [[ llvm-gcc = *=* ]]
10 compdef:155> [[ llvm-g++ = *=* ]]
10 compdef:155> [[ links2 = *=* ]]
10 compdef:155> [[ light = *=* ]]
10 compdef:155> [[ lftp = *=* ]]
10 compdef:155> [[ lastb = *=* ]]
10 compdef:155> [[ konqueror = *=* ]]
10 compdef:155> [[ keystone = *=* ]]
10 compdef:155> [[ jdb = *=* ]]
10 compdef:155> [[ javap = *=* ]]
10 compdef:155> [[ javah = *=* ]]
10 compdef:155> [[ javadoc = *=* ]]
10 compdef:155> [[ jarsigner = *=* ]]
10 compdef:155> [[ jar = *=* ]]
10 compdef:155> [[ jadetex = *=* ]]
10 compdef:155> [[ irb = *=* ]]
10 compdef:155> [[ iptables-restore = *=* ]]
10 compdef:155> [[ ipkg = *=* ]]
10 compdef:155> [[ ip6tables-save = *=* ]]
10 compdef:155> [[ ip6tables = *=* ]]
10 compdef:155> [[ interdiff = *=* ]]
10 compdef:155> [[ integer = *=* ]]
10 compdef:155> [[ insmod = *=* ]]
10 compdef:155> [[ initdb = *=* ]]
10 compdef:155> [[ includeres = *=* ]]
10 compdef:155> [[ import = *=* ]]
10 compdef:155> [[ ijoin = *=* ]]
10 compdef:155> [[ ifdown = *=* ]]
10 compdef:155> [[ identify = *=* ]]
10 compdef:155> [[ hilite = *=* ]]
10 compdef:155> [[ help = *=* ]]
10 compdef:155> [[ hd = *=* ]]
10 compdef:155> [[ gzgrep = *=* ]]
10 compdef:155> [[ gzfgrep = *=* ]]
10 compdef:155> [[ gzegrep = *=* ]]
10 compdef:155> [[ gvimdiff = *=* ]]
10 compdef:155> [[ gvim = *=* ]]
10 compdef:155> [[ gview = *=* ]]
10 compdef:155> [[ guptime = *=* ]]
10 compdef:155> [[ guname = *=* ]]
10 compdef:155> [[ guilt-rm = *=* ]]
10 compdef:155> [[ gtr = *=* ]]
10 compdef:155> [[ gtouch = *=* ]]
10 compdef:155> [[ gtimeout = *=* ]]
10 compdef:155> [[ gtail = *=* ]]
10 compdef:155> [[ gtac = *=* ]]
10 compdef:155> [[ gstty = *=* ]]
10 compdef:155> [[ gstat = *=* ]]
10 compdef:155> [[ gsplit = *=* ]]
10 compdef:155> [[ gsort = *=* ]]
10 compdef:155> [[ gslp = *=* ]]
10 compdef:155> [[ gslj = *=* ]]
10 compdef:155> [[ gshuf = *=* ]]
10 compdef:155> [[ gshred = *=* ]]
10 compdef:155> [[ gsed = *=* ]]
10 compdef:155> [[ gsdj500 = *=* ]]
10 compdef:155> [[ gsdj = *=* ]]
10 compdef:155> [[ groups = *=* ]]
10 compdef:155> [[ groupmod = *=* ]]
10 compdef:155> [[ grm = *=* ]]
10 compdef:155> [[ grepdiff = *=* ]]
10 compdef:155> [[ greadlink = *=* ]]
10 compdef:155> [[ gradlew = *=* ]]
10 compdef:155> [[ gpgv = *=* ]]
10 compdef:155> [[ gpg-zip = *=* ]]
10 compdef:155> [[ gpatch = *=* ]]
10 compdef:155> [[ gofmt = *=* ]]
10 compdef:155> [[ gnutls-serv = *=* ]]
10 compdef:155> [[ gnupod_search = *=* ]]
10 compdef:155> [[ gnupod_check = *=* ]]
10 compdef:155> [[ gnl = *=* ]]
10 compdef:155> [[ gmv = *=* ]]
10 compdef:155> [[ gmplayer = *=* ]]
10 compdef:155> [[ gmktemp = *=* ]]
10 compdef:155> [[ gmknod = *=* ]]
10 compdef:155> [[ gmkfifo = *=* ]]
10 compdef:155> [[ glocate = *=* ]]
10 compdef:155> [[ gjoin = *=* ]]
10 compdef:155> [[ ginstall = *=* ]]
10 compdef:155> [[ ghostscript = *=* ]]
10 compdef:155> [[ ghead = *=* ]]
10 compdef:155> [[ ggv = *=* ]]
10 compdef:155> [[ ggrep = *=* ]]
10 compdef:155> [[ ggetopt = *=* ]]
10 compdef:155> [[ gfold = *=* ]]
10 compdef:155> [[ gfmt = *=* ]]
10 compdef:155> [[ gfind = *=* ]]
10 compdef:155> [[ gfgrep = *=* ]]
10 compdef:155> [[ gexpand = *=* ]]
10 compdef:155> [[ gex = *=* ]]
10 compdef:155> [[ getclip.exe = *=* ]]
10 compdef:155> [[ getafm = *=* ]]
10 compdef:155> [[ get = *=* ]]
10 compdef:155> [[ gegrep = *=* ]]
10 compdef:155> [[ gdf = *=* ]]
10 compdef:155> [[ gcp = *=* ]]
10 compdef:155> [[ gbasename = *=* ]]
10 compdef:155> [[ gbase64 = *=* ]]
10 compdef:155> [[ gbase32 = *=* ]]
10 compdef:155> [[ gawk = *=* ]]
10 compdef:155> [[ g++ = *=* ]]
10 compdef:155> [[ fwhois = *=* ]]
10 compdef:155> [[ forw = *=* ]]
10 compdef:155> [[ folders = *=* ]]
10 compdef:155> [[ folder = *=* ]]
10 compdef:155> [[ fnext = *=* ]]
10 compdef:155> [[ fmttest = *=* ]]
10 compdef:155> [[ fly = *=* ]]
10 compdef:155> [[ float = *=* ]]
10 compdef:155> [[ flists = *=* ]]
10 compdef:155> [[ flist = *=* ]]
10 compdef:155> [[ flipdiff = *=* ]]
10 compdef:155> [[ flex++ = *=* ]]
10 compdef:155> [[ fixwwps = *=* ]]
10 compdef:155> [[ fixwpps = *=* ]]
10 compdef:155> [[ fixwfwps = *=* ]]
10 compdef:155> [[ fixtpps = *=* ]]
10 compdef:155> [[ fixpsditps = *=* ]]
10 compdef:155> [[ fixmacps = *=* ]]
10 compdef:155> [[ fixdlsrps = *=* ]]
10 compdef:155> [[ findaffix = *=* ]]
10 compdef:155> [[ filterdiff = *=* ]]
10 compdef:155> [[ fgrep = *=* ]]
10 compdef:155> [[ false = *=* ]]
10 compdef:155> [[ extcheck = *=* ]]
10 compdef:155> [[ express = *=* ]]
10 compdef:155> [[ export = *=* ]]
10 compdef:155> [[ explodepkg = *=* ]]
10 compdef:155> [[ eview = *=* ]]
10 compdef:155> [[ eu-strings = *=* ]]
10 compdef:155> [[ eu-objdump = *=* ]]
10 compdef:155> [[ eu-nm = *=* ]]
10 compdef:155> [[ erb = *=* ]]
10 compdef:155> [[ egrep = *=* ]]
10 compdef:155> [[ eatmydata = *=* ]]
10 compdef:155> [[ dropuser = *=* ]]
10 compdef:155> [[ dropdb = *=* ]]
10 compdef:155> [[ dpkg-deb = *=* ]]
10 compdef:155> [[ dosdel = *=* ]]
10 compdef:155> [[ domainname = *=* ]]
10 compdef:155> [[ display = *=* ]]
10 compdef:155> [[ createuser = *=* ]]
10 compdef:155> [[ createdb = *=* ]]
10 compdef:155> [[ convert = *=* ]]
10 compdef:155> [[ composite = *=* ]]
10 compdef:155> [[ comp = *=* ]]
10 compdef:155> [[ combine = *=* ]]
10 compdef:155> [[ cockroach = *=* ]]
10 compdef:155> [[ clear = *=* ]]
10 compdef:155> [[ chkstow = *=* ]]
10 compdef:155> [[ chimera = *=* ]]
10 compdef:155> [[ chfn = *=* ]]
10 compdef:155> [[ cftp = *=* ]]
10 compdef:155> [[ certtool = *=* ]]
10 compdef:155> [[ cdc = *=* ]]
10 compdef:155> [[ cc = *=* ]]
10 compdef:155> [[ catchsegv = *=* ]]
10 compdef:155> [[ c++ = *=* ]]
10 compdef:155> [[ bzgrep = *=* ]]
10 compdef:155> [[ bzfgrep = *=* ]]
10 compdef:155> [[ bzegrep = *=* ]]
10 compdef:155> [[ burst = *=* ]]
10 compdef:155> [[ bunzip2 = *=* ]]
10 compdef:155> [[ bttrack = *=* ]]
10 compdef:155> [[ btrename = *=* ]]
10 compdef:155> [[ btlaunchmany = *=* ]]
10 compdef:155> [[ btdownloadheadless = *=* ]]
10 compdef:155> [[ bsdgrep = *=* ]]
10 compdef:155> [[ bpython3 = *=* ]]
10 compdef:155> [[ bpython2-gtk = *=* ]]
10 compdef:155> [[ bpython2 = *=* ]]
10 compdef:155> [[ bmake = *=* ]]
10 compdef:155> [[ batch = *=* ]]
10 compdef:155> [[ base32 = *=* ]]
10 compdef:155> [[ at = *=* ]]
10 compdef:155> [[ ash = *=* ]]
10 compdef:155> [[ arena = *=* ]]
10 compdef:155> [[ arecord = *=* ]]
10 compdef:155> [[ apt-mark = *=* ]]
10 compdef:155> [[ apt-config = *=* ]]
10 compdef:155> [[ apt-cache = *=* ]]
10 compdef:155> [[ appletviewer = *=* ]]
10 compdef:155> [[ apache2ctl = *=* ]]
10 compdef:155> [[ ansible-vault = *=* ]]
10 compdef:155> [[ ansible-pull = *=* ]]
10 compdef:155> [[ ansible-playbook = *=* ]]
10 compdef:155> [[ ansible-inventory = *=* ]]
10 compdef:155> [[ ansible-galaxy = *=* ]]
10 compdef:155> [[ ansible-console = *=* ]]
10 compdef:155> [[ ansible-config = *=* ]]
10 compdef:155> [[ ack2 = *=* ]]
10 compdef:155> [[ ack-standalone = *=* ]]
10 compdef:155> [[ ack-grep = *=* ]]
10 compdef:155> [[ aaaa = *=* ]]
10 compdef:155> [[ Mosaic = *=* ]]
10 compdef:155> [[ 8l = *=* ]]
10 compdef:155> [[ 8g = *=* ]]
10 compdef:155> [[ 6l = *=* ]]
10 compdef:155> [[ 6g = *=* ]]
10 compdef:155> [[ -value-,RPS1,-default- = *=* ]]
10 compdef:155> [[ -value-,P4USER,-default- = *=* ]]
10 compdef:155> [[ -value-,P4CLIENT,-default- = *=* ]]
10 compdef:155> [[ -array-value- = *=* ]]
10 compdef:155> [[ 'xzcat=unxz' = *=* ]]
10 compdef:155> [[ 'xetex=tex' = *=* ]]
10 compdef:155> [[ 'unlzma=unxz' = *=* ]]
10 compdef:155> [[ 'svnlite=svn' = *=* ]]
10 compdef:155> [[ 'remsh=rsh' = *=* ]]
10 compdef:155> [[ 'nedit-nc=nc' = *=* ]]
10 compdef:155> [[ 'ncl=nc' = *=* ]]
10 compdef:155> [[ 'mailx=mail' = *=* ]]
10 compdef:155> [[ 'lzma=xz' = *=* ]]
10 compdef:155> [[ 'gdnolock=git-diff' = *=* ]]
10 compdef:155> [[ 'Mail=mail' = *=* ]]
10 compdef:148> [[ 'zf*' = (#b)(*)=(*) ]]
10 compdef:148> [[ 'shasum(|5).*' = (#b)(*)=(*) ]]
10 compdef:148> [[ 'pydoc[0-9.]#' = (#b)(*)=(*) ]]
10 compdef:148> [[ 'g++-*' = (#b)(*)=(*) ]]
10 compdef:148> [[ 'c++-*' = (#b)(*)=(*) ]]
10 compdef:139> case postpattern (postpattern)
10 compdef:139> case postpattern (postpattern)
10 compdef:139> case postpattern (postpattern)
10 compdef:139> case postpattern (postpattern)
10 compdef:139> case postpattern (postpattern)
10 compdef:139> case postpattern (pattern)
10 compdef:139> case postpattern (pattern)
10 compdef:139> case postpattern (pattern)
10 compdef:139> case postpattern (pattern)
10 compdef:139> case pattern (pattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (postpattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (pattern)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:139> case  (*)
10 compdef:136> [[ zxpdf = -P ]]
10 compdef:136> [[ zstat = -P ]]
10 compdef:136> [[ zone = -P ]]
10 compdef:136> [[ zln = -P ]]
10 compdef:136> [[ zip = -P ]]
10 compdef:136> [[ zgetattr = -P ]]
10 compdef:136> [[ zfs = -P ]]
10 compdef:136> [[ zfgrep = -P ]]
10 compdef:136> [[ zf_rmdir = -P ]]
10 compdef:136> [[ zf_mv = -P ]]
10 compdef:136> [[ zf_mkdir = -P ]]
10 compdef:136> [[ zegrep = -P ]]
10 compdef:136> [[ zed = -P ]]
10 compdef:136> [[ zdump = -P ]]
10 compdef:136> [[ zcalc = -P ]]
10 compdef:136> [[ yum = -P ]]
10 compdef:136> [[ ytalk = -P ]]
10 compdef:136> [[ ypset = -P ]]
10 compdef:136> [[ ypserv = -P ]]
10 compdef:136> [[ yppoll = -P ]]
10 compdef:136> [[ ypmatch = -P ]]
10 compdef:136> [[ ypcat = -P ]]
10 compdef:136> [[ ypbind = -P ]]
10 compdef:136> [[ yast2 = -P ]]
10 compdef:136> [[ yast = -P ]]
10 compdef:136> [[ yash = -P ]]
10 compdef:136> [[ yafc = -P ]]
10 compdef:136> [[ xz = -P ]]
10 compdef:136> [[ xwud = -P ]]
10 compdef:136> [[ xwit = -P ]]
10 compdef:136> [[ xv = -P ]]
10 compdef:136> [[ xterm = -P ]]
10 compdef:136> [[ xset = -P ]]
10 compdef:136> [[ xscreensaver-command = -P ]]
10 compdef:136> [[ xrandr = -P ]]
10 compdef:136> [[ xprop = -P ]]
10 compdef:136> [[ xournal = -P ]]
10 compdef:136> [[ xmosaic = -P ]]
10 compdef:136> [[ xmodmap = -P ]]
10 compdef:136> [[ xmms2 = -P ]]
10 compdef:136> [[ xfreerdp = -P ]]
10 compdef:136> [[ xev = -P ]]
10 compdef:136> [[ xattr = -P ]]
10 compdef:136> [[ write = -P ]]
10 compdef:136> [[ whom = -P ]]
10 compdef:136> [[ whois = -P ]]
10 compdef:136> [[ which = -P ]]
10 compdef:136> [[ whereis = -P ]]
10 compdef:136> [[ where = -P ]]
10 compdef:136> [[ whence = -P ]]
10 compdef:136> [[ wget = -P ]]
10 compdef:136> [[ wc = -P ]]
10 compdef:136> [[ watch = -P ]]
10 compdef:136> [[ wajig = -P ]]
10 compdef:136> [[ wait = -P ]]
10 compdef:136> [[ w = -P ]]
10 compdef:136> [[ vserver = -P ]]
10 compdef:136> [[ vpnc-connect = -P ]]
10 compdef:136> [[ vncviewer = -P ]]
10 compdef:136> [[ vncserver = -P ]]
10 compdef:136> [[ vmstat = -P ]]
10 compdef:136> [[ vitrage = -P ]]
10 compdef:136> [[ visudo = -P ]]
10 compdef:136> [[ virt-xml-validate = -P ]]
10 compdef:136> [[ virt-pki-validate = -P ]]
10 compdef:136> [[ virt-host-validate = -P ]]
10 compdef:136> [[ virt-admin = -P ]]
10 compdef:136> [[ virsh = -P ]]
10 compdef:136> [[ vim-addons = -P ]]
10 compdef:136> [[ vim = -P ]]
10 compdef:136> [[ vcsh = -P ]]
10 compdef:136> [[ vared = -P ]]
10 compdef:136> [[ valgrind = -P ]]
10 compdef:136> [[ vacuumdb = -P ]]
10 compdef:136> [[ userdel = -P ]]
10 compdef:136> [[ useradd = -P ]]
10 compdef:136> [[ urxvt256cc = -P ]]
10 compdef:136> [[ urxvt = -P ]]
10 compdef:136> [[ urpmq = -P ]]
10 compdef:136> [[ urpmi.update = -P ]]
10 compdef:136> [[ urpmi.removemedia = -P ]]
10 compdef:136> [[ urpmi = -P ]]
10 compdef:136> [[ urpme = -P ]]
10 compdef:136> [[ uptime = -P ]]
10 compdef:136> [[ unzip = -P ]]
10 compdef:136> [[ units = -P ]]
10 compdef:136> [[ unison = -P ]]
10 compdef:136> [[ uniq = -P ]]
10 compdef:136> [[ unhash = -P ]]
10 compdef:136> [[ unfunction = -P ]]
10 compdef:136> [[ unexpand = -P ]]
10 compdef:136> [[ uname = -P ]]
10 compdef:136> [[ unace = -P ]]
10 compdef:136> [[ umount = -P ]]
10 compdef:136> [[ uml_mconsole = -P ]]
10 compdef:136> [[ ulimit = -P ]]
10 compdef:136> [[ type = -P ]]
10 compdef:136> [[ txt = -P ]]
10 compdef:136> [[ twist = -P ]]
10 compdef:136> [[ tune2fs = -P ]]
10 compdef:136> [[ tty = -P ]]
10 compdef:136> [[ tryaffix = -P ]]
10 compdef:136> [[ true = -P ]]
10 compdef:136> [[ trash = -P ]]
10 compdef:136> [[ trash = -P ]]
10 compdef:136> [[ transmission-remote = -P ]]
10 compdef:136> [[ tracepath6 = -P ]]
10 compdef:136> [[ tracepath = -P ]]
10 compdef:136> [[ tput = -P ]]
10 compdef:136> [[ tpkg-install-libc = -P ]]
10 compdef:136> [[ tpkg-install = -P ]]
10 compdef:136> [[ totdconfig = -P ]]
10 compdef:136> [[ tload = -P ]]
10 compdef:136> [[ tkinfo = -P ]]
10 compdef:136> [[ tin = -P ]]
10 compdef:136> [[ tg = -P ]]
10 compdef:136> [[ texindex = -P ]]
10 compdef:136> [[ texi2dvi = -P ]]
10 compdef:136> [[ telnet = -P ]]
10 compdef:136> [[ tcptraceroute = -P ]]
10 compdef:136> [[ tcpdump = -P ]]
10 compdef:136> [[ tail = -P ]]
10 compdef:136> [[ tac = -P ]]
10 compdef:136> [[ system_profiler = -P ]]
10 compdef:136> [[ sysrc = -P ]]
10 compdef:136> [[ sysctl = -P ]]
10 compdef:136> [[ swift = -P ]]
10 compdef:136> [[ swaks = -P ]]
10 compdef:136> [[ svn-buildpackage = -P ]]
10 compdef:136> [[ svcs = -P ]]
10 compdef:136> [[ svcprop = -P ]]
10 compdef:136> [[ surfraw = -P ]]
10 compdef:136> [[ sudoedit = -P ]]
10 compdef:136> [[ subl = -P ]]
10 compdef:136> [[ su = -P ]]
10 compdef:136> [[ strings = -P ]]
10 compdef:136> [[ strftime = -P ]]
10 compdef:136> [[ strace = -P ]]
10 compdef:136> [[ stow = -P ]]
10 compdef:136> [[ stop = -P ]]
10 compdef:136> [[ status = -P ]]
10 compdef:136> [[ start = -P ]]
10 compdef:136> [[ sshfs = -P ]]
10 compdef:136> [[ ssh-keyscan = -P ]]
10 compdef:136> [[ ssh-copy-id = -P ]]
10 compdef:136> [[ ssh-agent = -P ]]
10 compdef:136> [[ sr = -P ]]
10 compdef:136> [[ sqsh = -P ]]
10 compdef:136> [[ split = -P ]]
10 compdef:136> [[ spamassassin = -P ]]
10 compdef:136> [[ source = -P ]]
10 compdef:136> [[ socket = -P ]]
10 compdef:136> [[ snoop = -P ]]
10 compdef:136> [[ smbcontrol = -P ]]
10 compdef:136> [[ slrn = -P ]]
10 compdef:136> [[ slocate = -P ]]
10 compdef:136> [[ slitex = -P ]]
10 compdef:136> [[ skipstone = -P ]]
10 compdef:136> [[ shutdown = -P ]]
10 compdef:136> [[ shred = -P ]]
10 compdef:136> [[ showmount = -P ]]
10 compdef:136> [[ setxkbmap = -P ]]
10 compdef:136> [[ setfacl.exe = -P ]]
10 compdef:136> [[ setfacl = -P ]]
10 compdef:136> [[ set = -P ]]
10 compdef:136> [[ service = -P ]]
10 compdef:136> [[ serialver = -P ]]
10 compdef:136> [[ seq = -P ]]
10 compdef:136> [[ sed = -P ]]
10 compdef:136> [[ seaf-cli = -P ]]
10 compdef:136> [[ scutil = -P ]]
10 compdef:136> [[ scselect = -P ]]
10 compdef:136> [[ scriptreplay = -P ]]
10 compdef:136> [[ schedtool = -P ]]
10 compdef:136> [[ sched = -P ]]
10 compdef:136> [[ sccsdiff = -P ]]
10 compdef:136> [[ sccs = -P ]]
10 compdef:136> [[ sar = -P ]]
10 compdef:136> [[ sahara = -P ]]
10 compdef:136> [[ sact = -P ]]
10 compdef:136> [[ rup = -P ]]
10 compdef:136> [[ ruby = -P ]]
10 compdef:136> [[ rubber-pipe = -P ]]
10 compdef:136> [[ rubber = -P ]]
10 compdef:136> [[ rtin = -P ]]
10 compdef:136> [[ rrdtool = -P ]]
10 compdef:136> [[ rpmkeys = -P ]]
10 compdef:136> [[ rmf = -P ]]
10 compdef:136> [[ rm = -P ]]
10 compdef:136> [[ retawq = -P ]]
10 compdef:136> [[ restart = -P ]]
10 compdef:136> [[ reprepro = -P ]]
10 compdef:136> [[ reportbug = -P ]]
10 compdef:136> [[ repl = -P ]]
10 compdef:136> [[ renice = -P ]]
10 compdef:136> [[ reload = -P ]]
10 compdef:136> [[ rehash = -P ]]
10 compdef:136> [[ readonly = -P ]]
10 compdef:136> [[ readlink = -P ]]
10 compdef:136> [[ rdesktop = -P ]]
10 compdef:136> [[ rcsdiff = -P ]]
10 compdef:136> [[ rcp = -P ]]
10 compdef:136> [[ rc = -P ]]
10 compdef:136> [[ rake = -P ]]
10 compdef:136> [[ qiv = -P ]]
10 compdef:136> [[ pyhtmlizer = -P ]]
10 compdef:136> [[ pwgen = -P ]]
10 compdef:136> [[ pwdx = -P ]]
10 compdef:136> [[ pstotgif = -P ]]
10 compdef:136> [[ psselect = -P ]]
10 compdef:136> [[ psmulti = -P ]]
10 compdef:136> [[ ps2pdfwr = -P ]]
10 compdef:136> [[ ps2pdf14 = -P ]]
10 compdef:136> [[ ps2pdf13 = -P ]]
10 compdef:136> [[ prstat = -P ]]
10 compdef:136> [[ prompt = -P ]]
10 compdef:136> [[ printenv = -P ]]
10 compdef:136> [[ print = -P ]]
10 compdef:136> [[ portsnap = -P ]]
10 compdef:136> [[ portlint = -P ]]
10 compdef:136> [[ portaudit = -P ]]
10 compdef:136> [[ pon = -P ]]
10 compdef:136> [[ podpath = -P ]]
10 compdef:136> [[ podgrep = -P ]]
10 compdef:136> [[ pmvers = -P ]]
10 compdef:136> [[ pmpath = -P ]]
10 compdef:136> [[ pmload = -P ]]
10 compdef:136> [[ pmfunc = -P ]]
10 compdef:136> [[ pmeth = -P ]]
10 compdef:136> [[ pmap = -P ]]
10 compdef:136> [[ pman = -P ]]
10 compdef:136> [[ pkgadd = -P ]]
10 compdef:136> [[ pkg_create = -P ]]
10 compdef:136> [[ pixz = -P ]]
10 compdef:136> [[ ping6 = -P ]]
10 compdef:136> [[ ping = -P ]]
10 compdef:136> [[ pinfo = -P ]]
10 compdef:136> [[ pigz = -P ]]
10 compdef:136> [[ pidof = -P ]]
10 compdef:136> [[ picocom = -P ]]
10 compdef:136> [[ pick = -P ]]
10 compdef:136> [[ pgrep = -P ]]
10 compdef:136> [[ pg_restore = -P ]]
10 compdef:136> [[ pg_dumpall = -P ]]
10 compdef:136> [[ pg_dump = -P ]]
10 compdef:136> [[ pflags = -P ]]
10 compdef:136> [[ pfiles = -P ]]
10 compdef:136> [[ perl = -P ]]
10 compdef:136> [[ pdftops = -P ]]
10 compdef:136> [[ pdftk = -P ]]
10 compdef:136> [[ pdfopt = -P ]]
10 compdef:136> [[ pdfjadetex = -P ]]
10 compdef:136> [[ pdffonts = -P ]]
10 compdef:136> [[ pdf2dsc = -P ]]
10 compdef:136> [[ pcred = -P ]]
10 compdef:136> [[ pbuilder = -P ]]
10 compdef:136> [[ paste = -P ]]
10 compdef:136> [[ passwd = -P ]]
10 compdef:136> [[ parsehdlist = -P ]]
10 compdef:136> [[ otool = -P ]]
10 compdef:136> [[ osc = -P ]]
10 compdef:136> [[ opera-next = -P ]]
10 compdef:136> [[ oksh = -P ]]
10 compdef:136> [[ ogginfo = -P ]]
10 compdef:136> [[ oggenc = -P ]]
10 compdef:136> [[ oggdec = -P ]]
10 compdef:136> [[ ogg123 = -P ]]
10 compdef:136> [[ objdump = -P ]]
10 compdef:136> [[ nvram = -P ]]
10 compdef:136> [[ nvim = -P ]]
10 compdef:136> [[ numfmt = -P ]]
10 compdef:136> [[ nslookup = -P ]]
10 compdef:136> [[ ns = -P ]]
10 compdef:136> [[ npm = -P ]]
10 compdef:136> [[ nohup = -P ]]
10 compdef:136> [[ nmap = -P ]]
10 compdef:136> [[ ngrep = -P ]]
10 compdef:136> [[ nginx = -P ]]
10 compdef:136> [[ next = -P ]]
10 compdef:136> [[ neutron = -P ]]
10 compdef:136> [[ networksetup = -P ]]
10 compdef:136> [[ netscape = -P ]]
10 compdef:136> [[ netrik = -P ]]
10 compdef:136> [[ netcat = -P ]]
10 compdef:136> [[ nedit = -P ]]
10 compdef:136> [[ ncftp = -P ]]
10 compdef:136> [[ nc = -P ]]
10 compdef:136> [[ nawk = -P ]]
10 compdef:136> [[ nautilus = -P ]]
10 compdef:136> [[ native2ascii = -P ]]
10 compdef:136> [[ mysqlshow = -P ]]
10 compdef:136> [[ mysqladmin = -P ]]
10 compdef:136> [[ mvim = -P ]]
10 compdef:136> [[ mv = -P ]]
10 compdef:136> [[ munchlist = -P ]]
10 compdef:136> [[ mtype = -P ]]
10 compdef:136> [[ mtn = -P ]]
10 compdef:136> [[ mt = -P ]]
10 compdef:136> [[ msgchk = -P ]]
10 compdef:136> [[ mrd = -P ]]
10 compdef:136> [[ mpstat = -P ]]
10 compdef:136> [[ mpc = -P ]]
10 compdef:136> [[ mozilla-xremote-client = -P ]]
10 compdef:136> [[ mozilla-firefox = -P ]]
10 compdef:136> [[ mozilla = -P ]]
10 compdef:136> [[ mount = -P ]]
10 compdef:136> [[ mosh = -P ]]
10 compdef:136> [[ moosic = -P ]]
10 compdef:136> [[ montage = -P ]]
10 compdef:136> [[ monasca = -P ]]
10 compdef:136> [[ mogrify = -P ]]
10 compdef:136> [[ module-assistant = -P ]]
10 compdef:136> [[ module = -P ]]
10 compdef:136> [[ mmove = -P ]]
10 compdef:136> [[ mmd = -P ]]
10 compdef:136> [[ mlocate = -P ]]
10 compdef:136> [[ mkzsh.exe = -P ]]
10 compdef:136> [[ mktunes = -P ]]
10 compdef:136> [[ mktemp = -P ]]
10 compdef:136> [[ mkshortcut.exe = -P ]]
10 compdef:136> [[ mkshortcut = -P ]]
10 compdef:136> [[ mksh = -P ]]
10 compdef:136> [[ mkfifo = -P ]]
10 compdef:136> [[ mkdir = -P ]]
10 compdef:136> [[ mixerctl = -P ]]
10 compdef:136> [[ mistral = -P ]]
10 compdef:136> [[ mii-tool = -P ]]
10 compdef:136> [[ mhstore = -P ]]
10 compdef:136> [[ mhshow = -P ]]
10 compdef:136> [[ mhparam = -P ]]
10 compdef:136> [[ mhmail = -P ]]
10 compdef:136> [[ mhfixmsg = -P ]]
10 compdef:136> [[ mgv = -P ]]
10 compdef:136> [[ mergechanges = -P ]]
10 compdef:136> [[ mere = -P ]]
10 compdef:136> [[ mencal = -P ]]
10 compdef:136> [[ members = -P ]]
10 compdef:136> [[ mdutil = -P ]]
10 compdef:136> [[ mdu = -P ]]
10 compdef:136> [[ mdls = -P ]]
10 compdef:136> [[ mdeltree = -P ]]
10 compdef:136> [[ mdel = -P ]]
10 compdef:136> [[ mdadm = -P ]]
10 compdef:136> [[ md5 = -P ]]
10 compdef:136> [[ md4 = -P ]]
10 compdef:136> [[ mcd = -P ]]
10 compdef:136> [[ manila = -P ]]
10 compdef:136> [[ make-kpkg = -P ]]
10 compdef:136> [[ make = -P ]]
10 compdef:136> [[ mail = -P ]]
10 compdef:136> [[ magnum = -P ]]
10 compdef:136> [[ lzop = -P ]]
10 compdef:136> [[ lz4c32 = -P ]]
10 compdef:136> [[ lz4c = -P ]]
10 compdef:136> [[ lynx = -P ]]
10 compdef:136> [[ lunchy = -P ]]
10 compdef:136> [[ luarocks = -P ]]
10 compdef:136> [[ lua = -P ]]
10 compdef:136> [[ lsvg = -P ]]
10 compdef:136> [[ lspv = -P ]]
10 compdef:136> [[ lsof = -P ]]
10 compdef:136> [[ lslv = -P ]]
10 compdef:136> [[ lscfg = -P ]]
10 compdef:136> [[ ls = -P ]]
10 compdef:136> [[ lpstat = -P ]]
10 compdef:136> [[ lprm = -P ]]
10 compdef:136> [[ lpr = -P ]]
10 compdef:136> [[ lpq = -P ]]
10 compdef:136> [[ lpoptions = -P ]]
10 compdef:136> [[ look = -P ]]
10 compdef:136> [[ localedef = -P ]]
10 compdef:136> [[ locale = -P ]]
10 compdef:136> [[ llvm-otool = -P ]]
10 compdef:136> [[ llvm-objdump = -P ]]
10 compdef:136> [[ lldb = -P ]]
10 compdef:136> [[ lintian-info = -P ]]
10 compdef:136> [[ lintian = -P ]]
10 compdef:136> [[ limit = -P ]]
10 compdef:136> [[ light = -P ]]
10 compdef:136> [[ less = -P ]]
10 compdef:136> [[ ldd = -P ]]
10 compdef:136> [[ ldconfig = -P ]]
10 compdef:136> [[ latexmk = -P ]]
10 compdef:136> [[ ksh = -P ]]
10 compdef:136> [[ konqueror = -P ]]
10 compdef:136> [[ knock = -P ]]
10 compdef:136> [[ knife = -P ]]
10 compdef:136> [[ kldload = -P ]]
10 compdef:136> [[ kioclient = -P ]]
10 compdef:136> [[ killall5 = -P ]]
10 compdef:136> [[ kill = -P ]]
10 compdef:136> [[ kfmclient = -P ]]
10 compdef:136> [[ keystone = -P ]]
10 compdef:136> [[ kdeconnect-cli = -P ]]
10 compdef:136> [[ jot = -P ]]
10 compdef:136> [[ jonas = -P ]]
10 compdef:136> [[ joe = -P ]]
10 compdef:136> [[ jmeter = -P ]]
10 compdef:136> [[ javadoc = -P ]]
10 compdef:136> [[ javac = -P ]]
10 compdef:136> [[ java = -P ]]
10 compdef:136> [[ jarsigner = -P ]]
10 compdef:136> [[ jail = -P ]]
10 compdef:136> [[ iwconfig = -P ]]
10 compdef:136> [[ ispell = -P ]]
10 compdef:136> [[ ironic = -P ]]
10 compdef:136> [[ iptables-save = -P ]]
10 compdef:136> [[ iptables-restore = -P ]]
10 compdef:136> [[ iptables = -P ]]
10 compdef:136> [[ ipset = -P ]]
10 compdef:136> [[ ipkg = -P ]]
10 compdef:136> [[ ipadm = -P ]]
10 compdef:136> [[ ip6tables-save = -P ]]
10 compdef:136> [[ ip6tables-restore = -P ]]
10 compdef:136> [[ ip6tables = -P ]]
10 compdef:136> [[ ip = -P ]]
10 compdef:136> [[ iostat = -P ]]
10 compdef:136> [[ ionice = -P ]]
10 compdef:136> [[ inxi = -P ]]
10 compdef:136> [[ invoke-rc.d = -P ]]
10 compdef:136> [[ installpkg = -P ]]
10 compdef:136> [[ install-info = -P ]]
10 compdef:136> [[ install = -P ]]
10 compdef:136> [[ insmod = -P ]]
10 compdef:136> [[ initdb = -P ]]
10 compdef:136> [[ initctl = -P ]]
10 compdef:136> [[ info = -P ]]
10 compdef:136> [[ inetadm = -P ]]
10 compdef:136> [[ includeres = -P ]]
10 compdef:136> [[ import = -P ]]
10 compdef:136> [[ ifup = -P ]]
10 compdef:136> [[ iftop = -P ]]
10 compdef:136> [[ ifdown = -P ]]
10 compdef:136> [[ ifconfig = -P ]]
10 compdef:136> [[ id = -P ]]
10 compdef:136> [[ iconv = -P ]]
10 compdef:136> [[ icombine = -P ]]
10 compdef:136> [[ ibus = -P ]]
10 compdef:136> [[ hwinfo = -P ]]
10 compdef:136> [[ http = -P ]]
10 compdef:136> [[ htop = -P ]]
10 compdef:136> [[ hotjava = -P ]]
10 compdef:136> [[ hostname = -P ]]
10 compdef:136> [[ host = -P ]]
10 compdef:136> [[ hledger = -P ]]
10 compdef:136> [[ hilite = -P ]]
10 compdef:136> [[ hexdump = -P ]]
10 compdef:136> [[ heroku = -P ]]
10 compdef:136> [[ hdiutil = -P ]]
10 compdef:136> [[ hd = -P ]]
10 compdef:136> [[ gzgrep = -P ]]
10 compdef:136> [[ gvimdiff = -P ]]
10 compdef:136> [[ guptime = -P ]]
10 compdef:136> [[ gunzip = -P ]]
10 compdef:136> [[ gunexpand = -P ]]
10 compdef:136> [[ guname = -P ]]
10 compdef:136> [[ gtouch = -P ]]
10 compdef:136> [[ gtail = -P ]]
10 compdef:136> [[ gsort = -P ]]
10 compdef:136> [[ gshred = -P ]]
10 compdef:136> [[ gsdj = -P ]]
10 compdef:136> [[ gsbj = -P ]]
10 compdef:136> [[ gs = -P ]]
10 compdef:136> [[ groupmod = -P ]]
10 compdef:136> [[ groupadd = -P ]]
10 compdef:136> [[ groff = -P ]]
10 compdef:136> [[ grep-excuses = -P ]]
10 compdef:136> [[ grep = -P ]]
10 compdef:136> [[ greadlink = -P ]]
10 compdef:136> [[ grail = -P ]]
10 compdef:136> [[ gradlew = -P ]]
10 compdef:136> [[ gradle = -P ]]
10 compdef:136> [[ gpgv = -P ]]
10 compdef:136> [[ gpg = -P ]]
10 compdef:136> [[ gpasswd = -P ]]
10 compdef:136> [[ google = -P ]]
10 compdef:136> [[ go = -P ]]
10 compdef:136> [[ gnutls-cli-debug = -P ]]
10 compdef:136> [[ gnutls-cli = -P ]]
10 compdef:136> [[ gnupod_search = -P ]]
10 compdef:136> [[ gnupod_addsong = -P ]]
10 compdef:136> [[ gnupod_INIT = -P ]]
10 compdef:136> [[ gnome-gv = -P ]]
10 compdef:136> [[ gnl = -P ]]
10 compdef:136> [[ gmplayer = -P ]]
10 compdef:136> [[ gmktemp = -P ]]
10 compdef:136> [[ gmkdir = -P ]]
10 compdef:136> [[ gmake = -P ]]
10 compdef:136> [[ gm = -P ]]
10 compdef:136> [[ global = -P ]]
10 compdef:136> [[ glances = -P ]]
10 compdef:136> [[ git-revise = -P ]]
10 compdef:136> [[ git-journal = -P ]]
10 compdef:136> [[ git-flow = -P ]]
10 compdef:136> [[ git-buildpackage = -P ]]
10 compdef:136> [[ ginstall = -P ]]
10 compdef:136> [[ ghostscript = -P ]]
10 compdef:136> [[ ghead = -P ]]
10 compdef:136> [[ ggetopt = -P ]]
10 compdef:136> [[ gfold = -P ]]
10 compdef:136> [[ gfgrep = -P ]]
10 compdef:136> [[ getopt = -P ]]
10 compdef:136> [[ getfacl.exe = -P ]]
10 compdef:136> [[ getfacl = -P ]]
10 compdef:136> [[ getent = -P ]]
10 compdef:136> [[ getconf = -P ]]
10 compdef:136> [[ getclip.exe = -P ]]
10 compdef:136> [[ getclip = -P ]]
10 compdef:136> [[ genisoimage = -P ]]
10 compdef:136> [[ gem = -P ]]
10 compdef:136> [[ gegrep = -P ]]
10 compdef:136> [[ geany = -P ]]
10 compdef:136> [[ gdb = -P ]]
10 compdef:136> [[ gcut = -P ]]
10 compdef:136> [[ gcore = -P ]]
10 compdef:136> [[ gbasename = -P ]]
10 compdef:136> [[ gbase64 = -P ]]
10 compdef:136> [[ gawk = -P ]]
10 compdef:136> [[ gas = -P ]]
10 compdef:136> [[ galeon = -P ]]
10 compdef:136> [[ g++ = -P ]]
10 compdef:136> [[ fwupdmgr = -P ]]
10 compdef:136> [[ fwhois = -P ]]
10 compdef:136> [[ fw_update = -P ]]
10 compdef:136> [[ fusermount = -P ]]
10 compdef:136> [[ fsh = -P ]]
10 compdef:136> [[ freebsd-update = -P ]]
10 compdef:136> [[ free = -P ]]
10 compdef:136> [[ forw = -P ]]
10 compdef:136> [[ folders = -P ]]
10 compdef:136> [[ folder = -P ]]
10 compdef:136> [[ fold = -P ]]
10 compdef:136> [[ fmt = -P ]]
10 compdef:136> [[ fmadm = -P ]]
10 compdef:136> [[ flowadm = -P ]]
10 compdef:136> [[ flex = -P ]]
10 compdef:136> [[ fleetctl = -P ]]
10 compdef:136> [[ flac = -P ]]
10 compdef:136> [[ fixwwps = -P ]]
10 compdef:136> [[ fixwfwps = -P ]]
10 compdef:136> [[ fixtpps = -P ]]
10 compdef:136> [[ fixpspps = -P ]]
10 compdef:136> [[ fixfmps = -P ]]
10 compdef:136> [[ fixdlsrps = -P ]]
10 compdef:136> [[ firefox = -P ]]
10 compdef:136> [[ fink = -P ]]
10 compdef:136> [[ findmnt = -P ]]
10 compdef:136> [[ findaffix = -P ]]
10 compdef:136> [[ find = -P ]]
10 compdef:136> [[ ffind = -P ]]
10 compdef:136> [[ fetchmail = -P ]]
10 compdef:136> [[ fetch = -P ]]
10 compdef:136> [[ feh = -P ]]
10 compdef:136> [[ fc = -P ]]
10 compdef:136> [[ false = -P ]]
10 compdef:136> [[ fakeroot = -P ]]
10 compdef:136> [[ fail2ban-client = -P ]]
10 compdef:136> [[ fab = -P ]]
10 compdef:136> [[ extcheck = -P ]]
10 compdef:136> [[ express = -P ]]
10 compdef:136> [[ exportfs = -P ]]
10 compdef:136> [[ expand = -P ]]
10 compdef:136> [[ eval = -P ]]
10 compdef:136> [[ eu-strings = -P ]]
10 compdef:136> [[ eu-readelf = -P ]]
10 compdef:136> [[ eu-objdump = -P ]]
10 compdef:136> [[ epsffit = -P ]]
10 compdef:136> [[ env = -P ]]
10 compdef:136> [[ enable = -P ]]
10 compdef:136> [[ emulator = -P ]]
10 compdef:136> [[ egrep = -P ]]
10 compdef:136> [[ echoti = -P ]]
10 compdef:136> [[ ecdsautil = -P ]]
10 compdef:136> [[ dvc = -P ]]
10 compdef:136> [[ dupload = -P ]]
10 compdef:136> [[ dtrace = -P ]]
10 compdef:136> [[ dropuser = -P ]]
10 compdef:136> [[ dosread = -P ]]
10 compdef:136> [[ docpad = -P ]]
10 compdef:136> [[ dockerd = -P ]]
10 compdef:136> [[ docker-compose = -P ]]
10 compdef:136> [[ dnf = -P ]]
10 compdef:136> [[ display = -P ]]
10 compdef:136> [[ disown = -P ]]
10 compdef:136> [[ dircmp = -P ]]
10 compdef:136> [[ dget = -P ]]
10 compdef:136> [[ deno = -P ]]
10 compdef:136> [[ dcopobject = -P ]]
10 compdef:136> [[ dcopfind = -P ]]
10 compdef:136> [[ dbus-send = -P ]]
10 compdef:136> [[ dad = -P ]]
10 compdef:136> [[ crsh = -P ]]
10 compdef:136> [[ console = -P ]]
10 compdef:136> [[ conan = -P ]]
10 compdef:136> [[ composite = -P ]]
10 compdef:136> [[ composer = -P ]]
10 compdef:136> [[ comp = -P ]]
10 compdef:136> [[ combinediff = -P ]]
10 compdef:136> [[ combine = -P ]]
10 compdef:136> [[ co = -P ]]
10 compdef:136> [[ clusterdb = -P ]]
10 compdef:136> [[ clang++ = -P ]]
10 compdef:136> [[ cifsiostat = -P ]]
10 compdef:136> [[ chromium = -P ]]
10 compdef:136> [[ choc = -P ]]
10 compdef:136> [[ chimera = -P ]]
10 compdef:136> [[ cf = -P ]]
10 compdef:136> [[ certtool = -P ]]
10 compdef:136> [[ ccache = -P ]]
10 compdef:136> [[ cap = -P ]]
10 compdef:136> [[ bzip2recover = -P ]]
10 compdef:136> [[ bzip2 = -P ]]
10 compdef:136> [[ bzgrep = -P ]]
10 compdef:136> [[ bzfgrep = -P ]]
10 compdef:136> [[ bzegrep = -P ]]
10 compdef:136> [[ burst = -P ]]
10 compdef:136> [[ builtin = -P ]]
10 compdef:136> [[ buildhash = -P ]]
10 compdef:136> [[ bttrack = -P ]]
10 compdef:136> [[ btshowmetainfo = -P ]]
10 compdef:136> [[ bts = -P ]]
10 compdef:136> [[ btrename = -P ]]
10 compdef:136> [[ btreannounce = -P ]]
10 compdef:136> [[ btmakemetafile = -P ]]
10 compdef:136> [[ btlaunchmanycurses = -P ]]
10 compdef:136> [[ btdownloadheadless = -P ]]
10 compdef:136> [[ btdownloadgui = -P ]]
10 compdef:136> [[ btdownloadcurses = -P ]]
10 compdef:136> [[ bsdtar = -P ]]
10 compdef:136> [[ brew = -P ]]
10 compdef:136> [[ brctl = -P ]]
10 compdef:136> [[ bpython2-urwid = -P ]]
10 compdef:136> [[ bpython2 = -P ]]
10 compdef:136> [[ bpython-gtk = -P ]]
10 compdef:136> [[ bogotune = -P ]]
10 compdef:136> [[ bitcoin-cli = -P ]]
10 compdef:136> [[ baz = -P ]]
10 compdef:136> [[ bash = -P ]]
10 compdef:136> [[ base32 = -P ]]
10 compdef:136> [[ axi-cache = -P ]]
10 compdef:136> [[ aws = -P ]]
10 compdef:136> [[ awk = -P ]]
10 compdef:136> [[ avahi-resolve-host-name = -P ]]
10 compdef:136> [[ avahi-resolve-address = -P ]]
10 compdef:136> [[ avahi-resolve = -P ]]
10 compdef:136> [[ avahi-browse-domains = -P ]]
10 compdef:136> [[ avahi-browse = -P ]]
10 compdef:136> [[ autoload = -P ]]
10 compdef:136> [[ auto-apt = -P ]]
10 compdef:136> [[ augtool = -P ]]
10 compdef:136> [[ atach = -P ]]
10 compdef:136> [[ asciinema = -P ]]
10 compdef:136> [[ asciidoctor = -P ]]
10 compdef:136> [[ artisan = -P ]]
10 compdef:136> [[ arena = -P ]]
10 compdef:136> [[ apt-show-versions = -P ]]
10 compdef:136> [[ apt-mark = -P ]]
10 compdef:136> [[ apt-get = -P ]]
10 compdef:136> [[ apt-file = -P ]]
10 compdef:136> [[ apt-cache = -P ]]
10 compdef:136> [[ apt = -P ]]
10 compdef:136> [[ aplay = -P ]]
10 compdef:136> [[ apache2ctl = -P ]]
10 compdef:136> [[ antiword = -P ]]
10 compdef:136> [[ ant = -P ]]
10 compdef:136> [[ ansible-vault = -P ]]
10 compdef:136> [[ ansible-pull = -P ]]
10 compdef:136> [[ ansible-playbook = -P ]]
10 compdef:136> [[ ansible-inventory = -P ]]
10 compdef:136> [[ ansible-galaxy = -P ]]
10 compdef:136> [[ ansible-doc = -P ]]
10 compdef:136> [[ ansible-config = -P ]]
10 compdef:136> [[ ansible = -P ]]
10 compdef:136> [[ anno = -P ]]
10 compdef:136> [[ android = -P ]]
10 compdef:136> [[ analyseplugin = -P ]]
10 compdef:136> [[ acroread = -P ]]
10 compdef:136> [[ acpitool = -P ]]
10 compdef:136> [[ acpi = -P ]]
10 compdef:136> [[ ack-standalone = -P ]]
10 compdef:136> [[ ack = -P ]]
10 compdef:136> [[ abcde = -P ]]
10 compdef:136> [[ aaaa = -P ]]
10 compdef:136> [[ _cockroach = -P ]]
10 compdef:136> [[ SuSEconfig = -P ]]
10 compdef:136> [[ Mosaic = -P ]]
10 compdef:136> [[ 8l = -P ]]
10 compdef:136> [[ 6l = -P ]]
10 compdef:136> [[ -zcalc-line- = -P ]]
10 compdef:136> [[ -vared- = -P ]]
10 compdef:136> [[ -value-,XZ_OPT,-default- = -P ]]
10 compdef:136> [[ -value-,TZ,-default- = -P ]]
10 compdef:136> [[ -value-,RPS1,-default- = -P ]]
10 compdef:136> [[ -value-,PS4,-default- = -P ]]
10 compdef:136> [[ -value-,PS3,-default- = -P ]]
10 compdef:136> [[ -value-,PS2,-default- = -P ]]
10 compdef:136> [[ -value-,PROMPT,-default- = -P ]]
10 compdef:136> [[ -value-,PERLDOC,-default- = -P ]]
10 compdef:136> [[ -value-,P4USER,-default- = -P ]]
10 compdef:136> [[ -value-,P4PORT,-default- = -P ]]
10 compdef:136> [[ -value-,P4MERGE,-default- = -P ]]
10 compdef:136> [[ -value-,LPDEST,-default- = -P ]]
10 compdef:136> [[ -value-,CFLAGS,-default- = -P ]]
10 compdef:136> [[ -value-,ADB_TRACE,-default- = -P ]]
10 compdef:136> [[ -value- = -P ]]
10 compdef:136> [[ -tilde- = -P ]]
10 compdef:136> [[ -subscript- = -P ]]
10 compdef:136> [[ -redirect- = -P ]]
10 compdef:136> [[ -parameter- = -P ]]
10 compdef:136> [[ -first- = -P ]]
10 compdef:136> [[ -command-line- = -P ]]
10 compdef:136> [[ -assign-parameter- = -P ]]
10 compdef:136> [[ -array-value- = -P ]]
10 compdef:136> [[ -P = -P ]]
10 compdef:136> [[ -P = -P ]]
10 compdef:136> [[ 'zf*' = -P ]]
10 compdef:136> [[ 'yodl(|2*)' = -P ]]
10 compdef:136> [[ 'xelatex=latex' = -P ]]
10 compdef:136> [[ 'unlzma=unxz' = -P ]]
10 compdef:136> [[ 'tunes2pod.pl=tunes2pod' = -P ]]
10 compdef:136> [[ 'svnlite=svn' = -P ]]
10 compdef:136> [[ 'slogin=ssh' = -P ]]
10 compdef:136> [[ 'shasum(|5).*' = -P ]]
10 compdef:136> [[ 'qemu(|-system-*)' = -P ]]
10 compdef:136> [[ 'python[0-9.]#' = -P ]]
10 compdef:136> [[ 'pydoc[0-9.]#' = -P ]]
10 compdef:136> [[ 'php[0-9.-]' = -P ]]
10 compdef:136> [[ 'pcat=unpack' = -P ]]
10 compdef:136> [[ 'nedit-nc=nc' = -P ]]
10 compdef:136> [[ 'ncl=nc' = -P ]]
10 compdef:136> [[ 'nail=mail' = -P ]]
10 compdef:136> [[ 'mktunes.pl=mktunes' = -P ]]
10 compdef:136> [[ 'mailx=mail' = -P ]]
10 compdef:136> [[ 'lzma=xz' = -P ]]
10 compdef:136> [[ 'lua[0-9.-]##' = -P ]]
10 compdef:136> [[ 'iceweasel=firefox' = -P ]]
10 compdef:136> [[ 'gpg2=gpg' = -P ]]
10 compdef:136> [[ 'gnupod_search.pl=gnupod_search' = -P ]]
10 compdef:136> [[ 'gem[0-9.]#' = -P ]]
10 compdef:136> [[ 'gcc-*' = -P ]]
10 compdef:136> [[ 'g++-*' = -P ]]
10 compdef:136> [[ 'bzcat=bunzip2' = -P ]]
10 compdef:136> [[ 'Mail=mail' = -P ]]
10 compdef:136> [[ '-value-,CGO*,-default-' = -P ]]
10 compdef:136> [[ '-redirect-,>,compress=uncompress' = -P ]]
10 compdef:136> [[ '-redirect-,<,xz=xz' = -P ]]
10 compdef:136> [[ '-redirect-,<,unxz=unxz' = -P ]]
10 compdef:136> [[ '*/(init|rc[0-9S]#).d/*' = -P ]]
10 compdef:136> [[ '(ruby|[ei]rb)[0-9.]#' = -P ]]
10 compdef:136> [[ '(p[bgpn]m*|*top[bgpn]m)' = -P ]]
10 compdef:134> [[ zun = -p ]]
10 compdef:134> [[ zlistattr = -p ]]
10 compdef:134> [[ zf_mkdir = -p ]]
10 compdef:134> [[ zdump = -p ]]
10 compdef:134> [[ zdelattr = -p ]]
10 compdef:134> [[ zcp = -p ]]
10 compdef:134> [[ yumdb = -p ]]
10 compdef:134> [[ ypbind = -p ]]
10 compdef:134> [[ xwud = -p ]]
10 compdef:134> [[ xwd = -p ]]
10 compdef:134> [[ xview = -p ]]
10 compdef:134> [[ xterm = -p ]]
10 compdef:134> [[ xrdb = -p ]]
10 compdef:134> [[ xprop = -p ]]
10 compdef:134> [[ xon = -p ]]
10 compdef:134> [[ xkill = -p ]]
10 compdef:134> [[ xhost = -p ]]
10 compdef:134> [[ xfontsel = -p ]]
10 compdef:134> [[ xfd = -p ]]
10 compdef:134> [[ xev = -p ]]
10 compdef:134> [[ write = -p ]]
10 compdef:134> [[ who = -p ]]
10 compdef:134> [[ which = -p ]]
10 compdef:134> [[ whereis = -p ]]
10 compdef:134> [[ where = -p ]]
10 compdef:134> [[ w3m = -p ]]
10 compdef:134> [[ vpnc-connect = -p ]]
10 compdef:134> [[ vncserver = -p ]]
10 compdef:134> [[ vmstat = -p ]]
10 compdef:134> [[ vmctl = -p ]]
10 compdef:134> [[ visudo = -p ]]
10 compdef:134> [[ virt-pki-validate = -p ]]
10 compdef:134> [[ virt-host-validate = -p ]]
10 compdef:134> [[ virt-admin = -p ]]
10 compdef:134> [[ vim-addons = -p ]]
10 compdef:134> [[ vim = -p ]]
10 compdef:134> [[ vcsh = -p ]]
10 compdef:134> [[ vared = -p ]]
10 compdef:134> [[ valgrind = -p ]]
10 compdef:134> [[ userdel = -p ]]
10 compdef:134> [[ urxvt256c-mlc = -p ]]
10 compdef:134> [[ urxvt256c-ml = -p ]]
10 compdef:134> [[ urxvt256c = -p ]]
10 compdef:134> [[ urpmi.removemedia = -p ]]
10 compdef:134> [[ urpmi.addmedia = -p ]]
10 compdef:134> [[ urpmf = -p ]]
10 compdef:134> [[ uptime = -p ]]
10 compdef:134> [[ update-rc.d = -p ]]
10 compdef:134> [[ update-alternatives = -p ]]
10 compdef:134> [[ unxz = -p ]]
10 compdef:134> [[ unset = -p ]]
10 compdef:134> [[ unpigz = -p ]]
10 compdef:134> [[ unpack = -p ]]
10 compdef:134> [[ unix2mac = -p ]]
10 compdef:134> [[ units = -p ]]
10 compdef:134> [[ unison = -p ]]
10 compdef:134> [[ uniq = -p ]]
10 compdef:134> [[ uname = -p ]]
10 compdef:134> [[ unalias = -p ]]
10 compdef:134> [[ ulimit = -p ]]
10 compdef:134> [[ twist = -p ]]
10 compdef:134> [[ twidge = -p ]]
10 compdef:134> [[ tunes2pod = -p ]]
10 compdef:134> [[ tune2fs = -p ]]
10 compdef:134> [[ true = -p ]]
10 compdef:134> [[ trash = -p ]]
10 compdef:134> [[ trap = -p ]]
10 compdef:134> [[ tracepath6 = -p ]]
10 compdef:134> [[ tracepath = -p ]]
10 compdef:134> [[ tput = -p ]]
10 compdef:134> [[ tmux = -p ]]
10 compdef:134> [[ tex = -p ]]
10 compdef:134> [[ tee = -p ]]
10 compdef:134> [[ tcsh = -p ]]
10 compdef:134> [[ tcptraceroute = -p ]]
10 compdef:134> [[ tcpdump = -p ]]
10 compdef:134> [[ talk = -p ]]
10 compdef:134> [[ tail = -p ]]
10 compdef:134> [[ tac = -p ]]
10 compdef:134> [[ systat = -p ]]
10 compdef:134> [[ sysctl = -p ]]
10 compdef:134> [[ swiftc = -p ]]
10 compdef:134> [[ svn-buildpackage = -p ]]
10 compdef:134> [[ svn = -p ]]
10 compdef:134> [[ svcs = -p ]]
10 compdef:134> [[ subl = -p ]]
10 compdef:134> [[ su = -p ]]
10 compdef:134> [[ stty = -p ]]
10 compdef:134> [[ strings = -p ]]
10 compdef:134> [[ strftime = -p ]]
10 compdef:134> [[ strace = -p ]]
10 compdef:134> [[ status = -p ]]
10 compdef:134> [[ stat = -p ]]
10 compdef:134> [[ sshfs = -p ]]
10 compdef:134> [[ ssh-keygen = -p ]]
10 compdef:134> [[ ssh-copy-id = -p ]]
10 compdef:134> [[ ssh-agent = -p ]]
10 compdef:134> [[ ssh = -p ]]
10 compdef:134> [[ ss = -p ]]
10 compdef:134> [[ split = -p ]]
10 compdef:134> [[ spamassassin = -p ]]
10 compdef:134> [[ sockstat = -p ]]
10 compdef:134> [[ socket = -p ]]
10 compdef:134> [[ snoop = -p ]]
10 compdef:134> [[ smitty = -p ]]
10 compdef:134> [[ smit = -p ]]
10 compdef:134> [[ smartctl = -p ]]
10 compdef:134> [[ slrn = -p ]]
10 compdef:134> [[ slabtop = -p ]]
10 compdef:134> [[ skein512 = -p ]]
10 compdef:134> [[ sisu = -p ]]
10 compdef:134> [[ signify = -p ]]
10 compdef:134> [[ shutdown = -p ]]
10 compdef:134> [[ shuf = -p ]]
10 compdef:134> [[ showchar = -p ]]
10 compdef:134> [[ shasum = -p ]]
10 compdef:134> [[ sha512t256 = -p ]]
10 compdef:134> [[ sha256 = -p ]]
10 compdef:134> [[ sha1 = -p ]]
10 compdef:134> [[ sh = -p ]]
10 compdef:134> [[ sftp = -p ]]
10 compdef:134> [[ setopt = -p ]]
10 compdef:134> [[ setfattr = -p ]]
10 compdef:134> [[ setfacl = -p ]]
10 compdef:134> [[ set = -p ]]
10 compdef:134> [[ seq = -p ]]
10 compdef:134> [[ seaf-cli = -p ]]
10 compdef:134> [[ scriptreplay = -p ]]
10 compdef:134> [[ screen = -p ]]
10 compdef:134> [[ scons = -p ]]
10 compdef:134> [[ schedtool = -p ]]
10 compdef:134> [[ scan = -p ]]
10 compdef:134> [[ scalac = -p ]]
10 compdef:134> [[ sbuild = -p ]]
10 compdef:134> [[ rwho = -p ]]
10 compdef:134> [[ ruby-mri = -p ]]
10 compdef:134> [[ ruby = -p ]]
10 compdef:134> [[ rubber-pipe = -p ]]
10 compdef:134> [[ rsync = -p ]]
10 compdef:134> [[ rrdtool = -p ]]
10 compdef:134> [[ rpmbuild = -p ]]
10 compdef:134> [[ rmid = -p ]]
10 compdef:134> [[ rmdir = -p ]]
10 compdef:134> [[ rmadison = -p ]]
10 compdef:134> [[ restart = -p ]]
10 compdef:134> [[ reprepro = -p ]]
10 compdef:134> [[ renice = -p ]]
10 compdef:134> [[ removepkg = -p ]]
10 compdef:134> [[ reload = -p ]]
10 compdef:134> [[ reindexdb = -p ]]
10 compdef:134> [[ rec = -p ]]
10 compdef:134> [[ rebootin = -p ]]
10 compdef:134> [[ read = -p ]]
10 compdef:134> [[ rdesktop = -p ]]
10 compdef:134> [[ rar = -p ]]
10 compdef:134> [[ quilt = -p ]]
10 compdef:134> [[ querybts = -p ]]
10 compdef:134> [[ pwgen = -p ]]
10 compdef:134> [[ putclip.exe = -p ]]
10 compdef:134> [[ pushd = -p ]]
10 compdef:134> [[ pswrap = -p ]]
10 compdef:134> [[ pstop = -p ]]
10 compdef:134> [[ pstack = -p ]]
10 compdef:134> [[ pscp.exe = -p ]]
10 compdef:134> [[ pscp = -p ]]
10 compdef:134> [[ ps2pdf13 = -p ]]
10 compdef:134> [[ ps2epsi = -p ]]
10 compdef:134> [[ ps = -p ]]
10 compdef:134> [[ prompt = -p ]]
10 compdef:134> [[ procstat = -p ]]
10 compdef:134> [[ print = -p ]]
10 compdef:134> [[ powerd = -p ]]
10 compdef:134> [[ postsuper = -p ]]
10 compdef:134> [[ portaudit = -p ]]
10 compdef:134> [[ pmvers = -p ]]
10 compdef:134> [[ pmpath = -p ]]
10 compdef:134> [[ pmload = -p ]]
10 compdef:134> [[ pmdesc = -p ]]
10 compdef:134> [[ pmap = -p ]]
10 compdef:134> [[ plutil = -p ]]
10 compdef:134> [[ pldd = -p ]]
10 compdef:134> [[ pkill = -p ]]
10 compdef:134> [[ pkgrm = -p ]]
10 compdef:134> [[ pkgin = -p ]]
10 compdef:134> [[ pkgadd = -p ]]
10 compdef:134> [[ pkg_info = -p ]]
10 compdef:134> [[ pkg_delete = -p ]]
10 compdef:134> [[ pkg = -p ]]
10 compdef:134> [[ piuparts = -p ]]
10 compdef:134> [[ ping = -p ]]
10 compdef:134> [[ pinef = -p ]]
10 compdef:134> [[ pine = -p ]]
10 compdef:134> [[ pg_restore = -p ]]
10 compdef:134> [[ pg_dump = -p ]]
10 compdef:134> [[ pfctl = -p ]]
10 compdef:134> [[ pdksh = -p ]]
10 compdef:134> [[ pdftotext = -p ]]
10 compdef:134> [[ pdftk = -p ]]
10 compdef:134> [[ patch = -p ]]
10 compdef:134> [[ paste = -p ]]
10 compdef:134> [[ passwd = -p ]]
10 compdef:134> [[ parsehdlist = -p ]]
10 compdef:134> [[ pandoc = -p ]]
10 compdef:134> [[ pack = -p ]]
10 compdef:134> [[ p4 = -p ]]
10 compdef:134> [[ otool = -p ]]
10 compdef:134> [[ osc = -p ]]
10 compdef:134> [[ osascript = -p ]]
10 compdef:134> [[ opera-next = -p ]]
10 compdef:134> [[ omz = -p ]]
10 compdef:134> [[ oggenc = -p ]]
10 compdef:134> [[ odme = -p ]]
10 compdef:134> [[ nslookup = -p ]]
10 compdef:134> [[ npm = -p ]]
10 compdef:134> [[ nmap = -p ]]
10 compdef:134> [[ ngrep = -p ]]
10 compdef:134> [[ new = -p ]]
10 compdef:134> [[ netscape = -p ]]
10 compdef:134> [[ nedit = -p ]]
10 compdef:134> [[ native2ascii = -p ]]
10 compdef:134> [[ mysqlimport = -p ]]
10 compdef:134> [[ mysqldiff = -p ]]
10 compdef:134> [[ mv = -p ]]
10 compdef:134> [[ mush = -p ]]
10 compdef:134> [[ murano = -p ]]
10 compdef:134> [[ munchlist = -p ]]
10 compdef:134> [[ mtype = -p ]]
10 compdef:134> [[ mtoolstest = -p ]]
10 compdef:134> [[ mtn = -p ]]
10 compdef:134> [[ mt = -p ]]
10 compdef:134> [[ mread = -p ]]
10 compdef:134> [[ mr = -p ]]
10 compdef:134> [[ mpstat = -p ]]
10 compdef:134> [[ mozilla-xremote-client = -p ]]
10 compdef:134> [[ mosh = -p ]]
10 compdef:134> [[ module-assistant = -p ]]
10 compdef:134> [[ mmount = -p ]]
10 compdef:134> [[ mmm = -p ]]
10 compdef:134> [[ mktunes = -p ]]
10 compdef:134> [[ mkshortcut.exe = -p ]]
10 compdef:134> [[ mkshortcut = -p ]]
10 compdef:134> [[ mksh = -p ]]
10 compdef:134> [[ mknod = -p ]]
10 compdef:134> [[ mixerctl = -p ]]
10 compdef:134> [[ mhfixmsg = -p ]]
10 compdef:134> [[ metaflac = -p ]]
10 compdef:134> [[ mergechanges = -p ]]
10 compdef:134> [[ mdutil = -p ]]
10 compdef:134> [[ mdls = -p ]]
10 compdef:134> [[ mdir = -p ]]
10 compdef:134> [[ mdeltree = -p ]]
10 compdef:134> [[ md2 = -p ]]
10 compdef:134> [[ mcopy = -p ]]
10 compdef:134> [[ mattrib = -p ]]
10 compdef:134> [[ manage.py = -p ]]
10 compdef:134> [[ make = -p ]]
10 compdef:134> [[ m-a = -p ]]
10 compdef:134> [[ lzop = -p ]]
10 compdef:134> [[ lua = -p ]]
10 compdef:134> [[ lsof = -p ]]
10 compdef:134> [[ lscfg = -p ]]
10 compdef:134> [[ lsblk = -p ]]
10 compdef:134> [[ ls = -p ]]
10 compdef:134> [[ loadkeys = -p ]]
10 compdef:134> [[ llvm-g++ = -p ]]
10 compdef:134> [[ lldb = -p ]]
10 compdef:134> [[ linux = -p ]]
10 compdef:134> [[ links2 = -p ]]
10 compdef:134> [[ limit = -p ]]
10 compdef:134> [[ lighty-disable-mod = -p ]]
10 compdef:134> [[ lftp = -p ]]
10 compdef:134> [[ less = -p ]]
10 compdef:134> [[ kpartx = -p ]]
10 compdef:134> [[ knock = -p ]]
10 compdef:134> [[ knife = -p ]]
10 compdef:134> [[ kldunload = -p ]]
10 compdef:134> [[ kioclient = -p ]]
10 compdef:134> [[ keytool = -p ]]
10 compdef:134> [[ kak = -p ]]
10 compdef:134> [[ jrnl = -p ]]
10 compdef:134> [[ jonas = -p ]]
10 compdef:134> [[ jmeter = -p ]]
10 compdef:134> [[ isag = -p ]]
10 compdef:134> [[ iptables-save = -p ]]
10 compdef:134> [[ iptables = -p ]]
10 compdef:134> [[ ipset = -p ]]
10 compdef:134> [[ ipadm = -p ]]
10 compdef:134> [[ ip6tables-restore = -p ]]
10 compdef:134> [[ installpkg = -p ]]
10 compdef:134> [[ install-info = -p ]]
10 compdef:134> [[ install = -p ]]
10 compdef:134> [[ ijoin = -p ]]
10 compdef:134> [[ ifup = -p ]]
10 compdef:134> [[ ifdown = -p ]]
10 compdef:134> [[ id = -p ]]
10 compdef:134> [[ icombine = -p ]]
10 compdef:134> [[ hwinfo = -p ]]
10 compdef:134> [[ homestead = -p ]]
10 compdef:134> [[ helm = -p ]]
10 compdef:134> [[ heat = -p ]]
10 compdef:134> [[ hd = -p ]]
10 compdef:134> [[ gzilla = -p ]]
10 compdef:134> [[ gzegrep = -p ]]
10 compdef:134> [[ gvimdiff = -p ]]
10 compdef:134> [[ guilt-rm = -p ]]
10 compdef:134> [[ guilt-prev = -p ]]
10 compdef:134> [[ guilt-pop = -p ]]
10 compdef:134> [[ guilt-fold = -p ]]
10 compdef:134> [[ guilt-add = -p ]]
10 compdef:134> [[ gtty = -p ]]
10 compdef:134> [[ gstty = -p ]]
10 compdef:134> [[ gslj = -p ]]
10 compdef:134> [[ gsdj = -p ]]
10 compdef:134> [[ gsbj = -p ]]
10 compdef:134> [[ gs = -p ]]
10 compdef:134> [[ groupadd = -p ]]
10 compdef:134> [[ grmdir = -p ]]
10 compdef:134> [[ gradlew = -p ]]
10 compdef:134> [[ gprof = -p ]]
10 compdef:134> [[ google = -p ]]
10 compdef:134> [[ god = -p ]]
10 compdef:134> [[ go = -p ]]
10 compdef:134> [[ gnutls-serv = -p ]]
10 compdef:134> [[ gnutls-cli-debug = -p ]]
10 compdef:134> [[ gnupod_search = -p ]]
10 compdef:134> [[ gnome-gv = -p ]]
10 compdef:134> [[ gnocchi = -p ]]
10 compdef:134> [[ gmknod = -p ]]
10 compdef:134> [[ gm = -p ]]
10 compdef:134> [[ glocate = -p ]]
10 compdef:134> [[ gln = -p ]]
10 compdef:134> [[ glances = -p ]]
10 compdef:134> [[ git-revise = -p ]]
10 compdef:134> [[ git-journal = -p ]]
10 compdef:134> [[ git-flow = -p ]]
10 compdef:134> [[ ghostview = -p ]]
10 compdef:134> [[ ghostscript = -p ]]
10 compdef:134> [[ gh = -p ]]
10 compdef:134> [[ ggv = -p ]]
10 compdef:134> [[ ggrep = -p ]]
10 compdef:134> [[ gfmt = -p ]]
10 compdef:134> [[ gfind = -p ]]
10 compdef:134> [[ gex = -p ]]
10 compdef:134> [[ getfattr = -p ]]
10 compdef:134> [[ getfacl.exe = -p ]]
10 compdef:134> [[ getfacl = -p ]]
10 compdef:134> [[ getclip.exe = -p ]]
10 compdef:134> [[ getclip = -p ]]
10 compdef:134> [[ getafm = -p ]]
10 compdef:134> [[ genv = -p ]]
10 compdef:134> [[ geany = -p ]]
10 compdef:134> [[ gdu = -p ]]
10 compdef:134> [[ gdf = -p ]]
10 compdef:134> [[ gdb = -p ]]
10 compdef:134> [[ gdate = -p ]]
10 compdef:134> [[ gcp = -p ]]
10 compdef:134> [[ gcmp = -p ]]
10 compdef:134> [[ gchroot = -p ]]
10 compdef:134> [[ gccgo = -p ]]
10 compdef:134> [[ gcc = -p ]]
10 compdef:134> [[ gcat = -p ]]
10 compdef:134> [[ gbasename = -p ]]
10 compdef:134> [[ gas = -p ]]
10 compdef:134> [[ fwupdmgr = -p ]]
10 compdef:134> [[ fusermount = -p ]]
10 compdef:134> [[ functions = -p ]]
10 compdef:134> [[ fsh = -p ]]
10 compdef:134> [[ freebsd-update = -p ]]
10 compdef:134> [[ fprev = -p ]]
10 compdef:134> [[ folders = -p ]]
10 compdef:134> [[ fold = -p ]]
10 compdef:134> [[ fmttest = -p ]]
10 compdef:134> [[ fmt = -p ]]
10 compdef:134> [[ flowadm = -p ]]
10 compdef:134> [[ flists = -p ]]
10 compdef:134> [[ fleetctl = -p ]]
10 compdef:134> [[ fixwpps = -p ]]
10 compdef:134> [[ fixpsditps = -p ]]
10 compdef:134> [[ fixmacps = -p ]]
10 compdef:134> [[ fink = -p ]]
10 compdef:134> [[ find = -p ]]
10 compdef:134> [[ fg = -p ]]
10 compdef:134> [[ ffind = -p ]]
10 compdef:134> [[ fetchmail = -p ]]
10 compdef:134> [[ feh = -p ]]
10 compdef:134> [[ fc = -p ]]
10 compdef:134> [[ fakeroot = -p ]]
10 compdef:134> [[ fab = -p ]]
10 compdef:134> [[ extcheck = -p ]]
10 compdef:134> [[ exportfs = -p ]]
10 compdef:134> [[ dvipdf = -p ]]
10 compdef:134> [[ dvc = -p ]]
10 compdef:134> [[ drush = -p ]]
10 compdef:134> [[ dropdb = -p ]]
10 compdef:134> [[ dpkg-query = -p ]]
10 compdef:134> [[ dosread = -p ]]
10 compdef:134> [[ dosdel = -p ]]
10 compdef:134> [[ domainname = -p ]]
10 compdef:134> [[ dnf-3 = -p ]]
10 compdef:134> [[ dmake = -p ]]
10 compdef:134> [[ disown = -p ]]
10 compdef:134> [[ dcopref = -p ]]
10 compdef:134> [[ createuser = -p ]]
10 compdef:134> [[ createuser = -p ]]
10 compdef:134> [[ cppcheck = -p ]]
10 compdef:134> [[ cpio = -p ]]
10 compdef:134> [[ coreadm = -p ]]
10 compdef:134> [[ conan = -p ]]
10 compdef:134> [[ combinediff = -p ]]
10 compdef:134> [[ comb = -p ]]
10 compdef:134> [[ co = -p ]]
10 compdef:134> [[ clusterdb = -p ]]
10 compdef:134> [[ clang = -p ]]
10 compdef:134> [[ cinder = -p ]]
10 compdef:134> [[ cifsiostat = -p ]]
10 compdef:134> [[ choc = -p ]]
10 compdef:134> [[ chkstow = -p ]]
10 compdef:134> [[ chdir = -p ]]
10 compdef:134> [[ cf = -p ]]
10 compdef:134> [[ ccache = -p ]]
10 compdef:134> [[ catchsegv = -p ]]
10 compdef:134> [[ cap = -p ]]
10 compdef:134> [[ c++ = -p ]]
10 compdef:134> [[ bzip2recover = -p ]]
10 compdef:134> [[ bzip2 = -p ]]
10 compdef:134> [[ buildhash = -p ]]
10 compdef:134> [[ btshowmetainfo = -p ]]
10 compdef:134> [[ btlaunchmanycurses = -p ]]
10 compdef:134> [[ btlaunchmany = -p ]]
10 compdef:134> [[ btdownloadheadless = -p ]]
10 compdef:134> [[ btdownloadgui = -p ]]
10 compdef:134> [[ bsdinstall = -p ]]
10 compdef:134> [[ brctl = -p ]]
10 compdef:134> [[ bpython3-gtk = -p ]]
10 compdef:134> [[ bpython2-urwid = -p ]]
10 compdef:134> [[ bpython-urwid = -p ]]
10 compdef:134> [[ bpython-gtk = -p ]]
10 compdef:134> [[ bindkey = -p ]]
10 compdef:134> [[ beadm = -p ]]
10 compdef:134> [[ batch = -p ]]
10 compdef:134> [[ basename = -p ]]
10 compdef:134> [[ base64 = -p ]]
10 compdef:134> [[ axi-cache = -p ]]
10 compdef:134> [[ aws = -p ]]
10 compdef:134> [[ avahi-resolve-host-name = -p ]]
10 compdef:134> [[ avahi-browse-domains = -p ]]
10 compdef:134> [[ auto-apt = -p ]]
10 compdef:134> [[ atq = -p ]]
10 compdef:134> [[ atach = -p ]]
10 compdef:134> [[ asdf = -p ]]
10 compdef:134> [[ arping = -p ]]
10 compdef:134> [[ archlinux-java = -p ]]
10 compdef:134> [[ apt-file = -p ]]
10 compdef:134> [[ apt-config = -p ]]
10 compdef:134> [[ appletviewer = -p ]]
10 compdef:134> [[ aplay = -p ]]
10 compdef:134> [[ apachectl = -p ]]
10 compdef:134> [[ aodh = -p ]]
10 compdef:134> [[ antiword = -p ]]
10 compdef:134> [[ ansible-pull = -p ]]
10 compdef:134> [[ ansible-playbook = -p ]]
10 compdef:134> [[ ansible-doc = -p ]]
10 compdef:134> [[ ansible-console = -p ]]
10 compdef:134> [[ anno = -p ]]
10 compdef:134> [[ animate = -p ]]
10 compdef:134> [[ android = -p ]]
10 compdef:134> [[ amaya = -p ]]
10 compdef:134> [[ acroread = -p ]]
10 compdef:134> [[ acpitool = -p ]]
10 compdef:134> [[ ack2 = -p ]]
10 compdef:134> [[ abcde = -p ]]
10 compdef:134> [[ a2enmod = -p ]]
10 compdef:134> [[ _cockroach = -p ]]
10 compdef:134> [[ 6g = -p ]]
10 compdef:134> [[ -zcalc-line- = -p ]]
10 compdef:134> [[ -value-,XZ_DEFAULTS,-default- = -p ]]
10 compdef:134> [[ -value-,VALGRIND_OPTS,-default- = -p ]]
10 compdef:134> [[ -value-,TERM,-default- = -p ]]
10 compdef:134> [[ -value-,RPS1,-default- = -p ]]
10 compdef:134> [[ -value-,RPROMPT,-default- = -p ]]
10 compdef:134> [[ -value-,PS3,-default- = -p ]]
10 compdef:134> [[ -value-,PS1,-default- = -p ]]
10 compdef:134> [[ -value-,PROMPT4,-default- = -p ]]
10 compdef:134> [[ -value-,PROMPT2,-default- = -p ]]
10 compdef:134> [[ -value-,P4USER,-default- = -p ]]
10 compdef:134> [[ -value-,P4PORT,-default- = -p ]]
10 compdef:134> [[ -value-,P4MERGE,-default- = -p ]]
10 compdef:134> [[ -value-,LPDEST,-default- = -p ]]
10 compdef:134> [[ -value-,LESS,-default- = -p ]]
10 compdef:134> [[ -value-,LDFLAGS,-default- = -p ]]
10 compdef:134> [[ -value-,LANGUAGE,-default- = -p ]]
10 compdef:134> [[ -value-,LANG,-default- = -p ]]
10 compdef:134> [[ -value-,CXXFLAGS,-default- = -p ]]
10 compdef:134> [[ -value-,CPPFLAGS,-default- = -p ]]
10 compdef:134> [[ -value-,ANT_ARGS,-default- = -p ]]
10 compdef:134> [[ -value-,ANDROID_LOG_TAGS,-default- = -p ]]
10 compdef:134> [[ -subscript- = -p ]]
10 compdef:134> [[ -redirect- = -p ]]
10 compdef:134> [[ -parameter- = -p ]]
10 compdef:134> [[ -brace-parameter- = -p ]]
10 compdef:134> [[ -P = -p ]]
10 compdef:134> [[ - = -p ]]
10 compdef:134> [[ 'xzcat=unxz' = -p ]]
10 compdef:134> [[ 'unlzma=unxz' = -p ]]
10 compdef:134> [[ 'remsh=rsh' = -p ]]
10 compdef:134> [[ 'python[0-9.]#' = -p ]]
10 compdef:134> [[ 'pydoc[0-9.]#' = -p ]]
10 compdef:134> [[ 'php[0-9.-]' = -p ]]
10 compdef:134> [[ 'nail=mail' = -p ]]
10 compdef:134> [[ 'mktunes.pl=mktunes' = -p ]]
10 compdef:134> [[ 'mailx=mail' = -p ]]
10 compdef:134> [[ 'lzcat=unxz' = -p ]]
10 compdef:134> [[ 'lua[0-9.-]##' = -p ]]
10 compdef:134> [[ 'iceweasel=firefox' = -p ]]
10 compdef:134> [[ 'gnupod_check.pl=gnupod_check' = -p ]]
10 compdef:134> [[ 'ggu=git-checkout' = -p ]]
10 compdef:134> [[ 'ggpnp=git-checkout' = -p ]]
10 compdef:134> [[ 'ggf=git-checkout' = -p ]]
10 compdef:134> [[ 'g++-*' = -p ]]
10 compdef:134> [[ '-value-,LC_*,-default-' = -p ]]
10 compdef:134> [[ '-value-,GO*,-default-' = -p ]]
10 compdef:134> [[ '-redirect-,>,xz=unxz' = -p ]]
10 compdef:134> [[ '-redirect-,<,xz=xz' = -p ]]
10 compdef:134> [[ '-redirect-,<,compress=compress' = -p ]]
10 compdef:134> [[ '-redirect-,<,bzip2=bzip2' = -p ]]
10 compdef:134> [[ '(tiff*|*2tiff|pal2rgb)' = -p ]]
10 compdef:134> [[ '(texi(2*|ndex))' = -p ]]
10 compdef:134> [[ '(ruby|[ei]rb)[0-9.]#' = -p ]]
10 compdef:132> [[ zsetattr = -N ]]
10 compdef:132> [[ zln = -N ]]
10 compdef:132> [[ zlistattr = -N ]]
10 compdef:132> [[ zipinfo = -N ]]
10 compdef:132> [[ zgrep = -N ]]
10 compdef:132> [[ zf_rm = -N ]]
10 compdef:132> [[ zf_mkdir = -N ]]
10 compdef:132> [[ zen = -N ]]
10 compdef:132> [[ zdelattr = -N ]]
10 compdef:132> [[ ypxfr = -N ]]
10 compdef:132> [[ ypserv = -N ]]
10 compdef:132> [[ yppush = -N ]]
10 compdef:132> [[ yppasswd = -N ]]
10 compdef:132> [[ ypmatch = -N ]]
10 compdef:132> [[ yast2 = -N ]]
10 compdef:132> [[ xwd = -N ]]
10 compdef:132> [[ xvncviewer = -N ]]
10 compdef:132> [[ xvnc4viewer = -N ]]
10 compdef:132> [[ xtp = -N ]]
10 compdef:132> [[ xtightvncviewer = -N ]]
10 compdef:132> [[ xping = -N ]]
10 compdef:132> [[ xon = -N ]]
10 compdef:132> [[ xmosaic = -N ]]
10 compdef:132> [[ xattr = -N ]]
10 compdef:132> [[ www = -N ]]
10 compdef:132> [[ whoami = -N ]]
10 compdef:132> [[ watcher = -N ]]
10 compdef:132> [[ vpnc-connect = -N ]]
10 compdef:132> [[ vorbiscomment = -N ]]
10 compdef:132> [[ vncviewer = -N ]]
10 compdef:132> [[ vitrage = -N ]]
10 compdef:132> [[ virt-xml-validate = -N ]]
10 compdef:132> [[ virt-pki-validate = -N ]]
10 compdef:132> [[ val = -N ]]
10 compdef:132> [[ urxvtc = -N ]]
10 compdef:132> [[ urxvt256c-mlc = -N ]]
10 compdef:132> [[ urpmi.update = -N ]]
10 compdef:132> [[ urpmi.addmedia = -N ]]
10 compdef:132> [[ upgradepkg = -N ]]
10 compdef:132> [[ unzip = -N ]]
10 compdef:132> [[ unwrapdiff = -N ]]
10 compdef:132> [[ unset = -N ]]
10 compdef:132> [[ unpack = -N ]]
10 compdef:132> [[ unlz4 = -N ]]
10 compdef:132> [[ unget = -N ]]
10 compdef:132> [[ umount = -N ]]
10 compdef:132> [[ txt = -N ]]
10 compdef:132> [[ tunes2pod = -N ]]
10 compdef:132> [[ tunctl = -N ]]
10 compdef:132> [[ tryaffix = -N ]]
10 compdef:132> [[ trove = -N ]]
10 compdef:132> [[ trial = -N ]]
10 compdef:132> [[ traceroute = -N ]]
10 compdef:132> [[ tracepath6 = -N ]]
10 compdef:132> [[ tpkg-install-libc = -N ]]
10 compdef:132> [[ tkinfo = -N ]]
10 compdef:132> [[ tkconch = -N ]]
10 compdef:132> [[ times = -N ]]
10 compdef:132> [[ texindex = -N ]]
10 compdef:132> [[ texi2pdf = -N ]]
10 compdef:132> [[ texi2dvi = -N ]]
10 compdef:132> [[ texi2any = -N ]]
10 compdef:132> [[ tacker = -N ]]
10 compdef:132> [[ strace64 = -N ]]
10 compdef:132> [[ stop = -N ]]
10 compdef:132> [[ status = -N ]]
10 compdef:132> [[ start = -N ]]
10 compdef:132> [[ star = -N ]]
10 compdef:132> [[ ssh-keyscan = -N ]]
10 compdef:132> [[ ssh-keygen = -N ]]
10 compdef:132> [[ ssh-copy-id = -N ]]
10 compdef:132> [[ ssh-add = -N ]]
10 compdef:132> [[ srptool = -N ]]
10 compdef:132> [[ sr = -N ]]
10 compdef:132> [[ sqlite3 = -N ]]
10 compdef:132> [[ splitdiff = -N ]]
10 compdef:132> [[ soa = -N ]]
10 compdef:132> [[ smbstatus = -N ]]
10 compdef:132> [[ slocate = -N ]]
10 compdef:132> [[ slitex = -N ]]
10 compdef:132> [[ skipstone = -N ]]
10 compdef:132> [[ show = -N ]]
10 compdef:132> [[ sha512 = -N ]]
10 compdef:132> [[ setfattr = -N ]]
10 compdef:132> [[ senlin = -N ]]
10 compdef:132> [[ scriptreplay = -N ]]
10 compdef:132> [[ scp = -N ]]
10 compdef:132> [[ sar = -N ]]
10 compdef:132> [[ sahara = -N ]]
10 compdef:132> [[ rvim = -N ]]
10 compdef:132> [[ rview = -N ]]
10 compdef:132> [[ rusage = -N ]]
10 compdef:132> [[ ruby-mri = -N ]]
10 compdef:132> [[ rubber-info = -N ]]
10 compdef:132> [[ rpmverify = -N ]]
10 compdef:132> [[ rpmquery = -N ]]
10 compdef:132> [[ rpmbuild = -N ]]
10 compdef:132> [[ rmmod = -N ]]
10 compdef:132> [[ rmm = -N ]]
10 compdef:132> [[ rmiregistry = -N ]]
10 compdef:132> [[ rmid = -N ]]
10 compdef:132> [[ rmic = -N ]]
10 compdef:132> [[ rmf = -N ]]
10 compdef:132> [[ rmadison = -N ]]
10 compdef:132> [[ rgvim = -N ]]
10 compdef:132> [[ rgview = -N ]]
10 compdef:132> [[ retawq = -N ]]
10 compdef:132> [[ restart = -N ]]
10 compdef:132> [[ reportbug = -N ]]
10 compdef:132> [[ repl = -N ]]
10 compdef:132> [[ removepkg = -N ]]
10 compdef:132> [[ reindexdb = -N ]]
10 compdef:132> [[ rehash = -N ]]
10 compdef:132> [[ refile = -N ]]
10 compdef:132> [[ r = -N ]]
10 compdef:132> [[ putclip.exe = -N ]]
10 compdef:132> [[ pstotgif = -N ]]
10 compdef:132> [[ pstops = -N ]]
10 compdef:132> [[ psresize = -N ]]
10 compdef:132> [[ psql = -N ]]
10 compdef:132> [[ psnup = -N ]]
10 compdef:132> [[ psig = -N ]]
10 compdef:132> [[ psed = -N ]]
10 compdef:132> [[ ps2pdf12 = -N ]]
10 compdef:132> [[ ps2pdf = -N ]]
10 compdef:132> [[ prev = -N ]]
10 compdef:132> [[ postsuper = -N ]]
10 compdef:132> [[ postgres = -N ]]
10 compdef:132> [[ policytool = -N ]]
10 compdef:132> [[ podtoc = -N ]]
10 compdef:132> [[ podpath = -N ]]
10 compdef:132> [[ pmvers = -N ]]
10 compdef:132> [[ pmls = -N ]]
10 compdef:132> [[ pmexp = -N ]]
10 compdef:132> [[ pmdesc = -N ]]
10 compdef:132> [[ pman = -N ]]
10 compdef:132> [[ pmake = -N ]]
10 compdef:132> [[ pkill = -N ]]
10 compdef:132> [[ pkg_info = -N ]]
10 compdef:132> [[ ping6 = -N ]]
10 compdef:132> [[ pinfo = -N ]]
10 compdef:132> [[ pigz = -N ]]
10 compdef:132> [[ pg_upgrade = -N ]]
10 compdef:132> [[ pg_restore = -N ]]
10 compdef:132> [[ pg_isready = -N ]]
10 compdef:132> [[ pg_dumpall = -N ]]
10 compdef:132> [[ pg_ctl = -N ]]
10 compdef:132> [[ pfiles = -N ]]
10 compdef:132> [[ pdksh = -N ]]
10 compdef:132> [[ pdftexi2dvi = -N ]]
10 compdef:132> [[ pdfjadetex = -N ]]
10 compdef:132> [[ pdfinfo = -N ]]
10 compdef:132> [[ pdfimages = -N ]]
10 compdef:132> [[ pdffonts = -N ]]
10 compdef:132> [[ pdf2ps = -N ]]
10 compdef:132> [[ packf = -N ]]
10 compdef:132> [[ p4d = -N ]]
10 compdef:132> [[ opera = -N ]]
10 compdef:132> [[ odmshow = -N ]]
10 compdef:132> [[ odme = -N ]]
10 compdef:132> [[ ns = -N ]]
10 compdef:132> [[ nova = -N ]]
10 compdef:132> [[ noglob = -N ]]
10 compdef:132> [[ next = -N ]]
10 compdef:132> [[ new = -N ]]
10 compdef:132> [[ neutron = -N ]]
10 compdef:132> [[ netrik = -N ]]
10 compdef:132> [[ netcat = -N ]]
10 compdef:132> [[ nawk = -N ]]
10 compdef:132> [[ mysqlimport = -N ]]
10 compdef:132> [[ mysqldump = -N ]]
10 compdef:132> [[ mysqladmin = -N ]]
10 compdef:132> [[ mx = -N ]]
10 compdef:132> [[ mtoolstest = -N ]]
10 compdef:132> [[ msgchk = -N ]]
10 compdef:132> [[ mren = -N ]]
10 compdef:132> [[ montage = -N ]]
10 compdef:132> [[ mogrify = -N ]]
10 compdef:132> [[ modprobe = -N ]]
10 compdef:132> [[ modinfo = -N ]]
10 compdef:132> [[ mmount = -N ]]
10 compdef:132> [[ mlabel = -N ]]
10 compdef:132> [[ mkzsh.exe = -N ]]
10 compdef:132> [[ mktunes = -N ]]
10 compdef:132> [[ mkshortcut.exe = -N ]]
10 compdef:132> [[ mksh = -N ]]
10 compdef:132> [[ mistral = -N ]]
10 compdef:132> [[ mhpath = -N ]]
10 compdef:132> [[ mhparam = -N ]]
10 compdef:132> [[ mhlist = -N ]]
10 compdef:132> [[ mhfixmsg = -N ]]
10 compdef:132> [[ mformat = -N ]]
10 compdef:132> [[ metaflac = -N ]]
10 compdef:132> [[ mdeltree = -N ]]
10 compdef:132> [[ mdel = -N ]]
10 compdef:132> [[ md5 = -N ]]
10 compdef:132> [[ md4 = -N ]]
10 compdef:132> [[ mcopy = -N ]]
10 compdef:132> [[ manila = -N ]]
10 compdef:132> [[ makeinfo = -N ]]
10 compdef:132> [[ m-a = -N ]]
10 compdef:132> [[ lz4cat = -N ]]
10 compdef:132> [[ lz4c32 = -N ]]
10 compdef:132> [[ lz4c = -N ]]
10 compdef:132> [[ lpr = -N ]]
10 compdef:132> [[ lpq = -N ]]
10 compdef:132> [[ lpinfo = -N ]]
10 compdef:132> [[ lpadmin = -N ]]
10 compdef:132> [[ local = -N ]]
10 compdef:132> [[ llvm-otool = -N ]]
10 compdef:132> [[ llvm-objdump = -N ]]
10 compdef:132> [[ llvm-gcc = -N ]]
10 compdef:132> [[ llvm-g++ = -N ]]
10 compdef:132> [[ lintian-info = -N ]]
10 compdef:132> [[ latex = -N ]]
10 compdef:132> [[ lastb = -N ]]
10 compdef:132> [[ konqueror = -N ]]
10 compdef:132> [[ kldunload = -N ]]
10 compdef:132> [[ kioclient = -N ]]
10 compdef:132> [[ killall5 = -N ]]
10 compdef:132> [[ keystone = -N ]]
10 compdef:132> [[ java = -N ]]
10 compdef:132> [[ jarsigner = -N ]]
10 compdef:132> [[ jar = -N ]]
10 compdef:132> [[ irb = -N ]]
10 compdef:132> [[ iptables-save = -N ]]
10 compdef:132> [[ iptables-restore = -N ]]
10 compdef:132> [[ ipkg = -N ]]
10 compdef:132> [[ ip6tables-restore = -N ]]
10 compdef:132> [[ ip6tables = -N ]]
10 compdef:132> [[ interdiff = -N ]]
10 compdef:132> [[ install-info = -N ]]
10 compdef:132> [[ initdb = -N ]]
10 compdef:132> [[ includeres = -N ]]
10 compdef:132> [[ identify = -N ]]
10 compdef:132> [[ icombine = -N ]]
10 compdef:132> [[ hilite = -N ]]
10 compdef:132> [[ gzgrep = -N ]]
10 compdef:132> [[ gzfgrep = -N ]]
10 compdef:132> [[ gzegrep = -N ]]
10 compdef:132> [[ gwc = -N ]]
10 compdef:132> [[ gvim = -N ]]
10 compdef:132> [[ gview = -N ]]
10 compdef:132> [[ guptime = -N ]]
10 compdef:132> [[ guname = -N ]]
10 compdef:132> [[ guilt-new = -N ]]
10 compdef:132> [[ guilt-fork = -N ]]
10 compdef:132> [[ gtouch = -N ]]
10 compdef:132> [[ gtimeout = -N ]]
10 compdef:132> [[ gtee = -N ]]
10 compdef:132> [[ gtar = -N ]]
10 compdef:132> [[ gtac = -N ]]
10 compdef:132> [[ gstrings = -N ]]
10 compdef:132> [[ gstdbuf = -N ]]
10 compdef:132> [[ gsort = -N ]]
10 compdef:132> [[ gshuf = -N ]]
10 compdef:132> [[ gshred = -N ]]
10 compdef:132> [[ gsha384sum = -N ]]
10 compdef:132> [[ gsha256sum = -N ]]
10 compdef:132> [[ gsdj500 = -N ]]
10 compdef:132> [[ groups = -N ]]
10 compdef:132> [[ groupadd = -N ]]
10 compdef:132> [[ grm = -N ]]
10 compdef:132> [[ grepdiff = -N ]]
10 compdef:132> [[ grail = -N ]]
10 compdef:132> [[ gradlew = -N ]]
10 compdef:132> [[ gpg-zip = -N ]]
10 compdef:132> [[ gpatch = -N ]]
10 compdef:132> [[ gpaste = -N ]]
10 compdef:132> [[ gofmt = -N ]]
10 compdef:132> [[ gnutls-serv = -N ]]
10 compdef:132> [[ gnutls-cli-debug = -N ]]
10 compdef:132> [[ gnupod_search = -N ]]
10 compdef:132> [[ gnupod_check = -N ]]
10 compdef:132> [[ gnupod_INIT = -N ]]
10 compdef:132> [[ gnumfmt = -N ]]
10 compdef:132> [[ gnocchi = -N ]]
10 compdef:132> [[ gnl = -N ]]
10 compdef:132> [[ gmplayer = -N ]]
10 compdef:132> [[ gmknod = -N ]]
10 compdef:132> [[ gmkfifo = -N ]]
10 compdef:132> [[ gmkdir = -N ]]
10 compdef:132> [[ gmake = -N ]]
10 compdef:132> [[ glocate = -N ]]
10 compdef:132> [[ gjoin = -N ]]
10 compdef:132> [[ ginstall = -N ]]
10 compdef:132> [[ ghostscript = -N ]]
10 compdef:132> [[ ghci = -N ]]
10 compdef:132> [[ ghc-pkg = -N ]]
10 compdef:132> [[ ggv = -N ]]
10 compdef:132> [[ ggetopt = -N ]]
10 compdef:132> [[ gfold = -N ]]
10 compdef:132> [[ gfmt = -N ]]
10 compdef:132> [[ gexpand = -N ]]
10 compdef:132> [[ getfattr = -N ]]
10 compdef:132> [[ getfacl.exe = -N ]]
10 compdef:132> [[ getclip.exe = -N ]]
10 compdef:132> [[ gegrep = -N ]]
10 compdef:132> [[ gcut = -N ]]
10 compdef:132> [[ gbasename = -N ]]
10 compdef:132> [[ gbase64 = -N ]]
10 compdef:132> [[ gawk = -N ]]
10 compdef:132> [[ galeon = -N ]]
10 compdef:132> [[ g++ = -N ]]
10 compdef:132> [[ functions = -N ]]
10 compdef:132> [[ folder = -N ]]
10 compdef:132> [[ fned = -N ]]
10 compdef:132> [[ fly = -N ]]
10 compdef:132> [[ flist = -N ]]
10 compdef:132> [[ flex++ = -N ]]
10 compdef:132> [[ fixwwps = -N ]]
10 compdef:132> [[ fixtpps = -N ]]
10 compdef:132> [[ fixscribeps = -N ]]
10 compdef:132> [[ fixpspps = -N ]]
10 compdef:132> [[ fixpsditps = -N ]]
10 compdef:132> [[ fixmacps = -N ]]
10 compdef:132> [[ fixfmps = -N ]]
10 compdef:132> [[ firefox = -N ]]
10 compdef:132> [[ findaffix = -N ]]
10 compdef:132> [[ fgrep = -N ]]
10 compdef:132> [[ extractres = -N ]]
10 compdef:132> [[ extcheck = -N ]]
10 compdef:132> [[ express = -N ]]
10 compdef:132> [[ export = -N ]]
10 compdef:132> [[ evim = -N ]]
10 compdef:132> [[ eview = -N ]]
10 compdef:132> [[ eu-objdump = -N ]]
10 compdef:132> [[ epdfview = -N ]]
10 compdef:132> [[ egrep = -N ]]
10 compdef:132> [[ eatmydata = -N ]]
10 compdef:132> [[ dropuser = -N ]]
10 compdef:132> [[ dropdb = -N ]]
10 compdef:132> [[ dosdel = -N ]]
10 compdef:132> [[ domainname = -N ]]
10 compdef:132> [[ dockerd = -N ]]
10 compdef:132> [[ dnf-2 = -N ]]
10 compdef:132> [[ dmake = -N ]]
10 compdef:132> [[ dist = -N ]]
10 compdef:132> [[ dillo = -N ]]
10 compdef:132> [[ designate = -N ]]
10 compdef:132> [[ declare = -N ]]
10 compdef:132> [[ d = -N ]]
10 compdef:132> [[ createuser = -N ]]
10 compdef:132> [[ convert = -N ]]
10 compdef:132> [[ conch = -N ]]
10 compdef:132> [[ composite = -N ]]
10 compdef:132> [[ comp = -N ]]
10 compdef:132> [[ cockroach = -N ]]
10 compdef:132> [[ clang++ = -N ]]
10 compdef:132> [[ cifsiostat = -N ]]
10 compdef:132> [[ ci = -N ]]
10 compdef:132> [[ chimera = -N ]]
10 compdef:132> [[ chfn = -N ]]
10 compdef:132> [[ certtool = -N ]]
10 compdef:132> [[ cc = -N ]]
10 compdef:132> [[ c++ = -N ]]
10 compdef:132> [[ bzip2recover = -N ]]
10 compdef:132> [[ bzegrep = -N ]]
10 compdef:132> [[ burst = -N ]]
10 compdef:132> [[ bunzip2 = -N ]]
10 compdef:132> [[ bttrack = -N ]]
10 compdef:132> [[ btshowmetainfo = -N ]]
10 compdef:132> [[ btreannounce = -N ]]
10 compdef:132> [[ btmakemetafile = -N ]]
10 compdef:132> [[ btlaunchmanycurses = -N ]]
10 compdef:132> [[ btlaunchmany = -N ]]
10 compdef:132> [[ btdownloadheadless = -N ]]
10 compdef:132> [[ btdownloadgui = -N ]]
10 compdef:132> [[ bsdgrep = -N ]]
10 compdef:132> [[ bpython3-urwid = -N ]]
10 compdef:132> [[ bpython3 = -N ]]
10 compdef:132> [[ bpython2-gtk = -N ]]
10 compdef:132> [[ bpython2 = -N ]]
10 compdef:132> [[ bpython-urwid = -N ]]
10 compdef:132> [[ bogotune = -N ]]
10 compdef:132> [[ batch = -N ]]
10 compdef:132> [[ base32 = -N ]]
10 compdef:132> [[ avahi-resolve-address = -N ]]
10 compdef:132> [[ avahi-resolve = -N ]]
10 compdef:132> [[ atq = -N ]]
10 compdef:132> [[ at = -N ]]
10 compdef:132> [[ arena = -N ]]
10 compdef:132> [[ apt-mark = -N ]]
10 compdef:132> [[ apt-get = -N ]]
10 compdef:132> [[ apt-cdrom = -N ]]
10 compdef:132> [[ apt-cache = -N ]]
10 compdef:132> [[ appletviewer = -N ]]
10 compdef:132> [[ apache2ctl = -N ]]
10 compdef:132> [[ ansible-vault = -N ]]
10 compdef:132> [[ ansible-pull = -N ]]
10 compdef:132> [[ ansible-playbook = -N ]]
10 compdef:132> [[ ansible-galaxy = -N ]]
10 compdef:132> [[ ansible-doc = -N ]]
10 compdef:132> [[ ansible-console = -N ]]
10 compdef:132> [[ anno = -N ]]
10 compdef:132> [[ ack2 = -N ]]
10 compdef:132> [[ ack-grep = -N ]]
10 compdef:132> [[ aaaa = -N ]]
10 compdef:132> [[ Mosaic = -N ]]
10 compdef:132> [[ 5g = -N ]]
10 compdef:132> [[ -value-,XZ_OPT,-default- = -N ]]
10 compdef:132> [[ -value-,SPROMPT,-default- = -N ]]
10 compdef:132> [[ -value-,RPS1,-default- = -N ]]
10 compdef:132> [[ -value-,RPROMPT2,-default- = -N ]]
10 compdef:132> [[ -value-,PS4,-default- = -N ]]
10 compdef:132> [[ -value-,PS3,-default- = -N ]]
10 compdef:132> [[ -value-,PS2,-default- = -N ]]
10 compdef:132> [[ -value-,PS1,-default- = -N ]]
10 compdef:132> [[ -value-,P4USER,-default- = -N ]]
10 compdef:132> [[ -value-,P4MERGE,-default- = -N ]]
10 compdef:132> [[ -value-,LPDEST,-default- = -N ]]
10 compdef:132> [[ -value-,CFLAGS,-default- = -N ]]
10 compdef:132> [[ -array-value- = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ -P = -N ]]
10 compdef:132> [[ 'xzcat=unxz' = -N ]]
10 compdef:132> [[ 'xelatex=latex' = -N ]]
10 compdef:132> [[ 'unlzma=unxz' = -N ]]
10 compdef:132> [[ 'tunes2pod.pl=tunes2pod' = -N ]]
10 compdef:132> [[ 'slogin=ssh' = -N ]]
10 compdef:132> [[ 'shasum(|5).*' = -N ]]
10 compdef:132> [[ 'remsh=rsh' = -N ]]
10 compdef:132> [[ 'php[0-9.-]' = -N ]]
10 compdef:132> [[ 'pcat=unpack' = -N ]]
10 compdef:132> [[ 'ncl=nc' = -N ]]
10 compdef:132> [[ 'nail=mail' = -N ]]
10 compdef:132> [[ 'mktunes.pl=mktunes' = -N ]]
10 compdef:132> [[ 'lzcat=unxz' = -N ]]
10 compdef:132> [[ 'lua[0-9.-]##' = -N ]]
10 compdef:132> [[ 'gpg2=gpg' = -N ]]
10 compdef:132> [[ 'gnupod_INIT.pl=gnupod_INIT' = -N ]]
10 compdef:132> [[ 'ggfl=git-checkout' = -N ]]
10 compdef:132> [[ 'gem[0-9.]#' = -N ]]
10 compdef:132> [[ 'gdv=git-diff' = -N ]]
10 compdef:132> [[ 'gccd=git-clone' = -N ]]
10 compdef:132> [[ 'g++-*' = -N ]]
10 compdef:132> [[ 'c++-*' = -N ]]
10 compdef:132> [[ 'bzcat=bunzip2' = -N ]]
10 compdef:132> [[ 'Mail=mail' = -N ]]
10 compdef:132> [[ '-value-,CGO*,-default-' = -N ]]
10 compdef:132> [[ '-redirect-,>,xz=unxz' = -N ]]
10 compdef:132> [[ '-redirect-,<,xz=xz' = -N ]]
10 compdef:131> ((  36  ))
10 compdef:131> ((  33  ))
10 compdef:131> ((  32  ))
10 compdef:131> ((  31  ))
10 compdef:131> ((  30  ))
10 compdef:131> ((  28  ))
10 compdef:131> ((  25  ))
10 compdef:131> ((  24  ))
10 compdef:131> ((  24  ))
10 compdef:131> ((  23  ))
10 compdef:131> ((  22  ))
10 compdef:131> ((  22  ))
10 compdef:131> ((  21  ))
10 compdef:131> ((  21  ))
10 compdef:131> ((  21  ))
10 compdef:131> ((  20  ))
10 compdef:131> ((  19  ))
10 compdef:131> ((  18  ))
10 compdef:131> ((  18  ))
10 compdef:131> ((  17  ))
10 compdef:131> ((  17  ))
10 compdef:131> ((  17  ))
10 compdef:131> ((  16  ))
10 compdef:131> ((  16  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  14  ))
10 compdef:131> ((  13  ))
10 compdef:131> ((  13  ))
10 compdef:131> ((  12  ))
10 compdef:131> ((  12  ))
10 compdef:131> ((  12  ))
10 compdef:131> ((  12  ))
10 compdef:131> ((  12  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  11  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  10  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  9  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  8  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  7  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  6  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  5  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  4  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  3  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  2  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:131> ((  1  ))
10 compdef:120> i=C-xt
10 compdef:120> i=C-xC-r
10 compdef:110> [[ complete-word = .* ]]
10 compdef:91> [[ complete-word = .* ]]
10 compdef:91> 2=.complete-word
10 compdef:83> case widgetkey (widgetkey)
10 compdef:83> case postpattern (widgetkey)
10 compdef:83> case postpattern (widgetkey)
10 compdef:83> case postpattern (widgetkey)
10 compdef:83> case postpattern (widgetkey)
10 compdef:83> case postpattern (key)
10 compdef:83> case postpattern (*)
10 compdef:83> case postpattern (*)
10 compdef:83> case postpattern (*)
10 compdef:83> case postpattern (*)
10 compdef:83> case postpattern (*)
10 compdef:83> case pattern (widgetkey)
10 compdef:83> case pattern (*)
10 compdef:83> case key (widgetkey)
10 compdef:83> case key (widgetkey)
10 compdef:83> case key (widgetkey)
10 compdef:83> case key (widgetkey)
10 compdef:83> case key (widgetkey)
10 compdef:83> case key (key)
10 compdef:83> case key (key)
10 compdef:83> case key (key)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (widgetkey)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (key)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:83> case  (*)
10 compdef:79> func=_zip
10 compdef:79> func=_zftp
10 compdef:79> func=_zfs
10 compdef:79> func=_zed
10 compdef:79> func=_zeal
10 compdef:79> func=_zcalc_line
10 compdef:79> func=_zargs
10 compdef:79> func=_yp
10 compdef:79> func=_yafc
10 compdef:79> func=_xxd
10 compdef:79> func=_xv
10 compdef:79> func=_xterm
10 compdef:79> func=_xscreensaver
10 compdef:79> func=_xrandr
10 compdef:79> func=_xpdf
10 compdef:79> func=_xournal
10 compdef:79> func=_xmodmap
10 compdef:79> func=_whois
10 compdef:79> func=_who
10 compdef:79> func=_whereis
10 compdef:79> func=_wget
10 compdef:79> func=_webbrowser
10 compdef:79> func=_watch
10 compdef:79> func=_wanna-build
10 compdef:79> func=_wajig
10 compdef:79> func=_w
10 compdef:79> func=_vserver
10 compdef:79> func=_vpnc
10 compdef:79> func=_vmstat
10 compdef:79> func=_visudo
10 compdef:79> func=_vim-addons
10 compdef:79> func=_vim
10 compdef:79> func=_vcsh
10 compdef:79> func=_vars
10 compdef:79> func=_value
10 compdef:79> func=_valgrind
10 compdef:79> func=_users_on
10 compdef:79> func=_users
10 compdef:79> func=_user_admin
10 compdef:79> func=_uscan
10 compdef:79> func=_update-rc.d
10 compdef:79> func=_unison
10 compdef:79> func=_unexpand
10 compdef:79> func=_unace
10 compdef:79> func=_ulimit
10 compdef:79> func=_twidge
10 compdef:79> func=_tune2fs
10 compdef:79> func=_trash
10 compdef:79> func=_transmission
10 compdef:79> func=_tracepath
10 compdef:79> func=_tpb
10 compdef:79> func=_touch
10 compdef:79> func=_toolchain-source
10 compdef:79> func=_tla
10 compdef:79> func=_tin
10 compdef:79> func=_tilde
10 compdef:79> func=_texinfo
10 compdef:79> func=_terminals
10 compdef:79> func=_telnet
10 compdef:79> func=_tee
10 compdef:79> func=_tcptraceroute
10 compdef:79> func=_system_profiler
10 compdef:79> func=_systat
10 compdef:79> func=_sysstat
10 compdef:79> func=_sysctl
10 compdef:79> func=_swift
10 compdef:79> func=_swaks
10 compdef:79> func=_svn-buildpackage
10 compdef:79> func=_svcprop
10 compdef:79> func=_svccfg
10 compdef:79> func=_svcadm
10 compdef:79> func=_surfraw
10 compdef:79> func=_subversion
10 compdef:79> func=_sublimetext
10 compdef:79> func=_strings
10 compdef:79> func=_strftime
10 compdef:79> func=_strace
10 compdef:79> func=_stdbuf
10 compdef:79> func=_stat
10 compdef:79> func=_sqsh
10 compdef:79> func=_spamassassin
10 compdef:79> func=_source
10 compdef:79> func=_sort
10 compdef:79> func=_softwareupdate
10 compdef:79> func=_snoop
10 compdef:79> func=_smit
10 compdef:79> func=_smartmontools
10 compdef:79> func=_signify
10 compdef:79> func=_shred
10 compdef:79> func=_showmount
10 compdef:79> func=_setopt
10 compdef:79> func=_set
10 compdef:79> func=_service
10 compdef:79> func=_seafile
10 compdef:79> func=_scutil
10 compdef:79> func=_scselect
10 compdef:79> func=_script
10 compdef:79> func=_screen
10 compdef:79> func=_scons
10 compdef:79> func=_schroot
10 compdef:79> func=_schedtool
10 compdef:79> func=_sched
10 compdef:79> func=_sc_usage
10 compdef:79> func=_sbt
10 compdef:79> func=_samba
10 compdef:79> func=_runit
10 compdef:79> func=_run-help
10 compdef:79> func=_ruby
10 compdef:79> func=_rpm
10 compdef:79> func=_rlogin
10 compdef:79> func=_rkt
10 compdef:79> func=_ri
10 compdef:79> func=_redirect
10 compdef:79> func=_readshortcut
10 compdef:79> func=_readlink
10 compdef:79> func=_readelf
10 compdef:79> func=_read_comp
10 compdef:79> func=_read
10 compdef:79> func=_rcs
10 compdef:79> func=_ranlib
10 compdef:79> func=_qiv
10 compdef:79> func=_qdbus
10 compdef:79> func=_pwgen
10 compdef:79> func=_pv
10 compdef:79> func=_putclip
10 compdef:79> func=_psutils
10 compdef:79> func=_pspdf
10 compdef:79> func=_prove
10 compdef:79> func=_prompt
10 compdef:79> func=_procstat
10 compdef:79> func=_printers
10 compdef:79> func=_printenv
10 compdef:79> func=_postscript
10 compdef:79> func=_postfix
10 compdef:79> func=_portmaster
10 compdef:79> func=_portaudit
10 compdef:79> func=_pmap
10 compdef:79> func=_plutil
10 compdef:79> func=_pkginfo
10 compdef:79> func=_pkg-config
10 compdef:79> func=_piuparts
10 compdef:79> func=_ping
10 compdef:79> func=_pine
10 compdef:79> func=_pidof
10 compdef:79> func=_picocom
10 compdef:79> func=_php
10 compdef:79> func=_pgrep
10 compdef:79> func=_pfexec
10 compdef:79> func=_perldoc
10 compdef:79> func=_perl_modules
10 compdef:79> func=_perl
10 compdef:79> func=_perforce
10 compdef:79> func=_pbuilder
10 compdef:79> func=_pbm
10 compdef:79> func=_pax
10 compdef:79> func=_paste
10 compdef:79> func=_parameter
10 compdef:79> func=_pandoc
10 compdef:79> func=_osc
10 compdef:79> func=_optirun
10 compdef:79> func=_opkg
10 compdef:79> func=_okular
10 compdef:79> func=_objdump
10 compdef:79> func=_nvram
10 compdef:79> func=_npm
10 compdef:79> func=_ngrep
10 compdef:79> func=_nginx
10 compdef:79> func=_netstat
10 compdef:79> func=_netcat
10 compdef:79> func=_net_interfaces
10 compdef:79> func=_ncftp
10 compdef:79> func=_mysqldiff
10 compdef:79> func=_mysql_utils
10 compdef:79> func=_mv
10 compdef:79> func=_mutt
10 compdef:79> func=_mupdf
10 compdef:79> func=_mtr
10 compdef:79> func=_mtools
10 compdef:79> func=_mplayer
10 compdef:79> func=_mpc
10 compdef:79> func=_mondo
10 compdef:79> func=_modutils
10 compdef:79> func=_module
10 compdef:79> func=_mkzsh
10 compdef:79> func=_mixerctl
10 compdef:79> func=_mii-tool
10 compdef:79> func=_members
10 compdef:79> func=_mdutil
10 compdef:79> func=_lz4
10 compdef:79> func=_lynx
10 compdef:79> func=_lunchy
10 compdef:79> func=_luarocks
10 compdef:79> func=_lua
10 compdef:79> func=_lsusb
10 compdef:79> func=_lsof
10 compdef:79> func=_lslv
10 compdef:79> func=_lsdev
10 compdef:79> func=_ls
10 compdef:79> func=_losetup
10 compdef:79> func=_look
10 compdef:79> func=_locate
10 compdef:79> func=_locales
10 compdef:79> func=_localedef
10 compdef:79> func=_locale
10 compdef:79> func=_loadkeys
10 compdef:79> func=_lldb
10 compdef:79> func=_lintian
10 compdef:79> func=_links
10 compdef:79> func=_limits
10 compdef:79> func=_limit
10 compdef:79> func=_libvirt
10 compdef:79> func=_ldd
10 compdef:79> func=_ld_debug
10 compdef:79> func=_kvno
10 compdef:79> func=_kpartx
10 compdef:79> func=_knock
10 compdef:79> func=_knife
10 compdef:79> func=_kld
10 compdef:79> func=_kitchen
10 compdef:79> func=_kill
10 compdef:79> func=_kfmclient
10 compdef:79> func=_kdeconnect
10 compdef:79> func=_kak
10 compdef:79> func=_jq
10 compdef:79> func=_jot
10 compdef:79> func=_jonas
10 compdef:79> func=_joe
10 compdef:79> func=_jmeter-plugins
10 compdef:79> func=_jmeter
10 compdef:79> func=_jls
10 compdef:79> func=_jail
10 compdef:79> func=_irssi
10 compdef:79> func=_iptables
10 compdef:79> func=_ipset
10 compdef:79> func=_ipsec
10 compdef:79> func=_ipadm
10 compdef:79> func=_iostat
10 compdef:79> func=_ionice
10 compdef:79> func=_invoke-rc.d
10 compdef:79> func=_install
10 compdef:79> func=_inetadm
10 compdef:79> func=_imagemagick
10 compdef:79> func=_iconv
10 compdef:79> func=_ibus
10 compdef:79> func=_htop
10 compdef:79> func=_hosts
10 compdef:79> func=_hostname
10 compdef:79> func=_host
10 compdef:79> func=_homestead
10 compdef:79> func=_hexdump
10 compdef:79> func=_head
10 compdef:79> func=_hdiutil
10 compdef:79> func=_groff
10 compdef:79> func=_grep
10 compdef:79> func=_graphicsmagick
10 compdef:79> func=_gradle
10 compdef:79> func=_gprof
10 compdef:79> func=_gphoto2
10 compdef:79> func=_gpg
10 compdef:79> func=_gpasswd
10 compdef:79> func=_google
10 compdef:79> func=_golang
10 compdef:79> func=_go
10 compdef:79> func=_gnupod
10 compdef:79> func=_gnome-gv
10 compdef:79> func=_glances
10 compdef:79> func=_git-wtf
10 compdef:79> func=_git-revise
10 compdef:79> func=_git-journal
10 compdef:79> func=_git
10 compdef:79> func=_git
10 compdef:79> func=_git
10 compdef:79> func=_git
10 compdef:79> func=_ghc
10 compdef:79> func=_getmail
10 compdef:79> func=_getent
10 compdef:79> func=_getconf
10 compdef:79> func=_getclip
10 compdef:79> func=_gem
10 compdef:79> func=_geany
10 compdef:79> func=_gcore
10 compdef:79> func=_gcc
10 compdef:79> func=_gas
10 compdef:79> func=_fwupdmgr
10 compdef:79> func=_fw_update
10 compdef:79> func=_functions
10 compdef:79> func=_freebsd-update
10 compdef:79> func=_free
10 compdef:79> func=_force
10 compdef:79> func=_flutter
10 compdef:79> func=_floppy
10 compdef:79> func=_fleetctl
10 compdef:79> func=_first
10 compdef:79> func=_fink
10 compdef:79> func=_finger
10 compdef:79> func=_findmnt
10 compdef:79> func=_find
10 compdef:79> func=_ffind
10 compdef:79> func=_fetchmail
10 compdef:79> func=_fetch
10 compdef:79> func=_fc
10 compdef:79> func=_fakeroot
10 compdef:79> func=_fail2ban-client
10 compdef:79> func=_etags
10 compdef:79> func=_emulator
10 compdef:79> func=_elfdump
10 compdef:79> func=_echotc
10 compdef:79> func=_dvc
10 compdef:79> func=_drush
10 compdef:79> func=_docpad
10 compdef:79> func=_docker
10 compdef:79> func=_diff
10 compdef:79> func=_dget
10 compdef:79> func=_deno
10 compdef:79> func=_dad
10 compdef:79> func=_cppcheck
10 compdef:79> func=_cplay
10 compdef:79> func=_cp
10 compdef:79> func=_correct_word
10 compdef:79> func=_coreadm
10 compdef:79> func=_console
10 compdef:79> func=_condition
10 compdef:79> func=_conan
10 compdef:79> func=_complete_tag
10 compdef:79> func=_complete_help
10 compdef:79> func=_code
10 compdef:79> func=_cockroach
10 compdef:79> func=_chromium
10 compdef:79> func=_choc
10 compdef:79> func=_cf
10 compdef:79> func=_ccache
10 compdef:79> func=_cask
10 compdef:79> func=_bts
10 compdef:79> func=_btrfs
10 compdef:79> func=_bsdinstall
10 compdef:79> func=_bsdconfig
10 compdef:79> func=_bsd_pkg
10 compdef:79> func=_brew
10 compdef:79> func=_brctl
10 compdef:79> func=_brace_parameter
10 compdef:79> func=_bpython
10 compdef:79> func=_bower
10 compdef:79> func=_bogofilter
10 compdef:79> func=_bittorrent
10 compdef:79> func=_bitcoin-cli
10 compdef:79> func=_baz
10 compdef:79> func=_bash_completions
10 compdef:79> func=_bash
10 compdef:79> func=_basename
10 compdef:79> func=_axi-cache
10 compdef:79> func=_aws
10 compdef:79> func=_awk
10 compdef:79> func=_avahi
10 compdef:79> func=_auto-apt
10 compdef:79> func=_augeas
10 compdef:79> func=_attr
10 compdef:79> func=_atach
10 compdef:79> func=_assign
10 compdef:79> func=_asdf
10 compdef:79> func=_asciinema
10 compdef:79> func=_asciidoctor
10 compdef:79> func=_arrays
10 compdef:79> func=_arping
10 compdef:79> func=_arp
10 compdef:79> func=_archlinux-java
10 compdef:79> func=_apt-move
10 compdef:79> func=_apt-file
10 compdef:79> func=_apachectl
10 compdef:79> func=_antiword
10 compdef:79> func=_ansible
10 compdef:79> func=_android
10 compdef:79> func=_alsa-utils
10 compdef:79> func=_aliases
10 compdef:79> func=_add-zsh-hook
10 compdef:79> func=_adb
10 compdef:79> func=_acroread
10 compdef:79> func=_acpitool
10 compdef:79> func=_acpi
10 compdef:79> func=_ack
10 compdef:79> func=_abcde
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:49> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:45> [[ -z '' ]]
10 compdef:40> ((  ! 8  ))
10 compdef:40> ((  ! 6  ))
10 compdef:40> ((  ! 4  ))
10 compdef:40> ((  ! 3  ))
10 compdef:40> ((  ! 3  ))
10 compdef:40> ((  ! 2  ))
10 compdef:40> ((  ! 2  ))
10 compdef:40> ((  ! 2  ))
10 compdef:40> ((  ! 2  ))
10 compdef:40> ((  ! 2  ))
10 compdef:28> [[ k = K ]]
10 compdef:28> [[ k = K ]]
10 compdef:28> [[ K = K ]]
10 compdef:26> [[ k = P ]]
10 compdef:26> [[ k = P ]]
10 compdef:26> [[ k = P ]]
10 compdef:26> [[ P = P ]]
10 compdef:26> [[ P = P ]]
10 compdef:26> [[ K = P ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ k = p ]]
10 compdef:24> [[ P = p ]]
10 compdef:24> [[ P = p ]]
10 compdef:24> [[ P = p ]]
10 compdef:24> [[ P = p ]]
10 compdef:24> [[ P = p ]]
10 compdef:24> [[ K = p ]]
10 compdef:24> [[ K = p ]]
10 compdef:18> [[ -n '' ]]
10 compdef:18> [[ -n '' ]]
10 compdef:18> [[ -n '' ]]
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (n)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case n (a)
10 compdef:15> case k (n)
10 compdef:15> case k (a)
10 compdef:15> case k (a)
10 compdef:15> case k (a)
10 compdef:15> case k (a)
10 compdef:15> case k (a)
10 compdef:15> case k (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case a (a)
10 compdef:15> case P (n)
10 compdef:15> case P (n)
10 compdef:15> case P (a)
10 compdef:15> case P (a)
10 compdef:15> case P (a)
10 compdef:15> case P (a)
10 compdef:15> case P (a)
10 compdef:15> case K (n)
10 compdef:15> case K (a)
10 compdef:15> case K (a)
10 compaudit:101> _i_exe=/proc/87947/object/a.out
10 compaudit:101> _i_exe=/proc/87947/exe
10 compaudit:58> _i_wfiles=( )
10 compaudit:58> _i_wfiles=( )
10 compaudit:57> _i_wdirs=( )
10 colors:113> k=bg-yellow
10 colors:113> k=bg-red
10 colors:104> k=fg-red
10 colors:104> k=fg-red
10 colors:86> color[fg-grey]=30
10 colors:86> color[fg-grey]=30
10 colors:85> color[grey]=30
10 colors:81> k=30
10 colors:77> color[${color[$k]}]=25
10 colors:77> color[${color[$k]}]=00
10 add-zsh-hook:68> ((  del  ))
10 add-zsh-hook:68> ((  del  ))
10 add-zsh-hook:68> ((  del  ))
10 add-zsh-hook:68> ((  del  ))
10 add-zsh-hook:57> ((  list  ))
10 add-zsh-hook:57> ((  list  ))
10 add-zsh-hook:57> ((  list  ))
10 add-zsh-hook:57> ((  list  ))
10 add-zle-hook-widget:54> ((  del  ))
10 add-zle-hook-widget:42> ((  list  ))
10 _zsh_highlight_bind_widgets:27> case completion:.reverse-menu-complete:_main_...
10 _zsh_highlight_bind_widgets:27> case completion:.reverse-menu-complete:_main_...
10 _zsh_highlight_bind_widgets:27> case completion:.menu-expand-or-complete:_mai...
10 _zsh_highlight_bind_widgets:27> case completion:.menu-complete:_main_complete...
10 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_next_tags (use...
10 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_expand_word (u...
10 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete:_main_com...
10 _zsh_highlight_bind_widgets:27> case completion:.expand-or-complete-prefix:_m...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_word (...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_expand_alias ...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_word ...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_correct_filen...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_debu...
10 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_bash_completi...
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:_zsh_highlight_widget_*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (user:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
10 _zsh_highlight_bind_widgets:27> case  (completion:*)
10 _zsh_highlight_bind_widgets:27> case  (*)
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=247
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=242
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=234
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=230
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=225
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=215
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=214
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=212
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=205
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=202
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=198
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=191
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=188
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=186
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=176
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=161
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=149
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=146
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=143
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=139
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=137
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=122
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=117
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=112
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=110
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=108
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=106
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=102
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=097
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=091
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=089
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=082
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=080
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=071
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=065
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=063
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=052
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=050
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=048
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=043
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=034
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=029
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=028
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=015
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=009
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=006
10 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=002
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/usr/sh...
10 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
10 -antigen-parse-args:155> [[ -n '' ]]
10 -antigen-parse-args:155> [[ -n '' ]]
10 -antigen-parse-args:137> [[ -n '' ]]
10 -antigen-parse-args:137> [[ -n '' ]]
10 -antigen-parse-args:127> [[ -n '' ]]
10 -antigen-parse-args:127> [[ -n '' ]]
10 -antigen-parse-args:127> [[ -n '' ]]
10 -antigen-parse-args:105> [[ ! -z '' ]]
10 -antigen-parse-args:105> [[ ! -z '' ]]
10 -antigen-parse-args:70> case https://github.com/robbyrussell/oh-my-zsh.git (h...
10 -antigen-parse-args:24> [[ lib == --loc ]]
10 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--no-local-cl...
10 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--*)
10 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--no-local-clone)
10 -antigen-parse-args:22> case deno (--no-local-clone)
10 -antigen-parse-args:17> [[ 1 -gt 0 ]]
10 -antigen-parse-args:14> args[btype]=plugin
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-parse-args:12> args[loc]=/
10 -antigen-load:20> [[ 0 == 0 ]]
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:46> replace_hook=1
10 -antigen-hook-handler:45> hook=antigen-bundle-parallel
10 -antigen-hook-handler:45> hook=antigen-bundle-defer
10 -antigen-hook-handler:45> hook=antigen-apply-parallel-execute
10 -antigen-hook-handler:45> hook=-antigen-load-source-cached
10 -antigen-hook-handler:45> hook=-antigen-load-source-cached
10 -antigen-hook-handler:45> hook=-antigen-load-source-cached
10 -antigen-hook-handler:45> hook=-antigen-load-env-cached
10 -antigen-hook-handler:45> hook=-antigen-load-env-cached
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case replace (replace)
10 -antigen-hook-handler:22> case post (replace)
10 -antigen-hook-handler:22> case post (post)
10 -antigen-hook-handler:18> meta[called]=11
10 -antigen-hook-handler:10> hook=antigen-lock
10 -antigen-hook-handler:10> hook=antigen-lock
10 -antigen-hook-handler:10> hook=antigen-bundle-parallel
10 -antigen-hook-handler:10> hook=antigen-bundle-parallel
10 -antigen-hook-handler:10> hook=antigen-bundle-defer
10 -antigen-hook-handler:10> hook=antigen-bundle-defer
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-bundle-cached
10 -antigen-hook-handler:10> hook=antigen-apply-lock
10 -antigen-hook-handler:10> hook=antigen-apply-defer
10 -antigen-hook-handler:10> hook=antigen-apply-defer
10 -antigen-hook-handler:10> hook=-antigen-load-source-cached
10 -antigen-hook-handler:10> hook=-antigen-load-source-cached
10 -antigen-hook-handler:10> hook=-antigen-load-env-cached
10 -antigen-hook-handler:10> hook=-antigen-load-env-cached
10 -antigen-cache-init:6> _ZCACHE_BUNDLE_SOURCE=( )
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
10 (eval):196> alias 'rd=rmdir'
10 (eval):14> alias '9=cd -9'
10 (eval):7> alias '2=cd -2'
9 is-at-least:55> part=''
9 is-at-least:55> part=''
9 is-at-least:55> part=''
9 is-at-least:55> part=''
9 is-at-least:55> part=''
9 is-at-least:54> ((  part < min_ver[min_cnt]  ))
9 is-at-least:49> ((  ++min_cnt > 4  ))
9 is-at-least:31> [[ '' != <-> ]]
9 is-at-least:31> [[ '' != <-> ]]
9 is-at-least:31> [[ '' != <-> ]]
9 compinit:500> _i_name=_xv
9 compinit:500> _i_name=_urls
9 compinit:500> _i_name=_quilt
9 compinit:500> _i_name=_ionice
9 compinit:500> _i_name=_ghc
9 compinit:500> _i_name=_gh
9 compinit:500> _i_name=_fuse_values
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_zftp
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xterm
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_xt_session_id
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vorbis
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_vared
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_time_zone
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_sublimetext
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_setxkbmap
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_set
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_qdbus
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_procstat
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_paste
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_osascript
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_options_unset
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_java
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_hdiutil
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_git-buildpackage
9 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_bindkey
9 compinit:499> _i_file=/usr/local/share/zsh/site-functions/_docker
9 compinit:496> _i_dir=/Users/matt/.oh-my-zsh/cache/completions
9 compinit:77> case -i (-i)
9 compinit:77> case -i (-D)
9 compinit:77> case -C (-u)
9 compinit:77> case -C (-D)
9 compdump:116> ((  ! --_i && 949 > 1  ))
9 compdump:116> ((  ! --_i && 734 > 1  ))
9 compdump:116> ((  ! --_i && 684 > 1  ))
9 compdump:116> ((  ! --_i && 634 > 1  ))
9 compdump:116> ((  ! --_i && 409 > 1  ))
9 compdump:116> ((  ! --_i && 249 > 1  ))
9 compdump:116> ((  ! --_i && 179 > 1  ))
9 compdump:116> ((  ! --_i && 29 > 1  ))
9 compdump:113> ((  762  ))
9 compdump:113> ((  663  ))
9 compdump:113> ((  534  ))
9 compdump:113> ((  458  ))
9 compdump:113> ((  329  ))
9 compdump:113> ((  292  ))
9 compdump:113> ((  269  ))
9 compdump:113> ((  186  ))
9 compdump:113> ((  151  ))
9 compdump:113> ((  132  ))
9 compdump:113> ((  114  ))
9 compdump:113> ((  104  ))
9 compdump:113> ((  88  ))
9 compdump:113> ((  75  ))
9 compdump:113> ((  51  ))
9 compdump:113> ((  45  ))
9 compdump:113> ((  41  ))
9 compdump:113> ((  37  ))
9 compdump:113> ((  33  ))
9 compdump:113> ((  27  ))
9 compdump:113> ((  20  ))
9 compdump:113> ((  9  ))
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:164> [[ -n yes ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:162> [[ -z '' ]]
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:160> svc=''
9 compdef:159> cmd=zxpdf
9 compdef:159> cmd=zun
9 compdef:159> cmd=zipinfo
9 compdef:159> cmd=zgrep
9 compdef:159> cmd=zfs
9 compdef:159> cmd=zf_rm
9 compdef:159> cmd=zf_ln
9 compdef:159> cmd=zen
9 compdef:159> cmd=zeal
9 compdef:159> cmd=zdelattr
9 compdef:159> cmd=yum
9 compdef:159> cmd=ytalk
9 compdef:159> cmd=ypxfr
9 compdef:159> cmd=ypwhich
9 compdef:159> cmd=yppoll
9 compdef:159> cmd=ypmatch
9 compdef:159> cmd=ypbind
9 compdef:159> cmd=xz
9 compdef:159> cmd=xvncviewer
9 compdef:159> cmd=xvnc4viewer
9 compdef:159> cmd=xterm
9 compdef:159> cmd=xping
9 compdef:159> cmd=write
9 compdef:159> cmd=whom
9 compdef:159> cmd=whoami
9 compdef:159> cmd=who
9 compdef:159> cmd=whereis
9 compdef:159> cmd=what
9 compdef:159> cmd=wc
9 compdef:159> cmd=wajig
9 compdef:159> cmd=w3m
9 compdef:159> cmd=w
9 compdef:159> cmd=virt-pki-validate
9 compdef:159> cmd=vimdiff
9 compdef:159> cmd=vim-addons
9 compdef:159> cmd=vim
9 compdef:159> cmd=useradd
9 compdef:159> cmd=urxvtc
9 compdef:159> cmd=urxvt256cc
9 compdef:159> cmd=urxvt256c-ml
9 compdef:159> cmd=urxvt256c
9 compdef:159> cmd=urpmq
9 compdef:159> cmd=urpmi.update
9 compdef:159> cmd=urpmi
9 compdef:159> cmd=unsetopt
9 compdef:159> cmd=unset
9 compdef:159> cmd=unlz4
9 compdef:159> cmd=uname
9 compdef:159> cmd=uml_mconsole
9 compdef:159> cmd=typeset
9 compdef:159> cmd=twist
9 compdef:159> cmd=tunes2pod
9 compdef:159> cmd=tune2fs
9 compdef:159> cmd=trove
9 compdef:159> cmd=trash
9 compdef:159> cmd=tracepath6
9 compdef:159> cmd=tpkg-make
9 compdef:159> cmd=tpkg-install
9 compdef:159> cmd=totdconfig
9 compdef:159> cmd=tload
9 compdef:159> cmd=tidy
9 compdef:159> cmd=tg
9 compdef:159> cmd=texi2pdf
9 compdef:159> cmd=texi2any
9 compdef:159> cmd=telnet
9 compdef:159> cmd=tcptraceroute
9 compdef:159> cmd=talk
9 compdef:159> cmd=tail
9 compdef:159> cmd=tacker
9 compdef:159> cmd=systat
9 compdef:159> cmd=sync
9 compdef:159> cmd=swift
9 compdef:159> cmd=svcs
9 compdef:159> cmd=sudoedit
9 compdef:159> cmd=subl
9 compdef:159> cmd=su
9 compdef:159> cmd=stty
9 compdef:159> cmd=strings
9 compdef:159> cmd=strace64
9 compdef:159> cmd=strace
9 compdef:159> cmd=stow
9 compdef:159> cmd=stat
9 compdef:159> cmd=start
9 compdef:159> cmd=sshfs
9 compdef:159> cmd=ssh-copy-id
9 compdef:159> cmd=sqsh
9 compdef:159> cmd=split
9 compdef:159> cmd=sortm
9 compdef:159> cmd=socket
9 compdef:159> cmd=snoop
9 compdef:159> cmd=smitty
9 compdef:159> cmd=smit
9 compdef:159> cmd=smbstatus
9 compdef:159> cmd=slrn
9 compdef:159> cmd=slocate
9 compdef:159> cmd=skipstone
9 compdef:159> cmd=sisu
9 compdef:159> cmd=signify
9 compdef:159> cmd=shuf
9 compdef:159> cmd=showmount
9 compdef:159> cmd=showchar
9 compdef:159> cmd=sftp
9 compdef:159> cmd=setxkbmap
9 compdef:159> cmd=setsid
9 compdef:159> cmd=setopt
9 compdef:159> cmd=setfattr
9 compdef:159> cmd=service
9 compdef:159> cmd=seaf-cli
9 compdef:159> cmd=scselect
9 compdef:159> cmd=sccsdiff
9 compdef:159> cmd=scan
9 compdef:159> cmd=rup
9 compdef:159> cmd=run-help
9 compdef:159> cmd=ruby-mri
9 compdef:159> cmd=rubber-info
9 compdef:159> cmd=rtin
9 compdef:159> cmd=rpmsign
9 compdef:159> cmd=rpmquery
9 compdef:159> cmd=rmmod
9 compdef:159> cmd=rmm
9 compdef:159> cmd=rmf
9 compdef:159> cmd=rmdir
9 compdef:159> cmd=rm
9 compdef:159> cmd=rlogin
9 compdef:159> cmd=retawq
9 compdef:159> cmd=repl
9 compdef:159> cmd=rebootin
9 compdef:159> cmd=readlink
9 compdef:159> cmd=rdesktop
9 compdef:159> cmd=rcsdiff
9 compdef:159> cmd=rc
9 compdef:159> cmd=ranlib
9 compdef:159> cmd=r
9 compdef:159> cmd=qiv
9 compdef:159> cmd=pwgen
9 compdef:159> cmd=pv
9 compdef:159> cmd=putclip.exe
9 compdef:159> cmd=putclip
9 compdef:159> cmd=pswrap
9 compdef:159> cmd=pstops
9 compdef:159> cmd=psed
9 compdef:159> cmd=psbook
9 compdef:159> cmd=ps2pdfwr
9 compdef:159> cmd=ps2pdf12
9 compdef:159> cmd=ps2epsi
9 compdef:159> cmd=ps
9 compdef:159> cmd=prun
9 compdef:159> cmd=prove
9 compdef:159> cmd=prompt
9 compdef:159> cmd=postsuper
9 compdef:159> cmd=portlint
9 compdef:159> cmd=podgrep
9 compdef:159> cmd=pmvers
9 compdef:159> cmd=pmload
9 compdef:159> cmd=pmfunc
9 compdef:159> cmd=pmexp
9 compdef:159> cmd=pmeth
9 compdef:159> cmd=pmdesc
9 compdef:159> cmd=pmake
9 compdef:159> cmd=pldd
9 compdef:159> cmd=pkill
9 compdef:159> cmd=pkgadd
9 compdef:159> cmd=pkg-config
9 compdef:159> cmd=pkg
9 compdef:159> cmd=piuparts
9 compdef:159> cmd=pinef
9 compdef:159> cmd=pine
9 compdef:159> cmd=picocom
9 compdef:159> cmd=pick
9 compdef:159> cmd=pg_restore
9 compdef:159> cmd=pg_isready
9 compdef:159> cmd=pg_ctl
9 compdef:159> cmd=pflags
9 compdef:159> cmd=pfiles
9 compdef:159> cmd=pfctl
9 compdef:159> cmd=pdksh
9 compdef:159> cmd=pdftotext
9 compdef:159> cmd=pdftops
9 compdef:159> cmd=pdflatex
9 compdef:159> cmd=pdfjadetex
9 compdef:159> cmd=pdfinfo
9 compdef:159> cmd=pcred
9 compdef:159> cmd=pbuilder
9 compdef:159> cmd=pbpaste
9 compdef:159> cmd=paste
9 compdef:159> cmd=parsehdlist
9 compdef:159> cmd=pandoc
9 compdef:159> cmd=packf
9 compdef:159> cmd=p4
9 compdef:159> cmd=osc
9 compdef:159> cmd=osascript
9 compdef:159> cmd=opera-next
9 compdef:159> cmd=oksh
9 compdef:159> cmd=oggenc
9 compdef:159> cmd=oggdec
9 compdef:159> cmd=ogg123
9 compdef:159> cmd=odme
9 compdef:159> cmd=od
9 compdef:159> cmd=nvram
9 compdef:159> cmd=ntalk
9 compdef:159> cmd=nslookup
9 compdef:159> cmd=npm
9 compdef:159> cmd=nova
9 compdef:159> cmd=noglob
9 compdef:159> cmd=nmap
9 compdef:159> cmd=nft
9 compdef:159> cmd=next
9 compdef:159> cmd=netcat
9 compdef:159> cmd=nedit
9 compdef:159> cmd=ncftp
9 compdef:159> cmd=nawk
9 compdef:159> cmd=nautilus
9 compdef:159> cmd=mysqlshow
9 compdef:159> cmd=mvim
9 compdef:159> cmd=mv
9 compdef:159> cmd=mtr
9 compdef:159> cmd=mtoolstest
9 compdef:159> cmd=mread
9 compdef:159> cmd=mrd
9 compdef:159> cmd=mpstat
9 compdef:159> cmd=mosh
9 compdef:159> cmd=mogrify
9 compdef:159> cmd=mmove
9 compdef:159> cmd=mmd
9 compdef:159> cmd=mlocate
9 compdef:159> cmd=mlabel
9 compdef:159> cmd=mkshortcut
9 compdef:159> cmd=mknod
9 compdef:159> cmd=mistral
9 compdef:159> cmd=mhstore
9 compdef:159> cmd=mhshow
9 compdef:159> cmd=mhmail
9 compdef:159> cmd=metaflac
9 compdef:159> cmd=merge
9 compdef:159> cmd=mere
9 compdef:159> cmd=mdutil
9 compdef:159> cmd=mdu
9 compdef:159> cmd=mcopy
9 compdef:159> cmd=mcd
9 compdef:159> cmd=makepkg
9 compdef:159> cmd=m-a
9 compdef:159> cmd=lz4c32
9 compdef:159> cmd=lz4
9 compdef:159> cmd=luarocks
9 compdef:159> cmd=lpstat
9 compdef:159> cmd=lpinfo
9 compdef:159> cmd=lpadmin
9 compdef:159> cmd=lp
9 compdef:159> cmd=losetup
9 compdef:159> cmd=llvm-objdump
9 compdef:159> cmd=lintian-info
9 compdef:159> cmd=lha
9 compdef:159> cmd=less
9 compdef:159> cmd=latexmk
9 compdef:159> cmd=knife
9 compdef:159> cmd=kldload
9 compdef:159> cmd=killall5
9 compdef:159> cmd=killall
9 compdef:159> cmd=kfmclient
9 compdef:159> cmd=jot
9 compdef:159> cmd=joe
9 compdef:159> cmd=jdb
9 compdef:159> cmd=javadoc
9 compdef:159> cmd=javac
9 compdef:159> cmd=java
9 compdef:159> cmd=jadetex
9 compdef:159> cmd=irssi
9 compdef:159> cmd=ipset
9 compdef:159> cmd=ipadm
9 compdef:159> cmd=ionice
9 compdef:159> cmd=install
9 compdef:159> cmd=infocmp
9 compdef:159> cmd=ijoin
9 compdef:159> cmd=ifup
9 compdef:159> cmd=iftop
9 compdef:159> cmd=http
9 compdef:159> cmd=htop
9 compdef:159> cmd=host
9 compdef:159> cmd=homestead
9 compdef:159> cmd=help
9 compdef:159> cmd=hdiutil
9 compdef:159> cmd=gvimdiff
9 compdef:159> cmd=gvim
9 compdef:159> cmd=guptime
9 compdef:159> cmd=gtr
9 compdef:159> cmd=gtail
9 compdef:159> cmd=gtac
9 compdef:159> cmd=gstty
9 compdef:159> cmd=gstrings
9 compdef:159> cmd=gstdbuf
9 compdef:159> cmd=gsplit
9 compdef:159> cmd=gslp
9 compdef:159> cmd=gslj
9 compdef:159> cmd=gshuf
9 compdef:159> cmd=gseq
9 compdef:159> cmd=gsed
9 compdef:159> cmd=gsdj500
9 compdef:159> cmd=gsdj
9 compdef:159> cmd=gsbj
9 compdef:159> cmd=gs
9 compdef:159> cmd=grm
9 compdef:159> cmd=grail
9 compdef:159> cmd=gpatch
9 compdef:159> cmd=gpasswd
9 compdef:159> cmd=google
9 compdef:159> cmd=go
9 compdef:159> cmd=gnl
9 compdef:159> cmd=gmkfifo
9 compdef:159> cmd=gmake
9 compdef:159> cmd=gm
9 compdef:159> cmd=gls
9 compdef:159> cmd=glocate
9 compdef:159> cmd=gitk
9 compdef:159> cmd=git-journal
9 compdef:159> cmd=git-flow
9 compdef:159> cmd=gid
9 compdef:159> cmd=ghostview
9 compdef:159> cmd=ghead
9 compdef:159> cmd=ggv
9 compdef:159> cmd=ggrep
9 compdef:159> cmd=gfgrep
9 compdef:159> cmd=gexpand
9 compdef:159> cmd=gex
9 compdef:159> cmd=getfattr
9 compdef:159> cmd=getfacl.exe
9 compdef:159> cmd=getafm
9 compdef:159> cmd=gem
9 compdef:159> cmd=gbase64
9 compdef:159> cmd=gbase32
9 compdef:159> cmd=gawk
9 compdef:159> cmd=gas
9 compdef:159> cmd=g++
9 compdef:159> cmd=fuser
9 compdef:159> cmd=functions
9 compdef:159> cmd=fmt
9 compdef:159> cmd=fixwfwps
9 compdef:159> cmd=fixscribeps
9 compdef:159> cmd=fixpspps
9 compdef:159> cmd=fixmacps
9 compdef:159> cmd=firefox
9 compdef:159> cmd=fink
9 compdef:159> cmd=find
9 compdef:159> cmd=fgrep
9 compdef:159> cmd=fab
9 compdef:159> cmd=extractres
9 compdef:159> cmd=extcheck
9 compdef:159> cmd=express
9 compdef:159> cmd=exportfs
9 compdef:159> cmd=export
9 compdef:159> cmd=expand
9 compdef:159> cmd=eu-readelf
9 compdef:159> cmd=eatmydata
9 compdef:159> cmd=dvc
9 compdef:159> cmd=dropuser
9 compdef:159> cmd=dropdb
9 compdef:159> cmd=dosread
9 compdef:159> cmd=dosdel
9 compdef:159> cmd=dockerd
9 compdef:159> cmd=dist
9 compdef:159> cmd=display
9 compdef:159> cmd=dillo
9 compdef:159> cmd=deno
9 compdef:159> cmd=dad
9 compdef:159> cmd=createdb
9 compdef:159> cmd=cowthink
9 compdef:159> cmd=conch
9 compdef:159> cmd=composer.phar
9 compdef:159> cmd=comp
9 compdef:159> cmd=combine
9 compdef:159> cmd=co
9 compdef:159> cmd=cmake
9 compdef:159> cmd=clusterdb
9 compdef:159> cmd=clang++
9 compdef:159> cmd=clang
9 compdef:159> cmd=chkstow
9 compdef:159> cmd=cftp
9 compdef:159> cmd=cf
9 compdef:159> cmd=ccache
9 compdef:159> cmd=cc
9 compdef:159> cmd=catchsegv
9 compdef:159> cmd=bzip2recover
9 compdef:159> cmd=bzip2
9 compdef:159> cmd=bzgrep
9 compdef:159> cmd=btrfs
9 compdef:159> cmd=btrename
9 compdef:159> cmd=btreannounce
9 compdef:159> cmd=btmakemetafile
9 compdef:159> cmd=bsdtar
9 compdef:159> cmd=brew
9 compdef:159> cmd=bpython3-gtk
9 compdef:159> cmd=bpython3
9 compdef:159> cmd=bpython2-urwid
9 compdef:159> cmd=bpython-urwid
9 compdef:159> cmd=bpython
9 compdef:159> cmd=bower
9 compdef:159> cmd=bibtex
9 compdef:159> cmd=beadm
9 compdef:159> cmd=batch
9 compdef:159> cmd=base64
9 compdef:159> cmd=base32
9 compdef:159> cmd=axi-cache
9 compdef:159> cmd=awk
9 compdef:159> cmd=augtool
9 compdef:159> cmd=ash
9 compdef:159> cmd=arena
9 compdef:159> cmd=apvlv
9 compdef:159> cmd=apt-get
9 compdef:159> cmd=apt-cdrom
9 compdef:159> cmd=aoss
9 compdef:159> cmd=ant
9 compdef:159> cmd=ansible-galaxy
9 compdef:159> cmd=ansible
9 compdef:159> cmd=admin
9 compdef:159> cmd=acpitool
9 compdef:159> cmd=aap
9 compdef:159> cmd=aaaa
9 compdef:159> cmd=SuSEconfig
9 compdef:159> cmd=6l
9 compdef:159> cmd=6g
9 compdef:159> cmd=.
9 compdef:159> cmd=-vared-
9 compdef:159> cmd=-value-,PROMPT,-default-
9 compdef:159> cmd=-redirect-
9 compdef:159> cmd=-parameter-
9 compdef:159> cmd=-
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:157> svc=yes
9 compdef:155> [[ zlistattr = *=* ]]
9 compdef:155> [[ yash = *=* ]]
9 compdef:155> [[ xattr = *=* ]]
9 compdef:155> [[ unxz = *=* ]]
9 compdef:155> [[ unset = *=* ]]
9 compdef:155> [[ twistd = *=* ]]
9 compdef:155> [[ trial = *=* ]]
9 compdef:155> [[ tracepath6 = *=* ]]
9 compdef:155> [[ tcsh = *=* ]]
9 compdef:155> [[ swiftc = *=* ]]
9 compdef:155> [[ star = *=* ]]
9 compdef:155> [[ scan = *=* ]]
9 compdef:155> [[ sact = *=* ]]
9 compdef:155> [[ s2p = *=* ]]
9 compdef:155> [[ rsh = *=* ]]
9 compdef:155> [[ rpmspec = *=* ]]
9 compdef:155> [[ rpmkeys = *=* ]]
9 compdef:155> [[ rmic = *=* ]]
9 compdef:155> [[ rmadison = *=* ]]
9 compdef:155> [[ rgview = *=* ]]
9 compdef:155> [[ repl = *=* ]]
9 compdef:155> [[ readonly = *=* ]]
9 compdef:155> [[ rcp = *=* ]]
9 compdef:155> [[ pwdx = *=* ]]
9 compdef:155> [[ pwait = *=* ]]
9 compdef:155> [[ psnup = *=* ]]
9 compdef:155> [[ psmulti = *=* ]]
9 compdef:155> [[ psmerge = *=* ]]
9 compdef:155> [[ ps2ps = *=* ]]
9 compdef:155> [[ ps2pdf13 = *=* ]]
9 compdef:155> [[ prun = *=* ]]
9 compdef:155> [[ prt = *=* ]]
9 compdef:155> [[ prs = *=* ]]
9 compdef:155> [[ prev = *=* ]]
9 compdef:155> [[ pmload = *=* ]]
9 compdef:155> [[ pg_dump = *=* ]]
9 compdef:155> [[ pdftexi2dvi = *=* ]]
9 compdef:155> [[ pdftex = *=* ]]
9 compdef:155> [[ ns = *=* ]]
9 compdef:155> [[ nocorrect = *=* ]]
9 compdef:155> [[ mysqlshow = *=* ]]
9 compdef:155> [[ mmm = *=* ]]
9 compdef:155> [[ mhn = *=* ]]
9 compdef:155> [[ mdel = *=* ]]
9 compdef:155> [[ local = *=* ]]
9 compdef:155> [[ latex = *=* ]]
9 compdef:155> [[ install-info = *=* ]]
9 compdef:155> [[ inc = *=* ]]
9 compdef:155> [[ gzilla = *=* ]]
9 compdef:155> [[ gtty = *=* ]]
9 compdef:155> [[ gtee = *=* ]]
9 compdef:155> [[ gtar = *=* ]]
9 compdef:155> [[ gseq = *=* ]]
9 compdef:155> [[ groupadd = *=* ]]
9 compdef:155> [[ grmdir = *=* ]]
9 compdef:155> [[ grail = *=* ]]
9 compdef:155> [[ gpaste = *=* ]]
9 compdef:155> [[ god = *=* ]]
9 compdef:155> [[ ghostview = *=* ]]
9 compdef:155> [[ galeon = *=* ]]
9 compdef:155> [[ fprev = *=* ]]
9 compdef:155> [[ fixfmps = *=* ]]
9 compdef:155> [[ fg = *=* ]]
9 compdef:155> [[ evim = *=* ]]
9 compdef:155> [[ epdfview = *=* ]]
9 compdef:155> [[ dwb = *=* ]]
9 compdef:155> [[ d = *=* ]]
9 compdef:155> [[ csh = *=* ]]
9 compdef:155> [[ clang = *=* ]]
9 compdef:155> [[ ckeygen = *=* ]]
9 compdef:155> [[ cifsiostat = *=* ]]
9 compdef:155> [[ ci = *=* ]]
9 compdef:155> [[ apvlv = *=* ]]
9 compdef:155> [[ admin = *=* ]]
9 compdef:155> [[ 5l = *=* ]]
9 compdef:155> [[ 5g = *=* ]]
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (postpattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case postpattern (pattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (postpattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (pattern)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:139> case  (*)
9 compdef:136> [[ zun = -P ]]
9 compdef:136> [[ zsetattr = -P ]]
9 compdef:136> [[ zlistattr = -P ]]
9 compdef:136> [[ zipinfo = -P ]]
9 compdef:136> [[ zdelattr = -P ]]
9 compdef:136> [[ zargs = -P ]]
9 compdef:136> [[ yumdb = -P ]]
9 compdef:136> [[ ypwhich = -P ]]
9 compdef:136> [[ yppush = -P ]]
9 compdef:136> [[ yppasswd = -P ]]
9 compdef:136> [[ xvncviewer = -P ]]
9 compdef:136> [[ xping = -P ]]
9 compdef:136> [[ www = -P ]]
9 compdef:136> [[ who = -P ]]
9 compdef:136> [[ what = -P ]]
9 compdef:136> [[ vorbiscomment = -P ]]
9 compdef:136> [[ vimdiff = -P ]]
9 compdef:136> [[ val = -P ]]
9 compdef:136> [[ urxvt256c-ml = -P ]]
9 compdef:136> [[ urxvt256c = -P ]]
9 compdef:136> [[ urpmf = -P ]]
9 compdef:136> [[ unxz = -P ]]
9 compdef:136> [[ unsetopt = -P ]]
9 compdef:136> [[ unset = -P ]]
9 compdef:136> [[ unpack = -P ]]
9 compdef:136> [[ unlimit = -P ]]
9 compdef:136> [[ typeset = -P ]]
9 compdef:136> [[ twistd = -P ]]
9 compdef:136> [[ tunes2pod = -P ]]
9 compdef:136> [[ trove = -P ]]
9 compdef:136> [[ trial = -P ]]
9 compdef:136> [[ tr = -P ]]
9 compdef:136> [[ tpkg-update = -P ]]
9 compdef:136> [[ tpkg-debarch = -P ]]
9 compdef:136> [[ timeout = -P ]]
9 compdef:136> [[ tidy = -P ]]
9 compdef:136> [[ tex = -P ]]
9 compdef:136> [[ tee = -P ]]
9 compdef:136> [[ tcsh = -P ]]
9 compdef:136> [[ tacker = -P ]]
9 compdef:136> [[ sync = -P ]]
9 compdef:136> [[ swiftc = -P ]]
9 compdef:136> [[ sw_vers = -P ]]
9 compdef:136> [[ svn = -P ]]
9 compdef:136> [[ svccfg = -P ]]
9 compdef:136> [[ sudo = -P ]]
9 compdef:136> [[ stty = -P ]]
9 compdef:136> [[ stat = -P ]]
9 compdef:136> [[ star = -P ]]
9 compdef:136> [[ ssh-keygen = -P ]]
9 compdef:136> [[ ssh = -P ]]
9 compdef:136> [[ ss = -P ]]
9 compdef:136> [[ srptool = -P ]]
9 compdef:136> [[ splitdiff = -P ]]
9 compdef:136> [[ sortm = -P ]]
9 compdef:136> [[ smit = -P ]]
9 compdef:136> [[ slabtop = -P ]]
9 compdef:136> [[ sisu = -P ]]
9 compdef:136> [[ signify = -P ]]
9 compdef:136> [[ showchar = -P ]]
9 compdef:136> [[ shift = -P ]]
9 compdef:136> [[ sh = -P ]]
9 compdef:136> [[ sftp = -P ]]
9 compdef:136> [[ senlin = -P ]]
9 compdef:136> [[ script = -P ]]
9 compdef:136> [[ scp = -P ]]
9 compdef:136> [[ scons = -P ]]
9 compdef:136> [[ schroot = -P ]]
9 compdef:136> [[ scan = -P ]]
9 compdef:136> [[ sc_usage = -P ]]
9 compdef:136> [[ say = -P ]]
9 compdef:136> [[ savecore = -P ]]
9 compdef:136> [[ rusage = -P ]]
9 compdef:136> [[ ruby-mri = -P ]]
9 compdef:136> [[ rubber-info = -P ]]
9 compdef:136> [[ rsync = -P ]]
9 compdef:136> [[ rsh = -P ]]
9 compdef:136> [[ rpmspec = -P ]]
9 compdef:136> [[ rpmsign = -P ]]
9 compdef:136> [[ rpmbuild = -P ]]
9 compdef:136> [[ rmadison = -P ]]
9 compdef:136> [[ removepkg = -P ]]
9 compdef:136> [[ reindexdb = -P ]]
9 compdef:136> [[ refile = -P ]]
9 compdef:136> [[ rebootin = -P ]]
9 compdef:136> [[ read = -P ]]
9 compdef:136> [[ rcs = -P ]]
9 compdef:136> [[ ranlib = -P ]]
9 compdef:136> [[ qdbus = -P ]]
9 compdef:136> [[ pv = -P ]]
9 compdef:136> [[ putclip.exe = -P ]]
9 compdef:136> [[ ptree = -P ]]
9 compdef:136> [[ pswrap = -P ]]
9 compdef:136> [[ pstack = -P ]]
9 compdef:136> [[ psmerge = -P ]]
9 compdef:136> [[ psed = -P ]]
9 compdef:136> [[ pscp.exe = -P ]]
9 compdef:136> [[ pscp = -P ]]
9 compdef:136> [[ psbook = -P ]]
9 compdef:136> [[ ps2pdf12 = -P ]]
9 compdef:136> [[ ps2epsi = -P ]]
9 compdef:136> [[ prt = -P ]]
9 compdef:136> [[ prove = -P ]]
9 compdef:136> [[ procstat = -P ]]
9 compdef:136> [[ postsuper = -P ]]
9 compdef:136> [[ portmaster = -P ]]
9 compdef:136> [[ podtoc = -P ]]
9 compdef:136> [[ pmexp = -P ]]
9 compdef:136> [[ pmdesc = -P ]]
9 compdef:136> [[ pmcat = -P ]]
9 compdef:136> [[ plutil = -P ]]
9 compdef:136> [[ pldd = -P ]]
9 compdef:136> [[ pkill = -P ]]
9 compdef:136> [[ pkgin = -P ]]
9 compdef:136> [[ pkg_info = -P ]]
9 compdef:136> [[ pkg = -P ]]
9 compdef:136> [[ pinef = -P ]]
9 compdef:136> [[ pine = -P ]]
9 compdef:136> [[ php = -P ]]
9 compdef:136> [[ pg_upgrade = -P ]]
9 compdef:136> [[ pg_restore = -P ]]
9 compdef:136> [[ pg_ctl = -P ]]
9 compdef:136> [[ perldoc = -P ]]
9 compdef:136> [[ pdksh = -P ]]
9 compdef:136> [[ pdftotext = -P ]]
9 compdef:136> [[ pdftopbm = -P ]]
9 compdef:136> [[ pdftexi2dvi = -P ]]
9 compdef:136> [[ pdftex = -P ]]
9 compdef:136> [[ pdflatex = -P ]]
9 compdef:136> [[ pdfimages = -P ]]
9 compdef:136> [[ pbpaste = -P ]]
9 compdef:136> [[ pbcopy = -P ]]
9 compdef:136> [[ pax = -P ]]
9 compdef:136> [[ p4d = -P ]]
9 compdef:136> [[ p4 = -P ]]
9 compdef:136> [[ odmshow = -P ]]
9 compdef:136> [[ odme = -P ]]
9 compdef:136> [[ ntalk = -P ]]
9 compdef:136> [[ noglob = -P ]]
9 compdef:136> [[ nocorrect = -P ]]
9 compdef:136> [[ new = -P ]]
9 compdef:136> [[ netstat = -P ]]
9 compdef:136> [[ mysqlimport = -P ]]
9 compdef:136> [[ murano = -P ]]
9 compdef:136> [[ mtr = -P ]]
9 compdef:136> [[ mtoolstest = -P ]]
9 compdef:136> [[ mread = -P ]]
9 compdef:136> [[ modinfo = -P ]]
9 compdef:136> [[ mmount = -P ]]
9 compdef:136> [[ mmm = -P ]]
9 compdef:136> [[ mknod = -P ]]
9 compdef:136> [[ mhn = -P ]]
9 compdef:136> [[ mhlist = -P ]]
9 compdef:136> [[ merge = -P ]]
9 compdef:136> [[ mdir = -P ]]
9 compdef:136> [[ mcopy = -P ]]
9 compdef:136> [[ mark = -P ]]
9 compdef:136> [[ makepkg = -P ]]
9 compdef:136> [[ makeinfo = -P ]]
9 compdef:136> [[ m-a = -P ]]
9 compdef:136> [[ lsusb = -P ]]
9 compdef:136> [[ lsmod = -P ]]
9 compdef:136> [[ lsdiff = -P ]]
9 compdef:136> [[ lsdev = -P ]]
9 compdef:136> [[ lsblk = -P ]]
9 compdef:136> [[ lpinfo = -P ]]
9 compdef:136> [[ lpadmin = -P ]]
9 compdef:136> [[ locate = -P ]]
9 compdef:136> [[ local = -P ]]
9 compdef:136> [[ llvm-gcc = -P ]]
9 compdef:136> [[ llvm-g++ = -P ]]
9 compdef:136> [[ links2 = -P ]]
9 compdef:136> [[ links = -P ]]
9 compdef:136> [[ lha = -P ]]
9 compdef:136> [[ lftp = -P ]]
9 compdef:136> [[ latex = -P ]]
9 compdef:136> [[ kpdf = -P ]]
9 compdef:136> [[ kldunload = -P ]]
9 compdef:136> [[ keytool = -P ]]
9 compdef:136> [[ kak = -P ]]
9 compdef:136> [[ join = -P ]]
9 compdef:136> [[ javap = -P ]]
9 compdef:136> [[ jadetex = -P ]]
9 compdef:136> [[ isag = -P ]]
9 compdef:136> [[ irssi = -P ]]
9 compdef:136> [[ interdiff = -P ]]
9 compdef:136> [[ integer = -P ]]
9 compdef:136> [[ initdb = -P ]]
9 compdef:136> [[ infocmp = -P ]]
9 compdef:136> [[ inc = -P ]]
9 compdef:136> [[ ijoin = -P ]]
9 compdef:136> [[ identify = -P ]]
9 compdef:136> [[ homestead = -P ]]
9 compdef:136> [[ help = -P ]]
9 compdef:136> [[ head = -P ]]
9 compdef:136> [[ gzilla = -P ]]
9 compdef:136> [[ gzfgrep = -P ]]
9 compdef:136> [[ gwho = -P ]]
9 compdef:136> [[ gview = -P ]]
9 compdef:136> [[ gtty = -P ]]
9 compdef:136> [[ gtr = -P ]]
9 compdef:136> [[ gtar = -P ]]
9 compdef:136> [[ gstty = -P ]]
9 compdef:136> [[ gstat = -P ]]
9 compdef:136> [[ gsplit = -P ]]
9 compdef:136> [[ gslp = -P ]]
9 compdef:136> [[ gslj = -P ]]
9 compdef:136> [[ gsed = -P ]]
9 compdef:136> [[ gsdj500 = -P ]]
9 compdef:136> [[ grm = -P ]]
9 compdef:136> [[ grepdiff = -P ]]
9 compdef:136> [[ gpg-zip = -P ]]
9 compdef:136> [[ god = -P ]]
9 compdef:136> [[ gmv = -P ]]
9 compdef:136> [[ gmknod = -P ]]
9 compdef:136> [[ gmkfifo = -P ]]
9 compdef:136> [[ gls = -P ]]
9 compdef:136> [[ glocate = -P ]]
9 compdef:136> [[ git-wtf = -P ]]
9 compdef:136> [[ ghostview = -P ]]
9 compdef:136> [[ ggv = -P ]]
9 compdef:136> [[ ggrep = -P ]]
9 compdef:136> [[ gfmt = -P ]]
9 compdef:136> [[ gfind = -P ]]
9 compdef:136> [[ get = -P ]]
9 compdef:136> [[ gcp = -P ]]
9 compdef:136> [[ functions = -P ]]
9 compdef:136> [[ fstat = -P ]]
9 compdef:136> [[ fprev = -P ]]
9 compdef:136> [[ fnext = -P ]]
9 compdef:136> [[ fly = -P ]]
9 compdef:136> [[ flutter = -P ]]
9 compdef:136> [[ float = -P ]]
9 compdef:136> [[ flist = -P ]]
9 compdef:136> [[ flipdiff = -P ]]
9 compdef:136> [[ fixwpps = -P ]]
9 compdef:136> [[ fixmacps = -P ]]
9 compdef:136> [[ finger = -P ]]
9 compdef:136> [[ filterdiff = -P ]]
9 compdef:136> [[ fg = -P ]]
9 compdef:136> [[ export = -P ]]
9 compdef:136> [[ explodepkg = -P ]]
9 compdef:136> [[ eview = -P ]]
9 compdef:136> [[ eatmydata = -P ]]
9 compdef:136> [[ dwb = -P ]]
9 compdef:136> [[ dosdel = -P ]]
9 compdef:136> [[ dmake = -P ]]
9 compdef:136> [[ dist = -P ]]
9 compdef:136> [[ dillo = -P ]]
9 compdef:136> [[ csh = -P ]]
9 compdef:136> [[ createuser = -P ]]
9 compdef:136> [[ cpio = -P ]]
9 compdef:136> [[ cp = -P ]]
9 compdef:136> [[ cowthink = -P ]]
9 compdef:136> [[ coreadm = -P ]]
9 compdef:136> [[ conch = -P ]]
9 compdef:136> [[ coffee = -P ]]
9 compdef:136> [[ clang = -P ]]
9 compdef:136> [[ ckeygen = -P ]]
9 compdef:136> [[ ci = -P ]]
9 compdef:136> [[ chkstow = -P ]]
9 compdef:136> [[ chage = -P ]]
9 compdef:136> [[ cdc = -P ]]
9 compdef:136> [[ catchsegv = -P ]]
9 compdef:136> [[ cask = -P ]]
9 compdef:136> [[ c++ = -P ]]
9 compdef:136> [[ bunzip2 = -P ]]
9 compdef:136> [[ bug = -P ]]
9 compdef:136> [[ btrfs = -P ]]
9 compdef:136> [[ btlaunchmany = -P ]]
9 compdef:136> [[ bsdconfig = -P ]]
9 compdef:136> [[ bpython3-gtk = -P ]]
9 compdef:136> [[ bpython3 = -P ]]
9 compdef:136> [[ bpython2-gtk = -P ]]
9 compdef:136> [[ bpython-urwid = -P ]]
9 compdef:136> [[ bpython = -P ]]
9 compdef:136> [[ bower = -P ]]
9 compdef:136> [[ bison = -P ]]
9 compdef:136> [[ bibtex = -P ]]
9 compdef:136> [[ beep = -P ]]
9 compdef:136> [[ beadm = -P ]]
9 compdef:136> [[ batch = -P ]]
9 compdef:136> [[ attr = -P ]]
9 compdef:136> [[ at = -P ]]
9 compdef:136> [[ ash = -P ]]
9 compdef:136> [[ asdf = -P ]]
9 compdef:136> [[ apvlv = -P ]]
9 compdef:136> [[ apt-cdrom = -P ]]
9 compdef:136> [[ appletviewer = -P ]]
9 compdef:136> [[ apm = -P ]]
9 compdef:136> [[ animate = -P ]]
9 compdef:136> [[ ali = -P ]]
9 compdef:136> [[ admin = -P ]]
9 compdef:136> [[ add-zsh-hook = -P ]]
9 compdef:136> [[ ack2 = -P ]]
9 compdef:136> [[ 6g = -P ]]
9 compdef:136> [[ 5l = -P ]]
9 compdef:136> [[ 5g = -P ]]
9 compdef:136> [[ -value-,TERM,-default- = -P ]]
9 compdef:136> [[ -value-,SPROMPT,-default- = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ -P = -P ]]
9 compdef:136> [[ - = -P ]]
9 compdef:136> [[ 'xetex=tex' = -P ]]
9 compdef:136> [[ 'remsh=rsh' = -P ]]
9 compdef:134> [[ zxpdf = -p ]]
9 compdef:134> [[ zone = -p ]]
9 compdef:134> [[ zgrep = -p ]]
9 compdef:134> [[ zfgrep = -p ]]
9 compdef:134> [[ zf_rmdir = -p ]]
9 compdef:134> [[ zf_rm = -p ]]
9 compdef:134> [[ zf_mv = -p ]]
9 compdef:134> [[ zen = -p ]]
9 compdef:134> [[ zegrep = -p ]]
9 compdef:134> [[ ytalk = -p ]]
9 compdef:134> [[ ypxfr = -p ]]
9 compdef:134> [[ ypset = -p ]]
9 compdef:134> [[ ypserv = -p ]]
9 compdef:134> [[ yppush = -p ]]
9 compdef:134> [[ yppoll = -p ]]
9 compdef:134> [[ yppasswd = -p ]]
9 compdef:134> [[ ypmatch = -p ]]
9 compdef:134> [[ yash = -p ]]
9 compdef:134> [[ xvnc4viewer = -p ]]
9 compdef:134> [[ xtp = -p ]]
9 compdef:134> [[ xtightvncviewer = -p ]]
9 compdef:134> [[ xping = -p ]]
9 compdef:134> [[ xmosaic = -p ]]
9 compdef:134> [[ xlsclients = -p ]]
9 compdef:134> [[ xattr = -p ]]
9 compdef:134> [[ whom = -p ]]
9 compdef:134> [[ whoami = -p ]]
9 compdef:134> [[ whence = -p ]]
9 compdef:134> [[ what = -p ]]
9 compdef:134> [[ watcher = -p ]]
9 compdef:134> [[ vncviewer = -p ]]
9 compdef:134> [[ vitrage = -p ]]
9 compdef:134> [[ vacuumdb = -p ]]
9 compdef:134> [[ usermod = -p ]]
9 compdef:134> [[ urxvtc = -p ]]
9 compdef:134> [[ urxvt256cc = -p ]]
9 compdef:134> [[ urxvt = -p ]]
9 compdef:134> [[ urpmq = -p ]]
9 compdef:134> [[ urpmi.update = -p ]]
9 compdef:134> [[ urpmi = -p ]]
9 compdef:134> [[ upgradepkg = -p ]]
9 compdef:134> [[ unzip = -p ]]
9 compdef:134> [[ unwrapdiff = -p ]]
9 compdef:134> [[ unlz4 = -p ]]
9 compdef:134> [[ umount = -p ]]
9 compdef:134> [[ uml_moo = -p ]]
9 compdef:134> [[ uml_mconsole = -p ]]
9 compdef:134> [[ typeset = -p ]]
9 compdef:134> [[ txt = -p ]]
9 compdef:134> [[ tryaffix = -p ]]
9 compdef:134> [[ traceroute = -p ]]
9 compdef:134> [[ tpkg-make = -p ]]
9 compdef:134> [[ tload = -p ]]
9 compdef:134> [[ tkinfo = -p ]]
9 compdef:134> [[ tkconch = -p ]]
9 compdef:134> [[ times = -p ]]
9 compdef:134> [[ tg = -p ]]
9 compdef:134> [[ texi2pdf = -p ]]
9 compdef:134> [[ texi2dvi = -p ]]
9 compdef:134> [[ texi2any = -p ]]
9 compdef:134> [[ telnet = -p ]]
9 compdef:134> [[ tar = -p ]]
9 compdef:134> [[ swift = -p ]]
9 compdef:134> [[ strace64 = -p ]]
9 compdef:134> [[ stow = -p ]]
9 compdef:134> [[ stop = -p ]]
9 compdef:134> [[ start = -p ]]
9 compdef:134> [[ star = -p ]]
9 compdef:134> [[ ssh-keyscan = -p ]]
9 compdef:134> [[ ssh-add = -p ]]
9 compdef:134> [[ srptool = -p ]]
9 compdef:134> [[ sqlite3 = -p ]]
9 compdef:134> [[ soa = -p ]]
9 compdef:134> [[ smbstatus = -p ]]
9 compdef:134> [[ slocate = -p ]]
9 compdef:134> [[ skipstone = -p ]]
9 compdef:134> [[ shred = -p ]]
9 compdef:134> [[ showmount = -p ]]
9 compdef:134> [[ show = -p ]]
9 compdef:134> [[ setxkbmap = -p ]]
9 compdef:134> [[ setsid = -p ]]
9 compdef:134> [[ serialver = -p ]]
9 compdef:134> [[ sccsdiff = -p ]]
9 compdef:134> [[ sahara = -p ]]
9 compdef:134> [[ sadf = -p ]]
9 compdef:134> [[ s2p = -p ]]
9 compdef:134> [[ rvim = -p ]]
9 compdef:134> [[ rview = -p ]]
9 compdef:134> [[ run-help = -p ]]
9 compdef:134> [[ rtin = -p ]]
9 compdef:134> [[ rsh = -p ]]
9 compdef:134> [[ rpmverify = -p ]]
9 compdef:134> [[ rpmquery = -p ]]
9 compdef:134> [[ rpmkeys = -p ]]
9 compdef:134> [[ rmmod = -p ]]
9 compdef:134> [[ rmm = -p ]]
9 compdef:134> [[ rmic = -p ]]
9 compdef:134> [[ rmdel = -p ]]
9 compdef:134> [[ rgvim = -p ]]
9 compdef:134> [[ rgview = -p ]]
9 compdef:134> [[ retawq = -p ]]
9 compdef:134> [[ reportbug = -p ]]
9 compdef:134> [[ repl = -p ]]
9 compdef:134> [[ rc = -p ]]
9 compdef:134> [[ r = -p ]]
9 compdef:134> [[ pwdx = -p ]]
9 compdef:134> [[ pwait = -p ]]
9 compdef:134> [[ pv = -p ]]
9 compdef:134> [[ pstotgif = -p ]]
9 compdef:134> [[ pstops = -p ]]
9 compdef:134> [[ psresize = -p ]]
9 compdef:134> [[ psql = -p ]]
9 compdef:134> [[ psnup = -p ]]
9 compdef:134> [[ psmulti = -p ]]
9 compdef:134> [[ psig = -p ]]
9 compdef:134> [[ ps2pdfwr = -p ]]
9 compdef:134> [[ ps2pdf14 = -p ]]
9 compdef:134> [[ ps2pdf = -p ]]
9 compdef:134> [[ ps2ascii = -p ]]
9 compdef:134> [[ prs = -p ]]
9 compdef:134> [[ prove = -p ]]
9 compdef:134> [[ prev = -p ]]
9 compdef:134> [[ postqueue = -p ]]
9 compdef:134> [[ postmaster = -p ]]
9 compdef:134> [[ postgres = -p ]]
9 compdef:134> [[ policytool = -p ]]
9 compdef:134> [[ podtoc = -p ]]
9 compdef:134> [[ podpath = -p ]]
9 compdef:134> [[ podgrep = -p ]]
9 compdef:134> [[ pmls = -p ]]
9 compdef:134> [[ pmfunc = -p ]]
9 compdef:134> [[ pman = -p ]]
9 compdef:134> [[ pmake = -p ]]
9 compdef:134> [[ pkg_create = -p ]]
9 compdef:134> [[ pkg-config = -p ]]
9 compdef:134> [[ pick = -p ]]
9 compdef:134> [[ pg_isready = -p ]]
9 compdef:134> [[ pg_dumpall = -p ]]
9 compdef:134> [[ pg_dump = -p ]]
9 compdef:134> [[ pg_config = -p ]]
9 compdef:134> [[ pfiles = -p ]]
9 compdef:134> [[ pdftopbm = -p ]]
9 compdef:134> [[ pdfopt = -p ]]
9 compdef:134> [[ pdfjadetex = -p ]]
9 compdef:134> [[ pdfinfo = -p ]]
9 compdef:134> [[ pdfimages = -p ]]
9 compdef:134> [[ pdffonts = -p ]]
9 compdef:134> [[ pdf2ps = -p ]]
9 compdef:134> [[ pcred = -p ]]
9 compdef:134> [[ pax = -p ]]
9 compdef:134> [[ packf = -p ]]
9 compdef:134> [[ opera = -p ]]
9 compdef:134> [[ ogginfo = -p ]]
9 compdef:134> [[ oggdec = -p ]]
9 compdef:134> [[ ogg123 = -p ]]
9 compdef:134> [[ nvim = -p ]]
9 compdef:134> [[ ns = -p ]]
9 compdef:134> [[ nova = -p ]]
9 compdef:134> [[ nohup = -p ]]
9 compdef:134> [[ next = -p ]]
9 compdef:134> [[ netrik = -p ]]
9 compdef:134> [[ netcat = -p ]]
9 compdef:134> [[ nawk = -p ]]
9 compdef:134> [[ mysqlshow = -p ]]
9 compdef:134> [[ mysqldump = -p ]]
9 compdef:134> [[ mysqladmin = -p ]]
9 compdef:134> [[ mx = -p ]]
9 compdef:134> [[ mvim = -p ]]
9 compdef:134> [[ mutt = -p ]]
9 compdef:134> [[ msgchk = -p ]]
9 compdef:134> [[ mren = -p ]]
9 compdef:134> [[ mrd = -p ]]
9 compdef:134> [[ mozilla-firefox = -p ]]
9 compdef:134> [[ montage = -p ]]
9 compdef:134> [[ mogrify = -p ]]
9 compdef:134> [[ modprobe = -p ]]
9 compdef:134> [[ modinfo = -p ]]
9 compdef:134> [[ mlocate = -p ]]
9 compdef:134> [[ mlabel = -p ]]
9 compdef:134> [[ mkzsh.exe = -p ]]
9 compdef:134> [[ mistral = -p ]]
9 compdef:134> [[ mhstore = -p ]]
9 compdef:134> [[ mhpath = -p ]]
9 compdef:134> [[ mhparam = -p ]]
9 compdef:134> [[ mhmail = -p ]]
9 compdef:134> [[ mhlist = -p ]]
9 compdef:134> [[ mformat = -p ]]
9 compdef:134> [[ mdu = -p ]]
9 compdef:134> [[ mdel = -p ]]
9 compdef:134> [[ mcd = -p ]]
9 compdef:134> [[ makeinfo = -p ]]
9 compdef:134> [[ lz4cat = -p ]]
9 compdef:134> [[ lpstat = -p ]]
9 compdef:134> [[ lpr = -p ]]
9 compdef:134> [[ lpoptions = -p ]]
9 compdef:134> [[ logname = -p ]]
9 compdef:134> [[ localedef = -p ]]
9 compdef:134> [[ local = -p ]]
9 compdef:134> [[ llvm-objdump = -p ]]
9 compdef:134> [[ llvm-gcc = -p ]]
9 compdef:134> [[ lintian-info = -p ]]
9 compdef:134> [[ light = -p ]]
9 compdef:134> [[ ldconfig = -p ]]
9 compdef:134> [[ latexmk = -p ]]
9 compdef:134> [[ lastb = -p ]]
9 compdef:134> [[ kpdf = -p ]]
9 compdef:134> [[ killall5 = -p ]]
9 compdef:134> [[ kfmclient = -p ]]
9 compdef:134> [[ jdb = -p ]]
9 compdef:134> [[ javah = -p ]]
9 compdef:134> [[ javadoc = -p ]]
9 compdef:134> [[ java = -p ]]
9 compdef:134> [[ jarsigner = -p ]]
9 compdef:134> [[ jar = -p ]]
9 compdef:134> [[ ironic = -p ]]
9 compdef:134> [[ irb = -p ]]
9 compdef:134> [[ ip6tables-save = -p ]]
9 compdef:134> [[ ip6tables = -p ]]
9 compdef:134> [[ insmod = -p ]]
9 compdef:134> [[ infocmp = -p ]]
9 compdef:134> [[ includeres = -p ]]
9 compdef:134> [[ hotjava = -p ]]
9 compdef:134> [[ hilite = -p ]]
9 compdef:134> [[ help = -p ]]
9 compdef:134> [[ gwc = -p ]]
9 compdef:134> [[ gvim = -p ]]
9 compdef:134> [[ gview = -p ]]
9 compdef:134> [[ guptime = -p ]]
9 compdef:134> [[ gunexpand = -p ]]
9 compdef:134> [[ gtr = -p ]]
9 compdef:134> [[ gtimeout = -p ]]
9 compdef:134> [[ gtee = -p ]]
9 compdef:134> [[ gtac = -p ]]
9 compdef:134> [[ gstrings = -p ]]
9 compdef:134> [[ gstdbuf = -p ]]
9 compdef:134> [[ gsnd = -p ]]
9 compdef:134> [[ gslp = -p ]]
9 compdef:134> [[ gshuf = -p ]]
9 compdef:134> [[ gshred = -p ]]
9 compdef:134> [[ gsed = -p ]]
9 compdef:134> [[ groups = -p ]]
9 compdef:134> [[ groupmod = -p ]]
9 compdef:134> [[ greadlink = -p ]]
9 compdef:134> [[ grail = -p ]]
9 compdef:134> [[ gpatch = -p ]]
9 compdef:134> [[ gpaste = -p ]]
9 compdef:134> [[ gofmt = -p ]]
9 compdef:134> [[ gnupod_INIT = -p ]]
9 compdef:134> [[ gnumfmt = -p ]]
9 compdef:134> [[ gnl = -p ]]
9 compdef:134> [[ gmktemp = -p ]]
9 compdef:134> [[ gmkfifo = -p ]]
9 compdef:134> [[ gmkdir = -p ]]
9 compdef:134> [[ gmake = -p ]]
9 compdef:134> [[ gjoin = -p ]]
9 compdef:134> [[ ghead = -p ]]
9 compdef:134> [[ ggetopt = -p ]]
9 compdef:134> [[ gfold = -p ]]
9 compdef:134> [[ gfgrep = -p ]]
9 compdef:134> [[ gexpand = -p ]]
9 compdef:134> [[ get = -p ]]
9 compdef:134> [[ gdiff = -p ]]
9 compdef:134> [[ gbase32 = -p ]]
9 compdef:134> [[ galeon = -p ]]
9 compdef:134> [[ g++ = -p ]]
9 compdef:134> [[ fwhois = -p ]]
9 compdef:134> [[ forw = -p ]]
9 compdef:134> [[ folder = -p ]]
9 compdef:134> [[ fnext = -p ]]
9 compdef:134> [[ flist = -p ]]
9 compdef:134> [[ flex++ = -p ]]
9 compdef:134> [[ fixscribeps = -p ]]
9 compdef:134> [[ fixfmps = -p ]]
9 compdef:134> [[ fixdlsrps = -p ]]
9 compdef:134> [[ firefox = -p ]]
9 compdef:134> [[ fgrep = -p ]]
9 compdef:134> [[ false = -p ]]
9 compdef:134> [[ fail2ban-client = -p ]]
9 compdef:134> [[ extractres = -p ]]
9 compdef:134> [[ expand = -p ]]
9 compdef:134> [[ eu-strings = -p ]]
9 compdef:134> [[ eu-nm = -p ]]
9 compdef:134> [[ erb = -p ]]
9 compdef:134> [[ egrep = -p ]]
9 compdef:134> [[ eatmydata = -p ]]
9 compdef:134> [[ dropuser = -p ]]
9 compdef:134> [[ dropdb = -p ]]
9 compdef:134> [[ dockerd = -p ]]
9 compdef:134> [[ display = -p ]]
9 compdef:134> [[ declare = -p ]]
9 compdef:134> [[ cowthink = -p ]]
9 compdef:134> [[ console = -p ]]
9 compdef:134> [[ composite = -p ]]
9 compdef:134> [[ composer.phar = -p ]]
9 compdef:134> [[ comp = -p ]]
9 compdef:134> [[ combine = -p ]]
9 compdef:134> [[ cockroach = -p ]]
9 compdef:134> [[ clear = -p ]]
9 compdef:134> [[ clang++ = -p ]]
9 compdef:134> [[ chfn = -p ]]
9 compdef:134> [[ cftp = -p ]]
9 compdef:134> [[ certtool = -p ]]
9 compdef:134> [[ cdc = -p ]]
9 compdef:134> [[ cc = -p ]]
9 compdef:134> [[ bzgrep = -p ]]
9 compdef:134> [[ bzfgrep = -p ]]
9 compdef:134> [[ bzegrep = -p ]]
9 compdef:134> [[ burst = -p ]]
9 compdef:134> [[ bttrack = -p ]]
9 compdef:134> [[ bsdtar = -p ]]
9 compdef:134> [[ bsdgrep = -p ]]
9 compdef:134> [[ bsdconfig = -p ]]
9 compdef:134> [[ bpython2 = -p ]]
9 compdef:134> [[ bogotune = -p ]]
9 compdef:134> [[ baz = -p ]]
9 compdef:134> [[ base32 = -p ]]
9 compdef:134> [[ avahi-resolve = -p ]]
9 compdef:134> [[ ash = -p ]]
9 compdef:134> [[ arecord = -p ]]
9 compdef:134> [[ apvlv = -p ]]
9 compdef:134> [[ aoss = -p ]]
9 compdef:134> [[ ack-standalone = -p ]]
9 compdef:134> [[ aaaa = -p ]]
9 compdef:134> [[ SuSEconfig = -p ]]
9 compdef:134> [[ Mosaic = -p ]]
9 compdef:134> [[ 6l = -p ]]
9 compdef:134> [[ -value-,RPS2,-default- = -p ]]
9 compdef:134> [[ -value-,MPD_HOST,-default = -p ]]
9 compdef:134> [[ -array-value- = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ -P = -p ]]
9 compdef:134> [[ 'xelatex=latex' = -p ]]
9 compdef:134> [[ 'svnlite=svn' = -p ]]
9 compdef:134> [[ 'shasum(|5).*' = -p ]]
9 compdef:134> [[ 'pcat=unpack' = -p ]]
9 compdef:134> [[ 'nedit-nc=nc' = -p ]]
9 compdef:134> [[ 'ncl=nc' = -p ]]
9 compdef:134> [[ 'lzma=xz' = -p ]]
9 compdef:134> [[ 'ggp=git-checkout' = -p ]]
9 compdef:134> [[ 'ggl=git-checkout' = -p ]]
9 compdef:134> [[ 'gem[0-9.]#' = -p ]]
9 compdef:134> [[ 'c++-*' = -p ]]
9 compdef:134> [[ 'Mail=mail' = -p ]]
9 compdef:132> [[ zun = -N ]]
9 compdef:132> [[ zstat = -N ]]
9 compdef:132> [[ zf_mv = -N ]]
9 compdef:132> [[ ypwhich = -N ]]
9 compdef:132> [[ ypbind = -N ]]
9 compdef:132> [[ where = -N ]]
9 compdef:132> [[ virt-admin = -N ]]
9 compdef:132> [[ vimdiff = -N ]]
9 compdef:132> [[ userdel = -N ]]
9 compdef:132> [[ urpmf = -N ]]
9 compdef:132> [[ unxz = -N ]]
9 compdef:132> [[ unsetopt = -N ]]
9 compdef:132> [[ uml_mconsole = -N ]]
9 compdef:132> [[ type = -N ]]
9 compdef:132> [[ twistd = -N ]]
9 compdef:132> [[ tpkg-update = -N ]]
9 compdef:132> [[ tpkg-make = -N ]]
9 compdef:132> [[ tpkg-debarch = -N ]]
9 compdef:132> [[ tcsh = -N ]]
9 compdef:132> [[ sync = -N ]]
9 compdef:132> [[ swiftc = -N ]]
9 compdef:132> [[ sudoedit = -N ]]
9 compdef:132> [[ ssh-agent = -N ]]
9 compdef:132> [[ sortm = -N ]]
9 compdef:132> [[ smitty = -N ]]
9 compdef:132> [[ showchar = -N ]]
9 compdef:132> [[ sftp = -N ]]
9 compdef:132> [[ setfacl.exe = -N ]]
9 compdef:132> [[ sccsdiff = -N ]]
9 compdef:132> [[ scan = -N ]]
9 compdef:132> [[ sact = -N ]]
9 compdef:132> [[ rup = -N ]]
9 compdef:132> [[ rubber-pipe = -N ]]
9 compdef:132> [[ rpmspec = -N ]]
9 compdef:132> [[ rpmsign = -N ]]
9 compdef:132> [[ rmdel = -N ]]
9 compdef:132> [[ readonly = -N ]]
9 compdef:132> [[ rcsdiff = -N ]]
9 compdef:132> [[ rcs = -N ]]
9 compdef:132> [[ querybts = -N ]]
9 compdef:132> [[ pyhtmlizer = -N ]]
9 compdef:132> [[ pwait = -N ]]
9 compdef:132> [[ pswrap = -N ]]
9 compdef:132> [[ pstop = -N ]]
9 compdef:132> [[ pstack = -N ]]
9 compdef:132> [[ psmerge = -N ]]
9 compdef:132> [[ psbook = -N ]]
9 compdef:132> [[ ps2ps = -N ]]
9 compdef:132> [[ ps2pdfwr = -N ]]
9 compdef:132> [[ ps2pdf13 = -N ]]
9 compdef:132> [[ prt = -N ]]
9 compdef:132> [[ prs = -N ]]
9 compdef:132> [[ poff = -N ]]
9 compdef:132> [[ pmload = -N ]]
9 compdef:132> [[ pmeth = -N ]]
9 compdef:132> [[ pmcat = -N ]]
9 compdef:132> [[ pldd = -N ]]
9 compdef:132> [[ pkg_delete = -N ]]
9 compdef:132> [[ pinef = -N ]]
9 compdef:132> [[ pdftops = -N ]]
9 compdef:132> [[ pdftopbm = -N ]]
9 compdef:132> [[ pdftex = -N ]]
9 compdef:132> [[ pdflatex = -N ]]
9 compdef:132> [[ pbpaste = -N ]]
9 compdef:132> [[ oksh = -N ]]
9 compdef:132> [[ ntalk = -N ]]
9 compdef:132> [[ nohup = -N ]]
9 compdef:132> [[ nocorrect = -N ]]
9 compdef:132> [[ munchlist = -N ]]
9 compdef:132> [[ mtype = -N ]]
9 compdef:132> [[ mread = -N ]]
9 compdef:132> [[ monasca = -N ]]
9 compdef:132> [[ mmove = -N ]]
9 compdef:132> [[ mmm = -N ]]
9 compdef:132> [[ mmd = -N ]]
9 compdef:132> [[ mlocate = -N ]]
9 compdef:132> [[ mhstore = -N ]]
9 compdef:132> [[ mhshow = -N ]]
9 compdef:132> [[ mhn = -N ]]
9 compdef:132> [[ merge = -N ]]
9 compdef:132> [[ mdir = -N ]]
9 compdef:132> [[ mark = -N ]]
9 compdef:132> [[ makepkg = -N ]]
9 compdef:132> [[ magnum = -N ]]
9 compdef:132> [[ lsdiff = -N ]]
9 compdef:132> [[ lpstat = -N ]]
9 compdef:132> [[ lprm = -N ]]
9 compdef:132> [[ lftp = -N ]]
9 compdef:132> [[ jdb = -N ]]
9 compdef:132> [[ javap = -N ]]
9 compdef:132> [[ javadoc = -N ]]
9 compdef:132> [[ jadetex = -N ]]
9 compdef:132> [[ isag = -N ]]
9 compdef:132> [[ insmod = -N ]]
9 compdef:132> [[ inc = -N ]]
9 compdef:132> [[ import = -N ]]
9 compdef:132> [[ ijoin = -N ]]
9 compdef:132> [[ ifdown = -N ]]
9 compdef:132> [[ hd = -N ]]
9 compdef:132> [[ gzilla = -N ]]
9 compdef:132> [[ gwho = -N ]]
9 compdef:132> [[ gvimdiff = -N ]]
9 compdef:132> [[ gtty = -N ]]
9 compdef:132> [[ gtr = -N ]]
9 compdef:132> [[ gstty = -N ]]
9 compdef:132> [[ gstat = -N ]]
9 compdef:132> [[ gsplit = -N ]]
9 compdef:132> [[ gslp = -N ]]
9 compdef:132> [[ gslj = -N ]]
9 compdef:132> [[ gseq = -N ]]
9 compdef:132> [[ groupmod = -N ]]
9 compdef:132> [[ grmdir = -N ]]
9 compdef:132> [[ god = -N ]]
9 compdef:132> [[ gls = -N ]]
9 compdef:132> [[ ghostview = -N ]]
9 compdef:132> [[ ghead = -N ]]
9 compdef:132> [[ ggrep = -N ]]
9 compdef:132> [[ gex = -N ]]
9 compdef:132> [[ getafm = -N ]]
9 compdef:132> [[ gcp = -N ]]
9 compdef:132> [[ fprev = -N ]]
9 compdef:132> [[ folders = -N ]]
9 compdef:132> [[ fmttest = -N ]]
9 compdef:132> [[ float = -N ]]
9 compdef:132> [[ flists = -N ]]
9 compdef:132> [[ flipdiff = -N ]]
9 compdef:132> [[ fixwpps = -N ]]
9 compdef:132> [[ fixwfwps = -N ]]
9 compdef:132> [[ filterdiff = -N ]]
9 compdef:132> [[ fg = -N ]]
9 compdef:132> [[ explodepkg = -N ]]
9 compdef:132> [[ expand = -N ]]
9 compdef:132> [[ eval = -N ]]
9 compdef:132> [[ eu-readelf = -N ]]
9 compdef:132> [[ erb = -N ]]
9 compdef:132> [[ dwb = -N ]]
9 compdef:132> [[ display = -N ]]
9 compdef:132> [[ csh = -N ]]
9 compdef:132> [[ createdb = -N ]]
9 compdef:132> [[ clang = -N ]]
9 compdef:132> [[ ckeygen = -N ]]
9 compdef:132> [[ chkstow = -N ]]
9 compdef:132> [[ catchsegv = -N ]]
9 compdef:132> [[ btrename = -N ]]
9 compdef:132> [[ bpython3-gtk = -N ]]
9 compdef:132> [[ bpython2-urwid = -N ]]
9 compdef:132> [[ bpython-gtk = -N ]]
9 compdef:132> [[ apt-config = -N ]]
9 compdef:132> [[ aoss = -N ]]
9 compdef:132> [[ admin = -N ]]
9 compdef:132> [[ 8l = -N ]]
9 compdef:132> [[ 8g = -N ]]
9 compdef:132> [[ 6l = -N ]]
9 compdef:132> [[ 6g = -N ]]
9 compdef:132> [[ 5l = -N ]]
9 compdef:132> [[ -value-,P4PORT,-default- = -N ]]
9 compdef:132> [[ -P = -N ]]
9 compdef:132> [[ -P = -N ]]
9 compdef:132> [[ -P = -N ]]
9 compdef:132> [[ -P = -N ]]
9 compdef:132> [[ -P = -N ]]
9 compdef:132> [[ 'xetex=tex' = -N ]]
9 compdef:132> [[ 'gcc-*' = -N ]]
9 compdef:131> ((  34  ))
9 compdef:131> ((  27  ))
9 compdef:131> ((  20  ))
9 compdef:131> ((  20  ))
9 compdef:131> ((  19  ))
9 compdef:131> ((  19  ))
9 compdef:131> ((  18  ))
9 compdef:131> ((  18  ))
9 compdef:131> ((  17  ))
9 compdef:131> ((  17  ))
9 compdef:131> ((  17  ))
9 compdef:131> ((  16  ))
9 compdef:131> ((  16  ))
9 compdef:131> ((  16  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  15  ))
9 compdef:131> ((  14  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  13  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  12  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  11  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  10  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  9  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  8  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  7  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  6  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  5  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  4  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  3  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  2  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:131> ((  1  ))
9 compdef:120> i=C-xh
9 compdef:83> case postpattern (widgetkey)
9 compdef:83> case postpattern (key)
9 compdef:83> case postpattern (key)
9 compdef:83> case postpattern (key)
9 compdef:83> case postpattern (*)
9 compdef:83> case postpattern (*)
9 compdef:83> case pattern (key)
9 compdef:83> case key (widgetkey)
9 compdef:83> case key (widgetkey)
9 compdef:83> case key (widgetkey)
9 compdef:83> case key (key)
9 compdef:83> case key (key)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (widgetkey)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (key)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:83> case  (*)
9 compdef:79> func=_yum
9 compdef:79> func=_wc
9 compdef:79> func=_w3m
9 compdef:79> func=_vnc
9 compdef:79> func=_urpmi
9 compdef:79> func=_uname
9 compdef:79> func=_uml
9 compdef:79> func=_typeset
9 compdef:79> func=_ttyctl
9 compdef:79> func=_tty
9 compdef:79> func=_trap
9 compdef:79> func=_tr
9 compdef:79> func=_totd
9 compdef:79> func=_topgit
9 compdef:79> func=_tload
9 compdef:79> func=_timeout
9 compdef:79> func=_tidy
9 compdef:79> func=_texi
9 compdef:79> func=_tex
9 compdef:79> func=_tcpsys
9 compdef:79> func=_tar
9 compdef:79> func=_tac
9 compdef:79> func=_sysrc
9 compdef:79> func=_swanctl
9 compdef:79> func=_sw_vers
9 compdef:79> func=_svcs
9 compdef:79> func=_sudo
9 compdef:79> func=_stty
9 compdef:79> func=_stow
9 compdef:79> func=_ssh
9 compdef:79> func=_sqlite
9 compdef:79> func=_split
9 compdef:79> func=_socket
9 compdef:79> func=_slabtop
9 compdef:79> func=_shuf
9 compdef:79> func=_shasum
9 compdef:79> func=_setxkbmap
9 compdef:79> func=_setsid
9 compdef:79> func=_sed
9 compdef:79> func=_scl
9 compdef:79> func=_savecore
9 compdef:79> func=_rubber
9 compdef:79> func=_reprepro
9 compdef:79> func=_qtplay
9 compdef:79> func=_pydoc
9 compdef:79> func=_pump
9 compdef:79> func=_pscp
9 compdef:79> func=_print
9 compdef:79> func=_postgresql
9 compdef:79> func=_portlint
9 compdef:79> func=_pkg5
9 compdef:79> func=_pdftk
9 compdef:79> func=_pbcopy
9 compdef:79> func=_patchutils
9 compdef:79> func=_patch
9 compdef:79> func=_pack
9 compdef:79> func=_otool
9 compdef:79> func=_osascript
9 compdef:79> func=_omz
9 compdef:79> func=_od
9 compdef:79> func=_nothing
9 compdef:79> func=_normal
9 compdef:79> func=_nm
9 compdef:79> func=_mt
9 compdef:79> func=_mknod
9 compdef:79> func=_mkdir
9 compdef:79> func=_mergechanges
9 compdef:79> func=_mere
9 compdef:79> func=_mencal
9 compdef:79> func=_mdls
9 compdef:79> func=_lsblk
9 compdef:79> func=_jrnl
9 compdef:79> func=_join
9 compdef:79> func=_java
9 compdef:79> func=_inxi
9 compdef:79> func=_in_vared
9 compdef:79> func=_httpie
9 compdef:79> func=_global
9 compdef:79> func=_git
9 compdef:79> func=_git
9 compdef:79> func=_git
9 compdef:79> func=_getopt
9 compdef:79> func=_getfacl
9 compdef:79> func=_gdb
9 compdef:79> func=_fusermount
9 compdef:79> func=_fuser
9 compdef:79> func=_fstat
9 compdef:79> func=_fsh
9 compdef:79> func=_exportfs
9 compdef:79> func=_dirs
9 compdef:79> func=_composer
9 compdef:79> func=_cmake
9 compdef:79> func=_bzip2
9 compdef:79> func=_builtin
9 compdef:79> func=_bindkey
9 compdef:79> func=_bibtex
9 compdef:79> func=_beep
9 compdef:79> func=_beadm
9 compdef:79> func=_autocd
9 compdef:79> func=_apt-show-versions
9 compdef:79> func=_apt
9 compdef:79> func=_apm
9 compdef:79> func=_ant
9 compdef:79> func=_SUSEconfig
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:49> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:45> [[ -z '' ]]
9 compdef:28> [[ k = K ]]
9 compdef:28> [[ k = K ]]
9 compdef:26> [[ k = P ]]
9 compdef:26> [[ P = P ]]
9 compdef:26> [[ P = P ]]
9 compdef:26> [[ K = P ]]
9 compdef:26> [[ K = P ]]
9 compdef:24> [[ p = p ]]
9 compdef:24> [[ k = p ]]
9 compdef:24> [[ P = p ]]
9 compdef:24> [[ P = p ]]
9 compdef:15> case p (n)
9 compdef:15> case p (a)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (n)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case n (a)
9 compdef:15> case k (n)
9 compdef:15> case k (n)
9 compdef:15> case k (n)
9 compdef:15> case k (n)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case a (a)
9 compdef:15> case P (n)
9 compdef:15> case P (a)
9 colors:113> k=bg-yellow
9 colors:113> k=bg-grey
9 colors:113> k=bg-blue
9 colors:113> k=bg-black
9 colors:104> k=fg-magenta
9 colors:104> k=fg-grey
9 colors:104> k=fg-default
9 colors:81> k=30
9 colors:77> k=47
9 colors:77> k=45
9 colors:77> k=45
9 colors:77> k=36
9 colors:77> k=33
9 colors:77> k=33
9 colors:77> k=31
9 colors:77> k=27
9 colors:77> k=23
9 colors:77> k=08
9 colors:77> k=05
9 colors:77> k=00
9 add-zsh-hook:68> ((  del  ))
9 add-zsh-hook:57> ((  list  ))
9 add-zsh-hook:57> ((  list  ))
9 add-zsh-hook:57> ((  list  ))
9 add-zle-hook-widget:178> case file shfunc shfunc shfunc shfunc shfunc shfunc ...
9 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_read_comp (us...
9 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_history_compl...
9 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_tag ...
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (user:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
9 _zsh_highlight_bind_widgets:27> case  (builtin)
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=255
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=253
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=252
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=250
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=249
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=248
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=245
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=239
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=236
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=227
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=224
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=222
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=220
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=218
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=211
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=210
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=209
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=207
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=206
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=204
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=203
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=200
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=197
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=196
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=195
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=194
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=193
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=192
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=189
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=184
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=182
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=181
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=180
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=179
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=178
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=177
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=173
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=171
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=170
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=169
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=167
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=165
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=163
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=160
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=158
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=156
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=155
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=153
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=151
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=147
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=144
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=141
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=136
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=135
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=134
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=129
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=128
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=127
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=124
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=121
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=120
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=119
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=118
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=105
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=104
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=103
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=100
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=099
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=095
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=093
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=086
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=084
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=079
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=077
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=075
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=073
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=072
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=070
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=069
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=068
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=067
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=061
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=059
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=058
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=056
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=055
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=053
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=046
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=045
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=042
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=040
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=038
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=036
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=033
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=031
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=027
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=025
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=022
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=020
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=018
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=017
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=014
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=013
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=012
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=004
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=003
9 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=001
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/usr/sh...
9 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/misc.zsh:5> d=/Users/...
9 -antigen-parse-args:155> [[ -n '' ]]
9 -antigen-parse-args:127> [[ -n '' ]]
9 -antigen-parse-args:38> case 0 (0)
9 -antigen-parse-args:38> case 0 (0)
9 -antigen-parse-args:38> case 0 (0)
9 -antigen-parse-args:38> case 0 (0)
9 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--no-local-cl...
9 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--no-local-clone)
9 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--*)
9 -antigen-parse-args:22> case deno (--no-local-clone)
9 -antigen-parse-args:22> case deno (--*)
9 -antigen-parse-args:17> [[ 1 -gt 0 ]]
9 -antigen-parse-args:17> [[ 1 -gt 0 ]]
9 -antigen-parse-args:17> [[ 1 -gt 0 ]]
9 -antigen-parse-args:12> args[loc]=/
9 -antigen-hook-handler:45> hook=antigen-bundle-parallel
9 -antigen-hook-handler:45> hook=antigen-bundle-parallel
9 -antigen-hook-handler:45> hook=antigen-bundle-parallel
9 -antigen-hook-handler:45> hook=antigen-bundle-defer
9 -antigen-hook-handler:45> hook=antigen-bundle-defer
9 -antigen-hook-handler:45> hook=antigen-bundle-defer
9 -antigen-hook-handler:45> hook=-antigen-load-env-cached
9 -antigen-hook-handler:22> case post (replace)
9 -antigen-hook-handler:10> hook=antigen-lock
9 -antigen-hook-handler:10> hook=antigen-bundle-parallel
9 -antigen-hook-handler:10> hook=antigen-apply-parallel-execute
9 -antigen-hook-handler:10> hook=antigen-apply-parallel
9 -antigen-hook-handler:10> hook=antigen-apply-cached
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/zsh-users/zsh-...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
9 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
8 is-at-least:55> part=''
8 is-at-least:55> part=''
8 is-at-least:54> ((  part < min_ver[min_cnt]  ))
8 is-at-least:54> ((  part < min_ver[min_cnt]  ))
8 is-at-least:31> [[ '' != <-> ]]
8 is-at-least:31> [[ '' != <-> ]]
8 is-at-least:31> [[ '' != <-> ]]
8 compinit:500> _i_name=_vorbis
8 compinit:500> _i_name=_top
8 compinit:500> _i_name=_paste
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_users
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_stow
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_seq
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_rcs
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_pax
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_options_set
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_myrepos
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_history_complete_word
8 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_beadm
8 compinit:499> _i_file=/Users/matt/.oh-my-zsh/custom/plugins/zsh-completions/s...
8 compinit:77> case -C (-C)
8 compdump:116> ((  ! --_i && 44 > 1  ))
8 compdump:113> ((  46  ))
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:164> [[ -n yes ]]
8 compdef:162> [[ -z '' ]]
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:160> svc=''
8 compdef:159> cmd=zone
8 compdef:159> cmd=zfgrep
8 compdef:159> cmd=zf_rmdir
8 compdef:159> cmd=zf_mv
8 compdef:159> cmd=zf_mkdir
8 compdef:159> cmd=zegrep
8 compdef:159> cmd=zed
8 compdef:159> cmd=ypset
8 compdef:159> cmd=ypserv
8 compdef:159> cmd=where
8 compdef:159> cmd=watch
8 compdef:159> cmd=vorbiscomment
8 compdef:159> cmd=vncviewer
8 compdef:159> cmd=vmctl
8 compdef:159> cmd=visudo
8 compdef:159> cmd=valgrind
8 compdef:159> cmd=val
8 compdef:159> cmd=usermod
8 compdef:159> cmd=userdel
8 compdef:159> cmd=urxvt
8 compdef:159> cmd=urpmf
8 compdef:159> cmd=unxz
8 compdef:159> cmd=unlimit
8 compdef:159> cmd=unace
8 compdef:159> cmd=ulimit
8 compdef:159> cmd=twistd
8 compdef:159> cmd=trial
8 compdef:159> cmd=tpkg-update
8 compdef:159> cmd=tpkg-debarch
8 compdef:159> cmd=touch
8 compdef:159> cmd=tmux
8 compdef:159> cmd=tkconch
8 compdef:159> cmd=timeout
8 compdef:159> cmd=tee
8 compdef:159> cmd=system_profiler
8 compdef:159> cmd=svccfg
8 compdef:159> cmd=svcadm
8 compdef:159> cmd=sudo
8 compdef:159> cmd=strftime
8 compdef:159> cmd=ssh-add
8 compdef:159> cmd=srptool
8 compdef:159> cmd=sr
8 compdef:159> cmd=source
8 compdef:159> cmd=soa
8 compdef:159> cmd=smartctl
8 compdef:159> cmd=slabtop
8 compdef:159> cmd=shred
8 compdef:159> cmd=shasum
8 compdef:159> cmd=sh
8 compdef:159> cmd=setfacl.exe
8 compdef:159> cmd=serialver
8 compdef:159> cmd=seq
8 compdef:159> cmd=senlin
8 compdef:159> cmd=schroot
8 compdef:159> cmd=sc_usage
8 compdef:159> cmd=say
8 compdef:159> cmd=sahara
8 compdef:159> cmd=rwho
8 compdef:159> cmd=rubber-pipe
8 compdef:159> cmd=rsync
8 compdef:159> cmd=rpmspec
8 compdef:159> cmd=rpmkeys
8 compdef:159> cmd=rgview
8 compdef:159> cmd=restart
8 compdef:159> cmd=removepkg
8 compdef:159> cmd=refile
8 compdef:159> cmd=readelf
8 compdef:159> cmd=rar
8 compdef:159> cmd=qtplay
8 compdef:159> cmd=pyhtmlizer
8 compdef:159> cmd=pwdx
8 compdef:159> cmd=psselect
8 compdef:159> cmd=psnup
8 compdef:159> cmd=psmulti
8 compdef:159> cmd=psmerge
8 compdef:159> cmd=psig
8 compdef:159> cmd=ps2ascii
8 compdef:159> cmd=powerd
8 compdef:159> cmd=postmaster
8 compdef:159> cmd=policytool
8 compdef:159> cmd=pman
8 compdef:159> cmd=pgrep
8 compdef:159> cmd=pg_upgrade
8 compdef:159> cmd=pg_dumpall
8 compdef:159> cmd=pdftk
8 compdef:159> cmd=pdftex
8 compdef:159> cmd=pdfopt
8 compdef:159> cmd=pdffonts
8 compdef:159> cmd=pbcopy
8 compdef:159> cmd=nohup
8 compdef:159> cmd=nocorrect
8 compdef:159> cmd=nm
8 compdef:159> cmd=nginx
8 compdef:159> cmd=new
8 compdef:159> cmd=mtype
8 compdef:159> cmd=msgchk
8 compdef:159> cmd=mr
8 compdef:159> cmd=mpc
8 compdef:159> cmd=mmm
8 compdef:159> cmd=mktunes
8 compdef:159> cmd=mii-tool
8 compdef:159> cmd=mhparam
8 compdef:159> cmd=mhn
8 compdef:159> cmd=mhfixmsg
8 compdef:159> cmd=mdel
8 compdef:159> cmd=mattrib
8 compdef:159> cmd=manila
8 compdef:159> cmd=lsof
8 compdef:159> cmd=lsmod
8 compdef:159> cmd=lslv
8 compdef:159> cmd=lsdev
8 compdef:159> cmd=lsblk
8 compdef:159> cmd=ls
8 compdef:159> cmd=lpoptions
8 compdef:159> cmd=llvm-otool
8 compdef:159> cmd=llvm-g++
8 compdef:159> cmd=linux
8 compdef:159> cmd=light
8 compdef:159> cmd=lftp
8 compdef:159> cmd=latex
8 compdef:159> cmd=kpdf
8 compdef:159> cmd=knock
8 compdef:159> cmd=kldunload
8 compdef:159> cmd=kioclient
8 compdef:159> cmd=kak
8 compdef:159> cmd=join
8 compdef:159> cmd=javap
8 compdef:159> cmd=interdiff
8 compdef:159> cmd=installpkg
8 compdef:159> cmd=inc
8 compdef:159> cmd=ifdown
8 compdef:159> cmd=icombine
8 compdef:159> cmd=ibus
8 compdef:159> cmd=hexdump
8 compdef:159> cmd=hd
8 compdef:159> cmd=gzgrep
8 compdef:159> cmd=gwho
8 compdef:159> cmd=gunexpand
8 compdef:159> cmd=guname
8 compdef:159> cmd=gtouch
8 compdef:159> cmd=gtee
8 compdef:159> cmd=gtar
8 compdef:159> cmd=gstat
8 compdef:159> cmd=grep
8 compdef:159> cmd=greadlink
8 compdef:159> cmd=gradlew
8 compdef:159> cmd=gprof
8 compdef:159> cmd=gpaste
8 compdef:159> cmd=gnome-gv
8 compdef:159> cmd=gmknod
8 compdef:159> cmd=git-wtf
8 compdef:159> cmd=gfold
8 compdef:159> cmd=gfmt
8 compdef:159> cmd=gcc
8 compdef:159> cmd=galeon
8 compdef:159> cmd=fwhois
8 compdef:159> cmd=forw
8 compdef:159> cmd=folders
8 compdef:159> cmd=folder
8 compdef:159> cmd=flutter
8 compdef:159> cmd=float
8 compdef:159> cmd=flipdiff
8 compdef:159> cmd=fleetctl
8 compdef:159> cmd=fixwwps
8 compdef:159> cmd=fixtpps
8 compdef:159> cmd=fixdlsrps
8 compdef:159> cmd=ffind
8 compdef:159> cmd=feh
8 compdef:159> cmd=fc
8 compdef:159> cmd=false
8 compdef:159> cmd=explodepkg
8 compdef:159> cmd=erb
8 compdef:159> cmd=epdfview
8 compdef:159> cmd=egrep
8 compdef:159> cmd=dwb
8 compdef:159> cmd=disown
8 compdef:159> cmd=csh
8 compdef:159> cmd=cppcheck
8 compdef:159> cmd=convert
8 compdef:159> cmd=combinediff
8 compdef:159> cmd=ckeygen
8 compdef:159> cmd=ci
8 compdef:159> cmd=chromium
8 compdef:159> cmd=chimera
8 compdef:159> cmd=bzegrep
8 compdef:159> cmd=burst
8 compdef:159> cmd=bttrack
8 compdef:159> cmd=bts
8 compdef:159> cmd=aws
8 compdef:159> cmd=atach
8 compdef:159> cmd=asdf
8 compdef:159> cmd=apt
8 compdef:159> cmd=apm
8 compdef:159> cmd=anno
8 compdef:159> cmd=animate
8 compdef:159> cmd=ack2
8 compdef:159> cmd=5l
8 compdef:159> cmd=5g
8 compdef:159> cmd=-value-,RPS2,-default-
8 compdef:159> cmd=-tilde-
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:157> svc=yes
8 compdef:155> [[ zun = *=* ]]
8 compdef:155> [[ whom = *=* ]]
8 compdef:155> [[ val = *=* ]]
8 compdef:155> [[ slocate = *=* ]]
8 compdef:155> [[ rtin = *=* ]]
8 compdef:155> [[ rpmsign = *=* ]]
8 compdef:155> [[ rc = *=* ]]
8 compdef:155> [[ psed = *=* ]]
8 compdef:155> [[ psbook = *=* ]]
8 compdef:155> [[ ps2pdfwr = *=* ]]
8 compdef:155> [[ pldd = *=* ]]
8 compdef:155> [[ pick = *=* ]]
8 compdef:155> [[ pg_ctl = *=* ]]
8 compdef:155> [[ pdflatex = *=* ]]
8 compdef:155> [[ pbpaste = *=* ]]
8 compdef:155> [[ oksh = *=* ]]
8 compdef:155> [[ mvim = *=* ]]
8 compdef:155> [[ mmd = *=* ]]
8 compdef:155> [[ mdu = *=* ]]
8 compdef:155> [[ mcd = *=* ]]
8 compdef:155> [[ makepkg = *=* ]]
8 compdef:155> [[ latexmk = *=* ]]
8 compdef:155> [[ java = *=* ]]
8 compdef:155> [[ gmake = *=* ]]
8 compdef:155> [[ fixpspps = *=* ]]
8 compdef:155> [[ conch = *=* ]]
8 compdef:155> [[ bsdtar = *=* ]]
8 compdef:155> [[ . = *=* ]]
8 compdef:139> case postpattern (postpattern)
8 compdef:139> case postpattern (postpattern)
8 compdef:139> case postpattern (pattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (postpattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (pattern)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:139> case  (*)
8 compdef:136> [[ zgrep = -P ]]
8 compdef:136> [[ zf_rm = -P ]]
8 compdef:136> [[ zen = -P ]]
8 compdef:136> [[ ypxfr = -P ]]
8 compdef:136> [[ xvnc4viewer = -P ]]
8 compdef:136> [[ xtp = -P ]]
8 compdef:136> [[ whoami = -P ]]
8 compdef:136> [[ watcher = -P ]]
8 compdef:136> [[ vmctl = -P ]]
8 compdef:136> [[ urxvtc = -P ]]
8 compdef:136> [[ urpmi.addmedia = -P ]]
8 compdef:136> [[ upgradepkg = -P ]]
8 compdef:136> [[ update-rc.d = -P ]]
8 compdef:136> [[ unwrapdiff = -P ]]
8 compdef:136> [[ unlz4 = -P ]]
8 compdef:136> [[ unget = -P ]]
8 compdef:136> [[ trap = -P ]]
8 compdef:136> [[ tpkg-make = -P ]]
8 compdef:136> [[ touch = -P ]]
8 compdef:136> [[ tmux = -P ]]
8 compdef:136> [[ tkconch = -P ]]
8 compdef:136> [[ times = -P ]]
8 compdef:136> [[ time = -P ]]
8 compdef:136> [[ texi2pdf = -P ]]
8 compdef:136> [[ texi2any = -P ]]
8 compdef:136> [[ talk = -P ]]
8 compdef:136> [[ systat = -P ]]
8 compdef:136> [[ strace64 = -P ]]
8 compdef:136> [[ ssh-add = -P ]]
8 compdef:136> [[ sqlite3 = -P ]]
8 compdef:136> [[ soa = -P ]]
8 compdef:136> [[ smbstatus = -P ]]
8 compdef:136> [[ smartctl = -P ]]
8 compdef:136> [[ shuf = -P ]]
8 compdef:136> [[ show = -P ]]
8 compdef:136> [[ shasum = -P ]]
8 compdef:136> [[ setopt = -P ]]
8 compdef:136> [[ setfattr = -P ]]
8 compdef:136> [[ s2p = -P ]]
8 compdef:136> [[ rview = -P ]]
8 compdef:136> [[ run-help = -P ]]
8 compdef:136> [[ rpmverify = -P ]]
8 compdef:136> [[ rpmquery = -P ]]
8 compdef:136> [[ rpm = -P ]]
8 compdef:136> [[ rmmod = -P ]]
8 compdef:136> [[ rmm = -P ]]
8 compdef:136> [[ rmic = -P ]]
8 compdef:136> [[ rmdir = -P ]]
8 compdef:136> [[ rmdel = -P ]]
8 compdef:136> [[ rgvim = -P ]]
8 compdef:136> [[ rgview = -P ]]
8 compdef:136> [[ readelf = -P ]]
8 compdef:136> [[ rar = -P ]]
8 compdef:136> [[ r = -P ]]
8 compdef:136> [[ querybts = -P ]]
8 compdef:136> [[ pwait = -P ]]
8 compdef:136> [[ pstops = -P ]]
8 compdef:136> [[ pstop = -P ]]
8 compdef:136> [[ psresize = -P ]]
8 compdef:136> [[ psql = -P ]]
8 compdef:136> [[ psnup = -P ]]
8 compdef:136> [[ psig = -P ]]
8 compdef:136> [[ ps = -P ]]
8 compdef:136> [[ prun = -P ]]
8 compdef:136> [[ prs = -P ]]
8 compdef:136> [[ prev = -P ]]
8 compdef:136> [[ postgres = -P ]]
8 compdef:136> [[ poff = -P ]]
8 compdef:136> [[ pmls = -P ]]
8 compdef:136> [[ pmake = -P ]]
8 compdef:136> [[ pkgtool = -P ]]
8 compdef:136> [[ pkgrm = -P ]]
8 compdef:136> [[ pkg_delete = -P ]]
8 compdef:136> [[ pkg-config = -P ]]
8 compdef:136> [[ piuparts = -P ]]
8 compdef:136> [[ pg_isready = -P ]]
8 compdef:136> [[ pg_config = -P ]]
8 compdef:136> [[ pdfinfo = -P ]]
8 compdef:136> [[ pdf2ps = -P ]]
8 compdef:136> [[ pandoc = -P ]]
8 compdef:136> [[ packf = -P ]]
8 compdef:136> [[ pack = -P ]]
8 compdef:136> [[ opkg = -P ]]
8 compdef:136> [[ opera = -P ]]
8 compdef:136> [[ od = -P ]]
8 compdef:136> [[ nova = -P ]]
8 compdef:136> [[ nft = -P ]]
8 compdef:136> [[ mx = -P ]]
8 compdef:136> [[ mren = -P ]]
8 compdef:136> [[ mr = -P ]]
8 compdef:136> [[ modprobe = -P ]]
8 compdef:136> [[ mlabel = -P ]]
8 compdef:136> [[ mhpath = -P ]]
8 compdef:136> [[ mformat = -P ]]
8 compdef:136> [[ metaflac = -P ]]
8 compdef:136> [[ lz4cat = -P ]]
8 compdef:136> [[ lz4 = -P ]]
8 compdef:136> [[ logname = -P ]]
8 compdef:136> [[ linux = -P ]]
8 compdef:136> [[ ldap = -P ]]
8 compdef:136> [[ killall = -P ]]
8 compdef:136> [[ jdb = -P ]]
8 compdef:136> [[ javah = -P ]]
8 compdef:136> [[ jar = -P ]]
8 compdef:136> [[ irb = -P ]]
8 compdef:136> [[ gvim = -P ]]
8 compdef:136> [[ gtimeout = -P ]]
8 compdef:136> [[ gtee = -P ]]
8 compdef:136> [[ gtac = -P ]]
8 compdef:136> [[ gstrings = -P ]]
8 compdef:136> [[ gstdbuf = -P ]]
8 compdef:136> [[ gshuf = -P ]]
8 compdef:136> [[ groups = -P ]]
8 compdef:136> [[ grmdir = -P ]]
8 compdef:136> [[ gprof = -P ]]
8 compdef:136> [[ gpaste = -P ]]
8 compdef:136> [[ gofmt = -P ]]
8 compdef:136> [[ gnutls-serv = -P ]]
8 compdef:136> [[ gjoin = -P ]]
8 compdef:136> [[ gexpand = -P ]]
8 compdef:136> [[ getfattr = -P ]]
8 compdef:136> [[ getafm = -P ]]
8 compdef:136> [[ gbase32 = -P ]]
8 compdef:136> [[ fmttest = -P ]]
8 compdef:136> [[ flists = -P ]]
8 compdef:136> [[ fixscribeps = -P ]]
8 compdef:136> [[ fixpsditps = -P ]]
8 compdef:136> [[ fgrep = -P ]]
8 compdef:136> [[ extractres = -P ]]
8 compdef:136> [[ evim = -P ]]
8 compdef:136> [[ erb = -P ]]
8 compdef:136> [[ epdfview = -P ]]
8 compdef:136> [[ dropdb = -P ]]
8 compdef:136> [[ domainname = -P ]]
8 compdef:136> [[ cockroach = -P ]]
8 compdef:136> [[ chfn = -P ]]
8 compdef:136> [[ cftp = -P ]]
8 compdef:136> [[ cc = -P ]]
8 compdef:136> [[ bundle = -P ]]
8 compdef:136> [[ bsdgrep = -P ]]
8 compdef:136> [[ bindkey = -P ]]
8 compdef:136> [[ arecord = -P ]]
8 compdef:136> [[ apt-config = -P ]]
8 compdef:136> [[ aoss = -P ]]
8 compdef:136> [[ ansible-console = -P ]]
8 compdef:136> [[ adb = -P ]]
8 compdef:136> [[ aap = -P ]]
8 compdef:136> [[ . = -P ]]
8 compdef:136> [[ -P = -P ]]
8 compdef:136> [[ -P = -P ]]
8 compdef:136> [[ -P = -P ]]
8 compdef:136> [[ -P = -P ]]
8 compdef:136> [[ -P = -P ]]
8 compdef:136> [[ 'xzcat=unxz' = -P ]]
8 compdef:136> [[ 'lzcat=unxz' = -P ]]
8 compdef:136> [[ 'c++-*' = -P ]]
8 compdef:134> [[ zsetattr = -p ]]
8 compdef:134> [[ zipinfo = -p ]]
8 compdef:134> [[ ypwhich = -p ]]
8 compdef:134> [[ yast2 = -p ]]
8 compdef:134> [[ xvncviewer = -p ]]
8 compdef:134> [[ vorbiscomment = -p ]]
8 compdef:134> [[ vimdiff = -p ]]
8 compdef:134> [[ unsetopt = -p ]]
8 compdef:134> [[ unget = -p ]]
8 compdef:134> [[ type = -p ]]
8 compdef:134> [[ twistd = -p ]]
8 compdef:134> [[ trove = -p ]]
8 compdef:134> [[ tr = -p ]]
8 compdef:134> [[ tpkg-update = -p ]]
8 compdef:134> [[ tpkg-install-libc = -p ]]
8 compdef:134> [[ tpkg-install = -p ]]
8 compdef:134> [[ tpkg-debarch = -p ]]
8 compdef:134> [[ tacker = -p ]]
8 compdef:134> [[ system_profiler = -p ]]
8 compdef:134> [[ sync = -p ]]
8 compdef:134> [[ sudoedit = -p ]]
8 compdef:134> [[ sortm = -p ]]
8 compdef:134> [[ setfacl.exe = -p ]]
8 compdef:134> [[ senlin = -p ]]
8 compdef:134> [[ savecore = -p ]]
8 compdef:134> [[ rusage = -p ]]
8 compdef:134> [[ rup = -p ]]
8 compdef:134> [[ rubber-info = -p ]]
8 compdef:134> [[ rpmspec = -p ]]
8 compdef:134> [[ rpmsign = -p ]]
8 compdef:134> [[ rehash = -p ]]
8 compdef:134> [[ refile = -p ]]
8 compdef:134> [[ readonly = -p ]]
8 compdef:134> [[ readlink = -p ]]
8 compdef:134> [[ rcsdiff = -p ]]
8 compdef:134> [[ rcs = -p ]]
8 compdef:134> [[ rcp = -p ]]
8 compdef:134> [[ psselect = -p ]]
8 compdef:134> [[ psmerge = -p ]]
8 compdef:134> [[ psbook = -p ]]
8 compdef:134> [[ ps2ps = -p ]]
8 compdef:134> [[ ps2pdf12 = -p ]]
8 compdef:134> [[ portlint = -p ]]
8 compdef:134> [[ pmexp = -p ]]
8 compdef:134> [[ pmeth = -p ]]
8 compdef:134> [[ pmcat = -p ]]
8 compdef:134> [[ pkgtool = -p ]]
8 compdef:134> [[ pg_upgrade = -p ]]
8 compdef:134> [[ pg_ctl = -p ]]
8 compdef:134> [[ pdftops = -p ]]
8 compdef:134> [[ pdftexi2dvi = -p ]]
8 compdef:134> [[ pdftex = -p ]]
8 compdef:134> [[ pdflatex = -p ]]
8 compdef:134> [[ pbuilder = -p ]]
8 compdef:134> [[ pbpaste = -p ]]
8 compdef:134> [[ odmshow = -p ]]
8 compdef:134> [[ ntalk = -p ]]
8 compdef:134> [[ noglob = -p ]]
8 compdef:134> [[ nocorrect = -p ]]
8 compdef:134> [[ neutron = -p ]]
8 compdef:134> [[ monasca = -p ]]
8 compdef:134> [[ mmove = -p ]]
8 compdef:134> [[ mmd = -p ]]
8 compdef:134> [[ mhshow = -p ]]
8 compdef:134> [[ mhn = -p ]]
8 compdef:134> [[ mark = -p ]]
8 compdef:134> [[ manila = -p ]]
8 compdef:134> [[ makepkg = -p ]]
8 compdef:134> [[ magnum = -p ]]
8 compdef:134> [[ lsdiff = -p ]]
8 compdef:134> [[ lprm = -p ]]
8 compdef:134> [[ lpq = -p ]]
8 compdef:134> [[ lpinfo = -p ]]
8 compdef:134> [[ lpadmin = -p ]]
8 compdef:134> [[ konqueror = -p ]]
8 compdef:134> [[ keystone = -p ]]
8 compdef:134> [[ javap = -p ]]
8 compdef:134> [[ jadetex = -p ]]
8 compdef:134> [[ interdiff = -p ]]
8 compdef:134> [[ integer = -p ]]
8 compdef:134> [[ inc = -p ]]
8 compdef:134> [[ import = -p ]]
8 compdef:134> [[ identify = -p ]]
8 compdef:134> [[ gzfgrep = -p ]]
8 compdef:134> [[ gwho = -p ]]
8 compdef:134> [[ gtar = -p ]]
8 compdef:134> [[ gtail = -p ]]
8 compdef:134> [[ gstat = -p ]]
8 compdef:134> [[ gsplit = -p ]]
8 compdef:134> [[ gsort = -p ]]
8 compdef:134> [[ gseq = -p ]]
8 compdef:134> [[ gsdj500 = -p ]]
8 compdef:134> [[ grm = -p ]]
8 compdef:134> [[ grepdiff = -p ]]
8 compdef:134> [[ gpgv = -p ]]
8 compdef:134> [[ gpg-zip = -p ]]
8 compdef:134> [[ gmv = -p ]]
8 compdef:134> [[ gmplayer = -p ]]
8 compdef:134> [[ gls = -p ]]
8 compdef:134> [[ ginstall = -p ]]
8 compdef:134> [[ gegrep = -p ]]
8 compdef:134> [[ gbase64 = -p ]]
8 compdef:134> [[ gawk = -p ]]
8 compdef:134> [[ fned = -p ]]
8 compdef:134> [[ fly = -p ]]
8 compdef:134> [[ float = -p ]]
8 compdef:134> [[ flipdiff = -p ]]
8 compdef:134> [[ fixwfwps = -p ]]
8 compdef:134> [[ findaffix = -p ]]
8 compdef:134> [[ filterdiff = -p ]]
8 compdef:134> [[ express = -p ]]
8 compdef:134> [[ export = -p ]]
8 compdef:134> [[ explodepkg = -p ]]
8 compdef:134> [[ evim = -p ]]
8 compdef:134> [[ eview = -p ]]
8 compdef:134> [[ eu-readelf = -p ]]
8 compdef:134> [[ eu-objdump = -p ]]
8 compdef:134> [[ epdfview = -p ]]
8 compdef:134> [[ dwb = -p ]]
8 compdef:134> [[ dist = -p ]]
8 compdef:134> [[ dillo = -p ]]
8 compdef:134> [[ createdb = -p ]]
8 compdef:134> [[ convert = -p ]]
8 compdef:134> [[ ckeygen = -p ]]
8 compdef:134> [[ chimera = -p ]]
8 compdef:134> [[ chage = -p ]]
8 compdef:134> [[ bunzip2 = -p ]]
8 compdef:134> [[ btrename = -p ]]
8 compdef:134> [[ btreannounce = -p ]]
8 compdef:134> [[ brew = -p ]]
8 compdef:134> [[ bpython3 = -p ]]
8 compdef:134> [[ bison = -p ]]
8 compdef:134> [[ at = -p ]]
8 compdef:134> [[ apt-mark = -p ]]
8 compdef:134> [[ apt-get = -p ]]
8 compdef:134> [[ apt-cdrom = -p ]]
8 compdef:134> [[ apt-cache = -p ]]
8 compdef:134> [[ apache2ctl = -p ]]
8 compdef:134> [[ ansible-vault = -p ]]
8 compdef:134> [[ ansible-inventory = -p ]]
8 compdef:134> [[ ansible-config = -p ]]
8 compdef:134> [[ 8l = -p ]]
8 compdef:134> [[ 5l = -p ]]
8 compdef:134> [[ -value-,P4CLIENT,-default- = -p ]]
8 compdef:134> [[ -P = -p ]]
8 compdef:134> [[ -P = -p ]]
8 compdef:134> [[ -P = -p ]]
8 compdef:134> [[ -P = -p ]]
8 compdef:134> [[ -P = -p ]]
8 compdef:134> [[ 'xetex=tex' = -p ]]
8 compdef:134> [[ 'slogin=ssh' = -p ]]
8 compdef:134> [[ 'gpg2=gpg' = -p ]]
8 compdef:134> [[ 'ggfl=git-checkout' = -p ]]
8 compdef:134> [[ 'gdv=git-diff' = -p ]]
8 compdef:134> [[ 'gdnolock=git-diff' = -p ]]
8 compdef:134> [[ 'gcc-*' = -p ]]
8 compdef:132> [[ zone = -N ]]
8 compdef:132> [[ zfgrep = -N ]]
8 compdef:132> [[ zf_rmdir = -N ]]
8 compdef:132> [[ zegrep = -N ]]
8 compdef:132> [[ ytalk = -N ]]
8 compdef:132> [[ ypset = -N ]]
8 compdef:132> [[ yppoll = -N ]]
8 compdef:132> [[ yash = -N ]]
8 compdef:132> [[ whom = -N ]]
8 compdef:132> [[ what = -N ]]
8 compdef:132> [[ vacuumdb = -N ]]
8 compdef:132> [[ usermod = -N ]]
8 compdef:132> [[ urxvt256cc = -N ]]
8 compdef:132> [[ urxvt256c-ml = -N ]]
8 compdef:132> [[ urxvt256c = -N ]]
8 compdef:132> [[ urxvt = -N ]]
8 compdef:132> [[ urpmq = -N ]]
8 compdef:132> [[ urpmi = -N ]]
8 compdef:132> [[ uml_moo = -N ]]
8 compdef:132> [[ rtin = -N ]]
8 compdef:132> [[ rsh = -N ]]
8 compdef:132> [[ rpmkeys = -N ]]
8 compdef:132> [[ rcp = -N ]]
8 compdef:132> [[ rc = -N ]]
8 compdef:132> [[ pwdx = -N ]]
8 compdef:132> [[ pscp.exe = -N ]]
8 compdef:132> [[ ps2ascii = -N ]]
8 compdef:132> [[ postmaster = -N ]]
8 compdef:132> [[ podgrep = -N ]]
8 compdef:132> [[ pmfunc = -N ]]
8 compdef:132> [[ pick = -N ]]
8 compdef:132> [[ pg_dump = -N ]]
8 compdef:132> [[ pdftotext = -N ]]
8 compdef:132> [[ pdfopt = -N ]]
8 compdef:132> [[ pcred = -N ]]
8 compdef:132> [[ ogginfo = -N ]]
8 compdef:132> [[ oggdec = -N ]]
8 compdef:132> [[ ogg123 = -N ]]
8 compdef:132> [[ nvim = -N ]]
8 compdef:132> [[ mrd = -N ]]
8 compdef:132> [[ mhmail = -N ]]
8 compdef:132> [[ mdu = -N ]]
8 compdef:132> [[ mcd = -N ]]
8 compdef:132> [[ links2 = -N ]]
8 compdef:132> [[ light = -N ]]
8 compdef:132> [[ latexmk = -N ]]
8 compdef:132> [[ kpdf = -N ]]
8 compdef:132> [[ help = -N ]]
8 compdef:132> [[ gtail = -N ]]
8 compdef:132> [[ gsed = -N ]]
8 compdef:132> [[ gsdj = -N ]]
8 compdef:132> [[ greadlink = -N ]]
8 compdef:132> [[ gmktemp = -N ]]
8 compdef:132> [[ gfind = -N ]]
8 compdef:132> [[ gfgrep = -N ]]
8 compdef:132> [[ get = -N ]]
8 compdef:132> [[ fwhois = -N ]]
8 compdef:132> [[ forw = -N ]]
8 compdef:132> [[ fixdlsrps = -N ]]
8 compdef:132> [[ false = -N ]]
8 compdef:132> [[ eu-strings = -N ]]
8 compdef:132> [[ eu-nm = -N ]]
8 compdef:132> [[ dropuser = -N ]]
8 compdef:132> [[ combine = -N ]]
8 compdef:132> [[ clear = -N ]]
8 compdef:132> [[ bzgrep = -N ]]
8 compdef:132> [[ bzfgrep = -N ]]
8 compdef:132> [[ bsdtar = -N ]]
8 compdef:132> [[ ash = -N ]]
8 compdef:132> [[ -P = -N ]]
8 compdef:131> ((  37  ))
8 compdef:131> ((  35  ))
8 compdef:131> ((  29  ))
8 compdef:131> ((  26  ))
8 compdef:131> ((  22  ))
8 compdef:131> ((  18  ))
8 compdef:131> ((  18  ))
8 compdef:131> ((  17  ))
8 compdef:131> ((  16  ))
8 compdef:131> ((  16  ))
8 compdef:131> ((  16  ))
8 compdef:131> ((  15  ))
8 compdef:131> ((  15  ))
8 compdef:131> ((  14  ))
8 compdef:131> ((  14  ))
8 compdef:131> ((  13  ))
8 compdef:131> ((  13  ))
8 compdef:131> ((  12  ))
8 compdef:131> ((  12  ))
8 compdef:131> ((  12  ))
8 compdef:131> ((  12  ))
8 compdef:131> ((  11  ))
8 compdef:131> ((  11  ))
8 compdef:131> ((  10  ))
8 compdef:131> ((  10  ))
8 compdef:131> ((  10  ))
8 compdef:131> ((  10  ))
8 compdef:131> ((  9  ))
8 compdef:131> ((  9  ))
8 compdef:131> ((  9  ))
8 compdef:131> ((  9  ))
8 compdef:131> ((  8  ))
8 compdef:131> ((  8  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  7  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  6  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  5  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  4  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  3  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  2  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:131> ((  1  ))
8 compdef:83> case postpattern (widgetkey)
8 compdef:83> case postpattern (widgetkey)
8 compdef:83> case postpattern (key)
8 compdef:83> case postpattern (key)
8 compdef:83> case postpattern (*)
8 compdef:83> case key (key)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (widgetkey)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (key)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:83> case  (*)
8 compdef:79> func=_xz
8 compdef:79> func=_xset
8 compdef:79> func=_xmms2
8 compdef:79> func=_vorbis
8 compdef:79> func=_vared
8 compdef:79> func=_uptime
8 compdef:79> func=_truss
8 compdef:79> func=_tput
8 compdef:79> func=_tmux
8 compdef:79> func=_tcpdump
8 compdef:79> func=_su
8 compdef:79> func=_sshfs
8 compdef:79> func=_ss
8 compdef:79> func=_sockstat
8 compdef:79> func=_slrn
8 compdef:79> func=_sisu
8 compdef:79> func=_sh
8 compdef:79> func=_sbuild
8 compdef:79> func=_say
8 compdef:79> func=_renice
8 compdef:79> func=_rebootin
8 compdef:79> func=_rar
8 compdef:79> func=_qemu
8 compdef:79> func=_python
8 compdef:79> func=_ps1234
8 compdef:79> func=_ps
8 compdef:79> func=_prstat
8 compdef:79> func=_powerd
8 compdef:79> func=_pkgtool
8 compdef:79> func=_pkgrm
8 compdef:79> func=_pkgin
8 compdef:79> func=_nslookup
8 compdef:79> func=_nmap
8 compdef:79> func=_nedit
8 compdef:79> func=_myrepos
8 compdef:79> func=_mosh
8 compdef:79> func=_mkfifo
8 compdef:79> func=_make
8 compdef:79> func=_lha
8 compdef:79> func=_ldap
8 compdef:79> func=_killall
8 compdef:79> func=_id
8 compdef:79> func=_git
8 compdef:79> func=_fold
8 compdef:79> func=_flowadm
8 compdef:79> func=_files
8 compdef:79> func=_fab
8 compdef:79> func=_cap
8 compdef:79> func=_bison
8 compdef:79> func=_base64
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:49> [[ -z '' ]]
8 compdef:45> [[ -z '' ]]
8 compdef:45> [[ -z '' ]]
8 compdef:45> [[ -z '' ]]
8 compdef:28> [[ k = K ]]
8 compdef:28> [[ k = K ]]
8 compdef:28> [[ k = K ]]
8 compdef:28> [[ K = K ]]
8 compdef:26> [[ k = P ]]
8 compdef:26> [[ k = P ]]
8 compdef:26> [[ k = P ]]
8 compdef:26> [[ P = P ]]
8 compdef:26> [[ P = P ]]
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (n)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case n (a)
8 compdef:15> case k (n)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case a (a)
8 compdef:15> case K (n)
8 compaudit:101> _i_exe=/proc/87947/object/a.out
8 colors:113> k=bg-white
8 colors:113> k=bg-magenta
8 colors:113> k=bg-grey
8 colors:113> k=bg-green
8 colors:104> k=fg-yellow
8 colors:104> k=fg-grey
8 colors:104> k=fg-green
8 colors:104> k=fg-blue
8 colors:104> k=fg-black
8 colors:81> k=39
8 colors:81> k=36
8 colors:81> k=35
8 colors:81> k=34
8 colors:81> k=33
8 colors:81> k=33
8 colors:77> k=49
8 colors:77> k=47
8 colors:77> k=46
8 colors:77> k=44
8 colors:77> k=42
8 colors:77> k=41
8 colors:77> k=39
8 colors:77> k=39
8 colors:77> k=37
8 colors:77> k=34
8 colors:77> k=32
8 colors:77> k=31
8 colors:77> k=25
8 colors:77> k=25
8 colors:77> k=24
8 colors:77> k=23
8 colors:77> k=08
8 colors:77> k=07
8 colors:77> k=01
8 _zsh_highlight_bind_widgets:27> case completion:.menu-select:_main_complete (...
8 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_main_complete ...
8 _zsh_highlight_bind_widgets:27> case completion:.list-choices:_bash_completio...
8 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_most_recent_f...
8 _zsh_highlight_bind_widgets:27> case completion:.complete-word:_complete_help...
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (user:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case builtin (completion:*)
8 _zsh_highlight_bind_widgets:27> case  (user:*)
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=246
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=244
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=243
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=241
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=238
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=237
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=233
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=231
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=228
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=217
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=213
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=208
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=199
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=190
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=187
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=185
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=183
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=174
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=172
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=168
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=166
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=164
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=162
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=154
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=152
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=150
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=145
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=133
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=130
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=126
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=123
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=101
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=094
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=088
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=085
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=083
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=074
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=062
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=060
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=054
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=047
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=039
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=037
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=035
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=032
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=030
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=026
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=023
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=019
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=016
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=011
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=010
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=008
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=007
8 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=005
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 /Users/matt/.antigen/bundles/robbyrussell/oh-my-zsh/lib/spectrum.zsh:16> colo...
8 -antigen-parse-args:155> [[ -n '' ]]
8 -antigen-parse-args:127> [[ -n '' ]]
8 -antigen-parse-args:127> [[ -n '' ]]
8 -antigen-parse-args:38> case 0 (0)
8 -antigen-parse-args:22> case zsh-users/zsh-syntax-highlighting (--*)
8 -antigen-parse-args:22> case zsh-users/zsh-autosuggestions (--*)
8 -antigen-parse-args:22> case deno (--*)
8 -antigen-parse-args:12> args[loc]=/
8 -antigen-hook-handler:46> replace_hook=1
8 -antigen-hook-handler:10> hook=antigen-bundle-parallel
8 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
8 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
8 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
8 -antigen-cache-generate:5> record=/Users/matt/.antigen/bundles/robbyrussell/o...
7 is-at-least:55> part=''
7 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_surfraw
7 compinit:499> _i_file=/usr/share/zsh/5.8.1/functions/_path_files
7 compinit:77> case -i (-i)
7 compinit:77> case -i (-D)
7 compinit:77> case -d (-d)
7 compinit:77> case -C (-i)
7 compdef:164> [[ -n yes ]]
7 compdef:164> [[ -n yes ]]
7 compdef:164> [[ -n yes ]]
7 compdef:164> [[ -n yes ]]
7 compdef:164> [[ -n yes ]]
7 compdef:162> [[ -z '' ]]
7 compdef:162> [[ -z '' ]]
7 compdef:162> [[ -z '' ]]
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:160> svc=''
7 compdef:159> cmd=zstat
7 compdef:159> cmd=unwrapdiff
7 compdef:159> cmd=unget
7 compdef:159> cmd=texindex
7 compdef:159> cmd=tex
7 compdef:159> cmd=ssh
7 compdef:159> cmd=splitdiff
7 compdef:159> cmd=slitex
7 compdef:159> cmd=set
7 compdef:159> cmd=sed
7 compdef:159> cmd=scp
7 compdef:159> cmd=rvim
7 compdef:159> cmd=rview
7 compdef:159> cmd=rmdel
7 compdef:159> cmd=rgvim
7 compdef:159> cmd=rcs
7 compdef:159> cmd=pwait
7 compdef:159> cmd=pstack
7 compdef:159> cmd=psql
7 compdef:159> cmd=prt
7 compdef:159> cmd=prs
7 compdef:159> cmd=plutil
7 compdef:159> cmd=pkgtool
7 compdef:159> cmd=p4d
7 compdef:159> cmd=mren
7 compdef:159> cmd=mark
7 compdef:159> cmd=lsdiff
7 compdef:159> cmd=jar
7 compdef:159> cmd=insmod
7 compdef:159> cmd=initdb
7 compdef:159> cmd=hotjava
7 compdef:159> cmd=hilite
7 compdef:159> cmd=gsort
7 compdef:159> cmd=grepdiff
7 compdef:159> cmd=fixwpps
7 compdef:159> cmd=evim
7 compdef:159> cmd=eview
7 compdef:159> cmd=8l
7 compdef:159> cmd=8g
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:157> svc=yes
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (postpattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case postpattern (pattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (postpattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (pattern)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:139> case  (*)
7 compdef:136> [[ rvim = -P ]]
7 compdef:136> [[ gex = -P ]]
7 compdef:134> [[ zstat = -p ]]
7 compdef:134> [[ www = -p ]]
7 compdef:134> [[ val = -p ]]
7 compdef:134> [[ trial = -p ]]
7 compdef:134> [[ texindex = -p ]]
7 compdef:134> [[ splitdiff = -p ]]
7 compdef:134> [[ slitex = -p ]]
7 compdef:134> [[ scp = -p ]]
7 compdef:134> [[ sar = -p ]]
7 compdef:134> [[ sact = -p ]]
7 compdef:134> [[ rmf = -p ]]
7 compdef:134> [[ psed = -p ]]
7 compdef:134> [[ prt = -p ]]
7 compdef:134> [[ pinfo = -p ]]
7 compdef:134> [[ p4d = -p ]]
7 compdef:134> [[ oksh = -p ]]
7 compdef:134> [[ lz4c = -p ]]
7 compdef:134> [[ latex = -p ]]
7 compdef:134> [[ ipkg = -p ]]
7 compdef:134> [[ initdb = -p ]]
7 compdef:134> [[ guname = -p ]]
7 compdef:134> [[ gtouch = -p ]]
7 compdef:134> [[ fixwwps = -p ]]
7 compdef:134> [[ fixtpps = -p ]]
7 compdef:134> [[ fixpspps = -p ]]
7 compdef:134> [[ d = -p ]]
7 compdef:134> [[ csh = -p ]]
7 compdef:134> [[ conch = -p ]]
7 compdef:134> [[ ci = -p ]]
7 compdef:134> [[ admin = -p ]]
7 compdef:134> [[ 8g = -p ]]
7 compdef:134> [[ 5g = -p ]]
7 compdef:134> [[ -P = -p ]]
7 compdef:134> [[ -P = -p ]]
7 compdef:132> [[ s2p = -N ]]
7 compdef:132> [[ mvim = -N ]]
7 compdef:131> ((  12  ))
7 compdef:131> ((  8  ))
7 compdef:131> ((  7  ))
7 compdef:131> ((  7  ))
7 compdef:131> ((  7  ))
7 compdef:131> ((  6  ))
7 compdef:131> ((  4  ))
7 compdef:131> ((  4  ))
7 compdef:131> ((  4  ))
7 compdef:131> ((  4  ))
7 compdef:131> ((  3  ))
7 compdef:131> ((  3  ))
7 compdef:131> ((  3  ))
7 compdef:131> ((  3  ))
7 compdef:131> ((  2  ))
7 compdef:131> ((  2  ))
7 compdef:131> ((  2  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:131> ((  1  ))
7 compdef:83> case postpattern (key)
7 compdef:83> case postpattern (key)
7 compdef:83> case  (widgetkey)
7 compdef:83> case  (widgetkey)
7 compdef:83> case  (widgetkey)
7 compdef:83> case  (widgetkey)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:83> case  (key)
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:49> [[ -z '' ]]
7 compdef:28> [[ k = K ]]
7 compdef:28> [[ K = K ]]
7 compdef:26> [[ k = P ]]
7 compdef:26> [[ P = P ]]
7 compdef:26> [[ P = P ]]
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (n)
7 compdef:15> case n (a)
7 compdef:15> case n (a)
7 compdef:15> case k (n)
7 compdef:15> case k (n)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case a (a)
7 compdef:15> case P (n)
7 compdef:15> case P (n)
7 compdef:15> case P (n)
7 compdef:15> case P (n)
7 compdef:15> case K (n)
7 colors:113> k=bg-white
7 colors:113> k=bg-red
7 colors:113> k=bg-green
7 colors:113> k=bg-default
7 colors:113> k=bg-default
7 colors:113> k=bg-cyan
7 colors:113> k=bg-blue
7 colors:104> k=fg-yellow
7 colors:104> k=fg-white
7 colors:104> k=fg-default
7 colors:104> k=fg-cyan
7 colors:104> k=fg-blue
7 colors:104> k=fg-black
7 colors:81> k=39
7 colors:81> k=37
7 colors:81> k=34
7 colors:81> k=32
7 colors:77> k=49
7 colors:77> k=46
7 colors:77> k=43
7 colors:77> k=42
7 colors:77> k=41
7 colors:77> k=40
7 colors:77> k=37
7 colors:77> k=35
7 colors:77> k=32
7 colors:77> k=30
7 colors:77> k=30
7 colors:77> k=28
7 colors:77> k=24
7 colors:77> k=22
7 colors:77> k=22
7 colors:77> k=07
7 colors:77> k=04
7 colors:77> k=03
7 colors:77> k=02
7 colors:77> k=00
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=254
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=251
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=240
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=235
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=232
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=229
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=226
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=223
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=221
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=216
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=201
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=159
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=157
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=148
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=142
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=140
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=138
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=132
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=125
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=111
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=109
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=107
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=098
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=096
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=092
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=090
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=081
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=078
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=076
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=066
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=064
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=057
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=051
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=049
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=044
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=041
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=024
7 /Users/matt/.oh-my-zsh/lib/spectrum.zsh:16> color=021
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:160> svc=''
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (postpattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (pattern)
6 compdef:139> case  (*)
6 compdef:83> case postpattern (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:83> case  (key)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case n (n)
6 compdef:15> case P (n)
6 colors:113> k=bg-magenta
6 colors:113> k=bg-cyan
6 colors:113> k=bg-black
6 colors:104> k=fg-white
6 colors:104> k=fg-magenta
6 colors:104> k=fg-cyan
6 colors:81> k=37
6 colors:81> k=36
6 colors:81> k=35
6 colors:81> k=32
6 colors:81> k=31
6 colors:81> k=31
6 colors:77> k=40
6 colors:77> k=36
6 colors:77> k=35
6 colors:77> k=34
6 colors:77> k=28
6 colors:77> k=27
6 colors:77> k=05
6 colors:77> k=04
6 colors:77> k=03
6 colors:77> k=02
6 colors:77> k=01
-32372 /Users/matt/.zshrc:322> dirname /usr/local/anaconda3/bin
-32043 is-at-least:33> [[ 5 = *[0-9][^0-9]* ]]
-15794 /usr/local/opt/asdf/libexec/asdf.sh:15> dirname /usr/local/opt/asdf/libexec/a...
-15517 /usr/local/share/antigen/antigen.zsh:21> cat /Users/matt/.antigen/.resources
-7738 iterm2_print_state_data:3> hostname -f
-3229 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:100> scutil --get ComputerName
-1064 compdump:107> typeset +fm '_*'
-1019 current_epoch:2> echo 19134
-953 /Users/matt/.oh-my-zsh/cache/fasd-init-cache:74> zstyle -L ':completion:*' co...
-921 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:111> git rev-parse HEAD
-868 /Users/matt/.oh-my-zsh/plugins/git/git.plugin.zsh:3> git version
-815 (anon):8> zstat +mtime /Users/matt/.oh-my-zsh/log/update.lock
-92 compdef:95> read -A opt
-84 -antigen-cache-generate:64> rsrc=/Users/matt/.zshrc
-24 compdef:122> read -A opt
-22 /Users/matt/.oh-my-zsh/oh-my-zsh.sh:133> ((    ))
-16 LOG:1> local PREFIX='[LOG][1653210539.1528389454]'
-7 is-at-least:48> true
-5 is-at-least:50> [[ 5 = <-> ]]"""

# %%
def tryparse(x):
    try:
        return int(x) / 10 ** 6
    except ValueError:
        return 0

# %%
timings = seq(timings_raw.splitlines()).map(lambda x: x.split()[0]).map(tryparse)

# %%
sum = timings.sum()

# %%
sum
# Out:
# 3.1630810000008656

# %%
count = 0
res = sum
for timing in timings:
    res -= timing
    if res <= 0.5:
        break
    count += 1
print(count)
# Out:
# 28728

# %%
list(zip(timings, seq(timings_raw.splitlines()).map(lambda x: x.split(' ', 1)[1])))[:count]
# Out:
# [(0.128085,
#   'compdump:107> _d_als=( _deno _asdf _aws _brew _brew_services _cockroach _deno...'),
#  (0.101182,
#   '(eval):1> emulate -L zsh -o no_hist_expand -o extended_glob -o no_prompt_bang...'),
#  (0.055804, 'compaudit:154> _i_wfiles=( )'),
#  (0.034165,
#   "/Users/matt/.zshrc:322> PATH='/usr/local/anaconda3/condabin:/Users/matt/.asdf..."),
#  (0.034083, '/Users/matt/.zshrc:511> /usr/libexec/java_home -v 17'),
#  (0.032074, 'handle_completion_insecurities:13> insecure_dirs=( )'),
#  (0.027076,
#   '/Users/matt/.oh-my-zsh/plugins/zshfl/zshfl.plugin.zsh:17> compaudit'),
#  (0.025117, '/Users/matt/.zshrc:425> xcrun --show-sdk-path'),
#  (0.021932,
#   'compaudit:60> _i_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/...'),
#  (0.020789,
#   'compdump:26> _d_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/l...'),
#  (0.020462,
#   'compaudit:60> _i_files=( /Users/matt/.oh-my-zsh/cache/completions/_deno /usr/...'),
#  (0.017807,
# ...
